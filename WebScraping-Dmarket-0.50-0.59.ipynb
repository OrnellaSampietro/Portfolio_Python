# %%
import random
import time
from time import sleep
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.chrome.options import Options
from keyboard import press
import pandas as pd
import requests
from bs4 import BeautifulSoup as b
import scrapy
from scrapy.http import HtmlResponse
import csv

# %% [markdown]
# -------------------------------

# %% [markdown]
# ## CODIGO COMPLETO

# %% [markdown]
# -------------------------------------------------

# %%
driver = webdriver.Chrome('./chromedriver.exe')

driver.maximize_window()

driver.get('https://www.dmarket.net/Login')

mBox = driver.find_element("xpath", '//*[@id="username"]')
mBox.send_keys("info@mysterydiamonds.com")

mBox = driver.find_element("xpath", '//*[@id="password"]')
mBox.send_keys("sasha0417")

time.sleep(60)

WebDriverWait(driver,20).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="form-container"]/div/form/div[5]/div/button'))).click()

time.sleep(10)

try:
    WebDriverWait(driver,20).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="ReactPopupContainer"]/div/div/div[1]/div/div/div/div/div/button'))).click()
    pass
except:
    pass
WebDriverWait(driver,20).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="dmarket-new-menu"]/ul/li[2]/a'))).click()

time.sleep(3)

WebDriverWait(driver,20).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="inventory"]/div/div/div[3]/div[2]/div[1]/div[1]/div[2]/div'))).click()

try:
    WebDriverWait(driver,20).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="ReactPopupContainer"]/div/div/div[1]/div/div/div/div/div/button'))).click()
    pass
except:
    pass

Color = ["D", "E","F", "G", "H", "I", "J", "K", "L-M" ]
Clarity = ["IF", "VVS1", "VVS2", "VS1", "VS2", "SI1", "SI2", "I1"]
Shape = ["BR", "OV", "PR", "PS", "RAD","EC", "MQ", "CUB", "CUM"]

for k in Shape:
    for i in Color: 
        for j in Clarity:

            if k == "BR":
                WebDriverWait(driver,20).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="inventory"]/div/div/div[3]/div[1]/div/div[2]/div[1]/div/ul/li[2]/img'))).click()
            if k == "EC":
                WebDriverWait(driver,20).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="inventory"]/div/div/div[3]/div[1]/div/div[2]/div[1]/div/ul/li[5]/img'))).click()
            if k == "MQ":
                WebDriverWait(driver,20).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="inventory"]/div/div/div[3]/div[1]/div/div[2]/div[1]/div/ul/li[11]/img'))).click()
            if k == "OV":
                WebDriverWait(driver,20).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="inventory"]/div/div/div[3]/div[1]/div/div[2]/div[1]/div/ul/li[7]/img'))).click()
            if k == "PR":
                WebDriverWait(driver,20).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="inventory"]/div/div/div[3]/div[1]/div/div[2]/div[1]/div/ul/li[3]/img'))).click()
            if k == "PS":
                WebDriverWait(driver,20).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="inventory"]/div/div/div[3]/div[1]/div/div[2]/div[1]/div/ul/li[9]/img'))).click()
            if k == "RAD":
                WebDriverWait(driver,20).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="inventory"]/div/div/div[3]/div[1]/div/div[2]/div[1]/div/ul/li[8]/img'))).click()
            if k == "CUB":
                WebDriverWait(driver,20).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="inventory"]/div/div/div[3]/div[1]/div/div[2]/div[1]/div/ul/li[4]/img'))).click()
            if k == "CUM":
                WebDriverWait(driver,20).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="inventory"]/div/div/div[3]/div[1]/div/div[2]/div[1]/div/ul/li[4]/img'))).click()
            

            if i == "D" :
                WebDriverWait(driver,20).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="inventory"]/div/div/div[3]/div[1]/div/div[2]/div[1]/ul[1]/li[10]/span'))).click()
            elif i == "E":
                WebDriverWait(driver,20).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="inventory"]/div/div/div[3]/div[1]/div/div[2]/div[1]/ul[1]/li[9]/span'))).click()
            elif i == "F":
                WebDriverWait(driver,20).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="inventory"]/div/div/div[3]/div[1]/div/div[2]/div[1]/ul[1]/li[8]/span'))).click()
            elif i == "G":
                WebDriverWait(driver,20).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="inventory"]/div/div/div[3]/div[1]/div/div[2]/div[1]/ul[1]/li[7]/span'))).click()
            elif i == "H":
                WebDriverWait(driver,20).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="inventory"]/div/div/div[3]/div[1]/div/div[2]/div[1]/ul[1]/li[6]/span'))).click()
            elif i == "I":
                WebDriverWait(driver,20).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="inventory"]/div/div/div[3]/div[1]/div/div[2]/div[1]/ul[1]/li[5]/span'))).click()
            elif i == "J":
                WebDriverWait(driver,20).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="inventory"]/div/div/div[3]/div[1]/div/div[2]/div[1]/ul[1]/li[4]/span'))).click()
            elif i == "K":
                WebDriverWait(driver,20).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="inventory"]/div/div/div[3]/div[1]/div/div[2]/div[1]/ul[1]/li[3]/span'))).click()
            else:
                WebDriverWait(driver,20).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="inventory"]/div/div/div[3]/div[1]/div/div[2]/div[1]/ul[1]/li[2]/span'))).click()    


            if j == "IF":
                WebDriverWait(driver,20).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="inventory"]/div/div/div[3]/div[1]/div/div[2]/div[1]/ul[2]/li[9]/span'))).click()
            elif j == "VVS1":
                WebDriverWait(driver,20).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="inventory"]/div/div/div[3]/div[1]/div/div[2]/div[1]/ul[2]/li[8]/span'))).click()
            elif j == "VVS2":
                WebDriverWait(driver,20).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="inventory"]/div/div/div[3]/div[1]/div/div[2]/div[1]/ul[2]/li[7]/span'))).click()
            elif j == "VS1":
                WebDriverWait(driver,20).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="inventory"]/div/div/div[3]/div[1]/div/div[2]/div[1]/ul[2]/li[6]/span'))).click()
            elif j == "VS2":
                WebDriverWait(driver,20).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="inventory"]/div/div/div[3]/div[1]/div/div[2]/div[1]/ul[2]/li[5]/span'))).click()
            elif j == "SI1":
                WebDriverWait(driver,20).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="inventory"]/div/div/div[3]/div[1]/div/div[2]/div[1]/ul[2]/li[4]/span'))).click()
            elif j == "SI2":
                WebDriverWait(driver,20).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="inventory"]/div/div/div[3]/div[1]/div/div[2]/div[1]/ul[2]/li[3]/span'))).click()
            else:
                WebDriverWait(driver,20).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="inventory"]/div/div/div[3]/div[1]/div/div[2]/div[1]/ul[2]/li[2]/span'))).click()
            
            time.sleep(10)
            WebDriverWait(driver,20).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="inventory"]/div/div/div[3]/div[1]/div/div[3]/div[1]/div/div/span[3]/ul/li[3]/span[1]'))).click()
            time.sleep(30)
            WebDriverWait(driver,20).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="inventory"]/div/div/div[3]/div[1]/div/div[3]/div[1]/div/div/span[3]/ul/li[3]/div/div/div/ul/li[1]'))).click()
            WebDriverWait(driver,20).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="inventory"]/div/div/div[3]/div[1]/div/div[3]/div[1]/div/div/span[3]/ul/li[3]/div/div/div/ul/li[3]'))).click()
            time.sleep(10)
            #WebDriverWait(driver,20).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="inventory"]/div/div/div[3]/div[1]/div/div[2]/div[2]/div[2]/div[2]/div/div[2]/span[1]'))).click()
            mBox1 = driver.find_element('xpath', '/html/body/div/div[1]/div[2]/div/div/div[3]/div[1]/div/div[2]/div[2]/div[2]/div[2]/div/div[2]/span[1]/input')
            mBox1.send_keys(Keys.CONTROL, 'a')
            mBox1.send_keys(Keys.DELETE)
            mBox1 = driver.find_element('xpath', '/html/body/div/div[1]/div[2]/div/div/div[3]/div[1]/div/div[2]/div[2]/div[2]/div[2]/div/div[2]/span[1]/input') 
            mBox1.send_keys("0.50")
            ActionChains(driver).key_down(Keys.ENTER).key_up(Keys.ENTER).perform()
            time.sleep(2)
            ActionChains(driver).key_down(Keys.TAB).key_up(Keys.TAB).perform()
            mBox1 = driver.find_element('xpath', '/html/body/div/div[1]/div[2]/div/div/div[3]/div[1]/div/div[2]/div[2]/div[2]/div[2]/div/div[2]/span[2]/input') 
            mBox1.send_keys("0.59")
            ActionChains(driver).key_down(Keys.ENTER).key_up(Keys.ENTER).perform()
            
            time.sleep(5)
            
            if i == "D" and j == "IF" and k == "BR":
                WebDriverWait(driver,20).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="inventory"]/div/div/div[3]/div[2]/div[2]/div[2]/div[1]/div[1]/div/div[16]'))).click()            
            
            time.sleep(2)
            
            result = WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH, '//*[@id="inventory"]/div/div/div[3]/div[2]/div[2]/div[1]/div/div[1]/div[1]/div[1]/div[2]')))
            res = result.text
            
            try:
                WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH, '/html/body/div/div[1]/div[2]/div/div/div[3]/div[2]/div[2]/div[2]/div[1]/div[2]/div[9]/div/div[16]'))) #'//tbody/tr[9]'
                print("df_050_059_",k,"_",j,"_",i,",")
                
                #Num1
                time.sleep(2)
                WebDriverWait(driver,20).until(EC.element_to_be_clickable((By.XPATH, '/html/body/div/div[1]/div[2]/div/div/div[3]/div[2]/div[2]/div[2]/div[1]/div[2]/div[1]/div/div[18]'))).click()
                time.sleep(5)
                primcomp = WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH, '/html/body/div/div[2]/div/div/div[1]/div/div/div/div[2]/div[2]/div[5]/div/div[21]/div[2]/div[2]')))
                primcomp = primcomp.text
                WebDriverWait(driver,20).until(EC.element_to_be_clickable((By.XPATH, '/html/body/div/div[2]/div/div/div[1]/div/span'))).click()
                
                primshap = k

                primcar = WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH, '/html/body/div/div[1]/div[2]/div/div/div[3]/div[2]/div[2]/div[2]/div[1]/div[2]/div[1]/div/div[4]')))
                primcar = primcar.text

                primcol = WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH, '/html/body/div/div[1]/div[2]/div/div/div[3]/div[2]/div[2]/div[2]/div[1]/div[2]/div[1]/div/div[5]')))
                primcol = primcol.text

                primclar = WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH, '/html/body/div/div[1]/div[2]/div/div/div[3]/div[2]/div[2]/div[2]/div[1]/div[2]/div[1]/div/div[6]')))
                primclar = primclar.text

                primcut = WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH, '/html/body/div/div[1]/div[2]/div/div/div[3]/div[2]/div[2]/div[2]/div[1]/div[2]/div[1]/div/div[7]')))
                primcut = primcut.text

                primpol = WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH, '/html/body/div/div[1]/div[2]/div/div/div[3]/div[2]/div[2]/div[2]/div[1]/div[2]/div[1]/div/div[8]')))
                primpol = primpol.text

                primsym = WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH, '/html/body/div/div[1]/div[2]/div/div/div[3]/div[2]/div[2]/div[2]/div[1]/div[2]/div[1]/div/div[9]')))
                primsym = primsym.text

                #primrat = WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH, '//tbody/tr[1]/td[13]')))
                #primrat = primrat.text

                primdesc = WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH, '/html/body/div/div[1]/div[2]/div/div/div[3]/div[2]/div[2]/div[2]/div[1]/div[2]/div[1]/div/div[16]/div')))
                primdesc = primdesc.text
                primdesc = primdesc.replace('$', '')
                primdesc = primdesc.replace(',', '')

                #primtotal = primcar * primdesc
                
                #Num4
                driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
                time.sleep(2)
                WebDriverWait(driver,20).until(EC.element_to_be_clickable((By.XPATH, '/html/body/div/div[1]/div[2]/div/div/div[3]/div[2]/div[2]/div[2]/div[1]/div[2]/div[4]/div/div[18]'))).click()
                time.sleep(5)
                cuarcomp = WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH, '/html/body/div/div[2]/div/div/div[1]/div/div/div/div[2]/div[2]/div[5]/div/div[21]/div[2]/div[2]')))
                cuarcomp = cuarcomp.text
                WebDriverWait(driver,20).until(EC.element_to_be_clickable((By.XPATH, '/html/body/div/div[2]/div/div/div[1]/div/span'))).click()

                cuarshap = k

                cuarcar = WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH, '/html/body/div/div[1]/div[2]/div/div/div[3]/div[2]/div[2]/div[2]/div[1]/div[2]/div[4]/div/div[4]')))
                cuarcar = cuarcar.text

                cuarcol = WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH, '/html/body/div/div[1]/div[2]/div/div/div[3]/div[2]/div[2]/div[2]/div[1]/div[2]/div[4]/div/div[5]')))
                cuarcol = cuarcol.text

                cuarclar = WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH, '/html/body/div/div[1]/div[2]/div/div/div[3]/div[2]/div[2]/div[2]/div[1]/div[2]/div[4]/div/div[6]')))
                cuarclar = cuarclar.text

                cuarcut = WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH, '/html/body/div/div[1]/div[2]/div/div/div[3]/div[2]/div[2]/div[2]/div[1]/div[2]/div[4]/div/div[7]')))
                cuarcut = cuarcut.text

                cuarpol = WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH, '/html/body/div/div[1]/div[2]/div/div/div[3]/div[2]/div[2]/div[2]/div[1]/div[2]/div[4]/div/div[8]')))
                cuarpol = cuarpol.text

                cuarsym = WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH, '/html/body/div/div[1]/div[2]/div/div/div[3]/div[2]/div[2]/div[2]/div[1]/div[2]/div[4]/div/div[9]')))
                cuarsym = cuarsym.text

                #cuarrat = WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH, '//tbody/tr[4]/td[13]')))
                #cuarrat = cuarrat.text

                cuardesc = WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH, '/html/body/div/div[1]/div[2]/div/div/div[3]/div[2]/div[2]/div[2]/div[1]/div[2]/div[4]/div/div[16]/div')))
                cuardesc = cuardesc.text
                cuardesc = cuardesc.replace('$', '')
                cuardesc = cuardesc.replace(',', '')

                #cuartotal = cuarcar * cuardesc
                
                #Num9
                time.sleep(2)
                WebDriverWait(driver,20).until(EC.element_to_be_clickable((By.XPATH, '/html/body/div/div[1]/div[2]/div/div/div[3]/div[2]/div[2]/div[2]/div[1]/div[2]/div[9]/div/div[18]'))).click()
                time.sleep(5)
                novcomp = WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH, '/html/body/div/div[2]/div/div/div[1]/div/div/div/div[2]/div[2]/div[5]/div/div[21]/div[2]/div[2]')))
                novcomp = novcomp.text
                WebDriverWait(driver,20).until(EC.element_to_be_clickable((By.XPATH, '/html/body/div/div[2]/div/div/div[1]/div/span'))).click()


                novshap = k

                novcar = WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH, '/html/body/div/div[1]/div[2]/div/div/div[3]/div[2]/div[2]/div[2]/div[1]/div[2]/div[9]/div/div[4]')))
                novcar = novcar.text

                novcol = WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH, '/html/body/div/div[1]/div[2]/div/div/div[3]/div[2]/div[2]/div[2]/div[1]/div[2]/div[9]/div/div[5]')))
                novcol = novcol.text

                novclar = WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH, '/html/body/div/div[1]/div[2]/div/div/div[3]/div[2]/div[2]/div[2]/div[1]/div[2]/div[9]/div/div[6]')))
                novclar = novclar.text

                novcut = WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH, '/html/body/div/div[1]/div[2]/div/div/div[3]/div[2]/div[2]/div[2]/div[1]/div[2]/div[9]/div/div[7]')))
                novcut = novcut.text

                novpol = WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH, '/html/body/div/div[1]/div[2]/div/div/div[3]/div[2]/div[2]/div[2]/div[1]/div[2]/div[9]/div/div[8]')))
                novpol = novpol.text

                novsym = WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH, '/html/body/div/div[1]/div[2]/div/div/div[3]/div[2]/div[2]/div[2]/div[1]/div[2]/div[9]/div/div[9]')))
                novsym = novsym.text

                #novrat = WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH, '//tbody/tr[9]/td[13]')))
                #novrat = novrat.text

                novdesc = WebDriverWait(driver,20).until(EC.presence_of_element_located((By.XPATH, '/html/body/div/div[1]/div[2]/div/div/div[3]/div[2]/div[2]/div[2]/div[1]/div[2]/div[9]/div/div[16]/div')))
                novdesc = novdesc.text
                novdesc = novdesc.replace('$', '')
                novdesc = novdesc.replace(',', '')

                #novtotal = novcar * novdesc
                
                listwtrange = ["0.50-0.59","0.50-0.59","0.50-0.59" ]
                listcom = [primcomp, cuarcomp, novcomp]
                listshap = [primshap, cuarshap, novshap]
                listcar = [primcar, cuarcar, novcar]
                listcol = [primcol, cuarcol, novcol]
                listclar = [primclar, cuarclar, novclar]
                listcut = [primcut, cuarcut, novcut]
                listpol = [primpol, cuarpol, novpol]
                listsym = [primsym, cuarsym, novsym]
                listrat = [0,0,0]
                listdesc = [primdesc, cuardesc, novdesc]
                listtotal = [0, 0, 0]
                
                print("finish part 1")
                
                if i=="D" and j == "IF" and k == "BR":
                    df_050_059_BR_IF_D = pd.DataFrame()
                    df_050_059_BR_IF_D ['Wt Range'] = None
                    df_050_059_BR_IF_D  = df_050_059_BR_IF_D.assign(Company=None)
                    df_050_059_BR_IF_D  = df_050_059_BR_IF_D.assign(Shape=None)
                    df_050_059_BR_IF_D  = df_050_059_BR_IF_D.assign(Carat=None)
                    df_050_059_BR_IF_D  = df_050_059_BR_IF_D.assign(Color=None)
                    df_050_059_BR_IF_D  = df_050_059_BR_IF_D.assign(Clarity=None)
                    df_050_059_BR_IF_D  = df_050_059_BR_IF_D.assign(Cut=None)
                    df_050_059_BR_IF_D  = df_050_059_BR_IF_D.assign(Polish=None)
                    df_050_059_BR_IF_D  = df_050_059_BR_IF_D.assign(Symmetry=None)
                    df_050_059_BR_IF_D  = df_050_059_BR_IF_D.assign(Ratio=None)
                    df_050_059_BR_IF_D  = df_050_059_BR_IF_D.assign(PPC=None)
                    df_050_059_BR_IF_D  = df_050_059_BR_IF_D.assign(Total=None)
                    df_050_059_BR_IF_D ['Wt Range'] = listwtrange
                    df_050_059_BR_IF_D ['Company'] = listcom
                    df_050_059_BR_IF_D ['Shape'] = listshap
                    df_050_059_BR_IF_D ['Carat'] = listcar
                    df_050_059_BR_IF_D ['Color'] = listcol
                    df_050_059_BR_IF_D ['Clarity'] = listclar
                    df_050_059_BR_IF_D ['Cut'] = listcut
                    df_050_059_BR_IF_D ['Polish'] = listpol
                    df_050_059_BR_IF_D ['Symmetry'] = listsym
                    df_050_059_BR_IF_D ['Ratio'] = listrat
                    df_050_059_BR_IF_D ['PPC'] = listdesc
                    df_050_059_BR_IF_D ['Total'] = listtotal
                    df_050_059_BR_IF_D['Carat'] = df_050_059_BR_IF_D['Carat'].astype('float64')
                    df_050_059_BR_IF_D['PPC'] = df_050_059_BR_IF_D['PPC'].astype('float64')
                    df_050_059_BR_IF_D['Total'] = df_050_059_BR_IF_D['Total'].astype('float64')
                    df_050_059_BR_IF_D['Total'] = df_050_059_BR_IF_D['Carat'] * df_050_059_BR_IF_D['PPC']



                elif i=="D" and j == "VVS1" and k == "BR" :
                    df_050_059_BR_VVS1_D = pd.DataFrame()
                    df_050_059_BR_VVS1_D ['Wt Range'] = None
                    df_050_059_BR_VVS1_D  = df_050_059_BR_VVS1_D.assign(Company=None)
                    df_050_059_BR_VVS1_D  = df_050_059_BR_VVS1_D.assign(Shape=None)
                    df_050_059_BR_VVS1_D  = df_050_059_BR_VVS1_D.assign(Carat=None)
                    df_050_059_BR_VVS1_D  = df_050_059_BR_VVS1_D.assign(Color=None)
                    df_050_059_BR_VVS1_D  = df_050_059_BR_VVS1_D.assign(Clarity=None)
                    df_050_059_BR_VVS1_D  = df_050_059_BR_VVS1_D.assign(Cut=None)
                    df_050_059_BR_VVS1_D  = df_050_059_BR_VVS1_D.assign(Polish=None)
                    df_050_059_BR_VVS1_D  = df_050_059_BR_VVS1_D.assign(Symmetry=None)
                    df_050_059_BR_VVS1_D  = df_050_059_BR_VVS1_D.assign(Ratio=None)
                    df_050_059_BR_VVS1_D  = df_050_059_BR_VVS1_D.assign(PPC=None)
                    df_050_059_BR_VVS1_D  = df_050_059_BR_VVS1_D.assign(Total=None)
                    df_050_059_BR_VVS1_D ['Wt Range'] = listwtrange
                    df_050_059_BR_VVS1_D ['Company'] = listcom
                    df_050_059_BR_VVS1_D ['Shape'] = listshap
                    df_050_059_BR_VVS1_D ['Carat'] = listcar
                    df_050_059_BR_VVS1_D ['Color'] = listcol
                    df_050_059_BR_VVS1_D ['Clarity'] = listclar
                    df_050_059_BR_VVS1_D ['Cut'] = listcut
                    df_050_059_BR_VVS1_D ['Polish'] = listpol
                    df_050_059_BR_VVS1_D ['Symmetry'] = listsym
                    df_050_059_BR_VVS1_D ['Ratio'] = listrat
                    df_050_059_BR_VVS1_D ['PPC'] = listdesc
                    df_050_059_BR_VVS1_D ['Total'] = listtotal
                    df_050_059_BR_VVS1_D['Carat'] = df_050_059_BR_VVS1_D['Carat'].astype('float64')
                    df_050_059_BR_VVS1_D['PPC'] = df_050_059_BR_VVS1_D['PPC'].astype('float64')
                    df_050_059_BR_VVS1_D['Total'] = df_050_059_BR_VVS1_D['Total'].astype('float64')
                    df_050_059_BR_VVS1_D['Total'] = df_050_059_BR_VVS1_D['Carat'] * df_050_059_BR_VVS1_D['PPC']



                elif i=="D" and j == "VVS2" and k == "BR" :
                    df_050_059_BR_VVS2_D = pd.DataFrame()
                    df_050_059_BR_VVS2_D ['Wt Range'] = None
                    df_050_059_BR_VVS2_D  = df_050_059_BR_VVS2_D.assign(Company=None)
                    df_050_059_BR_VVS2_D  = df_050_059_BR_VVS2_D.assign(Shape=None)
                    df_050_059_BR_VVS2_D  = df_050_059_BR_VVS2_D.assign(Carat=None)
                    df_050_059_BR_VVS2_D  = df_050_059_BR_VVS2_D.assign(Color=None)
                    df_050_059_BR_VVS2_D  = df_050_059_BR_VVS2_D.assign(Clarity=None)
                    df_050_059_BR_VVS2_D  = df_050_059_BR_VVS2_D.assign(Cut=None)
                    df_050_059_BR_VVS2_D  = df_050_059_BR_VVS2_D.assign(Polish=None)
                    df_050_059_BR_VVS2_D  = df_050_059_BR_VVS2_D.assign(Symmetry=None)
                    df_050_059_BR_VVS2_D  = df_050_059_BR_VVS2_D.assign(Ratio=None)
                    df_050_059_BR_VVS2_D  = df_050_059_BR_VVS2_D.assign(PPC=None)
                    df_050_059_BR_VVS2_D  = df_050_059_BR_VVS2_D.assign(Total=None)
                    df_050_059_BR_VVS2_D ['Wt Range'] = listwtrange
                    df_050_059_BR_VVS2_D ['Company'] = listcom
                    df_050_059_BR_VVS2_D ['Shape'] = listshap
                    df_050_059_BR_VVS2_D ['Carat'] = listcar
                    df_050_059_BR_VVS2_D ['Color'] = listcol
                    df_050_059_BR_VVS2_D ['Clarity'] = listclar
                    df_050_059_BR_VVS2_D ['Cut'] = listcut
                    df_050_059_BR_VVS2_D ['Polish'] = listpol
                    df_050_059_BR_VVS2_D ['Symmetry'] = listsym
                    df_050_059_BR_VVS2_D ['Ratio'] = listrat
                    df_050_059_BR_VVS2_D ['PPC'] = listdesc
                    df_050_059_BR_VVS2_D ['Total'] = listtotal
                    df_050_059_BR_VVS2_D['Carat'] = df_050_059_BR_VVS2_D['Carat'].astype('float64')
                    df_050_059_BR_VVS2_D['PPC'] = df_050_059_BR_VVS2_D['PPC'].astype('float64')
                    df_050_059_BR_VVS2_D['Total'] = df_050_059_BR_VVS2_D['Total'].astype('float64')
                    df_050_059_BR_VVS2_D['Total'] = df_050_059_BR_VVS2_D['Carat'] * df_050_059_BR_VVS2_D['PPC']



                elif i=="D" and j == "VS1" and k == "BR":
                    df_050_059_BR_VS1_D = pd.DataFrame()
                    df_050_059_BR_VS1_D ['Wt Range'] = None
                    df_050_059_BR_VS1_D  = df_050_059_BR_VS1_D.assign(Company=None)
                    df_050_059_BR_VS1_D  = df_050_059_BR_VS1_D.assign(Shape=None)
                    df_050_059_BR_VS1_D  = df_050_059_BR_VS1_D.assign(Carat=None)
                    df_050_059_BR_VS1_D  = df_050_059_BR_VS1_D.assign(Color=None)
                    df_050_059_BR_VS1_D  = df_050_059_BR_VS1_D.assign(Clarity=None)
                    df_050_059_BR_VS1_D  = df_050_059_BR_VS1_D.assign(Cut=None)
                    df_050_059_BR_VS1_D  = df_050_059_BR_VS1_D.assign(Polish=None)
                    df_050_059_BR_VS1_D  = df_050_059_BR_VS1_D.assign(Symmetry=None)
                    df_050_059_BR_VS1_D  = df_050_059_BR_VS1_D.assign(Ratio=None)
                    df_050_059_BR_VS1_D  = df_050_059_BR_VS1_D.assign(PPC=None)
                    df_050_059_BR_VS1_D  = df_050_059_BR_VS1_D.assign(Total=None)
                    df_050_059_BR_VS1_D ['Wt Range'] = listwtrange
                    df_050_059_BR_VS1_D ['Company'] = listcom
                    df_050_059_BR_VS1_D ['Shape'] = listshap
                    df_050_059_BR_VS1_D ['Carat'] = listcar
                    df_050_059_BR_VS1_D ['Color'] = listcol
                    df_050_059_BR_VS1_D ['Clarity'] = listclar
                    df_050_059_BR_VS1_D ['Cut'] = listcut
                    df_050_059_BR_VS1_D ['Polish'] = listpol
                    df_050_059_BR_VS1_D ['Symmetry'] = listsym
                    df_050_059_BR_VS1_D ['Ratio'] = listrat
                    df_050_059_BR_VS1_D ['PPC'] = listdesc
                    df_050_059_BR_VS1_D ['Total'] = listtotal
                    df_050_059_BR_VS1_D['Carat'] = df_050_059_BR_VS1_D['Carat'].astype('float64')
                    df_050_059_BR_VS1_D['PPC'] = df_050_059_BR_VS1_D['PPC'].astype('float64')
                    df_050_059_BR_VS1_D['Total'] = df_050_059_BR_VS1_D['Total'].astype('float64')
                    df_050_059_BR_VS1_D['Total'] = df_050_059_BR_VS1_D['Carat'] * df_050_059_BR_VS1_D['PPC']


                elif i=="D" and j == "VS2" and k == "BR":
                    df_050_059_BR_VS2_D = pd.DataFrame()
                    df_050_059_BR_VS2_D ['Wt Range'] = None
                    df_050_059_BR_VS2_D  = df_050_059_BR_VS2_D.assign(Company=None)
                    df_050_059_BR_VS2_D  = df_050_059_BR_VS2_D.assign(Shape=None)
                    df_050_059_BR_VS2_D  = df_050_059_BR_VS2_D.assign(Carat=None)
                    df_050_059_BR_VS2_D  = df_050_059_BR_VS2_D.assign(Color=None)
                    df_050_059_BR_VS2_D  = df_050_059_BR_VS2_D.assign(Clarity=None)
                    df_050_059_BR_VS2_D  = df_050_059_BR_VS2_D.assign(Cut=None)
                    df_050_059_BR_VS2_D  = df_050_059_BR_VS2_D.assign(Polish=None)
                    df_050_059_BR_VS2_D  = df_050_059_BR_VS2_D.assign(Symmetry=None)
                    df_050_059_BR_VS2_D  = df_050_059_BR_VS2_D.assign(Ratio=None)
                    df_050_059_BR_VS2_D  = df_050_059_BR_VS2_D.assign(PPC=None)
                    df_050_059_BR_VS2_D  = df_050_059_BR_VS2_D.assign(Total=None)
                    df_050_059_BR_VS2_D ['Wt Range'] = listwtrange
                    df_050_059_BR_VS2_D ['Company'] = listcom
                    df_050_059_BR_VS2_D ['Shape'] = listshap
                    df_050_059_BR_VS2_D ['Carat'] = listcar
                    df_050_059_BR_VS2_D ['Color'] = listcol
                    df_050_059_BR_VS2_D ['Clarity'] = listclar
                    df_050_059_BR_VS2_D ['Cut'] = listcut
                    df_050_059_BR_VS2_D ['Polish'] = listpol
                    df_050_059_BR_VS2_D ['Symmetry'] = listsym
                    df_050_059_BR_VS2_D ['Ratio'] = listrat
                    df_050_059_BR_VS2_D ['PPC'] = listdesc
                    df_050_059_BR_VS2_D ['Total'] = listtotal
                    df_050_059_BR_VS2_D['Carat'] = df_050_059_BR_VS2_D['Carat'].astype('float64')
                    df_050_059_BR_VS2_D['PPC'] = df_050_059_BR_VS2_D['PPC'].astype('float64')
                    df_050_059_BR_VS2_D['Total'] = df_050_059_BR_VS2_D['Total'].astype('float64')
                    df_050_059_BR_VS2_D['Total'] = df_050_059_BR_VS2_D['Carat'] * df_050_059_BR_VS2_D['PPC']


                elif i=="D" and j == "SI1" and k == "BR":
                    df_050_059_BR_SI1_D = pd.DataFrame()
                    df_050_059_BR_SI1_D ['Wt Range'] = None
                    df_050_059_BR_SI1_D  = df_050_059_BR_SI1_D.assign(Company=None)
                    df_050_059_BR_SI1_D  = df_050_059_BR_SI1_D.assign(Shape=None)
                    df_050_059_BR_SI1_D  = df_050_059_BR_SI1_D.assign(Carat=None)
                    df_050_059_BR_SI1_D  = df_050_059_BR_SI1_D.assign(Color=None)
                    df_050_059_BR_SI1_D  = df_050_059_BR_SI1_D.assign(Clarity=None)
                    df_050_059_BR_SI1_D  = df_050_059_BR_SI1_D.assign(Cut=None)
                    df_050_059_BR_SI1_D  = df_050_059_BR_SI1_D.assign(Polish=None)
                    df_050_059_BR_SI1_D  = df_050_059_BR_SI1_D.assign(Symmetry=None)
                    df_050_059_BR_SI1_D  = df_050_059_BR_SI1_D.assign(Ratio=None)
                    df_050_059_BR_SI1_D  = df_050_059_BR_SI1_D.assign(PPC=None)
                    df_050_059_BR_SI1_D  = df_050_059_BR_SI1_D.assign(Total=None)
                    df_050_059_BR_SI1_D ['Wt Range'] = listwtrange
                    df_050_059_BR_SI1_D ['Company'] = listcom
                    df_050_059_BR_SI1_D ['Shape'] = listshap
                    df_050_059_BR_SI1_D ['Carat'] = listcar
                    df_050_059_BR_SI1_D ['Color'] = listcol
                    df_050_059_BR_SI1_D ['Clarity'] = listclar
                    df_050_059_BR_SI1_D ['Cut'] = listcut
                    df_050_059_BR_SI1_D ['Polish'] = listpol
                    df_050_059_BR_SI1_D ['Symmetry'] = listsym
                    df_050_059_BR_SI1_D ['Ratio'] = listrat
                    df_050_059_BR_SI1_D ['PPC'] = listdesc
                    df_050_059_BR_SI1_D ['Total'] = listtotal
                    df_050_059_BR_SI1_D['Carat'] = df_050_059_BR_SI1_D['Carat'].astype('float64')
                    df_050_059_BR_SI1_D['PPC'] = df_050_059_BR_SI1_D['PPC'].astype('float64')
                    df_050_059_BR_SI1_D['Total'] = df_050_059_BR_SI1_D['Total'].astype('float64')
                    df_050_059_BR_SI1_D['Total'] = df_050_059_BR_SI1_D['Carat'] * df_050_059_BR_SI1_D['PPC']


                elif i=="D" and j == "SI2" and k == "BR":
                    df_050_059_BR_SI2_D = pd.DataFrame()
                    df_050_059_BR_SI2_D ['Wt Range'] = None
                    df_050_059_BR_SI2_D  = df_050_059_BR_SI2_D.assign(Company=None)
                    df_050_059_BR_SI2_D  = df_050_059_BR_SI2_D.assign(Shape=None)
                    df_050_059_BR_SI2_D  = df_050_059_BR_SI2_D.assign(Carat=None)
                    df_050_059_BR_SI2_D  = df_050_059_BR_SI2_D.assign(Color=None)
                    df_050_059_BR_SI2_D  = df_050_059_BR_SI2_D.assign(Clarity=None)
                    df_050_059_BR_SI2_D  = df_050_059_BR_SI2_D.assign(Cut=None)
                    df_050_059_BR_SI2_D  = df_050_059_BR_SI2_D.assign(Polish=None)
                    df_050_059_BR_SI2_D  = df_050_059_BR_SI2_D.assign(Symmetry=None)
                    df_050_059_BR_SI2_D  = df_050_059_BR_SI2_D.assign(Ratio=None)
                    df_050_059_BR_SI2_D  = df_050_059_BR_SI2_D.assign(PPC=None)
                    df_050_059_BR_SI2_D  = df_050_059_BR_SI2_D.assign(Total=None)
                    df_050_059_BR_SI2_D ['Wt Range'] = listwtrange
                    df_050_059_BR_SI2_D ['Company'] = listcom
                    df_050_059_BR_SI2_D ['Shape'] = listshap
                    df_050_059_BR_SI2_D ['Carat'] = listcar
                    df_050_059_BR_SI2_D ['Color'] = listcol
                    df_050_059_BR_SI2_D ['Clarity'] = listclar
                    df_050_059_BR_SI2_D ['Cut'] = listcut
                    df_050_059_BR_SI2_D ['Polish'] = listpol
                    df_050_059_BR_SI2_D ['Symmetry'] = listsym
                    df_050_059_BR_SI2_D ['Ratio'] = listrat
                    df_050_059_BR_SI2_D ['PPC'] = listdesc
                    df_050_059_BR_SI2_D ['Total'] = listtotal
                    df_050_059_BR_SI2_D['Carat'] = df_050_059_BR_SI2_D['Carat'].astype('float64')
                    df_050_059_BR_SI2_D['PPC'] = df_050_059_BR_SI2_D['PPC'].astype('float64')
                    df_050_059_BR_SI2_D['Total'] = df_050_059_BR_SI2_D['Total'].astype('float64')
                    df_050_059_BR_SI2_D['Total'] = df_050_059_BR_SI2_D['Carat'] * df_050_059_BR_SI2_D['PPC']


                elif i=="D" and j == "I1" and k == "BR":
                    df_050_059_BR_I1_D = pd.DataFrame()
                    df_050_059_BR_I1_D ['Wt Range'] = None
                    df_050_059_BR_I1_D  = df_050_059_BR_I1_D.assign(Company=None)
                    df_050_059_BR_I1_D  = df_050_059_BR_I1_D.assign(Shape=None)
                    df_050_059_BR_I1_D  = df_050_059_BR_I1_D.assign(Carat=None)
                    df_050_059_BR_I1_D  = df_050_059_BR_I1_D.assign(Color=None)
                    df_050_059_BR_I1_D  = df_050_059_BR_I1_D.assign(Clarity=None)
                    df_050_059_BR_I1_D  = df_050_059_BR_I1_D.assign(Cut=None)
                    df_050_059_BR_I1_D  = df_050_059_BR_I1_D.assign(Polish=None)
                    df_050_059_BR_I1_D  = df_050_059_BR_I1_D.assign(Symmetry=None)
                    df_050_059_BR_I1_D  = df_050_059_BR_I1_D.assign(Ratio=None)
                    df_050_059_BR_I1_D  = df_050_059_BR_I1_D.assign(PPC=None)
                    df_050_059_BR_I1_D  = df_050_059_BR_I1_D.assign(Total=None)
                    df_050_059_BR_I1_D ['Wt Range'] = listwtrange
                    df_050_059_BR_I1_D ['Company'] = listcom
                    df_050_059_BR_I1_D ['Shape'] = listshap
                    df_050_059_BR_I1_D ['Carat'] = listcar
                    df_050_059_BR_I1_D ['Color'] = listcol
                    df_050_059_BR_I1_D ['Clarity'] = listclar
                    df_050_059_BR_I1_D ['Cut'] = listcut
                    df_050_059_BR_I1_D ['Polish'] = listpol
                    df_050_059_BR_I1_D ['Symmetry'] = listsym
                    df_050_059_BR_I1_D ['Ratio'] = listrat
                    df_050_059_BR_I1_D ['PPC'] = listdesc
                    df_050_059_BR_I1_D ['Total'] = listtotal
                    df_050_059_BR_I1_D['Carat'] = df_050_059_BR_I1_D['Carat'].astype('float64')
                    df_050_059_BR_I1_D['PPC'] = df_050_059_BR_I1_D['PPC'].astype('float64')
                    df_050_059_BR_I1_D['Total'] = df_050_059_BR_I1_D['Total'].astype('float64')
                    df_050_059_BR_I1_D['Total'] = df_050_059_BR_I1_D['Carat'] * df_050_059_BR_I1_D['PPC']


                elif i=="D" and j == "I2" and k == "BR":
                    df_050_059_BR_I2_D = pd.DataFrame()
                    df_050_059_BR_I2_D ['Wt Range'] = None
                    df_050_059_BR_I2_D  = df_050_059_BR_I2_D.assign(Company=None)
                    df_050_059_BR_I2_D  = df_050_059_BR_I2_D.assign(Shape=None)
                    df_050_059_BR_I2_D  = df_050_059_BR_I2_D.assign(Carat=None)
                    df_050_059_BR_I2_D  = df_050_059_BR_I2_D.assign(Color=None)
                    df_050_059_BR_I2_D  = df_050_059_BR_I2_D.assign(Clarity=None)
                    df_050_059_BR_I2_D  = df_050_059_BR_I2_D.assign(Cut=None)
                    df_050_059_BR_I2_D  = df_050_059_BR_I2_D.assign(Polish=None)
                    df_050_059_BR_I2_D  = df_050_059_BR_I2_D.assign(Symmetry=None)
                    df_050_059_BR_I2_D  = df_050_059_BR_I2_D.assign(Ratio=None)
                    df_050_059_BR_I2_D  = df_050_059_BR_I2_D.assign(PPC=None)
                    df_050_059_BR_I2_D  = df_050_059_BR_I2_D.assign(Total=None)
                    df_050_059_BR_I2_D ['Wt Range'] = listwtrange
                    df_050_059_BR_I2_D ['Company'] = listcom
                    df_050_059_BR_I2_D ['Shape'] = listshap
                    df_050_059_BR_I2_D ['Carat'] = listcar
                    df_050_059_BR_I2_D ['Color'] = listcol
                    df_050_059_BR_I2_D ['Clarity'] = listclar
                    df_050_059_BR_I2_D ['Cut'] = listcut
                    df_050_059_BR_I2_D ['Polish'] = listpol
                    df_050_059_BR_I2_D ['Symmetry'] = listsym
                    df_050_059_BR_I2_D ['Ratio'] = listrat
                    df_050_059_BR_I2_D ['PPC'] = listdesc
                    df_050_059_BR_I2_D ['Total'] = listtotal
                    df_050_059_BR_I2_D['Carat'] = df_050_059_BR_I2_D['Carat'].astype('float64')
                    df_050_059_BR_I2_D['PPC'] = df_050_059_BR_I2_D['PPC'].astype('float64')
                    df_050_059_BR_I2_D['Total'] = df_050_059_BR_I2_D['Total'].astype('float64')
                    df_050_059_BR_I2_D['Total'] = df_050_059_BR_I2_D['Carat'] * df_050_059_BR_I2_D['PPC']



                elif i=="E" and j == "IF" and k == "BR":
                    df_050_059_BR_IF_E = pd.DataFrame()
                    df_050_059_BR_IF_E ['Wt Range'] = None
                    df_050_059_BR_IF_E  = df_050_059_BR_IF_E.assign(Company=None)
                    df_050_059_BR_IF_E  = df_050_059_BR_IF_E.assign(Shape=None)
                    df_050_059_BR_IF_E  = df_050_059_BR_IF_E.assign(Carat=None)
                    df_050_059_BR_IF_E  = df_050_059_BR_IF_E.assign(Color=None)
                    df_050_059_BR_IF_E  = df_050_059_BR_IF_E.assign(Clarity=None)
                    df_050_059_BR_IF_E  = df_050_059_BR_IF_E.assign(Cut=None)
                    df_050_059_BR_IF_E  = df_050_059_BR_IF_E.assign(Polish=None)
                    df_050_059_BR_IF_E  = df_050_059_BR_IF_E.assign(Symmetry=None)
                    df_050_059_BR_IF_E  = df_050_059_BR_IF_E.assign(Ratio=None)
                    df_050_059_BR_IF_E  = df_050_059_BR_IF_E.assign(PPC=None)
                    df_050_059_BR_IF_E  = df_050_059_BR_IF_E.assign(Total=None)
                    df_050_059_BR_IF_E ['Wt Range'] = listwtrange
                    df_050_059_BR_IF_E ['Company'] = listcom
                    df_050_059_BR_IF_E ['Shape'] = listshap
                    df_050_059_BR_IF_E ['Carat'] = listcar
                    df_050_059_BR_IF_E ['Color'] = listcol
                    df_050_059_BR_IF_E ['Clarity'] = listclar
                    df_050_059_BR_IF_E ['Cut'] = listcut
                    df_050_059_BR_IF_E ['Polish'] = listpol
                    df_050_059_BR_IF_E ['Symmetry'] = listsym
                    df_050_059_BR_IF_E ['Ratio'] = listrat
                    df_050_059_BR_IF_E ['PPC'] = listdesc
                    df_050_059_BR_IF_E ['Total'] = listtotal
                    df_050_059_BR_IF_E['Carat'] = df_050_059_BR_IF_E['Carat'].astype('float64')
                    df_050_059_BR_IF_E['PPC'] = df_050_059_BR_IF_E['PPC'].astype('float64')
                    df_050_059_BR_IF_E['Total'] = df_050_059_BR_IF_E['Total'].astype('float64')
                    df_050_059_BR_IF_E['Total'] = df_050_059_BR_IF_E['Carat'] * df_050_059_BR_IF_E['PPC']



                elif i=="E" and j == "VVS1" and k == "BR":
                    df_050_059_BR_VVS1_E = pd.DataFrame()
                    df_050_059_BR_VVS1_E ['Wt Range'] = None
                    df_050_059_BR_VVS1_E  = df_050_059_BR_VVS1_E.assign(Company=None)
                    df_050_059_BR_VVS1_E  = df_050_059_BR_VVS1_E.assign(Shape=None)
                    df_050_059_BR_VVS1_E  = df_050_059_BR_VVS1_E.assign(Carat=None)
                    df_050_059_BR_VVS1_E  = df_050_059_BR_VVS1_E.assign(Color=None)
                    df_050_059_BR_VVS1_E  = df_050_059_BR_VVS1_E.assign(Clarity=None)
                    df_050_059_BR_VVS1_E  = df_050_059_BR_VVS1_E.assign(Cut=None)
                    df_050_059_BR_VVS1_E  = df_050_059_BR_VVS1_E.assign(Polish=None)
                    df_050_059_BR_VVS1_E  = df_050_059_BR_VVS1_E.assign(Symmetry=None)
                    df_050_059_BR_VVS1_E  = df_050_059_BR_VVS1_E.assign(Ratio=None)
                    df_050_059_BR_VVS1_E  = df_050_059_BR_VVS1_E.assign(PPC=None)
                    df_050_059_BR_VVS1_E  = df_050_059_BR_VVS1_E.assign(Total=None)
                    df_050_059_BR_VVS1_E ['Wt Range'] = listwtrange
                    df_050_059_BR_VVS1_E ['Company'] = listcom
                    df_050_059_BR_VVS1_E ['Shape'] = listshap
                    df_050_059_BR_VVS1_E ['Carat'] = listcar
                    df_050_059_BR_VVS1_E ['Color'] = listcol
                    df_050_059_BR_VVS1_E ['Clarity'] = listclar
                    df_050_059_BR_VVS1_E ['Cut'] = listcut
                    df_050_059_BR_VVS1_E ['Polish'] = listpol
                    df_050_059_BR_VVS1_E ['Symmetry'] = listsym
                    df_050_059_BR_VVS1_E ['Ratio'] = listrat
                    df_050_059_BR_VVS1_E ['PPC'] = listdesc
                    df_050_059_BR_VVS1_E ['Total'] = listtotal
                    df_050_059_BR_VVS1_E['Carat'] = df_050_059_BR_VVS1_E['Carat'].astype('float64')
                    df_050_059_BR_VVS1_E['PPC'] = df_050_059_BR_VVS1_E['PPC'].astype('float64')
                    df_050_059_BR_VVS1_E['Total'] = df_050_059_BR_VVS1_E['Total'].astype('float64')
                    df_050_059_BR_VVS1_E['Total'] = df_050_059_BR_VVS1_E['Carat'] * df_050_059_BR_VVS1_E['PPC']


                elif i=="E" and j == "VVS2" and k == "BR":
                    df_050_059_BR_VVS2_E = pd.DataFrame()
                    df_050_059_BR_VVS2_E ['Wt Range'] = None
                    df_050_059_BR_VVS2_E  = df_050_059_BR_VVS2_E.assign(Company=None)
                    df_050_059_BR_VVS2_E  = df_050_059_BR_VVS2_E.assign(Shape=None)
                    df_050_059_BR_VVS2_E  = df_050_059_BR_VVS2_E.assign(Carat=None)
                    df_050_059_BR_VVS2_E  = df_050_059_BR_VVS2_E.assign(Color=None)
                    df_050_059_BR_VVS2_E  = df_050_059_BR_VVS2_E.assign(Clarity=None)
                    df_050_059_BR_VVS2_E  = df_050_059_BR_VVS2_E.assign(Cut=None)
                    df_050_059_BR_VVS2_E  = df_050_059_BR_VVS2_E.assign(Polish=None)
                    df_050_059_BR_VVS2_E  = df_050_059_BR_VVS2_E.assign(Symmetry=None)
                    df_050_059_BR_VVS2_E  = df_050_059_BR_VVS2_E.assign(Ratio=None)
                    df_050_059_BR_VVS2_E  = df_050_059_BR_VVS2_E.assign(PPC=None)
                    df_050_059_BR_VVS2_E  = df_050_059_BR_VVS2_E.assign(Total=None)
                    df_050_059_BR_VVS2_E ['Wt Range'] = listwtrange
                    df_050_059_BR_VVS2_E ['Company'] = listcom
                    df_050_059_BR_VVS2_E ['Shape'] = listshap
                    df_050_059_BR_VVS2_E ['Carat'] = listcar
                    df_050_059_BR_VVS2_E ['Color'] = listcol
                    df_050_059_BR_VVS2_E ['Clarity'] = listclar
                    df_050_059_BR_VVS2_E ['Cut'] = listcut
                    df_050_059_BR_VVS2_E ['Polish'] = listpol
                    df_050_059_BR_VVS2_E ['Symmetry'] = listsym
                    df_050_059_BR_VVS2_E ['Ratio'] = listrat
                    df_050_059_BR_VVS2_E ['PPC'] = listdesc
                    df_050_059_BR_VVS2_E ['Total'] = listtotal
                    df_050_059_BR_VVS2_E['Carat'] = df_050_059_BR_VVS2_E['Carat'].astype('float64')
                    df_050_059_BR_VVS2_E['PPC'] = df_050_059_BR_VVS2_E['PPC'].astype('float64')
                    df_050_059_BR_VVS2_E['Total'] = df_050_059_BR_VVS2_E['Total'].astype('float64')
                    df_050_059_BR_VVS2_E['Total'] = df_050_059_BR_VVS2_E['Carat'] * df_050_059_BR_VVS2_E['PPC']


                elif i=="E" and j=="VS1" and k == "BR":
                    df_050_059_BR_VS1_E = pd.DataFrame()
                    df_050_059_BR_VS1_E ['Wt Range'] = None
                    df_050_059_BR_VS1_E  = df_050_059_BR_VS1_E.assign(Company=None)
                    df_050_059_BR_VS1_E  = df_050_059_BR_VS1_E.assign(Shape=None)
                    df_050_059_BR_VS1_E  = df_050_059_BR_VS1_E.assign(Carat=None)
                    df_050_059_BR_VS1_E  = df_050_059_BR_VS1_E.assign(Color=None)
                    df_050_059_BR_VS1_E  = df_050_059_BR_VS1_E.assign(Clarity=None)
                    df_050_059_BR_VS1_E  = df_050_059_BR_VS1_E.assign(Cut=None)
                    df_050_059_BR_VS1_E  = df_050_059_BR_VS1_E.assign(Polish=None)
                    df_050_059_BR_VS1_E  = df_050_059_BR_VS1_E.assign(Symmetry=None)
                    df_050_059_BR_VS1_E  = df_050_059_BR_VS1_E.assign(Ratio=None)
                    df_050_059_BR_VS1_E  = df_050_059_BR_VS1_E.assign(PPC=None)
                    df_050_059_BR_VS1_E  = df_050_059_BR_VS1_E.assign(Total=None)
                    df_050_059_BR_VS1_E ['Wt Range'] = listwtrange
                    df_050_059_BR_VS1_E ['Company'] = listcom
                    df_050_059_BR_VS1_E ['Shape'] = listshap
                    df_050_059_BR_VS1_E ['Carat'] = listcar
                    df_050_059_BR_VS1_E ['Color'] = listcol
                    df_050_059_BR_VS1_E ['Clarity'] = listclar
                    df_050_059_BR_VS1_E ['Cut'] = listcut
                    df_050_059_BR_VS1_E ['Polish'] = listpol
                    df_050_059_BR_VS1_E ['Symmetry'] = listsym
                    df_050_059_BR_VS1_E ['Ratio'] = listrat
                    df_050_059_BR_VS1_E ['PPC'] = listdesc
                    df_050_059_BR_VS1_E ['Total'] = listtotal
                    df_050_059_BR_VS1_E['Carat'] = df_050_059_BR_VS1_E['Carat'].astype('float64')
                    df_050_059_BR_VS1_E['PPC'] = df_050_059_BR_VS1_E['PPC'].astype('float64')
                    df_050_059_BR_VS1_E['Total'] = df_050_059_BR_VS1_E['Total'].astype('float64')
                    df_050_059_BR_VS1_E['Total'] = df_050_059_BR_VS1_E['Carat'] * df_050_059_BR_VS1_E['PPC']


                elif i=="E" and j == "VS2" and k == "BR":
                    df_050_059_BR_VS2_E = pd.DataFrame()
                    df_050_059_BR_VS2_E ['Wt Range'] = None
                    df_050_059_BR_VS2_E  = df_050_059_BR_VS2_E.assign(Company=None)
                    df_050_059_BR_VS2_E  = df_050_059_BR_VS2_E.assign(Shape=None)
                    df_050_059_BR_VS2_E  = df_050_059_BR_VS2_E.assign(Carat=None)
                    df_050_059_BR_VS2_E  = df_050_059_BR_VS2_E.assign(Color=None)
                    df_050_059_BR_VS2_E  = df_050_059_BR_VS2_E.assign(Clarity=None)
                    df_050_059_BR_VS2_E  = df_050_059_BR_VS2_E.assign(Cut=None)
                    df_050_059_BR_VS2_E  = df_050_059_BR_VS2_E.assign(Polish=None)
                    df_050_059_BR_VS2_E  = df_050_059_BR_VS2_E.assign(Symmetry=None)
                    df_050_059_BR_VS2_E  = df_050_059_BR_VS2_E.assign(Ratio=None)
                    df_050_059_BR_VS2_E  = df_050_059_BR_VS2_E.assign(PPC=None)
                    df_050_059_BR_VS2_E  = df_050_059_BR_VS2_E.assign(Total=None)
                    df_050_059_BR_VS2_E ['Wt Range'] = listwtrange
                    df_050_059_BR_VS2_E ['Company'] = listcom
                    df_050_059_BR_VS2_E ['Shape'] = listshap
                    df_050_059_BR_VS2_E ['Carat'] = listcar
                    df_050_059_BR_VS2_E ['Color'] = listcol
                    df_050_059_BR_VS2_E ['Clarity'] = listclar
                    df_050_059_BR_VS2_E ['Cut'] = listcut
                    df_050_059_BR_VS2_E ['Polish'] = listpol
                    df_050_059_BR_VS2_E ['Symmetry'] = listsym
                    df_050_059_BR_VS2_E ['Ratio'] = listrat
                    df_050_059_BR_VS2_E ['PPC'] = listdesc
                    df_050_059_BR_VS2_E ['Total'] = listtotal
                    df_050_059_BR_VS2_E['Carat'] = df_050_059_BR_VS2_E['Carat'].astype('float64')
                    df_050_059_BR_VS2_E['PPC'] = df_050_059_BR_VS2_E['PPC'].astype('float64')
                    df_050_059_BR_VS2_E['Total'] = df_050_059_BR_VS2_E['Total'].astype('float64')
                    df_050_059_BR_VS2_E['Total'] = df_050_059_BR_VS2_E['Carat'] * df_050_059_BR_VS2_E['PPC']


                elif i=="E" and j == "SI1" and k == "BR":
                    df_050_059_BR_SI1_E = pd.DataFrame()
                    df_050_059_BR_SI1_E ['Wt Range'] = None
                    df_050_059_BR_SI1_E  = df_050_059_BR_SI1_E.assign(Company=None)
                    df_050_059_BR_SI1_E  = df_050_059_BR_SI1_E.assign(Shape=None)
                    df_050_059_BR_SI1_E  = df_050_059_BR_SI1_E.assign(Carat=None)
                    df_050_059_BR_SI1_E  = df_050_059_BR_SI1_E.assign(Color=None)
                    df_050_059_BR_SI1_E  = df_050_059_BR_SI1_E.assign(Clarity=None)
                    df_050_059_BR_SI1_E  = df_050_059_BR_SI1_E.assign(Cut=None)
                    df_050_059_BR_SI1_E  = df_050_059_BR_SI1_E.assign(Polish=None)
                    df_050_059_BR_SI1_E  = df_050_059_BR_SI1_E.assign(Symmetry=None)
                    df_050_059_BR_SI1_E  = df_050_059_BR_SI1_E.assign(Ratio=None)
                    df_050_059_BR_SI1_E  = df_050_059_BR_SI1_E.assign(PPC=None)
                    df_050_059_BR_SI1_E  = df_050_059_BR_SI1_E.assign(Total=None)
                    df_050_059_BR_SI1_E ['Wt Range'] = listwtrange
                    df_050_059_BR_SI1_E ['Company'] = listcom
                    df_050_059_BR_SI1_E ['Shape'] = listshap
                    df_050_059_BR_SI1_E ['Carat'] = listcar
                    df_050_059_BR_SI1_E ['Color'] = listcol
                    df_050_059_BR_SI1_E ['Clarity'] = listclar
                    df_050_059_BR_SI1_E ['Cut'] = listcut
                    df_050_059_BR_SI1_E ['Polish'] = listpol
                    df_050_059_BR_SI1_E ['Symmetry'] = listsym
                    df_050_059_BR_SI1_E ['Ratio'] = listrat
                    df_050_059_BR_SI1_E ['PPC'] = listdesc
                    df_050_059_BR_SI1_E ['Total'] = listtotal
                    df_050_059_BR_SI1_E['Carat'] = df_050_059_BR_SI1_E['Carat'].astype('float64')
                    df_050_059_BR_SI1_E['PPC'] = df_050_059_BR_SI1_E['PPC'].astype('float64')
                    df_050_059_BR_SI1_E['Total'] = df_050_059_BR_SI1_E['Total'].astype('float64')
                    df_050_059_BR_SI1_E['Total'] = df_050_059_BR_SI1_E['Carat'] * df_050_059_BR_SI1_E['PPC']


                elif i=="E" and j == "SI2" and k == "BR":
                    df_050_059_BR_SI2_E = pd.DataFrame()
                    df_050_059_BR_SI2_E ['Wt Range'] = None
                    df_050_059_BR_SI2_E  = df_050_059_BR_SI2_E.assign(Company=None)
                    df_050_059_BR_SI2_E  = df_050_059_BR_SI2_E.assign(Shape=None)
                    df_050_059_BR_SI2_E  = df_050_059_BR_SI2_E.assign(Carat=None)
                    df_050_059_BR_SI2_E  = df_050_059_BR_SI2_E.assign(Color=None)
                    df_050_059_BR_SI2_E  = df_050_059_BR_SI2_E.assign(Clarity=None)
                    df_050_059_BR_SI2_E  = df_050_059_BR_SI2_E.assign(Cut=None)
                    df_050_059_BR_SI2_E  = df_050_059_BR_SI2_E.assign(Polish=None)
                    df_050_059_BR_SI2_E  = df_050_059_BR_SI2_E.assign(Symmetry=None)
                    df_050_059_BR_SI2_E  = df_050_059_BR_SI2_E.assign(Ratio=None)
                    df_050_059_BR_SI2_E  = df_050_059_BR_SI2_E.assign(PPC=None)
                    df_050_059_BR_SI2_E  = df_050_059_BR_SI2_E.assign(Total=None)
                    df_050_059_BR_SI2_E ['Wt Range'] = listwtrange
                    df_050_059_BR_SI2_E ['Company'] = listcom
                    df_050_059_BR_SI2_E ['Shape'] = listshap
                    df_050_059_BR_SI2_E ['Carat'] = listcar
                    df_050_059_BR_SI2_E ['Color'] = listcol
                    df_050_059_BR_SI2_E ['Clarity'] = listclar
                    df_050_059_BR_SI2_E ['Cut'] = listcut
                    df_050_059_BR_SI2_E ['Polish'] = listpol
                    df_050_059_BR_SI2_E ['Symmetry'] = listsym
                    df_050_059_BR_SI2_E ['Ratio'] = listrat
                    df_050_059_BR_SI2_E ['PPC'] = listdesc
                    df_050_059_BR_SI2_E ['Total'] = listtotal
                    df_050_059_BR_SI2_E['Carat'] = df_050_059_BR_SI2_E['Carat'].astype('float64')
                    df_050_059_BR_SI2_E['PPC'] = df_050_059_BR_SI2_E['PPC'].astype('float64')
                    df_050_059_BR_SI2_E['Total'] = df_050_059_BR_SI2_E['Total'].astype('float64')
                    df_050_059_BR_SI2_E['Total'] = df_050_059_BR_SI2_E['Carat'] * df_050_059_BR_SI2_E['PPC']


                elif i=="E" and j == "I1" and k == "BR":
                    df_050_059_BR_I1_E = pd.DataFrame()
                    df_050_059_BR_I1_E ['Wt Range'] = None
                    df_050_059_BR_I1_E  = df_050_059_BR_I1_E.assign(Company=None)
                    df_050_059_BR_I1_E  = df_050_059_BR_I1_E.assign(Shape=None)
                    df_050_059_BR_I1_E  = df_050_059_BR_I1_E.assign(Carat=None)
                    df_050_059_BR_I1_E  = df_050_059_BR_I1_E.assign(Color=None)
                    df_050_059_BR_I1_E  = df_050_059_BR_I1_E.assign(Clarity=None)
                    df_050_059_BR_I1_E  = df_050_059_BR_I1_E.assign(Cut=None)
                    df_050_059_BR_I1_E  = df_050_059_BR_I1_E.assign(Polish=None)
                    df_050_059_BR_I1_E  = df_050_059_BR_I1_E.assign(Symmetry=None)
                    df_050_059_BR_I1_E  = df_050_059_BR_I1_E.assign(Ratio=None)
                    df_050_059_BR_I1_E  = df_050_059_BR_I1_E.assign(PPC=None)
                    df_050_059_BR_I1_E  = df_050_059_BR_I1_E.assign(Total=None)
                    df_050_059_BR_I1_E ['Wt Range'] = listwtrange
                    df_050_059_BR_I1_E ['Company'] = listcom
                    df_050_059_BR_I1_E ['Shape'] = listshap
                    df_050_059_BR_I1_E ['Carat'] = listcar
                    df_050_059_BR_I1_E ['Color'] = listcol
                    df_050_059_BR_I1_E ['Clarity'] = listclar
                    df_050_059_BR_I1_E ['Cut'] = listcut
                    df_050_059_BR_I1_E ['Polish'] = listpol
                    df_050_059_BR_I1_E ['Symmetry'] = listsym
                    df_050_059_BR_I1_E ['Ratio'] = listrat
                    df_050_059_BR_I1_E ['PPC'] = listdesc
                    df_050_059_BR_I1_E ['Total'] = listtotal
                    df_050_059_BR_I1_E['Carat'] = df_050_059_BR_I1_E['Carat'].astype('float64')
                    df_050_059_BR_I1_E['PPC'] = df_050_059_BR_I1_E['PPC'].astype('float64')
                    df_050_059_BR_I1_E['Total'] = df_050_059_BR_I1_E['Total'].astype('float64')
                    df_050_059_BR_I1_E['Total'] = df_050_059_BR_I1_E['Carat'] * df_050_059_BR_I1_E['PPC']


                elif i=="E" and j == "I2" and k == "BR":
                    df_050_059_BR_I2_E = pd.DataFrame()
                    df_050_059_BR_I2_E ['Wt Range'] = None
                    df_050_059_BR_I2_E  = df_050_059_BR_I2_E.assign(Company=None)
                    df_050_059_BR_I2_E  = df_050_059_BR_I2_E.assign(Shape=None)
                    df_050_059_BR_I2_E  = df_050_059_BR_I2_E.assign(Carat=None)
                    df_050_059_BR_I2_E  = df_050_059_BR_I2_E.assign(Color=None)
                    df_050_059_BR_I2_E  = df_050_059_BR_I2_E.assign(Clarity=None)
                    df_050_059_BR_I2_E  = df_050_059_BR_I2_E.assign(Cut=None)
                    df_050_059_BR_I2_E  = df_050_059_BR_I2_E.assign(Polish=None)
                    df_050_059_BR_I2_E  = df_050_059_BR_I2_E.assign(Symmetry=None)
                    df_050_059_BR_I2_E  = df_050_059_BR_I2_E.assign(Ratio=None)
                    df_050_059_BR_I2_E  = df_050_059_BR_I2_E.assign(PPC=None)
                    df_050_059_BR_I2_E  = df_050_059_BR_I2_E.assign(Total=None)
                    df_050_059_BR_I2_E ['Wt Range'] = listwtrange
                    df_050_059_BR_I2_E ['Company'] = listcom
                    df_050_059_BR_I2_E ['Shape'] = listshap
                    df_050_059_BR_I2_E ['Carat'] = listcar
                    df_050_059_BR_I2_E ['Color'] = listcol
                    df_050_059_BR_I2_E ['Clarity'] = listclar
                    df_050_059_BR_I2_E ['Cut'] = listcut
                    df_050_059_BR_I2_E ['Polish'] = listpol
                    df_050_059_BR_I2_E ['Symmetry'] = listsym
                    df_050_059_BR_I2_E ['Ratio'] = listrat
                    df_050_059_BR_I2_E ['PPC'] = listdesc
                    df_050_059_BR_I2_E ['Total'] = listtotal
                    df_050_059_BR_I2_E['Carat'] = df_050_059_BR_I2_E['Carat'].astype('float64')
                    df_050_059_BR_I2_E['PPC'] = df_050_059_BR_I2_E['PPC'].astype('float64')
                    df_050_059_BR_I2_E['Total'] = df_050_059_BR_I2_E['Total'].astype('float64')
                    df_050_059_BR_I2_E['Total'] = df_050_059_BR_I2_E['Carat'] * df_050_059_BR_I2_E['PPC']
                
                elif i=="F" and j == "IF" and k == "BR":
                    df_050_059_BR_IF_F = pd.DataFrame()
                    df_050_059_BR_IF_F ['Wt Range'] = None
                    df_050_059_BR_IF_F  = df_050_059_BR_IF_F.assign(Company=None)
                    df_050_059_BR_IF_F  = df_050_059_BR_IF_F.assign(Shape=None)
                    df_050_059_BR_IF_F  = df_050_059_BR_IF_F.assign(Carat=None)
                    df_050_059_BR_IF_F  = df_050_059_BR_IF_F.assign(Color=None)
                    df_050_059_BR_IF_F  = df_050_059_BR_IF_F.assign(Clarity=None)
                    df_050_059_BR_IF_F  = df_050_059_BR_IF_F.assign(Cut=None)
                    df_050_059_BR_IF_F  = df_050_059_BR_IF_F.assign(Polish=None)
                    df_050_059_BR_IF_F  = df_050_059_BR_IF_F.assign(Symmetry=None)
                    df_050_059_BR_IF_F  = df_050_059_BR_IF_F.assign(Ratio=None)
                    df_050_059_BR_IF_F  = df_050_059_BR_IF_F.assign(PPC=None)
                    df_050_059_BR_IF_F  = df_050_059_BR_IF_F.assign(Total=None)
                    df_050_059_BR_IF_F ['Wt Range'] = listwtrange
                    df_050_059_BR_IF_F ['Company'] = listcom
                    df_050_059_BR_IF_F ['Shape'] = listshap
                    df_050_059_BR_IF_F ['Carat'] = listcar
                    df_050_059_BR_IF_F ['Color'] = listcol
                    df_050_059_BR_IF_F ['Clarity'] = listclar
                    df_050_059_BR_IF_F ['Cut'] = listcut
                    df_050_059_BR_IF_F ['Polish'] = listpol
                    df_050_059_BR_IF_F ['Symmetry'] = listsym
                    df_050_059_BR_IF_F ['Ratio'] = listrat
                    df_050_059_BR_IF_F ['PPC'] = listdesc
                    df_050_059_BR_IF_F ['Total'] = listtotal
                    df_050_059_BR_IF_F['Carat'] = df_050_059_BR_IF_F['Carat'].astype('float64')
                    df_050_059_BR_IF_F['PPC'] = df_050_059_BR_IF_F['PPC'].astype('float64')
                    df_050_059_BR_IF_F['Total'] = df_050_059_BR_IF_F['Total'].astype('float64')
                    df_050_059_BR_IF_F['Total'] = df_050_059_BR_IF_F['Carat'] * df_050_059_BR_IF_F['PPC']



                elif i=="F" and j == "VVS1" and k == "BR":
                    df_050_059_BR_VVS1_F = pd.DataFrame()
                    df_050_059_BR_VVS1_F ['Wt Range'] = None
                    df_050_059_BR_VVS1_F  = df_050_059_BR_VVS1_F.assign(Company=None)
                    df_050_059_BR_VVS1_F  = df_050_059_BR_VVS1_F.assign(Shape=None)
                    df_050_059_BR_VVS1_F  = df_050_059_BR_VVS1_F.assign(Carat=None)
                    df_050_059_BR_VVS1_F  = df_050_059_BR_VVS1_F.assign(Color=None)
                    df_050_059_BR_VVS1_F  = df_050_059_BR_VVS1_F.assign(Clarity=None)
                    df_050_059_BR_VVS1_F  = df_050_059_BR_VVS1_F.assign(Cut=None)
                    df_050_059_BR_VVS1_F  = df_050_059_BR_VVS1_F.assign(Polish=None)
                    df_050_059_BR_VVS1_F  = df_050_059_BR_VVS1_F.assign(Symmetry=None)
                    df_050_059_BR_VVS1_F  = df_050_059_BR_VVS1_F.assign(Ratio=None)
                    df_050_059_BR_VVS1_F  = df_050_059_BR_VVS1_F.assign(PPC=None)
                    df_050_059_BR_VVS1_F  = df_050_059_BR_VVS1_F.assign(Total=None)
                    df_050_059_BR_VVS1_F ['Wt Range'] = listwtrange
                    df_050_059_BR_VVS1_F ['Company'] = listcom
                    df_050_059_BR_VVS1_F ['Shape'] = listshap
                    df_050_059_BR_VVS1_F ['Carat'] = listcar
                    df_050_059_BR_VVS1_F ['Color'] = listcol
                    df_050_059_BR_VVS1_F ['Clarity'] = listclar
                    df_050_059_BR_VVS1_F ['Cut'] = listcut
                    df_050_059_BR_VVS1_F ['Polish'] = listpol
                    df_050_059_BR_VVS1_F ['Symmetry'] = listsym
                    df_050_059_BR_VVS1_F ['Ratio'] = listrat
                    df_050_059_BR_VVS1_F ['PPC'] = listdesc
                    df_050_059_BR_VVS1_F ['Total'] = listtotal
                    df_050_059_BR_VVS1_F['Carat'] = df_050_059_BR_VVS1_F['Carat'].astype('float64')
                    df_050_059_BR_VVS1_F['PPC'] = df_050_059_BR_VVS1_F['PPC'].astype('float64')
                    df_050_059_BR_VVS1_F['Total'] = df_050_059_BR_VVS1_F['Total'].astype('float64')
                    df_050_059_BR_VVS1_F['Total'] = df_050_059_BR_VVS1_F['Carat'] * df_050_059_BR_VVS1_F['PPC']


                elif i=="F" and j == "VVS2" and k == "BR":
                    df_050_059_BR_VVS2_F = pd.DataFrame()
                    df_050_059_BR_VVS2_F ['Wt Range'] = None
                    df_050_059_BR_VVS2_F  = df_050_059_BR_VVS2_F.assign(Company=None)
                    df_050_059_BR_VVS2_F  = df_050_059_BR_VVS2_F.assign(Shape=None)
                    df_050_059_BR_VVS2_F  = df_050_059_BR_VVS2_F.assign(Carat=None)
                    df_050_059_BR_VVS2_F  = df_050_059_BR_VVS2_F.assign(Color=None)
                    df_050_059_BR_VVS2_F  = df_050_059_BR_VVS2_F.assign(Clarity=None)
                    df_050_059_BR_VVS2_F  = df_050_059_BR_VVS2_F.assign(Cut=None)
                    df_050_059_BR_VVS2_F  = df_050_059_BR_VVS2_F.assign(Polish=None)
                    df_050_059_BR_VVS2_F  = df_050_059_BR_VVS2_F.assign(Symmetry=None)
                    df_050_059_BR_VVS2_F  = df_050_059_BR_VVS2_F.assign(Ratio=None)
                    df_050_059_BR_VVS2_F  = df_050_059_BR_VVS2_F.assign(PPC=None)
                    df_050_059_BR_VVS2_F  = df_050_059_BR_VVS2_F.assign(Total=None)
                    df_050_059_BR_VVS2_F ['Wt Range'] = listwtrange
                    df_050_059_BR_VVS2_F ['Company'] = listcom
                    df_050_059_BR_VVS2_F ['Shape'] = listshap
                    df_050_059_BR_VVS2_F ['Carat'] = listcar
                    df_050_059_BR_VVS2_F ['Color'] = listcol
                    df_050_059_BR_VVS2_F ['Clarity'] = listclar
                    df_050_059_BR_VVS2_F ['Cut'] = listcut
                    df_050_059_BR_VVS2_F ['Polish'] = listpol
                    df_050_059_BR_VVS2_F ['Symmetry'] = listsym
                    df_050_059_BR_VVS2_F ['Ratio'] = listrat
                    df_050_059_BR_VVS2_F ['PPC'] = listdesc
                    df_050_059_BR_VVS2_F ['Total'] = listtotal
                    df_050_059_BR_VVS2_F['Carat'] = df_050_059_BR_VVS2_F['Carat'].astype('float64')
                    df_050_059_BR_VVS2_F['PPC'] = df_050_059_BR_VVS2_F['PPC'].astype('float64')
                    df_050_059_BR_VVS2_F['Total'] = df_050_059_BR_VVS2_F['Total'].astype('float64')
                    df_050_059_BR_VVS2_F['Total'] = df_050_059_BR_VVS2_F['Carat'] * df_050_059_BR_VVS2_F['PPC']


                elif i=="F" and j=="VS1" and k == "BR":
                    df_050_059_BR_VS1_F = pd.DataFrame()
                    df_050_059_BR_VS1_F ['Wt Range'] = None
                    df_050_059_BR_VS1_F  = df_050_059_BR_VS1_F.assign(Company=None)
                    df_050_059_BR_VS1_F  = df_050_059_BR_VS1_F.assign(Shape=None)
                    df_050_059_BR_VS1_F  = df_050_059_BR_VS1_F.assign(Carat=None)
                    df_050_059_BR_VS1_F  = df_050_059_BR_VS1_F.assign(Color=None)
                    df_050_059_BR_VS1_F  = df_050_059_BR_VS1_F.assign(Clarity=None)
                    df_050_059_BR_VS1_F  = df_050_059_BR_VS1_F.assign(Cut=None)
                    df_050_059_BR_VS1_F  = df_050_059_BR_VS1_F.assign(Polish=None)
                    df_050_059_BR_VS1_F  = df_050_059_BR_VS1_F.assign(Symmetry=None)
                    df_050_059_BR_VS1_F  = df_050_059_BR_VS1_F.assign(Ratio=None)
                    df_050_059_BR_VS1_F  = df_050_059_BR_VS1_F.assign(PPC=None)
                    df_050_059_BR_VS1_F  = df_050_059_BR_VS1_F.assign(Total=None)
                    df_050_059_BR_VS1_F ['Wt Range'] = listwtrange
                    df_050_059_BR_VS1_F ['Company'] = listcom
                    df_050_059_BR_VS1_F ['Shape'] = listshap
                    df_050_059_BR_VS1_F ['Carat'] = listcar
                    df_050_059_BR_VS1_F ['Color'] = listcol
                    df_050_059_BR_VS1_F ['Clarity'] = listclar
                    df_050_059_BR_VS1_F ['Cut'] = listcut
                    df_050_059_BR_VS1_F ['Polish'] = listpol
                    df_050_059_BR_VS1_F ['Symmetry'] = listsym
                    df_050_059_BR_VS1_F ['Ratio'] = listrat
                    df_050_059_BR_VS1_F ['PPC'] = listdesc
                    df_050_059_BR_VS1_F ['Total'] = listtotal
                    df_050_059_BR_VS1_F['Carat'] = df_050_059_BR_VS1_F['Carat'].astype('float64')
                    df_050_059_BR_VS1_F['PPC'] = df_050_059_BR_VS1_F['PPC'].astype('float64')
                    df_050_059_BR_VS1_F['Total'] = df_050_059_BR_VS1_F['Total'].astype('float64')
                    df_050_059_BR_VS1_F['Total'] = df_050_059_BR_VS1_F['Carat'] * df_050_059_BR_VS1_F['PPC']


                elif i=="F" and j == "VS2" and k == "BR":
                    df_050_059_BR_VS2_F = pd.DataFrame()
                    df_050_059_BR_VS2_F ['Wt Range'] = None
                    df_050_059_BR_VS2_F  = df_050_059_BR_VS2_F.assign(Company=None)
                    df_050_059_BR_VS2_F  = df_050_059_BR_VS2_F.assign(Shape=None)
                    df_050_059_BR_VS2_F  = df_050_059_BR_VS2_F.assign(Carat=None)
                    df_050_059_BR_VS2_F  = df_050_059_BR_VS2_F.assign(Color=None)
                    df_050_059_BR_VS2_F  = df_050_059_BR_VS2_F.assign(Clarity=None)
                    df_050_059_BR_VS2_F  = df_050_059_BR_VS2_F.assign(Cut=None)
                    df_050_059_BR_VS2_F  = df_050_059_BR_VS2_F.assign(Polish=None)
                    df_050_059_BR_VS2_F  = df_050_059_BR_VS2_F.assign(Symmetry=None)
                    df_050_059_BR_VS2_F  = df_050_059_BR_VS2_F.assign(Ratio=None)
                    df_050_059_BR_VS2_F  = df_050_059_BR_VS2_F.assign(PPC=None)
                    df_050_059_BR_VS2_F  = df_050_059_BR_VS2_F.assign(Total=None)
                    df_050_059_BR_VS2_F ['Wt Range'] = listwtrange
                    df_050_059_BR_VS2_F ['Company'] = listcom
                    df_050_059_BR_VS2_F ['Shape'] = listshap
                    df_050_059_BR_VS2_F ['Carat'] = listcar
                    df_050_059_BR_VS2_F ['Color'] = listcol
                    df_050_059_BR_VS2_F ['Clarity'] = listclar
                    df_050_059_BR_VS2_F ['Cut'] = listcut
                    df_050_059_BR_VS2_F ['Polish'] = listpol
                    df_050_059_BR_VS2_F ['Symmetry'] = listsym
                    df_050_059_BR_VS2_F ['Ratio'] = listrat
                    df_050_059_BR_VS2_F ['PPC'] = listdesc
                    df_050_059_BR_VS2_F ['Total'] = listtotal
                    df_050_059_BR_VS2_F['Carat'] = df_050_059_BR_VS2_F['Carat'].astype('float64')
                    df_050_059_BR_VS2_F['PPC'] = df_050_059_BR_VS2_F['PPC'].astype('float64')
                    df_050_059_BR_VS2_F['Total'] = df_050_059_BR_VS2_F['Total'].astype('float64')
                    df_050_059_BR_VS2_F['Total'] = df_050_059_BR_VS2_F['Carat'] * df_050_059_BR_VS2_F['PPC']


                elif i=="F" and j == "SI1" and k == "BR":
                    df_050_059_BR_SI1_F = pd.DataFrame()
                    df_050_059_BR_SI1_F ['Wt Range'] = None
                    df_050_059_BR_SI1_F  = df_050_059_BR_SI1_F.assign(Company=None)
                    df_050_059_BR_SI1_F  = df_050_059_BR_SI1_F.assign(Shape=None)
                    df_050_059_BR_SI1_F  = df_050_059_BR_SI1_F.assign(Carat=None)
                    df_050_059_BR_SI1_F  = df_050_059_BR_SI1_F.assign(Color=None)
                    df_050_059_BR_SI1_F  = df_050_059_BR_SI1_F.assign(Clarity=None)
                    df_050_059_BR_SI1_F  = df_050_059_BR_SI1_F.assign(Cut=None)
                    df_050_059_BR_SI1_F  = df_050_059_BR_SI1_F.assign(Polish=None)
                    df_050_059_BR_SI1_F  = df_050_059_BR_SI1_F.assign(Symmetry=None)
                    df_050_059_BR_SI1_F  = df_050_059_BR_SI1_F.assign(Ratio=None)
                    df_050_059_BR_SI1_F  = df_050_059_BR_SI1_F.assign(PPC=None)
                    df_050_059_BR_SI1_F  = df_050_059_BR_SI1_F.assign(Total=None)
                    df_050_059_BR_SI1_F ['Wt Range'] = listwtrange
                    df_050_059_BR_SI1_F ['Company'] = listcom
                    df_050_059_BR_SI1_F ['Shape'] = listshap
                    df_050_059_BR_SI1_F ['Carat'] = listcar
                    df_050_059_BR_SI1_F ['Color'] = listcol
                    df_050_059_BR_SI1_F ['Clarity'] = listclar
                    df_050_059_BR_SI1_F ['Cut'] = listcut
                    df_050_059_BR_SI1_F ['Polish'] = listpol
                    df_050_059_BR_SI1_F ['Symmetry'] = listsym
                    df_050_059_BR_SI1_F ['Ratio'] = listrat
                    df_050_059_BR_SI1_F ['PPC'] = listdesc
                    df_050_059_BR_SI1_F ['Total'] = listtotal
                    df_050_059_BR_SI1_F['Carat'] = df_050_059_BR_SI1_F['Carat'].astype('float64')
                    df_050_059_BR_SI1_F['PPC'] = df_050_059_BR_SI1_F['PPC'].astype('float64')
                    df_050_059_BR_SI1_F['Total'] = df_050_059_BR_SI1_F['Total'].astype('float64')
                    df_050_059_BR_SI1_F['Total'] = df_050_059_BR_SI1_F['Carat'] * df_050_059_BR_SI1_F['PPC']


                elif i=="F" and j == "SI2" and k == "BR":
                    df_050_059_BR_SI2_F = pd.DataFrame()
                    df_050_059_BR_SI2_F ['Wt Range'] = None
                    df_050_059_BR_SI2_F  = df_050_059_BR_SI2_F.assign(Company=None)
                    df_050_059_BR_SI2_F  = df_050_059_BR_SI2_F.assign(Shape=None)
                    df_050_059_BR_SI2_F  = df_050_059_BR_SI2_F.assign(Carat=None)
                    df_050_059_BR_SI2_F  = df_050_059_BR_SI2_F.assign(Color=None)
                    df_050_059_BR_SI2_F  = df_050_059_BR_SI2_F.assign(Clarity=None)
                    df_050_059_BR_SI2_F  = df_050_059_BR_SI2_F.assign(Cut=None)
                    df_050_059_BR_SI2_F  = df_050_059_BR_SI2_F.assign(Polish=None)
                    df_050_059_BR_SI2_F  = df_050_059_BR_SI2_F.assign(Symmetry=None)
                    df_050_059_BR_SI2_F  = df_050_059_BR_SI2_F.assign(Ratio=None)
                    df_050_059_BR_SI2_F  = df_050_059_BR_SI2_F.assign(PPC=None)
                    df_050_059_BR_SI2_F  = df_050_059_BR_SI2_F.assign(Total=None)
                    df_050_059_BR_SI2_F ['Wt Range'] = listwtrange
                    df_050_059_BR_SI2_F ['Company'] = listcom
                    df_050_059_BR_SI2_F ['Shape'] = listshap
                    df_050_059_BR_SI2_F ['Carat'] = listcar
                    df_050_059_BR_SI2_F ['Color'] = listcol
                    df_050_059_BR_SI2_F ['Clarity'] = listclar
                    df_050_059_BR_SI2_F ['Cut'] = listcut
                    df_050_059_BR_SI2_F ['Polish'] = listpol
                    df_050_059_BR_SI2_F ['Symmetry'] = listsym
                    df_050_059_BR_SI2_F ['Ratio'] = listrat
                    df_050_059_BR_SI2_F ['PPC'] = listdesc
                    df_050_059_BR_SI2_F ['Total'] = listtotal
                    df_050_059_BR_SI2_F['Carat'] = df_050_059_BR_SI2_F['Carat'].astype('float64')
                    df_050_059_BR_SI2_F['PPC'] = df_050_059_BR_SI2_F['PPC'].astype('float64')
                    df_050_059_BR_SI2_F['Total'] = df_050_059_BR_SI2_F['Total'].astype('float64')
                    df_050_059_BR_SI2_F['Total'] = df_050_059_BR_SI2_F['Carat'] * df_050_059_BR_SI2_F['PPC']


                elif i=="F" and j == "I1" and k == "BR":
                    df_050_059_BR_I1_F = pd.DataFrame()
                    df_050_059_BR_I1_F ['Wt Range'] = None
                    df_050_059_BR_I1_F  = df_050_059_BR_I1_F.assign(Company=None)
                    df_050_059_BR_I1_F  = df_050_059_BR_I1_F.assign(Shape=None)
                    df_050_059_BR_I1_F  = df_050_059_BR_I1_F.assign(Carat=None)
                    df_050_059_BR_I1_F  = df_050_059_BR_I1_F.assign(Color=None)
                    df_050_059_BR_I1_F  = df_050_059_BR_I1_F.assign(Clarity=None)
                    df_050_059_BR_I1_F  = df_050_059_BR_I1_F.assign(Cut=None)
                    df_050_059_BR_I1_F  = df_050_059_BR_I1_F.assign(Polish=None)
                    df_050_059_BR_I1_F  = df_050_059_BR_I1_F.assign(Symmetry=None)
                    df_050_059_BR_I1_F  = df_050_059_BR_I1_F.assign(Ratio=None)
                    df_050_059_BR_I1_F  = df_050_059_BR_I1_F.assign(PPC=None)
                    df_050_059_BR_I1_F  = df_050_059_BR_I1_F.assign(Total=None)
                    df_050_059_BR_I1_F ['Wt Range'] = listwtrange
                    df_050_059_BR_I1_F ['Company'] = listcom
                    df_050_059_BR_I1_F ['Shape'] = listshap
                    df_050_059_BR_I1_F ['Carat'] = listcar
                    df_050_059_BR_I1_F ['Color'] = listcol
                    df_050_059_BR_I1_F ['Clarity'] = listclar
                    df_050_059_BR_I1_F ['Cut'] = listcut
                    df_050_059_BR_I1_F ['Polish'] = listpol
                    df_050_059_BR_I1_F ['Symmetry'] = listsym
                    df_050_059_BR_I1_F ['Ratio'] = listrat
                    df_050_059_BR_I1_F ['PPC'] = listdesc
                    df_050_059_BR_I1_F ['Total'] = listtotal
                    df_050_059_BR_I1_F['Carat'] = df_050_059_BR_I1_F['Carat'].astype('float64')
                    df_050_059_BR_I1_F['PPC'] = df_050_059_BR_I1_F['PPC'].astype('float64')
                    df_050_059_BR_I1_F['Total'] = df_050_059_BR_I1_F['Total'].astype('float64')
                    df_050_059_BR_I1_F['Total'] = df_050_059_BR_I1_F['Carat'] * df_050_059_BR_I1_F['PPC']


                elif i=="F" and j == "I2" and k == "BR":
                    df_050_059_BR_I2_F = pd.DataFrame()
                    df_050_059_BR_I2_F ['Wt Range'] = None
                    df_050_059_BR_I2_F  = df_050_059_BR_I2_F.assign(Company=None)
                    df_050_059_BR_I2_F  = df_050_059_BR_I2_F.assign(Shape=None)
                    df_050_059_BR_I2_F  = df_050_059_BR_I2_F.assign(Carat=None)
                    df_050_059_BR_I2_F  = df_050_059_BR_I2_F.assign(Color=None)
                    df_050_059_BR_I2_F  = df_050_059_BR_I2_F.assign(Clarity=None)
                    df_050_059_BR_I2_F  = df_050_059_BR_I2_F.assign(Cut=None)
                    df_050_059_BR_I2_F  = df_050_059_BR_I2_F.assign(Polish=None)
                    df_050_059_BR_I2_F  = df_050_059_BR_I2_F.assign(Symmetry=None)
                    df_050_059_BR_I2_F  = df_050_059_BR_I2_F.assign(Ratio=None)
                    df_050_059_BR_I2_F  = df_050_059_BR_I2_F.assign(PPC=None)
                    df_050_059_BR_I2_F  = df_050_059_BR_I2_F.assign(Total=None)
                    df_050_059_BR_I2_F ['Wt Range'] = listwtrange
                    df_050_059_BR_I2_F ['Company'] = listcom
                    df_050_059_BR_I2_F ['Shape'] = listshap
                    df_050_059_BR_I2_F ['Carat'] = listcar
                    df_050_059_BR_I2_F ['Color'] = listcol
                    df_050_059_BR_I2_F ['Clarity'] = listclar
                    df_050_059_BR_I2_F ['Cut'] = listcut
                    df_050_059_BR_I2_F ['Polish'] = listpol
                    df_050_059_BR_I2_F ['Symmetry'] = listsym
                    df_050_059_BR_I2_F ['Ratio'] = listrat
                    df_050_059_BR_I2_F ['PPC'] = listdesc
                    df_050_059_BR_I2_F ['Total'] = listtotal
                    df_050_059_BR_I2_F['Carat'] = df_050_059_BR_I2_F['Carat'].astype('float64')
                    df_050_059_BR_I2_F['PPC'] = df_050_059_BR_I2_F['PPC'].astype('float64')
                    df_050_059_BR_I2_F['Total'] = df_050_059_BR_I2_F['Total'].astype('float64')
                    df_050_059_BR_I2_F['Total'] = df_050_059_BR_I2_F['Carat'] * df_050_059_BR_I2_F['PPC']


                elif i=="G" and j == "IF" and k == "BR":
                    df_050_059_BR_IF_G = pd.DataFrame()
                    df_050_059_BR_IF_G ['Wt Range'] = None
                    df_050_059_BR_IF_G  = df_050_059_BR_IF_G.assign(Company=None)
                    df_050_059_BR_IF_G  = df_050_059_BR_IF_G.assign(Shape=None)
                    df_050_059_BR_IF_G  = df_050_059_BR_IF_G.assign(Carat=None)
                    df_050_059_BR_IF_G  = df_050_059_BR_IF_G.assign(Color=None)
                    df_050_059_BR_IF_G  = df_050_059_BR_IF_G.assign(Clarity=None)
                    df_050_059_BR_IF_G  = df_050_059_BR_IF_G.assign(Cut=None)
                    df_050_059_BR_IF_G  = df_050_059_BR_IF_G.assign(Polish=None)
                    df_050_059_BR_IF_G  = df_050_059_BR_IF_G.assign(Symmetry=None)
                    df_050_059_BR_IF_G  = df_050_059_BR_IF_G.assign(Ratio=None)
                    df_050_059_BR_IF_G  = df_050_059_BR_IF_G.assign(PPC=None)
                    df_050_059_BR_IF_G  = df_050_059_BR_IF_G.assign(Total=None)
                    df_050_059_BR_IF_G ['Wt Range'] = listwtrange
                    df_050_059_BR_IF_G ['Company'] = listcom
                    df_050_059_BR_IF_G ['Shape'] = listshap
                    df_050_059_BR_IF_G ['Carat'] = listcar
                    df_050_059_BR_IF_G ['Color'] = listcol
                    df_050_059_BR_IF_G ['Clarity'] = listclar
                    df_050_059_BR_IF_G ['Cut'] = listcut
                    df_050_059_BR_IF_G ['Polish'] = listpol
                    df_050_059_BR_IF_G ['Symmetry'] = listsym
                    df_050_059_BR_IF_G ['Ratio'] = listrat
                    df_050_059_BR_IF_G ['PPC'] = listdesc
                    df_050_059_BR_IF_G ['Total'] = listtotal
                    df_050_059_BR_IF_G['Carat'] = df_050_059_BR_IF_G['Carat'].astype('float64')
                    df_050_059_BR_IF_G['PPC'] = df_050_059_BR_IF_G['PPC'].astype('float64')
                    df_050_059_BR_IF_G['Total'] = df_050_059_BR_IF_G['Total'].astype('float64')
                    df_050_059_BR_IF_G['Total'] = df_050_059_BR_IF_G['Carat'] * df_050_059_BR_IF_G['PPC']



                elif i=="G" and j == "VVS1" and k == "BR":
                    df_050_059_BR_VVS1_G = pd.DataFrame()
                    df_050_059_BR_VVS1_G ['Wt Range'] = None
                    df_050_059_BR_VVS1_G  = df_050_059_BR_VVS1_G.assign(Company=None)
                    df_050_059_BR_VVS1_G  = df_050_059_BR_VVS1_G.assign(Shape=None)
                    df_050_059_BR_VVS1_G  = df_050_059_BR_VVS1_G.assign(Carat=None)
                    df_050_059_BR_VVS1_G  = df_050_059_BR_VVS1_G.assign(Color=None)
                    df_050_059_BR_VVS1_G  = df_050_059_BR_VVS1_G.assign(Clarity=None)
                    df_050_059_BR_VVS1_G  = df_050_059_BR_VVS1_G.assign(Cut=None)
                    df_050_059_BR_VVS1_G  = df_050_059_BR_VVS1_G.assign(Polish=None)
                    df_050_059_BR_VVS1_G  = df_050_059_BR_VVS1_G.assign(Symmetry=None)
                    df_050_059_BR_VVS1_G  = df_050_059_BR_VVS1_G.assign(Ratio=None)
                    df_050_059_BR_VVS1_G  = df_050_059_BR_VVS1_G.assign(PPC=None)
                    df_050_059_BR_VVS1_G  = df_050_059_BR_VVS1_G.assign(Total=None)
                    df_050_059_BR_VVS1_G ['Wt Range'] = listwtrange
                    df_050_059_BR_VVS1_G ['Company'] = listcom
                    df_050_059_BR_VVS1_G ['Shape'] = listshap
                    df_050_059_BR_VVS1_G ['Carat'] = listcar
                    df_050_059_BR_VVS1_G ['Color'] = listcol
                    df_050_059_BR_VVS1_G ['Clarity'] = listclar
                    df_050_059_BR_VVS1_G ['Cut'] = listcut
                    df_050_059_BR_VVS1_G ['Polish'] = listpol
                    df_050_059_BR_VVS1_G ['Symmetry'] = listsym
                    df_050_059_BR_VVS1_G ['Ratio'] = listrat
                    df_050_059_BR_VVS1_G ['PPC'] = listdesc
                    df_050_059_BR_VVS1_G ['Total'] = listtotal
                    df_050_059_BR_VVS1_G['Carat'] = df_050_059_BR_VVS1_G['Carat'].astype('float64')
                    df_050_059_BR_VVS1_G['PPC'] = df_050_059_BR_VVS1_G['PPC'].astype('float64')
                    df_050_059_BR_VVS1_G['Total'] = df_050_059_BR_VVS1_G['Total'].astype('float64')
                    df_050_059_BR_VVS1_G['Total'] = df_050_059_BR_VVS1_G['Carat'] * df_050_059_BR_VVS1_G['PPC']


                elif i=="G" and j == "VVS2" and k == "BR":
                    df_050_059_BR_VVS2_G = pd.DataFrame()
                    df_050_059_BR_VVS2_G ['Wt Range'] = None
                    df_050_059_BR_VVS2_G  = df_050_059_BR_VVS2_G.assign(Company=None)
                    df_050_059_BR_VVS2_G  = df_050_059_BR_VVS2_G.assign(Shape=None)
                    df_050_059_BR_VVS2_G  = df_050_059_BR_VVS2_G.assign(Carat=None)
                    df_050_059_BR_VVS2_G  = df_050_059_BR_VVS2_G.assign(Color=None)
                    df_050_059_BR_VVS2_G  = df_050_059_BR_VVS2_G.assign(Clarity=None)
                    df_050_059_BR_VVS2_G  = df_050_059_BR_VVS2_G.assign(Cut=None)
                    df_050_059_BR_VVS2_G  = df_050_059_BR_VVS2_G.assign(Polish=None)
                    df_050_059_BR_VVS2_G  = df_050_059_BR_VVS2_G.assign(Symmetry=None)
                    df_050_059_BR_VVS2_G  = df_050_059_BR_VVS2_G.assign(Ratio=None)
                    df_050_059_BR_VVS2_G  = df_050_059_BR_VVS2_G.assign(PPC=None)
                    df_050_059_BR_VVS2_G  = df_050_059_BR_VVS2_G.assign(Total=None)
                    df_050_059_BR_VVS2_G ['Wt Range'] = listwtrange
                    df_050_059_BR_VVS2_G ['Company'] = listcom
                    df_050_059_BR_VVS2_G ['Shape'] = listshap
                    df_050_059_BR_VVS2_G ['Carat'] = listcar
                    df_050_059_BR_VVS2_G ['Color'] = listcol
                    df_050_059_BR_VVS2_G ['Clarity'] = listclar
                    df_050_059_BR_VVS2_G ['Cut'] = listcut
                    df_050_059_BR_VVS2_G ['Polish'] = listpol
                    df_050_059_BR_VVS2_G ['Symmetry'] = listsym
                    df_050_059_BR_VVS2_G ['Ratio'] = listrat
                    df_050_059_BR_VVS2_G ['PPC'] = listdesc
                    df_050_059_BR_VVS2_G ['Total'] = listtotal
                    df_050_059_BR_VVS2_G['Carat'] = df_050_059_BR_VVS2_G['Carat'].astype('float64')
                    df_050_059_BR_VVS2_G['PPC'] = df_050_059_BR_VVS2_G['PPC'].astype('float64')
                    df_050_059_BR_VVS2_G['Total'] = df_050_059_BR_VVS2_G['Total'].astype('float64')
                    df_050_059_BR_VVS2_G['Total'] = df_050_059_BR_VVS2_G['Carat'] * df_050_059_BR_VVS2_G['PPC']


                elif i=="G" and j=="VS1" and k == "BR":
                    df_050_059_BR_VS1_G = pd.DataFrame()
                    df_050_059_BR_VS1_G ['Wt Range'] = None
                    df_050_059_BR_VS1_G  = df_050_059_BR_VS1_G.assign(Company=None)
                    df_050_059_BR_VS1_G  = df_050_059_BR_VS1_G.assign(Shape=None)
                    df_050_059_BR_VS1_G  = df_050_059_BR_VS1_G.assign(Carat=None)
                    df_050_059_BR_VS1_G  = df_050_059_BR_VS1_G.assign(Color=None)
                    df_050_059_BR_VS1_G  = df_050_059_BR_VS1_G.assign(Clarity=None)
                    df_050_059_BR_VS1_G  = df_050_059_BR_VS1_G.assign(Cut=None)
                    df_050_059_BR_VS1_G  = df_050_059_BR_VS1_G.assign(Polish=None)
                    df_050_059_BR_VS1_G  = df_050_059_BR_VS1_G.assign(Symmetry=None)
                    df_050_059_BR_VS1_G  = df_050_059_BR_VS1_G.assign(Ratio=None)
                    df_050_059_BR_VS1_G  = df_050_059_BR_VS1_G.assign(PPC=None)
                    df_050_059_BR_VS1_G  = df_050_059_BR_VS1_G.assign(Total=None)
                    df_050_059_BR_VS1_G ['Wt Range'] = listwtrange
                    df_050_059_BR_VS1_G ['Company'] = listcom
                    df_050_059_BR_VS1_G ['Shape'] = listshap
                    df_050_059_BR_VS1_G ['Carat'] = listcar
                    df_050_059_BR_VS1_G ['Color'] = listcol
                    df_050_059_BR_VS1_G ['Clarity'] = listclar
                    df_050_059_BR_VS1_G ['Cut'] = listcut
                    df_050_059_BR_VS1_G ['Polish'] = listpol
                    df_050_059_BR_VS1_G ['Symmetry'] = listsym
                    df_050_059_BR_VS1_G ['Ratio'] = listrat
                    df_050_059_BR_VS1_G ['PPC'] = listdesc
                    df_050_059_BR_VS1_G ['Total'] = listtotal
                    df_050_059_BR_VS1_G['Carat'] = df_050_059_BR_VS1_G['Carat'].astype('float64')
                    df_050_059_BR_VS1_G['PPC'] = df_050_059_BR_VS1_G['PPC'].astype('float64')
                    df_050_059_BR_VS1_G['Total'] = df_050_059_BR_VS1_G['Total'].astype('float64')
                    df_050_059_BR_VS1_G['Total'] = df_050_059_BR_VS1_G['Carat'] * df_050_059_BR_VS1_G['PPC']


                elif i=="G" and j == "VS2" and k == "BR":
                    df_050_059_BR_VS2_G = pd.DataFrame()
                    df_050_059_BR_VS2_G ['Wt Range'] = None
                    df_050_059_BR_VS2_G  = df_050_059_BR_VS2_G.assign(Company=None)
                    df_050_059_BR_VS2_G  = df_050_059_BR_VS2_G.assign(Shape=None)
                    df_050_059_BR_VS2_G  = df_050_059_BR_VS2_G.assign(Carat=None)
                    df_050_059_BR_VS2_G  = df_050_059_BR_VS2_G.assign(Color=None)
                    df_050_059_BR_VS2_G  = df_050_059_BR_VS2_G.assign(Clarity=None)
                    df_050_059_BR_VS2_G  = df_050_059_BR_VS2_G.assign(Cut=None)
                    df_050_059_BR_VS2_G  = df_050_059_BR_VS2_G.assign(Polish=None)
                    df_050_059_BR_VS2_G  = df_050_059_BR_VS2_G.assign(Symmetry=None)
                    df_050_059_BR_VS2_G  = df_050_059_BR_VS2_G.assign(Ratio=None)
                    df_050_059_BR_VS2_G  = df_050_059_BR_VS2_G.assign(PPC=None)
                    df_050_059_BR_VS2_G  = df_050_059_BR_VS2_G.assign(Total=None)
                    df_050_059_BR_VS2_G ['Wt Range'] = listwtrange
                    df_050_059_BR_VS2_G ['Company'] = listcom
                    df_050_059_BR_VS2_G ['Shape'] = listshap
                    df_050_059_BR_VS2_G ['Carat'] = listcar
                    df_050_059_BR_VS2_G ['Color'] = listcol
                    df_050_059_BR_VS2_G ['Clarity'] = listclar
                    df_050_059_BR_VS2_G ['Cut'] = listcut
                    df_050_059_BR_VS2_G ['Polish'] = listpol
                    df_050_059_BR_VS2_G ['Symmetry'] = listsym
                    df_050_059_BR_VS2_G ['Ratio'] = listrat
                    df_050_059_BR_VS2_G ['PPC'] = listdesc
                    df_050_059_BR_VS2_G ['Total'] = listtotal
                    df_050_059_BR_VS2_G['Carat'] = df_050_059_BR_VS2_G['Carat'].astype('float64')
                    df_050_059_BR_VS2_G['PPC'] = df_050_059_BR_VS2_G['PPC'].astype('float64')
                    df_050_059_BR_VS2_G['Total'] = df_050_059_BR_VS2_G['Total'].astype('float64')
                    df_050_059_BR_VS2_G['Total'] = df_050_059_BR_VS2_G['Carat'] * df_050_059_BR_VS2_G['PPC']


                elif i=="G" and j == "SI1" and k == "BR":
                    df_050_059_BR_SI1_G = pd.DataFrame()
                    df_050_059_BR_SI1_G ['Wt Range'] = None
                    df_050_059_BR_SI1_G  = df_050_059_BR_SI1_G.assign(Company=None)
                    df_050_059_BR_SI1_G  = df_050_059_BR_SI1_G.assign(Shape=None)
                    df_050_059_BR_SI1_G  = df_050_059_BR_SI1_G.assign(Carat=None)
                    df_050_059_BR_SI1_G  = df_050_059_BR_SI1_G.assign(Color=None)
                    df_050_059_BR_SI1_G  = df_050_059_BR_SI1_G.assign(Clarity=None)
                    df_050_059_BR_SI1_G  = df_050_059_BR_SI1_G.assign(Cut=None)
                    df_050_059_BR_SI1_G  = df_050_059_BR_SI1_G.assign(Polish=None)
                    df_050_059_BR_SI1_G  = df_050_059_BR_SI1_G.assign(Symmetry=None)
                    df_050_059_BR_SI1_G  = df_050_059_BR_SI1_G.assign(Ratio=None)
                    df_050_059_BR_SI1_G  = df_050_059_BR_SI1_G.assign(PPC=None)
                    df_050_059_BR_SI1_G  = df_050_059_BR_SI1_G.assign(Total=None)
                    df_050_059_BR_SI1_G ['Wt Range'] = listwtrange
                    df_050_059_BR_SI1_G ['Company'] = listcom
                    df_050_059_BR_SI1_G ['Shape'] = listshap
                    df_050_059_BR_SI1_G ['Carat'] = listcar
                    df_050_059_BR_SI1_G ['Color'] = listcol
                    df_050_059_BR_SI1_G ['Clarity'] = listclar
                    df_050_059_BR_SI1_G ['Cut'] = listcut
                    df_050_059_BR_SI1_G ['Polish'] = listpol
                    df_050_059_BR_SI1_G ['Symmetry'] = listsym
                    df_050_059_BR_SI1_G ['Ratio'] = listrat
                    df_050_059_BR_SI1_G ['PPC'] = listdesc
                    df_050_059_BR_SI1_G ['Total'] = listtotal
                    df_050_059_BR_SI1_G['Carat'] = df_050_059_BR_SI1_G['Carat'].astype('float64')
                    df_050_059_BR_SI1_G['PPC'] = df_050_059_BR_SI1_G['PPC'].astype('float64')
                    df_050_059_BR_SI1_G['Total'] = df_050_059_BR_SI1_G['Total'].astype('float64')
                    df_050_059_BR_SI1_G['Total'] = df_050_059_BR_SI1_G['Carat'] * df_050_059_BR_SI1_G['PPC']


                elif i=="G" and j == "SI2" and k == "BR":
                    df_050_059_BR_SI2_G = pd.DataFrame()
                    df_050_059_BR_SI2_G ['Wt Range'] = None
                    df_050_059_BR_SI2_G  = df_050_059_BR_SI2_G.assign(Company=None)
                    df_050_059_BR_SI2_G  = df_050_059_BR_SI2_G.assign(Shape=None)
                    df_050_059_BR_SI2_G  = df_050_059_BR_SI2_G.assign(Carat=None)
                    df_050_059_BR_SI2_G  = df_050_059_BR_SI2_G.assign(Color=None)
                    df_050_059_BR_SI2_G  = df_050_059_BR_SI2_G.assign(Clarity=None)
                    df_050_059_BR_SI2_G  = df_050_059_BR_SI2_G.assign(Cut=None)
                    df_050_059_BR_SI2_G  = df_050_059_BR_SI2_G.assign(Polish=None)
                    df_050_059_BR_SI2_G  = df_050_059_BR_SI2_G.assign(Symmetry=None)
                    df_050_059_BR_SI2_G  = df_050_059_BR_SI2_G.assign(Ratio=None)
                    df_050_059_BR_SI2_G  = df_050_059_BR_SI2_G.assign(PPC=None)
                    df_050_059_BR_SI2_G  = df_050_059_BR_SI2_G.assign(Total=None)
                    df_050_059_BR_SI2_G ['Wt Range'] = listwtrange
                    df_050_059_BR_SI2_G ['Company'] = listcom
                    df_050_059_BR_SI2_G ['Shape'] = listshap
                    df_050_059_BR_SI2_G ['Carat'] = listcar
                    df_050_059_BR_SI2_G ['Color'] = listcol
                    df_050_059_BR_SI2_G ['Clarity'] = listclar
                    df_050_059_BR_SI2_G ['Cut'] = listcut
                    df_050_059_BR_SI2_G ['Polish'] = listpol
                    df_050_059_BR_SI2_G ['Symmetry'] = listsym
                    df_050_059_BR_SI2_G ['Ratio'] = listrat
                    df_050_059_BR_SI2_G ['PPC'] = listdesc
                    df_050_059_BR_SI2_G ['Total'] = listtotal
                    df_050_059_BR_SI2_G['Carat'] = df_050_059_BR_SI2_G['Carat'].astype('float64')
                    df_050_059_BR_SI2_G['PPC'] = df_050_059_BR_SI2_G['PPC'].astype('float64')
                    df_050_059_BR_SI2_G['Total'] = df_050_059_BR_SI2_G['Total'].astype('float64')
                    df_050_059_BR_SI2_G['Total'] = df_050_059_BR_SI2_G['Carat'] * df_050_059_BR_SI2_G['PPC']


                elif i=="G" and j == "I1" and k == "BR":
                    df_050_059_BR_I1_G = pd.DataFrame()
                    df_050_059_BR_I1_G ['Wt Range'] = None
                    df_050_059_BR_I1_G  = df_050_059_BR_I1_G.assign(Company=None)
                    df_050_059_BR_I1_G  = df_050_059_BR_I1_G.assign(Shape=None)
                    df_050_059_BR_I1_G  = df_050_059_BR_I1_G.assign(Carat=None)
                    df_050_059_BR_I1_G  = df_050_059_BR_I1_G.assign(Color=None)
                    df_050_059_BR_I1_G  = df_050_059_BR_I1_G.assign(Clarity=None)
                    df_050_059_BR_I1_G  = df_050_059_BR_I1_G.assign(Cut=None)
                    df_050_059_BR_I1_G  = df_050_059_BR_I1_G.assign(Polish=None)
                    df_050_059_BR_I1_G  = df_050_059_BR_I1_G.assign(Symmetry=None)
                    df_050_059_BR_I1_G  = df_050_059_BR_I1_G.assign(Ratio=None)
                    df_050_059_BR_I1_G  = df_050_059_BR_I1_G.assign(PPC=None)
                    df_050_059_BR_I1_G  = df_050_059_BR_I1_G.assign(Total=None)
                    df_050_059_BR_I1_G ['Wt Range'] = listwtrange
                    df_050_059_BR_I1_G ['Company'] = listcom
                    df_050_059_BR_I1_G ['Shape'] = listshap
                    df_050_059_BR_I1_G ['Carat'] = listcar
                    df_050_059_BR_I1_G ['Color'] = listcol
                    df_050_059_BR_I1_G ['Clarity'] = listclar
                    df_050_059_BR_I1_G ['Cut'] = listcut
                    df_050_059_BR_I1_G ['Polish'] = listpol
                    df_050_059_BR_I1_G ['Symmetry'] = listsym
                    df_050_059_BR_I1_G ['Ratio'] = listrat
                    df_050_059_BR_I1_G ['PPC'] = listdesc
                    df_050_059_BR_I1_G ['Total'] = listtotal
                    df_050_059_BR_I1_G['Carat'] = df_050_059_BR_I1_G['Carat'].astype('float64')
                    df_050_059_BR_I1_G['PPC'] = df_050_059_BR_I1_G['PPC'].astype('float64')
                    df_050_059_BR_I1_G['Total'] = df_050_059_BR_I1_G['Total'].astype('float64')
                    df_050_059_BR_I1_G['Total'] = df_050_059_BR_I1_G['Carat'] * df_050_059_BR_I1_G['PPC']


                elif i=="G" and j == "I2" and k == "BR":
                    df_050_059_BR_I2_G = pd.DataFrame()
                    df_050_059_BR_I2_G ['Wt Range'] = None
                    df_050_059_BR_I2_G  = df_050_059_BR_I2_G.assign(Company=None)
                    df_050_059_BR_I2_G  = df_050_059_BR_I2_G.assign(Shape=None)
                    df_050_059_BR_I2_G  = df_050_059_BR_I2_G.assign(Carat=None)
                    df_050_059_BR_I2_G  = df_050_059_BR_I2_G.assign(Color=None)
                    df_050_059_BR_I2_G  = df_050_059_BR_I2_G.assign(Clarity=None)
                    df_050_059_BR_I2_G  = df_050_059_BR_I2_G.assign(Cut=None)
                    df_050_059_BR_I2_G  = df_050_059_BR_I2_G.assign(Polish=None)
                    df_050_059_BR_I2_G  = df_050_059_BR_I2_G.assign(Symmetry=None)
                    df_050_059_BR_I2_G  = df_050_059_BR_I2_G.assign(Ratio=None)
                    df_050_059_BR_I2_G  = df_050_059_BR_I2_G.assign(PPC=None)
                    df_050_059_BR_I2_G  = df_050_059_BR_I2_G.assign(Total=None)
                    df_050_059_BR_I2_G ['Wt Range'] = listwtrange
                    df_050_059_BR_I2_G ['Company'] = listcom
                    df_050_059_BR_I2_G ['Shape'] = listshap
                    df_050_059_BR_I2_G ['Carat'] = listcar
                    df_050_059_BR_I2_G ['Color'] = listcol
                    df_050_059_BR_I2_G ['Clarity'] = listclar
                    df_050_059_BR_I2_G ['Cut'] = listcut
                    df_050_059_BR_I2_G ['Polish'] = listpol
                    df_050_059_BR_I2_G ['Symmetry'] = listsym
                    df_050_059_BR_I2_G ['Ratio'] = listrat
                    df_050_059_BR_I2_G ['PPC'] = listdesc
                    df_050_059_BR_I2_G ['Total'] = listtotal
                    df_050_059_BR_I2_G['Carat'] = df_050_059_BR_I2_G['Carat'].astype('float64')
                    df_050_059_BR_I2_G['PPC'] = df_050_059_BR_I2_G['PPC'].astype('float64')
                    df_050_059_BR_I2_G['Total'] = df_050_059_BR_I2_G['Total'].astype('float64')
                    df_050_059_BR_I2_G['Total'] = df_050_059_BR_I2_G['Carat'] * df_050_059_BR_I2_G['PPC']


                elif i=="H" and j == "IF" and k == "BR":
                    df_050_059_BR_IF_H = pd.DataFrame()
                    df_050_059_BR_IF_H ['Wt Range'] = None
                    df_050_059_BR_IF_H  = df_050_059_BR_IF_H.assign(Company=None)
                    df_050_059_BR_IF_H  = df_050_059_BR_IF_H.assign(Shape=None)
                    df_050_059_BR_IF_H  = df_050_059_BR_IF_H.assign(Carat=None)
                    df_050_059_BR_IF_H  = df_050_059_BR_IF_H.assign(Color=None)
                    df_050_059_BR_IF_H  = df_050_059_BR_IF_H.assign(Clarity=None)
                    df_050_059_BR_IF_H  = df_050_059_BR_IF_H.assign(Cut=None)
                    df_050_059_BR_IF_H  = df_050_059_BR_IF_H.assign(Polish=None)
                    df_050_059_BR_IF_H  = df_050_059_BR_IF_H.assign(Symmetry=None)
                    df_050_059_BR_IF_H  = df_050_059_BR_IF_H.assign(Ratio=None)
                    df_050_059_BR_IF_H  = df_050_059_BR_IF_H.assign(PPC=None)
                    df_050_059_BR_IF_H  = df_050_059_BR_IF_H.assign(Total=None)
                    df_050_059_BR_IF_H ['Wt Range'] = listwtrange
                    df_050_059_BR_IF_H ['Company'] = listcom
                    df_050_059_BR_IF_H ['Shape'] = listshap
                    df_050_059_BR_IF_H ['Carat'] = listcar
                    df_050_059_BR_IF_H ['Color'] = listcol
                    df_050_059_BR_IF_H ['Clarity'] = listclar
                    df_050_059_BR_IF_H ['Cut'] = listcut
                    df_050_059_BR_IF_H ['Polish'] = listpol
                    df_050_059_BR_IF_H ['Symmetry'] = listsym
                    df_050_059_BR_IF_H ['Ratio'] = listrat
                    df_050_059_BR_IF_H ['PPC'] = listdesc
                    df_050_059_BR_IF_H ['Total'] = listtotal
                    df_050_059_BR_IF_H['Carat'] = df_050_059_BR_IF_H['Carat'].astype('float64')
                    df_050_059_BR_IF_H['PPC'] = df_050_059_BR_IF_H['PPC'].astype('float64')
                    df_050_059_BR_IF_H['Total'] = df_050_059_BR_IF_H['Total'].astype('float64')
                    df_050_059_BR_IF_H['Total'] = df_050_059_BR_IF_H['Carat'] * df_050_059_BR_IF_H['PPC']



                elif i=="H" and j == "VVS1" and k == "BR":
                    df_050_059_BR_VVS1_H = pd.DataFrame()
                    df_050_059_BR_VVS1_H ['Wt Range'] = None
                    df_050_059_BR_VVS1_H  = df_050_059_BR_VVS1_H.assign(Company=None)
                    df_050_059_BR_VVS1_H  = df_050_059_BR_VVS1_H.assign(Shape=None)
                    df_050_059_BR_VVS1_H  = df_050_059_BR_VVS1_H.assign(Carat=None)
                    df_050_059_BR_VVS1_H  = df_050_059_BR_VVS1_H.assign(Color=None)
                    df_050_059_BR_VVS1_H  = df_050_059_BR_VVS1_H.assign(Clarity=None)
                    df_050_059_BR_VVS1_H  = df_050_059_BR_VVS1_H.assign(Cut=None)
                    df_050_059_BR_VVS1_H  = df_050_059_BR_VVS1_H.assign(Polish=None)
                    df_050_059_BR_VVS1_H  = df_050_059_BR_VVS1_H.assign(Symmetry=None)
                    df_050_059_BR_VVS1_H  = df_050_059_BR_VVS1_H.assign(Ratio=None)
                    df_050_059_BR_VVS1_H  = df_050_059_BR_VVS1_H.assign(PPC=None)
                    df_050_059_BR_VVS1_H  = df_050_059_BR_VVS1_H.assign(Total=None)
                    df_050_059_BR_VVS1_H ['Wt Range'] = listwtrange
                    df_050_059_BR_VVS1_H ['Company'] = listcom
                    df_050_059_BR_VVS1_H ['Shape'] = listshap
                    df_050_059_BR_VVS1_H ['Carat'] = listcar
                    df_050_059_BR_VVS1_H ['Color'] = listcol
                    df_050_059_BR_VVS1_H ['Clarity'] = listclar
                    df_050_059_BR_VVS1_H ['Cut'] = listcut
                    df_050_059_BR_VVS1_H ['Polish'] = listpol
                    df_050_059_BR_VVS1_H ['Symmetry'] = listsym
                    df_050_059_BR_VVS1_H ['Ratio'] = listrat
                    df_050_059_BR_VVS1_H ['PPC'] = listdesc
                    df_050_059_BR_VVS1_H ['Total'] = listtotal
                    df_050_059_BR_VVS1_H['Carat'] = df_050_059_BR_VVS1_H['Carat'].astype('float64')
                    df_050_059_BR_VVS1_H['PPC'] = df_050_059_BR_VVS1_H['PPC'].astype('float64')
                    df_050_059_BR_VVS1_H['Total'] = df_050_059_BR_VVS1_H['Total'].astype('float64')
                    df_050_059_BR_VVS1_H['Total'] = df_050_059_BR_VVS1_H['Carat'] * df_050_059_BR_VVS1_H['PPC']


                elif i=="H" and j == "VVS2" and k == "BR":
                    df_050_059_BR_VVS2_H = pd.DataFrame()
                    df_050_059_BR_VVS2_H ['Wt Range'] = None
                    df_050_059_BR_VVS2_H  = df_050_059_BR_VVS2_H.assign(Company=None)
                    df_050_059_BR_VVS2_H  = df_050_059_BR_VVS2_H.assign(Shape=None)
                    df_050_059_BR_VVS2_H  = df_050_059_BR_VVS2_H.assign(Carat=None)
                    df_050_059_BR_VVS2_H  = df_050_059_BR_VVS2_H.assign(Color=None)
                    df_050_059_BR_VVS2_H  = df_050_059_BR_VVS2_H.assign(Clarity=None)
                    df_050_059_BR_VVS2_H  = df_050_059_BR_VVS2_H.assign(Cut=None)
                    df_050_059_BR_VVS2_H  = df_050_059_BR_VVS2_H.assign(Polish=None)
                    df_050_059_BR_VVS2_H  = df_050_059_BR_VVS2_H.assign(Symmetry=None)
                    df_050_059_BR_VVS2_H  = df_050_059_BR_VVS2_H.assign(Ratio=None)
                    df_050_059_BR_VVS2_H  = df_050_059_BR_VVS2_H.assign(PPC=None)
                    df_050_059_BR_VVS2_H  = df_050_059_BR_VVS2_H.assign(Total=None)
                    df_050_059_BR_VVS2_H ['Wt Range'] = listwtrange
                    df_050_059_BR_VVS2_H ['Company'] = listcom
                    df_050_059_BR_VVS2_H ['Shape'] = listshap
                    df_050_059_BR_VVS2_H ['Carat'] = listcar
                    df_050_059_BR_VVS2_H ['Color'] = listcol
                    df_050_059_BR_VVS2_H ['Clarity'] = listclar
                    df_050_059_BR_VVS2_H ['Cut'] = listcut
                    df_050_059_BR_VVS2_H ['Polish'] = listpol
                    df_050_059_BR_VVS2_H ['Symmetry'] = listsym
                    df_050_059_BR_VVS2_H ['Ratio'] = listrat
                    df_050_059_BR_VVS2_H ['PPC'] = listdesc
                    df_050_059_BR_VVS2_H ['Total'] = listtotal
                    df_050_059_BR_VVS2_H['Carat'] = df_050_059_BR_VVS2_H['Carat'].astype('float64')
                    df_050_059_BR_VVS2_H['PPC'] = df_050_059_BR_VVS2_H['PPC'].astype('float64')
                    df_050_059_BR_VVS2_H['Total'] = df_050_059_BR_VVS2_H['Total'].astype('float64')
                    df_050_059_BR_VVS2_H['Total'] = df_050_059_BR_VVS2_H['Carat'] * df_050_059_BR_VVS2_H['PPC']


                elif i=="H" and j=="VS1" and k == "BR":
                    df_050_059_BR_VS1_H = pd.DataFrame()
                    df_050_059_BR_VS1_H ['Wt Range'] = None
                    df_050_059_BR_VS1_H  = df_050_059_BR_VS1_H.assign(Company=None)
                    df_050_059_BR_VS1_H  = df_050_059_BR_VS1_H.assign(Shape=None)
                    df_050_059_BR_VS1_H  = df_050_059_BR_VS1_H.assign(Carat=None)
                    df_050_059_BR_VS1_H  = df_050_059_BR_VS1_H.assign(Color=None)
                    df_050_059_BR_VS1_H  = df_050_059_BR_VS1_H.assign(Clarity=None)
                    df_050_059_BR_VS1_H  = df_050_059_BR_VS1_H.assign(Cut=None)
                    df_050_059_BR_VS1_H  = df_050_059_BR_VS1_H.assign(Polish=None)
                    df_050_059_BR_VS1_H  = df_050_059_BR_VS1_H.assign(Symmetry=None)
                    df_050_059_BR_VS1_H  = df_050_059_BR_VS1_H.assign(Ratio=None)
                    df_050_059_BR_VS1_H  = df_050_059_BR_VS1_H.assign(PPC=None)
                    df_050_059_BR_VS1_H  = df_050_059_BR_VS1_H.assign(Total=None)
                    df_050_059_BR_VS1_H ['Wt Range'] = listwtrange
                    df_050_059_BR_VS1_H ['Company'] = listcom
                    df_050_059_BR_VS1_H ['Shape'] = listshap
                    df_050_059_BR_VS1_H ['Carat'] = listcar
                    df_050_059_BR_VS1_H ['Color'] = listcol
                    df_050_059_BR_VS1_H ['Clarity'] = listclar
                    df_050_059_BR_VS1_H ['Cut'] = listcut
                    df_050_059_BR_VS1_H ['Polish'] = listpol
                    df_050_059_BR_VS1_H ['Symmetry'] = listsym
                    df_050_059_BR_VS1_H ['Ratio'] = listrat
                    df_050_059_BR_VS1_H ['PPC'] = listdesc
                    df_050_059_BR_VS1_H ['Total'] = listtotal
                    df_050_059_BR_VS1_H['Carat'] = df_050_059_BR_VS1_H['Carat'].astype('float64')
                    df_050_059_BR_VS1_H['PPC'] = df_050_059_BR_VS1_H['PPC'].astype('float64')
                    df_050_059_BR_VS1_H['Total'] = df_050_059_BR_VS1_H['Total'].astype('float64')
                    df_050_059_BR_VS1_H['Total'] = df_050_059_BR_VS1_H['Carat'] * df_050_059_BR_VS1_H['PPC']


                elif i=="H" and j == "VS2" and k == "BR":
                    df_050_059_BR_VS2_H = pd.DataFrame()
                    df_050_059_BR_VS2_H ['Wt Range'] = None
                    df_050_059_BR_VS2_H  = df_050_059_BR_VS2_H.assign(Company=None)
                    df_050_059_BR_VS2_H  = df_050_059_BR_VS2_H.assign(Shape=None)
                    df_050_059_BR_VS2_H  = df_050_059_BR_VS2_H.assign(Carat=None)
                    df_050_059_BR_VS2_H  = df_050_059_BR_VS2_H.assign(Color=None)
                    df_050_059_BR_VS2_H  = df_050_059_BR_VS2_H.assign(Clarity=None)
                    df_050_059_BR_VS2_H  = df_050_059_BR_VS2_H.assign(Cut=None)
                    df_050_059_BR_VS2_H  = df_050_059_BR_VS2_H.assign(Polish=None)
                    df_050_059_BR_VS2_H  = df_050_059_BR_VS2_H.assign(Symmetry=None)
                    df_050_059_BR_VS2_H  = df_050_059_BR_VS2_H.assign(Ratio=None)
                    df_050_059_BR_VS2_H  = df_050_059_BR_VS2_H.assign(PPC=None)
                    df_050_059_BR_VS2_H  = df_050_059_BR_VS2_H.assign(Total=None)
                    df_050_059_BR_VS2_H ['Wt Range'] = listwtrange
                    df_050_059_BR_VS2_H ['Company'] = listcom
                    df_050_059_BR_VS2_H ['Shape'] = listshap
                    df_050_059_BR_VS2_H ['Carat'] = listcar
                    df_050_059_BR_VS2_H ['Color'] = listcol
                    df_050_059_BR_VS2_H ['Clarity'] = listclar
                    df_050_059_BR_VS2_H ['Cut'] = listcut
                    df_050_059_BR_VS2_H ['Polish'] = listpol
                    df_050_059_BR_VS2_H ['Symmetry'] = listsym
                    df_050_059_BR_VS2_H ['Ratio'] = listrat
                    df_050_059_BR_VS2_H ['PPC'] = listdesc
                    df_050_059_BR_VS2_H ['Total'] = listtotal
                    df_050_059_BR_VS2_H['Carat'] = df_050_059_BR_VS2_H['Carat'].astype('float64')
                    df_050_059_BR_VS2_H['PPC'] = df_050_059_BR_VS2_H['PPC'].astype('float64')
                    df_050_059_BR_VS2_H['Total'] = df_050_059_BR_VS2_H['Total'].astype('float64')
                    df_050_059_BR_VS2_H['Total'] = df_050_059_BR_VS2_H['Carat'] * df_050_059_BR_VS2_H['PPC']


                elif i=="H" and j == "SI1" and k == "BR":
                    df_050_059_BR_SI1_H = pd.DataFrame()
                    df_050_059_BR_SI1_H ['Wt Range'] = None
                    df_050_059_BR_SI1_H  = df_050_059_BR_SI1_H.assign(Company=None)
                    df_050_059_BR_SI1_H  = df_050_059_BR_SI1_H.assign(Shape=None)
                    df_050_059_BR_SI1_H  = df_050_059_BR_SI1_H.assign(Carat=None)
                    df_050_059_BR_SI1_H  = df_050_059_BR_SI1_H.assign(Color=None)
                    df_050_059_BR_SI1_H  = df_050_059_BR_SI1_H.assign(Clarity=None)
                    df_050_059_BR_SI1_H  = df_050_059_BR_SI1_H.assign(Cut=None)
                    df_050_059_BR_SI1_H  = df_050_059_BR_SI1_H.assign(Polish=None)
                    df_050_059_BR_SI1_H  = df_050_059_BR_SI1_H.assign(Symmetry=None)
                    df_050_059_BR_SI1_H  = df_050_059_BR_SI1_H.assign(Ratio=None)
                    df_050_059_BR_SI1_H  = df_050_059_BR_SI1_H.assign(PPC=None)
                    df_050_059_BR_SI1_H  = df_050_059_BR_SI1_H.assign(Total=None)
                    df_050_059_BR_SI1_H ['Wt Range'] = listwtrange
                    df_050_059_BR_SI1_H ['Company'] = listcom
                    df_050_059_BR_SI1_H ['Shape'] = listshap
                    df_050_059_BR_SI1_H ['Carat'] = listcar
                    df_050_059_BR_SI1_H ['Color'] = listcol
                    df_050_059_BR_SI1_H ['Clarity'] = listclar
                    df_050_059_BR_SI1_H ['Cut'] = listcut
                    df_050_059_BR_SI1_H ['Polish'] = listpol
                    df_050_059_BR_SI1_H ['Symmetry'] = listsym
                    df_050_059_BR_SI1_H ['Ratio'] = listrat
                    df_050_059_BR_SI1_H ['PPC'] = listdesc
                    df_050_059_BR_SI1_H ['Total'] = listtotal
                    df_050_059_BR_SI1_H['Carat'] = df_050_059_BR_SI1_H['Carat'].astype('float64')
                    df_050_059_BR_SI1_H['PPC'] = df_050_059_BR_SI1_H['PPC'].astype('float64')
                    df_050_059_BR_SI1_H['Total'] = df_050_059_BR_SI1_H['Total'].astype('float64')
                    df_050_059_BR_SI1_H['Total'] = df_050_059_BR_SI1_H['Carat'] * df_050_059_BR_SI1_H['PPC']


                elif i=="H" and j == "SI2" and k == "BR":
                    df_050_059_BR_SI2_H = pd.DataFrame()
                    df_050_059_BR_SI2_H ['Wt Range'] = None
                    df_050_059_BR_SI2_H  = df_050_059_BR_SI2_H.assign(Company=None)
                    df_050_059_BR_SI2_H  = df_050_059_BR_SI2_H.assign(Shape=None)
                    df_050_059_BR_SI2_H  = df_050_059_BR_SI2_H.assign(Carat=None)
                    df_050_059_BR_SI2_H  = df_050_059_BR_SI2_H.assign(Color=None)
                    df_050_059_BR_SI2_H  = df_050_059_BR_SI2_H.assign(Clarity=None)
                    df_050_059_BR_SI2_H  = df_050_059_BR_SI2_H.assign(Cut=None)
                    df_050_059_BR_SI2_H  = df_050_059_BR_SI2_H.assign(Polish=None)
                    df_050_059_BR_SI2_H  = df_050_059_BR_SI2_H.assign(Symmetry=None)
                    df_050_059_BR_SI2_H  = df_050_059_BR_SI2_H.assign(Ratio=None)
                    df_050_059_BR_SI2_H  = df_050_059_BR_SI2_H.assign(PPC=None)
                    df_050_059_BR_SI2_H  = df_050_059_BR_SI2_H.assign(Total=None)
                    df_050_059_BR_SI2_H ['Wt Range'] = listwtrange
                    df_050_059_BR_SI2_H ['Company'] = listcom
                    df_050_059_BR_SI2_H ['Shape'] = listshap
                    df_050_059_BR_SI2_H ['Carat'] = listcar
                    df_050_059_BR_SI2_H ['Color'] = listcol
                    df_050_059_BR_SI2_H ['Clarity'] = listclar
                    df_050_059_BR_SI2_H ['Cut'] = listcut
                    df_050_059_BR_SI2_H ['Polish'] = listpol
                    df_050_059_BR_SI2_H ['Symmetry'] = listsym
                    df_050_059_BR_SI2_H ['Ratio'] = listrat
                    df_050_059_BR_SI2_H ['PPC'] = listdesc
                    df_050_059_BR_SI2_H ['Total'] = listtotal
                    df_050_059_BR_SI2_H['Carat'] = df_050_059_BR_SI2_H['Carat'].astype('float64')
                    df_050_059_BR_SI2_H['PPC'] = df_050_059_BR_SI2_H['PPC'].astype('float64')
                    df_050_059_BR_SI2_H['Total'] = df_050_059_BR_SI2_H['Total'].astype('float64')
                    df_050_059_BR_SI2_H['Total'] = df_050_059_BR_SI2_H['Carat'] * df_050_059_BR_SI2_H['PPC']


                elif i=="H" and j == "I1" and k == "BR":
                    df_050_059_BR_I1_H = pd.DataFrame()
                    df_050_059_BR_I1_H ['Wt Range'] = None
                    df_050_059_BR_I1_H  = df_050_059_BR_I1_H.assign(Company=None)
                    df_050_059_BR_I1_H  = df_050_059_BR_I1_H.assign(Shape=None)
                    df_050_059_BR_I1_H  = df_050_059_BR_I1_H.assign(Carat=None)
                    df_050_059_BR_I1_H  = df_050_059_BR_I1_H.assign(Color=None)
                    df_050_059_BR_I1_H  = df_050_059_BR_I1_H.assign(Clarity=None)
                    df_050_059_BR_I1_H  = df_050_059_BR_I1_H.assign(Cut=None)
                    df_050_059_BR_I1_H  = df_050_059_BR_I1_H.assign(Polish=None)
                    df_050_059_BR_I1_H  = df_050_059_BR_I1_H.assign(Symmetry=None)
                    df_050_059_BR_I1_H  = df_050_059_BR_I1_H.assign(Ratio=None)
                    df_050_059_BR_I1_H  = df_050_059_BR_I1_H.assign(PPC=None)
                    df_050_059_BR_I1_H  = df_050_059_BR_I1_H.assign(Total=None)
                    df_050_059_BR_I1_H ['Wt Range'] = listwtrange
                    df_050_059_BR_I1_H ['Company'] = listcom
                    df_050_059_BR_I1_H ['Shape'] = listshap
                    df_050_059_BR_I1_H ['Carat'] = listcar
                    df_050_059_BR_I1_H ['Color'] = listcol
                    df_050_059_BR_I1_H ['Clarity'] = listclar
                    df_050_059_BR_I1_H ['Cut'] = listcut
                    df_050_059_BR_I1_H ['Polish'] = listpol
                    df_050_059_BR_I1_H ['Symmetry'] = listsym
                    df_050_059_BR_I1_H ['Ratio'] = listrat
                    df_050_059_BR_I1_H ['PPC'] = listdesc
                    df_050_059_BR_I1_H ['Total'] = listtotal
                    df_050_059_BR_I1_H['Carat'] = df_050_059_BR_I1_H['Carat'].astype('float64')
                    df_050_059_BR_I1_H['PPC'] = df_050_059_BR_I1_H['PPC'].astype('float64')
                    df_050_059_BR_I1_H['Total'] = df_050_059_BR_I1_H['Total'].astype('float64')
                    df_050_059_BR_I1_H['Total'] = df_050_059_BR_I1_H['Carat'] * df_050_059_BR_I1_H['PPC']


                elif i=="H" and j == "I2" and k == "BR":
                    df_050_059_BR_I2_H = pd.DataFrame()
                    df_050_059_BR_I2_H ['Wt Range'] = None
                    df_050_059_BR_I2_H  = df_050_059_BR_I2_H.assign(Company=None)
                    df_050_059_BR_I2_H  = df_050_059_BR_I2_H.assign(Shape=None)
                    df_050_059_BR_I2_H  = df_050_059_BR_I2_H.assign(Carat=None)
                    df_050_059_BR_I2_H  = df_050_059_BR_I2_H.assign(Color=None)
                    df_050_059_BR_I2_H  = df_050_059_BR_I2_H.assign(Clarity=None)
                    df_050_059_BR_I2_H  = df_050_059_BR_I2_H.assign(Cut=None)
                    df_050_059_BR_I2_H  = df_050_059_BR_I2_H.assign(Polish=None)
                    df_050_059_BR_I2_H  = df_050_059_BR_I2_H.assign(Symmetry=None)
                    df_050_059_BR_I2_H  = df_050_059_BR_I2_H.assign(Ratio=None)
                    df_050_059_BR_I2_H  = df_050_059_BR_I2_H.assign(PPC=None)
                    df_050_059_BR_I2_H  = df_050_059_BR_I2_H.assign(Total=None)
                    df_050_059_BR_I2_H ['Wt Range'] = listwtrange
                    df_050_059_BR_I2_H ['Company'] = listcom
                    df_050_059_BR_I2_H ['Shape'] = listshap
                    df_050_059_BR_I2_H ['Carat'] = listcar
                    df_050_059_BR_I2_H ['Color'] = listcol
                    df_050_059_BR_I2_H ['Clarity'] = listclar
                    df_050_059_BR_I2_H ['Cut'] = listcut
                    df_050_059_BR_I2_H ['Polish'] = listpol
                    df_050_059_BR_I2_H ['Symmetry'] = listsym
                    df_050_059_BR_I2_H ['Ratio'] = listrat
                    df_050_059_BR_I2_H ['PPC'] = listdesc
                    df_050_059_BR_I2_H ['Total'] = listtotal
                    df_050_059_BR_I2_H['Carat'] = df_050_059_BR_I2_H['Carat'].astype('float64')
                    df_050_059_BR_I2_H['PPC'] = df_050_059_BR_I2_H['PPC'].astype('float64')
                    df_050_059_BR_I2_H['Total'] = df_050_059_BR_I2_H['Total'].astype('float64')
                    df_050_059_BR_I2_H['Total'] = df_050_059_BR_I2_H['Carat'] * df_050_059_BR_I2_H['PPC']



                elif i== "I" and j == "IF" and k == "BR":
                    df_050_059_BR_IF_I = pd.DataFrame()
                    df_050_059_BR_IF_I ['Wt Range'] = None
                    df_050_059_BR_IF_I  = df_050_059_BR_IF_I.assign(Company=None)
                    df_050_059_BR_IF_I  = df_050_059_BR_IF_I.assign(Shape=None)
                    df_050_059_BR_IF_I  = df_050_059_BR_IF_I.assign(Carat=None)
                    df_050_059_BR_IF_I  = df_050_059_BR_IF_I.assign(Color=None)
                    df_050_059_BR_IF_I  = df_050_059_BR_IF_I.assign(Clarity=None)
                    df_050_059_BR_IF_I  = df_050_059_BR_IF_I.assign(Cut=None)
                    df_050_059_BR_IF_I  = df_050_059_BR_IF_I.assign(Polish=None)
                    df_050_059_BR_IF_I  = df_050_059_BR_IF_I.assign(Symmetry=None)
                    df_050_059_BR_IF_I  = df_050_059_BR_IF_I.assign(Ratio=None)
                    df_050_059_BR_IF_I  = df_050_059_BR_IF_I.assign(PPC=None)
                    df_050_059_BR_IF_I  = df_050_059_BR_IF_I.assign(Total=None)
                    df_050_059_BR_IF_I ['Wt Range'] = listwtrange
                    df_050_059_BR_IF_I ['Company'] = listcom
                    df_050_059_BR_IF_I ['Shape'] = listshap
                    df_050_059_BR_IF_I ['Carat'] = listcar
                    df_050_059_BR_IF_I ['Color'] = listcol
                    df_050_059_BR_IF_I ['Clarity'] = listclar
                    df_050_059_BR_IF_I ['Cut'] = listcut
                    df_050_059_BR_IF_I ['Polish'] = listpol
                    df_050_059_BR_IF_I ['Symmetry'] = listsym
                    df_050_059_BR_IF_I ['Ratio'] = listrat
                    df_050_059_BR_IF_I ['PPC'] = listdesc
                    df_050_059_BR_IF_I ['Total'] = listtotal
                    df_050_059_BR_IF_I['Carat'] = df_050_059_BR_IF_I['Carat'].astype('float64')
                    df_050_059_BR_IF_I['PPC'] = df_050_059_BR_IF_I['PPC'].astype('float64')
                    df_050_059_BR_IF_I['Total'] = df_050_059_BR_IF_I['Total'].astype('float64')
                    df_050_059_BR_IF_I['Total'] = df_050_059_BR_IF_I['Carat'] * df_050_059_BR_IF_I['PPC']



                elif i== "I" and j == "VVS1" and k == "BR":
                    df_050_059_BR_VVS1_I = pd.DataFrame()
                    df_050_059_BR_VVS1_I ['Wt Range'] = None
                    df_050_059_BR_VVS1_I  = df_050_059_BR_VVS1_I.assign(Company=None)
                    df_050_059_BR_VVS1_I  = df_050_059_BR_VVS1_I.assign(Shape=None)
                    df_050_059_BR_VVS1_I  = df_050_059_BR_VVS1_I.assign(Carat=None)
                    df_050_059_BR_VVS1_I  = df_050_059_BR_VVS1_I.assign(Color=None)
                    df_050_059_BR_VVS1_I  = df_050_059_BR_VVS1_I.assign(Clarity=None)
                    df_050_059_BR_VVS1_I  = df_050_059_BR_VVS1_I.assign(Cut=None)
                    df_050_059_BR_VVS1_I  = df_050_059_BR_VVS1_I.assign(Polish=None)
                    df_050_059_BR_VVS1_I  = df_050_059_BR_VVS1_I.assign(Symmetry=None)
                    df_050_059_BR_VVS1_I  = df_050_059_BR_VVS1_I.assign(Ratio=None)
                    df_050_059_BR_VVS1_I  = df_050_059_BR_VVS1_I.assign(PPC=None)
                    df_050_059_BR_VVS1_I  = df_050_059_BR_VVS1_I.assign(Total=None)
                    df_050_059_BR_VVS1_I ['Wt Range'] = listwtrange
                    df_050_059_BR_VVS1_I ['Company'] = listcom
                    df_050_059_BR_VVS1_I ['Shape'] = listshap
                    df_050_059_BR_VVS1_I ['Carat'] = listcar
                    df_050_059_BR_VVS1_I ['Color'] = listcol
                    df_050_059_BR_VVS1_I ['Clarity'] = listclar
                    df_050_059_BR_VVS1_I ['Cut'] = listcut
                    df_050_059_BR_VVS1_I ['Polish'] = listpol
                    df_050_059_BR_VVS1_I ['Symmetry'] = listsym
                    df_050_059_BR_VVS1_I ['Ratio'] = listrat
                    df_050_059_BR_VVS1_I ['PPC'] = listdesc
                    df_050_059_BR_VVS1_I ['Total'] = listtotal
                    df_050_059_BR_VVS1_I['Carat'] = df_050_059_BR_VVS1_I['Carat'].astype('float64')
                    df_050_059_BR_VVS1_I['PPC'] = df_050_059_BR_VVS1_I['PPC'].astype('float64')
                    df_050_059_BR_VVS1_I['Total'] = df_050_059_BR_VVS1_I['Total'].astype('float64')
                    df_050_059_BR_VVS1_I['Total'] = df_050_059_BR_VVS1_I['Carat'] * df_050_059_BR_VVS1_I['PPC']


                elif i== "I" and j == "VVS2" and k == "BR":
                    df_050_059_BR_VVS2_I = pd.DataFrame()
                    df_050_059_BR_VVS2_I ['Wt Range'] = None
                    df_050_059_BR_VVS2_I  = df_050_059_BR_VVS2_I.assign(Company=None)
                    df_050_059_BR_VVS2_I  = df_050_059_BR_VVS2_I.assign(Shape=None)
                    df_050_059_BR_VVS2_I  = df_050_059_BR_VVS2_I.assign(Carat=None)
                    df_050_059_BR_VVS2_I  = df_050_059_BR_VVS2_I.assign(Color=None)
                    df_050_059_BR_VVS2_I  = df_050_059_BR_VVS2_I.assign(Clarity=None)
                    df_050_059_BR_VVS2_I  = df_050_059_BR_VVS2_I.assign(Cut=None)
                    df_050_059_BR_VVS2_I  = df_050_059_BR_VVS2_I.assign(Polish=None)
                    df_050_059_BR_VVS2_I  = df_050_059_BR_VVS2_I.assign(Symmetry=None)
                    df_050_059_BR_VVS2_I  = df_050_059_BR_VVS2_I.assign(Ratio=None)
                    df_050_059_BR_VVS2_I  = df_050_059_BR_VVS2_I.assign(PPC=None)
                    df_050_059_BR_VVS2_I  = df_050_059_BR_VVS2_I.assign(Total=None)
                    df_050_059_BR_VVS2_I ['Wt Range'] = listwtrange
                    df_050_059_BR_VVS2_I ['Company'] = listcom
                    df_050_059_BR_VVS2_I ['Shape'] = listshap
                    df_050_059_BR_VVS2_I ['Carat'] = listcar
                    df_050_059_BR_VVS2_I ['Color'] = listcol
                    df_050_059_BR_VVS2_I ['Clarity'] = listclar
                    df_050_059_BR_VVS2_I ['Cut'] = listcut
                    df_050_059_BR_VVS2_I ['Polish'] = listpol
                    df_050_059_BR_VVS2_I ['Symmetry'] = listsym
                    df_050_059_BR_VVS2_I ['Ratio'] = listrat
                    df_050_059_BR_VVS2_I ['PPC'] = listdesc
                    df_050_059_BR_VVS2_I ['Total'] = listtotal
                    df_050_059_BR_VVS2_I['Carat'] = df_050_059_BR_VVS2_I['Carat'].astype('float64')
                    df_050_059_BR_VVS2_I['PPC'] = df_050_059_BR_VVS2_I['PPC'].astype('float64')
                    df_050_059_BR_VVS2_I['Total'] = df_050_059_BR_VVS2_I['Total'].astype('float64')
                    df_050_059_BR_VVS2_I['Total'] = df_050_059_BR_VVS2_I['Carat'] * df_050_059_BR_VVS2_I['PPC']


                elif i== "I" and j=="VS1" and k == "BR":
                    df_050_059_BR_VS1_I = pd.DataFrame()
                    df_050_059_BR_VS1_I ['Wt Range'] = None
                    df_050_059_BR_VS1_I  = df_050_059_BR_VS1_I.assign(Company=None)
                    df_050_059_BR_VS1_I  = df_050_059_BR_VS1_I.assign(Shape=None)
                    df_050_059_BR_VS1_I  = df_050_059_BR_VS1_I.assign(Carat=None)
                    df_050_059_BR_VS1_I  = df_050_059_BR_VS1_I.assign(Color=None)
                    df_050_059_BR_VS1_I  = df_050_059_BR_VS1_I.assign(Clarity=None)
                    df_050_059_BR_VS1_I  = df_050_059_BR_VS1_I.assign(Cut=None)
                    df_050_059_BR_VS1_I  = df_050_059_BR_VS1_I.assign(Polish=None)
                    df_050_059_BR_VS1_I  = df_050_059_BR_VS1_I.assign(Symmetry=None)
                    df_050_059_BR_VS1_I  = df_050_059_BR_VS1_I.assign(Ratio=None)
                    df_050_059_BR_VS1_I  = df_050_059_BR_VS1_I.assign(PPC=None)
                    df_050_059_BR_VS1_I  = df_050_059_BR_VS1_I.assign(Total=None)
                    df_050_059_BR_VS1_I ['Wt Range'] = listwtrange
                    df_050_059_BR_VS1_I ['Company'] = listcom
                    df_050_059_BR_VS1_I ['Shape'] = listshap
                    df_050_059_BR_VS1_I ['Carat'] = listcar
                    df_050_059_BR_VS1_I ['Color'] = listcol
                    df_050_059_BR_VS1_I ['Clarity'] = listclar
                    df_050_059_BR_VS1_I ['Cut'] = listcut
                    df_050_059_BR_VS1_I ['Polish'] = listpol
                    df_050_059_BR_VS1_I ['Symmetry'] = listsym
                    df_050_059_BR_VS1_I ['Ratio'] = listrat
                    df_050_059_BR_VS1_I ['PPC'] = listdesc
                    df_050_059_BR_VS1_I ['Total'] = listtotal
                    df_050_059_BR_VS1_I['Carat'] = df_050_059_BR_VS1_I['Carat'].astype('float64')
                    df_050_059_BR_VS1_I['PPC'] = df_050_059_BR_VS1_I['PPC'].astype('float64')
                    df_050_059_BR_VS1_I['Total'] = df_050_059_BR_VS1_I['Total'].astype('float64')
                    df_050_059_BR_VS1_I['Total'] = df_050_059_BR_VS1_I['Carat'] * df_050_059_BR_VS1_I['PPC']


                elif i== "I" and j == "VS2" and k == "BR":
                    df_050_059_BR_VS2_I = pd.DataFrame()
                    df_050_059_BR_VS2_I ['Wt Range'] = None
                    df_050_059_BR_VS2_I  = df_050_059_BR_VS2_I.assign(Company=None)
                    df_050_059_BR_VS2_I  = df_050_059_BR_VS2_I.assign(Shape=None)
                    df_050_059_BR_VS2_I  = df_050_059_BR_VS2_I.assign(Carat=None)
                    df_050_059_BR_VS2_I  = df_050_059_BR_VS2_I.assign(Color=None)
                    df_050_059_BR_VS2_I  = df_050_059_BR_VS2_I.assign(Clarity=None)
                    df_050_059_BR_VS2_I  = df_050_059_BR_VS2_I.assign(Cut=None)
                    df_050_059_BR_VS2_I  = df_050_059_BR_VS2_I.assign(Polish=None)
                    df_050_059_BR_VS2_I  = df_050_059_BR_VS2_I.assign(Symmetry=None)
                    df_050_059_BR_VS2_I  = df_050_059_BR_VS2_I.assign(Ratio=None)
                    df_050_059_BR_VS2_I  = df_050_059_BR_VS2_I.assign(PPC=None)
                    df_050_059_BR_VS2_I  = df_050_059_BR_VS2_I.assign(Total=None)
                    df_050_059_BR_VS2_I ['Wt Range'] = listwtrange
                    df_050_059_BR_VS2_I ['Company'] = listcom
                    df_050_059_BR_VS2_I ['Shape'] = listshap
                    df_050_059_BR_VS2_I ['Carat'] = listcar
                    df_050_059_BR_VS2_I ['Color'] = listcol
                    df_050_059_BR_VS2_I ['Clarity'] = listclar
                    df_050_059_BR_VS2_I ['Cut'] = listcut
                    df_050_059_BR_VS2_I ['Polish'] = listpol
                    df_050_059_BR_VS2_I ['Symmetry'] = listsym
                    df_050_059_BR_VS2_I ['Ratio'] = listrat
                    df_050_059_BR_VS2_I ['PPC'] = listdesc
                    df_050_059_BR_VS2_I ['Total'] = listtotal
                    df_050_059_BR_VS2_I['Carat'] = df_050_059_BR_VS2_I['Carat'].astype('float64')
                    df_050_059_BR_VS2_I['PPC'] = df_050_059_BR_VS2_I['PPC'].astype('float64')
                    df_050_059_BR_VS2_I['Total'] = df_050_059_BR_VS2_I['Total'].astype('float64')
                    df_050_059_BR_VS2_I['Total'] = df_050_059_BR_VS2_I['Carat'] * df_050_059_BR_VS2_I['PPC']


                elif i== "I" and j == "SI1" and k == "BR":
                    df_050_059_BR_SI1_I = pd.DataFrame()
                    df_050_059_BR_SI1_I ['Wt Range'] = None
                    df_050_059_BR_SI1_I  = df_050_059_BR_SI1_I.assign(Company=None)
                    df_050_059_BR_SI1_I  = df_050_059_BR_SI1_I.assign(Shape=None)
                    df_050_059_BR_SI1_I  = df_050_059_BR_SI1_I.assign(Carat=None)
                    df_050_059_BR_SI1_I  = df_050_059_BR_SI1_I.assign(Color=None)
                    df_050_059_BR_SI1_I  = df_050_059_BR_SI1_I.assign(Clarity=None)
                    df_050_059_BR_SI1_I  = df_050_059_BR_SI1_I.assign(Cut=None)
                    df_050_059_BR_SI1_I  = df_050_059_BR_SI1_I.assign(Polish=None)
                    df_050_059_BR_SI1_I  = df_050_059_BR_SI1_I.assign(Symmetry=None)
                    df_050_059_BR_SI1_I  = df_050_059_BR_SI1_I.assign(Ratio=None)
                    df_050_059_BR_SI1_I  = df_050_059_BR_SI1_I.assign(PPC=None)
                    df_050_059_BR_SI1_I  = df_050_059_BR_SI1_I.assign(Total=None)
                    df_050_059_BR_SI1_I ['Wt Range'] = listwtrange
                    df_050_059_BR_SI1_I ['Company'] = listcom
                    df_050_059_BR_SI1_I ['Shape'] = listshap
                    df_050_059_BR_SI1_I ['Carat'] = listcar
                    df_050_059_BR_SI1_I ['Color'] = listcol
                    df_050_059_BR_SI1_I ['Clarity'] = listclar
                    df_050_059_BR_SI1_I ['Cut'] = listcut
                    df_050_059_BR_SI1_I ['Polish'] = listpol
                    df_050_059_BR_SI1_I ['Symmetry'] = listsym
                    df_050_059_BR_SI1_I ['Ratio'] = listrat
                    df_050_059_BR_SI1_I ['PPC'] = listdesc
                    df_050_059_BR_SI1_I ['Total'] = listtotal
                    df_050_059_BR_SI1_I['Carat'] = df_050_059_BR_SI1_I['Carat'].astype('float64')
                    df_050_059_BR_SI1_I['PPC'] = df_050_059_BR_SI1_I['PPC'].astype('float64')
                    df_050_059_BR_SI1_I['Total'] = df_050_059_BR_SI1_I['Total'].astype('float64')
                    df_050_059_BR_SI1_I['Total'] = df_050_059_BR_SI1_I['Carat'] * df_050_059_BR_SI1_I['PPC']


                elif i== "I" and j == "SI2" and k == "BR":
                    df_050_059_BR_SI2_I = pd.DataFrame()
                    df_050_059_BR_SI2_I ['Wt Range'] = None
                    df_050_059_BR_SI2_I  = df_050_059_BR_SI2_I.assign(Company=None)
                    df_050_059_BR_SI2_I  = df_050_059_BR_SI2_I.assign(Shape=None)
                    df_050_059_BR_SI2_I  = df_050_059_BR_SI2_I.assign(Carat=None)
                    df_050_059_BR_SI2_I  = df_050_059_BR_SI2_I.assign(Color=None)
                    df_050_059_BR_SI2_I  = df_050_059_BR_SI2_I.assign(Clarity=None)
                    df_050_059_BR_SI2_I  = df_050_059_BR_SI2_I.assign(Cut=None)
                    df_050_059_BR_SI2_I  = df_050_059_BR_SI2_I.assign(Polish=None)
                    df_050_059_BR_SI2_I  = df_050_059_BR_SI2_I.assign(Symmetry=None)
                    df_050_059_BR_SI2_I  = df_050_059_BR_SI2_I.assign(Ratio=None)
                    df_050_059_BR_SI2_I  = df_050_059_BR_SI2_I.assign(PPC=None)
                    df_050_059_BR_SI2_I  = df_050_059_BR_SI2_I.assign(Total=None)
                    df_050_059_BR_SI2_I ['Wt Range'] = listwtrange
                    df_050_059_BR_SI2_I ['Company'] = listcom
                    df_050_059_BR_SI2_I ['Shape'] = listshap
                    df_050_059_BR_SI2_I ['Carat'] = listcar
                    df_050_059_BR_SI2_I ['Color'] = listcol
                    df_050_059_BR_SI2_I ['Clarity'] = listclar
                    df_050_059_BR_SI2_I ['Cut'] = listcut
                    df_050_059_BR_SI2_I ['Polish'] = listpol
                    df_050_059_BR_SI2_I ['Symmetry'] = listsym
                    df_050_059_BR_SI2_I ['Ratio'] = listrat
                    df_050_059_BR_SI2_I ['PPC'] = listdesc
                    df_050_059_BR_SI2_I ['Total'] = listtotal
                    df_050_059_BR_SI2_I['Carat'] = df_050_059_BR_SI2_I['Carat'].astype('float64')
                    df_050_059_BR_SI2_I['PPC'] = df_050_059_BR_SI2_I['PPC'].astype('float64')
                    df_050_059_BR_SI2_I['Total'] = df_050_059_BR_SI2_I['Total'].astype('float64')
                    df_050_059_BR_SI2_I['Total'] = df_050_059_BR_SI2_I['Carat'] * df_050_059_BR_SI2_I['PPC']


                elif i== "I" and j == "I1" and k == "BR":
                    df_050_059_BR_I1_I = pd.DataFrame()
                    df_050_059_BR_I1_I ['Wt Range'] = None
                    df_050_059_BR_I1_I  = df_050_059_BR_I1_I.assign(Company=None)
                    df_050_059_BR_I1_I  = df_050_059_BR_I1_I.assign(Shape=None)
                    df_050_059_BR_I1_I  = df_050_059_BR_I1_I.assign(Carat=None)
                    df_050_059_BR_I1_I  = df_050_059_BR_I1_I.assign(Color=None)
                    df_050_059_BR_I1_I  = df_050_059_BR_I1_I.assign(Clarity=None)
                    df_050_059_BR_I1_I  = df_050_059_BR_I1_I.assign(Cut=None)
                    df_050_059_BR_I1_I  = df_050_059_BR_I1_I.assign(Polish=None)
                    df_050_059_BR_I1_I  = df_050_059_BR_I1_I.assign(Symmetry=None)
                    df_050_059_BR_I1_I  = df_050_059_BR_I1_I.assign(Ratio=None)
                    df_050_059_BR_I1_I  = df_050_059_BR_I1_I.assign(PPC=None)
                    df_050_059_BR_I1_I  = df_050_059_BR_I1_I.assign(Total=None)
                    df_050_059_BR_I1_I ['Wt Range'] = listwtrange
                    df_050_059_BR_I1_I ['Company'] = listcom
                    df_050_059_BR_I1_I ['Shape'] = listshap
                    df_050_059_BR_I1_I ['Carat'] = listcar
                    df_050_059_BR_I1_I ['Color'] = listcol
                    df_050_059_BR_I1_I ['Clarity'] = listclar
                    df_050_059_BR_I1_I ['Cut'] = listcut
                    df_050_059_BR_I1_I ['Polish'] = listpol
                    df_050_059_BR_I1_I ['Symmetry'] = listsym
                    df_050_059_BR_I1_I ['Ratio'] = listrat
                    df_050_059_BR_I1_I ['PPC'] = listdesc
                    df_050_059_BR_I1_I ['Total'] = listtotal
                    df_050_059_BR_I1_I['Carat'] = df_050_059_BR_I1_I['Carat'].astype('float64')
                    df_050_059_BR_I1_I['PPC'] = df_050_059_BR_I1_I['PPC'].astype('float64')
                    df_050_059_BR_I1_I['Total'] = df_050_059_BR_I1_I['Total'].astype('float64')
                    df_050_059_BR_I1_I['Total'] = df_050_059_BR_I1_I['Carat'] * df_050_059_BR_I1_I['PPC']


                elif i== "I" and j == "I2" and k == "BR":
                    df_050_059_BR_I2_I = pd.DataFrame()
                    df_050_059_BR_I2_I ['Wt Range'] = None
                    df_050_059_BR_I2_I  = df_050_059_BR_I2_I.assign(Company=None)
                    df_050_059_BR_I2_I  = df_050_059_BR_I2_I.assign(Shape=None)
                    df_050_059_BR_I2_I  = df_050_059_BR_I2_I.assign(Carat=None)
                    df_050_059_BR_I2_I  = df_050_059_BR_I2_I.assign(Color=None)
                    df_050_059_BR_I2_I  = df_050_059_BR_I2_I.assign(Clarity=None)
                    df_050_059_BR_I2_I  = df_050_059_BR_I2_I.assign(Cut=None)
                    df_050_059_BR_I2_I  = df_050_059_BR_I2_I.assign(Polish=None)
                    df_050_059_BR_I2_I  = df_050_059_BR_I2_I.assign(Symmetry=None)
                    df_050_059_BR_I2_I  = df_050_059_BR_I2_I.assign(Ratio=None)
                    df_050_059_BR_I2_I  = df_050_059_BR_I2_I.assign(PPC=None)
                    df_050_059_BR_I2_I  = df_050_059_BR_I2_I.assign(Total=None)
                    df_050_059_BR_I2_I ['Wt Range'] = listwtrange
                    df_050_059_BR_I2_I ['Company'] = listcom
                    df_050_059_BR_I2_I ['Shape'] = listshap
                    df_050_059_BR_I2_I ['Carat'] = listcar
                    df_050_059_BR_I2_I ['Color'] = listcol
                    df_050_059_BR_I2_I ['Clarity'] = listclar
                    df_050_059_BR_I2_I ['Cut'] = listcut
                    df_050_059_BR_I2_I ['Polish'] = listpol
                    df_050_059_BR_I2_I ['Symmetry'] = listsym
                    df_050_059_BR_I2_I ['Ratio'] = listrat
                    df_050_059_BR_I2_I ['PPC'] = listdesc
                    df_050_059_BR_I2_I ['Total'] = listtotal
                    df_050_059_BR_I2_I['Carat'] = df_050_059_BR_I2_I['Carat'].astype('float64')
                    df_050_059_BR_I2_I['PPC'] = df_050_059_BR_I2_I['PPC'].astype('float64')
                    df_050_059_BR_I2_I['Total'] = df_050_059_BR_I2_I['Total'].astype('float64')
                    df_050_059_BR_I2_I['Total'] = df_050_059_BR_I2_I['Carat'] * df_050_059_BR_I2_I['PPC']


                elif i=="J" and j == "IF" and k == "BR":
                    df_050_059_BR_IF_J = pd.DataFrame()
                    df_050_059_BR_IF_J ['Wt Range'] = None
                    df_050_059_BR_IF_J  = df_050_059_BR_IF_J.assign(Company=None)
                    df_050_059_BR_IF_J  = df_050_059_BR_IF_J.assign(Shape=None)
                    df_050_059_BR_IF_J  = df_050_059_BR_IF_J.assign(Carat=None)
                    df_050_059_BR_IF_J  = df_050_059_BR_IF_J.assign(Color=None)
                    df_050_059_BR_IF_J  = df_050_059_BR_IF_J.assign(Clarity=None)
                    df_050_059_BR_IF_J  = df_050_059_BR_IF_J.assign(Cut=None)
                    df_050_059_BR_IF_J  = df_050_059_BR_IF_J.assign(Polish=None)
                    df_050_059_BR_IF_J  = df_050_059_BR_IF_J.assign(Symmetry=None)
                    df_050_059_BR_IF_J  = df_050_059_BR_IF_J.assign(Ratio=None)
                    df_050_059_BR_IF_J  = df_050_059_BR_IF_J.assign(PPC=None)
                    df_050_059_BR_IF_J  = df_050_059_BR_IF_J.assign(Total=None)
                    df_050_059_BR_IF_J ['Wt Range'] = listwtrange
                    df_050_059_BR_IF_J ['Company'] = listcom
                    df_050_059_BR_IF_J ['Shape'] = listshap
                    df_050_059_BR_IF_J ['Carat'] = listcar
                    df_050_059_BR_IF_J ['Color'] = listcol
                    df_050_059_BR_IF_J ['Clarity'] = listclar
                    df_050_059_BR_IF_J ['Cut'] = listcut
                    df_050_059_BR_IF_J ['Polish'] = listpol
                    df_050_059_BR_IF_J ['Symmetry'] = listsym
                    df_050_059_BR_IF_J ['Ratio'] = listrat
                    df_050_059_BR_IF_J ['PPC'] = listdesc
                    df_050_059_BR_IF_J ['Total'] = listtotal
                    df_050_059_BR_IF_J['Carat'] = df_050_059_BR_IF_J['Carat'].astype('float64')
                    df_050_059_BR_IF_J['PPC'] = df_050_059_BR_IF_J['PPC'].astype('float64')
                    df_050_059_BR_IF_J['Total'] = df_050_059_BR_IF_J['Total'].astype('float64')
                    df_050_059_BR_IF_J['Total'] = df_050_059_BR_IF_J['Carat'] * df_050_059_BR_IF_J['PPC']



                elif i=="J"  and j == "VVS1" and k == "BR":
                    df_050_059_BR_VVS1_J = pd.DataFrame()
                    df_050_059_BR_VVS1_J ['Wt Range'] = None
                    df_050_059_BR_VVS1_J  = df_050_059_BR_VVS1_J.assign(Company=None)
                    df_050_059_BR_VVS1_J  = df_050_059_BR_VVS1_J.assign(Shape=None)
                    df_050_059_BR_VVS1_J  = df_050_059_BR_VVS1_J.assign(Carat=None)
                    df_050_059_BR_VVS1_J  = df_050_059_BR_VVS1_J.assign(Color=None)
                    df_050_059_BR_VVS1_J  = df_050_059_BR_VVS1_J.assign(Clarity=None)
                    df_050_059_BR_VVS1_J  = df_050_059_BR_VVS1_J.assign(Cut=None)
                    df_050_059_BR_VVS1_J  = df_050_059_BR_VVS1_J.assign(Polish=None)
                    df_050_059_BR_VVS1_J  = df_050_059_BR_VVS1_J.assign(Symmetry=None)
                    df_050_059_BR_VVS1_J  = df_050_059_BR_VVS1_J.assign(Ratio=None)
                    df_050_059_BR_VVS1_J  = df_050_059_BR_VVS1_J.assign(PPC=None)
                    df_050_059_BR_VVS1_J  = df_050_059_BR_VVS1_J.assign(Total=None)
                    df_050_059_BR_VVS1_J ['Wt Range'] = listwtrange
                    df_050_059_BR_VVS1_J ['Company'] = listcom
                    df_050_059_BR_VVS1_J ['Shape'] = listshap
                    df_050_059_BR_VVS1_J ['Carat'] = listcar
                    df_050_059_BR_VVS1_J ['Color'] = listcol
                    df_050_059_BR_VVS1_J ['Clarity'] = listclar
                    df_050_059_BR_VVS1_J ['Cut'] = listcut
                    df_050_059_BR_VVS1_J ['Polish'] = listpol
                    df_050_059_BR_VVS1_J ['Symmetry'] = listsym
                    df_050_059_BR_VVS1_J ['Ratio'] = listrat
                    df_050_059_BR_VVS1_J ['PPC'] = listdesc
                    df_050_059_BR_VVS1_J ['Total'] = listtotal
                    df_050_059_BR_VVS1_J['Carat'] = df_050_059_BR_VVS1_J['Carat'].astype('float64')
                    df_050_059_BR_VVS1_J['PPC'] = df_050_059_BR_VVS1_J['PPC'].astype('float64')
                    df_050_059_BR_VVS1_J['Total'] = df_050_059_BR_VVS1_J['Total'].astype('float64')
                    df_050_059_BR_VVS1_J['Total'] = df_050_059_BR_VVS1_J['Carat'] * df_050_059_BR_VVS1_J['PPC']


                elif i=="J"  and j == "VVS2" and k == "BR":
                    df_050_059_BR_VVS2_J = pd.DataFrame()
                    df_050_059_BR_VVS2_J ['Wt Range'] = None
                    df_050_059_BR_VVS2_J  = df_050_059_BR_VVS2_J.assign(Company=None)
                    df_050_059_BR_VVS2_J  = df_050_059_BR_VVS2_J.assign(Shape=None)
                    df_050_059_BR_VVS2_J  = df_050_059_BR_VVS2_J.assign(Carat=None)
                    df_050_059_BR_VVS2_J  = df_050_059_BR_VVS2_J.assign(Color=None)
                    df_050_059_BR_VVS2_J  = df_050_059_BR_VVS2_J.assign(Clarity=None)
                    df_050_059_BR_VVS2_J  = df_050_059_BR_VVS2_J.assign(Cut=None)
                    df_050_059_BR_VVS2_J  = df_050_059_BR_VVS2_J.assign(Polish=None)
                    df_050_059_BR_VVS2_J  = df_050_059_BR_VVS2_J.assign(Symmetry=None)
                    df_050_059_BR_VVS2_J  = df_050_059_BR_VVS2_J.assign(Ratio=None)
                    df_050_059_BR_VVS2_J  = df_050_059_BR_VVS2_J.assign(PPC=None)
                    df_050_059_BR_VVS2_J  = df_050_059_BR_VVS2_J.assign(Total=None)
                    df_050_059_BR_VVS2_J ['Wt Range'] = listwtrange
                    df_050_059_BR_VVS2_J ['Company'] = listcom
                    df_050_059_BR_VVS2_J ['Shape'] = listshap
                    df_050_059_BR_VVS2_J ['Carat'] = listcar
                    df_050_059_BR_VVS2_J ['Color'] = listcol
                    df_050_059_BR_VVS2_J ['Clarity'] = listclar
                    df_050_059_BR_VVS2_J ['Cut'] = listcut
                    df_050_059_BR_VVS2_J ['Polish'] = listpol
                    df_050_059_BR_VVS2_J ['Symmetry'] = listsym
                    df_050_059_BR_VVS2_J ['Ratio'] = listrat
                    df_050_059_BR_VVS2_J ['PPC'] = listdesc
                    df_050_059_BR_VVS2_J ['Total'] = listtotal
                    df_050_059_BR_VVS2_J['Carat'] = df_050_059_BR_VVS2_J['Carat'].astype('float64')
                    df_050_059_BR_VVS2_J['PPC'] = df_050_059_BR_VVS2_J['PPC'].astype('float64')
                    df_050_059_BR_VVS2_J['Total'] = df_050_059_BR_VVS2_J['Total'].astype('float64')
                    df_050_059_BR_VVS2_J['Total'] = df_050_059_BR_VVS2_J['Carat'] * df_050_059_BR_VVS2_J['PPC']


                elif i=="J"  and j=="VS1" and k == "BR":
                    df_050_059_BR_VS1_J = pd.DataFrame()
                    df_050_059_BR_VS1_J ['Wt Range'] = None
                    df_050_059_BR_VS1_J  = df_050_059_BR_VS1_J.assign(Company=None)
                    df_050_059_BR_VS1_J  = df_050_059_BR_VS1_J.assign(Shape=None)
                    df_050_059_BR_VS1_J  = df_050_059_BR_VS1_J.assign(Carat=None)
                    df_050_059_BR_VS1_J  = df_050_059_BR_VS1_J.assign(Color=None)
                    df_050_059_BR_VS1_J  = df_050_059_BR_VS1_J.assign(Clarity=None)
                    df_050_059_BR_VS1_J  = df_050_059_BR_VS1_J.assign(Cut=None)
                    df_050_059_BR_VS1_J  = df_050_059_BR_VS1_J.assign(Polish=None)
                    df_050_059_BR_VS1_J  = df_050_059_BR_VS1_J.assign(Symmetry=None)
                    df_050_059_BR_VS1_J  = df_050_059_BR_VS1_J.assign(Ratio=None)
                    df_050_059_BR_VS1_J  = df_050_059_BR_VS1_J.assign(PPC=None)
                    df_050_059_BR_VS1_J  = df_050_059_BR_VS1_J.assign(Total=None)
                    df_050_059_BR_VS1_J ['Wt Range'] = listwtrange
                    df_050_059_BR_VS1_J ['Company'] = listcom
                    df_050_059_BR_VS1_J ['Shape'] = listshap
                    df_050_059_BR_VS1_J ['Carat'] = listcar
                    df_050_059_BR_VS1_J ['Color'] = listcol
                    df_050_059_BR_VS1_J ['Clarity'] = listclar
                    df_050_059_BR_VS1_J ['Cut'] = listcut
                    df_050_059_BR_VS1_J ['Polish'] = listpol
                    df_050_059_BR_VS1_J ['Symmetry'] = listsym
                    df_050_059_BR_VS1_J ['Ratio'] = listrat
                    df_050_059_BR_VS1_J ['PPC'] = listdesc
                    df_050_059_BR_VS1_J ['Total'] = listtotal
                    df_050_059_BR_VS1_J['Carat'] = df_050_059_BR_VS1_J['Carat'].astype('float64')
                    df_050_059_BR_VS1_J['PPC'] = df_050_059_BR_VS1_J['PPC'].astype('float64')
                    df_050_059_BR_VS1_J['Total'] = df_050_059_BR_VS1_J['Total'].astype('float64')
                    df_050_059_BR_VS1_J['Total'] = df_050_059_BR_VS1_J['Carat'] * df_050_059_BR_VS1_J['PPC']


                elif i=="J"  and j == "VS2" and k == "BR":
                    df_050_059_BR_VS2_J = pd.DataFrame()
                    df_050_059_BR_VS2_J ['Wt Range'] = None
                    df_050_059_BR_VS2_J  = df_050_059_BR_VS2_J.assign(Company=None)
                    df_050_059_BR_VS2_J  = df_050_059_BR_VS2_J.assign(Shape=None)
                    df_050_059_BR_VS2_J  = df_050_059_BR_VS2_J.assign(Carat=None)
                    df_050_059_BR_VS2_J  = df_050_059_BR_VS2_J.assign(Color=None)
                    df_050_059_BR_VS2_J  = df_050_059_BR_VS2_J.assign(Clarity=None)
                    df_050_059_BR_VS2_J  = df_050_059_BR_VS2_J.assign(Cut=None)
                    df_050_059_BR_VS2_J  = df_050_059_BR_VS2_J.assign(Polish=None)
                    df_050_059_BR_VS2_J  = df_050_059_BR_VS2_J.assign(Symmetry=None)
                    df_050_059_BR_VS2_J  = df_050_059_BR_VS2_J.assign(Ratio=None)
                    df_050_059_BR_VS2_J  = df_050_059_BR_VS2_J.assign(PPC=None)
                    df_050_059_BR_VS2_J  = df_050_059_BR_VS2_J.assign(Total=None)
                    df_050_059_BR_VS2_J ['Wt Range'] = listwtrange
                    df_050_059_BR_VS2_J ['Company'] = listcom
                    df_050_059_BR_VS2_J ['Shape'] = listshap
                    df_050_059_BR_VS2_J ['Carat'] = listcar
                    df_050_059_BR_VS2_J ['Color'] = listcol
                    df_050_059_BR_VS2_J ['Clarity'] = listclar
                    df_050_059_BR_VS2_J ['Cut'] = listcut
                    df_050_059_BR_VS2_J ['Polish'] = listpol
                    df_050_059_BR_VS2_J ['Symmetry'] = listsym
                    df_050_059_BR_VS2_J ['Ratio'] = listrat
                    df_050_059_BR_VS2_J ['PPC'] = listdesc
                    df_050_059_BR_VS2_J ['Total'] = listtotal
                    df_050_059_BR_VS2_J['Carat'] = df_050_059_BR_VS2_J['Carat'].astype('float64')
                    df_050_059_BR_VS2_J['PPC'] = df_050_059_BR_VS2_J['PPC'].astype('float64')
                    df_050_059_BR_VS2_J['Total'] = df_050_059_BR_VS2_J['Total'].astype('float64')
                    df_050_059_BR_VS2_J['Total'] = df_050_059_BR_VS2_J['Carat'] * df_050_059_BR_VS2_J['PPC']


                elif i=="J"  and j == "SI1" and k == "BR":
                    df_050_059_BR_SI1_J = pd.DataFrame()
                    df_050_059_BR_SI1_J ['Wt Range'] = None
                    df_050_059_BR_SI1_J  = df_050_059_BR_SI1_J.assign(Company=None)
                    df_050_059_BR_SI1_J  = df_050_059_BR_SI1_J.assign(Shape=None)
                    df_050_059_BR_SI1_J  = df_050_059_BR_SI1_J.assign(Carat=None)
                    df_050_059_BR_SI1_J  = df_050_059_BR_SI1_J.assign(Color=None)
                    df_050_059_BR_SI1_J  = df_050_059_BR_SI1_J.assign(Clarity=None)
                    df_050_059_BR_SI1_J  = df_050_059_BR_SI1_J.assign(Cut=None)
                    df_050_059_BR_SI1_J  = df_050_059_BR_SI1_J.assign(Polish=None)
                    df_050_059_BR_SI1_J  = df_050_059_BR_SI1_J.assign(Symmetry=None)
                    df_050_059_BR_SI1_J  = df_050_059_BR_SI1_J.assign(Ratio=None)
                    df_050_059_BR_SI1_J  = df_050_059_BR_SI1_J.assign(PPC=None)
                    df_050_059_BR_SI1_J  = df_050_059_BR_SI1_J.assign(Total=None)
                    df_050_059_BR_SI1_J ['Wt Range'] = listwtrange
                    df_050_059_BR_SI1_J ['Company'] = listcom
                    df_050_059_BR_SI1_J ['Shape'] = listshap
                    df_050_059_BR_SI1_J ['Carat'] = listcar
                    df_050_059_BR_SI1_J ['Color'] = listcol
                    df_050_059_BR_SI1_J ['Clarity'] = listclar
                    df_050_059_BR_SI1_J ['Cut'] = listcut
                    df_050_059_BR_SI1_J ['Polish'] = listpol
                    df_050_059_BR_SI1_J ['Symmetry'] = listsym
                    df_050_059_BR_SI1_J ['Ratio'] = listrat
                    df_050_059_BR_SI1_J ['PPC'] = listdesc
                    df_050_059_BR_SI1_J ['Total'] = listtotal
                    df_050_059_BR_SI1_J['Carat'] = df_050_059_BR_SI1_J['Carat'].astype('float64')
                    df_050_059_BR_SI1_J['PPC'] = df_050_059_BR_SI1_J['PPC'].astype('float64')
                    df_050_059_BR_SI1_J['Total'] = df_050_059_BR_SI1_J['Total'].astype('float64')
                    df_050_059_BR_SI1_J['Total'] = df_050_059_BR_SI1_J['Carat'] * df_050_059_BR_SI1_J['PPC']


                elif i=="J"  and j == "SI2" and k == "BR":
                    df_050_059_BR_SI2_J = pd.DataFrame()
                    df_050_059_BR_SI2_J ['Wt Range'] = None
                    df_050_059_BR_SI2_J  = df_050_059_BR_SI2_J.assign(Company=None)
                    df_050_059_BR_SI2_J  = df_050_059_BR_SI2_J.assign(Shape=None)
                    df_050_059_BR_SI2_J  = df_050_059_BR_SI2_J.assign(Carat=None)
                    df_050_059_BR_SI2_J  = df_050_059_BR_SI2_J.assign(Color=None)
                    df_050_059_BR_SI2_J  = df_050_059_BR_SI2_J.assign(Clarity=None)
                    df_050_059_BR_SI2_J  = df_050_059_BR_SI2_J.assign(Cut=None)
                    df_050_059_BR_SI2_J  = df_050_059_BR_SI2_J.assign(Polish=None)
                    df_050_059_BR_SI2_J  = df_050_059_BR_SI2_J.assign(Symmetry=None)
                    df_050_059_BR_SI2_J  = df_050_059_BR_SI2_J.assign(Ratio=None)
                    df_050_059_BR_SI2_J  = df_050_059_BR_SI2_J.assign(PPC=None)
                    df_050_059_BR_SI2_J  = df_050_059_BR_SI2_J.assign(Total=None)
                    df_050_059_BR_SI2_J ['Wt Range'] = listwtrange
                    df_050_059_BR_SI2_J ['Company'] = listcom
                    df_050_059_BR_SI2_J ['Shape'] = listshap
                    df_050_059_BR_SI2_J ['Carat'] = listcar
                    df_050_059_BR_SI2_J ['Color'] = listcol
                    df_050_059_BR_SI2_J ['Clarity'] = listclar
                    df_050_059_BR_SI2_J ['Cut'] = listcut
                    df_050_059_BR_SI2_J ['Polish'] = listpol
                    df_050_059_BR_SI2_J ['Symmetry'] = listsym
                    df_050_059_BR_SI2_J ['Ratio'] = listrat
                    df_050_059_BR_SI2_J ['PPC'] = listdesc
                    df_050_059_BR_SI2_J ['Total'] = listtotal
                    df_050_059_BR_SI2_J['Carat'] = df_050_059_BR_SI2_J['Carat'].astype('float64')
                    df_050_059_BR_SI2_J['PPC'] = df_050_059_BR_SI2_J['PPC'].astype('float64')
                    df_050_059_BR_SI2_J['Total'] = df_050_059_BR_SI2_J['Total'].astype('float64')
                    df_050_059_BR_SI2_J['Total'] = df_050_059_BR_SI2_J['Carat'] * df_050_059_BR_SI2_J['PPC']


                elif i=="J"  and j == "I1" and k == "BR":
                    df_050_059_BR_I1_J = pd.DataFrame()
                    df_050_059_BR_I1_J ['Wt Range'] = None
                    df_050_059_BR_I1_J  = df_050_059_BR_I1_J.assign(Company=None)
                    df_050_059_BR_I1_J  = df_050_059_BR_I1_J.assign(Shape=None)
                    df_050_059_BR_I1_J  = df_050_059_BR_I1_J.assign(Carat=None)
                    df_050_059_BR_I1_J  = df_050_059_BR_I1_J.assign(Color=None)
                    df_050_059_BR_I1_J  = df_050_059_BR_I1_J.assign(Clarity=None)
                    df_050_059_BR_I1_J  = df_050_059_BR_I1_J.assign(Cut=None)
                    df_050_059_BR_I1_J  = df_050_059_BR_I1_J.assign(Polish=None)
                    df_050_059_BR_I1_J  = df_050_059_BR_I1_J.assign(Symmetry=None)
                    df_050_059_BR_I1_J  = df_050_059_BR_I1_J.assign(Ratio=None)
                    df_050_059_BR_I1_J  = df_050_059_BR_I1_J.assign(PPC=None)
                    df_050_059_BR_I1_J  = df_050_059_BR_I1_J.assign(Total=None)
                    df_050_059_BR_I1_J ['Wt Range'] = listwtrange
                    df_050_059_BR_I1_J ['Company'] = listcom
                    df_050_059_BR_I1_J ['Shape'] = listshap
                    df_050_059_BR_I1_J ['Carat'] = listcar
                    df_050_059_BR_I1_J ['Color'] = listcol
                    df_050_059_BR_I1_J ['Clarity'] = listclar
                    df_050_059_BR_I1_J ['Cut'] = listcut
                    df_050_059_BR_I1_J ['Polish'] = listpol
                    df_050_059_BR_I1_J ['Symmetry'] = listsym
                    df_050_059_BR_I1_J ['Ratio'] = listrat
                    df_050_059_BR_I1_J ['PPC'] = listdesc
                    df_050_059_BR_I1_J ['Total'] = listtotal
                    df_050_059_BR_I1_J['Carat'] = df_050_059_BR_I1_J['Carat'].astype('float64')
                    df_050_059_BR_I1_J['PPC'] = df_050_059_BR_I1_J['PPC'].astype('float64')
                    df_050_059_BR_I1_J['Total'] = df_050_059_BR_I1_J['Total'].astype('float64')
                    df_050_059_BR_I1_J['Total'] = df_050_059_BR_I1_J['Carat'] * df_050_059_BR_I1_J['PPC']


                elif i=="J"  and j == "I2" and k == "BR":
                    df_050_059_BR_I2_J = pd.DataFrame()
                    df_050_059_BR_I2_J ['Wt Range'] = None
                    df_050_059_BR_I2_J  = df_050_059_BR_I2_J.assign(Company=None)
                    df_050_059_BR_I2_J  = df_050_059_BR_I2_J.assign(Shape=None)
                    df_050_059_BR_I2_J  = df_050_059_BR_I2_J.assign(Carat=None)
                    df_050_059_BR_I2_J  = df_050_059_BR_I2_J.assign(Color=None)
                    df_050_059_BR_I2_J  = df_050_059_BR_I2_J.assign(Clarity=None)
                    df_050_059_BR_I2_J  = df_050_059_BR_I2_J.assign(Cut=None)
                    df_050_059_BR_I2_J  = df_050_059_BR_I2_J.assign(Polish=None)
                    df_050_059_BR_I2_J  = df_050_059_BR_I2_J.assign(Symmetry=None)
                    df_050_059_BR_I2_J  = df_050_059_BR_I2_J.assign(Ratio=None)
                    df_050_059_BR_I2_J  = df_050_059_BR_I2_J.assign(PPC=None)
                    df_050_059_BR_I2_J  = df_050_059_BR_I2_J.assign(Total=None)
                    df_050_059_BR_I2_J ['Wt Range'] = listwtrange
                    df_050_059_BR_I2_J ['Company'] = listcom
                    df_050_059_BR_I2_J ['Shape'] = listshap
                    df_050_059_BR_I2_J ['Carat'] = listcar
                    df_050_059_BR_I2_J ['Color'] = listcol
                    df_050_059_BR_I2_J ['Clarity'] = listclar
                    df_050_059_BR_I2_J ['Cut'] = listcut
                    df_050_059_BR_I2_J ['Polish'] = listpol
                    df_050_059_BR_I2_J ['Symmetry'] = listsym
                    df_050_059_BR_I2_J ['Ratio'] = listrat
                    df_050_059_BR_I2_J ['PPC'] = listdesc
                    df_050_059_BR_I2_J ['Total'] = listtotal
                    df_050_059_BR_I2_J['Carat'] = df_050_059_BR_I2_J['Carat'].astype('float64')
                    df_050_059_BR_I2_J['PPC'] = df_050_059_BR_I2_J['PPC'].astype('float64')
                    df_050_059_BR_I2_J['Total'] = df_050_059_BR_I2_J['Total'].astype('float64')
                    df_050_059_BR_I2_J['Total'] = df_050_059_BR_I2_J['Carat'] * df_050_059_BR_I2_J['PPC']


                elif i=="K" and j == "IF" and k == "BR":
                    df_050_059_BR_IF_K = pd.DataFrame()
                    df_050_059_BR_IF_K ['Wt Range'] = None
                    df_050_059_BR_IF_K  = df_050_059_BR_IF_K.assign(Company=None)
                    df_050_059_BR_IF_K  = df_050_059_BR_IF_K.assign(Shape=None)
                    df_050_059_BR_IF_K  = df_050_059_BR_IF_K.assign(Carat=None)
                    df_050_059_BR_IF_K  = df_050_059_BR_IF_K.assign(Color=None)
                    df_050_059_BR_IF_K  = df_050_059_BR_IF_K.assign(Clarity=None)
                    df_050_059_BR_IF_K  = df_050_059_BR_IF_K.assign(Cut=None)
                    df_050_059_BR_IF_K  = df_050_059_BR_IF_K.assign(Polish=None)
                    df_050_059_BR_IF_K  = df_050_059_BR_IF_K.assign(Symmetry=None)
                    df_050_059_BR_IF_K  = df_050_059_BR_IF_K.assign(Ratio=None)
                    df_050_059_BR_IF_K  = df_050_059_BR_IF_K.assign(PPC=None)
                    df_050_059_BR_IF_K  = df_050_059_BR_IF_K.assign(Total=None)
                    df_050_059_BR_IF_K ['Wt Range'] = listwtrange
                    df_050_059_BR_IF_K ['Company'] = listcom
                    df_050_059_BR_IF_K ['Shape'] = listshap
                    df_050_059_BR_IF_K ['Carat'] = listcar
                    df_050_059_BR_IF_K ['Color'] = listcol
                    df_050_059_BR_IF_K ['Clarity'] = listclar
                    df_050_059_BR_IF_K ['Cut'] = listcut
                    df_050_059_BR_IF_K ['Polish'] = listpol
                    df_050_059_BR_IF_K ['Symmetry'] = listsym
                    df_050_059_BR_IF_K ['Ratio'] = listrat
                    df_050_059_BR_IF_K ['PPC'] = listdesc
                    df_050_059_BR_IF_K ['Total'] = listtotal
                    df_050_059_BR_IF_K['Carat'] = df_050_059_BR_IF_K['Carat'].astype('float64')
                    df_050_059_BR_IF_K['PPC'] = df_050_059_BR_IF_K['PPC'].astype('float64')
                    df_050_059_BR_IF_K['Total'] = df_050_059_BR_IF_K['Total'].astype('float64')
                    df_050_059_BR_IF_K['Total'] = df_050_059_BR_IF_K['Carat'] * df_050_059_BR_IF_K['PPC']



                elif i=="K" and j == "VVS1" and k == "BR":
                    df_050_059_BR_VVS1_K = pd.DataFrame()
                    df_050_059_BR_VVS1_K ['Wt Range'] = None
                    df_050_059_BR_VVS1_K  = df_050_059_BR_VVS1_K.assign(Company=None)
                    df_050_059_BR_VVS1_K  = df_050_059_BR_VVS1_K.assign(Shape=None)
                    df_050_059_BR_VVS1_K  = df_050_059_BR_VVS1_K.assign(Carat=None)
                    df_050_059_BR_VVS1_K  = df_050_059_BR_VVS1_K.assign(Color=None)
                    df_050_059_BR_VVS1_K  = df_050_059_BR_VVS1_K.assign(Clarity=None)
                    df_050_059_BR_VVS1_K  = df_050_059_BR_VVS1_K.assign(Cut=None)
                    df_050_059_BR_VVS1_K  = df_050_059_BR_VVS1_K.assign(Polish=None)
                    df_050_059_BR_VVS1_K  = df_050_059_BR_VVS1_K.assign(Symmetry=None)
                    df_050_059_BR_VVS1_K  = df_050_059_BR_VVS1_K.assign(Ratio=None)
                    df_050_059_BR_VVS1_K  = df_050_059_BR_VVS1_K.assign(PPC=None)
                    df_050_059_BR_VVS1_K  = df_050_059_BR_VVS1_K.assign(Total=None)
                    df_050_059_BR_VVS1_K ['Wt Range'] = listwtrange
                    df_050_059_BR_VVS1_K ['Company'] = listcom
                    df_050_059_BR_VVS1_K ['Shape'] = listshap
                    df_050_059_BR_VVS1_K ['Carat'] = listcar
                    df_050_059_BR_VVS1_K ['Color'] = listcol
                    df_050_059_BR_VVS1_K ['Clarity'] = listclar
                    df_050_059_BR_VVS1_K ['Cut'] = listcut
                    df_050_059_BR_VVS1_K ['Polish'] = listpol
                    df_050_059_BR_VVS1_K ['Symmetry'] = listsym
                    df_050_059_BR_VVS1_K ['Ratio'] = listrat
                    df_050_059_BR_VVS1_K ['PPC'] = listdesc
                    df_050_059_BR_VVS1_K ['Total'] = listtotal
                    df_050_059_BR_VVS1_K['Carat'] = df_050_059_BR_VVS1_K['Carat'].astype('float64')
                    df_050_059_BR_VVS1_K['PPC'] = df_050_059_BR_VVS1_K['PPC'].astype('float64')
                    df_050_059_BR_VVS1_K['Total'] = df_050_059_BR_VVS1_K['Total'].astype('float64')
                    df_050_059_BR_VVS1_K['Total'] = df_050_059_BR_VVS1_K['Carat'] * df_050_059_BR_VVS1_K['PPC']


                elif i=="K" and j == "VVS2" and k == "BR":
                    df_050_059_BR_VVS2_K = pd.DataFrame()
                    df_050_059_BR_VVS2_K ['Wt Range'] = None
                    df_050_059_BR_VVS2_K  = df_050_059_BR_VVS2_K.assign(Company=None)
                    df_050_059_BR_VVS2_K  = df_050_059_BR_VVS2_K.assign(Shape=None)
                    df_050_059_BR_VVS2_K  = df_050_059_BR_VVS2_K.assign(Carat=None)
                    df_050_059_BR_VVS2_K  = df_050_059_BR_VVS2_K.assign(Color=None)
                    df_050_059_BR_VVS2_K  = df_050_059_BR_VVS2_K.assign(Clarity=None)
                    df_050_059_BR_VVS2_K  = df_050_059_BR_VVS2_K.assign(Cut=None)
                    df_050_059_BR_VVS2_K  = df_050_059_BR_VVS2_K.assign(Polish=None)
                    df_050_059_BR_VVS2_K  = df_050_059_BR_VVS2_K.assign(Symmetry=None)
                    df_050_059_BR_VVS2_K  = df_050_059_BR_VVS2_K.assign(Ratio=None)
                    df_050_059_BR_VVS2_K  = df_050_059_BR_VVS2_K.assign(PPC=None)
                    df_050_059_BR_VVS2_K  = df_050_059_BR_VVS2_K.assign(Total=None)
                    df_050_059_BR_VVS2_K ['Wt Range'] = listwtrange
                    df_050_059_BR_VVS2_K ['Company'] = listcom
                    df_050_059_BR_VVS2_K ['Shape'] = listshap
                    df_050_059_BR_VVS2_K ['Carat'] = listcar
                    df_050_059_BR_VVS2_K ['Color'] = listcol
                    df_050_059_BR_VVS2_K ['Clarity'] = listclar
                    df_050_059_BR_VVS2_K ['Cut'] = listcut
                    df_050_059_BR_VVS2_K ['Polish'] = listpol
                    df_050_059_BR_VVS2_K ['Symmetry'] = listsym
                    df_050_059_BR_VVS2_K ['Ratio'] = listrat
                    df_050_059_BR_VVS2_K ['PPC'] = listdesc
                    df_050_059_BR_VVS2_K ['Total'] = listtotal
                    df_050_059_BR_VVS2_K['Carat'] = df_050_059_BR_VVS2_K['Carat'].astype('float64')
                    df_050_059_BR_VVS2_K['PPC'] = df_050_059_BR_VVS2_K['PPC'].astype('float64')
                    df_050_059_BR_VVS2_K['Total'] = df_050_059_BR_VVS2_K['Total'].astype('float64')
                    df_050_059_BR_VVS2_K['Total'] = df_050_059_BR_VVS2_K['Carat'] * df_050_059_BR_VVS2_K['PPC']


                elif i=="K" and j=="VS1" and k == "BR":
                    df_050_059_BR_VS1_K = pd.DataFrame()
                    df_050_059_BR_VS1_K ['Wt Range'] = None
                    df_050_059_BR_VS1_K  = df_050_059_BR_VS1_K.assign(Company=None)
                    df_050_059_BR_VS1_K  = df_050_059_BR_VS1_K.assign(Shape=None)
                    df_050_059_BR_VS1_K  = df_050_059_BR_VS1_K.assign(Carat=None)
                    df_050_059_BR_VS1_K  = df_050_059_BR_VS1_K.assign(Color=None)
                    df_050_059_BR_VS1_K  = df_050_059_BR_VS1_K.assign(Clarity=None)
                    df_050_059_BR_VS1_K  = df_050_059_BR_VS1_K.assign(Cut=None)
                    df_050_059_BR_VS1_K  = df_050_059_BR_VS1_K.assign(Polish=None)
                    df_050_059_BR_VS1_K  = df_050_059_BR_VS1_K.assign(Symmetry=None)
                    df_050_059_BR_VS1_K  = df_050_059_BR_VS1_K.assign(Ratio=None)
                    df_050_059_BR_VS1_K  = df_050_059_BR_VS1_K.assign(PPC=None)
                    df_050_059_BR_VS1_K  = df_050_059_BR_VS1_K.assign(Total=None)
                    df_050_059_BR_VS1_K ['Wt Range'] = listwtrange
                    df_050_059_BR_VS1_K ['Company'] = listcom
                    df_050_059_BR_VS1_K ['Shape'] = listshap
                    df_050_059_BR_VS1_K ['Carat'] = listcar
                    df_050_059_BR_VS1_K ['Color'] = listcol
                    df_050_059_BR_VS1_K ['Clarity'] = listclar
                    df_050_059_BR_VS1_K ['Cut'] = listcut
                    df_050_059_BR_VS1_K ['Polish'] = listpol
                    df_050_059_BR_VS1_K ['Symmetry'] = listsym
                    df_050_059_BR_VS1_K ['Ratio'] = listrat
                    df_050_059_BR_VS1_K ['PPC'] = listdesc
                    df_050_059_BR_VS1_K ['Total'] = listtotal
                    df_050_059_BR_VS1_K['Carat'] = df_050_059_BR_VS1_K['Carat'].astype('float64')
                    df_050_059_BR_VS1_K['PPC'] = df_050_059_BR_VS1_K['PPC'].astype('float64')
                    df_050_059_BR_VS1_K['Total'] = df_050_059_BR_VS1_K['Total'].astype('float64')
                    df_050_059_BR_VS1_K['Total'] = df_050_059_BR_VS1_K['Carat'] * df_050_059_BR_VS1_K['PPC']


                elif i=="K" and j == "VS2" and k == "BR":
                    df_050_059_BR_VS2_K = pd.DataFrame()
                    df_050_059_BR_VS2_K ['Wt Range'] = None
                    df_050_059_BR_VS2_K  = df_050_059_BR_VS2_K.assign(Company=None)
                    df_050_059_BR_VS2_K  = df_050_059_BR_VS2_K.assign(Shape=None)
                    df_050_059_BR_VS2_K  = df_050_059_BR_VS2_K.assign(Carat=None)
                    df_050_059_BR_VS2_K  = df_050_059_BR_VS2_K.assign(Color=None)
                    df_050_059_BR_VS2_K  = df_050_059_BR_VS2_K.assign(Clarity=None)
                    df_050_059_BR_VS2_K  = df_050_059_BR_VS2_K.assign(Cut=None)
                    df_050_059_BR_VS2_K  = df_050_059_BR_VS2_K.assign(Polish=None)
                    df_050_059_BR_VS2_K  = df_050_059_BR_VS2_K.assign(Symmetry=None)
                    df_050_059_BR_VS2_K  = df_050_059_BR_VS2_K.assign(Ratio=None)
                    df_050_059_BR_VS2_K  = df_050_059_BR_VS2_K.assign(PPC=None)
                    df_050_059_BR_VS2_K  = df_050_059_BR_VS2_K.assign(Total=None)
                    df_050_059_BR_VS2_K ['Wt Range'] = listwtrange
                    df_050_059_BR_VS2_K ['Company'] = listcom
                    df_050_059_BR_VS2_K ['Shape'] = listshap
                    df_050_059_BR_VS2_K ['Carat'] = listcar
                    df_050_059_BR_VS2_K ['Color'] = listcol
                    df_050_059_BR_VS2_K ['Clarity'] = listclar
                    df_050_059_BR_VS2_K ['Cut'] = listcut
                    df_050_059_BR_VS2_K ['Polish'] = listpol
                    df_050_059_BR_VS2_K ['Symmetry'] = listsym
                    df_050_059_BR_VS2_K ['Ratio'] = listrat
                    df_050_059_BR_VS2_K ['PPC'] = listdesc
                    df_050_059_BR_VS2_K ['Total'] = listtotal
                    df_050_059_BR_VS2_K['Carat'] = df_050_059_BR_VS2_K['Carat'].astype('float64')
                    df_050_059_BR_VS2_K['PPC'] = df_050_059_BR_VS2_K['PPC'].astype('float64')
                    df_050_059_BR_VS2_K['Total'] = df_050_059_BR_VS2_K['Total'].astype('float64')
                    df_050_059_BR_VS2_K['Total'] = df_050_059_BR_VS2_K['Carat'] * df_050_059_BR_VS2_K['PPC']


                elif i=="K" and j == "SI1" and k == "BR":
                    df_050_059_BR_SI1_K = pd.DataFrame()
                    df_050_059_BR_SI1_K ['Wt Range'] = None
                    df_050_059_BR_SI1_K  = df_050_059_BR_SI1_K.assign(Company=None)
                    df_050_059_BR_SI1_K  = df_050_059_BR_SI1_K.assign(Shape=None)
                    df_050_059_BR_SI1_K  = df_050_059_BR_SI1_K.assign(Carat=None)
                    df_050_059_BR_SI1_K  = df_050_059_BR_SI1_K.assign(Color=None)
                    df_050_059_BR_SI1_K  = df_050_059_BR_SI1_K.assign(Clarity=None)
                    df_050_059_BR_SI1_K  = df_050_059_BR_SI1_K.assign(Cut=None)
                    df_050_059_BR_SI1_K  = df_050_059_BR_SI1_K.assign(Polish=None)
                    df_050_059_BR_SI1_K  = df_050_059_BR_SI1_K.assign(Symmetry=None)
                    df_050_059_BR_SI1_K  = df_050_059_BR_SI1_K.assign(Ratio=None)
                    df_050_059_BR_SI1_K  = df_050_059_BR_SI1_K.assign(PPC=None)
                    df_050_059_BR_SI1_K  = df_050_059_BR_SI1_K.assign(Total=None)
                    df_050_059_BR_SI1_K ['Wt Range'] = listwtrange
                    df_050_059_BR_SI1_K ['Company'] = listcom
                    df_050_059_BR_SI1_K ['Shape'] = listshap
                    df_050_059_BR_SI1_K ['Carat'] = listcar
                    df_050_059_BR_SI1_K ['Color'] = listcol
                    df_050_059_BR_SI1_K ['Clarity'] = listclar
                    df_050_059_BR_SI1_K ['Cut'] = listcut
                    df_050_059_BR_SI1_K ['Polish'] = listpol
                    df_050_059_BR_SI1_K ['Symmetry'] = listsym
                    df_050_059_BR_SI1_K ['Ratio'] = listrat
                    df_050_059_BR_SI1_K ['PPC'] = listdesc
                    df_050_059_BR_SI1_K ['Total'] = listtotal
                    df_050_059_BR_SI1_K['Carat'] = df_050_059_BR_SI1_K['Carat'].astype('float64')
                    df_050_059_BR_SI1_K['PPC'] = df_050_059_BR_SI1_K['PPC'].astype('float64')
                    df_050_059_BR_SI1_K['Total'] = df_050_059_BR_SI1_K['Total'].astype('float64')
                    df_050_059_BR_SI1_K['Total'] = df_050_059_BR_SI1_K['Carat'] * df_050_059_BR_SI1_K['PPC']


                elif i=="K" and j == "SI2" and k == "BR":
                    df_050_059_BR_SI2_K = pd.DataFrame()
                    df_050_059_BR_SI2_K ['Wt Range'] = None
                    df_050_059_BR_SI2_K  = df_050_059_BR_SI2_K.assign(Company=None)
                    df_050_059_BR_SI2_K  = df_050_059_BR_SI2_K.assign(Shape=None)
                    df_050_059_BR_SI2_K  = df_050_059_BR_SI2_K.assign(Carat=None)
                    df_050_059_BR_SI2_K  = df_050_059_BR_SI2_K.assign(Color=None)
                    df_050_059_BR_SI2_K  = df_050_059_BR_SI2_K.assign(Clarity=None)
                    df_050_059_BR_SI2_K  = df_050_059_BR_SI2_K.assign(Cut=None)
                    df_050_059_BR_SI2_K  = df_050_059_BR_SI2_K.assign(Polish=None)
                    df_050_059_BR_SI2_K  = df_050_059_BR_SI2_K.assign(Symmetry=None)
                    df_050_059_BR_SI2_K  = df_050_059_BR_SI2_K.assign(Ratio=None)
                    df_050_059_BR_SI2_K  = df_050_059_BR_SI2_K.assign(PPC=None)
                    df_050_059_BR_SI2_K  = df_050_059_BR_SI2_K.assign(Total=None)
                    df_050_059_BR_SI2_K ['Wt Range'] = listwtrange
                    df_050_059_BR_SI2_K ['Company'] = listcom
                    df_050_059_BR_SI2_K ['Shape'] = listshap
                    df_050_059_BR_SI2_K ['Carat'] = listcar
                    df_050_059_BR_SI2_K ['Color'] = listcol
                    df_050_059_BR_SI2_K ['Clarity'] = listclar
                    df_050_059_BR_SI2_K ['Cut'] = listcut
                    df_050_059_BR_SI2_K ['Polish'] = listpol
                    df_050_059_BR_SI2_K ['Symmetry'] = listsym
                    df_050_059_BR_SI2_K ['Ratio'] = listrat
                    df_050_059_BR_SI2_K ['PPC'] = listdesc
                    df_050_059_BR_SI2_K ['Total'] = listtotal
                    df_050_059_BR_SI2_K['Carat'] = df_050_059_BR_SI2_K['Carat'].astype('float64')
                    df_050_059_BR_SI2_K['PPC'] = df_050_059_BR_SI2_K['PPC'].astype('float64')
                    df_050_059_BR_SI2_K['Total'] = df_050_059_BR_SI2_K['Total'].astype('float64')
                    df_050_059_BR_SI2_K['Total'] = df_050_059_BR_SI2_K['Carat'] * df_050_059_BR_SI2_K['PPC']


                elif i=="K" and j == "I1" and k == "BR":
                    df_050_059_BR_I1_K = pd.DataFrame()
                    df_050_059_BR_I1_K ['Wt Range'] = None
                    df_050_059_BR_I1_K  = df_050_059_BR_I1_K.assign(Company=None)
                    df_050_059_BR_I1_K  = df_050_059_BR_I1_K.assign(Shape=None)
                    df_050_059_BR_I1_K  = df_050_059_BR_I1_K.assign(Carat=None)
                    df_050_059_BR_I1_K  = df_050_059_BR_I1_K.assign(Color=None)
                    df_050_059_BR_I1_K  = df_050_059_BR_I1_K.assign(Clarity=None)
                    df_050_059_BR_I1_K  = df_050_059_BR_I1_K.assign(Cut=None)
                    df_050_059_BR_I1_K  = df_050_059_BR_I1_K.assign(Polish=None)
                    df_050_059_BR_I1_K  = df_050_059_BR_I1_K.assign(Symmetry=None)
                    df_050_059_BR_I1_K  = df_050_059_BR_I1_K.assign(Ratio=None)
                    df_050_059_BR_I1_K  = df_050_059_BR_I1_K.assign(PPC=None)
                    df_050_059_BR_I1_K  = df_050_059_BR_I1_K.assign(Total=None)
                    df_050_059_BR_I1_K ['Wt Range'] = listwtrange
                    df_050_059_BR_I1_K ['Company'] = listcom
                    df_050_059_BR_I1_K ['Shape'] = listshap
                    df_050_059_BR_I1_K ['Carat'] = listcar
                    df_050_059_BR_I1_K ['Color'] = listcol
                    df_050_059_BR_I1_K ['Clarity'] = listclar
                    df_050_059_BR_I1_K ['Cut'] = listcut
                    df_050_059_BR_I1_K ['Polish'] = listpol
                    df_050_059_BR_I1_K ['Symmetry'] = listsym
                    df_050_059_BR_I1_K ['Ratio'] = listrat
                    df_050_059_BR_I1_K ['PPC'] = listdesc
                    df_050_059_BR_I1_K ['Total'] = listtotal
                    df_050_059_BR_I1_K['Carat'] = df_050_059_BR_I1_K['Carat'].astype('float64')
                    df_050_059_BR_I1_K['PPC'] = df_050_059_BR_I1_K['PPC'].astype('float64')
                    df_050_059_BR_I1_K['Total'] = df_050_059_BR_I1_K['Total'].astype('float64')
                    df_050_059_BR_I1_K['Total'] = df_050_059_BR_I1_K['Carat'] * df_050_059_BR_I1_K['PPC']


                elif i=="K" and j == "I2" and k == "BR":
                    df_050_059_BR_I2_K = pd.DataFrame()
                    df_050_059_BR_I2_K ['Wt Range'] = None
                    df_050_059_BR_I2_K  = df_050_059_BR_I2_K.assign(Company=None)
                    df_050_059_BR_I2_K  = df_050_059_BR_I2_K.assign(Shape=None)
                    df_050_059_BR_I2_K  = df_050_059_BR_I2_K.assign(Carat=None)
                    df_050_059_BR_I2_K  = df_050_059_BR_I2_K.assign(Color=None)
                    df_050_059_BR_I2_K  = df_050_059_BR_I2_K.assign(Clarity=None)
                    df_050_059_BR_I2_K  = df_050_059_BR_I2_K.assign(Cut=None)
                    df_050_059_BR_I2_K  = df_050_059_BR_I2_K.assign(Polish=None)
                    df_050_059_BR_I2_K  = df_050_059_BR_I2_K.assign(Symmetry=None)
                    df_050_059_BR_I2_K  = df_050_059_BR_I2_K.assign(Ratio=None)
                    df_050_059_BR_I2_K  = df_050_059_BR_I2_K.assign(PPC=None)
                    df_050_059_BR_I2_K  = df_050_059_BR_I2_K.assign(Total=None)
                    df_050_059_BR_I2_K ['Wt Range'] = listwtrange
                    df_050_059_BR_I2_K ['Company'] = listcom
                    df_050_059_BR_I2_K ['Shape'] = listshap
                    df_050_059_BR_I2_K ['Carat'] = listcar
                    df_050_059_BR_I2_K ['Color'] = listcol
                    df_050_059_BR_I2_K ['Clarity'] = listclar
                    df_050_059_BR_I2_K ['Cut'] = listcut
                    df_050_059_BR_I2_K ['Polish'] = listpol
                    df_050_059_BR_I2_K ['Symmetry'] = listsym
                    df_050_059_BR_I2_K ['Ratio'] = listrat
                    df_050_059_BR_I2_K ['PPC'] = listdesc
                    df_050_059_BR_I2_K ['Total'] = listtotal
                    df_050_059_BR_I2_K['Carat'] = df_050_059_BR_I2_K['Carat'].astype('float64')
                    df_050_059_BR_I2_K['PPC'] = df_050_059_BR_I2_K['PPC'].astype('float64')
                    df_050_059_BR_I2_K['Total'] = df_050_059_BR_I2_K['Total'].astype('float64')
                    df_050_059_BR_I2_K['Total'] = df_050_059_BR_I2_K['Carat'] * df_050_059_BR_I2_K['PPC']


                elif i=="L" and j == "IF" and k == "BR":
                    df_050_059_BR_IF_L = pd.DataFrame()
                    df_050_059_BR_IF_L ['Wt Range'] = None
                    df_050_059_BR_IF_L  = df_050_059_BR_IF_L.assign(Company=None)
                    df_050_059_BR_IF_L  = df_050_059_BR_IF_L.assign(Shape=None)
                    df_050_059_BR_IF_L  = df_050_059_BR_IF_L.assign(Carat=None)
                    df_050_059_BR_IF_L  = df_050_059_BR_IF_L.assign(Color=None)
                    df_050_059_BR_IF_L  = df_050_059_BR_IF_L.assign(Clarity=None)
                    df_050_059_BR_IF_L  = df_050_059_BR_IF_L.assign(Cut=None)
                    df_050_059_BR_IF_L  = df_050_059_BR_IF_L.assign(Polish=None)
                    df_050_059_BR_IF_L  = df_050_059_BR_IF_L.assign(Symmetry=None)
                    df_050_059_BR_IF_L  = df_050_059_BR_IF_L.assign(Ratio=None)
                    df_050_059_BR_IF_L  = df_050_059_BR_IF_L.assign(PPC=None)
                    df_050_059_BR_IF_L  = df_050_059_BR_IF_L.assign(Total=None)
                    df_050_059_BR_IF_L ['Wt Range'] = listwtrange
                    df_050_059_BR_IF_L ['Company'] = listcom
                    df_050_059_BR_IF_L ['Shape'] = listshap
                    df_050_059_BR_IF_L ['Carat'] = listcar
                    df_050_059_BR_IF_L ['Color'] = listcol
                    df_050_059_BR_IF_L ['Clarity'] = listclar
                    df_050_059_BR_IF_L ['Cut'] = listcut
                    df_050_059_BR_IF_L ['Polish'] = listpol
                    df_050_059_BR_IF_L ['Symmetry'] = listsym
                    df_050_059_BR_IF_L ['Ratio'] = listrat
                    df_050_059_BR_IF_L ['PPC'] = listdesc
                    df_050_059_BR_IF_L ['Total'] = listtotal
                    df_050_059_BR_IF_L['Carat'] = df_050_059_BR_IF_L['Carat'].astype('float64')
                    df_050_059_BR_IF_L['PPC'] = df_050_059_BR_IF_L['PPC'].astype('float64')
                    df_050_059_BR_IF_L['Total'] = df_050_059_BR_IF_L['Total'].astype('float64')
                    df_050_059_BR_IF_L['Total'] = df_050_059_BR_IF_L['Carat'] * df_050_059_BR_IF_L['PPC']


                elif i=="L" and j == "VVS1" and k == "BR":
                    df_050_059_BR_VVS1_L = pd.DataFrame()
                    df_050_059_BR_VVS1_L ['Wt Range'] = None
                    df_050_059_BR_VVS1_L  = df_050_059_BR_VVS1_L.assign(Company=None)
                    df_050_059_BR_VVS1_L  = df_050_059_BR_VVS1_L.assign(Shape=None)
                    df_050_059_BR_VVS1_L  = df_050_059_BR_VVS1_L.assign(Carat=None)
                    df_050_059_BR_VVS1_L  = df_050_059_BR_VVS1_L.assign(Color=None)
                    df_050_059_BR_VVS1_L  = df_050_059_BR_VVS1_L.assign(Clarity=None)
                    df_050_059_BR_VVS1_L  = df_050_059_BR_VVS1_L.assign(Cut=None)
                    df_050_059_BR_VVS1_L  = df_050_059_BR_VVS1_L.assign(Polish=None)
                    df_050_059_BR_VVS1_L  = df_050_059_BR_VVS1_L.assign(Symmetry=None)
                    df_050_059_BR_VVS1_L  = df_050_059_BR_VVS1_L.assign(Ratio=None)
                    df_050_059_BR_VVS1_L  = df_050_059_BR_VVS1_L.assign(PPC=None)
                    df_050_059_BR_VVS1_L  = df_050_059_BR_VVS1_L.assign(Total=None)
                    df_050_059_BR_VVS1_L ['Wt Range'] = listwtrange
                    df_050_059_BR_VVS1_L ['Company'] = listcom
                    df_050_059_BR_VVS1_L ['Shape'] = listshap
                    df_050_059_BR_VVS1_L ['Carat'] = listcar
                    df_050_059_BR_VVS1_L ['Color'] = listcol
                    df_050_059_BR_VVS1_L ['Clarity'] = listclar
                    df_050_059_BR_VVS1_L ['Cut'] = listcut
                    df_050_059_BR_VVS1_L ['Polish'] = listpol
                    df_050_059_BR_VVS1_L ['Symmetry'] = listsym
                    df_050_059_BR_VVS1_L ['Ratio'] = listrat
                    df_050_059_BR_VVS1_L ['PPC'] = listdesc
                    df_050_059_BR_VVS1_L ['Total'] = listtotal
                    df_050_059_BR_VVS1_L['Carat'] = df_050_059_BR_VVS1_L['Carat'].astype('float64')
                    df_050_059_BR_VVS1_L['PPC'] = df_050_059_BR_VVS1_L['PPC'].astype('float64')
                    df_050_059_BR_VVS1_L['Total'] = df_050_059_BR_VVS1_L['Total'].astype('float64')
                    df_050_059_BR_VVS1_L['Total'] = df_050_059_BR_VVS1_L['Carat'] * df_050_059_BR_VVS1_L['PPC']


                elif i=="L" and j == "VVS2" and k == "BR":
                    df_050_059_BR_VVS2_L = pd.DataFrame()
                    df_050_059_BR_VVS2_L ['Wt Range'] = None
                    df_050_059_BR_VVS2_L  = df_050_059_BR_VVS2_L.assign(Company=None)
                    df_050_059_BR_VVS2_L  = df_050_059_BR_VVS2_L.assign(Shape=None)
                    df_050_059_BR_VVS2_L  = df_050_059_BR_VVS2_L.assign(Carat=None)
                    df_050_059_BR_VVS2_L  = df_050_059_BR_VVS2_L.assign(Color=None)
                    df_050_059_BR_VVS2_L  = df_050_059_BR_VVS2_L.assign(Clarity=None)
                    df_050_059_BR_VVS2_L  = df_050_059_BR_VVS2_L.assign(Cut=None)
                    df_050_059_BR_VVS2_L  = df_050_059_BR_VVS2_L.assign(Polish=None)
                    df_050_059_BR_VVS2_L  = df_050_059_BR_VVS2_L.assign(Symmetry=None)
                    df_050_059_BR_VVS2_L  = df_050_059_BR_VVS2_L.assign(Ratio=None)
                    df_050_059_BR_VVS2_L  = df_050_059_BR_VVS2_L.assign(PPC=None)
                    df_050_059_BR_VVS2_L  = df_050_059_BR_VVS2_L.assign(Total=None)
                    df_050_059_BR_VVS2_L ['Wt Range'] = listwtrange
                    df_050_059_BR_VVS2_L ['Company'] = listcom
                    df_050_059_BR_VVS2_L ['Shape'] = listshap
                    df_050_059_BR_VVS2_L ['Carat'] = listcar
                    df_050_059_BR_VVS2_L ['Color'] = listcol
                    df_050_059_BR_VVS2_L ['Clarity'] = listclar
                    df_050_059_BR_VVS2_L ['Cut'] = listcut
                    df_050_059_BR_VVS2_L ['Polish'] = listpol
                    df_050_059_BR_VVS2_L ['Symmetry'] = listsym
                    df_050_059_BR_VVS2_L ['Ratio'] = listrat
                    df_050_059_BR_VVS2_L ['PPC'] = listdesc
                    df_050_059_BR_VVS2_L ['Total'] = listtotal
                    df_050_059_BR_VVS2_L['Carat'] = df_050_059_BR_VVS2_L['Carat'].astype('float64')
                    df_050_059_BR_VVS2_L['PPC'] = df_050_059_BR_VVS2_L['PPC'].astype('float64')
                    df_050_059_BR_VVS2_L['Total'] = df_050_059_BR_VVS2_L['Total'].astype('float64')
                    df_050_059_BR_VVS2_L['Total'] = df_050_059_BR_VVS2_L['Carat'] * df_050_059_BR_VVS2_L['PPC']


                elif i=="L" and j=="VS1" and k == "BR":
                    df_050_059_BR_VS1_L = pd.DataFrame()
                    df_050_059_BR_VS1_L ['Wt Range'] = None
                    df_050_059_BR_VS1_L  = df_050_059_BR_VS1_L.assign(Company=None)
                    df_050_059_BR_VS1_L  = df_050_059_BR_VS1_L.assign(Shape=None)
                    df_050_059_BR_VS1_L  = df_050_059_BR_VS1_L.assign(Carat=None)
                    df_050_059_BR_VS1_L  = df_050_059_BR_VS1_L.assign(Color=None)
                    df_050_059_BR_VS1_L  = df_050_059_BR_VS1_L.assign(Clarity=None)
                    df_050_059_BR_VS1_L  = df_050_059_BR_VS1_L.assign(Cut=None)
                    df_050_059_BR_VS1_L  = df_050_059_BR_VS1_L.assign(Polish=None)
                    df_050_059_BR_VS1_L  = df_050_059_BR_VS1_L.assign(Symmetry=None)
                    df_050_059_BR_VS1_L  = df_050_059_BR_VS1_L.assign(Ratio=None)
                    df_050_059_BR_VS1_L  = df_050_059_BR_VS1_L.assign(PPC=None)
                    df_050_059_BR_VS1_L  = df_050_059_BR_VS1_L.assign(Total=None)
                    df_050_059_BR_VS1_L ['Wt Range'] = listwtrange
                    df_050_059_BR_VS1_L ['Company'] = listcom
                    df_050_059_BR_VS1_L ['Shape'] = listshap
                    df_050_059_BR_VS1_L ['Carat'] = listcar
                    df_050_059_BR_VS1_L ['Color'] = listcol
                    df_050_059_BR_VS1_L ['Clarity'] = listclar
                    df_050_059_BR_VS1_L ['Cut'] = listcut
                    df_050_059_BR_VS1_L ['Polish'] = listpol
                    df_050_059_BR_VS1_L ['Symmetry'] = listsym
                    df_050_059_BR_VS1_L ['Ratio'] = listrat
                    df_050_059_BR_VS1_L ['PPC'] = listdesc
                    df_050_059_BR_VS1_L ['Total'] = listtotal
                    df_050_059_BR_VS1_L['Carat'] = df_050_059_BR_VS1_L['Carat'].astype('float64')
                    df_050_059_BR_VS1_L['PPC'] = df_050_059_BR_VS1_L['PPC'].astype('float64')
                    df_050_059_BR_VS1_L['Total'] = df_050_059_BR_VS1_L['Total'].astype('float64')
                    df_050_059_BR_VS1_L['Total'] = df_050_059_BR_VS1_L['Carat'] * df_050_059_BR_VS1_L['PPC']


                elif i=="L" and j == "VS2" and k == "BR":
                    df_050_059_BR_VS2_L = pd.DataFrame()
                    df_050_059_BR_VS2_L ['Wt Range'] = None
                    df_050_059_BR_VS2_L  = df_050_059_BR_VS2_L.assign(Company=None)
                    df_050_059_BR_VS2_L  = df_050_059_BR_VS2_L.assign(Shape=None)
                    df_050_059_BR_VS2_L  = df_050_059_BR_VS2_L.assign(Carat=None)
                    df_050_059_BR_VS2_L  = df_050_059_BR_VS2_L.assign(Color=None)
                    df_050_059_BR_VS2_L  = df_050_059_BR_VS2_L.assign(Clarity=None)
                    df_050_059_BR_VS2_L  = df_050_059_BR_VS2_L.assign(Cut=None)
                    df_050_059_BR_VS2_L  = df_050_059_BR_VS2_L.assign(Polish=None)
                    df_050_059_BR_VS2_L  = df_050_059_BR_VS2_L.assign(Symmetry=None)
                    df_050_059_BR_VS2_L  = df_050_059_BR_VS2_L.assign(Ratio=None)
                    df_050_059_BR_VS2_L  = df_050_059_BR_VS2_L.assign(PPC=None)
                    df_050_059_BR_VS2_L  = df_050_059_BR_VS2_L.assign(Total=None)
                    df_050_059_BR_VS2_L ['Wt Range'] = listwtrange
                    df_050_059_BR_VS2_L ['Company'] = listcom
                    df_050_059_BR_VS2_L ['Shape'] = listshap
                    df_050_059_BR_VS2_L ['Carat'] = listcar
                    df_050_059_BR_VS2_L ['Color'] = listcol
                    df_050_059_BR_VS2_L ['Clarity'] = listclar
                    df_050_059_BR_VS2_L ['Cut'] = listcut
                    df_050_059_BR_VS2_L ['Polish'] = listpol
                    df_050_059_BR_VS2_L ['Symmetry'] = listsym
                    df_050_059_BR_VS2_L ['Ratio'] = listrat
                    df_050_059_BR_VS2_L ['PPC'] = listdesc
                    df_050_059_BR_VS2_L ['Total'] = listtotal
                    df_050_059_BR_VS2_L['Carat'] = df_050_059_BR_VS2_L['Carat'].astype('float64')
                    df_050_059_BR_VS2_L['PPC'] = df_050_059_BR_VS2_L['PPC'].astype('float64')
                    df_050_059_BR_VS2_L['Total'] = df_050_059_BR_VS2_L['Total'].astype('float64')
                    df_050_059_BR_VS2_L['Total'] = df_050_059_BR_VS2_L['Carat'] * df_050_059_BR_VS2_L['PPC']


                elif i=="L" and j == "SI1" and k == "BR":
                    df_050_059_BR_SI1_L = pd.DataFrame()
                    df_050_059_BR_SI1_L ['Wt Range'] = None
                    df_050_059_BR_SI1_L  = df_050_059_BR_SI1_L.assign(Company=None)
                    df_050_059_BR_SI1_L  = df_050_059_BR_SI1_L.assign(Shape=None)
                    df_050_059_BR_SI1_L  = df_050_059_BR_SI1_L.assign(Carat=None)
                    df_050_059_BR_SI1_L  = df_050_059_BR_SI1_L.assign(Color=None)
                    df_050_059_BR_SI1_L  = df_050_059_BR_SI1_L.assign(Clarity=None)
                    df_050_059_BR_SI1_L  = df_050_059_BR_SI1_L.assign(Cut=None)
                    df_050_059_BR_SI1_L  = df_050_059_BR_SI1_L.assign(Polish=None)
                    df_050_059_BR_SI1_L  = df_050_059_BR_SI1_L.assign(Symmetry=None)
                    df_050_059_BR_SI1_L  = df_050_059_BR_SI1_L.assign(Ratio=None)
                    df_050_059_BR_SI1_L  = df_050_059_BR_SI1_L.assign(PPC=None)
                    df_050_059_BR_SI1_L  = df_050_059_BR_SI1_L.assign(Total=None)
                    df_050_059_BR_SI1_L ['Wt Range'] = listwtrange
                    df_050_059_BR_SI1_L ['Company'] = listcom
                    df_050_059_BR_SI1_L ['Shape'] = listshap
                    df_050_059_BR_SI1_L ['Carat'] = listcar
                    df_050_059_BR_SI1_L ['Color'] = listcol
                    df_050_059_BR_SI1_L ['Clarity'] = listclar
                    df_050_059_BR_SI1_L ['Cut'] = listcut
                    df_050_059_BR_SI1_L ['Polish'] = listpol
                    df_050_059_BR_SI1_L ['Symmetry'] = listsym
                    df_050_059_BR_SI1_L ['Ratio'] = listrat
                    df_050_059_BR_SI1_L ['PPC'] = listdesc
                    df_050_059_BR_SI1_L ['Total'] = listtotal
                    df_050_059_BR_SI1_L['Carat'] = df_050_059_BR_SI1_L['Carat'].astype('float64')
                    df_050_059_BR_SI1_L['PPC'] = df_050_059_BR_SI1_L['PPC'].astype('float64')
                    df_050_059_BR_SI1_L['Total'] = df_050_059_BR_SI1_L['Total'].astype('float64')
                    df_050_059_BR_SI1_L['Total'] = df_050_059_BR_SI1_L['Carat'] * df_050_059_BR_SI1_L['PPC']


                elif i=="L" and j == "SI2" and k == "BR":
                    df_050_059_BR_SI2_L = pd.DataFrame()
                    df_050_059_BR_SI2_L ['Wt Range'] = None
                    df_050_059_BR_SI2_L  = df_050_059_BR_SI2_L.assign(Company=None)
                    df_050_059_BR_SI2_L  = df_050_059_BR_SI2_L.assign(Shape=None)
                    df_050_059_BR_SI2_L  = df_050_059_BR_SI2_L.assign(Carat=None)
                    df_050_059_BR_SI2_L  = df_050_059_BR_SI2_L.assign(Color=None)
                    df_050_059_BR_SI2_L  = df_050_059_BR_SI2_L.assign(Clarity=None)
                    df_050_059_BR_SI2_L  = df_050_059_BR_SI2_L.assign(Cut=None)
                    df_050_059_BR_SI2_L  = df_050_059_BR_SI2_L.assign(Polish=None)
                    df_050_059_BR_SI2_L  = df_050_059_BR_SI2_L.assign(Symmetry=None)
                    df_050_059_BR_SI2_L  = df_050_059_BR_SI2_L.assign(Ratio=None)
                    df_050_059_BR_SI2_L  = df_050_059_BR_SI2_L.assign(PPC=None)
                    df_050_059_BR_SI2_L  = df_050_059_BR_SI2_L.assign(Total=None)
                    df_050_059_BR_SI2_L ['Wt Range'] = listwtrange
                    df_050_059_BR_SI2_L ['Company'] = listcom
                    df_050_059_BR_SI2_L ['Shape'] = listshap
                    df_050_059_BR_SI2_L ['Carat'] = listcar
                    df_050_059_BR_SI2_L ['Color'] = listcol
                    df_050_059_BR_SI2_L ['Clarity'] = listclar
                    df_050_059_BR_SI2_L ['Cut'] = listcut
                    df_050_059_BR_SI2_L ['Polish'] = listpol
                    df_050_059_BR_SI2_L ['Symmetry'] = listsym
                    df_050_059_BR_SI2_L ['Ratio'] = listrat
                    df_050_059_BR_SI2_L ['PPC'] = listdesc
                    df_050_059_BR_SI2_L ['Total'] = listtotal
                    df_050_059_BR_SI2_L['Carat'] = df_050_059_BR_SI2_L['Carat'].astype('float64')
                    df_050_059_BR_SI2_L['PPC'] = df_050_059_BR_SI2_L['PPC'].astype('float64')
                    df_050_059_BR_SI2_L['Total'] = df_050_059_BR_SI2_L['Total'].astype('float64')
                    df_050_059_BR_SI2_L['Total'] = df_050_059_BR_SI2_L['Carat'] * df_050_059_BR_SI2_L['PPC']


                elif i=="L" and j == "I1" and k == "BR":
                    df_050_059_BR_I1_L = pd.DataFrame()
                    df_050_059_BR_I1_L ['Wt Range'] = None
                    df_050_059_BR_I1_L  = df_050_059_BR_I1_L.assign(Company=None)
                    df_050_059_BR_I1_L  = df_050_059_BR_I1_L.assign(Shape=None)
                    df_050_059_BR_I1_L  = df_050_059_BR_I1_L.assign(Carat=None)
                    df_050_059_BR_I1_L  = df_050_059_BR_I1_L.assign(Color=None)
                    df_050_059_BR_I1_L  = df_050_059_BR_I1_L.assign(Clarity=None)
                    df_050_059_BR_I1_L  = df_050_059_BR_I1_L.assign(Cut=None)
                    df_050_059_BR_I1_L  = df_050_059_BR_I1_L.assign(Polish=None)
                    df_050_059_BR_I1_L  = df_050_059_BR_I1_L.assign(Symmetry=None)
                    df_050_059_BR_I1_L  = df_050_059_BR_I1_L.assign(Ratio=None)
                    df_050_059_BR_I1_L  = df_050_059_BR_I1_L.assign(PPC=None)
                    df_050_059_BR_I1_L  = df_050_059_BR_I1_L.assign(Total=None)
                    df_050_059_BR_I1_L ['Wt Range'] = listwtrange
                    df_050_059_BR_I1_L ['Company'] = listcom
                    df_050_059_BR_I1_L ['Shape'] = listshap
                    df_050_059_BR_I1_L ['Carat'] = listcar
                    df_050_059_BR_I1_L ['Color'] = listcol
                    df_050_059_BR_I1_L ['Clarity'] = listclar
                    df_050_059_BR_I1_L ['Cut'] = listcut
                    df_050_059_BR_I1_L ['Polish'] = listpol
                    df_050_059_BR_I1_L ['Symmetry'] = listsym
                    df_050_059_BR_I1_L ['Ratio'] = listrat
                    df_050_059_BR_I1_L ['PPC'] = listdesc
                    df_050_059_BR_I1_L ['Total'] = listtotal
                    df_050_059_BR_I1_L['Carat'] = df_050_059_BR_I1_L['Carat'].astype('float64')
                    df_050_059_BR_I1_L['PPC'] = df_050_059_BR_I1_L['PPC'].astype('float64')
                    df_050_059_BR_I1_L['Total'] = df_050_059_BR_I1_L['Total'].astype('float64')
                    df_050_059_BR_I1_L['Total'] = df_050_059_BR_I1_L['Carat'] * df_050_059_BR_I1_L['PPC']


                elif i=="L" and j == "I2" and k == "BR":
                    df_050_059_BR_I2_L = pd.DataFrame()
                    df_050_059_BR_I2_L ['Wt Range'] = None
                    df_050_059_BR_I2_L  = df_050_059_BR_I2_L.assign(Company=None)
                    df_050_059_BR_I2_L  = df_050_059_BR_I2_L.assign(Shape=None)
                    df_050_059_BR_I2_L  = df_050_059_BR_I2_L.assign(Carat=None)
                    df_050_059_BR_I2_L  = df_050_059_BR_I2_L.assign(Color=None)
                    df_050_059_BR_I2_L  = df_050_059_BR_I2_L.assign(Clarity=None)
                    df_050_059_BR_I2_L  = df_050_059_BR_I2_L.assign(Cut=None)
                    df_050_059_BR_I2_L  = df_050_059_BR_I2_L.assign(Polish=None)
                    df_050_059_BR_I2_L  = df_050_059_BR_I2_L.assign(Symmetry=None)
                    df_050_059_BR_I2_L  = df_050_059_BR_I2_L.assign(Ratio=None)
                    df_050_059_BR_I2_L  = df_050_059_BR_I2_L.assign(PPC=None)
                    df_050_059_BR_I2_L  = df_050_059_BR_I2_L.assign(Total=None)
                    df_050_059_BR_I2_L ['Wt Range'] = listwtrange
                    df_050_059_BR_I2_L ['Company'] = listcom
                    df_050_059_BR_I2_L ['Shape'] = listshap
                    df_050_059_BR_I2_L ['Carat'] = listcar
                    df_050_059_BR_I2_L ['Color'] = listcol
                    df_050_059_BR_I2_L ['Clarity'] = listclar
                    df_050_059_BR_I2_L ['Cut'] = listcut
                    df_050_059_BR_I2_L ['Polish'] = listpol
                    df_050_059_BR_I2_L ['Symmetry'] = listsym
                    df_050_059_BR_I2_L ['Ratio'] = listrat
                    df_050_059_BR_I2_L ['PPC'] = listdesc
                    df_050_059_BR_I2_L ['Total'] = listtotal
                    df_050_059_BR_I2_L['Carat'] = df_050_059_BR_I2_L['Carat'].astype('float64')
                    df_050_059_BR_I2_L['PPC'] = df_050_059_BR_I2_L['PPC'].astype('float64')
                    df_050_059_BR_I2_L['Total'] = df_050_059_BR_I2_L['Total'].astype('float64')
                    df_050_059_BR_I2_L['Total'] = df_050_059_BR_I2_L['Carat'] * df_050_059_BR_I2_L['PPC']

                    
                elif i=="D" and j == "IF" and k == "OV":
                    df_050_059_OV_IF_D = pd.DataFrame()
                    df_050_059_OV_IF_D ['Wt Range'] = None
                    df_050_059_OV_IF_D  = df_050_059_OV_IF_D.assign(Company=None)
                    df_050_059_OV_IF_D  = df_050_059_OV_IF_D.assign(Shape=None)
                    df_050_059_OV_IF_D  = df_050_059_OV_IF_D.assign(Carat=None)
                    df_050_059_OV_IF_D  = df_050_059_OV_IF_D.assign(Color=None)
                    df_050_059_OV_IF_D  = df_050_059_OV_IF_D.assign(Clarity=None)
                    df_050_059_OV_IF_D  = df_050_059_OV_IF_D.assign(Cut=None)
                    df_050_059_OV_IF_D  = df_050_059_OV_IF_D.assign(Polish=None)
                    df_050_059_OV_IF_D  = df_050_059_OV_IF_D.assign(Symmetry=None)
                    df_050_059_OV_IF_D  = df_050_059_OV_IF_D.assign(Ratio=None)
                    df_050_059_OV_IF_D  = df_050_059_OV_IF_D.assign(PPC=None)
                    df_050_059_OV_IF_D  = df_050_059_OV_IF_D.assign(Total=None)
                    df_050_059_OV_IF_D ['Wt Range'] = listwtrange
                    df_050_059_OV_IF_D ['Company'] = listcom
                    df_050_059_OV_IF_D ['Shape'] = listshap
                    df_050_059_OV_IF_D ['Carat'] = listcar
                    df_050_059_OV_IF_D ['Color'] = listcol
                    df_050_059_OV_IF_D ['Clarity'] = listclar
                    df_050_059_OV_IF_D ['Cut'] = listcut
                    df_050_059_OV_IF_D ['Polish'] = listpol
                    df_050_059_OV_IF_D ['Symmetry'] = listsym
                    df_050_059_OV_IF_D ['Ratio'] = listrat
                    df_050_059_OV_IF_D ['PPC'] = listdesc
                    df_050_059_OV_IF_D ['Total'] = listtotal
                    df_050_059_OV_IF_D['Carat'] = df_050_059_OV_IF_D['Carat'].astype('float64')
                    df_050_059_OV_IF_D['PPC'] = df_050_059_OV_IF_D['PPC'].astype('float64')
                    df_050_059_OV_IF_D['Total'] = df_050_059_OV_IF_D['Total'].astype('float64')
                    df_050_059_OV_IF_D['Total'] = df_050_059_OV_IF_D['Carat'] * df_050_059_OV_IF_D['PPC']



                elif i=="D" and j == "VVS1" and k == "OV" :
                    df_050_059_OV_VVS1_D = pd.DataFrame()
                    df_050_059_OV_VVS1_D ['Wt Range'] = None
                    df_050_059_OV_VVS1_D  = df_050_059_OV_VVS1_D.assign(Company=None)
                    df_050_059_OV_VVS1_D  = df_050_059_OV_VVS1_D.assign(Shape=None)
                    df_050_059_OV_VVS1_D  = df_050_059_OV_VVS1_D.assign(Carat=None)
                    df_050_059_OV_VVS1_D  = df_050_059_OV_VVS1_D.assign(Color=None)
                    df_050_059_OV_VVS1_D  = df_050_059_OV_VVS1_D.assign(Clarity=None)
                    df_050_059_OV_VVS1_D  = df_050_059_OV_VVS1_D.assign(Cut=None)
                    df_050_059_OV_VVS1_D  = df_050_059_OV_VVS1_D.assign(Polish=None)
                    df_050_059_OV_VVS1_D  = df_050_059_OV_VVS1_D.assign(Symmetry=None)
                    df_050_059_OV_VVS1_D  = df_050_059_OV_VVS1_D.assign(Ratio=None)
                    df_050_059_OV_VVS1_D  = df_050_059_OV_VVS1_D.assign(PPC=None)
                    df_050_059_OV_VVS1_D  = df_050_059_OV_VVS1_D.assign(Total=None)
                    df_050_059_OV_VVS1_D ['Wt Range'] = listwtrange
                    df_050_059_OV_VVS1_D ['Company'] = listcom
                    df_050_059_OV_VVS1_D ['Shape'] = listshap
                    df_050_059_OV_VVS1_D ['Carat'] = listcar
                    df_050_059_OV_VVS1_D ['Color'] = listcol
                    df_050_059_OV_VVS1_D ['Clarity'] = listclar
                    df_050_059_OV_VVS1_D ['Cut'] = listcut
                    df_050_059_OV_VVS1_D ['Polish'] = listpol
                    df_050_059_OV_VVS1_D ['Symmetry'] = listsym
                    df_050_059_OV_VVS1_D ['Ratio'] = listrat
                    df_050_059_OV_VVS1_D ['PPC'] = listdesc
                    df_050_059_OV_VVS1_D ['Total'] = listtotal
                    df_050_059_OV_VVS1_D['Carat'] = df_050_059_OV_VVS1_D['Carat'].astype('float64')
                    df_050_059_OV_VVS1_D['PPC'] = df_050_059_OV_VVS1_D['PPC'].astype('float64')
                    df_050_059_OV_VVS1_D['Total'] = df_050_059_OV_VVS1_D['Total'].astype('float64')
                    df_050_059_OV_VVS1_D['Total'] = df_050_059_OV_VVS1_D['Carat'] * df_050_059_OV_VVS1_D['PPC']



                elif i=="D" and j == "VVS2" and k == "OV" :
                    df_050_059_OV_VVS2_D = pd.DataFrame()
                    df_050_059_OV_VVS2_D ['Wt Range'] = None
                    df_050_059_OV_VVS2_D  = df_050_059_OV_VVS2_D.assign(Company=None)
                    df_050_059_OV_VVS2_D  = df_050_059_OV_VVS2_D.assign(Shape=None)
                    df_050_059_OV_VVS2_D  = df_050_059_OV_VVS2_D.assign(Carat=None)
                    df_050_059_OV_VVS2_D  = df_050_059_OV_VVS2_D.assign(Color=None)
                    df_050_059_OV_VVS2_D  = df_050_059_OV_VVS2_D.assign(Clarity=None)
                    df_050_059_OV_VVS2_D  = df_050_059_OV_VVS2_D.assign(Cut=None)
                    df_050_059_OV_VVS2_D  = df_050_059_OV_VVS2_D.assign(Polish=None)
                    df_050_059_OV_VVS2_D  = df_050_059_OV_VVS2_D.assign(Symmetry=None)
                    df_050_059_OV_VVS2_D  = df_050_059_OV_VVS2_D.assign(Ratio=None)
                    df_050_059_OV_VVS2_D  = df_050_059_OV_VVS2_D.assign(PPC=None)
                    df_050_059_OV_VVS2_D  = df_050_059_OV_VVS2_D.assign(Total=None)
                    df_050_059_OV_VVS2_D ['Wt Range'] = listwtrange
                    df_050_059_OV_VVS2_D ['Company'] = listcom
                    df_050_059_OV_VVS2_D ['Shape'] = listshap
                    df_050_059_OV_VVS2_D ['Carat'] = listcar
                    df_050_059_OV_VVS2_D ['Color'] = listcol
                    df_050_059_OV_VVS2_D ['Clarity'] = listclar
                    df_050_059_OV_VVS2_D ['Cut'] = listcut
                    df_050_059_OV_VVS2_D ['Polish'] = listpol
                    df_050_059_OV_VVS2_D ['Symmetry'] = listsym
                    df_050_059_OV_VVS2_D ['Ratio'] = listrat
                    df_050_059_OV_VVS2_D ['PPC'] = listdesc
                    df_050_059_OV_VVS2_D ['Total'] = listtotal
                    df_050_059_OV_VVS2_D['Carat'] = df_050_059_OV_VVS2_D['Carat'].astype('float64')
                    df_050_059_OV_VVS2_D['PPC'] = df_050_059_OV_VVS2_D['PPC'].astype('float64')
                    df_050_059_OV_VVS2_D['Total'] = df_050_059_OV_VVS2_D['Total'].astype('float64')
                    df_050_059_OV_VVS2_D['Total'] = df_050_059_OV_VVS2_D['Carat'] * df_050_059_OV_VVS2_D['PPC']



                elif i=="D" and j == "VS1" and k == "OV":
                    df_050_059_OV_VS1_D = pd.DataFrame()
                    df_050_059_OV_VS1_D ['Wt Range'] = None
                    df_050_059_OV_VS1_D  = df_050_059_OV_VS1_D.assign(Company=None)
                    df_050_059_OV_VS1_D  = df_050_059_OV_VS1_D.assign(Shape=None)
                    df_050_059_OV_VS1_D  = df_050_059_OV_VS1_D.assign(Carat=None)
                    df_050_059_OV_VS1_D  = df_050_059_OV_VS1_D.assign(Color=None)
                    df_050_059_OV_VS1_D  = df_050_059_OV_VS1_D.assign(Clarity=None)
                    df_050_059_OV_VS1_D  = df_050_059_OV_VS1_D.assign(Cut=None)
                    df_050_059_OV_VS1_D  = df_050_059_OV_VS1_D.assign(Polish=None)
                    df_050_059_OV_VS1_D  = df_050_059_OV_VS1_D.assign(Symmetry=None)
                    df_050_059_OV_VS1_D  = df_050_059_OV_VS1_D.assign(Ratio=None)
                    df_050_059_OV_VS1_D  = df_050_059_OV_VS1_D.assign(PPC=None)
                    df_050_059_OV_VS1_D  = df_050_059_OV_VS1_D.assign(Total=None)
                    df_050_059_OV_VS1_D ['Wt Range'] = listwtrange
                    df_050_059_OV_VS1_D ['Company'] = listcom
                    df_050_059_OV_VS1_D ['Shape'] = listshap
                    df_050_059_OV_VS1_D ['Carat'] = listcar
                    df_050_059_OV_VS1_D ['Color'] = listcol
                    df_050_059_OV_VS1_D ['Clarity'] = listclar
                    df_050_059_OV_VS1_D ['Cut'] = listcut
                    df_050_059_OV_VS1_D ['Polish'] = listpol
                    df_050_059_OV_VS1_D ['Symmetry'] = listsym
                    df_050_059_OV_VS1_D ['Ratio'] = listrat
                    df_050_059_OV_VS1_D ['PPC'] = listdesc
                    df_050_059_OV_VS1_D ['Total'] = listtotal
                    df_050_059_OV_VS1_D['Carat'] = df_050_059_OV_VS1_D['Carat'].astype('float64')
                    df_050_059_OV_VS1_D['PPC'] = df_050_059_OV_VS1_D['PPC'].astype('float64')
                    df_050_059_OV_VS1_D['Total'] = df_050_059_OV_VS1_D['Total'].astype('float64')
                    df_050_059_OV_VS1_D['Total'] = df_050_059_OV_VS1_D['Carat'] * df_050_059_OV_VS1_D['PPC']


                elif i=="D" and j == "VS2" and k == "OV":
                    df_050_059_OV_VS2_D = pd.DataFrame()
                    df_050_059_OV_VS2_D ['Wt Range'] = None
                    df_050_059_OV_VS2_D  = df_050_059_OV_VS2_D.assign(Company=None)
                    df_050_059_OV_VS2_D  = df_050_059_OV_VS2_D.assign(Shape=None)
                    df_050_059_OV_VS2_D  = df_050_059_OV_VS2_D.assign(Carat=None)
                    df_050_059_OV_VS2_D  = df_050_059_OV_VS2_D.assign(Color=None)
                    df_050_059_OV_VS2_D  = df_050_059_OV_VS2_D.assign(Clarity=None)
                    df_050_059_OV_VS2_D  = df_050_059_OV_VS2_D.assign(Cut=None)
                    df_050_059_OV_VS2_D  = df_050_059_OV_VS2_D.assign(Polish=None)
                    df_050_059_OV_VS2_D  = df_050_059_OV_VS2_D.assign(Symmetry=None)
                    df_050_059_OV_VS2_D  = df_050_059_OV_VS2_D.assign(Ratio=None)
                    df_050_059_OV_VS2_D  = df_050_059_OV_VS2_D.assign(PPC=None)
                    df_050_059_OV_VS2_D  = df_050_059_OV_VS2_D.assign(Total=None)
                    df_050_059_OV_VS2_D ['Wt Range'] = listwtrange
                    df_050_059_OV_VS2_D ['Company'] = listcom
                    df_050_059_OV_VS2_D ['Shape'] = listshap
                    df_050_059_OV_VS2_D ['Carat'] = listcar
                    df_050_059_OV_VS2_D ['Color'] = listcol
                    df_050_059_OV_VS2_D ['Clarity'] = listclar
                    df_050_059_OV_VS2_D ['Cut'] = listcut
                    df_050_059_OV_VS2_D ['Polish'] = listpol
                    df_050_059_OV_VS2_D ['Symmetry'] = listsym
                    df_050_059_OV_VS2_D ['Ratio'] = listrat
                    df_050_059_OV_VS2_D ['PPC'] = listdesc
                    df_050_059_OV_VS2_D ['Total'] = listtotal
                    df_050_059_OV_VS2_D['Carat'] = df_050_059_OV_VS2_D['Carat'].astype('float64')
                    df_050_059_OV_VS2_D['PPC'] = df_050_059_OV_VS2_D['PPC'].astype('float64')
                    df_050_059_OV_VS2_D['Total'] = df_050_059_OV_VS2_D['Total'].astype('float64')
                    df_050_059_OV_VS2_D['Total'] = df_050_059_OV_VS2_D['Carat'] * df_050_059_OV_VS2_D['PPC']


                elif i=="D" and j == "SI1" and k == "OV":
                    df_050_059_OV_SI1_D = pd.DataFrame()
                    df_050_059_OV_SI1_D ['Wt Range'] = None
                    df_050_059_OV_SI1_D  = df_050_059_OV_SI1_D.assign(Company=None)
                    df_050_059_OV_SI1_D  = df_050_059_OV_SI1_D.assign(Shape=None)
                    df_050_059_OV_SI1_D  = df_050_059_OV_SI1_D.assign(Carat=None)
                    df_050_059_OV_SI1_D  = df_050_059_OV_SI1_D.assign(Color=None)
                    df_050_059_OV_SI1_D  = df_050_059_OV_SI1_D.assign(Clarity=None)
                    df_050_059_OV_SI1_D  = df_050_059_OV_SI1_D.assign(Cut=None)
                    df_050_059_OV_SI1_D  = df_050_059_OV_SI1_D.assign(Polish=None)
                    df_050_059_OV_SI1_D  = df_050_059_OV_SI1_D.assign(Symmetry=None)
                    df_050_059_OV_SI1_D  = df_050_059_OV_SI1_D.assign(Ratio=None)
                    df_050_059_OV_SI1_D  = df_050_059_OV_SI1_D.assign(PPC=None)
                    df_050_059_OV_SI1_D  = df_050_059_OV_SI1_D.assign(Total=None)
                    df_050_059_OV_SI1_D ['Wt Range'] = listwtrange
                    df_050_059_OV_SI1_D ['Company'] = listcom
                    df_050_059_OV_SI1_D ['Shape'] = listshap
                    df_050_059_OV_SI1_D ['Carat'] = listcar
                    df_050_059_OV_SI1_D ['Color'] = listcol
                    df_050_059_OV_SI1_D ['Clarity'] = listclar
                    df_050_059_OV_SI1_D ['Cut'] = listcut
                    df_050_059_OV_SI1_D ['Polish'] = listpol
                    df_050_059_OV_SI1_D ['Symmetry'] = listsym
                    df_050_059_OV_SI1_D ['Ratio'] = listrat
                    df_050_059_OV_SI1_D ['PPC'] = listdesc
                    df_050_059_OV_SI1_D ['Total'] = listtotal
                    df_050_059_OV_SI1_D['Carat'] = df_050_059_OV_SI1_D['Carat'].astype('float64')
                    df_050_059_OV_SI1_D['PPC'] = df_050_059_OV_SI1_D['PPC'].astype('float64')
                    df_050_059_OV_SI1_D['Total'] = df_050_059_OV_SI1_D['Total'].astype('float64')
                    df_050_059_OV_SI1_D['Total'] = df_050_059_OV_SI1_D['Carat'] * df_050_059_OV_SI1_D['PPC']


                elif i=="D" and j == "SI2" and k == "OV":
                    df_050_059_OV_SI2_D = pd.DataFrame()
                    df_050_059_OV_SI2_D ['Wt Range'] = None
                    df_050_059_OV_SI2_D  = df_050_059_OV_SI2_D.assign(Company=None)
                    df_050_059_OV_SI2_D  = df_050_059_OV_SI2_D.assign(Shape=None)
                    df_050_059_OV_SI2_D  = df_050_059_OV_SI2_D.assign(Carat=None)
                    df_050_059_OV_SI2_D  = df_050_059_OV_SI2_D.assign(Color=None)
                    df_050_059_OV_SI2_D  = df_050_059_OV_SI2_D.assign(Clarity=None)
                    df_050_059_OV_SI2_D  = df_050_059_OV_SI2_D.assign(Cut=None)
                    df_050_059_OV_SI2_D  = df_050_059_OV_SI2_D.assign(Polish=None)
                    df_050_059_OV_SI2_D  = df_050_059_OV_SI2_D.assign(Symmetry=None)
                    df_050_059_OV_SI2_D  = df_050_059_OV_SI2_D.assign(Ratio=None)
                    df_050_059_OV_SI2_D  = df_050_059_OV_SI2_D.assign(PPC=None)
                    df_050_059_OV_SI2_D  = df_050_059_OV_SI2_D.assign(Total=None)
                    df_050_059_OV_SI2_D ['Wt Range'] = listwtrange
                    df_050_059_OV_SI2_D ['Company'] = listcom
                    df_050_059_OV_SI2_D ['Shape'] = listshap
                    df_050_059_OV_SI2_D ['Carat'] = listcar
                    df_050_059_OV_SI2_D ['Color'] = listcol
                    df_050_059_OV_SI2_D ['Clarity'] = listclar
                    df_050_059_OV_SI2_D ['Cut'] = listcut
                    df_050_059_OV_SI2_D ['Polish'] = listpol
                    df_050_059_OV_SI2_D ['Symmetry'] = listsym
                    df_050_059_OV_SI2_D ['Ratio'] = listrat
                    df_050_059_OV_SI2_D ['PPC'] = listdesc
                    df_050_059_OV_SI2_D ['Total'] = listtotal
                    df_050_059_OV_SI2_D['Carat'] = df_050_059_OV_SI2_D['Carat'].astype('float64')
                    df_050_059_OV_SI2_D['PPC'] = df_050_059_OV_SI2_D['PPC'].astype('float64')
                    df_050_059_OV_SI2_D['Total'] = df_050_059_OV_SI2_D['Total'].astype('float64')
                    df_050_059_OV_SI2_D['Total'] = df_050_059_OV_SI2_D['Carat'] * df_050_059_OV_SI2_D['PPC']


                elif i=="D" and j == "I1" and k == "OV":
                    df_050_059_OV_I1_D = pd.DataFrame()
                    df_050_059_OV_I1_D ['Wt Range'] = None
                    df_050_059_OV_I1_D  = df_050_059_OV_I1_D.assign(Company=None)
                    df_050_059_OV_I1_D  = df_050_059_OV_I1_D.assign(Shape=None)
                    df_050_059_OV_I1_D  = df_050_059_OV_I1_D.assign(Carat=None)
                    df_050_059_OV_I1_D  = df_050_059_OV_I1_D.assign(Color=None)
                    df_050_059_OV_I1_D  = df_050_059_OV_I1_D.assign(Clarity=None)
                    df_050_059_OV_I1_D  = df_050_059_OV_I1_D.assign(Cut=None)
                    df_050_059_OV_I1_D  = df_050_059_OV_I1_D.assign(Polish=None)
                    df_050_059_OV_I1_D  = df_050_059_OV_I1_D.assign(Symmetry=None)
                    df_050_059_OV_I1_D  = df_050_059_OV_I1_D.assign(Ratio=None)
                    df_050_059_OV_I1_D  = df_050_059_OV_I1_D.assign(PPC=None)
                    df_050_059_OV_I1_D  = df_050_059_OV_I1_D.assign(Total=None)
                    df_050_059_OV_I1_D ['Wt Range'] = listwtrange
                    df_050_059_OV_I1_D ['Company'] = listcom
                    df_050_059_OV_I1_D ['Shape'] = listshap
                    df_050_059_OV_I1_D ['Carat'] = listcar
                    df_050_059_OV_I1_D ['Color'] = listcol
                    df_050_059_OV_I1_D ['Clarity'] = listclar
                    df_050_059_OV_I1_D ['Cut'] = listcut
                    df_050_059_OV_I1_D ['Polish'] = listpol
                    df_050_059_OV_I1_D ['Symmetry'] = listsym
                    df_050_059_OV_I1_D ['Ratio'] = listrat
                    df_050_059_OV_I1_D ['PPC'] = listdesc
                    df_050_059_OV_I1_D ['Total'] = listtotal
                    df_050_059_OV_I1_D['Carat'] = df_050_059_OV_I1_D['Carat'].astype('float64')
                    df_050_059_OV_I1_D['PPC'] = df_050_059_OV_I1_D['PPC'].astype('float64')
                    df_050_059_OV_I1_D['Total'] = df_050_059_OV_I1_D['Total'].astype('float64')
                    df_050_059_OV_I1_D['Total'] = df_050_059_OV_I1_D['Carat'] * df_050_059_OV_I1_D['PPC']


                elif i=="D" and j == "I2" and k == "OV":
                    df_050_059_OV_I2_D = pd.DataFrame()
                    df_050_059_OV_I2_D ['Wt Range'] = None
                    df_050_059_OV_I2_D  = df_050_059_OV_I2_D.assign(Company=None)
                    df_050_059_OV_I2_D  = df_050_059_OV_I2_D.assign(Shape=None)
                    df_050_059_OV_I2_D  = df_050_059_OV_I2_D.assign(Carat=None)
                    df_050_059_OV_I2_D  = df_050_059_OV_I2_D.assign(Color=None)
                    df_050_059_OV_I2_D  = df_050_059_OV_I2_D.assign(Clarity=None)
                    df_050_059_OV_I2_D  = df_050_059_OV_I2_D.assign(Cut=None)
                    df_050_059_OV_I2_D  = df_050_059_OV_I2_D.assign(Polish=None)
                    df_050_059_OV_I2_D  = df_050_059_OV_I2_D.assign(Symmetry=None)
                    df_050_059_OV_I2_D  = df_050_059_OV_I2_D.assign(Ratio=None)
                    df_050_059_OV_I2_D  = df_050_059_OV_I2_D.assign(PPC=None)
                    df_050_059_OV_I2_D  = df_050_059_OV_I2_D.assign(Total=None)
                    df_050_059_OV_I2_D ['Wt Range'] = listwtrange
                    df_050_059_OV_I2_D ['Company'] = listcom
                    df_050_059_OV_I2_D ['Shape'] = listshap
                    df_050_059_OV_I2_D ['Carat'] = listcar
                    df_050_059_OV_I2_D ['Color'] = listcol
                    df_050_059_OV_I2_D ['Clarity'] = listclar
                    df_050_059_OV_I2_D ['Cut'] = listcut
                    df_050_059_OV_I2_D ['Polish'] = listpol
                    df_050_059_OV_I2_D ['Symmetry'] = listsym
                    df_050_059_OV_I2_D ['Ratio'] = listrat
                    df_050_059_OV_I2_D ['PPC'] = listdesc
                    df_050_059_OV_I2_D ['Total'] = listtotal
                    df_050_059_OV_I2_D['Carat'] = df_050_059_OV_I2_D['Carat'].astype('float64')
                    df_050_059_OV_I2_D['PPC'] = df_050_059_OV_I2_D['PPC'].astype('float64')
                    df_050_059_OV_I2_D['Total'] = df_050_059_OV_I2_D['Total'].astype('float64')
                    df_050_059_OV_I2_D['Total'] = df_050_059_OV_I2_D['Carat'] * df_050_059_OV_I2_D['PPC']



                elif i=="E" and j == "IF" and k == "OV":
                    df_050_059_OV_IF_E = pd.DataFrame()
                    df_050_059_OV_IF_E ['Wt Range'] = None
                    df_050_059_OV_IF_E  = df_050_059_OV_IF_E.assign(Company=None)
                    df_050_059_OV_IF_E  = df_050_059_OV_IF_E.assign(Shape=None)
                    df_050_059_OV_IF_E  = df_050_059_OV_IF_E.assign(Carat=None)
                    df_050_059_OV_IF_E  = df_050_059_OV_IF_E.assign(Color=None)
                    df_050_059_OV_IF_E  = df_050_059_OV_IF_E.assign(Clarity=None)
                    df_050_059_OV_IF_E  = df_050_059_OV_IF_E.assign(Cut=None)
                    df_050_059_OV_IF_E  = df_050_059_OV_IF_E.assign(Polish=None)
                    df_050_059_OV_IF_E  = df_050_059_OV_IF_E.assign(Symmetry=None)
                    df_050_059_OV_IF_E  = df_050_059_OV_IF_E.assign(Ratio=None)
                    df_050_059_OV_IF_E  = df_050_059_OV_IF_E.assign(PPC=None)
                    df_050_059_OV_IF_E  = df_050_059_OV_IF_E.assign(Total=None)
                    df_050_059_OV_IF_E ['Wt Range'] = listwtrange
                    df_050_059_OV_IF_E ['Company'] = listcom
                    df_050_059_OV_IF_E ['Shape'] = listshap
                    df_050_059_OV_IF_E ['Carat'] = listcar
                    df_050_059_OV_IF_E ['Color'] = listcol
                    df_050_059_OV_IF_E ['Clarity'] = listclar
                    df_050_059_OV_IF_E ['Cut'] = listcut
                    df_050_059_OV_IF_E ['Polish'] = listpol
                    df_050_059_OV_IF_E ['Symmetry'] = listsym
                    df_050_059_OV_IF_E ['Ratio'] = listrat
                    df_050_059_OV_IF_E ['PPC'] = listdesc
                    df_050_059_OV_IF_E ['Total'] = listtotal
                    df_050_059_OV_IF_E['Carat'] = df_050_059_OV_IF_E['Carat'].astype('float64')
                    df_050_059_OV_IF_E['PPC'] = df_050_059_OV_IF_E['PPC'].astype('float64')
                    df_050_059_OV_IF_E['Total'] = df_050_059_OV_IF_E['Total'].astype('float64')
                    df_050_059_OV_IF_E['Total'] = df_050_059_OV_IF_E['Carat'] * df_050_059_OV_IF_E['PPC']



                elif i=="E" and j == "VVS1" and k == "OV":
                    df_050_059_OV_VVS1_E = pd.DataFrame()
                    df_050_059_OV_VVS1_E ['Wt Range'] = None
                    df_050_059_OV_VVS1_E  = df_050_059_OV_VVS1_E.assign(Company=None)
                    df_050_059_OV_VVS1_E  = df_050_059_OV_VVS1_E.assign(Shape=None)
                    df_050_059_OV_VVS1_E  = df_050_059_OV_VVS1_E.assign(Carat=None)
                    df_050_059_OV_VVS1_E  = df_050_059_OV_VVS1_E.assign(Color=None)
                    df_050_059_OV_VVS1_E  = df_050_059_OV_VVS1_E.assign(Clarity=None)
                    df_050_059_OV_VVS1_E  = df_050_059_OV_VVS1_E.assign(Cut=None)
                    df_050_059_OV_VVS1_E  = df_050_059_OV_VVS1_E.assign(Polish=None)
                    df_050_059_OV_VVS1_E  = df_050_059_OV_VVS1_E.assign(Symmetry=None)
                    df_050_059_OV_VVS1_E  = df_050_059_OV_VVS1_E.assign(Ratio=None)
                    df_050_059_OV_VVS1_E  = df_050_059_OV_VVS1_E.assign(PPC=None)
                    df_050_059_OV_VVS1_E  = df_050_059_OV_VVS1_E.assign(Total=None)
                    df_050_059_OV_VVS1_E ['Wt Range'] = listwtrange
                    df_050_059_OV_VVS1_E ['Company'] = listcom
                    df_050_059_OV_VVS1_E ['Shape'] = listshap
                    df_050_059_OV_VVS1_E ['Carat'] = listcar
                    df_050_059_OV_VVS1_E ['Color'] = listcol
                    df_050_059_OV_VVS1_E ['Clarity'] = listclar
                    df_050_059_OV_VVS1_E ['Cut'] = listcut
                    df_050_059_OV_VVS1_E ['Polish'] = listpol
                    df_050_059_OV_VVS1_E ['Symmetry'] = listsym
                    df_050_059_OV_VVS1_E ['Ratio'] = listrat
                    df_050_059_OV_VVS1_E ['PPC'] = listdesc
                    df_050_059_OV_VVS1_E ['Total'] = listtotal
                    df_050_059_OV_VVS1_E['Carat'] = df_050_059_OV_VVS1_E['Carat'].astype('float64')
                    df_050_059_OV_VVS1_E['PPC'] = df_050_059_OV_VVS1_E['PPC'].astype('float64')
                    df_050_059_OV_VVS1_E['Total'] = df_050_059_OV_VVS1_E['Total'].astype('float64')
                    df_050_059_OV_VVS1_E['Total'] = df_050_059_OV_VVS1_E['Carat'] * df_050_059_OV_VVS1_E['PPC']


                elif i=="E" and j == "VVS2" and k == "OV":
                    df_050_059_OV_VVS2_E = pd.DataFrame()
                    df_050_059_OV_VVS2_E ['Wt Range'] = None
                    df_050_059_OV_VVS2_E  = df_050_059_OV_VVS2_E.assign(Company=None)
                    df_050_059_OV_VVS2_E  = df_050_059_OV_VVS2_E.assign(Shape=None)
                    df_050_059_OV_VVS2_E  = df_050_059_OV_VVS2_E.assign(Carat=None)
                    df_050_059_OV_VVS2_E  = df_050_059_OV_VVS2_E.assign(Color=None)
                    df_050_059_OV_VVS2_E  = df_050_059_OV_VVS2_E.assign(Clarity=None)
                    df_050_059_OV_VVS2_E  = df_050_059_OV_VVS2_E.assign(Cut=None)
                    df_050_059_OV_VVS2_E  = df_050_059_OV_VVS2_E.assign(Polish=None)
                    df_050_059_OV_VVS2_E  = df_050_059_OV_VVS2_E.assign(Symmetry=None)
                    df_050_059_OV_VVS2_E  = df_050_059_OV_VVS2_E.assign(Ratio=None)
                    df_050_059_OV_VVS2_E  = df_050_059_OV_VVS2_E.assign(PPC=None)
                    df_050_059_OV_VVS2_E  = df_050_059_OV_VVS2_E.assign(Total=None)
                    df_050_059_OV_VVS2_E ['Wt Range'] = listwtrange
                    df_050_059_OV_VVS2_E ['Company'] = listcom
                    df_050_059_OV_VVS2_E ['Shape'] = listshap
                    df_050_059_OV_VVS2_E ['Carat'] = listcar
                    df_050_059_OV_VVS2_E ['Color'] = listcol
                    df_050_059_OV_VVS2_E ['Clarity'] = listclar
                    df_050_059_OV_VVS2_E ['Cut'] = listcut
                    df_050_059_OV_VVS2_E ['Polish'] = listpol
                    df_050_059_OV_VVS2_E ['Symmetry'] = listsym
                    df_050_059_OV_VVS2_E ['Ratio'] = listrat
                    df_050_059_OV_VVS2_E ['PPC'] = listdesc
                    df_050_059_OV_VVS2_E ['Total'] = listtotal
                    df_050_059_OV_VVS2_E['Carat'] = df_050_059_OV_VVS2_E['Carat'].astype('float64')
                    df_050_059_OV_VVS2_E['PPC'] = df_050_059_OV_VVS2_E['PPC'].astype('float64')
                    df_050_059_OV_VVS2_E['Total'] = df_050_059_OV_VVS2_E['Total'].astype('float64')
                    df_050_059_OV_VVS2_E['Total'] = df_050_059_OV_VVS2_E['Carat'] * df_050_059_OV_VVS2_E['PPC']


                elif i=="E" and j=="VS1" and k == "OV":
                    df_050_059_OV_VS1_E = pd.DataFrame()
                    df_050_059_OV_VS1_E ['Wt Range'] = None
                    df_050_059_OV_VS1_E  = df_050_059_OV_VS1_E.assign(Company=None)
                    df_050_059_OV_VS1_E  = df_050_059_OV_VS1_E.assign(Shape=None)
                    df_050_059_OV_VS1_E  = df_050_059_OV_VS1_E.assign(Carat=None)
                    df_050_059_OV_VS1_E  = df_050_059_OV_VS1_E.assign(Color=None)
                    df_050_059_OV_VS1_E  = df_050_059_OV_VS1_E.assign(Clarity=None)
                    df_050_059_OV_VS1_E  = df_050_059_OV_VS1_E.assign(Cut=None)
                    df_050_059_OV_VS1_E  = df_050_059_OV_VS1_E.assign(Polish=None)
                    df_050_059_OV_VS1_E  = df_050_059_OV_VS1_E.assign(Symmetry=None)
                    df_050_059_OV_VS1_E  = df_050_059_OV_VS1_E.assign(Ratio=None)
                    df_050_059_OV_VS1_E  = df_050_059_OV_VS1_E.assign(PPC=None)
                    df_050_059_OV_VS1_E  = df_050_059_OV_VS1_E.assign(Total=None)
                    df_050_059_OV_VS1_E ['Wt Range'] = listwtrange
                    df_050_059_OV_VS1_E ['Company'] = listcom
                    df_050_059_OV_VS1_E ['Shape'] = listshap
                    df_050_059_OV_VS1_E ['Carat'] = listcar
                    df_050_059_OV_VS1_E ['Color'] = listcol
                    df_050_059_OV_VS1_E ['Clarity'] = listclar
                    df_050_059_OV_VS1_E ['Cut'] = listcut
                    df_050_059_OV_VS1_E ['Polish'] = listpol
                    df_050_059_OV_VS1_E ['Symmetry'] = listsym
                    df_050_059_OV_VS1_E ['Ratio'] = listrat
                    df_050_059_OV_VS1_E ['PPC'] = listdesc
                    df_050_059_OV_VS1_E ['Total'] = listtotal
                    df_050_059_OV_VS1_E['Carat'] = df_050_059_OV_VS1_E['Carat'].astype('float64')
                    df_050_059_OV_VS1_E['PPC'] = df_050_059_OV_VS1_E['PPC'].astype('float64')
                    df_050_059_OV_VS1_E['Total'] = df_050_059_OV_VS1_E['Total'].astype('float64')
                    df_050_059_OV_VS1_E['Total'] = df_050_059_OV_VS1_E['Carat'] * df_050_059_OV_VS1_E['PPC']


                elif i=="E" and j == "VS2" and k == "OV":
                    df_050_059_OV_VS2_E = pd.DataFrame()
                    df_050_059_OV_VS2_E ['Wt Range'] = None
                    df_050_059_OV_VS2_E  = df_050_059_OV_VS2_E.assign(Company=None)
                    df_050_059_OV_VS2_E  = df_050_059_OV_VS2_E.assign(Shape=None)
                    df_050_059_OV_VS2_E  = df_050_059_OV_VS2_E.assign(Carat=None)
                    df_050_059_OV_VS2_E  = df_050_059_OV_VS2_E.assign(Color=None)
                    df_050_059_OV_VS2_E  = df_050_059_OV_VS2_E.assign(Clarity=None)
                    df_050_059_OV_VS2_E  = df_050_059_OV_VS2_E.assign(Cut=None)
                    df_050_059_OV_VS2_E  = df_050_059_OV_VS2_E.assign(Polish=None)
                    df_050_059_OV_VS2_E  = df_050_059_OV_VS2_E.assign(Symmetry=None)
                    df_050_059_OV_VS2_E  = df_050_059_OV_VS2_E.assign(Ratio=None)
                    df_050_059_OV_VS2_E  = df_050_059_OV_VS2_E.assign(PPC=None)
                    df_050_059_OV_VS2_E  = df_050_059_OV_VS2_E.assign(Total=None)
                    df_050_059_OV_VS2_E ['Wt Range'] = listwtrange
                    df_050_059_OV_VS2_E ['Company'] = listcom
                    df_050_059_OV_VS2_E ['Shape'] = listshap
                    df_050_059_OV_VS2_E ['Carat'] = listcar
                    df_050_059_OV_VS2_E ['Color'] = listcol
                    df_050_059_OV_VS2_E ['Clarity'] = listclar
                    df_050_059_OV_VS2_E ['Cut'] = listcut
                    df_050_059_OV_VS2_E ['Polish'] = listpol
                    df_050_059_OV_VS2_E ['Symmetry'] = listsym
                    df_050_059_OV_VS2_E ['Ratio'] = listrat
                    df_050_059_OV_VS2_E ['PPC'] = listdesc
                    df_050_059_OV_VS2_E ['Total'] = listtotal
                    df_050_059_OV_VS2_E['Carat'] = df_050_059_OV_VS2_E['Carat'].astype('float64')
                    df_050_059_OV_VS2_E['PPC'] = df_050_059_OV_VS2_E['PPC'].astype('float64')
                    df_050_059_OV_VS2_E['Total'] = df_050_059_OV_VS2_E['Total'].astype('float64')
                    df_050_059_OV_VS2_E['Total'] = df_050_059_OV_VS2_E['Carat'] * df_050_059_OV_VS2_E['PPC']


                elif i=="E" and j == "SI1" and k == "OV":
                    df_050_059_OV_SI1_E = pd.DataFrame()
                    df_050_059_OV_SI1_E ['Wt Range'] = None
                    df_050_059_OV_SI1_E  = df_050_059_OV_SI1_E.assign(Company=None)
                    df_050_059_OV_SI1_E  = df_050_059_OV_SI1_E.assign(Shape=None)
                    df_050_059_OV_SI1_E  = df_050_059_OV_SI1_E.assign(Carat=None)
                    df_050_059_OV_SI1_E  = df_050_059_OV_SI1_E.assign(Color=None)
                    df_050_059_OV_SI1_E  = df_050_059_OV_SI1_E.assign(Clarity=None)
                    df_050_059_OV_SI1_E  = df_050_059_OV_SI1_E.assign(Cut=None)
                    df_050_059_OV_SI1_E  = df_050_059_OV_SI1_E.assign(Polish=None)
                    df_050_059_OV_SI1_E  = df_050_059_OV_SI1_E.assign(Symmetry=None)
                    df_050_059_OV_SI1_E  = df_050_059_OV_SI1_E.assign(Ratio=None)
                    df_050_059_OV_SI1_E  = df_050_059_OV_SI1_E.assign(PPC=None)
                    df_050_059_OV_SI1_E  = df_050_059_OV_SI1_E.assign(Total=None)
                    df_050_059_OV_SI1_E ['Wt Range'] = listwtrange
                    df_050_059_OV_SI1_E ['Company'] = listcom
                    df_050_059_OV_SI1_E ['Shape'] = listshap
                    df_050_059_OV_SI1_E ['Carat'] = listcar
                    df_050_059_OV_SI1_E ['Color'] = listcol
                    df_050_059_OV_SI1_E ['Clarity'] = listclar
                    df_050_059_OV_SI1_E ['Cut'] = listcut
                    df_050_059_OV_SI1_E ['Polish'] = listpol
                    df_050_059_OV_SI1_E ['Symmetry'] = listsym
                    df_050_059_OV_SI1_E ['Ratio'] = listrat
                    df_050_059_OV_SI1_E ['PPC'] = listdesc
                    df_050_059_OV_SI1_E ['Total'] = listtotal
                    df_050_059_OV_SI1_E['Carat'] = df_050_059_OV_SI1_E['Carat'].astype('float64')
                    df_050_059_OV_SI1_E['PPC'] = df_050_059_OV_SI1_E['PPC'].astype('float64')
                    df_050_059_OV_SI1_E['Total'] = df_050_059_OV_SI1_E['Total'].astype('float64')
                    df_050_059_OV_SI1_E['Total'] = df_050_059_OV_SI1_E['Carat'] * df_050_059_OV_SI1_E['PPC']


                elif i=="E" and j == "SI2" and k == "OV":
                    df_050_059_OV_SI2_E = pd.DataFrame()
                    df_050_059_OV_SI2_E ['Wt Range'] = None
                    df_050_059_OV_SI2_E  = df_050_059_OV_SI2_E.assign(Company=None)
                    df_050_059_OV_SI2_E  = df_050_059_OV_SI2_E.assign(Shape=None)
                    df_050_059_OV_SI2_E  = df_050_059_OV_SI2_E.assign(Carat=None)
                    df_050_059_OV_SI2_E  = df_050_059_OV_SI2_E.assign(Color=None)
                    df_050_059_OV_SI2_E  = df_050_059_OV_SI2_E.assign(Clarity=None)
                    df_050_059_OV_SI2_E  = df_050_059_OV_SI2_E.assign(Cut=None)
                    df_050_059_OV_SI2_E  = df_050_059_OV_SI2_E.assign(Polish=None)
                    df_050_059_OV_SI2_E  = df_050_059_OV_SI2_E.assign(Symmetry=None)
                    df_050_059_OV_SI2_E  = df_050_059_OV_SI2_E.assign(Ratio=None)
                    df_050_059_OV_SI2_E  = df_050_059_OV_SI2_E.assign(PPC=None)
                    df_050_059_OV_SI2_E  = df_050_059_OV_SI2_E.assign(Total=None)
                    df_050_059_OV_SI2_E ['Wt Range'] = listwtrange
                    df_050_059_OV_SI2_E ['Company'] = listcom
                    df_050_059_OV_SI2_E ['Shape'] = listshap
                    df_050_059_OV_SI2_E ['Carat'] = listcar
                    df_050_059_OV_SI2_E ['Color'] = listcol
                    df_050_059_OV_SI2_E ['Clarity'] = listclar
                    df_050_059_OV_SI2_E ['Cut'] = listcut
                    df_050_059_OV_SI2_E ['Polish'] = listpol
                    df_050_059_OV_SI2_E ['Symmetry'] = listsym
                    df_050_059_OV_SI2_E ['Ratio'] = listrat
                    df_050_059_OV_SI2_E ['PPC'] = listdesc
                    df_050_059_OV_SI2_E ['Total'] = listtotal
                    df_050_059_OV_SI2_E['Carat'] = df_050_059_OV_SI2_E['Carat'].astype('float64')
                    df_050_059_OV_SI2_E['PPC'] = df_050_059_OV_SI2_E['PPC'].astype('float64')
                    df_050_059_OV_SI2_E['Total'] = df_050_059_OV_SI2_E['Total'].astype('float64')
                    df_050_059_OV_SI2_E['Total'] = df_050_059_OV_SI2_E['Carat'] * df_050_059_OV_SI2_E['PPC']


                elif i=="E" and j == "I1" and k == "OV":
                    df_050_059_OV_I1_E = pd.DataFrame()
                    df_050_059_OV_I1_E ['Wt Range'] = None
                    df_050_059_OV_I1_E  = df_050_059_OV_I1_E.assign(Company=None)
                    df_050_059_OV_I1_E  = df_050_059_OV_I1_E.assign(Shape=None)
                    df_050_059_OV_I1_E  = df_050_059_OV_I1_E.assign(Carat=None)
                    df_050_059_OV_I1_E  = df_050_059_OV_I1_E.assign(Color=None)
                    df_050_059_OV_I1_E  = df_050_059_OV_I1_E.assign(Clarity=None)
                    df_050_059_OV_I1_E  = df_050_059_OV_I1_E.assign(Cut=None)
                    df_050_059_OV_I1_E  = df_050_059_OV_I1_E.assign(Polish=None)
                    df_050_059_OV_I1_E  = df_050_059_OV_I1_E.assign(Symmetry=None)
                    df_050_059_OV_I1_E  = df_050_059_OV_I1_E.assign(Ratio=None)
                    df_050_059_OV_I1_E  = df_050_059_OV_I1_E.assign(PPC=None)
                    df_050_059_OV_I1_E  = df_050_059_OV_I1_E.assign(Total=None)
                    df_050_059_OV_I1_E ['Wt Range'] = listwtrange
                    df_050_059_OV_I1_E ['Company'] = listcom
                    df_050_059_OV_I1_E ['Shape'] = listshap
                    df_050_059_OV_I1_E ['Carat'] = listcar
                    df_050_059_OV_I1_E ['Color'] = listcol
                    df_050_059_OV_I1_E ['Clarity'] = listclar
                    df_050_059_OV_I1_E ['Cut'] = listcut
                    df_050_059_OV_I1_E ['Polish'] = listpol
                    df_050_059_OV_I1_E ['Symmetry'] = listsym
                    df_050_059_OV_I1_E ['Ratio'] = listrat
                    df_050_059_OV_I1_E ['PPC'] = listdesc
                    df_050_059_OV_I1_E ['Total'] = listtotal
                    df_050_059_OV_I1_E['Carat'] = df_050_059_OV_I1_E['Carat'].astype('float64')
                    df_050_059_OV_I1_E['PPC'] = df_050_059_OV_I1_E['PPC'].astype('float64')
                    df_050_059_OV_I1_E['Total'] = df_050_059_OV_I1_E['Total'].astype('float64')
                    df_050_059_OV_I1_E['Total'] = df_050_059_OV_I1_E['Carat'] * df_050_059_OV_I1_E['PPC']


                elif i=="E" and j == "I2" and k == "OV":
                    df_050_059_OV_I2_E = pd.DataFrame()
                    df_050_059_OV_I2_E ['Wt Range'] = None
                    df_050_059_OV_I2_E  = df_050_059_OV_I2_E.assign(Company=None)
                    df_050_059_OV_I2_E  = df_050_059_OV_I2_E.assign(Shape=None)
                    df_050_059_OV_I2_E  = df_050_059_OV_I2_E.assign(Carat=None)
                    df_050_059_OV_I2_E  = df_050_059_OV_I2_E.assign(Color=None)
                    df_050_059_OV_I2_E  = df_050_059_OV_I2_E.assign(Clarity=None)
                    df_050_059_OV_I2_E  = df_050_059_OV_I2_E.assign(Cut=None)
                    df_050_059_OV_I2_E  = df_050_059_OV_I2_E.assign(Polish=None)
                    df_050_059_OV_I2_E  = df_050_059_OV_I2_E.assign(Symmetry=None)
                    df_050_059_OV_I2_E  = df_050_059_OV_I2_E.assign(Ratio=None)
                    df_050_059_OV_I2_E  = df_050_059_OV_I2_E.assign(PPC=None)
                    df_050_059_OV_I2_E  = df_050_059_OV_I2_E.assign(Total=None)
                    df_050_059_OV_I2_E ['Wt Range'] = listwtrange
                    df_050_059_OV_I2_E ['Company'] = listcom
                    df_050_059_OV_I2_E ['Shape'] = listshap
                    df_050_059_OV_I2_E ['Carat'] = listcar
                    df_050_059_OV_I2_E ['Color'] = listcol
                    df_050_059_OV_I2_E ['Clarity'] = listclar
                    df_050_059_OV_I2_E ['Cut'] = listcut
                    df_050_059_OV_I2_E ['Polish'] = listpol
                    df_050_059_OV_I2_E ['Symmetry'] = listsym
                    df_050_059_OV_I2_E ['Ratio'] = listrat
                    df_050_059_OV_I2_E ['PPC'] = listdesc
                    df_050_059_OV_I2_E ['Total'] = listtotal
                    df_050_059_OV_I2_E['Carat'] = df_050_059_OV_I2_E['Carat'].astype('float64')
                    df_050_059_OV_I2_E['PPC'] = df_050_059_OV_I2_E['PPC'].astype('float64')
                    df_050_059_OV_I2_E['Total'] = df_050_059_OV_I2_E['Total'].astype('float64')
                    df_050_059_OV_I2_E['Total'] = df_050_059_OV_I2_E['Carat'] * df_050_059_OV_I2_E['PPC']
                
                elif i=="F" and j == "IF" and k == "OV":
                    df_050_059_OV_IF_F = pd.DataFrame()
                    df_050_059_OV_IF_F ['Wt Range'] = None
                    df_050_059_OV_IF_F  = df_050_059_OV_IF_F.assign(Company=None)
                    df_050_059_OV_IF_F  = df_050_059_OV_IF_F.assign(Shape=None)
                    df_050_059_OV_IF_F  = df_050_059_OV_IF_F.assign(Carat=None)
                    df_050_059_OV_IF_F  = df_050_059_OV_IF_F.assign(Color=None)
                    df_050_059_OV_IF_F  = df_050_059_OV_IF_F.assign(Clarity=None)
                    df_050_059_OV_IF_F  = df_050_059_OV_IF_F.assign(Cut=None)
                    df_050_059_OV_IF_F  = df_050_059_OV_IF_F.assign(Polish=None)
                    df_050_059_OV_IF_F  = df_050_059_OV_IF_F.assign(Symmetry=None)
                    df_050_059_OV_IF_F  = df_050_059_OV_IF_F.assign(Ratio=None)
                    df_050_059_OV_IF_F  = df_050_059_OV_IF_F.assign(PPC=None)
                    df_050_059_OV_IF_F  = df_050_059_OV_IF_F.assign(Total=None)
                    df_050_059_OV_IF_F ['Wt Range'] = listwtrange
                    df_050_059_OV_IF_F ['Company'] = listcom
                    df_050_059_OV_IF_F ['Shape'] = listshap
                    df_050_059_OV_IF_F ['Carat'] = listcar
                    df_050_059_OV_IF_F ['Color'] = listcol
                    df_050_059_OV_IF_F ['Clarity'] = listclar
                    df_050_059_OV_IF_F ['Cut'] = listcut
                    df_050_059_OV_IF_F ['Polish'] = listpol
                    df_050_059_OV_IF_F ['Symmetry'] = listsym
                    df_050_059_OV_IF_F ['Ratio'] = listrat
                    df_050_059_OV_IF_F ['PPC'] = listdesc
                    df_050_059_OV_IF_F ['Total'] = listtotal
                    df_050_059_OV_IF_F['Carat'] = df_050_059_OV_IF_F['Carat'].astype('float64')
                    df_050_059_OV_IF_F['PPC'] = df_050_059_OV_IF_F['PPC'].astype('float64')
                    df_050_059_OV_IF_F['Total'] = df_050_059_OV_IF_F['Total'].astype('float64')
                    df_050_059_OV_IF_F['Total'] = df_050_059_OV_IF_F['Carat'] * df_050_059_OV_IF_F['PPC']



                elif i=="F" and j == "VVS1" and k == "OV":
                    df_050_059_OV_VVS1_F = pd.DataFrame()
                    df_050_059_OV_VVS1_F ['Wt Range'] = None
                    df_050_059_OV_VVS1_F  = df_050_059_OV_VVS1_F.assign(Company=None)
                    df_050_059_OV_VVS1_F  = df_050_059_OV_VVS1_F.assign(Shape=None)
                    df_050_059_OV_VVS1_F  = df_050_059_OV_VVS1_F.assign(Carat=None)
                    df_050_059_OV_VVS1_F  = df_050_059_OV_VVS1_F.assign(Color=None)
                    df_050_059_OV_VVS1_F  = df_050_059_OV_VVS1_F.assign(Clarity=None)
                    df_050_059_OV_VVS1_F  = df_050_059_OV_VVS1_F.assign(Cut=None)
                    df_050_059_OV_VVS1_F  = df_050_059_OV_VVS1_F.assign(Polish=None)
                    df_050_059_OV_VVS1_F  = df_050_059_OV_VVS1_F.assign(Symmetry=None)
                    df_050_059_OV_VVS1_F  = df_050_059_OV_VVS1_F.assign(Ratio=None)
                    df_050_059_OV_VVS1_F  = df_050_059_OV_VVS1_F.assign(PPC=None)
                    df_050_059_OV_VVS1_F  = df_050_059_OV_VVS1_F.assign(Total=None)
                    df_050_059_OV_VVS1_F ['Wt Range'] = listwtrange
                    df_050_059_OV_VVS1_F ['Company'] = listcom
                    df_050_059_OV_VVS1_F ['Shape'] = listshap
                    df_050_059_OV_VVS1_F ['Carat'] = listcar
                    df_050_059_OV_VVS1_F ['Color'] = listcol
                    df_050_059_OV_VVS1_F ['Clarity'] = listclar
                    df_050_059_OV_VVS1_F ['Cut'] = listcut
                    df_050_059_OV_VVS1_F ['Polish'] = listpol
                    df_050_059_OV_VVS1_F ['Symmetry'] = listsym
                    df_050_059_OV_VVS1_F ['Ratio'] = listrat
                    df_050_059_OV_VVS1_F ['PPC'] = listdesc
                    df_050_059_OV_VVS1_F ['Total'] = listtotal
                    df_050_059_OV_VVS1_F['Carat'] = df_050_059_OV_VVS1_F['Carat'].astype('float64')
                    df_050_059_OV_VVS1_F['PPC'] = df_050_059_OV_VVS1_F['PPC'].astype('float64')
                    df_050_059_OV_VVS1_F['Total'] = df_050_059_OV_VVS1_F['Total'].astype('float64')
                    df_050_059_OV_VVS1_F['Total'] = df_050_059_OV_VVS1_F['Carat'] * df_050_059_OV_VVS1_F['PPC']


                elif i=="F" and j == "VVS2" and k == "OV":
                    df_050_059_OV_VVS2_F = pd.DataFrame()
                    df_050_059_OV_VVS2_F ['Wt Range'] = None
                    df_050_059_OV_VVS2_F  = df_050_059_OV_VVS2_F.assign(Company=None)
                    df_050_059_OV_VVS2_F  = df_050_059_OV_VVS2_F.assign(Shape=None)
                    df_050_059_OV_VVS2_F  = df_050_059_OV_VVS2_F.assign(Carat=None)
                    df_050_059_OV_VVS2_F  = df_050_059_OV_VVS2_F.assign(Color=None)
                    df_050_059_OV_VVS2_F  = df_050_059_OV_VVS2_F.assign(Clarity=None)
                    df_050_059_OV_VVS2_F  = df_050_059_OV_VVS2_F.assign(Cut=None)
                    df_050_059_OV_VVS2_F  = df_050_059_OV_VVS2_F.assign(Polish=None)
                    df_050_059_OV_VVS2_F  = df_050_059_OV_VVS2_F.assign(Symmetry=None)
                    df_050_059_OV_VVS2_F  = df_050_059_OV_VVS2_F.assign(Ratio=None)
                    df_050_059_OV_VVS2_F  = df_050_059_OV_VVS2_F.assign(PPC=None)
                    df_050_059_OV_VVS2_F  = df_050_059_OV_VVS2_F.assign(Total=None)
                    df_050_059_OV_VVS2_F ['Wt Range'] = listwtrange
                    df_050_059_OV_VVS2_F ['Company'] = listcom
                    df_050_059_OV_VVS2_F ['Shape'] = listshap
                    df_050_059_OV_VVS2_F ['Carat'] = listcar
                    df_050_059_OV_VVS2_F ['Color'] = listcol
                    df_050_059_OV_VVS2_F ['Clarity'] = listclar
                    df_050_059_OV_VVS2_F ['Cut'] = listcut
                    df_050_059_OV_VVS2_F ['Polish'] = listpol
                    df_050_059_OV_VVS2_F ['Symmetry'] = listsym
                    df_050_059_OV_VVS2_F ['Ratio'] = listrat
                    df_050_059_OV_VVS2_F ['PPC'] = listdesc
                    df_050_059_OV_VVS2_F ['Total'] = listtotal
                    df_050_059_OV_VVS2_F['Carat'] = df_050_059_OV_VVS2_F['Carat'].astype('float64')
                    df_050_059_OV_VVS2_F['PPC'] = df_050_059_OV_VVS2_F['PPC'].astype('float64')
                    df_050_059_OV_VVS2_F['Total'] = df_050_059_OV_VVS2_F['Total'].astype('float64')
                    df_050_059_OV_VVS2_F['Total'] = df_050_059_OV_VVS2_F['Carat'] * df_050_059_OV_VVS2_F['PPC']


                elif i=="F" and j=="VS1" and k == "OV":
                    df_050_059_OV_VS1_F = pd.DataFrame()
                    df_050_059_OV_VS1_F ['Wt Range'] = None
                    df_050_059_OV_VS1_F  = df_050_059_OV_VS1_F.assign(Company=None)
                    df_050_059_OV_VS1_F  = df_050_059_OV_VS1_F.assign(Shape=None)
                    df_050_059_OV_VS1_F  = df_050_059_OV_VS1_F.assign(Carat=None)
                    df_050_059_OV_VS1_F  = df_050_059_OV_VS1_F.assign(Color=None)
                    df_050_059_OV_VS1_F  = df_050_059_OV_VS1_F.assign(Clarity=None)
                    df_050_059_OV_VS1_F  = df_050_059_OV_VS1_F.assign(Cut=None)
                    df_050_059_OV_VS1_F  = df_050_059_OV_VS1_F.assign(Polish=None)
                    df_050_059_OV_VS1_F  = df_050_059_OV_VS1_F.assign(Symmetry=None)
                    df_050_059_OV_VS1_F  = df_050_059_OV_VS1_F.assign(Ratio=None)
                    df_050_059_OV_VS1_F  = df_050_059_OV_VS1_F.assign(PPC=None)
                    df_050_059_OV_VS1_F  = df_050_059_OV_VS1_F.assign(Total=None)
                    df_050_059_OV_VS1_F ['Wt Range'] = listwtrange
                    df_050_059_OV_VS1_F ['Company'] = listcom
                    df_050_059_OV_VS1_F ['Shape'] = listshap
                    df_050_059_OV_VS1_F ['Carat'] = listcar
                    df_050_059_OV_VS1_F ['Color'] = listcol
                    df_050_059_OV_VS1_F ['Clarity'] = listclar
                    df_050_059_OV_VS1_F ['Cut'] = listcut
                    df_050_059_OV_VS1_F ['Polish'] = listpol
                    df_050_059_OV_VS1_F ['Symmetry'] = listsym
                    df_050_059_OV_VS1_F ['Ratio'] = listrat
                    df_050_059_OV_VS1_F ['PPC'] = listdesc
                    df_050_059_OV_VS1_F ['Total'] = listtotal
                    df_050_059_OV_VS1_F['Carat'] = df_050_059_OV_VS1_F['Carat'].astype('float64')
                    df_050_059_OV_VS1_F['PPC'] = df_050_059_OV_VS1_F['PPC'].astype('float64')
                    df_050_059_OV_VS1_F['Total'] = df_050_059_OV_VS1_F['Total'].astype('float64')
                    df_050_059_OV_VS1_F['Total'] = df_050_059_OV_VS1_F['Carat'] * df_050_059_OV_VS1_F['PPC']


                elif i=="F" and j == "VS2" and k == "OV":
                    df_050_059_OV_VS2_F = pd.DataFrame()
                    df_050_059_OV_VS2_F ['Wt Range'] = None
                    df_050_059_OV_VS2_F  = df_050_059_OV_VS2_F.assign(Company=None)
                    df_050_059_OV_VS2_F  = df_050_059_OV_VS2_F.assign(Shape=None)
                    df_050_059_OV_VS2_F  = df_050_059_OV_VS2_F.assign(Carat=None)
                    df_050_059_OV_VS2_F  = df_050_059_OV_VS2_F.assign(Color=None)
                    df_050_059_OV_VS2_F  = df_050_059_OV_VS2_F.assign(Clarity=None)
                    df_050_059_OV_VS2_F  = df_050_059_OV_VS2_F.assign(Cut=None)
                    df_050_059_OV_VS2_F  = df_050_059_OV_VS2_F.assign(Polish=None)
                    df_050_059_OV_VS2_F  = df_050_059_OV_VS2_F.assign(Symmetry=None)
                    df_050_059_OV_VS2_F  = df_050_059_OV_VS2_F.assign(Ratio=None)
                    df_050_059_OV_VS2_F  = df_050_059_OV_VS2_F.assign(PPC=None)
                    df_050_059_OV_VS2_F  = df_050_059_OV_VS2_F.assign(Total=None)
                    df_050_059_OV_VS2_F ['Wt Range'] = listwtrange
                    df_050_059_OV_VS2_F ['Company'] = listcom
                    df_050_059_OV_VS2_F ['Shape'] = listshap
                    df_050_059_OV_VS2_F ['Carat'] = listcar
                    df_050_059_OV_VS2_F ['Color'] = listcol
                    df_050_059_OV_VS2_F ['Clarity'] = listclar
                    df_050_059_OV_VS2_F ['Cut'] = listcut
                    df_050_059_OV_VS2_F ['Polish'] = listpol
                    df_050_059_OV_VS2_F ['Symmetry'] = listsym
                    df_050_059_OV_VS2_F ['Ratio'] = listrat
                    df_050_059_OV_VS2_F ['PPC'] = listdesc
                    df_050_059_OV_VS2_F ['Total'] = listtotal
                    df_050_059_OV_VS2_F['Carat'] = df_050_059_OV_VS2_F['Carat'].astype('float64')
                    df_050_059_OV_VS2_F['PPC'] = df_050_059_OV_VS2_F['PPC'].astype('float64')
                    df_050_059_OV_VS2_F['Total'] = df_050_059_OV_VS2_F['Total'].astype('float64')
                    df_050_059_OV_VS2_F['Total'] = df_050_059_OV_VS2_F['Carat'] * df_050_059_OV_VS2_F['PPC']


                elif i=="F" and j == "SI1" and k == "OV":
                    df_050_059_OV_SI1_F = pd.DataFrame()
                    df_050_059_OV_SI1_F ['Wt Range'] = None
                    df_050_059_OV_SI1_F  = df_050_059_OV_SI1_F.assign(Company=None)
                    df_050_059_OV_SI1_F  = df_050_059_OV_SI1_F.assign(Shape=None)
                    df_050_059_OV_SI1_F  = df_050_059_OV_SI1_F.assign(Carat=None)
                    df_050_059_OV_SI1_F  = df_050_059_OV_SI1_F.assign(Color=None)
                    df_050_059_OV_SI1_F  = df_050_059_OV_SI1_F.assign(Clarity=None)
                    df_050_059_OV_SI1_F  = df_050_059_OV_SI1_F.assign(Cut=None)
                    df_050_059_OV_SI1_F  = df_050_059_OV_SI1_F.assign(Polish=None)
                    df_050_059_OV_SI1_F  = df_050_059_OV_SI1_F.assign(Symmetry=None)
                    df_050_059_OV_SI1_F  = df_050_059_OV_SI1_F.assign(Ratio=None)
                    df_050_059_OV_SI1_F  = df_050_059_OV_SI1_F.assign(PPC=None)
                    df_050_059_OV_SI1_F  = df_050_059_OV_SI1_F.assign(Total=None)
                    df_050_059_OV_SI1_F ['Wt Range'] = listwtrange
                    df_050_059_OV_SI1_F ['Company'] = listcom
                    df_050_059_OV_SI1_F ['Shape'] = listshap
                    df_050_059_OV_SI1_F ['Carat'] = listcar
                    df_050_059_OV_SI1_F ['Color'] = listcol
                    df_050_059_OV_SI1_F ['Clarity'] = listclar
                    df_050_059_OV_SI1_F ['Cut'] = listcut
                    df_050_059_OV_SI1_F ['Polish'] = listpol
                    df_050_059_OV_SI1_F ['Symmetry'] = listsym
                    df_050_059_OV_SI1_F ['Ratio'] = listrat
                    df_050_059_OV_SI1_F ['PPC'] = listdesc
                    df_050_059_OV_SI1_F ['Total'] = listtotal
                    df_050_059_OV_SI1_F['Carat'] = df_050_059_OV_SI1_F['Carat'].astype('float64')
                    df_050_059_OV_SI1_F['PPC'] = df_050_059_OV_SI1_F['PPC'].astype('float64')
                    df_050_059_OV_SI1_F['Total'] = df_050_059_OV_SI1_F['Total'].astype('float64')
                    df_050_059_OV_SI1_F['Total'] = df_050_059_OV_SI1_F['Carat'] * df_050_059_OV_SI1_F['PPC']


                elif i=="F" and j == "SI2" and k == "OV":
                    df_050_059_OV_SI2_F = pd.DataFrame()
                    df_050_059_OV_SI2_F ['Wt Range'] = None
                    df_050_059_OV_SI2_F  = df_050_059_OV_SI2_F.assign(Company=None)
                    df_050_059_OV_SI2_F  = df_050_059_OV_SI2_F.assign(Shape=None)
                    df_050_059_OV_SI2_F  = df_050_059_OV_SI2_F.assign(Carat=None)
                    df_050_059_OV_SI2_F  = df_050_059_OV_SI2_F.assign(Color=None)
                    df_050_059_OV_SI2_F  = df_050_059_OV_SI2_F.assign(Clarity=None)
                    df_050_059_OV_SI2_F  = df_050_059_OV_SI2_F.assign(Cut=None)
                    df_050_059_OV_SI2_F  = df_050_059_OV_SI2_F.assign(Polish=None)
                    df_050_059_OV_SI2_F  = df_050_059_OV_SI2_F.assign(Symmetry=None)
                    df_050_059_OV_SI2_F  = df_050_059_OV_SI2_F.assign(Ratio=None)
                    df_050_059_OV_SI2_F  = df_050_059_OV_SI2_F.assign(PPC=None)
                    df_050_059_OV_SI2_F  = df_050_059_OV_SI2_F.assign(Total=None)
                    df_050_059_OV_SI2_F ['Wt Range'] = listwtrange
                    df_050_059_OV_SI2_F ['Company'] = listcom
                    df_050_059_OV_SI2_F ['Shape'] = listshap
                    df_050_059_OV_SI2_F ['Carat'] = listcar
                    df_050_059_OV_SI2_F ['Color'] = listcol
                    df_050_059_OV_SI2_F ['Clarity'] = listclar
                    df_050_059_OV_SI2_F ['Cut'] = listcut
                    df_050_059_OV_SI2_F ['Polish'] = listpol
                    df_050_059_OV_SI2_F ['Symmetry'] = listsym
                    df_050_059_OV_SI2_F ['Ratio'] = listrat
                    df_050_059_OV_SI2_F ['PPC'] = listdesc
                    df_050_059_OV_SI2_F ['Total'] = listtotal
                    df_050_059_OV_SI2_F['Carat'] = df_050_059_OV_SI2_F['Carat'].astype('float64')
                    df_050_059_OV_SI2_F['PPC'] = df_050_059_OV_SI2_F['PPC'].astype('float64')
                    df_050_059_OV_SI2_F['Total'] = df_050_059_OV_SI2_F['Total'].astype('float64')
                    df_050_059_OV_SI2_F['Total'] = df_050_059_OV_SI2_F['Carat'] * df_050_059_OV_SI2_F['PPC']


                elif i=="F" and j == "I1" and k == "OV":
                    df_050_059_OV_I1_F = pd.DataFrame()
                    df_050_059_OV_I1_F ['Wt Range'] = None
                    df_050_059_OV_I1_F  = df_050_059_OV_I1_F.assign(Company=None)
                    df_050_059_OV_I1_F  = df_050_059_OV_I1_F.assign(Shape=None)
                    df_050_059_OV_I1_F  = df_050_059_OV_I1_F.assign(Carat=None)
                    df_050_059_OV_I1_F  = df_050_059_OV_I1_F.assign(Color=None)
                    df_050_059_OV_I1_F  = df_050_059_OV_I1_F.assign(Clarity=None)
                    df_050_059_OV_I1_F  = df_050_059_OV_I1_F.assign(Cut=None)
                    df_050_059_OV_I1_F  = df_050_059_OV_I1_F.assign(Polish=None)
                    df_050_059_OV_I1_F  = df_050_059_OV_I1_F.assign(Symmetry=None)
                    df_050_059_OV_I1_F  = df_050_059_OV_I1_F.assign(Ratio=None)
                    df_050_059_OV_I1_F  = df_050_059_OV_I1_F.assign(PPC=None)
                    df_050_059_OV_I1_F  = df_050_059_OV_I1_F.assign(Total=None)
                    df_050_059_OV_I1_F ['Wt Range'] = listwtrange
                    df_050_059_OV_I1_F ['Company'] = listcom
                    df_050_059_OV_I1_F ['Shape'] = listshap
                    df_050_059_OV_I1_F ['Carat'] = listcar
                    df_050_059_OV_I1_F ['Color'] = listcol
                    df_050_059_OV_I1_F ['Clarity'] = listclar
                    df_050_059_OV_I1_F ['Cut'] = listcut
                    df_050_059_OV_I1_F ['Polish'] = listpol
                    df_050_059_OV_I1_F ['Symmetry'] = listsym
                    df_050_059_OV_I1_F ['Ratio'] = listrat
                    df_050_059_OV_I1_F ['PPC'] = listdesc
                    df_050_059_OV_I1_F ['Total'] = listtotal
                    df_050_059_OV_I1_F['Carat'] = df_050_059_OV_I1_F['Carat'].astype('float64')
                    df_050_059_OV_I1_F['PPC'] = df_050_059_OV_I1_F['PPC'].astype('float64')
                    df_050_059_OV_I1_F['Total'] = df_050_059_OV_I1_F['Total'].astype('float64')
                    df_050_059_OV_I1_F['Total'] = df_050_059_OV_I1_F['Carat'] * df_050_059_OV_I1_F['PPC']


                elif i=="F" and j == "I2" and k == "OV":
                    df_050_059_OV_I2_F = pd.DataFrame()
                    df_050_059_OV_I2_F ['Wt Range'] = None
                    df_050_059_OV_I2_F  = df_050_059_OV_I2_F.assign(Company=None)
                    df_050_059_OV_I2_F  = df_050_059_OV_I2_F.assign(Shape=None)
                    df_050_059_OV_I2_F  = df_050_059_OV_I2_F.assign(Carat=None)
                    df_050_059_OV_I2_F  = df_050_059_OV_I2_F.assign(Color=None)
                    df_050_059_OV_I2_F  = df_050_059_OV_I2_F.assign(Clarity=None)
                    df_050_059_OV_I2_F  = df_050_059_OV_I2_F.assign(Cut=None)
                    df_050_059_OV_I2_F  = df_050_059_OV_I2_F.assign(Polish=None)
                    df_050_059_OV_I2_F  = df_050_059_OV_I2_F.assign(Symmetry=None)
                    df_050_059_OV_I2_F  = df_050_059_OV_I2_F.assign(Ratio=None)
                    df_050_059_OV_I2_F  = df_050_059_OV_I2_F.assign(PPC=None)
                    df_050_059_OV_I2_F  = df_050_059_OV_I2_F.assign(Total=None)
                    df_050_059_OV_I2_F ['Wt Range'] = listwtrange
                    df_050_059_OV_I2_F ['Company'] = listcom
                    df_050_059_OV_I2_F ['Shape'] = listshap
                    df_050_059_OV_I2_F ['Carat'] = listcar
                    df_050_059_OV_I2_F ['Color'] = listcol
                    df_050_059_OV_I2_F ['Clarity'] = listclar
                    df_050_059_OV_I2_F ['Cut'] = listcut
                    df_050_059_OV_I2_F ['Polish'] = listpol
                    df_050_059_OV_I2_F ['Symmetry'] = listsym
                    df_050_059_OV_I2_F ['Ratio'] = listrat
                    df_050_059_OV_I2_F ['PPC'] = listdesc
                    df_050_059_OV_I2_F ['Total'] = listtotal
                    df_050_059_OV_I2_F['Carat'] = df_050_059_OV_I2_F['Carat'].astype('float64')
                    df_050_059_OV_I2_F['PPC'] = df_050_059_OV_I2_F['PPC'].astype('float64')
                    df_050_059_OV_I2_F['Total'] = df_050_059_OV_I2_F['Total'].astype('float64')
                    df_050_059_OV_I2_F['Total'] = df_050_059_OV_I2_F['Carat'] * df_050_059_OV_I2_F['PPC']


                elif i=="G" and j == "IF" and k == "OV":
                    df_050_059_OV_IF_G = pd.DataFrame()
                    df_050_059_OV_IF_G ['Wt Range'] = None
                    df_050_059_OV_IF_G  = df_050_059_OV_IF_G.assign(Company=None)
                    df_050_059_OV_IF_G  = df_050_059_OV_IF_G.assign(Shape=None)
                    df_050_059_OV_IF_G  = df_050_059_OV_IF_G.assign(Carat=None)
                    df_050_059_OV_IF_G  = df_050_059_OV_IF_G.assign(Color=None)
                    df_050_059_OV_IF_G  = df_050_059_OV_IF_G.assign(Clarity=None)
                    df_050_059_OV_IF_G  = df_050_059_OV_IF_G.assign(Cut=None)
                    df_050_059_OV_IF_G  = df_050_059_OV_IF_G.assign(Polish=None)
                    df_050_059_OV_IF_G  = df_050_059_OV_IF_G.assign(Symmetry=None)
                    df_050_059_OV_IF_G  = df_050_059_OV_IF_G.assign(Ratio=None)
                    df_050_059_OV_IF_G  = df_050_059_OV_IF_G.assign(PPC=None)
                    df_050_059_OV_IF_G  = df_050_059_OV_IF_G.assign(Total=None)
                    df_050_059_OV_IF_G ['Wt Range'] = listwtrange
                    df_050_059_OV_IF_G ['Company'] = listcom
                    df_050_059_OV_IF_G ['Shape'] = listshap
                    df_050_059_OV_IF_G ['Carat'] = listcar
                    df_050_059_OV_IF_G ['Color'] = listcol
                    df_050_059_OV_IF_G ['Clarity'] = listclar
                    df_050_059_OV_IF_G ['Cut'] = listcut
                    df_050_059_OV_IF_G ['Polish'] = listpol
                    df_050_059_OV_IF_G ['Symmetry'] = listsym
                    df_050_059_OV_IF_G ['Ratio'] = listrat
                    df_050_059_OV_IF_G ['PPC'] = listdesc
                    df_050_059_OV_IF_G ['Total'] = listtotal
                    df_050_059_OV_IF_G['Carat'] = df_050_059_OV_IF_G['Carat'].astype('float64')
                    df_050_059_OV_IF_G['PPC'] = df_050_059_OV_IF_G['PPC'].astype('float64')
                    df_050_059_OV_IF_G['Total'] = df_050_059_OV_IF_G['Total'].astype('float64')
                    df_050_059_OV_IF_G['Total'] = df_050_059_OV_IF_G['Carat'] * df_050_059_OV_IF_G['PPC']



                elif i=="G" and j == "VVS1" and k == "OV":
                    df_050_059_OV_VVS1_G = pd.DataFrame()
                    df_050_059_OV_VVS1_G ['Wt Range'] = None
                    df_050_059_OV_VVS1_G  = df_050_059_OV_VVS1_G.assign(Company=None)
                    df_050_059_OV_VVS1_G  = df_050_059_OV_VVS1_G.assign(Shape=None)
                    df_050_059_OV_VVS1_G  = df_050_059_OV_VVS1_G.assign(Carat=None)
                    df_050_059_OV_VVS1_G  = df_050_059_OV_VVS1_G.assign(Color=None)
                    df_050_059_OV_VVS1_G  = df_050_059_OV_VVS1_G.assign(Clarity=None)
                    df_050_059_OV_VVS1_G  = df_050_059_OV_VVS1_G.assign(Cut=None)
                    df_050_059_OV_VVS1_G  = df_050_059_OV_VVS1_G.assign(Polish=None)
                    df_050_059_OV_VVS1_G  = df_050_059_OV_VVS1_G.assign(Symmetry=None)
                    df_050_059_OV_VVS1_G  = df_050_059_OV_VVS1_G.assign(Ratio=None)
                    df_050_059_OV_VVS1_G  = df_050_059_OV_VVS1_G.assign(PPC=None)
                    df_050_059_OV_VVS1_G  = df_050_059_OV_VVS1_G.assign(Total=None)
                    df_050_059_OV_VVS1_G ['Wt Range'] = listwtrange
                    df_050_059_OV_VVS1_G ['Company'] = listcom
                    df_050_059_OV_VVS1_G ['Shape'] = listshap
                    df_050_059_OV_VVS1_G ['Carat'] = listcar
                    df_050_059_OV_VVS1_G ['Color'] = listcol
                    df_050_059_OV_VVS1_G ['Clarity'] = listclar
                    df_050_059_OV_VVS1_G ['Cut'] = listcut
                    df_050_059_OV_VVS1_G ['Polish'] = listpol
                    df_050_059_OV_VVS1_G ['Symmetry'] = listsym
                    df_050_059_OV_VVS1_G ['Ratio'] = listrat
                    df_050_059_OV_VVS1_G ['PPC'] = listdesc
                    df_050_059_OV_VVS1_G ['Total'] = listtotal
                    df_050_059_OV_VVS1_G['Carat'] = df_050_059_OV_VVS1_G['Carat'].astype('float64')
                    df_050_059_OV_VVS1_G['PPC'] = df_050_059_OV_VVS1_G['PPC'].astype('float64')
                    df_050_059_OV_VVS1_G['Total'] = df_050_059_OV_VVS1_G['Total'].astype('float64')
                    df_050_059_OV_VVS1_G['Total'] = df_050_059_OV_VVS1_G['Carat'] * df_050_059_OV_VVS1_G['PPC']


                elif i=="G" and j == "VVS2" and k == "OV":
                    df_050_059_OV_VVS2_G = pd.DataFrame()
                    df_050_059_OV_VVS2_G ['Wt Range'] = None
                    df_050_059_OV_VVS2_G  = df_050_059_OV_VVS2_G.assign(Company=None)
                    df_050_059_OV_VVS2_G  = df_050_059_OV_VVS2_G.assign(Shape=None)
                    df_050_059_OV_VVS2_G  = df_050_059_OV_VVS2_G.assign(Carat=None)
                    df_050_059_OV_VVS2_G  = df_050_059_OV_VVS2_G.assign(Color=None)
                    df_050_059_OV_VVS2_G  = df_050_059_OV_VVS2_G.assign(Clarity=None)
                    df_050_059_OV_VVS2_G  = df_050_059_OV_VVS2_G.assign(Cut=None)
                    df_050_059_OV_VVS2_G  = df_050_059_OV_VVS2_G.assign(Polish=None)
                    df_050_059_OV_VVS2_G  = df_050_059_OV_VVS2_G.assign(Symmetry=None)
                    df_050_059_OV_VVS2_G  = df_050_059_OV_VVS2_G.assign(Ratio=None)
                    df_050_059_OV_VVS2_G  = df_050_059_OV_VVS2_G.assign(PPC=None)
                    df_050_059_OV_VVS2_G  = df_050_059_OV_VVS2_G.assign(Total=None)
                    df_050_059_OV_VVS2_G ['Wt Range'] = listwtrange
                    df_050_059_OV_VVS2_G ['Company'] = listcom
                    df_050_059_OV_VVS2_G ['Shape'] = listshap
                    df_050_059_OV_VVS2_G ['Carat'] = listcar
                    df_050_059_OV_VVS2_G ['Color'] = listcol
                    df_050_059_OV_VVS2_G ['Clarity'] = listclar
                    df_050_059_OV_VVS2_G ['Cut'] = listcut
                    df_050_059_OV_VVS2_G ['Polish'] = listpol
                    df_050_059_OV_VVS2_G ['Symmetry'] = listsym
                    df_050_059_OV_VVS2_G ['Ratio'] = listrat
                    df_050_059_OV_VVS2_G ['PPC'] = listdesc
                    df_050_059_OV_VVS2_G ['Total'] = listtotal
                    df_050_059_OV_VVS2_G['Carat'] = df_050_059_OV_VVS2_G['Carat'].astype('float64')
                    df_050_059_OV_VVS2_G['PPC'] = df_050_059_OV_VVS2_G['PPC'].astype('float64')
                    df_050_059_OV_VVS2_G['Total'] = df_050_059_OV_VVS2_G['Total'].astype('float64')
                    df_050_059_OV_VVS2_G['Total'] = df_050_059_OV_VVS2_G['Carat'] * df_050_059_OV_VVS2_G['PPC']


                elif i=="G" and j=="VS1" and k == "OV":
                    df_050_059_OV_VS1_G = pd.DataFrame()
                    df_050_059_OV_VS1_G ['Wt Range'] = None
                    df_050_059_OV_VS1_G  = df_050_059_OV_VS1_G.assign(Company=None)
                    df_050_059_OV_VS1_G  = df_050_059_OV_VS1_G.assign(Shape=None)
                    df_050_059_OV_VS1_G  = df_050_059_OV_VS1_G.assign(Carat=None)
                    df_050_059_OV_VS1_G  = df_050_059_OV_VS1_G.assign(Color=None)
                    df_050_059_OV_VS1_G  = df_050_059_OV_VS1_G.assign(Clarity=None)
                    df_050_059_OV_VS1_G  = df_050_059_OV_VS1_G.assign(Cut=None)
                    df_050_059_OV_VS1_G  = df_050_059_OV_VS1_G.assign(Polish=None)
                    df_050_059_OV_VS1_G  = df_050_059_OV_VS1_G.assign(Symmetry=None)
                    df_050_059_OV_VS1_G  = df_050_059_OV_VS1_G.assign(Ratio=None)
                    df_050_059_OV_VS1_G  = df_050_059_OV_VS1_G.assign(PPC=None)
                    df_050_059_OV_VS1_G  = df_050_059_OV_VS1_G.assign(Total=None)
                    df_050_059_OV_VS1_G ['Wt Range'] = listwtrange
                    df_050_059_OV_VS1_G ['Company'] = listcom
                    df_050_059_OV_VS1_G ['Shape'] = listshap
                    df_050_059_OV_VS1_G ['Carat'] = listcar
                    df_050_059_OV_VS1_G ['Color'] = listcol
                    df_050_059_OV_VS1_G ['Clarity'] = listclar
                    df_050_059_OV_VS1_G ['Cut'] = listcut
                    df_050_059_OV_VS1_G ['Polish'] = listpol
                    df_050_059_OV_VS1_G ['Symmetry'] = listsym
                    df_050_059_OV_VS1_G ['Ratio'] = listrat
                    df_050_059_OV_VS1_G ['PPC'] = listdesc
                    df_050_059_OV_VS1_G ['Total'] = listtotal
                    df_050_059_OV_VS1_G['Carat'] = df_050_059_OV_VS1_G['Carat'].astype('float64')
                    df_050_059_OV_VS1_G['PPC'] = df_050_059_OV_VS1_G['PPC'].astype('float64')
                    df_050_059_OV_VS1_G['Total'] = df_050_059_OV_VS1_G['Total'].astype('float64')
                    df_050_059_OV_VS1_G['Total'] = df_050_059_OV_VS1_G['Carat'] * df_050_059_OV_VS1_G['PPC']


                elif i=="G" and j == "VS2" and k == "OV":
                    df_050_059_OV_VS2_G = pd.DataFrame()
                    df_050_059_OV_VS2_G ['Wt Range'] = None
                    df_050_059_OV_VS2_G  = df_050_059_OV_VS2_G.assign(Company=None)
                    df_050_059_OV_VS2_G  = df_050_059_OV_VS2_G.assign(Shape=None)
                    df_050_059_OV_VS2_G  = df_050_059_OV_VS2_G.assign(Carat=None)
                    df_050_059_OV_VS2_G  = df_050_059_OV_VS2_G.assign(Color=None)
                    df_050_059_OV_VS2_G  = df_050_059_OV_VS2_G.assign(Clarity=None)
                    df_050_059_OV_VS2_G  = df_050_059_OV_VS2_G.assign(Cut=None)
                    df_050_059_OV_VS2_G  = df_050_059_OV_VS2_G.assign(Polish=None)
                    df_050_059_OV_VS2_G  = df_050_059_OV_VS2_G.assign(Symmetry=None)
                    df_050_059_OV_VS2_G  = df_050_059_OV_VS2_G.assign(Ratio=None)
                    df_050_059_OV_VS2_G  = df_050_059_OV_VS2_G.assign(PPC=None)
                    df_050_059_OV_VS2_G  = df_050_059_OV_VS2_G.assign(Total=None)
                    df_050_059_OV_VS2_G ['Wt Range'] = listwtrange
                    df_050_059_OV_VS2_G ['Company'] = listcom
                    df_050_059_OV_VS2_G ['Shape'] = listshap
                    df_050_059_OV_VS2_G ['Carat'] = listcar
                    df_050_059_OV_VS2_G ['Color'] = listcol
                    df_050_059_OV_VS2_G ['Clarity'] = listclar
                    df_050_059_OV_VS2_G ['Cut'] = listcut
                    df_050_059_OV_VS2_G ['Polish'] = listpol
                    df_050_059_OV_VS2_G ['Symmetry'] = listsym
                    df_050_059_OV_VS2_G ['Ratio'] = listrat
                    df_050_059_OV_VS2_G ['PPC'] = listdesc
                    df_050_059_OV_VS2_G ['Total'] = listtotal
                    df_050_059_OV_VS2_G['Carat'] = df_050_059_OV_VS2_G['Carat'].astype('float64')
                    df_050_059_OV_VS2_G['PPC'] = df_050_059_OV_VS2_G['PPC'].astype('float64')
                    df_050_059_OV_VS2_G['Total'] = df_050_059_OV_VS2_G['Total'].astype('float64')
                    df_050_059_OV_VS2_G['Total'] = df_050_059_OV_VS2_G['Carat'] * df_050_059_OV_VS2_G['PPC']


                elif i=="G" and j == "SI1" and k == "OV":
                    df_050_059_OV_SI1_G = pd.DataFrame()
                    df_050_059_OV_SI1_G ['Wt Range'] = None
                    df_050_059_OV_SI1_G  = df_050_059_OV_SI1_G.assign(Company=None)
                    df_050_059_OV_SI1_G  = df_050_059_OV_SI1_G.assign(Shape=None)
                    df_050_059_OV_SI1_G  = df_050_059_OV_SI1_G.assign(Carat=None)
                    df_050_059_OV_SI1_G  = df_050_059_OV_SI1_G.assign(Color=None)
                    df_050_059_OV_SI1_G  = df_050_059_OV_SI1_G.assign(Clarity=None)
                    df_050_059_OV_SI1_G  = df_050_059_OV_SI1_G.assign(Cut=None)
                    df_050_059_OV_SI1_G  = df_050_059_OV_SI1_G.assign(Polish=None)
                    df_050_059_OV_SI1_G  = df_050_059_OV_SI1_G.assign(Symmetry=None)
                    df_050_059_OV_SI1_G  = df_050_059_OV_SI1_G.assign(Ratio=None)
                    df_050_059_OV_SI1_G  = df_050_059_OV_SI1_G.assign(PPC=None)
                    df_050_059_OV_SI1_G  = df_050_059_OV_SI1_G.assign(Total=None)
                    df_050_059_OV_SI1_G ['Wt Range'] = listwtrange
                    df_050_059_OV_SI1_G ['Company'] = listcom
                    df_050_059_OV_SI1_G ['Shape'] = listshap
                    df_050_059_OV_SI1_G ['Carat'] = listcar
                    df_050_059_OV_SI1_G ['Color'] = listcol
                    df_050_059_OV_SI1_G ['Clarity'] = listclar
                    df_050_059_OV_SI1_G ['Cut'] = listcut
                    df_050_059_OV_SI1_G ['Polish'] = listpol
                    df_050_059_OV_SI1_G ['Symmetry'] = listsym
                    df_050_059_OV_SI1_G ['Ratio'] = listrat
                    df_050_059_OV_SI1_G ['PPC'] = listdesc
                    df_050_059_OV_SI1_G ['Total'] = listtotal
                    df_050_059_OV_SI1_G['Carat'] = df_050_059_OV_SI1_G['Carat'].astype('float64')
                    df_050_059_OV_SI1_G['PPC'] = df_050_059_OV_SI1_G['PPC'].astype('float64')
                    df_050_059_OV_SI1_G['Total'] = df_050_059_OV_SI1_G['Total'].astype('float64')
                    df_050_059_OV_SI1_G['Total'] = df_050_059_OV_SI1_G['Carat'] * df_050_059_OV_SI1_G['PPC']


                elif i=="G" and j == "SI2" and k == "OV":
                    df_050_059_OV_SI2_G = pd.DataFrame()
                    df_050_059_OV_SI2_G ['Wt Range'] = None
                    df_050_059_OV_SI2_G  = df_050_059_OV_SI2_G.assign(Company=None)
                    df_050_059_OV_SI2_G  = df_050_059_OV_SI2_G.assign(Shape=None)
                    df_050_059_OV_SI2_G  = df_050_059_OV_SI2_G.assign(Carat=None)
                    df_050_059_OV_SI2_G  = df_050_059_OV_SI2_G.assign(Color=None)
                    df_050_059_OV_SI2_G  = df_050_059_OV_SI2_G.assign(Clarity=None)
                    df_050_059_OV_SI2_G  = df_050_059_OV_SI2_G.assign(Cut=None)
                    df_050_059_OV_SI2_G  = df_050_059_OV_SI2_G.assign(Polish=None)
                    df_050_059_OV_SI2_G  = df_050_059_OV_SI2_G.assign(Symmetry=None)
                    df_050_059_OV_SI2_G  = df_050_059_OV_SI2_G.assign(Ratio=None)
                    df_050_059_OV_SI2_G  = df_050_059_OV_SI2_G.assign(PPC=None)
                    df_050_059_OV_SI2_G  = df_050_059_OV_SI2_G.assign(Total=None)
                    df_050_059_OV_SI2_G ['Wt Range'] = listwtrange
                    df_050_059_OV_SI2_G ['Company'] = listcom
                    df_050_059_OV_SI2_G ['Shape'] = listshap
                    df_050_059_OV_SI2_G ['Carat'] = listcar
                    df_050_059_OV_SI2_G ['Color'] = listcol
                    df_050_059_OV_SI2_G ['Clarity'] = listclar
                    df_050_059_OV_SI2_G ['Cut'] = listcut
                    df_050_059_OV_SI2_G ['Polish'] = listpol
                    df_050_059_OV_SI2_G ['Symmetry'] = listsym
                    df_050_059_OV_SI2_G ['Ratio'] = listrat
                    df_050_059_OV_SI2_G ['PPC'] = listdesc
                    df_050_059_OV_SI2_G ['Total'] = listtotal
                    df_050_059_OV_SI2_G['Carat'] = df_050_059_OV_SI2_G['Carat'].astype('float64')
                    df_050_059_OV_SI2_G['PPC'] = df_050_059_OV_SI2_G['PPC'].astype('float64')
                    df_050_059_OV_SI2_G['Total'] = df_050_059_OV_SI2_G['Total'].astype('float64')
                    df_050_059_OV_SI2_G['Total'] = df_050_059_OV_SI2_G['Carat'] * df_050_059_OV_SI2_G['PPC']


                elif i=="G" and j == "I1" and k == "OV":
                    df_050_059_OV_I1_G = pd.DataFrame()
                    df_050_059_OV_I1_G ['Wt Range'] = None
                    df_050_059_OV_I1_G  = df_050_059_OV_I1_G.assign(Company=None)
                    df_050_059_OV_I1_G  = df_050_059_OV_I1_G.assign(Shape=None)
                    df_050_059_OV_I1_G  = df_050_059_OV_I1_G.assign(Carat=None)
                    df_050_059_OV_I1_G  = df_050_059_OV_I1_G.assign(Color=None)
                    df_050_059_OV_I1_G  = df_050_059_OV_I1_G.assign(Clarity=None)
                    df_050_059_OV_I1_G  = df_050_059_OV_I1_G.assign(Cut=None)
                    df_050_059_OV_I1_G  = df_050_059_OV_I1_G.assign(Polish=None)
                    df_050_059_OV_I1_G  = df_050_059_OV_I1_G.assign(Symmetry=None)
                    df_050_059_OV_I1_G  = df_050_059_OV_I1_G.assign(Ratio=None)
                    df_050_059_OV_I1_G  = df_050_059_OV_I1_G.assign(PPC=None)
                    df_050_059_OV_I1_G  = df_050_059_OV_I1_G.assign(Total=None)
                    df_050_059_OV_I1_G ['Wt Range'] = listwtrange
                    df_050_059_OV_I1_G ['Company'] = listcom
                    df_050_059_OV_I1_G ['Shape'] = listshap
                    df_050_059_OV_I1_G ['Carat'] = listcar
                    df_050_059_OV_I1_G ['Color'] = listcol
                    df_050_059_OV_I1_G ['Clarity'] = listclar
                    df_050_059_OV_I1_G ['Cut'] = listcut
                    df_050_059_OV_I1_G ['Polish'] = listpol
                    df_050_059_OV_I1_G ['Symmetry'] = listsym
                    df_050_059_OV_I1_G ['Ratio'] = listrat
                    df_050_059_OV_I1_G ['PPC'] = listdesc
                    df_050_059_OV_I1_G ['Total'] = listtotal
                    df_050_059_OV_I1_G['Carat'] = df_050_059_OV_I1_G['Carat'].astype('float64')
                    df_050_059_OV_I1_G['PPC'] = df_050_059_OV_I1_G['PPC'].astype('float64')
                    df_050_059_OV_I1_G['Total'] = df_050_059_OV_I1_G['Total'].astype('float64')
                    df_050_059_OV_I1_G['Total'] = df_050_059_OV_I1_G['Carat'] * df_050_059_OV_I1_G['PPC']


                elif i=="G" and j == "I2" and k == "OV":
                    df_050_059_OV_I2_G = pd.DataFrame()
                    df_050_059_OV_I2_G ['Wt Range'] = None
                    df_050_059_OV_I2_G  = df_050_059_OV_I2_G.assign(Company=None)
                    df_050_059_OV_I2_G  = df_050_059_OV_I2_G.assign(Shape=None)
                    df_050_059_OV_I2_G  = df_050_059_OV_I2_G.assign(Carat=None)
                    df_050_059_OV_I2_G  = df_050_059_OV_I2_G.assign(Color=None)
                    df_050_059_OV_I2_G  = df_050_059_OV_I2_G.assign(Clarity=None)
                    df_050_059_OV_I2_G  = df_050_059_OV_I2_G.assign(Cut=None)
                    df_050_059_OV_I2_G  = df_050_059_OV_I2_G.assign(Polish=None)
                    df_050_059_OV_I2_G  = df_050_059_OV_I2_G.assign(Symmetry=None)
                    df_050_059_OV_I2_G  = df_050_059_OV_I2_G.assign(Ratio=None)
                    df_050_059_OV_I2_G  = df_050_059_OV_I2_G.assign(PPC=None)
                    df_050_059_OV_I2_G  = df_050_059_OV_I2_G.assign(Total=None)
                    df_050_059_OV_I2_G ['Wt Range'] = listwtrange
                    df_050_059_OV_I2_G ['Company'] = listcom
                    df_050_059_OV_I2_G ['Shape'] = listshap
                    df_050_059_OV_I2_G ['Carat'] = listcar
                    df_050_059_OV_I2_G ['Color'] = listcol
                    df_050_059_OV_I2_G ['Clarity'] = listclar
                    df_050_059_OV_I2_G ['Cut'] = listcut
                    df_050_059_OV_I2_G ['Polish'] = listpol
                    df_050_059_OV_I2_G ['Symmetry'] = listsym
                    df_050_059_OV_I2_G ['Ratio'] = listrat
                    df_050_059_OV_I2_G ['PPC'] = listdesc
                    df_050_059_OV_I2_G ['Total'] = listtotal
                    df_050_059_OV_I2_G['Carat'] = df_050_059_OV_I2_G['Carat'].astype('float64')
                    df_050_059_OV_I2_G['PPC'] = df_050_059_OV_I2_G['PPC'].astype('float64')
                    df_050_059_OV_I2_G['Total'] = df_050_059_OV_I2_G['Total'].astype('float64')
                    df_050_059_OV_I2_G['Total'] = df_050_059_OV_I2_G['Carat'] * df_050_059_OV_I2_G['PPC']


                elif i=="H" and j == "IF" and k == "OV":
                    df_050_059_OV_IF_H = pd.DataFrame()
                    df_050_059_OV_IF_H ['Wt Range'] = None
                    df_050_059_OV_IF_H  = df_050_059_OV_IF_H.assign(Company=None)
                    df_050_059_OV_IF_H  = df_050_059_OV_IF_H.assign(Shape=None)
                    df_050_059_OV_IF_H  = df_050_059_OV_IF_H.assign(Carat=None)
                    df_050_059_OV_IF_H  = df_050_059_OV_IF_H.assign(Color=None)
                    df_050_059_OV_IF_H  = df_050_059_OV_IF_H.assign(Clarity=None)
                    df_050_059_OV_IF_H  = df_050_059_OV_IF_H.assign(Cut=None)
                    df_050_059_OV_IF_H  = df_050_059_OV_IF_H.assign(Polish=None)
                    df_050_059_OV_IF_H  = df_050_059_OV_IF_H.assign(Symmetry=None)
                    df_050_059_OV_IF_H  = df_050_059_OV_IF_H.assign(Ratio=None)
                    df_050_059_OV_IF_H  = df_050_059_OV_IF_H.assign(PPC=None)
                    df_050_059_OV_IF_H  = df_050_059_OV_IF_H.assign(Total=None)
                    df_050_059_OV_IF_H ['Wt Range'] = listwtrange
                    df_050_059_OV_IF_H ['Company'] = listcom
                    df_050_059_OV_IF_H ['Shape'] = listshap
                    df_050_059_OV_IF_H ['Carat'] = listcar
                    df_050_059_OV_IF_H ['Color'] = listcol
                    df_050_059_OV_IF_H ['Clarity'] = listclar
                    df_050_059_OV_IF_H ['Cut'] = listcut
                    df_050_059_OV_IF_H ['Polish'] = listpol
                    df_050_059_OV_IF_H ['Symmetry'] = listsym
                    df_050_059_OV_IF_H ['Ratio'] = listrat
                    df_050_059_OV_IF_H ['PPC'] = listdesc
                    df_050_059_OV_IF_H ['Total'] = listtotal
                    df_050_059_OV_IF_H['Carat'] = df_050_059_OV_IF_H['Carat'].astype('float64')
                    df_050_059_OV_IF_H['PPC'] = df_050_059_OV_IF_H['PPC'].astype('float64')
                    df_050_059_OV_IF_H['Total'] = df_050_059_OV_IF_H['Total'].astype('float64')
                    df_050_059_OV_IF_H['Total'] = df_050_059_OV_IF_H['Carat'] * df_050_059_OV_IF_H['PPC']



                elif i=="H" and j == "VVS1" and k == "OV":
                    df_050_059_OV_VVS1_H = pd.DataFrame()
                    df_050_059_OV_VVS1_H ['Wt Range'] = None
                    df_050_059_OV_VVS1_H  = df_050_059_OV_VVS1_H.assign(Company=None)
                    df_050_059_OV_VVS1_H  = df_050_059_OV_VVS1_H.assign(Shape=None)
                    df_050_059_OV_VVS1_H  = df_050_059_OV_VVS1_H.assign(Carat=None)
                    df_050_059_OV_VVS1_H  = df_050_059_OV_VVS1_H.assign(Color=None)
                    df_050_059_OV_VVS1_H  = df_050_059_OV_VVS1_H.assign(Clarity=None)
                    df_050_059_OV_VVS1_H  = df_050_059_OV_VVS1_H.assign(Cut=None)
                    df_050_059_OV_VVS1_H  = df_050_059_OV_VVS1_H.assign(Polish=None)
                    df_050_059_OV_VVS1_H  = df_050_059_OV_VVS1_H.assign(Symmetry=None)
                    df_050_059_OV_VVS1_H  = df_050_059_OV_VVS1_H.assign(Ratio=None)
                    df_050_059_OV_VVS1_H  = df_050_059_OV_VVS1_H.assign(PPC=None)
                    df_050_059_OV_VVS1_H  = df_050_059_OV_VVS1_H.assign(Total=None)
                    df_050_059_OV_VVS1_H ['Wt Range'] = listwtrange
                    df_050_059_OV_VVS1_H ['Company'] = listcom
                    df_050_059_OV_VVS1_H ['Shape'] = listshap
                    df_050_059_OV_VVS1_H ['Carat'] = listcar
                    df_050_059_OV_VVS1_H ['Color'] = listcol
                    df_050_059_OV_VVS1_H ['Clarity'] = listclar
                    df_050_059_OV_VVS1_H ['Cut'] = listcut
                    df_050_059_OV_VVS1_H ['Polish'] = listpol
                    df_050_059_OV_VVS1_H ['Symmetry'] = listsym
                    df_050_059_OV_VVS1_H ['Ratio'] = listrat
                    df_050_059_OV_VVS1_H ['PPC'] = listdesc
                    df_050_059_OV_VVS1_H ['Total'] = listtotal
                    df_050_059_OV_VVS1_H['Carat'] = df_050_059_OV_VVS1_H['Carat'].astype('float64')
                    df_050_059_OV_VVS1_H['PPC'] = df_050_059_OV_VVS1_H['PPC'].astype('float64')
                    df_050_059_OV_VVS1_H['Total'] = df_050_059_OV_VVS1_H['Total'].astype('float64')
                    df_050_059_OV_VVS1_H['Total'] = df_050_059_OV_VVS1_H['Carat'] * df_050_059_OV_VVS1_H['PPC']


                elif i=="H" and j == "VVS2" and k == "OV":
                    df_050_059_OV_VVS2_H = pd.DataFrame()
                    df_050_059_OV_VVS2_H ['Wt Range'] = None
                    df_050_059_OV_VVS2_H  = df_050_059_OV_VVS2_H.assign(Company=None)
                    df_050_059_OV_VVS2_H  = df_050_059_OV_VVS2_H.assign(Shape=None)
                    df_050_059_OV_VVS2_H  = df_050_059_OV_VVS2_H.assign(Carat=None)
                    df_050_059_OV_VVS2_H  = df_050_059_OV_VVS2_H.assign(Color=None)
                    df_050_059_OV_VVS2_H  = df_050_059_OV_VVS2_H.assign(Clarity=None)
                    df_050_059_OV_VVS2_H  = df_050_059_OV_VVS2_H.assign(Cut=None)
                    df_050_059_OV_VVS2_H  = df_050_059_OV_VVS2_H.assign(Polish=None)
                    df_050_059_OV_VVS2_H  = df_050_059_OV_VVS2_H.assign(Symmetry=None)
                    df_050_059_OV_VVS2_H  = df_050_059_OV_VVS2_H.assign(Ratio=None)
                    df_050_059_OV_VVS2_H  = df_050_059_OV_VVS2_H.assign(PPC=None)
                    df_050_059_OV_VVS2_H  = df_050_059_OV_VVS2_H.assign(Total=None)
                    df_050_059_OV_VVS2_H ['Wt Range'] = listwtrange
                    df_050_059_OV_VVS2_H ['Company'] = listcom
                    df_050_059_OV_VVS2_H ['Shape'] = listshap
                    df_050_059_OV_VVS2_H ['Carat'] = listcar
                    df_050_059_OV_VVS2_H ['Color'] = listcol
                    df_050_059_OV_VVS2_H ['Clarity'] = listclar
                    df_050_059_OV_VVS2_H ['Cut'] = listcut
                    df_050_059_OV_VVS2_H ['Polish'] = listpol
                    df_050_059_OV_VVS2_H ['Symmetry'] = listsym
                    df_050_059_OV_VVS2_H ['Ratio'] = listrat
                    df_050_059_OV_VVS2_H ['PPC'] = listdesc
                    df_050_059_OV_VVS2_H ['Total'] = listtotal
                    df_050_059_OV_VVS2_H['Carat'] = df_050_059_OV_VVS2_H['Carat'].astype('float64')
                    df_050_059_OV_VVS2_H['PPC'] = df_050_059_OV_VVS2_H['PPC'].astype('float64')
                    df_050_059_OV_VVS2_H['Total'] = df_050_059_OV_VVS2_H['Total'].astype('float64')
                    df_050_059_OV_VVS2_H['Total'] = df_050_059_OV_VVS2_H['Carat'] * df_050_059_OV_VVS2_H['PPC']


                elif i=="H" and j=="VS1" and k == "OV":
                    df_050_059_OV_VS1_H = pd.DataFrame()
                    df_050_059_OV_VS1_H ['Wt Range'] = None
                    df_050_059_OV_VS1_H  = df_050_059_OV_VS1_H.assign(Company=None)
                    df_050_059_OV_VS1_H  = df_050_059_OV_VS1_H.assign(Shape=None)
                    df_050_059_OV_VS1_H  = df_050_059_OV_VS1_H.assign(Carat=None)
                    df_050_059_OV_VS1_H  = df_050_059_OV_VS1_H.assign(Color=None)
                    df_050_059_OV_VS1_H  = df_050_059_OV_VS1_H.assign(Clarity=None)
                    df_050_059_OV_VS1_H  = df_050_059_OV_VS1_H.assign(Cut=None)
                    df_050_059_OV_VS1_H  = df_050_059_OV_VS1_H.assign(Polish=None)
                    df_050_059_OV_VS1_H  = df_050_059_OV_VS1_H.assign(Symmetry=None)
                    df_050_059_OV_VS1_H  = df_050_059_OV_VS1_H.assign(Ratio=None)
                    df_050_059_OV_VS1_H  = df_050_059_OV_VS1_H.assign(PPC=None)
                    df_050_059_OV_VS1_H  = df_050_059_OV_VS1_H.assign(Total=None)
                    df_050_059_OV_VS1_H ['Wt Range'] = listwtrange
                    df_050_059_OV_VS1_H ['Company'] = listcom
                    df_050_059_OV_VS1_H ['Shape'] = listshap
                    df_050_059_OV_VS1_H ['Carat'] = listcar
                    df_050_059_OV_VS1_H ['Color'] = listcol
                    df_050_059_OV_VS1_H ['Clarity'] = listclar
                    df_050_059_OV_VS1_H ['Cut'] = listcut
                    df_050_059_OV_VS1_H ['Polish'] = listpol
                    df_050_059_OV_VS1_H ['Symmetry'] = listsym
                    df_050_059_OV_VS1_H ['Ratio'] = listrat
                    df_050_059_OV_VS1_H ['PPC'] = listdesc
                    df_050_059_OV_VS1_H ['Total'] = listtotal
                    df_050_059_OV_VS1_H['Carat'] = df_050_059_OV_VS1_H['Carat'].astype('float64')
                    df_050_059_OV_VS1_H['PPC'] = df_050_059_OV_VS1_H['PPC'].astype('float64')
                    df_050_059_OV_VS1_H['Total'] = df_050_059_OV_VS1_H['Total'].astype('float64')
                    df_050_059_OV_VS1_H['Total'] = df_050_059_OV_VS1_H['Carat'] * df_050_059_OV_VS1_H['PPC']


                elif i=="H" and j == "VS2" and k == "OV":
                    df_050_059_OV_VS2_H = pd.DataFrame()
                    df_050_059_OV_VS2_H ['Wt Range'] = None
                    df_050_059_OV_VS2_H  = df_050_059_OV_VS2_H.assign(Company=None)
                    df_050_059_OV_VS2_H  = df_050_059_OV_VS2_H.assign(Shape=None)
                    df_050_059_OV_VS2_H  = df_050_059_OV_VS2_H.assign(Carat=None)
                    df_050_059_OV_VS2_H  = df_050_059_OV_VS2_H.assign(Color=None)
                    df_050_059_OV_VS2_H  = df_050_059_OV_VS2_H.assign(Clarity=None)
                    df_050_059_OV_VS2_H  = df_050_059_OV_VS2_H.assign(Cut=None)
                    df_050_059_OV_VS2_H  = df_050_059_OV_VS2_H.assign(Polish=None)
                    df_050_059_OV_VS2_H  = df_050_059_OV_VS2_H.assign(Symmetry=None)
                    df_050_059_OV_VS2_H  = df_050_059_OV_VS2_H.assign(Ratio=None)
                    df_050_059_OV_VS2_H  = df_050_059_OV_VS2_H.assign(PPC=None)
                    df_050_059_OV_VS2_H  = df_050_059_OV_VS2_H.assign(Total=None)
                    df_050_059_OV_VS2_H ['Wt Range'] = listwtrange
                    df_050_059_OV_VS2_H ['Company'] = listcom
                    df_050_059_OV_VS2_H ['Shape'] = listshap
                    df_050_059_OV_VS2_H ['Carat'] = listcar
                    df_050_059_OV_VS2_H ['Color'] = listcol
                    df_050_059_OV_VS2_H ['Clarity'] = listclar
                    df_050_059_OV_VS2_H ['Cut'] = listcut
                    df_050_059_OV_VS2_H ['Polish'] = listpol
                    df_050_059_OV_VS2_H ['Symmetry'] = listsym
                    df_050_059_OV_VS2_H ['Ratio'] = listrat
                    df_050_059_OV_VS2_H ['PPC'] = listdesc
                    df_050_059_OV_VS2_H ['Total'] = listtotal
                    df_050_059_OV_VS2_H['Carat'] = df_050_059_OV_VS2_H['Carat'].astype('float64')
                    df_050_059_OV_VS2_H['PPC'] = df_050_059_OV_VS2_H['PPC'].astype('float64')
                    df_050_059_OV_VS2_H['Total'] = df_050_059_OV_VS2_H['Total'].astype('float64')
                    df_050_059_OV_VS2_H['Total'] = df_050_059_OV_VS2_H['Carat'] * df_050_059_OV_VS2_H['PPC']


                elif i=="H" and j == "SI1" and k == "OV":
                    df_050_059_OV_SI1_H = pd.DataFrame()
                    df_050_059_OV_SI1_H ['Wt Range'] = None
                    df_050_059_OV_SI1_H  = df_050_059_OV_SI1_H.assign(Company=None)
                    df_050_059_OV_SI1_H  = df_050_059_OV_SI1_H.assign(Shape=None)
                    df_050_059_OV_SI1_H  = df_050_059_OV_SI1_H.assign(Carat=None)
                    df_050_059_OV_SI1_H  = df_050_059_OV_SI1_H.assign(Color=None)
                    df_050_059_OV_SI1_H  = df_050_059_OV_SI1_H.assign(Clarity=None)
                    df_050_059_OV_SI1_H  = df_050_059_OV_SI1_H.assign(Cut=None)
                    df_050_059_OV_SI1_H  = df_050_059_OV_SI1_H.assign(Polish=None)
                    df_050_059_OV_SI1_H  = df_050_059_OV_SI1_H.assign(Symmetry=None)
                    df_050_059_OV_SI1_H  = df_050_059_OV_SI1_H.assign(Ratio=None)
                    df_050_059_OV_SI1_H  = df_050_059_OV_SI1_H.assign(PPC=None)
                    df_050_059_OV_SI1_H  = df_050_059_OV_SI1_H.assign(Total=None)
                    df_050_059_OV_SI1_H ['Wt Range'] = listwtrange
                    df_050_059_OV_SI1_H ['Company'] = listcom
                    df_050_059_OV_SI1_H ['Shape'] = listshap
                    df_050_059_OV_SI1_H ['Carat'] = listcar
                    df_050_059_OV_SI1_H ['Color'] = listcol
                    df_050_059_OV_SI1_H ['Clarity'] = listclar
                    df_050_059_OV_SI1_H ['Cut'] = listcut
                    df_050_059_OV_SI1_H ['Polish'] = listpol
                    df_050_059_OV_SI1_H ['Symmetry'] = listsym
                    df_050_059_OV_SI1_H ['Ratio'] = listrat
                    df_050_059_OV_SI1_H ['PPC'] = listdesc
                    df_050_059_OV_SI1_H ['Total'] = listtotal
                    df_050_059_OV_SI1_H['Carat'] = df_050_059_OV_SI1_H['Carat'].astype('float64')
                    df_050_059_OV_SI1_H['PPC'] = df_050_059_OV_SI1_H['PPC'].astype('float64')
                    df_050_059_OV_SI1_H['Total'] = df_050_059_OV_SI1_H['Total'].astype('float64')
                    df_050_059_OV_SI1_H['Total'] = df_050_059_OV_SI1_H['Carat'] * df_050_059_OV_SI1_H['PPC']


                elif i=="H" and j == "SI2" and k == "OV":
                    df_050_059_OV_SI2_H = pd.DataFrame()
                    df_050_059_OV_SI2_H ['Wt Range'] = None
                    df_050_059_OV_SI2_H  = df_050_059_OV_SI2_H.assign(Company=None)
                    df_050_059_OV_SI2_H  = df_050_059_OV_SI2_H.assign(Shape=None)
                    df_050_059_OV_SI2_H  = df_050_059_OV_SI2_H.assign(Carat=None)
                    df_050_059_OV_SI2_H  = df_050_059_OV_SI2_H.assign(Color=None)
                    df_050_059_OV_SI2_H  = df_050_059_OV_SI2_H.assign(Clarity=None)
                    df_050_059_OV_SI2_H  = df_050_059_OV_SI2_H.assign(Cut=None)
                    df_050_059_OV_SI2_H  = df_050_059_OV_SI2_H.assign(Polish=None)
                    df_050_059_OV_SI2_H  = df_050_059_OV_SI2_H.assign(Symmetry=None)
                    df_050_059_OV_SI2_H  = df_050_059_OV_SI2_H.assign(Ratio=None)
                    df_050_059_OV_SI2_H  = df_050_059_OV_SI2_H.assign(PPC=None)
                    df_050_059_OV_SI2_H  = df_050_059_OV_SI2_H.assign(Total=None)
                    df_050_059_OV_SI2_H ['Wt Range'] = listwtrange
                    df_050_059_OV_SI2_H ['Company'] = listcom
                    df_050_059_OV_SI2_H ['Shape'] = listshap
                    df_050_059_OV_SI2_H ['Carat'] = listcar
                    df_050_059_OV_SI2_H ['Color'] = listcol
                    df_050_059_OV_SI2_H ['Clarity'] = listclar
                    df_050_059_OV_SI2_H ['Cut'] = listcut
                    df_050_059_OV_SI2_H ['Polish'] = listpol
                    df_050_059_OV_SI2_H ['Symmetry'] = listsym
                    df_050_059_OV_SI2_H ['Ratio'] = listrat
                    df_050_059_OV_SI2_H ['PPC'] = listdesc
                    df_050_059_OV_SI2_H ['Total'] = listtotal
                    df_050_059_OV_SI2_H['Carat'] = df_050_059_OV_SI2_H['Carat'].astype('float64')
                    df_050_059_OV_SI2_H['PPC'] = df_050_059_OV_SI2_H['PPC'].astype('float64')
                    df_050_059_OV_SI2_H['Total'] = df_050_059_OV_SI2_H['Total'].astype('float64')
                    df_050_059_OV_SI2_H['Total'] = df_050_059_OV_SI2_H['Carat'] * df_050_059_OV_SI2_H['PPC']


                elif i=="H" and j == "I1" and k == "OV":
                    df_050_059_OV_I1_H = pd.DataFrame()
                    df_050_059_OV_I1_H ['Wt Range'] = None
                    df_050_059_OV_I1_H  = df_050_059_OV_I1_H.assign(Company=None)
                    df_050_059_OV_I1_H  = df_050_059_OV_I1_H.assign(Shape=None)
                    df_050_059_OV_I1_H  = df_050_059_OV_I1_H.assign(Carat=None)
                    df_050_059_OV_I1_H  = df_050_059_OV_I1_H.assign(Color=None)
                    df_050_059_OV_I1_H  = df_050_059_OV_I1_H.assign(Clarity=None)
                    df_050_059_OV_I1_H  = df_050_059_OV_I1_H.assign(Cut=None)
                    df_050_059_OV_I1_H  = df_050_059_OV_I1_H.assign(Polish=None)
                    df_050_059_OV_I1_H  = df_050_059_OV_I1_H.assign(Symmetry=None)
                    df_050_059_OV_I1_H  = df_050_059_OV_I1_H.assign(Ratio=None)
                    df_050_059_OV_I1_H  = df_050_059_OV_I1_H.assign(PPC=None)
                    df_050_059_OV_I1_H  = df_050_059_OV_I1_H.assign(Total=None)
                    df_050_059_OV_I1_H ['Wt Range'] = listwtrange
                    df_050_059_OV_I1_H ['Company'] = listcom
                    df_050_059_OV_I1_H ['Shape'] = listshap
                    df_050_059_OV_I1_H ['Carat'] = listcar
                    df_050_059_OV_I1_H ['Color'] = listcol
                    df_050_059_OV_I1_H ['Clarity'] = listclar
                    df_050_059_OV_I1_H ['Cut'] = listcut
                    df_050_059_OV_I1_H ['Polish'] = listpol
                    df_050_059_OV_I1_H ['Symmetry'] = listsym
                    df_050_059_OV_I1_H ['Ratio'] = listrat
                    df_050_059_OV_I1_H ['PPC'] = listdesc
                    df_050_059_OV_I1_H ['Total'] = listtotal
                    df_050_059_OV_I1_H['Carat'] = df_050_059_OV_I1_H['Carat'].astype('float64')
                    df_050_059_OV_I1_H['PPC'] = df_050_059_OV_I1_H['PPC'].astype('float64')
                    df_050_059_OV_I1_H['Total'] = df_050_059_OV_I1_H['Total'].astype('float64')
                    df_050_059_OV_I1_H['Total'] = df_050_059_OV_I1_H['Carat'] * df_050_059_OV_I1_H['PPC']


                elif i=="H" and j == "I2" and k == "OV":
                    df_050_059_OV_I2_H = pd.DataFrame()
                    df_050_059_OV_I2_H ['Wt Range'] = None
                    df_050_059_OV_I2_H  = df_050_059_OV_I2_H.assign(Company=None)
                    df_050_059_OV_I2_H  = df_050_059_OV_I2_H.assign(Shape=None)
                    df_050_059_OV_I2_H  = df_050_059_OV_I2_H.assign(Carat=None)
                    df_050_059_OV_I2_H  = df_050_059_OV_I2_H.assign(Color=None)
                    df_050_059_OV_I2_H  = df_050_059_OV_I2_H.assign(Clarity=None)
                    df_050_059_OV_I2_H  = df_050_059_OV_I2_H.assign(Cut=None)
                    df_050_059_OV_I2_H  = df_050_059_OV_I2_H.assign(Polish=None)
                    df_050_059_OV_I2_H  = df_050_059_OV_I2_H.assign(Symmetry=None)
                    df_050_059_OV_I2_H  = df_050_059_OV_I2_H.assign(Ratio=None)
                    df_050_059_OV_I2_H  = df_050_059_OV_I2_H.assign(PPC=None)
                    df_050_059_OV_I2_H  = df_050_059_OV_I2_H.assign(Total=None)
                    df_050_059_OV_I2_H ['Wt Range'] = listwtrange
                    df_050_059_OV_I2_H ['Company'] = listcom
                    df_050_059_OV_I2_H ['Shape'] = listshap
                    df_050_059_OV_I2_H ['Carat'] = listcar
                    df_050_059_OV_I2_H ['Color'] = listcol
                    df_050_059_OV_I2_H ['Clarity'] = listclar
                    df_050_059_OV_I2_H ['Cut'] = listcut
                    df_050_059_OV_I2_H ['Polish'] = listpol
                    df_050_059_OV_I2_H ['Symmetry'] = listsym
                    df_050_059_OV_I2_H ['Ratio'] = listrat
                    df_050_059_OV_I2_H ['PPC'] = listdesc
                    df_050_059_OV_I2_H ['Total'] = listtotal
                    df_050_059_OV_I2_H['Carat'] = df_050_059_OV_I2_H['Carat'].astype('float64')
                    df_050_059_OV_I2_H['PPC'] = df_050_059_OV_I2_H['PPC'].astype('float64')
                    df_050_059_OV_I2_H['Total'] = df_050_059_OV_I2_H['Total'].astype('float64')
                    df_050_059_OV_I2_H['Total'] = df_050_059_OV_I2_H['Carat'] * df_050_059_OV_I2_H['PPC']



                elif i== "I" and j == "IF" and k == "OV":
                    df_050_059_OV_IF_I = pd.DataFrame()
                    df_050_059_OV_IF_I ['Wt Range'] = None
                    df_050_059_OV_IF_I  = df_050_059_OV_IF_I.assign(Company=None)
                    df_050_059_OV_IF_I  = df_050_059_OV_IF_I.assign(Shape=None)
                    df_050_059_OV_IF_I  = df_050_059_OV_IF_I.assign(Carat=None)
                    df_050_059_OV_IF_I  = df_050_059_OV_IF_I.assign(Color=None)
                    df_050_059_OV_IF_I  = df_050_059_OV_IF_I.assign(Clarity=None)
                    df_050_059_OV_IF_I  = df_050_059_OV_IF_I.assign(Cut=None)
                    df_050_059_OV_IF_I  = df_050_059_OV_IF_I.assign(Polish=None)
                    df_050_059_OV_IF_I  = df_050_059_OV_IF_I.assign(Symmetry=None)
                    df_050_059_OV_IF_I  = df_050_059_OV_IF_I.assign(Ratio=None)
                    df_050_059_OV_IF_I  = df_050_059_OV_IF_I.assign(PPC=None)
                    df_050_059_OV_IF_I  = df_050_059_OV_IF_I.assign(Total=None)
                    df_050_059_OV_IF_I ['Wt Range'] = listwtrange
                    df_050_059_OV_IF_I ['Company'] = listcom
                    df_050_059_OV_IF_I ['Shape'] = listshap
                    df_050_059_OV_IF_I ['Carat'] = listcar
                    df_050_059_OV_IF_I ['Color'] = listcol
                    df_050_059_OV_IF_I ['Clarity'] = listclar
                    df_050_059_OV_IF_I ['Cut'] = listcut
                    df_050_059_OV_IF_I ['Polish'] = listpol
                    df_050_059_OV_IF_I ['Symmetry'] = listsym
                    df_050_059_OV_IF_I ['Ratio'] = listrat
                    df_050_059_OV_IF_I ['PPC'] = listdesc
                    df_050_059_OV_IF_I ['Total'] = listtotal
                    df_050_059_OV_IF_I['Carat'] = df_050_059_OV_IF_I['Carat'].astype('float64')
                    df_050_059_OV_IF_I['PPC'] = df_050_059_OV_IF_I['PPC'].astype('float64')
                    df_050_059_OV_IF_I['Total'] = df_050_059_OV_IF_I['Total'].astype('float64')
                    df_050_059_OV_IF_I['Total'] = df_050_059_OV_IF_I['Carat'] * df_050_059_OV_IF_I['PPC']



                elif i== "I" and j == "VVS1" and k == "OV":
                    df_050_059_OV_VVS1_I = pd.DataFrame()
                    df_050_059_OV_VVS1_I ['Wt Range'] = None
                    df_050_059_OV_VVS1_I  = df_050_059_OV_VVS1_I.assign(Company=None)
                    df_050_059_OV_VVS1_I  = df_050_059_OV_VVS1_I.assign(Shape=None)
                    df_050_059_OV_VVS1_I  = df_050_059_OV_VVS1_I.assign(Carat=None)
                    df_050_059_OV_VVS1_I  = df_050_059_OV_VVS1_I.assign(Color=None)
                    df_050_059_OV_VVS1_I  = df_050_059_OV_VVS1_I.assign(Clarity=None)
                    df_050_059_OV_VVS1_I  = df_050_059_OV_VVS1_I.assign(Cut=None)
                    df_050_059_OV_VVS1_I  = df_050_059_OV_VVS1_I.assign(Polish=None)
                    df_050_059_OV_VVS1_I  = df_050_059_OV_VVS1_I.assign(Symmetry=None)
                    df_050_059_OV_VVS1_I  = df_050_059_OV_VVS1_I.assign(Ratio=None)
                    df_050_059_OV_VVS1_I  = df_050_059_OV_VVS1_I.assign(PPC=None)
                    df_050_059_OV_VVS1_I  = df_050_059_OV_VVS1_I.assign(Total=None)
                    df_050_059_OV_VVS1_I ['Wt Range'] = listwtrange
                    df_050_059_OV_VVS1_I ['Company'] = listcom
                    df_050_059_OV_VVS1_I ['Shape'] = listshap
                    df_050_059_OV_VVS1_I ['Carat'] = listcar
                    df_050_059_OV_VVS1_I ['Color'] = listcol
                    df_050_059_OV_VVS1_I ['Clarity'] = listclar
                    df_050_059_OV_VVS1_I ['Cut'] = listcut
                    df_050_059_OV_VVS1_I ['Polish'] = listpol
                    df_050_059_OV_VVS1_I ['Symmetry'] = listsym
                    df_050_059_OV_VVS1_I ['Ratio'] = listrat
                    df_050_059_OV_VVS1_I ['PPC'] = listdesc
                    df_050_059_OV_VVS1_I ['Total'] = listtotal
                    df_050_059_OV_VVS1_I['Carat'] = df_050_059_OV_VVS1_I['Carat'].astype('float64')
                    df_050_059_OV_VVS1_I['PPC'] = df_050_059_OV_VVS1_I['PPC'].astype('float64')
                    df_050_059_OV_VVS1_I['Total'] = df_050_059_OV_VVS1_I['Total'].astype('float64')
                    df_050_059_OV_VVS1_I['Total'] = df_050_059_OV_VVS1_I['Carat'] * df_050_059_OV_VVS1_I['PPC']


                elif i== "I" and j == "VVS2" and k == "OV":
                    df_050_059_OV_VVS2_I = pd.DataFrame()
                    df_050_059_OV_VVS2_I ['Wt Range'] = None
                    df_050_059_OV_VVS2_I  = df_050_059_OV_VVS2_I.assign(Company=None)
                    df_050_059_OV_VVS2_I  = df_050_059_OV_VVS2_I.assign(Shape=None)
                    df_050_059_OV_VVS2_I  = df_050_059_OV_VVS2_I.assign(Carat=None)
                    df_050_059_OV_VVS2_I  = df_050_059_OV_VVS2_I.assign(Color=None)
                    df_050_059_OV_VVS2_I  = df_050_059_OV_VVS2_I.assign(Clarity=None)
                    df_050_059_OV_VVS2_I  = df_050_059_OV_VVS2_I.assign(Cut=None)
                    df_050_059_OV_VVS2_I  = df_050_059_OV_VVS2_I.assign(Polish=None)
                    df_050_059_OV_VVS2_I  = df_050_059_OV_VVS2_I.assign(Symmetry=None)
                    df_050_059_OV_VVS2_I  = df_050_059_OV_VVS2_I.assign(Ratio=None)
                    df_050_059_OV_VVS2_I  = df_050_059_OV_VVS2_I.assign(PPC=None)
                    df_050_059_OV_VVS2_I  = df_050_059_OV_VVS2_I.assign(Total=None)
                    df_050_059_OV_VVS2_I ['Wt Range'] = listwtrange
                    df_050_059_OV_VVS2_I ['Company'] = listcom
                    df_050_059_OV_VVS2_I ['Shape'] = listshap
                    df_050_059_OV_VVS2_I ['Carat'] = listcar
                    df_050_059_OV_VVS2_I ['Color'] = listcol
                    df_050_059_OV_VVS2_I ['Clarity'] = listclar
                    df_050_059_OV_VVS2_I ['Cut'] = listcut
                    df_050_059_OV_VVS2_I ['Polish'] = listpol
                    df_050_059_OV_VVS2_I ['Symmetry'] = listsym
                    df_050_059_OV_VVS2_I ['Ratio'] = listrat
                    df_050_059_OV_VVS2_I ['PPC'] = listdesc
                    df_050_059_OV_VVS2_I ['Total'] = listtotal
                    df_050_059_OV_VVS2_I['Carat'] = df_050_059_OV_VVS2_I['Carat'].astype('float64')
                    df_050_059_OV_VVS2_I['PPC'] = df_050_059_OV_VVS2_I['PPC'].astype('float64')
                    df_050_059_OV_VVS2_I['Total'] = df_050_059_OV_VVS2_I['Total'].astype('float64')
                    df_050_059_OV_VVS2_I['Total'] = df_050_059_OV_VVS2_I['Carat'] * df_050_059_OV_VVS2_I['PPC']


                elif i== "I" and j=="VS1" and k == "OV":
                    df_050_059_OV_VS1_I = pd.DataFrame()
                    df_050_059_OV_VS1_I ['Wt Range'] = None
                    df_050_059_OV_VS1_I  = df_050_059_OV_VS1_I.assign(Company=None)
                    df_050_059_OV_VS1_I  = df_050_059_OV_VS1_I.assign(Shape=None)
                    df_050_059_OV_VS1_I  = df_050_059_OV_VS1_I.assign(Carat=None)
                    df_050_059_OV_VS1_I  = df_050_059_OV_VS1_I.assign(Color=None)
                    df_050_059_OV_VS1_I  = df_050_059_OV_VS1_I.assign(Clarity=None)
                    df_050_059_OV_VS1_I  = df_050_059_OV_VS1_I.assign(Cut=None)
                    df_050_059_OV_VS1_I  = df_050_059_OV_VS1_I.assign(Polish=None)
                    df_050_059_OV_VS1_I  = df_050_059_OV_VS1_I.assign(Symmetry=None)
                    df_050_059_OV_VS1_I  = df_050_059_OV_VS1_I.assign(Ratio=None)
                    df_050_059_OV_VS1_I  = df_050_059_OV_VS1_I.assign(PPC=None)
                    df_050_059_OV_VS1_I  = df_050_059_OV_VS1_I.assign(Total=None)
                    df_050_059_OV_VS1_I ['Wt Range'] = listwtrange
                    df_050_059_OV_VS1_I ['Company'] = listcom
                    df_050_059_OV_VS1_I ['Shape'] = listshap
                    df_050_059_OV_VS1_I ['Carat'] = listcar
                    df_050_059_OV_VS1_I ['Color'] = listcol
                    df_050_059_OV_VS1_I ['Clarity'] = listclar
                    df_050_059_OV_VS1_I ['Cut'] = listcut
                    df_050_059_OV_VS1_I ['Polish'] = listpol
                    df_050_059_OV_VS1_I ['Symmetry'] = listsym
                    df_050_059_OV_VS1_I ['Ratio'] = listrat
                    df_050_059_OV_VS1_I ['PPC'] = listdesc
                    df_050_059_OV_VS1_I ['Total'] = listtotal
                    df_050_059_OV_VS1_I['Carat'] = df_050_059_OV_VS1_I['Carat'].astype('float64')
                    df_050_059_OV_VS1_I['PPC'] = df_050_059_OV_VS1_I['PPC'].astype('float64')
                    df_050_059_OV_VS1_I['Total'] = df_050_059_OV_VS1_I['Total'].astype('float64')
                    df_050_059_OV_VS1_I['Total'] = df_050_059_OV_VS1_I['Carat'] * df_050_059_OV_VS1_I['PPC']


                elif i== "I" and j == "VS2" and k == "OV":
                    df_050_059_OV_VS2_I = pd.DataFrame()
                    df_050_059_OV_VS2_I ['Wt Range'] = None
                    df_050_059_OV_VS2_I  = df_050_059_OV_VS2_I.assign(Company=None)
                    df_050_059_OV_VS2_I  = df_050_059_OV_VS2_I.assign(Shape=None)
                    df_050_059_OV_VS2_I  = df_050_059_OV_VS2_I.assign(Carat=None)
                    df_050_059_OV_VS2_I  = df_050_059_OV_VS2_I.assign(Color=None)
                    df_050_059_OV_VS2_I  = df_050_059_OV_VS2_I.assign(Clarity=None)
                    df_050_059_OV_VS2_I  = df_050_059_OV_VS2_I.assign(Cut=None)
                    df_050_059_OV_VS2_I  = df_050_059_OV_VS2_I.assign(Polish=None)
                    df_050_059_OV_VS2_I  = df_050_059_OV_VS2_I.assign(Symmetry=None)
                    df_050_059_OV_VS2_I  = df_050_059_OV_VS2_I.assign(Ratio=None)
                    df_050_059_OV_VS2_I  = df_050_059_OV_VS2_I.assign(PPC=None)
                    df_050_059_OV_VS2_I  = df_050_059_OV_VS2_I.assign(Total=None)
                    df_050_059_OV_VS2_I ['Wt Range'] = listwtrange
                    df_050_059_OV_VS2_I ['Company'] = listcom
                    df_050_059_OV_VS2_I ['Shape'] = listshap
                    df_050_059_OV_VS2_I ['Carat'] = listcar
                    df_050_059_OV_VS2_I ['Color'] = listcol
                    df_050_059_OV_VS2_I ['Clarity'] = listclar
                    df_050_059_OV_VS2_I ['Cut'] = listcut
                    df_050_059_OV_VS2_I ['Polish'] = listpol
                    df_050_059_OV_VS2_I ['Symmetry'] = listsym
                    df_050_059_OV_VS2_I ['Ratio'] = listrat
                    df_050_059_OV_VS2_I ['PPC'] = listdesc
                    df_050_059_OV_VS2_I ['Total'] = listtotal
                    df_050_059_OV_VS2_I['Carat'] = df_050_059_OV_VS2_I['Carat'].astype('float64')
                    df_050_059_OV_VS2_I['PPC'] = df_050_059_OV_VS2_I['PPC'].astype('float64')
                    df_050_059_OV_VS2_I['Total'] = df_050_059_OV_VS2_I['Total'].astype('float64')
                    df_050_059_OV_VS2_I['Total'] = df_050_059_OV_VS2_I['Carat'] * df_050_059_OV_VS2_I['PPC']


                elif i== "I" and j == "SI1" and k == "OV":
                    df_050_059_OV_SI1_I = pd.DataFrame()
                    df_050_059_OV_SI1_I ['Wt Range'] = None
                    df_050_059_OV_SI1_I  = df_050_059_OV_SI1_I.assign(Company=None)
                    df_050_059_OV_SI1_I  = df_050_059_OV_SI1_I.assign(Shape=None)
                    df_050_059_OV_SI1_I  = df_050_059_OV_SI1_I.assign(Carat=None)
                    df_050_059_OV_SI1_I  = df_050_059_OV_SI1_I.assign(Color=None)
                    df_050_059_OV_SI1_I  = df_050_059_OV_SI1_I.assign(Clarity=None)
                    df_050_059_OV_SI1_I  = df_050_059_OV_SI1_I.assign(Cut=None)
                    df_050_059_OV_SI1_I  = df_050_059_OV_SI1_I.assign(Polish=None)
                    df_050_059_OV_SI1_I  = df_050_059_OV_SI1_I.assign(Symmetry=None)
                    df_050_059_OV_SI1_I  = df_050_059_OV_SI1_I.assign(Ratio=None)
                    df_050_059_OV_SI1_I  = df_050_059_OV_SI1_I.assign(PPC=None)
                    df_050_059_OV_SI1_I  = df_050_059_OV_SI1_I.assign(Total=None)
                    df_050_059_OV_SI1_I ['Wt Range'] = listwtrange
                    df_050_059_OV_SI1_I ['Company'] = listcom
                    df_050_059_OV_SI1_I ['Shape'] = listshap
                    df_050_059_OV_SI1_I ['Carat'] = listcar
                    df_050_059_OV_SI1_I ['Color'] = listcol
                    df_050_059_OV_SI1_I ['Clarity'] = listclar
                    df_050_059_OV_SI1_I ['Cut'] = listcut
                    df_050_059_OV_SI1_I ['Polish'] = listpol
                    df_050_059_OV_SI1_I ['Symmetry'] = listsym
                    df_050_059_OV_SI1_I ['Ratio'] = listrat
                    df_050_059_OV_SI1_I ['PPC'] = listdesc
                    df_050_059_OV_SI1_I ['Total'] = listtotal
                    df_050_059_OV_SI1_I['Carat'] = df_050_059_OV_SI1_I['Carat'].astype('float64')
                    df_050_059_OV_SI1_I['PPC'] = df_050_059_OV_SI1_I['PPC'].astype('float64')
                    df_050_059_OV_SI1_I['Total'] = df_050_059_OV_SI1_I['Total'].astype('float64')
                    df_050_059_OV_SI1_I['Total'] = df_050_059_OV_SI1_I['Carat'] * df_050_059_OV_SI1_I['PPC']


                elif i== "I" and j == "SI2" and k == "OV":
                    df_050_059_OV_SI2_I = pd.DataFrame()
                    df_050_059_OV_SI2_I ['Wt Range'] = None
                    df_050_059_OV_SI2_I  = df_050_059_OV_SI2_I.assign(Company=None)
                    df_050_059_OV_SI2_I  = df_050_059_OV_SI2_I.assign(Shape=None)
                    df_050_059_OV_SI2_I  = df_050_059_OV_SI2_I.assign(Carat=None)
                    df_050_059_OV_SI2_I  = df_050_059_OV_SI2_I.assign(Color=None)
                    df_050_059_OV_SI2_I  = df_050_059_OV_SI2_I.assign(Clarity=None)
                    df_050_059_OV_SI2_I  = df_050_059_OV_SI2_I.assign(Cut=None)
                    df_050_059_OV_SI2_I  = df_050_059_OV_SI2_I.assign(Polish=None)
                    df_050_059_OV_SI2_I  = df_050_059_OV_SI2_I.assign(Symmetry=None)
                    df_050_059_OV_SI2_I  = df_050_059_OV_SI2_I.assign(Ratio=None)
                    df_050_059_OV_SI2_I  = df_050_059_OV_SI2_I.assign(PPC=None)
                    df_050_059_OV_SI2_I  = df_050_059_OV_SI2_I.assign(Total=None)
                    df_050_059_OV_SI2_I ['Wt Range'] = listwtrange
                    df_050_059_OV_SI2_I ['Company'] = listcom
                    df_050_059_OV_SI2_I ['Shape'] = listshap
                    df_050_059_OV_SI2_I ['Carat'] = listcar
                    df_050_059_OV_SI2_I ['Color'] = listcol
                    df_050_059_OV_SI2_I ['Clarity'] = listclar
                    df_050_059_OV_SI2_I ['Cut'] = listcut
                    df_050_059_OV_SI2_I ['Polish'] = listpol
                    df_050_059_OV_SI2_I ['Symmetry'] = listsym
                    df_050_059_OV_SI2_I ['Ratio'] = listrat
                    df_050_059_OV_SI2_I ['PPC'] = listdesc
                    df_050_059_OV_SI2_I ['Total'] = listtotal
                    df_050_059_OV_SI2_I['Carat'] = df_050_059_OV_SI2_I['Carat'].astype('float64')
                    df_050_059_OV_SI2_I['PPC'] = df_050_059_OV_SI2_I['PPC'].astype('float64')
                    df_050_059_OV_SI2_I['Total'] = df_050_059_OV_SI2_I['Total'].astype('float64')
                    df_050_059_OV_SI2_I['Total'] = df_050_059_OV_SI2_I['Carat'] * df_050_059_OV_SI2_I['PPC']


                elif i== "I" and j == "I1" and k == "OV":
                    df_050_059_OV_I1_I = pd.DataFrame()
                    df_050_059_OV_I1_I ['Wt Range'] = None
                    df_050_059_OV_I1_I  = df_050_059_OV_I1_I.assign(Company=None)
                    df_050_059_OV_I1_I  = df_050_059_OV_I1_I.assign(Shape=None)
                    df_050_059_OV_I1_I  = df_050_059_OV_I1_I.assign(Carat=None)
                    df_050_059_OV_I1_I  = df_050_059_OV_I1_I.assign(Color=None)
                    df_050_059_OV_I1_I  = df_050_059_OV_I1_I.assign(Clarity=None)
                    df_050_059_OV_I1_I  = df_050_059_OV_I1_I.assign(Cut=None)
                    df_050_059_OV_I1_I  = df_050_059_OV_I1_I.assign(Polish=None)
                    df_050_059_OV_I1_I  = df_050_059_OV_I1_I.assign(Symmetry=None)
                    df_050_059_OV_I1_I  = df_050_059_OV_I1_I.assign(Ratio=None)
                    df_050_059_OV_I1_I  = df_050_059_OV_I1_I.assign(PPC=None)
                    df_050_059_OV_I1_I  = df_050_059_OV_I1_I.assign(Total=None)
                    df_050_059_OV_I1_I ['Wt Range'] = listwtrange
                    df_050_059_OV_I1_I ['Company'] = listcom
                    df_050_059_OV_I1_I ['Shape'] = listshap
                    df_050_059_OV_I1_I ['Carat'] = listcar
                    df_050_059_OV_I1_I ['Color'] = listcol
                    df_050_059_OV_I1_I ['Clarity'] = listclar
                    df_050_059_OV_I1_I ['Cut'] = listcut
                    df_050_059_OV_I1_I ['Polish'] = listpol
                    df_050_059_OV_I1_I ['Symmetry'] = listsym
                    df_050_059_OV_I1_I ['Ratio'] = listrat
                    df_050_059_OV_I1_I ['PPC'] = listdesc
                    df_050_059_OV_I1_I ['Total'] = listtotal
                    df_050_059_OV_I1_I['Carat'] = df_050_059_OV_I1_I['Carat'].astype('float64')
                    df_050_059_OV_I1_I['PPC'] = df_050_059_OV_I1_I['PPC'].astype('float64')
                    df_050_059_OV_I1_I['Total'] = df_050_059_OV_I1_I['Total'].astype('float64')
                    df_050_059_OV_I1_I['Total'] = df_050_059_OV_I1_I['Carat'] * df_050_059_OV_I1_I['PPC']


                elif i== "I" and j == "I2" and k == "OV":
                    df_050_059_OV_I2_I = pd.DataFrame()
                    df_050_059_OV_I2_I ['Wt Range'] = None
                    df_050_059_OV_I2_I  = df_050_059_OV_I2_I.assign(Company=None)
                    df_050_059_OV_I2_I  = df_050_059_OV_I2_I.assign(Shape=None)
                    df_050_059_OV_I2_I  = df_050_059_OV_I2_I.assign(Carat=None)
                    df_050_059_OV_I2_I  = df_050_059_OV_I2_I.assign(Color=None)
                    df_050_059_OV_I2_I  = df_050_059_OV_I2_I.assign(Clarity=None)
                    df_050_059_OV_I2_I  = df_050_059_OV_I2_I.assign(Cut=None)
                    df_050_059_OV_I2_I  = df_050_059_OV_I2_I.assign(Polish=None)
                    df_050_059_OV_I2_I  = df_050_059_OV_I2_I.assign(Symmetry=None)
                    df_050_059_OV_I2_I  = df_050_059_OV_I2_I.assign(Ratio=None)
                    df_050_059_OV_I2_I  = df_050_059_OV_I2_I.assign(PPC=None)
                    df_050_059_OV_I2_I  = df_050_059_OV_I2_I.assign(Total=None)
                    df_050_059_OV_I2_I ['Wt Range'] = listwtrange
                    df_050_059_OV_I2_I ['Company'] = listcom
                    df_050_059_OV_I2_I ['Shape'] = listshap
                    df_050_059_OV_I2_I ['Carat'] = listcar
                    df_050_059_OV_I2_I ['Color'] = listcol
                    df_050_059_OV_I2_I ['Clarity'] = listclar
                    df_050_059_OV_I2_I ['Cut'] = listcut
                    df_050_059_OV_I2_I ['Polish'] = listpol
                    df_050_059_OV_I2_I ['Symmetry'] = listsym
                    df_050_059_OV_I2_I ['Ratio'] = listrat
                    df_050_059_OV_I2_I ['PPC'] = listdesc
                    df_050_059_OV_I2_I ['Total'] = listtotal
                    df_050_059_OV_I2_I['Carat'] = df_050_059_OV_I2_I['Carat'].astype('float64')
                    df_050_059_OV_I2_I['PPC'] = df_050_059_OV_I2_I['PPC'].astype('float64')
                    df_050_059_OV_I2_I['Total'] = df_050_059_OV_I2_I['Total'].astype('float64')
                    df_050_059_OV_I2_I['Total'] = df_050_059_OV_I2_I['Carat'] * df_050_059_OV_I2_I['PPC']


                elif i=="J" and j == "IF" and k == "OV":
                    df_050_059_OV_IF_J = pd.DataFrame()
                    df_050_059_OV_IF_J ['Wt Range'] = None
                    df_050_059_OV_IF_J  = df_050_059_OV_IF_J.assign(Company=None)
                    df_050_059_OV_IF_J  = df_050_059_OV_IF_J.assign(Shape=None)
                    df_050_059_OV_IF_J  = df_050_059_OV_IF_J.assign(Carat=None)
                    df_050_059_OV_IF_J  = df_050_059_OV_IF_J.assign(Color=None)
                    df_050_059_OV_IF_J  = df_050_059_OV_IF_J.assign(Clarity=None)
                    df_050_059_OV_IF_J  = df_050_059_OV_IF_J.assign(Cut=None)
                    df_050_059_OV_IF_J  = df_050_059_OV_IF_J.assign(Polish=None)
                    df_050_059_OV_IF_J  = df_050_059_OV_IF_J.assign(Symmetry=None)
                    df_050_059_OV_IF_J  = df_050_059_OV_IF_J.assign(Ratio=None)
                    df_050_059_OV_IF_J  = df_050_059_OV_IF_J.assign(PPC=None)
                    df_050_059_OV_IF_J  = df_050_059_OV_IF_J.assign(Total=None)
                    df_050_059_OV_IF_J ['Wt Range'] = listwtrange
                    df_050_059_OV_IF_J ['Company'] = listcom
                    df_050_059_OV_IF_J ['Shape'] = listshap
                    df_050_059_OV_IF_J ['Carat'] = listcar
                    df_050_059_OV_IF_J ['Color'] = listcol
                    df_050_059_OV_IF_J ['Clarity'] = listclar
                    df_050_059_OV_IF_J ['Cut'] = listcut
                    df_050_059_OV_IF_J ['Polish'] = listpol
                    df_050_059_OV_IF_J ['Symmetry'] = listsym
                    df_050_059_OV_IF_J ['Ratio'] = listrat
                    df_050_059_OV_IF_J ['PPC'] = listdesc
                    df_050_059_OV_IF_J ['Total'] = listtotal
                    df_050_059_OV_IF_J['Carat'] = df_050_059_OV_IF_J['Carat'].astype('float64')
                    df_050_059_OV_IF_J['PPC'] = df_050_059_OV_IF_J['PPC'].astype('float64')
                    df_050_059_OV_IF_J['Total'] = df_050_059_OV_IF_J['Total'].astype('float64')
                    df_050_059_OV_IF_J['Total'] = df_050_059_OV_IF_J['Carat'] * df_050_059_OV_IF_J['PPC']



                elif i=="J"  and j == "VVS1" and k == "OV":
                    df_050_059_OV_VVS1_J = pd.DataFrame()
                    df_050_059_OV_VVS1_J ['Wt Range'] = None
                    df_050_059_OV_VVS1_J  = df_050_059_OV_VVS1_J.assign(Company=None)
                    df_050_059_OV_VVS1_J  = df_050_059_OV_VVS1_J.assign(Shape=None)
                    df_050_059_OV_VVS1_J  = df_050_059_OV_VVS1_J.assign(Carat=None)
                    df_050_059_OV_VVS1_J  = df_050_059_OV_VVS1_J.assign(Color=None)
                    df_050_059_OV_VVS1_J  = df_050_059_OV_VVS1_J.assign(Clarity=None)
                    df_050_059_OV_VVS1_J  = df_050_059_OV_VVS1_J.assign(Cut=None)
                    df_050_059_OV_VVS1_J  = df_050_059_OV_VVS1_J.assign(Polish=None)
                    df_050_059_OV_VVS1_J  = df_050_059_OV_VVS1_J.assign(Symmetry=None)
                    df_050_059_OV_VVS1_J  = df_050_059_OV_VVS1_J.assign(Ratio=None)
                    df_050_059_OV_VVS1_J  = df_050_059_OV_VVS1_J.assign(PPC=None)
                    df_050_059_OV_VVS1_J  = df_050_059_OV_VVS1_J.assign(Total=None)
                    df_050_059_OV_VVS1_J ['Wt Range'] = listwtrange
                    df_050_059_OV_VVS1_J ['Company'] = listcom
                    df_050_059_OV_VVS1_J ['Shape'] = listshap
                    df_050_059_OV_VVS1_J ['Carat'] = listcar
                    df_050_059_OV_VVS1_J ['Color'] = listcol
                    df_050_059_OV_VVS1_J ['Clarity'] = listclar
                    df_050_059_OV_VVS1_J ['Cut'] = listcut
                    df_050_059_OV_VVS1_J ['Polish'] = listpol
                    df_050_059_OV_VVS1_J ['Symmetry'] = listsym
                    df_050_059_OV_VVS1_J ['Ratio'] = listrat
                    df_050_059_OV_VVS1_J ['PPC'] = listdesc
                    df_050_059_OV_VVS1_J ['Total'] = listtotal
                    df_050_059_OV_VVS1_J['Carat'] = df_050_059_OV_VVS1_J['Carat'].astype('float64')
                    df_050_059_OV_VVS1_J['PPC'] = df_050_059_OV_VVS1_J['PPC'].astype('float64')
                    df_050_059_OV_VVS1_J['Total'] = df_050_059_OV_VVS1_J['Total'].astype('float64')
                    df_050_059_OV_VVS1_J['Total'] = df_050_059_OV_VVS1_J['Carat'] * df_050_059_OV_VVS1_J['PPC']


                elif i=="J"  and j == "VVS2" and k == "OV":
                    df_050_059_OV_VVS2_J = pd.DataFrame()
                    df_050_059_OV_VVS2_J ['Wt Range'] = None
                    df_050_059_OV_VVS2_J  = df_050_059_OV_VVS2_J.assign(Company=None)
                    df_050_059_OV_VVS2_J  = df_050_059_OV_VVS2_J.assign(Shape=None)
                    df_050_059_OV_VVS2_J  = df_050_059_OV_VVS2_J.assign(Carat=None)
                    df_050_059_OV_VVS2_J  = df_050_059_OV_VVS2_J.assign(Color=None)
                    df_050_059_OV_VVS2_J  = df_050_059_OV_VVS2_J.assign(Clarity=None)
                    df_050_059_OV_VVS2_J  = df_050_059_OV_VVS2_J.assign(Cut=None)
                    df_050_059_OV_VVS2_J  = df_050_059_OV_VVS2_J.assign(Polish=None)
                    df_050_059_OV_VVS2_J  = df_050_059_OV_VVS2_J.assign(Symmetry=None)
                    df_050_059_OV_VVS2_J  = df_050_059_OV_VVS2_J.assign(Ratio=None)
                    df_050_059_OV_VVS2_J  = df_050_059_OV_VVS2_J.assign(PPC=None)
                    df_050_059_OV_VVS2_J  = df_050_059_OV_VVS2_J.assign(Total=None)
                    df_050_059_OV_VVS2_J ['Wt Range'] = listwtrange
                    df_050_059_OV_VVS2_J ['Company'] = listcom
                    df_050_059_OV_VVS2_J ['Shape'] = listshap
                    df_050_059_OV_VVS2_J ['Carat'] = listcar
                    df_050_059_OV_VVS2_J ['Color'] = listcol
                    df_050_059_OV_VVS2_J ['Clarity'] = listclar
                    df_050_059_OV_VVS2_J ['Cut'] = listcut
                    df_050_059_OV_VVS2_J ['Polish'] = listpol
                    df_050_059_OV_VVS2_J ['Symmetry'] = listsym
                    df_050_059_OV_VVS2_J ['Ratio'] = listrat
                    df_050_059_OV_VVS2_J ['PPC'] = listdesc
                    df_050_059_OV_VVS2_J ['Total'] = listtotal
                    df_050_059_OV_VVS2_J['Carat'] = df_050_059_OV_VVS2_J['Carat'].astype('float64')
                    df_050_059_OV_VVS2_J['PPC'] = df_050_059_OV_VVS2_J['PPC'].astype('float64')
                    df_050_059_OV_VVS2_J['Total'] = df_050_059_OV_VVS2_J['Total'].astype('float64')
                    df_050_059_OV_VVS2_J['Total'] = df_050_059_OV_VVS2_J['Carat'] * df_050_059_OV_VVS2_J['PPC']


                elif i=="J"  and j=="VS1" and k == "OV":
                    df_050_059_OV_VS1_J = pd.DataFrame()
                    df_050_059_OV_VS1_J ['Wt Range'] = None
                    df_050_059_OV_VS1_J  = df_050_059_OV_VS1_J.assign(Company=None)
                    df_050_059_OV_VS1_J  = df_050_059_OV_VS1_J.assign(Shape=None)
                    df_050_059_OV_VS1_J  = df_050_059_OV_VS1_J.assign(Carat=None)
                    df_050_059_OV_VS1_J  = df_050_059_OV_VS1_J.assign(Color=None)
                    df_050_059_OV_VS1_J  = df_050_059_OV_VS1_J.assign(Clarity=None)
                    df_050_059_OV_VS1_J  = df_050_059_OV_VS1_J.assign(Cut=None)
                    df_050_059_OV_VS1_J  = df_050_059_OV_VS1_J.assign(Polish=None)
                    df_050_059_OV_VS1_J  = df_050_059_OV_VS1_J.assign(Symmetry=None)
                    df_050_059_OV_VS1_J  = df_050_059_OV_VS1_J.assign(Ratio=None)
                    df_050_059_OV_VS1_J  = df_050_059_OV_VS1_J.assign(PPC=None)
                    df_050_059_OV_VS1_J  = df_050_059_OV_VS1_J.assign(Total=None)
                    df_050_059_OV_VS1_J ['Wt Range'] = listwtrange
                    df_050_059_OV_VS1_J ['Company'] = listcom
                    df_050_059_OV_VS1_J ['Shape'] = listshap
                    df_050_059_OV_VS1_J ['Carat'] = listcar
                    df_050_059_OV_VS1_J ['Color'] = listcol
                    df_050_059_OV_VS1_J ['Clarity'] = listclar
                    df_050_059_OV_VS1_J ['Cut'] = listcut
                    df_050_059_OV_VS1_J ['Polish'] = listpol
                    df_050_059_OV_VS1_J ['Symmetry'] = listsym
                    df_050_059_OV_VS1_J ['Ratio'] = listrat
                    df_050_059_OV_VS1_J ['PPC'] = listdesc
                    df_050_059_OV_VS1_J ['Total'] = listtotal
                    df_050_059_OV_VS1_J['Carat'] = df_050_059_OV_VS1_J['Carat'].astype('float64')
                    df_050_059_OV_VS1_J['PPC'] = df_050_059_OV_VS1_J['PPC'].astype('float64')
                    df_050_059_OV_VS1_J['Total'] = df_050_059_OV_VS1_J['Total'].astype('float64')
                    df_050_059_OV_VS1_J['Total'] = df_050_059_OV_VS1_J['Carat'] * df_050_059_OV_VS1_J['PPC']


                elif i=="J"  and j == "VS2" and k == "OV":
                    df_050_059_OV_VS2_J = pd.DataFrame()
                    df_050_059_OV_VS2_J ['Wt Range'] = None
                    df_050_059_OV_VS2_J  = df_050_059_OV_VS2_J.assign(Company=None)
                    df_050_059_OV_VS2_J  = df_050_059_OV_VS2_J.assign(Shape=None)
                    df_050_059_OV_VS2_J  = df_050_059_OV_VS2_J.assign(Carat=None)
                    df_050_059_OV_VS2_J  = df_050_059_OV_VS2_J.assign(Color=None)
                    df_050_059_OV_VS2_J  = df_050_059_OV_VS2_J.assign(Clarity=None)
                    df_050_059_OV_VS2_J  = df_050_059_OV_VS2_J.assign(Cut=None)
                    df_050_059_OV_VS2_J  = df_050_059_OV_VS2_J.assign(Polish=None)
                    df_050_059_OV_VS2_J  = df_050_059_OV_VS2_J.assign(Symmetry=None)
                    df_050_059_OV_VS2_J  = df_050_059_OV_VS2_J.assign(Ratio=None)
                    df_050_059_OV_VS2_J  = df_050_059_OV_VS2_J.assign(PPC=None)
                    df_050_059_OV_VS2_J  = df_050_059_OV_VS2_J.assign(Total=None)
                    df_050_059_OV_VS2_J ['Wt Range'] = listwtrange
                    df_050_059_OV_VS2_J ['Company'] = listcom
                    df_050_059_OV_VS2_J ['Shape'] = listshap
                    df_050_059_OV_VS2_J ['Carat'] = listcar
                    df_050_059_OV_VS2_J ['Color'] = listcol
                    df_050_059_OV_VS2_J ['Clarity'] = listclar
                    df_050_059_OV_VS2_J ['Cut'] = listcut
                    df_050_059_OV_VS2_J ['Polish'] = listpol
                    df_050_059_OV_VS2_J ['Symmetry'] = listsym
                    df_050_059_OV_VS2_J ['Ratio'] = listrat
                    df_050_059_OV_VS2_J ['PPC'] = listdesc
                    df_050_059_OV_VS2_J ['Total'] = listtotal
                    df_050_059_OV_VS2_J['Carat'] = df_050_059_OV_VS2_J['Carat'].astype('float64')
                    df_050_059_OV_VS2_J['PPC'] = df_050_059_OV_VS2_J['PPC'].astype('float64')
                    df_050_059_OV_VS2_J['Total'] = df_050_059_OV_VS2_J['Total'].astype('float64')
                    df_050_059_OV_VS2_J['Total'] = df_050_059_OV_VS2_J['Carat'] * df_050_059_OV_VS2_J['PPC']


                elif i=="J"  and j == "SI1" and k == "OV":
                    df_050_059_OV_SI1_J = pd.DataFrame()
                    df_050_059_OV_SI1_J ['Wt Range'] = None
                    df_050_059_OV_SI1_J  = df_050_059_OV_SI1_J.assign(Company=None)
                    df_050_059_OV_SI1_J  = df_050_059_OV_SI1_J.assign(Shape=None)
                    df_050_059_OV_SI1_J  = df_050_059_OV_SI1_J.assign(Carat=None)
                    df_050_059_OV_SI1_J  = df_050_059_OV_SI1_J.assign(Color=None)
                    df_050_059_OV_SI1_J  = df_050_059_OV_SI1_J.assign(Clarity=None)
                    df_050_059_OV_SI1_J  = df_050_059_OV_SI1_J.assign(Cut=None)
                    df_050_059_OV_SI1_J  = df_050_059_OV_SI1_J.assign(Polish=None)
                    df_050_059_OV_SI1_J  = df_050_059_OV_SI1_J.assign(Symmetry=None)
                    df_050_059_OV_SI1_J  = df_050_059_OV_SI1_J.assign(Ratio=None)
                    df_050_059_OV_SI1_J  = df_050_059_OV_SI1_J.assign(PPC=None)
                    df_050_059_OV_SI1_J  = df_050_059_OV_SI1_J.assign(Total=None)
                    df_050_059_OV_SI1_J ['Wt Range'] = listwtrange
                    df_050_059_OV_SI1_J ['Company'] = listcom
                    df_050_059_OV_SI1_J ['Shape'] = listshap
                    df_050_059_OV_SI1_J ['Carat'] = listcar
                    df_050_059_OV_SI1_J ['Color'] = listcol
                    df_050_059_OV_SI1_J ['Clarity'] = listclar
                    df_050_059_OV_SI1_J ['Cut'] = listcut
                    df_050_059_OV_SI1_J ['Polish'] = listpol
                    df_050_059_OV_SI1_J ['Symmetry'] = listsym
                    df_050_059_OV_SI1_J ['Ratio'] = listrat
                    df_050_059_OV_SI1_J ['PPC'] = listdesc
                    df_050_059_OV_SI1_J ['Total'] = listtotal
                    df_050_059_OV_SI1_J['Carat'] = df_050_059_OV_SI1_J['Carat'].astype('float64')
                    df_050_059_OV_SI1_J['PPC'] = df_050_059_OV_SI1_J['PPC'].astype('float64')
                    df_050_059_OV_SI1_J['Total'] = df_050_059_OV_SI1_J['Total'].astype('float64')
                    df_050_059_OV_SI1_J['Total'] = df_050_059_OV_SI1_J['Carat'] * df_050_059_OV_SI1_J['PPC']


                elif i=="J"  and j == "SI2" and k == "OV":
                    df_050_059_OV_SI2_J = pd.DataFrame()
                    df_050_059_OV_SI2_J ['Wt Range'] = None
                    df_050_059_OV_SI2_J  = df_050_059_OV_SI2_J.assign(Company=None)
                    df_050_059_OV_SI2_J  = df_050_059_OV_SI2_J.assign(Shape=None)
                    df_050_059_OV_SI2_J  = df_050_059_OV_SI2_J.assign(Carat=None)
                    df_050_059_OV_SI2_J  = df_050_059_OV_SI2_J.assign(Color=None)
                    df_050_059_OV_SI2_J  = df_050_059_OV_SI2_J.assign(Clarity=None)
                    df_050_059_OV_SI2_J  = df_050_059_OV_SI2_J.assign(Cut=None)
                    df_050_059_OV_SI2_J  = df_050_059_OV_SI2_J.assign(Polish=None)
                    df_050_059_OV_SI2_J  = df_050_059_OV_SI2_J.assign(Symmetry=None)
                    df_050_059_OV_SI2_J  = df_050_059_OV_SI2_J.assign(Ratio=None)
                    df_050_059_OV_SI2_J  = df_050_059_OV_SI2_J.assign(PPC=None)
                    df_050_059_OV_SI2_J  = df_050_059_OV_SI2_J.assign(Total=None)
                    df_050_059_OV_SI2_J ['Wt Range'] = listwtrange
                    df_050_059_OV_SI2_J ['Company'] = listcom
                    df_050_059_OV_SI2_J ['Shape'] = listshap
                    df_050_059_OV_SI2_J ['Carat'] = listcar
                    df_050_059_OV_SI2_J ['Color'] = listcol
                    df_050_059_OV_SI2_J ['Clarity'] = listclar
                    df_050_059_OV_SI2_J ['Cut'] = listcut
                    df_050_059_OV_SI2_J ['Polish'] = listpol
                    df_050_059_OV_SI2_J ['Symmetry'] = listsym
                    df_050_059_OV_SI2_J ['Ratio'] = listrat
                    df_050_059_OV_SI2_J ['PPC'] = listdesc
                    df_050_059_OV_SI2_J ['Total'] = listtotal
                    df_050_059_OV_SI2_J['Carat'] = df_050_059_OV_SI2_J['Carat'].astype('float64')
                    df_050_059_OV_SI2_J['PPC'] = df_050_059_OV_SI2_J['PPC'].astype('float64')
                    df_050_059_OV_SI2_J['Total'] = df_050_059_OV_SI2_J['Total'].astype('float64')
                    df_050_059_OV_SI2_J['Total'] = df_050_059_OV_SI2_J['Carat'] * df_050_059_OV_SI2_J['PPC']


                elif i=="J"  and j == "I1" and k == "OV":
                    df_050_059_OV_I1_J = pd.DataFrame()
                    df_050_059_OV_I1_J ['Wt Range'] = None
                    df_050_059_OV_I1_J  = df_050_059_OV_I1_J.assign(Company=None)
                    df_050_059_OV_I1_J  = df_050_059_OV_I1_J.assign(Shape=None)
                    df_050_059_OV_I1_J  = df_050_059_OV_I1_J.assign(Carat=None)
                    df_050_059_OV_I1_J  = df_050_059_OV_I1_J.assign(Color=None)
                    df_050_059_OV_I1_J  = df_050_059_OV_I1_J.assign(Clarity=None)
                    df_050_059_OV_I1_J  = df_050_059_OV_I1_J.assign(Cut=None)
                    df_050_059_OV_I1_J  = df_050_059_OV_I1_J.assign(Polish=None)
                    df_050_059_OV_I1_J  = df_050_059_OV_I1_J.assign(Symmetry=None)
                    df_050_059_OV_I1_J  = df_050_059_OV_I1_J.assign(Ratio=None)
                    df_050_059_OV_I1_J  = df_050_059_OV_I1_J.assign(PPC=None)
                    df_050_059_OV_I1_J  = df_050_059_OV_I1_J.assign(Total=None)
                    df_050_059_OV_I1_J ['Wt Range'] = listwtrange
                    df_050_059_OV_I1_J ['Company'] = listcom
                    df_050_059_OV_I1_J ['Shape'] = listshap
                    df_050_059_OV_I1_J ['Carat'] = listcar
                    df_050_059_OV_I1_J ['Color'] = listcol
                    df_050_059_OV_I1_J ['Clarity'] = listclar
                    df_050_059_OV_I1_J ['Cut'] = listcut
                    df_050_059_OV_I1_J ['Polish'] = listpol
                    df_050_059_OV_I1_J ['Symmetry'] = listsym
                    df_050_059_OV_I1_J ['Ratio'] = listrat
                    df_050_059_OV_I1_J ['PPC'] = listdesc
                    df_050_059_OV_I1_J ['Total'] = listtotal
                    df_050_059_OV_I1_J['Carat'] = df_050_059_OV_I1_J['Carat'].astype('float64')
                    df_050_059_OV_I1_J['PPC'] = df_050_059_OV_I1_J['PPC'].astype('float64')
                    df_050_059_OV_I1_J['Total'] = df_050_059_OV_I1_J['Total'].astype('float64')
                    df_050_059_OV_I1_J['Total'] = df_050_059_OV_I1_J['Carat'] * df_050_059_OV_I1_J['PPC']


                elif i=="J"  and j == "I2" and k == "OV":
                    df_050_059_OV_I2_J = pd.DataFrame()
                    df_050_059_OV_I2_J ['Wt Range'] = None
                    df_050_059_OV_I2_J  = df_050_059_OV_I2_J.assign(Company=None)
                    df_050_059_OV_I2_J  = df_050_059_OV_I2_J.assign(Shape=None)
                    df_050_059_OV_I2_J  = df_050_059_OV_I2_J.assign(Carat=None)
                    df_050_059_OV_I2_J  = df_050_059_OV_I2_J.assign(Color=None)
                    df_050_059_OV_I2_J  = df_050_059_OV_I2_J.assign(Clarity=None)
                    df_050_059_OV_I2_J  = df_050_059_OV_I2_J.assign(Cut=None)
                    df_050_059_OV_I2_J  = df_050_059_OV_I2_J.assign(Polish=None)
                    df_050_059_OV_I2_J  = df_050_059_OV_I2_J.assign(Symmetry=None)
                    df_050_059_OV_I2_J  = df_050_059_OV_I2_J.assign(Ratio=None)
                    df_050_059_OV_I2_J  = df_050_059_OV_I2_J.assign(PPC=None)
                    df_050_059_OV_I2_J  = df_050_059_OV_I2_J.assign(Total=None)
                    df_050_059_OV_I2_J ['Wt Range'] = listwtrange
                    df_050_059_OV_I2_J ['Company'] = listcom
                    df_050_059_OV_I2_J ['Shape'] = listshap
                    df_050_059_OV_I2_J ['Carat'] = listcar
                    df_050_059_OV_I2_J ['Color'] = listcol
                    df_050_059_OV_I2_J ['Clarity'] = listclar
                    df_050_059_OV_I2_J ['Cut'] = listcut
                    df_050_059_OV_I2_J ['Polish'] = listpol
                    df_050_059_OV_I2_J ['Symmetry'] = listsym
                    df_050_059_OV_I2_J ['Ratio'] = listrat
                    df_050_059_OV_I2_J ['PPC'] = listdesc
                    df_050_059_OV_I2_J ['Total'] = listtotal
                    df_050_059_OV_I2_J['Carat'] = df_050_059_OV_I2_J['Carat'].astype('float64')
                    df_050_059_OV_I2_J['PPC'] = df_050_059_OV_I2_J['PPC'].astype('float64')
                    df_050_059_OV_I2_J['Total'] = df_050_059_OV_I2_J['Total'].astype('float64')
                    df_050_059_OV_I2_J['Total'] = df_050_059_OV_I2_J['Carat'] * df_050_059_OV_I2_J['PPC']


                elif i=="K" and j == "IF" and k == "OV":
                    df_050_059_OV_IF_K = pd.DataFrame()
                    df_050_059_OV_IF_K ['Wt Range'] = None
                    df_050_059_OV_IF_K  = df_050_059_OV_IF_K.assign(Company=None)
                    df_050_059_OV_IF_K  = df_050_059_OV_IF_K.assign(Shape=None)
                    df_050_059_OV_IF_K  = df_050_059_OV_IF_K.assign(Carat=None)
                    df_050_059_OV_IF_K  = df_050_059_OV_IF_K.assign(Color=None)
                    df_050_059_OV_IF_K  = df_050_059_OV_IF_K.assign(Clarity=None)
                    df_050_059_OV_IF_K  = df_050_059_OV_IF_K.assign(Cut=None)
                    df_050_059_OV_IF_K  = df_050_059_OV_IF_K.assign(Polish=None)
                    df_050_059_OV_IF_K  = df_050_059_OV_IF_K.assign(Symmetry=None)
                    df_050_059_OV_IF_K  = df_050_059_OV_IF_K.assign(Ratio=None)
                    df_050_059_OV_IF_K  = df_050_059_OV_IF_K.assign(PPC=None)
                    df_050_059_OV_IF_K  = df_050_059_OV_IF_K.assign(Total=None)
                    df_050_059_OV_IF_K ['Wt Range'] = listwtrange
                    df_050_059_OV_IF_K ['Company'] = listcom
                    df_050_059_OV_IF_K ['Shape'] = listshap
                    df_050_059_OV_IF_K ['Carat'] = listcar
                    df_050_059_OV_IF_K ['Color'] = listcol
                    df_050_059_OV_IF_K ['Clarity'] = listclar
                    df_050_059_OV_IF_K ['Cut'] = listcut
                    df_050_059_OV_IF_K ['Polish'] = listpol
                    df_050_059_OV_IF_K ['Symmetry'] = listsym
                    df_050_059_OV_IF_K ['Ratio'] = listrat
                    df_050_059_OV_IF_K ['PPC'] = listdesc
                    df_050_059_OV_IF_K ['Total'] = listtotal
                    df_050_059_OV_IF_K['Carat'] = df_050_059_OV_IF_K['Carat'].astype('float64')
                    df_050_059_OV_IF_K['PPC'] = df_050_059_OV_IF_K['PPC'].astype('float64')
                    df_050_059_OV_IF_K['Total'] = df_050_059_OV_IF_K['Total'].astype('float64')
                    df_050_059_OV_IF_K['Total'] = df_050_059_OV_IF_K['Carat'] * df_050_059_OV_IF_K['PPC']



                elif i=="K" and j == "VVS1" and k == "OV":
                    df_050_059_OV_VVS1_K = pd.DataFrame()
                    df_050_059_OV_VVS1_K ['Wt Range'] = None
                    df_050_059_OV_VVS1_K  = df_050_059_OV_VVS1_K.assign(Company=None)
                    df_050_059_OV_VVS1_K  = df_050_059_OV_VVS1_K.assign(Shape=None)
                    df_050_059_OV_VVS1_K  = df_050_059_OV_VVS1_K.assign(Carat=None)
                    df_050_059_OV_VVS1_K  = df_050_059_OV_VVS1_K.assign(Color=None)
                    df_050_059_OV_VVS1_K  = df_050_059_OV_VVS1_K.assign(Clarity=None)
                    df_050_059_OV_VVS1_K  = df_050_059_OV_VVS1_K.assign(Cut=None)
                    df_050_059_OV_VVS1_K  = df_050_059_OV_VVS1_K.assign(Polish=None)
                    df_050_059_OV_VVS1_K  = df_050_059_OV_VVS1_K.assign(Symmetry=None)
                    df_050_059_OV_VVS1_K  = df_050_059_OV_VVS1_K.assign(Ratio=None)
                    df_050_059_OV_VVS1_K  = df_050_059_OV_VVS1_K.assign(PPC=None)
                    df_050_059_OV_VVS1_K  = df_050_059_OV_VVS1_K.assign(Total=None)
                    df_050_059_OV_VVS1_K ['Wt Range'] = listwtrange
                    df_050_059_OV_VVS1_K ['Company'] = listcom
                    df_050_059_OV_VVS1_K ['Shape'] = listshap
                    df_050_059_OV_VVS1_K ['Carat'] = listcar
                    df_050_059_OV_VVS1_K ['Color'] = listcol
                    df_050_059_OV_VVS1_K ['Clarity'] = listclar
                    df_050_059_OV_VVS1_K ['Cut'] = listcut
                    df_050_059_OV_VVS1_K ['Polish'] = listpol
                    df_050_059_OV_VVS1_K ['Symmetry'] = listsym
                    df_050_059_OV_VVS1_K ['Ratio'] = listrat
                    df_050_059_OV_VVS1_K ['PPC'] = listdesc
                    df_050_059_OV_VVS1_K ['Total'] = listtotal
                    df_050_059_OV_VVS1_K['Carat'] = df_050_059_OV_VVS1_K['Carat'].astype('float64')
                    df_050_059_OV_VVS1_K['PPC'] = df_050_059_OV_VVS1_K['PPC'].astype('float64')
                    df_050_059_OV_VVS1_K['Total'] = df_050_059_OV_VVS1_K['Total'].astype('float64')
                    df_050_059_OV_VVS1_K['Total'] = df_050_059_OV_VVS1_K['Carat'] * df_050_059_OV_VVS1_K['PPC']


                elif i=="K" and j == "VVS2" and k == "OV":
                    df_050_059_OV_VVS2_K = pd.DataFrame()
                    df_050_059_OV_VVS2_K ['Wt Range'] = None
                    df_050_059_OV_VVS2_K  = df_050_059_OV_VVS2_K.assign(Company=None)
                    df_050_059_OV_VVS2_K  = df_050_059_OV_VVS2_K.assign(Shape=None)
                    df_050_059_OV_VVS2_K  = df_050_059_OV_VVS2_K.assign(Carat=None)
                    df_050_059_OV_VVS2_K  = df_050_059_OV_VVS2_K.assign(Color=None)
                    df_050_059_OV_VVS2_K  = df_050_059_OV_VVS2_K.assign(Clarity=None)
                    df_050_059_OV_VVS2_K  = df_050_059_OV_VVS2_K.assign(Cut=None)
                    df_050_059_OV_VVS2_K  = df_050_059_OV_VVS2_K.assign(Polish=None)
                    df_050_059_OV_VVS2_K  = df_050_059_OV_VVS2_K.assign(Symmetry=None)
                    df_050_059_OV_VVS2_K  = df_050_059_OV_VVS2_K.assign(Ratio=None)
                    df_050_059_OV_VVS2_K  = df_050_059_OV_VVS2_K.assign(PPC=None)
                    df_050_059_OV_VVS2_K  = df_050_059_OV_VVS2_K.assign(Total=None)
                    df_050_059_OV_VVS2_K ['Wt Range'] = listwtrange
                    df_050_059_OV_VVS2_K ['Company'] = listcom
                    df_050_059_OV_VVS2_K ['Shape'] = listshap
                    df_050_059_OV_VVS2_K ['Carat'] = listcar
                    df_050_059_OV_VVS2_K ['Color'] = listcol
                    df_050_059_OV_VVS2_K ['Clarity'] = listclar
                    df_050_059_OV_VVS2_K ['Cut'] = listcut
                    df_050_059_OV_VVS2_K ['Polish'] = listpol
                    df_050_059_OV_VVS2_K ['Symmetry'] = listsym
                    df_050_059_OV_VVS2_K ['Ratio'] = listrat
                    df_050_059_OV_VVS2_K ['PPC'] = listdesc
                    df_050_059_OV_VVS2_K ['Total'] = listtotal
                    df_050_059_OV_VVS2_K['Carat'] = df_050_059_OV_VVS2_K['Carat'].astype('float64')
                    df_050_059_OV_VVS2_K['PPC'] = df_050_059_OV_VVS2_K['PPC'].astype('float64')
                    df_050_059_OV_VVS2_K['Total'] = df_050_059_OV_VVS2_K['Total'].astype('float64')
                    df_050_059_OV_VVS2_K['Total'] = df_050_059_OV_VVS2_K['Carat'] * df_050_059_OV_VVS2_K['PPC']


                elif i=="K" and j=="VS1" and k == "OV":
                    df_050_059_OV_VS1_K = pd.DataFrame()
                    df_050_059_OV_VS1_K ['Wt Range'] = None
                    df_050_059_OV_VS1_K  = df_050_059_OV_VS1_K.assign(Company=None)
                    df_050_059_OV_VS1_K  = df_050_059_OV_VS1_K.assign(Shape=None)
                    df_050_059_OV_VS1_K  = df_050_059_OV_VS1_K.assign(Carat=None)
                    df_050_059_OV_VS1_K  = df_050_059_OV_VS1_K.assign(Color=None)
                    df_050_059_OV_VS1_K  = df_050_059_OV_VS1_K.assign(Clarity=None)
                    df_050_059_OV_VS1_K  = df_050_059_OV_VS1_K.assign(Cut=None)
                    df_050_059_OV_VS1_K  = df_050_059_OV_VS1_K.assign(Polish=None)
                    df_050_059_OV_VS1_K  = df_050_059_OV_VS1_K.assign(Symmetry=None)
                    df_050_059_OV_VS1_K  = df_050_059_OV_VS1_K.assign(Ratio=None)
                    df_050_059_OV_VS1_K  = df_050_059_OV_VS1_K.assign(PPC=None)
                    df_050_059_OV_VS1_K  = df_050_059_OV_VS1_K.assign(Total=None)
                    df_050_059_OV_VS1_K ['Wt Range'] = listwtrange
                    df_050_059_OV_VS1_K ['Company'] = listcom
                    df_050_059_OV_VS1_K ['Shape'] = listshap
                    df_050_059_OV_VS1_K ['Carat'] = listcar
                    df_050_059_OV_VS1_K ['Color'] = listcol
                    df_050_059_OV_VS1_K ['Clarity'] = listclar
                    df_050_059_OV_VS1_K ['Cut'] = listcut
                    df_050_059_OV_VS1_K ['Polish'] = listpol
                    df_050_059_OV_VS1_K ['Symmetry'] = listsym
                    df_050_059_OV_VS1_K ['Ratio'] = listrat
                    df_050_059_OV_VS1_K ['PPC'] = listdesc
                    df_050_059_OV_VS1_K ['Total'] = listtotal
                    df_050_059_OV_VS1_K['Carat'] = df_050_059_OV_VS1_K['Carat'].astype('float64')
                    df_050_059_OV_VS1_K['PPC'] = df_050_059_OV_VS1_K['PPC'].astype('float64')
                    df_050_059_OV_VS1_K['Total'] = df_050_059_OV_VS1_K['Total'].astype('float64')
                    df_050_059_OV_VS1_K['Total'] = df_050_059_OV_VS1_K['Carat'] * df_050_059_OV_VS1_K['PPC']


                elif i=="K" and j == "VS2" and k == "OV":
                    df_050_059_OV_VS2_K = pd.DataFrame()
                    df_050_059_OV_VS2_K ['Wt Range'] = None
                    df_050_059_OV_VS2_K  = df_050_059_OV_VS2_K.assign(Company=None)
                    df_050_059_OV_VS2_K  = df_050_059_OV_VS2_K.assign(Shape=None)
                    df_050_059_OV_VS2_K  = df_050_059_OV_VS2_K.assign(Carat=None)
                    df_050_059_OV_VS2_K  = df_050_059_OV_VS2_K.assign(Color=None)
                    df_050_059_OV_VS2_K  = df_050_059_OV_VS2_K.assign(Clarity=None)
                    df_050_059_OV_VS2_K  = df_050_059_OV_VS2_K.assign(Cut=None)
                    df_050_059_OV_VS2_K  = df_050_059_OV_VS2_K.assign(Polish=None)
                    df_050_059_OV_VS2_K  = df_050_059_OV_VS2_K.assign(Symmetry=None)
                    df_050_059_OV_VS2_K  = df_050_059_OV_VS2_K.assign(Ratio=None)
                    df_050_059_OV_VS2_K  = df_050_059_OV_VS2_K.assign(PPC=None)
                    df_050_059_OV_VS2_K  = df_050_059_OV_VS2_K.assign(Total=None)
                    df_050_059_OV_VS2_K ['Wt Range'] = listwtrange
                    df_050_059_OV_VS2_K ['Company'] = listcom
                    df_050_059_OV_VS2_K ['Shape'] = listshap
                    df_050_059_OV_VS2_K ['Carat'] = listcar
                    df_050_059_OV_VS2_K ['Color'] = listcol
                    df_050_059_OV_VS2_K ['Clarity'] = listclar
                    df_050_059_OV_VS2_K ['Cut'] = listcut
                    df_050_059_OV_VS2_K ['Polish'] = listpol
                    df_050_059_OV_VS2_K ['Symmetry'] = listsym
                    df_050_059_OV_VS2_K ['Ratio'] = listrat
                    df_050_059_OV_VS2_K ['PPC'] = listdesc
                    df_050_059_OV_VS2_K ['Total'] = listtotal
                    df_050_059_OV_VS2_K['Carat'] = df_050_059_OV_VS2_K['Carat'].astype('float64')
                    df_050_059_OV_VS2_K['PPC'] = df_050_059_OV_VS2_K['PPC'].astype('float64')
                    df_050_059_OV_VS2_K['Total'] = df_050_059_OV_VS2_K['Total'].astype('float64')
                    df_050_059_OV_VS2_K['Total'] = df_050_059_OV_VS2_K['Carat'] * df_050_059_OV_VS2_K['PPC']


                elif i=="K" and j == "SI1" and k == "OV":
                    df_050_059_OV_SI1_K = pd.DataFrame()
                    df_050_059_OV_SI1_K ['Wt Range'] = None
                    df_050_059_OV_SI1_K  = df_050_059_OV_SI1_K.assign(Company=None)
                    df_050_059_OV_SI1_K  = df_050_059_OV_SI1_K.assign(Shape=None)
                    df_050_059_OV_SI1_K  = df_050_059_OV_SI1_K.assign(Carat=None)
                    df_050_059_OV_SI1_K  = df_050_059_OV_SI1_K.assign(Color=None)
                    df_050_059_OV_SI1_K  = df_050_059_OV_SI1_K.assign(Clarity=None)
                    df_050_059_OV_SI1_K  = df_050_059_OV_SI1_K.assign(Cut=None)
                    df_050_059_OV_SI1_K  = df_050_059_OV_SI1_K.assign(Polish=None)
                    df_050_059_OV_SI1_K  = df_050_059_OV_SI1_K.assign(Symmetry=None)
                    df_050_059_OV_SI1_K  = df_050_059_OV_SI1_K.assign(Ratio=None)
                    df_050_059_OV_SI1_K  = df_050_059_OV_SI1_K.assign(PPC=None)
                    df_050_059_OV_SI1_K  = df_050_059_OV_SI1_K.assign(Total=None)
                    df_050_059_OV_SI1_K ['Wt Range'] = listwtrange
                    df_050_059_OV_SI1_K ['Company'] = listcom
                    df_050_059_OV_SI1_K ['Shape'] = listshap
                    df_050_059_OV_SI1_K ['Carat'] = listcar
                    df_050_059_OV_SI1_K ['Color'] = listcol
                    df_050_059_OV_SI1_K ['Clarity'] = listclar
                    df_050_059_OV_SI1_K ['Cut'] = listcut
                    df_050_059_OV_SI1_K ['Polish'] = listpol
                    df_050_059_OV_SI1_K ['Symmetry'] = listsym
                    df_050_059_OV_SI1_K ['Ratio'] = listrat
                    df_050_059_OV_SI1_K ['PPC'] = listdesc
                    df_050_059_OV_SI1_K ['Total'] = listtotal
                    df_050_059_OV_SI1_K['Carat'] = df_050_059_OV_SI1_K['Carat'].astype('float64')
                    df_050_059_OV_SI1_K['PPC'] = df_050_059_OV_SI1_K['PPC'].astype('float64')
                    df_050_059_OV_SI1_K['Total'] = df_050_059_OV_SI1_K['Total'].astype('float64')
                    df_050_059_OV_SI1_K['Total'] = df_050_059_OV_SI1_K['Carat'] * df_050_059_OV_SI1_K['PPC']


                elif i=="K" and j == "SI2" and k == "OV":
                    df_050_059_OV_SI2_K = pd.DataFrame()
                    df_050_059_OV_SI2_K ['Wt Range'] = None
                    df_050_059_OV_SI2_K  = df_050_059_OV_SI2_K.assign(Company=None)
                    df_050_059_OV_SI2_K  = df_050_059_OV_SI2_K.assign(Shape=None)
                    df_050_059_OV_SI2_K  = df_050_059_OV_SI2_K.assign(Carat=None)
                    df_050_059_OV_SI2_K  = df_050_059_OV_SI2_K.assign(Color=None)
                    df_050_059_OV_SI2_K  = df_050_059_OV_SI2_K.assign(Clarity=None)
                    df_050_059_OV_SI2_K  = df_050_059_OV_SI2_K.assign(Cut=None)
                    df_050_059_OV_SI2_K  = df_050_059_OV_SI2_K.assign(Polish=None)
                    df_050_059_OV_SI2_K  = df_050_059_OV_SI2_K.assign(Symmetry=None)
                    df_050_059_OV_SI2_K  = df_050_059_OV_SI2_K.assign(Ratio=None)
                    df_050_059_OV_SI2_K  = df_050_059_OV_SI2_K.assign(PPC=None)
                    df_050_059_OV_SI2_K  = df_050_059_OV_SI2_K.assign(Total=None)
                    df_050_059_OV_SI2_K ['Wt Range'] = listwtrange
                    df_050_059_OV_SI2_K ['Company'] = listcom
                    df_050_059_OV_SI2_K ['Shape'] = listshap
                    df_050_059_OV_SI2_K ['Carat'] = listcar
                    df_050_059_OV_SI2_K ['Color'] = listcol
                    df_050_059_OV_SI2_K ['Clarity'] = listclar
                    df_050_059_OV_SI2_K ['Cut'] = listcut
                    df_050_059_OV_SI2_K ['Polish'] = listpol
                    df_050_059_OV_SI2_K ['Symmetry'] = listsym
                    df_050_059_OV_SI2_K ['Ratio'] = listrat
                    df_050_059_OV_SI2_K ['PPC'] = listdesc
                    df_050_059_OV_SI2_K ['Total'] = listtotal
                    df_050_059_OV_SI2_K['Carat'] = df_050_059_OV_SI2_K['Carat'].astype('float64')
                    df_050_059_OV_SI2_K['PPC'] = df_050_059_OV_SI2_K['PPC'].astype('float64')
                    df_050_059_OV_SI2_K['Total'] = df_050_059_OV_SI2_K['Total'].astype('float64')
                    df_050_059_OV_SI2_K['Total'] = df_050_059_OV_SI2_K['Carat'] * df_050_059_OV_SI2_K['PPC']


                elif i=="K" and j == "I1" and k == "OV":
                    df_050_059_OV_I1_K = pd.DataFrame()
                    df_050_059_OV_I1_K ['Wt Range'] = None
                    df_050_059_OV_I1_K  = df_050_059_OV_I1_K.assign(Company=None)
                    df_050_059_OV_I1_K  = df_050_059_OV_I1_K.assign(Shape=None)
                    df_050_059_OV_I1_K  = df_050_059_OV_I1_K.assign(Carat=None)
                    df_050_059_OV_I1_K  = df_050_059_OV_I1_K.assign(Color=None)
                    df_050_059_OV_I1_K  = df_050_059_OV_I1_K.assign(Clarity=None)
                    df_050_059_OV_I1_K  = df_050_059_OV_I1_K.assign(Cut=None)
                    df_050_059_OV_I1_K  = df_050_059_OV_I1_K.assign(Polish=None)
                    df_050_059_OV_I1_K  = df_050_059_OV_I1_K.assign(Symmetry=None)
                    df_050_059_OV_I1_K  = df_050_059_OV_I1_K.assign(Ratio=None)
                    df_050_059_OV_I1_K  = df_050_059_OV_I1_K.assign(PPC=None)
                    df_050_059_OV_I1_K  = df_050_059_OV_I1_K.assign(Total=None)
                    df_050_059_OV_I1_K ['Wt Range'] = listwtrange
                    df_050_059_OV_I1_K ['Company'] = listcom
                    df_050_059_OV_I1_K ['Shape'] = listshap
                    df_050_059_OV_I1_K ['Carat'] = listcar
                    df_050_059_OV_I1_K ['Color'] = listcol
                    df_050_059_OV_I1_K ['Clarity'] = listclar
                    df_050_059_OV_I1_K ['Cut'] = listcut
                    df_050_059_OV_I1_K ['Polish'] = listpol
                    df_050_059_OV_I1_K ['Symmetry'] = listsym
                    df_050_059_OV_I1_K ['Ratio'] = listrat
                    df_050_059_OV_I1_K ['PPC'] = listdesc
                    df_050_059_OV_I1_K ['Total'] = listtotal
                    df_050_059_OV_I1_K['Carat'] = df_050_059_OV_I1_K['Carat'].astype('float64')
                    df_050_059_OV_I1_K['PPC'] = df_050_059_OV_I1_K['PPC'].astype('float64')
                    df_050_059_OV_I1_K['Total'] = df_050_059_OV_I1_K['Total'].astype('float64')
                    df_050_059_OV_I1_K['Total'] = df_050_059_OV_I1_K['Carat'] * df_050_059_OV_I1_K['PPC']


                elif i=="K" and j == "I2" and k == "OV":
                    df_050_059_OV_I2_K = pd.DataFrame()
                    df_050_059_OV_I2_K ['Wt Range'] = None
                    df_050_059_OV_I2_K  = df_050_059_OV_I2_K.assign(Company=None)
                    df_050_059_OV_I2_K  = df_050_059_OV_I2_K.assign(Shape=None)
                    df_050_059_OV_I2_K  = df_050_059_OV_I2_K.assign(Carat=None)
                    df_050_059_OV_I2_K  = df_050_059_OV_I2_K.assign(Color=None)
                    df_050_059_OV_I2_K  = df_050_059_OV_I2_K.assign(Clarity=None)
                    df_050_059_OV_I2_K  = df_050_059_OV_I2_K.assign(Cut=None)
                    df_050_059_OV_I2_K  = df_050_059_OV_I2_K.assign(Polish=None)
                    df_050_059_OV_I2_K  = df_050_059_OV_I2_K.assign(Symmetry=None)
                    df_050_059_OV_I2_K  = df_050_059_OV_I2_K.assign(Ratio=None)
                    df_050_059_OV_I2_K  = df_050_059_OV_I2_K.assign(PPC=None)
                    df_050_059_OV_I2_K  = df_050_059_OV_I2_K.assign(Total=None)
                    df_050_059_OV_I2_K ['Wt Range'] = listwtrange
                    df_050_059_OV_I2_K ['Company'] = listcom
                    df_050_059_OV_I2_K ['Shape'] = listshap
                    df_050_059_OV_I2_K ['Carat'] = listcar
                    df_050_059_OV_I2_K ['Color'] = listcol
                    df_050_059_OV_I2_K ['Clarity'] = listclar
                    df_050_059_OV_I2_K ['Cut'] = listcut
                    df_050_059_OV_I2_K ['Polish'] = listpol
                    df_050_059_OV_I2_K ['Symmetry'] = listsym
                    df_050_059_OV_I2_K ['Ratio'] = listrat
                    df_050_059_OV_I2_K ['PPC'] = listdesc
                    df_050_059_OV_I2_K ['Total'] = listtotal
                    df_050_059_OV_I2_K['Carat'] = df_050_059_OV_I2_K['Carat'].astype('float64')
                    df_050_059_OV_I2_K['PPC'] = df_050_059_OV_I2_K['PPC'].astype('float64')
                    df_050_059_OV_I2_K['Total'] = df_050_059_OV_I2_K['Total'].astype('float64')
                    df_050_059_OV_I2_K['Total'] = df_050_059_OV_I2_K['Carat'] * df_050_059_OV_I2_K['PPC']


                elif i=="L" and j == "IF" and k == "OV":
                    df_050_059_OV_IF_L = pd.DataFrame()
                    df_050_059_OV_IF_L ['Wt Range'] = None
                    df_050_059_OV_IF_L  = df_050_059_OV_IF_L.assign(Company=None)
                    df_050_059_OV_IF_L  = df_050_059_OV_IF_L.assign(Shape=None)
                    df_050_059_OV_IF_L  = df_050_059_OV_IF_L.assign(Carat=None)
                    df_050_059_OV_IF_L  = df_050_059_OV_IF_L.assign(Color=None)
                    df_050_059_OV_IF_L  = df_050_059_OV_IF_L.assign(Clarity=None)
                    df_050_059_OV_IF_L  = df_050_059_OV_IF_L.assign(Cut=None)
                    df_050_059_OV_IF_L  = df_050_059_OV_IF_L.assign(Polish=None)
                    df_050_059_OV_IF_L  = df_050_059_OV_IF_L.assign(Symmetry=None)
                    df_050_059_OV_IF_L  = df_050_059_OV_IF_L.assign(Ratio=None)
                    df_050_059_OV_IF_L  = df_050_059_OV_IF_L.assign(PPC=None)
                    df_050_059_OV_IF_L  = df_050_059_OV_IF_L.assign(Total=None)
                    df_050_059_OV_IF_L ['Wt Range'] = listwtrange
                    df_050_059_OV_IF_L ['Company'] = listcom
                    df_050_059_OV_IF_L ['Shape'] = listshap
                    df_050_059_OV_IF_L ['Carat'] = listcar
                    df_050_059_OV_IF_L ['Color'] = listcol
                    df_050_059_OV_IF_L ['Clarity'] = listclar
                    df_050_059_OV_IF_L ['Cut'] = listcut
                    df_050_059_OV_IF_L ['Polish'] = listpol
                    df_050_059_OV_IF_L ['Symmetry'] = listsym
                    df_050_059_OV_IF_L ['Ratio'] = listrat
                    df_050_059_OV_IF_L ['PPC'] = listdesc
                    df_050_059_OV_IF_L ['Total'] = listtotal
                    df_050_059_OV_IF_L['Carat'] = df_050_059_OV_IF_L['Carat'].astype('float64')
                    df_050_059_OV_IF_L['PPC'] = df_050_059_OV_IF_L['PPC'].astype('float64')
                    df_050_059_OV_IF_L['Total'] = df_050_059_OV_IF_L['Total'].astype('float64')
                    df_050_059_OV_IF_L['Total'] = df_050_059_OV_IF_L['Carat'] * df_050_059_OV_IF_L['PPC']


                elif i=="L" and j == "VVS1" and k == "OV":
                    df_050_059_OV_VVS1_L = pd.DataFrame()
                    df_050_059_OV_VVS1_L ['Wt Range'] = None
                    df_050_059_OV_VVS1_L  = df_050_059_OV_VVS1_L.assign(Company=None)
                    df_050_059_OV_VVS1_L  = df_050_059_OV_VVS1_L.assign(Shape=None)
                    df_050_059_OV_VVS1_L  = df_050_059_OV_VVS1_L.assign(Carat=None)
                    df_050_059_OV_VVS1_L  = df_050_059_OV_VVS1_L.assign(Color=None)
                    df_050_059_OV_VVS1_L  = df_050_059_OV_VVS1_L.assign(Clarity=None)
                    df_050_059_OV_VVS1_L  = df_050_059_OV_VVS1_L.assign(Cut=None)
                    df_050_059_OV_VVS1_L  = df_050_059_OV_VVS1_L.assign(Polish=None)
                    df_050_059_OV_VVS1_L  = df_050_059_OV_VVS1_L.assign(Symmetry=None)
                    df_050_059_OV_VVS1_L  = df_050_059_OV_VVS1_L.assign(Ratio=None)
                    df_050_059_OV_VVS1_L  = df_050_059_OV_VVS1_L.assign(PPC=None)
                    df_050_059_OV_VVS1_L  = df_050_059_OV_VVS1_L.assign(Total=None)
                    df_050_059_OV_VVS1_L ['Wt Range'] = listwtrange
                    df_050_059_OV_VVS1_L ['Company'] = listcom
                    df_050_059_OV_VVS1_L ['Shape'] = listshap
                    df_050_059_OV_VVS1_L ['Carat'] = listcar
                    df_050_059_OV_VVS1_L ['Color'] = listcol
                    df_050_059_OV_VVS1_L ['Clarity'] = listclar
                    df_050_059_OV_VVS1_L ['Cut'] = listcut
                    df_050_059_OV_VVS1_L ['Polish'] = listpol
                    df_050_059_OV_VVS1_L ['Symmetry'] = listsym
                    df_050_059_OV_VVS1_L ['Ratio'] = listrat
                    df_050_059_OV_VVS1_L ['PPC'] = listdesc
                    df_050_059_OV_VVS1_L ['Total'] = listtotal
                    df_050_059_OV_VVS1_L['Carat'] = df_050_059_OV_VVS1_L['Carat'].astype('float64')
                    df_050_059_OV_VVS1_L['PPC'] = df_050_059_OV_VVS1_L['PPC'].astype('float64')
                    df_050_059_OV_VVS1_L['Total'] = df_050_059_OV_VVS1_L['Total'].astype('float64')
                    df_050_059_OV_VVS1_L['Total'] = df_050_059_OV_VVS1_L['Carat'] * df_050_059_OV_VVS1_L['PPC']


                elif i=="L" and j == "VVS2" and k == "OV":
                    df_050_059_OV_VVS2_L = pd.DataFrame()
                    df_050_059_OV_VVS2_L ['Wt Range'] = None
                    df_050_059_OV_VVS2_L  = df_050_059_OV_VVS2_L.assign(Company=None)
                    df_050_059_OV_VVS2_L  = df_050_059_OV_VVS2_L.assign(Shape=None)
                    df_050_059_OV_VVS2_L  = df_050_059_OV_VVS2_L.assign(Carat=None)
                    df_050_059_OV_VVS2_L  = df_050_059_OV_VVS2_L.assign(Color=None)
                    df_050_059_OV_VVS2_L  = df_050_059_OV_VVS2_L.assign(Clarity=None)
                    df_050_059_OV_VVS2_L  = df_050_059_OV_VVS2_L.assign(Cut=None)
                    df_050_059_OV_VVS2_L  = df_050_059_OV_VVS2_L.assign(Polish=None)
                    df_050_059_OV_VVS2_L  = df_050_059_OV_VVS2_L.assign(Symmetry=None)
                    df_050_059_OV_VVS2_L  = df_050_059_OV_VVS2_L.assign(Ratio=None)
                    df_050_059_OV_VVS2_L  = df_050_059_OV_VVS2_L.assign(PPC=None)
                    df_050_059_OV_VVS2_L  = df_050_059_OV_VVS2_L.assign(Total=None)
                    df_050_059_OV_VVS2_L ['Wt Range'] = listwtrange
                    df_050_059_OV_VVS2_L ['Company'] = listcom
                    df_050_059_OV_VVS2_L ['Shape'] = listshap
                    df_050_059_OV_VVS2_L ['Carat'] = listcar
                    df_050_059_OV_VVS2_L ['Color'] = listcol
                    df_050_059_OV_VVS2_L ['Clarity'] = listclar
                    df_050_059_OV_VVS2_L ['Cut'] = listcut
                    df_050_059_OV_VVS2_L ['Polish'] = listpol
                    df_050_059_OV_VVS2_L ['Symmetry'] = listsym
                    df_050_059_OV_VVS2_L ['Ratio'] = listrat
                    df_050_059_OV_VVS2_L ['PPC'] = listdesc
                    df_050_059_OV_VVS2_L ['Total'] = listtotal
                    df_050_059_OV_VVS2_L['Carat'] = df_050_059_OV_VVS2_L['Carat'].astype('float64')
                    df_050_059_OV_VVS2_L['PPC'] = df_050_059_OV_VVS2_L['PPC'].astype('float64')
                    df_050_059_OV_VVS2_L['Total'] = df_050_059_OV_VVS2_L['Total'].astype('float64')
                    df_050_059_OV_VVS2_L['Total'] = df_050_059_OV_VVS2_L['Carat'] * df_050_059_OV_VVS2_L['PPC']


                elif i=="L" and j=="VS1" and k == "OV":
                    df_050_059_OV_VS1_L = pd.DataFrame()
                    df_050_059_OV_VS1_L ['Wt Range'] = None
                    df_050_059_OV_VS1_L  = df_050_059_OV_VS1_L.assign(Company=None)
                    df_050_059_OV_VS1_L  = df_050_059_OV_VS1_L.assign(Shape=None)
                    df_050_059_OV_VS1_L  = df_050_059_OV_VS1_L.assign(Carat=None)
                    df_050_059_OV_VS1_L  = df_050_059_OV_VS1_L.assign(Color=None)
                    df_050_059_OV_VS1_L  = df_050_059_OV_VS1_L.assign(Clarity=None)
                    df_050_059_OV_VS1_L  = df_050_059_OV_VS1_L.assign(Cut=None)
                    df_050_059_OV_VS1_L  = df_050_059_OV_VS1_L.assign(Polish=None)
                    df_050_059_OV_VS1_L  = df_050_059_OV_VS1_L.assign(Symmetry=None)
                    df_050_059_OV_VS1_L  = df_050_059_OV_VS1_L.assign(Ratio=None)
                    df_050_059_OV_VS1_L  = df_050_059_OV_VS1_L.assign(PPC=None)
                    df_050_059_OV_VS1_L  = df_050_059_OV_VS1_L.assign(Total=None)
                    df_050_059_OV_VS1_L ['Wt Range'] = listwtrange
                    df_050_059_OV_VS1_L ['Company'] = listcom
                    df_050_059_OV_VS1_L ['Shape'] = listshap
                    df_050_059_OV_VS1_L ['Carat'] = listcar
                    df_050_059_OV_VS1_L ['Color'] = listcol
                    df_050_059_OV_VS1_L ['Clarity'] = listclar
                    df_050_059_OV_VS1_L ['Cut'] = listcut
                    df_050_059_OV_VS1_L ['Polish'] = listpol
                    df_050_059_OV_VS1_L ['Symmetry'] = listsym
                    df_050_059_OV_VS1_L ['Ratio'] = listrat
                    df_050_059_OV_VS1_L ['PPC'] = listdesc
                    df_050_059_OV_VS1_L ['Total'] = listtotal
                    df_050_059_OV_VS1_L['Carat'] = df_050_059_OV_VS1_L['Carat'].astype('float64')
                    df_050_059_OV_VS1_L['PPC'] = df_050_059_OV_VS1_L['PPC'].astype('float64')
                    df_050_059_OV_VS1_L['Total'] = df_050_059_OV_VS1_L['Total'].astype('float64')
                    df_050_059_OV_VS1_L['Total'] = df_050_059_OV_VS1_L['Carat'] * df_050_059_OV_VS1_L['PPC']


                elif i=="L" and j == "VS2" and k == "OV":
                    df_050_059_OV_VS2_L = pd.DataFrame()
                    df_050_059_OV_VS2_L ['Wt Range'] = None
                    df_050_059_OV_VS2_L  = df_050_059_OV_VS2_L.assign(Company=None)
                    df_050_059_OV_VS2_L  = df_050_059_OV_VS2_L.assign(Shape=None)
                    df_050_059_OV_VS2_L  = df_050_059_OV_VS2_L.assign(Carat=None)
                    df_050_059_OV_VS2_L  = df_050_059_OV_VS2_L.assign(Color=None)
                    df_050_059_OV_VS2_L  = df_050_059_OV_VS2_L.assign(Clarity=None)
                    df_050_059_OV_VS2_L  = df_050_059_OV_VS2_L.assign(Cut=None)
                    df_050_059_OV_VS2_L  = df_050_059_OV_VS2_L.assign(Polish=None)
                    df_050_059_OV_VS2_L  = df_050_059_OV_VS2_L.assign(Symmetry=None)
                    df_050_059_OV_VS2_L  = df_050_059_OV_VS2_L.assign(Ratio=None)
                    df_050_059_OV_VS2_L  = df_050_059_OV_VS2_L.assign(PPC=None)
                    df_050_059_OV_VS2_L  = df_050_059_OV_VS2_L.assign(Total=None)
                    df_050_059_OV_VS2_L ['Wt Range'] = listwtrange
                    df_050_059_OV_VS2_L ['Company'] = listcom
                    df_050_059_OV_VS2_L ['Shape'] = listshap
                    df_050_059_OV_VS2_L ['Carat'] = listcar
                    df_050_059_OV_VS2_L ['Color'] = listcol
                    df_050_059_OV_VS2_L ['Clarity'] = listclar
                    df_050_059_OV_VS2_L ['Cut'] = listcut
                    df_050_059_OV_VS2_L ['Polish'] = listpol
                    df_050_059_OV_VS2_L ['Symmetry'] = listsym
                    df_050_059_OV_VS2_L ['Ratio'] = listrat
                    df_050_059_OV_VS2_L ['PPC'] = listdesc
                    df_050_059_OV_VS2_L ['Total'] = listtotal
                    df_050_059_OV_VS2_L['Carat'] = df_050_059_OV_VS2_L['Carat'].astype('float64')
                    df_050_059_OV_VS2_L['PPC'] = df_050_059_OV_VS2_L['PPC'].astype('float64')
                    df_050_059_OV_VS2_L['Total'] = df_050_059_OV_VS2_L['Total'].astype('float64')
                    df_050_059_OV_VS2_L['Total'] = df_050_059_OV_VS2_L['Carat'] * df_050_059_OV_VS2_L['PPC']


                elif i=="L" and j == "SI1" and k == "OV":
                    df_050_059_OV_SI1_L = pd.DataFrame()
                    df_050_059_OV_SI1_L ['Wt Range'] = None
                    df_050_059_OV_SI1_L  = df_050_059_OV_SI1_L.assign(Company=None)
                    df_050_059_OV_SI1_L  = df_050_059_OV_SI1_L.assign(Shape=None)
                    df_050_059_OV_SI1_L  = df_050_059_OV_SI1_L.assign(Carat=None)
                    df_050_059_OV_SI1_L  = df_050_059_OV_SI1_L.assign(Color=None)
                    df_050_059_OV_SI1_L  = df_050_059_OV_SI1_L.assign(Clarity=None)
                    df_050_059_OV_SI1_L  = df_050_059_OV_SI1_L.assign(Cut=None)
                    df_050_059_OV_SI1_L  = df_050_059_OV_SI1_L.assign(Polish=None)
                    df_050_059_OV_SI1_L  = df_050_059_OV_SI1_L.assign(Symmetry=None)
                    df_050_059_OV_SI1_L  = df_050_059_OV_SI1_L.assign(Ratio=None)
                    df_050_059_OV_SI1_L  = df_050_059_OV_SI1_L.assign(PPC=None)
                    df_050_059_OV_SI1_L  = df_050_059_OV_SI1_L.assign(Total=None)
                    df_050_059_OV_SI1_L ['Wt Range'] = listwtrange
                    df_050_059_OV_SI1_L ['Company'] = listcom
                    df_050_059_OV_SI1_L ['Shape'] = listshap
                    df_050_059_OV_SI1_L ['Carat'] = listcar
                    df_050_059_OV_SI1_L ['Color'] = listcol
                    df_050_059_OV_SI1_L ['Clarity'] = listclar
                    df_050_059_OV_SI1_L ['Cut'] = listcut
                    df_050_059_OV_SI1_L ['Polish'] = listpol
                    df_050_059_OV_SI1_L ['Symmetry'] = listsym
                    df_050_059_OV_SI1_L ['Ratio'] = listrat
                    df_050_059_OV_SI1_L ['PPC'] = listdesc
                    df_050_059_OV_SI1_L ['Total'] = listtotal
                    df_050_059_OV_SI1_L['Carat'] = df_050_059_OV_SI1_L['Carat'].astype('float64')
                    df_050_059_OV_SI1_L['PPC'] = df_050_059_OV_SI1_L['PPC'].astype('float64')
                    df_050_059_OV_SI1_L['Total'] = df_050_059_OV_SI1_L['Total'].astype('float64')
                    df_050_059_OV_SI1_L['Total'] = df_050_059_OV_SI1_L['Carat'] * df_050_059_OV_SI1_L['PPC']


                elif i=="L" and j == "SI2" and k == "OV":
                    df_050_059_OV_SI2_L = pd.DataFrame()
                    df_050_059_OV_SI2_L ['Wt Range'] = None
                    df_050_059_OV_SI2_L  = df_050_059_OV_SI2_L.assign(Company=None)
                    df_050_059_OV_SI2_L  = df_050_059_OV_SI2_L.assign(Shape=None)
                    df_050_059_OV_SI2_L  = df_050_059_OV_SI2_L.assign(Carat=None)
                    df_050_059_OV_SI2_L  = df_050_059_OV_SI2_L.assign(Color=None)
                    df_050_059_OV_SI2_L  = df_050_059_OV_SI2_L.assign(Clarity=None)
                    df_050_059_OV_SI2_L  = df_050_059_OV_SI2_L.assign(Cut=None)
                    df_050_059_OV_SI2_L  = df_050_059_OV_SI2_L.assign(Polish=None)
                    df_050_059_OV_SI2_L  = df_050_059_OV_SI2_L.assign(Symmetry=None)
                    df_050_059_OV_SI2_L  = df_050_059_OV_SI2_L.assign(Ratio=None)
                    df_050_059_OV_SI2_L  = df_050_059_OV_SI2_L.assign(PPC=None)
                    df_050_059_OV_SI2_L  = df_050_059_OV_SI2_L.assign(Total=None)
                    df_050_059_OV_SI2_L ['Wt Range'] = listwtrange
                    df_050_059_OV_SI2_L ['Company'] = listcom
                    df_050_059_OV_SI2_L ['Shape'] = listshap
                    df_050_059_OV_SI2_L ['Carat'] = listcar
                    df_050_059_OV_SI2_L ['Color'] = listcol
                    df_050_059_OV_SI2_L ['Clarity'] = listclar
                    df_050_059_OV_SI2_L ['Cut'] = listcut
                    df_050_059_OV_SI2_L ['Polish'] = listpol
                    df_050_059_OV_SI2_L ['Symmetry'] = listsym
                    df_050_059_OV_SI2_L ['Ratio'] = listrat
                    df_050_059_OV_SI2_L ['PPC'] = listdesc
                    df_050_059_OV_SI2_L ['Total'] = listtotal
                    df_050_059_OV_SI2_L['Carat'] = df_050_059_OV_SI2_L['Carat'].astype('float64')
                    df_050_059_OV_SI2_L['PPC'] = df_050_059_OV_SI2_L['PPC'].astype('float64')
                    df_050_059_OV_SI2_L['Total'] = df_050_059_OV_SI2_L['Total'].astype('float64')
                    df_050_059_OV_SI2_L['Total'] = df_050_059_OV_SI2_L['Carat'] * df_050_059_OV_SI2_L['PPC']


                elif i=="L" and j == "I1" and k == "OV":
                    df_050_059_OV_I1_L = pd.DataFrame()
                    df_050_059_OV_I1_L ['Wt Range'] = None
                    df_050_059_OV_I1_L  = df_050_059_OV_I1_L.assign(Company=None)
                    df_050_059_OV_I1_L  = df_050_059_OV_I1_L.assign(Shape=None)
                    df_050_059_OV_I1_L  = df_050_059_OV_I1_L.assign(Carat=None)
                    df_050_059_OV_I1_L  = df_050_059_OV_I1_L.assign(Color=None)
                    df_050_059_OV_I1_L  = df_050_059_OV_I1_L.assign(Clarity=None)
                    df_050_059_OV_I1_L  = df_050_059_OV_I1_L.assign(Cut=None)
                    df_050_059_OV_I1_L  = df_050_059_OV_I1_L.assign(Polish=None)
                    df_050_059_OV_I1_L  = df_050_059_OV_I1_L.assign(Symmetry=None)
                    df_050_059_OV_I1_L  = df_050_059_OV_I1_L.assign(Ratio=None)
                    df_050_059_OV_I1_L  = df_050_059_OV_I1_L.assign(PPC=None)
                    df_050_059_OV_I1_L  = df_050_059_OV_I1_L.assign(Total=None)
                    df_050_059_OV_I1_L ['Wt Range'] = listwtrange
                    df_050_059_OV_I1_L ['Company'] = listcom
                    df_050_059_OV_I1_L ['Shape'] = listshap
                    df_050_059_OV_I1_L ['Carat'] = listcar
                    df_050_059_OV_I1_L ['Color'] = listcol
                    df_050_059_OV_I1_L ['Clarity'] = listclar
                    df_050_059_OV_I1_L ['Cut'] = listcut
                    df_050_059_OV_I1_L ['Polish'] = listpol
                    df_050_059_OV_I1_L ['Symmetry'] = listsym
                    df_050_059_OV_I1_L ['Ratio'] = listrat
                    df_050_059_OV_I1_L ['PPC'] = listdesc
                    df_050_059_OV_I1_L ['Total'] = listtotal
                    df_050_059_OV_I1_L['Carat'] = df_050_059_OV_I1_L['Carat'].astype('float64')
                    df_050_059_OV_I1_L['PPC'] = df_050_059_OV_I1_L['PPC'].astype('float64')
                    df_050_059_OV_I1_L['Total'] = df_050_059_OV_I1_L['Total'].astype('float64')
                    df_050_059_OV_I1_L['Total'] = df_050_059_OV_I1_L['Carat'] * df_050_059_OV_I1_L['PPC']


                elif i=="L" and j == "I2" and k == "OV":
                    df_050_059_OV_I2_L = pd.DataFrame()
                    df_050_059_OV_I2_L ['Wt Range'] = None
                    df_050_059_OV_I2_L  = df_050_059_OV_I2_L.assign(Company=None)
                    df_050_059_OV_I2_L  = df_050_059_OV_I2_L.assign(Shape=None)
                    df_050_059_OV_I2_L  = df_050_059_OV_I2_L.assign(Carat=None)
                    df_050_059_OV_I2_L  = df_050_059_OV_I2_L.assign(Color=None)
                    df_050_059_OV_I2_L  = df_050_059_OV_I2_L.assign(Clarity=None)
                    df_050_059_OV_I2_L  = df_050_059_OV_I2_L.assign(Cut=None)
                    df_050_059_OV_I2_L  = df_050_059_OV_I2_L.assign(Polish=None)
                    df_050_059_OV_I2_L  = df_050_059_OV_I2_L.assign(Symmetry=None)
                    df_050_059_OV_I2_L  = df_050_059_OV_I2_L.assign(Ratio=None)
                    df_050_059_OV_I2_L  = df_050_059_OV_I2_L.assign(PPC=None)
                    df_050_059_OV_I2_L  = df_050_059_OV_I2_L.assign(Total=None)
                    df_050_059_OV_I2_L ['Wt Range'] = listwtrange
                    df_050_059_OV_I2_L ['Company'] = listcom
                    df_050_059_OV_I2_L ['Shape'] = listshap
                    df_050_059_OV_I2_L ['Carat'] = listcar
                    df_050_059_OV_I2_L ['Color'] = listcol
                    df_050_059_OV_I2_L ['Clarity'] = listclar
                    df_050_059_OV_I2_L ['Cut'] = listcut
                    df_050_059_OV_I2_L ['Polish'] = listpol
                    df_050_059_OV_I2_L ['Symmetry'] = listsym
                    df_050_059_OV_I2_L ['Ratio'] = listrat
                    df_050_059_OV_I2_L ['PPC'] = listdesc
                    df_050_059_OV_I2_L ['Total'] = listtotal
                    df_050_059_OV_I2_L['Carat'] = df_050_059_OV_I2_L['Carat'].astype('float64')
                    df_050_059_OV_I2_L['PPC'] = df_050_059_OV_I2_L['PPC'].astype('float64')
                    df_050_059_OV_I2_L['Total'] = df_050_059_OV_I2_L['Total'].astype('float64')
                    df_050_059_OV_I2_L['Total'] = df_050_059_OV_I2_L['Carat'] * df_050_059_OV_I2_L['PPC']


                elif i=="D" and j == "IF" and k == "PR":
                    df_050_059_PR_IF_D = pd.DataFrame()
                    df_050_059_PR_IF_D ['Wt Range'] = None
                    df_050_059_PR_IF_D  = df_050_059_PR_IF_D.assign(Company=None)
                    df_050_059_PR_IF_D  = df_050_059_PR_IF_D.assign(Shape=None)
                    df_050_059_PR_IF_D  = df_050_059_PR_IF_D.assign(Carat=None)
                    df_050_059_PR_IF_D  = df_050_059_PR_IF_D.assign(Color=None)
                    df_050_059_PR_IF_D  = df_050_059_PR_IF_D.assign(Clarity=None)
                    df_050_059_PR_IF_D  = df_050_059_PR_IF_D.assign(Cut=None)
                    df_050_059_PR_IF_D  = df_050_059_PR_IF_D.assign(Polish=None)
                    df_050_059_PR_IF_D  = df_050_059_PR_IF_D.assign(Symmetry=None)
                    df_050_059_PR_IF_D  = df_050_059_PR_IF_D.assign(Ratio=None)
                    df_050_059_PR_IF_D  = df_050_059_PR_IF_D.assign(PPC=None)
                    df_050_059_PR_IF_D  = df_050_059_PR_IF_D.assign(Total=None)
                    df_050_059_PR_IF_D ['Wt Range'] = listwtrange
                    df_050_059_PR_IF_D ['Company'] = listcom
                    df_050_059_PR_IF_D ['Shape'] = listshap
                    df_050_059_PR_IF_D ['Carat'] = listcar
                    df_050_059_PR_IF_D ['Color'] = listcol
                    df_050_059_PR_IF_D ['Clarity'] = listclar
                    df_050_059_PR_IF_D ['Cut'] = listcut
                    df_050_059_PR_IF_D ['Polish'] = listpol
                    df_050_059_PR_IF_D ['Symmetry'] = listsym
                    df_050_059_PR_IF_D ['Ratio'] = listrat
                    df_050_059_PR_IF_D ['PPC'] = listdesc
                    df_050_059_PR_IF_D ['Total'] = listtotal
                    df_050_059_PR_IF_D['Carat'] = df_050_059_PR_IF_D['Carat'].astype('float64')
                    df_050_059_PR_IF_D['PPC'] = df_050_059_PR_IF_D['PPC'].astype('float64')
                    df_050_059_PR_IF_D['Total'] = df_050_059_PR_IF_D['Total'].astype('float64')
                    df_050_059_PR_IF_D['Total'] = df_050_059_PR_IF_D['Carat'] * df_050_059_PR_IF_D['PPC']



                elif i=="D" and j == "VVS1" and k == "PR" :
                    df_050_059_PR_VVS1_D = pd.DataFrame()
                    df_050_059_PR_VVS1_D ['Wt Range'] = None
                    df_050_059_PR_VVS1_D  = df_050_059_PR_VVS1_D.assign(Company=None)
                    df_050_059_PR_VVS1_D  = df_050_059_PR_VVS1_D.assign(Shape=None)
                    df_050_059_PR_VVS1_D  = df_050_059_PR_VVS1_D.assign(Carat=None)
                    df_050_059_PR_VVS1_D  = df_050_059_PR_VVS1_D.assign(Color=None)
                    df_050_059_PR_VVS1_D  = df_050_059_PR_VVS1_D.assign(Clarity=None)
                    df_050_059_PR_VVS1_D  = df_050_059_PR_VVS1_D.assign(Cut=None)
                    df_050_059_PR_VVS1_D  = df_050_059_PR_VVS1_D.assign(Polish=None)
                    df_050_059_PR_VVS1_D  = df_050_059_PR_VVS1_D.assign(Symmetry=None)
                    df_050_059_PR_VVS1_D  = df_050_059_PR_VVS1_D.assign(Ratio=None)
                    df_050_059_PR_VVS1_D  = df_050_059_PR_VVS1_D.assign(PPC=None)
                    df_050_059_PR_VVS1_D  = df_050_059_PR_VVS1_D.assign(Total=None)
                    df_050_059_PR_VVS1_D ['Wt Range'] = listwtrange
                    df_050_059_PR_VVS1_D ['Company'] = listcom
                    df_050_059_PR_VVS1_D ['Shape'] = listshap
                    df_050_059_PR_VVS1_D ['Carat'] = listcar
                    df_050_059_PR_VVS1_D ['Color'] = listcol
                    df_050_059_PR_VVS1_D ['Clarity'] = listclar
                    df_050_059_PR_VVS1_D ['Cut'] = listcut
                    df_050_059_PR_VVS1_D ['Polish'] = listpol
                    df_050_059_PR_VVS1_D ['Symmetry'] = listsym
                    df_050_059_PR_VVS1_D ['Ratio'] = listrat
                    df_050_059_PR_VVS1_D ['PPC'] = listdesc
                    df_050_059_PR_VVS1_D ['Total'] = listtotal
                    df_050_059_PR_VVS1_D['Carat'] = df_050_059_PR_VVS1_D['Carat'].astype('float64')
                    df_050_059_PR_VVS1_D['PPC'] = df_050_059_PR_VVS1_D['PPC'].astype('float64')
                    df_050_059_PR_VVS1_D['Total'] = df_050_059_PR_VVS1_D['Total'].astype('float64')
                    df_050_059_PR_VVS1_D['Total'] = df_050_059_PR_VVS1_D['Carat'] * df_050_059_PR_VVS1_D['PPC']



                elif i=="D" and j == "VVS2" and k == "PR" :
                    df_050_059_PR_VVS2_D = pd.DataFrame()
                    df_050_059_PR_VVS2_D ['Wt Range'] = None
                    df_050_059_PR_VVS2_D  = df_050_059_PR_VVS2_D.assign(Company=None)
                    df_050_059_PR_VVS2_D  = df_050_059_PR_VVS2_D.assign(Shape=None)
                    df_050_059_PR_VVS2_D  = df_050_059_PR_VVS2_D.assign(Carat=None)
                    df_050_059_PR_VVS2_D  = df_050_059_PR_VVS2_D.assign(Color=None)
                    df_050_059_PR_VVS2_D  = df_050_059_PR_VVS2_D.assign(Clarity=None)
                    df_050_059_PR_VVS2_D  = df_050_059_PR_VVS2_D.assign(Cut=None)
                    df_050_059_PR_VVS2_D  = df_050_059_PR_VVS2_D.assign(Polish=None)
                    df_050_059_PR_VVS2_D  = df_050_059_PR_VVS2_D.assign(Symmetry=None)
                    df_050_059_PR_VVS2_D  = df_050_059_PR_VVS2_D.assign(Ratio=None)
                    df_050_059_PR_VVS2_D  = df_050_059_PR_VVS2_D.assign(PPC=None)
                    df_050_059_PR_VVS2_D  = df_050_059_PR_VVS2_D.assign(Total=None)
                    df_050_059_PR_VVS2_D ['Wt Range'] = listwtrange
                    df_050_059_PR_VVS2_D ['Company'] = listcom
                    df_050_059_PR_VVS2_D ['Shape'] = listshap
                    df_050_059_PR_VVS2_D ['Carat'] = listcar
                    df_050_059_PR_VVS2_D ['Color'] = listcol
                    df_050_059_PR_VVS2_D ['Clarity'] = listclar
                    df_050_059_PR_VVS2_D ['Cut'] = listcut
                    df_050_059_PR_VVS2_D ['Polish'] = listpol
                    df_050_059_PR_VVS2_D ['Symmetry'] = listsym
                    df_050_059_PR_VVS2_D ['Ratio'] = listrat
                    df_050_059_PR_VVS2_D ['PPC'] = listdesc
                    df_050_059_PR_VVS2_D ['Total'] = listtotal
                    df_050_059_PR_VVS2_D['Carat'] = df_050_059_PR_VVS2_D['Carat'].astype('float64')
                    df_050_059_PR_VVS2_D['PPC'] = df_050_059_PR_VVS2_D['PPC'].astype('float64')
                    df_050_059_PR_VVS2_D['Total'] = df_050_059_PR_VVS2_D['Total'].astype('float64')
                    df_050_059_PR_VVS2_D['Total'] = df_050_059_PR_VVS2_D['Carat'] * df_050_059_PR_VVS2_D['PPC']



                elif i=="D" and j == "VS1" and k == "PR":
                    df_050_059_PR_VS1_D = pd.DataFrame()
                    df_050_059_PR_VS1_D ['Wt Range'] = None
                    df_050_059_PR_VS1_D  = df_050_059_PR_VS1_D.assign(Company=None)
                    df_050_059_PR_VS1_D  = df_050_059_PR_VS1_D.assign(Shape=None)
                    df_050_059_PR_VS1_D  = df_050_059_PR_VS1_D.assign(Carat=None)
                    df_050_059_PR_VS1_D  = df_050_059_PR_VS1_D.assign(Color=None)
                    df_050_059_PR_VS1_D  = df_050_059_PR_VS1_D.assign(Clarity=None)
                    df_050_059_PR_VS1_D  = df_050_059_PR_VS1_D.assign(Cut=None)
                    df_050_059_PR_VS1_D  = df_050_059_PR_VS1_D.assign(Polish=None)
                    df_050_059_PR_VS1_D  = df_050_059_PR_VS1_D.assign(Symmetry=None)
                    df_050_059_PR_VS1_D  = df_050_059_PR_VS1_D.assign(Ratio=None)
                    df_050_059_PR_VS1_D  = df_050_059_PR_VS1_D.assign(PPC=None)
                    df_050_059_PR_VS1_D  = df_050_059_PR_VS1_D.assign(Total=None)
                    df_050_059_PR_VS1_D ['Wt Range'] = listwtrange
                    df_050_059_PR_VS1_D ['Company'] = listcom
                    df_050_059_PR_VS1_D ['Shape'] = listshap
                    df_050_059_PR_VS1_D ['Carat'] = listcar
                    df_050_059_PR_VS1_D ['Color'] = listcol
                    df_050_059_PR_VS1_D ['Clarity'] = listclar
                    df_050_059_PR_VS1_D ['Cut'] = listcut
                    df_050_059_PR_VS1_D ['Polish'] = listpol
                    df_050_059_PR_VS1_D ['Symmetry'] = listsym
                    df_050_059_PR_VS1_D ['Ratio'] = listrat
                    df_050_059_PR_VS1_D ['PPC'] = listdesc
                    df_050_059_PR_VS1_D ['Total'] = listtotal
                    df_050_059_PR_VS1_D['Carat'] = df_050_059_PR_VS1_D['Carat'].astype('float64')
                    df_050_059_PR_VS1_D['PPC'] = df_050_059_PR_VS1_D['PPC'].astype('float64')
                    df_050_059_PR_VS1_D['Total'] = df_050_059_PR_VS1_D['Total'].astype('float64')
                    df_050_059_PR_VS1_D['Total'] = df_050_059_PR_VS1_D['Carat'] * df_050_059_PR_VS1_D['PPC']


                elif i=="D" and j == "VS2" and k == "PR":
                    df_050_059_PR_VS2_D = pd.DataFrame()
                    df_050_059_PR_VS2_D ['Wt Range'] = None
                    df_050_059_PR_VS2_D  = df_050_059_PR_VS2_D.assign(Company=None)
                    df_050_059_PR_VS2_D  = df_050_059_PR_VS2_D.assign(Shape=None)
                    df_050_059_PR_VS2_D  = df_050_059_PR_VS2_D.assign(Carat=None)
                    df_050_059_PR_VS2_D  = df_050_059_PR_VS2_D.assign(Color=None)
                    df_050_059_PR_VS2_D  = df_050_059_PR_VS2_D.assign(Clarity=None)
                    df_050_059_PR_VS2_D  = df_050_059_PR_VS2_D.assign(Cut=None)
                    df_050_059_PR_VS2_D  = df_050_059_PR_VS2_D.assign(Polish=None)
                    df_050_059_PR_VS2_D  = df_050_059_PR_VS2_D.assign(Symmetry=None)
                    df_050_059_PR_VS2_D  = df_050_059_PR_VS2_D.assign(Ratio=None)
                    df_050_059_PR_VS2_D  = df_050_059_PR_VS2_D.assign(PPC=None)
                    df_050_059_PR_VS2_D  = df_050_059_PR_VS2_D.assign(Total=None)
                    df_050_059_PR_VS2_D ['Wt Range'] = listwtrange
                    df_050_059_PR_VS2_D ['Company'] = listcom
                    df_050_059_PR_VS2_D ['Shape'] = listshap
                    df_050_059_PR_VS2_D ['Carat'] = listcar
                    df_050_059_PR_VS2_D ['Color'] = listcol
                    df_050_059_PR_VS2_D ['Clarity'] = listclar
                    df_050_059_PR_VS2_D ['Cut'] = listcut
                    df_050_059_PR_VS2_D ['Polish'] = listpol
                    df_050_059_PR_VS2_D ['Symmetry'] = listsym
                    df_050_059_PR_VS2_D ['Ratio'] = listrat
                    df_050_059_PR_VS2_D ['PPC'] = listdesc
                    df_050_059_PR_VS2_D ['Total'] = listtotal
                    df_050_059_PR_VS2_D['Carat'] = df_050_059_PR_VS2_D['Carat'].astype('float64')
                    df_050_059_PR_VS2_D['PPC'] = df_050_059_PR_VS2_D['PPC'].astype('float64')
                    df_050_059_PR_VS2_D['Total'] = df_050_059_PR_VS2_D['Total'].astype('float64')
                    df_050_059_PR_VS2_D['Total'] = df_050_059_PR_VS2_D['Carat'] * df_050_059_PR_VS2_D['PPC']


                elif i=="D" and j == "SI1" and k == "PR":
                    df_050_059_PR_SI1_D = pd.DataFrame()
                    df_050_059_PR_SI1_D ['Wt Range'] = None
                    df_050_059_PR_SI1_D  = df_050_059_PR_SI1_D.assign(Company=None)
                    df_050_059_PR_SI1_D  = df_050_059_PR_SI1_D.assign(Shape=None)
                    df_050_059_PR_SI1_D  = df_050_059_PR_SI1_D.assign(Carat=None)
                    df_050_059_PR_SI1_D  = df_050_059_PR_SI1_D.assign(Color=None)
                    df_050_059_PR_SI1_D  = df_050_059_PR_SI1_D.assign(Clarity=None)
                    df_050_059_PR_SI1_D  = df_050_059_PR_SI1_D.assign(Cut=None)
                    df_050_059_PR_SI1_D  = df_050_059_PR_SI1_D.assign(Polish=None)
                    df_050_059_PR_SI1_D  = df_050_059_PR_SI1_D.assign(Symmetry=None)
                    df_050_059_PR_SI1_D  = df_050_059_PR_SI1_D.assign(Ratio=None)
                    df_050_059_PR_SI1_D  = df_050_059_PR_SI1_D.assign(PPC=None)
                    df_050_059_PR_SI1_D  = df_050_059_PR_SI1_D.assign(Total=None)
                    df_050_059_PR_SI1_D ['Wt Range'] = listwtrange
                    df_050_059_PR_SI1_D ['Company'] = listcom
                    df_050_059_PR_SI1_D ['Shape'] = listshap
                    df_050_059_PR_SI1_D ['Carat'] = listcar
                    df_050_059_PR_SI1_D ['Color'] = listcol
                    df_050_059_PR_SI1_D ['Clarity'] = listclar
                    df_050_059_PR_SI1_D ['Cut'] = listcut
                    df_050_059_PR_SI1_D ['Polish'] = listpol
                    df_050_059_PR_SI1_D ['Symmetry'] = listsym
                    df_050_059_PR_SI1_D ['Ratio'] = listrat
                    df_050_059_PR_SI1_D ['PPC'] = listdesc
                    df_050_059_PR_SI1_D ['Total'] = listtotal
                    df_050_059_PR_SI1_D['Carat'] = df_050_059_PR_SI1_D['Carat'].astype('float64')
                    df_050_059_PR_SI1_D['PPC'] = df_050_059_PR_SI1_D['PPC'].astype('float64')
                    df_050_059_PR_SI1_D['Total'] = df_050_059_PR_SI1_D['Total'].astype('float64')
                    df_050_059_PR_SI1_D['Total'] = df_050_059_PR_SI1_D['Carat'] * df_050_059_PR_SI1_D['PPC']


                elif i=="D" and j == "SI2" and k == "PR":
                    df_050_059_PR_SI2_D = pd.DataFrame()
                    df_050_059_PR_SI2_D ['Wt Range'] = None
                    df_050_059_PR_SI2_D  = df_050_059_PR_SI2_D.assign(Company=None)
                    df_050_059_PR_SI2_D  = df_050_059_PR_SI2_D.assign(Shape=None)
                    df_050_059_PR_SI2_D  = df_050_059_PR_SI2_D.assign(Carat=None)
                    df_050_059_PR_SI2_D  = df_050_059_PR_SI2_D.assign(Color=None)
                    df_050_059_PR_SI2_D  = df_050_059_PR_SI2_D.assign(Clarity=None)
                    df_050_059_PR_SI2_D  = df_050_059_PR_SI2_D.assign(Cut=None)
                    df_050_059_PR_SI2_D  = df_050_059_PR_SI2_D.assign(Polish=None)
                    df_050_059_PR_SI2_D  = df_050_059_PR_SI2_D.assign(Symmetry=None)
                    df_050_059_PR_SI2_D  = df_050_059_PR_SI2_D.assign(Ratio=None)
                    df_050_059_PR_SI2_D  = df_050_059_PR_SI2_D.assign(PPC=None)
                    df_050_059_PR_SI2_D  = df_050_059_PR_SI2_D.assign(Total=None)
                    df_050_059_PR_SI2_D ['Wt Range'] = listwtrange
                    df_050_059_PR_SI2_D ['Company'] = listcom
                    df_050_059_PR_SI2_D ['Shape'] = listshap
                    df_050_059_PR_SI2_D ['Carat'] = listcar
                    df_050_059_PR_SI2_D ['Color'] = listcol
                    df_050_059_PR_SI2_D ['Clarity'] = listclar
                    df_050_059_PR_SI2_D ['Cut'] = listcut
                    df_050_059_PR_SI2_D ['Polish'] = listpol
                    df_050_059_PR_SI2_D ['Symmetry'] = listsym
                    df_050_059_PR_SI2_D ['Ratio'] = listrat
                    df_050_059_PR_SI2_D ['PPC'] = listdesc
                    df_050_059_PR_SI2_D ['Total'] = listtotal
                    df_050_059_PR_SI2_D['Carat'] = df_050_059_PR_SI2_D['Carat'].astype('float64')
                    df_050_059_PR_SI2_D['PPC'] = df_050_059_PR_SI2_D['PPC'].astype('float64')
                    df_050_059_PR_SI2_D['Total'] = df_050_059_PR_SI2_D['Total'].astype('float64')
                    df_050_059_PR_SI2_D['Total'] = df_050_059_PR_SI2_D['Carat'] * df_050_059_PR_SI2_D['PPC']


                elif i=="D" and j == "I1" and k == "PR":
                    df_050_059_PR_I1_D = pd.DataFrame()
                    df_050_059_PR_I1_D ['Wt Range'] = None
                    df_050_059_PR_I1_D  = df_050_059_PR_I1_D.assign(Company=None)
                    df_050_059_PR_I1_D  = df_050_059_PR_I1_D.assign(Shape=None)
                    df_050_059_PR_I1_D  = df_050_059_PR_I1_D.assign(Carat=None)
                    df_050_059_PR_I1_D  = df_050_059_PR_I1_D.assign(Color=None)
                    df_050_059_PR_I1_D  = df_050_059_PR_I1_D.assign(Clarity=None)
                    df_050_059_PR_I1_D  = df_050_059_PR_I1_D.assign(Cut=None)
                    df_050_059_PR_I1_D  = df_050_059_PR_I1_D.assign(Polish=None)
                    df_050_059_PR_I1_D  = df_050_059_PR_I1_D.assign(Symmetry=None)
                    df_050_059_PR_I1_D  = df_050_059_PR_I1_D.assign(Ratio=None)
                    df_050_059_PR_I1_D  = df_050_059_PR_I1_D.assign(PPC=None)
                    df_050_059_PR_I1_D  = df_050_059_PR_I1_D.assign(Total=None)
                    df_050_059_PR_I1_D ['Wt Range'] = listwtrange
                    df_050_059_PR_I1_D ['Company'] = listcom
                    df_050_059_PR_I1_D ['Shape'] = listshap
                    df_050_059_PR_I1_D ['Carat'] = listcar
                    df_050_059_PR_I1_D ['Color'] = listcol
                    df_050_059_PR_I1_D ['Clarity'] = listclar
                    df_050_059_PR_I1_D ['Cut'] = listcut
                    df_050_059_PR_I1_D ['Polish'] = listpol
                    df_050_059_PR_I1_D ['Symmetry'] = listsym
                    df_050_059_PR_I1_D ['Ratio'] = listrat
                    df_050_059_PR_I1_D ['PPC'] = listdesc
                    df_050_059_PR_I1_D ['Total'] = listtotal
                    df_050_059_PR_I1_D['Carat'] = df_050_059_PR_I1_D['Carat'].astype('float64')
                    df_050_059_PR_I1_D['PPC'] = df_050_059_PR_I1_D['PPC'].astype('float64')
                    df_050_059_PR_I1_D['Total'] = df_050_059_PR_I1_D['Total'].astype('float64')
                    df_050_059_PR_I1_D['Total'] = df_050_059_PR_I1_D['Carat'] * df_050_059_PR_I1_D['PPC']


                elif i=="D" and j == "I2" and k == "PR":
                    df_050_059_PR_I2_D = pd.DataFrame()
                    df_050_059_PR_I2_D ['Wt Range'] = None
                    df_050_059_PR_I2_D  = df_050_059_PR_I2_D.assign(Company=None)
                    df_050_059_PR_I2_D  = df_050_059_PR_I2_D.assign(Shape=None)
                    df_050_059_PR_I2_D  = df_050_059_PR_I2_D.assign(Carat=None)
                    df_050_059_PR_I2_D  = df_050_059_PR_I2_D.assign(Color=None)
                    df_050_059_PR_I2_D  = df_050_059_PR_I2_D.assign(Clarity=None)
                    df_050_059_PR_I2_D  = df_050_059_PR_I2_D.assign(Cut=None)
                    df_050_059_PR_I2_D  = df_050_059_PR_I2_D.assign(Polish=None)
                    df_050_059_PR_I2_D  = df_050_059_PR_I2_D.assign(Symmetry=None)
                    df_050_059_PR_I2_D  = df_050_059_PR_I2_D.assign(Ratio=None)
                    df_050_059_PR_I2_D  = df_050_059_PR_I2_D.assign(PPC=None)
                    df_050_059_PR_I2_D  = df_050_059_PR_I2_D.assign(Total=None)
                    df_050_059_PR_I2_D ['Wt Range'] = listwtrange
                    df_050_059_PR_I2_D ['Company'] = listcom
                    df_050_059_PR_I2_D ['Shape'] = listshap
                    df_050_059_PR_I2_D ['Carat'] = listcar
                    df_050_059_PR_I2_D ['Color'] = listcol
                    df_050_059_PR_I2_D ['Clarity'] = listclar
                    df_050_059_PR_I2_D ['Cut'] = listcut
                    df_050_059_PR_I2_D ['Polish'] = listpol
                    df_050_059_PR_I2_D ['Symmetry'] = listsym
                    df_050_059_PR_I2_D ['Ratio'] = listrat
                    df_050_059_PR_I2_D ['PPC'] = listdesc
                    df_050_059_PR_I2_D ['Total'] = listtotal
                    df_050_059_PR_I2_D['Carat'] = df_050_059_PR_I2_D['Carat'].astype('float64')
                    df_050_059_PR_I2_D['PPC'] = df_050_059_PR_I2_D['PPC'].astype('float64')
                    df_050_059_PR_I2_D['Total'] = df_050_059_PR_I2_D['Total'].astype('float64')
                    df_050_059_PR_I2_D['Total'] = df_050_059_PR_I2_D['Carat'] * df_050_059_PR_I2_D['PPC']



                elif i=="E" and j == "IF" and k == "PR":
                    df_050_059_PR_IF_E = pd.DataFrame()
                    df_050_059_PR_IF_E ['Wt Range'] = None
                    df_050_059_PR_IF_E  = df_050_059_PR_IF_E.assign(Company=None)
                    df_050_059_PR_IF_E  = df_050_059_PR_IF_E.assign(Shape=None)
                    df_050_059_PR_IF_E  = df_050_059_PR_IF_E.assign(Carat=None)
                    df_050_059_PR_IF_E  = df_050_059_PR_IF_E.assign(Color=None)
                    df_050_059_PR_IF_E  = df_050_059_PR_IF_E.assign(Clarity=None)
                    df_050_059_PR_IF_E  = df_050_059_PR_IF_E.assign(Cut=None)
                    df_050_059_PR_IF_E  = df_050_059_PR_IF_E.assign(Polish=None)
                    df_050_059_PR_IF_E  = df_050_059_PR_IF_E.assign(Symmetry=None)
                    df_050_059_PR_IF_E  = df_050_059_PR_IF_E.assign(Ratio=None)
                    df_050_059_PR_IF_E  = df_050_059_PR_IF_E.assign(PPC=None)
                    df_050_059_PR_IF_E  = df_050_059_PR_IF_E.assign(Total=None)
                    df_050_059_PR_IF_E ['Wt Range'] = listwtrange
                    df_050_059_PR_IF_E ['Company'] = listcom
                    df_050_059_PR_IF_E ['Shape'] = listshap
                    df_050_059_PR_IF_E ['Carat'] = listcar
                    df_050_059_PR_IF_E ['Color'] = listcol
                    df_050_059_PR_IF_E ['Clarity'] = listclar
                    df_050_059_PR_IF_E ['Cut'] = listcut
                    df_050_059_PR_IF_E ['Polish'] = listpol
                    df_050_059_PR_IF_E ['Symmetry'] = listsym
                    df_050_059_PR_IF_E ['Ratio'] = listrat
                    df_050_059_PR_IF_E ['PPC'] = listdesc
                    df_050_059_PR_IF_E ['Total'] = listtotal
                    df_050_059_PR_IF_E['Carat'] = df_050_059_PR_IF_E['Carat'].astype('float64')
                    df_050_059_PR_IF_E['PPC'] = df_050_059_PR_IF_E['PPC'].astype('float64')
                    df_050_059_PR_IF_E['Total'] = df_050_059_PR_IF_E['Total'].astype('float64')
                    df_050_059_PR_IF_E['Total'] = df_050_059_PR_IF_E['Carat'] * df_050_059_PR_IF_E['PPC']



                elif i=="E" and j == "VVS1" and k == "PR":
                    df_050_059_PR_VVS1_E = pd.DataFrame()
                    df_050_059_PR_VVS1_E ['Wt Range'] = None
                    df_050_059_PR_VVS1_E  = df_050_059_PR_VVS1_E.assign(Company=None)
                    df_050_059_PR_VVS1_E  = df_050_059_PR_VVS1_E.assign(Shape=None)
                    df_050_059_PR_VVS1_E  = df_050_059_PR_VVS1_E.assign(Carat=None)
                    df_050_059_PR_VVS1_E  = df_050_059_PR_VVS1_E.assign(Color=None)
                    df_050_059_PR_VVS1_E  = df_050_059_PR_VVS1_E.assign(Clarity=None)
                    df_050_059_PR_VVS1_E  = df_050_059_PR_VVS1_E.assign(Cut=None)
                    df_050_059_PR_VVS1_E  = df_050_059_PR_VVS1_E.assign(Polish=None)
                    df_050_059_PR_VVS1_E  = df_050_059_PR_VVS1_E.assign(Symmetry=None)
                    df_050_059_PR_VVS1_E  = df_050_059_PR_VVS1_E.assign(Ratio=None)
                    df_050_059_PR_VVS1_E  = df_050_059_PR_VVS1_E.assign(PPC=None)
                    df_050_059_PR_VVS1_E  = df_050_059_PR_VVS1_E.assign(Total=None)
                    df_050_059_PR_VVS1_E ['Wt Range'] = listwtrange
                    df_050_059_PR_VVS1_E ['Company'] = listcom
                    df_050_059_PR_VVS1_E ['Shape'] = listshap
                    df_050_059_PR_VVS1_E ['Carat'] = listcar
                    df_050_059_PR_VVS1_E ['Color'] = listcol
                    df_050_059_PR_VVS1_E ['Clarity'] = listclar
                    df_050_059_PR_VVS1_E ['Cut'] = listcut
                    df_050_059_PR_VVS1_E ['Polish'] = listpol
                    df_050_059_PR_VVS1_E ['Symmetry'] = listsym
                    df_050_059_PR_VVS1_E ['Ratio'] = listrat
                    df_050_059_PR_VVS1_E ['PPC'] = listdesc
                    df_050_059_PR_VVS1_E ['Total'] = listtotal
                    df_050_059_PR_VVS1_E['Carat'] = df_050_059_PR_VVS1_E['Carat'].astype('float64')
                    df_050_059_PR_VVS1_E['PPC'] = df_050_059_PR_VVS1_E['PPC'].astype('float64')
                    df_050_059_PR_VVS1_E['Total'] = df_050_059_PR_VVS1_E['Total'].astype('float64')
                    df_050_059_PR_VVS1_E['Total'] = df_050_059_PR_VVS1_E['Carat'] * df_050_059_PR_VVS1_E['PPC']


                elif i=="E" and j == "VVS2" and k == "PR":
                    df_050_059_PR_VVS2_E = pd.DataFrame()
                    df_050_059_PR_VVS2_E ['Wt Range'] = None
                    df_050_059_PR_VVS2_E  = df_050_059_PR_VVS2_E.assign(Company=None)
                    df_050_059_PR_VVS2_E  = df_050_059_PR_VVS2_E.assign(Shape=None)
                    df_050_059_PR_VVS2_E  = df_050_059_PR_VVS2_E.assign(Carat=None)
                    df_050_059_PR_VVS2_E  = df_050_059_PR_VVS2_E.assign(Color=None)
                    df_050_059_PR_VVS2_E  = df_050_059_PR_VVS2_E.assign(Clarity=None)
                    df_050_059_PR_VVS2_E  = df_050_059_PR_VVS2_E.assign(Cut=None)
                    df_050_059_PR_VVS2_E  = df_050_059_PR_VVS2_E.assign(Polish=None)
                    df_050_059_PR_VVS2_E  = df_050_059_PR_VVS2_E.assign(Symmetry=None)
                    df_050_059_PR_VVS2_E  = df_050_059_PR_VVS2_E.assign(Ratio=None)
                    df_050_059_PR_VVS2_E  = df_050_059_PR_VVS2_E.assign(PPC=None)
                    df_050_059_PR_VVS2_E  = df_050_059_PR_VVS2_E.assign(Total=None)
                    df_050_059_PR_VVS2_E ['Wt Range'] = listwtrange
                    df_050_059_PR_VVS2_E ['Company'] = listcom
                    df_050_059_PR_VVS2_E ['Shape'] = listshap
                    df_050_059_PR_VVS2_E ['Carat'] = listcar
                    df_050_059_PR_VVS2_E ['Color'] = listcol
                    df_050_059_PR_VVS2_E ['Clarity'] = listclar
                    df_050_059_PR_VVS2_E ['Cut'] = listcut
                    df_050_059_PR_VVS2_E ['Polish'] = listpol
                    df_050_059_PR_VVS2_E ['Symmetry'] = listsym
                    df_050_059_PR_VVS2_E ['Ratio'] = listrat
                    df_050_059_PR_VVS2_E ['PPC'] = listdesc
                    df_050_059_PR_VVS2_E ['Total'] = listtotal
                    df_050_059_PR_VVS2_E['Carat'] = df_050_059_PR_VVS2_E['Carat'].astype('float64')
                    df_050_059_PR_VVS2_E['PPC'] = df_050_059_PR_VVS2_E['PPC'].astype('float64')
                    df_050_059_PR_VVS2_E['Total'] = df_050_059_PR_VVS2_E['Total'].astype('float64')
                    df_050_059_PR_VVS2_E['Total'] = df_050_059_PR_VVS2_E['Carat'] * df_050_059_PR_VVS2_E['PPC']


                elif i=="E" and j=="VS1" and k == "PR":
                    df_050_059_PR_VS1_E = pd.DataFrame()
                    df_050_059_PR_VS1_E ['Wt Range'] = None
                    df_050_059_PR_VS1_E  = df_050_059_PR_VS1_E.assign(Company=None)
                    df_050_059_PR_VS1_E  = df_050_059_PR_VS1_E.assign(Shape=None)
                    df_050_059_PR_VS1_E  = df_050_059_PR_VS1_E.assign(Carat=None)
                    df_050_059_PR_VS1_E  = df_050_059_PR_VS1_E.assign(Color=None)
                    df_050_059_PR_VS1_E  = df_050_059_PR_VS1_E.assign(Clarity=None)
                    df_050_059_PR_VS1_E  = df_050_059_PR_VS1_E.assign(Cut=None)
                    df_050_059_PR_VS1_E  = df_050_059_PR_VS1_E.assign(Polish=None)
                    df_050_059_PR_VS1_E  = df_050_059_PR_VS1_E.assign(Symmetry=None)
                    df_050_059_PR_VS1_E  = df_050_059_PR_VS1_E.assign(Ratio=None)
                    df_050_059_PR_VS1_E  = df_050_059_PR_VS1_E.assign(PPC=None)
                    df_050_059_PR_VS1_E  = df_050_059_PR_VS1_E.assign(Total=None)
                    df_050_059_PR_VS1_E ['Wt Range'] = listwtrange
                    df_050_059_PR_VS1_E ['Company'] = listcom
                    df_050_059_PR_VS1_E ['Shape'] = listshap
                    df_050_059_PR_VS1_E ['Carat'] = listcar
                    df_050_059_PR_VS1_E ['Color'] = listcol
                    df_050_059_PR_VS1_E ['Clarity'] = listclar
                    df_050_059_PR_VS1_E ['Cut'] = listcut
                    df_050_059_PR_VS1_E ['Polish'] = listpol
                    df_050_059_PR_VS1_E ['Symmetry'] = listsym
                    df_050_059_PR_VS1_E ['Ratio'] = listrat
                    df_050_059_PR_VS1_E ['PPC'] = listdesc
                    df_050_059_PR_VS1_E ['Total'] = listtotal
                    df_050_059_PR_VS1_E['Carat'] = df_050_059_PR_VS1_E['Carat'].astype('float64')
                    df_050_059_PR_VS1_E['PPC'] = df_050_059_PR_VS1_E['PPC'].astype('float64')
                    df_050_059_PR_VS1_E['Total'] = df_050_059_PR_VS1_E['Total'].astype('float64')
                    df_050_059_PR_VS1_E['Total'] = df_050_059_PR_VS1_E['Carat'] * df_050_059_PR_VS1_E['PPC']


                elif i=="E" and j == "VS2" and k == "PR":
                    df_050_059_PR_VS2_E = pd.DataFrame()
                    df_050_059_PR_VS2_E ['Wt Range'] = None
                    df_050_059_PR_VS2_E  = df_050_059_PR_VS2_E.assign(Company=None)
                    df_050_059_PR_VS2_E  = df_050_059_PR_VS2_E.assign(Shape=None)
                    df_050_059_PR_VS2_E  = df_050_059_PR_VS2_E.assign(Carat=None)
                    df_050_059_PR_VS2_E  = df_050_059_PR_VS2_E.assign(Color=None)
                    df_050_059_PR_VS2_E  = df_050_059_PR_VS2_E.assign(Clarity=None)
                    df_050_059_PR_VS2_E  = df_050_059_PR_VS2_E.assign(Cut=None)
                    df_050_059_PR_VS2_E  = df_050_059_PR_VS2_E.assign(Polish=None)
                    df_050_059_PR_VS2_E  = df_050_059_PR_VS2_E.assign(Symmetry=None)
                    df_050_059_PR_VS2_E  = df_050_059_PR_VS2_E.assign(Ratio=None)
                    df_050_059_PR_VS2_E  = df_050_059_PR_VS2_E.assign(PPC=None)
                    df_050_059_PR_VS2_E  = df_050_059_PR_VS2_E.assign(Total=None)
                    df_050_059_PR_VS2_E ['Wt Range'] = listwtrange
                    df_050_059_PR_VS2_E ['Company'] = listcom
                    df_050_059_PR_VS2_E ['Shape'] = listshap
                    df_050_059_PR_VS2_E ['Carat'] = listcar
                    df_050_059_PR_VS2_E ['Color'] = listcol
                    df_050_059_PR_VS2_E ['Clarity'] = listclar
                    df_050_059_PR_VS2_E ['Cut'] = listcut
                    df_050_059_PR_VS2_E ['Polish'] = listpol
                    df_050_059_PR_VS2_E ['Symmetry'] = listsym
                    df_050_059_PR_VS2_E ['Ratio'] = listrat
                    df_050_059_PR_VS2_E ['PPC'] = listdesc
                    df_050_059_PR_VS2_E ['Total'] = listtotal
                    df_050_059_PR_VS2_E['Carat'] = df_050_059_PR_VS2_E['Carat'].astype('float64')
                    df_050_059_PR_VS2_E['PPC'] = df_050_059_PR_VS2_E['PPC'].astype('float64')
                    df_050_059_PR_VS2_E['Total'] = df_050_059_PR_VS2_E['Total'].astype('float64')
                    df_050_059_PR_VS2_E['Total'] = df_050_059_PR_VS2_E['Carat'] * df_050_059_PR_VS2_E['PPC']


                elif i=="E" and j == "SI1" and k == "PR":
                    df_050_059_PR_SI1_E = pd.DataFrame()
                    df_050_059_PR_SI1_E ['Wt Range'] = None
                    df_050_059_PR_SI1_E  = df_050_059_PR_SI1_E.assign(Company=None)
                    df_050_059_PR_SI1_E  = df_050_059_PR_SI1_E.assign(Shape=None)
                    df_050_059_PR_SI1_E  = df_050_059_PR_SI1_E.assign(Carat=None)
                    df_050_059_PR_SI1_E  = df_050_059_PR_SI1_E.assign(Color=None)
                    df_050_059_PR_SI1_E  = df_050_059_PR_SI1_E.assign(Clarity=None)
                    df_050_059_PR_SI1_E  = df_050_059_PR_SI1_E.assign(Cut=None)
                    df_050_059_PR_SI1_E  = df_050_059_PR_SI1_E.assign(Polish=None)
                    df_050_059_PR_SI1_E  = df_050_059_PR_SI1_E.assign(Symmetry=None)
                    df_050_059_PR_SI1_E  = df_050_059_PR_SI1_E.assign(Ratio=None)
                    df_050_059_PR_SI1_E  = df_050_059_PR_SI1_E.assign(PPC=None)
                    df_050_059_PR_SI1_E  = df_050_059_PR_SI1_E.assign(Total=None)
                    df_050_059_PR_SI1_E ['Wt Range'] = listwtrange
                    df_050_059_PR_SI1_E ['Company'] = listcom
                    df_050_059_PR_SI1_E ['Shape'] = listshap
                    df_050_059_PR_SI1_E ['Carat'] = listcar
                    df_050_059_PR_SI1_E ['Color'] = listcol
                    df_050_059_PR_SI1_E ['Clarity'] = listclar
                    df_050_059_PR_SI1_E ['Cut'] = listcut
                    df_050_059_PR_SI1_E ['Polish'] = listpol
                    df_050_059_PR_SI1_E ['Symmetry'] = listsym
                    df_050_059_PR_SI1_E ['Ratio'] = listrat
                    df_050_059_PR_SI1_E ['PPC'] = listdesc
                    df_050_059_PR_SI1_E ['Total'] = listtotal
                    df_050_059_PR_SI1_E['Carat'] = df_050_059_PR_SI1_E['Carat'].astype('float64')
                    df_050_059_PR_SI1_E['PPC'] = df_050_059_PR_SI1_E['PPC'].astype('float64')
                    df_050_059_PR_SI1_E['Total'] = df_050_059_PR_SI1_E['Total'].astype('float64')
                    df_050_059_PR_SI1_E['Total'] = df_050_059_PR_SI1_E['Carat'] * df_050_059_PR_SI1_E['PPC']


                elif i=="E" and j == "SI2" and k == "PR":
                    df_050_059_PR_SI2_E = pd.DataFrame()
                    df_050_059_PR_SI2_E ['Wt Range'] = None
                    df_050_059_PR_SI2_E  = df_050_059_PR_SI2_E.assign(Company=None)
                    df_050_059_PR_SI2_E  = df_050_059_PR_SI2_E.assign(Shape=None)
                    df_050_059_PR_SI2_E  = df_050_059_PR_SI2_E.assign(Carat=None)
                    df_050_059_PR_SI2_E  = df_050_059_PR_SI2_E.assign(Color=None)
                    df_050_059_PR_SI2_E  = df_050_059_PR_SI2_E.assign(Clarity=None)
                    df_050_059_PR_SI2_E  = df_050_059_PR_SI2_E.assign(Cut=None)
                    df_050_059_PR_SI2_E  = df_050_059_PR_SI2_E.assign(Polish=None)
                    df_050_059_PR_SI2_E  = df_050_059_PR_SI2_E.assign(Symmetry=None)
                    df_050_059_PR_SI2_E  = df_050_059_PR_SI2_E.assign(Ratio=None)
                    df_050_059_PR_SI2_E  = df_050_059_PR_SI2_E.assign(PPC=None)
                    df_050_059_PR_SI2_E  = df_050_059_PR_SI2_E.assign(Total=None)
                    df_050_059_PR_SI2_E ['Wt Range'] = listwtrange
                    df_050_059_PR_SI2_E ['Company'] = listcom
                    df_050_059_PR_SI2_E ['Shape'] = listshap
                    df_050_059_PR_SI2_E ['Carat'] = listcar
                    df_050_059_PR_SI2_E ['Color'] = listcol
                    df_050_059_PR_SI2_E ['Clarity'] = listclar
                    df_050_059_PR_SI2_E ['Cut'] = listcut
                    df_050_059_PR_SI2_E ['Polish'] = listpol
                    df_050_059_PR_SI2_E ['Symmetry'] = listsym
                    df_050_059_PR_SI2_E ['Ratio'] = listrat
                    df_050_059_PR_SI2_E ['PPC'] = listdesc
                    df_050_059_PR_SI2_E ['Total'] = listtotal
                    df_050_059_PR_SI2_E['Carat'] = df_050_059_PR_SI2_E['Carat'].astype('float64')
                    df_050_059_PR_SI2_E['PPC'] = df_050_059_PR_SI2_E['PPC'].astype('float64')
                    df_050_059_PR_SI2_E['Total'] = df_050_059_PR_SI2_E['Total'].astype('float64')
                    df_050_059_PR_SI2_E['Total'] = df_050_059_PR_SI2_E['Carat'] * df_050_059_PR_SI2_E['PPC']


                elif i=="E" and j == "I1" and k == "PR":
                    df_050_059_PR_I1_E = pd.DataFrame()
                    df_050_059_PR_I1_E ['Wt Range'] = None
                    df_050_059_PR_I1_E  = df_050_059_PR_I1_E.assign(Company=None)
                    df_050_059_PR_I1_E  = df_050_059_PR_I1_E.assign(Shape=None)
                    df_050_059_PR_I1_E  = df_050_059_PR_I1_E.assign(Carat=None)
                    df_050_059_PR_I1_E  = df_050_059_PR_I1_E.assign(Color=None)
                    df_050_059_PR_I1_E  = df_050_059_PR_I1_E.assign(Clarity=None)
                    df_050_059_PR_I1_E  = df_050_059_PR_I1_E.assign(Cut=None)
                    df_050_059_PR_I1_E  = df_050_059_PR_I1_E.assign(Polish=None)
                    df_050_059_PR_I1_E  = df_050_059_PR_I1_E.assign(Symmetry=None)
                    df_050_059_PR_I1_E  = df_050_059_PR_I1_E.assign(Ratio=None)
                    df_050_059_PR_I1_E  = df_050_059_PR_I1_E.assign(PPC=None)
                    df_050_059_PR_I1_E  = df_050_059_PR_I1_E.assign(Total=None)
                    df_050_059_PR_I1_E ['Wt Range'] = listwtrange
                    df_050_059_PR_I1_E ['Company'] = listcom
                    df_050_059_PR_I1_E ['Shape'] = listshap
                    df_050_059_PR_I1_E ['Carat'] = listcar
                    df_050_059_PR_I1_E ['Color'] = listcol
                    df_050_059_PR_I1_E ['Clarity'] = listclar
                    df_050_059_PR_I1_E ['Cut'] = listcut
                    df_050_059_PR_I1_E ['Polish'] = listpol
                    df_050_059_PR_I1_E ['Symmetry'] = listsym
                    df_050_059_PR_I1_E ['Ratio'] = listrat
                    df_050_059_PR_I1_E ['PPC'] = listdesc
                    df_050_059_PR_I1_E ['Total'] = listtotal
                    df_050_059_PR_I1_E['Carat'] = df_050_059_PR_I1_E['Carat'].astype('float64')
                    df_050_059_PR_I1_E['PPC'] = df_050_059_PR_I1_E['PPC'].astype('float64')
                    df_050_059_PR_I1_E['Total'] = df_050_059_PR_I1_E['Total'].astype('float64')
                    df_050_059_PR_I1_E['Total'] = df_050_059_PR_I1_E['Carat'] * df_050_059_PR_I1_E['PPC']


                elif i=="E" and j == "I2" and k == "PR":
                    df_050_059_PR_I2_E = pd.DataFrame()
                    df_050_059_PR_I2_E ['Wt Range'] = None
                    df_050_059_PR_I2_E  = df_050_059_PR_I2_E.assign(Company=None)
                    df_050_059_PR_I2_E  = df_050_059_PR_I2_E.assign(Shape=None)
                    df_050_059_PR_I2_E  = df_050_059_PR_I2_E.assign(Carat=None)
                    df_050_059_PR_I2_E  = df_050_059_PR_I2_E.assign(Color=None)
                    df_050_059_PR_I2_E  = df_050_059_PR_I2_E.assign(Clarity=None)
                    df_050_059_PR_I2_E  = df_050_059_PR_I2_E.assign(Cut=None)
                    df_050_059_PR_I2_E  = df_050_059_PR_I2_E.assign(Polish=None)
                    df_050_059_PR_I2_E  = df_050_059_PR_I2_E.assign(Symmetry=None)
                    df_050_059_PR_I2_E  = df_050_059_PR_I2_E.assign(Ratio=None)
                    df_050_059_PR_I2_E  = df_050_059_PR_I2_E.assign(PPC=None)
                    df_050_059_PR_I2_E  = df_050_059_PR_I2_E.assign(Total=None)
                    df_050_059_PR_I2_E ['Wt Range'] = listwtrange
                    df_050_059_PR_I2_E ['Company'] = listcom
                    df_050_059_PR_I2_E ['Shape'] = listshap
                    df_050_059_PR_I2_E ['Carat'] = listcar
                    df_050_059_PR_I2_E ['Color'] = listcol
                    df_050_059_PR_I2_E ['Clarity'] = listclar
                    df_050_059_PR_I2_E ['Cut'] = listcut
                    df_050_059_PR_I2_E ['Polish'] = listpol
                    df_050_059_PR_I2_E ['Symmetry'] = listsym
                    df_050_059_PR_I2_E ['Ratio'] = listrat
                    df_050_059_PR_I2_E ['PPC'] = listdesc
                    df_050_059_PR_I2_E ['Total'] = listtotal
                    df_050_059_PR_I2_E['Carat'] = df_050_059_PR_I2_E['Carat'].astype('float64')
                    df_050_059_PR_I2_E['PPC'] = df_050_059_PR_I2_E['PPC'].astype('float64')
                    df_050_059_PR_I2_E['Total'] = df_050_059_PR_I2_E['Total'].astype('float64')
                    df_050_059_PR_I2_E['Total'] = df_050_059_PR_I2_E['Carat'] * df_050_059_PR_I2_E['PPC']
                
                elif i=="F" and j == "IF" and k == "PR":
                    df_050_059_PR_IF_F = pd.DataFrame()
                    df_050_059_PR_IF_F ['Wt Range'] = None
                    df_050_059_PR_IF_F  = df_050_059_PR_IF_F.assign(Company=None)
                    df_050_059_PR_IF_F  = df_050_059_PR_IF_F.assign(Shape=None)
                    df_050_059_PR_IF_F  = df_050_059_PR_IF_F.assign(Carat=None)
                    df_050_059_PR_IF_F  = df_050_059_PR_IF_F.assign(Color=None)
                    df_050_059_PR_IF_F  = df_050_059_PR_IF_F.assign(Clarity=None)
                    df_050_059_PR_IF_F  = df_050_059_PR_IF_F.assign(Cut=None)
                    df_050_059_PR_IF_F  = df_050_059_PR_IF_F.assign(Polish=None)
                    df_050_059_PR_IF_F  = df_050_059_PR_IF_F.assign(Symmetry=None)
                    df_050_059_PR_IF_F  = df_050_059_PR_IF_F.assign(Ratio=None)
                    df_050_059_PR_IF_F  = df_050_059_PR_IF_F.assign(PPC=None)
                    df_050_059_PR_IF_F  = df_050_059_PR_IF_F.assign(Total=None)
                    df_050_059_PR_IF_F ['Wt Range'] = listwtrange
                    df_050_059_PR_IF_F ['Company'] = listcom
                    df_050_059_PR_IF_F ['Shape'] = listshap
                    df_050_059_PR_IF_F ['Carat'] = listcar
                    df_050_059_PR_IF_F ['Color'] = listcol
                    df_050_059_PR_IF_F ['Clarity'] = listclar
                    df_050_059_PR_IF_F ['Cut'] = listcut
                    df_050_059_PR_IF_F ['Polish'] = listpol
                    df_050_059_PR_IF_F ['Symmetry'] = listsym
                    df_050_059_PR_IF_F ['Ratio'] = listrat
                    df_050_059_PR_IF_F ['PPC'] = listdesc
                    df_050_059_PR_IF_F ['Total'] = listtotal
                    df_050_059_PR_IF_F['Carat'] = df_050_059_PR_IF_F['Carat'].astype('float64')
                    df_050_059_PR_IF_F['PPC'] = df_050_059_PR_IF_F['PPC'].astype('float64')
                    df_050_059_PR_IF_F['Total'] = df_050_059_PR_IF_F['Total'].astype('float64')
                    df_050_059_PR_IF_F['Total'] = df_050_059_PR_IF_F['Carat'] * df_050_059_PR_IF_F['PPC']



                elif i=="F" and j == "VVS1" and k == "PR":
                    df_050_059_PR_VVS1_F = pd.DataFrame()
                    df_050_059_PR_VVS1_F ['Wt Range'] = None
                    df_050_059_PR_VVS1_F  = df_050_059_PR_VVS1_F.assign(Company=None)
                    df_050_059_PR_VVS1_F  = df_050_059_PR_VVS1_F.assign(Shape=None)
                    df_050_059_PR_VVS1_F  = df_050_059_PR_VVS1_F.assign(Carat=None)
                    df_050_059_PR_VVS1_F  = df_050_059_PR_VVS1_F.assign(Color=None)
                    df_050_059_PR_VVS1_F  = df_050_059_PR_VVS1_F.assign(Clarity=None)
                    df_050_059_PR_VVS1_F  = df_050_059_PR_VVS1_F.assign(Cut=None)
                    df_050_059_PR_VVS1_F  = df_050_059_PR_VVS1_F.assign(Polish=None)
                    df_050_059_PR_VVS1_F  = df_050_059_PR_VVS1_F.assign(Symmetry=None)
                    df_050_059_PR_VVS1_F  = df_050_059_PR_VVS1_F.assign(Ratio=None)
                    df_050_059_PR_VVS1_F  = df_050_059_PR_VVS1_F.assign(PPC=None)
                    df_050_059_PR_VVS1_F  = df_050_059_PR_VVS1_F.assign(Total=None)
                    df_050_059_PR_VVS1_F ['Wt Range'] = listwtrange
                    df_050_059_PR_VVS1_F ['Company'] = listcom
                    df_050_059_PR_VVS1_F ['Shape'] = listshap
                    df_050_059_PR_VVS1_F ['Carat'] = listcar
                    df_050_059_PR_VVS1_F ['Color'] = listcol
                    df_050_059_PR_VVS1_F ['Clarity'] = listclar
                    df_050_059_PR_VVS1_F ['Cut'] = listcut
                    df_050_059_PR_VVS1_F ['Polish'] = listpol
                    df_050_059_PR_VVS1_F ['Symmetry'] = listsym
                    df_050_059_PR_VVS1_F ['Ratio'] = listrat
                    df_050_059_PR_VVS1_F ['PPC'] = listdesc
                    df_050_059_PR_VVS1_F ['Total'] = listtotal
                    df_050_059_PR_VVS1_F['Carat'] = df_050_059_PR_VVS1_F['Carat'].astype('float64')
                    df_050_059_PR_VVS1_F['PPC'] = df_050_059_PR_VVS1_F['PPC'].astype('float64')
                    df_050_059_PR_VVS1_F['Total'] = df_050_059_PR_VVS1_F['Total'].astype('float64')
                    df_050_059_PR_VVS1_F['Total'] = df_050_059_PR_VVS1_F['Carat'] * df_050_059_PR_VVS1_F['PPC']


                elif i=="F" and j == "VVS2" and k == "PR":
                    df_050_059_PR_VVS2_F = pd.DataFrame()
                    df_050_059_PR_VVS2_F ['Wt Range'] = None
                    df_050_059_PR_VVS2_F  = df_050_059_PR_VVS2_F.assign(Company=None)
                    df_050_059_PR_VVS2_F  = df_050_059_PR_VVS2_F.assign(Shape=None)
                    df_050_059_PR_VVS2_F  = df_050_059_PR_VVS2_F.assign(Carat=None)
                    df_050_059_PR_VVS2_F  = df_050_059_PR_VVS2_F.assign(Color=None)
                    df_050_059_PR_VVS2_F  = df_050_059_PR_VVS2_F.assign(Clarity=None)
                    df_050_059_PR_VVS2_F  = df_050_059_PR_VVS2_F.assign(Cut=None)
                    df_050_059_PR_VVS2_F  = df_050_059_PR_VVS2_F.assign(Polish=None)
                    df_050_059_PR_VVS2_F  = df_050_059_PR_VVS2_F.assign(Symmetry=None)
                    df_050_059_PR_VVS2_F  = df_050_059_PR_VVS2_F.assign(Ratio=None)
                    df_050_059_PR_VVS2_F  = df_050_059_PR_VVS2_F.assign(PPC=None)
                    df_050_059_PR_VVS2_F  = df_050_059_PR_VVS2_F.assign(Total=None)
                    df_050_059_PR_VVS2_F ['Wt Range'] = listwtrange
                    df_050_059_PR_VVS2_F ['Company'] = listcom
                    df_050_059_PR_VVS2_F ['Shape'] = listshap
                    df_050_059_PR_VVS2_F ['Carat'] = listcar
                    df_050_059_PR_VVS2_F ['Color'] = listcol
                    df_050_059_PR_VVS2_F ['Clarity'] = listclar
                    df_050_059_PR_VVS2_F ['Cut'] = listcut
                    df_050_059_PR_VVS2_F ['Polish'] = listpol
                    df_050_059_PR_VVS2_F ['Symmetry'] = listsym
                    df_050_059_PR_VVS2_F ['Ratio'] = listrat
                    df_050_059_PR_VVS2_F ['PPC'] = listdesc
                    df_050_059_PR_VVS2_F ['Total'] = listtotal
                    df_050_059_PR_VVS2_F['Carat'] = df_050_059_PR_VVS2_F['Carat'].astype('float64')
                    df_050_059_PR_VVS2_F['PPC'] = df_050_059_PR_VVS2_F['PPC'].astype('float64')
                    df_050_059_PR_VVS2_F['Total'] = df_050_059_PR_VVS2_F['Total'].astype('float64')
                    df_050_059_PR_VVS2_F['Total'] = df_050_059_PR_VVS2_F['Carat'] * df_050_059_PR_VVS2_F['PPC']


                elif i=="F" and j=="VS1" and k == "PR":
                    df_050_059_PR_VS1_F = pd.DataFrame()
                    df_050_059_PR_VS1_F ['Wt Range'] = None
                    df_050_059_PR_VS1_F  = df_050_059_PR_VS1_F.assign(Company=None)
                    df_050_059_PR_VS1_F  = df_050_059_PR_VS1_F.assign(Shape=None)
                    df_050_059_PR_VS1_F  = df_050_059_PR_VS1_F.assign(Carat=None)
                    df_050_059_PR_VS1_F  = df_050_059_PR_VS1_F.assign(Color=None)
                    df_050_059_PR_VS1_F  = df_050_059_PR_VS1_F.assign(Clarity=None)
                    df_050_059_PR_VS1_F  = df_050_059_PR_VS1_F.assign(Cut=None)
                    df_050_059_PR_VS1_F  = df_050_059_PR_VS1_F.assign(Polish=None)
                    df_050_059_PR_VS1_F  = df_050_059_PR_VS1_F.assign(Symmetry=None)
                    df_050_059_PR_VS1_F  = df_050_059_PR_VS1_F.assign(Ratio=None)
                    df_050_059_PR_VS1_F  = df_050_059_PR_VS1_F.assign(PPC=None)
                    df_050_059_PR_VS1_F  = df_050_059_PR_VS1_F.assign(Total=None)
                    df_050_059_PR_VS1_F ['Wt Range'] = listwtrange
                    df_050_059_PR_VS1_F ['Company'] = listcom
                    df_050_059_PR_VS1_F ['Shape'] = listshap
                    df_050_059_PR_VS1_F ['Carat'] = listcar
                    df_050_059_PR_VS1_F ['Color'] = listcol
                    df_050_059_PR_VS1_F ['Clarity'] = listclar
                    df_050_059_PR_VS1_F ['Cut'] = listcut
                    df_050_059_PR_VS1_F ['Polish'] = listpol
                    df_050_059_PR_VS1_F ['Symmetry'] = listsym
                    df_050_059_PR_VS1_F ['Ratio'] = listrat
                    df_050_059_PR_VS1_F ['PPC'] = listdesc
                    df_050_059_PR_VS1_F ['Total'] = listtotal
                    df_050_059_PR_VS1_F['Carat'] = df_050_059_PR_VS1_F['Carat'].astype('float64')
                    df_050_059_PR_VS1_F['PPC'] = df_050_059_PR_VS1_F['PPC'].astype('float64')
                    df_050_059_PR_VS1_F['Total'] = df_050_059_PR_VS1_F['Total'].astype('float64')
                    df_050_059_PR_VS1_F['Total'] = df_050_059_PR_VS1_F['Carat'] * df_050_059_PR_VS1_F['PPC']


                elif i=="F" and j == "VS2" and k == "PR":
                    df_050_059_PR_VS2_F = pd.DataFrame()
                    df_050_059_PR_VS2_F ['Wt Range'] = None
                    df_050_059_PR_VS2_F  = df_050_059_PR_VS2_F.assign(Company=None)
                    df_050_059_PR_VS2_F  = df_050_059_PR_VS2_F.assign(Shape=None)
                    df_050_059_PR_VS2_F  = df_050_059_PR_VS2_F.assign(Carat=None)
                    df_050_059_PR_VS2_F  = df_050_059_PR_VS2_F.assign(Color=None)
                    df_050_059_PR_VS2_F  = df_050_059_PR_VS2_F.assign(Clarity=None)
                    df_050_059_PR_VS2_F  = df_050_059_PR_VS2_F.assign(Cut=None)
                    df_050_059_PR_VS2_F  = df_050_059_PR_VS2_F.assign(Polish=None)
                    df_050_059_PR_VS2_F  = df_050_059_PR_VS2_F.assign(Symmetry=None)
                    df_050_059_PR_VS2_F  = df_050_059_PR_VS2_F.assign(Ratio=None)
                    df_050_059_PR_VS2_F  = df_050_059_PR_VS2_F.assign(PPC=None)
                    df_050_059_PR_VS2_F  = df_050_059_PR_VS2_F.assign(Total=None)
                    df_050_059_PR_VS2_F ['Wt Range'] = listwtrange
                    df_050_059_PR_VS2_F ['Company'] = listcom
                    df_050_059_PR_VS2_F ['Shape'] = listshap
                    df_050_059_PR_VS2_F ['Carat'] = listcar
                    df_050_059_PR_VS2_F ['Color'] = listcol
                    df_050_059_PR_VS2_F ['Clarity'] = listclar
                    df_050_059_PR_VS2_F ['Cut'] = listcut
                    df_050_059_PR_VS2_F ['Polish'] = listpol
                    df_050_059_PR_VS2_F ['Symmetry'] = listsym
                    df_050_059_PR_VS2_F ['Ratio'] = listrat
                    df_050_059_PR_VS2_F ['PPC'] = listdesc
                    df_050_059_PR_VS2_F ['Total'] = listtotal
                    df_050_059_PR_VS2_F['Carat'] = df_050_059_PR_VS2_F['Carat'].astype('float64')
                    df_050_059_PR_VS2_F['PPC'] = df_050_059_PR_VS2_F['PPC'].astype('float64')
                    df_050_059_PR_VS2_F['Total'] = df_050_059_PR_VS2_F['Total'].astype('float64')
                    df_050_059_PR_VS2_F['Total'] = df_050_059_PR_VS2_F['Carat'] * df_050_059_PR_VS2_F['PPC']


                elif i=="F" and j == "SI1" and k == "PR":
                    df_050_059_PR_SI1_F = pd.DataFrame()
                    df_050_059_PR_SI1_F ['Wt Range'] = None
                    df_050_059_PR_SI1_F  = df_050_059_PR_SI1_F.assign(Company=None)
                    df_050_059_PR_SI1_F  = df_050_059_PR_SI1_F.assign(Shape=None)
                    df_050_059_PR_SI1_F  = df_050_059_PR_SI1_F.assign(Carat=None)
                    df_050_059_PR_SI1_F  = df_050_059_PR_SI1_F.assign(Color=None)
                    df_050_059_PR_SI1_F  = df_050_059_PR_SI1_F.assign(Clarity=None)
                    df_050_059_PR_SI1_F  = df_050_059_PR_SI1_F.assign(Cut=None)
                    df_050_059_PR_SI1_F  = df_050_059_PR_SI1_F.assign(Polish=None)
                    df_050_059_PR_SI1_F  = df_050_059_PR_SI1_F.assign(Symmetry=None)
                    df_050_059_PR_SI1_F  = df_050_059_PR_SI1_F.assign(Ratio=None)
                    df_050_059_PR_SI1_F  = df_050_059_PR_SI1_F.assign(PPC=None)
                    df_050_059_PR_SI1_F  = df_050_059_PR_SI1_F.assign(Total=None)
                    df_050_059_PR_SI1_F ['Wt Range'] = listwtrange
                    df_050_059_PR_SI1_F ['Company'] = listcom
                    df_050_059_PR_SI1_F ['Shape'] = listshap
                    df_050_059_PR_SI1_F ['Carat'] = listcar
                    df_050_059_PR_SI1_F ['Color'] = listcol
                    df_050_059_PR_SI1_F ['Clarity'] = listclar
                    df_050_059_PR_SI1_F ['Cut'] = listcut
                    df_050_059_PR_SI1_F ['Polish'] = listpol
                    df_050_059_PR_SI1_F ['Symmetry'] = listsym
                    df_050_059_PR_SI1_F ['Ratio'] = listrat
                    df_050_059_PR_SI1_F ['PPC'] = listdesc
                    df_050_059_PR_SI1_F ['Total'] = listtotal
                    df_050_059_PR_SI1_F['Carat'] = df_050_059_PR_SI1_F['Carat'].astype('float64')
                    df_050_059_PR_SI1_F['PPC'] = df_050_059_PR_SI1_F['PPC'].astype('float64')
                    df_050_059_PR_SI1_F['Total'] = df_050_059_PR_SI1_F['Total'].astype('float64')
                    df_050_059_PR_SI1_F['Total'] = df_050_059_PR_SI1_F['Carat'] * df_050_059_PR_SI1_F['PPC']


                elif i=="F" and j == "SI2" and k == "PR":
                    df_050_059_PR_SI2_F = pd.DataFrame()
                    df_050_059_PR_SI2_F ['Wt Range'] = None
                    df_050_059_PR_SI2_F  = df_050_059_PR_SI2_F.assign(Company=None)
                    df_050_059_PR_SI2_F  = df_050_059_PR_SI2_F.assign(Shape=None)
                    df_050_059_PR_SI2_F  = df_050_059_PR_SI2_F.assign(Carat=None)
                    df_050_059_PR_SI2_F  = df_050_059_PR_SI2_F.assign(Color=None)
                    df_050_059_PR_SI2_F  = df_050_059_PR_SI2_F.assign(Clarity=None)
                    df_050_059_PR_SI2_F  = df_050_059_PR_SI2_F.assign(Cut=None)
                    df_050_059_PR_SI2_F  = df_050_059_PR_SI2_F.assign(Polish=None)
                    df_050_059_PR_SI2_F  = df_050_059_PR_SI2_F.assign(Symmetry=None)
                    df_050_059_PR_SI2_F  = df_050_059_PR_SI2_F.assign(Ratio=None)
                    df_050_059_PR_SI2_F  = df_050_059_PR_SI2_F.assign(PPC=None)
                    df_050_059_PR_SI2_F  = df_050_059_PR_SI2_F.assign(Total=None)
                    df_050_059_PR_SI2_F ['Wt Range'] = listwtrange
                    df_050_059_PR_SI2_F ['Company'] = listcom
                    df_050_059_PR_SI2_F ['Shape'] = listshap
                    df_050_059_PR_SI2_F ['Carat'] = listcar
                    df_050_059_PR_SI2_F ['Color'] = listcol
                    df_050_059_PR_SI2_F ['Clarity'] = listclar
                    df_050_059_PR_SI2_F ['Cut'] = listcut
                    df_050_059_PR_SI2_F ['Polish'] = listpol
                    df_050_059_PR_SI2_F ['Symmetry'] = listsym
                    df_050_059_PR_SI2_F ['Ratio'] = listrat
                    df_050_059_PR_SI2_F ['PPC'] = listdesc
                    df_050_059_PR_SI2_F ['Total'] = listtotal
                    df_050_059_PR_SI2_F['Carat'] = df_050_059_PR_SI2_F['Carat'].astype('float64')
                    df_050_059_PR_SI2_F['PPC'] = df_050_059_PR_SI2_F['PPC'].astype('float64')
                    df_050_059_PR_SI2_F['Total'] = df_050_059_PR_SI2_F['Total'].astype('float64')
                    df_050_059_PR_SI2_F['Total'] = df_050_059_PR_SI2_F['Carat'] * df_050_059_PR_SI2_F['PPC']


                elif i=="F" and j == "I1" and k == "PR":
                    df_050_059_PR_I1_F = pd.DataFrame()
                    df_050_059_PR_I1_F ['Wt Range'] = None
                    df_050_059_PR_I1_F  = df_050_059_PR_I1_F.assign(Company=None)
                    df_050_059_PR_I1_F  = df_050_059_PR_I1_F.assign(Shape=None)
                    df_050_059_PR_I1_F  = df_050_059_PR_I1_F.assign(Carat=None)
                    df_050_059_PR_I1_F  = df_050_059_PR_I1_F.assign(Color=None)
                    df_050_059_PR_I1_F  = df_050_059_PR_I1_F.assign(Clarity=None)
                    df_050_059_PR_I1_F  = df_050_059_PR_I1_F.assign(Cut=None)
                    df_050_059_PR_I1_F  = df_050_059_PR_I1_F.assign(Polish=None)
                    df_050_059_PR_I1_F  = df_050_059_PR_I1_F.assign(Symmetry=None)
                    df_050_059_PR_I1_F  = df_050_059_PR_I1_F.assign(Ratio=None)
                    df_050_059_PR_I1_F  = df_050_059_PR_I1_F.assign(PPC=None)
                    df_050_059_PR_I1_F  = df_050_059_PR_I1_F.assign(Total=None)
                    df_050_059_PR_I1_F ['Wt Range'] = listwtrange
                    df_050_059_PR_I1_F ['Company'] = listcom
                    df_050_059_PR_I1_F ['Shape'] = listshap
                    df_050_059_PR_I1_F ['Carat'] = listcar
                    df_050_059_PR_I1_F ['Color'] = listcol
                    df_050_059_PR_I1_F ['Clarity'] = listclar
                    df_050_059_PR_I1_F ['Cut'] = listcut
                    df_050_059_PR_I1_F ['Polish'] = listpol
                    df_050_059_PR_I1_F ['Symmetry'] = listsym
                    df_050_059_PR_I1_F ['Ratio'] = listrat
                    df_050_059_PR_I1_F ['PPC'] = listdesc
                    df_050_059_PR_I1_F ['Total'] = listtotal
                    df_050_059_PR_I1_F['Carat'] = df_050_059_PR_I1_F['Carat'].astype('float64')
                    df_050_059_PR_I1_F['PPC'] = df_050_059_PR_I1_F['PPC'].astype('float64')
                    df_050_059_PR_I1_F['Total'] = df_050_059_PR_I1_F['Total'].astype('float64')
                    df_050_059_PR_I1_F['Total'] = df_050_059_PR_I1_F['Carat'] * df_050_059_PR_I1_F['PPC']


                elif i=="F" and j == "I2" and k == "PR":
                    df_050_059_PR_I2_F = pd.DataFrame()
                    df_050_059_PR_I2_F ['Wt Range'] = None
                    df_050_059_PR_I2_F  = df_050_059_PR_I2_F.assign(Company=None)
                    df_050_059_PR_I2_F  = df_050_059_PR_I2_F.assign(Shape=None)
                    df_050_059_PR_I2_F  = df_050_059_PR_I2_F.assign(Carat=None)
                    df_050_059_PR_I2_F  = df_050_059_PR_I2_F.assign(Color=None)
                    df_050_059_PR_I2_F  = df_050_059_PR_I2_F.assign(Clarity=None)
                    df_050_059_PR_I2_F  = df_050_059_PR_I2_F.assign(Cut=None)
                    df_050_059_PR_I2_F  = df_050_059_PR_I2_F.assign(Polish=None)
                    df_050_059_PR_I2_F  = df_050_059_PR_I2_F.assign(Symmetry=None)
                    df_050_059_PR_I2_F  = df_050_059_PR_I2_F.assign(Ratio=None)
                    df_050_059_PR_I2_F  = df_050_059_PR_I2_F.assign(PPC=None)
                    df_050_059_PR_I2_F  = df_050_059_PR_I2_F.assign(Total=None)
                    df_050_059_PR_I2_F ['Wt Range'] = listwtrange
                    df_050_059_PR_I2_F ['Company'] = listcom
                    df_050_059_PR_I2_F ['Shape'] = listshap
                    df_050_059_PR_I2_F ['Carat'] = listcar
                    df_050_059_PR_I2_F ['Color'] = listcol
                    df_050_059_PR_I2_F ['Clarity'] = listclar
                    df_050_059_PR_I2_F ['Cut'] = listcut
                    df_050_059_PR_I2_F ['Polish'] = listpol
                    df_050_059_PR_I2_F ['Symmetry'] = listsym
                    df_050_059_PR_I2_F ['Ratio'] = listrat
                    df_050_059_PR_I2_F ['PPC'] = listdesc
                    df_050_059_PR_I2_F ['Total'] = listtotal
                    df_050_059_PR_I2_F['Carat'] = df_050_059_PR_I2_F['Carat'].astype('float64')
                    df_050_059_PR_I2_F['PPC'] = df_050_059_PR_I2_F['PPC'].astype('float64')
                    df_050_059_PR_I2_F['Total'] = df_050_059_PR_I2_F['Total'].astype('float64')
                    df_050_059_PR_I2_F['Total'] = df_050_059_PR_I2_F['Carat'] * df_050_059_PR_I2_F['PPC']


                elif i=="G" and j == "IF" and k == "PR":
                    df_050_059_PR_IF_G = pd.DataFrame()
                    df_050_059_PR_IF_G ['Wt Range'] = None
                    df_050_059_PR_IF_G  = df_050_059_PR_IF_G.assign(Company=None)
                    df_050_059_PR_IF_G  = df_050_059_PR_IF_G.assign(Shape=None)
                    df_050_059_PR_IF_G  = df_050_059_PR_IF_G.assign(Carat=None)
                    df_050_059_PR_IF_G  = df_050_059_PR_IF_G.assign(Color=None)
                    df_050_059_PR_IF_G  = df_050_059_PR_IF_G.assign(Clarity=None)
                    df_050_059_PR_IF_G  = df_050_059_PR_IF_G.assign(Cut=None)
                    df_050_059_PR_IF_G  = df_050_059_PR_IF_G.assign(Polish=None)
                    df_050_059_PR_IF_G  = df_050_059_PR_IF_G.assign(Symmetry=None)
                    df_050_059_PR_IF_G  = df_050_059_PR_IF_G.assign(Ratio=None)
                    df_050_059_PR_IF_G  = df_050_059_PR_IF_G.assign(PPC=None)
                    df_050_059_PR_IF_G  = df_050_059_PR_IF_G.assign(Total=None)
                    df_050_059_PR_IF_G ['Wt Range'] = listwtrange
                    df_050_059_PR_IF_G ['Company'] = listcom
                    df_050_059_PR_IF_G ['Shape'] = listshap
                    df_050_059_PR_IF_G ['Carat'] = listcar
                    df_050_059_PR_IF_G ['Color'] = listcol
                    df_050_059_PR_IF_G ['Clarity'] = listclar
                    df_050_059_PR_IF_G ['Cut'] = listcut
                    df_050_059_PR_IF_G ['Polish'] = listpol
                    df_050_059_PR_IF_G ['Symmetry'] = listsym
                    df_050_059_PR_IF_G ['Ratio'] = listrat
                    df_050_059_PR_IF_G ['PPC'] = listdesc
                    df_050_059_PR_IF_G ['Total'] = listtotal
                    df_050_059_PR_IF_G['Carat'] = df_050_059_PR_IF_G['Carat'].astype('float64')
                    df_050_059_PR_IF_G['PPC'] = df_050_059_PR_IF_G['PPC'].astype('float64')
                    df_050_059_PR_IF_G['Total'] = df_050_059_PR_IF_G['Total'].astype('float64')
                    df_050_059_PR_IF_G['Total'] = df_050_059_PR_IF_G['Carat'] * df_050_059_PR_IF_G['PPC']



                elif i=="G" and j == "VVS1" and k == "PR":
                    df_050_059_PR_VVS1_G = pd.DataFrame()
                    df_050_059_PR_VVS1_G ['Wt Range'] = None
                    df_050_059_PR_VVS1_G  = df_050_059_PR_VVS1_G.assign(Company=None)
                    df_050_059_PR_VVS1_G  = df_050_059_PR_VVS1_G.assign(Shape=None)
                    df_050_059_PR_VVS1_G  = df_050_059_PR_VVS1_G.assign(Carat=None)
                    df_050_059_PR_VVS1_G  = df_050_059_PR_VVS1_G.assign(Color=None)
                    df_050_059_PR_VVS1_G  = df_050_059_PR_VVS1_G.assign(Clarity=None)
                    df_050_059_PR_VVS1_G  = df_050_059_PR_VVS1_G.assign(Cut=None)
                    df_050_059_PR_VVS1_G  = df_050_059_PR_VVS1_G.assign(Polish=None)
                    df_050_059_PR_VVS1_G  = df_050_059_PR_VVS1_G.assign(Symmetry=None)
                    df_050_059_PR_VVS1_G  = df_050_059_PR_VVS1_G.assign(Ratio=None)
                    df_050_059_PR_VVS1_G  = df_050_059_PR_VVS1_G.assign(PPC=None)
                    df_050_059_PR_VVS1_G  = df_050_059_PR_VVS1_G.assign(Total=None)
                    df_050_059_PR_VVS1_G ['Wt Range'] = listwtrange
                    df_050_059_PR_VVS1_G ['Company'] = listcom
                    df_050_059_PR_VVS1_G ['Shape'] = listshap
                    df_050_059_PR_VVS1_G ['Carat'] = listcar
                    df_050_059_PR_VVS1_G ['Color'] = listcol
                    df_050_059_PR_VVS1_G ['Clarity'] = listclar
                    df_050_059_PR_VVS1_G ['Cut'] = listcut
                    df_050_059_PR_VVS1_G ['Polish'] = listpol
                    df_050_059_PR_VVS1_G ['Symmetry'] = listsym
                    df_050_059_PR_VVS1_G ['Ratio'] = listrat
                    df_050_059_PR_VVS1_G ['PPC'] = listdesc
                    df_050_059_PR_VVS1_G ['Total'] = listtotal
                    df_050_059_PR_VVS1_G['Carat'] = df_050_059_PR_VVS1_G['Carat'].astype('float64')
                    df_050_059_PR_VVS1_G['PPC'] = df_050_059_PR_VVS1_G['PPC'].astype('float64')
                    df_050_059_PR_VVS1_G['Total'] = df_050_059_PR_VVS1_G['Total'].astype('float64')
                    df_050_059_PR_VVS1_G['Total'] = df_050_059_PR_VVS1_G['Carat'] * df_050_059_PR_VVS1_G['PPC']


                elif i=="G" and j == "VVS2" and k == "PR":
                    df_050_059_PR_VVS2_G = pd.DataFrame()
                    df_050_059_PR_VVS2_G ['Wt Range'] = None
                    df_050_059_PR_VVS2_G  = df_050_059_PR_VVS2_G.assign(Company=None)
                    df_050_059_PR_VVS2_G  = df_050_059_PR_VVS2_G.assign(Shape=None)
                    df_050_059_PR_VVS2_G  = df_050_059_PR_VVS2_G.assign(Carat=None)
                    df_050_059_PR_VVS2_G  = df_050_059_PR_VVS2_G.assign(Color=None)
                    df_050_059_PR_VVS2_G  = df_050_059_PR_VVS2_G.assign(Clarity=None)
                    df_050_059_PR_VVS2_G  = df_050_059_PR_VVS2_G.assign(Cut=None)
                    df_050_059_PR_VVS2_G  = df_050_059_PR_VVS2_G.assign(Polish=None)
                    df_050_059_PR_VVS2_G  = df_050_059_PR_VVS2_G.assign(Symmetry=None)
                    df_050_059_PR_VVS2_G  = df_050_059_PR_VVS2_G.assign(Ratio=None)
                    df_050_059_PR_VVS2_G  = df_050_059_PR_VVS2_G.assign(PPC=None)
                    df_050_059_PR_VVS2_G  = df_050_059_PR_VVS2_G.assign(Total=None)
                    df_050_059_PR_VVS2_G ['Wt Range'] = listwtrange
                    df_050_059_PR_VVS2_G ['Company'] = listcom
                    df_050_059_PR_VVS2_G ['Shape'] = listshap
                    df_050_059_PR_VVS2_G ['Carat'] = listcar
                    df_050_059_PR_VVS2_G ['Color'] = listcol
                    df_050_059_PR_VVS2_G ['Clarity'] = listclar
                    df_050_059_PR_VVS2_G ['Cut'] = listcut
                    df_050_059_PR_VVS2_G ['Polish'] = listpol
                    df_050_059_PR_VVS2_G ['Symmetry'] = listsym
                    df_050_059_PR_VVS2_G ['Ratio'] = listrat
                    df_050_059_PR_VVS2_G ['PPC'] = listdesc
                    df_050_059_PR_VVS2_G ['Total'] = listtotal
                    df_050_059_PR_VVS2_G['Carat'] = df_050_059_PR_VVS2_G['Carat'].astype('float64')
                    df_050_059_PR_VVS2_G['PPC'] = df_050_059_PR_VVS2_G['PPC'].astype('float64')
                    df_050_059_PR_VVS2_G['Total'] = df_050_059_PR_VVS2_G['Total'].astype('float64')
                    df_050_059_PR_VVS2_G['Total'] = df_050_059_PR_VVS2_G['Carat'] * df_050_059_PR_VVS2_G['PPC']


                elif i=="G" and j=="VS1" and k == "PR":
                    df_050_059_PR_VS1_G = pd.DataFrame()
                    df_050_059_PR_VS1_G ['Wt Range'] = None
                    df_050_059_PR_VS1_G  = df_050_059_PR_VS1_G.assign(Company=None)
                    df_050_059_PR_VS1_G  = df_050_059_PR_VS1_G.assign(Shape=None)
                    df_050_059_PR_VS1_G  = df_050_059_PR_VS1_G.assign(Carat=None)
                    df_050_059_PR_VS1_G  = df_050_059_PR_VS1_G.assign(Color=None)
                    df_050_059_PR_VS1_G  = df_050_059_PR_VS1_G.assign(Clarity=None)
                    df_050_059_PR_VS1_G  = df_050_059_PR_VS1_G.assign(Cut=None)
                    df_050_059_PR_VS1_G  = df_050_059_PR_VS1_G.assign(Polish=None)
                    df_050_059_PR_VS1_G  = df_050_059_PR_VS1_G.assign(Symmetry=None)
                    df_050_059_PR_VS1_G  = df_050_059_PR_VS1_G.assign(Ratio=None)
                    df_050_059_PR_VS1_G  = df_050_059_PR_VS1_G.assign(PPC=None)
                    df_050_059_PR_VS1_G  = df_050_059_PR_VS1_G.assign(Total=None)
                    df_050_059_PR_VS1_G ['Wt Range'] = listwtrange
                    df_050_059_PR_VS1_G ['Company'] = listcom
                    df_050_059_PR_VS1_G ['Shape'] = listshap
                    df_050_059_PR_VS1_G ['Carat'] = listcar
                    df_050_059_PR_VS1_G ['Color'] = listcol
                    df_050_059_PR_VS1_G ['Clarity'] = listclar
                    df_050_059_PR_VS1_G ['Cut'] = listcut
                    df_050_059_PR_VS1_G ['Polish'] = listpol
                    df_050_059_PR_VS1_G ['Symmetry'] = listsym
                    df_050_059_PR_VS1_G ['Ratio'] = listrat
                    df_050_059_PR_VS1_G ['PPC'] = listdesc
                    df_050_059_PR_VS1_G ['Total'] = listtotal
                    df_050_059_PR_VS1_G['Carat'] = df_050_059_PR_VS1_G['Carat'].astype('float64')
                    df_050_059_PR_VS1_G['PPC'] = df_050_059_PR_VS1_G['PPC'].astype('float64')
                    df_050_059_PR_VS1_G['Total'] = df_050_059_PR_VS1_G['Total'].astype('float64')
                    df_050_059_PR_VS1_G['Total'] = df_050_059_PR_VS1_G['Carat'] * df_050_059_PR_VS1_G['PPC']


                elif i=="G" and j == "VS2" and k == "PR":
                    df_050_059_PR_VS2_G = pd.DataFrame()
                    df_050_059_PR_VS2_G ['Wt Range'] = None
                    df_050_059_PR_VS2_G  = df_050_059_PR_VS2_G.assign(Company=None)
                    df_050_059_PR_VS2_G  = df_050_059_PR_VS2_G.assign(Shape=None)
                    df_050_059_PR_VS2_G  = df_050_059_PR_VS2_G.assign(Carat=None)
                    df_050_059_PR_VS2_G  = df_050_059_PR_VS2_G.assign(Color=None)
                    df_050_059_PR_VS2_G  = df_050_059_PR_VS2_G.assign(Clarity=None)
                    df_050_059_PR_VS2_G  = df_050_059_PR_VS2_G.assign(Cut=None)
                    df_050_059_PR_VS2_G  = df_050_059_PR_VS2_G.assign(Polish=None)
                    df_050_059_PR_VS2_G  = df_050_059_PR_VS2_G.assign(Symmetry=None)
                    df_050_059_PR_VS2_G  = df_050_059_PR_VS2_G.assign(Ratio=None)
                    df_050_059_PR_VS2_G  = df_050_059_PR_VS2_G.assign(PPC=None)
                    df_050_059_PR_VS2_G  = df_050_059_PR_VS2_G.assign(Total=None)
                    df_050_059_PR_VS2_G ['Wt Range'] = listwtrange
                    df_050_059_PR_VS2_G ['Company'] = listcom
                    df_050_059_PR_VS2_G ['Shape'] = listshap
                    df_050_059_PR_VS2_G ['Carat'] = listcar
                    df_050_059_PR_VS2_G ['Color'] = listcol
                    df_050_059_PR_VS2_G ['Clarity'] = listclar
                    df_050_059_PR_VS2_G ['Cut'] = listcut
                    df_050_059_PR_VS2_G ['Polish'] = listpol
                    df_050_059_PR_VS2_G ['Symmetry'] = listsym
                    df_050_059_PR_VS2_G ['Ratio'] = listrat
                    df_050_059_PR_VS2_G ['PPC'] = listdesc
                    df_050_059_PR_VS2_G ['Total'] = listtotal
                    df_050_059_PR_VS2_G['Carat'] = df_050_059_PR_VS2_G['Carat'].astype('float64')
                    df_050_059_PR_VS2_G['PPC'] = df_050_059_PR_VS2_G['PPC'].astype('float64')
                    df_050_059_PR_VS2_G['Total'] = df_050_059_PR_VS2_G['Total'].astype('float64')
                    df_050_059_PR_VS2_G['Total'] = df_050_059_PR_VS2_G['Carat'] * df_050_059_PR_VS2_G['PPC']


                elif i=="G" and j == "SI1" and k == "PR":
                    df_050_059_PR_SI1_G = pd.DataFrame()
                    df_050_059_PR_SI1_G ['Wt Range'] = None
                    df_050_059_PR_SI1_G  = df_050_059_PR_SI1_G.assign(Company=None)
                    df_050_059_PR_SI1_G  = df_050_059_PR_SI1_G.assign(Shape=None)
                    df_050_059_PR_SI1_G  = df_050_059_PR_SI1_G.assign(Carat=None)
                    df_050_059_PR_SI1_G  = df_050_059_PR_SI1_G.assign(Color=None)
                    df_050_059_PR_SI1_G  = df_050_059_PR_SI1_G.assign(Clarity=None)
                    df_050_059_PR_SI1_G  = df_050_059_PR_SI1_G.assign(Cut=None)
                    df_050_059_PR_SI1_G  = df_050_059_PR_SI1_G.assign(Polish=None)
                    df_050_059_PR_SI1_G  = df_050_059_PR_SI1_G.assign(Symmetry=None)
                    df_050_059_PR_SI1_G  = df_050_059_PR_SI1_G.assign(Ratio=None)
                    df_050_059_PR_SI1_G  = df_050_059_PR_SI1_G.assign(PPC=None)
                    df_050_059_PR_SI1_G  = df_050_059_PR_SI1_G.assign(Total=None)
                    df_050_059_PR_SI1_G ['Wt Range'] = listwtrange
                    df_050_059_PR_SI1_G ['Company'] = listcom
                    df_050_059_PR_SI1_G ['Shape'] = listshap
                    df_050_059_PR_SI1_G ['Carat'] = listcar
                    df_050_059_PR_SI1_G ['Color'] = listcol
                    df_050_059_PR_SI1_G ['Clarity'] = listclar
                    df_050_059_PR_SI1_G ['Cut'] = listcut
                    df_050_059_PR_SI1_G ['Polish'] = listpol
                    df_050_059_PR_SI1_G ['Symmetry'] = listsym
                    df_050_059_PR_SI1_G ['Ratio'] = listrat
                    df_050_059_PR_SI1_G ['PPC'] = listdesc
                    df_050_059_PR_SI1_G ['Total'] = listtotal
                    df_050_059_PR_SI1_G['Carat'] = df_050_059_PR_SI1_G['Carat'].astype('float64')
                    df_050_059_PR_SI1_G['PPC'] = df_050_059_PR_SI1_G['PPC'].astype('float64')
                    df_050_059_PR_SI1_G['Total'] = df_050_059_PR_SI1_G['Total'].astype('float64')
                    df_050_059_PR_SI1_G['Total'] = df_050_059_PR_SI1_G['Carat'] * df_050_059_PR_SI1_G['PPC']


                elif i=="G" and j == "SI2" and k == "PR":
                    df_050_059_PR_SI2_G = pd.DataFrame()
                    df_050_059_PR_SI2_G ['Wt Range'] = None
                    df_050_059_PR_SI2_G  = df_050_059_PR_SI2_G.assign(Company=None)
                    df_050_059_PR_SI2_G  = df_050_059_PR_SI2_G.assign(Shape=None)
                    df_050_059_PR_SI2_G  = df_050_059_PR_SI2_G.assign(Carat=None)
                    df_050_059_PR_SI2_G  = df_050_059_PR_SI2_G.assign(Color=None)
                    df_050_059_PR_SI2_G  = df_050_059_PR_SI2_G.assign(Clarity=None)
                    df_050_059_PR_SI2_G  = df_050_059_PR_SI2_G.assign(Cut=None)
                    df_050_059_PR_SI2_G  = df_050_059_PR_SI2_G.assign(Polish=None)
                    df_050_059_PR_SI2_G  = df_050_059_PR_SI2_G.assign(Symmetry=None)
                    df_050_059_PR_SI2_G  = df_050_059_PR_SI2_G.assign(Ratio=None)
                    df_050_059_PR_SI2_G  = df_050_059_PR_SI2_G.assign(PPC=None)
                    df_050_059_PR_SI2_G  = df_050_059_PR_SI2_G.assign(Total=None)
                    df_050_059_PR_SI2_G ['Wt Range'] = listwtrange
                    df_050_059_PR_SI2_G ['Company'] = listcom
                    df_050_059_PR_SI2_G ['Shape'] = listshap
                    df_050_059_PR_SI2_G ['Carat'] = listcar
                    df_050_059_PR_SI2_G ['Color'] = listcol
                    df_050_059_PR_SI2_G ['Clarity'] = listclar
                    df_050_059_PR_SI2_G ['Cut'] = listcut
                    df_050_059_PR_SI2_G ['Polish'] = listpol
                    df_050_059_PR_SI2_G ['Symmetry'] = listsym
                    df_050_059_PR_SI2_G ['Ratio'] = listrat
                    df_050_059_PR_SI2_G ['PPC'] = listdesc
                    df_050_059_PR_SI2_G ['Total'] = listtotal
                    df_050_059_PR_SI2_G['Carat'] = df_050_059_PR_SI2_G['Carat'].astype('float64')
                    df_050_059_PR_SI2_G['PPC'] = df_050_059_PR_SI2_G['PPC'].astype('float64')
                    df_050_059_PR_SI2_G['Total'] = df_050_059_PR_SI2_G['Total'].astype('float64')
                    df_050_059_PR_SI2_G['Total'] = df_050_059_PR_SI2_G['Carat'] * df_050_059_PR_SI2_G['PPC']


                elif i=="G" and j == "I1" and k == "PR":
                    df_050_059_PR_I1_G = pd.DataFrame()
                    df_050_059_PR_I1_G ['Wt Range'] = None
                    df_050_059_PR_I1_G  = df_050_059_PR_I1_G.assign(Company=None)
                    df_050_059_PR_I1_G  = df_050_059_PR_I1_G.assign(Shape=None)
                    df_050_059_PR_I1_G  = df_050_059_PR_I1_G.assign(Carat=None)
                    df_050_059_PR_I1_G  = df_050_059_PR_I1_G.assign(Color=None)
                    df_050_059_PR_I1_G  = df_050_059_PR_I1_G.assign(Clarity=None)
                    df_050_059_PR_I1_G  = df_050_059_PR_I1_G.assign(Cut=None)
                    df_050_059_PR_I1_G  = df_050_059_PR_I1_G.assign(Polish=None)
                    df_050_059_PR_I1_G  = df_050_059_PR_I1_G.assign(Symmetry=None)
                    df_050_059_PR_I1_G  = df_050_059_PR_I1_G.assign(Ratio=None)
                    df_050_059_PR_I1_G  = df_050_059_PR_I1_G.assign(PPC=None)
                    df_050_059_PR_I1_G  = df_050_059_PR_I1_G.assign(Total=None)
                    df_050_059_PR_I1_G ['Wt Range'] = listwtrange
                    df_050_059_PR_I1_G ['Company'] = listcom
                    df_050_059_PR_I1_G ['Shape'] = listshap
                    df_050_059_PR_I1_G ['Carat'] = listcar
                    df_050_059_PR_I1_G ['Color'] = listcol
                    df_050_059_PR_I1_G ['Clarity'] = listclar
                    df_050_059_PR_I1_G ['Cut'] = listcut
                    df_050_059_PR_I1_G ['Polish'] = listpol
                    df_050_059_PR_I1_G ['Symmetry'] = listsym
                    df_050_059_PR_I1_G ['Ratio'] = listrat
                    df_050_059_PR_I1_G ['PPC'] = listdesc
                    df_050_059_PR_I1_G ['Total'] = listtotal
                    df_050_059_PR_I1_G['Carat'] = df_050_059_PR_I1_G['Carat'].astype('float64')
                    df_050_059_PR_I1_G['PPC'] = df_050_059_PR_I1_G['PPC'].astype('float64')
                    df_050_059_PR_I1_G['Total'] = df_050_059_PR_I1_G['Total'].astype('float64')
                    df_050_059_PR_I1_G['Total'] = df_050_059_PR_I1_G['Carat'] * df_050_059_PR_I1_G['PPC']


                elif i=="G" and j == "I2" and k == "PR":
                    df_050_059_PR_I2_G = pd.DataFrame()
                    df_050_059_PR_I2_G ['Wt Range'] = None
                    df_050_059_PR_I2_G  = df_050_059_PR_I2_G.assign(Company=None)
                    df_050_059_PR_I2_G  = df_050_059_PR_I2_G.assign(Shape=None)
                    df_050_059_PR_I2_G  = df_050_059_PR_I2_G.assign(Carat=None)
                    df_050_059_PR_I2_G  = df_050_059_PR_I2_G.assign(Color=None)
                    df_050_059_PR_I2_G  = df_050_059_PR_I2_G.assign(Clarity=None)
                    df_050_059_PR_I2_G  = df_050_059_PR_I2_G.assign(Cut=None)
                    df_050_059_PR_I2_G  = df_050_059_PR_I2_G.assign(Polish=None)
                    df_050_059_PR_I2_G  = df_050_059_PR_I2_G.assign(Symmetry=None)
                    df_050_059_PR_I2_G  = df_050_059_PR_I2_G.assign(Ratio=None)
                    df_050_059_PR_I2_G  = df_050_059_PR_I2_G.assign(PPC=None)
                    df_050_059_PR_I2_G  = df_050_059_PR_I2_G.assign(Total=None)
                    df_050_059_PR_I2_G ['Wt Range'] = listwtrange
                    df_050_059_PR_I2_G ['Company'] = listcom
                    df_050_059_PR_I2_G ['Shape'] = listshap
                    df_050_059_PR_I2_G ['Carat'] = listcar
                    df_050_059_PR_I2_G ['Color'] = listcol
                    df_050_059_PR_I2_G ['Clarity'] = listclar
                    df_050_059_PR_I2_G ['Cut'] = listcut
                    df_050_059_PR_I2_G ['Polish'] = listpol
                    df_050_059_PR_I2_G ['Symmetry'] = listsym
                    df_050_059_PR_I2_G ['Ratio'] = listrat
                    df_050_059_PR_I2_G ['PPC'] = listdesc
                    df_050_059_PR_I2_G ['Total'] = listtotal
                    df_050_059_PR_I2_G['Carat'] = df_050_059_PR_I2_G['Carat'].astype('float64')
                    df_050_059_PR_I2_G['PPC'] = df_050_059_PR_I2_G['PPC'].astype('float64')
                    df_050_059_PR_I2_G['Total'] = df_050_059_PR_I2_G['Total'].astype('float64')
                    df_050_059_PR_I2_G['Total'] = df_050_059_PR_I2_G['Carat'] * df_050_059_PR_I2_G['PPC']


                elif i=="H" and j == "IF" and k == "PR":
                    df_050_059_PR_IF_H = pd.DataFrame()
                    df_050_059_PR_IF_H ['Wt Range'] = None
                    df_050_059_PR_IF_H  = df_050_059_PR_IF_H.assign(Company=None)
                    df_050_059_PR_IF_H  = df_050_059_PR_IF_H.assign(Shape=None)
                    df_050_059_PR_IF_H  = df_050_059_PR_IF_H.assign(Carat=None)
                    df_050_059_PR_IF_H  = df_050_059_PR_IF_H.assign(Color=None)
                    df_050_059_PR_IF_H  = df_050_059_PR_IF_H.assign(Clarity=None)
                    df_050_059_PR_IF_H  = df_050_059_PR_IF_H.assign(Cut=None)
                    df_050_059_PR_IF_H  = df_050_059_PR_IF_H.assign(Polish=None)
                    df_050_059_PR_IF_H  = df_050_059_PR_IF_H.assign(Symmetry=None)
                    df_050_059_PR_IF_H  = df_050_059_PR_IF_H.assign(Ratio=None)
                    df_050_059_PR_IF_H  = df_050_059_PR_IF_H.assign(PPC=None)
                    df_050_059_PR_IF_H  = df_050_059_PR_IF_H.assign(Total=None)
                    df_050_059_PR_IF_H ['Wt Range'] = listwtrange
                    df_050_059_PR_IF_H ['Company'] = listcom
                    df_050_059_PR_IF_H ['Shape'] = listshap
                    df_050_059_PR_IF_H ['Carat'] = listcar
                    df_050_059_PR_IF_H ['Color'] = listcol
                    df_050_059_PR_IF_H ['Clarity'] = listclar
                    df_050_059_PR_IF_H ['Cut'] = listcut
                    df_050_059_PR_IF_H ['Polish'] = listpol
                    df_050_059_PR_IF_H ['Symmetry'] = listsym
                    df_050_059_PR_IF_H ['Ratio'] = listrat
                    df_050_059_PR_IF_H ['PPC'] = listdesc
                    df_050_059_PR_IF_H ['Total'] = listtotal
                    df_050_059_PR_IF_H['Carat'] = df_050_059_PR_IF_H['Carat'].astype('float64')
                    df_050_059_PR_IF_H['PPC'] = df_050_059_PR_IF_H['PPC'].astype('float64')
                    df_050_059_PR_IF_H['Total'] = df_050_059_PR_IF_H['Total'].astype('float64')
                    df_050_059_PR_IF_H['Total'] = df_050_059_PR_IF_H['Carat'] * df_050_059_PR_IF_H['PPC']



                elif i=="H" and j == "VVS1" and k == "PR":
                    df_050_059_PR_VVS1_H = pd.DataFrame()
                    df_050_059_PR_VVS1_H ['Wt Range'] = None
                    df_050_059_PR_VVS1_H  = df_050_059_PR_VVS1_H.assign(Company=None)
                    df_050_059_PR_VVS1_H  = df_050_059_PR_VVS1_H.assign(Shape=None)
                    df_050_059_PR_VVS1_H  = df_050_059_PR_VVS1_H.assign(Carat=None)
                    df_050_059_PR_VVS1_H  = df_050_059_PR_VVS1_H.assign(Color=None)
                    df_050_059_PR_VVS1_H  = df_050_059_PR_VVS1_H.assign(Clarity=None)
                    df_050_059_PR_VVS1_H  = df_050_059_PR_VVS1_H.assign(Cut=None)
                    df_050_059_PR_VVS1_H  = df_050_059_PR_VVS1_H.assign(Polish=None)
                    df_050_059_PR_VVS1_H  = df_050_059_PR_VVS1_H.assign(Symmetry=None)
                    df_050_059_PR_VVS1_H  = df_050_059_PR_VVS1_H.assign(Ratio=None)
                    df_050_059_PR_VVS1_H  = df_050_059_PR_VVS1_H.assign(PPC=None)
                    df_050_059_PR_VVS1_H  = df_050_059_PR_VVS1_H.assign(Total=None)
                    df_050_059_PR_VVS1_H ['Wt Range'] = listwtrange
                    df_050_059_PR_VVS1_H ['Company'] = listcom
                    df_050_059_PR_VVS1_H ['Shape'] = listshap
                    df_050_059_PR_VVS1_H ['Carat'] = listcar
                    df_050_059_PR_VVS1_H ['Color'] = listcol
                    df_050_059_PR_VVS1_H ['Clarity'] = listclar
                    df_050_059_PR_VVS1_H ['Cut'] = listcut
                    df_050_059_PR_VVS1_H ['Polish'] = listpol
                    df_050_059_PR_VVS1_H ['Symmetry'] = listsym
                    df_050_059_PR_VVS1_H ['Ratio'] = listrat
                    df_050_059_PR_VVS1_H ['PPC'] = listdesc
                    df_050_059_PR_VVS1_H ['Total'] = listtotal
                    df_050_059_PR_VVS1_H['Carat'] = df_050_059_PR_VVS1_H['Carat'].astype('float64')
                    df_050_059_PR_VVS1_H['PPC'] = df_050_059_PR_VVS1_H['PPC'].astype('float64')
                    df_050_059_PR_VVS1_H['Total'] = df_050_059_PR_VVS1_H['Total'].astype('float64')
                    df_050_059_PR_VVS1_H['Total'] = df_050_059_PR_VVS1_H['Carat'] * df_050_059_PR_VVS1_H['PPC']


                elif i=="H" and j == "VVS2" and k == "PR":
                    df_050_059_PR_VVS2_H = pd.DataFrame()
                    df_050_059_PR_VVS2_H ['Wt Range'] = None
                    df_050_059_PR_VVS2_H  = df_050_059_PR_VVS2_H.assign(Company=None)
                    df_050_059_PR_VVS2_H  = df_050_059_PR_VVS2_H.assign(Shape=None)
                    df_050_059_PR_VVS2_H  = df_050_059_PR_VVS2_H.assign(Carat=None)
                    df_050_059_PR_VVS2_H  = df_050_059_PR_VVS2_H.assign(Color=None)
                    df_050_059_PR_VVS2_H  = df_050_059_PR_VVS2_H.assign(Clarity=None)
                    df_050_059_PR_VVS2_H  = df_050_059_PR_VVS2_H.assign(Cut=None)
                    df_050_059_PR_VVS2_H  = df_050_059_PR_VVS2_H.assign(Polish=None)
                    df_050_059_PR_VVS2_H  = df_050_059_PR_VVS2_H.assign(Symmetry=None)
                    df_050_059_PR_VVS2_H  = df_050_059_PR_VVS2_H.assign(Ratio=None)
                    df_050_059_PR_VVS2_H  = df_050_059_PR_VVS2_H.assign(PPC=None)
                    df_050_059_PR_VVS2_H  = df_050_059_PR_VVS2_H.assign(Total=None)
                    df_050_059_PR_VVS2_H ['Wt Range'] = listwtrange
                    df_050_059_PR_VVS2_H ['Company'] = listcom
                    df_050_059_PR_VVS2_H ['Shape'] = listshap
                    df_050_059_PR_VVS2_H ['Carat'] = listcar
                    df_050_059_PR_VVS2_H ['Color'] = listcol
                    df_050_059_PR_VVS2_H ['Clarity'] = listclar
                    df_050_059_PR_VVS2_H ['Cut'] = listcut
                    df_050_059_PR_VVS2_H ['Polish'] = listpol
                    df_050_059_PR_VVS2_H ['Symmetry'] = listsym
                    df_050_059_PR_VVS2_H ['Ratio'] = listrat
                    df_050_059_PR_VVS2_H ['PPC'] = listdesc
                    df_050_059_PR_VVS2_H ['Total'] = listtotal
                    df_050_059_PR_VVS2_H['Carat'] = df_050_059_PR_VVS2_H['Carat'].astype('float64')
                    df_050_059_PR_VVS2_H['PPC'] = df_050_059_PR_VVS2_H['PPC'].astype('float64')
                    df_050_059_PR_VVS2_H['Total'] = df_050_059_PR_VVS2_H['Total'].astype('float64')
                    df_050_059_PR_VVS2_H['Total'] = df_050_059_PR_VVS2_H['Carat'] * df_050_059_PR_VVS2_H['PPC']


                elif i=="H" and j=="VS1" and k == "PR":
                    df_050_059_PR_VS1_H = pd.DataFrame()
                    df_050_059_PR_VS1_H ['Wt Range'] = None
                    df_050_059_PR_VS1_H  = df_050_059_PR_VS1_H.assign(Company=None)
                    df_050_059_PR_VS1_H  = df_050_059_PR_VS1_H.assign(Shape=None)
                    df_050_059_PR_VS1_H  = df_050_059_PR_VS1_H.assign(Carat=None)
                    df_050_059_PR_VS1_H  = df_050_059_PR_VS1_H.assign(Color=None)
                    df_050_059_PR_VS1_H  = df_050_059_PR_VS1_H.assign(Clarity=None)
                    df_050_059_PR_VS1_H  = df_050_059_PR_VS1_H.assign(Cut=None)
                    df_050_059_PR_VS1_H  = df_050_059_PR_VS1_H.assign(Polish=None)
                    df_050_059_PR_VS1_H  = df_050_059_PR_VS1_H.assign(Symmetry=None)
                    df_050_059_PR_VS1_H  = df_050_059_PR_VS1_H.assign(Ratio=None)
                    df_050_059_PR_VS1_H  = df_050_059_PR_VS1_H.assign(PPC=None)
                    df_050_059_PR_VS1_H  = df_050_059_PR_VS1_H.assign(Total=None)
                    df_050_059_PR_VS1_H ['Wt Range'] = listwtrange
                    df_050_059_PR_VS1_H ['Company'] = listcom
                    df_050_059_PR_VS1_H ['Shape'] = listshap
                    df_050_059_PR_VS1_H ['Carat'] = listcar
                    df_050_059_PR_VS1_H ['Color'] = listcol
                    df_050_059_PR_VS1_H ['Clarity'] = listclar
                    df_050_059_PR_VS1_H ['Cut'] = listcut
                    df_050_059_PR_VS1_H ['Polish'] = listpol
                    df_050_059_PR_VS1_H ['Symmetry'] = listsym
                    df_050_059_PR_VS1_H ['Ratio'] = listrat
                    df_050_059_PR_VS1_H ['PPC'] = listdesc
                    df_050_059_PR_VS1_H ['Total'] = listtotal
                    df_050_059_PR_VS1_H['Carat'] = df_050_059_PR_VS1_H['Carat'].astype('float64')
                    df_050_059_PR_VS1_H['PPC'] = df_050_059_PR_VS1_H['PPC'].astype('float64')
                    df_050_059_PR_VS1_H['Total'] = df_050_059_PR_VS1_H['Total'].astype('float64')
                    df_050_059_PR_VS1_H['Total'] = df_050_059_PR_VS1_H['Carat'] * df_050_059_PR_VS1_H['PPC']


                elif i=="H" and j == "VS2" and k == "PR":
                    df_050_059_PR_VS2_H = pd.DataFrame()
                    df_050_059_PR_VS2_H ['Wt Range'] = None
                    df_050_059_PR_VS2_H  = df_050_059_PR_VS2_H.assign(Company=None)
                    df_050_059_PR_VS2_H  = df_050_059_PR_VS2_H.assign(Shape=None)
                    df_050_059_PR_VS2_H  = df_050_059_PR_VS2_H.assign(Carat=None)
                    df_050_059_PR_VS2_H  = df_050_059_PR_VS2_H.assign(Color=None)
                    df_050_059_PR_VS2_H  = df_050_059_PR_VS2_H.assign(Clarity=None)
                    df_050_059_PR_VS2_H  = df_050_059_PR_VS2_H.assign(Cut=None)
                    df_050_059_PR_VS2_H  = df_050_059_PR_VS2_H.assign(Polish=None)
                    df_050_059_PR_VS2_H  = df_050_059_PR_VS2_H.assign(Symmetry=None)
                    df_050_059_PR_VS2_H  = df_050_059_PR_VS2_H.assign(Ratio=None)
                    df_050_059_PR_VS2_H  = df_050_059_PR_VS2_H.assign(PPC=None)
                    df_050_059_PR_VS2_H  = df_050_059_PR_VS2_H.assign(Total=None)
                    df_050_059_PR_VS2_H ['Wt Range'] = listwtrange
                    df_050_059_PR_VS2_H ['Company'] = listcom
                    df_050_059_PR_VS2_H ['Shape'] = listshap
                    df_050_059_PR_VS2_H ['Carat'] = listcar
                    df_050_059_PR_VS2_H ['Color'] = listcol
                    df_050_059_PR_VS2_H ['Clarity'] = listclar
                    df_050_059_PR_VS2_H ['Cut'] = listcut
                    df_050_059_PR_VS2_H ['Polish'] = listpol
                    df_050_059_PR_VS2_H ['Symmetry'] = listsym
                    df_050_059_PR_VS2_H ['Ratio'] = listrat
                    df_050_059_PR_VS2_H ['PPC'] = listdesc
                    df_050_059_PR_VS2_H ['Total'] = listtotal
                    df_050_059_PR_VS2_H['Carat'] = df_050_059_PR_VS2_H['Carat'].astype('float64')
                    df_050_059_PR_VS2_H['PPC'] = df_050_059_PR_VS2_H['PPC'].astype('float64')
                    df_050_059_PR_VS2_H['Total'] = df_050_059_PR_VS2_H['Total'].astype('float64')
                    df_050_059_PR_VS2_H['Total'] = df_050_059_PR_VS2_H['Carat'] * df_050_059_PR_VS2_H['PPC']


                elif i=="H" and j == "SI1" and k == "PR":
                    df_050_059_PR_SI1_H = pd.DataFrame()
                    df_050_059_PR_SI1_H ['Wt Range'] = None
                    df_050_059_PR_SI1_H  = df_050_059_PR_SI1_H.assign(Company=None)
                    df_050_059_PR_SI1_H  = df_050_059_PR_SI1_H.assign(Shape=None)
                    df_050_059_PR_SI1_H  = df_050_059_PR_SI1_H.assign(Carat=None)
                    df_050_059_PR_SI1_H  = df_050_059_PR_SI1_H.assign(Color=None)
                    df_050_059_PR_SI1_H  = df_050_059_PR_SI1_H.assign(Clarity=None)
                    df_050_059_PR_SI1_H  = df_050_059_PR_SI1_H.assign(Cut=None)
                    df_050_059_PR_SI1_H  = df_050_059_PR_SI1_H.assign(Polish=None)
                    df_050_059_PR_SI1_H  = df_050_059_PR_SI1_H.assign(Symmetry=None)
                    df_050_059_PR_SI1_H  = df_050_059_PR_SI1_H.assign(Ratio=None)
                    df_050_059_PR_SI1_H  = df_050_059_PR_SI1_H.assign(PPC=None)
                    df_050_059_PR_SI1_H  = df_050_059_PR_SI1_H.assign(Total=None)
                    df_050_059_PR_SI1_H ['Wt Range'] = listwtrange
                    df_050_059_PR_SI1_H ['Company'] = listcom
                    df_050_059_PR_SI1_H ['Shape'] = listshap
                    df_050_059_PR_SI1_H ['Carat'] = listcar
                    df_050_059_PR_SI1_H ['Color'] = listcol
                    df_050_059_PR_SI1_H ['Clarity'] = listclar
                    df_050_059_PR_SI1_H ['Cut'] = listcut
                    df_050_059_PR_SI1_H ['Polish'] = listpol
                    df_050_059_PR_SI1_H ['Symmetry'] = listsym
                    df_050_059_PR_SI1_H ['Ratio'] = listrat
                    df_050_059_PR_SI1_H ['PPC'] = listdesc
                    df_050_059_PR_SI1_H ['Total'] = listtotal
                    df_050_059_PR_SI1_H['Carat'] = df_050_059_PR_SI1_H['Carat'].astype('float64')
                    df_050_059_PR_SI1_H['PPC'] = df_050_059_PR_SI1_H['PPC'].astype('float64')
                    df_050_059_PR_SI1_H['Total'] = df_050_059_PR_SI1_H['Total'].astype('float64')
                    df_050_059_PR_SI1_H['Total'] = df_050_059_PR_SI1_H['Carat'] * df_050_059_PR_SI1_H['PPC']


                elif i=="H" and j == "SI2" and k == "PR":
                    df_050_059_PR_SI2_H = pd.DataFrame()
                    df_050_059_PR_SI2_H ['Wt Range'] = None
                    df_050_059_PR_SI2_H  = df_050_059_PR_SI2_H.assign(Company=None)
                    df_050_059_PR_SI2_H  = df_050_059_PR_SI2_H.assign(Shape=None)
                    df_050_059_PR_SI2_H  = df_050_059_PR_SI2_H.assign(Carat=None)
                    df_050_059_PR_SI2_H  = df_050_059_PR_SI2_H.assign(Color=None)
                    df_050_059_PR_SI2_H  = df_050_059_PR_SI2_H.assign(Clarity=None)
                    df_050_059_PR_SI2_H  = df_050_059_PR_SI2_H.assign(Cut=None)
                    df_050_059_PR_SI2_H  = df_050_059_PR_SI2_H.assign(Polish=None)
                    df_050_059_PR_SI2_H  = df_050_059_PR_SI2_H.assign(Symmetry=None)
                    df_050_059_PR_SI2_H  = df_050_059_PR_SI2_H.assign(Ratio=None)
                    df_050_059_PR_SI2_H  = df_050_059_PR_SI2_H.assign(PPC=None)
                    df_050_059_PR_SI2_H  = df_050_059_PR_SI2_H.assign(Total=None)
                    df_050_059_PR_SI2_H ['Wt Range'] = listwtrange
                    df_050_059_PR_SI2_H ['Company'] = listcom
                    df_050_059_PR_SI2_H ['Shape'] = listshap
                    df_050_059_PR_SI2_H ['Carat'] = listcar
                    df_050_059_PR_SI2_H ['Color'] = listcol
                    df_050_059_PR_SI2_H ['Clarity'] = listclar
                    df_050_059_PR_SI2_H ['Cut'] = listcut
                    df_050_059_PR_SI2_H ['Polish'] = listpol
                    df_050_059_PR_SI2_H ['Symmetry'] = listsym
                    df_050_059_PR_SI2_H ['Ratio'] = listrat
                    df_050_059_PR_SI2_H ['PPC'] = listdesc
                    df_050_059_PR_SI2_H ['Total'] = listtotal
                    df_050_059_PR_SI2_H['Carat'] = df_050_059_PR_SI2_H['Carat'].astype('float64')
                    df_050_059_PR_SI2_H['PPC'] = df_050_059_PR_SI2_H['PPC'].astype('float64')
                    df_050_059_PR_SI2_H['Total'] = df_050_059_PR_SI2_H['Total'].astype('float64')
                    df_050_059_PR_SI2_H['Total'] = df_050_059_PR_SI2_H['Carat'] * df_050_059_PR_SI2_H['PPC']


                elif i=="H" and j == "I1" and k == "PR":
                    df_050_059_PR_I1_H = pd.DataFrame()
                    df_050_059_PR_I1_H ['Wt Range'] = None
                    df_050_059_PR_I1_H  = df_050_059_PR_I1_H.assign(Company=None)
                    df_050_059_PR_I1_H  = df_050_059_PR_I1_H.assign(Shape=None)
                    df_050_059_PR_I1_H  = df_050_059_PR_I1_H.assign(Carat=None)
                    df_050_059_PR_I1_H  = df_050_059_PR_I1_H.assign(Color=None)
                    df_050_059_PR_I1_H  = df_050_059_PR_I1_H.assign(Clarity=None)
                    df_050_059_PR_I1_H  = df_050_059_PR_I1_H.assign(Cut=None)
                    df_050_059_PR_I1_H  = df_050_059_PR_I1_H.assign(Polish=None)
                    df_050_059_PR_I1_H  = df_050_059_PR_I1_H.assign(Symmetry=None)
                    df_050_059_PR_I1_H  = df_050_059_PR_I1_H.assign(Ratio=None)
                    df_050_059_PR_I1_H  = df_050_059_PR_I1_H.assign(PPC=None)
                    df_050_059_PR_I1_H  = df_050_059_PR_I1_H.assign(Total=None)
                    df_050_059_PR_I1_H ['Wt Range'] = listwtrange
                    df_050_059_PR_I1_H ['Company'] = listcom
                    df_050_059_PR_I1_H ['Shape'] = listshap
                    df_050_059_PR_I1_H ['Carat'] = listcar
                    df_050_059_PR_I1_H ['Color'] = listcol
                    df_050_059_PR_I1_H ['Clarity'] = listclar
                    df_050_059_PR_I1_H ['Cut'] = listcut
                    df_050_059_PR_I1_H ['Polish'] = listpol
                    df_050_059_PR_I1_H ['Symmetry'] = listsym
                    df_050_059_PR_I1_H ['Ratio'] = listrat
                    df_050_059_PR_I1_H ['PPC'] = listdesc
                    df_050_059_PR_I1_H ['Total'] = listtotal
                    df_050_059_PR_I1_H['Carat'] = df_050_059_PR_I1_H['Carat'].astype('float64')
                    df_050_059_PR_I1_H['PPC'] = df_050_059_PR_I1_H['PPC'].astype('float64')
                    df_050_059_PR_I1_H['Total'] = df_050_059_PR_I1_H['Total'].astype('float64')
                    df_050_059_PR_I1_H['Total'] = df_050_059_PR_I1_H['Carat'] * df_050_059_PR_I1_H['PPC']


                elif i=="H" and j == "I2" and k == "PR":
                    df_050_059_PR_I2_H = pd.DataFrame()
                    df_050_059_PR_I2_H ['Wt Range'] = None
                    df_050_059_PR_I2_H  = df_050_059_PR_I2_H.assign(Company=None)
                    df_050_059_PR_I2_H  = df_050_059_PR_I2_H.assign(Shape=None)
                    df_050_059_PR_I2_H  = df_050_059_PR_I2_H.assign(Carat=None)
                    df_050_059_PR_I2_H  = df_050_059_PR_I2_H.assign(Color=None)
                    df_050_059_PR_I2_H  = df_050_059_PR_I2_H.assign(Clarity=None)
                    df_050_059_PR_I2_H  = df_050_059_PR_I2_H.assign(Cut=None)
                    df_050_059_PR_I2_H  = df_050_059_PR_I2_H.assign(Polish=None)
                    df_050_059_PR_I2_H  = df_050_059_PR_I2_H.assign(Symmetry=None)
                    df_050_059_PR_I2_H  = df_050_059_PR_I2_H.assign(Ratio=None)
                    df_050_059_PR_I2_H  = df_050_059_PR_I2_H.assign(PPC=None)
                    df_050_059_PR_I2_H  = df_050_059_PR_I2_H.assign(Total=None)
                    df_050_059_PR_I2_H ['Wt Range'] = listwtrange
                    df_050_059_PR_I2_H ['Company'] = listcom
                    df_050_059_PR_I2_H ['Shape'] = listshap
                    df_050_059_PR_I2_H ['Carat'] = listcar
                    df_050_059_PR_I2_H ['Color'] = listcol
                    df_050_059_PR_I2_H ['Clarity'] = listclar
                    df_050_059_PR_I2_H ['Cut'] = listcut
                    df_050_059_PR_I2_H ['Polish'] = listpol
                    df_050_059_PR_I2_H ['Symmetry'] = listsym
                    df_050_059_PR_I2_H ['Ratio'] = listrat
                    df_050_059_PR_I2_H ['PPC'] = listdesc
                    df_050_059_PR_I2_H ['Total'] = listtotal
                    df_050_059_PR_I2_H['Carat'] = df_050_059_PR_I2_H['Carat'].astype('float64')
                    df_050_059_PR_I2_H['PPC'] = df_050_059_PR_I2_H['PPC'].astype('float64')
                    df_050_059_PR_I2_H['Total'] = df_050_059_PR_I2_H['Total'].astype('float64')
                    df_050_059_PR_I2_H['Total'] = df_050_059_PR_I2_H['Carat'] * df_050_059_PR_I2_H['PPC']



                elif i== "I" and j == "IF" and k == "PR":
                    df_050_059_PR_IF_I = pd.DataFrame()
                    df_050_059_PR_IF_I ['Wt Range'] = None
                    df_050_059_PR_IF_I  = df_050_059_PR_IF_I.assign(Company=None)
                    df_050_059_PR_IF_I  = df_050_059_PR_IF_I.assign(Shape=None)
                    df_050_059_PR_IF_I  = df_050_059_PR_IF_I.assign(Carat=None)
                    df_050_059_PR_IF_I  = df_050_059_PR_IF_I.assign(Color=None)
                    df_050_059_PR_IF_I  = df_050_059_PR_IF_I.assign(Clarity=None)
                    df_050_059_PR_IF_I  = df_050_059_PR_IF_I.assign(Cut=None)
                    df_050_059_PR_IF_I  = df_050_059_PR_IF_I.assign(Polish=None)
                    df_050_059_PR_IF_I  = df_050_059_PR_IF_I.assign(Symmetry=None)
                    df_050_059_PR_IF_I  = df_050_059_PR_IF_I.assign(Ratio=None)
                    df_050_059_PR_IF_I  = df_050_059_PR_IF_I.assign(PPC=None)
                    df_050_059_PR_IF_I  = df_050_059_PR_IF_I.assign(Total=None)
                    df_050_059_PR_IF_I ['Wt Range'] = listwtrange
                    df_050_059_PR_IF_I ['Company'] = listcom
                    df_050_059_PR_IF_I ['Shape'] = listshap
                    df_050_059_PR_IF_I ['Carat'] = listcar
                    df_050_059_PR_IF_I ['Color'] = listcol
                    df_050_059_PR_IF_I ['Clarity'] = listclar
                    df_050_059_PR_IF_I ['Cut'] = listcut
                    df_050_059_PR_IF_I ['Polish'] = listpol
                    df_050_059_PR_IF_I ['Symmetry'] = listsym
                    df_050_059_PR_IF_I ['Ratio'] = listrat
                    df_050_059_PR_IF_I ['PPC'] = listdesc
                    df_050_059_PR_IF_I ['Total'] = listtotal
                    df_050_059_PR_IF_I['Carat'] = df_050_059_PR_IF_I['Carat'].astype('float64')
                    df_050_059_PR_IF_I['PPC'] = df_050_059_PR_IF_I['PPC'].astype('float64')
                    df_050_059_PR_IF_I['Total'] = df_050_059_PR_IF_I['Total'].astype('float64')
                    df_050_059_PR_IF_I['Total'] = df_050_059_PR_IF_I['Carat'] * df_050_059_PR_IF_I['PPC']



                elif i== "I" and j == "VVS1" and k == "PR":
                    df_050_059_PR_VVS1_I = pd.DataFrame()
                    df_050_059_PR_VVS1_I ['Wt Range'] = None
                    df_050_059_PR_VVS1_I  = df_050_059_PR_VVS1_I.assign(Company=None)
                    df_050_059_PR_VVS1_I  = df_050_059_PR_VVS1_I.assign(Shape=None)
                    df_050_059_PR_VVS1_I  = df_050_059_PR_VVS1_I.assign(Carat=None)
                    df_050_059_PR_VVS1_I  = df_050_059_PR_VVS1_I.assign(Color=None)
                    df_050_059_PR_VVS1_I  = df_050_059_PR_VVS1_I.assign(Clarity=None)
                    df_050_059_PR_VVS1_I  = df_050_059_PR_VVS1_I.assign(Cut=None)
                    df_050_059_PR_VVS1_I  = df_050_059_PR_VVS1_I.assign(Polish=None)
                    df_050_059_PR_VVS1_I  = df_050_059_PR_VVS1_I.assign(Symmetry=None)
                    df_050_059_PR_VVS1_I  = df_050_059_PR_VVS1_I.assign(Ratio=None)
                    df_050_059_PR_VVS1_I  = df_050_059_PR_VVS1_I.assign(PPC=None)
                    df_050_059_PR_VVS1_I  = df_050_059_PR_VVS1_I.assign(Total=None)
                    df_050_059_PR_VVS1_I ['Wt Range'] = listwtrange
                    df_050_059_PR_VVS1_I ['Company'] = listcom
                    df_050_059_PR_VVS1_I ['Shape'] = listshap
                    df_050_059_PR_VVS1_I ['Carat'] = listcar
                    df_050_059_PR_VVS1_I ['Color'] = listcol
                    df_050_059_PR_VVS1_I ['Clarity'] = listclar
                    df_050_059_PR_VVS1_I ['Cut'] = listcut
                    df_050_059_PR_VVS1_I ['Polish'] = listpol
                    df_050_059_PR_VVS1_I ['Symmetry'] = listsym
                    df_050_059_PR_VVS1_I ['Ratio'] = listrat
                    df_050_059_PR_VVS1_I ['PPC'] = listdesc
                    df_050_059_PR_VVS1_I ['Total'] = listtotal
                    df_050_059_PR_VVS1_I['Carat'] = df_050_059_PR_VVS1_I['Carat'].astype('float64')
                    df_050_059_PR_VVS1_I['PPC'] = df_050_059_PR_VVS1_I['PPC'].astype('float64')
                    df_050_059_PR_VVS1_I['Total'] = df_050_059_PR_VVS1_I['Total'].astype('float64')
                    df_050_059_PR_VVS1_I['Total'] = df_050_059_PR_VVS1_I['Carat'] * df_050_059_PR_VVS1_I['PPC']


                elif i== "I" and j == "VVS2" and k == "PR":
                    df_050_059_PR_VVS2_I = pd.DataFrame()
                    df_050_059_PR_VVS2_I ['Wt Range'] = None
                    df_050_059_PR_VVS2_I  = df_050_059_PR_VVS2_I.assign(Company=None)
                    df_050_059_PR_VVS2_I  = df_050_059_PR_VVS2_I.assign(Shape=None)
                    df_050_059_PR_VVS2_I  = df_050_059_PR_VVS2_I.assign(Carat=None)
                    df_050_059_PR_VVS2_I  = df_050_059_PR_VVS2_I.assign(Color=None)
                    df_050_059_PR_VVS2_I  = df_050_059_PR_VVS2_I.assign(Clarity=None)
                    df_050_059_PR_VVS2_I  = df_050_059_PR_VVS2_I.assign(Cut=None)
                    df_050_059_PR_VVS2_I  = df_050_059_PR_VVS2_I.assign(Polish=None)
                    df_050_059_PR_VVS2_I  = df_050_059_PR_VVS2_I.assign(Symmetry=None)
                    df_050_059_PR_VVS2_I  = df_050_059_PR_VVS2_I.assign(Ratio=None)
                    df_050_059_PR_VVS2_I  = df_050_059_PR_VVS2_I.assign(PPC=None)
                    df_050_059_PR_VVS2_I  = df_050_059_PR_VVS2_I.assign(Total=None)
                    df_050_059_PR_VVS2_I ['Wt Range'] = listwtrange
                    df_050_059_PR_VVS2_I ['Company'] = listcom
                    df_050_059_PR_VVS2_I ['Shape'] = listshap
                    df_050_059_PR_VVS2_I ['Carat'] = listcar
                    df_050_059_PR_VVS2_I ['Color'] = listcol
                    df_050_059_PR_VVS2_I ['Clarity'] = listclar
                    df_050_059_PR_VVS2_I ['Cut'] = listcut
                    df_050_059_PR_VVS2_I ['Polish'] = listpol
                    df_050_059_PR_VVS2_I ['Symmetry'] = listsym
                    df_050_059_PR_VVS2_I ['Ratio'] = listrat
                    df_050_059_PR_VVS2_I ['PPC'] = listdesc
                    df_050_059_PR_VVS2_I ['Total'] = listtotal
                    df_050_059_PR_VVS2_I['Carat'] = df_050_059_PR_VVS2_I['Carat'].astype('float64')
                    df_050_059_PR_VVS2_I['PPC'] = df_050_059_PR_VVS2_I['PPC'].astype('float64')
                    df_050_059_PR_VVS2_I['Total'] = df_050_059_PR_VVS2_I['Total'].astype('float64')
                    df_050_059_PR_VVS2_I['Total'] = df_050_059_PR_VVS2_I['Carat'] * df_050_059_PR_VVS2_I['PPC']


                elif i== "I" and j=="VS1" and k == "PR":
                    df_050_059_PR_VS1_I = pd.DataFrame()
                    df_050_059_PR_VS1_I ['Wt Range'] = None
                    df_050_059_PR_VS1_I  = df_050_059_PR_VS1_I.assign(Company=None)
                    df_050_059_PR_VS1_I  = df_050_059_PR_VS1_I.assign(Shape=None)
                    df_050_059_PR_VS1_I  = df_050_059_PR_VS1_I.assign(Carat=None)
                    df_050_059_PR_VS1_I  = df_050_059_PR_VS1_I.assign(Color=None)
                    df_050_059_PR_VS1_I  = df_050_059_PR_VS1_I.assign(Clarity=None)
                    df_050_059_PR_VS1_I  = df_050_059_PR_VS1_I.assign(Cut=None)
                    df_050_059_PR_VS1_I  = df_050_059_PR_VS1_I.assign(Polish=None)
                    df_050_059_PR_VS1_I  = df_050_059_PR_VS1_I.assign(Symmetry=None)
                    df_050_059_PR_VS1_I  = df_050_059_PR_VS1_I.assign(Ratio=None)
                    df_050_059_PR_VS1_I  = df_050_059_PR_VS1_I.assign(PPC=None)
                    df_050_059_PR_VS1_I  = df_050_059_PR_VS1_I.assign(Total=None)
                    df_050_059_PR_VS1_I ['Wt Range'] = listwtrange
                    df_050_059_PR_VS1_I ['Company'] = listcom
                    df_050_059_PR_VS1_I ['Shape'] = listshap
                    df_050_059_PR_VS1_I ['Carat'] = listcar
                    df_050_059_PR_VS1_I ['Color'] = listcol
                    df_050_059_PR_VS1_I ['Clarity'] = listclar
                    df_050_059_PR_VS1_I ['Cut'] = listcut
                    df_050_059_PR_VS1_I ['Polish'] = listpol
                    df_050_059_PR_VS1_I ['Symmetry'] = listsym
                    df_050_059_PR_VS1_I ['Ratio'] = listrat
                    df_050_059_PR_VS1_I ['PPC'] = listdesc
                    df_050_059_PR_VS1_I ['Total'] = listtotal
                    df_050_059_PR_VS1_I['Carat'] = df_050_059_PR_VS1_I['Carat'].astype('float64')
                    df_050_059_PR_VS1_I['PPC'] = df_050_059_PR_VS1_I['PPC'].astype('float64')
                    df_050_059_PR_VS1_I['Total'] = df_050_059_PR_VS1_I['Total'].astype('float64')
                    df_050_059_PR_VS1_I['Total'] = df_050_059_PR_VS1_I['Carat'] * df_050_059_PR_VS1_I['PPC']


                elif i== "I" and j == "VS2" and k == "PR":
                    df_050_059_PR_VS2_I = pd.DataFrame()
                    df_050_059_PR_VS2_I ['Wt Range'] = None
                    df_050_059_PR_VS2_I  = df_050_059_PR_VS2_I.assign(Company=None)
                    df_050_059_PR_VS2_I  = df_050_059_PR_VS2_I.assign(Shape=None)
                    df_050_059_PR_VS2_I  = df_050_059_PR_VS2_I.assign(Carat=None)
                    df_050_059_PR_VS2_I  = df_050_059_PR_VS2_I.assign(Color=None)
                    df_050_059_PR_VS2_I  = df_050_059_PR_VS2_I.assign(Clarity=None)
                    df_050_059_PR_VS2_I  = df_050_059_PR_VS2_I.assign(Cut=None)
                    df_050_059_PR_VS2_I  = df_050_059_PR_VS2_I.assign(Polish=None)
                    df_050_059_PR_VS2_I  = df_050_059_PR_VS2_I.assign(Symmetry=None)
                    df_050_059_PR_VS2_I  = df_050_059_PR_VS2_I.assign(Ratio=None)
                    df_050_059_PR_VS2_I  = df_050_059_PR_VS2_I.assign(PPC=None)
                    df_050_059_PR_VS2_I  = df_050_059_PR_VS2_I.assign(Total=None)
                    df_050_059_PR_VS2_I ['Wt Range'] = listwtrange
                    df_050_059_PR_VS2_I ['Company'] = listcom
                    df_050_059_PR_VS2_I ['Shape'] = listshap
                    df_050_059_PR_VS2_I ['Carat'] = listcar
                    df_050_059_PR_VS2_I ['Color'] = listcol
                    df_050_059_PR_VS2_I ['Clarity'] = listclar
                    df_050_059_PR_VS2_I ['Cut'] = listcut
                    df_050_059_PR_VS2_I ['Polish'] = listpol
                    df_050_059_PR_VS2_I ['Symmetry'] = listsym
                    df_050_059_PR_VS2_I ['Ratio'] = listrat
                    df_050_059_PR_VS2_I ['PPC'] = listdesc
                    df_050_059_PR_VS2_I ['Total'] = listtotal
                    df_050_059_PR_VS2_I['Carat'] = df_050_059_PR_VS2_I['Carat'].astype('float64')
                    df_050_059_PR_VS2_I['PPC'] = df_050_059_PR_VS2_I['PPC'].astype('float64')
                    df_050_059_PR_VS2_I['Total'] = df_050_059_PR_VS2_I['Total'].astype('float64')
                    df_050_059_PR_VS2_I['Total'] = df_050_059_PR_VS2_I['Carat'] * df_050_059_PR_VS2_I['PPC']


                elif i== "I" and j == "SI1" and k == "PR":
                    df_050_059_PR_SI1_I = pd.DataFrame()
                    df_050_059_PR_SI1_I ['Wt Range'] = None
                    df_050_059_PR_SI1_I  = df_050_059_PR_SI1_I.assign(Company=None)
                    df_050_059_PR_SI1_I  = df_050_059_PR_SI1_I.assign(Shape=None)
                    df_050_059_PR_SI1_I  = df_050_059_PR_SI1_I.assign(Carat=None)
                    df_050_059_PR_SI1_I  = df_050_059_PR_SI1_I.assign(Color=None)
                    df_050_059_PR_SI1_I  = df_050_059_PR_SI1_I.assign(Clarity=None)
                    df_050_059_PR_SI1_I  = df_050_059_PR_SI1_I.assign(Cut=None)
                    df_050_059_PR_SI1_I  = df_050_059_PR_SI1_I.assign(Polish=None)
                    df_050_059_PR_SI1_I  = df_050_059_PR_SI1_I.assign(Symmetry=None)
                    df_050_059_PR_SI1_I  = df_050_059_PR_SI1_I.assign(Ratio=None)
                    df_050_059_PR_SI1_I  = df_050_059_PR_SI1_I.assign(PPC=None)
                    df_050_059_PR_SI1_I  = df_050_059_PR_SI1_I.assign(Total=None)
                    df_050_059_PR_SI1_I ['Wt Range'] = listwtrange
                    df_050_059_PR_SI1_I ['Company'] = listcom
                    df_050_059_PR_SI1_I ['Shape'] = listshap
                    df_050_059_PR_SI1_I ['Carat'] = listcar
                    df_050_059_PR_SI1_I ['Color'] = listcol
                    df_050_059_PR_SI1_I ['Clarity'] = listclar
                    df_050_059_PR_SI1_I ['Cut'] = listcut
                    df_050_059_PR_SI1_I ['Polish'] = listpol
                    df_050_059_PR_SI1_I ['Symmetry'] = listsym
                    df_050_059_PR_SI1_I ['Ratio'] = listrat
                    df_050_059_PR_SI1_I ['PPC'] = listdesc
                    df_050_059_PR_SI1_I ['Total'] = listtotal
                    df_050_059_PR_SI1_I['Carat'] = df_050_059_PR_SI1_I['Carat'].astype('float64')
                    df_050_059_PR_SI1_I['PPC'] = df_050_059_PR_SI1_I['PPC'].astype('float64')
                    df_050_059_PR_SI1_I['Total'] = df_050_059_PR_SI1_I['Total'].astype('float64')
                    df_050_059_PR_SI1_I['Total'] = df_050_059_PR_SI1_I['Carat'] * df_050_059_PR_SI1_I['PPC']


                elif i== "I" and j == "SI2" and k == "PR":
                    df_050_059_PR_SI2_I = pd.DataFrame()
                    df_050_059_PR_SI2_I ['Wt Range'] = None
                    df_050_059_PR_SI2_I  = df_050_059_PR_SI2_I.assign(Company=None)
                    df_050_059_PR_SI2_I  = df_050_059_PR_SI2_I.assign(Shape=None)
                    df_050_059_PR_SI2_I  = df_050_059_PR_SI2_I.assign(Carat=None)
                    df_050_059_PR_SI2_I  = df_050_059_PR_SI2_I.assign(Color=None)
                    df_050_059_PR_SI2_I  = df_050_059_PR_SI2_I.assign(Clarity=None)
                    df_050_059_PR_SI2_I  = df_050_059_PR_SI2_I.assign(Cut=None)
                    df_050_059_PR_SI2_I  = df_050_059_PR_SI2_I.assign(Polish=None)
                    df_050_059_PR_SI2_I  = df_050_059_PR_SI2_I.assign(Symmetry=None)
                    df_050_059_PR_SI2_I  = df_050_059_PR_SI2_I.assign(Ratio=None)
                    df_050_059_PR_SI2_I  = df_050_059_PR_SI2_I.assign(PPC=None)
                    df_050_059_PR_SI2_I  = df_050_059_PR_SI2_I.assign(Total=None)
                    df_050_059_PR_SI2_I ['Wt Range'] = listwtrange
                    df_050_059_PR_SI2_I ['Company'] = listcom
                    df_050_059_PR_SI2_I ['Shape'] = listshap
                    df_050_059_PR_SI2_I ['Carat'] = listcar
                    df_050_059_PR_SI2_I ['Color'] = listcol
                    df_050_059_PR_SI2_I ['Clarity'] = listclar
                    df_050_059_PR_SI2_I ['Cut'] = listcut
                    df_050_059_PR_SI2_I ['Polish'] = listpol
                    df_050_059_PR_SI2_I ['Symmetry'] = listsym
                    df_050_059_PR_SI2_I ['Ratio'] = listrat
                    df_050_059_PR_SI2_I ['PPC'] = listdesc
                    df_050_059_PR_SI2_I ['Total'] = listtotal
                    df_050_059_PR_SI2_I['Carat'] = df_050_059_PR_SI2_I['Carat'].astype('float64')
                    df_050_059_PR_SI2_I['PPC'] = df_050_059_PR_SI2_I['PPC'].astype('float64')
                    df_050_059_PR_SI2_I['Total'] = df_050_059_PR_SI2_I['Total'].astype('float64')
                    df_050_059_PR_SI2_I['Total'] = df_050_059_PR_SI2_I['Carat'] * df_050_059_PR_SI2_I['PPC']


                elif i== "I" and j == "I1" and k == "PR":
                    df_050_059_PR_I1_I = pd.DataFrame()
                    df_050_059_PR_I1_I ['Wt Range'] = None
                    df_050_059_PR_I1_I  = df_050_059_PR_I1_I.assign(Company=None)
                    df_050_059_PR_I1_I  = df_050_059_PR_I1_I.assign(Shape=None)
                    df_050_059_PR_I1_I  = df_050_059_PR_I1_I.assign(Carat=None)
                    df_050_059_PR_I1_I  = df_050_059_PR_I1_I.assign(Color=None)
                    df_050_059_PR_I1_I  = df_050_059_PR_I1_I.assign(Clarity=None)
                    df_050_059_PR_I1_I  = df_050_059_PR_I1_I.assign(Cut=None)
                    df_050_059_PR_I1_I  = df_050_059_PR_I1_I.assign(Polish=None)
                    df_050_059_PR_I1_I  = df_050_059_PR_I1_I.assign(Symmetry=None)
                    df_050_059_PR_I1_I  = df_050_059_PR_I1_I.assign(Ratio=None)
                    df_050_059_PR_I1_I  = df_050_059_PR_I1_I.assign(PPC=None)
                    df_050_059_PR_I1_I  = df_050_059_PR_I1_I.assign(Total=None)
                    df_050_059_PR_I1_I ['Wt Range'] = listwtrange
                    df_050_059_PR_I1_I ['Company'] = listcom
                    df_050_059_PR_I1_I ['Shape'] = listshap
                    df_050_059_PR_I1_I ['Carat'] = listcar
                    df_050_059_PR_I1_I ['Color'] = listcol
                    df_050_059_PR_I1_I ['Clarity'] = listclar
                    df_050_059_PR_I1_I ['Cut'] = listcut
                    df_050_059_PR_I1_I ['Polish'] = listpol
                    df_050_059_PR_I1_I ['Symmetry'] = listsym
                    df_050_059_PR_I1_I ['Ratio'] = listrat
                    df_050_059_PR_I1_I ['PPC'] = listdesc
                    df_050_059_PR_I1_I ['Total'] = listtotal
                    df_050_059_PR_I1_I['Carat'] = df_050_059_PR_I1_I['Carat'].astype('float64')
                    df_050_059_PR_I1_I['PPC'] = df_050_059_PR_I1_I['PPC'].astype('float64')
                    df_050_059_PR_I1_I['Total'] = df_050_059_PR_I1_I['Total'].astype('float64')
                    df_050_059_PR_I1_I['Total'] = df_050_059_PR_I1_I['Carat'] * df_050_059_PR_I1_I['PPC']


                elif i== "I" and j == "I2" and k == "PR":
                    df_050_059_PR_I2_I = pd.DataFrame()
                    df_050_059_PR_I2_I ['Wt Range'] = None
                    df_050_059_PR_I2_I  = df_050_059_PR_I2_I.assign(Company=None)
                    df_050_059_PR_I2_I  = df_050_059_PR_I2_I.assign(Shape=None)
                    df_050_059_PR_I2_I  = df_050_059_PR_I2_I.assign(Carat=None)
                    df_050_059_PR_I2_I  = df_050_059_PR_I2_I.assign(Color=None)
                    df_050_059_PR_I2_I  = df_050_059_PR_I2_I.assign(Clarity=None)
                    df_050_059_PR_I2_I  = df_050_059_PR_I2_I.assign(Cut=None)
                    df_050_059_PR_I2_I  = df_050_059_PR_I2_I.assign(Polish=None)
                    df_050_059_PR_I2_I  = df_050_059_PR_I2_I.assign(Symmetry=None)
                    df_050_059_PR_I2_I  = df_050_059_PR_I2_I.assign(Ratio=None)
                    df_050_059_PR_I2_I  = df_050_059_PR_I2_I.assign(PPC=None)
                    df_050_059_PR_I2_I  = df_050_059_PR_I2_I.assign(Total=None)
                    df_050_059_PR_I2_I ['Wt Range'] = listwtrange
                    df_050_059_PR_I2_I ['Company'] = listcom
                    df_050_059_PR_I2_I ['Shape'] = listshap
                    df_050_059_PR_I2_I ['Carat'] = listcar
                    df_050_059_PR_I2_I ['Color'] = listcol
                    df_050_059_PR_I2_I ['Clarity'] = listclar
                    df_050_059_PR_I2_I ['Cut'] = listcut
                    df_050_059_PR_I2_I ['Polish'] = listpol
                    df_050_059_PR_I2_I ['Symmetry'] = listsym
                    df_050_059_PR_I2_I ['Ratio'] = listrat
                    df_050_059_PR_I2_I ['PPC'] = listdesc
                    df_050_059_PR_I2_I ['Total'] = listtotal
                    df_050_059_PR_I2_I['Carat'] = df_050_059_PR_I2_I['Carat'].astype('float64')
                    df_050_059_PR_I2_I['PPC'] = df_050_059_PR_I2_I['PPC'].astype('float64')
                    df_050_059_PR_I2_I['Total'] = df_050_059_PR_I2_I['Total'].astype('float64')
                    df_050_059_PR_I2_I['Total'] = df_050_059_PR_I2_I['Carat'] * df_050_059_PR_I2_I['PPC']


                elif i=="J" and j == "IF" and k == "PR":
                    df_050_059_PR_IF_J = pd.DataFrame()
                    df_050_059_PR_IF_J ['Wt Range'] = None
                    df_050_059_PR_IF_J  = df_050_059_PR_IF_J.assign(Company=None)
                    df_050_059_PR_IF_J  = df_050_059_PR_IF_J.assign(Shape=None)
                    df_050_059_PR_IF_J  = df_050_059_PR_IF_J.assign(Carat=None)
                    df_050_059_PR_IF_J  = df_050_059_PR_IF_J.assign(Color=None)
                    df_050_059_PR_IF_J  = df_050_059_PR_IF_J.assign(Clarity=None)
                    df_050_059_PR_IF_J  = df_050_059_PR_IF_J.assign(Cut=None)
                    df_050_059_PR_IF_J  = df_050_059_PR_IF_J.assign(Polish=None)
                    df_050_059_PR_IF_J  = df_050_059_PR_IF_J.assign(Symmetry=None)
                    df_050_059_PR_IF_J  = df_050_059_PR_IF_J.assign(Ratio=None)
                    df_050_059_PR_IF_J  = df_050_059_PR_IF_J.assign(PPC=None)
                    df_050_059_PR_IF_J  = df_050_059_PR_IF_J.assign(Total=None)
                    df_050_059_PR_IF_J ['Wt Range'] = listwtrange
                    df_050_059_PR_IF_J ['Company'] = listcom
                    df_050_059_PR_IF_J ['Shape'] = listshap
                    df_050_059_PR_IF_J ['Carat'] = listcar
                    df_050_059_PR_IF_J ['Color'] = listcol
                    df_050_059_PR_IF_J ['Clarity'] = listclar
                    df_050_059_PR_IF_J ['Cut'] = listcut
                    df_050_059_PR_IF_J ['Polish'] = listpol
                    df_050_059_PR_IF_J ['Symmetry'] = listsym
                    df_050_059_PR_IF_J ['Ratio'] = listrat
                    df_050_059_PR_IF_J ['PPC'] = listdesc
                    df_050_059_PR_IF_J ['Total'] = listtotal
                    df_050_059_PR_IF_J['Carat'] = df_050_059_PR_IF_J['Carat'].astype('float64')
                    df_050_059_PR_IF_J['PPC'] = df_050_059_PR_IF_J['PPC'].astype('float64')
                    df_050_059_PR_IF_J['Total'] = df_050_059_PR_IF_J['Total'].astype('float64')
                    df_050_059_PR_IF_J['Total'] = df_050_059_PR_IF_J['Carat'] * df_050_059_PR_IF_J['PPC']



                elif i=="J"  and j == "VVS1" and k == "PR":
                    df_050_059_PR_VVS1_J = pd.DataFrame()
                    df_050_059_PR_VVS1_J ['Wt Range'] = None
                    df_050_059_PR_VVS1_J  = df_050_059_PR_VVS1_J.assign(Company=None)
                    df_050_059_PR_VVS1_J  = df_050_059_PR_VVS1_J.assign(Shape=None)
                    df_050_059_PR_VVS1_J  = df_050_059_PR_VVS1_J.assign(Carat=None)
                    df_050_059_PR_VVS1_J  = df_050_059_PR_VVS1_J.assign(Color=None)
                    df_050_059_PR_VVS1_J  = df_050_059_PR_VVS1_J.assign(Clarity=None)
                    df_050_059_PR_VVS1_J  = df_050_059_PR_VVS1_J.assign(Cut=None)
                    df_050_059_PR_VVS1_J  = df_050_059_PR_VVS1_J.assign(Polish=None)
                    df_050_059_PR_VVS1_J  = df_050_059_PR_VVS1_J.assign(Symmetry=None)
                    df_050_059_PR_VVS1_J  = df_050_059_PR_VVS1_J.assign(Ratio=None)
                    df_050_059_PR_VVS1_J  = df_050_059_PR_VVS1_J.assign(PPC=None)
                    df_050_059_PR_VVS1_J  = df_050_059_PR_VVS1_J.assign(Total=None)
                    df_050_059_PR_VVS1_J ['Wt Range'] = listwtrange
                    df_050_059_PR_VVS1_J ['Company'] = listcom
                    df_050_059_PR_VVS1_J ['Shape'] = listshap
                    df_050_059_PR_VVS1_J ['Carat'] = listcar
                    df_050_059_PR_VVS1_J ['Color'] = listcol
                    df_050_059_PR_VVS1_J ['Clarity'] = listclar
                    df_050_059_PR_VVS1_J ['Cut'] = listcut
                    df_050_059_PR_VVS1_J ['Polish'] = listpol
                    df_050_059_PR_VVS1_J ['Symmetry'] = listsym
                    df_050_059_PR_VVS1_J ['Ratio'] = listrat
                    df_050_059_PR_VVS1_J ['PPC'] = listdesc
                    df_050_059_PR_VVS1_J ['Total'] = listtotal
                    df_050_059_PR_VVS1_J['Carat'] = df_050_059_PR_VVS1_J['Carat'].astype('float64')
                    df_050_059_PR_VVS1_J['PPC'] = df_050_059_PR_VVS1_J['PPC'].astype('float64')
                    df_050_059_PR_VVS1_J['Total'] = df_050_059_PR_VVS1_J['Total'].astype('float64')
                    df_050_059_PR_VVS1_J['Total'] = df_050_059_PR_VVS1_J['Carat'] * df_050_059_PR_VVS1_J['PPC']


                elif i=="J"  and j == "VVS2" and k == "PR":
                    df_050_059_PR_VVS2_J = pd.DataFrame()
                    df_050_059_PR_VVS2_J ['Wt Range'] = None
                    df_050_059_PR_VVS2_J  = df_050_059_PR_VVS2_J.assign(Company=None)
                    df_050_059_PR_VVS2_J  = df_050_059_PR_VVS2_J.assign(Shape=None)
                    df_050_059_PR_VVS2_J  = df_050_059_PR_VVS2_J.assign(Carat=None)
                    df_050_059_PR_VVS2_J  = df_050_059_PR_VVS2_J.assign(Color=None)
                    df_050_059_PR_VVS2_J  = df_050_059_PR_VVS2_J.assign(Clarity=None)
                    df_050_059_PR_VVS2_J  = df_050_059_PR_VVS2_J.assign(Cut=None)
                    df_050_059_PR_VVS2_J  = df_050_059_PR_VVS2_J.assign(Polish=None)
                    df_050_059_PR_VVS2_J  = df_050_059_PR_VVS2_J.assign(Symmetry=None)
                    df_050_059_PR_VVS2_J  = df_050_059_PR_VVS2_J.assign(Ratio=None)
                    df_050_059_PR_VVS2_J  = df_050_059_PR_VVS2_J.assign(PPC=None)
                    df_050_059_PR_VVS2_J  = df_050_059_PR_VVS2_J.assign(Total=None)
                    df_050_059_PR_VVS2_J ['Wt Range'] = listwtrange
                    df_050_059_PR_VVS2_J ['Company'] = listcom
                    df_050_059_PR_VVS2_J ['Shape'] = listshap
                    df_050_059_PR_VVS2_J ['Carat'] = listcar
                    df_050_059_PR_VVS2_J ['Color'] = listcol
                    df_050_059_PR_VVS2_J ['Clarity'] = listclar
                    df_050_059_PR_VVS2_J ['Cut'] = listcut
                    df_050_059_PR_VVS2_J ['Polish'] = listpol
                    df_050_059_PR_VVS2_J ['Symmetry'] = listsym
                    df_050_059_PR_VVS2_J ['Ratio'] = listrat
                    df_050_059_PR_VVS2_J ['PPC'] = listdesc
                    df_050_059_PR_VVS2_J ['Total'] = listtotal
                    df_050_059_PR_VVS2_J['Carat'] = df_050_059_PR_VVS2_J['Carat'].astype('float64')
                    df_050_059_PR_VVS2_J['PPC'] = df_050_059_PR_VVS2_J['PPC'].astype('float64')
                    df_050_059_PR_VVS2_J['Total'] = df_050_059_PR_VVS2_J['Total'].astype('float64')
                    df_050_059_PR_VVS2_J['Total'] = df_050_059_PR_VVS2_J['Carat'] * df_050_059_PR_VVS2_J['PPC']


                elif i=="J"  and j=="VS1" and k == "PR":
                    df_050_059_PR_VS1_J = pd.DataFrame()
                    df_050_059_PR_VS1_J ['Wt Range'] = None
                    df_050_059_PR_VS1_J  = df_050_059_PR_VS1_J.assign(Company=None)
                    df_050_059_PR_VS1_J  = df_050_059_PR_VS1_J.assign(Shape=None)
                    df_050_059_PR_VS1_J  = df_050_059_PR_VS1_J.assign(Carat=None)
                    df_050_059_PR_VS1_J  = df_050_059_PR_VS1_J.assign(Color=None)
                    df_050_059_PR_VS1_J  = df_050_059_PR_VS1_J.assign(Clarity=None)
                    df_050_059_PR_VS1_J  = df_050_059_PR_VS1_J.assign(Cut=None)
                    df_050_059_PR_VS1_J  = df_050_059_PR_VS1_J.assign(Polish=None)
                    df_050_059_PR_VS1_J  = df_050_059_PR_VS1_J.assign(Symmetry=None)
                    df_050_059_PR_VS1_J  = df_050_059_PR_VS1_J.assign(Ratio=None)
                    df_050_059_PR_VS1_J  = df_050_059_PR_VS1_J.assign(PPC=None)
                    df_050_059_PR_VS1_J  = df_050_059_PR_VS1_J.assign(Total=None)
                    df_050_059_PR_VS1_J ['Wt Range'] = listwtrange
                    df_050_059_PR_VS1_J ['Company'] = listcom
                    df_050_059_PR_VS1_J ['Shape'] = listshap
                    df_050_059_PR_VS1_J ['Carat'] = listcar
                    df_050_059_PR_VS1_J ['Color'] = listcol
                    df_050_059_PR_VS1_J ['Clarity'] = listclar
                    df_050_059_PR_VS1_J ['Cut'] = listcut
                    df_050_059_PR_VS1_J ['Polish'] = listpol
                    df_050_059_PR_VS1_J ['Symmetry'] = listsym
                    df_050_059_PR_VS1_J ['Ratio'] = listrat
                    df_050_059_PR_VS1_J ['PPC'] = listdesc
                    df_050_059_PR_VS1_J ['Total'] = listtotal
                    df_050_059_PR_VS1_J['Carat'] = df_050_059_PR_VS1_J['Carat'].astype('float64')
                    df_050_059_PR_VS1_J['PPC'] = df_050_059_PR_VS1_J['PPC'].astype('float64')
                    df_050_059_PR_VS1_J['Total'] = df_050_059_PR_VS1_J['Total'].astype('float64')
                    df_050_059_PR_VS1_J['Total'] = df_050_059_PR_VS1_J['Carat'] * df_050_059_PR_VS1_J['PPC']


                elif i=="J"  and j == "VS2" and k == "PR":
                    df_050_059_PR_VS2_J = pd.DataFrame()
                    df_050_059_PR_VS2_J ['Wt Range'] = None
                    df_050_059_PR_VS2_J  = df_050_059_PR_VS2_J.assign(Company=None)
                    df_050_059_PR_VS2_J  = df_050_059_PR_VS2_J.assign(Shape=None)
                    df_050_059_PR_VS2_J  = df_050_059_PR_VS2_J.assign(Carat=None)
                    df_050_059_PR_VS2_J  = df_050_059_PR_VS2_J.assign(Color=None)
                    df_050_059_PR_VS2_J  = df_050_059_PR_VS2_J.assign(Clarity=None)
                    df_050_059_PR_VS2_J  = df_050_059_PR_VS2_J.assign(Cut=None)
                    df_050_059_PR_VS2_J  = df_050_059_PR_VS2_J.assign(Polish=None)
                    df_050_059_PR_VS2_J  = df_050_059_PR_VS2_J.assign(Symmetry=None)
                    df_050_059_PR_VS2_J  = df_050_059_PR_VS2_J.assign(Ratio=None)
                    df_050_059_PR_VS2_J  = df_050_059_PR_VS2_J.assign(PPC=None)
                    df_050_059_PR_VS2_J  = df_050_059_PR_VS2_J.assign(Total=None)
                    df_050_059_PR_VS2_J ['Wt Range'] = listwtrange
                    df_050_059_PR_VS2_J ['Company'] = listcom
                    df_050_059_PR_VS2_J ['Shape'] = listshap
                    df_050_059_PR_VS2_J ['Carat'] = listcar
                    df_050_059_PR_VS2_J ['Color'] = listcol
                    df_050_059_PR_VS2_J ['Clarity'] = listclar
                    df_050_059_PR_VS2_J ['Cut'] = listcut
                    df_050_059_PR_VS2_J ['Polish'] = listpol
                    df_050_059_PR_VS2_J ['Symmetry'] = listsym
                    df_050_059_PR_VS2_J ['Ratio'] = listrat
                    df_050_059_PR_VS2_J ['PPC'] = listdesc
                    df_050_059_PR_VS2_J ['Total'] = listtotal
                    df_050_059_PR_VS2_J['Carat'] = df_050_059_PR_VS2_J['Carat'].astype('float64')
                    df_050_059_PR_VS2_J['PPC'] = df_050_059_PR_VS2_J['PPC'].astype('float64')
                    df_050_059_PR_VS2_J['Total'] = df_050_059_PR_VS2_J['Total'].astype('float64')
                    df_050_059_PR_VS2_J['Total'] = df_050_059_PR_VS2_J['Carat'] * df_050_059_PR_VS2_J['PPC']


                elif i=="J"  and j == "SI1" and k == "PR":
                    df_050_059_PR_SI1_J = pd.DataFrame()
                    df_050_059_PR_SI1_J ['Wt Range'] = None
                    df_050_059_PR_SI1_J  = df_050_059_PR_SI1_J.assign(Company=None)
                    df_050_059_PR_SI1_J  = df_050_059_PR_SI1_J.assign(Shape=None)
                    df_050_059_PR_SI1_J  = df_050_059_PR_SI1_J.assign(Carat=None)
                    df_050_059_PR_SI1_J  = df_050_059_PR_SI1_J.assign(Color=None)
                    df_050_059_PR_SI1_J  = df_050_059_PR_SI1_J.assign(Clarity=None)
                    df_050_059_PR_SI1_J  = df_050_059_PR_SI1_J.assign(Cut=None)
                    df_050_059_PR_SI1_J  = df_050_059_PR_SI1_J.assign(Polish=None)
                    df_050_059_PR_SI1_J  = df_050_059_PR_SI1_J.assign(Symmetry=None)
                    df_050_059_PR_SI1_J  = df_050_059_PR_SI1_J.assign(Ratio=None)
                    df_050_059_PR_SI1_J  = df_050_059_PR_SI1_J.assign(PPC=None)
                    df_050_059_PR_SI1_J  = df_050_059_PR_SI1_J.assign(Total=None)
                    df_050_059_PR_SI1_J ['Wt Range'] = listwtrange
                    df_050_059_PR_SI1_J ['Company'] = listcom
                    df_050_059_PR_SI1_J ['Shape'] = listshap
                    df_050_059_PR_SI1_J ['Carat'] = listcar
                    df_050_059_PR_SI1_J ['Color'] = listcol
                    df_050_059_PR_SI1_J ['Clarity'] = listclar
                    df_050_059_PR_SI1_J ['Cut'] = listcut
                    df_050_059_PR_SI1_J ['Polish'] = listpol
                    df_050_059_PR_SI1_J ['Symmetry'] = listsym
                    df_050_059_PR_SI1_J ['Ratio'] = listrat
                    df_050_059_PR_SI1_J ['PPC'] = listdesc
                    df_050_059_PR_SI1_J ['Total'] = listtotal
                    df_050_059_PR_SI1_J['Carat'] = df_050_059_PR_SI1_J['Carat'].astype('float64')
                    df_050_059_PR_SI1_J['PPC'] = df_050_059_PR_SI1_J['PPC'].astype('float64')
                    df_050_059_PR_SI1_J['Total'] = df_050_059_PR_SI1_J['Total'].astype('float64')
                    df_050_059_PR_SI1_J['Total'] = df_050_059_PR_SI1_J['Carat'] * df_050_059_PR_SI1_J['PPC']


                elif i=="J"  and j == "SI2" and k == "PR":
                    df_050_059_PR_SI2_J = pd.DataFrame()
                    df_050_059_PR_SI2_J ['Wt Range'] = None
                    df_050_059_PR_SI2_J  = df_050_059_PR_SI2_J.assign(Company=None)
                    df_050_059_PR_SI2_J  = df_050_059_PR_SI2_J.assign(Shape=None)
                    df_050_059_PR_SI2_J  = df_050_059_PR_SI2_J.assign(Carat=None)
                    df_050_059_PR_SI2_J  = df_050_059_PR_SI2_J.assign(Color=None)
                    df_050_059_PR_SI2_J  = df_050_059_PR_SI2_J.assign(Clarity=None)
                    df_050_059_PR_SI2_J  = df_050_059_PR_SI2_J.assign(Cut=None)
                    df_050_059_PR_SI2_J  = df_050_059_PR_SI2_J.assign(Polish=None)
                    df_050_059_PR_SI2_J  = df_050_059_PR_SI2_J.assign(Symmetry=None)
                    df_050_059_PR_SI2_J  = df_050_059_PR_SI2_J.assign(Ratio=None)
                    df_050_059_PR_SI2_J  = df_050_059_PR_SI2_J.assign(PPC=None)
                    df_050_059_PR_SI2_J  = df_050_059_PR_SI2_J.assign(Total=None)
                    df_050_059_PR_SI2_J ['Wt Range'] = listwtrange
                    df_050_059_PR_SI2_J ['Company'] = listcom
                    df_050_059_PR_SI2_J ['Shape'] = listshap
                    df_050_059_PR_SI2_J ['Carat'] = listcar
                    df_050_059_PR_SI2_J ['Color'] = listcol
                    df_050_059_PR_SI2_J ['Clarity'] = listclar
                    df_050_059_PR_SI2_J ['Cut'] = listcut
                    df_050_059_PR_SI2_J ['Polish'] = listpol
                    df_050_059_PR_SI2_J ['Symmetry'] = listsym
                    df_050_059_PR_SI2_J ['Ratio'] = listrat
                    df_050_059_PR_SI2_J ['PPC'] = listdesc
                    df_050_059_PR_SI2_J ['Total'] = listtotal
                    df_050_059_PR_SI2_J['Carat'] = df_050_059_PR_SI2_J['Carat'].astype('float64')
                    df_050_059_PR_SI2_J['PPC'] = df_050_059_PR_SI2_J['PPC'].astype('float64')
                    df_050_059_PR_SI2_J['Total'] = df_050_059_PR_SI2_J['Total'].astype('float64')
                    df_050_059_PR_SI2_J['Total'] = df_050_059_PR_SI2_J['Carat'] * df_050_059_PR_SI2_J['PPC']


                elif i=="J"  and j == "I1" and k == "PR":
                    df_050_059_PR_I1_J = pd.DataFrame()
                    df_050_059_PR_I1_J ['Wt Range'] = None
                    df_050_059_PR_I1_J  = df_050_059_PR_I1_J.assign(Company=None)
                    df_050_059_PR_I1_J  = df_050_059_PR_I1_J.assign(Shape=None)
                    df_050_059_PR_I1_J  = df_050_059_PR_I1_J.assign(Carat=None)
                    df_050_059_PR_I1_J  = df_050_059_PR_I1_J.assign(Color=None)
                    df_050_059_PR_I1_J  = df_050_059_PR_I1_J.assign(Clarity=None)
                    df_050_059_PR_I1_J  = df_050_059_PR_I1_J.assign(Cut=None)
                    df_050_059_PR_I1_J  = df_050_059_PR_I1_J.assign(Polish=None)
                    df_050_059_PR_I1_J  = df_050_059_PR_I1_J.assign(Symmetry=None)
                    df_050_059_PR_I1_J  = df_050_059_PR_I1_J.assign(Ratio=None)
                    df_050_059_PR_I1_J  = df_050_059_PR_I1_J.assign(PPC=None)
                    df_050_059_PR_I1_J  = df_050_059_PR_I1_J.assign(Total=None)
                    df_050_059_PR_I1_J ['Wt Range'] = listwtrange
                    df_050_059_PR_I1_J ['Company'] = listcom
                    df_050_059_PR_I1_J ['Shape'] = listshap
                    df_050_059_PR_I1_J ['Carat'] = listcar
                    df_050_059_PR_I1_J ['Color'] = listcol
                    df_050_059_PR_I1_J ['Clarity'] = listclar
                    df_050_059_PR_I1_J ['Cut'] = listcut
                    df_050_059_PR_I1_J ['Polish'] = listpol
                    df_050_059_PR_I1_J ['Symmetry'] = listsym
                    df_050_059_PR_I1_J ['Ratio'] = listrat
                    df_050_059_PR_I1_J ['PPC'] = listdesc
                    df_050_059_PR_I1_J ['Total'] = listtotal
                    df_050_059_PR_I1_J['Carat'] = df_050_059_PR_I1_J['Carat'].astype('float64')
                    df_050_059_PR_I1_J['PPC'] = df_050_059_PR_I1_J['PPC'].astype('float64')
                    df_050_059_PR_I1_J['Total'] = df_050_059_PR_I1_J['Total'].astype('float64')
                    df_050_059_PR_I1_J['Total'] = df_050_059_PR_I1_J['Carat'] * df_050_059_PR_I1_J['PPC']


                elif i=="J"  and j == "I2" and k == "PR":
                    df_050_059_PR_I2_J = pd.DataFrame()
                    df_050_059_PR_I2_J ['Wt Range'] = None
                    df_050_059_PR_I2_J  = df_050_059_PR_I2_J.assign(Company=None)
                    df_050_059_PR_I2_J  = df_050_059_PR_I2_J.assign(Shape=None)
                    df_050_059_PR_I2_J  = df_050_059_PR_I2_J.assign(Carat=None)
                    df_050_059_PR_I2_J  = df_050_059_PR_I2_J.assign(Color=None)
                    df_050_059_PR_I2_J  = df_050_059_PR_I2_J.assign(Clarity=None)
                    df_050_059_PR_I2_J  = df_050_059_PR_I2_J.assign(Cut=None)
                    df_050_059_PR_I2_J  = df_050_059_PR_I2_J.assign(Polish=None)
                    df_050_059_PR_I2_J  = df_050_059_PR_I2_J.assign(Symmetry=None)
                    df_050_059_PR_I2_J  = df_050_059_PR_I2_J.assign(Ratio=None)
                    df_050_059_PR_I2_J  = df_050_059_PR_I2_J.assign(PPC=None)
                    df_050_059_PR_I2_J  = df_050_059_PR_I2_J.assign(Total=None)
                    df_050_059_PR_I2_J ['Wt Range'] = listwtrange
                    df_050_059_PR_I2_J ['Company'] = listcom
                    df_050_059_PR_I2_J ['Shape'] = listshap
                    df_050_059_PR_I2_J ['Carat'] = listcar
                    df_050_059_PR_I2_J ['Color'] = listcol
                    df_050_059_PR_I2_J ['Clarity'] = listclar
                    df_050_059_PR_I2_J ['Cut'] = listcut
                    df_050_059_PR_I2_J ['Polish'] = listpol
                    df_050_059_PR_I2_J ['Symmetry'] = listsym
                    df_050_059_PR_I2_J ['Ratio'] = listrat
                    df_050_059_PR_I2_J ['PPC'] = listdesc
                    df_050_059_PR_I2_J ['Total'] = listtotal
                    df_050_059_PR_I2_J['Carat'] = df_050_059_PR_I2_J['Carat'].astype('float64')
                    df_050_059_PR_I2_J['PPC'] = df_050_059_PR_I2_J['PPC'].astype('float64')
                    df_050_059_PR_I2_J['Total'] = df_050_059_PR_I2_J['Total'].astype('float64')
                    df_050_059_PR_I2_J['Total'] = df_050_059_PR_I2_J['Carat'] * df_050_059_PR_I2_J['PPC']


                elif i=="K" and j == "IF" and k == "PR":
                    df_050_059_PR_IF_K = pd.DataFrame()
                    df_050_059_PR_IF_K ['Wt Range'] = None
                    df_050_059_PR_IF_K  = df_050_059_PR_IF_K.assign(Company=None)
                    df_050_059_PR_IF_K  = df_050_059_PR_IF_K.assign(Shape=None)
                    df_050_059_PR_IF_K  = df_050_059_PR_IF_K.assign(Carat=None)
                    df_050_059_PR_IF_K  = df_050_059_PR_IF_K.assign(Color=None)
                    df_050_059_PR_IF_K  = df_050_059_PR_IF_K.assign(Clarity=None)
                    df_050_059_PR_IF_K  = df_050_059_PR_IF_K.assign(Cut=None)
                    df_050_059_PR_IF_K  = df_050_059_PR_IF_K.assign(Polish=None)
                    df_050_059_PR_IF_K  = df_050_059_PR_IF_K.assign(Symmetry=None)
                    df_050_059_PR_IF_K  = df_050_059_PR_IF_K.assign(Ratio=None)
                    df_050_059_PR_IF_K  = df_050_059_PR_IF_K.assign(PPC=None)
                    df_050_059_PR_IF_K  = df_050_059_PR_IF_K.assign(Total=None)
                    df_050_059_PR_IF_K ['Wt Range'] = listwtrange
                    df_050_059_PR_IF_K ['Company'] = listcom
                    df_050_059_PR_IF_K ['Shape'] = listshap
                    df_050_059_PR_IF_K ['Carat'] = listcar
                    df_050_059_PR_IF_K ['Color'] = listcol
                    df_050_059_PR_IF_K ['Clarity'] = listclar
                    df_050_059_PR_IF_K ['Cut'] = listcut
                    df_050_059_PR_IF_K ['Polish'] = listpol
                    df_050_059_PR_IF_K ['Symmetry'] = listsym
                    df_050_059_PR_IF_K ['Ratio'] = listrat
                    df_050_059_PR_IF_K ['PPC'] = listdesc
                    df_050_059_PR_IF_K ['Total'] = listtotal
                    df_050_059_PR_IF_K['Carat'] = df_050_059_PR_IF_K['Carat'].astype('float64')
                    df_050_059_PR_IF_K['PPC'] = df_050_059_PR_IF_K['PPC'].astype('float64')
                    df_050_059_PR_IF_K['Total'] = df_050_059_PR_IF_K['Total'].astype('float64')
                    df_050_059_PR_IF_K['Total'] = df_050_059_PR_IF_K['Carat'] * df_050_059_PR_IF_K['PPC']



                elif i=="K" and j == "VVS1" and k == "PR":
                    df_050_059_PR_VVS1_K = pd.DataFrame()
                    df_050_059_PR_VVS1_K ['Wt Range'] = None
                    df_050_059_PR_VVS1_K  = df_050_059_PR_VVS1_K.assign(Company=None)
                    df_050_059_PR_VVS1_K  = df_050_059_PR_VVS1_K.assign(Shape=None)
                    df_050_059_PR_VVS1_K  = df_050_059_PR_VVS1_K.assign(Carat=None)
                    df_050_059_PR_VVS1_K  = df_050_059_PR_VVS1_K.assign(Color=None)
                    df_050_059_PR_VVS1_K  = df_050_059_PR_VVS1_K.assign(Clarity=None)
                    df_050_059_PR_VVS1_K  = df_050_059_PR_VVS1_K.assign(Cut=None)
                    df_050_059_PR_VVS1_K  = df_050_059_PR_VVS1_K.assign(Polish=None)
                    df_050_059_PR_VVS1_K  = df_050_059_PR_VVS1_K.assign(Symmetry=None)
                    df_050_059_PR_VVS1_K  = df_050_059_PR_VVS1_K.assign(Ratio=None)
                    df_050_059_PR_VVS1_K  = df_050_059_PR_VVS1_K.assign(PPC=None)
                    df_050_059_PR_VVS1_K  = df_050_059_PR_VVS1_K.assign(Total=None)
                    df_050_059_PR_VVS1_K ['Wt Range'] = listwtrange
                    df_050_059_PR_VVS1_K ['Company'] = listcom
                    df_050_059_PR_VVS1_K ['Shape'] = listshap
                    df_050_059_PR_VVS1_K ['Carat'] = listcar
                    df_050_059_PR_VVS1_K ['Color'] = listcol
                    df_050_059_PR_VVS1_K ['Clarity'] = listclar
                    df_050_059_PR_VVS1_K ['Cut'] = listcut
                    df_050_059_PR_VVS1_K ['Polish'] = listpol
                    df_050_059_PR_VVS1_K ['Symmetry'] = listsym
                    df_050_059_PR_VVS1_K ['Ratio'] = listrat
                    df_050_059_PR_VVS1_K ['PPC'] = listdesc
                    df_050_059_PR_VVS1_K ['Total'] = listtotal
                    df_050_059_PR_VVS1_K['Carat'] = df_050_059_PR_VVS1_K['Carat'].astype('float64')
                    df_050_059_PR_VVS1_K['PPC'] = df_050_059_PR_VVS1_K['PPC'].astype('float64')
                    df_050_059_PR_VVS1_K['Total'] = df_050_059_PR_VVS1_K['Total'].astype('float64')
                    df_050_059_PR_VVS1_K['Total'] = df_050_059_PR_VVS1_K['Carat'] * df_050_059_PR_VVS1_K['PPC']


                elif i=="K" and j == "VVS2" and k == "PR":
                    df_050_059_PR_VVS2_K = pd.DataFrame()
                    df_050_059_PR_VVS2_K ['Wt Range'] = None
                    df_050_059_PR_VVS2_K  = df_050_059_PR_VVS2_K.assign(Company=None)
                    df_050_059_PR_VVS2_K  = df_050_059_PR_VVS2_K.assign(Shape=None)
                    df_050_059_PR_VVS2_K  = df_050_059_PR_VVS2_K.assign(Carat=None)
                    df_050_059_PR_VVS2_K  = df_050_059_PR_VVS2_K.assign(Color=None)
                    df_050_059_PR_VVS2_K  = df_050_059_PR_VVS2_K.assign(Clarity=None)
                    df_050_059_PR_VVS2_K  = df_050_059_PR_VVS2_K.assign(Cut=None)
                    df_050_059_PR_VVS2_K  = df_050_059_PR_VVS2_K.assign(Polish=None)
                    df_050_059_PR_VVS2_K  = df_050_059_PR_VVS2_K.assign(Symmetry=None)
                    df_050_059_PR_VVS2_K  = df_050_059_PR_VVS2_K.assign(Ratio=None)
                    df_050_059_PR_VVS2_K  = df_050_059_PR_VVS2_K.assign(PPC=None)
                    df_050_059_PR_VVS2_K  = df_050_059_PR_VVS2_K.assign(Total=None)
                    df_050_059_PR_VVS2_K ['Wt Range'] = listwtrange
                    df_050_059_PR_VVS2_K ['Company'] = listcom
                    df_050_059_PR_VVS2_K ['Shape'] = listshap
                    df_050_059_PR_VVS2_K ['Carat'] = listcar
                    df_050_059_PR_VVS2_K ['Color'] = listcol
                    df_050_059_PR_VVS2_K ['Clarity'] = listclar
                    df_050_059_PR_VVS2_K ['Cut'] = listcut
                    df_050_059_PR_VVS2_K ['Polish'] = listpol
                    df_050_059_PR_VVS2_K ['Symmetry'] = listsym
                    df_050_059_PR_VVS2_K ['Ratio'] = listrat
                    df_050_059_PR_VVS2_K ['PPC'] = listdesc
                    df_050_059_PR_VVS2_K ['Total'] = listtotal
                    df_050_059_PR_VVS2_K['Carat'] = df_050_059_PR_VVS2_K['Carat'].astype('float64')
                    df_050_059_PR_VVS2_K['PPC'] = df_050_059_PR_VVS2_K['PPC'].astype('float64')
                    df_050_059_PR_VVS2_K['Total'] = df_050_059_PR_VVS2_K['Total'].astype('float64')
                    df_050_059_PR_VVS2_K['Total'] = df_050_059_PR_VVS2_K['Carat'] * df_050_059_PR_VVS2_K['PPC']


                elif i=="K" and j=="VS1" and k == "PR":
                    df_050_059_PR_VS1_K = pd.DataFrame()
                    df_050_059_PR_VS1_K ['Wt Range'] = None
                    df_050_059_PR_VS1_K  = df_050_059_PR_VS1_K.assign(Company=None)
                    df_050_059_PR_VS1_K  = df_050_059_PR_VS1_K.assign(Shape=None)
                    df_050_059_PR_VS1_K  = df_050_059_PR_VS1_K.assign(Carat=None)
                    df_050_059_PR_VS1_K  = df_050_059_PR_VS1_K.assign(Color=None)
                    df_050_059_PR_VS1_K  = df_050_059_PR_VS1_K.assign(Clarity=None)
                    df_050_059_PR_VS1_K  = df_050_059_PR_VS1_K.assign(Cut=None)
                    df_050_059_PR_VS1_K  = df_050_059_PR_VS1_K.assign(Polish=None)
                    df_050_059_PR_VS1_K  = df_050_059_PR_VS1_K.assign(Symmetry=None)
                    df_050_059_PR_VS1_K  = df_050_059_PR_VS1_K.assign(Ratio=None)
                    df_050_059_PR_VS1_K  = df_050_059_PR_VS1_K.assign(PPC=None)
                    df_050_059_PR_VS1_K  = df_050_059_PR_VS1_K.assign(Total=None)
                    df_050_059_PR_VS1_K ['Wt Range'] = listwtrange
                    df_050_059_PR_VS1_K ['Company'] = listcom
                    df_050_059_PR_VS1_K ['Shape'] = listshap
                    df_050_059_PR_VS1_K ['Carat'] = listcar
                    df_050_059_PR_VS1_K ['Color'] = listcol
                    df_050_059_PR_VS1_K ['Clarity'] = listclar
                    df_050_059_PR_VS1_K ['Cut'] = listcut
                    df_050_059_PR_VS1_K ['Polish'] = listpol
                    df_050_059_PR_VS1_K ['Symmetry'] = listsym
                    df_050_059_PR_VS1_K ['Ratio'] = listrat
                    df_050_059_PR_VS1_K ['PPC'] = listdesc
                    df_050_059_PR_VS1_K ['Total'] = listtotal
                    df_050_059_PR_VS1_K['Carat'] = df_050_059_PR_VS1_K['Carat'].astype('float64')
                    df_050_059_PR_VS1_K['PPC'] = df_050_059_PR_VS1_K['PPC'].astype('float64')
                    df_050_059_PR_VS1_K['Total'] = df_050_059_PR_VS1_K['Total'].astype('float64')
                    df_050_059_PR_VS1_K['Total'] = df_050_059_PR_VS1_K['Carat'] * df_050_059_PR_VS1_K['PPC']


                elif i=="K" and j == "VS2" and k == "PR":
                    df_050_059_PR_VS2_K = pd.DataFrame()
                    df_050_059_PR_VS2_K ['Wt Range'] = None
                    df_050_059_PR_VS2_K  = df_050_059_PR_VS2_K.assign(Company=None)
                    df_050_059_PR_VS2_K  = df_050_059_PR_VS2_K.assign(Shape=None)
                    df_050_059_PR_VS2_K  = df_050_059_PR_VS2_K.assign(Carat=None)
                    df_050_059_PR_VS2_K  = df_050_059_PR_VS2_K.assign(Color=None)
                    df_050_059_PR_VS2_K  = df_050_059_PR_VS2_K.assign(Clarity=None)
                    df_050_059_PR_VS2_K  = df_050_059_PR_VS2_K.assign(Cut=None)
                    df_050_059_PR_VS2_K  = df_050_059_PR_VS2_K.assign(Polish=None)
                    df_050_059_PR_VS2_K  = df_050_059_PR_VS2_K.assign(Symmetry=None)
                    df_050_059_PR_VS2_K  = df_050_059_PR_VS2_K.assign(Ratio=None)
                    df_050_059_PR_VS2_K  = df_050_059_PR_VS2_K.assign(PPC=None)
                    df_050_059_PR_VS2_K  = df_050_059_PR_VS2_K.assign(Total=None)
                    df_050_059_PR_VS2_K ['Wt Range'] = listwtrange
                    df_050_059_PR_VS2_K ['Company'] = listcom
                    df_050_059_PR_VS2_K ['Shape'] = listshap
                    df_050_059_PR_VS2_K ['Carat'] = listcar
                    df_050_059_PR_VS2_K ['Color'] = listcol
                    df_050_059_PR_VS2_K ['Clarity'] = listclar
                    df_050_059_PR_VS2_K ['Cut'] = listcut
                    df_050_059_PR_VS2_K ['Polish'] = listpol
                    df_050_059_PR_VS2_K ['Symmetry'] = listsym
                    df_050_059_PR_VS2_K ['Ratio'] = listrat
                    df_050_059_PR_VS2_K ['PPC'] = listdesc
                    df_050_059_PR_VS2_K ['Total'] = listtotal
                    df_050_059_PR_VS2_K['Carat'] = df_050_059_PR_VS2_K['Carat'].astype('float64')
                    df_050_059_PR_VS2_K['PPC'] = df_050_059_PR_VS2_K['PPC'].astype('float64')
                    df_050_059_PR_VS2_K['Total'] = df_050_059_PR_VS2_K['Total'].astype('float64')
                    df_050_059_PR_VS2_K['Total'] = df_050_059_PR_VS2_K['Carat'] * df_050_059_PR_VS2_K['PPC']


                elif i=="K" and j == "SI1" and k == "PR":
                    df_050_059_PR_SI1_K = pd.DataFrame()
                    df_050_059_PR_SI1_K ['Wt Range'] = None
                    df_050_059_PR_SI1_K  = df_050_059_PR_SI1_K.assign(Company=None)
                    df_050_059_PR_SI1_K  = df_050_059_PR_SI1_K.assign(Shape=None)
                    df_050_059_PR_SI1_K  = df_050_059_PR_SI1_K.assign(Carat=None)
                    df_050_059_PR_SI1_K  = df_050_059_PR_SI1_K.assign(Color=None)
                    df_050_059_PR_SI1_K  = df_050_059_PR_SI1_K.assign(Clarity=None)
                    df_050_059_PR_SI1_K  = df_050_059_PR_SI1_K.assign(Cut=None)
                    df_050_059_PR_SI1_K  = df_050_059_PR_SI1_K.assign(Polish=None)
                    df_050_059_PR_SI1_K  = df_050_059_PR_SI1_K.assign(Symmetry=None)
                    df_050_059_PR_SI1_K  = df_050_059_PR_SI1_K.assign(Ratio=None)
                    df_050_059_PR_SI1_K  = df_050_059_PR_SI1_K.assign(PPC=None)
                    df_050_059_PR_SI1_K  = df_050_059_PR_SI1_K.assign(Total=None)
                    df_050_059_PR_SI1_K ['Wt Range'] = listwtrange
                    df_050_059_PR_SI1_K ['Company'] = listcom
                    df_050_059_PR_SI1_K ['Shape'] = listshap
                    df_050_059_PR_SI1_K ['Carat'] = listcar
                    df_050_059_PR_SI1_K ['Color'] = listcol
                    df_050_059_PR_SI1_K ['Clarity'] = listclar
                    df_050_059_PR_SI1_K ['Cut'] = listcut
                    df_050_059_PR_SI1_K ['Polish'] = listpol
                    df_050_059_PR_SI1_K ['Symmetry'] = listsym
                    df_050_059_PR_SI1_K ['Ratio'] = listrat
                    df_050_059_PR_SI1_K ['PPC'] = listdesc
                    df_050_059_PR_SI1_K ['Total'] = listtotal
                    df_050_059_PR_SI1_K['Carat'] = df_050_059_PR_SI1_K['Carat'].astype('float64')
                    df_050_059_PR_SI1_K['PPC'] = df_050_059_PR_SI1_K['PPC'].astype('float64')
                    df_050_059_PR_SI1_K['Total'] = df_050_059_PR_SI1_K['Total'].astype('float64')
                    df_050_059_PR_SI1_K['Total'] = df_050_059_PR_SI1_K['Carat'] * df_050_059_PR_SI1_K['PPC']


                elif i=="K" and j == "SI2" and k == "PR":
                    df_050_059_PR_SI2_K = pd.DataFrame()
                    df_050_059_PR_SI2_K ['Wt Range'] = None
                    df_050_059_PR_SI2_K  = df_050_059_PR_SI2_K.assign(Company=None)
                    df_050_059_PR_SI2_K  = df_050_059_PR_SI2_K.assign(Shape=None)
                    df_050_059_PR_SI2_K  = df_050_059_PR_SI2_K.assign(Carat=None)
                    df_050_059_PR_SI2_K  = df_050_059_PR_SI2_K.assign(Color=None)
                    df_050_059_PR_SI2_K  = df_050_059_PR_SI2_K.assign(Clarity=None)
                    df_050_059_PR_SI2_K  = df_050_059_PR_SI2_K.assign(Cut=None)
                    df_050_059_PR_SI2_K  = df_050_059_PR_SI2_K.assign(Polish=None)
                    df_050_059_PR_SI2_K  = df_050_059_PR_SI2_K.assign(Symmetry=None)
                    df_050_059_PR_SI2_K  = df_050_059_PR_SI2_K.assign(Ratio=None)
                    df_050_059_PR_SI2_K  = df_050_059_PR_SI2_K.assign(PPC=None)
                    df_050_059_PR_SI2_K  = df_050_059_PR_SI2_K.assign(Total=None)
                    df_050_059_PR_SI2_K ['Wt Range'] = listwtrange
                    df_050_059_PR_SI2_K ['Company'] = listcom
                    df_050_059_PR_SI2_K ['Shape'] = listshap
                    df_050_059_PR_SI2_K ['Carat'] = listcar
                    df_050_059_PR_SI2_K ['Color'] = listcol
                    df_050_059_PR_SI2_K ['Clarity'] = listclar
                    df_050_059_PR_SI2_K ['Cut'] = listcut
                    df_050_059_PR_SI2_K ['Polish'] = listpol
                    df_050_059_PR_SI2_K ['Symmetry'] = listsym
                    df_050_059_PR_SI2_K ['Ratio'] = listrat
                    df_050_059_PR_SI2_K ['PPC'] = listdesc
                    df_050_059_PR_SI2_K ['Total'] = listtotal
                    df_050_059_PR_SI2_K['Carat'] = df_050_059_PR_SI2_K['Carat'].astype('float64')
                    df_050_059_PR_SI2_K['PPC'] = df_050_059_PR_SI2_K['PPC'].astype('float64')
                    df_050_059_PR_SI2_K['Total'] = df_050_059_PR_SI2_K['Total'].astype('float64')
                    df_050_059_PR_SI2_K['Total'] = df_050_059_PR_SI2_K['Carat'] * df_050_059_PR_SI2_K['PPC']


                elif i=="K" and j == "I1" and k == "PR":
                    df_050_059_PR_I1_K = pd.DataFrame()
                    df_050_059_PR_I1_K ['Wt Range'] = None
                    df_050_059_PR_I1_K  = df_050_059_PR_I1_K.assign(Company=None)
                    df_050_059_PR_I1_K  = df_050_059_PR_I1_K.assign(Shape=None)
                    df_050_059_PR_I1_K  = df_050_059_PR_I1_K.assign(Carat=None)
                    df_050_059_PR_I1_K  = df_050_059_PR_I1_K.assign(Color=None)
                    df_050_059_PR_I1_K  = df_050_059_PR_I1_K.assign(Clarity=None)
                    df_050_059_PR_I1_K  = df_050_059_PR_I1_K.assign(Cut=None)
                    df_050_059_PR_I1_K  = df_050_059_PR_I1_K.assign(Polish=None)
                    df_050_059_PR_I1_K  = df_050_059_PR_I1_K.assign(Symmetry=None)
                    df_050_059_PR_I1_K  = df_050_059_PR_I1_K.assign(Ratio=None)
                    df_050_059_PR_I1_K  = df_050_059_PR_I1_K.assign(PPC=None)
                    df_050_059_PR_I1_K  = df_050_059_PR_I1_K.assign(Total=None)
                    df_050_059_PR_I1_K ['Wt Range'] = listwtrange
                    df_050_059_PR_I1_K ['Company'] = listcom
                    df_050_059_PR_I1_K ['Shape'] = listshap
                    df_050_059_PR_I1_K ['Carat'] = listcar
                    df_050_059_PR_I1_K ['Color'] = listcol
                    df_050_059_PR_I1_K ['Clarity'] = listclar
                    df_050_059_PR_I1_K ['Cut'] = listcut
                    df_050_059_PR_I1_K ['Polish'] = listpol
                    df_050_059_PR_I1_K ['Symmetry'] = listsym
                    df_050_059_PR_I1_K ['Ratio'] = listrat
                    df_050_059_PR_I1_K ['PPC'] = listdesc
                    df_050_059_PR_I1_K ['Total'] = listtotal
                    df_050_059_PR_I1_K['Carat'] = df_050_059_PR_I1_K['Carat'].astype('float64')
                    df_050_059_PR_I1_K['PPC'] = df_050_059_PR_I1_K['PPC'].astype('float64')
                    df_050_059_PR_I1_K['Total'] = df_050_059_PR_I1_K['Total'].astype('float64')
                    df_050_059_PR_I1_K['Total'] = df_050_059_PR_I1_K['Carat'] * df_050_059_PR_I1_K['PPC']


                elif i=="K" and j == "I2" and k == "PR":
                    df_050_059_PR_I2_K = pd.DataFrame()
                    df_050_059_PR_I2_K ['Wt Range'] = None
                    df_050_059_PR_I2_K  = df_050_059_PR_I2_K.assign(Company=None)
                    df_050_059_PR_I2_K  = df_050_059_PR_I2_K.assign(Shape=None)
                    df_050_059_PR_I2_K  = df_050_059_PR_I2_K.assign(Carat=None)
                    df_050_059_PR_I2_K  = df_050_059_PR_I2_K.assign(Color=None)
                    df_050_059_PR_I2_K  = df_050_059_PR_I2_K.assign(Clarity=None)
                    df_050_059_PR_I2_K  = df_050_059_PR_I2_K.assign(Cut=None)
                    df_050_059_PR_I2_K  = df_050_059_PR_I2_K.assign(Polish=None)
                    df_050_059_PR_I2_K  = df_050_059_PR_I2_K.assign(Symmetry=None)
                    df_050_059_PR_I2_K  = df_050_059_PR_I2_K.assign(Ratio=None)
                    df_050_059_PR_I2_K  = df_050_059_PR_I2_K.assign(PPC=None)
                    df_050_059_PR_I2_K  = df_050_059_PR_I2_K.assign(Total=None)
                    df_050_059_PR_I2_K ['Wt Range'] = listwtrange
                    df_050_059_PR_I2_K ['Company'] = listcom
                    df_050_059_PR_I2_K ['Shape'] = listshap
                    df_050_059_PR_I2_K ['Carat'] = listcar
                    df_050_059_PR_I2_K ['Color'] = listcol
                    df_050_059_PR_I2_K ['Clarity'] = listclar
                    df_050_059_PR_I2_K ['Cut'] = listcut
                    df_050_059_PR_I2_K ['Polish'] = listpol
                    df_050_059_PR_I2_K ['Symmetry'] = listsym
                    df_050_059_PR_I2_K ['Ratio'] = listrat
                    df_050_059_PR_I2_K ['PPC'] = listdesc
                    df_050_059_PR_I2_K ['Total'] = listtotal
                    df_050_059_PR_I2_K['Carat'] = df_050_059_PR_I2_K['Carat'].astype('float64')
                    df_050_059_PR_I2_K['PPC'] = df_050_059_PR_I2_K['PPC'].astype('float64')
                    df_050_059_PR_I2_K['Total'] = df_050_059_PR_I2_K['Total'].astype('float64')
                    df_050_059_PR_I2_K['Total'] = df_050_059_PR_I2_K['Carat'] * df_050_059_PR_I2_K['PPC']


                elif i=="L" and j == "IF" and k == "PR":
                    df_050_059_PR_IF_L = pd.DataFrame()
                    df_050_059_PR_IF_L ['Wt Range'] = None
                    df_050_059_PR_IF_L  = df_050_059_PR_IF_L.assign(Company=None)
                    df_050_059_PR_IF_L  = df_050_059_PR_IF_L.assign(Shape=None)
                    df_050_059_PR_IF_L  = df_050_059_PR_IF_L.assign(Carat=None)
                    df_050_059_PR_IF_L  = df_050_059_PR_IF_L.assign(Color=None)
                    df_050_059_PR_IF_L  = df_050_059_PR_IF_L.assign(Clarity=None)
                    df_050_059_PR_IF_L  = df_050_059_PR_IF_L.assign(Cut=None)
                    df_050_059_PR_IF_L  = df_050_059_PR_IF_L.assign(Polish=None)
                    df_050_059_PR_IF_L  = df_050_059_PR_IF_L.assign(Symmetry=None)
                    df_050_059_PR_IF_L  = df_050_059_PR_IF_L.assign(Ratio=None)
                    df_050_059_PR_IF_L  = df_050_059_PR_IF_L.assign(PPC=None)
                    df_050_059_PR_IF_L  = df_050_059_PR_IF_L.assign(Total=None)
                    df_050_059_PR_IF_L ['Wt Range'] = listwtrange
                    df_050_059_PR_IF_L ['Company'] = listcom
                    df_050_059_PR_IF_L ['Shape'] = listshap
                    df_050_059_PR_IF_L ['Carat'] = listcar
                    df_050_059_PR_IF_L ['Color'] = listcol
                    df_050_059_PR_IF_L ['Clarity'] = listclar
                    df_050_059_PR_IF_L ['Cut'] = listcut
                    df_050_059_PR_IF_L ['Polish'] = listpol
                    df_050_059_PR_IF_L ['Symmetry'] = listsym
                    df_050_059_PR_IF_L ['Ratio'] = listrat
                    df_050_059_PR_IF_L ['PPC'] = listdesc
                    df_050_059_PR_IF_L ['Total'] = listtotal
                    df_050_059_PR_IF_L['Carat'] = df_050_059_PR_IF_L['Carat'].astype('float64')
                    df_050_059_PR_IF_L['PPC'] = df_050_059_PR_IF_L['PPC'].astype('float64')
                    df_050_059_PR_IF_L['Total'] = df_050_059_PR_IF_L['Total'].astype('float64')
                    df_050_059_PR_IF_L['Total'] = df_050_059_PR_IF_L['Carat'] * df_050_059_PR_IF_L['PPC']


                elif i=="L" and j == "VVS1" and k == "PR":
                    df_050_059_PR_VVS1_L = pd.DataFrame()
                    df_050_059_PR_VVS1_L ['Wt Range'] = None
                    df_050_059_PR_VVS1_L  = df_050_059_PR_VVS1_L.assign(Company=None)
                    df_050_059_PR_VVS1_L  = df_050_059_PR_VVS1_L.assign(Shape=None)
                    df_050_059_PR_VVS1_L  = df_050_059_PR_VVS1_L.assign(Carat=None)
                    df_050_059_PR_VVS1_L  = df_050_059_PR_VVS1_L.assign(Color=None)
                    df_050_059_PR_VVS1_L  = df_050_059_PR_VVS1_L.assign(Clarity=None)
                    df_050_059_PR_VVS1_L  = df_050_059_PR_VVS1_L.assign(Cut=None)
                    df_050_059_PR_VVS1_L  = df_050_059_PR_VVS1_L.assign(Polish=None)
                    df_050_059_PR_VVS1_L  = df_050_059_PR_VVS1_L.assign(Symmetry=None)
                    df_050_059_PR_VVS1_L  = df_050_059_PR_VVS1_L.assign(Ratio=None)
                    df_050_059_PR_VVS1_L  = df_050_059_PR_VVS1_L.assign(PPC=None)
                    df_050_059_PR_VVS1_L  = df_050_059_PR_VVS1_L.assign(Total=None)
                    df_050_059_PR_VVS1_L ['Wt Range'] = listwtrange
                    df_050_059_PR_VVS1_L ['Company'] = listcom
                    df_050_059_PR_VVS1_L ['Shape'] = listshap
                    df_050_059_PR_VVS1_L ['Carat'] = listcar
                    df_050_059_PR_VVS1_L ['Color'] = listcol
                    df_050_059_PR_VVS1_L ['Clarity'] = listclar
                    df_050_059_PR_VVS1_L ['Cut'] = listcut
                    df_050_059_PR_VVS1_L ['Polish'] = listpol
                    df_050_059_PR_VVS1_L ['Symmetry'] = listsym
                    df_050_059_PR_VVS1_L ['Ratio'] = listrat
                    df_050_059_PR_VVS1_L ['PPC'] = listdesc
                    df_050_059_PR_VVS1_L ['Total'] = listtotal
                    df_050_059_PR_VVS1_L['Carat'] = df_050_059_PR_VVS1_L['Carat'].astype('float64')
                    df_050_059_PR_VVS1_L['PPC'] = df_050_059_PR_VVS1_L['PPC'].astype('float64')
                    df_050_059_PR_VVS1_L['Total'] = df_050_059_PR_VVS1_L['Total'].astype('float64')
                    df_050_059_PR_VVS1_L['Total'] = df_050_059_PR_VVS1_L['Carat'] * df_050_059_PR_VVS1_L['PPC']


                elif i=="L" and j == "VVS2" and k == "PR":
                    df_050_059_PR_VVS2_L = pd.DataFrame()
                    df_050_059_PR_VVS2_L ['Wt Range'] = None
                    df_050_059_PR_VVS2_L  = df_050_059_PR_VVS2_L.assign(Company=None)
                    df_050_059_PR_VVS2_L  = df_050_059_PR_VVS2_L.assign(Shape=None)
                    df_050_059_PR_VVS2_L  = df_050_059_PR_VVS2_L.assign(Carat=None)
                    df_050_059_PR_VVS2_L  = df_050_059_PR_VVS2_L.assign(Color=None)
                    df_050_059_PR_VVS2_L  = df_050_059_PR_VVS2_L.assign(Clarity=None)
                    df_050_059_PR_VVS2_L  = df_050_059_PR_VVS2_L.assign(Cut=None)
                    df_050_059_PR_VVS2_L  = df_050_059_PR_VVS2_L.assign(Polish=None)
                    df_050_059_PR_VVS2_L  = df_050_059_PR_VVS2_L.assign(Symmetry=None)
                    df_050_059_PR_VVS2_L  = df_050_059_PR_VVS2_L.assign(Ratio=None)
                    df_050_059_PR_VVS2_L  = df_050_059_PR_VVS2_L.assign(PPC=None)
                    df_050_059_PR_VVS2_L  = df_050_059_PR_VVS2_L.assign(Total=None)
                    df_050_059_PR_VVS2_L ['Wt Range'] = listwtrange
                    df_050_059_PR_VVS2_L ['Company'] = listcom
                    df_050_059_PR_VVS2_L ['Shape'] = listshap
                    df_050_059_PR_VVS2_L ['Carat'] = listcar
                    df_050_059_PR_VVS2_L ['Color'] = listcol
                    df_050_059_PR_VVS2_L ['Clarity'] = listclar
                    df_050_059_PR_VVS2_L ['Cut'] = listcut
                    df_050_059_PR_VVS2_L ['Polish'] = listpol
                    df_050_059_PR_VVS2_L ['Symmetry'] = listsym
                    df_050_059_PR_VVS2_L ['Ratio'] = listrat
                    df_050_059_PR_VVS2_L ['PPC'] = listdesc
                    df_050_059_PR_VVS2_L ['Total'] = listtotal
                    df_050_059_PR_VVS2_L['Carat'] = df_050_059_PR_VVS2_L['Carat'].astype('float64')
                    df_050_059_PR_VVS2_L['PPC'] = df_050_059_PR_VVS2_L['PPC'].astype('float64')
                    df_050_059_PR_VVS2_L['Total'] = df_050_059_PR_VVS2_L['Total'].astype('float64')
                    df_050_059_PR_VVS2_L['Total'] = df_050_059_PR_VVS2_L['Carat'] * df_050_059_PR_VVS2_L['PPC']


                elif i=="L" and j=="VS1" and k == "PR":
                    df_050_059_PR_VS1_L = pd.DataFrame()
                    df_050_059_PR_VS1_L ['Wt Range'] = None
                    df_050_059_PR_VS1_L  = df_050_059_PR_VS1_L.assign(Company=None)
                    df_050_059_PR_VS1_L  = df_050_059_PR_VS1_L.assign(Shape=None)
                    df_050_059_PR_VS1_L  = df_050_059_PR_VS1_L.assign(Carat=None)
                    df_050_059_PR_VS1_L  = df_050_059_PR_VS1_L.assign(Color=None)
                    df_050_059_PR_VS1_L  = df_050_059_PR_VS1_L.assign(Clarity=None)
                    df_050_059_PR_VS1_L  = df_050_059_PR_VS1_L.assign(Cut=None)
                    df_050_059_PR_VS1_L  = df_050_059_PR_VS1_L.assign(Polish=None)
                    df_050_059_PR_VS1_L  = df_050_059_PR_VS1_L.assign(Symmetry=None)
                    df_050_059_PR_VS1_L  = df_050_059_PR_VS1_L.assign(Ratio=None)
                    df_050_059_PR_VS1_L  = df_050_059_PR_VS1_L.assign(PPC=None)
                    df_050_059_PR_VS1_L  = df_050_059_PR_VS1_L.assign(Total=None)
                    df_050_059_PR_VS1_L ['Wt Range'] = listwtrange
                    df_050_059_PR_VS1_L ['Company'] = listcom
                    df_050_059_PR_VS1_L ['Shape'] = listshap
                    df_050_059_PR_VS1_L ['Carat'] = listcar
                    df_050_059_PR_VS1_L ['Color'] = listcol
                    df_050_059_PR_VS1_L ['Clarity'] = listclar
                    df_050_059_PR_VS1_L ['Cut'] = listcut
                    df_050_059_PR_VS1_L ['Polish'] = listpol
                    df_050_059_PR_VS1_L ['Symmetry'] = listsym
                    df_050_059_PR_VS1_L ['Ratio'] = listrat
                    df_050_059_PR_VS1_L ['PPC'] = listdesc
                    df_050_059_PR_VS1_L ['Total'] = listtotal
                    df_050_059_PR_VS1_L['Carat'] = df_050_059_PR_VS1_L['Carat'].astype('float64')
                    df_050_059_PR_VS1_L['PPC'] = df_050_059_PR_VS1_L['PPC'].astype('float64')
                    df_050_059_PR_VS1_L['Total'] = df_050_059_PR_VS1_L['Total'].astype('float64')
                    df_050_059_PR_VS1_L['Total'] = df_050_059_PR_VS1_L['Carat'] * df_050_059_PR_VS1_L['PPC']


                elif i=="L" and j == "VS2" and k == "PR":
                    df_050_059_PR_VS2_L = pd.DataFrame()
                    df_050_059_PR_VS2_L ['Wt Range'] = None
                    df_050_059_PR_VS2_L  = df_050_059_PR_VS2_L.assign(Company=None)
                    df_050_059_PR_VS2_L  = df_050_059_PR_VS2_L.assign(Shape=None)
                    df_050_059_PR_VS2_L  = df_050_059_PR_VS2_L.assign(Carat=None)
                    df_050_059_PR_VS2_L  = df_050_059_PR_VS2_L.assign(Color=None)
                    df_050_059_PR_VS2_L  = df_050_059_PR_VS2_L.assign(Clarity=None)
                    df_050_059_PR_VS2_L  = df_050_059_PR_VS2_L.assign(Cut=None)
                    df_050_059_PR_VS2_L  = df_050_059_PR_VS2_L.assign(Polish=None)
                    df_050_059_PR_VS2_L  = df_050_059_PR_VS2_L.assign(Symmetry=None)
                    df_050_059_PR_VS2_L  = df_050_059_PR_VS2_L.assign(Ratio=None)
                    df_050_059_PR_VS2_L  = df_050_059_PR_VS2_L.assign(PPC=None)
                    df_050_059_PR_VS2_L  = df_050_059_PR_VS2_L.assign(Total=None)
                    df_050_059_PR_VS2_L ['Wt Range'] = listwtrange
                    df_050_059_PR_VS2_L ['Company'] = listcom
                    df_050_059_PR_VS2_L ['Shape'] = listshap
                    df_050_059_PR_VS2_L ['Carat'] = listcar
                    df_050_059_PR_VS2_L ['Color'] = listcol
                    df_050_059_PR_VS2_L ['Clarity'] = listclar
                    df_050_059_PR_VS2_L ['Cut'] = listcut
                    df_050_059_PR_VS2_L ['Polish'] = listpol
                    df_050_059_PR_VS2_L ['Symmetry'] = listsym
                    df_050_059_PR_VS2_L ['Ratio'] = listrat
                    df_050_059_PR_VS2_L ['PPC'] = listdesc
                    df_050_059_PR_VS2_L ['Total'] = listtotal
                    df_050_059_PR_VS2_L['Carat'] = df_050_059_PR_VS2_L['Carat'].astype('float64')
                    df_050_059_PR_VS2_L['PPC'] = df_050_059_PR_VS2_L['PPC'].astype('float64')
                    df_050_059_PR_VS2_L['Total'] = df_050_059_PR_VS2_L['Total'].astype('float64')
                    df_050_059_PR_VS2_L['Total'] = df_050_059_PR_VS2_L['Carat'] * df_050_059_PR_VS2_L['PPC']


                elif i=="L" and j == "SI1" and k == "PR":
                    df_050_059_PR_SI1_L = pd.DataFrame()
                    df_050_059_PR_SI1_L ['Wt Range'] = None
                    df_050_059_PR_SI1_L  = df_050_059_PR_SI1_L.assign(Company=None)
                    df_050_059_PR_SI1_L  = df_050_059_PR_SI1_L.assign(Shape=None)
                    df_050_059_PR_SI1_L  = df_050_059_PR_SI1_L.assign(Carat=None)
                    df_050_059_PR_SI1_L  = df_050_059_PR_SI1_L.assign(Color=None)
                    df_050_059_PR_SI1_L  = df_050_059_PR_SI1_L.assign(Clarity=None)
                    df_050_059_PR_SI1_L  = df_050_059_PR_SI1_L.assign(Cut=None)
                    df_050_059_PR_SI1_L  = df_050_059_PR_SI1_L.assign(Polish=None)
                    df_050_059_PR_SI1_L  = df_050_059_PR_SI1_L.assign(Symmetry=None)
                    df_050_059_PR_SI1_L  = df_050_059_PR_SI1_L.assign(Ratio=None)
                    df_050_059_PR_SI1_L  = df_050_059_PR_SI1_L.assign(PPC=None)
                    df_050_059_PR_SI1_L  = df_050_059_PR_SI1_L.assign(Total=None)
                    df_050_059_PR_SI1_L ['Wt Range'] = listwtrange
                    df_050_059_PR_SI1_L ['Company'] = listcom
                    df_050_059_PR_SI1_L ['Shape'] = listshap
                    df_050_059_PR_SI1_L ['Carat'] = listcar
                    df_050_059_PR_SI1_L ['Color'] = listcol
                    df_050_059_PR_SI1_L ['Clarity'] = listclar
                    df_050_059_PR_SI1_L ['Cut'] = listcut
                    df_050_059_PR_SI1_L ['Polish'] = listpol
                    df_050_059_PR_SI1_L ['Symmetry'] = listsym
                    df_050_059_PR_SI1_L ['Ratio'] = listrat
                    df_050_059_PR_SI1_L ['PPC'] = listdesc
                    df_050_059_PR_SI1_L ['Total'] = listtotal
                    df_050_059_PR_SI1_L['Carat'] = df_050_059_PR_SI1_L['Carat'].astype('float64')
                    df_050_059_PR_SI1_L['PPC'] = df_050_059_PR_SI1_L['PPC'].astype('float64')
                    df_050_059_PR_SI1_L['Total'] = df_050_059_PR_SI1_L['Total'].astype('float64')
                    df_050_059_PR_SI1_L['Total'] = df_050_059_PR_SI1_L['Carat'] * df_050_059_PR_SI1_L['PPC']


                elif i=="L" and j == "SI2" and k == "PR":
                    df_050_059_PR_SI2_L = pd.DataFrame()
                    df_050_059_PR_SI2_L ['Wt Range'] = None
                    df_050_059_PR_SI2_L  = df_050_059_PR_SI2_L.assign(Company=None)
                    df_050_059_PR_SI2_L  = df_050_059_PR_SI2_L.assign(Shape=None)
                    df_050_059_PR_SI2_L  = df_050_059_PR_SI2_L.assign(Carat=None)
                    df_050_059_PR_SI2_L  = df_050_059_PR_SI2_L.assign(Color=None)
                    df_050_059_PR_SI2_L  = df_050_059_PR_SI2_L.assign(Clarity=None)
                    df_050_059_PR_SI2_L  = df_050_059_PR_SI2_L.assign(Cut=None)
                    df_050_059_PR_SI2_L  = df_050_059_PR_SI2_L.assign(Polish=None)
                    df_050_059_PR_SI2_L  = df_050_059_PR_SI2_L.assign(Symmetry=None)
                    df_050_059_PR_SI2_L  = df_050_059_PR_SI2_L.assign(Ratio=None)
                    df_050_059_PR_SI2_L  = df_050_059_PR_SI2_L.assign(PPC=None)
                    df_050_059_PR_SI2_L  = df_050_059_PR_SI2_L.assign(Total=None)
                    df_050_059_PR_SI2_L ['Wt Range'] = listwtrange
                    df_050_059_PR_SI2_L ['Company'] = listcom
                    df_050_059_PR_SI2_L ['Shape'] = listshap
                    df_050_059_PR_SI2_L ['Carat'] = listcar
                    df_050_059_PR_SI2_L ['Color'] = listcol
                    df_050_059_PR_SI2_L ['Clarity'] = listclar
                    df_050_059_PR_SI2_L ['Cut'] = listcut
                    df_050_059_PR_SI2_L ['Polish'] = listpol
                    df_050_059_PR_SI2_L ['Symmetry'] = listsym
                    df_050_059_PR_SI2_L ['Ratio'] = listrat
                    df_050_059_PR_SI2_L ['PPC'] = listdesc
                    df_050_059_PR_SI2_L ['Total'] = listtotal
                    df_050_059_PR_SI2_L['Carat'] = df_050_059_PR_SI2_L['Carat'].astype('float64')
                    df_050_059_PR_SI2_L['PPC'] = df_050_059_PR_SI2_L['PPC'].astype('float64')
                    df_050_059_PR_SI2_L['Total'] = df_050_059_PR_SI2_L['Total'].astype('float64')
                    df_050_059_PR_SI2_L['Total'] = df_050_059_PR_SI2_L['Carat'] * df_050_059_PR_SI2_L['PPC']


                elif i=="L" and j == "I1" and k == "PR":
                    df_050_059_PR_I1_L = pd.DataFrame()
                    df_050_059_PR_I1_L ['Wt Range'] = None
                    df_050_059_PR_I1_L  = df_050_059_PR_I1_L.assign(Company=None)
                    df_050_059_PR_I1_L  = df_050_059_PR_I1_L.assign(Shape=None)
                    df_050_059_PR_I1_L  = df_050_059_PR_I1_L.assign(Carat=None)
                    df_050_059_PR_I1_L  = df_050_059_PR_I1_L.assign(Color=None)
                    df_050_059_PR_I1_L  = df_050_059_PR_I1_L.assign(Clarity=None)
                    df_050_059_PR_I1_L  = df_050_059_PR_I1_L.assign(Cut=None)
                    df_050_059_PR_I1_L  = df_050_059_PR_I1_L.assign(Polish=None)
                    df_050_059_PR_I1_L  = df_050_059_PR_I1_L.assign(Symmetry=None)
                    df_050_059_PR_I1_L  = df_050_059_PR_I1_L.assign(Ratio=None)
                    df_050_059_PR_I1_L  = df_050_059_PR_I1_L.assign(PPC=None)
                    df_050_059_PR_I1_L  = df_050_059_PR_I1_L.assign(Total=None)
                    df_050_059_PR_I1_L ['Wt Range'] = listwtrange
                    df_050_059_PR_I1_L ['Company'] = listcom
                    df_050_059_PR_I1_L ['Shape'] = listshap
                    df_050_059_PR_I1_L ['Carat'] = listcar
                    df_050_059_PR_I1_L ['Color'] = listcol
                    df_050_059_PR_I1_L ['Clarity'] = listclar
                    df_050_059_PR_I1_L ['Cut'] = listcut
                    df_050_059_PR_I1_L ['Polish'] = listpol
                    df_050_059_PR_I1_L ['Symmetry'] = listsym
                    df_050_059_PR_I1_L ['Ratio'] = listrat
                    df_050_059_PR_I1_L ['PPC'] = listdesc
                    df_050_059_PR_I1_L ['Total'] = listtotal
                    df_050_059_PR_I1_L['Carat'] = df_050_059_PR_I1_L['Carat'].astype('float64')
                    df_050_059_PR_I1_L['PPC'] = df_050_059_PR_I1_L['PPC'].astype('float64')
                    df_050_059_PR_I1_L['Total'] = df_050_059_PR_I1_L['Total'].astype('float64')
                    df_050_059_PR_I1_L['Total'] = df_050_059_PR_I1_L['Carat'] * df_050_059_PR_I1_L['PPC']


                elif i=="L" and j == "I2" and k == "PR":
                    df_050_059_PR_I2_L = pd.DataFrame()
                    df_050_059_PR_I2_L ['Wt Range'] = None
                    df_050_059_PR_I2_L  = df_050_059_PR_I2_L.assign(Company=None)
                    df_050_059_PR_I2_L  = df_050_059_PR_I2_L.assign(Shape=None)
                    df_050_059_PR_I2_L  = df_050_059_PR_I2_L.assign(Carat=None)
                    df_050_059_PR_I2_L  = df_050_059_PR_I2_L.assign(Color=None)
                    df_050_059_PR_I2_L  = df_050_059_PR_I2_L.assign(Clarity=None)
                    df_050_059_PR_I2_L  = df_050_059_PR_I2_L.assign(Cut=None)
                    df_050_059_PR_I2_L  = df_050_059_PR_I2_L.assign(Polish=None)
                    df_050_059_PR_I2_L  = df_050_059_PR_I2_L.assign(Symmetry=None)
                    df_050_059_PR_I2_L  = df_050_059_PR_I2_L.assign(Ratio=None)
                    df_050_059_PR_I2_L  = df_050_059_PR_I2_L.assign(PPC=None)
                    df_050_059_PR_I2_L  = df_050_059_PR_I2_L.assign(Total=None)
                    df_050_059_PR_I2_L ['Wt Range'] = listwtrange
                    df_050_059_PR_I2_L ['Company'] = listcom
                    df_050_059_PR_I2_L ['Shape'] = listshap
                    df_050_059_PR_I2_L ['Carat'] = listcar
                    df_050_059_PR_I2_L ['Color'] = listcol
                    df_050_059_PR_I2_L ['Clarity'] = listclar
                    df_050_059_PR_I2_L ['Cut'] = listcut
                    df_050_059_PR_I2_L ['Polish'] = listpol
                    df_050_059_PR_I2_L ['Symmetry'] = listsym
                    df_050_059_PR_I2_L ['Ratio'] = listrat
                    df_050_059_PR_I2_L ['PPC'] = listdesc
                    df_050_059_PR_I2_L ['Total'] = listtotal
                    df_050_059_PR_I2_L['Carat'] = df_050_059_PR_I2_L['Carat'].astype('float64')
                    df_050_059_PR_I2_L['PPC'] = df_050_059_PR_I2_L['PPC'].astype('float64')
                    df_050_059_PR_I2_L['Total'] = df_050_059_PR_I2_L['Total'].astype('float64')
                    df_050_059_PR_I2_L['Total'] = df_050_059_PR_I2_L['Carat'] * df_050_059_PR_I2_L['PPC']


                elif i=="D" and j == "IF" and k == "PS":
                    df_050_059_PS_IF_D = pd.DataFrame()
                    df_050_059_PS_IF_D ['Wt Range'] = None
                    df_050_059_PS_IF_D  = df_050_059_PS_IF_D.assign(Company=None)
                    df_050_059_PS_IF_D  = df_050_059_PS_IF_D.assign(Shape=None)
                    df_050_059_PS_IF_D  = df_050_059_PS_IF_D.assign(Carat=None)
                    df_050_059_PS_IF_D  = df_050_059_PS_IF_D.assign(Color=None)
                    df_050_059_PS_IF_D  = df_050_059_PS_IF_D.assign(Clarity=None)
                    df_050_059_PS_IF_D  = df_050_059_PS_IF_D.assign(Cut=None)
                    df_050_059_PS_IF_D  = df_050_059_PS_IF_D.assign(Polish=None)
                    df_050_059_PS_IF_D  = df_050_059_PS_IF_D.assign(Symmetry=None)
                    df_050_059_PS_IF_D  = df_050_059_PS_IF_D.assign(Ratio=None)
                    df_050_059_PS_IF_D  = df_050_059_PS_IF_D.assign(PPC=None)
                    df_050_059_PS_IF_D  = df_050_059_PS_IF_D.assign(Total=None)
                    df_050_059_PS_IF_D ['Wt Range'] = listwtrange
                    df_050_059_PS_IF_D ['Company'] = listcom
                    df_050_059_PS_IF_D ['Shape'] = listshap
                    df_050_059_PS_IF_D ['Carat'] = listcar
                    df_050_059_PS_IF_D ['Color'] = listcol
                    df_050_059_PS_IF_D ['Clarity'] = listclar
                    df_050_059_PS_IF_D ['Cut'] = listcut
                    df_050_059_PS_IF_D ['Polish'] = listpol
                    df_050_059_PS_IF_D ['Symmetry'] = listsym
                    df_050_059_PS_IF_D ['Ratio'] = listrat
                    df_050_059_PS_IF_D ['PPC'] = listdesc
                    df_050_059_PS_IF_D ['Total'] = listtotal
                    df_050_059_PS_IF_D['Carat'] = df_050_059_PS_IF_D['Carat'].astype('float64')
                    df_050_059_PS_IF_D['PPC'] = df_050_059_PS_IF_D['PPC'].astype('float64')
                    df_050_059_PS_IF_D['Total'] = df_050_059_PS_IF_D['Total'].astype('float64')
                    df_050_059_PS_IF_D['Total'] = df_050_059_PS_IF_D['Carat'] * df_050_059_PS_IF_D['PPC']



                elif i=="D" and j == "VVS1" and k == "PS" :
                    df_050_059_PS_VVS1_D = pd.DataFrame()
                    df_050_059_PS_VVS1_D ['Wt Range'] = None
                    df_050_059_PS_VVS1_D  = df_050_059_PS_VVS1_D.assign(Company=None)
                    df_050_059_PS_VVS1_D  = df_050_059_PS_VVS1_D.assign(Shape=None)
                    df_050_059_PS_VVS1_D  = df_050_059_PS_VVS1_D.assign(Carat=None)
                    df_050_059_PS_VVS1_D  = df_050_059_PS_VVS1_D.assign(Color=None)
                    df_050_059_PS_VVS1_D  = df_050_059_PS_VVS1_D.assign(Clarity=None)
                    df_050_059_PS_VVS1_D  = df_050_059_PS_VVS1_D.assign(Cut=None)
                    df_050_059_PS_VVS1_D  = df_050_059_PS_VVS1_D.assign(Polish=None)
                    df_050_059_PS_VVS1_D  = df_050_059_PS_VVS1_D.assign(Symmetry=None)
                    df_050_059_PS_VVS1_D  = df_050_059_PS_VVS1_D.assign(Ratio=None)
                    df_050_059_PS_VVS1_D  = df_050_059_PS_VVS1_D.assign(PPC=None)
                    df_050_059_PS_VVS1_D  = df_050_059_PS_VVS1_D.assign(Total=None)
                    df_050_059_PS_VVS1_D ['Wt Range'] = listwtrange
                    df_050_059_PS_VVS1_D ['Company'] = listcom
                    df_050_059_PS_VVS1_D ['Shape'] = listshap
                    df_050_059_PS_VVS1_D ['Carat'] = listcar
                    df_050_059_PS_VVS1_D ['Color'] = listcol
                    df_050_059_PS_VVS1_D ['Clarity'] = listclar
                    df_050_059_PS_VVS1_D ['Cut'] = listcut
                    df_050_059_PS_VVS1_D ['Polish'] = listpol
                    df_050_059_PS_VVS1_D ['Symmetry'] = listsym
                    df_050_059_PS_VVS1_D ['Ratio'] = listrat
                    df_050_059_PS_VVS1_D ['PPC'] = listdesc
                    df_050_059_PS_VVS1_D ['Total'] = listtotal
                    df_050_059_PS_VVS1_D['Carat'] = df_050_059_PS_VVS1_D['Carat'].astype('float64')
                    df_050_059_PS_VVS1_D['PPC'] = df_050_059_PS_VVS1_D['PPC'].astype('float64')
                    df_050_059_PS_VVS1_D['Total'] = df_050_059_PS_VVS1_D['Total'].astype('float64')
                    df_050_059_PS_VVS1_D['Total'] = df_050_059_PS_VVS1_D['Carat'] * df_050_059_PS_VVS1_D['PPC']



                elif i=="D" and j == "VVS2" and k == "PS" :
                    df_050_059_PS_VVS2_D = pd.DataFrame()
                    df_050_059_PS_VVS2_D ['Wt Range'] = None
                    df_050_059_PS_VVS2_D  = df_050_059_PS_VVS2_D.assign(Company=None)
                    df_050_059_PS_VVS2_D  = df_050_059_PS_VVS2_D.assign(Shape=None)
                    df_050_059_PS_VVS2_D  = df_050_059_PS_VVS2_D.assign(Carat=None)
                    df_050_059_PS_VVS2_D  = df_050_059_PS_VVS2_D.assign(Color=None)
                    df_050_059_PS_VVS2_D  = df_050_059_PS_VVS2_D.assign(Clarity=None)
                    df_050_059_PS_VVS2_D  = df_050_059_PS_VVS2_D.assign(Cut=None)
                    df_050_059_PS_VVS2_D  = df_050_059_PS_VVS2_D.assign(Polish=None)
                    df_050_059_PS_VVS2_D  = df_050_059_PS_VVS2_D.assign(Symmetry=None)
                    df_050_059_PS_VVS2_D  = df_050_059_PS_VVS2_D.assign(Ratio=None)
                    df_050_059_PS_VVS2_D  = df_050_059_PS_VVS2_D.assign(PPC=None)
                    df_050_059_PS_VVS2_D  = df_050_059_PS_VVS2_D.assign(Total=None)
                    df_050_059_PS_VVS2_D ['Wt Range'] = listwtrange
                    df_050_059_PS_VVS2_D ['Company'] = listcom
                    df_050_059_PS_VVS2_D ['Shape'] = listshap
                    df_050_059_PS_VVS2_D ['Carat'] = listcar
                    df_050_059_PS_VVS2_D ['Color'] = listcol
                    df_050_059_PS_VVS2_D ['Clarity'] = listclar
                    df_050_059_PS_VVS2_D ['Cut'] = listcut
                    df_050_059_PS_VVS2_D ['Polish'] = listpol
                    df_050_059_PS_VVS2_D ['Symmetry'] = listsym
                    df_050_059_PS_VVS2_D ['Ratio'] = listrat
                    df_050_059_PS_VVS2_D ['PPC'] = listdesc
                    df_050_059_PS_VVS2_D ['Total'] = listtotal
                    df_050_059_PS_VVS2_D['Carat'] = df_050_059_PS_VVS2_D['Carat'].astype('float64')
                    df_050_059_PS_VVS2_D['PPC'] = df_050_059_PS_VVS2_D['PPC'].astype('float64')
                    df_050_059_PS_VVS2_D['Total'] = df_050_059_PS_VVS2_D['Total'].astype('float64')
                    df_050_059_PS_VVS2_D['Total'] = df_050_059_PS_VVS2_D['Carat'] * df_050_059_PS_VVS2_D['PPC']



                elif i=="D" and j == "VS1" and k == "PS":
                    df_050_059_PS_VS1_D = pd.DataFrame()
                    df_050_059_PS_VS1_D ['Wt Range'] = None
                    df_050_059_PS_VS1_D  = df_050_059_PS_VS1_D.assign(Company=None)
                    df_050_059_PS_VS1_D  = df_050_059_PS_VS1_D.assign(Shape=None)
                    df_050_059_PS_VS1_D  = df_050_059_PS_VS1_D.assign(Carat=None)
                    df_050_059_PS_VS1_D  = df_050_059_PS_VS1_D.assign(Color=None)
                    df_050_059_PS_VS1_D  = df_050_059_PS_VS1_D.assign(Clarity=None)
                    df_050_059_PS_VS1_D  = df_050_059_PS_VS1_D.assign(Cut=None)
                    df_050_059_PS_VS1_D  = df_050_059_PS_VS1_D.assign(Polish=None)
                    df_050_059_PS_VS1_D  = df_050_059_PS_VS1_D.assign(Symmetry=None)
                    df_050_059_PS_VS1_D  = df_050_059_PS_VS1_D.assign(Ratio=None)
                    df_050_059_PS_VS1_D  = df_050_059_PS_VS1_D.assign(PPC=None)
                    df_050_059_PS_VS1_D  = df_050_059_PS_VS1_D.assign(Total=None)
                    df_050_059_PS_VS1_D ['Wt Range'] = listwtrange
                    df_050_059_PS_VS1_D ['Company'] = listcom
                    df_050_059_PS_VS1_D ['Shape'] = listshap
                    df_050_059_PS_VS1_D ['Carat'] = listcar
                    df_050_059_PS_VS1_D ['Color'] = listcol
                    df_050_059_PS_VS1_D ['Clarity'] = listclar
                    df_050_059_PS_VS1_D ['Cut'] = listcut
                    df_050_059_PS_VS1_D ['Polish'] = listpol
                    df_050_059_PS_VS1_D ['Symmetry'] = listsym
                    df_050_059_PS_VS1_D ['Ratio'] = listrat
                    df_050_059_PS_VS1_D ['PPC'] = listdesc
                    df_050_059_PS_VS1_D ['Total'] = listtotal
                    df_050_059_PS_VS1_D['Carat'] = df_050_059_PS_VS1_D['Carat'].astype('float64')
                    df_050_059_PS_VS1_D['PPC'] = df_050_059_PS_VS1_D['PPC'].astype('float64')
                    df_050_059_PS_VS1_D['Total'] = df_050_059_PS_VS1_D['Total'].astype('float64')
                    df_050_059_PS_VS1_D['Total'] = df_050_059_PS_VS1_D['Carat'] * df_050_059_PS_VS1_D['PPC']


                elif i=="D" and j == "VS2" and k == "PS":
                    df_050_059_PS_VS2_D = pd.DataFrame()
                    df_050_059_PS_VS2_D ['Wt Range'] = None
                    df_050_059_PS_VS2_D  = df_050_059_PS_VS2_D.assign(Company=None)
                    df_050_059_PS_VS2_D  = df_050_059_PS_VS2_D.assign(Shape=None)
                    df_050_059_PS_VS2_D  = df_050_059_PS_VS2_D.assign(Carat=None)
                    df_050_059_PS_VS2_D  = df_050_059_PS_VS2_D.assign(Color=None)
                    df_050_059_PS_VS2_D  = df_050_059_PS_VS2_D.assign(Clarity=None)
                    df_050_059_PS_VS2_D  = df_050_059_PS_VS2_D.assign(Cut=None)
                    df_050_059_PS_VS2_D  = df_050_059_PS_VS2_D.assign(Polish=None)
                    df_050_059_PS_VS2_D  = df_050_059_PS_VS2_D.assign(Symmetry=None)
                    df_050_059_PS_VS2_D  = df_050_059_PS_VS2_D.assign(Ratio=None)
                    df_050_059_PS_VS2_D  = df_050_059_PS_VS2_D.assign(PPC=None)
                    df_050_059_PS_VS2_D  = df_050_059_PS_VS2_D.assign(Total=None)
                    df_050_059_PS_VS2_D ['Wt Range'] = listwtrange
                    df_050_059_PS_VS2_D ['Company'] = listcom
                    df_050_059_PS_VS2_D ['Shape'] = listshap
                    df_050_059_PS_VS2_D ['Carat'] = listcar
                    df_050_059_PS_VS2_D ['Color'] = listcol
                    df_050_059_PS_VS2_D ['Clarity'] = listclar
                    df_050_059_PS_VS2_D ['Cut'] = listcut
                    df_050_059_PS_VS2_D ['Polish'] = listpol
                    df_050_059_PS_VS2_D ['Symmetry'] = listsym
                    df_050_059_PS_VS2_D ['Ratio'] = listrat
                    df_050_059_PS_VS2_D ['PPC'] = listdesc
                    df_050_059_PS_VS2_D ['Total'] = listtotal
                    df_050_059_PS_VS2_D['Carat'] = df_050_059_PS_VS2_D['Carat'].astype('float64')
                    df_050_059_PS_VS2_D['PPC'] = df_050_059_PS_VS2_D['PPC'].astype('float64')
                    df_050_059_PS_VS2_D['Total'] = df_050_059_PS_VS2_D['Total'].astype('float64')
                    df_050_059_PS_VS2_D['Total'] = df_050_059_PS_VS2_D['Carat'] * df_050_059_PS_VS2_D['PPC']


                elif i=="D" and j == "SI1" and k == "PS":
                    df_050_059_PS_SI1_D = pd.DataFrame()
                    df_050_059_PS_SI1_D ['Wt Range'] = None
                    df_050_059_PS_SI1_D  = df_050_059_PS_SI1_D.assign(Company=None)
                    df_050_059_PS_SI1_D  = df_050_059_PS_SI1_D.assign(Shape=None)
                    df_050_059_PS_SI1_D  = df_050_059_PS_SI1_D.assign(Carat=None)
                    df_050_059_PS_SI1_D  = df_050_059_PS_SI1_D.assign(Color=None)
                    df_050_059_PS_SI1_D  = df_050_059_PS_SI1_D.assign(Clarity=None)
                    df_050_059_PS_SI1_D  = df_050_059_PS_SI1_D.assign(Cut=None)
                    df_050_059_PS_SI1_D  = df_050_059_PS_SI1_D.assign(Polish=None)
                    df_050_059_PS_SI1_D  = df_050_059_PS_SI1_D.assign(Symmetry=None)
                    df_050_059_PS_SI1_D  = df_050_059_PS_SI1_D.assign(Ratio=None)
                    df_050_059_PS_SI1_D  = df_050_059_PS_SI1_D.assign(PPC=None)
                    df_050_059_PS_SI1_D  = df_050_059_PS_SI1_D.assign(Total=None)
                    df_050_059_PS_SI1_D ['Wt Range'] = listwtrange
                    df_050_059_PS_SI1_D ['Company'] = listcom
                    df_050_059_PS_SI1_D ['Shape'] = listshap
                    df_050_059_PS_SI1_D ['Carat'] = listcar
                    df_050_059_PS_SI1_D ['Color'] = listcol
                    df_050_059_PS_SI1_D ['Clarity'] = listclar
                    df_050_059_PS_SI1_D ['Cut'] = listcut
                    df_050_059_PS_SI1_D ['Polish'] = listpol
                    df_050_059_PS_SI1_D ['Symmetry'] = listsym
                    df_050_059_PS_SI1_D ['Ratio'] = listrat
                    df_050_059_PS_SI1_D ['PPC'] = listdesc
                    df_050_059_PS_SI1_D ['Total'] = listtotal
                    df_050_059_PS_SI1_D['Carat'] = df_050_059_PS_SI1_D['Carat'].astype('float64')
                    df_050_059_PS_SI1_D['PPC'] = df_050_059_PS_SI1_D['PPC'].astype('float64')
                    df_050_059_PS_SI1_D['Total'] = df_050_059_PS_SI1_D['Total'].astype('float64')
                    df_050_059_PS_SI1_D['Total'] = df_050_059_PS_SI1_D['Carat'] * df_050_059_PS_SI1_D['PPC']


                elif i=="D" and j == "SI2" and k == "PS":
                    df_050_059_PS_SI2_D = pd.DataFrame()
                    df_050_059_PS_SI2_D ['Wt Range'] = None
                    df_050_059_PS_SI2_D  = df_050_059_PS_SI2_D.assign(Company=None)
                    df_050_059_PS_SI2_D  = df_050_059_PS_SI2_D.assign(Shape=None)
                    df_050_059_PS_SI2_D  = df_050_059_PS_SI2_D.assign(Carat=None)
                    df_050_059_PS_SI2_D  = df_050_059_PS_SI2_D.assign(Color=None)
                    df_050_059_PS_SI2_D  = df_050_059_PS_SI2_D.assign(Clarity=None)
                    df_050_059_PS_SI2_D  = df_050_059_PS_SI2_D.assign(Cut=None)
                    df_050_059_PS_SI2_D  = df_050_059_PS_SI2_D.assign(Polish=None)
                    df_050_059_PS_SI2_D  = df_050_059_PS_SI2_D.assign(Symmetry=None)
                    df_050_059_PS_SI2_D  = df_050_059_PS_SI2_D.assign(Ratio=None)
                    df_050_059_PS_SI2_D  = df_050_059_PS_SI2_D.assign(PPC=None)
                    df_050_059_PS_SI2_D  = df_050_059_PS_SI2_D.assign(Total=None)
                    df_050_059_PS_SI2_D ['Wt Range'] = listwtrange
                    df_050_059_PS_SI2_D ['Company'] = listcom
                    df_050_059_PS_SI2_D ['Shape'] = listshap
                    df_050_059_PS_SI2_D ['Carat'] = listcar
                    df_050_059_PS_SI2_D ['Color'] = listcol
                    df_050_059_PS_SI2_D ['Clarity'] = listclar
                    df_050_059_PS_SI2_D ['Cut'] = listcut
                    df_050_059_PS_SI2_D ['Polish'] = listpol
                    df_050_059_PS_SI2_D ['Symmetry'] = listsym
                    df_050_059_PS_SI2_D ['Ratio'] = listrat
                    df_050_059_PS_SI2_D ['PPC'] = listdesc
                    df_050_059_PS_SI2_D ['Total'] = listtotal
                    df_050_059_PS_SI2_D['Carat'] = df_050_059_PS_SI2_D['Carat'].astype('float64')
                    df_050_059_PS_SI2_D['PPC'] = df_050_059_PS_SI2_D['PPC'].astype('float64')
                    df_050_059_PS_SI2_D['Total'] = df_050_059_PS_SI2_D['Total'].astype('float64')
                    df_050_059_PS_SI2_D['Total'] = df_050_059_PS_SI2_D['Carat'] * df_050_059_PS_SI2_D['PPC']


                elif i=="D" and j == "I1" and k == "PS":
                    df_050_059_PS_I1_D = pd.DataFrame()
                    df_050_059_PS_I1_D ['Wt Range'] = None
                    df_050_059_PS_I1_D  = df_050_059_PS_I1_D.assign(Company=None)
                    df_050_059_PS_I1_D  = df_050_059_PS_I1_D.assign(Shape=None)
                    df_050_059_PS_I1_D  = df_050_059_PS_I1_D.assign(Carat=None)
                    df_050_059_PS_I1_D  = df_050_059_PS_I1_D.assign(Color=None)
                    df_050_059_PS_I1_D  = df_050_059_PS_I1_D.assign(Clarity=None)
                    df_050_059_PS_I1_D  = df_050_059_PS_I1_D.assign(Cut=None)
                    df_050_059_PS_I1_D  = df_050_059_PS_I1_D.assign(Polish=None)
                    df_050_059_PS_I1_D  = df_050_059_PS_I1_D.assign(Symmetry=None)
                    df_050_059_PS_I1_D  = df_050_059_PS_I1_D.assign(Ratio=None)
                    df_050_059_PS_I1_D  = df_050_059_PS_I1_D.assign(PPC=None)
                    df_050_059_PS_I1_D  = df_050_059_PS_I1_D.assign(Total=None)
                    df_050_059_PS_I1_D ['Wt Range'] = listwtrange
                    df_050_059_PS_I1_D ['Company'] = listcom
                    df_050_059_PS_I1_D ['Shape'] = listshap
                    df_050_059_PS_I1_D ['Carat'] = listcar
                    df_050_059_PS_I1_D ['Color'] = listcol
                    df_050_059_PS_I1_D ['Clarity'] = listclar
                    df_050_059_PS_I1_D ['Cut'] = listcut
                    df_050_059_PS_I1_D ['Polish'] = listpol
                    df_050_059_PS_I1_D ['Symmetry'] = listsym
                    df_050_059_PS_I1_D ['Ratio'] = listrat
                    df_050_059_PS_I1_D ['PPC'] = listdesc
                    df_050_059_PS_I1_D ['Total'] = listtotal
                    df_050_059_PS_I1_D['Carat'] = df_050_059_PS_I1_D['Carat'].astype('float64')
                    df_050_059_PS_I1_D['PPC'] = df_050_059_PS_I1_D['PPC'].astype('float64')
                    df_050_059_PS_I1_D['Total'] = df_050_059_PS_I1_D['Total'].astype('float64')
                    df_050_059_PS_I1_D['Total'] = df_050_059_PS_I1_D['Carat'] * df_050_059_PS_I1_D['PPC']


                elif i=="D" and j == "I2" and k == "PS":
                    df_050_059_PS_I2_D = pd.DataFrame()
                    df_050_059_PS_I2_D ['Wt Range'] = None
                    df_050_059_PS_I2_D  = df_050_059_PS_I2_D.assign(Company=None)
                    df_050_059_PS_I2_D  = df_050_059_PS_I2_D.assign(Shape=None)
                    df_050_059_PS_I2_D  = df_050_059_PS_I2_D.assign(Carat=None)
                    df_050_059_PS_I2_D  = df_050_059_PS_I2_D.assign(Color=None)
                    df_050_059_PS_I2_D  = df_050_059_PS_I2_D.assign(Clarity=None)
                    df_050_059_PS_I2_D  = df_050_059_PS_I2_D.assign(Cut=None)
                    df_050_059_PS_I2_D  = df_050_059_PS_I2_D.assign(Polish=None)
                    df_050_059_PS_I2_D  = df_050_059_PS_I2_D.assign(Symmetry=None)
                    df_050_059_PS_I2_D  = df_050_059_PS_I2_D.assign(Ratio=None)
                    df_050_059_PS_I2_D  = df_050_059_PS_I2_D.assign(PPC=None)
                    df_050_059_PS_I2_D  = df_050_059_PS_I2_D.assign(Total=None)
                    df_050_059_PS_I2_D ['Wt Range'] = listwtrange
                    df_050_059_PS_I2_D ['Company'] = listcom
                    df_050_059_PS_I2_D ['Shape'] = listshap
                    df_050_059_PS_I2_D ['Carat'] = listcar
                    df_050_059_PS_I2_D ['Color'] = listcol
                    df_050_059_PS_I2_D ['Clarity'] = listclar
                    df_050_059_PS_I2_D ['Cut'] = listcut
                    df_050_059_PS_I2_D ['Polish'] = listpol
                    df_050_059_PS_I2_D ['Symmetry'] = listsym
                    df_050_059_PS_I2_D ['Ratio'] = listrat
                    df_050_059_PS_I2_D ['PPC'] = listdesc
                    df_050_059_PS_I2_D ['Total'] = listtotal
                    df_050_059_PS_I2_D['Carat'] = df_050_059_PS_I2_D['Carat'].astype('float64')
                    df_050_059_PS_I2_D['PPC'] = df_050_059_PS_I2_D['PPC'].astype('float64')
                    df_050_059_PS_I2_D['Total'] = df_050_059_PS_I2_D['Total'].astype('float64')
                    df_050_059_PS_I2_D['Total'] = df_050_059_PS_I2_D['Carat'] * df_050_059_PS_I2_D['PPC']



                elif i=="E" and j == "IF" and k == "PS":
                    df_050_059_PS_IF_E = pd.DataFrame()
                    df_050_059_PS_IF_E ['Wt Range'] = None
                    df_050_059_PS_IF_E  = df_050_059_PS_IF_E.assign(Company=None)
                    df_050_059_PS_IF_E  = df_050_059_PS_IF_E.assign(Shape=None)
                    df_050_059_PS_IF_E  = df_050_059_PS_IF_E.assign(Carat=None)
                    df_050_059_PS_IF_E  = df_050_059_PS_IF_E.assign(Color=None)
                    df_050_059_PS_IF_E  = df_050_059_PS_IF_E.assign(Clarity=None)
                    df_050_059_PS_IF_E  = df_050_059_PS_IF_E.assign(Cut=None)
                    df_050_059_PS_IF_E  = df_050_059_PS_IF_E.assign(Polish=None)
                    df_050_059_PS_IF_E  = df_050_059_PS_IF_E.assign(Symmetry=None)
                    df_050_059_PS_IF_E  = df_050_059_PS_IF_E.assign(Ratio=None)
                    df_050_059_PS_IF_E  = df_050_059_PS_IF_E.assign(PPC=None)
                    df_050_059_PS_IF_E  = df_050_059_PS_IF_E.assign(Total=None)
                    df_050_059_PS_IF_E ['Wt Range'] = listwtrange
                    df_050_059_PS_IF_E ['Company'] = listcom
                    df_050_059_PS_IF_E ['Shape'] = listshap
                    df_050_059_PS_IF_E ['Carat'] = listcar
                    df_050_059_PS_IF_E ['Color'] = listcol
                    df_050_059_PS_IF_E ['Clarity'] = listclar
                    df_050_059_PS_IF_E ['Cut'] = listcut
                    df_050_059_PS_IF_E ['Polish'] = listpol
                    df_050_059_PS_IF_E ['Symmetry'] = listsym
                    df_050_059_PS_IF_E ['Ratio'] = listrat
                    df_050_059_PS_IF_E ['PPC'] = listdesc
                    df_050_059_PS_IF_E ['Total'] = listtotal
                    df_050_059_PS_IF_E['Carat'] = df_050_059_PS_IF_E['Carat'].astype('float64')
                    df_050_059_PS_IF_E['PPC'] = df_050_059_PS_IF_E['PPC'].astype('float64')
                    df_050_059_PS_IF_E['Total'] = df_050_059_PS_IF_E['Total'].astype('float64')
                    df_050_059_PS_IF_E['Total'] = df_050_059_PS_IF_E['Carat'] * df_050_059_PS_IF_E['PPC']



                elif i=="E" and j == "VVS1" and k == "PS":
                    df_050_059_PS_VVS1_E = pd.DataFrame()
                    df_050_059_PS_VVS1_E ['Wt Range'] = None
                    df_050_059_PS_VVS1_E  = df_050_059_PS_VVS1_E.assign(Company=None)
                    df_050_059_PS_VVS1_E  = df_050_059_PS_VVS1_E.assign(Shape=None)
                    df_050_059_PS_VVS1_E  = df_050_059_PS_VVS1_E.assign(Carat=None)
                    df_050_059_PS_VVS1_E  = df_050_059_PS_VVS1_E.assign(Color=None)
                    df_050_059_PS_VVS1_E  = df_050_059_PS_VVS1_E.assign(Clarity=None)
                    df_050_059_PS_VVS1_E  = df_050_059_PS_VVS1_E.assign(Cut=None)
                    df_050_059_PS_VVS1_E  = df_050_059_PS_VVS1_E.assign(Polish=None)
                    df_050_059_PS_VVS1_E  = df_050_059_PS_VVS1_E.assign(Symmetry=None)
                    df_050_059_PS_VVS1_E  = df_050_059_PS_VVS1_E.assign(Ratio=None)
                    df_050_059_PS_VVS1_E  = df_050_059_PS_VVS1_E.assign(PPC=None)
                    df_050_059_PS_VVS1_E  = df_050_059_PS_VVS1_E.assign(Total=None)
                    df_050_059_PS_VVS1_E ['Wt Range'] = listwtrange
                    df_050_059_PS_VVS1_E ['Company'] = listcom
                    df_050_059_PS_VVS1_E ['Shape'] = listshap
                    df_050_059_PS_VVS1_E ['Carat'] = listcar
                    df_050_059_PS_VVS1_E ['Color'] = listcol
                    df_050_059_PS_VVS1_E ['Clarity'] = listclar
                    df_050_059_PS_VVS1_E ['Cut'] = listcut
                    df_050_059_PS_VVS1_E ['Polish'] = listpol
                    df_050_059_PS_VVS1_E ['Symmetry'] = listsym
                    df_050_059_PS_VVS1_E ['Ratio'] = listrat
                    df_050_059_PS_VVS1_E ['PPC'] = listdesc
                    df_050_059_PS_VVS1_E ['Total'] = listtotal
                    df_050_059_PS_VVS1_E['Carat'] = df_050_059_PS_VVS1_E['Carat'].astype('float64')
                    df_050_059_PS_VVS1_E['PPC'] = df_050_059_PS_VVS1_E['PPC'].astype('float64')
                    df_050_059_PS_VVS1_E['Total'] = df_050_059_PS_VVS1_E['Total'].astype('float64')
                    df_050_059_PS_VVS1_E['Total'] = df_050_059_PS_VVS1_E['Carat'] * df_050_059_PS_VVS1_E['PPC']


                elif i=="E" and j == "VVS2" and k == "PS":
                    df_050_059_PS_VVS2_E = pd.DataFrame()
                    df_050_059_PS_VVS2_E ['Wt Range'] = None
                    df_050_059_PS_VVS2_E  = df_050_059_PS_VVS2_E.assign(Company=None)
                    df_050_059_PS_VVS2_E  = df_050_059_PS_VVS2_E.assign(Shape=None)
                    df_050_059_PS_VVS2_E  = df_050_059_PS_VVS2_E.assign(Carat=None)
                    df_050_059_PS_VVS2_E  = df_050_059_PS_VVS2_E.assign(Color=None)
                    df_050_059_PS_VVS2_E  = df_050_059_PS_VVS2_E.assign(Clarity=None)
                    df_050_059_PS_VVS2_E  = df_050_059_PS_VVS2_E.assign(Cut=None)
                    df_050_059_PS_VVS2_E  = df_050_059_PS_VVS2_E.assign(Polish=None)
                    df_050_059_PS_VVS2_E  = df_050_059_PS_VVS2_E.assign(Symmetry=None)
                    df_050_059_PS_VVS2_E  = df_050_059_PS_VVS2_E.assign(Ratio=None)
                    df_050_059_PS_VVS2_E  = df_050_059_PS_VVS2_E.assign(PPC=None)
                    df_050_059_PS_VVS2_E  = df_050_059_PS_VVS2_E.assign(Total=None)
                    df_050_059_PS_VVS2_E ['Wt Range'] = listwtrange
                    df_050_059_PS_VVS2_E ['Company'] = listcom
                    df_050_059_PS_VVS2_E ['Shape'] = listshap
                    df_050_059_PS_VVS2_E ['Carat'] = listcar
                    df_050_059_PS_VVS2_E ['Color'] = listcol
                    df_050_059_PS_VVS2_E ['Clarity'] = listclar
                    df_050_059_PS_VVS2_E ['Cut'] = listcut
                    df_050_059_PS_VVS2_E ['Polish'] = listpol
                    df_050_059_PS_VVS2_E ['Symmetry'] = listsym
                    df_050_059_PS_VVS2_E ['Ratio'] = listrat
                    df_050_059_PS_VVS2_E ['PPC'] = listdesc
                    df_050_059_PS_VVS2_E ['Total'] = listtotal
                    df_050_059_PS_VVS2_E['Carat'] = df_050_059_PS_VVS2_E['Carat'].astype('float64')
                    df_050_059_PS_VVS2_E['PPC'] = df_050_059_PS_VVS2_E['PPC'].astype('float64')
                    df_050_059_PS_VVS2_E['Total'] = df_050_059_PS_VVS2_E['Total'].astype('float64')
                    df_050_059_PS_VVS2_E['Total'] = df_050_059_PS_VVS2_E['Carat'] * df_050_059_PS_VVS2_E['PPC']


                elif i=="E" and j=="VS1" and k == "PS":
                    df_050_059_PS_VS1_E = pd.DataFrame()
                    df_050_059_PS_VS1_E ['Wt Range'] = None
                    df_050_059_PS_VS1_E  = df_050_059_PS_VS1_E.assign(Company=None)
                    df_050_059_PS_VS1_E  = df_050_059_PS_VS1_E.assign(Shape=None)
                    df_050_059_PS_VS1_E  = df_050_059_PS_VS1_E.assign(Carat=None)
                    df_050_059_PS_VS1_E  = df_050_059_PS_VS1_E.assign(Color=None)
                    df_050_059_PS_VS1_E  = df_050_059_PS_VS1_E.assign(Clarity=None)
                    df_050_059_PS_VS1_E  = df_050_059_PS_VS1_E.assign(Cut=None)
                    df_050_059_PS_VS1_E  = df_050_059_PS_VS1_E.assign(Polish=None)
                    df_050_059_PS_VS1_E  = df_050_059_PS_VS1_E.assign(Symmetry=None)
                    df_050_059_PS_VS1_E  = df_050_059_PS_VS1_E.assign(Ratio=None)
                    df_050_059_PS_VS1_E  = df_050_059_PS_VS1_E.assign(PPC=None)
                    df_050_059_PS_VS1_E  = df_050_059_PS_VS1_E.assign(Total=None)
                    df_050_059_PS_VS1_E ['Wt Range'] = listwtrange
                    df_050_059_PS_VS1_E ['Company'] = listcom
                    df_050_059_PS_VS1_E ['Shape'] = listshap
                    df_050_059_PS_VS1_E ['Carat'] = listcar
                    df_050_059_PS_VS1_E ['Color'] = listcol
                    df_050_059_PS_VS1_E ['Clarity'] = listclar
                    df_050_059_PS_VS1_E ['Cut'] = listcut
                    df_050_059_PS_VS1_E ['Polish'] = listpol
                    df_050_059_PS_VS1_E ['Symmetry'] = listsym
                    df_050_059_PS_VS1_E ['Ratio'] = listrat
                    df_050_059_PS_VS1_E ['PPC'] = listdesc
                    df_050_059_PS_VS1_E ['Total'] = listtotal
                    df_050_059_PS_VS1_E['Carat'] = df_050_059_PS_VS1_E['Carat'].astype('float64')
                    df_050_059_PS_VS1_E['PPC'] = df_050_059_PS_VS1_E['PPC'].astype('float64')
                    df_050_059_PS_VS1_E['Total'] = df_050_059_PS_VS1_E['Total'].astype('float64')
                    df_050_059_PS_VS1_E['Total'] = df_050_059_PS_VS1_E['Carat'] * df_050_059_PS_VS1_E['PPC']


                elif i=="E" and j == "VS2" and k == "PS":
                    df_050_059_PS_VS2_E = pd.DataFrame()
                    df_050_059_PS_VS2_E ['Wt Range'] = None
                    df_050_059_PS_VS2_E  = df_050_059_PS_VS2_E.assign(Company=None)
                    df_050_059_PS_VS2_E  = df_050_059_PS_VS2_E.assign(Shape=None)
                    df_050_059_PS_VS2_E  = df_050_059_PS_VS2_E.assign(Carat=None)
                    df_050_059_PS_VS2_E  = df_050_059_PS_VS2_E.assign(Color=None)
                    df_050_059_PS_VS2_E  = df_050_059_PS_VS2_E.assign(Clarity=None)
                    df_050_059_PS_VS2_E  = df_050_059_PS_VS2_E.assign(Cut=None)
                    df_050_059_PS_VS2_E  = df_050_059_PS_VS2_E.assign(Polish=None)
                    df_050_059_PS_VS2_E  = df_050_059_PS_VS2_E.assign(Symmetry=None)
                    df_050_059_PS_VS2_E  = df_050_059_PS_VS2_E.assign(Ratio=None)
                    df_050_059_PS_VS2_E  = df_050_059_PS_VS2_E.assign(PPC=None)
                    df_050_059_PS_VS2_E  = df_050_059_PS_VS2_E.assign(Total=None)
                    df_050_059_PS_VS2_E ['Wt Range'] = listwtrange
                    df_050_059_PS_VS2_E ['Company'] = listcom
                    df_050_059_PS_VS2_E ['Shape'] = listshap
                    df_050_059_PS_VS2_E ['Carat'] = listcar
                    df_050_059_PS_VS2_E ['Color'] = listcol
                    df_050_059_PS_VS2_E ['Clarity'] = listclar
                    df_050_059_PS_VS2_E ['Cut'] = listcut
                    df_050_059_PS_VS2_E ['Polish'] = listpol
                    df_050_059_PS_VS2_E ['Symmetry'] = listsym
                    df_050_059_PS_VS2_E ['Ratio'] = listrat
                    df_050_059_PS_VS2_E ['PPC'] = listdesc
                    df_050_059_PS_VS2_E ['Total'] = listtotal
                    df_050_059_PS_VS2_E['Carat'] = df_050_059_PS_VS2_E['Carat'].astype('float64')
                    df_050_059_PS_VS2_E['PPC'] = df_050_059_PS_VS2_E['PPC'].astype('float64')
                    df_050_059_PS_VS2_E['Total'] = df_050_059_PS_VS2_E['Total'].astype('float64')
                    df_050_059_PS_VS2_E['Total'] = df_050_059_PS_VS2_E['Carat'] * df_050_059_PS_VS2_E['PPC']


                elif i=="E" and j == "SI1" and k == "PS":
                    df_050_059_PS_SI1_E = pd.DataFrame()
                    df_050_059_PS_SI1_E ['Wt Range'] = None
                    df_050_059_PS_SI1_E  = df_050_059_PS_SI1_E.assign(Company=None)
                    df_050_059_PS_SI1_E  = df_050_059_PS_SI1_E.assign(Shape=None)
                    df_050_059_PS_SI1_E  = df_050_059_PS_SI1_E.assign(Carat=None)
                    df_050_059_PS_SI1_E  = df_050_059_PS_SI1_E.assign(Color=None)
                    df_050_059_PS_SI1_E  = df_050_059_PS_SI1_E.assign(Clarity=None)
                    df_050_059_PS_SI1_E  = df_050_059_PS_SI1_E.assign(Cut=None)
                    df_050_059_PS_SI1_E  = df_050_059_PS_SI1_E.assign(Polish=None)
                    df_050_059_PS_SI1_E  = df_050_059_PS_SI1_E.assign(Symmetry=None)
                    df_050_059_PS_SI1_E  = df_050_059_PS_SI1_E.assign(Ratio=None)
                    df_050_059_PS_SI1_E  = df_050_059_PS_SI1_E.assign(PPC=None)
                    df_050_059_PS_SI1_E  = df_050_059_PS_SI1_E.assign(Total=None)
                    df_050_059_PS_SI1_E ['Wt Range'] = listwtrange
                    df_050_059_PS_SI1_E ['Company'] = listcom
                    df_050_059_PS_SI1_E ['Shape'] = listshap
                    df_050_059_PS_SI1_E ['Carat'] = listcar
                    df_050_059_PS_SI1_E ['Color'] = listcol
                    df_050_059_PS_SI1_E ['Clarity'] = listclar
                    df_050_059_PS_SI1_E ['Cut'] = listcut
                    df_050_059_PS_SI1_E ['Polish'] = listpol
                    df_050_059_PS_SI1_E ['Symmetry'] = listsym
                    df_050_059_PS_SI1_E ['Ratio'] = listrat
                    df_050_059_PS_SI1_E ['PPC'] = listdesc
                    df_050_059_PS_SI1_E ['Total'] = listtotal
                    df_050_059_PS_SI1_E['Carat'] = df_050_059_PS_SI1_E['Carat'].astype('float64')
                    df_050_059_PS_SI1_E['PPC'] = df_050_059_PS_SI1_E['PPC'].astype('float64')
                    df_050_059_PS_SI1_E['Total'] = df_050_059_PS_SI1_E['Total'].astype('float64')
                    df_050_059_PS_SI1_E['Total'] = df_050_059_PS_SI1_E['Carat'] * df_050_059_PS_SI1_E['PPC']


                elif i=="E" and j == "SI2" and k == "PS":
                    df_050_059_PS_SI2_E = pd.DataFrame()
                    df_050_059_PS_SI2_E ['Wt Range'] = None
                    df_050_059_PS_SI2_E  = df_050_059_PS_SI2_E.assign(Company=None)
                    df_050_059_PS_SI2_E  = df_050_059_PS_SI2_E.assign(Shape=None)
                    df_050_059_PS_SI2_E  = df_050_059_PS_SI2_E.assign(Carat=None)
                    df_050_059_PS_SI2_E  = df_050_059_PS_SI2_E.assign(Color=None)
                    df_050_059_PS_SI2_E  = df_050_059_PS_SI2_E.assign(Clarity=None)
                    df_050_059_PS_SI2_E  = df_050_059_PS_SI2_E.assign(Cut=None)
                    df_050_059_PS_SI2_E  = df_050_059_PS_SI2_E.assign(Polish=None)
                    df_050_059_PS_SI2_E  = df_050_059_PS_SI2_E.assign(Symmetry=None)
                    df_050_059_PS_SI2_E  = df_050_059_PS_SI2_E.assign(Ratio=None)
                    df_050_059_PS_SI2_E  = df_050_059_PS_SI2_E.assign(PPC=None)
                    df_050_059_PS_SI2_E  = df_050_059_PS_SI2_E.assign(Total=None)
                    df_050_059_PS_SI2_E ['Wt Range'] = listwtrange
                    df_050_059_PS_SI2_E ['Company'] = listcom
                    df_050_059_PS_SI2_E ['Shape'] = listshap
                    df_050_059_PS_SI2_E ['Carat'] = listcar
                    df_050_059_PS_SI2_E ['Color'] = listcol
                    df_050_059_PS_SI2_E ['Clarity'] = listclar
                    df_050_059_PS_SI2_E ['Cut'] = listcut
                    df_050_059_PS_SI2_E ['Polish'] = listpol
                    df_050_059_PS_SI2_E ['Symmetry'] = listsym
                    df_050_059_PS_SI2_E ['Ratio'] = listrat
                    df_050_059_PS_SI2_E ['PPC'] = listdesc
                    df_050_059_PS_SI2_E ['Total'] = listtotal
                    df_050_059_PS_SI2_E['Carat'] = df_050_059_PS_SI2_E['Carat'].astype('float64')
                    df_050_059_PS_SI2_E['PPC'] = df_050_059_PS_SI2_E['PPC'].astype('float64')
                    df_050_059_PS_SI2_E['Total'] = df_050_059_PS_SI2_E['Total'].astype('float64')
                    df_050_059_PS_SI2_E['Total'] = df_050_059_PS_SI2_E['Carat'] * df_050_059_PS_SI2_E['PPC']


                elif i=="E" and j == "I1" and k == "PS":
                    df_050_059_PS_I1_E = pd.DataFrame()
                    df_050_059_PS_I1_E ['Wt Range'] = None
                    df_050_059_PS_I1_E  = df_050_059_PS_I1_E.assign(Company=None)
                    df_050_059_PS_I1_E  = df_050_059_PS_I1_E.assign(Shape=None)
                    df_050_059_PS_I1_E  = df_050_059_PS_I1_E.assign(Carat=None)
                    df_050_059_PS_I1_E  = df_050_059_PS_I1_E.assign(Color=None)
                    df_050_059_PS_I1_E  = df_050_059_PS_I1_E.assign(Clarity=None)
                    df_050_059_PS_I1_E  = df_050_059_PS_I1_E.assign(Cut=None)
                    df_050_059_PS_I1_E  = df_050_059_PS_I1_E.assign(Polish=None)
                    df_050_059_PS_I1_E  = df_050_059_PS_I1_E.assign(Symmetry=None)
                    df_050_059_PS_I1_E  = df_050_059_PS_I1_E.assign(Ratio=None)
                    df_050_059_PS_I1_E  = df_050_059_PS_I1_E.assign(PPC=None)
                    df_050_059_PS_I1_E  = df_050_059_PS_I1_E.assign(Total=None)
                    df_050_059_PS_I1_E ['Wt Range'] = listwtrange
                    df_050_059_PS_I1_E ['Company'] = listcom
                    df_050_059_PS_I1_E ['Shape'] = listshap
                    df_050_059_PS_I1_E ['Carat'] = listcar
                    df_050_059_PS_I1_E ['Color'] = listcol
                    df_050_059_PS_I1_E ['Clarity'] = listclar
                    df_050_059_PS_I1_E ['Cut'] = listcut
                    df_050_059_PS_I1_E ['Polish'] = listpol
                    df_050_059_PS_I1_E ['Symmetry'] = listsym
                    df_050_059_PS_I1_E ['Ratio'] = listrat
                    df_050_059_PS_I1_E ['PPC'] = listdesc
                    df_050_059_PS_I1_E ['Total'] = listtotal
                    df_050_059_PS_I1_E['Carat'] = df_050_059_PS_I1_E['Carat'].astype('float64')
                    df_050_059_PS_I1_E['PPC'] = df_050_059_PS_I1_E['PPC'].astype('float64')
                    df_050_059_PS_I1_E['Total'] = df_050_059_PS_I1_E['Total'].astype('float64')
                    df_050_059_PS_I1_E['Total'] = df_050_059_PS_I1_E['Carat'] * df_050_059_PS_I1_E['PPC']


                elif i=="E" and j == "I2" and k == "PS":
                    df_050_059_PS_I2_E = pd.DataFrame()
                    df_050_059_PS_I2_E ['Wt Range'] = None
                    df_050_059_PS_I2_E  = df_050_059_PS_I2_E.assign(Company=None)
                    df_050_059_PS_I2_E  = df_050_059_PS_I2_E.assign(Shape=None)
                    df_050_059_PS_I2_E  = df_050_059_PS_I2_E.assign(Carat=None)
                    df_050_059_PS_I2_E  = df_050_059_PS_I2_E.assign(Color=None)
                    df_050_059_PS_I2_E  = df_050_059_PS_I2_E.assign(Clarity=None)
                    df_050_059_PS_I2_E  = df_050_059_PS_I2_E.assign(Cut=None)
                    df_050_059_PS_I2_E  = df_050_059_PS_I2_E.assign(Polish=None)
                    df_050_059_PS_I2_E  = df_050_059_PS_I2_E.assign(Symmetry=None)
                    df_050_059_PS_I2_E  = df_050_059_PS_I2_E.assign(Ratio=None)
                    df_050_059_PS_I2_E  = df_050_059_PS_I2_E.assign(PPC=None)
                    df_050_059_PS_I2_E  = df_050_059_PS_I2_E.assign(Total=None)
                    df_050_059_PS_I2_E ['Wt Range'] = listwtrange
                    df_050_059_PS_I2_E ['Company'] = listcom
                    df_050_059_PS_I2_E ['Shape'] = listshap
                    df_050_059_PS_I2_E ['Carat'] = listcar
                    df_050_059_PS_I2_E ['Color'] = listcol
                    df_050_059_PS_I2_E ['Clarity'] = listclar
                    df_050_059_PS_I2_E ['Cut'] = listcut
                    df_050_059_PS_I2_E ['Polish'] = listpol
                    df_050_059_PS_I2_E ['Symmetry'] = listsym
                    df_050_059_PS_I2_E ['Ratio'] = listrat
                    df_050_059_PS_I2_E ['PPC'] = listdesc
                    df_050_059_PS_I2_E ['Total'] = listtotal
                    df_050_059_PS_I2_E['Carat'] = df_050_059_PS_I2_E['Carat'].astype('float64')
                    df_050_059_PS_I2_E['PPC'] = df_050_059_PS_I2_E['PPC'].astype('float64')
                    df_050_059_PS_I2_E['Total'] = df_050_059_PS_I2_E['Total'].astype('float64')
                    df_050_059_PS_I2_E['Total'] = df_050_059_PS_I2_E['Carat'] * df_050_059_PS_I2_E['PPC']
                
                elif i=="F" and j == "IF" and k == "PS":
                    df_050_059_PS_IF_F = pd.DataFrame()
                    df_050_059_PS_IF_F ['Wt Range'] = None
                    df_050_059_PS_IF_F  = df_050_059_PS_IF_F.assign(Company=None)
                    df_050_059_PS_IF_F  = df_050_059_PS_IF_F.assign(Shape=None)
                    df_050_059_PS_IF_F  = df_050_059_PS_IF_F.assign(Carat=None)
                    df_050_059_PS_IF_F  = df_050_059_PS_IF_F.assign(Color=None)
                    df_050_059_PS_IF_F  = df_050_059_PS_IF_F.assign(Clarity=None)
                    df_050_059_PS_IF_F  = df_050_059_PS_IF_F.assign(Cut=None)
                    df_050_059_PS_IF_F  = df_050_059_PS_IF_F.assign(Polish=None)
                    df_050_059_PS_IF_F  = df_050_059_PS_IF_F.assign(Symmetry=None)
                    df_050_059_PS_IF_F  = df_050_059_PS_IF_F.assign(Ratio=None)
                    df_050_059_PS_IF_F  = df_050_059_PS_IF_F.assign(PPC=None)
                    df_050_059_PS_IF_F  = df_050_059_PS_IF_F.assign(Total=None)
                    df_050_059_PS_IF_F ['Wt Range'] = listwtrange
                    df_050_059_PS_IF_F ['Company'] = listcom
                    df_050_059_PS_IF_F ['Shape'] = listshap
                    df_050_059_PS_IF_F ['Carat'] = listcar
                    df_050_059_PS_IF_F ['Color'] = listcol
                    df_050_059_PS_IF_F ['Clarity'] = listclar
                    df_050_059_PS_IF_F ['Cut'] = listcut
                    df_050_059_PS_IF_F ['Polish'] = listpol
                    df_050_059_PS_IF_F ['Symmetry'] = listsym
                    df_050_059_PS_IF_F ['Ratio'] = listrat
                    df_050_059_PS_IF_F ['PPC'] = listdesc
                    df_050_059_PS_IF_F ['Total'] = listtotal
                    df_050_059_PS_IF_F['Carat'] = df_050_059_PS_IF_F['Carat'].astype('float64')
                    df_050_059_PS_IF_F['PPC'] = df_050_059_PS_IF_F['PPC'].astype('float64')
                    df_050_059_PS_IF_F['Total'] = df_050_059_PS_IF_F['Total'].astype('float64')
                    df_050_059_PS_IF_F['Total'] = df_050_059_PS_IF_F['Carat'] * df_050_059_PS_IF_F['PPC']



                elif i=="F" and j == "VVS1" and k == "PS":
                    df_050_059_PS_VVS1_F = pd.DataFrame()
                    df_050_059_PS_VVS1_F ['Wt Range'] = None
                    df_050_059_PS_VVS1_F  = df_050_059_PS_VVS1_F.assign(Company=None)
                    df_050_059_PS_VVS1_F  = df_050_059_PS_VVS1_F.assign(Shape=None)
                    df_050_059_PS_VVS1_F  = df_050_059_PS_VVS1_F.assign(Carat=None)
                    df_050_059_PS_VVS1_F  = df_050_059_PS_VVS1_F.assign(Color=None)
                    df_050_059_PS_VVS1_F  = df_050_059_PS_VVS1_F.assign(Clarity=None)
                    df_050_059_PS_VVS1_F  = df_050_059_PS_VVS1_F.assign(Cut=None)
                    df_050_059_PS_VVS1_F  = df_050_059_PS_VVS1_F.assign(Polish=None)
                    df_050_059_PS_VVS1_F  = df_050_059_PS_VVS1_F.assign(Symmetry=None)
                    df_050_059_PS_VVS1_F  = df_050_059_PS_VVS1_F.assign(Ratio=None)
                    df_050_059_PS_VVS1_F  = df_050_059_PS_VVS1_F.assign(PPC=None)
                    df_050_059_PS_VVS1_F  = df_050_059_PS_VVS1_F.assign(Total=None)
                    df_050_059_PS_VVS1_F ['Wt Range'] = listwtrange
                    df_050_059_PS_VVS1_F ['Company'] = listcom
                    df_050_059_PS_VVS1_F ['Shape'] = listshap
                    df_050_059_PS_VVS1_F ['Carat'] = listcar
                    df_050_059_PS_VVS1_F ['Color'] = listcol
                    df_050_059_PS_VVS1_F ['Clarity'] = listclar
                    df_050_059_PS_VVS1_F ['Cut'] = listcut
                    df_050_059_PS_VVS1_F ['Polish'] = listpol
                    df_050_059_PS_VVS1_F ['Symmetry'] = listsym
                    df_050_059_PS_VVS1_F ['Ratio'] = listrat
                    df_050_059_PS_VVS1_F ['PPC'] = listdesc
                    df_050_059_PS_VVS1_F ['Total'] = listtotal
                    df_050_059_PS_VVS1_F['Carat'] = df_050_059_PS_VVS1_F['Carat'].astype('float64')
                    df_050_059_PS_VVS1_F['PPC'] = df_050_059_PS_VVS1_F['PPC'].astype('float64')
                    df_050_059_PS_VVS1_F['Total'] = df_050_059_PS_VVS1_F['Total'].astype('float64')
                    df_050_059_PS_VVS1_F['Total'] = df_050_059_PS_VVS1_F['Carat'] * df_050_059_PS_VVS1_F['PPC']


                elif i=="F" and j == "VVS2" and k == "PS":
                    df_050_059_PS_VVS2_F = pd.DataFrame()
                    df_050_059_PS_VVS2_F ['Wt Range'] = None
                    df_050_059_PS_VVS2_F  = df_050_059_PS_VVS2_F.assign(Company=None)
                    df_050_059_PS_VVS2_F  = df_050_059_PS_VVS2_F.assign(Shape=None)
                    df_050_059_PS_VVS2_F  = df_050_059_PS_VVS2_F.assign(Carat=None)
                    df_050_059_PS_VVS2_F  = df_050_059_PS_VVS2_F.assign(Color=None)
                    df_050_059_PS_VVS2_F  = df_050_059_PS_VVS2_F.assign(Clarity=None)
                    df_050_059_PS_VVS2_F  = df_050_059_PS_VVS2_F.assign(Cut=None)
                    df_050_059_PS_VVS2_F  = df_050_059_PS_VVS2_F.assign(Polish=None)
                    df_050_059_PS_VVS2_F  = df_050_059_PS_VVS2_F.assign(Symmetry=None)
                    df_050_059_PS_VVS2_F  = df_050_059_PS_VVS2_F.assign(Ratio=None)
                    df_050_059_PS_VVS2_F  = df_050_059_PS_VVS2_F.assign(PPC=None)
                    df_050_059_PS_VVS2_F  = df_050_059_PS_VVS2_F.assign(Total=None)
                    df_050_059_PS_VVS2_F ['Wt Range'] = listwtrange
                    df_050_059_PS_VVS2_F ['Company'] = listcom
                    df_050_059_PS_VVS2_F ['Shape'] = listshap
                    df_050_059_PS_VVS2_F ['Carat'] = listcar
                    df_050_059_PS_VVS2_F ['Color'] = listcol
                    df_050_059_PS_VVS2_F ['Clarity'] = listclar
                    df_050_059_PS_VVS2_F ['Cut'] = listcut
                    df_050_059_PS_VVS2_F ['Polish'] = listpol
                    df_050_059_PS_VVS2_F ['Symmetry'] = listsym
                    df_050_059_PS_VVS2_F ['Ratio'] = listrat
                    df_050_059_PS_VVS2_F ['PPC'] = listdesc
                    df_050_059_PS_VVS2_F ['Total'] = listtotal
                    df_050_059_PS_VVS2_F['Carat'] = df_050_059_PS_VVS2_F['Carat'].astype('float64')
                    df_050_059_PS_VVS2_F['PPC'] = df_050_059_PS_VVS2_F['PPC'].astype('float64')
                    df_050_059_PS_VVS2_F['Total'] = df_050_059_PS_VVS2_F['Total'].astype('float64')
                    df_050_059_PS_VVS2_F['Total'] = df_050_059_PS_VVS2_F['Carat'] * df_050_059_PS_VVS2_F['PPC']


                elif i=="F" and j=="VS1" and k == "PS":
                    df_050_059_PS_VS1_F = pd.DataFrame()
                    df_050_059_PS_VS1_F ['Wt Range'] = None
                    df_050_059_PS_VS1_F  = df_050_059_PS_VS1_F.assign(Company=None)
                    df_050_059_PS_VS1_F  = df_050_059_PS_VS1_F.assign(Shape=None)
                    df_050_059_PS_VS1_F  = df_050_059_PS_VS1_F.assign(Carat=None)
                    df_050_059_PS_VS1_F  = df_050_059_PS_VS1_F.assign(Color=None)
                    df_050_059_PS_VS1_F  = df_050_059_PS_VS1_F.assign(Clarity=None)
                    df_050_059_PS_VS1_F  = df_050_059_PS_VS1_F.assign(Cut=None)
                    df_050_059_PS_VS1_F  = df_050_059_PS_VS1_F.assign(Polish=None)
                    df_050_059_PS_VS1_F  = df_050_059_PS_VS1_F.assign(Symmetry=None)
                    df_050_059_PS_VS1_F  = df_050_059_PS_VS1_F.assign(Ratio=None)
                    df_050_059_PS_VS1_F  = df_050_059_PS_VS1_F.assign(PPC=None)
                    df_050_059_PS_VS1_F  = df_050_059_PS_VS1_F.assign(Total=None)
                    df_050_059_PS_VS1_F ['Wt Range'] = listwtrange
                    df_050_059_PS_VS1_F ['Company'] = listcom
                    df_050_059_PS_VS1_F ['Shape'] = listshap
                    df_050_059_PS_VS1_F ['Carat'] = listcar
                    df_050_059_PS_VS1_F ['Color'] = listcol
                    df_050_059_PS_VS1_F ['Clarity'] = listclar
                    df_050_059_PS_VS1_F ['Cut'] = listcut
                    df_050_059_PS_VS1_F ['Polish'] = listpol
                    df_050_059_PS_VS1_F ['Symmetry'] = listsym
                    df_050_059_PS_VS1_F ['Ratio'] = listrat
                    df_050_059_PS_VS1_F ['PPC'] = listdesc
                    df_050_059_PS_VS1_F ['Total'] = listtotal
                    df_050_059_PS_VS1_F['Carat'] = df_050_059_PS_VS1_F['Carat'].astype('float64')
                    df_050_059_PS_VS1_F['PPC'] = df_050_059_PS_VS1_F['PPC'].astype('float64')
                    df_050_059_PS_VS1_F['Total'] = df_050_059_PS_VS1_F['Total'].astype('float64')
                    df_050_059_PS_VS1_F['Total'] = df_050_059_PS_VS1_F['Carat'] * df_050_059_PS_VS1_F['PPC']


                elif i=="F" and j == "VS2" and k == "PS":
                    df_050_059_PS_VS2_F = pd.DataFrame()
                    df_050_059_PS_VS2_F ['Wt Range'] = None
                    df_050_059_PS_VS2_F  = df_050_059_PS_VS2_F.assign(Company=None)
                    df_050_059_PS_VS2_F  = df_050_059_PS_VS2_F.assign(Shape=None)
                    df_050_059_PS_VS2_F  = df_050_059_PS_VS2_F.assign(Carat=None)
                    df_050_059_PS_VS2_F  = df_050_059_PS_VS2_F.assign(Color=None)
                    df_050_059_PS_VS2_F  = df_050_059_PS_VS2_F.assign(Clarity=None)
                    df_050_059_PS_VS2_F  = df_050_059_PS_VS2_F.assign(Cut=None)
                    df_050_059_PS_VS2_F  = df_050_059_PS_VS2_F.assign(Polish=None)
                    df_050_059_PS_VS2_F  = df_050_059_PS_VS2_F.assign(Symmetry=None)
                    df_050_059_PS_VS2_F  = df_050_059_PS_VS2_F.assign(Ratio=None)
                    df_050_059_PS_VS2_F  = df_050_059_PS_VS2_F.assign(PPC=None)
                    df_050_059_PS_VS2_F  = df_050_059_PS_VS2_F.assign(Total=None)
                    df_050_059_PS_VS2_F ['Wt Range'] = listwtrange
                    df_050_059_PS_VS2_F ['Company'] = listcom
                    df_050_059_PS_VS2_F ['Shape'] = listshap
                    df_050_059_PS_VS2_F ['Carat'] = listcar
                    df_050_059_PS_VS2_F ['Color'] = listcol
                    df_050_059_PS_VS2_F ['Clarity'] = listclar
                    df_050_059_PS_VS2_F ['Cut'] = listcut
                    df_050_059_PS_VS2_F ['Polish'] = listpol
                    df_050_059_PS_VS2_F ['Symmetry'] = listsym
                    df_050_059_PS_VS2_F ['Ratio'] = listrat
                    df_050_059_PS_VS2_F ['PPC'] = listdesc
                    df_050_059_PS_VS2_F ['Total'] = listtotal
                    df_050_059_PS_VS2_F['Carat'] = df_050_059_PS_VS2_F['Carat'].astype('float64')
                    df_050_059_PS_VS2_F['PPC'] = df_050_059_PS_VS2_F['PPC'].astype('float64')
                    df_050_059_PS_VS2_F['Total'] = df_050_059_PS_VS2_F['Total'].astype('float64')
                    df_050_059_PS_VS2_F['Total'] = df_050_059_PS_VS2_F['Carat'] * df_050_059_PS_VS2_F['PPC']


                elif i=="F" and j == "SI1" and k == "PS":
                    df_050_059_PS_SI1_F = pd.DataFrame()
                    df_050_059_PS_SI1_F ['Wt Range'] = None
                    df_050_059_PS_SI1_F  = df_050_059_PS_SI1_F.assign(Company=None)
                    df_050_059_PS_SI1_F  = df_050_059_PS_SI1_F.assign(Shape=None)
                    df_050_059_PS_SI1_F  = df_050_059_PS_SI1_F.assign(Carat=None)
                    df_050_059_PS_SI1_F  = df_050_059_PS_SI1_F.assign(Color=None)
                    df_050_059_PS_SI1_F  = df_050_059_PS_SI1_F.assign(Clarity=None)
                    df_050_059_PS_SI1_F  = df_050_059_PS_SI1_F.assign(Cut=None)
                    df_050_059_PS_SI1_F  = df_050_059_PS_SI1_F.assign(Polish=None)
                    df_050_059_PS_SI1_F  = df_050_059_PS_SI1_F.assign(Symmetry=None)
                    df_050_059_PS_SI1_F  = df_050_059_PS_SI1_F.assign(Ratio=None)
                    df_050_059_PS_SI1_F  = df_050_059_PS_SI1_F.assign(PPC=None)
                    df_050_059_PS_SI1_F  = df_050_059_PS_SI1_F.assign(Total=None)
                    df_050_059_PS_SI1_F ['Wt Range'] = listwtrange
                    df_050_059_PS_SI1_F ['Company'] = listcom
                    df_050_059_PS_SI1_F ['Shape'] = listshap
                    df_050_059_PS_SI1_F ['Carat'] = listcar
                    df_050_059_PS_SI1_F ['Color'] = listcol
                    df_050_059_PS_SI1_F ['Clarity'] = listclar
                    df_050_059_PS_SI1_F ['Cut'] = listcut
                    df_050_059_PS_SI1_F ['Polish'] = listpol
                    df_050_059_PS_SI1_F ['Symmetry'] = listsym
                    df_050_059_PS_SI1_F ['Ratio'] = listrat
                    df_050_059_PS_SI1_F ['PPC'] = listdesc
                    df_050_059_PS_SI1_F ['Total'] = listtotal
                    df_050_059_PS_SI1_F['Carat'] = df_050_059_PS_SI1_F['Carat'].astype('float64')
                    df_050_059_PS_SI1_F['PPC'] = df_050_059_PS_SI1_F['PPC'].astype('float64')
                    df_050_059_PS_SI1_F['Total'] = df_050_059_PS_SI1_F['Total'].astype('float64')
                    df_050_059_PS_SI1_F['Total'] = df_050_059_PS_SI1_F['Carat'] * df_050_059_PS_SI1_F['PPC']


                elif i=="F" and j == "SI2" and k == "PS":
                    df_050_059_PS_SI2_F = pd.DataFrame()
                    df_050_059_PS_SI2_F ['Wt Range'] = None
                    df_050_059_PS_SI2_F  = df_050_059_PS_SI2_F.assign(Company=None)
                    df_050_059_PS_SI2_F  = df_050_059_PS_SI2_F.assign(Shape=None)
                    df_050_059_PS_SI2_F  = df_050_059_PS_SI2_F.assign(Carat=None)
                    df_050_059_PS_SI2_F  = df_050_059_PS_SI2_F.assign(Color=None)
                    df_050_059_PS_SI2_F  = df_050_059_PS_SI2_F.assign(Clarity=None)
                    df_050_059_PS_SI2_F  = df_050_059_PS_SI2_F.assign(Cut=None)
                    df_050_059_PS_SI2_F  = df_050_059_PS_SI2_F.assign(Polish=None)
                    df_050_059_PS_SI2_F  = df_050_059_PS_SI2_F.assign(Symmetry=None)
                    df_050_059_PS_SI2_F  = df_050_059_PS_SI2_F.assign(Ratio=None)
                    df_050_059_PS_SI2_F  = df_050_059_PS_SI2_F.assign(PPC=None)
                    df_050_059_PS_SI2_F  = df_050_059_PS_SI2_F.assign(Total=None)
                    df_050_059_PS_SI2_F ['Wt Range'] = listwtrange
                    df_050_059_PS_SI2_F ['Company'] = listcom
                    df_050_059_PS_SI2_F ['Shape'] = listshap
                    df_050_059_PS_SI2_F ['Carat'] = listcar
                    df_050_059_PS_SI2_F ['Color'] = listcol
                    df_050_059_PS_SI2_F ['Clarity'] = listclar
                    df_050_059_PS_SI2_F ['Cut'] = listcut
                    df_050_059_PS_SI2_F ['Polish'] = listpol
                    df_050_059_PS_SI2_F ['Symmetry'] = listsym
                    df_050_059_PS_SI2_F ['Ratio'] = listrat
                    df_050_059_PS_SI2_F ['PPC'] = listdesc
                    df_050_059_PS_SI2_F ['Total'] = listtotal
                    df_050_059_PS_SI2_F['Carat'] = df_050_059_PS_SI2_F['Carat'].astype('float64')
                    df_050_059_PS_SI2_F['PPC'] = df_050_059_PS_SI2_F['PPC'].astype('float64')
                    df_050_059_PS_SI2_F['Total'] = df_050_059_PS_SI2_F['Total'].astype('float64')
                    df_050_059_PS_SI2_F['Total'] = df_050_059_PS_SI2_F['Carat'] * df_050_059_PS_SI2_F['PPC']


                elif i=="F" and j == "I1" and k == "PS":
                    df_050_059_PS_I1_F = pd.DataFrame()
                    df_050_059_PS_I1_F ['Wt Range'] = None
                    df_050_059_PS_I1_F  = df_050_059_PS_I1_F.assign(Company=None)
                    df_050_059_PS_I1_F  = df_050_059_PS_I1_F.assign(Shape=None)
                    df_050_059_PS_I1_F  = df_050_059_PS_I1_F.assign(Carat=None)
                    df_050_059_PS_I1_F  = df_050_059_PS_I1_F.assign(Color=None)
                    df_050_059_PS_I1_F  = df_050_059_PS_I1_F.assign(Clarity=None)
                    df_050_059_PS_I1_F  = df_050_059_PS_I1_F.assign(Cut=None)
                    df_050_059_PS_I1_F  = df_050_059_PS_I1_F.assign(Polish=None)
                    df_050_059_PS_I1_F  = df_050_059_PS_I1_F.assign(Symmetry=None)
                    df_050_059_PS_I1_F  = df_050_059_PS_I1_F.assign(Ratio=None)
                    df_050_059_PS_I1_F  = df_050_059_PS_I1_F.assign(PPC=None)
                    df_050_059_PS_I1_F  = df_050_059_PS_I1_F.assign(Total=None)
                    df_050_059_PS_I1_F ['Wt Range'] = listwtrange
                    df_050_059_PS_I1_F ['Company'] = listcom
                    df_050_059_PS_I1_F ['Shape'] = listshap
                    df_050_059_PS_I1_F ['Carat'] = listcar
                    df_050_059_PS_I1_F ['Color'] = listcol
                    df_050_059_PS_I1_F ['Clarity'] = listclar
                    df_050_059_PS_I1_F ['Cut'] = listcut
                    df_050_059_PS_I1_F ['Polish'] = listpol
                    df_050_059_PS_I1_F ['Symmetry'] = listsym
                    df_050_059_PS_I1_F ['Ratio'] = listrat
                    df_050_059_PS_I1_F ['PPC'] = listdesc
                    df_050_059_PS_I1_F ['Total'] = listtotal
                    df_050_059_PS_I1_F['Carat'] = df_050_059_PS_I1_F['Carat'].astype('float64')
                    df_050_059_PS_I1_F['PPC'] = df_050_059_PS_I1_F['PPC'].astype('float64')
                    df_050_059_PS_I1_F['Total'] = df_050_059_PS_I1_F['Total'].astype('float64')
                    df_050_059_PS_I1_F['Total'] = df_050_059_PS_I1_F['Carat'] * df_050_059_PS_I1_F['PPC']


                elif i=="F" and j == "I2" and k == "PS":
                    df_050_059_PS_I2_F = pd.DataFrame()
                    df_050_059_PS_I2_F ['Wt Range'] = None
                    df_050_059_PS_I2_F  = df_050_059_PS_I2_F.assign(Company=None)
                    df_050_059_PS_I2_F  = df_050_059_PS_I2_F.assign(Shape=None)
                    df_050_059_PS_I2_F  = df_050_059_PS_I2_F.assign(Carat=None)
                    df_050_059_PS_I2_F  = df_050_059_PS_I2_F.assign(Color=None)
                    df_050_059_PS_I2_F  = df_050_059_PS_I2_F.assign(Clarity=None)
                    df_050_059_PS_I2_F  = df_050_059_PS_I2_F.assign(Cut=None)
                    df_050_059_PS_I2_F  = df_050_059_PS_I2_F.assign(Polish=None)
                    df_050_059_PS_I2_F  = df_050_059_PS_I2_F.assign(Symmetry=None)
                    df_050_059_PS_I2_F  = df_050_059_PS_I2_F.assign(Ratio=None)
                    df_050_059_PS_I2_F  = df_050_059_PS_I2_F.assign(PPC=None)
                    df_050_059_PS_I2_F  = df_050_059_PS_I2_F.assign(Total=None)
                    df_050_059_PS_I2_F ['Wt Range'] = listwtrange
                    df_050_059_PS_I2_F ['Company'] = listcom
                    df_050_059_PS_I2_F ['Shape'] = listshap
                    df_050_059_PS_I2_F ['Carat'] = listcar
                    df_050_059_PS_I2_F ['Color'] = listcol
                    df_050_059_PS_I2_F ['Clarity'] = listclar
                    df_050_059_PS_I2_F ['Cut'] = listcut
                    df_050_059_PS_I2_F ['Polish'] = listpol
                    df_050_059_PS_I2_F ['Symmetry'] = listsym
                    df_050_059_PS_I2_F ['Ratio'] = listrat
                    df_050_059_PS_I2_F ['PPC'] = listdesc
                    df_050_059_PS_I2_F ['Total'] = listtotal
                    df_050_059_PS_I2_F['Carat'] = df_050_059_PS_I2_F['Carat'].astype('float64')
                    df_050_059_PS_I2_F['PPC'] = df_050_059_PS_I2_F['PPC'].astype('float64')
                    df_050_059_PS_I2_F['Total'] = df_050_059_PS_I2_F['Total'].astype('float64')
                    df_050_059_PS_I2_F['Total'] = df_050_059_PS_I2_F['Carat'] * df_050_059_PS_I2_F['PPC']


                elif i=="G" and j == "IF" and k == "PS":
                    df_050_059_PS_IF_G = pd.DataFrame()
                    df_050_059_PS_IF_G ['Wt Range'] = None
                    df_050_059_PS_IF_G  = df_050_059_PS_IF_G.assign(Company=None)
                    df_050_059_PS_IF_G  = df_050_059_PS_IF_G.assign(Shape=None)
                    df_050_059_PS_IF_G  = df_050_059_PS_IF_G.assign(Carat=None)
                    df_050_059_PS_IF_G  = df_050_059_PS_IF_G.assign(Color=None)
                    df_050_059_PS_IF_G  = df_050_059_PS_IF_G.assign(Clarity=None)
                    df_050_059_PS_IF_G  = df_050_059_PS_IF_G.assign(Cut=None)
                    df_050_059_PS_IF_G  = df_050_059_PS_IF_G.assign(Polish=None)
                    df_050_059_PS_IF_G  = df_050_059_PS_IF_G.assign(Symmetry=None)
                    df_050_059_PS_IF_G  = df_050_059_PS_IF_G.assign(Ratio=None)
                    df_050_059_PS_IF_G  = df_050_059_PS_IF_G.assign(PPC=None)
                    df_050_059_PS_IF_G  = df_050_059_PS_IF_G.assign(Total=None)
                    df_050_059_PS_IF_G ['Wt Range'] = listwtrange
                    df_050_059_PS_IF_G ['Company'] = listcom
                    df_050_059_PS_IF_G ['Shape'] = listshap
                    df_050_059_PS_IF_G ['Carat'] = listcar
                    df_050_059_PS_IF_G ['Color'] = listcol
                    df_050_059_PS_IF_G ['Clarity'] = listclar
                    df_050_059_PS_IF_G ['Cut'] = listcut
                    df_050_059_PS_IF_G ['Polish'] = listpol
                    df_050_059_PS_IF_G ['Symmetry'] = listsym
                    df_050_059_PS_IF_G ['Ratio'] = listrat
                    df_050_059_PS_IF_G ['PPC'] = listdesc
                    df_050_059_PS_IF_G ['Total'] = listtotal
                    df_050_059_PS_IF_G['Carat'] = df_050_059_PS_IF_G['Carat'].astype('float64')
                    df_050_059_PS_IF_G['PPC'] = df_050_059_PS_IF_G['PPC'].astype('float64')
                    df_050_059_PS_IF_G['Total'] = df_050_059_PS_IF_G['Total'].astype('float64')
                    df_050_059_PS_IF_G['Total'] = df_050_059_PS_IF_G['Carat'] * df_050_059_PS_IF_G['PPC']



                elif i=="G" and j == "VVS1" and k == "PS":
                    df_050_059_PS_VVS1_G = pd.DataFrame()
                    df_050_059_PS_VVS1_G ['Wt Range'] = None
                    df_050_059_PS_VVS1_G  = df_050_059_PS_VVS1_G.assign(Company=None)
                    df_050_059_PS_VVS1_G  = df_050_059_PS_VVS1_G.assign(Shape=None)
                    df_050_059_PS_VVS1_G  = df_050_059_PS_VVS1_G.assign(Carat=None)
                    df_050_059_PS_VVS1_G  = df_050_059_PS_VVS1_G.assign(Color=None)
                    df_050_059_PS_VVS1_G  = df_050_059_PS_VVS1_G.assign(Clarity=None)
                    df_050_059_PS_VVS1_G  = df_050_059_PS_VVS1_G.assign(Cut=None)
                    df_050_059_PS_VVS1_G  = df_050_059_PS_VVS1_G.assign(Polish=None)
                    df_050_059_PS_VVS1_G  = df_050_059_PS_VVS1_G.assign(Symmetry=None)
                    df_050_059_PS_VVS1_G  = df_050_059_PS_VVS1_G.assign(Ratio=None)
                    df_050_059_PS_VVS1_G  = df_050_059_PS_VVS1_G.assign(PPC=None)
                    df_050_059_PS_VVS1_G  = df_050_059_PS_VVS1_G.assign(Total=None)
                    df_050_059_PS_VVS1_G ['Wt Range'] = listwtrange
                    df_050_059_PS_VVS1_G ['Company'] = listcom
                    df_050_059_PS_VVS1_G ['Shape'] = listshap
                    df_050_059_PS_VVS1_G ['Carat'] = listcar
                    df_050_059_PS_VVS1_G ['Color'] = listcol
                    df_050_059_PS_VVS1_G ['Clarity'] = listclar
                    df_050_059_PS_VVS1_G ['Cut'] = listcut
                    df_050_059_PS_VVS1_G ['Polish'] = listpol
                    df_050_059_PS_VVS1_G ['Symmetry'] = listsym
                    df_050_059_PS_VVS1_G ['Ratio'] = listrat
                    df_050_059_PS_VVS1_G ['PPC'] = listdesc
                    df_050_059_PS_VVS1_G ['Total'] = listtotal
                    df_050_059_PS_VVS1_G['Carat'] = df_050_059_PS_VVS1_G['Carat'].astype('float64')
                    df_050_059_PS_VVS1_G['PPC'] = df_050_059_PS_VVS1_G['PPC'].astype('float64')
                    df_050_059_PS_VVS1_G['Total'] = df_050_059_PS_VVS1_G['Total'].astype('float64')
                    df_050_059_PS_VVS1_G['Total'] = df_050_059_PS_VVS1_G['Carat'] * df_050_059_PS_VVS1_G['PPC']


                elif i=="G" and j == "VVS2" and k == "PS":
                    df_050_059_PS_VVS2_G = pd.DataFrame()
                    df_050_059_PS_VVS2_G ['Wt Range'] = None
                    df_050_059_PS_VVS2_G  = df_050_059_PS_VVS2_G.assign(Company=None)
                    df_050_059_PS_VVS2_G  = df_050_059_PS_VVS2_G.assign(Shape=None)
                    df_050_059_PS_VVS2_G  = df_050_059_PS_VVS2_G.assign(Carat=None)
                    df_050_059_PS_VVS2_G  = df_050_059_PS_VVS2_G.assign(Color=None)
                    df_050_059_PS_VVS2_G  = df_050_059_PS_VVS2_G.assign(Clarity=None)
                    df_050_059_PS_VVS2_G  = df_050_059_PS_VVS2_G.assign(Cut=None)
                    df_050_059_PS_VVS2_G  = df_050_059_PS_VVS2_G.assign(Polish=None)
                    df_050_059_PS_VVS2_G  = df_050_059_PS_VVS2_G.assign(Symmetry=None)
                    df_050_059_PS_VVS2_G  = df_050_059_PS_VVS2_G.assign(Ratio=None)
                    df_050_059_PS_VVS2_G  = df_050_059_PS_VVS2_G.assign(PPC=None)
                    df_050_059_PS_VVS2_G  = df_050_059_PS_VVS2_G.assign(Total=None)
                    df_050_059_PS_VVS2_G ['Wt Range'] = listwtrange
                    df_050_059_PS_VVS2_G ['Company'] = listcom
                    df_050_059_PS_VVS2_G ['Shape'] = listshap
                    df_050_059_PS_VVS2_G ['Carat'] = listcar
                    df_050_059_PS_VVS2_G ['Color'] = listcol
                    df_050_059_PS_VVS2_G ['Clarity'] = listclar
                    df_050_059_PS_VVS2_G ['Cut'] = listcut
                    df_050_059_PS_VVS2_G ['Polish'] = listpol
                    df_050_059_PS_VVS2_G ['Symmetry'] = listsym
                    df_050_059_PS_VVS2_G ['Ratio'] = listrat
                    df_050_059_PS_VVS2_G ['PPC'] = listdesc
                    df_050_059_PS_VVS2_G ['Total'] = listtotal
                    df_050_059_PS_VVS2_G['Carat'] = df_050_059_PS_VVS2_G['Carat'].astype('float64')
                    df_050_059_PS_VVS2_G['PPC'] = df_050_059_PS_VVS2_G['PPC'].astype('float64')
                    df_050_059_PS_VVS2_G['Total'] = df_050_059_PS_VVS2_G['Total'].astype('float64')
                    df_050_059_PS_VVS2_G['Total'] = df_050_059_PS_VVS2_G['Carat'] * df_050_059_PS_VVS2_G['PPC']


                elif i=="G" and j=="VS1" and k == "PS":
                    df_050_059_PS_VS1_G = pd.DataFrame()
                    df_050_059_PS_VS1_G ['Wt Range'] = None
                    df_050_059_PS_VS1_G  = df_050_059_PS_VS1_G.assign(Company=None)
                    df_050_059_PS_VS1_G  = df_050_059_PS_VS1_G.assign(Shape=None)
                    df_050_059_PS_VS1_G  = df_050_059_PS_VS1_G.assign(Carat=None)
                    df_050_059_PS_VS1_G  = df_050_059_PS_VS1_G.assign(Color=None)
                    df_050_059_PS_VS1_G  = df_050_059_PS_VS1_G.assign(Clarity=None)
                    df_050_059_PS_VS1_G  = df_050_059_PS_VS1_G.assign(Cut=None)
                    df_050_059_PS_VS1_G  = df_050_059_PS_VS1_G.assign(Polish=None)
                    df_050_059_PS_VS1_G  = df_050_059_PS_VS1_G.assign(Symmetry=None)
                    df_050_059_PS_VS1_G  = df_050_059_PS_VS1_G.assign(Ratio=None)
                    df_050_059_PS_VS1_G  = df_050_059_PS_VS1_G.assign(PPC=None)
                    df_050_059_PS_VS1_G  = df_050_059_PS_VS1_G.assign(Total=None)
                    df_050_059_PS_VS1_G ['Wt Range'] = listwtrange
                    df_050_059_PS_VS1_G ['Company'] = listcom
                    df_050_059_PS_VS1_G ['Shape'] = listshap
                    df_050_059_PS_VS1_G ['Carat'] = listcar
                    df_050_059_PS_VS1_G ['Color'] = listcol
                    df_050_059_PS_VS1_G ['Clarity'] = listclar
                    df_050_059_PS_VS1_G ['Cut'] = listcut
                    df_050_059_PS_VS1_G ['Polish'] = listpol
                    df_050_059_PS_VS1_G ['Symmetry'] = listsym
                    df_050_059_PS_VS1_G ['Ratio'] = listrat
                    df_050_059_PS_VS1_G ['PPC'] = listdesc
                    df_050_059_PS_VS1_G ['Total'] = listtotal
                    df_050_059_PS_VS1_G['Carat'] = df_050_059_PS_VS1_G['Carat'].astype('float64')
                    df_050_059_PS_VS1_G['PPC'] = df_050_059_PS_VS1_G['PPC'].astype('float64')
                    df_050_059_PS_VS1_G['Total'] = df_050_059_PS_VS1_G['Total'].astype('float64')
                    df_050_059_PS_VS1_G['Total'] = df_050_059_PS_VS1_G['Carat'] * df_050_059_PS_VS1_G['PPC']


                elif i=="G" and j == "VS2" and k == "PS":
                    df_050_059_PS_VS2_G = pd.DataFrame()
                    df_050_059_PS_VS2_G ['Wt Range'] = None
                    df_050_059_PS_VS2_G  = df_050_059_PS_VS2_G.assign(Company=None)
                    df_050_059_PS_VS2_G  = df_050_059_PS_VS2_G.assign(Shape=None)
                    df_050_059_PS_VS2_G  = df_050_059_PS_VS2_G.assign(Carat=None)
                    df_050_059_PS_VS2_G  = df_050_059_PS_VS2_G.assign(Color=None)
                    df_050_059_PS_VS2_G  = df_050_059_PS_VS2_G.assign(Clarity=None)
                    df_050_059_PS_VS2_G  = df_050_059_PS_VS2_G.assign(Cut=None)
                    df_050_059_PS_VS2_G  = df_050_059_PS_VS2_G.assign(Polish=None)
                    df_050_059_PS_VS2_G  = df_050_059_PS_VS2_G.assign(Symmetry=None)
                    df_050_059_PS_VS2_G  = df_050_059_PS_VS2_G.assign(Ratio=None)
                    df_050_059_PS_VS2_G  = df_050_059_PS_VS2_G.assign(PPC=None)
                    df_050_059_PS_VS2_G  = df_050_059_PS_VS2_G.assign(Total=None)
                    df_050_059_PS_VS2_G ['Wt Range'] = listwtrange
                    df_050_059_PS_VS2_G ['Company'] = listcom
                    df_050_059_PS_VS2_G ['Shape'] = listshap
                    df_050_059_PS_VS2_G ['Carat'] = listcar
                    df_050_059_PS_VS2_G ['Color'] = listcol
                    df_050_059_PS_VS2_G ['Clarity'] = listclar
                    df_050_059_PS_VS2_G ['Cut'] = listcut
                    df_050_059_PS_VS2_G ['Polish'] = listpol
                    df_050_059_PS_VS2_G ['Symmetry'] = listsym
                    df_050_059_PS_VS2_G ['Ratio'] = listrat
                    df_050_059_PS_VS2_G ['PPC'] = listdesc
                    df_050_059_PS_VS2_G ['Total'] = listtotal
                    df_050_059_PS_VS2_G['Carat'] = df_050_059_PS_VS2_G['Carat'].astype('float64')
                    df_050_059_PS_VS2_G['PPC'] = df_050_059_PS_VS2_G['PPC'].astype('float64')
                    df_050_059_PS_VS2_G['Total'] = df_050_059_PS_VS2_G['Total'].astype('float64')
                    df_050_059_PS_VS2_G['Total'] = df_050_059_PS_VS2_G['Carat'] * df_050_059_PS_VS2_G['PPC']


                elif i=="G" and j == "SI1" and k == "PS":
                    df_050_059_PS_SI1_G = pd.DataFrame()
                    df_050_059_PS_SI1_G ['Wt Range'] = None
                    df_050_059_PS_SI1_G  = df_050_059_PS_SI1_G.assign(Company=None)
                    df_050_059_PS_SI1_G  = df_050_059_PS_SI1_G.assign(Shape=None)
                    df_050_059_PS_SI1_G  = df_050_059_PS_SI1_G.assign(Carat=None)
                    df_050_059_PS_SI1_G  = df_050_059_PS_SI1_G.assign(Color=None)
                    df_050_059_PS_SI1_G  = df_050_059_PS_SI1_G.assign(Clarity=None)
                    df_050_059_PS_SI1_G  = df_050_059_PS_SI1_G.assign(Cut=None)
                    df_050_059_PS_SI1_G  = df_050_059_PS_SI1_G.assign(Polish=None)
                    df_050_059_PS_SI1_G  = df_050_059_PS_SI1_G.assign(Symmetry=None)
                    df_050_059_PS_SI1_G  = df_050_059_PS_SI1_G.assign(Ratio=None)
                    df_050_059_PS_SI1_G  = df_050_059_PS_SI1_G.assign(PPC=None)
                    df_050_059_PS_SI1_G  = df_050_059_PS_SI1_G.assign(Total=None)
                    df_050_059_PS_SI1_G ['Wt Range'] = listwtrange
                    df_050_059_PS_SI1_G ['Company'] = listcom
                    df_050_059_PS_SI1_G ['Shape'] = listshap
                    df_050_059_PS_SI1_G ['Carat'] = listcar
                    df_050_059_PS_SI1_G ['Color'] = listcol
                    df_050_059_PS_SI1_G ['Clarity'] = listclar
                    df_050_059_PS_SI1_G ['Cut'] = listcut
                    df_050_059_PS_SI1_G ['Polish'] = listpol
                    df_050_059_PS_SI1_G ['Symmetry'] = listsym
                    df_050_059_PS_SI1_G ['Ratio'] = listrat
                    df_050_059_PS_SI1_G ['PPC'] = listdesc
                    df_050_059_PS_SI1_G ['Total'] = listtotal
                    df_050_059_PS_SI1_G['Carat'] = df_050_059_PS_SI1_G['Carat'].astype('float64')
                    df_050_059_PS_SI1_G['PPC'] = df_050_059_PS_SI1_G['PPC'].astype('float64')
                    df_050_059_PS_SI1_G['Total'] = df_050_059_PS_SI1_G['Total'].astype('float64')
                    df_050_059_PS_SI1_G['Total'] = df_050_059_PS_SI1_G['Carat'] * df_050_059_PS_SI1_G['PPC']


                elif i=="G" and j == "SI2" and k == "PS":
                    df_050_059_PS_SI2_G = pd.DataFrame()
                    df_050_059_PS_SI2_G ['Wt Range'] = None
                    df_050_059_PS_SI2_G  = df_050_059_PS_SI2_G.assign(Company=None)
                    df_050_059_PS_SI2_G  = df_050_059_PS_SI2_G.assign(Shape=None)
                    df_050_059_PS_SI2_G  = df_050_059_PS_SI2_G.assign(Carat=None)
                    df_050_059_PS_SI2_G  = df_050_059_PS_SI2_G.assign(Color=None)
                    df_050_059_PS_SI2_G  = df_050_059_PS_SI2_G.assign(Clarity=None)
                    df_050_059_PS_SI2_G  = df_050_059_PS_SI2_G.assign(Cut=None)
                    df_050_059_PS_SI2_G  = df_050_059_PS_SI2_G.assign(Polish=None)
                    df_050_059_PS_SI2_G  = df_050_059_PS_SI2_G.assign(Symmetry=None)
                    df_050_059_PS_SI2_G  = df_050_059_PS_SI2_G.assign(Ratio=None)
                    df_050_059_PS_SI2_G  = df_050_059_PS_SI2_G.assign(PPC=None)
                    df_050_059_PS_SI2_G  = df_050_059_PS_SI2_G.assign(Total=None)
                    df_050_059_PS_SI2_G ['Wt Range'] = listwtrange
                    df_050_059_PS_SI2_G ['Company'] = listcom
                    df_050_059_PS_SI2_G ['Shape'] = listshap
                    df_050_059_PS_SI2_G ['Carat'] = listcar
                    df_050_059_PS_SI2_G ['Color'] = listcol
                    df_050_059_PS_SI2_G ['Clarity'] = listclar
                    df_050_059_PS_SI2_G ['Cut'] = listcut
                    df_050_059_PS_SI2_G ['Polish'] = listpol
                    df_050_059_PS_SI2_G ['Symmetry'] = listsym
                    df_050_059_PS_SI2_G ['Ratio'] = listrat
                    df_050_059_PS_SI2_G ['PPC'] = listdesc
                    df_050_059_PS_SI2_G ['Total'] = listtotal
                    df_050_059_PS_SI2_G['Carat'] = df_050_059_PS_SI2_G['Carat'].astype('float64')
                    df_050_059_PS_SI2_G['PPC'] = df_050_059_PS_SI2_G['PPC'].astype('float64')
                    df_050_059_PS_SI2_G['Total'] = df_050_059_PS_SI2_G['Total'].astype('float64')
                    df_050_059_PS_SI2_G['Total'] = df_050_059_PS_SI2_G['Carat'] * df_050_059_PS_SI2_G['PPC']


                elif i=="G" and j == "I1" and k == "PS":
                    df_050_059_PS_I1_G = pd.DataFrame()
                    df_050_059_PS_I1_G ['Wt Range'] = None
                    df_050_059_PS_I1_G  = df_050_059_PS_I1_G.assign(Company=None)
                    df_050_059_PS_I1_G  = df_050_059_PS_I1_G.assign(Shape=None)
                    df_050_059_PS_I1_G  = df_050_059_PS_I1_G.assign(Carat=None)
                    df_050_059_PS_I1_G  = df_050_059_PS_I1_G.assign(Color=None)
                    df_050_059_PS_I1_G  = df_050_059_PS_I1_G.assign(Clarity=None)
                    df_050_059_PS_I1_G  = df_050_059_PS_I1_G.assign(Cut=None)
                    df_050_059_PS_I1_G  = df_050_059_PS_I1_G.assign(Polish=None)
                    df_050_059_PS_I1_G  = df_050_059_PS_I1_G.assign(Symmetry=None)
                    df_050_059_PS_I1_G  = df_050_059_PS_I1_G.assign(Ratio=None)
                    df_050_059_PS_I1_G  = df_050_059_PS_I1_G.assign(PPC=None)
                    df_050_059_PS_I1_G  = df_050_059_PS_I1_G.assign(Total=None)
                    df_050_059_PS_I1_G ['Wt Range'] = listwtrange
                    df_050_059_PS_I1_G ['Company'] = listcom
                    df_050_059_PS_I1_G ['Shape'] = listshap
                    df_050_059_PS_I1_G ['Carat'] = listcar
                    df_050_059_PS_I1_G ['Color'] = listcol
                    df_050_059_PS_I1_G ['Clarity'] = listclar
                    df_050_059_PS_I1_G ['Cut'] = listcut
                    df_050_059_PS_I1_G ['Polish'] = listpol
                    df_050_059_PS_I1_G ['Symmetry'] = listsym
                    df_050_059_PS_I1_G ['Ratio'] = listrat
                    df_050_059_PS_I1_G ['PPC'] = listdesc
                    df_050_059_PS_I1_G ['Total'] = listtotal
                    df_050_059_PS_I1_G['Carat'] = df_050_059_PS_I1_G['Carat'].astype('float64')
                    df_050_059_PS_I1_G['PPC'] = df_050_059_PS_I1_G['PPC'].astype('float64')
                    df_050_059_PS_I1_G['Total'] = df_050_059_PS_I1_G['Total'].astype('float64')
                    df_050_059_PS_I1_G['Total'] = df_050_059_PS_I1_G['Carat'] * df_050_059_PS_I1_G['PPC']


                elif i=="G" and j == "I2" and k == "PS":
                    df_050_059_PS_I2_G = pd.DataFrame()
                    df_050_059_PS_I2_G ['Wt Range'] = None
                    df_050_059_PS_I2_G  = df_050_059_PS_I2_G.assign(Company=None)
                    df_050_059_PS_I2_G  = df_050_059_PS_I2_G.assign(Shape=None)
                    df_050_059_PS_I2_G  = df_050_059_PS_I2_G.assign(Carat=None)
                    df_050_059_PS_I2_G  = df_050_059_PS_I2_G.assign(Color=None)
                    df_050_059_PS_I2_G  = df_050_059_PS_I2_G.assign(Clarity=None)
                    df_050_059_PS_I2_G  = df_050_059_PS_I2_G.assign(Cut=None)
                    df_050_059_PS_I2_G  = df_050_059_PS_I2_G.assign(Polish=None)
                    df_050_059_PS_I2_G  = df_050_059_PS_I2_G.assign(Symmetry=None)
                    df_050_059_PS_I2_G  = df_050_059_PS_I2_G.assign(Ratio=None)
                    df_050_059_PS_I2_G  = df_050_059_PS_I2_G.assign(PPC=None)
                    df_050_059_PS_I2_G  = df_050_059_PS_I2_G.assign(Total=None)
                    df_050_059_PS_I2_G ['Wt Range'] = listwtrange
                    df_050_059_PS_I2_G ['Company'] = listcom
                    df_050_059_PS_I2_G ['Shape'] = listshap
                    df_050_059_PS_I2_G ['Carat'] = listcar
                    df_050_059_PS_I2_G ['Color'] = listcol
                    df_050_059_PS_I2_G ['Clarity'] = listclar
                    df_050_059_PS_I2_G ['Cut'] = listcut
                    df_050_059_PS_I2_G ['Polish'] = listpol
                    df_050_059_PS_I2_G ['Symmetry'] = listsym
                    df_050_059_PS_I2_G ['Ratio'] = listrat
                    df_050_059_PS_I2_G ['PPC'] = listdesc
                    df_050_059_PS_I2_G ['Total'] = listtotal
                    df_050_059_PS_I2_G['Carat'] = df_050_059_PS_I2_G['Carat'].astype('float64')
                    df_050_059_PS_I2_G['PPC'] = df_050_059_PS_I2_G['PPC'].astype('float64')
                    df_050_059_PS_I2_G['Total'] = df_050_059_PS_I2_G['Total'].astype('float64')
                    df_050_059_PS_I2_G['Total'] = df_050_059_PS_I2_G['Carat'] * df_050_059_PS_I2_G['PPC']


                elif i=="H" and j == "IF" and k == "PS":
                    df_050_059_PS_IF_H = pd.DataFrame()
                    df_050_059_PS_IF_H ['Wt Range'] = None
                    df_050_059_PS_IF_H  = df_050_059_PS_IF_H.assign(Company=None)
                    df_050_059_PS_IF_H  = df_050_059_PS_IF_H.assign(Shape=None)
                    df_050_059_PS_IF_H  = df_050_059_PS_IF_H.assign(Carat=None)
                    df_050_059_PS_IF_H  = df_050_059_PS_IF_H.assign(Color=None)
                    df_050_059_PS_IF_H  = df_050_059_PS_IF_H.assign(Clarity=None)
                    df_050_059_PS_IF_H  = df_050_059_PS_IF_H.assign(Cut=None)
                    df_050_059_PS_IF_H  = df_050_059_PS_IF_H.assign(Polish=None)
                    df_050_059_PS_IF_H  = df_050_059_PS_IF_H.assign(Symmetry=None)
                    df_050_059_PS_IF_H  = df_050_059_PS_IF_H.assign(Ratio=None)
                    df_050_059_PS_IF_H  = df_050_059_PS_IF_H.assign(PPC=None)
                    df_050_059_PS_IF_H  = df_050_059_PS_IF_H.assign(Total=None)
                    df_050_059_PS_IF_H ['Wt Range'] = listwtrange
                    df_050_059_PS_IF_H ['Company'] = listcom
                    df_050_059_PS_IF_H ['Shape'] = listshap
                    df_050_059_PS_IF_H ['Carat'] = listcar
                    df_050_059_PS_IF_H ['Color'] = listcol
                    df_050_059_PS_IF_H ['Clarity'] = listclar
                    df_050_059_PS_IF_H ['Cut'] = listcut
                    df_050_059_PS_IF_H ['Polish'] = listpol
                    df_050_059_PS_IF_H ['Symmetry'] = listsym
                    df_050_059_PS_IF_H ['Ratio'] = listrat
                    df_050_059_PS_IF_H ['PPC'] = listdesc
                    df_050_059_PS_IF_H ['Total'] = listtotal
                    df_050_059_PS_IF_H['Carat'] = df_050_059_PS_IF_H['Carat'].astype('float64')
                    df_050_059_PS_IF_H['PPC'] = df_050_059_PS_IF_H['PPC'].astype('float64')
                    df_050_059_PS_IF_H['Total'] = df_050_059_PS_IF_H['Total'].astype('float64')
                    df_050_059_PS_IF_H['Total'] = df_050_059_PS_IF_H['Carat'] * df_050_059_PS_IF_H['PPC']



                elif i=="H" and j == "VVS1" and k == "PS":
                    df_050_059_PS_VVS1_H = pd.DataFrame()
                    df_050_059_PS_VVS1_H ['Wt Range'] = None
                    df_050_059_PS_VVS1_H  = df_050_059_PS_VVS1_H.assign(Company=None)
                    df_050_059_PS_VVS1_H  = df_050_059_PS_VVS1_H.assign(Shape=None)
                    df_050_059_PS_VVS1_H  = df_050_059_PS_VVS1_H.assign(Carat=None)
                    df_050_059_PS_VVS1_H  = df_050_059_PS_VVS1_H.assign(Color=None)
                    df_050_059_PS_VVS1_H  = df_050_059_PS_VVS1_H.assign(Clarity=None)
                    df_050_059_PS_VVS1_H  = df_050_059_PS_VVS1_H.assign(Cut=None)
                    df_050_059_PS_VVS1_H  = df_050_059_PS_VVS1_H.assign(Polish=None)
                    df_050_059_PS_VVS1_H  = df_050_059_PS_VVS1_H.assign(Symmetry=None)
                    df_050_059_PS_VVS1_H  = df_050_059_PS_VVS1_H.assign(Ratio=None)
                    df_050_059_PS_VVS1_H  = df_050_059_PS_VVS1_H.assign(PPC=None)
                    df_050_059_PS_VVS1_H  = df_050_059_PS_VVS1_H.assign(Total=None)
                    df_050_059_PS_VVS1_H ['Wt Range'] = listwtrange
                    df_050_059_PS_VVS1_H ['Company'] = listcom
                    df_050_059_PS_VVS1_H ['Shape'] = listshap
                    df_050_059_PS_VVS1_H ['Carat'] = listcar
                    df_050_059_PS_VVS1_H ['Color'] = listcol
                    df_050_059_PS_VVS1_H ['Clarity'] = listclar
                    df_050_059_PS_VVS1_H ['Cut'] = listcut
                    df_050_059_PS_VVS1_H ['Polish'] = listpol
                    df_050_059_PS_VVS1_H ['Symmetry'] = listsym
                    df_050_059_PS_VVS1_H ['Ratio'] = listrat
                    df_050_059_PS_VVS1_H ['PPC'] = listdesc
                    df_050_059_PS_VVS1_H ['Total'] = listtotal
                    df_050_059_PS_VVS1_H['Carat'] = df_050_059_PS_VVS1_H['Carat'].astype('float64')
                    df_050_059_PS_VVS1_H['PPC'] = df_050_059_PS_VVS1_H['PPC'].astype('float64')
                    df_050_059_PS_VVS1_H['Total'] = df_050_059_PS_VVS1_H['Total'].astype('float64')
                    df_050_059_PS_VVS1_H['Total'] = df_050_059_PS_VVS1_H['Carat'] * df_050_059_PS_VVS1_H['PPC']


                elif i=="H" and j == "VVS2" and k == "PS":
                    df_050_059_PS_VVS2_H = pd.DataFrame()
                    df_050_059_PS_VVS2_H ['Wt Range'] = None
                    df_050_059_PS_VVS2_H  = df_050_059_PS_VVS2_H.assign(Company=None)
                    df_050_059_PS_VVS2_H  = df_050_059_PS_VVS2_H.assign(Shape=None)
                    df_050_059_PS_VVS2_H  = df_050_059_PS_VVS2_H.assign(Carat=None)
                    df_050_059_PS_VVS2_H  = df_050_059_PS_VVS2_H.assign(Color=None)
                    df_050_059_PS_VVS2_H  = df_050_059_PS_VVS2_H.assign(Clarity=None)
                    df_050_059_PS_VVS2_H  = df_050_059_PS_VVS2_H.assign(Cut=None)
                    df_050_059_PS_VVS2_H  = df_050_059_PS_VVS2_H.assign(Polish=None)
                    df_050_059_PS_VVS2_H  = df_050_059_PS_VVS2_H.assign(Symmetry=None)
                    df_050_059_PS_VVS2_H  = df_050_059_PS_VVS2_H.assign(Ratio=None)
                    df_050_059_PS_VVS2_H  = df_050_059_PS_VVS2_H.assign(PPC=None)
                    df_050_059_PS_VVS2_H  = df_050_059_PS_VVS2_H.assign(Total=None)
                    df_050_059_PS_VVS2_H ['Wt Range'] = listwtrange
                    df_050_059_PS_VVS2_H ['Company'] = listcom
                    df_050_059_PS_VVS2_H ['Shape'] = listshap
                    df_050_059_PS_VVS2_H ['Carat'] = listcar
                    df_050_059_PS_VVS2_H ['Color'] = listcol
                    df_050_059_PS_VVS2_H ['Clarity'] = listclar
                    df_050_059_PS_VVS2_H ['Cut'] = listcut
                    df_050_059_PS_VVS2_H ['Polish'] = listpol
                    df_050_059_PS_VVS2_H ['Symmetry'] = listsym
                    df_050_059_PS_VVS2_H ['Ratio'] = listrat
                    df_050_059_PS_VVS2_H ['PPC'] = listdesc
                    df_050_059_PS_VVS2_H ['Total'] = listtotal
                    df_050_059_PS_VVS2_H['Carat'] = df_050_059_PS_VVS2_H['Carat'].astype('float64')
                    df_050_059_PS_VVS2_H['PPC'] = df_050_059_PS_VVS2_H['PPC'].astype('float64')
                    df_050_059_PS_VVS2_H['Total'] = df_050_059_PS_VVS2_H['Total'].astype('float64')
                    df_050_059_PS_VVS2_H['Total'] = df_050_059_PS_VVS2_H['Carat'] * df_050_059_PS_VVS2_H['PPC']


                elif i=="H" and j=="VS1" and k == "PS":
                    df_050_059_PS_VS1_H = pd.DataFrame()
                    df_050_059_PS_VS1_H ['Wt Range'] = None
                    df_050_059_PS_VS1_H  = df_050_059_PS_VS1_H.assign(Company=None)
                    df_050_059_PS_VS1_H  = df_050_059_PS_VS1_H.assign(Shape=None)
                    df_050_059_PS_VS1_H  = df_050_059_PS_VS1_H.assign(Carat=None)
                    df_050_059_PS_VS1_H  = df_050_059_PS_VS1_H.assign(Color=None)
                    df_050_059_PS_VS1_H  = df_050_059_PS_VS1_H.assign(Clarity=None)
                    df_050_059_PS_VS1_H  = df_050_059_PS_VS1_H.assign(Cut=None)
                    df_050_059_PS_VS1_H  = df_050_059_PS_VS1_H.assign(Polish=None)
                    df_050_059_PS_VS1_H  = df_050_059_PS_VS1_H.assign(Symmetry=None)
                    df_050_059_PS_VS1_H  = df_050_059_PS_VS1_H.assign(Ratio=None)
                    df_050_059_PS_VS1_H  = df_050_059_PS_VS1_H.assign(PPC=None)
                    df_050_059_PS_VS1_H  = df_050_059_PS_VS1_H.assign(Total=None)
                    df_050_059_PS_VS1_H ['Wt Range'] = listwtrange
                    df_050_059_PS_VS1_H ['Company'] = listcom
                    df_050_059_PS_VS1_H ['Shape'] = listshap
                    df_050_059_PS_VS1_H ['Carat'] = listcar
                    df_050_059_PS_VS1_H ['Color'] = listcol
                    df_050_059_PS_VS1_H ['Clarity'] = listclar
                    df_050_059_PS_VS1_H ['Cut'] = listcut
                    df_050_059_PS_VS1_H ['Polish'] = listpol
                    df_050_059_PS_VS1_H ['Symmetry'] = listsym
                    df_050_059_PS_VS1_H ['Ratio'] = listrat
                    df_050_059_PS_VS1_H ['PPC'] = listdesc
                    df_050_059_PS_VS1_H ['Total'] = listtotal
                    df_050_059_PS_VS1_H['Carat'] = df_050_059_PS_VS1_H['Carat'].astype('float64')
                    df_050_059_PS_VS1_H['PPC'] = df_050_059_PS_VS1_H['PPC'].astype('float64')
                    df_050_059_PS_VS1_H['Total'] = df_050_059_PS_VS1_H['Total'].astype('float64')
                    df_050_059_PS_VS1_H['Total'] = df_050_059_PS_VS1_H['Carat'] * df_050_059_PS_VS1_H['PPC']


                elif i=="H" and j == "VS2" and k == "PS":
                    df_050_059_PS_VS2_H = pd.DataFrame()
                    df_050_059_PS_VS2_H ['Wt Range'] = None
                    df_050_059_PS_VS2_H  = df_050_059_PS_VS2_H.assign(Company=None)
                    df_050_059_PS_VS2_H  = df_050_059_PS_VS2_H.assign(Shape=None)
                    df_050_059_PS_VS2_H  = df_050_059_PS_VS2_H.assign(Carat=None)
                    df_050_059_PS_VS2_H  = df_050_059_PS_VS2_H.assign(Color=None)
                    df_050_059_PS_VS2_H  = df_050_059_PS_VS2_H.assign(Clarity=None)
                    df_050_059_PS_VS2_H  = df_050_059_PS_VS2_H.assign(Cut=None)
                    df_050_059_PS_VS2_H  = df_050_059_PS_VS2_H.assign(Polish=None)
                    df_050_059_PS_VS2_H  = df_050_059_PS_VS2_H.assign(Symmetry=None)
                    df_050_059_PS_VS2_H  = df_050_059_PS_VS2_H.assign(Ratio=None)
                    df_050_059_PS_VS2_H  = df_050_059_PS_VS2_H.assign(PPC=None)
                    df_050_059_PS_VS2_H  = df_050_059_PS_VS2_H.assign(Total=None)
                    df_050_059_PS_VS2_H ['Wt Range'] = listwtrange
                    df_050_059_PS_VS2_H ['Company'] = listcom
                    df_050_059_PS_VS2_H ['Shape'] = listshap
                    df_050_059_PS_VS2_H ['Carat'] = listcar
                    df_050_059_PS_VS2_H ['Color'] = listcol
                    df_050_059_PS_VS2_H ['Clarity'] = listclar
                    df_050_059_PS_VS2_H ['Cut'] = listcut
                    df_050_059_PS_VS2_H ['Polish'] = listpol
                    df_050_059_PS_VS2_H ['Symmetry'] = listsym
                    df_050_059_PS_VS2_H ['Ratio'] = listrat
                    df_050_059_PS_VS2_H ['PPC'] = listdesc
                    df_050_059_PS_VS2_H ['Total'] = listtotal
                    df_050_059_PS_VS2_H['Carat'] = df_050_059_PS_VS2_H['Carat'].astype('float64')
                    df_050_059_PS_VS2_H['PPC'] = df_050_059_PS_VS2_H['PPC'].astype('float64')
                    df_050_059_PS_VS2_H['Total'] = df_050_059_PS_VS2_H['Total'].astype('float64')
                    df_050_059_PS_VS2_H['Total'] = df_050_059_PS_VS2_H['Carat'] * df_050_059_PS_VS2_H['PPC']


                elif i=="H" and j == "SI1" and k == "PS":
                    df_050_059_PS_SI1_H = pd.DataFrame()
                    df_050_059_PS_SI1_H ['Wt Range'] = None
                    df_050_059_PS_SI1_H  = df_050_059_PS_SI1_H.assign(Company=None)
                    df_050_059_PS_SI1_H  = df_050_059_PS_SI1_H.assign(Shape=None)
                    df_050_059_PS_SI1_H  = df_050_059_PS_SI1_H.assign(Carat=None)
                    df_050_059_PS_SI1_H  = df_050_059_PS_SI1_H.assign(Color=None)
                    df_050_059_PS_SI1_H  = df_050_059_PS_SI1_H.assign(Clarity=None)
                    df_050_059_PS_SI1_H  = df_050_059_PS_SI1_H.assign(Cut=None)
                    df_050_059_PS_SI1_H  = df_050_059_PS_SI1_H.assign(Polish=None)
                    df_050_059_PS_SI1_H  = df_050_059_PS_SI1_H.assign(Symmetry=None)
                    df_050_059_PS_SI1_H  = df_050_059_PS_SI1_H.assign(Ratio=None)
                    df_050_059_PS_SI1_H  = df_050_059_PS_SI1_H.assign(PPC=None)
                    df_050_059_PS_SI1_H  = df_050_059_PS_SI1_H.assign(Total=None)
                    df_050_059_PS_SI1_H ['Wt Range'] = listwtrange
                    df_050_059_PS_SI1_H ['Company'] = listcom
                    df_050_059_PS_SI1_H ['Shape'] = listshap
                    df_050_059_PS_SI1_H ['Carat'] = listcar
                    df_050_059_PS_SI1_H ['Color'] = listcol
                    df_050_059_PS_SI1_H ['Clarity'] = listclar
                    df_050_059_PS_SI1_H ['Cut'] = listcut
                    df_050_059_PS_SI1_H ['Polish'] = listpol
                    df_050_059_PS_SI1_H ['Symmetry'] = listsym
                    df_050_059_PS_SI1_H ['Ratio'] = listrat
                    df_050_059_PS_SI1_H ['PPC'] = listdesc
                    df_050_059_PS_SI1_H ['Total'] = listtotal
                    df_050_059_PS_SI1_H['Carat'] = df_050_059_PS_SI1_H['Carat'].astype('float64')
                    df_050_059_PS_SI1_H['PPC'] = df_050_059_PS_SI1_H['PPC'].astype('float64')
                    df_050_059_PS_SI1_H['Total'] = df_050_059_PS_SI1_H['Total'].astype('float64')
                    df_050_059_PS_SI1_H['Total'] = df_050_059_PS_SI1_H['Carat'] * df_050_059_PS_SI1_H['PPC']


                elif i=="H" and j == "SI2" and k == "PS":
                    df_050_059_PS_SI2_H = pd.DataFrame()
                    df_050_059_PS_SI2_H ['Wt Range'] = None
                    df_050_059_PS_SI2_H  = df_050_059_PS_SI2_H.assign(Company=None)
                    df_050_059_PS_SI2_H  = df_050_059_PS_SI2_H.assign(Shape=None)
                    df_050_059_PS_SI2_H  = df_050_059_PS_SI2_H.assign(Carat=None)
                    df_050_059_PS_SI2_H  = df_050_059_PS_SI2_H.assign(Color=None)
                    df_050_059_PS_SI2_H  = df_050_059_PS_SI2_H.assign(Clarity=None)
                    df_050_059_PS_SI2_H  = df_050_059_PS_SI2_H.assign(Cut=None)
                    df_050_059_PS_SI2_H  = df_050_059_PS_SI2_H.assign(Polish=None)
                    df_050_059_PS_SI2_H  = df_050_059_PS_SI2_H.assign(Symmetry=None)
                    df_050_059_PS_SI2_H  = df_050_059_PS_SI2_H.assign(Ratio=None)
                    df_050_059_PS_SI2_H  = df_050_059_PS_SI2_H.assign(PPC=None)
                    df_050_059_PS_SI2_H  = df_050_059_PS_SI2_H.assign(Total=None)
                    df_050_059_PS_SI2_H ['Wt Range'] = listwtrange
                    df_050_059_PS_SI2_H ['Company'] = listcom
                    df_050_059_PS_SI2_H ['Shape'] = listshap
                    df_050_059_PS_SI2_H ['Carat'] = listcar
                    df_050_059_PS_SI2_H ['Color'] = listcol
                    df_050_059_PS_SI2_H ['Clarity'] = listclar
                    df_050_059_PS_SI2_H ['Cut'] = listcut
                    df_050_059_PS_SI2_H ['Polish'] = listpol
                    df_050_059_PS_SI2_H ['Symmetry'] = listsym
                    df_050_059_PS_SI2_H ['Ratio'] = listrat
                    df_050_059_PS_SI2_H ['PPC'] = listdesc
                    df_050_059_PS_SI2_H ['Total'] = listtotal
                    df_050_059_PS_SI2_H['Carat'] = df_050_059_PS_SI2_H['Carat'].astype('float64')
                    df_050_059_PS_SI2_H['PPC'] = df_050_059_PS_SI2_H['PPC'].astype('float64')
                    df_050_059_PS_SI2_H['Total'] = df_050_059_PS_SI2_H['Total'].astype('float64')
                    df_050_059_PS_SI2_H['Total'] = df_050_059_PS_SI2_H['Carat'] * df_050_059_PS_SI2_H['PPC']


                elif i=="H" and j == "I1" and k == "PS":
                    df_050_059_PS_I1_H = pd.DataFrame()
                    df_050_059_PS_I1_H ['Wt Range'] = None
                    df_050_059_PS_I1_H  = df_050_059_PS_I1_H.assign(Company=None)
                    df_050_059_PS_I1_H  = df_050_059_PS_I1_H.assign(Shape=None)
                    df_050_059_PS_I1_H  = df_050_059_PS_I1_H.assign(Carat=None)
                    df_050_059_PS_I1_H  = df_050_059_PS_I1_H.assign(Color=None)
                    df_050_059_PS_I1_H  = df_050_059_PS_I1_H.assign(Clarity=None)
                    df_050_059_PS_I1_H  = df_050_059_PS_I1_H.assign(Cut=None)
                    df_050_059_PS_I1_H  = df_050_059_PS_I1_H.assign(Polish=None)
                    df_050_059_PS_I1_H  = df_050_059_PS_I1_H.assign(Symmetry=None)
                    df_050_059_PS_I1_H  = df_050_059_PS_I1_H.assign(Ratio=None)
                    df_050_059_PS_I1_H  = df_050_059_PS_I1_H.assign(PPC=None)
                    df_050_059_PS_I1_H  = df_050_059_PS_I1_H.assign(Total=None)
                    df_050_059_PS_I1_H ['Wt Range'] = listwtrange
                    df_050_059_PS_I1_H ['Company'] = listcom
                    df_050_059_PS_I1_H ['Shape'] = listshap
                    df_050_059_PS_I1_H ['Carat'] = listcar
                    df_050_059_PS_I1_H ['Color'] = listcol
                    df_050_059_PS_I1_H ['Clarity'] = listclar
                    df_050_059_PS_I1_H ['Cut'] = listcut
                    df_050_059_PS_I1_H ['Polish'] = listpol
                    df_050_059_PS_I1_H ['Symmetry'] = listsym
                    df_050_059_PS_I1_H ['Ratio'] = listrat
                    df_050_059_PS_I1_H ['PPC'] = listdesc
                    df_050_059_PS_I1_H ['Total'] = listtotal
                    df_050_059_PS_I1_H['Carat'] = df_050_059_PS_I1_H['Carat'].astype('float64')
                    df_050_059_PS_I1_H['PPC'] = df_050_059_PS_I1_H['PPC'].astype('float64')
                    df_050_059_PS_I1_H['Total'] = df_050_059_PS_I1_H['Total'].astype('float64')
                    df_050_059_PS_I1_H['Total'] = df_050_059_PS_I1_H['Carat'] * df_050_059_PS_I1_H['PPC']


                elif i=="H" and j == "I2" and k == "PS":
                    df_050_059_PS_I2_H = pd.DataFrame()
                    df_050_059_PS_I2_H ['Wt Range'] = None
                    df_050_059_PS_I2_H  = df_050_059_PS_I2_H.assign(Company=None)
                    df_050_059_PS_I2_H  = df_050_059_PS_I2_H.assign(Shape=None)
                    df_050_059_PS_I2_H  = df_050_059_PS_I2_H.assign(Carat=None)
                    df_050_059_PS_I2_H  = df_050_059_PS_I2_H.assign(Color=None)
                    df_050_059_PS_I2_H  = df_050_059_PS_I2_H.assign(Clarity=None)
                    df_050_059_PS_I2_H  = df_050_059_PS_I2_H.assign(Cut=None)
                    df_050_059_PS_I2_H  = df_050_059_PS_I2_H.assign(Polish=None)
                    df_050_059_PS_I2_H  = df_050_059_PS_I2_H.assign(Symmetry=None)
                    df_050_059_PS_I2_H  = df_050_059_PS_I2_H.assign(Ratio=None)
                    df_050_059_PS_I2_H  = df_050_059_PS_I2_H.assign(PPC=None)
                    df_050_059_PS_I2_H  = df_050_059_PS_I2_H.assign(Total=None)
                    df_050_059_PS_I2_H ['Wt Range'] = listwtrange
                    df_050_059_PS_I2_H ['Company'] = listcom
                    df_050_059_PS_I2_H ['Shape'] = listshap
                    df_050_059_PS_I2_H ['Carat'] = listcar
                    df_050_059_PS_I2_H ['Color'] = listcol
                    df_050_059_PS_I2_H ['Clarity'] = listclar
                    df_050_059_PS_I2_H ['Cut'] = listcut
                    df_050_059_PS_I2_H ['Polish'] = listpol
                    df_050_059_PS_I2_H ['Symmetry'] = listsym
                    df_050_059_PS_I2_H ['Ratio'] = listrat
                    df_050_059_PS_I2_H ['PPC'] = listdesc
                    df_050_059_PS_I2_H ['Total'] = listtotal
                    df_050_059_PS_I2_H['Carat'] = df_050_059_PS_I2_H['Carat'].astype('float64')
                    df_050_059_PS_I2_H['PPC'] = df_050_059_PS_I2_H['PPC'].astype('float64')
                    df_050_059_PS_I2_H['Total'] = df_050_059_PS_I2_H['Total'].astype('float64')
                    df_050_059_PS_I2_H['Total'] = df_050_059_PS_I2_H['Carat'] * df_050_059_PS_I2_H['PPC']



                elif i== "I" and j == "IF" and k == "PS":
                    df_050_059_PS_IF_I = pd.DataFrame()
                    df_050_059_PS_IF_I ['Wt Range'] = None
                    df_050_059_PS_IF_I  = df_050_059_PS_IF_I.assign(Company=None)
                    df_050_059_PS_IF_I  = df_050_059_PS_IF_I.assign(Shape=None)
                    df_050_059_PS_IF_I  = df_050_059_PS_IF_I.assign(Carat=None)
                    df_050_059_PS_IF_I  = df_050_059_PS_IF_I.assign(Color=None)
                    df_050_059_PS_IF_I  = df_050_059_PS_IF_I.assign(Clarity=None)
                    df_050_059_PS_IF_I  = df_050_059_PS_IF_I.assign(Cut=None)
                    df_050_059_PS_IF_I  = df_050_059_PS_IF_I.assign(Polish=None)
                    df_050_059_PS_IF_I  = df_050_059_PS_IF_I.assign(Symmetry=None)
                    df_050_059_PS_IF_I  = df_050_059_PS_IF_I.assign(Ratio=None)
                    df_050_059_PS_IF_I  = df_050_059_PS_IF_I.assign(PPC=None)
                    df_050_059_PS_IF_I  = df_050_059_PS_IF_I.assign(Total=None)
                    df_050_059_PS_IF_I ['Wt Range'] = listwtrange
                    df_050_059_PS_IF_I ['Company'] = listcom
                    df_050_059_PS_IF_I ['Shape'] = listshap
                    df_050_059_PS_IF_I ['Carat'] = listcar
                    df_050_059_PS_IF_I ['Color'] = listcol
                    df_050_059_PS_IF_I ['Clarity'] = listclar
                    df_050_059_PS_IF_I ['Cut'] = listcut
                    df_050_059_PS_IF_I ['Polish'] = listpol
                    df_050_059_PS_IF_I ['Symmetry'] = listsym
                    df_050_059_PS_IF_I ['Ratio'] = listrat
                    df_050_059_PS_IF_I ['PPC'] = listdesc
                    df_050_059_PS_IF_I ['Total'] = listtotal
                    df_050_059_PS_IF_I['Carat'] = df_050_059_PS_IF_I['Carat'].astype('float64')
                    df_050_059_PS_IF_I['PPC'] = df_050_059_PS_IF_I['PPC'].astype('float64')
                    df_050_059_PS_IF_I['Total'] = df_050_059_PS_IF_I['Total'].astype('float64')
                    df_050_059_PS_IF_I['Total'] = df_050_059_PS_IF_I['Carat'] * df_050_059_PS_IF_I['PPC']



                elif i== "I" and j == "VVS1" and k == "PS":
                    df_050_059_PS_VVS1_I = pd.DataFrame()
                    df_050_059_PS_VVS1_I ['Wt Range'] = None
                    df_050_059_PS_VVS1_I  = df_050_059_PS_VVS1_I.assign(Company=None)
                    df_050_059_PS_VVS1_I  = df_050_059_PS_VVS1_I.assign(Shape=None)
                    df_050_059_PS_VVS1_I  = df_050_059_PS_VVS1_I.assign(Carat=None)
                    df_050_059_PS_VVS1_I  = df_050_059_PS_VVS1_I.assign(Color=None)
                    df_050_059_PS_VVS1_I  = df_050_059_PS_VVS1_I.assign(Clarity=None)
                    df_050_059_PS_VVS1_I  = df_050_059_PS_VVS1_I.assign(Cut=None)
                    df_050_059_PS_VVS1_I  = df_050_059_PS_VVS1_I.assign(Polish=None)
                    df_050_059_PS_VVS1_I  = df_050_059_PS_VVS1_I.assign(Symmetry=None)
                    df_050_059_PS_VVS1_I  = df_050_059_PS_VVS1_I.assign(Ratio=None)
                    df_050_059_PS_VVS1_I  = df_050_059_PS_VVS1_I.assign(PPC=None)
                    df_050_059_PS_VVS1_I  = df_050_059_PS_VVS1_I.assign(Total=None)
                    df_050_059_PS_VVS1_I ['Wt Range'] = listwtrange
                    df_050_059_PS_VVS1_I ['Company'] = listcom
                    df_050_059_PS_VVS1_I ['Shape'] = listshap
                    df_050_059_PS_VVS1_I ['Carat'] = listcar
                    df_050_059_PS_VVS1_I ['Color'] = listcol
                    df_050_059_PS_VVS1_I ['Clarity'] = listclar
                    df_050_059_PS_VVS1_I ['Cut'] = listcut
                    df_050_059_PS_VVS1_I ['Polish'] = listpol
                    df_050_059_PS_VVS1_I ['Symmetry'] = listsym
                    df_050_059_PS_VVS1_I ['Ratio'] = listrat
                    df_050_059_PS_VVS1_I ['PPC'] = listdesc
                    df_050_059_PS_VVS1_I ['Total'] = listtotal
                    df_050_059_PS_VVS1_I['Carat'] = df_050_059_PS_VVS1_I['Carat'].astype('float64')
                    df_050_059_PS_VVS1_I['PPC'] = df_050_059_PS_VVS1_I['PPC'].astype('float64')
                    df_050_059_PS_VVS1_I['Total'] = df_050_059_PS_VVS1_I['Total'].astype('float64')
                    df_050_059_PS_VVS1_I['Total'] = df_050_059_PS_VVS1_I['Carat'] * df_050_059_PS_VVS1_I['PPC']


                elif i== "I" and j == "VVS2" and k == "PS":
                    df_050_059_PS_VVS2_I = pd.DataFrame()
                    df_050_059_PS_VVS2_I ['Wt Range'] = None
                    df_050_059_PS_VVS2_I  = df_050_059_PS_VVS2_I.assign(Company=None)
                    df_050_059_PS_VVS2_I  = df_050_059_PS_VVS2_I.assign(Shape=None)
                    df_050_059_PS_VVS2_I  = df_050_059_PS_VVS2_I.assign(Carat=None)
                    df_050_059_PS_VVS2_I  = df_050_059_PS_VVS2_I.assign(Color=None)
                    df_050_059_PS_VVS2_I  = df_050_059_PS_VVS2_I.assign(Clarity=None)
                    df_050_059_PS_VVS2_I  = df_050_059_PS_VVS2_I.assign(Cut=None)
                    df_050_059_PS_VVS2_I  = df_050_059_PS_VVS2_I.assign(Polish=None)
                    df_050_059_PS_VVS2_I  = df_050_059_PS_VVS2_I.assign(Symmetry=None)
                    df_050_059_PS_VVS2_I  = df_050_059_PS_VVS2_I.assign(Ratio=None)
                    df_050_059_PS_VVS2_I  = df_050_059_PS_VVS2_I.assign(PPC=None)
                    df_050_059_PS_VVS2_I  = df_050_059_PS_VVS2_I.assign(Total=None)
                    df_050_059_PS_VVS2_I ['Wt Range'] = listwtrange
                    df_050_059_PS_VVS2_I ['Company'] = listcom
                    df_050_059_PS_VVS2_I ['Shape'] = listshap
                    df_050_059_PS_VVS2_I ['Carat'] = listcar
                    df_050_059_PS_VVS2_I ['Color'] = listcol
                    df_050_059_PS_VVS2_I ['Clarity'] = listclar
                    df_050_059_PS_VVS2_I ['Cut'] = listcut
                    df_050_059_PS_VVS2_I ['Polish'] = listpol
                    df_050_059_PS_VVS2_I ['Symmetry'] = listsym
                    df_050_059_PS_VVS2_I ['Ratio'] = listrat
                    df_050_059_PS_VVS2_I ['PPC'] = listdesc
                    df_050_059_PS_VVS2_I ['Total'] = listtotal
                    df_050_059_PS_VVS2_I['Carat'] = df_050_059_PS_VVS2_I['Carat'].astype('float64')
                    df_050_059_PS_VVS2_I['PPC'] = df_050_059_PS_VVS2_I['PPC'].astype('float64')
                    df_050_059_PS_VVS2_I['Total'] = df_050_059_PS_VVS2_I['Total'].astype('float64')
                    df_050_059_PS_VVS2_I['Total'] = df_050_059_PS_VVS2_I['Carat'] * df_050_059_PS_VVS2_I['PPC']


                elif i== "I" and j=="VS1" and k == "PS":
                    df_050_059_PS_VS1_I = pd.DataFrame()
                    df_050_059_PS_VS1_I ['Wt Range'] = None
                    df_050_059_PS_VS1_I  = df_050_059_PS_VS1_I.assign(Company=None)
                    df_050_059_PS_VS1_I  = df_050_059_PS_VS1_I.assign(Shape=None)
                    df_050_059_PS_VS1_I  = df_050_059_PS_VS1_I.assign(Carat=None)
                    df_050_059_PS_VS1_I  = df_050_059_PS_VS1_I.assign(Color=None)
                    df_050_059_PS_VS1_I  = df_050_059_PS_VS1_I.assign(Clarity=None)
                    df_050_059_PS_VS1_I  = df_050_059_PS_VS1_I.assign(Cut=None)
                    df_050_059_PS_VS1_I  = df_050_059_PS_VS1_I.assign(Polish=None)
                    df_050_059_PS_VS1_I  = df_050_059_PS_VS1_I.assign(Symmetry=None)
                    df_050_059_PS_VS1_I  = df_050_059_PS_VS1_I.assign(Ratio=None)
                    df_050_059_PS_VS1_I  = df_050_059_PS_VS1_I.assign(PPC=None)
                    df_050_059_PS_VS1_I  = df_050_059_PS_VS1_I.assign(Total=None)
                    df_050_059_PS_VS1_I ['Wt Range'] = listwtrange
                    df_050_059_PS_VS1_I ['Company'] = listcom
                    df_050_059_PS_VS1_I ['Shape'] = listshap
                    df_050_059_PS_VS1_I ['Carat'] = listcar
                    df_050_059_PS_VS1_I ['Color'] = listcol
                    df_050_059_PS_VS1_I ['Clarity'] = listclar
                    df_050_059_PS_VS1_I ['Cut'] = listcut
                    df_050_059_PS_VS1_I ['Polish'] = listpol
                    df_050_059_PS_VS1_I ['Symmetry'] = listsym
                    df_050_059_PS_VS1_I ['Ratio'] = listrat
                    df_050_059_PS_VS1_I ['PPC'] = listdesc
                    df_050_059_PS_VS1_I ['Total'] = listtotal
                    df_050_059_PS_VS1_I['Carat'] = df_050_059_PS_VS1_I['Carat'].astype('float64')
                    df_050_059_PS_VS1_I['PPC'] = df_050_059_PS_VS1_I['PPC'].astype('float64')
                    df_050_059_PS_VS1_I['Total'] = df_050_059_PS_VS1_I['Total'].astype('float64')
                    df_050_059_PS_VS1_I['Total'] = df_050_059_PS_VS1_I['Carat'] * df_050_059_PS_VS1_I['PPC']


                elif i== "I" and j == "VS2" and k == "PS":
                    df_050_059_PS_VS2_I = pd.DataFrame()
                    df_050_059_PS_VS2_I ['Wt Range'] = None
                    df_050_059_PS_VS2_I  = df_050_059_PS_VS2_I.assign(Company=None)
                    df_050_059_PS_VS2_I  = df_050_059_PS_VS2_I.assign(Shape=None)
                    df_050_059_PS_VS2_I  = df_050_059_PS_VS2_I.assign(Carat=None)
                    df_050_059_PS_VS2_I  = df_050_059_PS_VS2_I.assign(Color=None)
                    df_050_059_PS_VS2_I  = df_050_059_PS_VS2_I.assign(Clarity=None)
                    df_050_059_PS_VS2_I  = df_050_059_PS_VS2_I.assign(Cut=None)
                    df_050_059_PS_VS2_I  = df_050_059_PS_VS2_I.assign(Polish=None)
                    df_050_059_PS_VS2_I  = df_050_059_PS_VS2_I.assign(Symmetry=None)
                    df_050_059_PS_VS2_I  = df_050_059_PS_VS2_I.assign(Ratio=None)
                    df_050_059_PS_VS2_I  = df_050_059_PS_VS2_I.assign(PPC=None)
                    df_050_059_PS_VS2_I  = df_050_059_PS_VS2_I.assign(Total=None)
                    df_050_059_PS_VS2_I ['Wt Range'] = listwtrange
                    df_050_059_PS_VS2_I ['Company'] = listcom
                    df_050_059_PS_VS2_I ['Shape'] = listshap
                    df_050_059_PS_VS2_I ['Carat'] = listcar
                    df_050_059_PS_VS2_I ['Color'] = listcol
                    df_050_059_PS_VS2_I ['Clarity'] = listclar
                    df_050_059_PS_VS2_I ['Cut'] = listcut
                    df_050_059_PS_VS2_I ['Polish'] = listpol
                    df_050_059_PS_VS2_I ['Symmetry'] = listsym
                    df_050_059_PS_VS2_I ['Ratio'] = listrat
                    df_050_059_PS_VS2_I ['PPC'] = listdesc
                    df_050_059_PS_VS2_I ['Total'] = listtotal
                    df_050_059_PS_VS2_I['Carat'] = df_050_059_PS_VS2_I['Carat'].astype('float64')
                    df_050_059_PS_VS2_I['PPC'] = df_050_059_PS_VS2_I['PPC'].astype('float64')
                    df_050_059_PS_VS2_I['Total'] = df_050_059_PS_VS2_I['Total'].astype('float64')
                    df_050_059_PS_VS2_I['Total'] = df_050_059_PS_VS2_I['Carat'] * df_050_059_PS_VS2_I['PPC']


                elif i== "I" and j == "SI1" and k == "PS":
                    df_050_059_PS_SI1_I = pd.DataFrame()
                    df_050_059_PS_SI1_I ['Wt Range'] = None
                    df_050_059_PS_SI1_I  = df_050_059_PS_SI1_I.assign(Company=None)
                    df_050_059_PS_SI1_I  = df_050_059_PS_SI1_I.assign(Shape=None)
                    df_050_059_PS_SI1_I  = df_050_059_PS_SI1_I.assign(Carat=None)
                    df_050_059_PS_SI1_I  = df_050_059_PS_SI1_I.assign(Color=None)
                    df_050_059_PS_SI1_I  = df_050_059_PS_SI1_I.assign(Clarity=None)
                    df_050_059_PS_SI1_I  = df_050_059_PS_SI1_I.assign(Cut=None)
                    df_050_059_PS_SI1_I  = df_050_059_PS_SI1_I.assign(Polish=None)
                    df_050_059_PS_SI1_I  = df_050_059_PS_SI1_I.assign(Symmetry=None)
                    df_050_059_PS_SI1_I  = df_050_059_PS_SI1_I.assign(Ratio=None)
                    df_050_059_PS_SI1_I  = df_050_059_PS_SI1_I.assign(PPC=None)
                    df_050_059_PS_SI1_I  = df_050_059_PS_SI1_I.assign(Total=None)
                    df_050_059_PS_SI1_I ['Wt Range'] = listwtrange
                    df_050_059_PS_SI1_I ['Company'] = listcom
                    df_050_059_PS_SI1_I ['Shape'] = listshap
                    df_050_059_PS_SI1_I ['Carat'] = listcar
                    df_050_059_PS_SI1_I ['Color'] = listcol
                    df_050_059_PS_SI1_I ['Clarity'] = listclar
                    df_050_059_PS_SI1_I ['Cut'] = listcut
                    df_050_059_PS_SI1_I ['Polish'] = listpol
                    df_050_059_PS_SI1_I ['Symmetry'] = listsym
                    df_050_059_PS_SI1_I ['Ratio'] = listrat
                    df_050_059_PS_SI1_I ['PPC'] = listdesc
                    df_050_059_PS_SI1_I ['Total'] = listtotal
                    df_050_059_PS_SI1_I['Carat'] = df_050_059_PS_SI1_I['Carat'].astype('float64')
                    df_050_059_PS_SI1_I['PPC'] = df_050_059_PS_SI1_I['PPC'].astype('float64')
                    df_050_059_PS_SI1_I['Total'] = df_050_059_PS_SI1_I['Total'].astype('float64')
                    df_050_059_PS_SI1_I['Total'] = df_050_059_PS_SI1_I['Carat'] * df_050_059_PS_SI1_I['PPC']


                elif i== "I" and j == "SI2" and k == "PS":
                    df_050_059_PS_SI2_I = pd.DataFrame()
                    df_050_059_PS_SI2_I ['Wt Range'] = None
                    df_050_059_PS_SI2_I  = df_050_059_PS_SI2_I.assign(Company=None)
                    df_050_059_PS_SI2_I  = df_050_059_PS_SI2_I.assign(Shape=None)
                    df_050_059_PS_SI2_I  = df_050_059_PS_SI2_I.assign(Carat=None)
                    df_050_059_PS_SI2_I  = df_050_059_PS_SI2_I.assign(Color=None)
                    df_050_059_PS_SI2_I  = df_050_059_PS_SI2_I.assign(Clarity=None)
                    df_050_059_PS_SI2_I  = df_050_059_PS_SI2_I.assign(Cut=None)
                    df_050_059_PS_SI2_I  = df_050_059_PS_SI2_I.assign(Polish=None)
                    df_050_059_PS_SI2_I  = df_050_059_PS_SI2_I.assign(Symmetry=None)
                    df_050_059_PS_SI2_I  = df_050_059_PS_SI2_I.assign(Ratio=None)
                    df_050_059_PS_SI2_I  = df_050_059_PS_SI2_I.assign(PPC=None)
                    df_050_059_PS_SI2_I  = df_050_059_PS_SI2_I.assign(Total=None)
                    df_050_059_PS_SI2_I ['Wt Range'] = listwtrange
                    df_050_059_PS_SI2_I ['Company'] = listcom
                    df_050_059_PS_SI2_I ['Shape'] = listshap
                    df_050_059_PS_SI2_I ['Carat'] = listcar
                    df_050_059_PS_SI2_I ['Color'] = listcol
                    df_050_059_PS_SI2_I ['Clarity'] = listclar
                    df_050_059_PS_SI2_I ['Cut'] = listcut
                    df_050_059_PS_SI2_I ['Polish'] = listpol
                    df_050_059_PS_SI2_I ['Symmetry'] = listsym
                    df_050_059_PS_SI2_I ['Ratio'] = listrat
                    df_050_059_PS_SI2_I ['PPC'] = listdesc
                    df_050_059_PS_SI2_I ['Total'] = listtotal
                    df_050_059_PS_SI2_I['Carat'] = df_050_059_PS_SI2_I['Carat'].astype('float64')
                    df_050_059_PS_SI2_I['PPC'] = df_050_059_PS_SI2_I['PPC'].astype('float64')
                    df_050_059_PS_SI2_I['Total'] = df_050_059_PS_SI2_I['Total'].astype('float64')
                    df_050_059_PS_SI2_I['Total'] = df_050_059_PS_SI2_I['Carat'] * df_050_059_PS_SI2_I['PPC']


                elif i== "I" and j == "I1" and k == "PS":
                    df_050_059_PS_I1_I = pd.DataFrame()
                    df_050_059_PS_I1_I ['Wt Range'] = None
                    df_050_059_PS_I1_I  = df_050_059_PS_I1_I.assign(Company=None)
                    df_050_059_PS_I1_I  = df_050_059_PS_I1_I.assign(Shape=None)
                    df_050_059_PS_I1_I  = df_050_059_PS_I1_I.assign(Carat=None)
                    df_050_059_PS_I1_I  = df_050_059_PS_I1_I.assign(Color=None)
                    df_050_059_PS_I1_I  = df_050_059_PS_I1_I.assign(Clarity=None)
                    df_050_059_PS_I1_I  = df_050_059_PS_I1_I.assign(Cut=None)
                    df_050_059_PS_I1_I  = df_050_059_PS_I1_I.assign(Polish=None)
                    df_050_059_PS_I1_I  = df_050_059_PS_I1_I.assign(Symmetry=None)
                    df_050_059_PS_I1_I  = df_050_059_PS_I1_I.assign(Ratio=None)
                    df_050_059_PS_I1_I  = df_050_059_PS_I1_I.assign(PPC=None)
                    df_050_059_PS_I1_I  = df_050_059_PS_I1_I.assign(Total=None)
                    df_050_059_PS_I1_I ['Wt Range'] = listwtrange
                    df_050_059_PS_I1_I ['Company'] = listcom
                    df_050_059_PS_I1_I ['Shape'] = listshap
                    df_050_059_PS_I1_I ['Carat'] = listcar
                    df_050_059_PS_I1_I ['Color'] = listcol
                    df_050_059_PS_I1_I ['Clarity'] = listclar
                    df_050_059_PS_I1_I ['Cut'] = listcut
                    df_050_059_PS_I1_I ['Polish'] = listpol
                    df_050_059_PS_I1_I ['Symmetry'] = listsym
                    df_050_059_PS_I1_I ['Ratio'] = listrat
                    df_050_059_PS_I1_I ['PPC'] = listdesc
                    df_050_059_PS_I1_I ['Total'] = listtotal
                    df_050_059_PS_I1_I['Carat'] = df_050_059_PS_I1_I['Carat'].astype('float64')
                    df_050_059_PS_I1_I['PPC'] = df_050_059_PS_I1_I['PPC'].astype('float64')
                    df_050_059_PS_I1_I['Total'] = df_050_059_PS_I1_I['Total'].astype('float64')
                    df_050_059_PS_I1_I['Total'] = df_050_059_PS_I1_I['Carat'] * df_050_059_PS_I1_I['PPC']


                elif i== "I" and j == "I2" and k == "PS":
                    df_050_059_PS_I2_I = pd.DataFrame()
                    df_050_059_PS_I2_I ['Wt Range'] = None
                    df_050_059_PS_I2_I  = df_050_059_PS_I2_I.assign(Company=None)
                    df_050_059_PS_I2_I  = df_050_059_PS_I2_I.assign(Shape=None)
                    df_050_059_PS_I2_I  = df_050_059_PS_I2_I.assign(Carat=None)
                    df_050_059_PS_I2_I  = df_050_059_PS_I2_I.assign(Color=None)
                    df_050_059_PS_I2_I  = df_050_059_PS_I2_I.assign(Clarity=None)
                    df_050_059_PS_I2_I  = df_050_059_PS_I2_I.assign(Cut=None)
                    df_050_059_PS_I2_I  = df_050_059_PS_I2_I.assign(Polish=None)
                    df_050_059_PS_I2_I  = df_050_059_PS_I2_I.assign(Symmetry=None)
                    df_050_059_PS_I2_I  = df_050_059_PS_I2_I.assign(Ratio=None)
                    df_050_059_PS_I2_I  = df_050_059_PS_I2_I.assign(PPC=None)
                    df_050_059_PS_I2_I  = df_050_059_PS_I2_I.assign(Total=None)
                    df_050_059_PS_I2_I ['Wt Range'] = listwtrange
                    df_050_059_PS_I2_I ['Company'] = listcom
                    df_050_059_PS_I2_I ['Shape'] = listshap
                    df_050_059_PS_I2_I ['Carat'] = listcar
                    df_050_059_PS_I2_I ['Color'] = listcol
                    df_050_059_PS_I2_I ['Clarity'] = listclar
                    df_050_059_PS_I2_I ['Cut'] = listcut
                    df_050_059_PS_I2_I ['Polish'] = listpol
                    df_050_059_PS_I2_I ['Symmetry'] = listsym
                    df_050_059_PS_I2_I ['Ratio'] = listrat
                    df_050_059_PS_I2_I ['PPC'] = listdesc
                    df_050_059_PS_I2_I ['Total'] = listtotal
                    df_050_059_PS_I2_I['Carat'] = df_050_059_PS_I2_I['Carat'].astype('float64')
                    df_050_059_PS_I2_I['PPC'] = df_050_059_PS_I2_I['PPC'].astype('float64')
                    df_050_059_PS_I2_I['Total'] = df_050_059_PS_I2_I['Total'].astype('float64')
                    df_050_059_PS_I2_I['Total'] = df_050_059_PS_I2_I['Carat'] * df_050_059_PS_I2_I['PPC']


                elif i=="J" and j == "IF" and k == "PS":
                    df_050_059_PS_IF_J = pd.DataFrame()
                    df_050_059_PS_IF_J ['Wt Range'] = None
                    df_050_059_PS_IF_J  = df_050_059_PS_IF_J.assign(Company=None)
                    df_050_059_PS_IF_J  = df_050_059_PS_IF_J.assign(Shape=None)
                    df_050_059_PS_IF_J  = df_050_059_PS_IF_J.assign(Carat=None)
                    df_050_059_PS_IF_J  = df_050_059_PS_IF_J.assign(Color=None)
                    df_050_059_PS_IF_J  = df_050_059_PS_IF_J.assign(Clarity=None)
                    df_050_059_PS_IF_J  = df_050_059_PS_IF_J.assign(Cut=None)
                    df_050_059_PS_IF_J  = df_050_059_PS_IF_J.assign(Polish=None)
                    df_050_059_PS_IF_J  = df_050_059_PS_IF_J.assign(Symmetry=None)
                    df_050_059_PS_IF_J  = df_050_059_PS_IF_J.assign(Ratio=None)
                    df_050_059_PS_IF_J  = df_050_059_PS_IF_J.assign(PPC=None)
                    df_050_059_PS_IF_J  = df_050_059_PS_IF_J.assign(Total=None)
                    df_050_059_PS_IF_J ['Wt Range'] = listwtrange
                    df_050_059_PS_IF_J ['Company'] = listcom
                    df_050_059_PS_IF_J ['Shape'] = listshap
                    df_050_059_PS_IF_J ['Carat'] = listcar
                    df_050_059_PS_IF_J ['Color'] = listcol
                    df_050_059_PS_IF_J ['Clarity'] = listclar
                    df_050_059_PS_IF_J ['Cut'] = listcut
                    df_050_059_PS_IF_J ['Polish'] = listpol
                    df_050_059_PS_IF_J ['Symmetry'] = listsym
                    df_050_059_PS_IF_J ['Ratio'] = listrat
                    df_050_059_PS_IF_J ['PPC'] = listdesc
                    df_050_059_PS_IF_J ['Total'] = listtotal
                    df_050_059_PS_IF_J['Carat'] = df_050_059_PS_IF_J['Carat'].astype('float64')
                    df_050_059_PS_IF_J['PPC'] = df_050_059_PS_IF_J['PPC'].astype('float64')
                    df_050_059_PS_IF_J['Total'] = df_050_059_PS_IF_J['Total'].astype('float64')
                    df_050_059_PS_IF_J['Total'] = df_050_059_PS_IF_J['Carat'] * df_050_059_PS_IF_J['PPC']



                elif i=="J"  and j == "VVS1" and k == "PS":
                    df_050_059_PS_VVS1_J = pd.DataFrame()
                    df_050_059_PS_VVS1_J ['Wt Range'] = None
                    df_050_059_PS_VVS1_J  = df_050_059_PS_VVS1_J.assign(Company=None)
                    df_050_059_PS_VVS1_J  = df_050_059_PS_VVS1_J.assign(Shape=None)
                    df_050_059_PS_VVS1_J  = df_050_059_PS_VVS1_J.assign(Carat=None)
                    df_050_059_PS_VVS1_J  = df_050_059_PS_VVS1_J.assign(Color=None)
                    df_050_059_PS_VVS1_J  = df_050_059_PS_VVS1_J.assign(Clarity=None)
                    df_050_059_PS_VVS1_J  = df_050_059_PS_VVS1_J.assign(Cut=None)
                    df_050_059_PS_VVS1_J  = df_050_059_PS_VVS1_J.assign(Polish=None)
                    df_050_059_PS_VVS1_J  = df_050_059_PS_VVS1_J.assign(Symmetry=None)
                    df_050_059_PS_VVS1_J  = df_050_059_PS_VVS1_J.assign(Ratio=None)
                    df_050_059_PS_VVS1_J  = df_050_059_PS_VVS1_J.assign(PPC=None)
                    df_050_059_PS_VVS1_J  = df_050_059_PS_VVS1_J.assign(Total=None)
                    df_050_059_PS_VVS1_J ['Wt Range'] = listwtrange
                    df_050_059_PS_VVS1_J ['Company'] = listcom
                    df_050_059_PS_VVS1_J ['Shape'] = listshap
                    df_050_059_PS_VVS1_J ['Carat'] = listcar
                    df_050_059_PS_VVS1_J ['Color'] = listcol
                    df_050_059_PS_VVS1_J ['Clarity'] = listclar
                    df_050_059_PS_VVS1_J ['Cut'] = listcut
                    df_050_059_PS_VVS1_J ['Polish'] = listpol
                    df_050_059_PS_VVS1_J ['Symmetry'] = listsym
                    df_050_059_PS_VVS1_J ['Ratio'] = listrat
                    df_050_059_PS_VVS1_J ['PPC'] = listdesc
                    df_050_059_PS_VVS1_J ['Total'] = listtotal
                    df_050_059_PS_VVS1_J['Carat'] = df_050_059_PS_VVS1_J['Carat'].astype('float64')
                    df_050_059_PS_VVS1_J['PPC'] = df_050_059_PS_VVS1_J['PPC'].astype('float64')
                    df_050_059_PS_VVS1_J['Total'] = df_050_059_PS_VVS1_J['Total'].astype('float64')
                    df_050_059_PS_VVS1_J['Total'] = df_050_059_PS_VVS1_J['Carat'] * df_050_059_PS_VVS1_J['PPC']


                elif i=="J"  and j == "VVS2" and k == "PS":
                    df_050_059_PS_VVS2_J = pd.DataFrame()
                    df_050_059_PS_VVS2_J ['Wt Range'] = None
                    df_050_059_PS_VVS2_J  = df_050_059_PS_VVS2_J.assign(Company=None)
                    df_050_059_PS_VVS2_J  = df_050_059_PS_VVS2_J.assign(Shape=None)
                    df_050_059_PS_VVS2_J  = df_050_059_PS_VVS2_J.assign(Carat=None)
                    df_050_059_PS_VVS2_J  = df_050_059_PS_VVS2_J.assign(Color=None)
                    df_050_059_PS_VVS2_J  = df_050_059_PS_VVS2_J.assign(Clarity=None)
                    df_050_059_PS_VVS2_J  = df_050_059_PS_VVS2_J.assign(Cut=None)
                    df_050_059_PS_VVS2_J  = df_050_059_PS_VVS2_J.assign(Polish=None)
                    df_050_059_PS_VVS2_J  = df_050_059_PS_VVS2_J.assign(Symmetry=None)
                    df_050_059_PS_VVS2_J  = df_050_059_PS_VVS2_J.assign(Ratio=None)
                    df_050_059_PS_VVS2_J  = df_050_059_PS_VVS2_J.assign(PPC=None)
                    df_050_059_PS_VVS2_J  = df_050_059_PS_VVS2_J.assign(Total=None)
                    df_050_059_PS_VVS2_J ['Wt Range'] = listwtrange
                    df_050_059_PS_VVS2_J ['Company'] = listcom
                    df_050_059_PS_VVS2_J ['Shape'] = listshap
                    df_050_059_PS_VVS2_J ['Carat'] = listcar
                    df_050_059_PS_VVS2_J ['Color'] = listcol
                    df_050_059_PS_VVS2_J ['Clarity'] = listclar
                    df_050_059_PS_VVS2_J ['Cut'] = listcut
                    df_050_059_PS_VVS2_J ['Polish'] = listpol
                    df_050_059_PS_VVS2_J ['Symmetry'] = listsym
                    df_050_059_PS_VVS2_J ['Ratio'] = listrat
                    df_050_059_PS_VVS2_J ['PPC'] = listdesc
                    df_050_059_PS_VVS2_J ['Total'] = listtotal
                    df_050_059_PS_VVS2_J['Carat'] = df_050_059_PS_VVS2_J['Carat'].astype('float64')
                    df_050_059_PS_VVS2_J['PPC'] = df_050_059_PS_VVS2_J['PPC'].astype('float64')
                    df_050_059_PS_VVS2_J['Total'] = df_050_059_PS_VVS2_J['Total'].astype('float64')
                    df_050_059_PS_VVS2_J['Total'] = df_050_059_PS_VVS2_J['Carat'] * df_050_059_PS_VVS2_J['PPC']


                elif i=="J"  and j=="VS1" and k == "PS":
                    df_050_059_PS_VS1_J = pd.DataFrame()
                    df_050_059_PS_VS1_J ['Wt Range'] = None
                    df_050_059_PS_VS1_J  = df_050_059_PS_VS1_J.assign(Company=None)
                    df_050_059_PS_VS1_J  = df_050_059_PS_VS1_J.assign(Shape=None)
                    df_050_059_PS_VS1_J  = df_050_059_PS_VS1_J.assign(Carat=None)
                    df_050_059_PS_VS1_J  = df_050_059_PS_VS1_J.assign(Color=None)
                    df_050_059_PS_VS1_J  = df_050_059_PS_VS1_J.assign(Clarity=None)
                    df_050_059_PS_VS1_J  = df_050_059_PS_VS1_J.assign(Cut=None)
                    df_050_059_PS_VS1_J  = df_050_059_PS_VS1_J.assign(Polish=None)
                    df_050_059_PS_VS1_J  = df_050_059_PS_VS1_J.assign(Symmetry=None)
                    df_050_059_PS_VS1_J  = df_050_059_PS_VS1_J.assign(Ratio=None)
                    df_050_059_PS_VS1_J  = df_050_059_PS_VS1_J.assign(PPC=None)
                    df_050_059_PS_VS1_J  = df_050_059_PS_VS1_J.assign(Total=None)
                    df_050_059_PS_VS1_J ['Wt Range'] = listwtrange
                    df_050_059_PS_VS1_J ['Company'] = listcom
                    df_050_059_PS_VS1_J ['Shape'] = listshap
                    df_050_059_PS_VS1_J ['Carat'] = listcar
                    df_050_059_PS_VS1_J ['Color'] = listcol
                    df_050_059_PS_VS1_J ['Clarity'] = listclar
                    df_050_059_PS_VS1_J ['Cut'] = listcut
                    df_050_059_PS_VS1_J ['Polish'] = listpol
                    df_050_059_PS_VS1_J ['Symmetry'] = listsym
                    df_050_059_PS_VS1_J ['Ratio'] = listrat
                    df_050_059_PS_VS1_J ['PPC'] = listdesc
                    df_050_059_PS_VS1_J ['Total'] = listtotal
                    df_050_059_PS_VS1_J['Carat'] = df_050_059_PS_VS1_J['Carat'].astype('float64')
                    df_050_059_PS_VS1_J['PPC'] = df_050_059_PS_VS1_J['PPC'].astype('float64')
                    df_050_059_PS_VS1_J['Total'] = df_050_059_PS_VS1_J['Total'].astype('float64')
                    df_050_059_PS_VS1_J['Total'] = df_050_059_PS_VS1_J['Carat'] * df_050_059_PS_VS1_J['PPC']


                elif i=="J"  and j == "VS2" and k == "PS":
                    df_050_059_PS_VS2_J = pd.DataFrame()
                    df_050_059_PS_VS2_J ['Wt Range'] = None
                    df_050_059_PS_VS2_J  = df_050_059_PS_VS2_J.assign(Company=None)
                    df_050_059_PS_VS2_J  = df_050_059_PS_VS2_J.assign(Shape=None)
                    df_050_059_PS_VS2_J  = df_050_059_PS_VS2_J.assign(Carat=None)
                    df_050_059_PS_VS2_J  = df_050_059_PS_VS2_J.assign(Color=None)
                    df_050_059_PS_VS2_J  = df_050_059_PS_VS2_J.assign(Clarity=None)
                    df_050_059_PS_VS2_J  = df_050_059_PS_VS2_J.assign(Cut=None)
                    df_050_059_PS_VS2_J  = df_050_059_PS_VS2_J.assign(Polish=None)
                    df_050_059_PS_VS2_J  = df_050_059_PS_VS2_J.assign(Symmetry=None)
                    df_050_059_PS_VS2_J  = df_050_059_PS_VS2_J.assign(Ratio=None)
                    df_050_059_PS_VS2_J  = df_050_059_PS_VS2_J.assign(PPC=None)
                    df_050_059_PS_VS2_J  = df_050_059_PS_VS2_J.assign(Total=None)
                    df_050_059_PS_VS2_J ['Wt Range'] = listwtrange
                    df_050_059_PS_VS2_J ['Company'] = listcom
                    df_050_059_PS_VS2_J ['Shape'] = listshap
                    df_050_059_PS_VS2_J ['Carat'] = listcar
                    df_050_059_PS_VS2_J ['Color'] = listcol
                    df_050_059_PS_VS2_J ['Clarity'] = listclar
                    df_050_059_PS_VS2_J ['Cut'] = listcut
                    df_050_059_PS_VS2_J ['Polish'] = listpol
                    df_050_059_PS_VS2_J ['Symmetry'] = listsym
                    df_050_059_PS_VS2_J ['Ratio'] = listrat
                    df_050_059_PS_VS2_J ['PPC'] = listdesc
                    df_050_059_PS_VS2_J ['Total'] = listtotal
                    df_050_059_PS_VS2_J['Carat'] = df_050_059_PS_VS2_J['Carat'].astype('float64')
                    df_050_059_PS_VS2_J['PPC'] = df_050_059_PS_VS2_J['PPC'].astype('float64')
                    df_050_059_PS_VS2_J['Total'] = df_050_059_PS_VS2_J['Total'].astype('float64')
                    df_050_059_PS_VS2_J['Total'] = df_050_059_PS_VS2_J['Carat'] * df_050_059_PS_VS2_J['PPC']


                elif i=="J"  and j == "SI1" and k == "PS":
                    df_050_059_PS_SI1_J = pd.DataFrame()
                    df_050_059_PS_SI1_J ['Wt Range'] = None
                    df_050_059_PS_SI1_J  = df_050_059_PS_SI1_J.assign(Company=None)
                    df_050_059_PS_SI1_J  = df_050_059_PS_SI1_J.assign(Shape=None)
                    df_050_059_PS_SI1_J  = df_050_059_PS_SI1_J.assign(Carat=None)
                    df_050_059_PS_SI1_J  = df_050_059_PS_SI1_J.assign(Color=None)
                    df_050_059_PS_SI1_J  = df_050_059_PS_SI1_J.assign(Clarity=None)
                    df_050_059_PS_SI1_J  = df_050_059_PS_SI1_J.assign(Cut=None)
                    df_050_059_PS_SI1_J  = df_050_059_PS_SI1_J.assign(Polish=None)
                    df_050_059_PS_SI1_J  = df_050_059_PS_SI1_J.assign(Symmetry=None)
                    df_050_059_PS_SI1_J  = df_050_059_PS_SI1_J.assign(Ratio=None)
                    df_050_059_PS_SI1_J  = df_050_059_PS_SI1_J.assign(PPC=None)
                    df_050_059_PS_SI1_J  = df_050_059_PS_SI1_J.assign(Total=None)
                    df_050_059_PS_SI1_J ['Wt Range'] = listwtrange
                    df_050_059_PS_SI1_J ['Company'] = listcom
                    df_050_059_PS_SI1_J ['Shape'] = listshap
                    df_050_059_PS_SI1_J ['Carat'] = listcar
                    df_050_059_PS_SI1_J ['Color'] = listcol
                    df_050_059_PS_SI1_J ['Clarity'] = listclar
                    df_050_059_PS_SI1_J ['Cut'] = listcut
                    df_050_059_PS_SI1_J ['Polish'] = listpol
                    df_050_059_PS_SI1_J ['Symmetry'] = listsym
                    df_050_059_PS_SI1_J ['Ratio'] = listrat
                    df_050_059_PS_SI1_J ['PPC'] = listdesc
                    df_050_059_PS_SI1_J ['Total'] = listtotal
                    df_050_059_PS_SI1_J['Carat'] = df_050_059_PS_SI1_J['Carat'].astype('float64')
                    df_050_059_PS_SI1_J['PPC'] = df_050_059_PS_SI1_J['PPC'].astype('float64')
                    df_050_059_PS_SI1_J['Total'] = df_050_059_PS_SI1_J['Total'].astype('float64')
                    df_050_059_PS_SI1_J['Total'] = df_050_059_PS_SI1_J['Carat'] * df_050_059_PS_SI1_J['PPC']


                elif i=="J"  and j == "SI2" and k == "PS":
                    df_050_059_PS_SI2_J = pd.DataFrame()
                    df_050_059_PS_SI2_J ['Wt Range'] = None
                    df_050_059_PS_SI2_J  = df_050_059_PS_SI2_J.assign(Company=None)
                    df_050_059_PS_SI2_J  = df_050_059_PS_SI2_J.assign(Shape=None)
                    df_050_059_PS_SI2_J  = df_050_059_PS_SI2_J.assign(Carat=None)
                    df_050_059_PS_SI2_J  = df_050_059_PS_SI2_J.assign(Color=None)
                    df_050_059_PS_SI2_J  = df_050_059_PS_SI2_J.assign(Clarity=None)
                    df_050_059_PS_SI2_J  = df_050_059_PS_SI2_J.assign(Cut=None)
                    df_050_059_PS_SI2_J  = df_050_059_PS_SI2_J.assign(Polish=None)
                    df_050_059_PS_SI2_J  = df_050_059_PS_SI2_J.assign(Symmetry=None)
                    df_050_059_PS_SI2_J  = df_050_059_PS_SI2_J.assign(Ratio=None)
                    df_050_059_PS_SI2_J  = df_050_059_PS_SI2_J.assign(PPC=None)
                    df_050_059_PS_SI2_J  = df_050_059_PS_SI2_J.assign(Total=None)
                    df_050_059_PS_SI2_J ['Wt Range'] = listwtrange
                    df_050_059_PS_SI2_J ['Company'] = listcom
                    df_050_059_PS_SI2_J ['Shape'] = listshap
                    df_050_059_PS_SI2_J ['Carat'] = listcar
                    df_050_059_PS_SI2_J ['Color'] = listcol
                    df_050_059_PS_SI2_J ['Clarity'] = listclar
                    df_050_059_PS_SI2_J ['Cut'] = listcut
                    df_050_059_PS_SI2_J ['Polish'] = listpol
                    df_050_059_PS_SI2_J ['Symmetry'] = listsym
                    df_050_059_PS_SI2_J ['Ratio'] = listrat
                    df_050_059_PS_SI2_J ['PPC'] = listdesc
                    df_050_059_PS_SI2_J ['Total'] = listtotal
                    df_050_059_PS_SI2_J['Carat'] = df_050_059_PS_SI2_J['Carat'].astype('float64')
                    df_050_059_PS_SI2_J['PPC'] = df_050_059_PS_SI2_J['PPC'].astype('float64')
                    df_050_059_PS_SI2_J['Total'] = df_050_059_PS_SI2_J['Total'].astype('float64')
                    df_050_059_PS_SI2_J['Total'] = df_050_059_PS_SI2_J['Carat'] * df_050_059_PS_SI2_J['PPC']


                elif i=="J"  and j == "I1" and k == "PS":
                    df_050_059_PS_I1_J = pd.DataFrame()
                    df_050_059_PS_I1_J ['Wt Range'] = None
                    df_050_059_PS_I1_J  = df_050_059_PS_I1_J.assign(Company=None)
                    df_050_059_PS_I1_J  = df_050_059_PS_I1_J.assign(Shape=None)
                    df_050_059_PS_I1_J  = df_050_059_PS_I1_J.assign(Carat=None)
                    df_050_059_PS_I1_J  = df_050_059_PS_I1_J.assign(Color=None)
                    df_050_059_PS_I1_J  = df_050_059_PS_I1_J.assign(Clarity=None)
                    df_050_059_PS_I1_J  = df_050_059_PS_I1_J.assign(Cut=None)
                    df_050_059_PS_I1_J  = df_050_059_PS_I1_J.assign(Polish=None)
                    df_050_059_PS_I1_J  = df_050_059_PS_I1_J.assign(Symmetry=None)
                    df_050_059_PS_I1_J  = df_050_059_PS_I1_J.assign(Ratio=None)
                    df_050_059_PS_I1_J  = df_050_059_PS_I1_J.assign(PPC=None)
                    df_050_059_PS_I1_J  = df_050_059_PS_I1_J.assign(Total=None)
                    df_050_059_PS_I1_J ['Wt Range'] = listwtrange
                    df_050_059_PS_I1_J ['Company'] = listcom
                    df_050_059_PS_I1_J ['Shape'] = listshap
                    df_050_059_PS_I1_J ['Carat'] = listcar
                    df_050_059_PS_I1_J ['Color'] = listcol
                    df_050_059_PS_I1_J ['Clarity'] = listclar
                    df_050_059_PS_I1_J ['Cut'] = listcut
                    df_050_059_PS_I1_J ['Polish'] = listpol
                    df_050_059_PS_I1_J ['Symmetry'] = listsym
                    df_050_059_PS_I1_J ['Ratio'] = listrat
                    df_050_059_PS_I1_J ['PPC'] = listdesc
                    df_050_059_PS_I1_J ['Total'] = listtotal
                    df_050_059_PS_I1_J['Carat'] = df_050_059_PS_I1_J['Carat'].astype('float64')
                    df_050_059_PS_I1_J['PPC'] = df_050_059_PS_I1_J['PPC'].astype('float64')
                    df_050_059_PS_I1_J['Total'] = df_050_059_PS_I1_J['Total'].astype('float64')
                    df_050_059_PS_I1_J['Total'] = df_050_059_PS_I1_J['Carat'] * df_050_059_PS_I1_J['PPC']


                elif i=="J"  and j == "I2" and k == "PS":
                    df_050_059_PS_I2_J = pd.DataFrame()
                    df_050_059_PS_I2_J ['Wt Range'] = None
                    df_050_059_PS_I2_J  = df_050_059_PS_I2_J.assign(Company=None)
                    df_050_059_PS_I2_J  = df_050_059_PS_I2_J.assign(Shape=None)
                    df_050_059_PS_I2_J  = df_050_059_PS_I2_J.assign(Carat=None)
                    df_050_059_PS_I2_J  = df_050_059_PS_I2_J.assign(Color=None)
                    df_050_059_PS_I2_J  = df_050_059_PS_I2_J.assign(Clarity=None)
                    df_050_059_PS_I2_J  = df_050_059_PS_I2_J.assign(Cut=None)
                    df_050_059_PS_I2_J  = df_050_059_PS_I2_J.assign(Polish=None)
                    df_050_059_PS_I2_J  = df_050_059_PS_I2_J.assign(Symmetry=None)
                    df_050_059_PS_I2_J  = df_050_059_PS_I2_J.assign(Ratio=None)
                    df_050_059_PS_I2_J  = df_050_059_PS_I2_J.assign(PPC=None)
                    df_050_059_PS_I2_J  = df_050_059_PS_I2_J.assign(Total=None)
                    df_050_059_PS_I2_J ['Wt Range'] = listwtrange
                    df_050_059_PS_I2_J ['Company'] = listcom
                    df_050_059_PS_I2_J ['Shape'] = listshap
                    df_050_059_PS_I2_J ['Carat'] = listcar
                    df_050_059_PS_I2_J ['Color'] = listcol
                    df_050_059_PS_I2_J ['Clarity'] = listclar
                    df_050_059_PS_I2_J ['Cut'] = listcut
                    df_050_059_PS_I2_J ['Polish'] = listpol
                    df_050_059_PS_I2_J ['Symmetry'] = listsym
                    df_050_059_PS_I2_J ['Ratio'] = listrat
                    df_050_059_PS_I2_J ['PPC'] = listdesc
                    df_050_059_PS_I2_J ['Total'] = listtotal
                    df_050_059_PS_I2_J['Carat'] = df_050_059_PS_I2_J['Carat'].astype('float64')
                    df_050_059_PS_I2_J['PPC'] = df_050_059_PS_I2_J['PPC'].astype('float64')
                    df_050_059_PS_I2_J['Total'] = df_050_059_PS_I2_J['Total'].astype('float64')
                    df_050_059_PS_I2_J['Total'] = df_050_059_PS_I2_J['Carat'] * df_050_059_PS_I2_J['PPC']


                elif i=="K" and j == "IF" and k == "PS":
                    df_050_059_PS_IF_K = pd.DataFrame()
                    df_050_059_PS_IF_K ['Wt Range'] = None
                    df_050_059_PS_IF_K  = df_050_059_PS_IF_K.assign(Company=None)
                    df_050_059_PS_IF_K  = df_050_059_PS_IF_K.assign(Shape=None)
                    df_050_059_PS_IF_K  = df_050_059_PS_IF_K.assign(Carat=None)
                    df_050_059_PS_IF_K  = df_050_059_PS_IF_K.assign(Color=None)
                    df_050_059_PS_IF_K  = df_050_059_PS_IF_K.assign(Clarity=None)
                    df_050_059_PS_IF_K  = df_050_059_PS_IF_K.assign(Cut=None)
                    df_050_059_PS_IF_K  = df_050_059_PS_IF_K.assign(Polish=None)
                    df_050_059_PS_IF_K  = df_050_059_PS_IF_K.assign(Symmetry=None)
                    df_050_059_PS_IF_K  = df_050_059_PS_IF_K.assign(Ratio=None)
                    df_050_059_PS_IF_K  = df_050_059_PS_IF_K.assign(PPC=None)
                    df_050_059_PS_IF_K  = df_050_059_PS_IF_K.assign(Total=None)
                    df_050_059_PS_IF_K ['Wt Range'] = listwtrange
                    df_050_059_PS_IF_K ['Company'] = listcom
                    df_050_059_PS_IF_K ['Shape'] = listshap
                    df_050_059_PS_IF_K ['Carat'] = listcar
                    df_050_059_PS_IF_K ['Color'] = listcol
                    df_050_059_PS_IF_K ['Clarity'] = listclar
                    df_050_059_PS_IF_K ['Cut'] = listcut
                    df_050_059_PS_IF_K ['Polish'] = listpol
                    df_050_059_PS_IF_K ['Symmetry'] = listsym
                    df_050_059_PS_IF_K ['Ratio'] = listrat
                    df_050_059_PS_IF_K ['PPC'] = listdesc
                    df_050_059_PS_IF_K ['Total'] = listtotal
                    df_050_059_PS_IF_K['Carat'] = df_050_059_PS_IF_K['Carat'].astype('float64')
                    df_050_059_PS_IF_K['PPC'] = df_050_059_PS_IF_K['PPC'].astype('float64')
                    df_050_059_PS_IF_K['Total'] = df_050_059_PS_IF_K['Total'].astype('float64')
                    df_050_059_PS_IF_K['Total'] = df_050_059_PS_IF_K['Carat'] * df_050_059_PS_IF_K['PPC']



                elif i=="K" and j == "VVS1" and k == "PS":
                    df_050_059_PS_VVS1_K = pd.DataFrame()
                    df_050_059_PS_VVS1_K ['Wt Range'] = None
                    df_050_059_PS_VVS1_K  = df_050_059_PS_VVS1_K.assign(Company=None)
                    df_050_059_PS_VVS1_K  = df_050_059_PS_VVS1_K.assign(Shape=None)
                    df_050_059_PS_VVS1_K  = df_050_059_PS_VVS1_K.assign(Carat=None)
                    df_050_059_PS_VVS1_K  = df_050_059_PS_VVS1_K.assign(Color=None)
                    df_050_059_PS_VVS1_K  = df_050_059_PS_VVS1_K.assign(Clarity=None)
                    df_050_059_PS_VVS1_K  = df_050_059_PS_VVS1_K.assign(Cut=None)
                    df_050_059_PS_VVS1_K  = df_050_059_PS_VVS1_K.assign(Polish=None)
                    df_050_059_PS_VVS1_K  = df_050_059_PS_VVS1_K.assign(Symmetry=None)
                    df_050_059_PS_VVS1_K  = df_050_059_PS_VVS1_K.assign(Ratio=None)
                    df_050_059_PS_VVS1_K  = df_050_059_PS_VVS1_K.assign(PPC=None)
                    df_050_059_PS_VVS1_K  = df_050_059_PS_VVS1_K.assign(Total=None)
                    df_050_059_PS_VVS1_K ['Wt Range'] = listwtrange
                    df_050_059_PS_VVS1_K ['Company'] = listcom
                    df_050_059_PS_VVS1_K ['Shape'] = listshap
                    df_050_059_PS_VVS1_K ['Carat'] = listcar
                    df_050_059_PS_VVS1_K ['Color'] = listcol
                    df_050_059_PS_VVS1_K ['Clarity'] = listclar
                    df_050_059_PS_VVS1_K ['Cut'] = listcut
                    df_050_059_PS_VVS1_K ['Polish'] = listpol
                    df_050_059_PS_VVS1_K ['Symmetry'] = listsym
                    df_050_059_PS_VVS1_K ['Ratio'] = listrat
                    df_050_059_PS_VVS1_K ['PPC'] = listdesc
                    df_050_059_PS_VVS1_K ['Total'] = listtotal
                    df_050_059_PS_VVS1_K['Carat'] = df_050_059_PS_VVS1_K['Carat'].astype('float64')
                    df_050_059_PS_VVS1_K['PPC'] = df_050_059_PS_VVS1_K['PPC'].astype('float64')
                    df_050_059_PS_VVS1_K['Total'] = df_050_059_PS_VVS1_K['Total'].astype('float64')
                    df_050_059_PS_VVS1_K['Total'] = df_050_059_PS_VVS1_K['Carat'] * df_050_059_PS_VVS1_K['PPC']


                elif i=="K" and j == "VVS2" and k == "PS":
                    df_050_059_PS_VVS2_K = pd.DataFrame()
                    df_050_059_PS_VVS2_K ['Wt Range'] = None
                    df_050_059_PS_VVS2_K  = df_050_059_PS_VVS2_K.assign(Company=None)
                    df_050_059_PS_VVS2_K  = df_050_059_PS_VVS2_K.assign(Shape=None)
                    df_050_059_PS_VVS2_K  = df_050_059_PS_VVS2_K.assign(Carat=None)
                    df_050_059_PS_VVS2_K  = df_050_059_PS_VVS2_K.assign(Color=None)
                    df_050_059_PS_VVS2_K  = df_050_059_PS_VVS2_K.assign(Clarity=None)
                    df_050_059_PS_VVS2_K  = df_050_059_PS_VVS2_K.assign(Cut=None)
                    df_050_059_PS_VVS2_K  = df_050_059_PS_VVS2_K.assign(Polish=None)
                    df_050_059_PS_VVS2_K  = df_050_059_PS_VVS2_K.assign(Symmetry=None)
                    df_050_059_PS_VVS2_K  = df_050_059_PS_VVS2_K.assign(Ratio=None)
                    df_050_059_PS_VVS2_K  = df_050_059_PS_VVS2_K.assign(PPC=None)
                    df_050_059_PS_VVS2_K  = df_050_059_PS_VVS2_K.assign(Total=None)
                    df_050_059_PS_VVS2_K ['Wt Range'] = listwtrange
                    df_050_059_PS_VVS2_K ['Company'] = listcom
                    df_050_059_PS_VVS2_K ['Shape'] = listshap
                    df_050_059_PS_VVS2_K ['Carat'] = listcar
                    df_050_059_PS_VVS2_K ['Color'] = listcol
                    df_050_059_PS_VVS2_K ['Clarity'] = listclar
                    df_050_059_PS_VVS2_K ['Cut'] = listcut
                    df_050_059_PS_VVS2_K ['Polish'] = listpol
                    df_050_059_PS_VVS2_K ['Symmetry'] = listsym
                    df_050_059_PS_VVS2_K ['Ratio'] = listrat
                    df_050_059_PS_VVS2_K ['PPC'] = listdesc
                    df_050_059_PS_VVS2_K ['Total'] = listtotal
                    df_050_059_PS_VVS2_K['Carat'] = df_050_059_PS_VVS2_K['Carat'].astype('float64')
                    df_050_059_PS_VVS2_K['PPC'] = df_050_059_PS_VVS2_K['PPC'].astype('float64')
                    df_050_059_PS_VVS2_K['Total'] = df_050_059_PS_VVS2_K['Total'].astype('float64')
                    df_050_059_PS_VVS2_K['Total'] = df_050_059_PS_VVS2_K['Carat'] * df_050_059_PS_VVS2_K['PPC']


                elif i=="K" and j=="VS1" and k == "PS":
                    df_050_059_PS_VS1_K = pd.DataFrame()
                    df_050_059_PS_VS1_K ['Wt Range'] = None
                    df_050_059_PS_VS1_K  = df_050_059_PS_VS1_K.assign(Company=None)
                    df_050_059_PS_VS1_K  = df_050_059_PS_VS1_K.assign(Shape=None)
                    df_050_059_PS_VS1_K  = df_050_059_PS_VS1_K.assign(Carat=None)
                    df_050_059_PS_VS1_K  = df_050_059_PS_VS1_K.assign(Color=None)
                    df_050_059_PS_VS1_K  = df_050_059_PS_VS1_K.assign(Clarity=None)
                    df_050_059_PS_VS1_K  = df_050_059_PS_VS1_K.assign(Cut=None)
                    df_050_059_PS_VS1_K  = df_050_059_PS_VS1_K.assign(Polish=None)
                    df_050_059_PS_VS1_K  = df_050_059_PS_VS1_K.assign(Symmetry=None)
                    df_050_059_PS_VS1_K  = df_050_059_PS_VS1_K.assign(Ratio=None)
                    df_050_059_PS_VS1_K  = df_050_059_PS_VS1_K.assign(PPC=None)
                    df_050_059_PS_VS1_K  = df_050_059_PS_VS1_K.assign(Total=None)
                    df_050_059_PS_VS1_K ['Wt Range'] = listwtrange
                    df_050_059_PS_VS1_K ['Company'] = listcom
                    df_050_059_PS_VS1_K ['Shape'] = listshap
                    df_050_059_PS_VS1_K ['Carat'] = listcar
                    df_050_059_PS_VS1_K ['Color'] = listcol
                    df_050_059_PS_VS1_K ['Clarity'] = listclar
                    df_050_059_PS_VS1_K ['Cut'] = listcut
                    df_050_059_PS_VS1_K ['Polish'] = listpol
                    df_050_059_PS_VS1_K ['Symmetry'] = listsym
                    df_050_059_PS_VS1_K ['Ratio'] = listrat
                    df_050_059_PS_VS1_K ['PPC'] = listdesc
                    df_050_059_PS_VS1_K ['Total'] = listtotal
                    df_050_059_PS_VS1_K['Carat'] = df_050_059_PS_VS1_K['Carat'].astype('float64')
                    df_050_059_PS_VS1_K['PPC'] = df_050_059_PS_VS1_K['PPC'].astype('float64')
                    df_050_059_PS_VS1_K['Total'] = df_050_059_PS_VS1_K['Total'].astype('float64')
                    df_050_059_PS_VS1_K['Total'] = df_050_059_PS_VS1_K['Carat'] * df_050_059_PS_VS1_K['PPC']


                elif i=="K" and j == "VS2" and k == "PS":
                    df_050_059_PS_VS2_K = pd.DataFrame()
                    df_050_059_PS_VS2_K ['Wt Range'] = None
                    df_050_059_PS_VS2_K  = df_050_059_PS_VS2_K.assign(Company=None)
                    df_050_059_PS_VS2_K  = df_050_059_PS_VS2_K.assign(Shape=None)
                    df_050_059_PS_VS2_K  = df_050_059_PS_VS2_K.assign(Carat=None)
                    df_050_059_PS_VS2_K  = df_050_059_PS_VS2_K.assign(Color=None)
                    df_050_059_PS_VS2_K  = df_050_059_PS_VS2_K.assign(Clarity=None)
                    df_050_059_PS_VS2_K  = df_050_059_PS_VS2_K.assign(Cut=None)
                    df_050_059_PS_VS2_K  = df_050_059_PS_VS2_K.assign(Polish=None)
                    df_050_059_PS_VS2_K  = df_050_059_PS_VS2_K.assign(Symmetry=None)
                    df_050_059_PS_VS2_K  = df_050_059_PS_VS2_K.assign(Ratio=None)
                    df_050_059_PS_VS2_K  = df_050_059_PS_VS2_K.assign(PPC=None)
                    df_050_059_PS_VS2_K  = df_050_059_PS_VS2_K.assign(Total=None)
                    df_050_059_PS_VS2_K ['Wt Range'] = listwtrange
                    df_050_059_PS_VS2_K ['Company'] = listcom
                    df_050_059_PS_VS2_K ['Shape'] = listshap
                    df_050_059_PS_VS2_K ['Carat'] = listcar
                    df_050_059_PS_VS2_K ['Color'] = listcol
                    df_050_059_PS_VS2_K ['Clarity'] = listclar
                    df_050_059_PS_VS2_K ['Cut'] = listcut
                    df_050_059_PS_VS2_K ['Polish'] = listpol
                    df_050_059_PS_VS2_K ['Symmetry'] = listsym
                    df_050_059_PS_VS2_K ['Ratio'] = listrat
                    df_050_059_PS_VS2_K ['PPC'] = listdesc
                    df_050_059_PS_VS2_K ['Total'] = listtotal
                    df_050_059_PS_VS2_K['Carat'] = df_050_059_PS_VS2_K['Carat'].astype('float64')
                    df_050_059_PS_VS2_K['PPC'] = df_050_059_PS_VS2_K['PPC'].astype('float64')
                    df_050_059_PS_VS2_K['Total'] = df_050_059_PS_VS2_K['Total'].astype('float64')
                    df_050_059_PS_VS2_K['Total'] = df_050_059_PS_VS2_K['Carat'] * df_050_059_PS_VS2_K['PPC']


                elif i=="K" and j == "SI1" and k == "PS":
                    df_050_059_PS_SI1_K = pd.DataFrame()
                    df_050_059_PS_SI1_K ['Wt Range'] = None
                    df_050_059_PS_SI1_K  = df_050_059_PS_SI1_K.assign(Company=None)
                    df_050_059_PS_SI1_K  = df_050_059_PS_SI1_K.assign(Shape=None)
                    df_050_059_PS_SI1_K  = df_050_059_PS_SI1_K.assign(Carat=None)
                    df_050_059_PS_SI1_K  = df_050_059_PS_SI1_K.assign(Color=None)
                    df_050_059_PS_SI1_K  = df_050_059_PS_SI1_K.assign(Clarity=None)
                    df_050_059_PS_SI1_K  = df_050_059_PS_SI1_K.assign(Cut=None)
                    df_050_059_PS_SI1_K  = df_050_059_PS_SI1_K.assign(Polish=None)
                    df_050_059_PS_SI1_K  = df_050_059_PS_SI1_K.assign(Symmetry=None)
                    df_050_059_PS_SI1_K  = df_050_059_PS_SI1_K.assign(Ratio=None)
                    df_050_059_PS_SI1_K  = df_050_059_PS_SI1_K.assign(PPC=None)
                    df_050_059_PS_SI1_K  = df_050_059_PS_SI1_K.assign(Total=None)
                    df_050_059_PS_SI1_K ['Wt Range'] = listwtrange
                    df_050_059_PS_SI1_K ['Company'] = listcom
                    df_050_059_PS_SI1_K ['Shape'] = listshap
                    df_050_059_PS_SI1_K ['Carat'] = listcar
                    df_050_059_PS_SI1_K ['Color'] = listcol
                    df_050_059_PS_SI1_K ['Clarity'] = listclar
                    df_050_059_PS_SI1_K ['Cut'] = listcut
                    df_050_059_PS_SI1_K ['Polish'] = listpol
                    df_050_059_PS_SI1_K ['Symmetry'] = listsym
                    df_050_059_PS_SI1_K ['Ratio'] = listrat
                    df_050_059_PS_SI1_K ['PPC'] = listdesc
                    df_050_059_PS_SI1_K ['Total'] = listtotal
                    df_050_059_PS_SI1_K['Carat'] = df_050_059_PS_SI1_K['Carat'].astype('float64')
                    df_050_059_PS_SI1_K['PPC'] = df_050_059_PS_SI1_K['PPC'].astype('float64')
                    df_050_059_PS_SI1_K['Total'] = df_050_059_PS_SI1_K['Total'].astype('float64')
                    df_050_059_PS_SI1_K['Total'] = df_050_059_PS_SI1_K['Carat'] * df_050_059_PS_SI1_K['PPC']


                elif i=="K" and j == "SI2" and k == "PS":
                    df_050_059_PS_SI2_K = pd.DataFrame()
                    df_050_059_PS_SI2_K ['Wt Range'] = None
                    df_050_059_PS_SI2_K  = df_050_059_PS_SI2_K.assign(Company=None)
                    df_050_059_PS_SI2_K  = df_050_059_PS_SI2_K.assign(Shape=None)
                    df_050_059_PS_SI2_K  = df_050_059_PS_SI2_K.assign(Carat=None)
                    df_050_059_PS_SI2_K  = df_050_059_PS_SI2_K.assign(Color=None)
                    df_050_059_PS_SI2_K  = df_050_059_PS_SI2_K.assign(Clarity=None)
                    df_050_059_PS_SI2_K  = df_050_059_PS_SI2_K.assign(Cut=None)
                    df_050_059_PS_SI2_K  = df_050_059_PS_SI2_K.assign(Polish=None)
                    df_050_059_PS_SI2_K  = df_050_059_PS_SI2_K.assign(Symmetry=None)
                    df_050_059_PS_SI2_K  = df_050_059_PS_SI2_K.assign(Ratio=None)
                    df_050_059_PS_SI2_K  = df_050_059_PS_SI2_K.assign(PPC=None)
                    df_050_059_PS_SI2_K  = df_050_059_PS_SI2_K.assign(Total=None)
                    df_050_059_PS_SI2_K ['Wt Range'] = listwtrange
                    df_050_059_PS_SI2_K ['Company'] = listcom
                    df_050_059_PS_SI2_K ['Shape'] = listshap
                    df_050_059_PS_SI2_K ['Carat'] = listcar
                    df_050_059_PS_SI2_K ['Color'] = listcol
                    df_050_059_PS_SI2_K ['Clarity'] = listclar
                    df_050_059_PS_SI2_K ['Cut'] = listcut
                    df_050_059_PS_SI2_K ['Polish'] = listpol
                    df_050_059_PS_SI2_K ['Symmetry'] = listsym
                    df_050_059_PS_SI2_K ['Ratio'] = listrat
                    df_050_059_PS_SI2_K ['PPC'] = listdesc
                    df_050_059_PS_SI2_K ['Total'] = listtotal
                    df_050_059_PS_SI2_K['Carat'] = df_050_059_PS_SI2_K['Carat'].astype('float64')
                    df_050_059_PS_SI2_K['PPC'] = df_050_059_PS_SI2_K['PPC'].astype('float64')
                    df_050_059_PS_SI2_K['Total'] = df_050_059_PS_SI2_K['Total'].astype('float64')
                    df_050_059_PS_SI2_K['Total'] = df_050_059_PS_SI2_K['Carat'] * df_050_059_PS_SI2_K['PPC']


                elif i=="K" and j == "I1" and k == "PS":
                    df_050_059_PS_I1_K = pd.DataFrame()
                    df_050_059_PS_I1_K ['Wt Range'] = None
                    df_050_059_PS_I1_K  = df_050_059_PS_I1_K.assign(Company=None)
                    df_050_059_PS_I1_K  = df_050_059_PS_I1_K.assign(Shape=None)
                    df_050_059_PS_I1_K  = df_050_059_PS_I1_K.assign(Carat=None)
                    df_050_059_PS_I1_K  = df_050_059_PS_I1_K.assign(Color=None)
                    df_050_059_PS_I1_K  = df_050_059_PS_I1_K.assign(Clarity=None)
                    df_050_059_PS_I1_K  = df_050_059_PS_I1_K.assign(Cut=None)
                    df_050_059_PS_I1_K  = df_050_059_PS_I1_K.assign(Polish=None)
                    df_050_059_PS_I1_K  = df_050_059_PS_I1_K.assign(Symmetry=None)
                    df_050_059_PS_I1_K  = df_050_059_PS_I1_K.assign(Ratio=None)
                    df_050_059_PS_I1_K  = df_050_059_PS_I1_K.assign(PPC=None)
                    df_050_059_PS_I1_K  = df_050_059_PS_I1_K.assign(Total=None)
                    df_050_059_PS_I1_K ['Wt Range'] = listwtrange
                    df_050_059_PS_I1_K ['Company'] = listcom
                    df_050_059_PS_I1_K ['Shape'] = listshap
                    df_050_059_PS_I1_K ['Carat'] = listcar
                    df_050_059_PS_I1_K ['Color'] = listcol
                    df_050_059_PS_I1_K ['Clarity'] = listclar
                    df_050_059_PS_I1_K ['Cut'] = listcut
                    df_050_059_PS_I1_K ['Polish'] = listpol
                    df_050_059_PS_I1_K ['Symmetry'] = listsym
                    df_050_059_PS_I1_K ['Ratio'] = listrat
                    df_050_059_PS_I1_K ['PPC'] = listdesc
                    df_050_059_PS_I1_K ['Total'] = listtotal
                    df_050_059_PS_I1_K['Carat'] = df_050_059_PS_I1_K['Carat'].astype('float64')
                    df_050_059_PS_I1_K['PPC'] = df_050_059_PS_I1_K['PPC'].astype('float64')
                    df_050_059_PS_I1_K['Total'] = df_050_059_PS_I1_K['Total'].astype('float64')
                    df_050_059_PS_I1_K['Total'] = df_050_059_PS_I1_K['Carat'] * df_050_059_PS_I1_K['PPC']


                elif i=="K" and j == "I2" and k == "PS":
                    df_050_059_PS_I2_K = pd.DataFrame()
                    df_050_059_PS_I2_K ['Wt Range'] = None
                    df_050_059_PS_I2_K  = df_050_059_PS_I2_K.assign(Company=None)
                    df_050_059_PS_I2_K  = df_050_059_PS_I2_K.assign(Shape=None)
                    df_050_059_PS_I2_K  = df_050_059_PS_I2_K.assign(Carat=None)
                    df_050_059_PS_I2_K  = df_050_059_PS_I2_K.assign(Color=None)
                    df_050_059_PS_I2_K  = df_050_059_PS_I2_K.assign(Clarity=None)
                    df_050_059_PS_I2_K  = df_050_059_PS_I2_K.assign(Cut=None)
                    df_050_059_PS_I2_K  = df_050_059_PS_I2_K.assign(Polish=None)
                    df_050_059_PS_I2_K  = df_050_059_PS_I2_K.assign(Symmetry=None)
                    df_050_059_PS_I2_K  = df_050_059_PS_I2_K.assign(Ratio=None)
                    df_050_059_PS_I2_K  = df_050_059_PS_I2_K.assign(PPC=None)
                    df_050_059_PS_I2_K  = df_050_059_PS_I2_K.assign(Total=None)
                    df_050_059_PS_I2_K ['Wt Range'] = listwtrange
                    df_050_059_PS_I2_K ['Company'] = listcom
                    df_050_059_PS_I2_K ['Shape'] = listshap
                    df_050_059_PS_I2_K ['Carat'] = listcar
                    df_050_059_PS_I2_K ['Color'] = listcol
                    df_050_059_PS_I2_K ['Clarity'] = listclar
                    df_050_059_PS_I2_K ['Cut'] = listcut
                    df_050_059_PS_I2_K ['Polish'] = listpol
                    df_050_059_PS_I2_K ['Symmetry'] = listsym
                    df_050_059_PS_I2_K ['Ratio'] = listrat
                    df_050_059_PS_I2_K ['PPC'] = listdesc
                    df_050_059_PS_I2_K ['Total'] = listtotal
                    df_050_059_PS_I2_K['Carat'] = df_050_059_PS_I2_K['Carat'].astype('float64')
                    df_050_059_PS_I2_K['PPC'] = df_050_059_PS_I2_K['PPC'].astype('float64')
                    df_050_059_PS_I2_K['Total'] = df_050_059_PS_I2_K['Total'].astype('float64')
                    df_050_059_PS_I2_K['Total'] = df_050_059_PS_I2_K['Carat'] * df_050_059_PS_I2_K['PPC']


                elif i=="L" and j == "IF" and k == "PS":
                    df_050_059_PS_IF_L = pd.DataFrame()
                    df_050_059_PS_IF_L ['Wt Range'] = None
                    df_050_059_PS_IF_L  = df_050_059_PS_IF_L.assign(Company=None)
                    df_050_059_PS_IF_L  = df_050_059_PS_IF_L.assign(Shape=None)
                    df_050_059_PS_IF_L  = df_050_059_PS_IF_L.assign(Carat=None)
                    df_050_059_PS_IF_L  = df_050_059_PS_IF_L.assign(Color=None)
                    df_050_059_PS_IF_L  = df_050_059_PS_IF_L.assign(Clarity=None)
                    df_050_059_PS_IF_L  = df_050_059_PS_IF_L.assign(Cut=None)
                    df_050_059_PS_IF_L  = df_050_059_PS_IF_L.assign(Polish=None)
                    df_050_059_PS_IF_L  = df_050_059_PS_IF_L.assign(Symmetry=None)
                    df_050_059_PS_IF_L  = df_050_059_PS_IF_L.assign(Ratio=None)
                    df_050_059_PS_IF_L  = df_050_059_PS_IF_L.assign(PPC=None)
                    df_050_059_PS_IF_L  = df_050_059_PS_IF_L.assign(Total=None)
                    df_050_059_PS_IF_L ['Wt Range'] = listwtrange
                    df_050_059_PS_IF_L ['Company'] = listcom
                    df_050_059_PS_IF_L ['Shape'] = listshap
                    df_050_059_PS_IF_L ['Carat'] = listcar
                    df_050_059_PS_IF_L ['Color'] = listcol
                    df_050_059_PS_IF_L ['Clarity'] = listclar
                    df_050_059_PS_IF_L ['Cut'] = listcut
                    df_050_059_PS_IF_L ['Polish'] = listpol
                    df_050_059_PS_IF_L ['Symmetry'] = listsym
                    df_050_059_PS_IF_L ['Ratio'] = listrat
                    df_050_059_PS_IF_L ['PPC'] = listdesc
                    df_050_059_PS_IF_L ['Total'] = listtotal
                    df_050_059_PS_IF_L['Carat'] = df_050_059_PS_IF_L['Carat'].astype('float64')
                    df_050_059_PS_IF_L['PPC'] = df_050_059_PS_IF_L['PPC'].astype('float64')
                    df_050_059_PS_IF_L['Total'] = df_050_059_PS_IF_L['Total'].astype('float64')
                    df_050_059_PS_IF_L['Total'] = df_050_059_PS_IF_L['Carat'] * df_050_059_PS_IF_L['PPC']


                elif i=="L" and j == "VVS1" and k == "PS":
                    df_050_059_PS_VVS1_L = pd.DataFrame()
                    df_050_059_PS_VVS1_L ['Wt Range'] = None
                    df_050_059_PS_VVS1_L  = df_050_059_PS_VVS1_L.assign(Company=None)
                    df_050_059_PS_VVS1_L  = df_050_059_PS_VVS1_L.assign(Shape=None)
                    df_050_059_PS_VVS1_L  = df_050_059_PS_VVS1_L.assign(Carat=None)
                    df_050_059_PS_VVS1_L  = df_050_059_PS_VVS1_L.assign(Color=None)
                    df_050_059_PS_VVS1_L  = df_050_059_PS_VVS1_L.assign(Clarity=None)
                    df_050_059_PS_VVS1_L  = df_050_059_PS_VVS1_L.assign(Cut=None)
                    df_050_059_PS_VVS1_L  = df_050_059_PS_VVS1_L.assign(Polish=None)
                    df_050_059_PS_VVS1_L  = df_050_059_PS_VVS1_L.assign(Symmetry=None)
                    df_050_059_PS_VVS1_L  = df_050_059_PS_VVS1_L.assign(Ratio=None)
                    df_050_059_PS_VVS1_L  = df_050_059_PS_VVS1_L.assign(PPC=None)
                    df_050_059_PS_VVS1_L  = df_050_059_PS_VVS1_L.assign(Total=None)
                    df_050_059_PS_VVS1_L ['Wt Range'] = listwtrange
                    df_050_059_PS_VVS1_L ['Company'] = listcom
                    df_050_059_PS_VVS1_L ['Shape'] = listshap
                    df_050_059_PS_VVS1_L ['Carat'] = listcar
                    df_050_059_PS_VVS1_L ['Color'] = listcol
                    df_050_059_PS_VVS1_L ['Clarity'] = listclar
                    df_050_059_PS_VVS1_L ['Cut'] = listcut
                    df_050_059_PS_VVS1_L ['Polish'] = listpol
                    df_050_059_PS_VVS1_L ['Symmetry'] = listsym
                    df_050_059_PS_VVS1_L ['Ratio'] = listrat
                    df_050_059_PS_VVS1_L ['PPC'] = listdesc
                    df_050_059_PS_VVS1_L ['Total'] = listtotal
                    df_050_059_PS_VVS1_L['Carat'] = df_050_059_PS_VVS1_L['Carat'].astype('float64')
                    df_050_059_PS_VVS1_L['PPC'] = df_050_059_PS_VVS1_L['PPC'].astype('float64')
                    df_050_059_PS_VVS1_L['Total'] = df_050_059_PS_VVS1_L['Total'].astype('float64')
                    df_050_059_PS_VVS1_L['Total'] = df_050_059_PS_VVS1_L['Carat'] * df_050_059_PS_VVS1_L['PPC']


                elif i=="L" and j == "VVS2" and k == "PS":
                    df_050_059_PS_VVS2_L = pd.DataFrame()
                    df_050_059_PS_VVS2_L ['Wt Range'] = None
                    df_050_059_PS_VVS2_L  = df_050_059_PS_VVS2_L.assign(Company=None)
                    df_050_059_PS_VVS2_L  = df_050_059_PS_VVS2_L.assign(Shape=None)
                    df_050_059_PS_VVS2_L  = df_050_059_PS_VVS2_L.assign(Carat=None)
                    df_050_059_PS_VVS2_L  = df_050_059_PS_VVS2_L.assign(Color=None)
                    df_050_059_PS_VVS2_L  = df_050_059_PS_VVS2_L.assign(Clarity=None)
                    df_050_059_PS_VVS2_L  = df_050_059_PS_VVS2_L.assign(Cut=None)
                    df_050_059_PS_VVS2_L  = df_050_059_PS_VVS2_L.assign(Polish=None)
                    df_050_059_PS_VVS2_L  = df_050_059_PS_VVS2_L.assign(Symmetry=None)
                    df_050_059_PS_VVS2_L  = df_050_059_PS_VVS2_L.assign(Ratio=None)
                    df_050_059_PS_VVS2_L  = df_050_059_PS_VVS2_L.assign(PPC=None)
                    df_050_059_PS_VVS2_L  = df_050_059_PS_VVS2_L.assign(Total=None)
                    df_050_059_PS_VVS2_L ['Wt Range'] = listwtrange
                    df_050_059_PS_VVS2_L ['Company'] = listcom
                    df_050_059_PS_VVS2_L ['Shape'] = listshap
                    df_050_059_PS_VVS2_L ['Carat'] = listcar
                    df_050_059_PS_VVS2_L ['Color'] = listcol
                    df_050_059_PS_VVS2_L ['Clarity'] = listclar
                    df_050_059_PS_VVS2_L ['Cut'] = listcut
                    df_050_059_PS_VVS2_L ['Polish'] = listpol
                    df_050_059_PS_VVS2_L ['Symmetry'] = listsym
                    df_050_059_PS_VVS2_L ['Ratio'] = listrat
                    df_050_059_PS_VVS2_L ['PPC'] = listdesc
                    df_050_059_PS_VVS2_L ['Total'] = listtotal
                    df_050_059_PS_VVS2_L['Carat'] = df_050_059_PS_VVS2_L['Carat'].astype('float64')
                    df_050_059_PS_VVS2_L['PPC'] = df_050_059_PS_VVS2_L['PPC'].astype('float64')
                    df_050_059_PS_VVS2_L['Total'] = df_050_059_PS_VVS2_L['Total'].astype('float64')
                    df_050_059_PS_VVS2_L['Total'] = df_050_059_PS_VVS2_L['Carat'] * df_050_059_PS_VVS2_L['PPC']


                elif i=="L" and j=="VS1" and k == "PS":
                    df_050_059_PS_VS1_L = pd.DataFrame()
                    df_050_059_PS_VS1_L ['Wt Range'] = None
                    df_050_059_PS_VS1_L  = df_050_059_PS_VS1_L.assign(Company=None)
                    df_050_059_PS_VS1_L  = df_050_059_PS_VS1_L.assign(Shape=None)
                    df_050_059_PS_VS1_L  = df_050_059_PS_VS1_L.assign(Carat=None)
                    df_050_059_PS_VS1_L  = df_050_059_PS_VS1_L.assign(Color=None)
                    df_050_059_PS_VS1_L  = df_050_059_PS_VS1_L.assign(Clarity=None)
                    df_050_059_PS_VS1_L  = df_050_059_PS_VS1_L.assign(Cut=None)
                    df_050_059_PS_VS1_L  = df_050_059_PS_VS1_L.assign(Polish=None)
                    df_050_059_PS_VS1_L  = df_050_059_PS_VS1_L.assign(Symmetry=None)
                    df_050_059_PS_VS1_L  = df_050_059_PS_VS1_L.assign(Ratio=None)
                    df_050_059_PS_VS1_L  = df_050_059_PS_VS1_L.assign(PPC=None)
                    df_050_059_PS_VS1_L  = df_050_059_PS_VS1_L.assign(Total=None)
                    df_050_059_PS_VS1_L ['Wt Range'] = listwtrange
                    df_050_059_PS_VS1_L ['Company'] = listcom
                    df_050_059_PS_VS1_L ['Shape'] = listshap
                    df_050_059_PS_VS1_L ['Carat'] = listcar
                    df_050_059_PS_VS1_L ['Color'] = listcol
                    df_050_059_PS_VS1_L ['Clarity'] = listclar
                    df_050_059_PS_VS1_L ['Cut'] = listcut
                    df_050_059_PS_VS1_L ['Polish'] = listpol
                    df_050_059_PS_VS1_L ['Symmetry'] = listsym
                    df_050_059_PS_VS1_L ['Ratio'] = listrat
                    df_050_059_PS_VS1_L ['PPC'] = listdesc
                    df_050_059_PS_VS1_L ['Total'] = listtotal
                    df_050_059_PS_VS1_L['Carat'] = df_050_059_PS_VS1_L['Carat'].astype('float64')
                    df_050_059_PS_VS1_L['PPC'] = df_050_059_PS_VS1_L['PPC'].astype('float64')
                    df_050_059_PS_VS1_L['Total'] = df_050_059_PS_VS1_L['Total'].astype('float64')
                    df_050_059_PS_VS1_L['Total'] = df_050_059_PS_VS1_L['Carat'] * df_050_059_PS_VS1_L['PPC']


                elif i=="L" and j == "VS2" and k == "PS":
                    df_050_059_PS_VS2_L = pd.DataFrame()
                    df_050_059_PS_VS2_L ['Wt Range'] = None
                    df_050_059_PS_VS2_L  = df_050_059_PS_VS2_L.assign(Company=None)
                    df_050_059_PS_VS2_L  = df_050_059_PS_VS2_L.assign(Shape=None)
                    df_050_059_PS_VS2_L  = df_050_059_PS_VS2_L.assign(Carat=None)
                    df_050_059_PS_VS2_L  = df_050_059_PS_VS2_L.assign(Color=None)
                    df_050_059_PS_VS2_L  = df_050_059_PS_VS2_L.assign(Clarity=None)
                    df_050_059_PS_VS2_L  = df_050_059_PS_VS2_L.assign(Cut=None)
                    df_050_059_PS_VS2_L  = df_050_059_PS_VS2_L.assign(Polish=None)
                    df_050_059_PS_VS2_L  = df_050_059_PS_VS2_L.assign(Symmetry=None)
                    df_050_059_PS_VS2_L  = df_050_059_PS_VS2_L.assign(Ratio=None)
                    df_050_059_PS_VS2_L  = df_050_059_PS_VS2_L.assign(PPC=None)
                    df_050_059_PS_VS2_L  = df_050_059_PS_VS2_L.assign(Total=None)
                    df_050_059_PS_VS2_L ['Wt Range'] = listwtrange
                    df_050_059_PS_VS2_L ['Company'] = listcom
                    df_050_059_PS_VS2_L ['Shape'] = listshap
                    df_050_059_PS_VS2_L ['Carat'] = listcar
                    df_050_059_PS_VS2_L ['Color'] = listcol
                    df_050_059_PS_VS2_L ['Clarity'] = listclar
                    df_050_059_PS_VS2_L ['Cut'] = listcut
                    df_050_059_PS_VS2_L ['Polish'] = listpol
                    df_050_059_PS_VS2_L ['Symmetry'] = listsym
                    df_050_059_PS_VS2_L ['Ratio'] = listrat
                    df_050_059_PS_VS2_L ['PPC'] = listdesc
                    df_050_059_PS_VS2_L ['Total'] = listtotal
                    df_050_059_PS_VS2_L['Carat'] = df_050_059_PS_VS2_L['Carat'].astype('float64')
                    df_050_059_PS_VS2_L['PPC'] = df_050_059_PS_VS2_L['PPC'].astype('float64')
                    df_050_059_PS_VS2_L['Total'] = df_050_059_PS_VS2_L['Total'].astype('float64')
                    df_050_059_PS_VS2_L['Total'] = df_050_059_PS_VS2_L['Carat'] * df_050_059_PS_VS2_L['PPC']


                elif i=="L" and j == "SI1" and k == "PS":
                    df_050_059_PS_SI1_L = pd.DataFrame()
                    df_050_059_PS_SI1_L ['Wt Range'] = None
                    df_050_059_PS_SI1_L  = df_050_059_PS_SI1_L.assign(Company=None)
                    df_050_059_PS_SI1_L  = df_050_059_PS_SI1_L.assign(Shape=None)
                    df_050_059_PS_SI1_L  = df_050_059_PS_SI1_L.assign(Carat=None)
                    df_050_059_PS_SI1_L  = df_050_059_PS_SI1_L.assign(Color=None)
                    df_050_059_PS_SI1_L  = df_050_059_PS_SI1_L.assign(Clarity=None)
                    df_050_059_PS_SI1_L  = df_050_059_PS_SI1_L.assign(Cut=None)
                    df_050_059_PS_SI1_L  = df_050_059_PS_SI1_L.assign(Polish=None)
                    df_050_059_PS_SI1_L  = df_050_059_PS_SI1_L.assign(Symmetry=None)
                    df_050_059_PS_SI1_L  = df_050_059_PS_SI1_L.assign(Ratio=None)
                    df_050_059_PS_SI1_L  = df_050_059_PS_SI1_L.assign(PPC=None)
                    df_050_059_PS_SI1_L  = df_050_059_PS_SI1_L.assign(Total=None)
                    df_050_059_PS_SI1_L ['Wt Range'] = listwtrange
                    df_050_059_PS_SI1_L ['Company'] = listcom
                    df_050_059_PS_SI1_L ['Shape'] = listshap
                    df_050_059_PS_SI1_L ['Carat'] = listcar
                    df_050_059_PS_SI1_L ['Color'] = listcol
                    df_050_059_PS_SI1_L ['Clarity'] = listclar
                    df_050_059_PS_SI1_L ['Cut'] = listcut
                    df_050_059_PS_SI1_L ['Polish'] = listpol
                    df_050_059_PS_SI1_L ['Symmetry'] = listsym
                    df_050_059_PS_SI1_L ['Ratio'] = listrat
                    df_050_059_PS_SI1_L ['PPC'] = listdesc
                    df_050_059_PS_SI1_L ['Total'] = listtotal
                    df_050_059_PS_SI1_L['Carat'] = df_050_059_PS_SI1_L['Carat'].astype('float64')
                    df_050_059_PS_SI1_L['PPC'] = df_050_059_PS_SI1_L['PPC'].astype('float64')
                    df_050_059_PS_SI1_L['Total'] = df_050_059_PS_SI1_L['Total'].astype('float64')
                    df_050_059_PS_SI1_L['Total'] = df_050_059_PS_SI1_L['Carat'] * df_050_059_PS_SI1_L['PPC']


                elif i=="L" and j == "SI2" and k == "PS":
                    df_050_059_PS_SI2_L = pd.DataFrame()
                    df_050_059_PS_SI2_L ['Wt Range'] = None
                    df_050_059_PS_SI2_L  = df_050_059_PS_SI2_L.assign(Company=None)
                    df_050_059_PS_SI2_L  = df_050_059_PS_SI2_L.assign(Shape=None)
                    df_050_059_PS_SI2_L  = df_050_059_PS_SI2_L.assign(Carat=None)
                    df_050_059_PS_SI2_L  = df_050_059_PS_SI2_L.assign(Color=None)
                    df_050_059_PS_SI2_L  = df_050_059_PS_SI2_L.assign(Clarity=None)
                    df_050_059_PS_SI2_L  = df_050_059_PS_SI2_L.assign(Cut=None)
                    df_050_059_PS_SI2_L  = df_050_059_PS_SI2_L.assign(Polish=None)
                    df_050_059_PS_SI2_L  = df_050_059_PS_SI2_L.assign(Symmetry=None)
                    df_050_059_PS_SI2_L  = df_050_059_PS_SI2_L.assign(Ratio=None)
                    df_050_059_PS_SI2_L  = df_050_059_PS_SI2_L.assign(PPC=None)
                    df_050_059_PS_SI2_L  = df_050_059_PS_SI2_L.assign(Total=None)
                    df_050_059_PS_SI2_L ['Wt Range'] = listwtrange
                    df_050_059_PS_SI2_L ['Company'] = listcom
                    df_050_059_PS_SI2_L ['Shape'] = listshap
                    df_050_059_PS_SI2_L ['Carat'] = listcar
                    df_050_059_PS_SI2_L ['Color'] = listcol
                    df_050_059_PS_SI2_L ['Clarity'] = listclar
                    df_050_059_PS_SI2_L ['Cut'] = listcut
                    df_050_059_PS_SI2_L ['Polish'] = listpol
                    df_050_059_PS_SI2_L ['Symmetry'] = listsym
                    df_050_059_PS_SI2_L ['Ratio'] = listrat
                    df_050_059_PS_SI2_L ['PPC'] = listdesc
                    df_050_059_PS_SI2_L ['Total'] = listtotal
                    df_050_059_PS_SI2_L['Carat'] = df_050_059_PS_SI2_L['Carat'].astype('float64')
                    df_050_059_PS_SI2_L['PPC'] = df_050_059_PS_SI2_L['PPC'].astype('float64')
                    df_050_059_PS_SI2_L['Total'] = df_050_059_PS_SI2_L['Total'].astype('float64')
                    df_050_059_PS_SI2_L['Total'] = df_050_059_PS_SI2_L['Carat'] * df_050_059_PS_SI2_L['PPC']


                elif i=="L" and j == "I1" and k == "PS":
                    df_050_059_PS_I1_L = pd.DataFrame()
                    df_050_059_PS_I1_L ['Wt Range'] = None
                    df_050_059_PS_I1_L  = df_050_059_PS_I1_L.assign(Company=None)
                    df_050_059_PS_I1_L  = df_050_059_PS_I1_L.assign(Shape=None)
                    df_050_059_PS_I1_L  = df_050_059_PS_I1_L.assign(Carat=None)
                    df_050_059_PS_I1_L  = df_050_059_PS_I1_L.assign(Color=None)
                    df_050_059_PS_I1_L  = df_050_059_PS_I1_L.assign(Clarity=None)
                    df_050_059_PS_I1_L  = df_050_059_PS_I1_L.assign(Cut=None)
                    df_050_059_PS_I1_L  = df_050_059_PS_I1_L.assign(Polish=None)
                    df_050_059_PS_I1_L  = df_050_059_PS_I1_L.assign(Symmetry=None)
                    df_050_059_PS_I1_L  = df_050_059_PS_I1_L.assign(Ratio=None)
                    df_050_059_PS_I1_L  = df_050_059_PS_I1_L.assign(PPC=None)
                    df_050_059_PS_I1_L  = df_050_059_PS_I1_L.assign(Total=None)
                    df_050_059_PS_I1_L ['Wt Range'] = listwtrange
                    df_050_059_PS_I1_L ['Company'] = listcom
                    df_050_059_PS_I1_L ['Shape'] = listshap
                    df_050_059_PS_I1_L ['Carat'] = listcar
                    df_050_059_PS_I1_L ['Color'] = listcol
                    df_050_059_PS_I1_L ['Clarity'] = listclar
                    df_050_059_PS_I1_L ['Cut'] = listcut
                    df_050_059_PS_I1_L ['Polish'] = listpol
                    df_050_059_PS_I1_L ['Symmetry'] = listsym
                    df_050_059_PS_I1_L ['Ratio'] = listrat
                    df_050_059_PS_I1_L ['PPC'] = listdesc
                    df_050_059_PS_I1_L ['Total'] = listtotal
                    df_050_059_PS_I1_L['Carat'] = df_050_059_PS_I1_L['Carat'].astype('float64')
                    df_050_059_PS_I1_L['PPC'] = df_050_059_PS_I1_L['PPC'].astype('float64')
                    df_050_059_PS_I1_L['Total'] = df_050_059_PS_I1_L['Total'].astype('float64')
                    df_050_059_PS_I1_L['Total'] = df_050_059_PS_I1_L['Carat'] * df_050_059_PS_I1_L['PPC']


                elif i=="L" and j == "I2" and k == "PS":
                    df_050_059_PS_I2_L = pd.DataFrame()
                    df_050_059_PS_I2_L ['Wt Range'] = None
                    df_050_059_PS_I2_L  = df_050_059_PS_I2_L.assign(Company=None)
                    df_050_059_PS_I2_L  = df_050_059_PS_I2_L.assign(Shape=None)
                    df_050_059_PS_I2_L  = df_050_059_PS_I2_L.assign(Carat=None)
                    df_050_059_PS_I2_L  = df_050_059_PS_I2_L.assign(Color=None)
                    df_050_059_PS_I2_L  = df_050_059_PS_I2_L.assign(Clarity=None)
                    df_050_059_PS_I2_L  = df_050_059_PS_I2_L.assign(Cut=None)
                    df_050_059_PS_I2_L  = df_050_059_PS_I2_L.assign(Polish=None)
                    df_050_059_PS_I2_L  = df_050_059_PS_I2_L.assign(Symmetry=None)
                    df_050_059_PS_I2_L  = df_050_059_PS_I2_L.assign(Ratio=None)
                    df_050_059_PS_I2_L  = df_050_059_PS_I2_L.assign(PPC=None)
                    df_050_059_PS_I2_L  = df_050_059_PS_I2_L.assign(Total=None)
                    df_050_059_PS_I2_L ['Wt Range'] = listwtrange
                    df_050_059_PS_I2_L ['Company'] = listcom
                    df_050_059_PS_I2_L ['Shape'] = listshap
                    df_050_059_PS_I2_L ['Carat'] = listcar
                    df_050_059_PS_I2_L ['Color'] = listcol
                    df_050_059_PS_I2_L ['Clarity'] = listclar
                    df_050_059_PS_I2_L ['Cut'] = listcut
                    df_050_059_PS_I2_L ['Polish'] = listpol
                    df_050_059_PS_I2_L ['Symmetry'] = listsym
                    df_050_059_PS_I2_L ['Ratio'] = listrat
                    df_050_059_PS_I2_L ['PPC'] = listdesc
                    df_050_059_PS_I2_L ['Total'] = listtotal
                    df_050_059_PS_I2_L['Carat'] = df_050_059_PS_I2_L['Carat'].astype('float64')
                    df_050_059_PS_I2_L['PPC'] = df_050_059_PS_I2_L['PPC'].astype('float64')
                    df_050_059_PS_I2_L['Total'] = df_050_059_PS_I2_L['Total'].astype('float64')
                    df_050_059_PS_I2_L['Total'] = df_050_059_PS_I2_L['Carat'] * df_050_059_PS_I2_L['PPC']

                    
                elif i=="D" and j == "IF" and k == "RAD":
                    df_050_059_RAD_IF_D = pd.DataFrame()
                    df_050_059_RAD_IF_D ['Wt Range'] = None
                    df_050_059_RAD_IF_D  = df_050_059_RAD_IF_D.assign(Company=None)
                    df_050_059_RAD_IF_D  = df_050_059_RAD_IF_D.assign(Shape=None)
                    df_050_059_RAD_IF_D  = df_050_059_RAD_IF_D.assign(Carat=None)
                    df_050_059_RAD_IF_D  = df_050_059_RAD_IF_D.assign(Color=None)
                    df_050_059_RAD_IF_D  = df_050_059_RAD_IF_D.assign(Clarity=None)
                    df_050_059_RAD_IF_D  = df_050_059_RAD_IF_D.assign(Cut=None)
                    df_050_059_RAD_IF_D  = df_050_059_RAD_IF_D.assign(Polish=None)
                    df_050_059_RAD_IF_D  = df_050_059_RAD_IF_D.assign(Symmetry=None)
                    df_050_059_RAD_IF_D  = df_050_059_RAD_IF_D.assign(Ratio=None)
                    df_050_059_RAD_IF_D  = df_050_059_RAD_IF_D.assign(PPC=None)
                    df_050_059_RAD_IF_D  = df_050_059_RAD_IF_D.assign(Total=None)
                    df_050_059_RAD_IF_D ['Wt Range'] = listwtrange
                    df_050_059_RAD_IF_D ['Company'] = listcom
                    df_050_059_RAD_IF_D ['Shape'] = listshap
                    df_050_059_RAD_IF_D ['Carat'] = listcar
                    df_050_059_RAD_IF_D ['Color'] = listcol
                    df_050_059_RAD_IF_D ['Clarity'] = listclar
                    df_050_059_RAD_IF_D ['Cut'] = listcut
                    df_050_059_RAD_IF_D ['Polish'] = listpol
                    df_050_059_RAD_IF_D ['Symmetry'] = listsym
                    df_050_059_RAD_IF_D ['Ratio'] = listrat
                    df_050_059_RAD_IF_D ['PPC'] = listdesc
                    df_050_059_RAD_IF_D ['Total'] = listtotal
                    df_050_059_RAD_IF_D['Carat'] = df_050_059_RAD_IF_D['Carat'].astype('float64')
                    df_050_059_RAD_IF_D['PPC'] = df_050_059_RAD_IF_D['PPC'].astype('float64')
                    df_050_059_RAD_IF_D['Total'] = df_050_059_RAD_IF_D['Total'].astype('float64')
                    df_050_059_RAD_IF_D['Total'] = df_050_059_RAD_IF_D['Carat'] * df_050_059_RAD_IF_D['PPC']



                elif i=="D" and j == "VVS1" and k == "RAD" :
                    df_050_059_RAD_VVS1_D = pd.DataFrame()
                    df_050_059_RAD_VVS1_D ['Wt Range'] = None
                    df_050_059_RAD_VVS1_D  = df_050_059_RAD_VVS1_D.assign(Company=None)
                    df_050_059_RAD_VVS1_D  = df_050_059_RAD_VVS1_D.assign(Shape=None)
                    df_050_059_RAD_VVS1_D  = df_050_059_RAD_VVS1_D.assign(Carat=None)
                    df_050_059_RAD_VVS1_D  = df_050_059_RAD_VVS1_D.assign(Color=None)
                    df_050_059_RAD_VVS1_D  = df_050_059_RAD_VVS1_D.assign(Clarity=None)
                    df_050_059_RAD_VVS1_D  = df_050_059_RAD_VVS1_D.assign(Cut=None)
                    df_050_059_RAD_VVS1_D  = df_050_059_RAD_VVS1_D.assign(Polish=None)
                    df_050_059_RAD_VVS1_D  = df_050_059_RAD_VVS1_D.assign(Symmetry=None)
                    df_050_059_RAD_VVS1_D  = df_050_059_RAD_VVS1_D.assign(Ratio=None)
                    df_050_059_RAD_VVS1_D  = df_050_059_RAD_VVS1_D.assign(PPC=None)
                    df_050_059_RAD_VVS1_D  = df_050_059_RAD_VVS1_D.assign(Total=None)
                    df_050_059_RAD_VVS1_D ['Wt Range'] = listwtrange
                    df_050_059_RAD_VVS1_D ['Company'] = listcom
                    df_050_059_RAD_VVS1_D ['Shape'] = listshap
                    df_050_059_RAD_VVS1_D ['Carat'] = listcar
                    df_050_059_RAD_VVS1_D ['Color'] = listcol
                    df_050_059_RAD_VVS1_D ['Clarity'] = listclar
                    df_050_059_RAD_VVS1_D ['Cut'] = listcut
                    df_050_059_RAD_VVS1_D ['Polish'] = listpol
                    df_050_059_RAD_VVS1_D ['Symmetry'] = listsym
                    df_050_059_RAD_VVS1_D ['Ratio'] = listrat
                    df_050_059_RAD_VVS1_D ['PPC'] = listdesc
                    df_050_059_RAD_VVS1_D ['Total'] = listtotal
                    df_050_059_RAD_VVS1_D['Carat'] = df_050_059_RAD_VVS1_D['Carat'].astype('float64')
                    df_050_059_RAD_VVS1_D['PPC'] = df_050_059_RAD_VVS1_D['PPC'].astype('float64')
                    df_050_059_RAD_VVS1_D['Total'] = df_050_059_RAD_VVS1_D['Total'].astype('float64')
                    df_050_059_RAD_VVS1_D['Total'] = df_050_059_RAD_VVS1_D['Carat'] * df_050_059_RAD_VVS1_D['PPC']



                elif i=="D" and j == "VVS2" and k == "RAD" :
                    df_050_059_RAD_VVS2_D = pd.DataFrame()
                    df_050_059_RAD_VVS2_D ['Wt Range'] = None
                    df_050_059_RAD_VVS2_D  = df_050_059_RAD_VVS2_D.assign(Company=None)
                    df_050_059_RAD_VVS2_D  = df_050_059_RAD_VVS2_D.assign(Shape=None)
                    df_050_059_RAD_VVS2_D  = df_050_059_RAD_VVS2_D.assign(Carat=None)
                    df_050_059_RAD_VVS2_D  = df_050_059_RAD_VVS2_D.assign(Color=None)
                    df_050_059_RAD_VVS2_D  = df_050_059_RAD_VVS2_D.assign(Clarity=None)
                    df_050_059_RAD_VVS2_D  = df_050_059_RAD_VVS2_D.assign(Cut=None)
                    df_050_059_RAD_VVS2_D  = df_050_059_RAD_VVS2_D.assign(Polish=None)
                    df_050_059_RAD_VVS2_D  = df_050_059_RAD_VVS2_D.assign(Symmetry=None)
                    df_050_059_RAD_VVS2_D  = df_050_059_RAD_VVS2_D.assign(Ratio=None)
                    df_050_059_RAD_VVS2_D  = df_050_059_RAD_VVS2_D.assign(PPC=None)
                    df_050_059_RAD_VVS2_D  = df_050_059_RAD_VVS2_D.assign(Total=None)
                    df_050_059_RAD_VVS2_D ['Wt Range'] = listwtrange
                    df_050_059_RAD_VVS2_D ['Company'] = listcom
                    df_050_059_RAD_VVS2_D ['Shape'] = listshap
                    df_050_059_RAD_VVS2_D ['Carat'] = listcar
                    df_050_059_RAD_VVS2_D ['Color'] = listcol
                    df_050_059_RAD_VVS2_D ['Clarity'] = listclar
                    df_050_059_RAD_VVS2_D ['Cut'] = listcut
                    df_050_059_RAD_VVS2_D ['Polish'] = listpol
                    df_050_059_RAD_VVS2_D ['Symmetry'] = listsym
                    df_050_059_RAD_VVS2_D ['Ratio'] = listrat
                    df_050_059_RAD_VVS2_D ['PPC'] = listdesc
                    df_050_059_RAD_VVS2_D ['Total'] = listtotal
                    df_050_059_RAD_VVS2_D['Carat'] = df_050_059_RAD_VVS2_D['Carat'].astype('float64')
                    df_050_059_RAD_VVS2_D['PPC'] = df_050_059_RAD_VVS2_D['PPC'].astype('float64')
                    df_050_059_RAD_VVS2_D['Total'] = df_050_059_RAD_VVS2_D['Total'].astype('float64')
                    df_050_059_RAD_VVS2_D['Total'] = df_050_059_RAD_VVS2_D['Carat'] * df_050_059_RAD_VVS2_D['PPC']



                elif i=="D" and j == "VS1" and k == "RAD":
                    df_050_059_RAD_VS1_D = pd.DataFrame()
                    df_050_059_RAD_VS1_D ['Wt Range'] = None
                    df_050_059_RAD_VS1_D  = df_050_059_RAD_VS1_D.assign(Company=None)
                    df_050_059_RAD_VS1_D  = df_050_059_RAD_VS1_D.assign(Shape=None)
                    df_050_059_RAD_VS1_D  = df_050_059_RAD_VS1_D.assign(Carat=None)
                    df_050_059_RAD_VS1_D  = df_050_059_RAD_VS1_D.assign(Color=None)
                    df_050_059_RAD_VS1_D  = df_050_059_RAD_VS1_D.assign(Clarity=None)
                    df_050_059_RAD_VS1_D  = df_050_059_RAD_VS1_D.assign(Cut=None)
                    df_050_059_RAD_VS1_D  = df_050_059_RAD_VS1_D.assign(Polish=None)
                    df_050_059_RAD_VS1_D  = df_050_059_RAD_VS1_D.assign(Symmetry=None)
                    df_050_059_RAD_VS1_D  = df_050_059_RAD_VS1_D.assign(Ratio=None)
                    df_050_059_RAD_VS1_D  = df_050_059_RAD_VS1_D.assign(PPC=None)
                    df_050_059_RAD_VS1_D  = df_050_059_RAD_VS1_D.assign(Total=None)
                    df_050_059_RAD_VS1_D ['Wt Range'] = listwtrange
                    df_050_059_RAD_VS1_D ['Company'] = listcom
                    df_050_059_RAD_VS1_D ['Shape'] = listshap
                    df_050_059_RAD_VS1_D ['Carat'] = listcar
                    df_050_059_RAD_VS1_D ['Color'] = listcol
                    df_050_059_RAD_VS1_D ['Clarity'] = listclar
                    df_050_059_RAD_VS1_D ['Cut'] = listcut
                    df_050_059_RAD_VS1_D ['Polish'] = listpol
                    df_050_059_RAD_VS1_D ['Symmetry'] = listsym
                    df_050_059_RAD_VS1_D ['Ratio'] = listrat
                    df_050_059_RAD_VS1_D ['PPC'] = listdesc
                    df_050_059_RAD_VS1_D ['Total'] = listtotal
                    df_050_059_RAD_VS1_D['Carat'] = df_050_059_RAD_VS1_D['Carat'].astype('float64')
                    df_050_059_RAD_VS1_D['PPC'] = df_050_059_RAD_VS1_D['PPC'].astype('float64')
                    df_050_059_RAD_VS1_D['Total'] = df_050_059_RAD_VS1_D['Total'].astype('float64')
                    df_050_059_RAD_VS1_D['Total'] = df_050_059_RAD_VS1_D['Carat'] * df_050_059_RAD_VS1_D['PPC']


                elif i=="D" and j == "VS2" and k == "RAD":
                    df_050_059_RAD_VS2_D = pd.DataFrame()
                    df_050_059_RAD_VS2_D ['Wt Range'] = None
                    df_050_059_RAD_VS2_D  = df_050_059_RAD_VS2_D.assign(Company=None)
                    df_050_059_RAD_VS2_D  = df_050_059_RAD_VS2_D.assign(Shape=None)
                    df_050_059_RAD_VS2_D  = df_050_059_RAD_VS2_D.assign(Carat=None)
                    df_050_059_RAD_VS2_D  = df_050_059_RAD_VS2_D.assign(Color=None)
                    df_050_059_RAD_VS2_D  = df_050_059_RAD_VS2_D.assign(Clarity=None)
                    df_050_059_RAD_VS2_D  = df_050_059_RAD_VS2_D.assign(Cut=None)
                    df_050_059_RAD_VS2_D  = df_050_059_RAD_VS2_D.assign(Polish=None)
                    df_050_059_RAD_VS2_D  = df_050_059_RAD_VS2_D.assign(Symmetry=None)
                    df_050_059_RAD_VS2_D  = df_050_059_RAD_VS2_D.assign(Ratio=None)
                    df_050_059_RAD_VS2_D  = df_050_059_RAD_VS2_D.assign(PPC=None)
                    df_050_059_RAD_VS2_D  = df_050_059_RAD_VS2_D.assign(Total=None)
                    df_050_059_RAD_VS2_D ['Wt Range'] = listwtrange
                    df_050_059_RAD_VS2_D ['Company'] = listcom
                    df_050_059_RAD_VS2_D ['Shape'] = listshap
                    df_050_059_RAD_VS2_D ['Carat'] = listcar
                    df_050_059_RAD_VS2_D ['Color'] = listcol
                    df_050_059_RAD_VS2_D ['Clarity'] = listclar
                    df_050_059_RAD_VS2_D ['Cut'] = listcut
                    df_050_059_RAD_VS2_D ['Polish'] = listpol
                    df_050_059_RAD_VS2_D ['Symmetry'] = listsym
                    df_050_059_RAD_VS2_D ['Ratio'] = listrat
                    df_050_059_RAD_VS2_D ['PPC'] = listdesc
                    df_050_059_RAD_VS2_D ['Total'] = listtotal
                    df_050_059_RAD_VS2_D['Carat'] = df_050_059_RAD_VS2_D['Carat'].astype('float64')
                    df_050_059_RAD_VS2_D['PPC'] = df_050_059_RAD_VS2_D['PPC'].astype('float64')
                    df_050_059_RAD_VS2_D['Total'] = df_050_059_RAD_VS2_D['Total'].astype('float64')
                    df_050_059_RAD_VS2_D['Total'] = df_050_059_RAD_VS2_D['Carat'] * df_050_059_RAD_VS2_D['PPC']


                elif i=="D" and j == "SI1" and k == "RAD":
                    df_050_059_RAD_SI1_D = pd.DataFrame()
                    df_050_059_RAD_SI1_D ['Wt Range'] = None
                    df_050_059_RAD_SI1_D  = df_050_059_RAD_SI1_D.assign(Company=None)
                    df_050_059_RAD_SI1_D  = df_050_059_RAD_SI1_D.assign(Shape=None)
                    df_050_059_RAD_SI1_D  = df_050_059_RAD_SI1_D.assign(Carat=None)
                    df_050_059_RAD_SI1_D  = df_050_059_RAD_SI1_D.assign(Color=None)
                    df_050_059_RAD_SI1_D  = df_050_059_RAD_SI1_D.assign(Clarity=None)
                    df_050_059_RAD_SI1_D  = df_050_059_RAD_SI1_D.assign(Cut=None)
                    df_050_059_RAD_SI1_D  = df_050_059_RAD_SI1_D.assign(Polish=None)
                    df_050_059_RAD_SI1_D  = df_050_059_RAD_SI1_D.assign(Symmetry=None)
                    df_050_059_RAD_SI1_D  = df_050_059_RAD_SI1_D.assign(Ratio=None)
                    df_050_059_RAD_SI1_D  = df_050_059_RAD_SI1_D.assign(PPC=None)
                    df_050_059_RAD_SI1_D  = df_050_059_RAD_SI1_D.assign(Total=None)
                    df_050_059_RAD_SI1_D ['Wt Range'] = listwtrange
                    df_050_059_RAD_SI1_D ['Company'] = listcom
                    df_050_059_RAD_SI1_D ['Shape'] = listshap
                    df_050_059_RAD_SI1_D ['Carat'] = listcar
                    df_050_059_RAD_SI1_D ['Color'] = listcol
                    df_050_059_RAD_SI1_D ['Clarity'] = listclar
                    df_050_059_RAD_SI1_D ['Cut'] = listcut
                    df_050_059_RAD_SI1_D ['Polish'] = listpol
                    df_050_059_RAD_SI1_D ['Symmetry'] = listsym
                    df_050_059_RAD_SI1_D ['Ratio'] = listrat
                    df_050_059_RAD_SI1_D ['PPC'] = listdesc
                    df_050_059_RAD_SI1_D ['Total'] = listtotal
                    df_050_059_RAD_SI1_D['Carat'] = df_050_059_RAD_SI1_D['Carat'].astype('float64')
                    df_050_059_RAD_SI1_D['PPC'] = df_050_059_RAD_SI1_D['PPC'].astype('float64')
                    df_050_059_RAD_SI1_D['Total'] = df_050_059_RAD_SI1_D['Total'].astype('float64')
                    df_050_059_RAD_SI1_D['Total'] = df_050_059_RAD_SI1_D['Carat'] * df_050_059_RAD_SI1_D['PPC']


                elif i=="D" and j == "SI2" and k == "RAD":
                    df_050_059_RAD_SI2_D = pd.DataFrame()
                    df_050_059_RAD_SI2_D ['Wt Range'] = None
                    df_050_059_RAD_SI2_D  = df_050_059_RAD_SI2_D.assign(Company=None)
                    df_050_059_RAD_SI2_D  = df_050_059_RAD_SI2_D.assign(Shape=None)
                    df_050_059_RAD_SI2_D  = df_050_059_RAD_SI2_D.assign(Carat=None)
                    df_050_059_RAD_SI2_D  = df_050_059_RAD_SI2_D.assign(Color=None)
                    df_050_059_RAD_SI2_D  = df_050_059_RAD_SI2_D.assign(Clarity=None)
                    df_050_059_RAD_SI2_D  = df_050_059_RAD_SI2_D.assign(Cut=None)
                    df_050_059_RAD_SI2_D  = df_050_059_RAD_SI2_D.assign(Polish=None)
                    df_050_059_RAD_SI2_D  = df_050_059_RAD_SI2_D.assign(Symmetry=None)
                    df_050_059_RAD_SI2_D  = df_050_059_RAD_SI2_D.assign(Ratio=None)
                    df_050_059_RAD_SI2_D  = df_050_059_RAD_SI2_D.assign(PPC=None)
                    df_050_059_RAD_SI2_D  = df_050_059_RAD_SI2_D.assign(Total=None)
                    df_050_059_RAD_SI2_D ['Wt Range'] = listwtrange
                    df_050_059_RAD_SI2_D ['Company'] = listcom
                    df_050_059_RAD_SI2_D ['Shape'] = listshap
                    df_050_059_RAD_SI2_D ['Carat'] = listcar
                    df_050_059_RAD_SI2_D ['Color'] = listcol
                    df_050_059_RAD_SI2_D ['Clarity'] = listclar
                    df_050_059_RAD_SI2_D ['Cut'] = listcut
                    df_050_059_RAD_SI2_D ['Polish'] = listpol
                    df_050_059_RAD_SI2_D ['Symmetry'] = listsym
                    df_050_059_RAD_SI2_D ['Ratio'] = listrat
                    df_050_059_RAD_SI2_D ['PPC'] = listdesc
                    df_050_059_RAD_SI2_D ['Total'] = listtotal
                    df_050_059_RAD_SI2_D['Carat'] = df_050_059_RAD_SI2_D['Carat'].astype('float64')
                    df_050_059_RAD_SI2_D['PPC'] = df_050_059_RAD_SI2_D['PPC'].astype('float64')
                    df_050_059_RAD_SI2_D['Total'] = df_050_059_RAD_SI2_D['Total'].astype('float64')
                    df_050_059_RAD_SI2_D['Total'] = df_050_059_RAD_SI2_D['Carat'] * df_050_059_RAD_SI2_D['PPC']


                elif i=="D" and j == "I1" and k == "RAD":
                    df_050_059_RAD_I1_D = pd.DataFrame()
                    df_050_059_RAD_I1_D ['Wt Range'] = None
                    df_050_059_RAD_I1_D  = df_050_059_RAD_I1_D.assign(Company=None)
                    df_050_059_RAD_I1_D  = df_050_059_RAD_I1_D.assign(Shape=None)
                    df_050_059_RAD_I1_D  = df_050_059_RAD_I1_D.assign(Carat=None)
                    df_050_059_RAD_I1_D  = df_050_059_RAD_I1_D.assign(Color=None)
                    df_050_059_RAD_I1_D  = df_050_059_RAD_I1_D.assign(Clarity=None)
                    df_050_059_RAD_I1_D  = df_050_059_RAD_I1_D.assign(Cut=None)
                    df_050_059_RAD_I1_D  = df_050_059_RAD_I1_D.assign(Polish=None)
                    df_050_059_RAD_I1_D  = df_050_059_RAD_I1_D.assign(Symmetry=None)
                    df_050_059_RAD_I1_D  = df_050_059_RAD_I1_D.assign(Ratio=None)
                    df_050_059_RAD_I1_D  = df_050_059_RAD_I1_D.assign(PPC=None)
                    df_050_059_RAD_I1_D  = df_050_059_RAD_I1_D.assign(Total=None)
                    df_050_059_RAD_I1_D ['Wt Range'] = listwtrange
                    df_050_059_RAD_I1_D ['Company'] = listcom
                    df_050_059_RAD_I1_D ['Shape'] = listshap
                    df_050_059_RAD_I1_D ['Carat'] = listcar
                    df_050_059_RAD_I1_D ['Color'] = listcol
                    df_050_059_RAD_I1_D ['Clarity'] = listclar
                    df_050_059_RAD_I1_D ['Cut'] = listcut
                    df_050_059_RAD_I1_D ['Polish'] = listpol
                    df_050_059_RAD_I1_D ['Symmetry'] = listsym
                    df_050_059_RAD_I1_D ['Ratio'] = listrat
                    df_050_059_RAD_I1_D ['PPC'] = listdesc
                    df_050_059_RAD_I1_D ['Total'] = listtotal
                    df_050_059_RAD_I1_D['Carat'] = df_050_059_RAD_I1_D['Carat'].astype('float64')
                    df_050_059_RAD_I1_D['PPC'] = df_050_059_RAD_I1_D['PPC'].astype('float64')
                    df_050_059_RAD_I1_D['Total'] = df_050_059_RAD_I1_D['Total'].astype('float64')
                    df_050_059_RAD_I1_D['Total'] = df_050_059_RAD_I1_D['Carat'] * df_050_059_RAD_I1_D['PPC']


                elif i=="D" and j == "I2" and k == "RAD":
                    df_050_059_RAD_I2_D = pd.DataFrame()
                    df_050_059_RAD_I2_D ['Wt Range'] = None
                    df_050_059_RAD_I2_D  = df_050_059_RAD_I2_D.assign(Company=None)
                    df_050_059_RAD_I2_D  = df_050_059_RAD_I2_D.assign(Shape=None)
                    df_050_059_RAD_I2_D  = df_050_059_RAD_I2_D.assign(Carat=None)
                    df_050_059_RAD_I2_D  = df_050_059_RAD_I2_D.assign(Color=None)
                    df_050_059_RAD_I2_D  = df_050_059_RAD_I2_D.assign(Clarity=None)
                    df_050_059_RAD_I2_D  = df_050_059_RAD_I2_D.assign(Cut=None)
                    df_050_059_RAD_I2_D  = df_050_059_RAD_I2_D.assign(Polish=None)
                    df_050_059_RAD_I2_D  = df_050_059_RAD_I2_D.assign(Symmetry=None)
                    df_050_059_RAD_I2_D  = df_050_059_RAD_I2_D.assign(Ratio=None)
                    df_050_059_RAD_I2_D  = df_050_059_RAD_I2_D.assign(PPC=None)
                    df_050_059_RAD_I2_D  = df_050_059_RAD_I2_D.assign(Total=None)
                    df_050_059_RAD_I2_D ['Wt Range'] = listwtrange
                    df_050_059_RAD_I2_D ['Company'] = listcom
                    df_050_059_RAD_I2_D ['Shape'] = listshap
                    df_050_059_RAD_I2_D ['Carat'] = listcar
                    df_050_059_RAD_I2_D ['Color'] = listcol
                    df_050_059_RAD_I2_D ['Clarity'] = listclar
                    df_050_059_RAD_I2_D ['Cut'] = listcut
                    df_050_059_RAD_I2_D ['Polish'] = listpol
                    df_050_059_RAD_I2_D ['Symmetry'] = listsym
                    df_050_059_RAD_I2_D ['Ratio'] = listrat
                    df_050_059_RAD_I2_D ['PPC'] = listdesc
                    df_050_059_RAD_I2_D ['Total'] = listtotal
                    df_050_059_RAD_I2_D['Carat'] = df_050_059_RAD_I2_D['Carat'].astype('float64')
                    df_050_059_RAD_I2_D['PPC'] = df_050_059_RAD_I2_D['PPC'].astype('float64')
                    df_050_059_RAD_I2_D['Total'] = df_050_059_RAD_I2_D['Total'].astype('float64')
                    df_050_059_RAD_I2_D['Total'] = df_050_059_RAD_I2_D['Carat'] * df_050_059_RAD_I2_D['PPC']



                elif i=="E" and j == "IF" and k == "RAD":
                    df_050_059_RAD_IF_E = pd.DataFrame()
                    df_050_059_RAD_IF_E ['Wt Range'] = None
                    df_050_059_RAD_IF_E  = df_050_059_RAD_IF_E.assign(Company=None)
                    df_050_059_RAD_IF_E  = df_050_059_RAD_IF_E.assign(Shape=None)
                    df_050_059_RAD_IF_E  = df_050_059_RAD_IF_E.assign(Carat=None)
                    df_050_059_RAD_IF_E  = df_050_059_RAD_IF_E.assign(Color=None)
                    df_050_059_RAD_IF_E  = df_050_059_RAD_IF_E.assign(Clarity=None)
                    df_050_059_RAD_IF_E  = df_050_059_RAD_IF_E.assign(Cut=None)
                    df_050_059_RAD_IF_E  = df_050_059_RAD_IF_E.assign(Polish=None)
                    df_050_059_RAD_IF_E  = df_050_059_RAD_IF_E.assign(Symmetry=None)
                    df_050_059_RAD_IF_E  = df_050_059_RAD_IF_E.assign(Ratio=None)
                    df_050_059_RAD_IF_E  = df_050_059_RAD_IF_E.assign(PPC=None)
                    df_050_059_RAD_IF_E  = df_050_059_RAD_IF_E.assign(Total=None)
                    df_050_059_RAD_IF_E ['Wt Range'] = listwtrange
                    df_050_059_RAD_IF_E ['Company'] = listcom
                    df_050_059_RAD_IF_E ['Shape'] = listshap
                    df_050_059_RAD_IF_E ['Carat'] = listcar
                    df_050_059_RAD_IF_E ['Color'] = listcol
                    df_050_059_RAD_IF_E ['Clarity'] = listclar
                    df_050_059_RAD_IF_E ['Cut'] = listcut
                    df_050_059_RAD_IF_E ['Polish'] = listpol
                    df_050_059_RAD_IF_E ['Symmetry'] = listsym
                    df_050_059_RAD_IF_E ['Ratio'] = listrat
                    df_050_059_RAD_IF_E ['PPC'] = listdesc
                    df_050_059_RAD_IF_E ['Total'] = listtotal
                    df_050_059_RAD_IF_E['Carat'] = df_050_059_RAD_IF_E['Carat'].astype('float64')
                    df_050_059_RAD_IF_E['PPC'] = df_050_059_RAD_IF_E['PPC'].astype('float64')
                    df_050_059_RAD_IF_E['Total'] = df_050_059_RAD_IF_E['Total'].astype('float64')
                    df_050_059_RAD_IF_E['Total'] = df_050_059_RAD_IF_E['Carat'] * df_050_059_RAD_IF_E['PPC']



                elif i=="E" and j == "VVS1" and k == "RAD":
                    df_050_059_RAD_VVS1_E = pd.DataFrame()
                    df_050_059_RAD_VVS1_E ['Wt Range'] = None
                    df_050_059_RAD_VVS1_E  = df_050_059_RAD_VVS1_E.assign(Company=None)
                    df_050_059_RAD_VVS1_E  = df_050_059_RAD_VVS1_E.assign(Shape=None)
                    df_050_059_RAD_VVS1_E  = df_050_059_RAD_VVS1_E.assign(Carat=None)
                    df_050_059_RAD_VVS1_E  = df_050_059_RAD_VVS1_E.assign(Color=None)
                    df_050_059_RAD_VVS1_E  = df_050_059_RAD_VVS1_E.assign(Clarity=None)
                    df_050_059_RAD_VVS1_E  = df_050_059_RAD_VVS1_E.assign(Cut=None)
                    df_050_059_RAD_VVS1_E  = df_050_059_RAD_VVS1_E.assign(Polish=None)
                    df_050_059_RAD_VVS1_E  = df_050_059_RAD_VVS1_E.assign(Symmetry=None)
                    df_050_059_RAD_VVS1_E  = df_050_059_RAD_VVS1_E.assign(Ratio=None)
                    df_050_059_RAD_VVS1_E  = df_050_059_RAD_VVS1_E.assign(PPC=None)
                    df_050_059_RAD_VVS1_E  = df_050_059_RAD_VVS1_E.assign(Total=None)
                    df_050_059_RAD_VVS1_E ['Wt Range'] = listwtrange
                    df_050_059_RAD_VVS1_E ['Company'] = listcom
                    df_050_059_RAD_VVS1_E ['Shape'] = listshap
                    df_050_059_RAD_VVS1_E ['Carat'] = listcar
                    df_050_059_RAD_VVS1_E ['Color'] = listcol
                    df_050_059_RAD_VVS1_E ['Clarity'] = listclar
                    df_050_059_RAD_VVS1_E ['Cut'] = listcut
                    df_050_059_RAD_VVS1_E ['Polish'] = listpol
                    df_050_059_RAD_VVS1_E ['Symmetry'] = listsym
                    df_050_059_RAD_VVS1_E ['Ratio'] = listrat
                    df_050_059_RAD_VVS1_E ['PPC'] = listdesc
                    df_050_059_RAD_VVS1_E ['Total'] = listtotal
                    df_050_059_RAD_VVS1_E['Carat'] = df_050_059_RAD_VVS1_E['Carat'].astype('float64')
                    df_050_059_RAD_VVS1_E['PPC'] = df_050_059_RAD_VVS1_E['PPC'].astype('float64')
                    df_050_059_RAD_VVS1_E['Total'] = df_050_059_RAD_VVS1_E['Total'].astype('float64')
                    df_050_059_RAD_VVS1_E['Total'] = df_050_059_RAD_VVS1_E['Carat'] * df_050_059_RAD_VVS1_E['PPC']


                elif i=="E" and j == "VVS2" and k == "RAD":
                    df_050_059_RAD_VVS2_E = pd.DataFrame()
                    df_050_059_RAD_VVS2_E ['Wt Range'] = None
                    df_050_059_RAD_VVS2_E  = df_050_059_RAD_VVS2_E.assign(Company=None)
                    df_050_059_RAD_VVS2_E  = df_050_059_RAD_VVS2_E.assign(Shape=None)
                    df_050_059_RAD_VVS2_E  = df_050_059_RAD_VVS2_E.assign(Carat=None)
                    df_050_059_RAD_VVS2_E  = df_050_059_RAD_VVS2_E.assign(Color=None)
                    df_050_059_RAD_VVS2_E  = df_050_059_RAD_VVS2_E.assign(Clarity=None)
                    df_050_059_RAD_VVS2_E  = df_050_059_RAD_VVS2_E.assign(Cut=None)
                    df_050_059_RAD_VVS2_E  = df_050_059_RAD_VVS2_E.assign(Polish=None)
                    df_050_059_RAD_VVS2_E  = df_050_059_RAD_VVS2_E.assign(Symmetry=None)
                    df_050_059_RAD_VVS2_E  = df_050_059_RAD_VVS2_E.assign(Ratio=None)
                    df_050_059_RAD_VVS2_E  = df_050_059_RAD_VVS2_E.assign(PPC=None)
                    df_050_059_RAD_VVS2_E  = df_050_059_RAD_VVS2_E.assign(Total=None)
                    df_050_059_RAD_VVS2_E ['Wt Range'] = listwtrange
                    df_050_059_RAD_VVS2_E ['Company'] = listcom
                    df_050_059_RAD_VVS2_E ['Shape'] = listshap
                    df_050_059_RAD_VVS2_E ['Carat'] = listcar
                    df_050_059_RAD_VVS2_E ['Color'] = listcol
                    df_050_059_RAD_VVS2_E ['Clarity'] = listclar
                    df_050_059_RAD_VVS2_E ['Cut'] = listcut
                    df_050_059_RAD_VVS2_E ['Polish'] = listpol
                    df_050_059_RAD_VVS2_E ['Symmetry'] = listsym
                    df_050_059_RAD_VVS2_E ['Ratio'] = listrat
                    df_050_059_RAD_VVS2_E ['PPC'] = listdesc
                    df_050_059_RAD_VVS2_E ['Total'] = listtotal
                    df_050_059_RAD_VVS2_E['Carat'] = df_050_059_RAD_VVS2_E['Carat'].astype('float64')
                    df_050_059_RAD_VVS2_E['PPC'] = df_050_059_RAD_VVS2_E['PPC'].astype('float64')
                    df_050_059_RAD_VVS2_E['Total'] = df_050_059_RAD_VVS2_E['Total'].astype('float64')
                    df_050_059_RAD_VVS2_E['Total'] = df_050_059_RAD_VVS2_E['Carat'] * df_050_059_RAD_VVS2_E['PPC']


                elif i=="E" and j=="VS1" and k == "RAD":
                    df_050_059_RAD_VS1_E = pd.DataFrame()
                    df_050_059_RAD_VS1_E ['Wt Range'] = None
                    df_050_059_RAD_VS1_E  = df_050_059_RAD_VS1_E.assign(Company=None)
                    df_050_059_RAD_VS1_E  = df_050_059_RAD_VS1_E.assign(Shape=None)
                    df_050_059_RAD_VS1_E  = df_050_059_RAD_VS1_E.assign(Carat=None)
                    df_050_059_RAD_VS1_E  = df_050_059_RAD_VS1_E.assign(Color=None)
                    df_050_059_RAD_VS1_E  = df_050_059_RAD_VS1_E.assign(Clarity=None)
                    df_050_059_RAD_VS1_E  = df_050_059_RAD_VS1_E.assign(Cut=None)
                    df_050_059_RAD_VS1_E  = df_050_059_RAD_VS1_E.assign(Polish=None)
                    df_050_059_RAD_VS1_E  = df_050_059_RAD_VS1_E.assign(Symmetry=None)
                    df_050_059_RAD_VS1_E  = df_050_059_RAD_VS1_E.assign(Ratio=None)
                    df_050_059_RAD_VS1_E  = df_050_059_RAD_VS1_E.assign(PPC=None)
                    df_050_059_RAD_VS1_E  = df_050_059_RAD_VS1_E.assign(Total=None)
                    df_050_059_RAD_VS1_E ['Wt Range'] = listwtrange
                    df_050_059_RAD_VS1_E ['Company'] = listcom
                    df_050_059_RAD_VS1_E ['Shape'] = listshap
                    df_050_059_RAD_VS1_E ['Carat'] = listcar
                    df_050_059_RAD_VS1_E ['Color'] = listcol
                    df_050_059_RAD_VS1_E ['Clarity'] = listclar
                    df_050_059_RAD_VS1_E ['Cut'] = listcut
                    df_050_059_RAD_VS1_E ['Polish'] = listpol
                    df_050_059_RAD_VS1_E ['Symmetry'] = listsym
                    df_050_059_RAD_VS1_E ['Ratio'] = listrat
                    df_050_059_RAD_VS1_E ['PPC'] = listdesc
                    df_050_059_RAD_VS1_E ['Total'] = listtotal
                    df_050_059_RAD_VS1_E['Carat'] = df_050_059_RAD_VS1_E['Carat'].astype('float64')
                    df_050_059_RAD_VS1_E['PPC'] = df_050_059_RAD_VS1_E['PPC'].astype('float64')
                    df_050_059_RAD_VS1_E['Total'] = df_050_059_RAD_VS1_E['Total'].astype('float64')
                    df_050_059_RAD_VS1_E['Total'] = df_050_059_RAD_VS1_E['Carat'] * df_050_059_RAD_VS1_E['PPC']


                elif i=="E" and j == "VS2" and k == "RAD":
                    df_050_059_RAD_VS2_E = pd.DataFrame()
                    df_050_059_RAD_VS2_E ['Wt Range'] = None
                    df_050_059_RAD_VS2_E  = df_050_059_RAD_VS2_E.assign(Company=None)
                    df_050_059_RAD_VS2_E  = df_050_059_RAD_VS2_E.assign(Shape=None)
                    df_050_059_RAD_VS2_E  = df_050_059_RAD_VS2_E.assign(Carat=None)
                    df_050_059_RAD_VS2_E  = df_050_059_RAD_VS2_E.assign(Color=None)
                    df_050_059_RAD_VS2_E  = df_050_059_RAD_VS2_E.assign(Clarity=None)
                    df_050_059_RAD_VS2_E  = df_050_059_RAD_VS2_E.assign(Cut=None)
                    df_050_059_RAD_VS2_E  = df_050_059_RAD_VS2_E.assign(Polish=None)
                    df_050_059_RAD_VS2_E  = df_050_059_RAD_VS2_E.assign(Symmetry=None)
                    df_050_059_RAD_VS2_E  = df_050_059_RAD_VS2_E.assign(Ratio=None)
                    df_050_059_RAD_VS2_E  = df_050_059_RAD_VS2_E.assign(PPC=None)
                    df_050_059_RAD_VS2_E  = df_050_059_RAD_VS2_E.assign(Total=None)
                    df_050_059_RAD_VS2_E ['Wt Range'] = listwtrange
                    df_050_059_RAD_VS2_E ['Company'] = listcom
                    df_050_059_RAD_VS2_E ['Shape'] = listshap
                    df_050_059_RAD_VS2_E ['Carat'] = listcar
                    df_050_059_RAD_VS2_E ['Color'] = listcol
                    df_050_059_RAD_VS2_E ['Clarity'] = listclar
                    df_050_059_RAD_VS2_E ['Cut'] = listcut
                    df_050_059_RAD_VS2_E ['Polish'] = listpol
                    df_050_059_RAD_VS2_E ['Symmetry'] = listsym
                    df_050_059_RAD_VS2_E ['Ratio'] = listrat
                    df_050_059_RAD_VS2_E ['PPC'] = listdesc
                    df_050_059_RAD_VS2_E ['Total'] = listtotal
                    df_050_059_RAD_VS2_E['Carat'] = df_050_059_RAD_VS2_E['Carat'].astype('float64')
                    df_050_059_RAD_VS2_E['PPC'] = df_050_059_RAD_VS2_E['PPC'].astype('float64')
                    df_050_059_RAD_VS2_E['Total'] = df_050_059_RAD_VS2_E['Total'].astype('float64')
                    df_050_059_RAD_VS2_E['Total'] = df_050_059_RAD_VS2_E['Carat'] * df_050_059_RAD_VS2_E['PPC']


                elif i=="E" and j == "SI1" and k == "RAD":
                    df_050_059_RAD_SI1_E = pd.DataFrame()
                    df_050_059_RAD_SI1_E ['Wt Range'] = None
                    df_050_059_RAD_SI1_E  = df_050_059_RAD_SI1_E.assign(Company=None)
                    df_050_059_RAD_SI1_E  = df_050_059_RAD_SI1_E.assign(Shape=None)
                    df_050_059_RAD_SI1_E  = df_050_059_RAD_SI1_E.assign(Carat=None)
                    df_050_059_RAD_SI1_E  = df_050_059_RAD_SI1_E.assign(Color=None)
                    df_050_059_RAD_SI1_E  = df_050_059_RAD_SI1_E.assign(Clarity=None)
                    df_050_059_RAD_SI1_E  = df_050_059_RAD_SI1_E.assign(Cut=None)
                    df_050_059_RAD_SI1_E  = df_050_059_RAD_SI1_E.assign(Polish=None)
                    df_050_059_RAD_SI1_E  = df_050_059_RAD_SI1_E.assign(Symmetry=None)
                    df_050_059_RAD_SI1_E  = df_050_059_RAD_SI1_E.assign(Ratio=None)
                    df_050_059_RAD_SI1_E  = df_050_059_RAD_SI1_E.assign(PPC=None)
                    df_050_059_RAD_SI1_E  = df_050_059_RAD_SI1_E.assign(Total=None)
                    df_050_059_RAD_SI1_E ['Wt Range'] = listwtrange
                    df_050_059_RAD_SI1_E ['Company'] = listcom
                    df_050_059_RAD_SI1_E ['Shape'] = listshap
                    df_050_059_RAD_SI1_E ['Carat'] = listcar
                    df_050_059_RAD_SI1_E ['Color'] = listcol
                    df_050_059_RAD_SI1_E ['Clarity'] = listclar
                    df_050_059_RAD_SI1_E ['Cut'] = listcut
                    df_050_059_RAD_SI1_E ['Polish'] = listpol
                    df_050_059_RAD_SI1_E ['Symmetry'] = listsym
                    df_050_059_RAD_SI1_E ['Ratio'] = listrat
                    df_050_059_RAD_SI1_E ['PPC'] = listdesc
                    df_050_059_RAD_SI1_E ['Total'] = listtotal
                    df_050_059_RAD_SI1_E['Carat'] = df_050_059_RAD_SI1_E['Carat'].astype('float64')
                    df_050_059_RAD_SI1_E['PPC'] = df_050_059_RAD_SI1_E['PPC'].astype('float64')
                    df_050_059_RAD_SI1_E['Total'] = df_050_059_RAD_SI1_E['Total'].astype('float64')
                    df_050_059_RAD_SI1_E['Total'] = df_050_059_RAD_SI1_E['Carat'] * df_050_059_RAD_SI1_E['PPC']


                elif i=="E" and j == "SI2" and k == "RAD":
                    df_050_059_RAD_SI2_E = pd.DataFrame()
                    df_050_059_RAD_SI2_E ['Wt Range'] = None
                    df_050_059_RAD_SI2_E  = df_050_059_RAD_SI2_E.assign(Company=None)
                    df_050_059_RAD_SI2_E  = df_050_059_RAD_SI2_E.assign(Shape=None)
                    df_050_059_RAD_SI2_E  = df_050_059_RAD_SI2_E.assign(Carat=None)
                    df_050_059_RAD_SI2_E  = df_050_059_RAD_SI2_E.assign(Color=None)
                    df_050_059_RAD_SI2_E  = df_050_059_RAD_SI2_E.assign(Clarity=None)
                    df_050_059_RAD_SI2_E  = df_050_059_RAD_SI2_E.assign(Cut=None)
                    df_050_059_RAD_SI2_E  = df_050_059_RAD_SI2_E.assign(Polish=None)
                    df_050_059_RAD_SI2_E  = df_050_059_RAD_SI2_E.assign(Symmetry=None)
                    df_050_059_RAD_SI2_E  = df_050_059_RAD_SI2_E.assign(Ratio=None)
                    df_050_059_RAD_SI2_E  = df_050_059_RAD_SI2_E.assign(PPC=None)
                    df_050_059_RAD_SI2_E  = df_050_059_RAD_SI2_E.assign(Total=None)
                    df_050_059_RAD_SI2_E ['Wt Range'] = listwtrange
                    df_050_059_RAD_SI2_E ['Company'] = listcom
                    df_050_059_RAD_SI2_E ['Shape'] = listshap
                    df_050_059_RAD_SI2_E ['Carat'] = listcar
                    df_050_059_RAD_SI2_E ['Color'] = listcol
                    df_050_059_RAD_SI2_E ['Clarity'] = listclar
                    df_050_059_RAD_SI2_E ['Cut'] = listcut
                    df_050_059_RAD_SI2_E ['Polish'] = listpol
                    df_050_059_RAD_SI2_E ['Symmetry'] = listsym
                    df_050_059_RAD_SI2_E ['Ratio'] = listrat
                    df_050_059_RAD_SI2_E ['PPC'] = listdesc
                    df_050_059_RAD_SI2_E ['Total'] = listtotal
                    df_050_059_RAD_SI2_E['Carat'] = df_050_059_RAD_SI2_E['Carat'].astype('float64')
                    df_050_059_RAD_SI2_E['PPC'] = df_050_059_RAD_SI2_E['PPC'].astype('float64')
                    df_050_059_RAD_SI2_E['Total'] = df_050_059_RAD_SI2_E['Total'].astype('float64')
                    df_050_059_RAD_SI2_E['Total'] = df_050_059_RAD_SI2_E['Carat'] * df_050_059_RAD_SI2_E['PPC']


                elif i=="E" and j == "I1" and k == "RAD":
                    df_050_059_RAD_I1_E = pd.DataFrame()
                    df_050_059_RAD_I1_E ['Wt Range'] = None
                    df_050_059_RAD_I1_E  = df_050_059_RAD_I1_E.assign(Company=None)
                    df_050_059_RAD_I1_E  = df_050_059_RAD_I1_E.assign(Shape=None)
                    df_050_059_RAD_I1_E  = df_050_059_RAD_I1_E.assign(Carat=None)
                    df_050_059_RAD_I1_E  = df_050_059_RAD_I1_E.assign(Color=None)
                    df_050_059_RAD_I1_E  = df_050_059_RAD_I1_E.assign(Clarity=None)
                    df_050_059_RAD_I1_E  = df_050_059_RAD_I1_E.assign(Cut=None)
                    df_050_059_RAD_I1_E  = df_050_059_RAD_I1_E.assign(Polish=None)
                    df_050_059_RAD_I1_E  = df_050_059_RAD_I1_E.assign(Symmetry=None)
                    df_050_059_RAD_I1_E  = df_050_059_RAD_I1_E.assign(Ratio=None)
                    df_050_059_RAD_I1_E  = df_050_059_RAD_I1_E.assign(PPC=None)
                    df_050_059_RAD_I1_E  = df_050_059_RAD_I1_E.assign(Total=None)
                    df_050_059_RAD_I1_E ['Wt Range'] = listwtrange
                    df_050_059_RAD_I1_E ['Company'] = listcom
                    df_050_059_RAD_I1_E ['Shape'] = listshap
                    df_050_059_RAD_I1_E ['Carat'] = listcar
                    df_050_059_RAD_I1_E ['Color'] = listcol
                    df_050_059_RAD_I1_E ['Clarity'] = listclar
                    df_050_059_RAD_I1_E ['Cut'] = listcut
                    df_050_059_RAD_I1_E ['Polish'] = listpol
                    df_050_059_RAD_I1_E ['Symmetry'] = listsym
                    df_050_059_RAD_I1_E ['Ratio'] = listrat
                    df_050_059_RAD_I1_E ['PPC'] = listdesc
                    df_050_059_RAD_I1_E ['Total'] = listtotal
                    df_050_059_RAD_I1_E['Carat'] = df_050_059_RAD_I1_E['Carat'].astype('float64')
                    df_050_059_RAD_I1_E['PPC'] = df_050_059_RAD_I1_E['PPC'].astype('float64')
                    df_050_059_RAD_I1_E['Total'] = df_050_059_RAD_I1_E['Total'].astype('float64')
                    df_050_059_RAD_I1_E['Total'] = df_050_059_RAD_I1_E['Carat'] * df_050_059_RAD_I1_E['PPC']


                elif i=="E" and j == "I2" and k == "RAD":
                    df_050_059_RAD_I2_E = pd.DataFrame()
                    df_050_059_RAD_I2_E ['Wt Range'] = None
                    df_050_059_RAD_I2_E  = df_050_059_RAD_I2_E.assign(Company=None)
                    df_050_059_RAD_I2_E  = df_050_059_RAD_I2_E.assign(Shape=None)
                    df_050_059_RAD_I2_E  = df_050_059_RAD_I2_E.assign(Carat=None)
                    df_050_059_RAD_I2_E  = df_050_059_RAD_I2_E.assign(Color=None)
                    df_050_059_RAD_I2_E  = df_050_059_RAD_I2_E.assign(Clarity=None)
                    df_050_059_RAD_I2_E  = df_050_059_RAD_I2_E.assign(Cut=None)
                    df_050_059_RAD_I2_E  = df_050_059_RAD_I2_E.assign(Polish=None)
                    df_050_059_RAD_I2_E  = df_050_059_RAD_I2_E.assign(Symmetry=None)
                    df_050_059_RAD_I2_E  = df_050_059_RAD_I2_E.assign(Ratio=None)
                    df_050_059_RAD_I2_E  = df_050_059_RAD_I2_E.assign(PPC=None)
                    df_050_059_RAD_I2_E  = df_050_059_RAD_I2_E.assign(Total=None)
                    df_050_059_RAD_I2_E ['Wt Range'] = listwtrange
                    df_050_059_RAD_I2_E ['Company'] = listcom
                    df_050_059_RAD_I2_E ['Shape'] = listshap
                    df_050_059_RAD_I2_E ['Carat'] = listcar
                    df_050_059_RAD_I2_E ['Color'] = listcol
                    df_050_059_RAD_I2_E ['Clarity'] = listclar
                    df_050_059_RAD_I2_E ['Cut'] = listcut
                    df_050_059_RAD_I2_E ['Polish'] = listpol
                    df_050_059_RAD_I2_E ['Symmetry'] = listsym
                    df_050_059_RAD_I2_E ['Ratio'] = listrat
                    df_050_059_RAD_I2_E ['PPC'] = listdesc
                    df_050_059_RAD_I2_E ['Total'] = listtotal
                    df_050_059_RAD_I2_E['Carat'] = df_050_059_RAD_I2_E['Carat'].astype('float64')
                    df_050_059_RAD_I2_E['PPC'] = df_050_059_RAD_I2_E['PPC'].astype('float64')
                    df_050_059_RAD_I2_E['Total'] = df_050_059_RAD_I2_E['Total'].astype('float64')
                    df_050_059_RAD_I2_E['Total'] = df_050_059_RAD_I2_E['Carat'] * df_050_059_RAD_I2_E['PPC']
                
                elif i=="F" and j == "IF" and k == "RAD":
                    df_050_059_RAD_IF_F = pd.DataFrame()
                    df_050_059_RAD_IF_F ['Wt Range'] = None
                    df_050_059_RAD_IF_F  = df_050_059_RAD_IF_F.assign(Company=None)
                    df_050_059_RAD_IF_F  = df_050_059_RAD_IF_F.assign(Shape=None)
                    df_050_059_RAD_IF_F  = df_050_059_RAD_IF_F.assign(Carat=None)
                    df_050_059_RAD_IF_F  = df_050_059_RAD_IF_F.assign(Color=None)
                    df_050_059_RAD_IF_F  = df_050_059_RAD_IF_F.assign(Clarity=None)
                    df_050_059_RAD_IF_F  = df_050_059_RAD_IF_F.assign(Cut=None)
                    df_050_059_RAD_IF_F  = df_050_059_RAD_IF_F.assign(Polish=None)
                    df_050_059_RAD_IF_F  = df_050_059_RAD_IF_F.assign(Symmetry=None)
                    df_050_059_RAD_IF_F  = df_050_059_RAD_IF_F.assign(Ratio=None)
                    df_050_059_RAD_IF_F  = df_050_059_RAD_IF_F.assign(PPC=None)
                    df_050_059_RAD_IF_F  = df_050_059_RAD_IF_F.assign(Total=None)
                    df_050_059_RAD_IF_F ['Wt Range'] = listwtrange
                    df_050_059_RAD_IF_F ['Company'] = listcom
                    df_050_059_RAD_IF_F ['Shape'] = listshap
                    df_050_059_RAD_IF_F ['Carat'] = listcar
                    df_050_059_RAD_IF_F ['Color'] = listcol
                    df_050_059_RAD_IF_F ['Clarity'] = listclar
                    df_050_059_RAD_IF_F ['Cut'] = listcut
                    df_050_059_RAD_IF_F ['Polish'] = listpol
                    df_050_059_RAD_IF_F ['Symmetry'] = listsym
                    df_050_059_RAD_IF_F ['Ratio'] = listrat
                    df_050_059_RAD_IF_F ['PPC'] = listdesc
                    df_050_059_RAD_IF_F ['Total'] = listtotal
                    df_050_059_RAD_IF_F['Carat'] = df_050_059_RAD_IF_F['Carat'].astype('float64')
                    df_050_059_RAD_IF_F['PPC'] = df_050_059_RAD_IF_F['PPC'].astype('float64')
                    df_050_059_RAD_IF_F['Total'] = df_050_059_RAD_IF_F['Total'].astype('float64')
                    df_050_059_RAD_IF_F['Total'] = df_050_059_RAD_IF_F['Carat'] * df_050_059_RAD_IF_F['PPC']



                elif i=="F" and j == "VVS1" and k == "RAD":
                    df_050_059_RAD_VVS1_F = pd.DataFrame()
                    df_050_059_RAD_VVS1_F ['Wt Range'] = None
                    df_050_059_RAD_VVS1_F  = df_050_059_RAD_VVS1_F.assign(Company=None)
                    df_050_059_RAD_VVS1_F  = df_050_059_RAD_VVS1_F.assign(Shape=None)
                    df_050_059_RAD_VVS1_F  = df_050_059_RAD_VVS1_F.assign(Carat=None)
                    df_050_059_RAD_VVS1_F  = df_050_059_RAD_VVS1_F.assign(Color=None)
                    df_050_059_RAD_VVS1_F  = df_050_059_RAD_VVS1_F.assign(Clarity=None)
                    df_050_059_RAD_VVS1_F  = df_050_059_RAD_VVS1_F.assign(Cut=None)
                    df_050_059_RAD_VVS1_F  = df_050_059_RAD_VVS1_F.assign(Polish=None)
                    df_050_059_RAD_VVS1_F  = df_050_059_RAD_VVS1_F.assign(Symmetry=None)
                    df_050_059_RAD_VVS1_F  = df_050_059_RAD_VVS1_F.assign(Ratio=None)
                    df_050_059_RAD_VVS1_F  = df_050_059_RAD_VVS1_F.assign(PPC=None)
                    df_050_059_RAD_VVS1_F  = df_050_059_RAD_VVS1_F.assign(Total=None)
                    df_050_059_RAD_VVS1_F ['Wt Range'] = listwtrange
                    df_050_059_RAD_VVS1_F ['Company'] = listcom
                    df_050_059_RAD_VVS1_F ['Shape'] = listshap
                    df_050_059_RAD_VVS1_F ['Carat'] = listcar
                    df_050_059_RAD_VVS1_F ['Color'] = listcol
                    df_050_059_RAD_VVS1_F ['Clarity'] = listclar
                    df_050_059_RAD_VVS1_F ['Cut'] = listcut
                    df_050_059_RAD_VVS1_F ['Polish'] = listpol
                    df_050_059_RAD_VVS1_F ['Symmetry'] = listsym
                    df_050_059_RAD_VVS1_F ['Ratio'] = listrat
                    df_050_059_RAD_VVS1_F ['PPC'] = listdesc
                    df_050_059_RAD_VVS1_F ['Total'] = listtotal
                    df_050_059_RAD_VVS1_F['Carat'] = df_050_059_RAD_VVS1_F['Carat'].astype('float64')
                    df_050_059_RAD_VVS1_F['PPC'] = df_050_059_RAD_VVS1_F['PPC'].astype('float64')
                    df_050_059_RAD_VVS1_F['Total'] = df_050_059_RAD_VVS1_F['Total'].astype('float64')
                    df_050_059_RAD_VVS1_F['Total'] = df_050_059_RAD_VVS1_F['Carat'] * df_050_059_RAD_VVS1_F['PPC']


                elif i=="F" and j == "VVS2" and k == "RAD":
                    df_050_059_RAD_VVS2_F = pd.DataFrame()
                    df_050_059_RAD_VVS2_F ['Wt Range'] = None
                    df_050_059_RAD_VVS2_F  = df_050_059_RAD_VVS2_F.assign(Company=None)
                    df_050_059_RAD_VVS2_F  = df_050_059_RAD_VVS2_F.assign(Shape=None)
                    df_050_059_RAD_VVS2_F  = df_050_059_RAD_VVS2_F.assign(Carat=None)
                    df_050_059_RAD_VVS2_F  = df_050_059_RAD_VVS2_F.assign(Color=None)
                    df_050_059_RAD_VVS2_F  = df_050_059_RAD_VVS2_F.assign(Clarity=None)
                    df_050_059_RAD_VVS2_F  = df_050_059_RAD_VVS2_F.assign(Cut=None)
                    df_050_059_RAD_VVS2_F  = df_050_059_RAD_VVS2_F.assign(Polish=None)
                    df_050_059_RAD_VVS2_F  = df_050_059_RAD_VVS2_F.assign(Symmetry=None)
                    df_050_059_RAD_VVS2_F  = df_050_059_RAD_VVS2_F.assign(Ratio=None)
                    df_050_059_RAD_VVS2_F  = df_050_059_RAD_VVS2_F.assign(PPC=None)
                    df_050_059_RAD_VVS2_F  = df_050_059_RAD_VVS2_F.assign(Total=None)
                    df_050_059_RAD_VVS2_F ['Wt Range'] = listwtrange
                    df_050_059_RAD_VVS2_F ['Company'] = listcom
                    df_050_059_RAD_VVS2_F ['Shape'] = listshap
                    df_050_059_RAD_VVS2_F ['Carat'] = listcar
                    df_050_059_RAD_VVS2_F ['Color'] = listcol
                    df_050_059_RAD_VVS2_F ['Clarity'] = listclar
                    df_050_059_RAD_VVS2_F ['Cut'] = listcut
                    df_050_059_RAD_VVS2_F ['Polish'] = listpol
                    df_050_059_RAD_VVS2_F ['Symmetry'] = listsym
                    df_050_059_RAD_VVS2_F ['Ratio'] = listrat
                    df_050_059_RAD_VVS2_F ['PPC'] = listdesc
                    df_050_059_RAD_VVS2_F ['Total'] = listtotal
                    df_050_059_RAD_VVS2_F['Carat'] = df_050_059_RAD_VVS2_F['Carat'].astype('float64')
                    df_050_059_RAD_VVS2_F['PPC'] = df_050_059_RAD_VVS2_F['PPC'].astype('float64')
                    df_050_059_RAD_VVS2_F['Total'] = df_050_059_RAD_VVS2_F['Total'].astype('float64')
                    df_050_059_RAD_VVS2_F['Total'] = df_050_059_RAD_VVS2_F['Carat'] * df_050_059_RAD_VVS2_F['PPC']


                elif i=="F" and j=="VS1" and k == "RAD":
                    df_050_059_RAD_VS1_F = pd.DataFrame()
                    df_050_059_RAD_VS1_F ['Wt Range'] = None
                    df_050_059_RAD_VS1_F  = df_050_059_RAD_VS1_F.assign(Company=None)
                    df_050_059_RAD_VS1_F  = df_050_059_RAD_VS1_F.assign(Shape=None)
                    df_050_059_RAD_VS1_F  = df_050_059_RAD_VS1_F.assign(Carat=None)
                    df_050_059_RAD_VS1_F  = df_050_059_RAD_VS1_F.assign(Color=None)
                    df_050_059_RAD_VS1_F  = df_050_059_RAD_VS1_F.assign(Clarity=None)
                    df_050_059_RAD_VS1_F  = df_050_059_RAD_VS1_F.assign(Cut=None)
                    df_050_059_RAD_VS1_F  = df_050_059_RAD_VS1_F.assign(Polish=None)
                    df_050_059_RAD_VS1_F  = df_050_059_RAD_VS1_F.assign(Symmetry=None)
                    df_050_059_RAD_VS1_F  = df_050_059_RAD_VS1_F.assign(Ratio=None)
                    df_050_059_RAD_VS1_F  = df_050_059_RAD_VS1_F.assign(PPC=None)
                    df_050_059_RAD_VS1_F  = df_050_059_RAD_VS1_F.assign(Total=None)
                    df_050_059_RAD_VS1_F ['Wt Range'] = listwtrange
                    df_050_059_RAD_VS1_F ['Company'] = listcom
                    df_050_059_RAD_VS1_F ['Shape'] = listshap
                    df_050_059_RAD_VS1_F ['Carat'] = listcar
                    df_050_059_RAD_VS1_F ['Color'] = listcol
                    df_050_059_RAD_VS1_F ['Clarity'] = listclar
                    df_050_059_RAD_VS1_F ['Cut'] = listcut
                    df_050_059_RAD_VS1_F ['Polish'] = listpol
                    df_050_059_RAD_VS1_F ['Symmetry'] = listsym
                    df_050_059_RAD_VS1_F ['Ratio'] = listrat
                    df_050_059_RAD_VS1_F ['PPC'] = listdesc
                    df_050_059_RAD_VS1_F ['Total'] = listtotal
                    df_050_059_RAD_VS1_F['Carat'] = df_050_059_RAD_VS1_F['Carat'].astype('float64')
                    df_050_059_RAD_VS1_F['PPC'] = df_050_059_RAD_VS1_F['PPC'].astype('float64')
                    df_050_059_RAD_VS1_F['Total'] = df_050_059_RAD_VS1_F['Total'].astype('float64')
                    df_050_059_RAD_VS1_F['Total'] = df_050_059_RAD_VS1_F['Carat'] * df_050_059_RAD_VS1_F['PPC']


                elif i=="F" and j == "VS2" and k == "RAD":
                    df_050_059_RAD_VS2_F = pd.DataFrame()
                    df_050_059_RAD_VS2_F ['Wt Range'] = None
                    df_050_059_RAD_VS2_F  = df_050_059_RAD_VS2_F.assign(Company=None)
                    df_050_059_RAD_VS2_F  = df_050_059_RAD_VS2_F.assign(Shape=None)
                    df_050_059_RAD_VS2_F  = df_050_059_RAD_VS2_F.assign(Carat=None)
                    df_050_059_RAD_VS2_F  = df_050_059_RAD_VS2_F.assign(Color=None)
                    df_050_059_RAD_VS2_F  = df_050_059_RAD_VS2_F.assign(Clarity=None)
                    df_050_059_RAD_VS2_F  = df_050_059_RAD_VS2_F.assign(Cut=None)
                    df_050_059_RAD_VS2_F  = df_050_059_RAD_VS2_F.assign(Polish=None)
                    df_050_059_RAD_VS2_F  = df_050_059_RAD_VS2_F.assign(Symmetry=None)
                    df_050_059_RAD_VS2_F  = df_050_059_RAD_VS2_F.assign(Ratio=None)
                    df_050_059_RAD_VS2_F  = df_050_059_RAD_VS2_F.assign(PPC=None)
                    df_050_059_RAD_VS2_F  = df_050_059_RAD_VS2_F.assign(Total=None)
                    df_050_059_RAD_VS2_F ['Wt Range'] = listwtrange
                    df_050_059_RAD_VS2_F ['Company'] = listcom
                    df_050_059_RAD_VS2_F ['Shape'] = listshap
                    df_050_059_RAD_VS2_F ['Carat'] = listcar
                    df_050_059_RAD_VS2_F ['Color'] = listcol
                    df_050_059_RAD_VS2_F ['Clarity'] = listclar
                    df_050_059_RAD_VS2_F ['Cut'] = listcut
                    df_050_059_RAD_VS2_F ['Polish'] = listpol
                    df_050_059_RAD_VS2_F ['Symmetry'] = listsym
                    df_050_059_RAD_VS2_F ['Ratio'] = listrat
                    df_050_059_RAD_VS2_F ['PPC'] = listdesc
                    df_050_059_RAD_VS2_F ['Total'] = listtotal
                    df_050_059_RAD_VS2_F['Carat'] = df_050_059_RAD_VS2_F['Carat'].astype('float64')
                    df_050_059_RAD_VS2_F['PPC'] = df_050_059_RAD_VS2_F['PPC'].astype('float64')
                    df_050_059_RAD_VS2_F['Total'] = df_050_059_RAD_VS2_F['Total'].astype('float64')
                    df_050_059_RAD_VS2_F['Total'] = df_050_059_RAD_VS2_F['Carat'] * df_050_059_RAD_VS2_F['PPC']


                elif i=="F" and j == "SI1" and k == "RAD":
                    df_050_059_RAD_SI1_F = pd.DataFrame()
                    df_050_059_RAD_SI1_F ['Wt Range'] = None
                    df_050_059_RAD_SI1_F  = df_050_059_RAD_SI1_F.assign(Company=None)
                    df_050_059_RAD_SI1_F  = df_050_059_RAD_SI1_F.assign(Shape=None)
                    df_050_059_RAD_SI1_F  = df_050_059_RAD_SI1_F.assign(Carat=None)
                    df_050_059_RAD_SI1_F  = df_050_059_RAD_SI1_F.assign(Color=None)
                    df_050_059_RAD_SI1_F  = df_050_059_RAD_SI1_F.assign(Clarity=None)
                    df_050_059_RAD_SI1_F  = df_050_059_RAD_SI1_F.assign(Cut=None)
                    df_050_059_RAD_SI1_F  = df_050_059_RAD_SI1_F.assign(Polish=None)
                    df_050_059_RAD_SI1_F  = df_050_059_RAD_SI1_F.assign(Symmetry=None)
                    df_050_059_RAD_SI1_F  = df_050_059_RAD_SI1_F.assign(Ratio=None)
                    df_050_059_RAD_SI1_F  = df_050_059_RAD_SI1_F.assign(PPC=None)
                    df_050_059_RAD_SI1_F  = df_050_059_RAD_SI1_F.assign(Total=None)
                    df_050_059_RAD_SI1_F ['Wt Range'] = listwtrange
                    df_050_059_RAD_SI1_F ['Company'] = listcom
                    df_050_059_RAD_SI1_F ['Shape'] = listshap
                    df_050_059_RAD_SI1_F ['Carat'] = listcar
                    df_050_059_RAD_SI1_F ['Color'] = listcol
                    df_050_059_RAD_SI1_F ['Clarity'] = listclar
                    df_050_059_RAD_SI1_F ['Cut'] = listcut
                    df_050_059_RAD_SI1_F ['Polish'] = listpol
                    df_050_059_RAD_SI1_F ['Symmetry'] = listsym
                    df_050_059_RAD_SI1_F ['Ratio'] = listrat
                    df_050_059_RAD_SI1_F ['PPC'] = listdesc
                    df_050_059_RAD_SI1_F ['Total'] = listtotal
                    df_050_059_RAD_SI1_F['Carat'] = df_050_059_RAD_SI1_F['Carat'].astype('float64')
                    df_050_059_RAD_SI1_F['PPC'] = df_050_059_RAD_SI1_F['PPC'].astype('float64')
                    df_050_059_RAD_SI1_F['Total'] = df_050_059_RAD_SI1_F['Total'].astype('float64')
                    df_050_059_RAD_SI1_F['Total'] = df_050_059_RAD_SI1_F['Carat'] * df_050_059_RAD_SI1_F['PPC']


                elif i=="F" and j == "SI2" and k == "RAD":
                    df_050_059_RAD_SI2_F = pd.DataFrame()
                    df_050_059_RAD_SI2_F ['Wt Range'] = None
                    df_050_059_RAD_SI2_F  = df_050_059_RAD_SI2_F.assign(Company=None)
                    df_050_059_RAD_SI2_F  = df_050_059_RAD_SI2_F.assign(Shape=None)
                    df_050_059_RAD_SI2_F  = df_050_059_RAD_SI2_F.assign(Carat=None)
                    df_050_059_RAD_SI2_F  = df_050_059_RAD_SI2_F.assign(Color=None)
                    df_050_059_RAD_SI2_F  = df_050_059_RAD_SI2_F.assign(Clarity=None)
                    df_050_059_RAD_SI2_F  = df_050_059_RAD_SI2_F.assign(Cut=None)
                    df_050_059_RAD_SI2_F  = df_050_059_RAD_SI2_F.assign(Polish=None)
                    df_050_059_RAD_SI2_F  = df_050_059_RAD_SI2_F.assign(Symmetry=None)
                    df_050_059_RAD_SI2_F  = df_050_059_RAD_SI2_F.assign(Ratio=None)
                    df_050_059_RAD_SI2_F  = df_050_059_RAD_SI2_F.assign(PPC=None)
                    df_050_059_RAD_SI2_F  = df_050_059_RAD_SI2_F.assign(Total=None)
                    df_050_059_RAD_SI2_F ['Wt Range'] = listwtrange
                    df_050_059_RAD_SI2_F ['Company'] = listcom
                    df_050_059_RAD_SI2_F ['Shape'] = listshap
                    df_050_059_RAD_SI2_F ['Carat'] = listcar
                    df_050_059_RAD_SI2_F ['Color'] = listcol
                    df_050_059_RAD_SI2_F ['Clarity'] = listclar
                    df_050_059_RAD_SI2_F ['Cut'] = listcut
                    df_050_059_RAD_SI2_F ['Polish'] = listpol
                    df_050_059_RAD_SI2_F ['Symmetry'] = listsym
                    df_050_059_RAD_SI2_F ['Ratio'] = listrat
                    df_050_059_RAD_SI2_F ['PPC'] = listdesc
                    df_050_059_RAD_SI2_F ['Total'] = listtotal
                    df_050_059_RAD_SI2_F['Carat'] = df_050_059_RAD_SI2_F['Carat'].astype('float64')
                    df_050_059_RAD_SI2_F['PPC'] = df_050_059_RAD_SI2_F['PPC'].astype('float64')
                    df_050_059_RAD_SI2_F['Total'] = df_050_059_RAD_SI2_F['Total'].astype('float64')
                    df_050_059_RAD_SI2_F['Total'] = df_050_059_RAD_SI2_F['Carat'] * df_050_059_RAD_SI2_F['PPC']


                elif i=="F" and j == "I1" and k == "RAD":
                    df_050_059_RAD_I1_F = pd.DataFrame()
                    df_050_059_RAD_I1_F ['Wt Range'] = None
                    df_050_059_RAD_I1_F  = df_050_059_RAD_I1_F.assign(Company=None)
                    df_050_059_RAD_I1_F  = df_050_059_RAD_I1_F.assign(Shape=None)
                    df_050_059_RAD_I1_F  = df_050_059_RAD_I1_F.assign(Carat=None)
                    df_050_059_RAD_I1_F  = df_050_059_RAD_I1_F.assign(Color=None)
                    df_050_059_RAD_I1_F  = df_050_059_RAD_I1_F.assign(Clarity=None)
                    df_050_059_RAD_I1_F  = df_050_059_RAD_I1_F.assign(Cut=None)
                    df_050_059_RAD_I1_F  = df_050_059_RAD_I1_F.assign(Polish=None)
                    df_050_059_RAD_I1_F  = df_050_059_RAD_I1_F.assign(Symmetry=None)
                    df_050_059_RAD_I1_F  = df_050_059_RAD_I1_F.assign(Ratio=None)
                    df_050_059_RAD_I1_F  = df_050_059_RAD_I1_F.assign(PPC=None)
                    df_050_059_RAD_I1_F  = df_050_059_RAD_I1_F.assign(Total=None)
                    df_050_059_RAD_I1_F ['Wt Range'] = listwtrange
                    df_050_059_RAD_I1_F ['Company'] = listcom
                    df_050_059_RAD_I1_F ['Shape'] = listshap
                    df_050_059_RAD_I1_F ['Carat'] = listcar
                    df_050_059_RAD_I1_F ['Color'] = listcol
                    df_050_059_RAD_I1_F ['Clarity'] = listclar
                    df_050_059_RAD_I1_F ['Cut'] = listcut
                    df_050_059_RAD_I1_F ['Polish'] = listpol
                    df_050_059_RAD_I1_F ['Symmetry'] = listsym
                    df_050_059_RAD_I1_F ['Ratio'] = listrat
                    df_050_059_RAD_I1_F ['PPC'] = listdesc
                    df_050_059_RAD_I1_F ['Total'] = listtotal
                    df_050_059_RAD_I1_F['Carat'] = df_050_059_RAD_I1_F['Carat'].astype('float64')
                    df_050_059_RAD_I1_F['PPC'] = df_050_059_RAD_I1_F['PPC'].astype('float64')
                    df_050_059_RAD_I1_F['Total'] = df_050_059_RAD_I1_F['Total'].astype('float64')
                    df_050_059_RAD_I1_F['Total'] = df_050_059_RAD_I1_F['Carat'] * df_050_059_RAD_I1_F['PPC']


                elif i=="F" and j == "I2" and k == "RAD":
                    df_050_059_RAD_I2_F = pd.DataFrame()
                    df_050_059_RAD_I2_F ['Wt Range'] = None
                    df_050_059_RAD_I2_F  = df_050_059_RAD_I2_F.assign(Company=None)
                    df_050_059_RAD_I2_F  = df_050_059_RAD_I2_F.assign(Shape=None)
                    df_050_059_RAD_I2_F  = df_050_059_RAD_I2_F.assign(Carat=None)
                    df_050_059_RAD_I2_F  = df_050_059_RAD_I2_F.assign(Color=None)
                    df_050_059_RAD_I2_F  = df_050_059_RAD_I2_F.assign(Clarity=None)
                    df_050_059_RAD_I2_F  = df_050_059_RAD_I2_F.assign(Cut=None)
                    df_050_059_RAD_I2_F  = df_050_059_RAD_I2_F.assign(Polish=None)
                    df_050_059_RAD_I2_F  = df_050_059_RAD_I2_F.assign(Symmetry=None)
                    df_050_059_RAD_I2_F  = df_050_059_RAD_I2_F.assign(Ratio=None)
                    df_050_059_RAD_I2_F  = df_050_059_RAD_I2_F.assign(PPC=None)
                    df_050_059_RAD_I2_F  = df_050_059_RAD_I2_F.assign(Total=None)
                    df_050_059_RAD_I2_F ['Wt Range'] = listwtrange
                    df_050_059_RAD_I2_F ['Company'] = listcom
                    df_050_059_RAD_I2_F ['Shape'] = listshap
                    df_050_059_RAD_I2_F ['Carat'] = listcar
                    df_050_059_RAD_I2_F ['Color'] = listcol
                    df_050_059_RAD_I2_F ['Clarity'] = listclar
                    df_050_059_RAD_I2_F ['Cut'] = listcut
                    df_050_059_RAD_I2_F ['Polish'] = listpol
                    df_050_059_RAD_I2_F ['Symmetry'] = listsym
                    df_050_059_RAD_I2_F ['Ratio'] = listrat
                    df_050_059_RAD_I2_F ['PPC'] = listdesc
                    df_050_059_RAD_I2_F ['Total'] = listtotal
                    df_050_059_RAD_I2_F['Carat'] = df_050_059_RAD_I2_F['Carat'].astype('float64')
                    df_050_059_RAD_I2_F['PPC'] = df_050_059_RAD_I2_F['PPC'].astype('float64')
                    df_050_059_RAD_I2_F['Total'] = df_050_059_RAD_I2_F['Total'].astype('float64')
                    df_050_059_RAD_I2_F['Total'] = df_050_059_RAD_I2_F['Carat'] * df_050_059_RAD_I2_F['PPC']


                elif i=="G" and j == "IF" and k == "RAD":
                    df_050_059_RAD_IF_G = pd.DataFrame()
                    df_050_059_RAD_IF_G ['Wt Range'] = None
                    df_050_059_RAD_IF_G  = df_050_059_RAD_IF_G.assign(Company=None)
                    df_050_059_RAD_IF_G  = df_050_059_RAD_IF_G.assign(Shape=None)
                    df_050_059_RAD_IF_G  = df_050_059_RAD_IF_G.assign(Carat=None)
                    df_050_059_RAD_IF_G  = df_050_059_RAD_IF_G.assign(Color=None)
                    df_050_059_RAD_IF_G  = df_050_059_RAD_IF_G.assign(Clarity=None)
                    df_050_059_RAD_IF_G  = df_050_059_RAD_IF_G.assign(Cut=None)
                    df_050_059_RAD_IF_G  = df_050_059_RAD_IF_G.assign(Polish=None)
                    df_050_059_RAD_IF_G  = df_050_059_RAD_IF_G.assign(Symmetry=None)
                    df_050_059_RAD_IF_G  = df_050_059_RAD_IF_G.assign(Ratio=None)
                    df_050_059_RAD_IF_G  = df_050_059_RAD_IF_G.assign(PPC=None)
                    df_050_059_RAD_IF_G  = df_050_059_RAD_IF_G.assign(Total=None)
                    df_050_059_RAD_IF_G ['Wt Range'] = listwtrange
                    df_050_059_RAD_IF_G ['Company'] = listcom
                    df_050_059_RAD_IF_G ['Shape'] = listshap
                    df_050_059_RAD_IF_G ['Carat'] = listcar
                    df_050_059_RAD_IF_G ['Color'] = listcol
                    df_050_059_RAD_IF_G ['Clarity'] = listclar
                    df_050_059_RAD_IF_G ['Cut'] = listcut
                    df_050_059_RAD_IF_G ['Polish'] = listpol
                    df_050_059_RAD_IF_G ['Symmetry'] = listsym
                    df_050_059_RAD_IF_G ['Ratio'] = listrat
                    df_050_059_RAD_IF_G ['PPC'] = listdesc
                    df_050_059_RAD_IF_G ['Total'] = listtotal
                    df_050_059_RAD_IF_G['Carat'] = df_050_059_RAD_IF_G['Carat'].astype('float64')
                    df_050_059_RAD_IF_G['PPC'] = df_050_059_RAD_IF_G['PPC'].astype('float64')
                    df_050_059_RAD_IF_G['Total'] = df_050_059_RAD_IF_G['Total'].astype('float64')
                    df_050_059_RAD_IF_G['Total'] = df_050_059_RAD_IF_G['Carat'] * df_050_059_RAD_IF_G['PPC']



                elif i=="G" and j == "VVS1" and k == "RAD":
                    df_050_059_RAD_VVS1_G = pd.DataFrame()
                    df_050_059_RAD_VVS1_G ['Wt Range'] = None
                    df_050_059_RAD_VVS1_G  = df_050_059_RAD_VVS1_G.assign(Company=None)
                    df_050_059_RAD_VVS1_G  = df_050_059_RAD_VVS1_G.assign(Shape=None)
                    df_050_059_RAD_VVS1_G  = df_050_059_RAD_VVS1_G.assign(Carat=None)
                    df_050_059_RAD_VVS1_G  = df_050_059_RAD_VVS1_G.assign(Color=None)
                    df_050_059_RAD_VVS1_G  = df_050_059_RAD_VVS1_G.assign(Clarity=None)
                    df_050_059_RAD_VVS1_G  = df_050_059_RAD_VVS1_G.assign(Cut=None)
                    df_050_059_RAD_VVS1_G  = df_050_059_RAD_VVS1_G.assign(Polish=None)
                    df_050_059_RAD_VVS1_G  = df_050_059_RAD_VVS1_G.assign(Symmetry=None)
                    df_050_059_RAD_VVS1_G  = df_050_059_RAD_VVS1_G.assign(Ratio=None)
                    df_050_059_RAD_VVS1_G  = df_050_059_RAD_VVS1_G.assign(PPC=None)
                    df_050_059_RAD_VVS1_G  = df_050_059_RAD_VVS1_G.assign(Total=None)
                    df_050_059_RAD_VVS1_G ['Wt Range'] = listwtrange
                    df_050_059_RAD_VVS1_G ['Company'] = listcom
                    df_050_059_RAD_VVS1_G ['Shape'] = listshap
                    df_050_059_RAD_VVS1_G ['Carat'] = listcar
                    df_050_059_RAD_VVS1_G ['Color'] = listcol
                    df_050_059_RAD_VVS1_G ['Clarity'] = listclar
                    df_050_059_RAD_VVS1_G ['Cut'] = listcut
                    df_050_059_RAD_VVS1_G ['Polish'] = listpol
                    df_050_059_RAD_VVS1_G ['Symmetry'] = listsym
                    df_050_059_RAD_VVS1_G ['Ratio'] = listrat
                    df_050_059_RAD_VVS1_G ['PPC'] = listdesc
                    df_050_059_RAD_VVS1_G ['Total'] = listtotal
                    df_050_059_RAD_VVS1_G['Carat'] = df_050_059_RAD_VVS1_G['Carat'].astype('float64')
                    df_050_059_RAD_VVS1_G['PPC'] = df_050_059_RAD_VVS1_G['PPC'].astype('float64')
                    df_050_059_RAD_VVS1_G['Total'] = df_050_059_RAD_VVS1_G['Total'].astype('float64')
                    df_050_059_RAD_VVS1_G['Total'] = df_050_059_RAD_VVS1_G['Carat'] * df_050_059_RAD_VVS1_G['PPC']


                elif i=="G" and j == "VVS2" and k == "RAD":
                    df_050_059_RAD_VVS2_G = pd.DataFrame()
                    df_050_059_RAD_VVS2_G ['Wt Range'] = None
                    df_050_059_RAD_VVS2_G  = df_050_059_RAD_VVS2_G.assign(Company=None)
                    df_050_059_RAD_VVS2_G  = df_050_059_RAD_VVS2_G.assign(Shape=None)
                    df_050_059_RAD_VVS2_G  = df_050_059_RAD_VVS2_G.assign(Carat=None)
                    df_050_059_RAD_VVS2_G  = df_050_059_RAD_VVS2_G.assign(Color=None)
                    df_050_059_RAD_VVS2_G  = df_050_059_RAD_VVS2_G.assign(Clarity=None)
                    df_050_059_RAD_VVS2_G  = df_050_059_RAD_VVS2_G.assign(Cut=None)
                    df_050_059_RAD_VVS2_G  = df_050_059_RAD_VVS2_G.assign(Polish=None)
                    df_050_059_RAD_VVS2_G  = df_050_059_RAD_VVS2_G.assign(Symmetry=None)
                    df_050_059_RAD_VVS2_G  = df_050_059_RAD_VVS2_G.assign(Ratio=None)
                    df_050_059_RAD_VVS2_G  = df_050_059_RAD_VVS2_G.assign(PPC=None)
                    df_050_059_RAD_VVS2_G  = df_050_059_RAD_VVS2_G.assign(Total=None)
                    df_050_059_RAD_VVS2_G ['Wt Range'] = listwtrange
                    df_050_059_RAD_VVS2_G ['Company'] = listcom
                    df_050_059_RAD_VVS2_G ['Shape'] = listshap
                    df_050_059_RAD_VVS2_G ['Carat'] = listcar
                    df_050_059_RAD_VVS2_G ['Color'] = listcol
                    df_050_059_RAD_VVS2_G ['Clarity'] = listclar
                    df_050_059_RAD_VVS2_G ['Cut'] = listcut
                    df_050_059_RAD_VVS2_G ['Polish'] = listpol
                    df_050_059_RAD_VVS2_G ['Symmetry'] = listsym
                    df_050_059_RAD_VVS2_G ['Ratio'] = listrat
                    df_050_059_RAD_VVS2_G ['PPC'] = listdesc
                    df_050_059_RAD_VVS2_G ['Total'] = listtotal
                    df_050_059_RAD_VVS2_G['Carat'] = df_050_059_RAD_VVS2_G['Carat'].astype('float64')
                    df_050_059_RAD_VVS2_G['PPC'] = df_050_059_RAD_VVS2_G['PPC'].astype('float64')
                    df_050_059_RAD_VVS2_G['Total'] = df_050_059_RAD_VVS2_G['Total'].astype('float64')
                    df_050_059_RAD_VVS2_G['Total'] = df_050_059_RAD_VVS2_G['Carat'] * df_050_059_RAD_VVS2_G['PPC']


                elif i=="G" and j=="VS1" and k == "RAD":
                    df_050_059_RAD_VS1_G = pd.DataFrame()
                    df_050_059_RAD_VS1_G ['Wt Range'] = None
                    df_050_059_RAD_VS1_G  = df_050_059_RAD_VS1_G.assign(Company=None)
                    df_050_059_RAD_VS1_G  = df_050_059_RAD_VS1_G.assign(Shape=None)
                    df_050_059_RAD_VS1_G  = df_050_059_RAD_VS1_G.assign(Carat=None)
                    df_050_059_RAD_VS1_G  = df_050_059_RAD_VS1_G.assign(Color=None)
                    df_050_059_RAD_VS1_G  = df_050_059_RAD_VS1_G.assign(Clarity=None)
                    df_050_059_RAD_VS1_G  = df_050_059_RAD_VS1_G.assign(Cut=None)
                    df_050_059_RAD_VS1_G  = df_050_059_RAD_VS1_G.assign(Polish=None)
                    df_050_059_RAD_VS1_G  = df_050_059_RAD_VS1_G.assign(Symmetry=None)
                    df_050_059_RAD_VS1_G  = df_050_059_RAD_VS1_G.assign(Ratio=None)
                    df_050_059_RAD_VS1_G  = df_050_059_RAD_VS1_G.assign(PPC=None)
                    df_050_059_RAD_VS1_G  = df_050_059_RAD_VS1_G.assign(Total=None)
                    df_050_059_RAD_VS1_G ['Wt Range'] = listwtrange
                    df_050_059_RAD_VS1_G ['Company'] = listcom
                    df_050_059_RAD_VS1_G ['Shape'] = listshap
                    df_050_059_RAD_VS1_G ['Carat'] = listcar
                    df_050_059_RAD_VS1_G ['Color'] = listcol
                    df_050_059_RAD_VS1_G ['Clarity'] = listclar
                    df_050_059_RAD_VS1_G ['Cut'] = listcut
                    df_050_059_RAD_VS1_G ['Polish'] = listpol
                    df_050_059_RAD_VS1_G ['Symmetry'] = listsym
                    df_050_059_RAD_VS1_G ['Ratio'] = listrat
                    df_050_059_RAD_VS1_G ['PPC'] = listdesc
                    df_050_059_RAD_VS1_G ['Total'] = listtotal
                    df_050_059_RAD_VS1_G['Carat'] = df_050_059_RAD_VS1_G['Carat'].astype('float64')
                    df_050_059_RAD_VS1_G['PPC'] = df_050_059_RAD_VS1_G['PPC'].astype('float64')
                    df_050_059_RAD_VS1_G['Total'] = df_050_059_RAD_VS1_G['Total'].astype('float64')
                    df_050_059_RAD_VS1_G['Total'] = df_050_059_RAD_VS1_G['Carat'] * df_050_059_RAD_VS1_G['PPC']


                elif i=="G" and j == "VS2" and k == "RAD":
                    df_050_059_RAD_VS2_G = pd.DataFrame()
                    df_050_059_RAD_VS2_G ['Wt Range'] = None
                    df_050_059_RAD_VS2_G  = df_050_059_RAD_VS2_G.assign(Company=None)
                    df_050_059_RAD_VS2_G  = df_050_059_RAD_VS2_G.assign(Shape=None)
                    df_050_059_RAD_VS2_G  = df_050_059_RAD_VS2_G.assign(Carat=None)
                    df_050_059_RAD_VS2_G  = df_050_059_RAD_VS2_G.assign(Color=None)
                    df_050_059_RAD_VS2_G  = df_050_059_RAD_VS2_G.assign(Clarity=None)
                    df_050_059_RAD_VS2_G  = df_050_059_RAD_VS2_G.assign(Cut=None)
                    df_050_059_RAD_VS2_G  = df_050_059_RAD_VS2_G.assign(Polish=None)
                    df_050_059_RAD_VS2_G  = df_050_059_RAD_VS2_G.assign(Symmetry=None)
                    df_050_059_RAD_VS2_G  = df_050_059_RAD_VS2_G.assign(Ratio=None)
                    df_050_059_RAD_VS2_G  = df_050_059_RAD_VS2_G.assign(PPC=None)
                    df_050_059_RAD_VS2_G  = df_050_059_RAD_VS2_G.assign(Total=None)
                    df_050_059_RAD_VS2_G ['Wt Range'] = listwtrange
                    df_050_059_RAD_VS2_G ['Company'] = listcom
                    df_050_059_RAD_VS2_G ['Shape'] = listshap
                    df_050_059_RAD_VS2_G ['Carat'] = listcar
                    df_050_059_RAD_VS2_G ['Color'] = listcol
                    df_050_059_RAD_VS2_G ['Clarity'] = listclar
                    df_050_059_RAD_VS2_G ['Cut'] = listcut
                    df_050_059_RAD_VS2_G ['Polish'] = listpol
                    df_050_059_RAD_VS2_G ['Symmetry'] = listsym
                    df_050_059_RAD_VS2_G ['Ratio'] = listrat
                    df_050_059_RAD_VS2_G ['PPC'] = listdesc
                    df_050_059_RAD_VS2_G ['Total'] = listtotal
                    df_050_059_RAD_VS2_G['Carat'] = df_050_059_RAD_VS2_G['Carat'].astype('float64')
                    df_050_059_RAD_VS2_G['PPC'] = df_050_059_RAD_VS2_G['PPC'].astype('float64')
                    df_050_059_RAD_VS2_G['Total'] = df_050_059_RAD_VS2_G['Total'].astype('float64')
                    df_050_059_RAD_VS2_G['Total'] = df_050_059_RAD_VS2_G['Carat'] * df_050_059_RAD_VS2_G['PPC']


                elif i=="G" and j == "SI1" and k == "RAD":
                    df_050_059_RAD_SI1_G = pd.DataFrame()
                    df_050_059_RAD_SI1_G ['Wt Range'] = None
                    df_050_059_RAD_SI1_G  = df_050_059_RAD_SI1_G.assign(Company=None)
                    df_050_059_RAD_SI1_G  = df_050_059_RAD_SI1_G.assign(Shape=None)
                    df_050_059_RAD_SI1_G  = df_050_059_RAD_SI1_G.assign(Carat=None)
                    df_050_059_RAD_SI1_G  = df_050_059_RAD_SI1_G.assign(Color=None)
                    df_050_059_RAD_SI1_G  = df_050_059_RAD_SI1_G.assign(Clarity=None)
                    df_050_059_RAD_SI1_G  = df_050_059_RAD_SI1_G.assign(Cut=None)
                    df_050_059_RAD_SI1_G  = df_050_059_RAD_SI1_G.assign(Polish=None)
                    df_050_059_RAD_SI1_G  = df_050_059_RAD_SI1_G.assign(Symmetry=None)
                    df_050_059_RAD_SI1_G  = df_050_059_RAD_SI1_G.assign(Ratio=None)
                    df_050_059_RAD_SI1_G  = df_050_059_RAD_SI1_G.assign(PPC=None)
                    df_050_059_RAD_SI1_G  = df_050_059_RAD_SI1_G.assign(Total=None)
                    df_050_059_RAD_SI1_G ['Wt Range'] = listwtrange
                    df_050_059_RAD_SI1_G ['Company'] = listcom
                    df_050_059_RAD_SI1_G ['Shape'] = listshap
                    df_050_059_RAD_SI1_G ['Carat'] = listcar
                    df_050_059_RAD_SI1_G ['Color'] = listcol
                    df_050_059_RAD_SI1_G ['Clarity'] = listclar
                    df_050_059_RAD_SI1_G ['Cut'] = listcut
                    df_050_059_RAD_SI1_G ['Polish'] = listpol
                    df_050_059_RAD_SI1_G ['Symmetry'] = listsym
                    df_050_059_RAD_SI1_G ['Ratio'] = listrat
                    df_050_059_RAD_SI1_G ['PPC'] = listdesc
                    df_050_059_RAD_SI1_G ['Total'] = listtotal
                    df_050_059_RAD_SI1_G['Carat'] = df_050_059_RAD_SI1_G['Carat'].astype('float64')
                    df_050_059_RAD_SI1_G['PPC'] = df_050_059_RAD_SI1_G['PPC'].astype('float64')
                    df_050_059_RAD_SI1_G['Total'] = df_050_059_RAD_SI1_G['Total'].astype('float64')
                    df_050_059_RAD_SI1_G['Total'] = df_050_059_RAD_SI1_G['Carat'] * df_050_059_RAD_SI1_G['PPC']


                elif i=="G" and j == "SI2" and k == "RAD":
                    df_050_059_RAD_SI2_G = pd.DataFrame()
                    df_050_059_RAD_SI2_G ['Wt Range'] = None
                    df_050_059_RAD_SI2_G  = df_050_059_RAD_SI2_G.assign(Company=None)
                    df_050_059_RAD_SI2_G  = df_050_059_RAD_SI2_G.assign(Shape=None)
                    df_050_059_RAD_SI2_G  = df_050_059_RAD_SI2_G.assign(Carat=None)
                    df_050_059_RAD_SI2_G  = df_050_059_RAD_SI2_G.assign(Color=None)
                    df_050_059_RAD_SI2_G  = df_050_059_RAD_SI2_G.assign(Clarity=None)
                    df_050_059_RAD_SI2_G  = df_050_059_RAD_SI2_G.assign(Cut=None)
                    df_050_059_RAD_SI2_G  = df_050_059_RAD_SI2_G.assign(Polish=None)
                    df_050_059_RAD_SI2_G  = df_050_059_RAD_SI2_G.assign(Symmetry=None)
                    df_050_059_RAD_SI2_G  = df_050_059_RAD_SI2_G.assign(Ratio=None)
                    df_050_059_RAD_SI2_G  = df_050_059_RAD_SI2_G.assign(PPC=None)
                    df_050_059_RAD_SI2_G  = df_050_059_RAD_SI2_G.assign(Total=None)
                    df_050_059_RAD_SI2_G ['Wt Range'] = listwtrange
                    df_050_059_RAD_SI2_G ['Company'] = listcom
                    df_050_059_RAD_SI2_G ['Shape'] = listshap
                    df_050_059_RAD_SI2_G ['Carat'] = listcar
                    df_050_059_RAD_SI2_G ['Color'] = listcol
                    df_050_059_RAD_SI2_G ['Clarity'] = listclar
                    df_050_059_RAD_SI2_G ['Cut'] = listcut
                    df_050_059_RAD_SI2_G ['Polish'] = listpol
                    df_050_059_RAD_SI2_G ['Symmetry'] = listsym
                    df_050_059_RAD_SI2_G ['Ratio'] = listrat
                    df_050_059_RAD_SI2_G ['PPC'] = listdesc
                    df_050_059_RAD_SI2_G ['Total'] = listtotal
                    df_050_059_RAD_SI2_G['Carat'] = df_050_059_RAD_SI2_G['Carat'].astype('float64')
                    df_050_059_RAD_SI2_G['PPC'] = df_050_059_RAD_SI2_G['PPC'].astype('float64')
                    df_050_059_RAD_SI2_G['Total'] = df_050_059_RAD_SI2_G['Total'].astype('float64')
                    df_050_059_RAD_SI2_G['Total'] = df_050_059_RAD_SI2_G['Carat'] * df_050_059_RAD_SI2_G['PPC']


                elif i=="G" and j == "I1" and k == "RAD":
                    df_050_059_RAD_I1_G = pd.DataFrame()
                    df_050_059_RAD_I1_G ['Wt Range'] = None
                    df_050_059_RAD_I1_G  = df_050_059_RAD_I1_G.assign(Company=None)
                    df_050_059_RAD_I1_G  = df_050_059_RAD_I1_G.assign(Shape=None)
                    df_050_059_RAD_I1_G  = df_050_059_RAD_I1_G.assign(Carat=None)
                    df_050_059_RAD_I1_G  = df_050_059_RAD_I1_G.assign(Color=None)
                    df_050_059_RAD_I1_G  = df_050_059_RAD_I1_G.assign(Clarity=None)
                    df_050_059_RAD_I1_G  = df_050_059_RAD_I1_G.assign(Cut=None)
                    df_050_059_RAD_I1_G  = df_050_059_RAD_I1_G.assign(Polish=None)
                    df_050_059_RAD_I1_G  = df_050_059_RAD_I1_G.assign(Symmetry=None)
                    df_050_059_RAD_I1_G  = df_050_059_RAD_I1_G.assign(Ratio=None)
                    df_050_059_RAD_I1_G  = df_050_059_RAD_I1_G.assign(PPC=None)
                    df_050_059_RAD_I1_G  = df_050_059_RAD_I1_G.assign(Total=None)
                    df_050_059_RAD_I1_G ['Wt Range'] = listwtrange
                    df_050_059_RAD_I1_G ['Company'] = listcom
                    df_050_059_RAD_I1_G ['Shape'] = listshap
                    df_050_059_RAD_I1_G ['Carat'] = listcar
                    df_050_059_RAD_I1_G ['Color'] = listcol
                    df_050_059_RAD_I1_G ['Clarity'] = listclar
                    df_050_059_RAD_I1_G ['Cut'] = listcut
                    df_050_059_RAD_I1_G ['Polish'] = listpol
                    df_050_059_RAD_I1_G ['Symmetry'] = listsym
                    df_050_059_RAD_I1_G ['Ratio'] = listrat
                    df_050_059_RAD_I1_G ['PPC'] = listdesc
                    df_050_059_RAD_I1_G ['Total'] = listtotal
                    df_050_059_RAD_I1_G['Carat'] = df_050_059_RAD_I1_G['Carat'].astype('float64')
                    df_050_059_RAD_I1_G['PPC'] = df_050_059_RAD_I1_G['PPC'].astype('float64')
                    df_050_059_RAD_I1_G['Total'] = df_050_059_RAD_I1_G['Total'].astype('float64')
                    df_050_059_RAD_I1_G['Total'] = df_050_059_RAD_I1_G['Carat'] * df_050_059_RAD_I1_G['PPC']


                elif i=="G" and j == "I2" and k == "RAD":
                    df_050_059_RAD_I2_G = pd.DataFrame()
                    df_050_059_RAD_I2_G ['Wt Range'] = None
                    df_050_059_RAD_I2_G  = df_050_059_RAD_I2_G.assign(Company=None)
                    df_050_059_RAD_I2_G  = df_050_059_RAD_I2_G.assign(Shape=None)
                    df_050_059_RAD_I2_G  = df_050_059_RAD_I2_G.assign(Carat=None)
                    df_050_059_RAD_I2_G  = df_050_059_RAD_I2_G.assign(Color=None)
                    df_050_059_RAD_I2_G  = df_050_059_RAD_I2_G.assign(Clarity=None)
                    df_050_059_RAD_I2_G  = df_050_059_RAD_I2_G.assign(Cut=None)
                    df_050_059_RAD_I2_G  = df_050_059_RAD_I2_G.assign(Polish=None)
                    df_050_059_RAD_I2_G  = df_050_059_RAD_I2_G.assign(Symmetry=None)
                    df_050_059_RAD_I2_G  = df_050_059_RAD_I2_G.assign(Ratio=None)
                    df_050_059_RAD_I2_G  = df_050_059_RAD_I2_G.assign(PPC=None)
                    df_050_059_RAD_I2_G  = df_050_059_RAD_I2_G.assign(Total=None)
                    df_050_059_RAD_I2_G ['Wt Range'] = listwtrange
                    df_050_059_RAD_I2_G ['Company'] = listcom
                    df_050_059_RAD_I2_G ['Shape'] = listshap
                    df_050_059_RAD_I2_G ['Carat'] = listcar
                    df_050_059_RAD_I2_G ['Color'] = listcol
                    df_050_059_RAD_I2_G ['Clarity'] = listclar
                    df_050_059_RAD_I2_G ['Cut'] = listcut
                    df_050_059_RAD_I2_G ['Polish'] = listpol
                    df_050_059_RAD_I2_G ['Symmetry'] = listsym
                    df_050_059_RAD_I2_G ['Ratio'] = listrat
                    df_050_059_RAD_I2_G ['PPC'] = listdesc
                    df_050_059_RAD_I2_G ['Total'] = listtotal
                    df_050_059_RAD_I2_G['Carat'] = df_050_059_RAD_I2_G['Carat'].astype('float64')
                    df_050_059_RAD_I2_G['PPC'] = df_050_059_RAD_I2_G['PPC'].astype('float64')
                    df_050_059_RAD_I2_G['Total'] = df_050_059_RAD_I2_G['Total'].astype('float64')
                    df_050_059_RAD_I2_G['Total'] = df_050_059_RAD_I2_G['Carat'] * df_050_059_RAD_I2_G['PPC']


                elif i=="H" and j == "IF" and k == "RAD":
                    df_050_059_RAD_IF_H = pd.DataFrame()
                    df_050_059_RAD_IF_H ['Wt Range'] = None
                    df_050_059_RAD_IF_H  = df_050_059_RAD_IF_H.assign(Company=None)
                    df_050_059_RAD_IF_H  = df_050_059_RAD_IF_H.assign(Shape=None)
                    df_050_059_RAD_IF_H  = df_050_059_RAD_IF_H.assign(Carat=None)
                    df_050_059_RAD_IF_H  = df_050_059_RAD_IF_H.assign(Color=None)
                    df_050_059_RAD_IF_H  = df_050_059_RAD_IF_H.assign(Clarity=None)
                    df_050_059_RAD_IF_H  = df_050_059_RAD_IF_H.assign(Cut=None)
                    df_050_059_RAD_IF_H  = df_050_059_RAD_IF_H.assign(Polish=None)
                    df_050_059_RAD_IF_H  = df_050_059_RAD_IF_H.assign(Symmetry=None)
                    df_050_059_RAD_IF_H  = df_050_059_RAD_IF_H.assign(Ratio=None)
                    df_050_059_RAD_IF_H  = df_050_059_RAD_IF_H.assign(PPC=None)
                    df_050_059_RAD_IF_H  = df_050_059_RAD_IF_H.assign(Total=None)
                    df_050_059_RAD_IF_H ['Wt Range'] = listwtrange
                    df_050_059_RAD_IF_H ['Company'] = listcom
                    df_050_059_RAD_IF_H ['Shape'] = listshap
                    df_050_059_RAD_IF_H ['Carat'] = listcar
                    df_050_059_RAD_IF_H ['Color'] = listcol
                    df_050_059_RAD_IF_H ['Clarity'] = listclar
                    df_050_059_RAD_IF_H ['Cut'] = listcut
                    df_050_059_RAD_IF_H ['Polish'] = listpol
                    df_050_059_RAD_IF_H ['Symmetry'] = listsym
                    df_050_059_RAD_IF_H ['Ratio'] = listrat
                    df_050_059_RAD_IF_H ['PPC'] = listdesc
                    df_050_059_RAD_IF_H ['Total'] = listtotal
                    df_050_059_RAD_IF_H['Carat'] = df_050_059_RAD_IF_H['Carat'].astype('float64')
                    df_050_059_RAD_IF_H['PPC'] = df_050_059_RAD_IF_H['PPC'].astype('float64')
                    df_050_059_RAD_IF_H['Total'] = df_050_059_RAD_IF_H['Total'].astype('float64')
                    df_050_059_RAD_IF_H['Total'] = df_050_059_RAD_IF_H['Carat'] * df_050_059_RAD_IF_H['PPC']



                elif i=="H" and j == "VVS1" and k == "RAD":
                    df_050_059_RAD_VVS1_H = pd.DataFrame()
                    df_050_059_RAD_VVS1_H ['Wt Range'] = None
                    df_050_059_RAD_VVS1_H  = df_050_059_RAD_VVS1_H.assign(Company=None)
                    df_050_059_RAD_VVS1_H  = df_050_059_RAD_VVS1_H.assign(Shape=None)
                    df_050_059_RAD_VVS1_H  = df_050_059_RAD_VVS1_H.assign(Carat=None)
                    df_050_059_RAD_VVS1_H  = df_050_059_RAD_VVS1_H.assign(Color=None)
                    df_050_059_RAD_VVS1_H  = df_050_059_RAD_VVS1_H.assign(Clarity=None)
                    df_050_059_RAD_VVS1_H  = df_050_059_RAD_VVS1_H.assign(Cut=None)
                    df_050_059_RAD_VVS1_H  = df_050_059_RAD_VVS1_H.assign(Polish=None)
                    df_050_059_RAD_VVS1_H  = df_050_059_RAD_VVS1_H.assign(Symmetry=None)
                    df_050_059_RAD_VVS1_H  = df_050_059_RAD_VVS1_H.assign(Ratio=None)
                    df_050_059_RAD_VVS1_H  = df_050_059_RAD_VVS1_H.assign(PPC=None)
                    df_050_059_RAD_VVS1_H  = df_050_059_RAD_VVS1_H.assign(Total=None)
                    df_050_059_RAD_VVS1_H ['Wt Range'] = listwtrange
                    df_050_059_RAD_VVS1_H ['Company'] = listcom
                    df_050_059_RAD_VVS1_H ['Shape'] = listshap
                    df_050_059_RAD_VVS1_H ['Carat'] = listcar
                    df_050_059_RAD_VVS1_H ['Color'] = listcol
                    df_050_059_RAD_VVS1_H ['Clarity'] = listclar
                    df_050_059_RAD_VVS1_H ['Cut'] = listcut
                    df_050_059_RAD_VVS1_H ['Polish'] = listpol
                    df_050_059_RAD_VVS1_H ['Symmetry'] = listsym
                    df_050_059_RAD_VVS1_H ['Ratio'] = listrat
                    df_050_059_RAD_VVS1_H ['PPC'] = listdesc
                    df_050_059_RAD_VVS1_H ['Total'] = listtotal
                    df_050_059_RAD_VVS1_H['Carat'] = df_050_059_RAD_VVS1_H['Carat'].astype('float64')
                    df_050_059_RAD_VVS1_H['PPC'] = df_050_059_RAD_VVS1_H['PPC'].astype('float64')
                    df_050_059_RAD_VVS1_H['Total'] = df_050_059_RAD_VVS1_H['Total'].astype('float64')
                    df_050_059_RAD_VVS1_H['Total'] = df_050_059_RAD_VVS1_H['Carat'] * df_050_059_RAD_VVS1_H['PPC']


                elif i=="H" and j == "VVS2" and k == "RAD":
                    df_050_059_RAD_VVS2_H = pd.DataFrame()
                    df_050_059_RAD_VVS2_H ['Wt Range'] = None
                    df_050_059_RAD_VVS2_H  = df_050_059_RAD_VVS2_H.assign(Company=None)
                    df_050_059_RAD_VVS2_H  = df_050_059_RAD_VVS2_H.assign(Shape=None)
                    df_050_059_RAD_VVS2_H  = df_050_059_RAD_VVS2_H.assign(Carat=None)
                    df_050_059_RAD_VVS2_H  = df_050_059_RAD_VVS2_H.assign(Color=None)
                    df_050_059_RAD_VVS2_H  = df_050_059_RAD_VVS2_H.assign(Clarity=None)
                    df_050_059_RAD_VVS2_H  = df_050_059_RAD_VVS2_H.assign(Cut=None)
                    df_050_059_RAD_VVS2_H  = df_050_059_RAD_VVS2_H.assign(Polish=None)
                    df_050_059_RAD_VVS2_H  = df_050_059_RAD_VVS2_H.assign(Symmetry=None)
                    df_050_059_RAD_VVS2_H  = df_050_059_RAD_VVS2_H.assign(Ratio=None)
                    df_050_059_RAD_VVS2_H  = df_050_059_RAD_VVS2_H.assign(PPC=None)
                    df_050_059_RAD_VVS2_H  = df_050_059_RAD_VVS2_H.assign(Total=None)
                    df_050_059_RAD_VVS2_H ['Wt Range'] = listwtrange
                    df_050_059_RAD_VVS2_H ['Company'] = listcom
                    df_050_059_RAD_VVS2_H ['Shape'] = listshap
                    df_050_059_RAD_VVS2_H ['Carat'] = listcar
                    df_050_059_RAD_VVS2_H ['Color'] = listcol
                    df_050_059_RAD_VVS2_H ['Clarity'] = listclar
                    df_050_059_RAD_VVS2_H ['Cut'] = listcut
                    df_050_059_RAD_VVS2_H ['Polish'] = listpol
                    df_050_059_RAD_VVS2_H ['Symmetry'] = listsym
                    df_050_059_RAD_VVS2_H ['Ratio'] = listrat
                    df_050_059_RAD_VVS2_H ['PPC'] = listdesc
                    df_050_059_RAD_VVS2_H ['Total'] = listtotal
                    df_050_059_RAD_VVS2_H['Carat'] = df_050_059_RAD_VVS2_H['Carat'].astype('float64')
                    df_050_059_RAD_VVS2_H['PPC'] = df_050_059_RAD_VVS2_H['PPC'].astype('float64')
                    df_050_059_RAD_VVS2_H['Total'] = df_050_059_RAD_VVS2_H['Total'].astype('float64')
                    df_050_059_RAD_VVS2_H['Total'] = df_050_059_RAD_VVS2_H['Carat'] * df_050_059_RAD_VVS2_H['PPC']


                elif i=="H" and j=="VS1" and k == "RAD":
                    df_050_059_RAD_VS1_H = pd.DataFrame()
                    df_050_059_RAD_VS1_H ['Wt Range'] = None
                    df_050_059_RAD_VS1_H  = df_050_059_RAD_VS1_H.assign(Company=None)
                    df_050_059_RAD_VS1_H  = df_050_059_RAD_VS1_H.assign(Shape=None)
                    df_050_059_RAD_VS1_H  = df_050_059_RAD_VS1_H.assign(Carat=None)
                    df_050_059_RAD_VS1_H  = df_050_059_RAD_VS1_H.assign(Color=None)
                    df_050_059_RAD_VS1_H  = df_050_059_RAD_VS1_H.assign(Clarity=None)
                    df_050_059_RAD_VS1_H  = df_050_059_RAD_VS1_H.assign(Cut=None)
                    df_050_059_RAD_VS1_H  = df_050_059_RAD_VS1_H.assign(Polish=None)
                    df_050_059_RAD_VS1_H  = df_050_059_RAD_VS1_H.assign(Symmetry=None)
                    df_050_059_RAD_VS1_H  = df_050_059_RAD_VS1_H.assign(Ratio=None)
                    df_050_059_RAD_VS1_H  = df_050_059_RAD_VS1_H.assign(PPC=None)
                    df_050_059_RAD_VS1_H  = df_050_059_RAD_VS1_H.assign(Total=None)
                    df_050_059_RAD_VS1_H ['Wt Range'] = listwtrange
                    df_050_059_RAD_VS1_H ['Company'] = listcom
                    df_050_059_RAD_VS1_H ['Shape'] = listshap
                    df_050_059_RAD_VS1_H ['Carat'] = listcar
                    df_050_059_RAD_VS1_H ['Color'] = listcol
                    df_050_059_RAD_VS1_H ['Clarity'] = listclar
                    df_050_059_RAD_VS1_H ['Cut'] = listcut
                    df_050_059_RAD_VS1_H ['Polish'] = listpol
                    df_050_059_RAD_VS1_H ['Symmetry'] = listsym
                    df_050_059_RAD_VS1_H ['Ratio'] = listrat
                    df_050_059_RAD_VS1_H ['PPC'] = listdesc
                    df_050_059_RAD_VS1_H ['Total'] = listtotal
                    df_050_059_RAD_VS1_H['Carat'] = df_050_059_RAD_VS1_H['Carat'].astype('float64')
                    df_050_059_RAD_VS1_H['PPC'] = df_050_059_RAD_VS1_H['PPC'].astype('float64')
                    df_050_059_RAD_VS1_H['Total'] = df_050_059_RAD_VS1_H['Total'].astype('float64')
                    df_050_059_RAD_VS1_H['Total'] = df_050_059_RAD_VS1_H['Carat'] * df_050_059_RAD_VS1_H['PPC']


                elif i=="H" and j == "VS2" and k == "RAD":
                    df_050_059_RAD_VS2_H = pd.DataFrame()
                    df_050_059_RAD_VS2_H ['Wt Range'] = None
                    df_050_059_RAD_VS2_H  = df_050_059_RAD_VS2_H.assign(Company=None)
                    df_050_059_RAD_VS2_H  = df_050_059_RAD_VS2_H.assign(Shape=None)
                    df_050_059_RAD_VS2_H  = df_050_059_RAD_VS2_H.assign(Carat=None)
                    df_050_059_RAD_VS2_H  = df_050_059_RAD_VS2_H.assign(Color=None)
                    df_050_059_RAD_VS2_H  = df_050_059_RAD_VS2_H.assign(Clarity=None)
                    df_050_059_RAD_VS2_H  = df_050_059_RAD_VS2_H.assign(Cut=None)
                    df_050_059_RAD_VS2_H  = df_050_059_RAD_VS2_H.assign(Polish=None)
                    df_050_059_RAD_VS2_H  = df_050_059_RAD_VS2_H.assign(Symmetry=None)
                    df_050_059_RAD_VS2_H  = df_050_059_RAD_VS2_H.assign(Ratio=None)
                    df_050_059_RAD_VS2_H  = df_050_059_RAD_VS2_H.assign(PPC=None)
                    df_050_059_RAD_VS2_H  = df_050_059_RAD_VS2_H.assign(Total=None)
                    df_050_059_RAD_VS2_H ['Wt Range'] = listwtrange
                    df_050_059_RAD_VS2_H ['Company'] = listcom
                    df_050_059_RAD_VS2_H ['Shape'] = listshap
                    df_050_059_RAD_VS2_H ['Carat'] = listcar
                    df_050_059_RAD_VS2_H ['Color'] = listcol
                    df_050_059_RAD_VS2_H ['Clarity'] = listclar
                    df_050_059_RAD_VS2_H ['Cut'] = listcut
                    df_050_059_RAD_VS2_H ['Polish'] = listpol
                    df_050_059_RAD_VS2_H ['Symmetry'] = listsym
                    df_050_059_RAD_VS2_H ['Ratio'] = listrat
                    df_050_059_RAD_VS2_H ['PPC'] = listdesc
                    df_050_059_RAD_VS2_H ['Total'] = listtotal
                    df_050_059_RAD_VS2_H['Carat'] = df_050_059_RAD_VS2_H['Carat'].astype('float64')
                    df_050_059_RAD_VS2_H['PPC'] = df_050_059_RAD_VS2_H['PPC'].astype('float64')
                    df_050_059_RAD_VS2_H['Total'] = df_050_059_RAD_VS2_H['Total'].astype('float64')
                    df_050_059_RAD_VS2_H['Total'] = df_050_059_RAD_VS2_H['Carat'] * df_050_059_RAD_VS2_H['PPC']


                elif i=="H" and j == "SI1" and k == "RAD":
                    df_050_059_RAD_SI1_H = pd.DataFrame()
                    df_050_059_RAD_SI1_H ['Wt Range'] = None
                    df_050_059_RAD_SI1_H  = df_050_059_RAD_SI1_H.assign(Company=None)
                    df_050_059_RAD_SI1_H  = df_050_059_RAD_SI1_H.assign(Shape=None)
                    df_050_059_RAD_SI1_H  = df_050_059_RAD_SI1_H.assign(Carat=None)
                    df_050_059_RAD_SI1_H  = df_050_059_RAD_SI1_H.assign(Color=None)
                    df_050_059_RAD_SI1_H  = df_050_059_RAD_SI1_H.assign(Clarity=None)
                    df_050_059_RAD_SI1_H  = df_050_059_RAD_SI1_H.assign(Cut=None)
                    df_050_059_RAD_SI1_H  = df_050_059_RAD_SI1_H.assign(Polish=None)
                    df_050_059_RAD_SI1_H  = df_050_059_RAD_SI1_H.assign(Symmetry=None)
                    df_050_059_RAD_SI1_H  = df_050_059_RAD_SI1_H.assign(Ratio=None)
                    df_050_059_RAD_SI1_H  = df_050_059_RAD_SI1_H.assign(PPC=None)
                    df_050_059_RAD_SI1_H  = df_050_059_RAD_SI1_H.assign(Total=None)
                    df_050_059_RAD_SI1_H ['Wt Range'] = listwtrange
                    df_050_059_RAD_SI1_H ['Company'] = listcom
                    df_050_059_RAD_SI1_H ['Shape'] = listshap
                    df_050_059_RAD_SI1_H ['Carat'] = listcar
                    df_050_059_RAD_SI1_H ['Color'] = listcol
                    df_050_059_RAD_SI1_H ['Clarity'] = listclar
                    df_050_059_RAD_SI1_H ['Cut'] = listcut
                    df_050_059_RAD_SI1_H ['Polish'] = listpol
                    df_050_059_RAD_SI1_H ['Symmetry'] = listsym
                    df_050_059_RAD_SI1_H ['Ratio'] = listrat
                    df_050_059_RAD_SI1_H ['PPC'] = listdesc
                    df_050_059_RAD_SI1_H ['Total'] = listtotal
                    df_050_059_RAD_SI1_H['Carat'] = df_050_059_RAD_SI1_H['Carat'].astype('float64')
                    df_050_059_RAD_SI1_H['PPC'] = df_050_059_RAD_SI1_H['PPC'].astype('float64')
                    df_050_059_RAD_SI1_H['Total'] = df_050_059_RAD_SI1_H['Total'].astype('float64')
                    df_050_059_RAD_SI1_H['Total'] = df_050_059_RAD_SI1_H['Carat'] * df_050_059_RAD_SI1_H['PPC']


                elif i=="H" and j == "SI2" and k == "RAD":
                    df_050_059_RAD_SI2_H = pd.DataFrame()
                    df_050_059_RAD_SI2_H ['Wt Range'] = None
                    df_050_059_RAD_SI2_H  = df_050_059_RAD_SI2_H.assign(Company=None)
                    df_050_059_RAD_SI2_H  = df_050_059_RAD_SI2_H.assign(Shape=None)
                    df_050_059_RAD_SI2_H  = df_050_059_RAD_SI2_H.assign(Carat=None)
                    df_050_059_RAD_SI2_H  = df_050_059_RAD_SI2_H.assign(Color=None)
                    df_050_059_RAD_SI2_H  = df_050_059_RAD_SI2_H.assign(Clarity=None)
                    df_050_059_RAD_SI2_H  = df_050_059_RAD_SI2_H.assign(Cut=None)
                    df_050_059_RAD_SI2_H  = df_050_059_RAD_SI2_H.assign(Polish=None)
                    df_050_059_RAD_SI2_H  = df_050_059_RAD_SI2_H.assign(Symmetry=None)
                    df_050_059_RAD_SI2_H  = df_050_059_RAD_SI2_H.assign(Ratio=None)
                    df_050_059_RAD_SI2_H  = df_050_059_RAD_SI2_H.assign(PPC=None)
                    df_050_059_RAD_SI2_H  = df_050_059_RAD_SI2_H.assign(Total=None)
                    df_050_059_RAD_SI2_H ['Wt Range'] = listwtrange
                    df_050_059_RAD_SI2_H ['Company'] = listcom
                    df_050_059_RAD_SI2_H ['Shape'] = listshap
                    df_050_059_RAD_SI2_H ['Carat'] = listcar
                    df_050_059_RAD_SI2_H ['Color'] = listcol
                    df_050_059_RAD_SI2_H ['Clarity'] = listclar
                    df_050_059_RAD_SI2_H ['Cut'] = listcut
                    df_050_059_RAD_SI2_H ['Polish'] = listpol
                    df_050_059_RAD_SI2_H ['Symmetry'] = listsym
                    df_050_059_RAD_SI2_H ['Ratio'] = listrat
                    df_050_059_RAD_SI2_H ['PPC'] = listdesc
                    df_050_059_RAD_SI2_H ['Total'] = listtotal
                    df_050_059_RAD_SI2_H['Carat'] = df_050_059_RAD_SI2_H['Carat'].astype('float64')
                    df_050_059_RAD_SI2_H['PPC'] = df_050_059_RAD_SI2_H['PPC'].astype('float64')
                    df_050_059_RAD_SI2_H['Total'] = df_050_059_RAD_SI2_H['Total'].astype('float64')
                    df_050_059_RAD_SI2_H['Total'] = df_050_059_RAD_SI2_H['Carat'] * df_050_059_RAD_SI2_H['PPC']


                elif i=="H" and j == "I1" and k == "RAD":
                    df_050_059_RAD_I1_H = pd.DataFrame()
                    df_050_059_RAD_I1_H ['Wt Range'] = None
                    df_050_059_RAD_I1_H  = df_050_059_RAD_I1_H.assign(Company=None)
                    df_050_059_RAD_I1_H  = df_050_059_RAD_I1_H.assign(Shape=None)
                    df_050_059_RAD_I1_H  = df_050_059_RAD_I1_H.assign(Carat=None)
                    df_050_059_RAD_I1_H  = df_050_059_RAD_I1_H.assign(Color=None)
                    df_050_059_RAD_I1_H  = df_050_059_RAD_I1_H.assign(Clarity=None)
                    df_050_059_RAD_I1_H  = df_050_059_RAD_I1_H.assign(Cut=None)
                    df_050_059_RAD_I1_H  = df_050_059_RAD_I1_H.assign(Polish=None)
                    df_050_059_RAD_I1_H  = df_050_059_RAD_I1_H.assign(Symmetry=None)
                    df_050_059_RAD_I1_H  = df_050_059_RAD_I1_H.assign(Ratio=None)
                    df_050_059_RAD_I1_H  = df_050_059_RAD_I1_H.assign(PPC=None)
                    df_050_059_RAD_I1_H  = df_050_059_RAD_I1_H.assign(Total=None)
                    df_050_059_RAD_I1_H ['Wt Range'] = listwtrange
                    df_050_059_RAD_I1_H ['Company'] = listcom
                    df_050_059_RAD_I1_H ['Shape'] = listshap
                    df_050_059_RAD_I1_H ['Carat'] = listcar
                    df_050_059_RAD_I1_H ['Color'] = listcol
                    df_050_059_RAD_I1_H ['Clarity'] = listclar
                    df_050_059_RAD_I1_H ['Cut'] = listcut
                    df_050_059_RAD_I1_H ['Polish'] = listpol
                    df_050_059_RAD_I1_H ['Symmetry'] = listsym
                    df_050_059_RAD_I1_H ['Ratio'] = listrat
                    df_050_059_RAD_I1_H ['PPC'] = listdesc
                    df_050_059_RAD_I1_H ['Total'] = listtotal
                    df_050_059_RAD_I1_H['Carat'] = df_050_059_RAD_I1_H['Carat'].astype('float64')
                    df_050_059_RAD_I1_H['PPC'] = df_050_059_RAD_I1_H['PPC'].astype('float64')
                    df_050_059_RAD_I1_H['Total'] = df_050_059_RAD_I1_H['Total'].astype('float64')
                    df_050_059_RAD_I1_H['Total'] = df_050_059_RAD_I1_H['Carat'] * df_050_059_RAD_I1_H['PPC']


                elif i=="H" and j == "I2" and k == "RAD":
                    df_050_059_RAD_I2_H = pd.DataFrame()
                    df_050_059_RAD_I2_H ['Wt Range'] = None
                    df_050_059_RAD_I2_H  = df_050_059_RAD_I2_H.assign(Company=None)
                    df_050_059_RAD_I2_H  = df_050_059_RAD_I2_H.assign(Shape=None)
                    df_050_059_RAD_I2_H  = df_050_059_RAD_I2_H.assign(Carat=None)
                    df_050_059_RAD_I2_H  = df_050_059_RAD_I2_H.assign(Color=None)
                    df_050_059_RAD_I2_H  = df_050_059_RAD_I2_H.assign(Clarity=None)
                    df_050_059_RAD_I2_H  = df_050_059_RAD_I2_H.assign(Cut=None)
                    df_050_059_RAD_I2_H  = df_050_059_RAD_I2_H.assign(Polish=None)
                    df_050_059_RAD_I2_H  = df_050_059_RAD_I2_H.assign(Symmetry=None)
                    df_050_059_RAD_I2_H  = df_050_059_RAD_I2_H.assign(Ratio=None)
                    df_050_059_RAD_I2_H  = df_050_059_RAD_I2_H.assign(PPC=None)
                    df_050_059_RAD_I2_H  = df_050_059_RAD_I2_H.assign(Total=None)
                    df_050_059_RAD_I2_H ['Wt Range'] = listwtrange
                    df_050_059_RAD_I2_H ['Company'] = listcom
                    df_050_059_RAD_I2_H ['Shape'] = listshap
                    df_050_059_RAD_I2_H ['Carat'] = listcar
                    df_050_059_RAD_I2_H ['Color'] = listcol
                    df_050_059_RAD_I2_H ['Clarity'] = listclar
                    df_050_059_RAD_I2_H ['Cut'] = listcut
                    df_050_059_RAD_I2_H ['Polish'] = listpol
                    df_050_059_RAD_I2_H ['Symmetry'] = listsym
                    df_050_059_RAD_I2_H ['Ratio'] = listrat
                    df_050_059_RAD_I2_H ['PPC'] = listdesc
                    df_050_059_RAD_I2_H ['Total'] = listtotal
                    df_050_059_RAD_I2_H['Carat'] = df_050_059_RAD_I2_H['Carat'].astype('float64')
                    df_050_059_RAD_I2_H['PPC'] = df_050_059_RAD_I2_H['PPC'].astype('float64')
                    df_050_059_RAD_I2_H['Total'] = df_050_059_RAD_I2_H['Total'].astype('float64')
                    df_050_059_RAD_I2_H['Total'] = df_050_059_RAD_I2_H['Carat'] * df_050_059_RAD_I2_H['PPC']



                elif i== "I" and j == "IF" and k == "RAD":
                    df_050_059_RAD_IF_I = pd.DataFrame()
                    df_050_059_RAD_IF_I ['Wt Range'] = None
                    df_050_059_RAD_IF_I  = df_050_059_RAD_IF_I.assign(Company=None)
                    df_050_059_RAD_IF_I  = df_050_059_RAD_IF_I.assign(Shape=None)
                    df_050_059_RAD_IF_I  = df_050_059_RAD_IF_I.assign(Carat=None)
                    df_050_059_RAD_IF_I  = df_050_059_RAD_IF_I.assign(Color=None)
                    df_050_059_RAD_IF_I  = df_050_059_RAD_IF_I.assign(Clarity=None)
                    df_050_059_RAD_IF_I  = df_050_059_RAD_IF_I.assign(Cut=None)
                    df_050_059_RAD_IF_I  = df_050_059_RAD_IF_I.assign(Polish=None)
                    df_050_059_RAD_IF_I  = df_050_059_RAD_IF_I.assign(Symmetry=None)
                    df_050_059_RAD_IF_I  = df_050_059_RAD_IF_I.assign(Ratio=None)
                    df_050_059_RAD_IF_I  = df_050_059_RAD_IF_I.assign(PPC=None)
                    df_050_059_RAD_IF_I  = df_050_059_RAD_IF_I.assign(Total=None)
                    df_050_059_RAD_IF_I ['Wt Range'] = listwtrange
                    df_050_059_RAD_IF_I ['Company'] = listcom
                    df_050_059_RAD_IF_I ['Shape'] = listshap
                    df_050_059_RAD_IF_I ['Carat'] = listcar
                    df_050_059_RAD_IF_I ['Color'] = listcol
                    df_050_059_RAD_IF_I ['Clarity'] = listclar
                    df_050_059_RAD_IF_I ['Cut'] = listcut
                    df_050_059_RAD_IF_I ['Polish'] = listpol
                    df_050_059_RAD_IF_I ['Symmetry'] = listsym
                    df_050_059_RAD_IF_I ['Ratio'] = listrat
                    df_050_059_RAD_IF_I ['PPC'] = listdesc
                    df_050_059_RAD_IF_I ['Total'] = listtotal
                    df_050_059_RAD_IF_I['Carat'] = df_050_059_RAD_IF_I['Carat'].astype('float64')
                    df_050_059_RAD_IF_I['PPC'] = df_050_059_RAD_IF_I['PPC'].astype('float64')
                    df_050_059_RAD_IF_I['Total'] = df_050_059_RAD_IF_I['Total'].astype('float64')
                    df_050_059_RAD_IF_I['Total'] = df_050_059_RAD_IF_I['Carat'] * df_050_059_RAD_IF_I['PPC']



                elif i== "I" and j == "VVS1" and k == "RAD":
                    df_050_059_RAD_VVS1_I = pd.DataFrame()
                    df_050_059_RAD_VVS1_I ['Wt Range'] = None
                    df_050_059_RAD_VVS1_I  = df_050_059_RAD_VVS1_I.assign(Company=None)
                    df_050_059_RAD_VVS1_I  = df_050_059_RAD_VVS1_I.assign(Shape=None)
                    df_050_059_RAD_VVS1_I  = df_050_059_RAD_VVS1_I.assign(Carat=None)
                    df_050_059_RAD_VVS1_I  = df_050_059_RAD_VVS1_I.assign(Color=None)
                    df_050_059_RAD_VVS1_I  = df_050_059_RAD_VVS1_I.assign(Clarity=None)
                    df_050_059_RAD_VVS1_I  = df_050_059_RAD_VVS1_I.assign(Cut=None)
                    df_050_059_RAD_VVS1_I  = df_050_059_RAD_VVS1_I.assign(Polish=None)
                    df_050_059_RAD_VVS1_I  = df_050_059_RAD_VVS1_I.assign(Symmetry=None)
                    df_050_059_RAD_VVS1_I  = df_050_059_RAD_VVS1_I.assign(Ratio=None)
                    df_050_059_RAD_VVS1_I  = df_050_059_RAD_VVS1_I.assign(PPC=None)
                    df_050_059_RAD_VVS1_I  = df_050_059_RAD_VVS1_I.assign(Total=None)
                    df_050_059_RAD_VVS1_I ['Wt Range'] = listwtrange
                    df_050_059_RAD_VVS1_I ['Company'] = listcom
                    df_050_059_RAD_VVS1_I ['Shape'] = listshap
                    df_050_059_RAD_VVS1_I ['Carat'] = listcar
                    df_050_059_RAD_VVS1_I ['Color'] = listcol
                    df_050_059_RAD_VVS1_I ['Clarity'] = listclar
                    df_050_059_RAD_VVS1_I ['Cut'] = listcut
                    df_050_059_RAD_VVS1_I ['Polish'] = listpol
                    df_050_059_RAD_VVS1_I ['Symmetry'] = listsym
                    df_050_059_RAD_VVS1_I ['Ratio'] = listrat
                    df_050_059_RAD_VVS1_I ['PPC'] = listdesc
                    df_050_059_RAD_VVS1_I ['Total'] = listtotal
                    df_050_059_RAD_VVS1_I['Carat'] = df_050_059_RAD_VVS1_I['Carat'].astype('float64')
                    df_050_059_RAD_VVS1_I['PPC'] = df_050_059_RAD_VVS1_I['PPC'].astype('float64')
                    df_050_059_RAD_VVS1_I['Total'] = df_050_059_RAD_VVS1_I['Total'].astype('float64')
                    df_050_059_RAD_VVS1_I['Total'] = df_050_059_RAD_VVS1_I['Carat'] * df_050_059_RAD_VVS1_I['PPC']


                elif i== "I" and j == "VVS2" and k == "RAD":
                    df_050_059_RAD_VVS2_I = pd.DataFrame()
                    df_050_059_RAD_VVS2_I ['Wt Range'] = None
                    df_050_059_RAD_VVS2_I  = df_050_059_RAD_VVS2_I.assign(Company=None)
                    df_050_059_RAD_VVS2_I  = df_050_059_RAD_VVS2_I.assign(Shape=None)
                    df_050_059_RAD_VVS2_I  = df_050_059_RAD_VVS2_I.assign(Carat=None)
                    df_050_059_RAD_VVS2_I  = df_050_059_RAD_VVS2_I.assign(Color=None)
                    df_050_059_RAD_VVS2_I  = df_050_059_RAD_VVS2_I.assign(Clarity=None)
                    df_050_059_RAD_VVS2_I  = df_050_059_RAD_VVS2_I.assign(Cut=None)
                    df_050_059_RAD_VVS2_I  = df_050_059_RAD_VVS2_I.assign(Polish=None)
                    df_050_059_RAD_VVS2_I  = df_050_059_RAD_VVS2_I.assign(Symmetry=None)
                    df_050_059_RAD_VVS2_I  = df_050_059_RAD_VVS2_I.assign(Ratio=None)
                    df_050_059_RAD_VVS2_I  = df_050_059_RAD_VVS2_I.assign(PPC=None)
                    df_050_059_RAD_VVS2_I  = df_050_059_RAD_VVS2_I.assign(Total=None)
                    df_050_059_RAD_VVS2_I ['Wt Range'] = listwtrange
                    df_050_059_RAD_VVS2_I ['Company'] = listcom
                    df_050_059_RAD_VVS2_I ['Shape'] = listshap
                    df_050_059_RAD_VVS2_I ['Carat'] = listcar
                    df_050_059_RAD_VVS2_I ['Color'] = listcol
                    df_050_059_RAD_VVS2_I ['Clarity'] = listclar
                    df_050_059_RAD_VVS2_I ['Cut'] = listcut
                    df_050_059_RAD_VVS2_I ['Polish'] = listpol
                    df_050_059_RAD_VVS2_I ['Symmetry'] = listsym
                    df_050_059_RAD_VVS2_I ['Ratio'] = listrat
                    df_050_059_RAD_VVS2_I ['PPC'] = listdesc
                    df_050_059_RAD_VVS2_I ['Total'] = listtotal
                    df_050_059_RAD_VVS2_I['Carat'] = df_050_059_RAD_VVS2_I['Carat'].astype('float64')
                    df_050_059_RAD_VVS2_I['PPC'] = df_050_059_RAD_VVS2_I['PPC'].astype('float64')
                    df_050_059_RAD_VVS2_I['Total'] = df_050_059_RAD_VVS2_I['Total'].astype('float64')
                    df_050_059_RAD_VVS2_I['Total'] = df_050_059_RAD_VVS2_I['Carat'] * df_050_059_RAD_VVS2_I['PPC']


                elif i== "I" and j=="VS1" and k == "RAD":
                    df_050_059_RAD_VS1_I = pd.DataFrame()
                    df_050_059_RAD_VS1_I ['Wt Range'] = None
                    df_050_059_RAD_VS1_I  = df_050_059_RAD_VS1_I.assign(Company=None)
                    df_050_059_RAD_VS1_I  = df_050_059_RAD_VS1_I.assign(Shape=None)
                    df_050_059_RAD_VS1_I  = df_050_059_RAD_VS1_I.assign(Carat=None)
                    df_050_059_RAD_VS1_I  = df_050_059_RAD_VS1_I.assign(Color=None)
                    df_050_059_RAD_VS1_I  = df_050_059_RAD_VS1_I.assign(Clarity=None)
                    df_050_059_RAD_VS1_I  = df_050_059_RAD_VS1_I.assign(Cut=None)
                    df_050_059_RAD_VS1_I  = df_050_059_RAD_VS1_I.assign(Polish=None)
                    df_050_059_RAD_VS1_I  = df_050_059_RAD_VS1_I.assign(Symmetry=None)
                    df_050_059_RAD_VS1_I  = df_050_059_RAD_VS1_I.assign(Ratio=None)
                    df_050_059_RAD_VS1_I  = df_050_059_RAD_VS1_I.assign(PPC=None)
                    df_050_059_RAD_VS1_I  = df_050_059_RAD_VS1_I.assign(Total=None)
                    df_050_059_RAD_VS1_I ['Wt Range'] = listwtrange
                    df_050_059_RAD_VS1_I ['Company'] = listcom
                    df_050_059_RAD_VS1_I ['Shape'] = listshap
                    df_050_059_RAD_VS1_I ['Carat'] = listcar
                    df_050_059_RAD_VS1_I ['Color'] = listcol
                    df_050_059_RAD_VS1_I ['Clarity'] = listclar
                    df_050_059_RAD_VS1_I ['Cut'] = listcut
                    df_050_059_RAD_VS1_I ['Polish'] = listpol
                    df_050_059_RAD_VS1_I ['Symmetry'] = listsym
                    df_050_059_RAD_VS1_I ['Ratio'] = listrat
                    df_050_059_RAD_VS1_I ['PPC'] = listdesc
                    df_050_059_RAD_VS1_I ['Total'] = listtotal
                    df_050_059_RAD_VS1_I['Carat'] = df_050_059_RAD_VS1_I['Carat'].astype('float64')
                    df_050_059_RAD_VS1_I['PPC'] = df_050_059_RAD_VS1_I['PPC'].astype('float64')
                    df_050_059_RAD_VS1_I['Total'] = df_050_059_RAD_VS1_I['Total'].astype('float64')
                    df_050_059_RAD_VS1_I['Total'] = df_050_059_RAD_VS1_I['Carat'] * df_050_059_RAD_VS1_I['PPC']


                elif i== "I" and j == "VS2" and k == "RAD":
                    df_050_059_RAD_VS2_I = pd.DataFrame()
                    df_050_059_RAD_VS2_I ['Wt Range'] = None
                    df_050_059_RAD_VS2_I  = df_050_059_RAD_VS2_I.assign(Company=None)
                    df_050_059_RAD_VS2_I  = df_050_059_RAD_VS2_I.assign(Shape=None)
                    df_050_059_RAD_VS2_I  = df_050_059_RAD_VS2_I.assign(Carat=None)
                    df_050_059_RAD_VS2_I  = df_050_059_RAD_VS2_I.assign(Color=None)
                    df_050_059_RAD_VS2_I  = df_050_059_RAD_VS2_I.assign(Clarity=None)
                    df_050_059_RAD_VS2_I  = df_050_059_RAD_VS2_I.assign(Cut=None)
                    df_050_059_RAD_VS2_I  = df_050_059_RAD_VS2_I.assign(Polish=None)
                    df_050_059_RAD_VS2_I  = df_050_059_RAD_VS2_I.assign(Symmetry=None)
                    df_050_059_RAD_VS2_I  = df_050_059_RAD_VS2_I.assign(Ratio=None)
                    df_050_059_RAD_VS2_I  = df_050_059_RAD_VS2_I.assign(PPC=None)
                    df_050_059_RAD_VS2_I  = df_050_059_RAD_VS2_I.assign(Total=None)
                    df_050_059_RAD_VS2_I ['Wt Range'] = listwtrange
                    df_050_059_RAD_VS2_I ['Company'] = listcom
                    df_050_059_RAD_VS2_I ['Shape'] = listshap
                    df_050_059_RAD_VS2_I ['Carat'] = listcar
                    df_050_059_RAD_VS2_I ['Color'] = listcol
                    df_050_059_RAD_VS2_I ['Clarity'] = listclar
                    df_050_059_RAD_VS2_I ['Cut'] = listcut
                    df_050_059_RAD_VS2_I ['Polish'] = listpol
                    df_050_059_RAD_VS2_I ['Symmetry'] = listsym
                    df_050_059_RAD_VS2_I ['Ratio'] = listrat
                    df_050_059_RAD_VS2_I ['PPC'] = listdesc
                    df_050_059_RAD_VS2_I ['Total'] = listtotal
                    df_050_059_RAD_VS2_I['Carat'] = df_050_059_RAD_VS2_I['Carat'].astype('float64')
                    df_050_059_RAD_VS2_I['PPC'] = df_050_059_RAD_VS2_I['PPC'].astype('float64')
                    df_050_059_RAD_VS2_I['Total'] = df_050_059_RAD_VS2_I['Total'].astype('float64')
                    df_050_059_RAD_VS2_I['Total'] = df_050_059_RAD_VS2_I['Carat'] * df_050_059_RAD_VS2_I['PPC']


                elif i== "I" and j == "SI1" and k == "RAD":
                    df_050_059_RAD_SI1_I = pd.DataFrame()
                    df_050_059_RAD_SI1_I ['Wt Range'] = None
                    df_050_059_RAD_SI1_I  = df_050_059_RAD_SI1_I.assign(Company=None)
                    df_050_059_RAD_SI1_I  = df_050_059_RAD_SI1_I.assign(Shape=None)
                    df_050_059_RAD_SI1_I  = df_050_059_RAD_SI1_I.assign(Carat=None)
                    df_050_059_RAD_SI1_I  = df_050_059_RAD_SI1_I.assign(Color=None)
                    df_050_059_RAD_SI1_I  = df_050_059_RAD_SI1_I.assign(Clarity=None)
                    df_050_059_RAD_SI1_I  = df_050_059_RAD_SI1_I.assign(Cut=None)
                    df_050_059_RAD_SI1_I  = df_050_059_RAD_SI1_I.assign(Polish=None)
                    df_050_059_RAD_SI1_I  = df_050_059_RAD_SI1_I.assign(Symmetry=None)
                    df_050_059_RAD_SI1_I  = df_050_059_RAD_SI1_I.assign(Ratio=None)
                    df_050_059_RAD_SI1_I  = df_050_059_RAD_SI1_I.assign(PPC=None)
                    df_050_059_RAD_SI1_I  = df_050_059_RAD_SI1_I.assign(Total=None)
                    df_050_059_RAD_SI1_I ['Wt Range'] = listwtrange
                    df_050_059_RAD_SI1_I ['Company'] = listcom
                    df_050_059_RAD_SI1_I ['Shape'] = listshap
                    df_050_059_RAD_SI1_I ['Carat'] = listcar
                    df_050_059_RAD_SI1_I ['Color'] = listcol
                    df_050_059_RAD_SI1_I ['Clarity'] = listclar
                    df_050_059_RAD_SI1_I ['Cut'] = listcut
                    df_050_059_RAD_SI1_I ['Polish'] = listpol
                    df_050_059_RAD_SI1_I ['Symmetry'] = listsym
                    df_050_059_RAD_SI1_I ['Ratio'] = listrat
                    df_050_059_RAD_SI1_I ['PPC'] = listdesc
                    df_050_059_RAD_SI1_I ['Total'] = listtotal
                    df_050_059_RAD_SI1_I['Carat'] = df_050_059_RAD_SI1_I['Carat'].astype('float64')
                    df_050_059_RAD_SI1_I['PPC'] = df_050_059_RAD_SI1_I['PPC'].astype('float64')
                    df_050_059_RAD_SI1_I['Total'] = df_050_059_RAD_SI1_I['Total'].astype('float64')
                    df_050_059_RAD_SI1_I['Total'] = df_050_059_RAD_SI1_I['Carat'] * df_050_059_RAD_SI1_I['PPC']


                elif i== "I" and j == "SI2" and k == "RAD":
                    df_050_059_RAD_SI2_I = pd.DataFrame()
                    df_050_059_RAD_SI2_I ['Wt Range'] = None
                    df_050_059_RAD_SI2_I  = df_050_059_RAD_SI2_I.assign(Company=None)
                    df_050_059_RAD_SI2_I  = df_050_059_RAD_SI2_I.assign(Shape=None)
                    df_050_059_RAD_SI2_I  = df_050_059_RAD_SI2_I.assign(Carat=None)
                    df_050_059_RAD_SI2_I  = df_050_059_RAD_SI2_I.assign(Color=None)
                    df_050_059_RAD_SI2_I  = df_050_059_RAD_SI2_I.assign(Clarity=None)
                    df_050_059_RAD_SI2_I  = df_050_059_RAD_SI2_I.assign(Cut=None)
                    df_050_059_RAD_SI2_I  = df_050_059_RAD_SI2_I.assign(Polish=None)
                    df_050_059_RAD_SI2_I  = df_050_059_RAD_SI2_I.assign(Symmetry=None)
                    df_050_059_RAD_SI2_I  = df_050_059_RAD_SI2_I.assign(Ratio=None)
                    df_050_059_RAD_SI2_I  = df_050_059_RAD_SI2_I.assign(PPC=None)
                    df_050_059_RAD_SI2_I  = df_050_059_RAD_SI2_I.assign(Total=None)
                    df_050_059_RAD_SI2_I ['Wt Range'] = listwtrange
                    df_050_059_RAD_SI2_I ['Company'] = listcom
                    df_050_059_RAD_SI2_I ['Shape'] = listshap
                    df_050_059_RAD_SI2_I ['Carat'] = listcar
                    df_050_059_RAD_SI2_I ['Color'] = listcol
                    df_050_059_RAD_SI2_I ['Clarity'] = listclar
                    df_050_059_RAD_SI2_I ['Cut'] = listcut
                    df_050_059_RAD_SI2_I ['Polish'] = listpol
                    df_050_059_RAD_SI2_I ['Symmetry'] = listsym
                    df_050_059_RAD_SI2_I ['Ratio'] = listrat
                    df_050_059_RAD_SI2_I ['PPC'] = listdesc
                    df_050_059_RAD_SI2_I ['Total'] = listtotal
                    df_050_059_RAD_SI2_I['Carat'] = df_050_059_RAD_SI2_I['Carat'].astype('float64')
                    df_050_059_RAD_SI2_I['PPC'] = df_050_059_RAD_SI2_I['PPC'].astype('float64')
                    df_050_059_RAD_SI2_I['Total'] = df_050_059_RAD_SI2_I['Total'].astype('float64')
                    df_050_059_RAD_SI2_I['Total'] = df_050_059_RAD_SI2_I['Carat'] * df_050_059_RAD_SI2_I['PPC']


                elif i== "I" and j == "I1" and k == "RAD":
                    df_050_059_RAD_I1_I = pd.DataFrame()
                    df_050_059_RAD_I1_I ['Wt Range'] = None
                    df_050_059_RAD_I1_I  = df_050_059_RAD_I1_I.assign(Company=None)
                    df_050_059_RAD_I1_I  = df_050_059_RAD_I1_I.assign(Shape=None)
                    df_050_059_RAD_I1_I  = df_050_059_RAD_I1_I.assign(Carat=None)
                    df_050_059_RAD_I1_I  = df_050_059_RAD_I1_I.assign(Color=None)
                    df_050_059_RAD_I1_I  = df_050_059_RAD_I1_I.assign(Clarity=None)
                    df_050_059_RAD_I1_I  = df_050_059_RAD_I1_I.assign(Cut=None)
                    df_050_059_RAD_I1_I  = df_050_059_RAD_I1_I.assign(Polish=None)
                    df_050_059_RAD_I1_I  = df_050_059_RAD_I1_I.assign(Symmetry=None)
                    df_050_059_RAD_I1_I  = df_050_059_RAD_I1_I.assign(Ratio=None)
                    df_050_059_RAD_I1_I  = df_050_059_RAD_I1_I.assign(PPC=None)
                    df_050_059_RAD_I1_I  = df_050_059_RAD_I1_I.assign(Total=None)
                    df_050_059_RAD_I1_I ['Wt Range'] = listwtrange
                    df_050_059_RAD_I1_I ['Company'] = listcom
                    df_050_059_RAD_I1_I ['Shape'] = listshap
                    df_050_059_RAD_I1_I ['Carat'] = listcar
                    df_050_059_RAD_I1_I ['Color'] = listcol
                    df_050_059_RAD_I1_I ['Clarity'] = listclar
                    df_050_059_RAD_I1_I ['Cut'] = listcut
                    df_050_059_RAD_I1_I ['Polish'] = listpol
                    df_050_059_RAD_I1_I ['Symmetry'] = listsym
                    df_050_059_RAD_I1_I ['Ratio'] = listrat
                    df_050_059_RAD_I1_I ['PPC'] = listdesc
                    df_050_059_RAD_I1_I ['Total'] = listtotal
                    df_050_059_RAD_I1_I['Carat'] = df_050_059_RAD_I1_I['Carat'].astype('float64')
                    df_050_059_RAD_I1_I['PPC'] = df_050_059_RAD_I1_I['PPC'].astype('float64')
                    df_050_059_RAD_I1_I['Total'] = df_050_059_RAD_I1_I['Total'].astype('float64')
                    df_050_059_RAD_I1_I['Total'] = df_050_059_RAD_I1_I['Carat'] * df_050_059_RAD_I1_I['PPC']


                elif i== "I" and j == "I2" and k == "RAD":
                    df_050_059_RAD_I2_I = pd.DataFrame()
                    df_050_059_RAD_I2_I ['Wt Range'] = None
                    df_050_059_RAD_I2_I  = df_050_059_RAD_I2_I.assign(Company=None)
                    df_050_059_RAD_I2_I  = df_050_059_RAD_I2_I.assign(Shape=None)
                    df_050_059_RAD_I2_I  = df_050_059_RAD_I2_I.assign(Carat=None)
                    df_050_059_RAD_I2_I  = df_050_059_RAD_I2_I.assign(Color=None)
                    df_050_059_RAD_I2_I  = df_050_059_RAD_I2_I.assign(Clarity=None)
                    df_050_059_RAD_I2_I  = df_050_059_RAD_I2_I.assign(Cut=None)
                    df_050_059_RAD_I2_I  = df_050_059_RAD_I2_I.assign(Polish=None)
                    df_050_059_RAD_I2_I  = df_050_059_RAD_I2_I.assign(Symmetry=None)
                    df_050_059_RAD_I2_I  = df_050_059_RAD_I2_I.assign(Ratio=None)
                    df_050_059_RAD_I2_I  = df_050_059_RAD_I2_I.assign(PPC=None)
                    df_050_059_RAD_I2_I  = df_050_059_RAD_I2_I.assign(Total=None)
                    df_050_059_RAD_I2_I ['Wt Range'] = listwtrange
                    df_050_059_RAD_I2_I ['Company'] = listcom
                    df_050_059_RAD_I2_I ['Shape'] = listshap
                    df_050_059_RAD_I2_I ['Carat'] = listcar
                    df_050_059_RAD_I2_I ['Color'] = listcol
                    df_050_059_RAD_I2_I ['Clarity'] = listclar
                    df_050_059_RAD_I2_I ['Cut'] = listcut
                    df_050_059_RAD_I2_I ['Polish'] = listpol
                    df_050_059_RAD_I2_I ['Symmetry'] = listsym
                    df_050_059_RAD_I2_I ['Ratio'] = listrat
                    df_050_059_RAD_I2_I ['PPC'] = listdesc
                    df_050_059_RAD_I2_I ['Total'] = listtotal
                    df_050_059_RAD_I2_I['Carat'] = df_050_059_RAD_I2_I['Carat'].astype('float64')
                    df_050_059_RAD_I2_I['PPC'] = df_050_059_RAD_I2_I['PPC'].astype('float64')
                    df_050_059_RAD_I2_I['Total'] = df_050_059_RAD_I2_I['Total'].astype('float64')
                    df_050_059_RAD_I2_I['Total'] = df_050_059_RAD_I2_I['Carat'] * df_050_059_RAD_I2_I['PPC']


                elif i=="J" and j == "IF" and k == "RAD":
                    df_050_059_RAD_IF_J = pd.DataFrame()
                    df_050_059_RAD_IF_J ['Wt Range'] = None
                    df_050_059_RAD_IF_J  = df_050_059_RAD_IF_J.assign(Company=None)
                    df_050_059_RAD_IF_J  = df_050_059_RAD_IF_J.assign(Shape=None)
                    df_050_059_RAD_IF_J  = df_050_059_RAD_IF_J.assign(Carat=None)
                    df_050_059_RAD_IF_J  = df_050_059_RAD_IF_J.assign(Color=None)
                    df_050_059_RAD_IF_J  = df_050_059_RAD_IF_J.assign(Clarity=None)
                    df_050_059_RAD_IF_J  = df_050_059_RAD_IF_J.assign(Cut=None)
                    df_050_059_RAD_IF_J  = df_050_059_RAD_IF_J.assign(Polish=None)
                    df_050_059_RAD_IF_J  = df_050_059_RAD_IF_J.assign(Symmetry=None)
                    df_050_059_RAD_IF_J  = df_050_059_RAD_IF_J.assign(Ratio=None)
                    df_050_059_RAD_IF_J  = df_050_059_RAD_IF_J.assign(PPC=None)
                    df_050_059_RAD_IF_J  = df_050_059_RAD_IF_J.assign(Total=None)
                    df_050_059_RAD_IF_J ['Wt Range'] = listwtrange
                    df_050_059_RAD_IF_J ['Company'] = listcom
                    df_050_059_RAD_IF_J ['Shape'] = listshap
                    df_050_059_RAD_IF_J ['Carat'] = listcar
                    df_050_059_RAD_IF_J ['Color'] = listcol
                    df_050_059_RAD_IF_J ['Clarity'] = listclar
                    df_050_059_RAD_IF_J ['Cut'] = listcut
                    df_050_059_RAD_IF_J ['Polish'] = listpol
                    df_050_059_RAD_IF_J ['Symmetry'] = listsym
                    df_050_059_RAD_IF_J ['Ratio'] = listrat
                    df_050_059_RAD_IF_J ['PPC'] = listdesc
                    df_050_059_RAD_IF_J ['Total'] = listtotal
                    df_050_059_RAD_IF_J['Carat'] = df_050_059_RAD_IF_J['Carat'].astype('float64')
                    df_050_059_RAD_IF_J['PPC'] = df_050_059_RAD_IF_J['PPC'].astype('float64')
                    df_050_059_RAD_IF_J['Total'] = df_050_059_RAD_IF_J['Total'].astype('float64')
                    df_050_059_RAD_IF_J['Total'] = df_050_059_RAD_IF_J['Carat'] * df_050_059_RAD_IF_J['PPC']



                elif i=="J"  and j == "VVS1" and k == "RAD":
                    df_050_059_RAD_VVS1_J = pd.DataFrame()
                    df_050_059_RAD_VVS1_J ['Wt Range'] = None
                    df_050_059_RAD_VVS1_J  = df_050_059_RAD_VVS1_J.assign(Company=None)
                    df_050_059_RAD_VVS1_J  = df_050_059_RAD_VVS1_J.assign(Shape=None)
                    df_050_059_RAD_VVS1_J  = df_050_059_RAD_VVS1_J.assign(Carat=None)
                    df_050_059_RAD_VVS1_J  = df_050_059_RAD_VVS1_J.assign(Color=None)
                    df_050_059_RAD_VVS1_J  = df_050_059_RAD_VVS1_J.assign(Clarity=None)
                    df_050_059_RAD_VVS1_J  = df_050_059_RAD_VVS1_J.assign(Cut=None)
                    df_050_059_RAD_VVS1_J  = df_050_059_RAD_VVS1_J.assign(Polish=None)
                    df_050_059_RAD_VVS1_J  = df_050_059_RAD_VVS1_J.assign(Symmetry=None)
                    df_050_059_RAD_VVS1_J  = df_050_059_RAD_VVS1_J.assign(Ratio=None)
                    df_050_059_RAD_VVS1_J  = df_050_059_RAD_VVS1_J.assign(PPC=None)
                    df_050_059_RAD_VVS1_J  = df_050_059_RAD_VVS1_J.assign(Total=None)
                    df_050_059_RAD_VVS1_J ['Wt Range'] = listwtrange
                    df_050_059_RAD_VVS1_J ['Company'] = listcom
                    df_050_059_RAD_VVS1_J ['Shape'] = listshap
                    df_050_059_RAD_VVS1_J ['Carat'] = listcar
                    df_050_059_RAD_VVS1_J ['Color'] = listcol
                    df_050_059_RAD_VVS1_J ['Clarity'] = listclar
                    df_050_059_RAD_VVS1_J ['Cut'] = listcut
                    df_050_059_RAD_VVS1_J ['Polish'] = listpol
                    df_050_059_RAD_VVS1_J ['Symmetry'] = listsym
                    df_050_059_RAD_VVS1_J ['Ratio'] = listrat
                    df_050_059_RAD_VVS1_J ['PPC'] = listdesc
                    df_050_059_RAD_VVS1_J ['Total'] = listtotal
                    df_050_059_RAD_VVS1_J['Carat'] = df_050_059_RAD_VVS1_J['Carat'].astype('float64')
                    df_050_059_RAD_VVS1_J['PPC'] = df_050_059_RAD_VVS1_J['PPC'].astype('float64')
                    df_050_059_RAD_VVS1_J['Total'] = df_050_059_RAD_VVS1_J['Total'].astype('float64')
                    df_050_059_RAD_VVS1_J['Total'] = df_050_059_RAD_VVS1_J['Carat'] * df_050_059_RAD_VVS1_J['PPC']


                elif i=="J"  and j == "VVS2" and k == "RAD":
                    df_050_059_RAD_VVS2_J = pd.DataFrame()
                    df_050_059_RAD_VVS2_J ['Wt Range'] = None
                    df_050_059_RAD_VVS2_J  = df_050_059_RAD_VVS2_J.assign(Company=None)
                    df_050_059_RAD_VVS2_J  = df_050_059_RAD_VVS2_J.assign(Shape=None)
                    df_050_059_RAD_VVS2_J  = df_050_059_RAD_VVS2_J.assign(Carat=None)
                    df_050_059_RAD_VVS2_J  = df_050_059_RAD_VVS2_J.assign(Color=None)
                    df_050_059_RAD_VVS2_J  = df_050_059_RAD_VVS2_J.assign(Clarity=None)
                    df_050_059_RAD_VVS2_J  = df_050_059_RAD_VVS2_J.assign(Cut=None)
                    df_050_059_RAD_VVS2_J  = df_050_059_RAD_VVS2_J.assign(Polish=None)
                    df_050_059_RAD_VVS2_J  = df_050_059_RAD_VVS2_J.assign(Symmetry=None)
                    df_050_059_RAD_VVS2_J  = df_050_059_RAD_VVS2_J.assign(Ratio=None)
                    df_050_059_RAD_VVS2_J  = df_050_059_RAD_VVS2_J.assign(PPC=None)
                    df_050_059_RAD_VVS2_J  = df_050_059_RAD_VVS2_J.assign(Total=None)
                    df_050_059_RAD_VVS2_J ['Wt Range'] = listwtrange
                    df_050_059_RAD_VVS2_J ['Company'] = listcom
                    df_050_059_RAD_VVS2_J ['Shape'] = listshap
                    df_050_059_RAD_VVS2_J ['Carat'] = listcar
                    df_050_059_RAD_VVS2_J ['Color'] = listcol
                    df_050_059_RAD_VVS2_J ['Clarity'] = listclar
                    df_050_059_RAD_VVS2_J ['Cut'] = listcut
                    df_050_059_RAD_VVS2_J ['Polish'] = listpol
                    df_050_059_RAD_VVS2_J ['Symmetry'] = listsym
                    df_050_059_RAD_VVS2_J ['Ratio'] = listrat
                    df_050_059_RAD_VVS2_J ['PPC'] = listdesc
                    df_050_059_RAD_VVS2_J ['Total'] = listtotal
                    df_050_059_RAD_VVS2_J['Carat'] = df_050_059_RAD_VVS2_J['Carat'].astype('float64')
                    df_050_059_RAD_VVS2_J['PPC'] = df_050_059_RAD_VVS2_J['PPC'].astype('float64')
                    df_050_059_RAD_VVS2_J['Total'] = df_050_059_RAD_VVS2_J['Total'].astype('float64')
                    df_050_059_RAD_VVS2_J['Total'] = df_050_059_RAD_VVS2_J['Carat'] * df_050_059_RAD_VVS2_J['PPC']


                elif i=="J"  and j=="VS1" and k == "RAD":
                    df_050_059_RAD_VS1_J = pd.DataFrame()
                    df_050_059_RAD_VS1_J ['Wt Range'] = None
                    df_050_059_RAD_VS1_J  = df_050_059_RAD_VS1_J.assign(Company=None)
                    df_050_059_RAD_VS1_J  = df_050_059_RAD_VS1_J.assign(Shape=None)
                    df_050_059_RAD_VS1_J  = df_050_059_RAD_VS1_J.assign(Carat=None)
                    df_050_059_RAD_VS1_J  = df_050_059_RAD_VS1_J.assign(Color=None)
                    df_050_059_RAD_VS1_J  = df_050_059_RAD_VS1_J.assign(Clarity=None)
                    df_050_059_RAD_VS1_J  = df_050_059_RAD_VS1_J.assign(Cut=None)
                    df_050_059_RAD_VS1_J  = df_050_059_RAD_VS1_J.assign(Polish=None)
                    df_050_059_RAD_VS1_J  = df_050_059_RAD_VS1_J.assign(Symmetry=None)
                    df_050_059_RAD_VS1_J  = df_050_059_RAD_VS1_J.assign(Ratio=None)
                    df_050_059_RAD_VS1_J  = df_050_059_RAD_VS1_J.assign(PPC=None)
                    df_050_059_RAD_VS1_J  = df_050_059_RAD_VS1_J.assign(Total=None)
                    df_050_059_RAD_VS1_J ['Wt Range'] = listwtrange
                    df_050_059_RAD_VS1_J ['Company'] = listcom
                    df_050_059_RAD_VS1_J ['Shape'] = listshap
                    df_050_059_RAD_VS1_J ['Carat'] = listcar
                    df_050_059_RAD_VS1_J ['Color'] = listcol
                    df_050_059_RAD_VS1_J ['Clarity'] = listclar
                    df_050_059_RAD_VS1_J ['Cut'] = listcut
                    df_050_059_RAD_VS1_J ['Polish'] = listpol
                    df_050_059_RAD_VS1_J ['Symmetry'] = listsym
                    df_050_059_RAD_VS1_J ['Ratio'] = listrat
                    df_050_059_RAD_VS1_J ['PPC'] = listdesc
                    df_050_059_RAD_VS1_J ['Total'] = listtotal
                    df_050_059_RAD_VS1_J['Carat'] = df_050_059_RAD_VS1_J['Carat'].astype('float64')
                    df_050_059_RAD_VS1_J['PPC'] = df_050_059_RAD_VS1_J['PPC'].astype('float64')
                    df_050_059_RAD_VS1_J['Total'] = df_050_059_RAD_VS1_J['Total'].astype('float64')
                    df_050_059_RAD_VS1_J['Total'] = df_050_059_RAD_VS1_J['Carat'] * df_050_059_RAD_VS1_J['PPC']


                elif i=="J"  and j == "VS2" and k == "RAD":
                    df_050_059_RAD_VS2_J = pd.DataFrame()
                    df_050_059_RAD_VS2_J ['Wt Range'] = None
                    df_050_059_RAD_VS2_J  = df_050_059_RAD_VS2_J.assign(Company=None)
                    df_050_059_RAD_VS2_J  = df_050_059_RAD_VS2_J.assign(Shape=None)
                    df_050_059_RAD_VS2_J  = df_050_059_RAD_VS2_J.assign(Carat=None)
                    df_050_059_RAD_VS2_J  = df_050_059_RAD_VS2_J.assign(Color=None)
                    df_050_059_RAD_VS2_J  = df_050_059_RAD_VS2_J.assign(Clarity=None)
                    df_050_059_RAD_VS2_J  = df_050_059_RAD_VS2_J.assign(Cut=None)
                    df_050_059_RAD_VS2_J  = df_050_059_RAD_VS2_J.assign(Polish=None)
                    df_050_059_RAD_VS2_J  = df_050_059_RAD_VS2_J.assign(Symmetry=None)
                    df_050_059_RAD_VS2_J  = df_050_059_RAD_VS2_J.assign(Ratio=None)
                    df_050_059_RAD_VS2_J  = df_050_059_RAD_VS2_J.assign(PPC=None)
                    df_050_059_RAD_VS2_J  = df_050_059_RAD_VS2_J.assign(Total=None)
                    df_050_059_RAD_VS2_J ['Wt Range'] = listwtrange
                    df_050_059_RAD_VS2_J ['Company'] = listcom
                    df_050_059_RAD_VS2_J ['Shape'] = listshap
                    df_050_059_RAD_VS2_J ['Carat'] = listcar
                    df_050_059_RAD_VS2_J ['Color'] = listcol
                    df_050_059_RAD_VS2_J ['Clarity'] = listclar
                    df_050_059_RAD_VS2_J ['Cut'] = listcut
                    df_050_059_RAD_VS2_J ['Polish'] = listpol
                    df_050_059_RAD_VS2_J ['Symmetry'] = listsym
                    df_050_059_RAD_VS2_J ['Ratio'] = listrat
                    df_050_059_RAD_VS2_J ['PPC'] = listdesc
                    df_050_059_RAD_VS2_J ['Total'] = listtotal
                    df_050_059_RAD_VS2_J['Carat'] = df_050_059_RAD_VS2_J['Carat'].astype('float64')
                    df_050_059_RAD_VS2_J['PPC'] = df_050_059_RAD_VS2_J['PPC'].astype('float64')
                    df_050_059_RAD_VS2_J['Total'] = df_050_059_RAD_VS2_J['Total'].astype('float64')
                    df_050_059_RAD_VS2_J['Total'] = df_050_059_RAD_VS2_J['Carat'] * df_050_059_RAD_VS2_J['PPC']


                elif i=="J"  and j == "SI1" and k == "RAD":
                    df_050_059_RAD_SI1_J = pd.DataFrame()
                    df_050_059_RAD_SI1_J ['Wt Range'] = None
                    df_050_059_RAD_SI1_J  = df_050_059_RAD_SI1_J.assign(Company=None)
                    df_050_059_RAD_SI1_J  = df_050_059_RAD_SI1_J.assign(Shape=None)
                    df_050_059_RAD_SI1_J  = df_050_059_RAD_SI1_J.assign(Carat=None)
                    df_050_059_RAD_SI1_J  = df_050_059_RAD_SI1_J.assign(Color=None)
                    df_050_059_RAD_SI1_J  = df_050_059_RAD_SI1_J.assign(Clarity=None)
                    df_050_059_RAD_SI1_J  = df_050_059_RAD_SI1_J.assign(Cut=None)
                    df_050_059_RAD_SI1_J  = df_050_059_RAD_SI1_J.assign(Polish=None)
                    df_050_059_RAD_SI1_J  = df_050_059_RAD_SI1_J.assign(Symmetry=None)
                    df_050_059_RAD_SI1_J  = df_050_059_RAD_SI1_J.assign(Ratio=None)
                    df_050_059_RAD_SI1_J  = df_050_059_RAD_SI1_J.assign(PPC=None)
                    df_050_059_RAD_SI1_J  = df_050_059_RAD_SI1_J.assign(Total=None)
                    df_050_059_RAD_SI1_J ['Wt Range'] = listwtrange
                    df_050_059_RAD_SI1_J ['Company'] = listcom
                    df_050_059_RAD_SI1_J ['Shape'] = listshap
                    df_050_059_RAD_SI1_J ['Carat'] = listcar
                    df_050_059_RAD_SI1_J ['Color'] = listcol
                    df_050_059_RAD_SI1_J ['Clarity'] = listclar
                    df_050_059_RAD_SI1_J ['Cut'] = listcut
                    df_050_059_RAD_SI1_J ['Polish'] = listpol
                    df_050_059_RAD_SI1_J ['Symmetry'] = listsym
                    df_050_059_RAD_SI1_J ['Ratio'] = listrat
                    df_050_059_RAD_SI1_J ['PPC'] = listdesc
                    df_050_059_RAD_SI1_J ['Total'] = listtotal
                    df_050_059_RAD_SI1_J['Carat'] = df_050_059_RAD_SI1_J['Carat'].astype('float64')
                    df_050_059_RAD_SI1_J['PPC'] = df_050_059_RAD_SI1_J['PPC'].astype('float64')
                    df_050_059_RAD_SI1_J['Total'] = df_050_059_RAD_SI1_J['Total'].astype('float64')
                    df_050_059_RAD_SI1_J['Total'] = df_050_059_RAD_SI1_J['Carat'] * df_050_059_RAD_SI1_J['PPC']


                elif i=="J"  and j == "SI2" and k == "RAD":
                    df_050_059_RAD_SI2_J = pd.DataFrame()
                    df_050_059_RAD_SI2_J ['Wt Range'] = None
                    df_050_059_RAD_SI2_J  = df_050_059_RAD_SI2_J.assign(Company=None)
                    df_050_059_RAD_SI2_J  = df_050_059_RAD_SI2_J.assign(Shape=None)
                    df_050_059_RAD_SI2_J  = df_050_059_RAD_SI2_J.assign(Carat=None)
                    df_050_059_RAD_SI2_J  = df_050_059_RAD_SI2_J.assign(Color=None)
                    df_050_059_RAD_SI2_J  = df_050_059_RAD_SI2_J.assign(Clarity=None)
                    df_050_059_RAD_SI2_J  = df_050_059_RAD_SI2_J.assign(Cut=None)
                    df_050_059_RAD_SI2_J  = df_050_059_RAD_SI2_J.assign(Polish=None)
                    df_050_059_RAD_SI2_J  = df_050_059_RAD_SI2_J.assign(Symmetry=None)
                    df_050_059_RAD_SI2_J  = df_050_059_RAD_SI2_J.assign(Ratio=None)
                    df_050_059_RAD_SI2_J  = df_050_059_RAD_SI2_J.assign(PPC=None)
                    df_050_059_RAD_SI2_J  = df_050_059_RAD_SI2_J.assign(Total=None)
                    df_050_059_RAD_SI2_J ['Wt Range'] = listwtrange
                    df_050_059_RAD_SI2_J ['Company'] = listcom
                    df_050_059_RAD_SI2_J ['Shape'] = listshap
                    df_050_059_RAD_SI2_J ['Carat'] = listcar
                    df_050_059_RAD_SI2_J ['Color'] = listcol
                    df_050_059_RAD_SI2_J ['Clarity'] = listclar
                    df_050_059_RAD_SI2_J ['Cut'] = listcut
                    df_050_059_RAD_SI2_J ['Polish'] = listpol
                    df_050_059_RAD_SI2_J ['Symmetry'] = listsym
                    df_050_059_RAD_SI2_J ['Ratio'] = listrat
                    df_050_059_RAD_SI2_J ['PPC'] = listdesc
                    df_050_059_RAD_SI2_J ['Total'] = listtotal
                    df_050_059_RAD_SI2_J['Carat'] = df_050_059_RAD_SI2_J['Carat'].astype('float64')
                    df_050_059_RAD_SI2_J['PPC'] = df_050_059_RAD_SI2_J['PPC'].astype('float64')
                    df_050_059_RAD_SI2_J['Total'] = df_050_059_RAD_SI2_J['Total'].astype('float64')
                    df_050_059_RAD_SI2_J['Total'] = df_050_059_RAD_SI2_J['Carat'] * df_050_059_RAD_SI2_J['PPC']


                elif i=="J"  and j == "I1" and k == "RAD":
                    df_050_059_RAD_I1_J = pd.DataFrame()
                    df_050_059_RAD_I1_J ['Wt Range'] = None
                    df_050_059_RAD_I1_J  = df_050_059_RAD_I1_J.assign(Company=None)
                    df_050_059_RAD_I1_J  = df_050_059_RAD_I1_J.assign(Shape=None)
                    df_050_059_RAD_I1_J  = df_050_059_RAD_I1_J.assign(Carat=None)
                    df_050_059_RAD_I1_J  = df_050_059_RAD_I1_J.assign(Color=None)
                    df_050_059_RAD_I1_J  = df_050_059_RAD_I1_J.assign(Clarity=None)
                    df_050_059_RAD_I1_J  = df_050_059_RAD_I1_J.assign(Cut=None)
                    df_050_059_RAD_I1_J  = df_050_059_RAD_I1_J.assign(Polish=None)
                    df_050_059_RAD_I1_J  = df_050_059_RAD_I1_J.assign(Symmetry=None)
                    df_050_059_RAD_I1_J  = df_050_059_RAD_I1_J.assign(Ratio=None)
                    df_050_059_RAD_I1_J  = df_050_059_RAD_I1_J.assign(PPC=None)
                    df_050_059_RAD_I1_J  = df_050_059_RAD_I1_J.assign(Total=None)
                    df_050_059_RAD_I1_J ['Wt Range'] = listwtrange
                    df_050_059_RAD_I1_J ['Company'] = listcom
                    df_050_059_RAD_I1_J ['Shape'] = listshap
                    df_050_059_RAD_I1_J ['Carat'] = listcar
                    df_050_059_RAD_I1_J ['Color'] = listcol
                    df_050_059_RAD_I1_J ['Clarity'] = listclar
                    df_050_059_RAD_I1_J ['Cut'] = listcut
                    df_050_059_RAD_I1_J ['Polish'] = listpol
                    df_050_059_RAD_I1_J ['Symmetry'] = listsym
                    df_050_059_RAD_I1_J ['Ratio'] = listrat
                    df_050_059_RAD_I1_J ['PPC'] = listdesc
                    df_050_059_RAD_I1_J ['Total'] = listtotal
                    df_050_059_RAD_I1_J['Carat'] = df_050_059_RAD_I1_J['Carat'].astype('float64')
                    df_050_059_RAD_I1_J['PPC'] = df_050_059_RAD_I1_J['PPC'].astype('float64')
                    df_050_059_RAD_I1_J['Total'] = df_050_059_RAD_I1_J['Total'].astype('float64')
                    df_050_059_RAD_I1_J['Total'] = df_050_059_RAD_I1_J['Carat'] * df_050_059_RAD_I1_J['PPC']


                elif i=="J"  and j == "I2" and k == "RAD":
                    df_050_059_RAD_I2_J = pd.DataFrame()
                    df_050_059_RAD_I2_J ['Wt Range'] = None
                    df_050_059_RAD_I2_J  = df_050_059_RAD_I2_J.assign(Company=None)
                    df_050_059_RAD_I2_J  = df_050_059_RAD_I2_J.assign(Shape=None)
                    df_050_059_RAD_I2_J  = df_050_059_RAD_I2_J.assign(Carat=None)
                    df_050_059_RAD_I2_J  = df_050_059_RAD_I2_J.assign(Color=None)
                    df_050_059_RAD_I2_J  = df_050_059_RAD_I2_J.assign(Clarity=None)
                    df_050_059_RAD_I2_J  = df_050_059_RAD_I2_J.assign(Cut=None)
                    df_050_059_RAD_I2_J  = df_050_059_RAD_I2_J.assign(Polish=None)
                    df_050_059_RAD_I2_J  = df_050_059_RAD_I2_J.assign(Symmetry=None)
                    df_050_059_RAD_I2_J  = df_050_059_RAD_I2_J.assign(Ratio=None)
                    df_050_059_RAD_I2_J  = df_050_059_RAD_I2_J.assign(PPC=None)
                    df_050_059_RAD_I2_J  = df_050_059_RAD_I2_J.assign(Total=None)
                    df_050_059_RAD_I2_J ['Wt Range'] = listwtrange
                    df_050_059_RAD_I2_J ['Company'] = listcom
                    df_050_059_RAD_I2_J ['Shape'] = listshap
                    df_050_059_RAD_I2_J ['Carat'] = listcar
                    df_050_059_RAD_I2_J ['Color'] = listcol
                    df_050_059_RAD_I2_J ['Clarity'] = listclar
                    df_050_059_RAD_I2_J ['Cut'] = listcut
                    df_050_059_RAD_I2_J ['Polish'] = listpol
                    df_050_059_RAD_I2_J ['Symmetry'] = listsym
                    df_050_059_RAD_I2_J ['Ratio'] = listrat
                    df_050_059_RAD_I2_J ['PPC'] = listdesc
                    df_050_059_RAD_I2_J ['Total'] = listtotal
                    df_050_059_RAD_I2_J['Carat'] = df_050_059_RAD_I2_J['Carat'].astype('float64')
                    df_050_059_RAD_I2_J['PPC'] = df_050_059_RAD_I2_J['PPC'].astype('float64')
                    df_050_059_RAD_I2_J['Total'] = df_050_059_RAD_I2_J['Total'].astype('float64')
                    df_050_059_RAD_I2_J['Total'] = df_050_059_RAD_I2_J['Carat'] * df_050_059_RAD_I2_J['PPC']


                elif i=="K" and j == "IF" and k == "RAD":
                    df_050_059_RAD_IF_K = pd.DataFrame()
                    df_050_059_RAD_IF_K ['Wt Range'] = None
                    df_050_059_RAD_IF_K  = df_050_059_RAD_IF_K.assign(Company=None)
                    df_050_059_RAD_IF_K  = df_050_059_RAD_IF_K.assign(Shape=None)
                    df_050_059_RAD_IF_K  = df_050_059_RAD_IF_K.assign(Carat=None)
                    df_050_059_RAD_IF_K  = df_050_059_RAD_IF_K.assign(Color=None)
                    df_050_059_RAD_IF_K  = df_050_059_RAD_IF_K.assign(Clarity=None)
                    df_050_059_RAD_IF_K  = df_050_059_RAD_IF_K.assign(Cut=None)
                    df_050_059_RAD_IF_K  = df_050_059_RAD_IF_K.assign(Polish=None)
                    df_050_059_RAD_IF_K  = df_050_059_RAD_IF_K.assign(Symmetry=None)
                    df_050_059_RAD_IF_K  = df_050_059_RAD_IF_K.assign(Ratio=None)
                    df_050_059_RAD_IF_K  = df_050_059_RAD_IF_K.assign(PPC=None)
                    df_050_059_RAD_IF_K  = df_050_059_RAD_IF_K.assign(Total=None)
                    df_050_059_RAD_IF_K ['Wt Range'] = listwtrange
                    df_050_059_RAD_IF_K ['Company'] = listcom
                    df_050_059_RAD_IF_K ['Shape'] = listshap
                    df_050_059_RAD_IF_K ['Carat'] = listcar
                    df_050_059_RAD_IF_K ['Color'] = listcol
                    df_050_059_RAD_IF_K ['Clarity'] = listclar
                    df_050_059_RAD_IF_K ['Cut'] = listcut
                    df_050_059_RAD_IF_K ['Polish'] = listpol
                    df_050_059_RAD_IF_K ['Symmetry'] = listsym
                    df_050_059_RAD_IF_K ['Ratio'] = listrat
                    df_050_059_RAD_IF_K ['PPC'] = listdesc
                    df_050_059_RAD_IF_K ['Total'] = listtotal
                    df_050_059_RAD_IF_K['Carat'] = df_050_059_RAD_IF_K['Carat'].astype('float64')
                    df_050_059_RAD_IF_K['PPC'] = df_050_059_RAD_IF_K['PPC'].astype('float64')
                    df_050_059_RAD_IF_K['Total'] = df_050_059_RAD_IF_K['Total'].astype('float64')
                    df_050_059_RAD_IF_K['Total'] = df_050_059_RAD_IF_K['Carat'] * df_050_059_RAD_IF_K['PPC']



                elif i=="K" and j == "VVS1" and k == "RAD":
                    df_050_059_RAD_VVS1_K = pd.DataFrame()
                    df_050_059_RAD_VVS1_K ['Wt Range'] = None
                    df_050_059_RAD_VVS1_K  = df_050_059_RAD_VVS1_K.assign(Company=None)
                    df_050_059_RAD_VVS1_K  = df_050_059_RAD_VVS1_K.assign(Shape=None)
                    df_050_059_RAD_VVS1_K  = df_050_059_RAD_VVS1_K.assign(Carat=None)
                    df_050_059_RAD_VVS1_K  = df_050_059_RAD_VVS1_K.assign(Color=None)
                    df_050_059_RAD_VVS1_K  = df_050_059_RAD_VVS1_K.assign(Clarity=None)
                    df_050_059_RAD_VVS1_K  = df_050_059_RAD_VVS1_K.assign(Cut=None)
                    df_050_059_RAD_VVS1_K  = df_050_059_RAD_VVS1_K.assign(Polish=None)
                    df_050_059_RAD_VVS1_K  = df_050_059_RAD_VVS1_K.assign(Symmetry=None)
                    df_050_059_RAD_VVS1_K  = df_050_059_RAD_VVS1_K.assign(Ratio=None)
                    df_050_059_RAD_VVS1_K  = df_050_059_RAD_VVS1_K.assign(PPC=None)
                    df_050_059_RAD_VVS1_K  = df_050_059_RAD_VVS1_K.assign(Total=None)
                    df_050_059_RAD_VVS1_K ['Wt Range'] = listwtrange
                    df_050_059_RAD_VVS1_K ['Company'] = listcom
                    df_050_059_RAD_VVS1_K ['Shape'] = listshap
                    df_050_059_RAD_VVS1_K ['Carat'] = listcar
                    df_050_059_RAD_VVS1_K ['Color'] = listcol
                    df_050_059_RAD_VVS1_K ['Clarity'] = listclar
                    df_050_059_RAD_VVS1_K ['Cut'] = listcut
                    df_050_059_RAD_VVS1_K ['Polish'] = listpol
                    df_050_059_RAD_VVS1_K ['Symmetry'] = listsym
                    df_050_059_RAD_VVS1_K ['Ratio'] = listrat
                    df_050_059_RAD_VVS1_K ['PPC'] = listdesc
                    df_050_059_RAD_VVS1_K ['Total'] = listtotal
                    df_050_059_RAD_VVS1_K['Carat'] = df_050_059_RAD_VVS1_K['Carat'].astype('float64')
                    df_050_059_RAD_VVS1_K['PPC'] = df_050_059_RAD_VVS1_K['PPC'].astype('float64')
                    df_050_059_RAD_VVS1_K['Total'] = df_050_059_RAD_VVS1_K['Total'].astype('float64')
                    df_050_059_RAD_VVS1_K['Total'] = df_050_059_RAD_VVS1_K['Carat'] * df_050_059_RAD_VVS1_K['PPC']


                elif i=="K" and j == "VVS2" and k == "RAD":
                    df_050_059_RAD_VVS2_K = pd.DataFrame()
                    df_050_059_RAD_VVS2_K ['Wt Range'] = None
                    df_050_059_RAD_VVS2_K  = df_050_059_RAD_VVS2_K.assign(Company=None)
                    df_050_059_RAD_VVS2_K  = df_050_059_RAD_VVS2_K.assign(Shape=None)
                    df_050_059_RAD_VVS2_K  = df_050_059_RAD_VVS2_K.assign(Carat=None)
                    df_050_059_RAD_VVS2_K  = df_050_059_RAD_VVS2_K.assign(Color=None)
                    df_050_059_RAD_VVS2_K  = df_050_059_RAD_VVS2_K.assign(Clarity=None)
                    df_050_059_RAD_VVS2_K  = df_050_059_RAD_VVS2_K.assign(Cut=None)
                    df_050_059_RAD_VVS2_K  = df_050_059_RAD_VVS2_K.assign(Polish=None)
                    df_050_059_RAD_VVS2_K  = df_050_059_RAD_VVS2_K.assign(Symmetry=None)
                    df_050_059_RAD_VVS2_K  = df_050_059_RAD_VVS2_K.assign(Ratio=None)
                    df_050_059_RAD_VVS2_K  = df_050_059_RAD_VVS2_K.assign(PPC=None)
                    df_050_059_RAD_VVS2_K  = df_050_059_RAD_VVS2_K.assign(Total=None)
                    df_050_059_RAD_VVS2_K ['Wt Range'] = listwtrange
                    df_050_059_RAD_VVS2_K ['Company'] = listcom
                    df_050_059_RAD_VVS2_K ['Shape'] = listshap
                    df_050_059_RAD_VVS2_K ['Carat'] = listcar
                    df_050_059_RAD_VVS2_K ['Color'] = listcol
                    df_050_059_RAD_VVS2_K ['Clarity'] = listclar
                    df_050_059_RAD_VVS2_K ['Cut'] = listcut
                    df_050_059_RAD_VVS2_K ['Polish'] = listpol
                    df_050_059_RAD_VVS2_K ['Symmetry'] = listsym
                    df_050_059_RAD_VVS2_K ['Ratio'] = listrat
                    df_050_059_RAD_VVS2_K ['PPC'] = listdesc
                    df_050_059_RAD_VVS2_K ['Total'] = listtotal
                    df_050_059_RAD_VVS2_K['Carat'] = df_050_059_RAD_VVS2_K['Carat'].astype('float64')
                    df_050_059_RAD_VVS2_K['PPC'] = df_050_059_RAD_VVS2_K['PPC'].astype('float64')
                    df_050_059_RAD_VVS2_K['Total'] = df_050_059_RAD_VVS2_K['Total'].astype('float64')
                    df_050_059_RAD_VVS2_K['Total'] = df_050_059_RAD_VVS2_K['Carat'] * df_050_059_RAD_VVS2_K['PPC']


                elif i=="K" and j=="VS1" and k == "RAD":
                    df_050_059_RAD_VS1_K = pd.DataFrame()
                    df_050_059_RAD_VS1_K ['Wt Range'] = None
                    df_050_059_RAD_VS1_K  = df_050_059_RAD_VS1_K.assign(Company=None)
                    df_050_059_RAD_VS1_K  = df_050_059_RAD_VS1_K.assign(Shape=None)
                    df_050_059_RAD_VS1_K  = df_050_059_RAD_VS1_K.assign(Carat=None)
                    df_050_059_RAD_VS1_K  = df_050_059_RAD_VS1_K.assign(Color=None)
                    df_050_059_RAD_VS1_K  = df_050_059_RAD_VS1_K.assign(Clarity=None)
                    df_050_059_RAD_VS1_K  = df_050_059_RAD_VS1_K.assign(Cut=None)
                    df_050_059_RAD_VS1_K  = df_050_059_RAD_VS1_K.assign(Polish=None)
                    df_050_059_RAD_VS1_K  = df_050_059_RAD_VS1_K.assign(Symmetry=None)
                    df_050_059_RAD_VS1_K  = df_050_059_RAD_VS1_K.assign(Ratio=None)
                    df_050_059_RAD_VS1_K  = df_050_059_RAD_VS1_K.assign(PPC=None)
                    df_050_059_RAD_VS1_K  = df_050_059_RAD_VS1_K.assign(Total=None)
                    df_050_059_RAD_VS1_K ['Wt Range'] = listwtrange
                    df_050_059_RAD_VS1_K ['Company'] = listcom
                    df_050_059_RAD_VS1_K ['Shape'] = listshap
                    df_050_059_RAD_VS1_K ['Carat'] = listcar
                    df_050_059_RAD_VS1_K ['Color'] = listcol
                    df_050_059_RAD_VS1_K ['Clarity'] = listclar
                    df_050_059_RAD_VS1_K ['Cut'] = listcut
                    df_050_059_RAD_VS1_K ['Polish'] = listpol
                    df_050_059_RAD_VS1_K ['Symmetry'] = listsym
                    df_050_059_RAD_VS1_K ['Ratio'] = listrat
                    df_050_059_RAD_VS1_K ['PPC'] = listdesc
                    df_050_059_RAD_VS1_K ['Total'] = listtotal
                    df_050_059_RAD_VS1_K['Carat'] = df_050_059_RAD_VS1_K['Carat'].astype('float64')
                    df_050_059_RAD_VS1_K['PPC'] = df_050_059_RAD_VS1_K['PPC'].astype('float64')
                    df_050_059_RAD_VS1_K['Total'] = df_050_059_RAD_VS1_K['Total'].astype('float64')
                    df_050_059_RAD_VS1_K['Total'] = df_050_059_RAD_VS1_K['Carat'] * df_050_059_RAD_VS1_K['PPC']


                elif i=="K" and j == "VS2" and k == "RAD":
                    df_050_059_RAD_VS2_K = pd.DataFrame()
                    df_050_059_RAD_VS2_K ['Wt Range'] = None
                    df_050_059_RAD_VS2_K  = df_050_059_RAD_VS2_K.assign(Company=None)
                    df_050_059_RAD_VS2_K  = df_050_059_RAD_VS2_K.assign(Shape=None)
                    df_050_059_RAD_VS2_K  = df_050_059_RAD_VS2_K.assign(Carat=None)
                    df_050_059_RAD_VS2_K  = df_050_059_RAD_VS2_K.assign(Color=None)
                    df_050_059_RAD_VS2_K  = df_050_059_RAD_VS2_K.assign(Clarity=None)
                    df_050_059_RAD_VS2_K  = df_050_059_RAD_VS2_K.assign(Cut=None)
                    df_050_059_RAD_VS2_K  = df_050_059_RAD_VS2_K.assign(Polish=None)
                    df_050_059_RAD_VS2_K  = df_050_059_RAD_VS2_K.assign(Symmetry=None)
                    df_050_059_RAD_VS2_K  = df_050_059_RAD_VS2_K.assign(Ratio=None)
                    df_050_059_RAD_VS2_K  = df_050_059_RAD_VS2_K.assign(PPC=None)
                    df_050_059_RAD_VS2_K  = df_050_059_RAD_VS2_K.assign(Total=None)
                    df_050_059_RAD_VS2_K ['Wt Range'] = listwtrange
                    df_050_059_RAD_VS2_K ['Company'] = listcom
                    df_050_059_RAD_VS2_K ['Shape'] = listshap
                    df_050_059_RAD_VS2_K ['Carat'] = listcar
                    df_050_059_RAD_VS2_K ['Color'] = listcol
                    df_050_059_RAD_VS2_K ['Clarity'] = listclar
                    df_050_059_RAD_VS2_K ['Cut'] = listcut
                    df_050_059_RAD_VS2_K ['Polish'] = listpol
                    df_050_059_RAD_VS2_K ['Symmetry'] = listsym
                    df_050_059_RAD_VS2_K ['Ratio'] = listrat
                    df_050_059_RAD_VS2_K ['PPC'] = listdesc
                    df_050_059_RAD_VS2_K ['Total'] = listtotal
                    df_050_059_RAD_VS2_K['Carat'] = df_050_059_RAD_VS2_K['Carat'].astype('float64')
                    df_050_059_RAD_VS2_K['PPC'] = df_050_059_RAD_VS2_K['PPC'].astype('float64')
                    df_050_059_RAD_VS2_K['Total'] = df_050_059_RAD_VS2_K['Total'].astype('float64')
                    df_050_059_RAD_VS2_K['Total'] = df_050_059_RAD_VS2_K['Carat'] * df_050_059_RAD_VS2_K['PPC']


                elif i=="K" and j == "SI1" and k == "RAD":
                    df_050_059_RAD_SI1_K = pd.DataFrame()
                    df_050_059_RAD_SI1_K ['Wt Range'] = None
                    df_050_059_RAD_SI1_K  = df_050_059_RAD_SI1_K.assign(Company=None)
                    df_050_059_RAD_SI1_K  = df_050_059_RAD_SI1_K.assign(Shape=None)
                    df_050_059_RAD_SI1_K  = df_050_059_RAD_SI1_K.assign(Carat=None)
                    df_050_059_RAD_SI1_K  = df_050_059_RAD_SI1_K.assign(Color=None)
                    df_050_059_RAD_SI1_K  = df_050_059_RAD_SI1_K.assign(Clarity=None)
                    df_050_059_RAD_SI1_K  = df_050_059_RAD_SI1_K.assign(Cut=None)
                    df_050_059_RAD_SI1_K  = df_050_059_RAD_SI1_K.assign(Polish=None)
                    df_050_059_RAD_SI1_K  = df_050_059_RAD_SI1_K.assign(Symmetry=None)
                    df_050_059_RAD_SI1_K  = df_050_059_RAD_SI1_K.assign(Ratio=None)
                    df_050_059_RAD_SI1_K  = df_050_059_RAD_SI1_K.assign(PPC=None)
                    df_050_059_RAD_SI1_K  = df_050_059_RAD_SI1_K.assign(Total=None)
                    df_050_059_RAD_SI1_K ['Wt Range'] = listwtrange
                    df_050_059_RAD_SI1_K ['Company'] = listcom
                    df_050_059_RAD_SI1_K ['Shape'] = listshap
                    df_050_059_RAD_SI1_K ['Carat'] = listcar
                    df_050_059_RAD_SI1_K ['Color'] = listcol
                    df_050_059_RAD_SI1_K ['Clarity'] = listclar
                    df_050_059_RAD_SI1_K ['Cut'] = listcut
                    df_050_059_RAD_SI1_K ['Polish'] = listpol
                    df_050_059_RAD_SI1_K ['Symmetry'] = listsym
                    df_050_059_RAD_SI1_K ['Ratio'] = listrat
                    df_050_059_RAD_SI1_K ['PPC'] = listdesc
                    df_050_059_RAD_SI1_K ['Total'] = listtotal
                    df_050_059_RAD_SI1_K['Carat'] = df_050_059_RAD_SI1_K['Carat'].astype('float64')
                    df_050_059_RAD_SI1_K['PPC'] = df_050_059_RAD_SI1_K['PPC'].astype('float64')
                    df_050_059_RAD_SI1_K['Total'] = df_050_059_RAD_SI1_K['Total'].astype('float64')
                    df_050_059_RAD_SI1_K['Total'] = df_050_059_RAD_SI1_K['Carat'] * df_050_059_RAD_SI1_K['PPC']


                elif i=="K" and j == "SI2" and k == "RAD":
                    df_050_059_RAD_SI2_K = pd.DataFrame()
                    df_050_059_RAD_SI2_K ['Wt Range'] = None
                    df_050_059_RAD_SI2_K  = df_050_059_RAD_SI2_K.assign(Company=None)
                    df_050_059_RAD_SI2_K  = df_050_059_RAD_SI2_K.assign(Shape=None)
                    df_050_059_RAD_SI2_K  = df_050_059_RAD_SI2_K.assign(Carat=None)
                    df_050_059_RAD_SI2_K  = df_050_059_RAD_SI2_K.assign(Color=None)
                    df_050_059_RAD_SI2_K  = df_050_059_RAD_SI2_K.assign(Clarity=None)
                    df_050_059_RAD_SI2_K  = df_050_059_RAD_SI2_K.assign(Cut=None)
                    df_050_059_RAD_SI2_K  = df_050_059_RAD_SI2_K.assign(Polish=None)
                    df_050_059_RAD_SI2_K  = df_050_059_RAD_SI2_K.assign(Symmetry=None)
                    df_050_059_RAD_SI2_K  = df_050_059_RAD_SI2_K.assign(Ratio=None)
                    df_050_059_RAD_SI2_K  = df_050_059_RAD_SI2_K.assign(PPC=None)
                    df_050_059_RAD_SI2_K  = df_050_059_RAD_SI2_K.assign(Total=None)
                    df_050_059_RAD_SI2_K ['Wt Range'] = listwtrange
                    df_050_059_RAD_SI2_K ['Company'] = listcom
                    df_050_059_RAD_SI2_K ['Shape'] = listshap
                    df_050_059_RAD_SI2_K ['Carat'] = listcar
                    df_050_059_RAD_SI2_K ['Color'] = listcol
                    df_050_059_RAD_SI2_K ['Clarity'] = listclar
                    df_050_059_RAD_SI2_K ['Cut'] = listcut
                    df_050_059_RAD_SI2_K ['Polish'] = listpol
                    df_050_059_RAD_SI2_K ['Symmetry'] = listsym
                    df_050_059_RAD_SI2_K ['Ratio'] = listrat
                    df_050_059_RAD_SI2_K ['PPC'] = listdesc
                    df_050_059_RAD_SI2_K ['Total'] = listtotal
                    df_050_059_RAD_SI2_K['Carat'] = df_050_059_RAD_SI2_K['Carat'].astype('float64')
                    df_050_059_RAD_SI2_K['PPC'] = df_050_059_RAD_SI2_K['PPC'].astype('float64')
                    df_050_059_RAD_SI2_K['Total'] = df_050_059_RAD_SI2_K['Total'].astype('float64')
                    df_050_059_RAD_SI2_K['Total'] = df_050_059_RAD_SI2_K['Carat'] * df_050_059_RAD_SI2_K['PPC']


                elif i=="K" and j == "I1" and k == "RAD":
                    df_050_059_RAD_I1_K = pd.DataFrame()
                    df_050_059_RAD_I1_K ['Wt Range'] = None
                    df_050_059_RAD_I1_K  = df_050_059_RAD_I1_K.assign(Company=None)
                    df_050_059_RAD_I1_K  = df_050_059_RAD_I1_K.assign(Shape=None)
                    df_050_059_RAD_I1_K  = df_050_059_RAD_I1_K.assign(Carat=None)
                    df_050_059_RAD_I1_K  = df_050_059_RAD_I1_K.assign(Color=None)
                    df_050_059_RAD_I1_K  = df_050_059_RAD_I1_K.assign(Clarity=None)
                    df_050_059_RAD_I1_K  = df_050_059_RAD_I1_K.assign(Cut=None)
                    df_050_059_RAD_I1_K  = df_050_059_RAD_I1_K.assign(Polish=None)
                    df_050_059_RAD_I1_K  = df_050_059_RAD_I1_K.assign(Symmetry=None)
                    df_050_059_RAD_I1_K  = df_050_059_RAD_I1_K.assign(Ratio=None)
                    df_050_059_RAD_I1_K  = df_050_059_RAD_I1_K.assign(PPC=None)
                    df_050_059_RAD_I1_K  = df_050_059_RAD_I1_K.assign(Total=None)
                    df_050_059_RAD_I1_K ['Wt Range'] = listwtrange
                    df_050_059_RAD_I1_K ['Company'] = listcom
                    df_050_059_RAD_I1_K ['Shape'] = listshap
                    df_050_059_RAD_I1_K ['Carat'] = listcar
                    df_050_059_RAD_I1_K ['Color'] = listcol
                    df_050_059_RAD_I1_K ['Clarity'] = listclar
                    df_050_059_RAD_I1_K ['Cut'] = listcut
                    df_050_059_RAD_I1_K ['Polish'] = listpol
                    df_050_059_RAD_I1_K ['Symmetry'] = listsym
                    df_050_059_RAD_I1_K ['Ratio'] = listrat
                    df_050_059_RAD_I1_K ['PPC'] = listdesc
                    df_050_059_RAD_I1_K ['Total'] = listtotal
                    df_050_059_RAD_I1_K['Carat'] = df_050_059_RAD_I1_K['Carat'].astype('float64')
                    df_050_059_RAD_I1_K['PPC'] = df_050_059_RAD_I1_K['PPC'].astype('float64')
                    df_050_059_RAD_I1_K['Total'] = df_050_059_RAD_I1_K['Total'].astype('float64')
                    df_050_059_RAD_I1_K['Total'] = df_050_059_RAD_I1_K['Carat'] * df_050_059_RAD_I1_K['PPC']


                elif i=="K" and j == "I2" and k == "RAD":
                    df_050_059_RAD_I2_K = pd.DataFrame()
                    df_050_059_RAD_I2_K ['Wt Range'] = None
                    df_050_059_RAD_I2_K  = df_050_059_RAD_I2_K.assign(Company=None)
                    df_050_059_RAD_I2_K  = df_050_059_RAD_I2_K.assign(Shape=None)
                    df_050_059_RAD_I2_K  = df_050_059_RAD_I2_K.assign(Carat=None)
                    df_050_059_RAD_I2_K  = df_050_059_RAD_I2_K.assign(Color=None)
                    df_050_059_RAD_I2_K  = df_050_059_RAD_I2_K.assign(Clarity=None)
                    df_050_059_RAD_I2_K  = df_050_059_RAD_I2_K.assign(Cut=None)
                    df_050_059_RAD_I2_K  = df_050_059_RAD_I2_K.assign(Polish=None)
                    df_050_059_RAD_I2_K  = df_050_059_RAD_I2_K.assign(Symmetry=None)
                    df_050_059_RAD_I2_K  = df_050_059_RAD_I2_K.assign(Ratio=None)
                    df_050_059_RAD_I2_K  = df_050_059_RAD_I2_K.assign(PPC=None)
                    df_050_059_RAD_I2_K  = df_050_059_RAD_I2_K.assign(Total=None)
                    df_050_059_RAD_I2_K ['Wt Range'] = listwtrange
                    df_050_059_RAD_I2_K ['Company'] = listcom
                    df_050_059_RAD_I2_K ['Shape'] = listshap
                    df_050_059_RAD_I2_K ['Carat'] = listcar
                    df_050_059_RAD_I2_K ['Color'] = listcol
                    df_050_059_RAD_I2_K ['Clarity'] = listclar
                    df_050_059_RAD_I2_K ['Cut'] = listcut
                    df_050_059_RAD_I2_K ['Polish'] = listpol
                    df_050_059_RAD_I2_K ['Symmetry'] = listsym
                    df_050_059_RAD_I2_K ['Ratio'] = listrat
                    df_050_059_RAD_I2_K ['PPC'] = listdesc
                    df_050_059_RAD_I2_K ['Total'] = listtotal
                    df_050_059_RAD_I2_K['Carat'] = df_050_059_RAD_I2_K['Carat'].astype('float64')
                    df_050_059_RAD_I2_K['PPC'] = df_050_059_RAD_I2_K['PPC'].astype('float64')
                    df_050_059_RAD_I2_K['Total'] = df_050_059_RAD_I2_K['Total'].astype('float64')
                    df_050_059_RAD_I2_K['Total'] = df_050_059_RAD_I2_K['Carat'] * df_050_059_RAD_I2_K['PPC']


                elif i=="L" and j == "IF" and k == "RAD":
                    df_050_059_RAD_IF_L = pd.DataFrame()
                    df_050_059_RAD_IF_L ['Wt Range'] = None
                    df_050_059_RAD_IF_L  = df_050_059_RAD_IF_L.assign(Company=None)
                    df_050_059_RAD_IF_L  = df_050_059_RAD_IF_L.assign(Shape=None)
                    df_050_059_RAD_IF_L  = df_050_059_RAD_IF_L.assign(Carat=None)
                    df_050_059_RAD_IF_L  = df_050_059_RAD_IF_L.assign(Color=None)
                    df_050_059_RAD_IF_L  = df_050_059_RAD_IF_L.assign(Clarity=None)
                    df_050_059_RAD_IF_L  = df_050_059_RAD_IF_L.assign(Cut=None)
                    df_050_059_RAD_IF_L  = df_050_059_RAD_IF_L.assign(Polish=None)
                    df_050_059_RAD_IF_L  = df_050_059_RAD_IF_L.assign(Symmetry=None)
                    df_050_059_RAD_IF_L  = df_050_059_RAD_IF_L.assign(Ratio=None)
                    df_050_059_RAD_IF_L  = df_050_059_RAD_IF_L.assign(PPC=None)
                    df_050_059_RAD_IF_L  = df_050_059_RAD_IF_L.assign(Total=None)
                    df_050_059_RAD_IF_L ['Wt Range'] = listwtrange
                    df_050_059_RAD_IF_L ['Company'] = listcom
                    df_050_059_RAD_IF_L ['Shape'] = listshap
                    df_050_059_RAD_IF_L ['Carat'] = listcar
                    df_050_059_RAD_IF_L ['Color'] = listcol
                    df_050_059_RAD_IF_L ['Clarity'] = listclar
                    df_050_059_RAD_IF_L ['Cut'] = listcut
                    df_050_059_RAD_IF_L ['Polish'] = listpol
                    df_050_059_RAD_IF_L ['Symmetry'] = listsym
                    df_050_059_RAD_IF_L ['Ratio'] = listrat
                    df_050_059_RAD_IF_L ['PPC'] = listdesc
                    df_050_059_RAD_IF_L ['Total'] = listtotal
                    df_050_059_RAD_IF_L['Carat'] = df_050_059_RAD_IF_L['Carat'].astype('float64')
                    df_050_059_RAD_IF_L['PPC'] = df_050_059_RAD_IF_L['PPC'].astype('float64')
                    df_050_059_RAD_IF_L['Total'] = df_050_059_RAD_IF_L['Total'].astype('float64')
                    df_050_059_RAD_IF_L['Total'] = df_050_059_RAD_IF_L['Carat'] * df_050_059_RAD_IF_L['PPC']


                elif i=="L" and j == "VVS1" and k == "RAD":
                    df_050_059_RAD_VVS1_L = pd.DataFrame()
                    df_050_059_RAD_VVS1_L ['Wt Range'] = None
                    df_050_059_RAD_VVS1_L  = df_050_059_RAD_VVS1_L.assign(Company=None)
                    df_050_059_RAD_VVS1_L  = df_050_059_RAD_VVS1_L.assign(Shape=None)
                    df_050_059_RAD_VVS1_L  = df_050_059_RAD_VVS1_L.assign(Carat=None)
                    df_050_059_RAD_VVS1_L  = df_050_059_RAD_VVS1_L.assign(Color=None)
                    df_050_059_RAD_VVS1_L  = df_050_059_RAD_VVS1_L.assign(Clarity=None)
                    df_050_059_RAD_VVS1_L  = df_050_059_RAD_VVS1_L.assign(Cut=None)
                    df_050_059_RAD_VVS1_L  = df_050_059_RAD_VVS1_L.assign(Polish=None)
                    df_050_059_RAD_VVS1_L  = df_050_059_RAD_VVS1_L.assign(Symmetry=None)
                    df_050_059_RAD_VVS1_L  = df_050_059_RAD_VVS1_L.assign(Ratio=None)
                    df_050_059_RAD_VVS1_L  = df_050_059_RAD_VVS1_L.assign(PPC=None)
                    df_050_059_RAD_VVS1_L  = df_050_059_RAD_VVS1_L.assign(Total=None)
                    df_050_059_RAD_VVS1_L ['Wt Range'] = listwtrange
                    df_050_059_RAD_VVS1_L ['Company'] = listcom
                    df_050_059_RAD_VVS1_L ['Shape'] = listshap
                    df_050_059_RAD_VVS1_L ['Carat'] = listcar
                    df_050_059_RAD_VVS1_L ['Color'] = listcol
                    df_050_059_RAD_VVS1_L ['Clarity'] = listclar
                    df_050_059_RAD_VVS1_L ['Cut'] = listcut
                    df_050_059_RAD_VVS1_L ['Polish'] = listpol
                    df_050_059_RAD_VVS1_L ['Symmetry'] = listsym
                    df_050_059_RAD_VVS1_L ['Ratio'] = listrat
                    df_050_059_RAD_VVS1_L ['PPC'] = listdesc
                    df_050_059_RAD_VVS1_L ['Total'] = listtotal
                    df_050_059_RAD_VVS1_L['Carat'] = df_050_059_RAD_VVS1_L['Carat'].astype('float64')
                    df_050_059_RAD_VVS1_L['PPC'] = df_050_059_RAD_VVS1_L['PPC'].astype('float64')
                    df_050_059_RAD_VVS1_L['Total'] = df_050_059_RAD_VVS1_L['Total'].astype('float64')
                    df_050_059_RAD_VVS1_L['Total'] = df_050_059_RAD_VVS1_L['Carat'] * df_050_059_RAD_VVS1_L['PPC']


                elif i=="L" and j == "VVS2" and k == "RAD":
                    df_050_059_RAD_VVS2_L = pd.DataFrame()
                    df_050_059_RAD_VVS2_L ['Wt Range'] = None
                    df_050_059_RAD_VVS2_L  = df_050_059_RAD_VVS2_L.assign(Company=None)
                    df_050_059_RAD_VVS2_L  = df_050_059_RAD_VVS2_L.assign(Shape=None)
                    df_050_059_RAD_VVS2_L  = df_050_059_RAD_VVS2_L.assign(Carat=None)
                    df_050_059_RAD_VVS2_L  = df_050_059_RAD_VVS2_L.assign(Color=None)
                    df_050_059_RAD_VVS2_L  = df_050_059_RAD_VVS2_L.assign(Clarity=None)
                    df_050_059_RAD_VVS2_L  = df_050_059_RAD_VVS2_L.assign(Cut=None)
                    df_050_059_RAD_VVS2_L  = df_050_059_RAD_VVS2_L.assign(Polish=None)
                    df_050_059_RAD_VVS2_L  = df_050_059_RAD_VVS2_L.assign(Symmetry=None)
                    df_050_059_RAD_VVS2_L  = df_050_059_RAD_VVS2_L.assign(Ratio=None)
                    df_050_059_RAD_VVS2_L  = df_050_059_RAD_VVS2_L.assign(PPC=None)
                    df_050_059_RAD_VVS2_L  = df_050_059_RAD_VVS2_L.assign(Total=None)
                    df_050_059_RAD_VVS2_L ['Wt Range'] = listwtrange
                    df_050_059_RAD_VVS2_L ['Company'] = listcom
                    df_050_059_RAD_VVS2_L ['Shape'] = listshap
                    df_050_059_RAD_VVS2_L ['Carat'] = listcar
                    df_050_059_RAD_VVS2_L ['Color'] = listcol
                    df_050_059_RAD_VVS2_L ['Clarity'] = listclar
                    df_050_059_RAD_VVS2_L ['Cut'] = listcut
                    df_050_059_RAD_VVS2_L ['Polish'] = listpol
                    df_050_059_RAD_VVS2_L ['Symmetry'] = listsym
                    df_050_059_RAD_VVS2_L ['Ratio'] = listrat
                    df_050_059_RAD_VVS2_L ['PPC'] = listdesc
                    df_050_059_RAD_VVS2_L ['Total'] = listtotal
                    df_050_059_RAD_VVS2_L['Carat'] = df_050_059_RAD_VVS2_L['Carat'].astype('float64')
                    df_050_059_RAD_VVS2_L['PPC'] = df_050_059_RAD_VVS2_L['PPC'].astype('float64')
                    df_050_059_RAD_VVS2_L['Total'] = df_050_059_RAD_VVS2_L['Total'].astype('float64')
                    df_050_059_RAD_VVS2_L['Total'] = df_050_059_RAD_VVS2_L['Carat'] * df_050_059_RAD_VVS2_L['PPC']


                elif i=="L" and j=="VS1" and k == "RAD":
                    df_050_059_RAD_VS1_L = pd.DataFrame()
                    df_050_059_RAD_VS1_L ['Wt Range'] = None
                    df_050_059_RAD_VS1_L  = df_050_059_RAD_VS1_L.assign(Company=None)
                    df_050_059_RAD_VS1_L  = df_050_059_RAD_VS1_L.assign(Shape=None)
                    df_050_059_RAD_VS1_L  = df_050_059_RAD_VS1_L.assign(Carat=None)
                    df_050_059_RAD_VS1_L  = df_050_059_RAD_VS1_L.assign(Color=None)
                    df_050_059_RAD_VS1_L  = df_050_059_RAD_VS1_L.assign(Clarity=None)
                    df_050_059_RAD_VS1_L  = df_050_059_RAD_VS1_L.assign(Cut=None)
                    df_050_059_RAD_VS1_L  = df_050_059_RAD_VS1_L.assign(Polish=None)
                    df_050_059_RAD_VS1_L  = df_050_059_RAD_VS1_L.assign(Symmetry=None)
                    df_050_059_RAD_VS1_L  = df_050_059_RAD_VS1_L.assign(Ratio=None)
                    df_050_059_RAD_VS1_L  = df_050_059_RAD_VS1_L.assign(PPC=None)
                    df_050_059_RAD_VS1_L  = df_050_059_RAD_VS1_L.assign(Total=None)
                    df_050_059_RAD_VS1_L ['Wt Range'] = listwtrange
                    df_050_059_RAD_VS1_L ['Company'] = listcom
                    df_050_059_RAD_VS1_L ['Shape'] = listshap
                    df_050_059_RAD_VS1_L ['Carat'] = listcar
                    df_050_059_RAD_VS1_L ['Color'] = listcol
                    df_050_059_RAD_VS1_L ['Clarity'] = listclar
                    df_050_059_RAD_VS1_L ['Cut'] = listcut
                    df_050_059_RAD_VS1_L ['Polish'] = listpol
                    df_050_059_RAD_VS1_L ['Symmetry'] = listsym
                    df_050_059_RAD_VS1_L ['Ratio'] = listrat
                    df_050_059_RAD_VS1_L ['PPC'] = listdesc
                    df_050_059_RAD_VS1_L ['Total'] = listtotal
                    df_050_059_RAD_VS1_L['Carat'] = df_050_059_RAD_VS1_L['Carat'].astype('float64')
                    df_050_059_RAD_VS1_L['PPC'] = df_050_059_RAD_VS1_L['PPC'].astype('float64')
                    df_050_059_RAD_VS1_L['Total'] = df_050_059_RAD_VS1_L['Total'].astype('float64')
                    df_050_059_RAD_VS1_L['Total'] = df_050_059_RAD_VS1_L['Carat'] * df_050_059_RAD_VS1_L['PPC']


                elif i=="L" and j == "VS2" and k == "RAD":
                    df_050_059_RAD_VS2_L = pd.DataFrame()
                    df_050_059_RAD_VS2_L ['Wt Range'] = None
                    df_050_059_RAD_VS2_L  = df_050_059_RAD_VS2_L.assign(Company=None)
                    df_050_059_RAD_VS2_L  = df_050_059_RAD_VS2_L.assign(Shape=None)
                    df_050_059_RAD_VS2_L  = df_050_059_RAD_VS2_L.assign(Carat=None)
                    df_050_059_RAD_VS2_L  = df_050_059_RAD_VS2_L.assign(Color=None)
                    df_050_059_RAD_VS2_L  = df_050_059_RAD_VS2_L.assign(Clarity=None)
                    df_050_059_RAD_VS2_L  = df_050_059_RAD_VS2_L.assign(Cut=None)
                    df_050_059_RAD_VS2_L  = df_050_059_RAD_VS2_L.assign(Polish=None)
                    df_050_059_RAD_VS2_L  = df_050_059_RAD_VS2_L.assign(Symmetry=None)
                    df_050_059_RAD_VS2_L  = df_050_059_RAD_VS2_L.assign(Ratio=None)
                    df_050_059_RAD_VS2_L  = df_050_059_RAD_VS2_L.assign(PPC=None)
                    df_050_059_RAD_VS2_L  = df_050_059_RAD_VS2_L.assign(Total=None)
                    df_050_059_RAD_VS2_L ['Wt Range'] = listwtrange
                    df_050_059_RAD_VS2_L ['Company'] = listcom
                    df_050_059_RAD_VS2_L ['Shape'] = listshap
                    df_050_059_RAD_VS2_L ['Carat'] = listcar
                    df_050_059_RAD_VS2_L ['Color'] = listcol
                    df_050_059_RAD_VS2_L ['Clarity'] = listclar
                    df_050_059_RAD_VS2_L ['Cut'] = listcut
                    df_050_059_RAD_VS2_L ['Polish'] = listpol
                    df_050_059_RAD_VS2_L ['Symmetry'] = listsym
                    df_050_059_RAD_VS2_L ['Ratio'] = listrat
                    df_050_059_RAD_VS2_L ['PPC'] = listdesc
                    df_050_059_RAD_VS2_L ['Total'] = listtotal
                    df_050_059_RAD_VS2_L['Carat'] = df_050_059_RAD_VS2_L['Carat'].astype('float64')
                    df_050_059_RAD_VS2_L['PPC'] = df_050_059_RAD_VS2_L['PPC'].astype('float64')
                    df_050_059_RAD_VS2_L['Total'] = df_050_059_RAD_VS2_L['Total'].astype('float64')
                    df_050_059_RAD_VS2_L['Total'] = df_050_059_RAD_VS2_L['Carat'] * df_050_059_RAD_VS2_L['PPC']


                elif i=="L" and j == "SI1" and k == "RAD":
                    df_050_059_RAD_SI1_L = pd.DataFrame()
                    df_050_059_RAD_SI1_L ['Wt Range'] = None
                    df_050_059_RAD_SI1_L  = df_050_059_RAD_SI1_L.assign(Company=None)
                    df_050_059_RAD_SI1_L  = df_050_059_RAD_SI1_L.assign(Shape=None)
                    df_050_059_RAD_SI1_L  = df_050_059_RAD_SI1_L.assign(Carat=None)
                    df_050_059_RAD_SI1_L  = df_050_059_RAD_SI1_L.assign(Color=None)
                    df_050_059_RAD_SI1_L  = df_050_059_RAD_SI1_L.assign(Clarity=None)
                    df_050_059_RAD_SI1_L  = df_050_059_RAD_SI1_L.assign(Cut=None)
                    df_050_059_RAD_SI1_L  = df_050_059_RAD_SI1_L.assign(Polish=None)
                    df_050_059_RAD_SI1_L  = df_050_059_RAD_SI1_L.assign(Symmetry=None)
                    df_050_059_RAD_SI1_L  = df_050_059_RAD_SI1_L.assign(Ratio=None)
                    df_050_059_RAD_SI1_L  = df_050_059_RAD_SI1_L.assign(PPC=None)
                    df_050_059_RAD_SI1_L  = df_050_059_RAD_SI1_L.assign(Total=None)
                    df_050_059_RAD_SI1_L ['Wt Range'] = listwtrange
                    df_050_059_RAD_SI1_L ['Company'] = listcom
                    df_050_059_RAD_SI1_L ['Shape'] = listshap
                    df_050_059_RAD_SI1_L ['Carat'] = listcar
                    df_050_059_RAD_SI1_L ['Color'] = listcol
                    df_050_059_RAD_SI1_L ['Clarity'] = listclar
                    df_050_059_RAD_SI1_L ['Cut'] = listcut
                    df_050_059_RAD_SI1_L ['Polish'] = listpol
                    df_050_059_RAD_SI1_L ['Symmetry'] = listsym
                    df_050_059_RAD_SI1_L ['Ratio'] = listrat
                    df_050_059_RAD_SI1_L ['PPC'] = listdesc
                    df_050_059_RAD_SI1_L ['Total'] = listtotal
                    df_050_059_RAD_SI1_L['Carat'] = df_050_059_RAD_SI1_L['Carat'].astype('float64')
                    df_050_059_RAD_SI1_L['PPC'] = df_050_059_RAD_SI1_L['PPC'].astype('float64')
                    df_050_059_RAD_SI1_L['Total'] = df_050_059_RAD_SI1_L['Total'].astype('float64')
                    df_050_059_RAD_SI1_L['Total'] = df_050_059_RAD_SI1_L['Carat'] * df_050_059_RAD_SI1_L['PPC']


                elif i=="L" and j == "SI2" and k == "RAD":
                    df_050_059_RAD_SI2_L = pd.DataFrame()
                    df_050_059_RAD_SI2_L ['Wt Range'] = None
                    df_050_059_RAD_SI2_L  = df_050_059_RAD_SI2_L.assign(Company=None)
                    df_050_059_RAD_SI2_L  = df_050_059_RAD_SI2_L.assign(Shape=None)
                    df_050_059_RAD_SI2_L  = df_050_059_RAD_SI2_L.assign(Carat=None)
                    df_050_059_RAD_SI2_L  = df_050_059_RAD_SI2_L.assign(Color=None)
                    df_050_059_RAD_SI2_L  = df_050_059_RAD_SI2_L.assign(Clarity=None)
                    df_050_059_RAD_SI2_L  = df_050_059_RAD_SI2_L.assign(Cut=None)
                    df_050_059_RAD_SI2_L  = df_050_059_RAD_SI2_L.assign(Polish=None)
                    df_050_059_RAD_SI2_L  = df_050_059_RAD_SI2_L.assign(Symmetry=None)
                    df_050_059_RAD_SI2_L  = df_050_059_RAD_SI2_L.assign(Ratio=None)
                    df_050_059_RAD_SI2_L  = df_050_059_RAD_SI2_L.assign(PPC=None)
                    df_050_059_RAD_SI2_L  = df_050_059_RAD_SI2_L.assign(Total=None)
                    df_050_059_RAD_SI2_L ['Wt Range'] = listwtrange
                    df_050_059_RAD_SI2_L ['Company'] = listcom
                    df_050_059_RAD_SI2_L ['Shape'] = listshap
                    df_050_059_RAD_SI2_L ['Carat'] = listcar
                    df_050_059_RAD_SI2_L ['Color'] = listcol
                    df_050_059_RAD_SI2_L ['Clarity'] = listclar
                    df_050_059_RAD_SI2_L ['Cut'] = listcut
                    df_050_059_RAD_SI2_L ['Polish'] = listpol
                    df_050_059_RAD_SI2_L ['Symmetry'] = listsym
                    df_050_059_RAD_SI2_L ['Ratio'] = listrat
                    df_050_059_RAD_SI2_L ['PPC'] = listdesc
                    df_050_059_RAD_SI2_L ['Total'] = listtotal
                    df_050_059_RAD_SI2_L['Carat'] = df_050_059_RAD_SI2_L['Carat'].astype('float64')
                    df_050_059_RAD_SI2_L['PPC'] = df_050_059_RAD_SI2_L['PPC'].astype('float64')
                    df_050_059_RAD_SI2_L['Total'] = df_050_059_RAD_SI2_L['Total'].astype('float64')
                    df_050_059_RAD_SI2_L['Total'] = df_050_059_RAD_SI2_L['Carat'] * df_050_059_RAD_SI2_L['PPC']


                elif i=="L" and j == "I1" and k == "RAD":
                    df_050_059_RAD_I1_L = pd.DataFrame()
                    df_050_059_RAD_I1_L ['Wt Range'] = None
                    df_050_059_RAD_I1_L  = df_050_059_RAD_I1_L.assign(Company=None)
                    df_050_059_RAD_I1_L  = df_050_059_RAD_I1_L.assign(Shape=None)
                    df_050_059_RAD_I1_L  = df_050_059_RAD_I1_L.assign(Carat=None)
                    df_050_059_RAD_I1_L  = df_050_059_RAD_I1_L.assign(Color=None)
                    df_050_059_RAD_I1_L  = df_050_059_RAD_I1_L.assign(Clarity=None)
                    df_050_059_RAD_I1_L  = df_050_059_RAD_I1_L.assign(Cut=None)
                    df_050_059_RAD_I1_L  = df_050_059_RAD_I1_L.assign(Polish=None)
                    df_050_059_RAD_I1_L  = df_050_059_RAD_I1_L.assign(Symmetry=None)
                    df_050_059_RAD_I1_L  = df_050_059_RAD_I1_L.assign(Ratio=None)
                    df_050_059_RAD_I1_L  = df_050_059_RAD_I1_L.assign(PPC=None)
                    df_050_059_RAD_I1_L  = df_050_059_RAD_I1_L.assign(Total=None)
                    df_050_059_RAD_I1_L ['Wt Range'] = listwtrange
                    df_050_059_RAD_I1_L ['Company'] = listcom
                    df_050_059_RAD_I1_L ['Shape'] = listshap
                    df_050_059_RAD_I1_L ['Carat'] = listcar
                    df_050_059_RAD_I1_L ['Color'] = listcol
                    df_050_059_RAD_I1_L ['Clarity'] = listclar
                    df_050_059_RAD_I1_L ['Cut'] = listcut
                    df_050_059_RAD_I1_L ['Polish'] = listpol
                    df_050_059_RAD_I1_L ['Symmetry'] = listsym
                    df_050_059_RAD_I1_L ['Ratio'] = listrat
                    df_050_059_RAD_I1_L ['PPC'] = listdesc
                    df_050_059_RAD_I1_L ['Total'] = listtotal
                    df_050_059_RAD_I1_L['Carat'] = df_050_059_RAD_I1_L['Carat'].astype('float64')
                    df_050_059_RAD_I1_L['PPC'] = df_050_059_RAD_I1_L['PPC'].astype('float64')
                    df_050_059_RAD_I1_L['Total'] = df_050_059_RAD_I1_L['Total'].astype('float64')
                    df_050_059_RAD_I1_L['Total'] = df_050_059_RAD_I1_L['Carat'] * df_050_059_RAD_I1_L['PPC']


                elif i=="L" and j == "I2" and k == "RAD":
                    df_050_059_RAD_I2_L = pd.DataFrame()
                    df_050_059_RAD_I2_L ['Wt Range'] = None
                    df_050_059_RAD_I2_L  = df_050_059_RAD_I2_L.assign(Company=None)
                    df_050_059_RAD_I2_L  = df_050_059_RAD_I2_L.assign(Shape=None)
                    df_050_059_RAD_I2_L  = df_050_059_RAD_I2_L.assign(Carat=None)
                    df_050_059_RAD_I2_L  = df_050_059_RAD_I2_L.assign(Color=None)
                    df_050_059_RAD_I2_L  = df_050_059_RAD_I2_L.assign(Clarity=None)
                    df_050_059_RAD_I2_L  = df_050_059_RAD_I2_L.assign(Cut=None)
                    df_050_059_RAD_I2_L  = df_050_059_RAD_I2_L.assign(Polish=None)
                    df_050_059_RAD_I2_L  = df_050_059_RAD_I2_L.assign(Symmetry=None)
                    df_050_059_RAD_I2_L  = df_050_059_RAD_I2_L.assign(Ratio=None)
                    df_050_059_RAD_I2_L  = df_050_059_RAD_I2_L.assign(PPC=None)
                    df_050_059_RAD_I2_L  = df_050_059_RAD_I2_L.assign(Total=None)
                    df_050_059_RAD_I2_L ['Wt Range'] = listwtrange
                    df_050_059_RAD_I2_L ['Company'] = listcom
                    df_050_059_RAD_I2_L ['Shape'] = listshap
                    df_050_059_RAD_I2_L ['Carat'] = listcar
                    df_050_059_RAD_I2_L ['Color'] = listcol
                    df_050_059_RAD_I2_L ['Clarity'] = listclar
                    df_050_059_RAD_I2_L ['Cut'] = listcut
                    df_050_059_RAD_I2_L ['Polish'] = listpol
                    df_050_059_RAD_I2_L ['Symmetry'] = listsym
                    df_050_059_RAD_I2_L ['Ratio'] = listrat
                    df_050_059_RAD_I2_L ['PPC'] = listdesc
                    df_050_059_RAD_I2_L ['Total'] = listtotal
                    df_050_059_RAD_I2_L['Carat'] = df_050_059_RAD_I2_L['Carat'].astype('float64')
                    df_050_059_RAD_I2_L['PPC'] = df_050_059_RAD_I2_L['PPC'].astype('float64')
                    df_050_059_RAD_I2_L['Total'] = df_050_059_RAD_I2_L['Total'].astype('float64')
                    df_050_059_RAD_I2_L['Total'] = df_050_059_RAD_I2_L['Carat'] * df_050_059_RAD_I2_L['PPC']


                elif i=="D" and j == "IF" and k == "EC":
                    df_050_059_EC_IF_D = pd.DataFrame()
                    df_050_059_EC_IF_D ['Wt Range'] = None
                    df_050_059_EC_IF_D  = df_050_059_EC_IF_D.assign(Company=None)
                    df_050_059_EC_IF_D  = df_050_059_EC_IF_D.assign(Shape=None)
                    df_050_059_EC_IF_D  = df_050_059_EC_IF_D.assign(Carat=None)
                    df_050_059_EC_IF_D  = df_050_059_EC_IF_D.assign(Color=None)
                    df_050_059_EC_IF_D  = df_050_059_EC_IF_D.assign(Clarity=None)
                    df_050_059_EC_IF_D  = df_050_059_EC_IF_D.assign(Cut=None)
                    df_050_059_EC_IF_D  = df_050_059_EC_IF_D.assign(Polish=None)
                    df_050_059_EC_IF_D  = df_050_059_EC_IF_D.assign(Symmetry=None)
                    df_050_059_EC_IF_D  = df_050_059_EC_IF_D.assign(Ratio=None)
                    df_050_059_EC_IF_D  = df_050_059_EC_IF_D.assign(PPC=None)
                    df_050_059_EC_IF_D  = df_050_059_EC_IF_D.assign(Total=None)
                    df_050_059_EC_IF_D ['Wt Range'] = listwtrange
                    df_050_059_EC_IF_D ['Company'] = listcom
                    df_050_059_EC_IF_D ['Shape'] = listshap
                    df_050_059_EC_IF_D ['Carat'] = listcar
                    df_050_059_EC_IF_D ['Color'] = listcol
                    df_050_059_EC_IF_D ['Clarity'] = listclar
                    df_050_059_EC_IF_D ['Cut'] = listcut
                    df_050_059_EC_IF_D ['Polish'] = listpol
                    df_050_059_EC_IF_D ['Symmetry'] = listsym
                    df_050_059_EC_IF_D ['Ratio'] = listrat
                    df_050_059_EC_IF_D ['PPC'] = listdesc
                    df_050_059_EC_IF_D ['Total'] = listtotal
                    df_050_059_EC_IF_D['Carat'] = df_050_059_EC_IF_D['Carat'].astype('float64')
                    df_050_059_EC_IF_D['PPC'] = df_050_059_EC_IF_D['PPC'].astype('float64')
                    df_050_059_EC_IF_D['Total'] = df_050_059_EC_IF_D['Total'].astype('float64')
                    df_050_059_EC_IF_D['Total'] = df_050_059_EC_IF_D['Carat'] * df_050_059_EC_IF_D['PPC']



                elif i=="D" and j == "VVS1" and k == "EC" :
                    df_050_059_EC_VVS1_D = pd.DataFrame()
                    df_050_059_EC_VVS1_D ['Wt Range'] = None
                    df_050_059_EC_VVS1_D  = df_050_059_EC_VVS1_D.assign(Company=None)
                    df_050_059_EC_VVS1_D  = df_050_059_EC_VVS1_D.assign(Shape=None)
                    df_050_059_EC_VVS1_D  = df_050_059_EC_VVS1_D.assign(Carat=None)
                    df_050_059_EC_VVS1_D  = df_050_059_EC_VVS1_D.assign(Color=None)
                    df_050_059_EC_VVS1_D  = df_050_059_EC_VVS1_D.assign(Clarity=None)
                    df_050_059_EC_VVS1_D  = df_050_059_EC_VVS1_D.assign(Cut=None)
                    df_050_059_EC_VVS1_D  = df_050_059_EC_VVS1_D.assign(Polish=None)
                    df_050_059_EC_VVS1_D  = df_050_059_EC_VVS1_D.assign(Symmetry=None)
                    df_050_059_EC_VVS1_D  = df_050_059_EC_VVS1_D.assign(Ratio=None)
                    df_050_059_EC_VVS1_D  = df_050_059_EC_VVS1_D.assign(PPC=None)
                    df_050_059_EC_VVS1_D  = df_050_059_EC_VVS1_D.assign(Total=None)
                    df_050_059_EC_VVS1_D ['Wt Range'] = listwtrange
                    df_050_059_EC_VVS1_D ['Company'] = listcom
                    df_050_059_EC_VVS1_D ['Shape'] = listshap
                    df_050_059_EC_VVS1_D ['Carat'] = listcar
                    df_050_059_EC_VVS1_D ['Color'] = listcol
                    df_050_059_EC_VVS1_D ['Clarity'] = listclar
                    df_050_059_EC_VVS1_D ['Cut'] = listcut
                    df_050_059_EC_VVS1_D ['Polish'] = listpol
                    df_050_059_EC_VVS1_D ['Symmetry'] = listsym
                    df_050_059_EC_VVS1_D ['Ratio'] = listrat
                    df_050_059_EC_VVS1_D ['PPC'] = listdesc
                    df_050_059_EC_VVS1_D ['Total'] = listtotal
                    df_050_059_EC_VVS1_D['Carat'] = df_050_059_EC_VVS1_D['Carat'].astype('float64')
                    df_050_059_EC_VVS1_D['PPC'] = df_050_059_EC_VVS1_D['PPC'].astype('float64')
                    df_050_059_EC_VVS1_D['Total'] = df_050_059_EC_VVS1_D['Total'].astype('float64')
                    df_050_059_EC_VVS1_D['Total'] = df_050_059_EC_VVS1_D['Carat'] * df_050_059_EC_VVS1_D['PPC']



                elif i=="D" and j == "VVS2" and k == "EC" :
                    df_050_059_EC_VVS2_D = pd.DataFrame()
                    df_050_059_EC_VVS2_D ['Wt Range'] = None
                    df_050_059_EC_VVS2_D  = df_050_059_EC_VVS2_D.assign(Company=None)
                    df_050_059_EC_VVS2_D  = df_050_059_EC_VVS2_D.assign(Shape=None)
                    df_050_059_EC_VVS2_D  = df_050_059_EC_VVS2_D.assign(Carat=None)
                    df_050_059_EC_VVS2_D  = df_050_059_EC_VVS2_D.assign(Color=None)
                    df_050_059_EC_VVS2_D  = df_050_059_EC_VVS2_D.assign(Clarity=None)
                    df_050_059_EC_VVS2_D  = df_050_059_EC_VVS2_D.assign(Cut=None)
                    df_050_059_EC_VVS2_D  = df_050_059_EC_VVS2_D.assign(Polish=None)
                    df_050_059_EC_VVS2_D  = df_050_059_EC_VVS2_D.assign(Symmetry=None)
                    df_050_059_EC_VVS2_D  = df_050_059_EC_VVS2_D.assign(Ratio=None)
                    df_050_059_EC_VVS2_D  = df_050_059_EC_VVS2_D.assign(PPC=None)
                    df_050_059_EC_VVS2_D  = df_050_059_EC_VVS2_D.assign(Total=None)
                    df_050_059_EC_VVS2_D ['Wt Range'] = listwtrange
                    df_050_059_EC_VVS2_D ['Company'] = listcom
                    df_050_059_EC_VVS2_D ['Shape'] = listshap
                    df_050_059_EC_VVS2_D ['Carat'] = listcar
                    df_050_059_EC_VVS2_D ['Color'] = listcol
                    df_050_059_EC_VVS2_D ['Clarity'] = listclar
                    df_050_059_EC_VVS2_D ['Cut'] = listcut
                    df_050_059_EC_VVS2_D ['Polish'] = listpol
                    df_050_059_EC_VVS2_D ['Symmetry'] = listsym
                    df_050_059_EC_VVS2_D ['Ratio'] = listrat
                    df_050_059_EC_VVS2_D ['PPC'] = listdesc
                    df_050_059_EC_VVS2_D ['Total'] = listtotal
                    df_050_059_EC_VVS2_D['Carat'] = df_050_059_EC_VVS2_D['Carat'].astype('float64')
                    df_050_059_EC_VVS2_D['PPC'] = df_050_059_EC_VVS2_D['PPC'].astype('float64')
                    df_050_059_EC_VVS2_D['Total'] = df_050_059_EC_VVS2_D['Total'].astype('float64')
                    df_050_059_EC_VVS2_D['Total'] = df_050_059_EC_VVS2_D['Carat'] * df_050_059_EC_VVS2_D['PPC']



                elif i=="D" and j == "VS1" and k == "EC":
                    df_050_059_EC_VS1_D = pd.DataFrame()
                    df_050_059_EC_VS1_D ['Wt Range'] = None
                    df_050_059_EC_VS1_D  = df_050_059_EC_VS1_D.assign(Company=None)
                    df_050_059_EC_VS1_D  = df_050_059_EC_VS1_D.assign(Shape=None)
                    df_050_059_EC_VS1_D  = df_050_059_EC_VS1_D.assign(Carat=None)
                    df_050_059_EC_VS1_D  = df_050_059_EC_VS1_D.assign(Color=None)
                    df_050_059_EC_VS1_D  = df_050_059_EC_VS1_D.assign(Clarity=None)
                    df_050_059_EC_VS1_D  = df_050_059_EC_VS1_D.assign(Cut=None)
                    df_050_059_EC_VS1_D  = df_050_059_EC_VS1_D.assign(Polish=None)
                    df_050_059_EC_VS1_D  = df_050_059_EC_VS1_D.assign(Symmetry=None)
                    df_050_059_EC_VS1_D  = df_050_059_EC_VS1_D.assign(Ratio=None)
                    df_050_059_EC_VS1_D  = df_050_059_EC_VS1_D.assign(PPC=None)
                    df_050_059_EC_VS1_D  = df_050_059_EC_VS1_D.assign(Total=None)
                    df_050_059_EC_VS1_D ['Wt Range'] = listwtrange
                    df_050_059_EC_VS1_D ['Company'] = listcom
                    df_050_059_EC_VS1_D ['Shape'] = listshap
                    df_050_059_EC_VS1_D ['Carat'] = listcar
                    df_050_059_EC_VS1_D ['Color'] = listcol
                    df_050_059_EC_VS1_D ['Clarity'] = listclar
                    df_050_059_EC_VS1_D ['Cut'] = listcut
                    df_050_059_EC_VS1_D ['Polish'] = listpol
                    df_050_059_EC_VS1_D ['Symmetry'] = listsym
                    df_050_059_EC_VS1_D ['Ratio'] = listrat
                    df_050_059_EC_VS1_D ['PPC'] = listdesc
                    df_050_059_EC_VS1_D ['Total'] = listtotal
                    df_050_059_EC_VS1_D['Carat'] = df_050_059_EC_VS1_D['Carat'].astype('float64')
                    df_050_059_EC_VS1_D['PPC'] = df_050_059_EC_VS1_D['PPC'].astype('float64')
                    df_050_059_EC_VS1_D['Total'] = df_050_059_EC_VS1_D['Total'].astype('float64')
                    df_050_059_EC_VS1_D['Total'] = df_050_059_EC_VS1_D['Carat'] * df_050_059_EC_VS1_D['PPC']


                elif i=="D" and j == "VS2" and k == "EC":
                    df_050_059_EC_VS2_D = pd.DataFrame()
                    df_050_059_EC_VS2_D ['Wt Range'] = None
                    df_050_059_EC_VS2_D  = df_050_059_EC_VS2_D.assign(Company=None)
                    df_050_059_EC_VS2_D  = df_050_059_EC_VS2_D.assign(Shape=None)
                    df_050_059_EC_VS2_D  = df_050_059_EC_VS2_D.assign(Carat=None)
                    df_050_059_EC_VS2_D  = df_050_059_EC_VS2_D.assign(Color=None)
                    df_050_059_EC_VS2_D  = df_050_059_EC_VS2_D.assign(Clarity=None)
                    df_050_059_EC_VS2_D  = df_050_059_EC_VS2_D.assign(Cut=None)
                    df_050_059_EC_VS2_D  = df_050_059_EC_VS2_D.assign(Polish=None)
                    df_050_059_EC_VS2_D  = df_050_059_EC_VS2_D.assign(Symmetry=None)
                    df_050_059_EC_VS2_D  = df_050_059_EC_VS2_D.assign(Ratio=None)
                    df_050_059_EC_VS2_D  = df_050_059_EC_VS2_D.assign(PPC=None)
                    df_050_059_EC_VS2_D  = df_050_059_EC_VS2_D.assign(Total=None)
                    df_050_059_EC_VS2_D ['Wt Range'] = listwtrange
                    df_050_059_EC_VS2_D ['Company'] = listcom
                    df_050_059_EC_VS2_D ['Shape'] = listshap
                    df_050_059_EC_VS2_D ['Carat'] = listcar
                    df_050_059_EC_VS2_D ['Color'] = listcol
                    df_050_059_EC_VS2_D ['Clarity'] = listclar
                    df_050_059_EC_VS2_D ['Cut'] = listcut
                    df_050_059_EC_VS2_D ['Polish'] = listpol
                    df_050_059_EC_VS2_D ['Symmetry'] = listsym
                    df_050_059_EC_VS2_D ['Ratio'] = listrat
                    df_050_059_EC_VS2_D ['PPC'] = listdesc
                    df_050_059_EC_VS2_D ['Total'] = listtotal
                    df_050_059_EC_VS2_D['Carat'] = df_050_059_EC_VS2_D['Carat'].astype('float64')
                    df_050_059_EC_VS2_D['PPC'] = df_050_059_EC_VS2_D['PPC'].astype('float64')
                    df_050_059_EC_VS2_D['Total'] = df_050_059_EC_VS2_D['Total'].astype('float64')
                    df_050_059_EC_VS2_D['Total'] = df_050_059_EC_VS2_D['Carat'] * df_050_059_EC_VS2_D['PPC']


                elif i=="D" and j == "SI1" and k == "EC":
                    df_050_059_EC_SI1_D = pd.DataFrame()
                    df_050_059_EC_SI1_D ['Wt Range'] = None
                    df_050_059_EC_SI1_D  = df_050_059_EC_SI1_D.assign(Company=None)
                    df_050_059_EC_SI1_D  = df_050_059_EC_SI1_D.assign(Shape=None)
                    df_050_059_EC_SI1_D  = df_050_059_EC_SI1_D.assign(Carat=None)
                    df_050_059_EC_SI1_D  = df_050_059_EC_SI1_D.assign(Color=None)
                    df_050_059_EC_SI1_D  = df_050_059_EC_SI1_D.assign(Clarity=None)
                    df_050_059_EC_SI1_D  = df_050_059_EC_SI1_D.assign(Cut=None)
                    df_050_059_EC_SI1_D  = df_050_059_EC_SI1_D.assign(Polish=None)
                    df_050_059_EC_SI1_D  = df_050_059_EC_SI1_D.assign(Symmetry=None)
                    df_050_059_EC_SI1_D  = df_050_059_EC_SI1_D.assign(Ratio=None)
                    df_050_059_EC_SI1_D  = df_050_059_EC_SI1_D.assign(PPC=None)
                    df_050_059_EC_SI1_D  = df_050_059_EC_SI1_D.assign(Total=None)
                    df_050_059_EC_SI1_D ['Wt Range'] = listwtrange
                    df_050_059_EC_SI1_D ['Company'] = listcom
                    df_050_059_EC_SI1_D ['Shape'] = listshap
                    df_050_059_EC_SI1_D ['Carat'] = listcar
                    df_050_059_EC_SI1_D ['Color'] = listcol
                    df_050_059_EC_SI1_D ['Clarity'] = listclar
                    df_050_059_EC_SI1_D ['Cut'] = listcut
                    df_050_059_EC_SI1_D ['Polish'] = listpol
                    df_050_059_EC_SI1_D ['Symmetry'] = listsym
                    df_050_059_EC_SI1_D ['Ratio'] = listrat
                    df_050_059_EC_SI1_D ['PPC'] = listdesc
                    df_050_059_EC_SI1_D ['Total'] = listtotal
                    df_050_059_EC_SI1_D['Carat'] = df_050_059_EC_SI1_D['Carat'].astype('float64')
                    df_050_059_EC_SI1_D['PPC'] = df_050_059_EC_SI1_D['PPC'].astype('float64')
                    df_050_059_EC_SI1_D['Total'] = df_050_059_EC_SI1_D['Total'].astype('float64')
                    df_050_059_EC_SI1_D['Total'] = df_050_059_EC_SI1_D['Carat'] * df_050_059_EC_SI1_D['PPC']


                elif i=="D" and j == "SI2" and k == "EC":
                    df_050_059_EC_SI2_D = pd.DataFrame()
                    df_050_059_EC_SI2_D ['Wt Range'] = None
                    df_050_059_EC_SI2_D  = df_050_059_EC_SI2_D.assign(Company=None)
                    df_050_059_EC_SI2_D  = df_050_059_EC_SI2_D.assign(Shape=None)
                    df_050_059_EC_SI2_D  = df_050_059_EC_SI2_D.assign(Carat=None)
                    df_050_059_EC_SI2_D  = df_050_059_EC_SI2_D.assign(Color=None)
                    df_050_059_EC_SI2_D  = df_050_059_EC_SI2_D.assign(Clarity=None)
                    df_050_059_EC_SI2_D  = df_050_059_EC_SI2_D.assign(Cut=None)
                    df_050_059_EC_SI2_D  = df_050_059_EC_SI2_D.assign(Polish=None)
                    df_050_059_EC_SI2_D  = df_050_059_EC_SI2_D.assign(Symmetry=None)
                    df_050_059_EC_SI2_D  = df_050_059_EC_SI2_D.assign(Ratio=None)
                    df_050_059_EC_SI2_D  = df_050_059_EC_SI2_D.assign(PPC=None)
                    df_050_059_EC_SI2_D  = df_050_059_EC_SI2_D.assign(Total=None)
                    df_050_059_EC_SI2_D ['Wt Range'] = listwtrange
                    df_050_059_EC_SI2_D ['Company'] = listcom
                    df_050_059_EC_SI2_D ['Shape'] = listshap
                    df_050_059_EC_SI2_D ['Carat'] = listcar
                    df_050_059_EC_SI2_D ['Color'] = listcol
                    df_050_059_EC_SI2_D ['Clarity'] = listclar
                    df_050_059_EC_SI2_D ['Cut'] = listcut
                    df_050_059_EC_SI2_D ['Polish'] = listpol
                    df_050_059_EC_SI2_D ['Symmetry'] = listsym
                    df_050_059_EC_SI2_D ['Ratio'] = listrat
                    df_050_059_EC_SI2_D ['PPC'] = listdesc
                    df_050_059_EC_SI2_D ['Total'] = listtotal
                    df_050_059_EC_SI2_D['Carat'] = df_050_059_EC_SI2_D['Carat'].astype('float64')
                    df_050_059_EC_SI2_D['PPC'] = df_050_059_EC_SI2_D['PPC'].astype('float64')
                    df_050_059_EC_SI2_D['Total'] = df_050_059_EC_SI2_D['Total'].astype('float64')
                    df_050_059_EC_SI2_D['Total'] = df_050_059_EC_SI2_D['Carat'] * df_050_059_EC_SI2_D['PPC']


                elif i=="D" and j == "I1" and k == "EC":
                    df_050_059_EC_I1_D = pd.DataFrame()
                    df_050_059_EC_I1_D ['Wt Range'] = None
                    df_050_059_EC_I1_D  = df_050_059_EC_I1_D.assign(Company=None)
                    df_050_059_EC_I1_D  = df_050_059_EC_I1_D.assign(Shape=None)
                    df_050_059_EC_I1_D  = df_050_059_EC_I1_D.assign(Carat=None)
                    df_050_059_EC_I1_D  = df_050_059_EC_I1_D.assign(Color=None)
                    df_050_059_EC_I1_D  = df_050_059_EC_I1_D.assign(Clarity=None)
                    df_050_059_EC_I1_D  = df_050_059_EC_I1_D.assign(Cut=None)
                    df_050_059_EC_I1_D  = df_050_059_EC_I1_D.assign(Polish=None)
                    df_050_059_EC_I1_D  = df_050_059_EC_I1_D.assign(Symmetry=None)
                    df_050_059_EC_I1_D  = df_050_059_EC_I1_D.assign(Ratio=None)
                    df_050_059_EC_I1_D  = df_050_059_EC_I1_D.assign(PPC=None)
                    df_050_059_EC_I1_D  = df_050_059_EC_I1_D.assign(Total=None)
                    df_050_059_EC_I1_D ['Wt Range'] = listwtrange
                    df_050_059_EC_I1_D ['Company'] = listcom
                    df_050_059_EC_I1_D ['Shape'] = listshap
                    df_050_059_EC_I1_D ['Carat'] = listcar
                    df_050_059_EC_I1_D ['Color'] = listcol
                    df_050_059_EC_I1_D ['Clarity'] = listclar
                    df_050_059_EC_I1_D ['Cut'] = listcut
                    df_050_059_EC_I1_D ['Polish'] = listpol
                    df_050_059_EC_I1_D ['Symmetry'] = listsym
                    df_050_059_EC_I1_D ['Ratio'] = listrat
                    df_050_059_EC_I1_D ['PPC'] = listdesc
                    df_050_059_EC_I1_D ['Total'] = listtotal
                    df_050_059_EC_I1_D['Carat'] = df_050_059_EC_I1_D['Carat'].astype('float64')
                    df_050_059_EC_I1_D['PPC'] = df_050_059_EC_I1_D['PPC'].astype('float64')
                    df_050_059_EC_I1_D['Total'] = df_050_059_EC_I1_D['Total'].astype('float64')
                    df_050_059_EC_I1_D['Total'] = df_050_059_EC_I1_D['Carat'] * df_050_059_EC_I1_D['PPC']


                elif i=="D" and j == "I2" and k == "EC":
                    df_050_059_EC_I2_D = pd.DataFrame()
                    df_050_059_EC_I2_D ['Wt Range'] = None
                    df_050_059_EC_I2_D  = df_050_059_EC_I2_D.assign(Company=None)
                    df_050_059_EC_I2_D  = df_050_059_EC_I2_D.assign(Shape=None)
                    df_050_059_EC_I2_D  = df_050_059_EC_I2_D.assign(Carat=None)
                    df_050_059_EC_I2_D  = df_050_059_EC_I2_D.assign(Color=None)
                    df_050_059_EC_I2_D  = df_050_059_EC_I2_D.assign(Clarity=None)
                    df_050_059_EC_I2_D  = df_050_059_EC_I2_D.assign(Cut=None)
                    df_050_059_EC_I2_D  = df_050_059_EC_I2_D.assign(Polish=None)
                    df_050_059_EC_I2_D  = df_050_059_EC_I2_D.assign(Symmetry=None)
                    df_050_059_EC_I2_D  = df_050_059_EC_I2_D.assign(Ratio=None)
                    df_050_059_EC_I2_D  = df_050_059_EC_I2_D.assign(PPC=None)
                    df_050_059_EC_I2_D  = df_050_059_EC_I2_D.assign(Total=None)
                    df_050_059_EC_I2_D ['Wt Range'] = listwtrange
                    df_050_059_EC_I2_D ['Company'] = listcom
                    df_050_059_EC_I2_D ['Shape'] = listshap
                    df_050_059_EC_I2_D ['Carat'] = listcar
                    df_050_059_EC_I2_D ['Color'] = listcol
                    df_050_059_EC_I2_D ['Clarity'] = listclar
                    df_050_059_EC_I2_D ['Cut'] = listcut
                    df_050_059_EC_I2_D ['Polish'] = listpol
                    df_050_059_EC_I2_D ['Symmetry'] = listsym
                    df_050_059_EC_I2_D ['Ratio'] = listrat
                    df_050_059_EC_I2_D ['PPC'] = listdesc
                    df_050_059_EC_I2_D ['Total'] = listtotal
                    df_050_059_EC_I2_D['Carat'] = df_050_059_EC_I2_D['Carat'].astype('float64')
                    df_050_059_EC_I2_D['PPC'] = df_050_059_EC_I2_D['PPC'].astype('float64')
                    df_050_059_EC_I2_D['Total'] = df_050_059_EC_I2_D['Total'].astype('float64')
                    df_050_059_EC_I2_D['Total'] = df_050_059_EC_I2_D['Carat'] * df_050_059_EC_I2_D['PPC']



                elif i=="E" and j == "IF" and k == "EC":
                    df_050_059_EC_IF_E = pd.DataFrame()
                    df_050_059_EC_IF_E ['Wt Range'] = None
                    df_050_059_EC_IF_E  = df_050_059_EC_IF_E.assign(Company=None)
                    df_050_059_EC_IF_E  = df_050_059_EC_IF_E.assign(Shape=None)
                    df_050_059_EC_IF_E  = df_050_059_EC_IF_E.assign(Carat=None)
                    df_050_059_EC_IF_E  = df_050_059_EC_IF_E.assign(Color=None)
                    df_050_059_EC_IF_E  = df_050_059_EC_IF_E.assign(Clarity=None)
                    df_050_059_EC_IF_E  = df_050_059_EC_IF_E.assign(Cut=None)
                    df_050_059_EC_IF_E  = df_050_059_EC_IF_E.assign(Polish=None)
                    df_050_059_EC_IF_E  = df_050_059_EC_IF_E.assign(Symmetry=None)
                    df_050_059_EC_IF_E  = df_050_059_EC_IF_E.assign(Ratio=None)
                    df_050_059_EC_IF_E  = df_050_059_EC_IF_E.assign(PPC=None)
                    df_050_059_EC_IF_E  = df_050_059_EC_IF_E.assign(Total=None)
                    df_050_059_EC_IF_E ['Wt Range'] = listwtrange
                    df_050_059_EC_IF_E ['Company'] = listcom
                    df_050_059_EC_IF_E ['Shape'] = listshap
                    df_050_059_EC_IF_E ['Carat'] = listcar
                    df_050_059_EC_IF_E ['Color'] = listcol
                    df_050_059_EC_IF_E ['Clarity'] = listclar
                    df_050_059_EC_IF_E ['Cut'] = listcut
                    df_050_059_EC_IF_E ['Polish'] = listpol
                    df_050_059_EC_IF_E ['Symmetry'] = listsym
                    df_050_059_EC_IF_E ['Ratio'] = listrat
                    df_050_059_EC_IF_E ['PPC'] = listdesc
                    df_050_059_EC_IF_E ['Total'] = listtotal
                    df_050_059_EC_IF_E['Carat'] = df_050_059_EC_IF_E['Carat'].astype('float64')
                    df_050_059_EC_IF_E['PPC'] = df_050_059_EC_IF_E['PPC'].astype('float64')
                    df_050_059_EC_IF_E['Total'] = df_050_059_EC_IF_E['Total'].astype('float64')
                    df_050_059_EC_IF_E['Total'] = df_050_059_EC_IF_E['Carat'] * df_050_059_EC_IF_E['PPC']



                elif i=="E" and j == "VVS1" and k == "EC":
                    df_050_059_EC_VVS1_E = pd.DataFrame()
                    df_050_059_EC_VVS1_E ['Wt Range'] = None
                    df_050_059_EC_VVS1_E  = df_050_059_EC_VVS1_E.assign(Company=None)
                    df_050_059_EC_VVS1_E  = df_050_059_EC_VVS1_E.assign(Shape=None)
                    df_050_059_EC_VVS1_E  = df_050_059_EC_VVS1_E.assign(Carat=None)
                    df_050_059_EC_VVS1_E  = df_050_059_EC_VVS1_E.assign(Color=None)
                    df_050_059_EC_VVS1_E  = df_050_059_EC_VVS1_E.assign(Clarity=None)
                    df_050_059_EC_VVS1_E  = df_050_059_EC_VVS1_E.assign(Cut=None)
                    df_050_059_EC_VVS1_E  = df_050_059_EC_VVS1_E.assign(Polish=None)
                    df_050_059_EC_VVS1_E  = df_050_059_EC_VVS1_E.assign(Symmetry=None)
                    df_050_059_EC_VVS1_E  = df_050_059_EC_VVS1_E.assign(Ratio=None)
                    df_050_059_EC_VVS1_E  = df_050_059_EC_VVS1_E.assign(PPC=None)
                    df_050_059_EC_VVS1_E  = df_050_059_EC_VVS1_E.assign(Total=None)
                    df_050_059_EC_VVS1_E ['Wt Range'] = listwtrange
                    df_050_059_EC_VVS1_E ['Company'] = listcom
                    df_050_059_EC_VVS1_E ['Shape'] = listshap
                    df_050_059_EC_VVS1_E ['Carat'] = listcar
                    df_050_059_EC_VVS1_E ['Color'] = listcol
                    df_050_059_EC_VVS1_E ['Clarity'] = listclar
                    df_050_059_EC_VVS1_E ['Cut'] = listcut
                    df_050_059_EC_VVS1_E ['Polish'] = listpol
                    df_050_059_EC_VVS1_E ['Symmetry'] = listsym
                    df_050_059_EC_VVS1_E ['Ratio'] = listrat
                    df_050_059_EC_VVS1_E ['PPC'] = listdesc
                    df_050_059_EC_VVS1_E ['Total'] = listtotal
                    df_050_059_EC_VVS1_E['Carat'] = df_050_059_EC_VVS1_E['Carat'].astype('float64')
                    df_050_059_EC_VVS1_E['PPC'] = df_050_059_EC_VVS1_E['PPC'].astype('float64')
                    df_050_059_EC_VVS1_E['Total'] = df_050_059_EC_VVS1_E['Total'].astype('float64')
                    df_050_059_EC_VVS1_E['Total'] = df_050_059_EC_VVS1_E['Carat'] * df_050_059_EC_VVS1_E['PPC']


                elif i=="E" and j == "VVS2" and k == "EC":
                    df_050_059_EC_VVS2_E = pd.DataFrame()
                    df_050_059_EC_VVS2_E ['Wt Range'] = None
                    df_050_059_EC_VVS2_E  = df_050_059_EC_VVS2_E.assign(Company=None)
                    df_050_059_EC_VVS2_E  = df_050_059_EC_VVS2_E.assign(Shape=None)
                    df_050_059_EC_VVS2_E  = df_050_059_EC_VVS2_E.assign(Carat=None)
                    df_050_059_EC_VVS2_E  = df_050_059_EC_VVS2_E.assign(Color=None)
                    df_050_059_EC_VVS2_E  = df_050_059_EC_VVS2_E.assign(Clarity=None)
                    df_050_059_EC_VVS2_E  = df_050_059_EC_VVS2_E.assign(Cut=None)
                    df_050_059_EC_VVS2_E  = df_050_059_EC_VVS2_E.assign(Polish=None)
                    df_050_059_EC_VVS2_E  = df_050_059_EC_VVS2_E.assign(Symmetry=None)
                    df_050_059_EC_VVS2_E  = df_050_059_EC_VVS2_E.assign(Ratio=None)
                    df_050_059_EC_VVS2_E  = df_050_059_EC_VVS2_E.assign(PPC=None)
                    df_050_059_EC_VVS2_E  = df_050_059_EC_VVS2_E.assign(Total=None)
                    df_050_059_EC_VVS2_E ['Wt Range'] = listwtrange
                    df_050_059_EC_VVS2_E ['Company'] = listcom
                    df_050_059_EC_VVS2_E ['Shape'] = listshap
                    df_050_059_EC_VVS2_E ['Carat'] = listcar
                    df_050_059_EC_VVS2_E ['Color'] = listcol
                    df_050_059_EC_VVS2_E ['Clarity'] = listclar
                    df_050_059_EC_VVS2_E ['Cut'] = listcut
                    df_050_059_EC_VVS2_E ['Polish'] = listpol
                    df_050_059_EC_VVS2_E ['Symmetry'] = listsym
                    df_050_059_EC_VVS2_E ['Ratio'] = listrat
                    df_050_059_EC_VVS2_E ['PPC'] = listdesc
                    df_050_059_EC_VVS2_E ['Total'] = listtotal
                    df_050_059_EC_VVS2_E['Carat'] = df_050_059_EC_VVS2_E['Carat'].astype('float64')
                    df_050_059_EC_VVS2_E['PPC'] = df_050_059_EC_VVS2_E['PPC'].astype('float64')
                    df_050_059_EC_VVS2_E['Total'] = df_050_059_EC_VVS2_E['Total'].astype('float64')
                    df_050_059_EC_VVS2_E['Total'] = df_050_059_EC_VVS2_E['Carat'] * df_050_059_EC_VVS2_E['PPC']


                elif i=="E" and j=="VS1" and k == "EC":
                    df_050_059_EC_VS1_E = pd.DataFrame()
                    df_050_059_EC_VS1_E ['Wt Range'] = None
                    df_050_059_EC_VS1_E  = df_050_059_EC_VS1_E.assign(Company=None)
                    df_050_059_EC_VS1_E  = df_050_059_EC_VS1_E.assign(Shape=None)
                    df_050_059_EC_VS1_E  = df_050_059_EC_VS1_E.assign(Carat=None)
                    df_050_059_EC_VS1_E  = df_050_059_EC_VS1_E.assign(Color=None)
                    df_050_059_EC_VS1_E  = df_050_059_EC_VS1_E.assign(Clarity=None)
                    df_050_059_EC_VS1_E  = df_050_059_EC_VS1_E.assign(Cut=None)
                    df_050_059_EC_VS1_E  = df_050_059_EC_VS1_E.assign(Polish=None)
                    df_050_059_EC_VS1_E  = df_050_059_EC_VS1_E.assign(Symmetry=None)
                    df_050_059_EC_VS1_E  = df_050_059_EC_VS1_E.assign(Ratio=None)
                    df_050_059_EC_VS1_E  = df_050_059_EC_VS1_E.assign(PPC=None)
                    df_050_059_EC_VS1_E  = df_050_059_EC_VS1_E.assign(Total=None)
                    df_050_059_EC_VS1_E ['Wt Range'] = listwtrange
                    df_050_059_EC_VS1_E ['Company'] = listcom
                    df_050_059_EC_VS1_E ['Shape'] = listshap
                    df_050_059_EC_VS1_E ['Carat'] = listcar
                    df_050_059_EC_VS1_E ['Color'] = listcol
                    df_050_059_EC_VS1_E ['Clarity'] = listclar
                    df_050_059_EC_VS1_E ['Cut'] = listcut
                    df_050_059_EC_VS1_E ['Polish'] = listpol
                    df_050_059_EC_VS1_E ['Symmetry'] = listsym
                    df_050_059_EC_VS1_E ['Ratio'] = listrat
                    df_050_059_EC_VS1_E ['PPC'] = listdesc
                    df_050_059_EC_VS1_E ['Total'] = listtotal
                    df_050_059_EC_VS1_E['Carat'] = df_050_059_EC_VS1_E['Carat'].astype('float64')
                    df_050_059_EC_VS1_E['PPC'] = df_050_059_EC_VS1_E['PPC'].astype('float64')
                    df_050_059_EC_VS1_E['Total'] = df_050_059_EC_VS1_E['Total'].astype('float64')
                    df_050_059_EC_VS1_E['Total'] = df_050_059_EC_VS1_E['Carat'] * df_050_059_EC_VS1_E['PPC']


                elif i=="E" and j == "VS2" and k == "EC":
                    df_050_059_EC_VS2_E = pd.DataFrame()
                    df_050_059_EC_VS2_E ['Wt Range'] = None
                    df_050_059_EC_VS2_E  = df_050_059_EC_VS2_E.assign(Company=None)
                    df_050_059_EC_VS2_E  = df_050_059_EC_VS2_E.assign(Shape=None)
                    df_050_059_EC_VS2_E  = df_050_059_EC_VS2_E.assign(Carat=None)
                    df_050_059_EC_VS2_E  = df_050_059_EC_VS2_E.assign(Color=None)
                    df_050_059_EC_VS2_E  = df_050_059_EC_VS2_E.assign(Clarity=None)
                    df_050_059_EC_VS2_E  = df_050_059_EC_VS2_E.assign(Cut=None)
                    df_050_059_EC_VS2_E  = df_050_059_EC_VS2_E.assign(Polish=None)
                    df_050_059_EC_VS2_E  = df_050_059_EC_VS2_E.assign(Symmetry=None)
                    df_050_059_EC_VS2_E  = df_050_059_EC_VS2_E.assign(Ratio=None)
                    df_050_059_EC_VS2_E  = df_050_059_EC_VS2_E.assign(PPC=None)
                    df_050_059_EC_VS2_E  = df_050_059_EC_VS2_E.assign(Total=None)
                    df_050_059_EC_VS2_E ['Wt Range'] = listwtrange
                    df_050_059_EC_VS2_E ['Company'] = listcom
                    df_050_059_EC_VS2_E ['Shape'] = listshap
                    df_050_059_EC_VS2_E ['Carat'] = listcar
                    df_050_059_EC_VS2_E ['Color'] = listcol
                    df_050_059_EC_VS2_E ['Clarity'] = listclar
                    df_050_059_EC_VS2_E ['Cut'] = listcut
                    df_050_059_EC_VS2_E ['Polish'] = listpol
                    df_050_059_EC_VS2_E ['Symmetry'] = listsym
                    df_050_059_EC_VS2_E ['Ratio'] = listrat
                    df_050_059_EC_VS2_E ['PPC'] = listdesc
                    df_050_059_EC_VS2_E ['Total'] = listtotal
                    df_050_059_EC_VS2_E['Carat'] = df_050_059_EC_VS2_E['Carat'].astype('float64')
                    df_050_059_EC_VS2_E['PPC'] = df_050_059_EC_VS2_E['PPC'].astype('float64')
                    df_050_059_EC_VS2_E['Total'] = df_050_059_EC_VS2_E['Total'].astype('float64')
                    df_050_059_EC_VS2_E['Total'] = df_050_059_EC_VS2_E['Carat'] * df_050_059_EC_VS2_E['PPC']


                elif i=="E" and j == "SI1" and k == "EC":
                    df_050_059_EC_SI1_E = pd.DataFrame()
                    df_050_059_EC_SI1_E ['Wt Range'] = None
                    df_050_059_EC_SI1_E  = df_050_059_EC_SI1_E.assign(Company=None)
                    df_050_059_EC_SI1_E  = df_050_059_EC_SI1_E.assign(Shape=None)
                    df_050_059_EC_SI1_E  = df_050_059_EC_SI1_E.assign(Carat=None)
                    df_050_059_EC_SI1_E  = df_050_059_EC_SI1_E.assign(Color=None)
                    df_050_059_EC_SI1_E  = df_050_059_EC_SI1_E.assign(Clarity=None)
                    df_050_059_EC_SI1_E  = df_050_059_EC_SI1_E.assign(Cut=None)
                    df_050_059_EC_SI1_E  = df_050_059_EC_SI1_E.assign(Polish=None)
                    df_050_059_EC_SI1_E  = df_050_059_EC_SI1_E.assign(Symmetry=None)
                    df_050_059_EC_SI1_E  = df_050_059_EC_SI1_E.assign(Ratio=None)
                    df_050_059_EC_SI1_E  = df_050_059_EC_SI1_E.assign(PPC=None)
                    df_050_059_EC_SI1_E  = df_050_059_EC_SI1_E.assign(Total=None)
                    df_050_059_EC_SI1_E ['Wt Range'] = listwtrange
                    df_050_059_EC_SI1_E ['Company'] = listcom
                    df_050_059_EC_SI1_E ['Shape'] = listshap
                    df_050_059_EC_SI1_E ['Carat'] = listcar
                    df_050_059_EC_SI1_E ['Color'] = listcol
                    df_050_059_EC_SI1_E ['Clarity'] = listclar
                    df_050_059_EC_SI1_E ['Cut'] = listcut
                    df_050_059_EC_SI1_E ['Polish'] = listpol
                    df_050_059_EC_SI1_E ['Symmetry'] = listsym
                    df_050_059_EC_SI1_E ['Ratio'] = listrat
                    df_050_059_EC_SI1_E ['PPC'] = listdesc
                    df_050_059_EC_SI1_E ['Total'] = listtotal
                    df_050_059_EC_SI1_E['Carat'] = df_050_059_EC_SI1_E['Carat'].astype('float64')
                    df_050_059_EC_SI1_E['PPC'] = df_050_059_EC_SI1_E['PPC'].astype('float64')
                    df_050_059_EC_SI1_E['Total'] = df_050_059_EC_SI1_E['Total'].astype('float64')
                    df_050_059_EC_SI1_E['Total'] = df_050_059_EC_SI1_E['Carat'] * df_050_059_EC_SI1_E['PPC']


                elif i=="E" and j == "SI2" and k == "EC":
                    df_050_059_EC_SI2_E = pd.DataFrame()
                    df_050_059_EC_SI2_E ['Wt Range'] = None
                    df_050_059_EC_SI2_E  = df_050_059_EC_SI2_E.assign(Company=None)
                    df_050_059_EC_SI2_E  = df_050_059_EC_SI2_E.assign(Shape=None)
                    df_050_059_EC_SI2_E  = df_050_059_EC_SI2_E.assign(Carat=None)
                    df_050_059_EC_SI2_E  = df_050_059_EC_SI2_E.assign(Color=None)
                    df_050_059_EC_SI2_E  = df_050_059_EC_SI2_E.assign(Clarity=None)
                    df_050_059_EC_SI2_E  = df_050_059_EC_SI2_E.assign(Cut=None)
                    df_050_059_EC_SI2_E  = df_050_059_EC_SI2_E.assign(Polish=None)
                    df_050_059_EC_SI2_E  = df_050_059_EC_SI2_E.assign(Symmetry=None)
                    df_050_059_EC_SI2_E  = df_050_059_EC_SI2_E.assign(Ratio=None)
                    df_050_059_EC_SI2_E  = df_050_059_EC_SI2_E.assign(PPC=None)
                    df_050_059_EC_SI2_E  = df_050_059_EC_SI2_E.assign(Total=None)
                    df_050_059_EC_SI2_E ['Wt Range'] = listwtrange
                    df_050_059_EC_SI2_E ['Company'] = listcom
                    df_050_059_EC_SI2_E ['Shape'] = listshap
                    df_050_059_EC_SI2_E ['Carat'] = listcar
                    df_050_059_EC_SI2_E ['Color'] = listcol
                    df_050_059_EC_SI2_E ['Clarity'] = listclar
                    df_050_059_EC_SI2_E ['Cut'] = listcut
                    df_050_059_EC_SI2_E ['Polish'] = listpol
                    df_050_059_EC_SI2_E ['Symmetry'] = listsym
                    df_050_059_EC_SI2_E ['Ratio'] = listrat
                    df_050_059_EC_SI2_E ['PPC'] = listdesc
                    df_050_059_EC_SI2_E ['Total'] = listtotal
                    df_050_059_EC_SI2_E['Carat'] = df_050_059_EC_SI2_E['Carat'].astype('float64')
                    df_050_059_EC_SI2_E['PPC'] = df_050_059_EC_SI2_E['PPC'].astype('float64')
                    df_050_059_EC_SI2_E['Total'] = df_050_059_EC_SI2_E['Total'].astype('float64')
                    df_050_059_EC_SI2_E['Total'] = df_050_059_EC_SI2_E['Carat'] * df_050_059_EC_SI2_E['PPC']


                elif i=="E" and j == "I1" and k == "EC":
                    df_050_059_EC_I1_E = pd.DataFrame()
                    df_050_059_EC_I1_E ['Wt Range'] = None
                    df_050_059_EC_I1_E  = df_050_059_EC_I1_E.assign(Company=None)
                    df_050_059_EC_I1_E  = df_050_059_EC_I1_E.assign(Shape=None)
                    df_050_059_EC_I1_E  = df_050_059_EC_I1_E.assign(Carat=None)
                    df_050_059_EC_I1_E  = df_050_059_EC_I1_E.assign(Color=None)
                    df_050_059_EC_I1_E  = df_050_059_EC_I1_E.assign(Clarity=None)
                    df_050_059_EC_I1_E  = df_050_059_EC_I1_E.assign(Cut=None)
                    df_050_059_EC_I1_E  = df_050_059_EC_I1_E.assign(Polish=None)
                    df_050_059_EC_I1_E  = df_050_059_EC_I1_E.assign(Symmetry=None)
                    df_050_059_EC_I1_E  = df_050_059_EC_I1_E.assign(Ratio=None)
                    df_050_059_EC_I1_E  = df_050_059_EC_I1_E.assign(PPC=None)
                    df_050_059_EC_I1_E  = df_050_059_EC_I1_E.assign(Total=None)
                    df_050_059_EC_I1_E ['Wt Range'] = listwtrange
                    df_050_059_EC_I1_E ['Company'] = listcom
                    df_050_059_EC_I1_E ['Shape'] = listshap
                    df_050_059_EC_I1_E ['Carat'] = listcar
                    df_050_059_EC_I1_E ['Color'] = listcol
                    df_050_059_EC_I1_E ['Clarity'] = listclar
                    df_050_059_EC_I1_E ['Cut'] = listcut
                    df_050_059_EC_I1_E ['Polish'] = listpol
                    df_050_059_EC_I1_E ['Symmetry'] = listsym
                    df_050_059_EC_I1_E ['Ratio'] = listrat
                    df_050_059_EC_I1_E ['PPC'] = listdesc
                    df_050_059_EC_I1_E ['Total'] = listtotal
                    df_050_059_EC_I1_E['Carat'] = df_050_059_EC_I1_E['Carat'].astype('float64')
                    df_050_059_EC_I1_E['PPC'] = df_050_059_EC_I1_E['PPC'].astype('float64')
                    df_050_059_EC_I1_E['Total'] = df_050_059_EC_I1_E['Total'].astype('float64')
                    df_050_059_EC_I1_E['Total'] = df_050_059_EC_I1_E['Carat'] * df_050_059_EC_I1_E['PPC']


                elif i=="E" and j == "I2" and k == "EC":
                    df_050_059_EC_I2_E = pd.DataFrame()
                    df_050_059_EC_I2_E ['Wt Range'] = None
                    df_050_059_EC_I2_E  = df_050_059_EC_I2_E.assign(Company=None)
                    df_050_059_EC_I2_E  = df_050_059_EC_I2_E.assign(Shape=None)
                    df_050_059_EC_I2_E  = df_050_059_EC_I2_E.assign(Carat=None)
                    df_050_059_EC_I2_E  = df_050_059_EC_I2_E.assign(Color=None)
                    df_050_059_EC_I2_E  = df_050_059_EC_I2_E.assign(Clarity=None)
                    df_050_059_EC_I2_E  = df_050_059_EC_I2_E.assign(Cut=None)
                    df_050_059_EC_I2_E  = df_050_059_EC_I2_E.assign(Polish=None)
                    df_050_059_EC_I2_E  = df_050_059_EC_I2_E.assign(Symmetry=None)
                    df_050_059_EC_I2_E  = df_050_059_EC_I2_E.assign(Ratio=None)
                    df_050_059_EC_I2_E  = df_050_059_EC_I2_E.assign(PPC=None)
                    df_050_059_EC_I2_E  = df_050_059_EC_I2_E.assign(Total=None)
                    df_050_059_EC_I2_E ['Wt Range'] = listwtrange
                    df_050_059_EC_I2_E ['Company'] = listcom
                    df_050_059_EC_I2_E ['Shape'] = listshap
                    df_050_059_EC_I2_E ['Carat'] = listcar
                    df_050_059_EC_I2_E ['Color'] = listcol
                    df_050_059_EC_I2_E ['Clarity'] = listclar
                    df_050_059_EC_I2_E ['Cut'] = listcut
                    df_050_059_EC_I2_E ['Polish'] = listpol
                    df_050_059_EC_I2_E ['Symmetry'] = listsym
                    df_050_059_EC_I2_E ['Ratio'] = listrat
                    df_050_059_EC_I2_E ['PPC'] = listdesc
                    df_050_059_EC_I2_E ['Total'] = listtotal
                    df_050_059_EC_I2_E['Carat'] = df_050_059_EC_I2_E['Carat'].astype('float64')
                    df_050_059_EC_I2_E['PPC'] = df_050_059_EC_I2_E['PPC'].astype('float64')
                    df_050_059_EC_I2_E['Total'] = df_050_059_EC_I2_E['Total'].astype('float64')
                    df_050_059_EC_I2_E['Total'] = df_050_059_EC_I2_E['Carat'] * df_050_059_EC_I2_E['PPC']
                
                elif i=="F" and j == "IF" and k == "EC":
                    df_050_059_EC_IF_F = pd.DataFrame()
                    df_050_059_EC_IF_F ['Wt Range'] = None
                    df_050_059_EC_IF_F  = df_050_059_EC_IF_F.assign(Company=None)
                    df_050_059_EC_IF_F  = df_050_059_EC_IF_F.assign(Shape=None)
                    df_050_059_EC_IF_F  = df_050_059_EC_IF_F.assign(Carat=None)
                    df_050_059_EC_IF_F  = df_050_059_EC_IF_F.assign(Color=None)
                    df_050_059_EC_IF_F  = df_050_059_EC_IF_F.assign(Clarity=None)
                    df_050_059_EC_IF_F  = df_050_059_EC_IF_F.assign(Cut=None)
                    df_050_059_EC_IF_F  = df_050_059_EC_IF_F.assign(Polish=None)
                    df_050_059_EC_IF_F  = df_050_059_EC_IF_F.assign(Symmetry=None)
                    df_050_059_EC_IF_F  = df_050_059_EC_IF_F.assign(Ratio=None)
                    df_050_059_EC_IF_F  = df_050_059_EC_IF_F.assign(PPC=None)
                    df_050_059_EC_IF_F  = df_050_059_EC_IF_F.assign(Total=None)
                    df_050_059_EC_IF_F ['Wt Range'] = listwtrange
                    df_050_059_EC_IF_F ['Company'] = listcom
                    df_050_059_EC_IF_F ['Shape'] = listshap
                    df_050_059_EC_IF_F ['Carat'] = listcar
                    df_050_059_EC_IF_F ['Color'] = listcol
                    df_050_059_EC_IF_F ['Clarity'] = listclar
                    df_050_059_EC_IF_F ['Cut'] = listcut
                    df_050_059_EC_IF_F ['Polish'] = listpol
                    df_050_059_EC_IF_F ['Symmetry'] = listsym
                    df_050_059_EC_IF_F ['Ratio'] = listrat
                    df_050_059_EC_IF_F ['PPC'] = listdesc
                    df_050_059_EC_IF_F ['Total'] = listtotal
                    df_050_059_EC_IF_F['Carat'] = df_050_059_EC_IF_F['Carat'].astype('float64')
                    df_050_059_EC_IF_F['PPC'] = df_050_059_EC_IF_F['PPC'].astype('float64')
                    df_050_059_EC_IF_F['Total'] = df_050_059_EC_IF_F['Total'].astype('float64')
                    df_050_059_EC_IF_F['Total'] = df_050_059_EC_IF_F['Carat'] * df_050_059_EC_IF_F['PPC']



                elif i=="F" and j == "VVS1" and k == "EC":
                    df_050_059_EC_VVS1_F = pd.DataFrame()
                    df_050_059_EC_VVS1_F ['Wt Range'] = None
                    df_050_059_EC_VVS1_F  = df_050_059_EC_VVS1_F.assign(Company=None)
                    df_050_059_EC_VVS1_F  = df_050_059_EC_VVS1_F.assign(Shape=None)
                    df_050_059_EC_VVS1_F  = df_050_059_EC_VVS1_F.assign(Carat=None)
                    df_050_059_EC_VVS1_F  = df_050_059_EC_VVS1_F.assign(Color=None)
                    df_050_059_EC_VVS1_F  = df_050_059_EC_VVS1_F.assign(Clarity=None)
                    df_050_059_EC_VVS1_F  = df_050_059_EC_VVS1_F.assign(Cut=None)
                    df_050_059_EC_VVS1_F  = df_050_059_EC_VVS1_F.assign(Polish=None)
                    df_050_059_EC_VVS1_F  = df_050_059_EC_VVS1_F.assign(Symmetry=None)
                    df_050_059_EC_VVS1_F  = df_050_059_EC_VVS1_F.assign(Ratio=None)
                    df_050_059_EC_VVS1_F  = df_050_059_EC_VVS1_F.assign(PPC=None)
                    df_050_059_EC_VVS1_F  = df_050_059_EC_VVS1_F.assign(Total=None)
                    df_050_059_EC_VVS1_F ['Wt Range'] = listwtrange
                    df_050_059_EC_VVS1_F ['Company'] = listcom
                    df_050_059_EC_VVS1_F ['Shape'] = listshap
                    df_050_059_EC_VVS1_F ['Carat'] = listcar
                    df_050_059_EC_VVS1_F ['Color'] = listcol
                    df_050_059_EC_VVS1_F ['Clarity'] = listclar
                    df_050_059_EC_VVS1_F ['Cut'] = listcut
                    df_050_059_EC_VVS1_F ['Polish'] = listpol
                    df_050_059_EC_VVS1_F ['Symmetry'] = listsym
                    df_050_059_EC_VVS1_F ['Ratio'] = listrat
                    df_050_059_EC_VVS1_F ['PPC'] = listdesc
                    df_050_059_EC_VVS1_F ['Total'] = listtotal
                    df_050_059_EC_VVS1_F['Carat'] = df_050_059_EC_VVS1_F['Carat'].astype('float64')
                    df_050_059_EC_VVS1_F['PPC'] = df_050_059_EC_VVS1_F['PPC'].astype('float64')
                    df_050_059_EC_VVS1_F['Total'] = df_050_059_EC_VVS1_F['Total'].astype('float64')
                    df_050_059_EC_VVS1_F['Total'] = df_050_059_EC_VVS1_F['Carat'] * df_050_059_EC_VVS1_F['PPC']


                elif i=="F" and j == "VVS2" and k == "EC":
                    df_050_059_EC_VVS2_F = pd.DataFrame()
                    df_050_059_EC_VVS2_F ['Wt Range'] = None
                    df_050_059_EC_VVS2_F  = df_050_059_EC_VVS2_F.assign(Company=None)
                    df_050_059_EC_VVS2_F  = df_050_059_EC_VVS2_F.assign(Shape=None)
                    df_050_059_EC_VVS2_F  = df_050_059_EC_VVS2_F.assign(Carat=None)
                    df_050_059_EC_VVS2_F  = df_050_059_EC_VVS2_F.assign(Color=None)
                    df_050_059_EC_VVS2_F  = df_050_059_EC_VVS2_F.assign(Clarity=None)
                    df_050_059_EC_VVS2_F  = df_050_059_EC_VVS2_F.assign(Cut=None)
                    df_050_059_EC_VVS2_F  = df_050_059_EC_VVS2_F.assign(Polish=None)
                    df_050_059_EC_VVS2_F  = df_050_059_EC_VVS2_F.assign(Symmetry=None)
                    df_050_059_EC_VVS2_F  = df_050_059_EC_VVS2_F.assign(Ratio=None)
                    df_050_059_EC_VVS2_F  = df_050_059_EC_VVS2_F.assign(PPC=None)
                    df_050_059_EC_VVS2_F  = df_050_059_EC_VVS2_F.assign(Total=None)
                    df_050_059_EC_VVS2_F ['Wt Range'] = listwtrange
                    df_050_059_EC_VVS2_F ['Company'] = listcom
                    df_050_059_EC_VVS2_F ['Shape'] = listshap
                    df_050_059_EC_VVS2_F ['Carat'] = listcar
                    df_050_059_EC_VVS2_F ['Color'] = listcol
                    df_050_059_EC_VVS2_F ['Clarity'] = listclar
                    df_050_059_EC_VVS2_F ['Cut'] = listcut
                    df_050_059_EC_VVS2_F ['Polish'] = listpol
                    df_050_059_EC_VVS2_F ['Symmetry'] = listsym
                    df_050_059_EC_VVS2_F ['Ratio'] = listrat
                    df_050_059_EC_VVS2_F ['PPC'] = listdesc
                    df_050_059_EC_VVS2_F ['Total'] = listtotal
                    df_050_059_EC_VVS2_F['Carat'] = df_050_059_EC_VVS2_F['Carat'].astype('float64')
                    df_050_059_EC_VVS2_F['PPC'] = df_050_059_EC_VVS2_F['PPC'].astype('float64')
                    df_050_059_EC_VVS2_F['Total'] = df_050_059_EC_VVS2_F['Total'].astype('float64')
                    df_050_059_EC_VVS2_F['Total'] = df_050_059_EC_VVS2_F['Carat'] * df_050_059_EC_VVS2_F['PPC']


                elif i=="F" and j=="VS1" and k == "EC":
                    df_050_059_EC_VS1_F = pd.DataFrame()
                    df_050_059_EC_VS1_F ['Wt Range'] = None
                    df_050_059_EC_VS1_F  = df_050_059_EC_VS1_F.assign(Company=None)
                    df_050_059_EC_VS1_F  = df_050_059_EC_VS1_F.assign(Shape=None)
                    df_050_059_EC_VS1_F  = df_050_059_EC_VS1_F.assign(Carat=None)
                    df_050_059_EC_VS1_F  = df_050_059_EC_VS1_F.assign(Color=None)
                    df_050_059_EC_VS1_F  = df_050_059_EC_VS1_F.assign(Clarity=None)
                    df_050_059_EC_VS1_F  = df_050_059_EC_VS1_F.assign(Cut=None)
                    df_050_059_EC_VS1_F  = df_050_059_EC_VS1_F.assign(Polish=None)
                    df_050_059_EC_VS1_F  = df_050_059_EC_VS1_F.assign(Symmetry=None)
                    df_050_059_EC_VS1_F  = df_050_059_EC_VS1_F.assign(Ratio=None)
                    df_050_059_EC_VS1_F  = df_050_059_EC_VS1_F.assign(PPC=None)
                    df_050_059_EC_VS1_F  = df_050_059_EC_VS1_F.assign(Total=None)
                    df_050_059_EC_VS1_F ['Wt Range'] = listwtrange
                    df_050_059_EC_VS1_F ['Company'] = listcom
                    df_050_059_EC_VS1_F ['Shape'] = listshap
                    df_050_059_EC_VS1_F ['Carat'] = listcar
                    df_050_059_EC_VS1_F ['Color'] = listcol
                    df_050_059_EC_VS1_F ['Clarity'] = listclar
                    df_050_059_EC_VS1_F ['Cut'] = listcut
                    df_050_059_EC_VS1_F ['Polish'] = listpol
                    df_050_059_EC_VS1_F ['Symmetry'] = listsym
                    df_050_059_EC_VS1_F ['Ratio'] = listrat
                    df_050_059_EC_VS1_F ['PPC'] = listdesc
                    df_050_059_EC_VS1_F ['Total'] = listtotal
                    df_050_059_EC_VS1_F['Carat'] = df_050_059_EC_VS1_F['Carat'].astype('float64')
                    df_050_059_EC_VS1_F['PPC'] = df_050_059_EC_VS1_F['PPC'].astype('float64')
                    df_050_059_EC_VS1_F['Total'] = df_050_059_EC_VS1_F['Total'].astype('float64')
                    df_050_059_EC_VS1_F['Total'] = df_050_059_EC_VS1_F['Carat'] * df_050_059_EC_VS1_F['PPC']


                elif i=="F" and j == "VS2" and k == "EC":
                    df_050_059_EC_VS2_F = pd.DataFrame()
                    df_050_059_EC_VS2_F ['Wt Range'] = None
                    df_050_059_EC_VS2_F  = df_050_059_EC_VS2_F.assign(Company=None)
                    df_050_059_EC_VS2_F  = df_050_059_EC_VS2_F.assign(Shape=None)
                    df_050_059_EC_VS2_F  = df_050_059_EC_VS2_F.assign(Carat=None)
                    df_050_059_EC_VS2_F  = df_050_059_EC_VS2_F.assign(Color=None)
                    df_050_059_EC_VS2_F  = df_050_059_EC_VS2_F.assign(Clarity=None)
                    df_050_059_EC_VS2_F  = df_050_059_EC_VS2_F.assign(Cut=None)
                    df_050_059_EC_VS2_F  = df_050_059_EC_VS2_F.assign(Polish=None)
                    df_050_059_EC_VS2_F  = df_050_059_EC_VS2_F.assign(Symmetry=None)
                    df_050_059_EC_VS2_F  = df_050_059_EC_VS2_F.assign(Ratio=None)
                    df_050_059_EC_VS2_F  = df_050_059_EC_VS2_F.assign(PPC=None)
                    df_050_059_EC_VS2_F  = df_050_059_EC_VS2_F.assign(Total=None)
                    df_050_059_EC_VS2_F ['Wt Range'] = listwtrange
                    df_050_059_EC_VS2_F ['Company'] = listcom
                    df_050_059_EC_VS2_F ['Shape'] = listshap
                    df_050_059_EC_VS2_F ['Carat'] = listcar
                    df_050_059_EC_VS2_F ['Color'] = listcol
                    df_050_059_EC_VS2_F ['Clarity'] = listclar
                    df_050_059_EC_VS2_F ['Cut'] = listcut
                    df_050_059_EC_VS2_F ['Polish'] = listpol
                    df_050_059_EC_VS2_F ['Symmetry'] = listsym
                    df_050_059_EC_VS2_F ['Ratio'] = listrat
                    df_050_059_EC_VS2_F ['PPC'] = listdesc
                    df_050_059_EC_VS2_F ['Total'] = listtotal
                    df_050_059_EC_VS2_F['Carat'] = df_050_059_EC_VS2_F['Carat'].astype('float64')
                    df_050_059_EC_VS2_F['PPC'] = df_050_059_EC_VS2_F['PPC'].astype('float64')
                    df_050_059_EC_VS2_F['Total'] = df_050_059_EC_VS2_F['Total'].astype('float64')
                    df_050_059_EC_VS2_F['Total'] = df_050_059_EC_VS2_F['Carat'] * df_050_059_EC_VS2_F['PPC']


                elif i=="F" and j == "SI1" and k == "EC":
                    df_050_059_EC_SI1_F = pd.DataFrame()
                    df_050_059_EC_SI1_F ['Wt Range'] = None
                    df_050_059_EC_SI1_F  = df_050_059_EC_SI1_F.assign(Company=None)
                    df_050_059_EC_SI1_F  = df_050_059_EC_SI1_F.assign(Shape=None)
                    df_050_059_EC_SI1_F  = df_050_059_EC_SI1_F.assign(Carat=None)
                    df_050_059_EC_SI1_F  = df_050_059_EC_SI1_F.assign(Color=None)
                    df_050_059_EC_SI1_F  = df_050_059_EC_SI1_F.assign(Clarity=None)
                    df_050_059_EC_SI1_F  = df_050_059_EC_SI1_F.assign(Cut=None)
                    df_050_059_EC_SI1_F  = df_050_059_EC_SI1_F.assign(Polish=None)
                    df_050_059_EC_SI1_F  = df_050_059_EC_SI1_F.assign(Symmetry=None)
                    df_050_059_EC_SI1_F  = df_050_059_EC_SI1_F.assign(Ratio=None)
                    df_050_059_EC_SI1_F  = df_050_059_EC_SI1_F.assign(PPC=None)
                    df_050_059_EC_SI1_F  = df_050_059_EC_SI1_F.assign(Total=None)
                    df_050_059_EC_SI1_F ['Wt Range'] = listwtrange
                    df_050_059_EC_SI1_F ['Company'] = listcom
                    df_050_059_EC_SI1_F ['Shape'] = listshap
                    df_050_059_EC_SI1_F ['Carat'] = listcar
                    df_050_059_EC_SI1_F ['Color'] = listcol
                    df_050_059_EC_SI1_F ['Clarity'] = listclar
                    df_050_059_EC_SI1_F ['Cut'] = listcut
                    df_050_059_EC_SI1_F ['Polish'] = listpol
                    df_050_059_EC_SI1_F ['Symmetry'] = listsym
                    df_050_059_EC_SI1_F ['Ratio'] = listrat
                    df_050_059_EC_SI1_F ['PPC'] = listdesc
                    df_050_059_EC_SI1_F ['Total'] = listtotal
                    df_050_059_EC_SI1_F['Carat'] = df_050_059_EC_SI1_F['Carat'].astype('float64')
                    df_050_059_EC_SI1_F['PPC'] = df_050_059_EC_SI1_F['PPC'].astype('float64')
                    df_050_059_EC_SI1_F['Total'] = df_050_059_EC_SI1_F['Total'].astype('float64')
                    df_050_059_EC_SI1_F['Total'] = df_050_059_EC_SI1_F['Carat'] * df_050_059_EC_SI1_F['PPC']


                elif i=="F" and j == "SI2" and k == "EC":
                    df_050_059_EC_SI2_F = pd.DataFrame()
                    df_050_059_EC_SI2_F ['Wt Range'] = None
                    df_050_059_EC_SI2_F  = df_050_059_EC_SI2_F.assign(Company=None)
                    df_050_059_EC_SI2_F  = df_050_059_EC_SI2_F.assign(Shape=None)
                    df_050_059_EC_SI2_F  = df_050_059_EC_SI2_F.assign(Carat=None)
                    df_050_059_EC_SI2_F  = df_050_059_EC_SI2_F.assign(Color=None)
                    df_050_059_EC_SI2_F  = df_050_059_EC_SI2_F.assign(Clarity=None)
                    df_050_059_EC_SI2_F  = df_050_059_EC_SI2_F.assign(Cut=None)
                    df_050_059_EC_SI2_F  = df_050_059_EC_SI2_F.assign(Polish=None)
                    df_050_059_EC_SI2_F  = df_050_059_EC_SI2_F.assign(Symmetry=None)
                    df_050_059_EC_SI2_F  = df_050_059_EC_SI2_F.assign(Ratio=None)
                    df_050_059_EC_SI2_F  = df_050_059_EC_SI2_F.assign(PPC=None)
                    df_050_059_EC_SI2_F  = df_050_059_EC_SI2_F.assign(Total=None)
                    df_050_059_EC_SI2_F ['Wt Range'] = listwtrange
                    df_050_059_EC_SI2_F ['Company'] = listcom
                    df_050_059_EC_SI2_F ['Shape'] = listshap
                    df_050_059_EC_SI2_F ['Carat'] = listcar
                    df_050_059_EC_SI2_F ['Color'] = listcol
                    df_050_059_EC_SI2_F ['Clarity'] = listclar
                    df_050_059_EC_SI2_F ['Cut'] = listcut
                    df_050_059_EC_SI2_F ['Polish'] = listpol
                    df_050_059_EC_SI2_F ['Symmetry'] = listsym
                    df_050_059_EC_SI2_F ['Ratio'] = listrat
                    df_050_059_EC_SI2_F ['PPC'] = listdesc
                    df_050_059_EC_SI2_F ['Total'] = listtotal
                    df_050_059_EC_SI2_F['Carat'] = df_050_059_EC_SI2_F['Carat'].astype('float64')
                    df_050_059_EC_SI2_F['PPC'] = df_050_059_EC_SI2_F['PPC'].astype('float64')
                    df_050_059_EC_SI2_F['Total'] = df_050_059_EC_SI2_F['Total'].astype('float64')
                    df_050_059_EC_SI2_F['Total'] = df_050_059_EC_SI2_F['Carat'] * df_050_059_EC_SI2_F['PPC']


                elif i=="F" and j == "I1" and k == "EC":
                    df_050_059_EC_I1_F = pd.DataFrame()
                    df_050_059_EC_I1_F ['Wt Range'] = None
                    df_050_059_EC_I1_F  = df_050_059_EC_I1_F.assign(Company=None)
                    df_050_059_EC_I1_F  = df_050_059_EC_I1_F.assign(Shape=None)
                    df_050_059_EC_I1_F  = df_050_059_EC_I1_F.assign(Carat=None)
                    df_050_059_EC_I1_F  = df_050_059_EC_I1_F.assign(Color=None)
                    df_050_059_EC_I1_F  = df_050_059_EC_I1_F.assign(Clarity=None)
                    df_050_059_EC_I1_F  = df_050_059_EC_I1_F.assign(Cut=None)
                    df_050_059_EC_I1_F  = df_050_059_EC_I1_F.assign(Polish=None)
                    df_050_059_EC_I1_F  = df_050_059_EC_I1_F.assign(Symmetry=None)
                    df_050_059_EC_I1_F  = df_050_059_EC_I1_F.assign(Ratio=None)
                    df_050_059_EC_I1_F  = df_050_059_EC_I1_F.assign(PPC=None)
                    df_050_059_EC_I1_F  = df_050_059_EC_I1_F.assign(Total=None)
                    df_050_059_EC_I1_F ['Wt Range'] = listwtrange
                    df_050_059_EC_I1_F ['Company'] = listcom
                    df_050_059_EC_I1_F ['Shape'] = listshap
                    df_050_059_EC_I1_F ['Carat'] = listcar
                    df_050_059_EC_I1_F ['Color'] = listcol
                    df_050_059_EC_I1_F ['Clarity'] = listclar
                    df_050_059_EC_I1_F ['Cut'] = listcut
                    df_050_059_EC_I1_F ['Polish'] = listpol
                    df_050_059_EC_I1_F ['Symmetry'] = listsym
                    df_050_059_EC_I1_F ['Ratio'] = listrat
                    df_050_059_EC_I1_F ['PPC'] = listdesc
                    df_050_059_EC_I1_F ['Total'] = listtotal
                    df_050_059_EC_I1_F['Carat'] = df_050_059_EC_I1_F['Carat'].astype('float64')
                    df_050_059_EC_I1_F['PPC'] = df_050_059_EC_I1_F['PPC'].astype('float64')
                    df_050_059_EC_I1_F['Total'] = df_050_059_EC_I1_F['Total'].astype('float64')
                    df_050_059_EC_I1_F['Total'] = df_050_059_EC_I1_F['Carat'] * df_050_059_EC_I1_F['PPC']


                elif i=="F" and j == "I2" and k == "EC":
                    df_050_059_EC_I2_F = pd.DataFrame()
                    df_050_059_EC_I2_F ['Wt Range'] = None
                    df_050_059_EC_I2_F  = df_050_059_EC_I2_F.assign(Company=None)
                    df_050_059_EC_I2_F  = df_050_059_EC_I2_F.assign(Shape=None)
                    df_050_059_EC_I2_F  = df_050_059_EC_I2_F.assign(Carat=None)
                    df_050_059_EC_I2_F  = df_050_059_EC_I2_F.assign(Color=None)
                    df_050_059_EC_I2_F  = df_050_059_EC_I2_F.assign(Clarity=None)
                    df_050_059_EC_I2_F  = df_050_059_EC_I2_F.assign(Cut=None)
                    df_050_059_EC_I2_F  = df_050_059_EC_I2_F.assign(Polish=None)
                    df_050_059_EC_I2_F  = df_050_059_EC_I2_F.assign(Symmetry=None)
                    df_050_059_EC_I2_F  = df_050_059_EC_I2_F.assign(Ratio=None)
                    df_050_059_EC_I2_F  = df_050_059_EC_I2_F.assign(PPC=None)
                    df_050_059_EC_I2_F  = df_050_059_EC_I2_F.assign(Total=None)
                    df_050_059_EC_I2_F ['Wt Range'] = listwtrange
                    df_050_059_EC_I2_F ['Company'] = listcom
                    df_050_059_EC_I2_F ['Shape'] = listshap
                    df_050_059_EC_I2_F ['Carat'] = listcar
                    df_050_059_EC_I2_F ['Color'] = listcol
                    df_050_059_EC_I2_F ['Clarity'] = listclar
                    df_050_059_EC_I2_F ['Cut'] = listcut
                    df_050_059_EC_I2_F ['Polish'] = listpol
                    df_050_059_EC_I2_F ['Symmetry'] = listsym
                    df_050_059_EC_I2_F ['Ratio'] = listrat
                    df_050_059_EC_I2_F ['PPC'] = listdesc
                    df_050_059_EC_I2_F ['Total'] = listtotal
                    df_050_059_EC_I2_F['Carat'] = df_050_059_EC_I2_F['Carat'].astype('float64')
                    df_050_059_EC_I2_F['PPC'] = df_050_059_EC_I2_F['PPC'].astype('float64')
                    df_050_059_EC_I2_F['Total'] = df_050_059_EC_I2_F['Total'].astype('float64')
                    df_050_059_EC_I2_F['Total'] = df_050_059_EC_I2_F['Carat'] * df_050_059_EC_I2_F['PPC']


                elif i=="G" and j == "IF" and k == "EC":
                    df_050_059_EC_IF_G = pd.DataFrame()
                    df_050_059_EC_IF_G ['Wt Range'] = None
                    df_050_059_EC_IF_G  = df_050_059_EC_IF_G.assign(Company=None)
                    df_050_059_EC_IF_G  = df_050_059_EC_IF_G.assign(Shape=None)
                    df_050_059_EC_IF_G  = df_050_059_EC_IF_G.assign(Carat=None)
                    df_050_059_EC_IF_G  = df_050_059_EC_IF_G.assign(Color=None)
                    df_050_059_EC_IF_G  = df_050_059_EC_IF_G.assign(Clarity=None)
                    df_050_059_EC_IF_G  = df_050_059_EC_IF_G.assign(Cut=None)
                    df_050_059_EC_IF_G  = df_050_059_EC_IF_G.assign(Polish=None)
                    df_050_059_EC_IF_G  = df_050_059_EC_IF_G.assign(Symmetry=None)
                    df_050_059_EC_IF_G  = df_050_059_EC_IF_G.assign(Ratio=None)
                    df_050_059_EC_IF_G  = df_050_059_EC_IF_G.assign(PPC=None)
                    df_050_059_EC_IF_G  = df_050_059_EC_IF_G.assign(Total=None)
                    df_050_059_EC_IF_G ['Wt Range'] = listwtrange
                    df_050_059_EC_IF_G ['Company'] = listcom
                    df_050_059_EC_IF_G ['Shape'] = listshap
                    df_050_059_EC_IF_G ['Carat'] = listcar
                    df_050_059_EC_IF_G ['Color'] = listcol
                    df_050_059_EC_IF_G ['Clarity'] = listclar
                    df_050_059_EC_IF_G ['Cut'] = listcut
                    df_050_059_EC_IF_G ['Polish'] = listpol
                    df_050_059_EC_IF_G ['Symmetry'] = listsym
                    df_050_059_EC_IF_G ['Ratio'] = listrat
                    df_050_059_EC_IF_G ['PPC'] = listdesc
                    df_050_059_EC_IF_G ['Total'] = listtotal
                    df_050_059_EC_IF_G['Carat'] = df_050_059_EC_IF_G['Carat'].astype('float64')
                    df_050_059_EC_IF_G['PPC'] = df_050_059_EC_IF_G['PPC'].astype('float64')
                    df_050_059_EC_IF_G['Total'] = df_050_059_EC_IF_G['Total'].astype('float64')
                    df_050_059_EC_IF_G['Total'] = df_050_059_EC_IF_G['Carat'] * df_050_059_EC_IF_G['PPC']



                elif i=="G" and j == "VVS1" and k == "EC":
                    df_050_059_EC_VVS1_G = pd.DataFrame()
                    df_050_059_EC_VVS1_G ['Wt Range'] = None
                    df_050_059_EC_VVS1_G  = df_050_059_EC_VVS1_G.assign(Company=None)
                    df_050_059_EC_VVS1_G  = df_050_059_EC_VVS1_G.assign(Shape=None)
                    df_050_059_EC_VVS1_G  = df_050_059_EC_VVS1_G.assign(Carat=None)
                    df_050_059_EC_VVS1_G  = df_050_059_EC_VVS1_G.assign(Color=None)
                    df_050_059_EC_VVS1_G  = df_050_059_EC_VVS1_G.assign(Clarity=None)
                    df_050_059_EC_VVS1_G  = df_050_059_EC_VVS1_G.assign(Cut=None)
                    df_050_059_EC_VVS1_G  = df_050_059_EC_VVS1_G.assign(Polish=None)
                    df_050_059_EC_VVS1_G  = df_050_059_EC_VVS1_G.assign(Symmetry=None)
                    df_050_059_EC_VVS1_G  = df_050_059_EC_VVS1_G.assign(Ratio=None)
                    df_050_059_EC_VVS1_G  = df_050_059_EC_VVS1_G.assign(PPC=None)
                    df_050_059_EC_VVS1_G  = df_050_059_EC_VVS1_G.assign(Total=None)
                    df_050_059_EC_VVS1_G ['Wt Range'] = listwtrange
                    df_050_059_EC_VVS1_G ['Company'] = listcom
                    df_050_059_EC_VVS1_G ['Shape'] = listshap
                    df_050_059_EC_VVS1_G ['Carat'] = listcar
                    df_050_059_EC_VVS1_G ['Color'] = listcol
                    df_050_059_EC_VVS1_G ['Clarity'] = listclar
                    df_050_059_EC_VVS1_G ['Cut'] = listcut
                    df_050_059_EC_VVS1_G ['Polish'] = listpol
                    df_050_059_EC_VVS1_G ['Symmetry'] = listsym
                    df_050_059_EC_VVS1_G ['Ratio'] = listrat
                    df_050_059_EC_VVS1_G ['PPC'] = listdesc
                    df_050_059_EC_VVS1_G ['Total'] = listtotal
                    df_050_059_EC_VVS1_G['Carat'] = df_050_059_EC_VVS1_G['Carat'].astype('float64')
                    df_050_059_EC_VVS1_G['PPC'] = df_050_059_EC_VVS1_G['PPC'].astype('float64')
                    df_050_059_EC_VVS1_G['Total'] = df_050_059_EC_VVS1_G['Total'].astype('float64')
                    df_050_059_EC_VVS1_G['Total'] = df_050_059_EC_VVS1_G['Carat'] * df_050_059_EC_VVS1_G['PPC']


                elif i=="G" and j == "VVS2" and k == "EC":
                    df_050_059_EC_VVS2_G = pd.DataFrame()
                    df_050_059_EC_VVS2_G ['Wt Range'] = None
                    df_050_059_EC_VVS2_G  = df_050_059_EC_VVS2_G.assign(Company=None)
                    df_050_059_EC_VVS2_G  = df_050_059_EC_VVS2_G.assign(Shape=None)
                    df_050_059_EC_VVS2_G  = df_050_059_EC_VVS2_G.assign(Carat=None)
                    df_050_059_EC_VVS2_G  = df_050_059_EC_VVS2_G.assign(Color=None)
                    df_050_059_EC_VVS2_G  = df_050_059_EC_VVS2_G.assign(Clarity=None)
                    df_050_059_EC_VVS2_G  = df_050_059_EC_VVS2_G.assign(Cut=None)
                    df_050_059_EC_VVS2_G  = df_050_059_EC_VVS2_G.assign(Polish=None)
                    df_050_059_EC_VVS2_G  = df_050_059_EC_VVS2_G.assign(Symmetry=None)
                    df_050_059_EC_VVS2_G  = df_050_059_EC_VVS2_G.assign(Ratio=None)
                    df_050_059_EC_VVS2_G  = df_050_059_EC_VVS2_G.assign(PPC=None)
                    df_050_059_EC_VVS2_G  = df_050_059_EC_VVS2_G.assign(Total=None)
                    df_050_059_EC_VVS2_G ['Wt Range'] = listwtrange
                    df_050_059_EC_VVS2_G ['Company'] = listcom
                    df_050_059_EC_VVS2_G ['Shape'] = listshap
                    df_050_059_EC_VVS2_G ['Carat'] = listcar
                    df_050_059_EC_VVS2_G ['Color'] = listcol
                    df_050_059_EC_VVS2_G ['Clarity'] = listclar
                    df_050_059_EC_VVS2_G ['Cut'] = listcut
                    df_050_059_EC_VVS2_G ['Polish'] = listpol
                    df_050_059_EC_VVS2_G ['Symmetry'] = listsym
                    df_050_059_EC_VVS2_G ['Ratio'] = listrat
                    df_050_059_EC_VVS2_G ['PPC'] = listdesc
                    df_050_059_EC_VVS2_G ['Total'] = listtotal
                    df_050_059_EC_VVS2_G['Carat'] = df_050_059_EC_VVS2_G['Carat'].astype('float64')
                    df_050_059_EC_VVS2_G['PPC'] = df_050_059_EC_VVS2_G['PPC'].astype('float64')
                    df_050_059_EC_VVS2_G['Total'] = df_050_059_EC_VVS2_G['Total'].astype('float64')
                    df_050_059_EC_VVS2_G['Total'] = df_050_059_EC_VVS2_G['Carat'] * df_050_059_EC_VVS2_G['PPC']


                elif i=="G" and j=="VS1" and k == "EC":
                    df_050_059_EC_VS1_G = pd.DataFrame()
                    df_050_059_EC_VS1_G ['Wt Range'] = None
                    df_050_059_EC_VS1_G  = df_050_059_EC_VS1_G.assign(Company=None)
                    df_050_059_EC_VS1_G  = df_050_059_EC_VS1_G.assign(Shape=None)
                    df_050_059_EC_VS1_G  = df_050_059_EC_VS1_G.assign(Carat=None)
                    df_050_059_EC_VS1_G  = df_050_059_EC_VS1_G.assign(Color=None)
                    df_050_059_EC_VS1_G  = df_050_059_EC_VS1_G.assign(Clarity=None)
                    df_050_059_EC_VS1_G  = df_050_059_EC_VS1_G.assign(Cut=None)
                    df_050_059_EC_VS1_G  = df_050_059_EC_VS1_G.assign(Polish=None)
                    df_050_059_EC_VS1_G  = df_050_059_EC_VS1_G.assign(Symmetry=None)
                    df_050_059_EC_VS1_G  = df_050_059_EC_VS1_G.assign(Ratio=None)
                    df_050_059_EC_VS1_G  = df_050_059_EC_VS1_G.assign(PPC=None)
                    df_050_059_EC_VS1_G  = df_050_059_EC_VS1_G.assign(Total=None)
                    df_050_059_EC_VS1_G ['Wt Range'] = listwtrange
                    df_050_059_EC_VS1_G ['Company'] = listcom
                    df_050_059_EC_VS1_G ['Shape'] = listshap
                    df_050_059_EC_VS1_G ['Carat'] = listcar
                    df_050_059_EC_VS1_G ['Color'] = listcol
                    df_050_059_EC_VS1_G ['Clarity'] = listclar
                    df_050_059_EC_VS1_G ['Cut'] = listcut
                    df_050_059_EC_VS1_G ['Polish'] = listpol
                    df_050_059_EC_VS1_G ['Symmetry'] = listsym
                    df_050_059_EC_VS1_G ['Ratio'] = listrat
                    df_050_059_EC_VS1_G ['PPC'] = listdesc
                    df_050_059_EC_VS1_G ['Total'] = listtotal
                    df_050_059_EC_VS1_G['Carat'] = df_050_059_EC_VS1_G['Carat'].astype('float64')
                    df_050_059_EC_VS1_G['PPC'] = df_050_059_EC_VS1_G['PPC'].astype('float64')
                    df_050_059_EC_VS1_G['Total'] = df_050_059_EC_VS1_G['Total'].astype('float64')
                    df_050_059_EC_VS1_G['Total'] = df_050_059_EC_VS1_G['Carat'] * df_050_059_EC_VS1_G['PPC']


                elif i=="G" and j == "VS2" and k == "EC":
                    df_050_059_EC_VS2_G = pd.DataFrame()
                    df_050_059_EC_VS2_G ['Wt Range'] = None
                    df_050_059_EC_VS2_G  = df_050_059_EC_VS2_G.assign(Company=None)
                    df_050_059_EC_VS2_G  = df_050_059_EC_VS2_G.assign(Shape=None)
                    df_050_059_EC_VS2_G  = df_050_059_EC_VS2_G.assign(Carat=None)
                    df_050_059_EC_VS2_G  = df_050_059_EC_VS2_G.assign(Color=None)
                    df_050_059_EC_VS2_G  = df_050_059_EC_VS2_G.assign(Clarity=None)
                    df_050_059_EC_VS2_G  = df_050_059_EC_VS2_G.assign(Cut=None)
                    df_050_059_EC_VS2_G  = df_050_059_EC_VS2_G.assign(Polish=None)
                    df_050_059_EC_VS2_G  = df_050_059_EC_VS2_G.assign(Symmetry=None)
                    df_050_059_EC_VS2_G  = df_050_059_EC_VS2_G.assign(Ratio=None)
                    df_050_059_EC_VS2_G  = df_050_059_EC_VS2_G.assign(PPC=None)
                    df_050_059_EC_VS2_G  = df_050_059_EC_VS2_G.assign(Total=None)
                    df_050_059_EC_VS2_G ['Wt Range'] = listwtrange
                    df_050_059_EC_VS2_G ['Company'] = listcom
                    df_050_059_EC_VS2_G ['Shape'] = listshap
                    df_050_059_EC_VS2_G ['Carat'] = listcar
                    df_050_059_EC_VS2_G ['Color'] = listcol
                    df_050_059_EC_VS2_G ['Clarity'] = listclar
                    df_050_059_EC_VS2_G ['Cut'] = listcut
                    df_050_059_EC_VS2_G ['Polish'] = listpol
                    df_050_059_EC_VS2_G ['Symmetry'] = listsym
                    df_050_059_EC_VS2_G ['Ratio'] = listrat
                    df_050_059_EC_VS2_G ['PPC'] = listdesc
                    df_050_059_EC_VS2_G ['Total'] = listtotal
                    df_050_059_EC_VS2_G['Carat'] = df_050_059_EC_VS2_G['Carat'].astype('float64')
                    df_050_059_EC_VS2_G['PPC'] = df_050_059_EC_VS2_G['PPC'].astype('float64')
                    df_050_059_EC_VS2_G['Total'] = df_050_059_EC_VS2_G['Total'].astype('float64')
                    df_050_059_EC_VS2_G['Total'] = df_050_059_EC_VS2_G['Carat'] * df_050_059_EC_VS2_G['PPC']


                elif i=="G" and j == "SI1" and k == "EC":
                    df_050_059_EC_SI1_G = pd.DataFrame()
                    df_050_059_EC_SI1_G ['Wt Range'] = None
                    df_050_059_EC_SI1_G  = df_050_059_EC_SI1_G.assign(Company=None)
                    df_050_059_EC_SI1_G  = df_050_059_EC_SI1_G.assign(Shape=None)
                    df_050_059_EC_SI1_G  = df_050_059_EC_SI1_G.assign(Carat=None)
                    df_050_059_EC_SI1_G  = df_050_059_EC_SI1_G.assign(Color=None)
                    df_050_059_EC_SI1_G  = df_050_059_EC_SI1_G.assign(Clarity=None)
                    df_050_059_EC_SI1_G  = df_050_059_EC_SI1_G.assign(Cut=None)
                    df_050_059_EC_SI1_G  = df_050_059_EC_SI1_G.assign(Polish=None)
                    df_050_059_EC_SI1_G  = df_050_059_EC_SI1_G.assign(Symmetry=None)
                    df_050_059_EC_SI1_G  = df_050_059_EC_SI1_G.assign(Ratio=None)
                    df_050_059_EC_SI1_G  = df_050_059_EC_SI1_G.assign(PPC=None)
                    df_050_059_EC_SI1_G  = df_050_059_EC_SI1_G.assign(Total=None)
                    df_050_059_EC_SI1_G ['Wt Range'] = listwtrange
                    df_050_059_EC_SI1_G ['Company'] = listcom
                    df_050_059_EC_SI1_G ['Shape'] = listshap
                    df_050_059_EC_SI1_G ['Carat'] = listcar
                    df_050_059_EC_SI1_G ['Color'] = listcol
                    df_050_059_EC_SI1_G ['Clarity'] = listclar
                    df_050_059_EC_SI1_G ['Cut'] = listcut
                    df_050_059_EC_SI1_G ['Polish'] = listpol
                    df_050_059_EC_SI1_G ['Symmetry'] = listsym
                    df_050_059_EC_SI1_G ['Ratio'] = listrat
                    df_050_059_EC_SI1_G ['PPC'] = listdesc
                    df_050_059_EC_SI1_G ['Total'] = listtotal
                    df_050_059_EC_SI1_G['Carat'] = df_050_059_EC_SI1_G['Carat'].astype('float64')
                    df_050_059_EC_SI1_G['PPC'] = df_050_059_EC_SI1_G['PPC'].astype('float64')
                    df_050_059_EC_SI1_G['Total'] = df_050_059_EC_SI1_G['Total'].astype('float64')
                    df_050_059_EC_SI1_G['Total'] = df_050_059_EC_SI1_G['Carat'] * df_050_059_EC_SI1_G['PPC']


                elif i=="G" and j == "SI2" and k == "EC":
                    df_050_059_EC_SI2_G = pd.DataFrame()
                    df_050_059_EC_SI2_G ['Wt Range'] = None
                    df_050_059_EC_SI2_G  = df_050_059_EC_SI2_G.assign(Company=None)
                    df_050_059_EC_SI2_G  = df_050_059_EC_SI2_G.assign(Shape=None)
                    df_050_059_EC_SI2_G  = df_050_059_EC_SI2_G.assign(Carat=None)
                    df_050_059_EC_SI2_G  = df_050_059_EC_SI2_G.assign(Color=None)
                    df_050_059_EC_SI2_G  = df_050_059_EC_SI2_G.assign(Clarity=None)
                    df_050_059_EC_SI2_G  = df_050_059_EC_SI2_G.assign(Cut=None)
                    df_050_059_EC_SI2_G  = df_050_059_EC_SI2_G.assign(Polish=None)
                    df_050_059_EC_SI2_G  = df_050_059_EC_SI2_G.assign(Symmetry=None)
                    df_050_059_EC_SI2_G  = df_050_059_EC_SI2_G.assign(Ratio=None)
                    df_050_059_EC_SI2_G  = df_050_059_EC_SI2_G.assign(PPC=None)
                    df_050_059_EC_SI2_G  = df_050_059_EC_SI2_G.assign(Total=None)
                    df_050_059_EC_SI2_G ['Wt Range'] = listwtrange
                    df_050_059_EC_SI2_G ['Company'] = listcom
                    df_050_059_EC_SI2_G ['Shape'] = listshap
                    df_050_059_EC_SI2_G ['Carat'] = listcar
                    df_050_059_EC_SI2_G ['Color'] = listcol
                    df_050_059_EC_SI2_G ['Clarity'] = listclar
                    df_050_059_EC_SI2_G ['Cut'] = listcut
                    df_050_059_EC_SI2_G ['Polish'] = listpol
                    df_050_059_EC_SI2_G ['Symmetry'] = listsym
                    df_050_059_EC_SI2_G ['Ratio'] = listrat
                    df_050_059_EC_SI2_G ['PPC'] = listdesc
                    df_050_059_EC_SI2_G ['Total'] = listtotal
                    df_050_059_EC_SI2_G['Carat'] = df_050_059_EC_SI2_G['Carat'].astype('float64')
                    df_050_059_EC_SI2_G['PPC'] = df_050_059_EC_SI2_G['PPC'].astype('float64')
                    df_050_059_EC_SI2_G['Total'] = df_050_059_EC_SI2_G['Total'].astype('float64')
                    df_050_059_EC_SI2_G['Total'] = df_050_059_EC_SI2_G['Carat'] * df_050_059_EC_SI2_G['PPC']


                elif i=="G" and j == "I1" and k == "EC":
                    df_050_059_EC_I1_G = pd.DataFrame()
                    df_050_059_EC_I1_G ['Wt Range'] = None
                    df_050_059_EC_I1_G  = df_050_059_EC_I1_G.assign(Company=None)
                    df_050_059_EC_I1_G  = df_050_059_EC_I1_G.assign(Shape=None)
                    df_050_059_EC_I1_G  = df_050_059_EC_I1_G.assign(Carat=None)
                    df_050_059_EC_I1_G  = df_050_059_EC_I1_G.assign(Color=None)
                    df_050_059_EC_I1_G  = df_050_059_EC_I1_G.assign(Clarity=None)
                    df_050_059_EC_I1_G  = df_050_059_EC_I1_G.assign(Cut=None)
                    df_050_059_EC_I1_G  = df_050_059_EC_I1_G.assign(Polish=None)
                    df_050_059_EC_I1_G  = df_050_059_EC_I1_G.assign(Symmetry=None)
                    df_050_059_EC_I1_G  = df_050_059_EC_I1_G.assign(Ratio=None)
                    df_050_059_EC_I1_G  = df_050_059_EC_I1_G.assign(PPC=None)
                    df_050_059_EC_I1_G  = df_050_059_EC_I1_G.assign(Total=None)
                    df_050_059_EC_I1_G ['Wt Range'] = listwtrange
                    df_050_059_EC_I1_G ['Company'] = listcom
                    df_050_059_EC_I1_G ['Shape'] = listshap
                    df_050_059_EC_I1_G ['Carat'] = listcar
                    df_050_059_EC_I1_G ['Color'] = listcol
                    df_050_059_EC_I1_G ['Clarity'] = listclar
                    df_050_059_EC_I1_G ['Cut'] = listcut
                    df_050_059_EC_I1_G ['Polish'] = listpol
                    df_050_059_EC_I1_G ['Symmetry'] = listsym
                    df_050_059_EC_I1_G ['Ratio'] = listrat
                    df_050_059_EC_I1_G ['PPC'] = listdesc
                    df_050_059_EC_I1_G ['Total'] = listtotal
                    df_050_059_EC_I1_G['Carat'] = df_050_059_EC_I1_G['Carat'].astype('float64')
                    df_050_059_EC_I1_G['PPC'] = df_050_059_EC_I1_G['PPC'].astype('float64')
                    df_050_059_EC_I1_G['Total'] = df_050_059_EC_I1_G['Total'].astype('float64')
                    df_050_059_EC_I1_G['Total'] = df_050_059_EC_I1_G['Carat'] * df_050_059_EC_I1_G['PPC']


                elif i=="G" and j == "I2" and k == "EC":
                    df_050_059_EC_I2_G = pd.DataFrame()
                    df_050_059_EC_I2_G ['Wt Range'] = None
                    df_050_059_EC_I2_G  = df_050_059_EC_I2_G.assign(Company=None)
                    df_050_059_EC_I2_G  = df_050_059_EC_I2_G.assign(Shape=None)
                    df_050_059_EC_I2_G  = df_050_059_EC_I2_G.assign(Carat=None)
                    df_050_059_EC_I2_G  = df_050_059_EC_I2_G.assign(Color=None)
                    df_050_059_EC_I2_G  = df_050_059_EC_I2_G.assign(Clarity=None)
                    df_050_059_EC_I2_G  = df_050_059_EC_I2_G.assign(Cut=None)
                    df_050_059_EC_I2_G  = df_050_059_EC_I2_G.assign(Polish=None)
                    df_050_059_EC_I2_G  = df_050_059_EC_I2_G.assign(Symmetry=None)
                    df_050_059_EC_I2_G  = df_050_059_EC_I2_G.assign(Ratio=None)
                    df_050_059_EC_I2_G  = df_050_059_EC_I2_G.assign(PPC=None)
                    df_050_059_EC_I2_G  = df_050_059_EC_I2_G.assign(Total=None)
                    df_050_059_EC_I2_G ['Wt Range'] = listwtrange
                    df_050_059_EC_I2_G ['Company'] = listcom
                    df_050_059_EC_I2_G ['Shape'] = listshap
                    df_050_059_EC_I2_G ['Carat'] = listcar
                    df_050_059_EC_I2_G ['Color'] = listcol
                    df_050_059_EC_I2_G ['Clarity'] = listclar
                    df_050_059_EC_I2_G ['Cut'] = listcut
                    df_050_059_EC_I2_G ['Polish'] = listpol
                    df_050_059_EC_I2_G ['Symmetry'] = listsym
                    df_050_059_EC_I2_G ['Ratio'] = listrat
                    df_050_059_EC_I2_G ['PPC'] = listdesc
                    df_050_059_EC_I2_G ['Total'] = listtotal
                    df_050_059_EC_I2_G['Carat'] = df_050_059_EC_I2_G['Carat'].astype('float64')
                    df_050_059_EC_I2_G['PPC'] = df_050_059_EC_I2_G['PPC'].astype('float64')
                    df_050_059_EC_I2_G['Total'] = df_050_059_EC_I2_G['Total'].astype('float64')
                    df_050_059_EC_I2_G['Total'] = df_050_059_EC_I2_G['Carat'] * df_050_059_EC_I2_G['PPC']


                elif i=="H" and j == "IF" and k == "EC":
                    df_050_059_EC_IF_H = pd.DataFrame()
                    df_050_059_EC_IF_H ['Wt Range'] = None
                    df_050_059_EC_IF_H  = df_050_059_EC_IF_H.assign(Company=None)
                    df_050_059_EC_IF_H  = df_050_059_EC_IF_H.assign(Shape=None)
                    df_050_059_EC_IF_H  = df_050_059_EC_IF_H.assign(Carat=None)
                    df_050_059_EC_IF_H  = df_050_059_EC_IF_H.assign(Color=None)
                    df_050_059_EC_IF_H  = df_050_059_EC_IF_H.assign(Clarity=None)
                    df_050_059_EC_IF_H  = df_050_059_EC_IF_H.assign(Cut=None)
                    df_050_059_EC_IF_H  = df_050_059_EC_IF_H.assign(Polish=None)
                    df_050_059_EC_IF_H  = df_050_059_EC_IF_H.assign(Symmetry=None)
                    df_050_059_EC_IF_H  = df_050_059_EC_IF_H.assign(Ratio=None)
                    df_050_059_EC_IF_H  = df_050_059_EC_IF_H.assign(PPC=None)
                    df_050_059_EC_IF_H  = df_050_059_EC_IF_H.assign(Total=None)
                    df_050_059_EC_IF_H ['Wt Range'] = listwtrange
                    df_050_059_EC_IF_H ['Company'] = listcom
                    df_050_059_EC_IF_H ['Shape'] = listshap
                    df_050_059_EC_IF_H ['Carat'] = listcar
                    df_050_059_EC_IF_H ['Color'] = listcol
                    df_050_059_EC_IF_H ['Clarity'] = listclar
                    df_050_059_EC_IF_H ['Cut'] = listcut
                    df_050_059_EC_IF_H ['Polish'] = listpol
                    df_050_059_EC_IF_H ['Symmetry'] = listsym
                    df_050_059_EC_IF_H ['Ratio'] = listrat
                    df_050_059_EC_IF_H ['PPC'] = listdesc
                    df_050_059_EC_IF_H ['Total'] = listtotal
                    df_050_059_EC_IF_H['Carat'] = df_050_059_EC_IF_H['Carat'].astype('float64')
                    df_050_059_EC_IF_H['PPC'] = df_050_059_EC_IF_H['PPC'].astype('float64')
                    df_050_059_EC_IF_H['Total'] = df_050_059_EC_IF_H['Total'].astype('float64')
                    df_050_059_EC_IF_H['Total'] = df_050_059_EC_IF_H['Carat'] * df_050_059_EC_IF_H['PPC']



                elif i=="H" and j == "VVS1" and k == "EC":
                    df_050_059_EC_VVS1_H = pd.DataFrame()
                    df_050_059_EC_VVS1_H ['Wt Range'] = None
                    df_050_059_EC_VVS1_H  = df_050_059_EC_VVS1_H.assign(Company=None)
                    df_050_059_EC_VVS1_H  = df_050_059_EC_VVS1_H.assign(Shape=None)
                    df_050_059_EC_VVS1_H  = df_050_059_EC_VVS1_H.assign(Carat=None)
                    df_050_059_EC_VVS1_H  = df_050_059_EC_VVS1_H.assign(Color=None)
                    df_050_059_EC_VVS1_H  = df_050_059_EC_VVS1_H.assign(Clarity=None)
                    df_050_059_EC_VVS1_H  = df_050_059_EC_VVS1_H.assign(Cut=None)
                    df_050_059_EC_VVS1_H  = df_050_059_EC_VVS1_H.assign(Polish=None)
                    df_050_059_EC_VVS1_H  = df_050_059_EC_VVS1_H.assign(Symmetry=None)
                    df_050_059_EC_VVS1_H  = df_050_059_EC_VVS1_H.assign(Ratio=None)
                    df_050_059_EC_VVS1_H  = df_050_059_EC_VVS1_H.assign(PPC=None)
                    df_050_059_EC_VVS1_H  = df_050_059_EC_VVS1_H.assign(Total=None)
                    df_050_059_EC_VVS1_H ['Wt Range'] = listwtrange
                    df_050_059_EC_VVS1_H ['Company'] = listcom
                    df_050_059_EC_VVS1_H ['Shape'] = listshap
                    df_050_059_EC_VVS1_H ['Carat'] = listcar
                    df_050_059_EC_VVS1_H ['Color'] = listcol
                    df_050_059_EC_VVS1_H ['Clarity'] = listclar
                    df_050_059_EC_VVS1_H ['Cut'] = listcut
                    df_050_059_EC_VVS1_H ['Polish'] = listpol
                    df_050_059_EC_VVS1_H ['Symmetry'] = listsym
                    df_050_059_EC_VVS1_H ['Ratio'] = listrat
                    df_050_059_EC_VVS1_H ['PPC'] = listdesc
                    df_050_059_EC_VVS1_H ['Total'] = listtotal
                    df_050_059_EC_VVS1_H['Carat'] = df_050_059_EC_VVS1_H['Carat'].astype('float64')
                    df_050_059_EC_VVS1_H['PPC'] = df_050_059_EC_VVS1_H['PPC'].astype('float64')
                    df_050_059_EC_VVS1_H['Total'] = df_050_059_EC_VVS1_H['Total'].astype('float64')
                    df_050_059_EC_VVS1_H['Total'] = df_050_059_EC_VVS1_H['Carat'] * df_050_059_EC_VVS1_H['PPC']


                elif i=="H" and j == "VVS2" and k == "EC":
                    df_050_059_EC_VVS2_H = pd.DataFrame()
                    df_050_059_EC_VVS2_H ['Wt Range'] = None
                    df_050_059_EC_VVS2_H  = df_050_059_EC_VVS2_H.assign(Company=None)
                    df_050_059_EC_VVS2_H  = df_050_059_EC_VVS2_H.assign(Shape=None)
                    df_050_059_EC_VVS2_H  = df_050_059_EC_VVS2_H.assign(Carat=None)
                    df_050_059_EC_VVS2_H  = df_050_059_EC_VVS2_H.assign(Color=None)
                    df_050_059_EC_VVS2_H  = df_050_059_EC_VVS2_H.assign(Clarity=None)
                    df_050_059_EC_VVS2_H  = df_050_059_EC_VVS2_H.assign(Cut=None)
                    df_050_059_EC_VVS2_H  = df_050_059_EC_VVS2_H.assign(Polish=None)
                    df_050_059_EC_VVS2_H  = df_050_059_EC_VVS2_H.assign(Symmetry=None)
                    df_050_059_EC_VVS2_H  = df_050_059_EC_VVS2_H.assign(Ratio=None)
                    df_050_059_EC_VVS2_H  = df_050_059_EC_VVS2_H.assign(PPC=None)
                    df_050_059_EC_VVS2_H  = df_050_059_EC_VVS2_H.assign(Total=None)
                    df_050_059_EC_VVS2_H ['Wt Range'] = listwtrange
                    df_050_059_EC_VVS2_H ['Company'] = listcom
                    df_050_059_EC_VVS2_H ['Shape'] = listshap
                    df_050_059_EC_VVS2_H ['Carat'] = listcar
                    df_050_059_EC_VVS2_H ['Color'] = listcol
                    df_050_059_EC_VVS2_H ['Clarity'] = listclar
                    df_050_059_EC_VVS2_H ['Cut'] = listcut
                    df_050_059_EC_VVS2_H ['Polish'] = listpol
                    df_050_059_EC_VVS2_H ['Symmetry'] = listsym
                    df_050_059_EC_VVS2_H ['Ratio'] = listrat
                    df_050_059_EC_VVS2_H ['PPC'] = listdesc
                    df_050_059_EC_VVS2_H ['Total'] = listtotal
                    df_050_059_EC_VVS2_H['Carat'] = df_050_059_EC_VVS2_H['Carat'].astype('float64')
                    df_050_059_EC_VVS2_H['PPC'] = df_050_059_EC_VVS2_H['PPC'].astype('float64')
                    df_050_059_EC_VVS2_H['Total'] = df_050_059_EC_VVS2_H['Total'].astype('float64')
                    df_050_059_EC_VVS2_H['Total'] = df_050_059_EC_VVS2_H['Carat'] * df_050_059_EC_VVS2_H['PPC']


                elif i=="H" and j=="VS1" and k == "EC":
                    df_050_059_EC_VS1_H = pd.DataFrame()
                    df_050_059_EC_VS1_H ['Wt Range'] = None
                    df_050_059_EC_VS1_H  = df_050_059_EC_VS1_H.assign(Company=None)
                    df_050_059_EC_VS1_H  = df_050_059_EC_VS1_H.assign(Shape=None)
                    df_050_059_EC_VS1_H  = df_050_059_EC_VS1_H.assign(Carat=None)
                    df_050_059_EC_VS1_H  = df_050_059_EC_VS1_H.assign(Color=None)
                    df_050_059_EC_VS1_H  = df_050_059_EC_VS1_H.assign(Clarity=None)
                    df_050_059_EC_VS1_H  = df_050_059_EC_VS1_H.assign(Cut=None)
                    df_050_059_EC_VS1_H  = df_050_059_EC_VS1_H.assign(Polish=None)
                    df_050_059_EC_VS1_H  = df_050_059_EC_VS1_H.assign(Symmetry=None)
                    df_050_059_EC_VS1_H  = df_050_059_EC_VS1_H.assign(Ratio=None)
                    df_050_059_EC_VS1_H  = df_050_059_EC_VS1_H.assign(PPC=None)
                    df_050_059_EC_VS1_H  = df_050_059_EC_VS1_H.assign(Total=None)
                    df_050_059_EC_VS1_H ['Wt Range'] = listwtrange
                    df_050_059_EC_VS1_H ['Company'] = listcom
                    df_050_059_EC_VS1_H ['Shape'] = listshap
                    df_050_059_EC_VS1_H ['Carat'] = listcar
                    df_050_059_EC_VS1_H ['Color'] = listcol
                    df_050_059_EC_VS1_H ['Clarity'] = listclar
                    df_050_059_EC_VS1_H ['Cut'] = listcut
                    df_050_059_EC_VS1_H ['Polish'] = listpol
                    df_050_059_EC_VS1_H ['Symmetry'] = listsym
                    df_050_059_EC_VS1_H ['Ratio'] = listrat
                    df_050_059_EC_VS1_H ['PPC'] = listdesc
                    df_050_059_EC_VS1_H ['Total'] = listtotal
                    df_050_059_EC_VS1_H['Carat'] = df_050_059_EC_VS1_H['Carat'].astype('float64')
                    df_050_059_EC_VS1_H['PPC'] = df_050_059_EC_VS1_H['PPC'].astype('float64')
                    df_050_059_EC_VS1_H['Total'] = df_050_059_EC_VS1_H['Total'].astype('float64')
                    df_050_059_EC_VS1_H['Total'] = df_050_059_EC_VS1_H['Carat'] * df_050_059_EC_VS1_H['PPC']


                elif i=="H" and j == "VS2" and k == "EC":
                    df_050_059_EC_VS2_H = pd.DataFrame()
                    df_050_059_EC_VS2_H ['Wt Range'] = None
                    df_050_059_EC_VS2_H  = df_050_059_EC_VS2_H.assign(Company=None)
                    df_050_059_EC_VS2_H  = df_050_059_EC_VS2_H.assign(Shape=None)
                    df_050_059_EC_VS2_H  = df_050_059_EC_VS2_H.assign(Carat=None)
                    df_050_059_EC_VS2_H  = df_050_059_EC_VS2_H.assign(Color=None)
                    df_050_059_EC_VS2_H  = df_050_059_EC_VS2_H.assign(Clarity=None)
                    df_050_059_EC_VS2_H  = df_050_059_EC_VS2_H.assign(Cut=None)
                    df_050_059_EC_VS2_H  = df_050_059_EC_VS2_H.assign(Polish=None)
                    df_050_059_EC_VS2_H  = df_050_059_EC_VS2_H.assign(Symmetry=None)
                    df_050_059_EC_VS2_H  = df_050_059_EC_VS2_H.assign(Ratio=None)
                    df_050_059_EC_VS2_H  = df_050_059_EC_VS2_H.assign(PPC=None)
                    df_050_059_EC_VS2_H  = df_050_059_EC_VS2_H.assign(Total=None)
                    df_050_059_EC_VS2_H ['Wt Range'] = listwtrange
                    df_050_059_EC_VS2_H ['Company'] = listcom
                    df_050_059_EC_VS2_H ['Shape'] = listshap
                    df_050_059_EC_VS2_H ['Carat'] = listcar
                    df_050_059_EC_VS2_H ['Color'] = listcol
                    df_050_059_EC_VS2_H ['Clarity'] = listclar
                    df_050_059_EC_VS2_H ['Cut'] = listcut
                    df_050_059_EC_VS2_H ['Polish'] = listpol
                    df_050_059_EC_VS2_H ['Symmetry'] = listsym
                    df_050_059_EC_VS2_H ['Ratio'] = listrat
                    df_050_059_EC_VS2_H ['PPC'] = listdesc
                    df_050_059_EC_VS2_H ['Total'] = listtotal
                    df_050_059_EC_VS2_H['Carat'] = df_050_059_EC_VS2_H['Carat'].astype('float64')
                    df_050_059_EC_VS2_H['PPC'] = df_050_059_EC_VS2_H['PPC'].astype('float64')
                    df_050_059_EC_VS2_H['Total'] = df_050_059_EC_VS2_H['Total'].astype('float64')
                    df_050_059_EC_VS2_H['Total'] = df_050_059_EC_VS2_H['Carat'] * df_050_059_EC_VS2_H['PPC']


                elif i=="H" and j == "SI1" and k == "EC":
                    df_050_059_EC_SI1_H = pd.DataFrame()
                    df_050_059_EC_SI1_H ['Wt Range'] = None
                    df_050_059_EC_SI1_H  = df_050_059_EC_SI1_H.assign(Company=None)
                    df_050_059_EC_SI1_H  = df_050_059_EC_SI1_H.assign(Shape=None)
                    df_050_059_EC_SI1_H  = df_050_059_EC_SI1_H.assign(Carat=None)
                    df_050_059_EC_SI1_H  = df_050_059_EC_SI1_H.assign(Color=None)
                    df_050_059_EC_SI1_H  = df_050_059_EC_SI1_H.assign(Clarity=None)
                    df_050_059_EC_SI1_H  = df_050_059_EC_SI1_H.assign(Cut=None)
                    df_050_059_EC_SI1_H  = df_050_059_EC_SI1_H.assign(Polish=None)
                    df_050_059_EC_SI1_H  = df_050_059_EC_SI1_H.assign(Symmetry=None)
                    df_050_059_EC_SI1_H  = df_050_059_EC_SI1_H.assign(Ratio=None)
                    df_050_059_EC_SI1_H  = df_050_059_EC_SI1_H.assign(PPC=None)
                    df_050_059_EC_SI1_H  = df_050_059_EC_SI1_H.assign(Total=None)
                    df_050_059_EC_SI1_H ['Wt Range'] = listwtrange
                    df_050_059_EC_SI1_H ['Company'] = listcom
                    df_050_059_EC_SI1_H ['Shape'] = listshap
                    df_050_059_EC_SI1_H ['Carat'] = listcar
                    df_050_059_EC_SI1_H ['Color'] = listcol
                    df_050_059_EC_SI1_H ['Clarity'] = listclar
                    df_050_059_EC_SI1_H ['Cut'] = listcut
                    df_050_059_EC_SI1_H ['Polish'] = listpol
                    df_050_059_EC_SI1_H ['Symmetry'] = listsym
                    df_050_059_EC_SI1_H ['Ratio'] = listrat
                    df_050_059_EC_SI1_H ['PPC'] = listdesc
                    df_050_059_EC_SI1_H ['Total'] = listtotal
                    df_050_059_EC_SI1_H['Carat'] = df_050_059_EC_SI1_H['Carat'].astype('float64')
                    df_050_059_EC_SI1_H['PPC'] = df_050_059_EC_SI1_H['PPC'].astype('float64')
                    df_050_059_EC_SI1_H['Total'] = df_050_059_EC_SI1_H['Total'].astype('float64')
                    df_050_059_EC_SI1_H['Total'] = df_050_059_EC_SI1_H['Carat'] * df_050_059_EC_SI1_H['PPC']


                elif i=="H" and j == "SI2" and k == "EC":
                    df_050_059_EC_SI2_H = pd.DataFrame()
                    df_050_059_EC_SI2_H ['Wt Range'] = None
                    df_050_059_EC_SI2_H  = df_050_059_EC_SI2_H.assign(Company=None)
                    df_050_059_EC_SI2_H  = df_050_059_EC_SI2_H.assign(Shape=None)
                    df_050_059_EC_SI2_H  = df_050_059_EC_SI2_H.assign(Carat=None)
                    df_050_059_EC_SI2_H  = df_050_059_EC_SI2_H.assign(Color=None)
                    df_050_059_EC_SI2_H  = df_050_059_EC_SI2_H.assign(Clarity=None)
                    df_050_059_EC_SI2_H  = df_050_059_EC_SI2_H.assign(Cut=None)
                    df_050_059_EC_SI2_H  = df_050_059_EC_SI2_H.assign(Polish=None)
                    df_050_059_EC_SI2_H  = df_050_059_EC_SI2_H.assign(Symmetry=None)
                    df_050_059_EC_SI2_H  = df_050_059_EC_SI2_H.assign(Ratio=None)
                    df_050_059_EC_SI2_H  = df_050_059_EC_SI2_H.assign(PPC=None)
                    df_050_059_EC_SI2_H  = df_050_059_EC_SI2_H.assign(Total=None)
                    df_050_059_EC_SI2_H ['Wt Range'] = listwtrange
                    df_050_059_EC_SI2_H ['Company'] = listcom
                    df_050_059_EC_SI2_H ['Shape'] = listshap
                    df_050_059_EC_SI2_H ['Carat'] = listcar
                    df_050_059_EC_SI2_H ['Color'] = listcol
                    df_050_059_EC_SI2_H ['Clarity'] = listclar
                    df_050_059_EC_SI2_H ['Cut'] = listcut
                    df_050_059_EC_SI2_H ['Polish'] = listpol
                    df_050_059_EC_SI2_H ['Symmetry'] = listsym
                    df_050_059_EC_SI2_H ['Ratio'] = listrat
                    df_050_059_EC_SI2_H ['PPC'] = listdesc
                    df_050_059_EC_SI2_H ['Total'] = listtotal
                    df_050_059_EC_SI2_H['Carat'] = df_050_059_EC_SI2_H['Carat'].astype('float64')
                    df_050_059_EC_SI2_H['PPC'] = df_050_059_EC_SI2_H['PPC'].astype('float64')
                    df_050_059_EC_SI2_H['Total'] = df_050_059_EC_SI2_H['Total'].astype('float64')
                    df_050_059_EC_SI2_H['Total'] = df_050_059_EC_SI2_H['Carat'] * df_050_059_EC_SI2_H['PPC']


                elif i=="H" and j == "I1" and k == "EC":
                    df_050_059_EC_I1_H = pd.DataFrame()
                    df_050_059_EC_I1_H ['Wt Range'] = None
                    df_050_059_EC_I1_H  = df_050_059_EC_I1_H.assign(Company=None)
                    df_050_059_EC_I1_H  = df_050_059_EC_I1_H.assign(Shape=None)
                    df_050_059_EC_I1_H  = df_050_059_EC_I1_H.assign(Carat=None)
                    df_050_059_EC_I1_H  = df_050_059_EC_I1_H.assign(Color=None)
                    df_050_059_EC_I1_H  = df_050_059_EC_I1_H.assign(Clarity=None)
                    df_050_059_EC_I1_H  = df_050_059_EC_I1_H.assign(Cut=None)
                    df_050_059_EC_I1_H  = df_050_059_EC_I1_H.assign(Polish=None)
                    df_050_059_EC_I1_H  = df_050_059_EC_I1_H.assign(Symmetry=None)
                    df_050_059_EC_I1_H  = df_050_059_EC_I1_H.assign(Ratio=None)
                    df_050_059_EC_I1_H  = df_050_059_EC_I1_H.assign(PPC=None)
                    df_050_059_EC_I1_H  = df_050_059_EC_I1_H.assign(Total=None)
                    df_050_059_EC_I1_H ['Wt Range'] = listwtrange
                    df_050_059_EC_I1_H ['Company'] = listcom
                    df_050_059_EC_I1_H ['Shape'] = listshap
                    df_050_059_EC_I1_H ['Carat'] = listcar
                    df_050_059_EC_I1_H ['Color'] = listcol
                    df_050_059_EC_I1_H ['Clarity'] = listclar
                    df_050_059_EC_I1_H ['Cut'] = listcut
                    df_050_059_EC_I1_H ['Polish'] = listpol
                    df_050_059_EC_I1_H ['Symmetry'] = listsym
                    df_050_059_EC_I1_H ['Ratio'] = listrat
                    df_050_059_EC_I1_H ['PPC'] = listdesc
                    df_050_059_EC_I1_H ['Total'] = listtotal
                    df_050_059_EC_I1_H['Carat'] = df_050_059_EC_I1_H['Carat'].astype('float64')
                    df_050_059_EC_I1_H['PPC'] = df_050_059_EC_I1_H['PPC'].astype('float64')
                    df_050_059_EC_I1_H['Total'] = df_050_059_EC_I1_H['Total'].astype('float64')
                    df_050_059_EC_I1_H['Total'] = df_050_059_EC_I1_H['Carat'] * df_050_059_EC_I1_H['PPC']


                elif i=="H" and j == "I2" and k == "EC":
                    df_050_059_EC_I2_H = pd.DataFrame()
                    df_050_059_EC_I2_H ['Wt Range'] = None
                    df_050_059_EC_I2_H  = df_050_059_EC_I2_H.assign(Company=None)
                    df_050_059_EC_I2_H  = df_050_059_EC_I2_H.assign(Shape=None)
                    df_050_059_EC_I2_H  = df_050_059_EC_I2_H.assign(Carat=None)
                    df_050_059_EC_I2_H  = df_050_059_EC_I2_H.assign(Color=None)
                    df_050_059_EC_I2_H  = df_050_059_EC_I2_H.assign(Clarity=None)
                    df_050_059_EC_I2_H  = df_050_059_EC_I2_H.assign(Cut=None)
                    df_050_059_EC_I2_H  = df_050_059_EC_I2_H.assign(Polish=None)
                    df_050_059_EC_I2_H  = df_050_059_EC_I2_H.assign(Symmetry=None)
                    df_050_059_EC_I2_H  = df_050_059_EC_I2_H.assign(Ratio=None)
                    df_050_059_EC_I2_H  = df_050_059_EC_I2_H.assign(PPC=None)
                    df_050_059_EC_I2_H  = df_050_059_EC_I2_H.assign(Total=None)
                    df_050_059_EC_I2_H ['Wt Range'] = listwtrange
                    df_050_059_EC_I2_H ['Company'] = listcom
                    df_050_059_EC_I2_H ['Shape'] = listshap
                    df_050_059_EC_I2_H ['Carat'] = listcar
                    df_050_059_EC_I2_H ['Color'] = listcol
                    df_050_059_EC_I2_H ['Clarity'] = listclar
                    df_050_059_EC_I2_H ['Cut'] = listcut
                    df_050_059_EC_I2_H ['Polish'] = listpol
                    df_050_059_EC_I2_H ['Symmetry'] = listsym
                    df_050_059_EC_I2_H ['Ratio'] = listrat
                    df_050_059_EC_I2_H ['PPC'] = listdesc
                    df_050_059_EC_I2_H ['Total'] = listtotal
                    df_050_059_EC_I2_H['Carat'] = df_050_059_EC_I2_H['Carat'].astype('float64')
                    df_050_059_EC_I2_H['PPC'] = df_050_059_EC_I2_H['PPC'].astype('float64')
                    df_050_059_EC_I2_H['Total'] = df_050_059_EC_I2_H['Total'].astype('float64')
                    df_050_059_EC_I2_H['Total'] = df_050_059_EC_I2_H['Carat'] * df_050_059_EC_I2_H['PPC']



                elif i== "I" and j == "IF" and k == "EC":
                    df_050_059_EC_IF_I = pd.DataFrame()
                    df_050_059_EC_IF_I ['Wt Range'] = None
                    df_050_059_EC_IF_I  = df_050_059_EC_IF_I.assign(Company=None)
                    df_050_059_EC_IF_I  = df_050_059_EC_IF_I.assign(Shape=None)
                    df_050_059_EC_IF_I  = df_050_059_EC_IF_I.assign(Carat=None)
                    df_050_059_EC_IF_I  = df_050_059_EC_IF_I.assign(Color=None)
                    df_050_059_EC_IF_I  = df_050_059_EC_IF_I.assign(Clarity=None)
                    df_050_059_EC_IF_I  = df_050_059_EC_IF_I.assign(Cut=None)
                    df_050_059_EC_IF_I  = df_050_059_EC_IF_I.assign(Polish=None)
                    df_050_059_EC_IF_I  = df_050_059_EC_IF_I.assign(Symmetry=None)
                    df_050_059_EC_IF_I  = df_050_059_EC_IF_I.assign(Ratio=None)
                    df_050_059_EC_IF_I  = df_050_059_EC_IF_I.assign(PPC=None)
                    df_050_059_EC_IF_I  = df_050_059_EC_IF_I.assign(Total=None)
                    df_050_059_EC_IF_I ['Wt Range'] = listwtrange
                    df_050_059_EC_IF_I ['Company'] = listcom
                    df_050_059_EC_IF_I ['Shape'] = listshap
                    df_050_059_EC_IF_I ['Carat'] = listcar
                    df_050_059_EC_IF_I ['Color'] = listcol
                    df_050_059_EC_IF_I ['Clarity'] = listclar
                    df_050_059_EC_IF_I ['Cut'] = listcut
                    df_050_059_EC_IF_I ['Polish'] = listpol
                    df_050_059_EC_IF_I ['Symmetry'] = listsym
                    df_050_059_EC_IF_I ['Ratio'] = listrat
                    df_050_059_EC_IF_I ['PPC'] = listdesc
                    df_050_059_EC_IF_I ['Total'] = listtotal
                    df_050_059_EC_IF_I['Carat'] = df_050_059_EC_IF_I['Carat'].astype('float64')
                    df_050_059_EC_IF_I['PPC'] = df_050_059_EC_IF_I['PPC'].astype('float64')
                    df_050_059_EC_IF_I['Total'] = df_050_059_EC_IF_I['Total'].astype('float64')
                    df_050_059_EC_IF_I['Total'] = df_050_059_EC_IF_I['Carat'] * df_050_059_EC_IF_I['PPC']



                elif i== "I" and j == "VVS1" and k == "EC":
                    df_050_059_EC_VVS1_I = pd.DataFrame()
                    df_050_059_EC_VVS1_I ['Wt Range'] = None
                    df_050_059_EC_VVS1_I  = df_050_059_EC_VVS1_I.assign(Company=None)
                    df_050_059_EC_VVS1_I  = df_050_059_EC_VVS1_I.assign(Shape=None)
                    df_050_059_EC_VVS1_I  = df_050_059_EC_VVS1_I.assign(Carat=None)
                    df_050_059_EC_VVS1_I  = df_050_059_EC_VVS1_I.assign(Color=None)
                    df_050_059_EC_VVS1_I  = df_050_059_EC_VVS1_I.assign(Clarity=None)
                    df_050_059_EC_VVS1_I  = df_050_059_EC_VVS1_I.assign(Cut=None)
                    df_050_059_EC_VVS1_I  = df_050_059_EC_VVS1_I.assign(Polish=None)
                    df_050_059_EC_VVS1_I  = df_050_059_EC_VVS1_I.assign(Symmetry=None)
                    df_050_059_EC_VVS1_I  = df_050_059_EC_VVS1_I.assign(Ratio=None)
                    df_050_059_EC_VVS1_I  = df_050_059_EC_VVS1_I.assign(PPC=None)
                    df_050_059_EC_VVS1_I  = df_050_059_EC_VVS1_I.assign(Total=None)
                    df_050_059_EC_VVS1_I ['Wt Range'] = listwtrange
                    df_050_059_EC_VVS1_I ['Company'] = listcom
                    df_050_059_EC_VVS1_I ['Shape'] = listshap
                    df_050_059_EC_VVS1_I ['Carat'] = listcar
                    df_050_059_EC_VVS1_I ['Color'] = listcol
                    df_050_059_EC_VVS1_I ['Clarity'] = listclar
                    df_050_059_EC_VVS1_I ['Cut'] = listcut
                    df_050_059_EC_VVS1_I ['Polish'] = listpol
                    df_050_059_EC_VVS1_I ['Symmetry'] = listsym
                    df_050_059_EC_VVS1_I ['Ratio'] = listrat
                    df_050_059_EC_VVS1_I ['PPC'] = listdesc
                    df_050_059_EC_VVS1_I ['Total'] = listtotal
                    df_050_059_EC_VVS1_I['Carat'] = df_050_059_EC_VVS1_I['Carat'].astype('float64')
                    df_050_059_EC_VVS1_I['PPC'] = df_050_059_EC_VVS1_I['PPC'].astype('float64')
                    df_050_059_EC_VVS1_I['Total'] = df_050_059_EC_VVS1_I['Total'].astype('float64')
                    df_050_059_EC_VVS1_I['Total'] = df_050_059_EC_VVS1_I['Carat'] * df_050_059_EC_VVS1_I['PPC']


                elif i== "I" and j == "VVS2" and k == "EC":
                    df_050_059_EC_VVS2_I = pd.DataFrame()
                    df_050_059_EC_VVS2_I ['Wt Range'] = None
                    df_050_059_EC_VVS2_I  = df_050_059_EC_VVS2_I.assign(Company=None)
                    df_050_059_EC_VVS2_I  = df_050_059_EC_VVS2_I.assign(Shape=None)
                    df_050_059_EC_VVS2_I  = df_050_059_EC_VVS2_I.assign(Carat=None)
                    df_050_059_EC_VVS2_I  = df_050_059_EC_VVS2_I.assign(Color=None)
                    df_050_059_EC_VVS2_I  = df_050_059_EC_VVS2_I.assign(Clarity=None)
                    df_050_059_EC_VVS2_I  = df_050_059_EC_VVS2_I.assign(Cut=None)
                    df_050_059_EC_VVS2_I  = df_050_059_EC_VVS2_I.assign(Polish=None)
                    df_050_059_EC_VVS2_I  = df_050_059_EC_VVS2_I.assign(Symmetry=None)
                    df_050_059_EC_VVS2_I  = df_050_059_EC_VVS2_I.assign(Ratio=None)
                    df_050_059_EC_VVS2_I  = df_050_059_EC_VVS2_I.assign(PPC=None)
                    df_050_059_EC_VVS2_I  = df_050_059_EC_VVS2_I.assign(Total=None)
                    df_050_059_EC_VVS2_I ['Wt Range'] = listwtrange
                    df_050_059_EC_VVS2_I ['Company'] = listcom
                    df_050_059_EC_VVS2_I ['Shape'] = listshap
                    df_050_059_EC_VVS2_I ['Carat'] = listcar
                    df_050_059_EC_VVS2_I ['Color'] = listcol
                    df_050_059_EC_VVS2_I ['Clarity'] = listclar
                    df_050_059_EC_VVS2_I ['Cut'] = listcut
                    df_050_059_EC_VVS2_I ['Polish'] = listpol
                    df_050_059_EC_VVS2_I ['Symmetry'] = listsym
                    df_050_059_EC_VVS2_I ['Ratio'] = listrat
                    df_050_059_EC_VVS2_I ['PPC'] = listdesc
                    df_050_059_EC_VVS2_I ['Total'] = listtotal
                    df_050_059_EC_VVS2_I['Carat'] = df_050_059_EC_VVS2_I['Carat'].astype('float64')
                    df_050_059_EC_VVS2_I['PPC'] = df_050_059_EC_VVS2_I['PPC'].astype('float64')
                    df_050_059_EC_VVS2_I['Total'] = df_050_059_EC_VVS2_I['Total'].astype('float64')
                    df_050_059_EC_VVS2_I['Total'] = df_050_059_EC_VVS2_I['Carat'] * df_050_059_EC_VVS2_I['PPC']


                elif i== "I" and j=="VS1" and k == "EC":
                    df_050_059_EC_VS1_I = pd.DataFrame()
                    df_050_059_EC_VS1_I ['Wt Range'] = None
                    df_050_059_EC_VS1_I  = df_050_059_EC_VS1_I.assign(Company=None)
                    df_050_059_EC_VS1_I  = df_050_059_EC_VS1_I.assign(Shape=None)
                    df_050_059_EC_VS1_I  = df_050_059_EC_VS1_I.assign(Carat=None)
                    df_050_059_EC_VS1_I  = df_050_059_EC_VS1_I.assign(Color=None)
                    df_050_059_EC_VS1_I  = df_050_059_EC_VS1_I.assign(Clarity=None)
                    df_050_059_EC_VS1_I  = df_050_059_EC_VS1_I.assign(Cut=None)
                    df_050_059_EC_VS1_I  = df_050_059_EC_VS1_I.assign(Polish=None)
                    df_050_059_EC_VS1_I  = df_050_059_EC_VS1_I.assign(Symmetry=None)
                    df_050_059_EC_VS1_I  = df_050_059_EC_VS1_I.assign(Ratio=None)
                    df_050_059_EC_VS1_I  = df_050_059_EC_VS1_I.assign(PPC=None)
                    df_050_059_EC_VS1_I  = df_050_059_EC_VS1_I.assign(Total=None)
                    df_050_059_EC_VS1_I ['Wt Range'] = listwtrange
                    df_050_059_EC_VS1_I ['Company'] = listcom
                    df_050_059_EC_VS1_I ['Shape'] = listshap
                    df_050_059_EC_VS1_I ['Carat'] = listcar
                    df_050_059_EC_VS1_I ['Color'] = listcol
                    df_050_059_EC_VS1_I ['Clarity'] = listclar
                    df_050_059_EC_VS1_I ['Cut'] = listcut
                    df_050_059_EC_VS1_I ['Polish'] = listpol
                    df_050_059_EC_VS1_I ['Symmetry'] = listsym
                    df_050_059_EC_VS1_I ['Ratio'] = listrat
                    df_050_059_EC_VS1_I ['PPC'] = listdesc
                    df_050_059_EC_VS1_I ['Total'] = listtotal
                    df_050_059_EC_VS1_I['Carat'] = df_050_059_EC_VS1_I['Carat'].astype('float64')
                    df_050_059_EC_VS1_I['PPC'] = df_050_059_EC_VS1_I['PPC'].astype('float64')
                    df_050_059_EC_VS1_I['Total'] = df_050_059_EC_VS1_I['Total'].astype('float64')
                    df_050_059_EC_VS1_I['Total'] = df_050_059_EC_VS1_I['Carat'] * df_050_059_EC_VS1_I['PPC']


                elif i== "I" and j == "VS2" and k == "EC":
                    df_050_059_EC_VS2_I = pd.DataFrame()
                    df_050_059_EC_VS2_I ['Wt Range'] = None
                    df_050_059_EC_VS2_I  = df_050_059_EC_VS2_I.assign(Company=None)
                    df_050_059_EC_VS2_I  = df_050_059_EC_VS2_I.assign(Shape=None)
                    df_050_059_EC_VS2_I  = df_050_059_EC_VS2_I.assign(Carat=None)
                    df_050_059_EC_VS2_I  = df_050_059_EC_VS2_I.assign(Color=None)
                    df_050_059_EC_VS2_I  = df_050_059_EC_VS2_I.assign(Clarity=None)
                    df_050_059_EC_VS2_I  = df_050_059_EC_VS2_I.assign(Cut=None)
                    df_050_059_EC_VS2_I  = df_050_059_EC_VS2_I.assign(Polish=None)
                    df_050_059_EC_VS2_I  = df_050_059_EC_VS2_I.assign(Symmetry=None)
                    df_050_059_EC_VS2_I  = df_050_059_EC_VS2_I.assign(Ratio=None)
                    df_050_059_EC_VS2_I  = df_050_059_EC_VS2_I.assign(PPC=None)
                    df_050_059_EC_VS2_I  = df_050_059_EC_VS2_I.assign(Total=None)
                    df_050_059_EC_VS2_I ['Wt Range'] = listwtrange
                    df_050_059_EC_VS2_I ['Company'] = listcom
                    df_050_059_EC_VS2_I ['Shape'] = listshap
                    df_050_059_EC_VS2_I ['Carat'] = listcar
                    df_050_059_EC_VS2_I ['Color'] = listcol
                    df_050_059_EC_VS2_I ['Clarity'] = listclar
                    df_050_059_EC_VS2_I ['Cut'] = listcut
                    df_050_059_EC_VS2_I ['Polish'] = listpol
                    df_050_059_EC_VS2_I ['Symmetry'] = listsym
                    df_050_059_EC_VS2_I ['Ratio'] = listrat
                    df_050_059_EC_VS2_I ['PPC'] = listdesc
                    df_050_059_EC_VS2_I ['Total'] = listtotal
                    df_050_059_EC_VS2_I['Carat'] = df_050_059_EC_VS2_I['Carat'].astype('float64')
                    df_050_059_EC_VS2_I['PPC'] = df_050_059_EC_VS2_I['PPC'].astype('float64')
                    df_050_059_EC_VS2_I['Total'] = df_050_059_EC_VS2_I['Total'].astype('float64')
                    df_050_059_EC_VS2_I['Total'] = df_050_059_EC_VS2_I['Carat'] * df_050_059_EC_VS2_I['PPC']


                elif i== "I" and j == "SI1" and k == "EC":
                    df_050_059_EC_SI1_I = pd.DataFrame()
                    df_050_059_EC_SI1_I ['Wt Range'] = None
                    df_050_059_EC_SI1_I  = df_050_059_EC_SI1_I.assign(Company=None)
                    df_050_059_EC_SI1_I  = df_050_059_EC_SI1_I.assign(Shape=None)
                    df_050_059_EC_SI1_I  = df_050_059_EC_SI1_I.assign(Carat=None)
                    df_050_059_EC_SI1_I  = df_050_059_EC_SI1_I.assign(Color=None)
                    df_050_059_EC_SI1_I  = df_050_059_EC_SI1_I.assign(Clarity=None)
                    df_050_059_EC_SI1_I  = df_050_059_EC_SI1_I.assign(Cut=None)
                    df_050_059_EC_SI1_I  = df_050_059_EC_SI1_I.assign(Polish=None)
                    df_050_059_EC_SI1_I  = df_050_059_EC_SI1_I.assign(Symmetry=None)
                    df_050_059_EC_SI1_I  = df_050_059_EC_SI1_I.assign(Ratio=None)
                    df_050_059_EC_SI1_I  = df_050_059_EC_SI1_I.assign(PPC=None)
                    df_050_059_EC_SI1_I  = df_050_059_EC_SI1_I.assign(Total=None)
                    df_050_059_EC_SI1_I ['Wt Range'] = listwtrange
                    df_050_059_EC_SI1_I ['Company'] = listcom
                    df_050_059_EC_SI1_I ['Shape'] = listshap
                    df_050_059_EC_SI1_I ['Carat'] = listcar
                    df_050_059_EC_SI1_I ['Color'] = listcol
                    df_050_059_EC_SI1_I ['Clarity'] = listclar
                    df_050_059_EC_SI1_I ['Cut'] = listcut
                    df_050_059_EC_SI1_I ['Polish'] = listpol
                    df_050_059_EC_SI1_I ['Symmetry'] = listsym
                    df_050_059_EC_SI1_I ['Ratio'] = listrat
                    df_050_059_EC_SI1_I ['PPC'] = listdesc
                    df_050_059_EC_SI1_I ['Total'] = listtotal
                    df_050_059_EC_SI1_I['Carat'] = df_050_059_EC_SI1_I['Carat'].astype('float64')
                    df_050_059_EC_SI1_I['PPC'] = df_050_059_EC_SI1_I['PPC'].astype('float64')
                    df_050_059_EC_SI1_I['Total'] = df_050_059_EC_SI1_I['Total'].astype('float64')
                    df_050_059_EC_SI1_I['Total'] = df_050_059_EC_SI1_I['Carat'] * df_050_059_EC_SI1_I['PPC']


                elif i== "I" and j == "SI2" and k == "EC":
                    df_050_059_EC_SI2_I = pd.DataFrame()
                    df_050_059_EC_SI2_I ['Wt Range'] = None
                    df_050_059_EC_SI2_I  = df_050_059_EC_SI2_I.assign(Company=None)
                    df_050_059_EC_SI2_I  = df_050_059_EC_SI2_I.assign(Shape=None)
                    df_050_059_EC_SI2_I  = df_050_059_EC_SI2_I.assign(Carat=None)
                    df_050_059_EC_SI2_I  = df_050_059_EC_SI2_I.assign(Color=None)
                    df_050_059_EC_SI2_I  = df_050_059_EC_SI2_I.assign(Clarity=None)
                    df_050_059_EC_SI2_I  = df_050_059_EC_SI2_I.assign(Cut=None)
                    df_050_059_EC_SI2_I  = df_050_059_EC_SI2_I.assign(Polish=None)
                    df_050_059_EC_SI2_I  = df_050_059_EC_SI2_I.assign(Symmetry=None)
                    df_050_059_EC_SI2_I  = df_050_059_EC_SI2_I.assign(Ratio=None)
                    df_050_059_EC_SI2_I  = df_050_059_EC_SI2_I.assign(PPC=None)
                    df_050_059_EC_SI2_I  = df_050_059_EC_SI2_I.assign(Total=None)
                    df_050_059_EC_SI2_I ['Wt Range'] = listwtrange
                    df_050_059_EC_SI2_I ['Company'] = listcom
                    df_050_059_EC_SI2_I ['Shape'] = listshap
                    df_050_059_EC_SI2_I ['Carat'] = listcar
                    df_050_059_EC_SI2_I ['Color'] = listcol
                    df_050_059_EC_SI2_I ['Clarity'] = listclar
                    df_050_059_EC_SI2_I ['Cut'] = listcut
                    df_050_059_EC_SI2_I ['Polish'] = listpol
                    df_050_059_EC_SI2_I ['Symmetry'] = listsym
                    df_050_059_EC_SI2_I ['Ratio'] = listrat
                    df_050_059_EC_SI2_I ['PPC'] = listdesc
                    df_050_059_EC_SI2_I ['Total'] = listtotal
                    df_050_059_EC_SI2_I['Carat'] = df_050_059_EC_SI2_I['Carat'].astype('float64')
                    df_050_059_EC_SI2_I['PPC'] = df_050_059_EC_SI2_I['PPC'].astype('float64')
                    df_050_059_EC_SI2_I['Total'] = df_050_059_EC_SI2_I['Total'].astype('float64')
                    df_050_059_EC_SI2_I['Total'] = df_050_059_EC_SI2_I['Carat'] * df_050_059_EC_SI2_I['PPC']


                elif i== "I" and j == "I1" and k == "EC":
                    df_050_059_EC_I1_I = pd.DataFrame()
                    df_050_059_EC_I1_I ['Wt Range'] = None
                    df_050_059_EC_I1_I  = df_050_059_EC_I1_I.assign(Company=None)
                    df_050_059_EC_I1_I  = df_050_059_EC_I1_I.assign(Shape=None)
                    df_050_059_EC_I1_I  = df_050_059_EC_I1_I.assign(Carat=None)
                    df_050_059_EC_I1_I  = df_050_059_EC_I1_I.assign(Color=None)
                    df_050_059_EC_I1_I  = df_050_059_EC_I1_I.assign(Clarity=None)
                    df_050_059_EC_I1_I  = df_050_059_EC_I1_I.assign(Cut=None)
                    df_050_059_EC_I1_I  = df_050_059_EC_I1_I.assign(Polish=None)
                    df_050_059_EC_I1_I  = df_050_059_EC_I1_I.assign(Symmetry=None)
                    df_050_059_EC_I1_I  = df_050_059_EC_I1_I.assign(Ratio=None)
                    df_050_059_EC_I1_I  = df_050_059_EC_I1_I.assign(PPC=None)
                    df_050_059_EC_I1_I  = df_050_059_EC_I1_I.assign(Total=None)
                    df_050_059_EC_I1_I ['Wt Range'] = listwtrange
                    df_050_059_EC_I1_I ['Company'] = listcom
                    df_050_059_EC_I1_I ['Shape'] = listshap
                    df_050_059_EC_I1_I ['Carat'] = listcar
                    df_050_059_EC_I1_I ['Color'] = listcol
                    df_050_059_EC_I1_I ['Clarity'] = listclar
                    df_050_059_EC_I1_I ['Cut'] = listcut
                    df_050_059_EC_I1_I ['Polish'] = listpol
                    df_050_059_EC_I1_I ['Symmetry'] = listsym
                    df_050_059_EC_I1_I ['Ratio'] = listrat
                    df_050_059_EC_I1_I ['PPC'] = listdesc
                    df_050_059_EC_I1_I ['Total'] = listtotal
                    df_050_059_EC_I1_I['Carat'] = df_050_059_EC_I1_I['Carat'].astype('float64')
                    df_050_059_EC_I1_I['PPC'] = df_050_059_EC_I1_I['PPC'].astype('float64')
                    df_050_059_EC_I1_I['Total'] = df_050_059_EC_I1_I['Total'].astype('float64')
                    df_050_059_EC_I1_I['Total'] = df_050_059_EC_I1_I['Carat'] * df_050_059_EC_I1_I['PPC']


                elif i== "I" and j == "I2" and k == "EC":
                    df_050_059_EC_I2_I = pd.DataFrame()
                    df_050_059_EC_I2_I ['Wt Range'] = None
                    df_050_059_EC_I2_I  = df_050_059_EC_I2_I.assign(Company=None)
                    df_050_059_EC_I2_I  = df_050_059_EC_I2_I.assign(Shape=None)
                    df_050_059_EC_I2_I  = df_050_059_EC_I2_I.assign(Carat=None)
                    df_050_059_EC_I2_I  = df_050_059_EC_I2_I.assign(Color=None)
                    df_050_059_EC_I2_I  = df_050_059_EC_I2_I.assign(Clarity=None)
                    df_050_059_EC_I2_I  = df_050_059_EC_I2_I.assign(Cut=None)
                    df_050_059_EC_I2_I  = df_050_059_EC_I2_I.assign(Polish=None)
                    df_050_059_EC_I2_I  = df_050_059_EC_I2_I.assign(Symmetry=None)
                    df_050_059_EC_I2_I  = df_050_059_EC_I2_I.assign(Ratio=None)
                    df_050_059_EC_I2_I  = df_050_059_EC_I2_I.assign(PPC=None)
                    df_050_059_EC_I2_I  = df_050_059_EC_I2_I.assign(Total=None)
                    df_050_059_EC_I2_I ['Wt Range'] = listwtrange
                    df_050_059_EC_I2_I ['Company'] = listcom
                    df_050_059_EC_I2_I ['Shape'] = listshap
                    df_050_059_EC_I2_I ['Carat'] = listcar
                    df_050_059_EC_I2_I ['Color'] = listcol
                    df_050_059_EC_I2_I ['Clarity'] = listclar
                    df_050_059_EC_I2_I ['Cut'] = listcut
                    df_050_059_EC_I2_I ['Polish'] = listpol
                    df_050_059_EC_I2_I ['Symmetry'] = listsym
                    df_050_059_EC_I2_I ['Ratio'] = listrat
                    df_050_059_EC_I2_I ['PPC'] = listdesc
                    df_050_059_EC_I2_I ['Total'] = listtotal
                    df_050_059_EC_I2_I['Carat'] = df_050_059_EC_I2_I['Carat'].astype('float64')
                    df_050_059_EC_I2_I['PPC'] = df_050_059_EC_I2_I['PPC'].astype('float64')
                    df_050_059_EC_I2_I['Total'] = df_050_059_EC_I2_I['Total'].astype('float64')
                    df_050_059_EC_I2_I['Total'] = df_050_059_EC_I2_I['Carat'] * df_050_059_EC_I2_I['PPC']


                elif i=="J" and j == "IF" and k == "EC":
                    df_050_059_EC_IF_J = pd.DataFrame()
                    df_050_059_EC_IF_J ['Wt Range'] = None
                    df_050_059_EC_IF_J  = df_050_059_EC_IF_J.assign(Company=None)
                    df_050_059_EC_IF_J  = df_050_059_EC_IF_J.assign(Shape=None)
                    df_050_059_EC_IF_J  = df_050_059_EC_IF_J.assign(Carat=None)
                    df_050_059_EC_IF_J  = df_050_059_EC_IF_J.assign(Color=None)
                    df_050_059_EC_IF_J  = df_050_059_EC_IF_J.assign(Clarity=None)
                    df_050_059_EC_IF_J  = df_050_059_EC_IF_J.assign(Cut=None)
                    df_050_059_EC_IF_J  = df_050_059_EC_IF_J.assign(Polish=None)
                    df_050_059_EC_IF_J  = df_050_059_EC_IF_J.assign(Symmetry=None)
                    df_050_059_EC_IF_J  = df_050_059_EC_IF_J.assign(Ratio=None)
                    df_050_059_EC_IF_J  = df_050_059_EC_IF_J.assign(PPC=None)
                    df_050_059_EC_IF_J  = df_050_059_EC_IF_J.assign(Total=None)
                    df_050_059_EC_IF_J ['Wt Range'] = listwtrange
                    df_050_059_EC_IF_J ['Company'] = listcom
                    df_050_059_EC_IF_J ['Shape'] = listshap
                    df_050_059_EC_IF_J ['Carat'] = listcar
                    df_050_059_EC_IF_J ['Color'] = listcol
                    df_050_059_EC_IF_J ['Clarity'] = listclar
                    df_050_059_EC_IF_J ['Cut'] = listcut
                    df_050_059_EC_IF_J ['Polish'] = listpol
                    df_050_059_EC_IF_J ['Symmetry'] = listsym
                    df_050_059_EC_IF_J ['Ratio'] = listrat
                    df_050_059_EC_IF_J ['PPC'] = listdesc
                    df_050_059_EC_IF_J ['Total'] = listtotal
                    df_050_059_EC_IF_J['Carat'] = df_050_059_EC_IF_J['Carat'].astype('float64')
                    df_050_059_EC_IF_J['PPC'] = df_050_059_EC_IF_J['PPC'].astype('float64')
                    df_050_059_EC_IF_J['Total'] = df_050_059_EC_IF_J['Total'].astype('float64')
                    df_050_059_EC_IF_J['Total'] = df_050_059_EC_IF_J['Carat'] * df_050_059_EC_IF_J['PPC']



                elif i=="J"  and j == "VVS1" and k == "EC":
                    df_050_059_EC_VVS1_J = pd.DataFrame()
                    df_050_059_EC_VVS1_J ['Wt Range'] = None
                    df_050_059_EC_VVS1_J  = df_050_059_EC_VVS1_J.assign(Company=None)
                    df_050_059_EC_VVS1_J  = df_050_059_EC_VVS1_J.assign(Shape=None)
                    df_050_059_EC_VVS1_J  = df_050_059_EC_VVS1_J.assign(Carat=None)
                    df_050_059_EC_VVS1_J  = df_050_059_EC_VVS1_J.assign(Color=None)
                    df_050_059_EC_VVS1_J  = df_050_059_EC_VVS1_J.assign(Clarity=None)
                    df_050_059_EC_VVS1_J  = df_050_059_EC_VVS1_J.assign(Cut=None)
                    df_050_059_EC_VVS1_J  = df_050_059_EC_VVS1_J.assign(Polish=None)
                    df_050_059_EC_VVS1_J  = df_050_059_EC_VVS1_J.assign(Symmetry=None)
                    df_050_059_EC_VVS1_J  = df_050_059_EC_VVS1_J.assign(Ratio=None)
                    df_050_059_EC_VVS1_J  = df_050_059_EC_VVS1_J.assign(PPC=None)
                    df_050_059_EC_VVS1_J  = df_050_059_EC_VVS1_J.assign(Total=None)
                    df_050_059_EC_VVS1_J ['Wt Range'] = listwtrange
                    df_050_059_EC_VVS1_J ['Company'] = listcom
                    df_050_059_EC_VVS1_J ['Shape'] = listshap
                    df_050_059_EC_VVS1_J ['Carat'] = listcar
                    df_050_059_EC_VVS1_J ['Color'] = listcol
                    df_050_059_EC_VVS1_J ['Clarity'] = listclar
                    df_050_059_EC_VVS1_J ['Cut'] = listcut
                    df_050_059_EC_VVS1_J ['Polish'] = listpol
                    df_050_059_EC_VVS1_J ['Symmetry'] = listsym
                    df_050_059_EC_VVS1_J ['Ratio'] = listrat
                    df_050_059_EC_VVS1_J ['PPC'] = listdesc
                    df_050_059_EC_VVS1_J ['Total'] = listtotal
                    df_050_059_EC_VVS1_J['Carat'] = df_050_059_EC_VVS1_J['Carat'].astype('float64')
                    df_050_059_EC_VVS1_J['PPC'] = df_050_059_EC_VVS1_J['PPC'].astype('float64')
                    df_050_059_EC_VVS1_J['Total'] = df_050_059_EC_VVS1_J['Total'].astype('float64')
                    df_050_059_EC_VVS1_J['Total'] = df_050_059_EC_VVS1_J['Carat'] * df_050_059_EC_VVS1_J['PPC']


                elif i=="J"  and j == "VVS2" and k == "EC":
                    df_050_059_EC_VVS2_J = pd.DataFrame()
                    df_050_059_EC_VVS2_J ['Wt Range'] = None
                    df_050_059_EC_VVS2_J  = df_050_059_EC_VVS2_J.assign(Company=None)
                    df_050_059_EC_VVS2_J  = df_050_059_EC_VVS2_J.assign(Shape=None)
                    df_050_059_EC_VVS2_J  = df_050_059_EC_VVS2_J.assign(Carat=None)
                    df_050_059_EC_VVS2_J  = df_050_059_EC_VVS2_J.assign(Color=None)
                    df_050_059_EC_VVS2_J  = df_050_059_EC_VVS2_J.assign(Clarity=None)
                    df_050_059_EC_VVS2_J  = df_050_059_EC_VVS2_J.assign(Cut=None)
                    df_050_059_EC_VVS2_J  = df_050_059_EC_VVS2_J.assign(Polish=None)
                    df_050_059_EC_VVS2_J  = df_050_059_EC_VVS2_J.assign(Symmetry=None)
                    df_050_059_EC_VVS2_J  = df_050_059_EC_VVS2_J.assign(Ratio=None)
                    df_050_059_EC_VVS2_J  = df_050_059_EC_VVS2_J.assign(PPC=None)
                    df_050_059_EC_VVS2_J  = df_050_059_EC_VVS2_J.assign(Total=None)
                    df_050_059_EC_VVS2_J ['Wt Range'] = listwtrange
                    df_050_059_EC_VVS2_J ['Company'] = listcom
                    df_050_059_EC_VVS2_J ['Shape'] = listshap
                    df_050_059_EC_VVS2_J ['Carat'] = listcar
                    df_050_059_EC_VVS2_J ['Color'] = listcol
                    df_050_059_EC_VVS2_J ['Clarity'] = listclar
                    df_050_059_EC_VVS2_J ['Cut'] = listcut
                    df_050_059_EC_VVS2_J ['Polish'] = listpol
                    df_050_059_EC_VVS2_J ['Symmetry'] = listsym
                    df_050_059_EC_VVS2_J ['Ratio'] = listrat
                    df_050_059_EC_VVS2_J ['PPC'] = listdesc
                    df_050_059_EC_VVS2_J ['Total'] = listtotal
                    df_050_059_EC_VVS2_J['Carat'] = df_050_059_EC_VVS2_J['Carat'].astype('float64')
                    df_050_059_EC_VVS2_J['PPC'] = df_050_059_EC_VVS2_J['PPC'].astype('float64')
                    df_050_059_EC_VVS2_J['Total'] = df_050_059_EC_VVS2_J['Total'].astype('float64')
                    df_050_059_EC_VVS2_J['Total'] = df_050_059_EC_VVS2_J['Carat'] * df_050_059_EC_VVS2_J['PPC']


                elif i=="J"  and j=="VS1" and k == "EC":
                    df_050_059_EC_VS1_J = pd.DataFrame()
                    df_050_059_EC_VS1_J ['Wt Range'] = None
                    df_050_059_EC_VS1_J  = df_050_059_EC_VS1_J.assign(Company=None)
                    df_050_059_EC_VS1_J  = df_050_059_EC_VS1_J.assign(Shape=None)
                    df_050_059_EC_VS1_J  = df_050_059_EC_VS1_J.assign(Carat=None)
                    df_050_059_EC_VS1_J  = df_050_059_EC_VS1_J.assign(Color=None)
                    df_050_059_EC_VS1_J  = df_050_059_EC_VS1_J.assign(Clarity=None)
                    df_050_059_EC_VS1_J  = df_050_059_EC_VS1_J.assign(Cut=None)
                    df_050_059_EC_VS1_J  = df_050_059_EC_VS1_J.assign(Polish=None)
                    df_050_059_EC_VS1_J  = df_050_059_EC_VS1_J.assign(Symmetry=None)
                    df_050_059_EC_VS1_J  = df_050_059_EC_VS1_J.assign(Ratio=None)
                    df_050_059_EC_VS1_J  = df_050_059_EC_VS1_J.assign(PPC=None)
                    df_050_059_EC_VS1_J  = df_050_059_EC_VS1_J.assign(Total=None)
                    df_050_059_EC_VS1_J ['Wt Range'] = listwtrange
                    df_050_059_EC_VS1_J ['Company'] = listcom
                    df_050_059_EC_VS1_J ['Shape'] = listshap
                    df_050_059_EC_VS1_J ['Carat'] = listcar
                    df_050_059_EC_VS1_J ['Color'] = listcol
                    df_050_059_EC_VS1_J ['Clarity'] = listclar
                    df_050_059_EC_VS1_J ['Cut'] = listcut
                    df_050_059_EC_VS1_J ['Polish'] = listpol
                    df_050_059_EC_VS1_J ['Symmetry'] = listsym
                    df_050_059_EC_VS1_J ['Ratio'] = listrat
                    df_050_059_EC_VS1_J ['PPC'] = listdesc
                    df_050_059_EC_VS1_J ['Total'] = listtotal
                    df_050_059_EC_VS1_J['Carat'] = df_050_059_EC_VS1_J['Carat'].astype('float64')
                    df_050_059_EC_VS1_J['PPC'] = df_050_059_EC_VS1_J['PPC'].astype('float64')
                    df_050_059_EC_VS1_J['Total'] = df_050_059_EC_VS1_J['Total'].astype('float64')
                    df_050_059_EC_VS1_J['Total'] = df_050_059_EC_VS1_J['Carat'] * df_050_059_EC_VS1_J['PPC']


                elif i=="J"  and j == "VS2" and k == "EC":
                    df_050_059_EC_VS2_J = pd.DataFrame()
                    df_050_059_EC_VS2_J ['Wt Range'] = None
                    df_050_059_EC_VS2_J  = df_050_059_EC_VS2_J.assign(Company=None)
                    df_050_059_EC_VS2_J  = df_050_059_EC_VS2_J.assign(Shape=None)
                    df_050_059_EC_VS2_J  = df_050_059_EC_VS2_J.assign(Carat=None)
                    df_050_059_EC_VS2_J  = df_050_059_EC_VS2_J.assign(Color=None)
                    df_050_059_EC_VS2_J  = df_050_059_EC_VS2_J.assign(Clarity=None)
                    df_050_059_EC_VS2_J  = df_050_059_EC_VS2_J.assign(Cut=None)
                    df_050_059_EC_VS2_J  = df_050_059_EC_VS2_J.assign(Polish=None)
                    df_050_059_EC_VS2_J  = df_050_059_EC_VS2_J.assign(Symmetry=None)
                    df_050_059_EC_VS2_J  = df_050_059_EC_VS2_J.assign(Ratio=None)
                    df_050_059_EC_VS2_J  = df_050_059_EC_VS2_J.assign(PPC=None)
                    df_050_059_EC_VS2_J  = df_050_059_EC_VS2_J.assign(Total=None)
                    df_050_059_EC_VS2_J ['Wt Range'] = listwtrange
                    df_050_059_EC_VS2_J ['Company'] = listcom
                    df_050_059_EC_VS2_J ['Shape'] = listshap
                    df_050_059_EC_VS2_J ['Carat'] = listcar
                    df_050_059_EC_VS2_J ['Color'] = listcol
                    df_050_059_EC_VS2_J ['Clarity'] = listclar
                    df_050_059_EC_VS2_J ['Cut'] = listcut
                    df_050_059_EC_VS2_J ['Polish'] = listpol
                    df_050_059_EC_VS2_J ['Symmetry'] = listsym
                    df_050_059_EC_VS2_J ['Ratio'] = listrat
                    df_050_059_EC_VS2_J ['PPC'] = listdesc
                    df_050_059_EC_VS2_J ['Total'] = listtotal
                    df_050_059_EC_VS2_J['Carat'] = df_050_059_EC_VS2_J['Carat'].astype('float64')
                    df_050_059_EC_VS2_J['PPC'] = df_050_059_EC_VS2_J['PPC'].astype('float64')
                    df_050_059_EC_VS2_J['Total'] = df_050_059_EC_VS2_J['Total'].astype('float64')
                    df_050_059_EC_VS2_J['Total'] = df_050_059_EC_VS2_J['Carat'] * df_050_059_EC_VS2_J['PPC']


                elif i=="J"  and j == "SI1" and k == "EC":
                    df_050_059_EC_SI1_J = pd.DataFrame()
                    df_050_059_EC_SI1_J ['Wt Range'] = None
                    df_050_059_EC_SI1_J  = df_050_059_EC_SI1_J.assign(Company=None)
                    df_050_059_EC_SI1_J  = df_050_059_EC_SI1_J.assign(Shape=None)
                    df_050_059_EC_SI1_J  = df_050_059_EC_SI1_J.assign(Carat=None)
                    df_050_059_EC_SI1_J  = df_050_059_EC_SI1_J.assign(Color=None)
                    df_050_059_EC_SI1_J  = df_050_059_EC_SI1_J.assign(Clarity=None)
                    df_050_059_EC_SI1_J  = df_050_059_EC_SI1_J.assign(Cut=None)
                    df_050_059_EC_SI1_J  = df_050_059_EC_SI1_J.assign(Polish=None)
                    df_050_059_EC_SI1_J  = df_050_059_EC_SI1_J.assign(Symmetry=None)
                    df_050_059_EC_SI1_J  = df_050_059_EC_SI1_J.assign(Ratio=None)
                    df_050_059_EC_SI1_J  = df_050_059_EC_SI1_J.assign(PPC=None)
                    df_050_059_EC_SI1_J  = df_050_059_EC_SI1_J.assign(Total=None)
                    df_050_059_EC_SI1_J ['Wt Range'] = listwtrange
                    df_050_059_EC_SI1_J ['Company'] = listcom
                    df_050_059_EC_SI1_J ['Shape'] = listshap
                    df_050_059_EC_SI1_J ['Carat'] = listcar
                    df_050_059_EC_SI1_J ['Color'] = listcol
                    df_050_059_EC_SI1_J ['Clarity'] = listclar
                    df_050_059_EC_SI1_J ['Cut'] = listcut
                    df_050_059_EC_SI1_J ['Polish'] = listpol
                    df_050_059_EC_SI1_J ['Symmetry'] = listsym
                    df_050_059_EC_SI1_J ['Ratio'] = listrat
                    df_050_059_EC_SI1_J ['PPC'] = listdesc
                    df_050_059_EC_SI1_J ['Total'] = listtotal
                    df_050_059_EC_SI1_J['Carat'] = df_050_059_EC_SI1_J['Carat'].astype('float64')
                    df_050_059_EC_SI1_J['PPC'] = df_050_059_EC_SI1_J['PPC'].astype('float64')
                    df_050_059_EC_SI1_J['Total'] = df_050_059_EC_SI1_J['Total'].astype('float64')
                    df_050_059_EC_SI1_J['Total'] = df_050_059_EC_SI1_J['Carat'] * df_050_059_EC_SI1_J['PPC']


                elif i=="J"  and j == "SI2" and k == "EC":
                    df_050_059_EC_SI2_J = pd.DataFrame()
                    df_050_059_EC_SI2_J ['Wt Range'] = None
                    df_050_059_EC_SI2_J  = df_050_059_EC_SI2_J.assign(Company=None)
                    df_050_059_EC_SI2_J  = df_050_059_EC_SI2_J.assign(Shape=None)
                    df_050_059_EC_SI2_J  = df_050_059_EC_SI2_J.assign(Carat=None)
                    df_050_059_EC_SI2_J  = df_050_059_EC_SI2_J.assign(Color=None)
                    df_050_059_EC_SI2_J  = df_050_059_EC_SI2_J.assign(Clarity=None)
                    df_050_059_EC_SI2_J  = df_050_059_EC_SI2_J.assign(Cut=None)
                    df_050_059_EC_SI2_J  = df_050_059_EC_SI2_J.assign(Polish=None)
                    df_050_059_EC_SI2_J  = df_050_059_EC_SI2_J.assign(Symmetry=None)
                    df_050_059_EC_SI2_J  = df_050_059_EC_SI2_J.assign(Ratio=None)
                    df_050_059_EC_SI2_J  = df_050_059_EC_SI2_J.assign(PPC=None)
                    df_050_059_EC_SI2_J  = df_050_059_EC_SI2_J.assign(Total=None)
                    df_050_059_EC_SI2_J ['Wt Range'] = listwtrange
                    df_050_059_EC_SI2_J ['Company'] = listcom
                    df_050_059_EC_SI2_J ['Shape'] = listshap
                    df_050_059_EC_SI2_J ['Carat'] = listcar
                    df_050_059_EC_SI2_J ['Color'] = listcol
                    df_050_059_EC_SI2_J ['Clarity'] = listclar
                    df_050_059_EC_SI2_J ['Cut'] = listcut
                    df_050_059_EC_SI2_J ['Polish'] = listpol
                    df_050_059_EC_SI2_J ['Symmetry'] = listsym
                    df_050_059_EC_SI2_J ['Ratio'] = listrat
                    df_050_059_EC_SI2_J ['PPC'] = listdesc
                    df_050_059_EC_SI2_J ['Total'] = listtotal
                    df_050_059_EC_SI2_J['Carat'] = df_050_059_EC_SI2_J['Carat'].astype('float64')
                    df_050_059_EC_SI2_J['PPC'] = df_050_059_EC_SI2_J['PPC'].astype('float64')
                    df_050_059_EC_SI2_J['Total'] = df_050_059_EC_SI2_J['Total'].astype('float64')
                    df_050_059_EC_SI2_J['Total'] = df_050_059_EC_SI2_J['Carat'] * df_050_059_EC_SI2_J['PPC']


                elif i=="J"  and j == "I1" and k == "EC":
                    df_050_059_EC_I1_J = pd.DataFrame()
                    df_050_059_EC_I1_J ['Wt Range'] = None
                    df_050_059_EC_I1_J  = df_050_059_EC_I1_J.assign(Company=None)
                    df_050_059_EC_I1_J  = df_050_059_EC_I1_J.assign(Shape=None)
                    df_050_059_EC_I1_J  = df_050_059_EC_I1_J.assign(Carat=None)
                    df_050_059_EC_I1_J  = df_050_059_EC_I1_J.assign(Color=None)
                    df_050_059_EC_I1_J  = df_050_059_EC_I1_J.assign(Clarity=None)
                    df_050_059_EC_I1_J  = df_050_059_EC_I1_J.assign(Cut=None)
                    df_050_059_EC_I1_J  = df_050_059_EC_I1_J.assign(Polish=None)
                    df_050_059_EC_I1_J  = df_050_059_EC_I1_J.assign(Symmetry=None)
                    df_050_059_EC_I1_J  = df_050_059_EC_I1_J.assign(Ratio=None)
                    df_050_059_EC_I1_J  = df_050_059_EC_I1_J.assign(PPC=None)
                    df_050_059_EC_I1_J  = df_050_059_EC_I1_J.assign(Total=None)
                    df_050_059_EC_I1_J ['Wt Range'] = listwtrange
                    df_050_059_EC_I1_J ['Company'] = listcom
                    df_050_059_EC_I1_J ['Shape'] = listshap
                    df_050_059_EC_I1_J ['Carat'] = listcar
                    df_050_059_EC_I1_J ['Color'] = listcol
                    df_050_059_EC_I1_J ['Clarity'] = listclar
                    df_050_059_EC_I1_J ['Cut'] = listcut
                    df_050_059_EC_I1_J ['Polish'] = listpol
                    df_050_059_EC_I1_J ['Symmetry'] = listsym
                    df_050_059_EC_I1_J ['Ratio'] = listrat
                    df_050_059_EC_I1_J ['PPC'] = listdesc
                    df_050_059_EC_I1_J ['Total'] = listtotal
                    df_050_059_EC_I1_J['Carat'] = df_050_059_EC_I1_J['Carat'].astype('float64')
                    df_050_059_EC_I1_J['PPC'] = df_050_059_EC_I1_J['PPC'].astype('float64')
                    df_050_059_EC_I1_J['Total'] = df_050_059_EC_I1_J['Total'].astype('float64')
                    df_050_059_EC_I1_J['Total'] = df_050_059_EC_I1_J['Carat'] * df_050_059_EC_I1_J['PPC']


                elif i=="J"  and j == "I2" and k == "EC":
                    df_050_059_EC_I2_J = pd.DataFrame()
                    df_050_059_EC_I2_J ['Wt Range'] = None
                    df_050_059_EC_I2_J  = df_050_059_EC_I2_J.assign(Company=None)
                    df_050_059_EC_I2_J  = df_050_059_EC_I2_J.assign(Shape=None)
                    df_050_059_EC_I2_J  = df_050_059_EC_I2_J.assign(Carat=None)
                    df_050_059_EC_I2_J  = df_050_059_EC_I2_J.assign(Color=None)
                    df_050_059_EC_I2_J  = df_050_059_EC_I2_J.assign(Clarity=None)
                    df_050_059_EC_I2_J  = df_050_059_EC_I2_J.assign(Cut=None)
                    df_050_059_EC_I2_J  = df_050_059_EC_I2_J.assign(Polish=None)
                    df_050_059_EC_I2_J  = df_050_059_EC_I2_J.assign(Symmetry=None)
                    df_050_059_EC_I2_J  = df_050_059_EC_I2_J.assign(Ratio=None)
                    df_050_059_EC_I2_J  = df_050_059_EC_I2_J.assign(PPC=None)
                    df_050_059_EC_I2_J  = df_050_059_EC_I2_J.assign(Total=None)
                    df_050_059_EC_I2_J ['Wt Range'] = listwtrange
                    df_050_059_EC_I2_J ['Company'] = listcom
                    df_050_059_EC_I2_J ['Shape'] = listshap
                    df_050_059_EC_I2_J ['Carat'] = listcar
                    df_050_059_EC_I2_J ['Color'] = listcol
                    df_050_059_EC_I2_J ['Clarity'] = listclar
                    df_050_059_EC_I2_J ['Cut'] = listcut
                    df_050_059_EC_I2_J ['Polish'] = listpol
                    df_050_059_EC_I2_J ['Symmetry'] = listsym
                    df_050_059_EC_I2_J ['Ratio'] = listrat
                    df_050_059_EC_I2_J ['PPC'] = listdesc
                    df_050_059_EC_I2_J ['Total'] = listtotal
                    df_050_059_EC_I2_J['Carat'] = df_050_059_EC_I2_J['Carat'].astype('float64')
                    df_050_059_EC_I2_J['PPC'] = df_050_059_EC_I2_J['PPC'].astype('float64')
                    df_050_059_EC_I2_J['Total'] = df_050_059_EC_I2_J['Total'].astype('float64')
                    df_050_059_EC_I2_J['Total'] = df_050_059_EC_I2_J['Carat'] * df_050_059_EC_I2_J['PPC']


                elif i=="K" and j == "IF" and k == "EC":
                    df_050_059_EC_IF_K = pd.DataFrame()
                    df_050_059_EC_IF_K ['Wt Range'] = None
                    df_050_059_EC_IF_K  = df_050_059_EC_IF_K.assign(Company=None)
                    df_050_059_EC_IF_K  = df_050_059_EC_IF_K.assign(Shape=None)
                    df_050_059_EC_IF_K  = df_050_059_EC_IF_K.assign(Carat=None)
                    df_050_059_EC_IF_K  = df_050_059_EC_IF_K.assign(Color=None)
                    df_050_059_EC_IF_K  = df_050_059_EC_IF_K.assign(Clarity=None)
                    df_050_059_EC_IF_K  = df_050_059_EC_IF_K.assign(Cut=None)
                    df_050_059_EC_IF_K  = df_050_059_EC_IF_K.assign(Polish=None)
                    df_050_059_EC_IF_K  = df_050_059_EC_IF_K.assign(Symmetry=None)
                    df_050_059_EC_IF_K  = df_050_059_EC_IF_K.assign(Ratio=None)
                    df_050_059_EC_IF_K  = df_050_059_EC_IF_K.assign(PPC=None)
                    df_050_059_EC_IF_K  = df_050_059_EC_IF_K.assign(Total=None)
                    df_050_059_EC_IF_K ['Wt Range'] = listwtrange
                    df_050_059_EC_IF_K ['Company'] = listcom
                    df_050_059_EC_IF_K ['Shape'] = listshap
                    df_050_059_EC_IF_K ['Carat'] = listcar
                    df_050_059_EC_IF_K ['Color'] = listcol
                    df_050_059_EC_IF_K ['Clarity'] = listclar
                    df_050_059_EC_IF_K ['Cut'] = listcut
                    df_050_059_EC_IF_K ['Polish'] = listpol
                    df_050_059_EC_IF_K ['Symmetry'] = listsym
                    df_050_059_EC_IF_K ['Ratio'] = listrat
                    df_050_059_EC_IF_K ['PPC'] = listdesc
                    df_050_059_EC_IF_K ['Total'] = listtotal
                    df_050_059_EC_IF_K['Carat'] = df_050_059_EC_IF_K['Carat'].astype('float64')
                    df_050_059_EC_IF_K['PPC'] = df_050_059_EC_IF_K['PPC'].astype('float64')
                    df_050_059_EC_IF_K['Total'] = df_050_059_EC_IF_K['Total'].astype('float64')
                    df_050_059_EC_IF_K['Total'] = df_050_059_EC_IF_K['Carat'] * df_050_059_EC_IF_K['PPC']



                elif i=="K" and j == "VVS1" and k == "EC":
                    df_050_059_EC_VVS1_K = pd.DataFrame()
                    df_050_059_EC_VVS1_K ['Wt Range'] = None
                    df_050_059_EC_VVS1_K  = df_050_059_EC_VVS1_K.assign(Company=None)
                    df_050_059_EC_VVS1_K  = df_050_059_EC_VVS1_K.assign(Shape=None)
                    df_050_059_EC_VVS1_K  = df_050_059_EC_VVS1_K.assign(Carat=None)
                    df_050_059_EC_VVS1_K  = df_050_059_EC_VVS1_K.assign(Color=None)
                    df_050_059_EC_VVS1_K  = df_050_059_EC_VVS1_K.assign(Clarity=None)
                    df_050_059_EC_VVS1_K  = df_050_059_EC_VVS1_K.assign(Cut=None)
                    df_050_059_EC_VVS1_K  = df_050_059_EC_VVS1_K.assign(Polish=None)
                    df_050_059_EC_VVS1_K  = df_050_059_EC_VVS1_K.assign(Symmetry=None)
                    df_050_059_EC_VVS1_K  = df_050_059_EC_VVS1_K.assign(Ratio=None)
                    df_050_059_EC_VVS1_K  = df_050_059_EC_VVS1_K.assign(PPC=None)
                    df_050_059_EC_VVS1_K  = df_050_059_EC_VVS1_K.assign(Total=None)
                    df_050_059_EC_VVS1_K ['Wt Range'] = listwtrange
                    df_050_059_EC_VVS1_K ['Company'] = listcom
                    df_050_059_EC_VVS1_K ['Shape'] = listshap
                    df_050_059_EC_VVS1_K ['Carat'] = listcar
                    df_050_059_EC_VVS1_K ['Color'] = listcol
                    df_050_059_EC_VVS1_K ['Clarity'] = listclar
                    df_050_059_EC_VVS1_K ['Cut'] = listcut
                    df_050_059_EC_VVS1_K ['Polish'] = listpol
                    df_050_059_EC_VVS1_K ['Symmetry'] = listsym
                    df_050_059_EC_VVS1_K ['Ratio'] = listrat
                    df_050_059_EC_VVS1_K ['PPC'] = listdesc
                    df_050_059_EC_VVS1_K ['Total'] = listtotal
                    df_050_059_EC_VVS1_K['Carat'] = df_050_059_EC_VVS1_K['Carat'].astype('float64')
                    df_050_059_EC_VVS1_K['PPC'] = df_050_059_EC_VVS1_K['PPC'].astype('float64')
                    df_050_059_EC_VVS1_K['Total'] = df_050_059_EC_VVS1_K['Total'].astype('float64')
                    df_050_059_EC_VVS1_K['Total'] = df_050_059_EC_VVS1_K['Carat'] * df_050_059_EC_VVS1_K['PPC']


                elif i=="K" and j == "VVS2" and k == "EC":
                    df_050_059_EC_VVS2_K = pd.DataFrame()
                    df_050_059_EC_VVS2_K ['Wt Range'] = None
                    df_050_059_EC_VVS2_K  = df_050_059_EC_VVS2_K.assign(Company=None)
                    df_050_059_EC_VVS2_K  = df_050_059_EC_VVS2_K.assign(Shape=None)
                    df_050_059_EC_VVS2_K  = df_050_059_EC_VVS2_K.assign(Carat=None)
                    df_050_059_EC_VVS2_K  = df_050_059_EC_VVS2_K.assign(Color=None)
                    df_050_059_EC_VVS2_K  = df_050_059_EC_VVS2_K.assign(Clarity=None)
                    df_050_059_EC_VVS2_K  = df_050_059_EC_VVS2_K.assign(Cut=None)
                    df_050_059_EC_VVS2_K  = df_050_059_EC_VVS2_K.assign(Polish=None)
                    df_050_059_EC_VVS2_K  = df_050_059_EC_VVS2_K.assign(Symmetry=None)
                    df_050_059_EC_VVS2_K  = df_050_059_EC_VVS2_K.assign(Ratio=None)
                    df_050_059_EC_VVS2_K  = df_050_059_EC_VVS2_K.assign(PPC=None)
                    df_050_059_EC_VVS2_K  = df_050_059_EC_VVS2_K.assign(Total=None)
                    df_050_059_EC_VVS2_K ['Wt Range'] = listwtrange
                    df_050_059_EC_VVS2_K ['Company'] = listcom
                    df_050_059_EC_VVS2_K ['Shape'] = listshap
                    df_050_059_EC_VVS2_K ['Carat'] = listcar
                    df_050_059_EC_VVS2_K ['Color'] = listcol
                    df_050_059_EC_VVS2_K ['Clarity'] = listclar
                    df_050_059_EC_VVS2_K ['Cut'] = listcut
                    df_050_059_EC_VVS2_K ['Polish'] = listpol
                    df_050_059_EC_VVS2_K ['Symmetry'] = listsym
                    df_050_059_EC_VVS2_K ['Ratio'] = listrat
                    df_050_059_EC_VVS2_K ['PPC'] = listdesc
                    df_050_059_EC_VVS2_K ['Total'] = listtotal
                    df_050_059_EC_VVS2_K['Carat'] = df_050_059_EC_VVS2_K['Carat'].astype('float64')
                    df_050_059_EC_VVS2_K['PPC'] = df_050_059_EC_VVS2_K['PPC'].astype('float64')
                    df_050_059_EC_VVS2_K['Total'] = df_050_059_EC_VVS2_K['Total'].astype('float64')
                    df_050_059_EC_VVS2_K['Total'] = df_050_059_EC_VVS2_K['Carat'] * df_050_059_EC_VVS2_K['PPC']


                elif i=="K" and j=="VS1" and k == "EC":
                    df_050_059_EC_VS1_K = pd.DataFrame()
                    df_050_059_EC_VS1_K ['Wt Range'] = None
                    df_050_059_EC_VS1_K  = df_050_059_EC_VS1_K.assign(Company=None)
                    df_050_059_EC_VS1_K  = df_050_059_EC_VS1_K.assign(Shape=None)
                    df_050_059_EC_VS1_K  = df_050_059_EC_VS1_K.assign(Carat=None)
                    df_050_059_EC_VS1_K  = df_050_059_EC_VS1_K.assign(Color=None)
                    df_050_059_EC_VS1_K  = df_050_059_EC_VS1_K.assign(Clarity=None)
                    df_050_059_EC_VS1_K  = df_050_059_EC_VS1_K.assign(Cut=None)
                    df_050_059_EC_VS1_K  = df_050_059_EC_VS1_K.assign(Polish=None)
                    df_050_059_EC_VS1_K  = df_050_059_EC_VS1_K.assign(Symmetry=None)
                    df_050_059_EC_VS1_K  = df_050_059_EC_VS1_K.assign(Ratio=None)
                    df_050_059_EC_VS1_K  = df_050_059_EC_VS1_K.assign(PPC=None)
                    df_050_059_EC_VS1_K  = df_050_059_EC_VS1_K.assign(Total=None)
                    df_050_059_EC_VS1_K ['Wt Range'] = listwtrange
                    df_050_059_EC_VS1_K ['Company'] = listcom
                    df_050_059_EC_VS1_K ['Shape'] = listshap
                    df_050_059_EC_VS1_K ['Carat'] = listcar
                    df_050_059_EC_VS1_K ['Color'] = listcol
                    df_050_059_EC_VS1_K ['Clarity'] = listclar
                    df_050_059_EC_VS1_K ['Cut'] = listcut
                    df_050_059_EC_VS1_K ['Polish'] = listpol
                    df_050_059_EC_VS1_K ['Symmetry'] = listsym
                    df_050_059_EC_VS1_K ['Ratio'] = listrat
                    df_050_059_EC_VS1_K ['PPC'] = listdesc
                    df_050_059_EC_VS1_K ['Total'] = listtotal
                    df_050_059_EC_VS1_K['Carat'] = df_050_059_EC_VS1_K['Carat'].astype('float64')
                    df_050_059_EC_VS1_K['PPC'] = df_050_059_EC_VS1_K['PPC'].astype('float64')
                    df_050_059_EC_VS1_K['Total'] = df_050_059_EC_VS1_K['Total'].astype('float64')
                    df_050_059_EC_VS1_K['Total'] = df_050_059_EC_VS1_K['Carat'] * df_050_059_EC_VS1_K['PPC']


                elif i=="K" and j == "VS2" and k == "EC":
                    df_050_059_EC_VS2_K = pd.DataFrame()
                    df_050_059_EC_VS2_K ['Wt Range'] = None
                    df_050_059_EC_VS2_K  = df_050_059_EC_VS2_K.assign(Company=None)
                    df_050_059_EC_VS2_K  = df_050_059_EC_VS2_K.assign(Shape=None)
                    df_050_059_EC_VS2_K  = df_050_059_EC_VS2_K.assign(Carat=None)
                    df_050_059_EC_VS2_K  = df_050_059_EC_VS2_K.assign(Color=None)
                    df_050_059_EC_VS2_K  = df_050_059_EC_VS2_K.assign(Clarity=None)
                    df_050_059_EC_VS2_K  = df_050_059_EC_VS2_K.assign(Cut=None)
                    df_050_059_EC_VS2_K  = df_050_059_EC_VS2_K.assign(Polish=None)
                    df_050_059_EC_VS2_K  = df_050_059_EC_VS2_K.assign(Symmetry=None)
                    df_050_059_EC_VS2_K  = df_050_059_EC_VS2_K.assign(Ratio=None)
                    df_050_059_EC_VS2_K  = df_050_059_EC_VS2_K.assign(PPC=None)
                    df_050_059_EC_VS2_K  = df_050_059_EC_VS2_K.assign(Total=None)
                    df_050_059_EC_VS2_K ['Wt Range'] = listwtrange
                    df_050_059_EC_VS2_K ['Company'] = listcom
                    df_050_059_EC_VS2_K ['Shape'] = listshap
                    df_050_059_EC_VS2_K ['Carat'] = listcar
                    df_050_059_EC_VS2_K ['Color'] = listcol
                    df_050_059_EC_VS2_K ['Clarity'] = listclar
                    df_050_059_EC_VS2_K ['Cut'] = listcut
                    df_050_059_EC_VS2_K ['Polish'] = listpol
                    df_050_059_EC_VS2_K ['Symmetry'] = listsym
                    df_050_059_EC_VS2_K ['Ratio'] = listrat
                    df_050_059_EC_VS2_K ['PPC'] = listdesc
                    df_050_059_EC_VS2_K ['Total'] = listtotal
                    df_050_059_EC_VS2_K['Carat'] = df_050_059_EC_VS2_K['Carat'].astype('float64')
                    df_050_059_EC_VS2_K['PPC'] = df_050_059_EC_VS2_K['PPC'].astype('float64')
                    df_050_059_EC_VS2_K['Total'] = df_050_059_EC_VS2_K['Total'].astype('float64')
                    df_050_059_EC_VS2_K['Total'] = df_050_059_EC_VS2_K['Carat'] * df_050_059_EC_VS2_K['PPC']


                elif i=="K" and j == "SI1" and k == "EC":
                    df_050_059_EC_SI1_K = pd.DataFrame()
                    df_050_059_EC_SI1_K ['Wt Range'] = None
                    df_050_059_EC_SI1_K  = df_050_059_EC_SI1_K.assign(Company=None)
                    df_050_059_EC_SI1_K  = df_050_059_EC_SI1_K.assign(Shape=None)
                    df_050_059_EC_SI1_K  = df_050_059_EC_SI1_K.assign(Carat=None)
                    df_050_059_EC_SI1_K  = df_050_059_EC_SI1_K.assign(Color=None)
                    df_050_059_EC_SI1_K  = df_050_059_EC_SI1_K.assign(Clarity=None)
                    df_050_059_EC_SI1_K  = df_050_059_EC_SI1_K.assign(Cut=None)
                    df_050_059_EC_SI1_K  = df_050_059_EC_SI1_K.assign(Polish=None)
                    df_050_059_EC_SI1_K  = df_050_059_EC_SI1_K.assign(Symmetry=None)
                    df_050_059_EC_SI1_K  = df_050_059_EC_SI1_K.assign(Ratio=None)
                    df_050_059_EC_SI1_K  = df_050_059_EC_SI1_K.assign(PPC=None)
                    df_050_059_EC_SI1_K  = df_050_059_EC_SI1_K.assign(Total=None)
                    df_050_059_EC_SI1_K ['Wt Range'] = listwtrange
                    df_050_059_EC_SI1_K ['Company'] = listcom
                    df_050_059_EC_SI1_K ['Shape'] = listshap
                    df_050_059_EC_SI1_K ['Carat'] = listcar
                    df_050_059_EC_SI1_K ['Color'] = listcol
                    df_050_059_EC_SI1_K ['Clarity'] = listclar
                    df_050_059_EC_SI1_K ['Cut'] = listcut
                    df_050_059_EC_SI1_K ['Polish'] = listpol
                    df_050_059_EC_SI1_K ['Symmetry'] = listsym
                    df_050_059_EC_SI1_K ['Ratio'] = listrat
                    df_050_059_EC_SI1_K ['PPC'] = listdesc
                    df_050_059_EC_SI1_K ['Total'] = listtotal
                    df_050_059_EC_SI1_K['Carat'] = df_050_059_EC_SI1_K['Carat'].astype('float64')
                    df_050_059_EC_SI1_K['PPC'] = df_050_059_EC_SI1_K['PPC'].astype('float64')
                    df_050_059_EC_SI1_K['Total'] = df_050_059_EC_SI1_K['Total'].astype('float64')
                    df_050_059_EC_SI1_K['Total'] = df_050_059_EC_SI1_K['Carat'] * df_050_059_EC_SI1_K['PPC']


                elif i=="K" and j == "SI2" and k == "EC":
                    df_050_059_EC_SI2_K = pd.DataFrame()
                    df_050_059_EC_SI2_K ['Wt Range'] = None
                    df_050_059_EC_SI2_K  = df_050_059_EC_SI2_K.assign(Company=None)
                    df_050_059_EC_SI2_K  = df_050_059_EC_SI2_K.assign(Shape=None)
                    df_050_059_EC_SI2_K  = df_050_059_EC_SI2_K.assign(Carat=None)
                    df_050_059_EC_SI2_K  = df_050_059_EC_SI2_K.assign(Color=None)
                    df_050_059_EC_SI2_K  = df_050_059_EC_SI2_K.assign(Clarity=None)
                    df_050_059_EC_SI2_K  = df_050_059_EC_SI2_K.assign(Cut=None)
                    df_050_059_EC_SI2_K  = df_050_059_EC_SI2_K.assign(Polish=None)
                    df_050_059_EC_SI2_K  = df_050_059_EC_SI2_K.assign(Symmetry=None)
                    df_050_059_EC_SI2_K  = df_050_059_EC_SI2_K.assign(Ratio=None)
                    df_050_059_EC_SI2_K  = df_050_059_EC_SI2_K.assign(PPC=None)
                    df_050_059_EC_SI2_K  = df_050_059_EC_SI2_K.assign(Total=None)
                    df_050_059_EC_SI2_K ['Wt Range'] = listwtrange
                    df_050_059_EC_SI2_K ['Company'] = listcom
                    df_050_059_EC_SI2_K ['Shape'] = listshap
                    df_050_059_EC_SI2_K ['Carat'] = listcar
                    df_050_059_EC_SI2_K ['Color'] = listcol
                    df_050_059_EC_SI2_K ['Clarity'] = listclar
                    df_050_059_EC_SI2_K ['Cut'] = listcut
                    df_050_059_EC_SI2_K ['Polish'] = listpol
                    df_050_059_EC_SI2_K ['Symmetry'] = listsym
                    df_050_059_EC_SI2_K ['Ratio'] = listrat
                    df_050_059_EC_SI2_K ['PPC'] = listdesc
                    df_050_059_EC_SI2_K ['Total'] = listtotal
                    df_050_059_EC_SI2_K['Carat'] = df_050_059_EC_SI2_K['Carat'].astype('float64')
                    df_050_059_EC_SI2_K['PPC'] = df_050_059_EC_SI2_K['PPC'].astype('float64')
                    df_050_059_EC_SI2_K['Total'] = df_050_059_EC_SI2_K['Total'].astype('float64')
                    df_050_059_EC_SI2_K['Total'] = df_050_059_EC_SI2_K['Carat'] * df_050_059_EC_SI2_K['PPC']


                elif i=="K" and j == "I1" and k == "EC":
                    df_050_059_EC_I1_K = pd.DataFrame()
                    df_050_059_EC_I1_K ['Wt Range'] = None
                    df_050_059_EC_I1_K  = df_050_059_EC_I1_K.assign(Company=None)
                    df_050_059_EC_I1_K  = df_050_059_EC_I1_K.assign(Shape=None)
                    df_050_059_EC_I1_K  = df_050_059_EC_I1_K.assign(Carat=None)
                    df_050_059_EC_I1_K  = df_050_059_EC_I1_K.assign(Color=None)
                    df_050_059_EC_I1_K  = df_050_059_EC_I1_K.assign(Clarity=None)
                    df_050_059_EC_I1_K  = df_050_059_EC_I1_K.assign(Cut=None)
                    df_050_059_EC_I1_K  = df_050_059_EC_I1_K.assign(Polish=None)
                    df_050_059_EC_I1_K  = df_050_059_EC_I1_K.assign(Symmetry=None)
                    df_050_059_EC_I1_K  = df_050_059_EC_I1_K.assign(Ratio=None)
                    df_050_059_EC_I1_K  = df_050_059_EC_I1_K.assign(PPC=None)
                    df_050_059_EC_I1_K  = df_050_059_EC_I1_K.assign(Total=None)
                    df_050_059_EC_I1_K ['Wt Range'] = listwtrange
                    df_050_059_EC_I1_K ['Company'] = listcom
                    df_050_059_EC_I1_K ['Shape'] = listshap
                    df_050_059_EC_I1_K ['Carat'] = listcar
                    df_050_059_EC_I1_K ['Color'] = listcol
                    df_050_059_EC_I1_K ['Clarity'] = listclar
                    df_050_059_EC_I1_K ['Cut'] = listcut
                    df_050_059_EC_I1_K ['Polish'] = listpol
                    df_050_059_EC_I1_K ['Symmetry'] = listsym
                    df_050_059_EC_I1_K ['Ratio'] = listrat
                    df_050_059_EC_I1_K ['PPC'] = listdesc
                    df_050_059_EC_I1_K ['Total'] = listtotal
                    df_050_059_EC_I1_K['Carat'] = df_050_059_EC_I1_K['Carat'].astype('float64')
                    df_050_059_EC_I1_K['PPC'] = df_050_059_EC_I1_K['PPC'].astype('float64')
                    df_050_059_EC_I1_K['Total'] = df_050_059_EC_I1_K['Total'].astype('float64')
                    df_050_059_EC_I1_K['Total'] = df_050_059_EC_I1_K['Carat'] * df_050_059_EC_I1_K['PPC']


                elif i=="K" and j == "I2" and k == "EC":
                    df_050_059_EC_I2_K = pd.DataFrame()
                    df_050_059_EC_I2_K ['Wt Range'] = None
                    df_050_059_EC_I2_K  = df_050_059_EC_I2_K.assign(Company=None)
                    df_050_059_EC_I2_K  = df_050_059_EC_I2_K.assign(Shape=None)
                    df_050_059_EC_I2_K  = df_050_059_EC_I2_K.assign(Carat=None)
                    df_050_059_EC_I2_K  = df_050_059_EC_I2_K.assign(Color=None)
                    df_050_059_EC_I2_K  = df_050_059_EC_I2_K.assign(Clarity=None)
                    df_050_059_EC_I2_K  = df_050_059_EC_I2_K.assign(Cut=None)
                    df_050_059_EC_I2_K  = df_050_059_EC_I2_K.assign(Polish=None)
                    df_050_059_EC_I2_K  = df_050_059_EC_I2_K.assign(Symmetry=None)
                    df_050_059_EC_I2_K  = df_050_059_EC_I2_K.assign(Ratio=None)
                    df_050_059_EC_I2_K  = df_050_059_EC_I2_K.assign(PPC=None)
                    df_050_059_EC_I2_K  = df_050_059_EC_I2_K.assign(Total=None)
                    df_050_059_EC_I2_K ['Wt Range'] = listwtrange
                    df_050_059_EC_I2_K ['Company'] = listcom
                    df_050_059_EC_I2_K ['Shape'] = listshap
                    df_050_059_EC_I2_K ['Carat'] = listcar
                    df_050_059_EC_I2_K ['Color'] = listcol
                    df_050_059_EC_I2_K ['Clarity'] = listclar
                    df_050_059_EC_I2_K ['Cut'] = listcut
                    df_050_059_EC_I2_K ['Polish'] = listpol
                    df_050_059_EC_I2_K ['Symmetry'] = listsym
                    df_050_059_EC_I2_K ['Ratio'] = listrat
                    df_050_059_EC_I2_K ['PPC'] = listdesc
                    df_050_059_EC_I2_K ['Total'] = listtotal
                    df_050_059_EC_I2_K['Carat'] = df_050_059_EC_I2_K['Carat'].astype('float64')
                    df_050_059_EC_I2_K['PPC'] = df_050_059_EC_I2_K['PPC'].astype('float64')
                    df_050_059_EC_I2_K['Total'] = df_050_059_EC_I2_K['Total'].astype('float64')
                    df_050_059_EC_I2_K['Total'] = df_050_059_EC_I2_K['Carat'] * df_050_059_EC_I2_K['PPC']


                elif i=="L" and j == "IF" and k == "EC":
                    df_050_059_EC_IF_L = pd.DataFrame()
                    df_050_059_EC_IF_L ['Wt Range'] = None
                    df_050_059_EC_IF_L  = df_050_059_EC_IF_L.assign(Company=None)
                    df_050_059_EC_IF_L  = df_050_059_EC_IF_L.assign(Shape=None)
                    df_050_059_EC_IF_L  = df_050_059_EC_IF_L.assign(Carat=None)
                    df_050_059_EC_IF_L  = df_050_059_EC_IF_L.assign(Color=None)
                    df_050_059_EC_IF_L  = df_050_059_EC_IF_L.assign(Clarity=None)
                    df_050_059_EC_IF_L  = df_050_059_EC_IF_L.assign(Cut=None)
                    df_050_059_EC_IF_L  = df_050_059_EC_IF_L.assign(Polish=None)
                    df_050_059_EC_IF_L  = df_050_059_EC_IF_L.assign(Symmetry=None)
                    df_050_059_EC_IF_L  = df_050_059_EC_IF_L.assign(Ratio=None)
                    df_050_059_EC_IF_L  = df_050_059_EC_IF_L.assign(PPC=None)
                    df_050_059_EC_IF_L  = df_050_059_EC_IF_L.assign(Total=None)
                    df_050_059_EC_IF_L ['Wt Range'] = listwtrange
                    df_050_059_EC_IF_L ['Company'] = listcom
                    df_050_059_EC_IF_L ['Shape'] = listshap
                    df_050_059_EC_IF_L ['Carat'] = listcar
                    df_050_059_EC_IF_L ['Color'] = listcol
                    df_050_059_EC_IF_L ['Clarity'] = listclar
                    df_050_059_EC_IF_L ['Cut'] = listcut
                    df_050_059_EC_IF_L ['Polish'] = listpol
                    df_050_059_EC_IF_L ['Symmetry'] = listsym
                    df_050_059_EC_IF_L ['Ratio'] = listrat
                    df_050_059_EC_IF_L ['PPC'] = listdesc
                    df_050_059_EC_IF_L ['Total'] = listtotal
                    df_050_059_EC_IF_L['Carat'] = df_050_059_EC_IF_L['Carat'].astype('float64')
                    df_050_059_EC_IF_L['PPC'] = df_050_059_EC_IF_L['PPC'].astype('float64')
                    df_050_059_EC_IF_L['Total'] = df_050_059_EC_IF_L['Total'].astype('float64')
                    df_050_059_EC_IF_L['Total'] = df_050_059_EC_IF_L['Carat'] * df_050_059_EC_IF_L['PPC']


                elif i=="L" and j == "VVS1" and k == "EC":
                    df_050_059_EC_VVS1_L = pd.DataFrame()
                    df_050_059_EC_VVS1_L ['Wt Range'] = None
                    df_050_059_EC_VVS1_L  = df_050_059_EC_VVS1_L.assign(Company=None)
                    df_050_059_EC_VVS1_L  = df_050_059_EC_VVS1_L.assign(Shape=None)
                    df_050_059_EC_VVS1_L  = df_050_059_EC_VVS1_L.assign(Carat=None)
                    df_050_059_EC_VVS1_L  = df_050_059_EC_VVS1_L.assign(Color=None)
                    df_050_059_EC_VVS1_L  = df_050_059_EC_VVS1_L.assign(Clarity=None)
                    df_050_059_EC_VVS1_L  = df_050_059_EC_VVS1_L.assign(Cut=None)
                    df_050_059_EC_VVS1_L  = df_050_059_EC_VVS1_L.assign(Polish=None)
                    df_050_059_EC_VVS1_L  = df_050_059_EC_VVS1_L.assign(Symmetry=None)
                    df_050_059_EC_VVS1_L  = df_050_059_EC_VVS1_L.assign(Ratio=None)
                    df_050_059_EC_VVS1_L  = df_050_059_EC_VVS1_L.assign(PPC=None)
                    df_050_059_EC_VVS1_L  = df_050_059_EC_VVS1_L.assign(Total=None)
                    df_050_059_EC_VVS1_L ['Wt Range'] = listwtrange
                    df_050_059_EC_VVS1_L ['Company'] = listcom
                    df_050_059_EC_VVS1_L ['Shape'] = listshap
                    df_050_059_EC_VVS1_L ['Carat'] = listcar
                    df_050_059_EC_VVS1_L ['Color'] = listcol
                    df_050_059_EC_VVS1_L ['Clarity'] = listclar
                    df_050_059_EC_VVS1_L ['Cut'] = listcut
                    df_050_059_EC_VVS1_L ['Polish'] = listpol
                    df_050_059_EC_VVS1_L ['Symmetry'] = listsym
                    df_050_059_EC_VVS1_L ['Ratio'] = listrat
                    df_050_059_EC_VVS1_L ['PPC'] = listdesc
                    df_050_059_EC_VVS1_L ['Total'] = listtotal
                    df_050_059_EC_VVS1_L['Carat'] = df_050_059_EC_VVS1_L['Carat'].astype('float64')
                    df_050_059_EC_VVS1_L['PPC'] = df_050_059_EC_VVS1_L['PPC'].astype('float64')
                    df_050_059_EC_VVS1_L['Total'] = df_050_059_EC_VVS1_L['Total'].astype('float64')
                    df_050_059_EC_VVS1_L['Total'] = df_050_059_EC_VVS1_L['Carat'] * df_050_059_EC_VVS1_L['PPC']


                elif i=="L" and j == "VVS2" and k == "EC":
                    df_050_059_EC_VVS2_L = pd.DataFrame()
                    df_050_059_EC_VVS2_L ['Wt Range'] = None
                    df_050_059_EC_VVS2_L  = df_050_059_EC_VVS2_L.assign(Company=None)
                    df_050_059_EC_VVS2_L  = df_050_059_EC_VVS2_L.assign(Shape=None)
                    df_050_059_EC_VVS2_L  = df_050_059_EC_VVS2_L.assign(Carat=None)
                    df_050_059_EC_VVS2_L  = df_050_059_EC_VVS2_L.assign(Color=None)
                    df_050_059_EC_VVS2_L  = df_050_059_EC_VVS2_L.assign(Clarity=None)
                    df_050_059_EC_VVS2_L  = df_050_059_EC_VVS2_L.assign(Cut=None)
                    df_050_059_EC_VVS2_L  = df_050_059_EC_VVS2_L.assign(Polish=None)
                    df_050_059_EC_VVS2_L  = df_050_059_EC_VVS2_L.assign(Symmetry=None)
                    df_050_059_EC_VVS2_L  = df_050_059_EC_VVS2_L.assign(Ratio=None)
                    df_050_059_EC_VVS2_L  = df_050_059_EC_VVS2_L.assign(PPC=None)
                    df_050_059_EC_VVS2_L  = df_050_059_EC_VVS2_L.assign(Total=None)
                    df_050_059_EC_VVS2_L ['Wt Range'] = listwtrange
                    df_050_059_EC_VVS2_L ['Company'] = listcom
                    df_050_059_EC_VVS2_L ['Shape'] = listshap
                    df_050_059_EC_VVS2_L ['Carat'] = listcar
                    df_050_059_EC_VVS2_L ['Color'] = listcol
                    df_050_059_EC_VVS2_L ['Clarity'] = listclar
                    df_050_059_EC_VVS2_L ['Cut'] = listcut
                    df_050_059_EC_VVS2_L ['Polish'] = listpol
                    df_050_059_EC_VVS2_L ['Symmetry'] = listsym
                    df_050_059_EC_VVS2_L ['Ratio'] = listrat
                    df_050_059_EC_VVS2_L ['PPC'] = listdesc
                    df_050_059_EC_VVS2_L ['Total'] = listtotal
                    df_050_059_EC_VVS2_L['Carat'] = df_050_059_EC_VVS2_L['Carat'].astype('float64')
                    df_050_059_EC_VVS2_L['PPC'] = df_050_059_EC_VVS2_L['PPC'].astype('float64')
                    df_050_059_EC_VVS2_L['Total'] = df_050_059_EC_VVS2_L['Total'].astype('float64')
                    df_050_059_EC_VVS2_L['Total'] = df_050_059_EC_VVS2_L['Carat'] * df_050_059_EC_VVS2_L['PPC']


                elif i=="L" and j=="VS1" and k == "EC":
                    df_050_059_EC_VS1_L = pd.DataFrame()
                    df_050_059_EC_VS1_L ['Wt Range'] = None
                    df_050_059_EC_VS1_L  = df_050_059_EC_VS1_L.assign(Company=None)
                    df_050_059_EC_VS1_L  = df_050_059_EC_VS1_L.assign(Shape=None)
                    df_050_059_EC_VS1_L  = df_050_059_EC_VS1_L.assign(Carat=None)
                    df_050_059_EC_VS1_L  = df_050_059_EC_VS1_L.assign(Color=None)
                    df_050_059_EC_VS1_L  = df_050_059_EC_VS1_L.assign(Clarity=None)
                    df_050_059_EC_VS1_L  = df_050_059_EC_VS1_L.assign(Cut=None)
                    df_050_059_EC_VS1_L  = df_050_059_EC_VS1_L.assign(Polish=None)
                    df_050_059_EC_VS1_L  = df_050_059_EC_VS1_L.assign(Symmetry=None)
                    df_050_059_EC_VS1_L  = df_050_059_EC_VS1_L.assign(Ratio=None)
                    df_050_059_EC_VS1_L  = df_050_059_EC_VS1_L.assign(PPC=None)
                    df_050_059_EC_VS1_L  = df_050_059_EC_VS1_L.assign(Total=None)
                    df_050_059_EC_VS1_L ['Wt Range'] = listwtrange
                    df_050_059_EC_VS1_L ['Company'] = listcom
                    df_050_059_EC_VS1_L ['Shape'] = listshap
                    df_050_059_EC_VS1_L ['Carat'] = listcar
                    df_050_059_EC_VS1_L ['Color'] = listcol
                    df_050_059_EC_VS1_L ['Clarity'] = listclar
                    df_050_059_EC_VS1_L ['Cut'] = listcut
                    df_050_059_EC_VS1_L ['Polish'] = listpol
                    df_050_059_EC_VS1_L ['Symmetry'] = listsym
                    df_050_059_EC_VS1_L ['Ratio'] = listrat
                    df_050_059_EC_VS1_L ['PPC'] = listdesc
                    df_050_059_EC_VS1_L ['Total'] = listtotal
                    df_050_059_EC_VS1_L['Carat'] = df_050_059_EC_VS1_L['Carat'].astype('float64')
                    df_050_059_EC_VS1_L['PPC'] = df_050_059_EC_VS1_L['PPC'].astype('float64')
                    df_050_059_EC_VS1_L['Total'] = df_050_059_EC_VS1_L['Total'].astype('float64')
                    df_050_059_EC_VS1_L['Total'] = df_050_059_EC_VS1_L['Carat'] * df_050_059_EC_VS1_L['PPC']


                elif i=="L" and j == "VS2" and k == "EC":
                    df_050_059_EC_VS2_L = pd.DataFrame()
                    df_050_059_EC_VS2_L ['Wt Range'] = None
                    df_050_059_EC_VS2_L  = df_050_059_EC_VS2_L.assign(Company=None)
                    df_050_059_EC_VS2_L  = df_050_059_EC_VS2_L.assign(Shape=None)
                    df_050_059_EC_VS2_L  = df_050_059_EC_VS2_L.assign(Carat=None)
                    df_050_059_EC_VS2_L  = df_050_059_EC_VS2_L.assign(Color=None)
                    df_050_059_EC_VS2_L  = df_050_059_EC_VS2_L.assign(Clarity=None)
                    df_050_059_EC_VS2_L  = df_050_059_EC_VS2_L.assign(Cut=None)
                    df_050_059_EC_VS2_L  = df_050_059_EC_VS2_L.assign(Polish=None)
                    df_050_059_EC_VS2_L  = df_050_059_EC_VS2_L.assign(Symmetry=None)
                    df_050_059_EC_VS2_L  = df_050_059_EC_VS2_L.assign(Ratio=None)
                    df_050_059_EC_VS2_L  = df_050_059_EC_VS2_L.assign(PPC=None)
                    df_050_059_EC_VS2_L  = df_050_059_EC_VS2_L.assign(Total=None)
                    df_050_059_EC_VS2_L ['Wt Range'] = listwtrange
                    df_050_059_EC_VS2_L ['Company'] = listcom
                    df_050_059_EC_VS2_L ['Shape'] = listshap
                    df_050_059_EC_VS2_L ['Carat'] = listcar
                    df_050_059_EC_VS2_L ['Color'] = listcol
                    df_050_059_EC_VS2_L ['Clarity'] = listclar
                    df_050_059_EC_VS2_L ['Cut'] = listcut
                    df_050_059_EC_VS2_L ['Polish'] = listpol
                    df_050_059_EC_VS2_L ['Symmetry'] = listsym
                    df_050_059_EC_VS2_L ['Ratio'] = listrat
                    df_050_059_EC_VS2_L ['PPC'] = listdesc
                    df_050_059_EC_VS2_L ['Total'] = listtotal
                    df_050_059_EC_VS2_L['Carat'] = df_050_059_EC_VS2_L['Carat'].astype('float64')
                    df_050_059_EC_VS2_L['PPC'] = df_050_059_EC_VS2_L['PPC'].astype('float64')
                    df_050_059_EC_VS2_L['Total'] = df_050_059_EC_VS2_L['Total'].astype('float64')
                    df_050_059_EC_VS2_L['Total'] = df_050_059_EC_VS2_L['Carat'] * df_050_059_EC_VS2_L['PPC']


                elif i=="L" and j == "SI1" and k == "EC":
                    df_050_059_EC_SI1_L = pd.DataFrame()
                    df_050_059_EC_SI1_L ['Wt Range'] = None
                    df_050_059_EC_SI1_L  = df_050_059_EC_SI1_L.assign(Company=None)
                    df_050_059_EC_SI1_L  = df_050_059_EC_SI1_L.assign(Shape=None)
                    df_050_059_EC_SI1_L  = df_050_059_EC_SI1_L.assign(Carat=None)
                    df_050_059_EC_SI1_L  = df_050_059_EC_SI1_L.assign(Color=None)
                    df_050_059_EC_SI1_L  = df_050_059_EC_SI1_L.assign(Clarity=None)
                    df_050_059_EC_SI1_L  = df_050_059_EC_SI1_L.assign(Cut=None)
                    df_050_059_EC_SI1_L  = df_050_059_EC_SI1_L.assign(Polish=None)
                    df_050_059_EC_SI1_L  = df_050_059_EC_SI1_L.assign(Symmetry=None)
                    df_050_059_EC_SI1_L  = df_050_059_EC_SI1_L.assign(Ratio=None)
                    df_050_059_EC_SI1_L  = df_050_059_EC_SI1_L.assign(PPC=None)
                    df_050_059_EC_SI1_L  = df_050_059_EC_SI1_L.assign(Total=None)
                    df_050_059_EC_SI1_L ['Wt Range'] = listwtrange
                    df_050_059_EC_SI1_L ['Company'] = listcom
                    df_050_059_EC_SI1_L ['Shape'] = listshap
                    df_050_059_EC_SI1_L ['Carat'] = listcar
                    df_050_059_EC_SI1_L ['Color'] = listcol
                    df_050_059_EC_SI1_L ['Clarity'] = listclar
                    df_050_059_EC_SI1_L ['Cut'] = listcut
                    df_050_059_EC_SI1_L ['Polish'] = listpol
                    df_050_059_EC_SI1_L ['Symmetry'] = listsym
                    df_050_059_EC_SI1_L ['Ratio'] = listrat
                    df_050_059_EC_SI1_L ['PPC'] = listdesc
                    df_050_059_EC_SI1_L ['Total'] = listtotal
                    df_050_059_EC_SI1_L['Carat'] = df_050_059_EC_SI1_L['Carat'].astype('float64')
                    df_050_059_EC_SI1_L['PPC'] = df_050_059_EC_SI1_L['PPC'].astype('float64')
                    df_050_059_EC_SI1_L['Total'] = df_050_059_EC_SI1_L['Total'].astype('float64')
                    df_050_059_EC_SI1_L['Total'] = df_050_059_EC_SI1_L['Carat'] * df_050_059_EC_SI1_L['PPC']


                elif i=="L" and j == "SI2" and k == "EC":
                    df_050_059_EC_SI2_L = pd.DataFrame()
                    df_050_059_EC_SI2_L ['Wt Range'] = None
                    df_050_059_EC_SI2_L  = df_050_059_EC_SI2_L.assign(Company=None)
                    df_050_059_EC_SI2_L  = df_050_059_EC_SI2_L.assign(Shape=None)
                    df_050_059_EC_SI2_L  = df_050_059_EC_SI2_L.assign(Carat=None)
                    df_050_059_EC_SI2_L  = df_050_059_EC_SI2_L.assign(Color=None)
                    df_050_059_EC_SI2_L  = df_050_059_EC_SI2_L.assign(Clarity=None)
                    df_050_059_EC_SI2_L  = df_050_059_EC_SI2_L.assign(Cut=None)
                    df_050_059_EC_SI2_L  = df_050_059_EC_SI2_L.assign(Polish=None)
                    df_050_059_EC_SI2_L  = df_050_059_EC_SI2_L.assign(Symmetry=None)
                    df_050_059_EC_SI2_L  = df_050_059_EC_SI2_L.assign(Ratio=None)
                    df_050_059_EC_SI2_L  = df_050_059_EC_SI2_L.assign(PPC=None)
                    df_050_059_EC_SI2_L  = df_050_059_EC_SI2_L.assign(Total=None)
                    df_050_059_EC_SI2_L ['Wt Range'] = listwtrange
                    df_050_059_EC_SI2_L ['Company'] = listcom
                    df_050_059_EC_SI2_L ['Shape'] = listshap
                    df_050_059_EC_SI2_L ['Carat'] = listcar
                    df_050_059_EC_SI2_L ['Color'] = listcol
                    df_050_059_EC_SI2_L ['Clarity'] = listclar
                    df_050_059_EC_SI2_L ['Cut'] = listcut
                    df_050_059_EC_SI2_L ['Polish'] = listpol
                    df_050_059_EC_SI2_L ['Symmetry'] = listsym
                    df_050_059_EC_SI2_L ['Ratio'] = listrat
                    df_050_059_EC_SI2_L ['PPC'] = listdesc
                    df_050_059_EC_SI2_L ['Total'] = listtotal
                    df_050_059_EC_SI2_L['Carat'] = df_050_059_EC_SI2_L['Carat'].astype('float64')
                    df_050_059_EC_SI2_L['PPC'] = df_050_059_EC_SI2_L['PPC'].astype('float64')
                    df_050_059_EC_SI2_L['Total'] = df_050_059_EC_SI2_L['Total'].astype('float64')
                    df_050_059_EC_SI2_L['Total'] = df_050_059_EC_SI2_L['Carat'] * df_050_059_EC_SI2_L['PPC']


                elif i=="L" and j == "I1" and k == "EC":
                    df_050_059_EC_I1_L = pd.DataFrame()
                    df_050_059_EC_I1_L ['Wt Range'] = None
                    df_050_059_EC_I1_L  = df_050_059_EC_I1_L.assign(Company=None)
                    df_050_059_EC_I1_L  = df_050_059_EC_I1_L.assign(Shape=None)
                    df_050_059_EC_I1_L  = df_050_059_EC_I1_L.assign(Carat=None)
                    df_050_059_EC_I1_L  = df_050_059_EC_I1_L.assign(Color=None)
                    df_050_059_EC_I1_L  = df_050_059_EC_I1_L.assign(Clarity=None)
                    df_050_059_EC_I1_L  = df_050_059_EC_I1_L.assign(Cut=None)
                    df_050_059_EC_I1_L  = df_050_059_EC_I1_L.assign(Polish=None)
                    df_050_059_EC_I1_L  = df_050_059_EC_I1_L.assign(Symmetry=None)
                    df_050_059_EC_I1_L  = df_050_059_EC_I1_L.assign(Ratio=None)
                    df_050_059_EC_I1_L  = df_050_059_EC_I1_L.assign(PPC=None)
                    df_050_059_EC_I1_L  = df_050_059_EC_I1_L.assign(Total=None)
                    df_050_059_EC_I1_L ['Wt Range'] = listwtrange
                    df_050_059_EC_I1_L ['Company'] = listcom
                    df_050_059_EC_I1_L ['Shape'] = listshap
                    df_050_059_EC_I1_L ['Carat'] = listcar
                    df_050_059_EC_I1_L ['Color'] = listcol
                    df_050_059_EC_I1_L ['Clarity'] = listclar
                    df_050_059_EC_I1_L ['Cut'] = listcut
                    df_050_059_EC_I1_L ['Polish'] = listpol
                    df_050_059_EC_I1_L ['Symmetry'] = listsym
                    df_050_059_EC_I1_L ['Ratio'] = listrat
                    df_050_059_EC_I1_L ['PPC'] = listdesc
                    df_050_059_EC_I1_L ['Total'] = listtotal
                    df_050_059_EC_I1_L['Carat'] = df_050_059_EC_I1_L['Carat'].astype('float64')
                    df_050_059_EC_I1_L['PPC'] = df_050_059_EC_I1_L['PPC'].astype('float64')
                    df_050_059_EC_I1_L['Total'] = df_050_059_EC_I1_L['Total'].astype('float64')
                    df_050_059_EC_I1_L['Total'] = df_050_059_EC_I1_L['Carat'] * df_050_059_EC_I1_L['PPC']


                elif i=="L" and j == "I2" and k == "EC":
                    df_050_059_EC_I2_L = pd.DataFrame()
                    df_050_059_EC_I2_L ['Wt Range'] = None
                    df_050_059_EC_I2_L  = df_050_059_EC_I2_L.assign(Company=None)
                    df_050_059_EC_I2_L  = df_050_059_EC_I2_L.assign(Shape=None)
                    df_050_059_EC_I2_L  = df_050_059_EC_I2_L.assign(Carat=None)
                    df_050_059_EC_I2_L  = df_050_059_EC_I2_L.assign(Color=None)
                    df_050_059_EC_I2_L  = df_050_059_EC_I2_L.assign(Clarity=None)
                    df_050_059_EC_I2_L  = df_050_059_EC_I2_L.assign(Cut=None)
                    df_050_059_EC_I2_L  = df_050_059_EC_I2_L.assign(Polish=None)
                    df_050_059_EC_I2_L  = df_050_059_EC_I2_L.assign(Symmetry=None)
                    df_050_059_EC_I2_L  = df_050_059_EC_I2_L.assign(Ratio=None)
                    df_050_059_EC_I2_L  = df_050_059_EC_I2_L.assign(PPC=None)
                    df_050_059_EC_I2_L  = df_050_059_EC_I2_L.assign(Total=None)
                    df_050_059_EC_I2_L ['Wt Range'] = listwtrange
                    df_050_059_EC_I2_L ['Company'] = listcom
                    df_050_059_EC_I2_L ['Shape'] = listshap
                    df_050_059_EC_I2_L ['Carat'] = listcar
                    df_050_059_EC_I2_L ['Color'] = listcol
                    df_050_059_EC_I2_L ['Clarity'] = listclar
                    df_050_059_EC_I2_L ['Cut'] = listcut
                    df_050_059_EC_I2_L ['Polish'] = listpol
                    df_050_059_EC_I2_L ['Symmetry'] = listsym
                    df_050_059_EC_I2_L ['Ratio'] = listrat
                    df_050_059_EC_I2_L ['PPC'] = listdesc
                    df_050_059_EC_I2_L ['Total'] = listtotal
                    df_050_059_EC_I2_L['Carat'] = df_050_059_EC_I2_L['Carat'].astype('float64')
                    df_050_059_EC_I2_L['PPC'] = df_050_059_EC_I2_L['PPC'].astype('float64')
                    df_050_059_EC_I2_L['Total'] = df_050_059_EC_I2_L['Total'].astype('float64')
                    df_050_059_EC_I2_L['Total'] = df_050_059_EC_I2_L['Carat'] * df_050_059_EC_I2_L['PPC']

                
                elif i=="D" and j == "IF" and k == "MQ":
                    df_050_059_MQ_IF_D = pd.DataFrame()
                    df_050_059_MQ_IF_D ['Wt Range'] = None
                    df_050_059_MQ_IF_D  = df_050_059_MQ_IF_D.assign(Company=None)
                    df_050_059_MQ_IF_D  = df_050_059_MQ_IF_D.assign(Shape=None)
                    df_050_059_MQ_IF_D  = df_050_059_MQ_IF_D.assign(Carat=None)
                    df_050_059_MQ_IF_D  = df_050_059_MQ_IF_D.assign(Color=None)
                    df_050_059_MQ_IF_D  = df_050_059_MQ_IF_D.assign(Clarity=None)
                    df_050_059_MQ_IF_D  = df_050_059_MQ_IF_D.assign(Cut=None)
                    df_050_059_MQ_IF_D  = df_050_059_MQ_IF_D.assign(Polish=None)
                    df_050_059_MQ_IF_D  = df_050_059_MQ_IF_D.assign(Symmetry=None)
                    df_050_059_MQ_IF_D  = df_050_059_MQ_IF_D.assign(Ratio=None)
                    df_050_059_MQ_IF_D  = df_050_059_MQ_IF_D.assign(PPC=None)
                    df_050_059_MQ_IF_D  = df_050_059_MQ_IF_D.assign(Total=None)
                    df_050_059_MQ_IF_D ['Wt Range'] = listwtrange
                    df_050_059_MQ_IF_D ['Company'] = listcom
                    df_050_059_MQ_IF_D ['Shape'] = listshap
                    df_050_059_MQ_IF_D ['Carat'] = listcar
                    df_050_059_MQ_IF_D ['Color'] = listcol
                    df_050_059_MQ_IF_D ['Clarity'] = listclar
                    df_050_059_MQ_IF_D ['Cut'] = listcut
                    df_050_059_MQ_IF_D ['Polish'] = listpol
                    df_050_059_MQ_IF_D ['Symmetry'] = listsym
                    df_050_059_MQ_IF_D ['Ratio'] = listrat
                    df_050_059_MQ_IF_D ['PPC'] = listdesc
                    df_050_059_MQ_IF_D ['Total'] = listtotal
                    df_050_059_MQ_IF_D['Carat'] = df_050_059_MQ_IF_D['Carat'].astype('float64')
                    df_050_059_MQ_IF_D['PPC'] = df_050_059_MQ_IF_D['PPC'].astype('float64')
                    df_050_059_MQ_IF_D['Total'] = df_050_059_MQ_IF_D['Total'].astype('float64')
                    df_050_059_MQ_IF_D['Total'] = df_050_059_MQ_IF_D['Carat'] * df_050_059_MQ_IF_D['PPC']



                elif i=="D" and j == "VVS1" and k == "MQ" :
                    df_050_059_MQ_VVS1_D = pd.DataFrame()
                    df_050_059_MQ_VVS1_D ['Wt Range'] = None
                    df_050_059_MQ_VVS1_D  = df_050_059_MQ_VVS1_D.assign(Company=None)
                    df_050_059_MQ_VVS1_D  = df_050_059_MQ_VVS1_D.assign(Shape=None)
                    df_050_059_MQ_VVS1_D  = df_050_059_MQ_VVS1_D.assign(Carat=None)
                    df_050_059_MQ_VVS1_D  = df_050_059_MQ_VVS1_D.assign(Color=None)
                    df_050_059_MQ_VVS1_D  = df_050_059_MQ_VVS1_D.assign(Clarity=None)
                    df_050_059_MQ_VVS1_D  = df_050_059_MQ_VVS1_D.assign(Cut=None)
                    df_050_059_MQ_VVS1_D  = df_050_059_MQ_VVS1_D.assign(Polish=None)
                    df_050_059_MQ_VVS1_D  = df_050_059_MQ_VVS1_D.assign(Symmetry=None)
                    df_050_059_MQ_VVS1_D  = df_050_059_MQ_VVS1_D.assign(Ratio=None)
                    df_050_059_MQ_VVS1_D  = df_050_059_MQ_VVS1_D.assign(PPC=None)
                    df_050_059_MQ_VVS1_D  = df_050_059_MQ_VVS1_D.assign(Total=None)
                    df_050_059_MQ_VVS1_D ['Wt Range'] = listwtrange
                    df_050_059_MQ_VVS1_D ['Company'] = listcom
                    df_050_059_MQ_VVS1_D ['Shape'] = listshap
                    df_050_059_MQ_VVS1_D ['Carat'] = listcar
                    df_050_059_MQ_VVS1_D ['Color'] = listcol
                    df_050_059_MQ_VVS1_D ['Clarity'] = listclar
                    df_050_059_MQ_VVS1_D ['Cut'] = listcut
                    df_050_059_MQ_VVS1_D ['Polish'] = listpol
                    df_050_059_MQ_VVS1_D ['Symmetry'] = listsym
                    df_050_059_MQ_VVS1_D ['Ratio'] = listrat
                    df_050_059_MQ_VVS1_D ['PPC'] = listdesc
                    df_050_059_MQ_VVS1_D ['Total'] = listtotal
                    df_050_059_MQ_VVS1_D['Carat'] = df_050_059_MQ_VVS1_D['Carat'].astype('float64')
                    df_050_059_MQ_VVS1_D['PPC'] = df_050_059_MQ_VVS1_D['PPC'].astype('float64')
                    df_050_059_MQ_VVS1_D['Total'] = df_050_059_MQ_VVS1_D['Total'].astype('float64')
                    df_050_059_MQ_VVS1_D['Total'] = df_050_059_MQ_VVS1_D['Carat'] * df_050_059_MQ_VVS1_D['PPC']



                elif i=="D" and j == "VVS2" and k == "MQ" :
                    df_050_059_MQ_VVS2_D = pd.DataFrame()
                    df_050_059_MQ_VVS2_D ['Wt Range'] = None
                    df_050_059_MQ_VVS2_D  = df_050_059_MQ_VVS2_D.assign(Company=None)
                    df_050_059_MQ_VVS2_D  = df_050_059_MQ_VVS2_D.assign(Shape=None)
                    df_050_059_MQ_VVS2_D  = df_050_059_MQ_VVS2_D.assign(Carat=None)
                    df_050_059_MQ_VVS2_D  = df_050_059_MQ_VVS2_D.assign(Color=None)
                    df_050_059_MQ_VVS2_D  = df_050_059_MQ_VVS2_D.assign(Clarity=None)
                    df_050_059_MQ_VVS2_D  = df_050_059_MQ_VVS2_D.assign(Cut=None)
                    df_050_059_MQ_VVS2_D  = df_050_059_MQ_VVS2_D.assign(Polish=None)
                    df_050_059_MQ_VVS2_D  = df_050_059_MQ_VVS2_D.assign(Symmetry=None)
                    df_050_059_MQ_VVS2_D  = df_050_059_MQ_VVS2_D.assign(Ratio=None)
                    df_050_059_MQ_VVS2_D  = df_050_059_MQ_VVS2_D.assign(PPC=None)
                    df_050_059_MQ_VVS2_D  = df_050_059_MQ_VVS2_D.assign(Total=None)
                    df_050_059_MQ_VVS2_D ['Wt Range'] = listwtrange
                    df_050_059_MQ_VVS2_D ['Company'] = listcom
                    df_050_059_MQ_VVS2_D ['Shape'] = listshap
                    df_050_059_MQ_VVS2_D ['Carat'] = listcar
                    df_050_059_MQ_VVS2_D ['Color'] = listcol
                    df_050_059_MQ_VVS2_D ['Clarity'] = listclar
                    df_050_059_MQ_VVS2_D ['Cut'] = listcut
                    df_050_059_MQ_VVS2_D ['Polish'] = listpol
                    df_050_059_MQ_VVS2_D ['Symmetry'] = listsym
                    df_050_059_MQ_VVS2_D ['Ratio'] = listrat
                    df_050_059_MQ_VVS2_D ['PPC'] = listdesc
                    df_050_059_MQ_VVS2_D ['Total'] = listtotal
                    df_050_059_MQ_VVS2_D['Carat'] = df_050_059_MQ_VVS2_D['Carat'].astype('float64')
                    df_050_059_MQ_VVS2_D['PPC'] = df_050_059_MQ_VVS2_D['PPC'].astype('float64')
                    df_050_059_MQ_VVS2_D['Total'] = df_050_059_MQ_VVS2_D['Total'].astype('float64')
                    df_050_059_MQ_VVS2_D['Total'] = df_050_059_MQ_VVS2_D['Carat'] * df_050_059_MQ_VVS2_D['PPC']



                elif i=="D" and j == "VS1" and k == "MQ":
                    df_050_059_MQ_VS1_D = pd.DataFrame()
                    df_050_059_MQ_VS1_D ['Wt Range'] = None
                    df_050_059_MQ_VS1_D  = df_050_059_MQ_VS1_D.assign(Company=None)
                    df_050_059_MQ_VS1_D  = df_050_059_MQ_VS1_D.assign(Shape=None)
                    df_050_059_MQ_VS1_D  = df_050_059_MQ_VS1_D.assign(Carat=None)
                    df_050_059_MQ_VS1_D  = df_050_059_MQ_VS1_D.assign(Color=None)
                    df_050_059_MQ_VS1_D  = df_050_059_MQ_VS1_D.assign(Clarity=None)
                    df_050_059_MQ_VS1_D  = df_050_059_MQ_VS1_D.assign(Cut=None)
                    df_050_059_MQ_VS1_D  = df_050_059_MQ_VS1_D.assign(Polish=None)
                    df_050_059_MQ_VS1_D  = df_050_059_MQ_VS1_D.assign(Symmetry=None)
                    df_050_059_MQ_VS1_D  = df_050_059_MQ_VS1_D.assign(Ratio=None)
                    df_050_059_MQ_VS1_D  = df_050_059_MQ_VS1_D.assign(PPC=None)
                    df_050_059_MQ_VS1_D  = df_050_059_MQ_VS1_D.assign(Total=None)
                    df_050_059_MQ_VS1_D ['Wt Range'] = listwtrange
                    df_050_059_MQ_VS1_D ['Company'] = listcom
                    df_050_059_MQ_VS1_D ['Shape'] = listshap
                    df_050_059_MQ_VS1_D ['Carat'] = listcar
                    df_050_059_MQ_VS1_D ['Color'] = listcol
                    df_050_059_MQ_VS1_D ['Clarity'] = listclar
                    df_050_059_MQ_VS1_D ['Cut'] = listcut
                    df_050_059_MQ_VS1_D ['Polish'] = listpol
                    df_050_059_MQ_VS1_D ['Symmetry'] = listsym
                    df_050_059_MQ_VS1_D ['Ratio'] = listrat
                    df_050_059_MQ_VS1_D ['PPC'] = listdesc
                    df_050_059_MQ_VS1_D ['Total'] = listtotal
                    df_050_059_MQ_VS1_D['Carat'] = df_050_059_MQ_VS1_D['Carat'].astype('float64')
                    df_050_059_MQ_VS1_D['PPC'] = df_050_059_MQ_VS1_D['PPC'].astype('float64')
                    df_050_059_MQ_VS1_D['Total'] = df_050_059_MQ_VS1_D['Total'].astype('float64')
                    df_050_059_MQ_VS1_D['Total'] = df_050_059_MQ_VS1_D['Carat'] * df_050_059_MQ_VS1_D['PPC']


                elif i=="D" and j == "VS2" and k == "MQ":
                    df_050_059_MQ_VS2_D = pd.DataFrame()
                    df_050_059_MQ_VS2_D ['Wt Range'] = None
                    df_050_059_MQ_VS2_D  = df_050_059_MQ_VS2_D.assign(Company=None)
                    df_050_059_MQ_VS2_D  = df_050_059_MQ_VS2_D.assign(Shape=None)
                    df_050_059_MQ_VS2_D  = df_050_059_MQ_VS2_D.assign(Carat=None)
                    df_050_059_MQ_VS2_D  = df_050_059_MQ_VS2_D.assign(Color=None)
                    df_050_059_MQ_VS2_D  = df_050_059_MQ_VS2_D.assign(Clarity=None)
                    df_050_059_MQ_VS2_D  = df_050_059_MQ_VS2_D.assign(Cut=None)
                    df_050_059_MQ_VS2_D  = df_050_059_MQ_VS2_D.assign(Polish=None)
                    df_050_059_MQ_VS2_D  = df_050_059_MQ_VS2_D.assign(Symmetry=None)
                    df_050_059_MQ_VS2_D  = df_050_059_MQ_VS2_D.assign(Ratio=None)
                    df_050_059_MQ_VS2_D  = df_050_059_MQ_VS2_D.assign(PPC=None)
                    df_050_059_MQ_VS2_D  = df_050_059_MQ_VS2_D.assign(Total=None)
                    df_050_059_MQ_VS2_D ['Wt Range'] = listwtrange
                    df_050_059_MQ_VS2_D ['Company'] = listcom
                    df_050_059_MQ_VS2_D ['Shape'] = listshap
                    df_050_059_MQ_VS2_D ['Carat'] = listcar
                    df_050_059_MQ_VS2_D ['Color'] = listcol
                    df_050_059_MQ_VS2_D ['Clarity'] = listclar
                    df_050_059_MQ_VS2_D ['Cut'] = listcut
                    df_050_059_MQ_VS2_D ['Polish'] = listpol
                    df_050_059_MQ_VS2_D ['Symmetry'] = listsym
                    df_050_059_MQ_VS2_D ['Ratio'] = listrat
                    df_050_059_MQ_VS2_D ['PPC'] = listdesc
                    df_050_059_MQ_VS2_D ['Total'] = listtotal
                    df_050_059_MQ_VS2_D['Carat'] = df_050_059_MQ_VS2_D['Carat'].astype('float64')
                    df_050_059_MQ_VS2_D['PPC'] = df_050_059_MQ_VS2_D['PPC'].astype('float64')
                    df_050_059_MQ_VS2_D['Total'] = df_050_059_MQ_VS2_D['Total'].astype('float64')
                    df_050_059_MQ_VS2_D['Total'] = df_050_059_MQ_VS2_D['Carat'] * df_050_059_MQ_VS2_D['PPC']


                elif i=="D" and j == "SI1" and k == "MQ":
                    df_050_059_MQ_SI1_D = pd.DataFrame()
                    df_050_059_MQ_SI1_D ['Wt Range'] = None
                    df_050_059_MQ_SI1_D  = df_050_059_MQ_SI1_D.assign(Company=None)
                    df_050_059_MQ_SI1_D  = df_050_059_MQ_SI1_D.assign(Shape=None)
                    df_050_059_MQ_SI1_D  = df_050_059_MQ_SI1_D.assign(Carat=None)
                    df_050_059_MQ_SI1_D  = df_050_059_MQ_SI1_D.assign(Color=None)
                    df_050_059_MQ_SI1_D  = df_050_059_MQ_SI1_D.assign(Clarity=None)
                    df_050_059_MQ_SI1_D  = df_050_059_MQ_SI1_D.assign(Cut=None)
                    df_050_059_MQ_SI1_D  = df_050_059_MQ_SI1_D.assign(Polish=None)
                    df_050_059_MQ_SI1_D  = df_050_059_MQ_SI1_D.assign(Symmetry=None)
                    df_050_059_MQ_SI1_D  = df_050_059_MQ_SI1_D.assign(Ratio=None)
                    df_050_059_MQ_SI1_D  = df_050_059_MQ_SI1_D.assign(PPC=None)
                    df_050_059_MQ_SI1_D  = df_050_059_MQ_SI1_D.assign(Total=None)
                    df_050_059_MQ_SI1_D ['Wt Range'] = listwtrange
                    df_050_059_MQ_SI1_D ['Company'] = listcom
                    df_050_059_MQ_SI1_D ['Shape'] = listshap
                    df_050_059_MQ_SI1_D ['Carat'] = listcar
                    df_050_059_MQ_SI1_D ['Color'] = listcol
                    df_050_059_MQ_SI1_D ['Clarity'] = listclar
                    df_050_059_MQ_SI1_D ['Cut'] = listcut
                    df_050_059_MQ_SI1_D ['Polish'] = listpol
                    df_050_059_MQ_SI1_D ['Symmetry'] = listsym
                    df_050_059_MQ_SI1_D ['Ratio'] = listrat
                    df_050_059_MQ_SI1_D ['PPC'] = listdesc
                    df_050_059_MQ_SI1_D ['Total'] = listtotal
                    df_050_059_MQ_SI1_D['Carat'] = df_050_059_MQ_SI1_D['Carat'].astype('float64')
                    df_050_059_MQ_SI1_D['PPC'] = df_050_059_MQ_SI1_D['PPC'].astype('float64')
                    df_050_059_MQ_SI1_D['Total'] = df_050_059_MQ_SI1_D['Total'].astype('float64')
                    df_050_059_MQ_SI1_D['Total'] = df_050_059_MQ_SI1_D['Carat'] * df_050_059_MQ_SI1_D['PPC']


                elif i=="D" and j == "SI2" and k == "MQ":
                    df_050_059_MQ_SI2_D = pd.DataFrame()
                    df_050_059_MQ_SI2_D ['Wt Range'] = None
                    df_050_059_MQ_SI2_D  = df_050_059_MQ_SI2_D.assign(Company=None)
                    df_050_059_MQ_SI2_D  = df_050_059_MQ_SI2_D.assign(Shape=None)
                    df_050_059_MQ_SI2_D  = df_050_059_MQ_SI2_D.assign(Carat=None)
                    df_050_059_MQ_SI2_D  = df_050_059_MQ_SI2_D.assign(Color=None)
                    df_050_059_MQ_SI2_D  = df_050_059_MQ_SI2_D.assign(Clarity=None)
                    df_050_059_MQ_SI2_D  = df_050_059_MQ_SI2_D.assign(Cut=None)
                    df_050_059_MQ_SI2_D  = df_050_059_MQ_SI2_D.assign(Polish=None)
                    df_050_059_MQ_SI2_D  = df_050_059_MQ_SI2_D.assign(Symmetry=None)
                    df_050_059_MQ_SI2_D  = df_050_059_MQ_SI2_D.assign(Ratio=None)
                    df_050_059_MQ_SI2_D  = df_050_059_MQ_SI2_D.assign(PPC=None)
                    df_050_059_MQ_SI2_D  = df_050_059_MQ_SI2_D.assign(Total=None)
                    df_050_059_MQ_SI2_D ['Wt Range'] = listwtrange
                    df_050_059_MQ_SI2_D ['Company'] = listcom
                    df_050_059_MQ_SI2_D ['Shape'] = listshap
                    df_050_059_MQ_SI2_D ['Carat'] = listcar
                    df_050_059_MQ_SI2_D ['Color'] = listcol
                    df_050_059_MQ_SI2_D ['Clarity'] = listclar
                    df_050_059_MQ_SI2_D ['Cut'] = listcut
                    df_050_059_MQ_SI2_D ['Polish'] = listpol
                    df_050_059_MQ_SI2_D ['Symmetry'] = listsym
                    df_050_059_MQ_SI2_D ['Ratio'] = listrat
                    df_050_059_MQ_SI2_D ['PPC'] = listdesc
                    df_050_059_MQ_SI2_D ['Total'] = listtotal
                    df_050_059_MQ_SI2_D['Carat'] = df_050_059_MQ_SI2_D['Carat'].astype('float64')
                    df_050_059_MQ_SI2_D['PPC'] = df_050_059_MQ_SI2_D['PPC'].astype('float64')
                    df_050_059_MQ_SI2_D['Total'] = df_050_059_MQ_SI2_D['Total'].astype('float64')
                    df_050_059_MQ_SI2_D['Total'] = df_050_059_MQ_SI2_D['Carat'] * df_050_059_MQ_SI2_D['PPC']


                elif i=="D" and j == "I1" and k == "MQ":
                    df_050_059_MQ_I1_D = pd.DataFrame()
                    df_050_059_MQ_I1_D ['Wt Range'] = None
                    df_050_059_MQ_I1_D  = df_050_059_MQ_I1_D.assign(Company=None)
                    df_050_059_MQ_I1_D  = df_050_059_MQ_I1_D.assign(Shape=None)
                    df_050_059_MQ_I1_D  = df_050_059_MQ_I1_D.assign(Carat=None)
                    df_050_059_MQ_I1_D  = df_050_059_MQ_I1_D.assign(Color=None)
                    df_050_059_MQ_I1_D  = df_050_059_MQ_I1_D.assign(Clarity=None)
                    df_050_059_MQ_I1_D  = df_050_059_MQ_I1_D.assign(Cut=None)
                    df_050_059_MQ_I1_D  = df_050_059_MQ_I1_D.assign(Polish=None)
                    df_050_059_MQ_I1_D  = df_050_059_MQ_I1_D.assign(Symmetry=None)
                    df_050_059_MQ_I1_D  = df_050_059_MQ_I1_D.assign(Ratio=None)
                    df_050_059_MQ_I1_D  = df_050_059_MQ_I1_D.assign(PPC=None)
                    df_050_059_MQ_I1_D  = df_050_059_MQ_I1_D.assign(Total=None)
                    df_050_059_MQ_I1_D ['Wt Range'] = listwtrange
                    df_050_059_MQ_I1_D ['Company'] = listcom
                    df_050_059_MQ_I1_D ['Shape'] = listshap
                    df_050_059_MQ_I1_D ['Carat'] = listcar
                    df_050_059_MQ_I1_D ['Color'] = listcol
                    df_050_059_MQ_I1_D ['Clarity'] = listclar
                    df_050_059_MQ_I1_D ['Cut'] = listcut
                    df_050_059_MQ_I1_D ['Polish'] = listpol
                    df_050_059_MQ_I1_D ['Symmetry'] = listsym
                    df_050_059_MQ_I1_D ['Ratio'] = listrat
                    df_050_059_MQ_I1_D ['PPC'] = listdesc
                    df_050_059_MQ_I1_D ['Total'] = listtotal
                    df_050_059_MQ_I1_D['Carat'] = df_050_059_MQ_I1_D['Carat'].astype('float64')
                    df_050_059_MQ_I1_D['PPC'] = df_050_059_MQ_I1_D['PPC'].astype('float64')
                    df_050_059_MQ_I1_D['Total'] = df_050_059_MQ_I1_D['Total'].astype('float64')
                    df_050_059_MQ_I1_D['Total'] = df_050_059_MQ_I1_D['Carat'] * df_050_059_MQ_I1_D['PPC']


                elif i=="D" and j == "I2" and k == "MQ":
                    df_050_059_MQ_I2_D = pd.DataFrame()
                    df_050_059_MQ_I2_D ['Wt Range'] = None
                    df_050_059_MQ_I2_D  = df_050_059_MQ_I2_D.assign(Company=None)
                    df_050_059_MQ_I2_D  = df_050_059_MQ_I2_D.assign(Shape=None)
                    df_050_059_MQ_I2_D  = df_050_059_MQ_I2_D.assign(Carat=None)
                    df_050_059_MQ_I2_D  = df_050_059_MQ_I2_D.assign(Color=None)
                    df_050_059_MQ_I2_D  = df_050_059_MQ_I2_D.assign(Clarity=None)
                    df_050_059_MQ_I2_D  = df_050_059_MQ_I2_D.assign(Cut=None)
                    df_050_059_MQ_I2_D  = df_050_059_MQ_I2_D.assign(Polish=None)
                    df_050_059_MQ_I2_D  = df_050_059_MQ_I2_D.assign(Symmetry=None)
                    df_050_059_MQ_I2_D  = df_050_059_MQ_I2_D.assign(Ratio=None)
                    df_050_059_MQ_I2_D  = df_050_059_MQ_I2_D.assign(PPC=None)
                    df_050_059_MQ_I2_D  = df_050_059_MQ_I2_D.assign(Total=None)
                    df_050_059_MQ_I2_D ['Wt Range'] = listwtrange
                    df_050_059_MQ_I2_D ['Company'] = listcom
                    df_050_059_MQ_I2_D ['Shape'] = listshap
                    df_050_059_MQ_I2_D ['Carat'] = listcar
                    df_050_059_MQ_I2_D ['Color'] = listcol
                    df_050_059_MQ_I2_D ['Clarity'] = listclar
                    df_050_059_MQ_I2_D ['Cut'] = listcut
                    df_050_059_MQ_I2_D ['Polish'] = listpol
                    df_050_059_MQ_I2_D ['Symmetry'] = listsym
                    df_050_059_MQ_I2_D ['Ratio'] = listrat
                    df_050_059_MQ_I2_D ['PPC'] = listdesc
                    df_050_059_MQ_I2_D ['Total'] = listtotal
                    df_050_059_MQ_I2_D['Carat'] = df_050_059_MQ_I2_D['Carat'].astype('float64')
                    df_050_059_MQ_I2_D['PPC'] = df_050_059_MQ_I2_D['PPC'].astype('float64')
                    df_050_059_MQ_I2_D['Total'] = df_050_059_MQ_I2_D['Total'].astype('float64')
                    df_050_059_MQ_I2_D['Total'] = df_050_059_MQ_I2_D['Carat'] * df_050_059_MQ_I2_D['PPC']



                elif i=="E" and j == "IF" and k == "MQ":
                    df_050_059_MQ_IF_E = pd.DataFrame()
                    df_050_059_MQ_IF_E ['Wt Range'] = None
                    df_050_059_MQ_IF_E  = df_050_059_MQ_IF_E.assign(Company=None)
                    df_050_059_MQ_IF_E  = df_050_059_MQ_IF_E.assign(Shape=None)
                    df_050_059_MQ_IF_E  = df_050_059_MQ_IF_E.assign(Carat=None)
                    df_050_059_MQ_IF_E  = df_050_059_MQ_IF_E.assign(Color=None)
                    df_050_059_MQ_IF_E  = df_050_059_MQ_IF_E.assign(Clarity=None)
                    df_050_059_MQ_IF_E  = df_050_059_MQ_IF_E.assign(Cut=None)
                    df_050_059_MQ_IF_E  = df_050_059_MQ_IF_E.assign(Polish=None)
                    df_050_059_MQ_IF_E  = df_050_059_MQ_IF_E.assign(Symmetry=None)
                    df_050_059_MQ_IF_E  = df_050_059_MQ_IF_E.assign(Ratio=None)
                    df_050_059_MQ_IF_E  = df_050_059_MQ_IF_E.assign(PPC=None)
                    df_050_059_MQ_IF_E  = df_050_059_MQ_IF_E.assign(Total=None)
                    df_050_059_MQ_IF_E ['Wt Range'] = listwtrange
                    df_050_059_MQ_IF_E ['Company'] = listcom
                    df_050_059_MQ_IF_E ['Shape'] = listshap
                    df_050_059_MQ_IF_E ['Carat'] = listcar
                    df_050_059_MQ_IF_E ['Color'] = listcol
                    df_050_059_MQ_IF_E ['Clarity'] = listclar
                    df_050_059_MQ_IF_E ['Cut'] = listcut
                    df_050_059_MQ_IF_E ['Polish'] = listpol
                    df_050_059_MQ_IF_E ['Symmetry'] = listsym
                    df_050_059_MQ_IF_E ['Ratio'] = listrat
                    df_050_059_MQ_IF_E ['PPC'] = listdesc
                    df_050_059_MQ_IF_E ['Total'] = listtotal
                    df_050_059_MQ_IF_E['Carat'] = df_050_059_MQ_IF_E['Carat'].astype('float64')
                    df_050_059_MQ_IF_E['PPC'] = df_050_059_MQ_IF_E['PPC'].astype('float64')
                    df_050_059_MQ_IF_E['Total'] = df_050_059_MQ_IF_E['Total'].astype('float64')
                    df_050_059_MQ_IF_E['Total'] = df_050_059_MQ_IF_E['Carat'] * df_050_059_MQ_IF_E['PPC']



                elif i=="E" and j == "VVS1" and k == "MQ":
                    df_050_059_MQ_VVS1_E = pd.DataFrame()
                    df_050_059_MQ_VVS1_E ['Wt Range'] = None
                    df_050_059_MQ_VVS1_E  = df_050_059_MQ_VVS1_E.assign(Company=None)
                    df_050_059_MQ_VVS1_E  = df_050_059_MQ_VVS1_E.assign(Shape=None)
                    df_050_059_MQ_VVS1_E  = df_050_059_MQ_VVS1_E.assign(Carat=None)
                    df_050_059_MQ_VVS1_E  = df_050_059_MQ_VVS1_E.assign(Color=None)
                    df_050_059_MQ_VVS1_E  = df_050_059_MQ_VVS1_E.assign(Clarity=None)
                    df_050_059_MQ_VVS1_E  = df_050_059_MQ_VVS1_E.assign(Cut=None)
                    df_050_059_MQ_VVS1_E  = df_050_059_MQ_VVS1_E.assign(Polish=None)
                    df_050_059_MQ_VVS1_E  = df_050_059_MQ_VVS1_E.assign(Symmetry=None)
                    df_050_059_MQ_VVS1_E  = df_050_059_MQ_VVS1_E.assign(Ratio=None)
                    df_050_059_MQ_VVS1_E  = df_050_059_MQ_VVS1_E.assign(PPC=None)
                    df_050_059_MQ_VVS1_E  = df_050_059_MQ_VVS1_E.assign(Total=None)
                    df_050_059_MQ_VVS1_E ['Wt Range'] = listwtrange
                    df_050_059_MQ_VVS1_E ['Company'] = listcom
                    df_050_059_MQ_VVS1_E ['Shape'] = listshap
                    df_050_059_MQ_VVS1_E ['Carat'] = listcar
                    df_050_059_MQ_VVS1_E ['Color'] = listcol
                    df_050_059_MQ_VVS1_E ['Clarity'] = listclar
                    df_050_059_MQ_VVS1_E ['Cut'] = listcut
                    df_050_059_MQ_VVS1_E ['Polish'] = listpol
                    df_050_059_MQ_VVS1_E ['Symmetry'] = listsym
                    df_050_059_MQ_VVS1_E ['Ratio'] = listrat
                    df_050_059_MQ_VVS1_E ['PPC'] = listdesc
                    df_050_059_MQ_VVS1_E ['Total'] = listtotal
                    df_050_059_MQ_VVS1_E['Carat'] = df_050_059_MQ_VVS1_E['Carat'].astype('float64')
                    df_050_059_MQ_VVS1_E['PPC'] = df_050_059_MQ_VVS1_E['PPC'].astype('float64')
                    df_050_059_MQ_VVS1_E['Total'] = df_050_059_MQ_VVS1_E['Total'].astype('float64')
                    df_050_059_MQ_VVS1_E['Total'] = df_050_059_MQ_VVS1_E['Carat'] * df_050_059_MQ_VVS1_E['PPC']


                elif i=="E" and j == "VVS2" and k == "MQ":
                    df_050_059_MQ_VVS2_E = pd.DataFrame()
                    df_050_059_MQ_VVS2_E ['Wt Range'] = None
                    df_050_059_MQ_VVS2_E  = df_050_059_MQ_VVS2_E.assign(Company=None)
                    df_050_059_MQ_VVS2_E  = df_050_059_MQ_VVS2_E.assign(Shape=None)
                    df_050_059_MQ_VVS2_E  = df_050_059_MQ_VVS2_E.assign(Carat=None)
                    df_050_059_MQ_VVS2_E  = df_050_059_MQ_VVS2_E.assign(Color=None)
                    df_050_059_MQ_VVS2_E  = df_050_059_MQ_VVS2_E.assign(Clarity=None)
                    df_050_059_MQ_VVS2_E  = df_050_059_MQ_VVS2_E.assign(Cut=None)
                    df_050_059_MQ_VVS2_E  = df_050_059_MQ_VVS2_E.assign(Polish=None)
                    df_050_059_MQ_VVS2_E  = df_050_059_MQ_VVS2_E.assign(Symmetry=None)
                    df_050_059_MQ_VVS2_E  = df_050_059_MQ_VVS2_E.assign(Ratio=None)
                    df_050_059_MQ_VVS2_E  = df_050_059_MQ_VVS2_E.assign(PPC=None)
                    df_050_059_MQ_VVS2_E  = df_050_059_MQ_VVS2_E.assign(Total=None)
                    df_050_059_MQ_VVS2_E ['Wt Range'] = listwtrange
                    df_050_059_MQ_VVS2_E ['Company'] = listcom
                    df_050_059_MQ_VVS2_E ['Shape'] = listshap
                    df_050_059_MQ_VVS2_E ['Carat'] = listcar
                    df_050_059_MQ_VVS2_E ['Color'] = listcol
                    df_050_059_MQ_VVS2_E ['Clarity'] = listclar
                    df_050_059_MQ_VVS2_E ['Cut'] = listcut
                    df_050_059_MQ_VVS2_E ['Polish'] = listpol
                    df_050_059_MQ_VVS2_E ['Symmetry'] = listsym
                    df_050_059_MQ_VVS2_E ['Ratio'] = listrat
                    df_050_059_MQ_VVS2_E ['PPC'] = listdesc
                    df_050_059_MQ_VVS2_E ['Total'] = listtotal
                    df_050_059_MQ_VVS2_E['Carat'] = df_050_059_MQ_VVS2_E['Carat'].astype('float64')
                    df_050_059_MQ_VVS2_E['PPC'] = df_050_059_MQ_VVS2_E['PPC'].astype('float64')
                    df_050_059_MQ_VVS2_E['Total'] = df_050_059_MQ_VVS2_E['Total'].astype('float64')
                    df_050_059_MQ_VVS2_E['Total'] = df_050_059_MQ_VVS2_E['Carat'] * df_050_059_MQ_VVS2_E['PPC']


                elif i=="E" and j=="VS1" and k == "MQ":
                    df_050_059_MQ_VS1_E = pd.DataFrame()
                    df_050_059_MQ_VS1_E ['Wt Range'] = None
                    df_050_059_MQ_VS1_E  = df_050_059_MQ_VS1_E.assign(Company=None)
                    df_050_059_MQ_VS1_E  = df_050_059_MQ_VS1_E.assign(Shape=None)
                    df_050_059_MQ_VS1_E  = df_050_059_MQ_VS1_E.assign(Carat=None)
                    df_050_059_MQ_VS1_E  = df_050_059_MQ_VS1_E.assign(Color=None)
                    df_050_059_MQ_VS1_E  = df_050_059_MQ_VS1_E.assign(Clarity=None)
                    df_050_059_MQ_VS1_E  = df_050_059_MQ_VS1_E.assign(Cut=None)
                    df_050_059_MQ_VS1_E  = df_050_059_MQ_VS1_E.assign(Polish=None)
                    df_050_059_MQ_VS1_E  = df_050_059_MQ_VS1_E.assign(Symmetry=None)
                    df_050_059_MQ_VS1_E  = df_050_059_MQ_VS1_E.assign(Ratio=None)
                    df_050_059_MQ_VS1_E  = df_050_059_MQ_VS1_E.assign(PPC=None)
                    df_050_059_MQ_VS1_E  = df_050_059_MQ_VS1_E.assign(Total=None)
                    df_050_059_MQ_VS1_E ['Wt Range'] = listwtrange
                    df_050_059_MQ_VS1_E ['Company'] = listcom
                    df_050_059_MQ_VS1_E ['Shape'] = listshap
                    df_050_059_MQ_VS1_E ['Carat'] = listcar
                    df_050_059_MQ_VS1_E ['Color'] = listcol
                    df_050_059_MQ_VS1_E ['Clarity'] = listclar
                    df_050_059_MQ_VS1_E ['Cut'] = listcut
                    df_050_059_MQ_VS1_E ['Polish'] = listpol
                    df_050_059_MQ_VS1_E ['Symmetry'] = listsym
                    df_050_059_MQ_VS1_E ['Ratio'] = listrat
                    df_050_059_MQ_VS1_E ['PPC'] = listdesc
                    df_050_059_MQ_VS1_E ['Total'] = listtotal
                    df_050_059_MQ_VS1_E['Carat'] = df_050_059_MQ_VS1_E['Carat'].astype('float64')
                    df_050_059_MQ_VS1_E['PPC'] = df_050_059_MQ_VS1_E['PPC'].astype('float64')
                    df_050_059_MQ_VS1_E['Total'] = df_050_059_MQ_VS1_E['Total'].astype('float64')
                    df_050_059_MQ_VS1_E['Total'] = df_050_059_MQ_VS1_E['Carat'] * df_050_059_MQ_VS1_E['PPC']


                elif i=="E" and j == "VS2" and k == "MQ":
                    df_050_059_MQ_VS2_E = pd.DataFrame()
                    df_050_059_MQ_VS2_E ['Wt Range'] = None
                    df_050_059_MQ_VS2_E  = df_050_059_MQ_VS2_E.assign(Company=None)
                    df_050_059_MQ_VS2_E  = df_050_059_MQ_VS2_E.assign(Shape=None)
                    df_050_059_MQ_VS2_E  = df_050_059_MQ_VS2_E.assign(Carat=None)
                    df_050_059_MQ_VS2_E  = df_050_059_MQ_VS2_E.assign(Color=None)
                    df_050_059_MQ_VS2_E  = df_050_059_MQ_VS2_E.assign(Clarity=None)
                    df_050_059_MQ_VS2_E  = df_050_059_MQ_VS2_E.assign(Cut=None)
                    df_050_059_MQ_VS2_E  = df_050_059_MQ_VS2_E.assign(Polish=None)
                    df_050_059_MQ_VS2_E  = df_050_059_MQ_VS2_E.assign(Symmetry=None)
                    df_050_059_MQ_VS2_E  = df_050_059_MQ_VS2_E.assign(Ratio=None)
                    df_050_059_MQ_VS2_E  = df_050_059_MQ_VS2_E.assign(PPC=None)
                    df_050_059_MQ_VS2_E  = df_050_059_MQ_VS2_E.assign(Total=None)
                    df_050_059_MQ_VS2_E ['Wt Range'] = listwtrange
                    df_050_059_MQ_VS2_E ['Company'] = listcom
                    df_050_059_MQ_VS2_E ['Shape'] = listshap
                    df_050_059_MQ_VS2_E ['Carat'] = listcar
                    df_050_059_MQ_VS2_E ['Color'] = listcol
                    df_050_059_MQ_VS2_E ['Clarity'] = listclar
                    df_050_059_MQ_VS2_E ['Cut'] = listcut
                    df_050_059_MQ_VS2_E ['Polish'] = listpol
                    df_050_059_MQ_VS2_E ['Symmetry'] = listsym
                    df_050_059_MQ_VS2_E ['Ratio'] = listrat
                    df_050_059_MQ_VS2_E ['PPC'] = listdesc
                    df_050_059_MQ_VS2_E ['Total'] = listtotal
                    df_050_059_MQ_VS2_E['Carat'] = df_050_059_MQ_VS2_E['Carat'].astype('float64')
                    df_050_059_MQ_VS2_E['PPC'] = df_050_059_MQ_VS2_E['PPC'].astype('float64')
                    df_050_059_MQ_VS2_E['Total'] = df_050_059_MQ_VS2_E['Total'].astype('float64')
                    df_050_059_MQ_VS2_E['Total'] = df_050_059_MQ_VS2_E['Carat'] * df_050_059_MQ_VS2_E['PPC']


                elif i=="E" and j == "SI1" and k == "MQ":
                    df_050_059_MQ_SI1_E = pd.DataFrame()
                    df_050_059_MQ_SI1_E ['Wt Range'] = None
                    df_050_059_MQ_SI1_E  = df_050_059_MQ_SI1_E.assign(Company=None)
                    df_050_059_MQ_SI1_E  = df_050_059_MQ_SI1_E.assign(Shape=None)
                    df_050_059_MQ_SI1_E  = df_050_059_MQ_SI1_E.assign(Carat=None)
                    df_050_059_MQ_SI1_E  = df_050_059_MQ_SI1_E.assign(Color=None)
                    df_050_059_MQ_SI1_E  = df_050_059_MQ_SI1_E.assign(Clarity=None)
                    df_050_059_MQ_SI1_E  = df_050_059_MQ_SI1_E.assign(Cut=None)
                    df_050_059_MQ_SI1_E  = df_050_059_MQ_SI1_E.assign(Polish=None)
                    df_050_059_MQ_SI1_E  = df_050_059_MQ_SI1_E.assign(Symmetry=None)
                    df_050_059_MQ_SI1_E  = df_050_059_MQ_SI1_E.assign(Ratio=None)
                    df_050_059_MQ_SI1_E  = df_050_059_MQ_SI1_E.assign(PPC=None)
                    df_050_059_MQ_SI1_E  = df_050_059_MQ_SI1_E.assign(Total=None)
                    df_050_059_MQ_SI1_E ['Wt Range'] = listwtrange
                    df_050_059_MQ_SI1_E ['Company'] = listcom
                    df_050_059_MQ_SI1_E ['Shape'] = listshap
                    df_050_059_MQ_SI1_E ['Carat'] = listcar
                    df_050_059_MQ_SI1_E ['Color'] = listcol
                    df_050_059_MQ_SI1_E ['Clarity'] = listclar
                    df_050_059_MQ_SI1_E ['Cut'] = listcut
                    df_050_059_MQ_SI1_E ['Polish'] = listpol
                    df_050_059_MQ_SI1_E ['Symmetry'] = listsym
                    df_050_059_MQ_SI1_E ['Ratio'] = listrat
                    df_050_059_MQ_SI1_E ['PPC'] = listdesc
                    df_050_059_MQ_SI1_E ['Total'] = listtotal
                    df_050_059_MQ_SI1_E['Carat'] = df_050_059_MQ_SI1_E['Carat'].astype('float64')
                    df_050_059_MQ_SI1_E['PPC'] = df_050_059_MQ_SI1_E['PPC'].astype('float64')
                    df_050_059_MQ_SI1_E['Total'] = df_050_059_MQ_SI1_E['Total'].astype('float64')
                    df_050_059_MQ_SI1_E['Total'] = df_050_059_MQ_SI1_E['Carat'] * df_050_059_MQ_SI1_E['PPC']


                elif i=="E" and j == "SI2" and k == "MQ":
                    df_050_059_MQ_SI2_E = pd.DataFrame()
                    df_050_059_MQ_SI2_E ['Wt Range'] = None
                    df_050_059_MQ_SI2_E  = df_050_059_MQ_SI2_E.assign(Company=None)
                    df_050_059_MQ_SI2_E  = df_050_059_MQ_SI2_E.assign(Shape=None)
                    df_050_059_MQ_SI2_E  = df_050_059_MQ_SI2_E.assign(Carat=None)
                    df_050_059_MQ_SI2_E  = df_050_059_MQ_SI2_E.assign(Color=None)
                    df_050_059_MQ_SI2_E  = df_050_059_MQ_SI2_E.assign(Clarity=None)
                    df_050_059_MQ_SI2_E  = df_050_059_MQ_SI2_E.assign(Cut=None)
                    df_050_059_MQ_SI2_E  = df_050_059_MQ_SI2_E.assign(Polish=None)
                    df_050_059_MQ_SI2_E  = df_050_059_MQ_SI2_E.assign(Symmetry=None)
                    df_050_059_MQ_SI2_E  = df_050_059_MQ_SI2_E.assign(Ratio=None)
                    df_050_059_MQ_SI2_E  = df_050_059_MQ_SI2_E.assign(PPC=None)
                    df_050_059_MQ_SI2_E  = df_050_059_MQ_SI2_E.assign(Total=None)
                    df_050_059_MQ_SI2_E ['Wt Range'] = listwtrange
                    df_050_059_MQ_SI2_E ['Company'] = listcom
                    df_050_059_MQ_SI2_E ['Shape'] = listshap
                    df_050_059_MQ_SI2_E ['Carat'] = listcar
                    df_050_059_MQ_SI2_E ['Color'] = listcol
                    df_050_059_MQ_SI2_E ['Clarity'] = listclar
                    df_050_059_MQ_SI2_E ['Cut'] = listcut
                    df_050_059_MQ_SI2_E ['Polish'] = listpol
                    df_050_059_MQ_SI2_E ['Symmetry'] = listsym
                    df_050_059_MQ_SI2_E ['Ratio'] = listrat
                    df_050_059_MQ_SI2_E ['PPC'] = listdesc
                    df_050_059_MQ_SI2_E ['Total'] = listtotal
                    df_050_059_MQ_SI2_E['Carat'] = df_050_059_MQ_SI2_E['Carat'].astype('float64')
                    df_050_059_MQ_SI2_E['PPC'] = df_050_059_MQ_SI2_E['PPC'].astype('float64')
                    df_050_059_MQ_SI2_E['Total'] = df_050_059_MQ_SI2_E['Total'].astype('float64')
                    df_050_059_MQ_SI2_E['Total'] = df_050_059_MQ_SI2_E['Carat'] * df_050_059_MQ_SI2_E['PPC']


                elif i=="E" and j == "I1" and k == "MQ":
                    df_050_059_MQ_I1_E = pd.DataFrame()
                    df_050_059_MQ_I1_E ['Wt Range'] = None
                    df_050_059_MQ_I1_E  = df_050_059_MQ_I1_E.assign(Company=None)
                    df_050_059_MQ_I1_E  = df_050_059_MQ_I1_E.assign(Shape=None)
                    df_050_059_MQ_I1_E  = df_050_059_MQ_I1_E.assign(Carat=None)
                    df_050_059_MQ_I1_E  = df_050_059_MQ_I1_E.assign(Color=None)
                    df_050_059_MQ_I1_E  = df_050_059_MQ_I1_E.assign(Clarity=None)
                    df_050_059_MQ_I1_E  = df_050_059_MQ_I1_E.assign(Cut=None)
                    df_050_059_MQ_I1_E  = df_050_059_MQ_I1_E.assign(Polish=None)
                    df_050_059_MQ_I1_E  = df_050_059_MQ_I1_E.assign(Symmetry=None)
                    df_050_059_MQ_I1_E  = df_050_059_MQ_I1_E.assign(Ratio=None)
                    df_050_059_MQ_I1_E  = df_050_059_MQ_I1_E.assign(PPC=None)
                    df_050_059_MQ_I1_E  = df_050_059_MQ_I1_E.assign(Total=None)
                    df_050_059_MQ_I1_E ['Wt Range'] = listwtrange
                    df_050_059_MQ_I1_E ['Company'] = listcom
                    df_050_059_MQ_I1_E ['Shape'] = listshap
                    df_050_059_MQ_I1_E ['Carat'] = listcar
                    df_050_059_MQ_I1_E ['Color'] = listcol
                    df_050_059_MQ_I1_E ['Clarity'] = listclar
                    df_050_059_MQ_I1_E ['Cut'] = listcut
                    df_050_059_MQ_I1_E ['Polish'] = listpol
                    df_050_059_MQ_I1_E ['Symmetry'] = listsym
                    df_050_059_MQ_I1_E ['Ratio'] = listrat
                    df_050_059_MQ_I1_E ['PPC'] = listdesc
                    df_050_059_MQ_I1_E ['Total'] = listtotal
                    df_050_059_MQ_I1_E['Carat'] = df_050_059_MQ_I1_E['Carat'].astype('float64')
                    df_050_059_MQ_I1_E['PPC'] = df_050_059_MQ_I1_E['PPC'].astype('float64')
                    df_050_059_MQ_I1_E['Total'] = df_050_059_MQ_I1_E['Total'].astype('float64')
                    df_050_059_MQ_I1_E['Total'] = df_050_059_MQ_I1_E['Carat'] * df_050_059_MQ_I1_E['PPC']


                elif i=="E" and j == "I2" and k == "MQ":
                    df_050_059_MQ_I2_E = pd.DataFrame()
                    df_050_059_MQ_I2_E ['Wt Range'] = None
                    df_050_059_MQ_I2_E  = df_050_059_MQ_I2_E.assign(Company=None)
                    df_050_059_MQ_I2_E  = df_050_059_MQ_I2_E.assign(Shape=None)
                    df_050_059_MQ_I2_E  = df_050_059_MQ_I2_E.assign(Carat=None)
                    df_050_059_MQ_I2_E  = df_050_059_MQ_I2_E.assign(Color=None)
                    df_050_059_MQ_I2_E  = df_050_059_MQ_I2_E.assign(Clarity=None)
                    df_050_059_MQ_I2_E  = df_050_059_MQ_I2_E.assign(Cut=None)
                    df_050_059_MQ_I2_E  = df_050_059_MQ_I2_E.assign(Polish=None)
                    df_050_059_MQ_I2_E  = df_050_059_MQ_I2_E.assign(Symmetry=None)
                    df_050_059_MQ_I2_E  = df_050_059_MQ_I2_E.assign(Ratio=None)
                    df_050_059_MQ_I2_E  = df_050_059_MQ_I2_E.assign(PPC=None)
                    df_050_059_MQ_I2_E  = df_050_059_MQ_I2_E.assign(Total=None)
                    df_050_059_MQ_I2_E ['Wt Range'] = listwtrange
                    df_050_059_MQ_I2_E ['Company'] = listcom
                    df_050_059_MQ_I2_E ['Shape'] = listshap
                    df_050_059_MQ_I2_E ['Carat'] = listcar
                    df_050_059_MQ_I2_E ['Color'] = listcol
                    df_050_059_MQ_I2_E ['Clarity'] = listclar
                    df_050_059_MQ_I2_E ['Cut'] = listcut
                    df_050_059_MQ_I2_E ['Polish'] = listpol
                    df_050_059_MQ_I2_E ['Symmetry'] = listsym
                    df_050_059_MQ_I2_E ['Ratio'] = listrat
                    df_050_059_MQ_I2_E ['PPC'] = listdesc
                    df_050_059_MQ_I2_E ['Total'] = listtotal
                    df_050_059_MQ_I2_E['Carat'] = df_050_059_MQ_I2_E['Carat'].astype('float64')
                    df_050_059_MQ_I2_E['PPC'] = df_050_059_MQ_I2_E['PPC'].astype('float64')
                    df_050_059_MQ_I2_E['Total'] = df_050_059_MQ_I2_E['Total'].astype('float64')
                    df_050_059_MQ_I2_E['Total'] = df_050_059_MQ_I2_E['Carat'] * df_050_059_MQ_I2_E['PPC']
                
                elif i=="F" and j == "IF" and k == "MQ":
                    df_050_059_MQ_IF_F = pd.DataFrame()
                    df_050_059_MQ_IF_F ['Wt Range'] = None
                    df_050_059_MQ_IF_F  = df_050_059_MQ_IF_F.assign(Company=None)
                    df_050_059_MQ_IF_F  = df_050_059_MQ_IF_F.assign(Shape=None)
                    df_050_059_MQ_IF_F  = df_050_059_MQ_IF_F.assign(Carat=None)
                    df_050_059_MQ_IF_F  = df_050_059_MQ_IF_F.assign(Color=None)
                    df_050_059_MQ_IF_F  = df_050_059_MQ_IF_F.assign(Clarity=None)
                    df_050_059_MQ_IF_F  = df_050_059_MQ_IF_F.assign(Cut=None)
                    df_050_059_MQ_IF_F  = df_050_059_MQ_IF_F.assign(Polish=None)
                    df_050_059_MQ_IF_F  = df_050_059_MQ_IF_F.assign(Symmetry=None)
                    df_050_059_MQ_IF_F  = df_050_059_MQ_IF_F.assign(Ratio=None)
                    df_050_059_MQ_IF_F  = df_050_059_MQ_IF_F.assign(PPC=None)
                    df_050_059_MQ_IF_F  = df_050_059_MQ_IF_F.assign(Total=None)
                    df_050_059_MQ_IF_F ['Wt Range'] = listwtrange
                    df_050_059_MQ_IF_F ['Company'] = listcom
                    df_050_059_MQ_IF_F ['Shape'] = listshap
                    df_050_059_MQ_IF_F ['Carat'] = listcar
                    df_050_059_MQ_IF_F ['Color'] = listcol
                    df_050_059_MQ_IF_F ['Clarity'] = listclar
                    df_050_059_MQ_IF_F ['Cut'] = listcut
                    df_050_059_MQ_IF_F ['Polish'] = listpol
                    df_050_059_MQ_IF_F ['Symmetry'] = listsym
                    df_050_059_MQ_IF_F ['Ratio'] = listrat
                    df_050_059_MQ_IF_F ['PPC'] = listdesc
                    df_050_059_MQ_IF_F ['Total'] = listtotal
                    df_050_059_MQ_IF_F['Carat'] = df_050_059_MQ_IF_F['Carat'].astype('float64')
                    df_050_059_MQ_IF_F['PPC'] = df_050_059_MQ_IF_F['PPC'].astype('float64')
                    df_050_059_MQ_IF_F['Total'] = df_050_059_MQ_IF_F['Total'].astype('float64')
                    df_050_059_MQ_IF_F['Total'] = df_050_059_MQ_IF_F['Carat'] * df_050_059_MQ_IF_F['PPC']



                elif i=="F" and j == "VVS1" and k == "MQ":
                    df_050_059_MQ_VVS1_F = pd.DataFrame()
                    df_050_059_MQ_VVS1_F ['Wt Range'] = None
                    df_050_059_MQ_VVS1_F  = df_050_059_MQ_VVS1_F.assign(Company=None)
                    df_050_059_MQ_VVS1_F  = df_050_059_MQ_VVS1_F.assign(Shape=None)
                    df_050_059_MQ_VVS1_F  = df_050_059_MQ_VVS1_F.assign(Carat=None)
                    df_050_059_MQ_VVS1_F  = df_050_059_MQ_VVS1_F.assign(Color=None)
                    df_050_059_MQ_VVS1_F  = df_050_059_MQ_VVS1_F.assign(Clarity=None)
                    df_050_059_MQ_VVS1_F  = df_050_059_MQ_VVS1_F.assign(Cut=None)
                    df_050_059_MQ_VVS1_F  = df_050_059_MQ_VVS1_F.assign(Polish=None)
                    df_050_059_MQ_VVS1_F  = df_050_059_MQ_VVS1_F.assign(Symmetry=None)
                    df_050_059_MQ_VVS1_F  = df_050_059_MQ_VVS1_F.assign(Ratio=None)
                    df_050_059_MQ_VVS1_F  = df_050_059_MQ_VVS1_F.assign(PPC=None)
                    df_050_059_MQ_VVS1_F  = df_050_059_MQ_VVS1_F.assign(Total=None)
                    df_050_059_MQ_VVS1_F ['Wt Range'] = listwtrange
                    df_050_059_MQ_VVS1_F ['Company'] = listcom
                    df_050_059_MQ_VVS1_F ['Shape'] = listshap
                    df_050_059_MQ_VVS1_F ['Carat'] = listcar
                    df_050_059_MQ_VVS1_F ['Color'] = listcol
                    df_050_059_MQ_VVS1_F ['Clarity'] = listclar
                    df_050_059_MQ_VVS1_F ['Cut'] = listcut
                    df_050_059_MQ_VVS1_F ['Polish'] = listpol
                    df_050_059_MQ_VVS1_F ['Symmetry'] = listsym
                    df_050_059_MQ_VVS1_F ['Ratio'] = listrat
                    df_050_059_MQ_VVS1_F ['PPC'] = listdesc
                    df_050_059_MQ_VVS1_F ['Total'] = listtotal
                    df_050_059_MQ_VVS1_F['Carat'] = df_050_059_MQ_VVS1_F['Carat'].astype('float64')
                    df_050_059_MQ_VVS1_F['PPC'] = df_050_059_MQ_VVS1_F['PPC'].astype('float64')
                    df_050_059_MQ_VVS1_F['Total'] = df_050_059_MQ_VVS1_F['Total'].astype('float64')
                    df_050_059_MQ_VVS1_F['Total'] = df_050_059_MQ_VVS1_F['Carat'] * df_050_059_MQ_VVS1_F['PPC']


                elif i=="F" and j == "VVS2" and k == "MQ":
                    df_050_059_MQ_VVS2_F = pd.DataFrame()
                    df_050_059_MQ_VVS2_F ['Wt Range'] = None
                    df_050_059_MQ_VVS2_F  = df_050_059_MQ_VVS2_F.assign(Company=None)
                    df_050_059_MQ_VVS2_F  = df_050_059_MQ_VVS2_F.assign(Shape=None)
                    df_050_059_MQ_VVS2_F  = df_050_059_MQ_VVS2_F.assign(Carat=None)
                    df_050_059_MQ_VVS2_F  = df_050_059_MQ_VVS2_F.assign(Color=None)
                    df_050_059_MQ_VVS2_F  = df_050_059_MQ_VVS2_F.assign(Clarity=None)
                    df_050_059_MQ_VVS2_F  = df_050_059_MQ_VVS2_F.assign(Cut=None)
                    df_050_059_MQ_VVS2_F  = df_050_059_MQ_VVS2_F.assign(Polish=None)
                    df_050_059_MQ_VVS2_F  = df_050_059_MQ_VVS2_F.assign(Symmetry=None)
                    df_050_059_MQ_VVS2_F  = df_050_059_MQ_VVS2_F.assign(Ratio=None)
                    df_050_059_MQ_VVS2_F  = df_050_059_MQ_VVS2_F.assign(PPC=None)
                    df_050_059_MQ_VVS2_F  = df_050_059_MQ_VVS2_F.assign(Total=None)
                    df_050_059_MQ_VVS2_F ['Wt Range'] = listwtrange
                    df_050_059_MQ_VVS2_F ['Company'] = listcom
                    df_050_059_MQ_VVS2_F ['Shape'] = listshap
                    df_050_059_MQ_VVS2_F ['Carat'] = listcar
                    df_050_059_MQ_VVS2_F ['Color'] = listcol
                    df_050_059_MQ_VVS2_F ['Clarity'] = listclar
                    df_050_059_MQ_VVS2_F ['Cut'] = listcut
                    df_050_059_MQ_VVS2_F ['Polish'] = listpol
                    df_050_059_MQ_VVS2_F ['Symmetry'] = listsym
                    df_050_059_MQ_VVS2_F ['Ratio'] = listrat
                    df_050_059_MQ_VVS2_F ['PPC'] = listdesc
                    df_050_059_MQ_VVS2_F ['Total'] = listtotal
                    df_050_059_MQ_VVS2_F['Carat'] = df_050_059_MQ_VVS2_F['Carat'].astype('float64')
                    df_050_059_MQ_VVS2_F['PPC'] = df_050_059_MQ_VVS2_F['PPC'].astype('float64')
                    df_050_059_MQ_VVS2_F['Total'] = df_050_059_MQ_VVS2_F['Total'].astype('float64')
                    df_050_059_MQ_VVS2_F['Total'] = df_050_059_MQ_VVS2_F['Carat'] * df_050_059_MQ_VVS2_F['PPC']


                elif i=="F" and j=="VS1" and k == "MQ":
                    df_050_059_MQ_VS1_F = pd.DataFrame()
                    df_050_059_MQ_VS1_F ['Wt Range'] = None
                    df_050_059_MQ_VS1_F  = df_050_059_MQ_VS1_F.assign(Company=None)
                    df_050_059_MQ_VS1_F  = df_050_059_MQ_VS1_F.assign(Shape=None)
                    df_050_059_MQ_VS1_F  = df_050_059_MQ_VS1_F.assign(Carat=None)
                    df_050_059_MQ_VS1_F  = df_050_059_MQ_VS1_F.assign(Color=None)
                    df_050_059_MQ_VS1_F  = df_050_059_MQ_VS1_F.assign(Clarity=None)
                    df_050_059_MQ_VS1_F  = df_050_059_MQ_VS1_F.assign(Cut=None)
                    df_050_059_MQ_VS1_F  = df_050_059_MQ_VS1_F.assign(Polish=None)
                    df_050_059_MQ_VS1_F  = df_050_059_MQ_VS1_F.assign(Symmetry=None)
                    df_050_059_MQ_VS1_F  = df_050_059_MQ_VS1_F.assign(Ratio=None)
                    df_050_059_MQ_VS1_F  = df_050_059_MQ_VS1_F.assign(PPC=None)
                    df_050_059_MQ_VS1_F  = df_050_059_MQ_VS1_F.assign(Total=None)
                    df_050_059_MQ_VS1_F ['Wt Range'] = listwtrange
                    df_050_059_MQ_VS1_F ['Company'] = listcom
                    df_050_059_MQ_VS1_F ['Shape'] = listshap
                    df_050_059_MQ_VS1_F ['Carat'] = listcar
                    df_050_059_MQ_VS1_F ['Color'] = listcol
                    df_050_059_MQ_VS1_F ['Clarity'] = listclar
                    df_050_059_MQ_VS1_F ['Cut'] = listcut
                    df_050_059_MQ_VS1_F ['Polish'] = listpol
                    df_050_059_MQ_VS1_F ['Symmetry'] = listsym
                    df_050_059_MQ_VS1_F ['Ratio'] = listrat
                    df_050_059_MQ_VS1_F ['PPC'] = listdesc
                    df_050_059_MQ_VS1_F ['Total'] = listtotal
                    df_050_059_MQ_VS1_F['Carat'] = df_050_059_MQ_VS1_F['Carat'].astype('float64')
                    df_050_059_MQ_VS1_F['PPC'] = df_050_059_MQ_VS1_F['PPC'].astype('float64')
                    df_050_059_MQ_VS1_F['Total'] = df_050_059_MQ_VS1_F['Total'].astype('float64')
                    df_050_059_MQ_VS1_F['Total'] = df_050_059_MQ_VS1_F['Carat'] * df_050_059_MQ_VS1_F['PPC']


                elif i=="F" and j == "VS2" and k == "MQ":
                    df_050_059_MQ_VS2_F = pd.DataFrame()
                    df_050_059_MQ_VS2_F ['Wt Range'] = None
                    df_050_059_MQ_VS2_F  = df_050_059_MQ_VS2_F.assign(Company=None)
                    df_050_059_MQ_VS2_F  = df_050_059_MQ_VS2_F.assign(Shape=None)
                    df_050_059_MQ_VS2_F  = df_050_059_MQ_VS2_F.assign(Carat=None)
                    df_050_059_MQ_VS2_F  = df_050_059_MQ_VS2_F.assign(Color=None)
                    df_050_059_MQ_VS2_F  = df_050_059_MQ_VS2_F.assign(Clarity=None)
                    df_050_059_MQ_VS2_F  = df_050_059_MQ_VS2_F.assign(Cut=None)
                    df_050_059_MQ_VS2_F  = df_050_059_MQ_VS2_F.assign(Polish=None)
                    df_050_059_MQ_VS2_F  = df_050_059_MQ_VS2_F.assign(Symmetry=None)
                    df_050_059_MQ_VS2_F  = df_050_059_MQ_VS2_F.assign(Ratio=None)
                    df_050_059_MQ_VS2_F  = df_050_059_MQ_VS2_F.assign(PPC=None)
                    df_050_059_MQ_VS2_F  = df_050_059_MQ_VS2_F.assign(Total=None)
                    df_050_059_MQ_VS2_F ['Wt Range'] = listwtrange
                    df_050_059_MQ_VS2_F ['Company'] = listcom
                    df_050_059_MQ_VS2_F ['Shape'] = listshap
                    df_050_059_MQ_VS2_F ['Carat'] = listcar
                    df_050_059_MQ_VS2_F ['Color'] = listcol
                    df_050_059_MQ_VS2_F ['Clarity'] = listclar
                    df_050_059_MQ_VS2_F ['Cut'] = listcut
                    df_050_059_MQ_VS2_F ['Polish'] = listpol
                    df_050_059_MQ_VS2_F ['Symmetry'] = listsym
                    df_050_059_MQ_VS2_F ['Ratio'] = listrat
                    df_050_059_MQ_VS2_F ['PPC'] = listdesc
                    df_050_059_MQ_VS2_F ['Total'] = listtotal
                    df_050_059_MQ_VS2_F['Carat'] = df_050_059_MQ_VS2_F['Carat'].astype('float64')
                    df_050_059_MQ_VS2_F['PPC'] = df_050_059_MQ_VS2_F['PPC'].astype('float64')
                    df_050_059_MQ_VS2_F['Total'] = df_050_059_MQ_VS2_F['Total'].astype('float64')
                    df_050_059_MQ_VS2_F['Total'] = df_050_059_MQ_VS2_F['Carat'] * df_050_059_MQ_VS2_F['PPC']


                elif i=="F" and j == "SI1" and k == "MQ":
                    df_050_059_MQ_SI1_F = pd.DataFrame()
                    df_050_059_MQ_SI1_F ['Wt Range'] = None
                    df_050_059_MQ_SI1_F  = df_050_059_MQ_SI1_F.assign(Company=None)
                    df_050_059_MQ_SI1_F  = df_050_059_MQ_SI1_F.assign(Shape=None)
                    df_050_059_MQ_SI1_F  = df_050_059_MQ_SI1_F.assign(Carat=None)
                    df_050_059_MQ_SI1_F  = df_050_059_MQ_SI1_F.assign(Color=None)
                    df_050_059_MQ_SI1_F  = df_050_059_MQ_SI1_F.assign(Clarity=None)
                    df_050_059_MQ_SI1_F  = df_050_059_MQ_SI1_F.assign(Cut=None)
                    df_050_059_MQ_SI1_F  = df_050_059_MQ_SI1_F.assign(Polish=None)
                    df_050_059_MQ_SI1_F  = df_050_059_MQ_SI1_F.assign(Symmetry=None)
                    df_050_059_MQ_SI1_F  = df_050_059_MQ_SI1_F.assign(Ratio=None)
                    df_050_059_MQ_SI1_F  = df_050_059_MQ_SI1_F.assign(PPC=None)
                    df_050_059_MQ_SI1_F  = df_050_059_MQ_SI1_F.assign(Total=None)
                    df_050_059_MQ_SI1_F ['Wt Range'] = listwtrange
                    df_050_059_MQ_SI1_F ['Company'] = listcom
                    df_050_059_MQ_SI1_F ['Shape'] = listshap
                    df_050_059_MQ_SI1_F ['Carat'] = listcar
                    df_050_059_MQ_SI1_F ['Color'] = listcol
                    df_050_059_MQ_SI1_F ['Clarity'] = listclar
                    df_050_059_MQ_SI1_F ['Cut'] = listcut
                    df_050_059_MQ_SI1_F ['Polish'] = listpol
                    df_050_059_MQ_SI1_F ['Symmetry'] = listsym
                    df_050_059_MQ_SI1_F ['Ratio'] = listrat
                    df_050_059_MQ_SI1_F ['PPC'] = listdesc
                    df_050_059_MQ_SI1_F ['Total'] = listtotal
                    df_050_059_MQ_SI1_F['Carat'] = df_050_059_MQ_SI1_F['Carat'].astype('float64')
                    df_050_059_MQ_SI1_F['PPC'] = df_050_059_MQ_SI1_F['PPC'].astype('float64')
                    df_050_059_MQ_SI1_F['Total'] = df_050_059_MQ_SI1_F['Total'].astype('float64')
                    df_050_059_MQ_SI1_F['Total'] = df_050_059_MQ_SI1_F['Carat'] * df_050_059_MQ_SI1_F['PPC']


                elif i=="F" and j == "SI2" and k == "MQ":
                    df_050_059_MQ_SI2_F = pd.DataFrame()
                    df_050_059_MQ_SI2_F ['Wt Range'] = None
                    df_050_059_MQ_SI2_F  = df_050_059_MQ_SI2_F.assign(Company=None)
                    df_050_059_MQ_SI2_F  = df_050_059_MQ_SI2_F.assign(Shape=None)
                    df_050_059_MQ_SI2_F  = df_050_059_MQ_SI2_F.assign(Carat=None)
                    df_050_059_MQ_SI2_F  = df_050_059_MQ_SI2_F.assign(Color=None)
                    df_050_059_MQ_SI2_F  = df_050_059_MQ_SI2_F.assign(Clarity=None)
                    df_050_059_MQ_SI2_F  = df_050_059_MQ_SI2_F.assign(Cut=None)
                    df_050_059_MQ_SI2_F  = df_050_059_MQ_SI2_F.assign(Polish=None)
                    df_050_059_MQ_SI2_F  = df_050_059_MQ_SI2_F.assign(Symmetry=None)
                    df_050_059_MQ_SI2_F  = df_050_059_MQ_SI2_F.assign(Ratio=None)
                    df_050_059_MQ_SI2_F  = df_050_059_MQ_SI2_F.assign(PPC=None)
                    df_050_059_MQ_SI2_F  = df_050_059_MQ_SI2_F.assign(Total=None)
                    df_050_059_MQ_SI2_F ['Wt Range'] = listwtrange
                    df_050_059_MQ_SI2_F ['Company'] = listcom
                    df_050_059_MQ_SI2_F ['Shape'] = listshap
                    df_050_059_MQ_SI2_F ['Carat'] = listcar
                    df_050_059_MQ_SI2_F ['Color'] = listcol
                    df_050_059_MQ_SI2_F ['Clarity'] = listclar
                    df_050_059_MQ_SI2_F ['Cut'] = listcut
                    df_050_059_MQ_SI2_F ['Polish'] = listpol
                    df_050_059_MQ_SI2_F ['Symmetry'] = listsym
                    df_050_059_MQ_SI2_F ['Ratio'] = listrat
                    df_050_059_MQ_SI2_F ['PPC'] = listdesc
                    df_050_059_MQ_SI2_F ['Total'] = listtotal
                    df_050_059_MQ_SI2_F['Carat'] = df_050_059_MQ_SI2_F['Carat'].astype('float64')
                    df_050_059_MQ_SI2_F['PPC'] = df_050_059_MQ_SI2_F['PPC'].astype('float64')
                    df_050_059_MQ_SI2_F['Total'] = df_050_059_MQ_SI2_F['Total'].astype('float64')
                    df_050_059_MQ_SI2_F['Total'] = df_050_059_MQ_SI2_F['Carat'] * df_050_059_MQ_SI2_F['PPC']


                elif i=="F" and j == "I1" and k == "MQ":
                    df_050_059_MQ_I1_F = pd.DataFrame()
                    df_050_059_MQ_I1_F ['Wt Range'] = None
                    df_050_059_MQ_I1_F  = df_050_059_MQ_I1_F.assign(Company=None)
                    df_050_059_MQ_I1_F  = df_050_059_MQ_I1_F.assign(Shape=None)
                    df_050_059_MQ_I1_F  = df_050_059_MQ_I1_F.assign(Carat=None)
                    df_050_059_MQ_I1_F  = df_050_059_MQ_I1_F.assign(Color=None)
                    df_050_059_MQ_I1_F  = df_050_059_MQ_I1_F.assign(Clarity=None)
                    df_050_059_MQ_I1_F  = df_050_059_MQ_I1_F.assign(Cut=None)
                    df_050_059_MQ_I1_F  = df_050_059_MQ_I1_F.assign(Polish=None)
                    df_050_059_MQ_I1_F  = df_050_059_MQ_I1_F.assign(Symmetry=None)
                    df_050_059_MQ_I1_F  = df_050_059_MQ_I1_F.assign(Ratio=None)
                    df_050_059_MQ_I1_F  = df_050_059_MQ_I1_F.assign(PPC=None)
                    df_050_059_MQ_I1_F  = df_050_059_MQ_I1_F.assign(Total=None)
                    df_050_059_MQ_I1_F ['Wt Range'] = listwtrange
                    df_050_059_MQ_I1_F ['Company'] = listcom
                    df_050_059_MQ_I1_F ['Shape'] = listshap
                    df_050_059_MQ_I1_F ['Carat'] = listcar
                    df_050_059_MQ_I1_F ['Color'] = listcol
                    df_050_059_MQ_I1_F ['Clarity'] = listclar
                    df_050_059_MQ_I1_F ['Cut'] = listcut
                    df_050_059_MQ_I1_F ['Polish'] = listpol
                    df_050_059_MQ_I1_F ['Symmetry'] = listsym
                    df_050_059_MQ_I1_F ['Ratio'] = listrat
                    df_050_059_MQ_I1_F ['PPC'] = listdesc
                    df_050_059_MQ_I1_F ['Total'] = listtotal
                    df_050_059_MQ_I1_F['Carat'] = df_050_059_MQ_I1_F['Carat'].astype('float64')
                    df_050_059_MQ_I1_F['PPC'] = df_050_059_MQ_I1_F['PPC'].astype('float64')
                    df_050_059_MQ_I1_F['Total'] = df_050_059_MQ_I1_F['Total'].astype('float64')
                    df_050_059_MQ_I1_F['Total'] = df_050_059_MQ_I1_F['Carat'] * df_050_059_MQ_I1_F['PPC']


                elif i=="F" and j == "I2" and k == "MQ":
                    df_050_059_MQ_I2_F = pd.DataFrame()
                    df_050_059_MQ_I2_F ['Wt Range'] = None
                    df_050_059_MQ_I2_F  = df_050_059_MQ_I2_F.assign(Company=None)
                    df_050_059_MQ_I2_F  = df_050_059_MQ_I2_F.assign(Shape=None)
                    df_050_059_MQ_I2_F  = df_050_059_MQ_I2_F.assign(Carat=None)
                    df_050_059_MQ_I2_F  = df_050_059_MQ_I2_F.assign(Color=None)
                    df_050_059_MQ_I2_F  = df_050_059_MQ_I2_F.assign(Clarity=None)
                    df_050_059_MQ_I2_F  = df_050_059_MQ_I2_F.assign(Cut=None)
                    df_050_059_MQ_I2_F  = df_050_059_MQ_I2_F.assign(Polish=None)
                    df_050_059_MQ_I2_F  = df_050_059_MQ_I2_F.assign(Symmetry=None)
                    df_050_059_MQ_I2_F  = df_050_059_MQ_I2_F.assign(Ratio=None)
                    df_050_059_MQ_I2_F  = df_050_059_MQ_I2_F.assign(PPC=None)
                    df_050_059_MQ_I2_F  = df_050_059_MQ_I2_F.assign(Total=None)
                    df_050_059_MQ_I2_F ['Wt Range'] = listwtrange
                    df_050_059_MQ_I2_F ['Company'] = listcom
                    df_050_059_MQ_I2_F ['Shape'] = listshap
                    df_050_059_MQ_I2_F ['Carat'] = listcar
                    df_050_059_MQ_I2_F ['Color'] = listcol
                    df_050_059_MQ_I2_F ['Clarity'] = listclar
                    df_050_059_MQ_I2_F ['Cut'] = listcut
                    df_050_059_MQ_I2_F ['Polish'] = listpol
                    df_050_059_MQ_I2_F ['Symmetry'] = listsym
                    df_050_059_MQ_I2_F ['Ratio'] = listrat
                    df_050_059_MQ_I2_F ['PPC'] = listdesc
                    df_050_059_MQ_I2_F ['Total'] = listtotal
                    df_050_059_MQ_I2_F['Carat'] = df_050_059_MQ_I2_F['Carat'].astype('float64')
                    df_050_059_MQ_I2_F['PPC'] = df_050_059_MQ_I2_F['PPC'].astype('float64')
                    df_050_059_MQ_I2_F['Total'] = df_050_059_MQ_I2_F['Total'].astype('float64')
                    df_050_059_MQ_I2_F['Total'] = df_050_059_MQ_I2_F['Carat'] * df_050_059_MQ_I2_F['PPC']


                elif i=="G" and j == "IF" and k == "MQ":
                    df_050_059_MQ_IF_G = pd.DataFrame()
                    df_050_059_MQ_IF_G ['Wt Range'] = None
                    df_050_059_MQ_IF_G  = df_050_059_MQ_IF_G.assign(Company=None)
                    df_050_059_MQ_IF_G  = df_050_059_MQ_IF_G.assign(Shape=None)
                    df_050_059_MQ_IF_G  = df_050_059_MQ_IF_G.assign(Carat=None)
                    df_050_059_MQ_IF_G  = df_050_059_MQ_IF_G.assign(Color=None)
                    df_050_059_MQ_IF_G  = df_050_059_MQ_IF_G.assign(Clarity=None)
                    df_050_059_MQ_IF_G  = df_050_059_MQ_IF_G.assign(Cut=None)
                    df_050_059_MQ_IF_G  = df_050_059_MQ_IF_G.assign(Polish=None)
                    df_050_059_MQ_IF_G  = df_050_059_MQ_IF_G.assign(Symmetry=None)
                    df_050_059_MQ_IF_G  = df_050_059_MQ_IF_G.assign(Ratio=None)
                    df_050_059_MQ_IF_G  = df_050_059_MQ_IF_G.assign(PPC=None)
                    df_050_059_MQ_IF_G  = df_050_059_MQ_IF_G.assign(Total=None)
                    df_050_059_MQ_IF_G ['Wt Range'] = listwtrange
                    df_050_059_MQ_IF_G ['Company'] = listcom
                    df_050_059_MQ_IF_G ['Shape'] = listshap
                    df_050_059_MQ_IF_G ['Carat'] = listcar
                    df_050_059_MQ_IF_G ['Color'] = listcol
                    df_050_059_MQ_IF_G ['Clarity'] = listclar
                    df_050_059_MQ_IF_G ['Cut'] = listcut
                    df_050_059_MQ_IF_G ['Polish'] = listpol
                    df_050_059_MQ_IF_G ['Symmetry'] = listsym
                    df_050_059_MQ_IF_G ['Ratio'] = listrat
                    df_050_059_MQ_IF_G ['PPC'] = listdesc
                    df_050_059_MQ_IF_G ['Total'] = listtotal
                    df_050_059_MQ_IF_G['Carat'] = df_050_059_MQ_IF_G['Carat'].astype('float64')
                    df_050_059_MQ_IF_G['PPC'] = df_050_059_MQ_IF_G['PPC'].astype('float64')
                    df_050_059_MQ_IF_G['Total'] = df_050_059_MQ_IF_G['Total'].astype('float64')
                    df_050_059_MQ_IF_G['Total'] = df_050_059_MQ_IF_G['Carat'] * df_050_059_MQ_IF_G['PPC']



                elif i=="G" and j == "VVS1" and k == "MQ":
                    df_050_059_MQ_VVS1_G = pd.DataFrame()
                    df_050_059_MQ_VVS1_G ['Wt Range'] = None
                    df_050_059_MQ_VVS1_G  = df_050_059_MQ_VVS1_G.assign(Company=None)
                    df_050_059_MQ_VVS1_G  = df_050_059_MQ_VVS1_G.assign(Shape=None)
                    df_050_059_MQ_VVS1_G  = df_050_059_MQ_VVS1_G.assign(Carat=None)
                    df_050_059_MQ_VVS1_G  = df_050_059_MQ_VVS1_G.assign(Color=None)
                    df_050_059_MQ_VVS1_G  = df_050_059_MQ_VVS1_G.assign(Clarity=None)
                    df_050_059_MQ_VVS1_G  = df_050_059_MQ_VVS1_G.assign(Cut=None)
                    df_050_059_MQ_VVS1_G  = df_050_059_MQ_VVS1_G.assign(Polish=None)
                    df_050_059_MQ_VVS1_G  = df_050_059_MQ_VVS1_G.assign(Symmetry=None)
                    df_050_059_MQ_VVS1_G  = df_050_059_MQ_VVS1_G.assign(Ratio=None)
                    df_050_059_MQ_VVS1_G  = df_050_059_MQ_VVS1_G.assign(PPC=None)
                    df_050_059_MQ_VVS1_G  = df_050_059_MQ_VVS1_G.assign(Total=None)
                    df_050_059_MQ_VVS1_G ['Wt Range'] = listwtrange
                    df_050_059_MQ_VVS1_G ['Company'] = listcom
                    df_050_059_MQ_VVS1_G ['Shape'] = listshap
                    df_050_059_MQ_VVS1_G ['Carat'] = listcar
                    df_050_059_MQ_VVS1_G ['Color'] = listcol
                    df_050_059_MQ_VVS1_G ['Clarity'] = listclar
                    df_050_059_MQ_VVS1_G ['Cut'] = listcut
                    df_050_059_MQ_VVS1_G ['Polish'] = listpol
                    df_050_059_MQ_VVS1_G ['Symmetry'] = listsym
                    df_050_059_MQ_VVS1_G ['Ratio'] = listrat
                    df_050_059_MQ_VVS1_G ['PPC'] = listdesc
                    df_050_059_MQ_VVS1_G ['Total'] = listtotal
                    df_050_059_MQ_VVS1_G['Carat'] = df_050_059_MQ_VVS1_G['Carat'].astype('float64')
                    df_050_059_MQ_VVS1_G['PPC'] = df_050_059_MQ_VVS1_G['PPC'].astype('float64')
                    df_050_059_MQ_VVS1_G['Total'] = df_050_059_MQ_VVS1_G['Total'].astype('float64')
                    df_050_059_MQ_VVS1_G['Total'] = df_050_059_MQ_VVS1_G['Carat'] * df_050_059_MQ_VVS1_G['PPC']


                elif i=="G" and j == "VVS2" and k == "MQ":
                    df_050_059_MQ_VVS2_G = pd.DataFrame()
                    df_050_059_MQ_VVS2_G ['Wt Range'] = None
                    df_050_059_MQ_VVS2_G  = df_050_059_MQ_VVS2_G.assign(Company=None)
                    df_050_059_MQ_VVS2_G  = df_050_059_MQ_VVS2_G.assign(Shape=None)
                    df_050_059_MQ_VVS2_G  = df_050_059_MQ_VVS2_G.assign(Carat=None)
                    df_050_059_MQ_VVS2_G  = df_050_059_MQ_VVS2_G.assign(Color=None)
                    df_050_059_MQ_VVS2_G  = df_050_059_MQ_VVS2_G.assign(Clarity=None)
                    df_050_059_MQ_VVS2_G  = df_050_059_MQ_VVS2_G.assign(Cut=None)
                    df_050_059_MQ_VVS2_G  = df_050_059_MQ_VVS2_G.assign(Polish=None)
                    df_050_059_MQ_VVS2_G  = df_050_059_MQ_VVS2_G.assign(Symmetry=None)
                    df_050_059_MQ_VVS2_G  = df_050_059_MQ_VVS2_G.assign(Ratio=None)
                    df_050_059_MQ_VVS2_G  = df_050_059_MQ_VVS2_G.assign(PPC=None)
                    df_050_059_MQ_VVS2_G  = df_050_059_MQ_VVS2_G.assign(Total=None)
                    df_050_059_MQ_VVS2_G ['Wt Range'] = listwtrange
                    df_050_059_MQ_VVS2_G ['Company'] = listcom
                    df_050_059_MQ_VVS2_G ['Shape'] = listshap
                    df_050_059_MQ_VVS2_G ['Carat'] = listcar
                    df_050_059_MQ_VVS2_G ['Color'] = listcol
                    df_050_059_MQ_VVS2_G ['Clarity'] = listclar
                    df_050_059_MQ_VVS2_G ['Cut'] = listcut
                    df_050_059_MQ_VVS2_G ['Polish'] = listpol
                    df_050_059_MQ_VVS2_G ['Symmetry'] = listsym
                    df_050_059_MQ_VVS2_G ['Ratio'] = listrat
                    df_050_059_MQ_VVS2_G ['PPC'] = listdesc
                    df_050_059_MQ_VVS2_G ['Total'] = listtotal
                    df_050_059_MQ_VVS2_G['Carat'] = df_050_059_MQ_VVS2_G['Carat'].astype('float64')
                    df_050_059_MQ_VVS2_G['PPC'] = df_050_059_MQ_VVS2_G['PPC'].astype('float64')
                    df_050_059_MQ_VVS2_G['Total'] = df_050_059_MQ_VVS2_G['Total'].astype('float64')
                    df_050_059_MQ_VVS2_G['Total'] = df_050_059_MQ_VVS2_G['Carat'] * df_050_059_MQ_VVS2_G['PPC']


                elif i=="G" and j=="VS1" and k == "MQ":
                    df_050_059_MQ_VS1_G = pd.DataFrame()
                    df_050_059_MQ_VS1_G ['Wt Range'] = None
                    df_050_059_MQ_VS1_G  = df_050_059_MQ_VS1_G.assign(Company=None)
                    df_050_059_MQ_VS1_G  = df_050_059_MQ_VS1_G.assign(Shape=None)
                    df_050_059_MQ_VS1_G  = df_050_059_MQ_VS1_G.assign(Carat=None)
                    df_050_059_MQ_VS1_G  = df_050_059_MQ_VS1_G.assign(Color=None)
                    df_050_059_MQ_VS1_G  = df_050_059_MQ_VS1_G.assign(Clarity=None)
                    df_050_059_MQ_VS1_G  = df_050_059_MQ_VS1_G.assign(Cut=None)
                    df_050_059_MQ_VS1_G  = df_050_059_MQ_VS1_G.assign(Polish=None)
                    df_050_059_MQ_VS1_G  = df_050_059_MQ_VS1_G.assign(Symmetry=None)
                    df_050_059_MQ_VS1_G  = df_050_059_MQ_VS1_G.assign(Ratio=None)
                    df_050_059_MQ_VS1_G  = df_050_059_MQ_VS1_G.assign(PPC=None)
                    df_050_059_MQ_VS1_G  = df_050_059_MQ_VS1_G.assign(Total=None)
                    df_050_059_MQ_VS1_G ['Wt Range'] = listwtrange
                    df_050_059_MQ_VS1_G ['Company'] = listcom
                    df_050_059_MQ_VS1_G ['Shape'] = listshap
                    df_050_059_MQ_VS1_G ['Carat'] = listcar
                    df_050_059_MQ_VS1_G ['Color'] = listcol
                    df_050_059_MQ_VS1_G ['Clarity'] = listclar
                    df_050_059_MQ_VS1_G ['Cut'] = listcut
                    df_050_059_MQ_VS1_G ['Polish'] = listpol
                    df_050_059_MQ_VS1_G ['Symmetry'] = listsym
                    df_050_059_MQ_VS1_G ['Ratio'] = listrat
                    df_050_059_MQ_VS1_G ['PPC'] = listdesc
                    df_050_059_MQ_VS1_G ['Total'] = listtotal
                    df_050_059_MQ_VS1_G['Carat'] = df_050_059_MQ_VS1_G['Carat'].astype('float64')
                    df_050_059_MQ_VS1_G['PPC'] = df_050_059_MQ_VS1_G['PPC'].astype('float64')
                    df_050_059_MQ_VS1_G['Total'] = df_050_059_MQ_VS1_G['Total'].astype('float64')
                    df_050_059_MQ_VS1_G['Total'] = df_050_059_MQ_VS1_G['Carat'] * df_050_059_MQ_VS1_G['PPC']


                elif i=="G" and j == "VS2" and k == "MQ":
                    df_050_059_MQ_VS2_G = pd.DataFrame()
                    df_050_059_MQ_VS2_G ['Wt Range'] = None
                    df_050_059_MQ_VS2_G  = df_050_059_MQ_VS2_G.assign(Company=None)
                    df_050_059_MQ_VS2_G  = df_050_059_MQ_VS2_G.assign(Shape=None)
                    df_050_059_MQ_VS2_G  = df_050_059_MQ_VS2_G.assign(Carat=None)
                    df_050_059_MQ_VS2_G  = df_050_059_MQ_VS2_G.assign(Color=None)
                    df_050_059_MQ_VS2_G  = df_050_059_MQ_VS2_G.assign(Clarity=None)
                    df_050_059_MQ_VS2_G  = df_050_059_MQ_VS2_G.assign(Cut=None)
                    df_050_059_MQ_VS2_G  = df_050_059_MQ_VS2_G.assign(Polish=None)
                    df_050_059_MQ_VS2_G  = df_050_059_MQ_VS2_G.assign(Symmetry=None)
                    df_050_059_MQ_VS2_G  = df_050_059_MQ_VS2_G.assign(Ratio=None)
                    df_050_059_MQ_VS2_G  = df_050_059_MQ_VS2_G.assign(PPC=None)
                    df_050_059_MQ_VS2_G  = df_050_059_MQ_VS2_G.assign(Total=None)
                    df_050_059_MQ_VS2_G ['Wt Range'] = listwtrange
                    df_050_059_MQ_VS2_G ['Company'] = listcom
                    df_050_059_MQ_VS2_G ['Shape'] = listshap
                    df_050_059_MQ_VS2_G ['Carat'] = listcar
                    df_050_059_MQ_VS2_G ['Color'] = listcol
                    df_050_059_MQ_VS2_G ['Clarity'] = listclar
                    df_050_059_MQ_VS2_G ['Cut'] = listcut
                    df_050_059_MQ_VS2_G ['Polish'] = listpol
                    df_050_059_MQ_VS2_G ['Symmetry'] = listsym
                    df_050_059_MQ_VS2_G ['Ratio'] = listrat
                    df_050_059_MQ_VS2_G ['PPC'] = listdesc
                    df_050_059_MQ_VS2_G ['Total'] = listtotal
                    df_050_059_MQ_VS2_G['Carat'] = df_050_059_MQ_VS2_G['Carat'].astype('float64')
                    df_050_059_MQ_VS2_G['PPC'] = df_050_059_MQ_VS2_G['PPC'].astype('float64')
                    df_050_059_MQ_VS2_G['Total'] = df_050_059_MQ_VS2_G['Total'].astype('float64')
                    df_050_059_MQ_VS2_G['Total'] = df_050_059_MQ_VS2_G['Carat'] * df_050_059_MQ_VS2_G['PPC']


                elif i=="G" and j == "SI1" and k == "MQ":
                    df_050_059_MQ_SI1_G = pd.DataFrame()
                    df_050_059_MQ_SI1_G ['Wt Range'] = None
                    df_050_059_MQ_SI1_G  = df_050_059_MQ_SI1_G.assign(Company=None)
                    df_050_059_MQ_SI1_G  = df_050_059_MQ_SI1_G.assign(Shape=None)
                    df_050_059_MQ_SI1_G  = df_050_059_MQ_SI1_G.assign(Carat=None)
                    df_050_059_MQ_SI1_G  = df_050_059_MQ_SI1_G.assign(Color=None)
                    df_050_059_MQ_SI1_G  = df_050_059_MQ_SI1_G.assign(Clarity=None)
                    df_050_059_MQ_SI1_G  = df_050_059_MQ_SI1_G.assign(Cut=None)
                    df_050_059_MQ_SI1_G  = df_050_059_MQ_SI1_G.assign(Polish=None)
                    df_050_059_MQ_SI1_G  = df_050_059_MQ_SI1_G.assign(Symmetry=None)
                    df_050_059_MQ_SI1_G  = df_050_059_MQ_SI1_G.assign(Ratio=None)
                    df_050_059_MQ_SI1_G  = df_050_059_MQ_SI1_G.assign(PPC=None)
                    df_050_059_MQ_SI1_G  = df_050_059_MQ_SI1_G.assign(Total=None)
                    df_050_059_MQ_SI1_G ['Wt Range'] = listwtrange
                    df_050_059_MQ_SI1_G ['Company'] = listcom
                    df_050_059_MQ_SI1_G ['Shape'] = listshap
                    df_050_059_MQ_SI1_G ['Carat'] = listcar
                    df_050_059_MQ_SI1_G ['Color'] = listcol
                    df_050_059_MQ_SI1_G ['Clarity'] = listclar
                    df_050_059_MQ_SI1_G ['Cut'] = listcut
                    df_050_059_MQ_SI1_G ['Polish'] = listpol
                    df_050_059_MQ_SI1_G ['Symmetry'] = listsym
                    df_050_059_MQ_SI1_G ['Ratio'] = listrat
                    df_050_059_MQ_SI1_G ['PPC'] = listdesc
                    df_050_059_MQ_SI1_G ['Total'] = listtotal
                    df_050_059_MQ_SI1_G['Carat'] = df_050_059_MQ_SI1_G['Carat'].astype('float64')
                    df_050_059_MQ_SI1_G['PPC'] = df_050_059_MQ_SI1_G['PPC'].astype('float64')
                    df_050_059_MQ_SI1_G['Total'] = df_050_059_MQ_SI1_G['Total'].astype('float64')
                    df_050_059_MQ_SI1_G['Total'] = df_050_059_MQ_SI1_G['Carat'] * df_050_059_MQ_SI1_G['PPC']


                elif i=="G" and j == "SI2" and k == "MQ":
                    df_050_059_MQ_SI2_G = pd.DataFrame()
                    df_050_059_MQ_SI2_G ['Wt Range'] = None
                    df_050_059_MQ_SI2_G  = df_050_059_MQ_SI2_G.assign(Company=None)
                    df_050_059_MQ_SI2_G  = df_050_059_MQ_SI2_G.assign(Shape=None)
                    df_050_059_MQ_SI2_G  = df_050_059_MQ_SI2_G.assign(Carat=None)
                    df_050_059_MQ_SI2_G  = df_050_059_MQ_SI2_G.assign(Color=None)
                    df_050_059_MQ_SI2_G  = df_050_059_MQ_SI2_G.assign(Clarity=None)
                    df_050_059_MQ_SI2_G  = df_050_059_MQ_SI2_G.assign(Cut=None)
                    df_050_059_MQ_SI2_G  = df_050_059_MQ_SI2_G.assign(Polish=None)
                    df_050_059_MQ_SI2_G  = df_050_059_MQ_SI2_G.assign(Symmetry=None)
                    df_050_059_MQ_SI2_G  = df_050_059_MQ_SI2_G.assign(Ratio=None)
                    df_050_059_MQ_SI2_G  = df_050_059_MQ_SI2_G.assign(PPC=None)
                    df_050_059_MQ_SI2_G  = df_050_059_MQ_SI2_G.assign(Total=None)
                    df_050_059_MQ_SI2_G ['Wt Range'] = listwtrange
                    df_050_059_MQ_SI2_G ['Company'] = listcom
                    df_050_059_MQ_SI2_G ['Shape'] = listshap
                    df_050_059_MQ_SI2_G ['Carat'] = listcar
                    df_050_059_MQ_SI2_G ['Color'] = listcol
                    df_050_059_MQ_SI2_G ['Clarity'] = listclar
                    df_050_059_MQ_SI2_G ['Cut'] = listcut
                    df_050_059_MQ_SI2_G ['Polish'] = listpol
                    df_050_059_MQ_SI2_G ['Symmetry'] = listsym
                    df_050_059_MQ_SI2_G ['Ratio'] = listrat
                    df_050_059_MQ_SI2_G ['PPC'] = listdesc
                    df_050_059_MQ_SI2_G ['Total'] = listtotal
                    df_050_059_MQ_SI2_G['Carat'] = df_050_059_MQ_SI2_G['Carat'].astype('float64')
                    df_050_059_MQ_SI2_G['PPC'] = df_050_059_MQ_SI2_G['PPC'].astype('float64')
                    df_050_059_MQ_SI2_G['Total'] = df_050_059_MQ_SI2_G['Total'].astype('float64')
                    df_050_059_MQ_SI2_G['Total'] = df_050_059_MQ_SI2_G['Carat'] * df_050_059_MQ_SI2_G['PPC']


                elif i=="G" and j == "I1" and k == "MQ":
                    df_050_059_MQ_I1_G = pd.DataFrame()
                    df_050_059_MQ_I1_G ['Wt Range'] = None
                    df_050_059_MQ_I1_G  = df_050_059_MQ_I1_G.assign(Company=None)
                    df_050_059_MQ_I1_G  = df_050_059_MQ_I1_G.assign(Shape=None)
                    df_050_059_MQ_I1_G  = df_050_059_MQ_I1_G.assign(Carat=None)
                    df_050_059_MQ_I1_G  = df_050_059_MQ_I1_G.assign(Color=None)
                    df_050_059_MQ_I1_G  = df_050_059_MQ_I1_G.assign(Clarity=None)
                    df_050_059_MQ_I1_G  = df_050_059_MQ_I1_G.assign(Cut=None)
                    df_050_059_MQ_I1_G  = df_050_059_MQ_I1_G.assign(Polish=None)
                    df_050_059_MQ_I1_G  = df_050_059_MQ_I1_G.assign(Symmetry=None)
                    df_050_059_MQ_I1_G  = df_050_059_MQ_I1_G.assign(Ratio=None)
                    df_050_059_MQ_I1_G  = df_050_059_MQ_I1_G.assign(PPC=None)
                    df_050_059_MQ_I1_G  = df_050_059_MQ_I1_G.assign(Total=None)
                    df_050_059_MQ_I1_G ['Wt Range'] = listwtrange
                    df_050_059_MQ_I1_G ['Company'] = listcom
                    df_050_059_MQ_I1_G ['Shape'] = listshap
                    df_050_059_MQ_I1_G ['Carat'] = listcar
                    df_050_059_MQ_I1_G ['Color'] = listcol
                    df_050_059_MQ_I1_G ['Clarity'] = listclar
                    df_050_059_MQ_I1_G ['Cut'] = listcut
                    df_050_059_MQ_I1_G ['Polish'] = listpol
                    df_050_059_MQ_I1_G ['Symmetry'] = listsym
                    df_050_059_MQ_I1_G ['Ratio'] = listrat
                    df_050_059_MQ_I1_G ['PPC'] = listdesc
                    df_050_059_MQ_I1_G ['Total'] = listtotal
                    df_050_059_MQ_I1_G['Carat'] = df_050_059_MQ_I1_G['Carat'].astype('float64')
                    df_050_059_MQ_I1_G['PPC'] = df_050_059_MQ_I1_G['PPC'].astype('float64')
                    df_050_059_MQ_I1_G['Total'] = df_050_059_MQ_I1_G['Total'].astype('float64')
                    df_050_059_MQ_I1_G['Total'] = df_050_059_MQ_I1_G['Carat'] * df_050_059_MQ_I1_G['PPC']


                elif i=="G" and j == "I2" and k == "MQ":
                    df_050_059_MQ_I2_G = pd.DataFrame()
                    df_050_059_MQ_I2_G ['Wt Range'] = None
                    df_050_059_MQ_I2_G  = df_050_059_MQ_I2_G.assign(Company=None)
                    df_050_059_MQ_I2_G  = df_050_059_MQ_I2_G.assign(Shape=None)
                    df_050_059_MQ_I2_G  = df_050_059_MQ_I2_G.assign(Carat=None)
                    df_050_059_MQ_I2_G  = df_050_059_MQ_I2_G.assign(Color=None)
                    df_050_059_MQ_I2_G  = df_050_059_MQ_I2_G.assign(Clarity=None)
                    df_050_059_MQ_I2_G  = df_050_059_MQ_I2_G.assign(Cut=None)
                    df_050_059_MQ_I2_G  = df_050_059_MQ_I2_G.assign(Polish=None)
                    df_050_059_MQ_I2_G  = df_050_059_MQ_I2_G.assign(Symmetry=None)
                    df_050_059_MQ_I2_G  = df_050_059_MQ_I2_G.assign(Ratio=None)
                    df_050_059_MQ_I2_G  = df_050_059_MQ_I2_G.assign(PPC=None)
                    df_050_059_MQ_I2_G  = df_050_059_MQ_I2_G.assign(Total=None)
                    df_050_059_MQ_I2_G ['Wt Range'] = listwtrange
                    df_050_059_MQ_I2_G ['Company'] = listcom
                    df_050_059_MQ_I2_G ['Shape'] = listshap
                    df_050_059_MQ_I2_G ['Carat'] = listcar
                    df_050_059_MQ_I2_G ['Color'] = listcol
                    df_050_059_MQ_I2_G ['Clarity'] = listclar
                    df_050_059_MQ_I2_G ['Cut'] = listcut
                    df_050_059_MQ_I2_G ['Polish'] = listpol
                    df_050_059_MQ_I2_G ['Symmetry'] = listsym
                    df_050_059_MQ_I2_G ['Ratio'] = listrat
                    df_050_059_MQ_I2_G ['PPC'] = listdesc
                    df_050_059_MQ_I2_G ['Total'] = listtotal
                    df_050_059_MQ_I2_G['Carat'] = df_050_059_MQ_I2_G['Carat'].astype('float64')
                    df_050_059_MQ_I2_G['PPC'] = df_050_059_MQ_I2_G['PPC'].astype('float64')
                    df_050_059_MQ_I2_G['Total'] = df_050_059_MQ_I2_G['Total'].astype('float64')
                    df_050_059_MQ_I2_G['Total'] = df_050_059_MQ_I2_G['Carat'] * df_050_059_MQ_I2_G['PPC']


                elif i=="H" and j == "IF" and k == "MQ":
                    df_050_059_MQ_IF_H = pd.DataFrame()
                    df_050_059_MQ_IF_H ['Wt Range'] = None
                    df_050_059_MQ_IF_H  = df_050_059_MQ_IF_H.assign(Company=None)
                    df_050_059_MQ_IF_H  = df_050_059_MQ_IF_H.assign(Shape=None)
                    df_050_059_MQ_IF_H  = df_050_059_MQ_IF_H.assign(Carat=None)
                    df_050_059_MQ_IF_H  = df_050_059_MQ_IF_H.assign(Color=None)
                    df_050_059_MQ_IF_H  = df_050_059_MQ_IF_H.assign(Clarity=None)
                    df_050_059_MQ_IF_H  = df_050_059_MQ_IF_H.assign(Cut=None)
                    df_050_059_MQ_IF_H  = df_050_059_MQ_IF_H.assign(Polish=None)
                    df_050_059_MQ_IF_H  = df_050_059_MQ_IF_H.assign(Symmetry=None)
                    df_050_059_MQ_IF_H  = df_050_059_MQ_IF_H.assign(Ratio=None)
                    df_050_059_MQ_IF_H  = df_050_059_MQ_IF_H.assign(PPC=None)
                    df_050_059_MQ_IF_H  = df_050_059_MQ_IF_H.assign(Total=None)
                    df_050_059_MQ_IF_H ['Wt Range'] = listwtrange
                    df_050_059_MQ_IF_H ['Company'] = listcom
                    df_050_059_MQ_IF_H ['Shape'] = listshap
                    df_050_059_MQ_IF_H ['Carat'] = listcar
                    df_050_059_MQ_IF_H ['Color'] = listcol
                    df_050_059_MQ_IF_H ['Clarity'] = listclar
                    df_050_059_MQ_IF_H ['Cut'] = listcut
                    df_050_059_MQ_IF_H ['Polish'] = listpol
                    df_050_059_MQ_IF_H ['Symmetry'] = listsym
                    df_050_059_MQ_IF_H ['Ratio'] = listrat
                    df_050_059_MQ_IF_H ['PPC'] = listdesc
                    df_050_059_MQ_IF_H ['Total'] = listtotal
                    df_050_059_MQ_IF_H['Carat'] = df_050_059_MQ_IF_H['Carat'].astype('float64')
                    df_050_059_MQ_IF_H['PPC'] = df_050_059_MQ_IF_H['PPC'].astype('float64')
                    df_050_059_MQ_IF_H['Total'] = df_050_059_MQ_IF_H['Total'].astype('float64')
                    df_050_059_MQ_IF_H['Total'] = df_050_059_MQ_IF_H['Carat'] * df_050_059_MQ_IF_H['PPC']



                elif i=="H" and j == "VVS1" and k == "MQ":
                    df_050_059_MQ_VVS1_H = pd.DataFrame()
                    df_050_059_MQ_VVS1_H ['Wt Range'] = None
                    df_050_059_MQ_VVS1_H  = df_050_059_MQ_VVS1_H.assign(Company=None)
                    df_050_059_MQ_VVS1_H  = df_050_059_MQ_VVS1_H.assign(Shape=None)
                    df_050_059_MQ_VVS1_H  = df_050_059_MQ_VVS1_H.assign(Carat=None)
                    df_050_059_MQ_VVS1_H  = df_050_059_MQ_VVS1_H.assign(Color=None)
                    df_050_059_MQ_VVS1_H  = df_050_059_MQ_VVS1_H.assign(Clarity=None)
                    df_050_059_MQ_VVS1_H  = df_050_059_MQ_VVS1_H.assign(Cut=None)
                    df_050_059_MQ_VVS1_H  = df_050_059_MQ_VVS1_H.assign(Polish=None)
                    df_050_059_MQ_VVS1_H  = df_050_059_MQ_VVS1_H.assign(Symmetry=None)
                    df_050_059_MQ_VVS1_H  = df_050_059_MQ_VVS1_H.assign(Ratio=None)
                    df_050_059_MQ_VVS1_H  = df_050_059_MQ_VVS1_H.assign(PPC=None)
                    df_050_059_MQ_VVS1_H  = df_050_059_MQ_VVS1_H.assign(Total=None)
                    df_050_059_MQ_VVS1_H ['Wt Range'] = listwtrange
                    df_050_059_MQ_VVS1_H ['Company'] = listcom
                    df_050_059_MQ_VVS1_H ['Shape'] = listshap
                    df_050_059_MQ_VVS1_H ['Carat'] = listcar
                    df_050_059_MQ_VVS1_H ['Color'] = listcol
                    df_050_059_MQ_VVS1_H ['Clarity'] = listclar
                    df_050_059_MQ_VVS1_H ['Cut'] = listcut
                    df_050_059_MQ_VVS1_H ['Polish'] = listpol
                    df_050_059_MQ_VVS1_H ['Symmetry'] = listsym
                    df_050_059_MQ_VVS1_H ['Ratio'] = listrat
                    df_050_059_MQ_VVS1_H ['PPC'] = listdesc
                    df_050_059_MQ_VVS1_H ['Total'] = listtotal
                    df_050_059_MQ_VVS1_H['Carat'] = df_050_059_MQ_VVS1_H['Carat'].astype('float64')
                    df_050_059_MQ_VVS1_H['PPC'] = df_050_059_MQ_VVS1_H['PPC'].astype('float64')
                    df_050_059_MQ_VVS1_H['Total'] = df_050_059_MQ_VVS1_H['Total'].astype('float64')
                    df_050_059_MQ_VVS1_H['Total'] = df_050_059_MQ_VVS1_H['Carat'] * df_050_059_MQ_VVS1_H['PPC']


                elif i=="H" and j == "VVS2" and k == "MQ":
                    df_050_059_MQ_VVS2_H = pd.DataFrame()
                    df_050_059_MQ_VVS2_H ['Wt Range'] = None
                    df_050_059_MQ_VVS2_H  = df_050_059_MQ_VVS2_H.assign(Company=None)
                    df_050_059_MQ_VVS2_H  = df_050_059_MQ_VVS2_H.assign(Shape=None)
                    df_050_059_MQ_VVS2_H  = df_050_059_MQ_VVS2_H.assign(Carat=None)
                    df_050_059_MQ_VVS2_H  = df_050_059_MQ_VVS2_H.assign(Color=None)
                    df_050_059_MQ_VVS2_H  = df_050_059_MQ_VVS2_H.assign(Clarity=None)
                    df_050_059_MQ_VVS2_H  = df_050_059_MQ_VVS2_H.assign(Cut=None)
                    df_050_059_MQ_VVS2_H  = df_050_059_MQ_VVS2_H.assign(Polish=None)
                    df_050_059_MQ_VVS2_H  = df_050_059_MQ_VVS2_H.assign(Symmetry=None)
                    df_050_059_MQ_VVS2_H  = df_050_059_MQ_VVS2_H.assign(Ratio=None)
                    df_050_059_MQ_VVS2_H  = df_050_059_MQ_VVS2_H.assign(PPC=None)
                    df_050_059_MQ_VVS2_H  = df_050_059_MQ_VVS2_H.assign(Total=None)
                    df_050_059_MQ_VVS2_H ['Wt Range'] = listwtrange
                    df_050_059_MQ_VVS2_H ['Company'] = listcom
                    df_050_059_MQ_VVS2_H ['Shape'] = listshap
                    df_050_059_MQ_VVS2_H ['Carat'] = listcar
                    df_050_059_MQ_VVS2_H ['Color'] = listcol
                    df_050_059_MQ_VVS2_H ['Clarity'] = listclar
                    df_050_059_MQ_VVS2_H ['Cut'] = listcut
                    df_050_059_MQ_VVS2_H ['Polish'] = listpol
                    df_050_059_MQ_VVS2_H ['Symmetry'] = listsym
                    df_050_059_MQ_VVS2_H ['Ratio'] = listrat
                    df_050_059_MQ_VVS2_H ['PPC'] = listdesc
                    df_050_059_MQ_VVS2_H ['Total'] = listtotal
                    df_050_059_MQ_VVS2_H['Carat'] = df_050_059_MQ_VVS2_H['Carat'].astype('float64')
                    df_050_059_MQ_VVS2_H['PPC'] = df_050_059_MQ_VVS2_H['PPC'].astype('float64')
                    df_050_059_MQ_VVS2_H['Total'] = df_050_059_MQ_VVS2_H['Total'].astype('float64')
                    df_050_059_MQ_VVS2_H['Total'] = df_050_059_MQ_VVS2_H['Carat'] * df_050_059_MQ_VVS2_H['PPC']


                elif i=="H" and j=="VS1" and k == "MQ":
                    df_050_059_MQ_VS1_H = pd.DataFrame()
                    df_050_059_MQ_VS1_H ['Wt Range'] = None
                    df_050_059_MQ_VS1_H  = df_050_059_MQ_VS1_H.assign(Company=None)
                    df_050_059_MQ_VS1_H  = df_050_059_MQ_VS1_H.assign(Shape=None)
                    df_050_059_MQ_VS1_H  = df_050_059_MQ_VS1_H.assign(Carat=None)
                    df_050_059_MQ_VS1_H  = df_050_059_MQ_VS1_H.assign(Color=None)
                    df_050_059_MQ_VS1_H  = df_050_059_MQ_VS1_H.assign(Clarity=None)
                    df_050_059_MQ_VS1_H  = df_050_059_MQ_VS1_H.assign(Cut=None)
                    df_050_059_MQ_VS1_H  = df_050_059_MQ_VS1_H.assign(Polish=None)
                    df_050_059_MQ_VS1_H  = df_050_059_MQ_VS1_H.assign(Symmetry=None)
                    df_050_059_MQ_VS1_H  = df_050_059_MQ_VS1_H.assign(Ratio=None)
                    df_050_059_MQ_VS1_H  = df_050_059_MQ_VS1_H.assign(PPC=None)
                    df_050_059_MQ_VS1_H  = df_050_059_MQ_VS1_H.assign(Total=None)
                    df_050_059_MQ_VS1_H ['Wt Range'] = listwtrange
                    df_050_059_MQ_VS1_H ['Company'] = listcom
                    df_050_059_MQ_VS1_H ['Shape'] = listshap
                    df_050_059_MQ_VS1_H ['Carat'] = listcar
                    df_050_059_MQ_VS1_H ['Color'] = listcol
                    df_050_059_MQ_VS1_H ['Clarity'] = listclar
                    df_050_059_MQ_VS1_H ['Cut'] = listcut
                    df_050_059_MQ_VS1_H ['Polish'] = listpol
                    df_050_059_MQ_VS1_H ['Symmetry'] = listsym
                    df_050_059_MQ_VS1_H ['Ratio'] = listrat
                    df_050_059_MQ_VS1_H ['PPC'] = listdesc
                    df_050_059_MQ_VS1_H ['Total'] = listtotal
                    df_050_059_MQ_VS1_H['Carat'] = df_050_059_MQ_VS1_H['Carat'].astype('float64')
                    df_050_059_MQ_VS1_H['PPC'] = df_050_059_MQ_VS1_H['PPC'].astype('float64')
                    df_050_059_MQ_VS1_H['Total'] = df_050_059_MQ_VS1_H['Total'].astype('float64')
                    df_050_059_MQ_VS1_H['Total'] = df_050_059_MQ_VS1_H['Carat'] * df_050_059_MQ_VS1_H['PPC']


                elif i=="H" and j == "VS2" and k == "MQ":
                    df_050_059_MQ_VS2_H = pd.DataFrame()
                    df_050_059_MQ_VS2_H ['Wt Range'] = None
                    df_050_059_MQ_VS2_H  = df_050_059_MQ_VS2_H.assign(Company=None)
                    df_050_059_MQ_VS2_H  = df_050_059_MQ_VS2_H.assign(Shape=None)
                    df_050_059_MQ_VS2_H  = df_050_059_MQ_VS2_H.assign(Carat=None)
                    df_050_059_MQ_VS2_H  = df_050_059_MQ_VS2_H.assign(Color=None)
                    df_050_059_MQ_VS2_H  = df_050_059_MQ_VS2_H.assign(Clarity=None)
                    df_050_059_MQ_VS2_H  = df_050_059_MQ_VS2_H.assign(Cut=None)
                    df_050_059_MQ_VS2_H  = df_050_059_MQ_VS2_H.assign(Polish=None)
                    df_050_059_MQ_VS2_H  = df_050_059_MQ_VS2_H.assign(Symmetry=None)
                    df_050_059_MQ_VS2_H  = df_050_059_MQ_VS2_H.assign(Ratio=None)
                    df_050_059_MQ_VS2_H  = df_050_059_MQ_VS2_H.assign(PPC=None)
                    df_050_059_MQ_VS2_H  = df_050_059_MQ_VS2_H.assign(Total=None)
                    df_050_059_MQ_VS2_H ['Wt Range'] = listwtrange
                    df_050_059_MQ_VS2_H ['Company'] = listcom
                    df_050_059_MQ_VS2_H ['Shape'] = listshap
                    df_050_059_MQ_VS2_H ['Carat'] = listcar
                    df_050_059_MQ_VS2_H ['Color'] = listcol
                    df_050_059_MQ_VS2_H ['Clarity'] = listclar
                    df_050_059_MQ_VS2_H ['Cut'] = listcut
                    df_050_059_MQ_VS2_H ['Polish'] = listpol
                    df_050_059_MQ_VS2_H ['Symmetry'] = listsym
                    df_050_059_MQ_VS2_H ['Ratio'] = listrat
                    df_050_059_MQ_VS2_H ['PPC'] = listdesc
                    df_050_059_MQ_VS2_H ['Total'] = listtotal
                    df_050_059_MQ_VS2_H['Carat'] = df_050_059_MQ_VS2_H['Carat'].astype('float64')
                    df_050_059_MQ_VS2_H['PPC'] = df_050_059_MQ_VS2_H['PPC'].astype('float64')
                    df_050_059_MQ_VS2_H['Total'] = df_050_059_MQ_VS2_H['Total'].astype('float64')
                    df_050_059_MQ_VS2_H['Total'] = df_050_059_MQ_VS2_H['Carat'] * df_050_059_MQ_VS2_H['PPC']


                elif i=="H" and j == "SI1" and k == "MQ":
                    df_050_059_MQ_SI1_H = pd.DataFrame()
                    df_050_059_MQ_SI1_H ['Wt Range'] = None
                    df_050_059_MQ_SI1_H  = df_050_059_MQ_SI1_H.assign(Company=None)
                    df_050_059_MQ_SI1_H  = df_050_059_MQ_SI1_H.assign(Shape=None)
                    df_050_059_MQ_SI1_H  = df_050_059_MQ_SI1_H.assign(Carat=None)
                    df_050_059_MQ_SI1_H  = df_050_059_MQ_SI1_H.assign(Color=None)
                    df_050_059_MQ_SI1_H  = df_050_059_MQ_SI1_H.assign(Clarity=None)
                    df_050_059_MQ_SI1_H  = df_050_059_MQ_SI1_H.assign(Cut=None)
                    df_050_059_MQ_SI1_H  = df_050_059_MQ_SI1_H.assign(Polish=None)
                    df_050_059_MQ_SI1_H  = df_050_059_MQ_SI1_H.assign(Symmetry=None)
                    df_050_059_MQ_SI1_H  = df_050_059_MQ_SI1_H.assign(Ratio=None)
                    df_050_059_MQ_SI1_H  = df_050_059_MQ_SI1_H.assign(PPC=None)
                    df_050_059_MQ_SI1_H  = df_050_059_MQ_SI1_H.assign(Total=None)
                    df_050_059_MQ_SI1_H ['Wt Range'] = listwtrange
                    df_050_059_MQ_SI1_H ['Company'] = listcom
                    df_050_059_MQ_SI1_H ['Shape'] = listshap
                    df_050_059_MQ_SI1_H ['Carat'] = listcar
                    df_050_059_MQ_SI1_H ['Color'] = listcol
                    df_050_059_MQ_SI1_H ['Clarity'] = listclar
                    df_050_059_MQ_SI1_H ['Cut'] = listcut
                    df_050_059_MQ_SI1_H ['Polish'] = listpol
                    df_050_059_MQ_SI1_H ['Symmetry'] = listsym
                    df_050_059_MQ_SI1_H ['Ratio'] = listrat
                    df_050_059_MQ_SI1_H ['PPC'] = listdesc
                    df_050_059_MQ_SI1_H ['Total'] = listtotal
                    df_050_059_MQ_SI1_H['Carat'] = df_050_059_MQ_SI1_H['Carat'].astype('float64')
                    df_050_059_MQ_SI1_H['PPC'] = df_050_059_MQ_SI1_H['PPC'].astype('float64')
                    df_050_059_MQ_SI1_H['Total'] = df_050_059_MQ_SI1_H['Total'].astype('float64')
                    df_050_059_MQ_SI1_H['Total'] = df_050_059_MQ_SI1_H['Carat'] * df_050_059_MQ_SI1_H['PPC']


                elif i=="H" and j == "SI2" and k == "MQ":
                    df_050_059_MQ_SI2_H = pd.DataFrame()
                    df_050_059_MQ_SI2_H ['Wt Range'] = None
                    df_050_059_MQ_SI2_H  = df_050_059_MQ_SI2_H.assign(Company=None)
                    df_050_059_MQ_SI2_H  = df_050_059_MQ_SI2_H.assign(Shape=None)
                    df_050_059_MQ_SI2_H  = df_050_059_MQ_SI2_H.assign(Carat=None)
                    df_050_059_MQ_SI2_H  = df_050_059_MQ_SI2_H.assign(Color=None)
                    df_050_059_MQ_SI2_H  = df_050_059_MQ_SI2_H.assign(Clarity=None)
                    df_050_059_MQ_SI2_H  = df_050_059_MQ_SI2_H.assign(Cut=None)
                    df_050_059_MQ_SI2_H  = df_050_059_MQ_SI2_H.assign(Polish=None)
                    df_050_059_MQ_SI2_H  = df_050_059_MQ_SI2_H.assign(Symmetry=None)
                    df_050_059_MQ_SI2_H  = df_050_059_MQ_SI2_H.assign(Ratio=None)
                    df_050_059_MQ_SI2_H  = df_050_059_MQ_SI2_H.assign(PPC=None)
                    df_050_059_MQ_SI2_H  = df_050_059_MQ_SI2_H.assign(Total=None)
                    df_050_059_MQ_SI2_H ['Wt Range'] = listwtrange
                    df_050_059_MQ_SI2_H ['Company'] = listcom
                    df_050_059_MQ_SI2_H ['Shape'] = listshap
                    df_050_059_MQ_SI2_H ['Carat'] = listcar
                    df_050_059_MQ_SI2_H ['Color'] = listcol
                    df_050_059_MQ_SI2_H ['Clarity'] = listclar
                    df_050_059_MQ_SI2_H ['Cut'] = listcut
                    df_050_059_MQ_SI2_H ['Polish'] = listpol
                    df_050_059_MQ_SI2_H ['Symmetry'] = listsym
                    df_050_059_MQ_SI2_H ['Ratio'] = listrat
                    df_050_059_MQ_SI2_H ['PPC'] = listdesc
                    df_050_059_MQ_SI2_H ['Total'] = listtotal
                    df_050_059_MQ_SI2_H['Carat'] = df_050_059_MQ_SI2_H['Carat'].astype('float64')
                    df_050_059_MQ_SI2_H['PPC'] = df_050_059_MQ_SI2_H['PPC'].astype('float64')
                    df_050_059_MQ_SI2_H['Total'] = df_050_059_MQ_SI2_H['Total'].astype('float64')
                    df_050_059_MQ_SI2_H['Total'] = df_050_059_MQ_SI2_H['Carat'] * df_050_059_MQ_SI2_H['PPC']


                elif i=="H" and j == "I1" and k == "MQ":
                    df_050_059_MQ_I1_H = pd.DataFrame()
                    df_050_059_MQ_I1_H ['Wt Range'] = None
                    df_050_059_MQ_I1_H  = df_050_059_MQ_I1_H.assign(Company=None)
                    df_050_059_MQ_I1_H  = df_050_059_MQ_I1_H.assign(Shape=None)
                    df_050_059_MQ_I1_H  = df_050_059_MQ_I1_H.assign(Carat=None)
                    df_050_059_MQ_I1_H  = df_050_059_MQ_I1_H.assign(Color=None)
                    df_050_059_MQ_I1_H  = df_050_059_MQ_I1_H.assign(Clarity=None)
                    df_050_059_MQ_I1_H  = df_050_059_MQ_I1_H.assign(Cut=None)
                    df_050_059_MQ_I1_H  = df_050_059_MQ_I1_H.assign(Polish=None)
                    df_050_059_MQ_I1_H  = df_050_059_MQ_I1_H.assign(Symmetry=None)
                    df_050_059_MQ_I1_H  = df_050_059_MQ_I1_H.assign(Ratio=None)
                    df_050_059_MQ_I1_H  = df_050_059_MQ_I1_H.assign(PPC=None)
                    df_050_059_MQ_I1_H  = df_050_059_MQ_I1_H.assign(Total=None)
                    df_050_059_MQ_I1_H ['Wt Range'] = listwtrange
                    df_050_059_MQ_I1_H ['Company'] = listcom
                    df_050_059_MQ_I1_H ['Shape'] = listshap
                    df_050_059_MQ_I1_H ['Carat'] = listcar
                    df_050_059_MQ_I1_H ['Color'] = listcol
                    df_050_059_MQ_I1_H ['Clarity'] = listclar
                    df_050_059_MQ_I1_H ['Cut'] = listcut
                    df_050_059_MQ_I1_H ['Polish'] = listpol
                    df_050_059_MQ_I1_H ['Symmetry'] = listsym
                    df_050_059_MQ_I1_H ['Ratio'] = listrat
                    df_050_059_MQ_I1_H ['PPC'] = listdesc
                    df_050_059_MQ_I1_H ['Total'] = listtotal
                    df_050_059_MQ_I1_H['Carat'] = df_050_059_MQ_I1_H['Carat'].astype('float64')
                    df_050_059_MQ_I1_H['PPC'] = df_050_059_MQ_I1_H['PPC'].astype('float64')
                    df_050_059_MQ_I1_H['Total'] = df_050_059_MQ_I1_H['Total'].astype('float64')
                    df_050_059_MQ_I1_H['Total'] = df_050_059_MQ_I1_H['Carat'] * df_050_059_MQ_I1_H['PPC']


                elif i=="H" and j == "I2" and k == "MQ":
                    df_050_059_MQ_I2_H = pd.DataFrame()
                    df_050_059_MQ_I2_H ['Wt Range'] = None
                    df_050_059_MQ_I2_H  = df_050_059_MQ_I2_H.assign(Company=None)
                    df_050_059_MQ_I2_H  = df_050_059_MQ_I2_H.assign(Shape=None)
                    df_050_059_MQ_I2_H  = df_050_059_MQ_I2_H.assign(Carat=None)
                    df_050_059_MQ_I2_H  = df_050_059_MQ_I2_H.assign(Color=None)
                    df_050_059_MQ_I2_H  = df_050_059_MQ_I2_H.assign(Clarity=None)
                    df_050_059_MQ_I2_H  = df_050_059_MQ_I2_H.assign(Cut=None)
                    df_050_059_MQ_I2_H  = df_050_059_MQ_I2_H.assign(Polish=None)
                    df_050_059_MQ_I2_H  = df_050_059_MQ_I2_H.assign(Symmetry=None)
                    df_050_059_MQ_I2_H  = df_050_059_MQ_I2_H.assign(Ratio=None)
                    df_050_059_MQ_I2_H  = df_050_059_MQ_I2_H.assign(PPC=None)
                    df_050_059_MQ_I2_H  = df_050_059_MQ_I2_H.assign(Total=None)
                    df_050_059_MQ_I2_H ['Wt Range'] = listwtrange
                    df_050_059_MQ_I2_H ['Company'] = listcom
                    df_050_059_MQ_I2_H ['Shape'] = listshap
                    df_050_059_MQ_I2_H ['Carat'] = listcar
                    df_050_059_MQ_I2_H ['Color'] = listcol
                    df_050_059_MQ_I2_H ['Clarity'] = listclar
                    df_050_059_MQ_I2_H ['Cut'] = listcut
                    df_050_059_MQ_I2_H ['Polish'] = listpol
                    df_050_059_MQ_I2_H ['Symmetry'] = listsym
                    df_050_059_MQ_I2_H ['Ratio'] = listrat
                    df_050_059_MQ_I2_H ['PPC'] = listdesc
                    df_050_059_MQ_I2_H ['Total'] = listtotal
                    df_050_059_MQ_I2_H['Carat'] = df_050_059_MQ_I2_H['Carat'].astype('float64')
                    df_050_059_MQ_I2_H['PPC'] = df_050_059_MQ_I2_H['PPC'].astype('float64')
                    df_050_059_MQ_I2_H['Total'] = df_050_059_MQ_I2_H['Total'].astype('float64')
                    df_050_059_MQ_I2_H['Total'] = df_050_059_MQ_I2_H['Carat'] * df_050_059_MQ_I2_H['PPC']



                elif i== "I" and j == "IF" and k == "MQ":
                    df_050_059_MQ_IF_I = pd.DataFrame()
                    df_050_059_MQ_IF_I ['Wt Range'] = None
                    df_050_059_MQ_IF_I  = df_050_059_MQ_IF_I.assign(Company=None)
                    df_050_059_MQ_IF_I  = df_050_059_MQ_IF_I.assign(Shape=None)
                    df_050_059_MQ_IF_I  = df_050_059_MQ_IF_I.assign(Carat=None)
                    df_050_059_MQ_IF_I  = df_050_059_MQ_IF_I.assign(Color=None)
                    df_050_059_MQ_IF_I  = df_050_059_MQ_IF_I.assign(Clarity=None)
                    df_050_059_MQ_IF_I  = df_050_059_MQ_IF_I.assign(Cut=None)
                    df_050_059_MQ_IF_I  = df_050_059_MQ_IF_I.assign(Polish=None)
                    df_050_059_MQ_IF_I  = df_050_059_MQ_IF_I.assign(Symmetry=None)
                    df_050_059_MQ_IF_I  = df_050_059_MQ_IF_I.assign(Ratio=None)
                    df_050_059_MQ_IF_I  = df_050_059_MQ_IF_I.assign(PPC=None)
                    df_050_059_MQ_IF_I  = df_050_059_MQ_IF_I.assign(Total=None)
                    df_050_059_MQ_IF_I ['Wt Range'] = listwtrange
                    df_050_059_MQ_IF_I ['Company'] = listcom
                    df_050_059_MQ_IF_I ['Shape'] = listshap
                    df_050_059_MQ_IF_I ['Carat'] = listcar
                    df_050_059_MQ_IF_I ['Color'] = listcol
                    df_050_059_MQ_IF_I ['Clarity'] = listclar
                    df_050_059_MQ_IF_I ['Cut'] = listcut
                    df_050_059_MQ_IF_I ['Polish'] = listpol
                    df_050_059_MQ_IF_I ['Symmetry'] = listsym
                    df_050_059_MQ_IF_I ['Ratio'] = listrat
                    df_050_059_MQ_IF_I ['PPC'] = listdesc
                    df_050_059_MQ_IF_I ['Total'] = listtotal
                    df_050_059_MQ_IF_I['Carat'] = df_050_059_MQ_IF_I['Carat'].astype('float64')
                    df_050_059_MQ_IF_I['PPC'] = df_050_059_MQ_IF_I['PPC'].astype('float64')
                    df_050_059_MQ_IF_I['Total'] = df_050_059_MQ_IF_I['Total'].astype('float64')
                    df_050_059_MQ_IF_I['Total'] = df_050_059_MQ_IF_I['Carat'] * df_050_059_MQ_IF_I['PPC']



                elif i== "I" and j == "VVS1" and k == "MQ":
                    df_050_059_MQ_VVS1_I = pd.DataFrame()
                    df_050_059_MQ_VVS1_I ['Wt Range'] = None
                    df_050_059_MQ_VVS1_I  = df_050_059_MQ_VVS1_I.assign(Company=None)
                    df_050_059_MQ_VVS1_I  = df_050_059_MQ_VVS1_I.assign(Shape=None)
                    df_050_059_MQ_VVS1_I  = df_050_059_MQ_VVS1_I.assign(Carat=None)
                    df_050_059_MQ_VVS1_I  = df_050_059_MQ_VVS1_I.assign(Color=None)
                    df_050_059_MQ_VVS1_I  = df_050_059_MQ_VVS1_I.assign(Clarity=None)
                    df_050_059_MQ_VVS1_I  = df_050_059_MQ_VVS1_I.assign(Cut=None)
                    df_050_059_MQ_VVS1_I  = df_050_059_MQ_VVS1_I.assign(Polish=None)
                    df_050_059_MQ_VVS1_I  = df_050_059_MQ_VVS1_I.assign(Symmetry=None)
                    df_050_059_MQ_VVS1_I  = df_050_059_MQ_VVS1_I.assign(Ratio=None)
                    df_050_059_MQ_VVS1_I  = df_050_059_MQ_VVS1_I.assign(PPC=None)
                    df_050_059_MQ_VVS1_I  = df_050_059_MQ_VVS1_I.assign(Total=None)
                    df_050_059_MQ_VVS1_I ['Wt Range'] = listwtrange
                    df_050_059_MQ_VVS1_I ['Company'] = listcom
                    df_050_059_MQ_VVS1_I ['Shape'] = listshap
                    df_050_059_MQ_VVS1_I ['Carat'] = listcar
                    df_050_059_MQ_VVS1_I ['Color'] = listcol
                    df_050_059_MQ_VVS1_I ['Clarity'] = listclar
                    df_050_059_MQ_VVS1_I ['Cut'] = listcut
                    df_050_059_MQ_VVS1_I ['Polish'] = listpol
                    df_050_059_MQ_VVS1_I ['Symmetry'] = listsym
                    df_050_059_MQ_VVS1_I ['Ratio'] = listrat
                    df_050_059_MQ_VVS1_I ['PPC'] = listdesc
                    df_050_059_MQ_VVS1_I ['Total'] = listtotal
                    df_050_059_MQ_VVS1_I['Carat'] = df_050_059_MQ_VVS1_I['Carat'].astype('float64')
                    df_050_059_MQ_VVS1_I['PPC'] = df_050_059_MQ_VVS1_I['PPC'].astype('float64')
                    df_050_059_MQ_VVS1_I['Total'] = df_050_059_MQ_VVS1_I['Total'].astype('float64')
                    df_050_059_MQ_VVS1_I['Total'] = df_050_059_MQ_VVS1_I['Carat'] * df_050_059_MQ_VVS1_I['PPC']


                elif i== "I" and j == "VVS2" and k == "MQ":
                    df_050_059_MQ_VVS2_I = pd.DataFrame()
                    df_050_059_MQ_VVS2_I ['Wt Range'] = None
                    df_050_059_MQ_VVS2_I  = df_050_059_MQ_VVS2_I.assign(Company=None)
                    df_050_059_MQ_VVS2_I  = df_050_059_MQ_VVS2_I.assign(Shape=None)
                    df_050_059_MQ_VVS2_I  = df_050_059_MQ_VVS2_I.assign(Carat=None)
                    df_050_059_MQ_VVS2_I  = df_050_059_MQ_VVS2_I.assign(Color=None)
                    df_050_059_MQ_VVS2_I  = df_050_059_MQ_VVS2_I.assign(Clarity=None)
                    df_050_059_MQ_VVS2_I  = df_050_059_MQ_VVS2_I.assign(Cut=None)
                    df_050_059_MQ_VVS2_I  = df_050_059_MQ_VVS2_I.assign(Polish=None)
                    df_050_059_MQ_VVS2_I  = df_050_059_MQ_VVS2_I.assign(Symmetry=None)
                    df_050_059_MQ_VVS2_I  = df_050_059_MQ_VVS2_I.assign(Ratio=None)
                    df_050_059_MQ_VVS2_I  = df_050_059_MQ_VVS2_I.assign(PPC=None)
                    df_050_059_MQ_VVS2_I  = df_050_059_MQ_VVS2_I.assign(Total=None)
                    df_050_059_MQ_VVS2_I ['Wt Range'] = listwtrange
                    df_050_059_MQ_VVS2_I ['Company'] = listcom
                    df_050_059_MQ_VVS2_I ['Shape'] = listshap
                    df_050_059_MQ_VVS2_I ['Carat'] = listcar
                    df_050_059_MQ_VVS2_I ['Color'] = listcol
                    df_050_059_MQ_VVS2_I ['Clarity'] = listclar
                    df_050_059_MQ_VVS2_I ['Cut'] = listcut
                    df_050_059_MQ_VVS2_I ['Polish'] = listpol
                    df_050_059_MQ_VVS2_I ['Symmetry'] = listsym
                    df_050_059_MQ_VVS2_I ['Ratio'] = listrat
                    df_050_059_MQ_VVS2_I ['PPC'] = listdesc
                    df_050_059_MQ_VVS2_I ['Total'] = listtotal
                    df_050_059_MQ_VVS2_I['Carat'] = df_050_059_MQ_VVS2_I['Carat'].astype('float64')
                    df_050_059_MQ_VVS2_I['PPC'] = df_050_059_MQ_VVS2_I['PPC'].astype('float64')
                    df_050_059_MQ_VVS2_I['Total'] = df_050_059_MQ_VVS2_I['Total'].astype('float64')
                    df_050_059_MQ_VVS2_I['Total'] = df_050_059_MQ_VVS2_I['Carat'] * df_050_059_MQ_VVS2_I['PPC']


                elif i== "I" and j=="VS1" and k == "MQ":
                    df_050_059_MQ_VS1_I = pd.DataFrame()
                    df_050_059_MQ_VS1_I ['Wt Range'] = None
                    df_050_059_MQ_VS1_I  = df_050_059_MQ_VS1_I.assign(Company=None)
                    df_050_059_MQ_VS1_I  = df_050_059_MQ_VS1_I.assign(Shape=None)
                    df_050_059_MQ_VS1_I  = df_050_059_MQ_VS1_I.assign(Carat=None)
                    df_050_059_MQ_VS1_I  = df_050_059_MQ_VS1_I.assign(Color=None)
                    df_050_059_MQ_VS1_I  = df_050_059_MQ_VS1_I.assign(Clarity=None)
                    df_050_059_MQ_VS1_I  = df_050_059_MQ_VS1_I.assign(Cut=None)
                    df_050_059_MQ_VS1_I  = df_050_059_MQ_VS1_I.assign(Polish=None)
                    df_050_059_MQ_VS1_I  = df_050_059_MQ_VS1_I.assign(Symmetry=None)
                    df_050_059_MQ_VS1_I  = df_050_059_MQ_VS1_I.assign(Ratio=None)
                    df_050_059_MQ_VS1_I  = df_050_059_MQ_VS1_I.assign(PPC=None)
                    df_050_059_MQ_VS1_I  = df_050_059_MQ_VS1_I.assign(Total=None)
                    df_050_059_MQ_VS1_I ['Wt Range'] = listwtrange
                    df_050_059_MQ_VS1_I ['Company'] = listcom
                    df_050_059_MQ_VS1_I ['Shape'] = listshap
                    df_050_059_MQ_VS1_I ['Carat'] = listcar
                    df_050_059_MQ_VS1_I ['Color'] = listcol
                    df_050_059_MQ_VS1_I ['Clarity'] = listclar
                    df_050_059_MQ_VS1_I ['Cut'] = listcut
                    df_050_059_MQ_VS1_I ['Polish'] = listpol
                    df_050_059_MQ_VS1_I ['Symmetry'] = listsym
                    df_050_059_MQ_VS1_I ['Ratio'] = listrat
                    df_050_059_MQ_VS1_I ['PPC'] = listdesc
                    df_050_059_MQ_VS1_I ['Total'] = listtotal
                    df_050_059_MQ_VS1_I['Carat'] = df_050_059_MQ_VS1_I['Carat'].astype('float64')
                    df_050_059_MQ_VS1_I['PPC'] = df_050_059_MQ_VS1_I['PPC'].astype('float64')
                    df_050_059_MQ_VS1_I['Total'] = df_050_059_MQ_VS1_I['Total'].astype('float64')
                    df_050_059_MQ_VS1_I['Total'] = df_050_059_MQ_VS1_I['Carat'] * df_050_059_MQ_VS1_I['PPC']


                elif i== "I" and j == "VS2" and k == "MQ":
                    df_050_059_MQ_VS2_I = pd.DataFrame()
                    df_050_059_MQ_VS2_I ['Wt Range'] = None
                    df_050_059_MQ_VS2_I  = df_050_059_MQ_VS2_I.assign(Company=None)
                    df_050_059_MQ_VS2_I  = df_050_059_MQ_VS2_I.assign(Shape=None)
                    df_050_059_MQ_VS2_I  = df_050_059_MQ_VS2_I.assign(Carat=None)
                    df_050_059_MQ_VS2_I  = df_050_059_MQ_VS2_I.assign(Color=None)
                    df_050_059_MQ_VS2_I  = df_050_059_MQ_VS2_I.assign(Clarity=None)
                    df_050_059_MQ_VS2_I  = df_050_059_MQ_VS2_I.assign(Cut=None)
                    df_050_059_MQ_VS2_I  = df_050_059_MQ_VS2_I.assign(Polish=None)
                    df_050_059_MQ_VS2_I  = df_050_059_MQ_VS2_I.assign(Symmetry=None)
                    df_050_059_MQ_VS2_I  = df_050_059_MQ_VS2_I.assign(Ratio=None)
                    df_050_059_MQ_VS2_I  = df_050_059_MQ_VS2_I.assign(PPC=None)
                    df_050_059_MQ_VS2_I  = df_050_059_MQ_VS2_I.assign(Total=None)
                    df_050_059_MQ_VS2_I ['Wt Range'] = listwtrange
                    df_050_059_MQ_VS2_I ['Company'] = listcom
                    df_050_059_MQ_VS2_I ['Shape'] = listshap
                    df_050_059_MQ_VS2_I ['Carat'] = listcar
                    df_050_059_MQ_VS2_I ['Color'] = listcol
                    df_050_059_MQ_VS2_I ['Clarity'] = listclar
                    df_050_059_MQ_VS2_I ['Cut'] = listcut
                    df_050_059_MQ_VS2_I ['Polish'] = listpol
                    df_050_059_MQ_VS2_I ['Symmetry'] = listsym
                    df_050_059_MQ_VS2_I ['Ratio'] = listrat
                    df_050_059_MQ_VS2_I ['PPC'] = listdesc
                    df_050_059_MQ_VS2_I ['Total'] = listtotal
                    df_050_059_MQ_VS2_I['Carat'] = df_050_059_MQ_VS2_I['Carat'].astype('float64')
                    df_050_059_MQ_VS2_I['PPC'] = df_050_059_MQ_VS2_I['PPC'].astype('float64')
                    df_050_059_MQ_VS2_I['Total'] = df_050_059_MQ_VS2_I['Total'].astype('float64')
                    df_050_059_MQ_VS2_I['Total'] = df_050_059_MQ_VS2_I['Carat'] * df_050_059_MQ_VS2_I['PPC']


                elif i== "I" and j == "SI1" and k == "MQ":
                    df_050_059_MQ_SI1_I = pd.DataFrame()
                    df_050_059_MQ_SI1_I ['Wt Range'] = None
                    df_050_059_MQ_SI1_I  = df_050_059_MQ_SI1_I.assign(Company=None)
                    df_050_059_MQ_SI1_I  = df_050_059_MQ_SI1_I.assign(Shape=None)
                    df_050_059_MQ_SI1_I  = df_050_059_MQ_SI1_I.assign(Carat=None)
                    df_050_059_MQ_SI1_I  = df_050_059_MQ_SI1_I.assign(Color=None)
                    df_050_059_MQ_SI1_I  = df_050_059_MQ_SI1_I.assign(Clarity=None)
                    df_050_059_MQ_SI1_I  = df_050_059_MQ_SI1_I.assign(Cut=None)
                    df_050_059_MQ_SI1_I  = df_050_059_MQ_SI1_I.assign(Polish=None)
                    df_050_059_MQ_SI1_I  = df_050_059_MQ_SI1_I.assign(Symmetry=None)
                    df_050_059_MQ_SI1_I  = df_050_059_MQ_SI1_I.assign(Ratio=None)
                    df_050_059_MQ_SI1_I  = df_050_059_MQ_SI1_I.assign(PPC=None)
                    df_050_059_MQ_SI1_I  = df_050_059_MQ_SI1_I.assign(Total=None)
                    df_050_059_MQ_SI1_I ['Wt Range'] = listwtrange
                    df_050_059_MQ_SI1_I ['Company'] = listcom
                    df_050_059_MQ_SI1_I ['Shape'] = listshap
                    df_050_059_MQ_SI1_I ['Carat'] = listcar
                    df_050_059_MQ_SI1_I ['Color'] = listcol
                    df_050_059_MQ_SI1_I ['Clarity'] = listclar
                    df_050_059_MQ_SI1_I ['Cut'] = listcut
                    df_050_059_MQ_SI1_I ['Polish'] = listpol
                    df_050_059_MQ_SI1_I ['Symmetry'] = listsym
                    df_050_059_MQ_SI1_I ['Ratio'] = listrat
                    df_050_059_MQ_SI1_I ['PPC'] = listdesc
                    df_050_059_MQ_SI1_I ['Total'] = listtotal
                    df_050_059_MQ_SI1_I['Carat'] = df_050_059_MQ_SI1_I['Carat'].astype('float64')
                    df_050_059_MQ_SI1_I['PPC'] = df_050_059_MQ_SI1_I['PPC'].astype('float64')
                    df_050_059_MQ_SI1_I['Total'] = df_050_059_MQ_SI1_I['Total'].astype('float64')
                    df_050_059_MQ_SI1_I['Total'] = df_050_059_MQ_SI1_I['Carat'] * df_050_059_MQ_SI1_I['PPC']


                elif i== "I" and j == "SI2" and k == "MQ":
                    df_050_059_MQ_SI2_I = pd.DataFrame()
                    df_050_059_MQ_SI2_I ['Wt Range'] = None
                    df_050_059_MQ_SI2_I  = df_050_059_MQ_SI2_I.assign(Company=None)
                    df_050_059_MQ_SI2_I  = df_050_059_MQ_SI2_I.assign(Shape=None)
                    df_050_059_MQ_SI2_I  = df_050_059_MQ_SI2_I.assign(Carat=None)
                    df_050_059_MQ_SI2_I  = df_050_059_MQ_SI2_I.assign(Color=None)
                    df_050_059_MQ_SI2_I  = df_050_059_MQ_SI2_I.assign(Clarity=None)
                    df_050_059_MQ_SI2_I  = df_050_059_MQ_SI2_I.assign(Cut=None)
                    df_050_059_MQ_SI2_I  = df_050_059_MQ_SI2_I.assign(Polish=None)
                    df_050_059_MQ_SI2_I  = df_050_059_MQ_SI2_I.assign(Symmetry=None)
                    df_050_059_MQ_SI2_I  = df_050_059_MQ_SI2_I.assign(Ratio=None)
                    df_050_059_MQ_SI2_I  = df_050_059_MQ_SI2_I.assign(PPC=None)
                    df_050_059_MQ_SI2_I  = df_050_059_MQ_SI2_I.assign(Total=None)
                    df_050_059_MQ_SI2_I ['Wt Range'] = listwtrange
                    df_050_059_MQ_SI2_I ['Company'] = listcom
                    df_050_059_MQ_SI2_I ['Shape'] = listshap
                    df_050_059_MQ_SI2_I ['Carat'] = listcar
                    df_050_059_MQ_SI2_I ['Color'] = listcol
                    df_050_059_MQ_SI2_I ['Clarity'] = listclar
                    df_050_059_MQ_SI2_I ['Cut'] = listcut
                    df_050_059_MQ_SI2_I ['Polish'] = listpol
                    df_050_059_MQ_SI2_I ['Symmetry'] = listsym
                    df_050_059_MQ_SI2_I ['Ratio'] = listrat
                    df_050_059_MQ_SI2_I ['PPC'] = listdesc
                    df_050_059_MQ_SI2_I ['Total'] = listtotal
                    df_050_059_MQ_SI2_I['Carat'] = df_050_059_MQ_SI2_I['Carat'].astype('float64')
                    df_050_059_MQ_SI2_I['PPC'] = df_050_059_MQ_SI2_I['PPC'].astype('float64')
                    df_050_059_MQ_SI2_I['Total'] = df_050_059_MQ_SI2_I['Total'].astype('float64')
                    df_050_059_MQ_SI2_I['Total'] = df_050_059_MQ_SI2_I['Carat'] * df_050_059_MQ_SI2_I['PPC']


                elif i== "I" and j == "I1" and k == "MQ":
                    df_050_059_MQ_I1_I = pd.DataFrame()
                    df_050_059_MQ_I1_I ['Wt Range'] = None
                    df_050_059_MQ_I1_I  = df_050_059_MQ_I1_I.assign(Company=None)
                    df_050_059_MQ_I1_I  = df_050_059_MQ_I1_I.assign(Shape=None)
                    df_050_059_MQ_I1_I  = df_050_059_MQ_I1_I.assign(Carat=None)
                    df_050_059_MQ_I1_I  = df_050_059_MQ_I1_I.assign(Color=None)
                    df_050_059_MQ_I1_I  = df_050_059_MQ_I1_I.assign(Clarity=None)
                    df_050_059_MQ_I1_I  = df_050_059_MQ_I1_I.assign(Cut=None)
                    df_050_059_MQ_I1_I  = df_050_059_MQ_I1_I.assign(Polish=None)
                    df_050_059_MQ_I1_I  = df_050_059_MQ_I1_I.assign(Symmetry=None)
                    df_050_059_MQ_I1_I  = df_050_059_MQ_I1_I.assign(Ratio=None)
                    df_050_059_MQ_I1_I  = df_050_059_MQ_I1_I.assign(PPC=None)
                    df_050_059_MQ_I1_I  = df_050_059_MQ_I1_I.assign(Total=None)
                    df_050_059_MQ_I1_I ['Wt Range'] = listwtrange
                    df_050_059_MQ_I1_I ['Company'] = listcom
                    df_050_059_MQ_I1_I ['Shape'] = listshap
                    df_050_059_MQ_I1_I ['Carat'] = listcar
                    df_050_059_MQ_I1_I ['Color'] = listcol
                    df_050_059_MQ_I1_I ['Clarity'] = listclar
                    df_050_059_MQ_I1_I ['Cut'] = listcut
                    df_050_059_MQ_I1_I ['Polish'] = listpol
                    df_050_059_MQ_I1_I ['Symmetry'] = listsym
                    df_050_059_MQ_I1_I ['Ratio'] = listrat
                    df_050_059_MQ_I1_I ['PPC'] = listdesc
                    df_050_059_MQ_I1_I ['Total'] = listtotal
                    df_050_059_MQ_I1_I['Carat'] = df_050_059_MQ_I1_I['Carat'].astype('float64')
                    df_050_059_MQ_I1_I['PPC'] = df_050_059_MQ_I1_I['PPC'].astype('float64')
                    df_050_059_MQ_I1_I['Total'] = df_050_059_MQ_I1_I['Total'].astype('float64')
                    df_050_059_MQ_I1_I['Total'] = df_050_059_MQ_I1_I['Carat'] * df_050_059_MQ_I1_I['PPC']


                elif i== "I" and j == "I2" and k == "MQ":
                    df_050_059_MQ_I2_I = pd.DataFrame()
                    df_050_059_MQ_I2_I ['Wt Range'] = None
                    df_050_059_MQ_I2_I  = df_050_059_MQ_I2_I.assign(Company=None)
                    df_050_059_MQ_I2_I  = df_050_059_MQ_I2_I.assign(Shape=None)
                    df_050_059_MQ_I2_I  = df_050_059_MQ_I2_I.assign(Carat=None)
                    df_050_059_MQ_I2_I  = df_050_059_MQ_I2_I.assign(Color=None)
                    df_050_059_MQ_I2_I  = df_050_059_MQ_I2_I.assign(Clarity=None)
                    df_050_059_MQ_I2_I  = df_050_059_MQ_I2_I.assign(Cut=None)
                    df_050_059_MQ_I2_I  = df_050_059_MQ_I2_I.assign(Polish=None)
                    df_050_059_MQ_I2_I  = df_050_059_MQ_I2_I.assign(Symmetry=None)
                    df_050_059_MQ_I2_I  = df_050_059_MQ_I2_I.assign(Ratio=None)
                    df_050_059_MQ_I2_I  = df_050_059_MQ_I2_I.assign(PPC=None)
                    df_050_059_MQ_I2_I  = df_050_059_MQ_I2_I.assign(Total=None)
                    df_050_059_MQ_I2_I ['Wt Range'] = listwtrange
                    df_050_059_MQ_I2_I ['Company'] = listcom
                    df_050_059_MQ_I2_I ['Shape'] = listshap
                    df_050_059_MQ_I2_I ['Carat'] = listcar
                    df_050_059_MQ_I2_I ['Color'] = listcol
                    df_050_059_MQ_I2_I ['Clarity'] = listclar
                    df_050_059_MQ_I2_I ['Cut'] = listcut
                    df_050_059_MQ_I2_I ['Polish'] = listpol
                    df_050_059_MQ_I2_I ['Symmetry'] = listsym
                    df_050_059_MQ_I2_I ['Ratio'] = listrat
                    df_050_059_MQ_I2_I ['PPC'] = listdesc
                    df_050_059_MQ_I2_I ['Total'] = listtotal
                    df_050_059_MQ_I2_I['Carat'] = df_050_059_MQ_I2_I['Carat'].astype('float64')
                    df_050_059_MQ_I2_I['PPC'] = df_050_059_MQ_I2_I['PPC'].astype('float64')
                    df_050_059_MQ_I2_I['Total'] = df_050_059_MQ_I2_I['Total'].astype('float64')
                    df_050_059_MQ_I2_I['Total'] = df_050_059_MQ_I2_I['Carat'] * df_050_059_MQ_I2_I['PPC']


                elif i=="J" and j == "IF" and k == "MQ":
                    df_050_059_MQ_IF_J = pd.DataFrame()
                    df_050_059_MQ_IF_J ['Wt Range'] = None
                    df_050_059_MQ_IF_J  = df_050_059_MQ_IF_J.assign(Company=None)
                    df_050_059_MQ_IF_J  = df_050_059_MQ_IF_J.assign(Shape=None)
                    df_050_059_MQ_IF_J  = df_050_059_MQ_IF_J.assign(Carat=None)
                    df_050_059_MQ_IF_J  = df_050_059_MQ_IF_J.assign(Color=None)
                    df_050_059_MQ_IF_J  = df_050_059_MQ_IF_J.assign(Clarity=None)
                    df_050_059_MQ_IF_J  = df_050_059_MQ_IF_J.assign(Cut=None)
                    df_050_059_MQ_IF_J  = df_050_059_MQ_IF_J.assign(Polish=None)
                    df_050_059_MQ_IF_J  = df_050_059_MQ_IF_J.assign(Symmetry=None)
                    df_050_059_MQ_IF_J  = df_050_059_MQ_IF_J.assign(Ratio=None)
                    df_050_059_MQ_IF_J  = df_050_059_MQ_IF_J.assign(PPC=None)
                    df_050_059_MQ_IF_J  = df_050_059_MQ_IF_J.assign(Total=None)
                    df_050_059_MQ_IF_J ['Wt Range'] = listwtrange
                    df_050_059_MQ_IF_J ['Company'] = listcom
                    df_050_059_MQ_IF_J ['Shape'] = listshap
                    df_050_059_MQ_IF_J ['Carat'] = listcar
                    df_050_059_MQ_IF_J ['Color'] = listcol
                    df_050_059_MQ_IF_J ['Clarity'] = listclar
                    df_050_059_MQ_IF_J ['Cut'] = listcut
                    df_050_059_MQ_IF_J ['Polish'] = listpol
                    df_050_059_MQ_IF_J ['Symmetry'] = listsym
                    df_050_059_MQ_IF_J ['Ratio'] = listrat
                    df_050_059_MQ_IF_J ['PPC'] = listdesc
                    df_050_059_MQ_IF_J ['Total'] = listtotal
                    df_050_059_MQ_IF_J['Carat'] = df_050_059_MQ_IF_J['Carat'].astype('float64')
                    df_050_059_MQ_IF_J['PPC'] = df_050_059_MQ_IF_J['PPC'].astype('float64')
                    df_050_059_MQ_IF_J['Total'] = df_050_059_MQ_IF_J['Total'].astype('float64')
                    df_050_059_MQ_IF_J['Total'] = df_050_059_MQ_IF_J['Carat'] * df_050_059_MQ_IF_J['PPC']



                elif i=="J"  and j == "VVS1" and k == "MQ":
                    df_050_059_MQ_VVS1_J = pd.DataFrame()
                    df_050_059_MQ_VVS1_J ['Wt Range'] = None
                    df_050_059_MQ_VVS1_J  = df_050_059_MQ_VVS1_J.assign(Company=None)
                    df_050_059_MQ_VVS1_J  = df_050_059_MQ_VVS1_J.assign(Shape=None)
                    df_050_059_MQ_VVS1_J  = df_050_059_MQ_VVS1_J.assign(Carat=None)
                    df_050_059_MQ_VVS1_J  = df_050_059_MQ_VVS1_J.assign(Color=None)
                    df_050_059_MQ_VVS1_J  = df_050_059_MQ_VVS1_J.assign(Clarity=None)
                    df_050_059_MQ_VVS1_J  = df_050_059_MQ_VVS1_J.assign(Cut=None)
                    df_050_059_MQ_VVS1_J  = df_050_059_MQ_VVS1_J.assign(Polish=None)
                    df_050_059_MQ_VVS1_J  = df_050_059_MQ_VVS1_J.assign(Symmetry=None)
                    df_050_059_MQ_VVS1_J  = df_050_059_MQ_VVS1_J.assign(Ratio=None)
                    df_050_059_MQ_VVS1_J  = df_050_059_MQ_VVS1_J.assign(PPC=None)
                    df_050_059_MQ_VVS1_J  = df_050_059_MQ_VVS1_J.assign(Total=None)
                    df_050_059_MQ_VVS1_J ['Wt Range'] = listwtrange
                    df_050_059_MQ_VVS1_J ['Company'] = listcom
                    df_050_059_MQ_VVS1_J ['Shape'] = listshap
                    df_050_059_MQ_VVS1_J ['Carat'] = listcar
                    df_050_059_MQ_VVS1_J ['Color'] = listcol
                    df_050_059_MQ_VVS1_J ['Clarity'] = listclar
                    df_050_059_MQ_VVS1_J ['Cut'] = listcut
                    df_050_059_MQ_VVS1_J ['Polish'] = listpol
                    df_050_059_MQ_VVS1_J ['Symmetry'] = listsym
                    df_050_059_MQ_VVS1_J ['Ratio'] = listrat
                    df_050_059_MQ_VVS1_J ['PPC'] = listdesc
                    df_050_059_MQ_VVS1_J ['Total'] = listtotal
                    df_050_059_MQ_VVS1_J['Carat'] = df_050_059_MQ_VVS1_J['Carat'].astype('float64')
                    df_050_059_MQ_VVS1_J['PPC'] = df_050_059_MQ_VVS1_J['PPC'].astype('float64')
                    df_050_059_MQ_VVS1_J['Total'] = df_050_059_MQ_VVS1_J['Total'].astype('float64')
                    df_050_059_MQ_VVS1_J['Total'] = df_050_059_MQ_VVS1_J['Carat'] * df_050_059_MQ_VVS1_J['PPC']


                elif i=="J"  and j == "VVS2" and k == "MQ":
                    df_050_059_MQ_VVS2_J = pd.DataFrame()
                    df_050_059_MQ_VVS2_J ['Wt Range'] = None
                    df_050_059_MQ_VVS2_J  = df_050_059_MQ_VVS2_J.assign(Company=None)
                    df_050_059_MQ_VVS2_J  = df_050_059_MQ_VVS2_J.assign(Shape=None)
                    df_050_059_MQ_VVS2_J  = df_050_059_MQ_VVS2_J.assign(Carat=None)
                    df_050_059_MQ_VVS2_J  = df_050_059_MQ_VVS2_J.assign(Color=None)
                    df_050_059_MQ_VVS2_J  = df_050_059_MQ_VVS2_J.assign(Clarity=None)
                    df_050_059_MQ_VVS2_J  = df_050_059_MQ_VVS2_J.assign(Cut=None)
                    df_050_059_MQ_VVS2_J  = df_050_059_MQ_VVS2_J.assign(Polish=None)
                    df_050_059_MQ_VVS2_J  = df_050_059_MQ_VVS2_J.assign(Symmetry=None)
                    df_050_059_MQ_VVS2_J  = df_050_059_MQ_VVS2_J.assign(Ratio=None)
                    df_050_059_MQ_VVS2_J  = df_050_059_MQ_VVS2_J.assign(PPC=None)
                    df_050_059_MQ_VVS2_J  = df_050_059_MQ_VVS2_J.assign(Total=None)
                    df_050_059_MQ_VVS2_J ['Wt Range'] = listwtrange
                    df_050_059_MQ_VVS2_J ['Company'] = listcom
                    df_050_059_MQ_VVS2_J ['Shape'] = listshap
                    df_050_059_MQ_VVS2_J ['Carat'] = listcar
                    df_050_059_MQ_VVS2_J ['Color'] = listcol
                    df_050_059_MQ_VVS2_J ['Clarity'] = listclar
                    df_050_059_MQ_VVS2_J ['Cut'] = listcut
                    df_050_059_MQ_VVS2_J ['Polish'] = listpol
                    df_050_059_MQ_VVS2_J ['Symmetry'] = listsym
                    df_050_059_MQ_VVS2_J ['Ratio'] = listrat
                    df_050_059_MQ_VVS2_J ['PPC'] = listdesc
                    df_050_059_MQ_VVS2_J ['Total'] = listtotal
                    df_050_059_MQ_VVS2_J['Carat'] = df_050_059_MQ_VVS2_J['Carat'].astype('float64')
                    df_050_059_MQ_VVS2_J['PPC'] = df_050_059_MQ_VVS2_J['PPC'].astype('float64')
                    df_050_059_MQ_VVS2_J['Total'] = df_050_059_MQ_VVS2_J['Total'].astype('float64')
                    df_050_059_MQ_VVS2_J['Total'] = df_050_059_MQ_VVS2_J['Carat'] * df_050_059_MQ_VVS2_J['PPC']


                elif i=="J"  and j=="VS1" and k == "MQ":
                    df_050_059_MQ_VS1_J = pd.DataFrame()
                    df_050_059_MQ_VS1_J ['Wt Range'] = None
                    df_050_059_MQ_VS1_J  = df_050_059_MQ_VS1_J.assign(Company=None)
                    df_050_059_MQ_VS1_J  = df_050_059_MQ_VS1_J.assign(Shape=None)
                    df_050_059_MQ_VS1_J  = df_050_059_MQ_VS1_J.assign(Carat=None)
                    df_050_059_MQ_VS1_J  = df_050_059_MQ_VS1_J.assign(Color=None)
                    df_050_059_MQ_VS1_J  = df_050_059_MQ_VS1_J.assign(Clarity=None)
                    df_050_059_MQ_VS1_J  = df_050_059_MQ_VS1_J.assign(Cut=None)
                    df_050_059_MQ_VS1_J  = df_050_059_MQ_VS1_J.assign(Polish=None)
                    df_050_059_MQ_VS1_J  = df_050_059_MQ_VS1_J.assign(Symmetry=None)
                    df_050_059_MQ_VS1_J  = df_050_059_MQ_VS1_J.assign(Ratio=None)
                    df_050_059_MQ_VS1_J  = df_050_059_MQ_VS1_J.assign(PPC=None)
                    df_050_059_MQ_VS1_J  = df_050_059_MQ_VS1_J.assign(Total=None)
                    df_050_059_MQ_VS1_J ['Wt Range'] = listwtrange
                    df_050_059_MQ_VS1_J ['Company'] = listcom
                    df_050_059_MQ_VS1_J ['Shape'] = listshap
                    df_050_059_MQ_VS1_J ['Carat'] = listcar
                    df_050_059_MQ_VS1_J ['Color'] = listcol
                    df_050_059_MQ_VS1_J ['Clarity'] = listclar
                    df_050_059_MQ_VS1_J ['Cut'] = listcut
                    df_050_059_MQ_VS1_J ['Polish'] = listpol
                    df_050_059_MQ_VS1_J ['Symmetry'] = listsym
                    df_050_059_MQ_VS1_J ['Ratio'] = listrat
                    df_050_059_MQ_VS1_J ['PPC'] = listdesc
                    df_050_059_MQ_VS1_J ['Total'] = listtotal
                    df_050_059_MQ_VS1_J['Carat'] = df_050_059_MQ_VS1_J['Carat'].astype('float64')
                    df_050_059_MQ_VS1_J['PPC'] = df_050_059_MQ_VS1_J['PPC'].astype('float64')
                    df_050_059_MQ_VS1_J['Total'] = df_050_059_MQ_VS1_J['Total'].astype('float64')
                    df_050_059_MQ_VS1_J['Total'] = df_050_059_MQ_VS1_J['Carat'] * df_050_059_MQ_VS1_J['PPC']


                elif i=="J"  and j == "VS2" and k == "MQ":
                    df_050_059_MQ_VS2_J = pd.DataFrame()
                    df_050_059_MQ_VS2_J ['Wt Range'] = None
                    df_050_059_MQ_VS2_J  = df_050_059_MQ_VS2_J.assign(Company=None)
                    df_050_059_MQ_VS2_J  = df_050_059_MQ_VS2_J.assign(Shape=None)
                    df_050_059_MQ_VS2_J  = df_050_059_MQ_VS2_J.assign(Carat=None)
                    df_050_059_MQ_VS2_J  = df_050_059_MQ_VS2_J.assign(Color=None)
                    df_050_059_MQ_VS2_J  = df_050_059_MQ_VS2_J.assign(Clarity=None)
                    df_050_059_MQ_VS2_J  = df_050_059_MQ_VS2_J.assign(Cut=None)
                    df_050_059_MQ_VS2_J  = df_050_059_MQ_VS2_J.assign(Polish=None)
                    df_050_059_MQ_VS2_J  = df_050_059_MQ_VS2_J.assign(Symmetry=None)
                    df_050_059_MQ_VS2_J  = df_050_059_MQ_VS2_J.assign(Ratio=None)
                    df_050_059_MQ_VS2_J  = df_050_059_MQ_VS2_J.assign(PPC=None)
                    df_050_059_MQ_VS2_J  = df_050_059_MQ_VS2_J.assign(Total=None)
                    df_050_059_MQ_VS2_J ['Wt Range'] = listwtrange
                    df_050_059_MQ_VS2_J ['Company'] = listcom
                    df_050_059_MQ_VS2_J ['Shape'] = listshap
                    df_050_059_MQ_VS2_J ['Carat'] = listcar
                    df_050_059_MQ_VS2_J ['Color'] = listcol
                    df_050_059_MQ_VS2_J ['Clarity'] = listclar
                    df_050_059_MQ_VS2_J ['Cut'] = listcut
                    df_050_059_MQ_VS2_J ['Polish'] = listpol
                    df_050_059_MQ_VS2_J ['Symmetry'] = listsym
                    df_050_059_MQ_VS2_J ['Ratio'] = listrat
                    df_050_059_MQ_VS2_J ['PPC'] = listdesc
                    df_050_059_MQ_VS2_J ['Total'] = listtotal
                    df_050_059_MQ_VS2_J['Carat'] = df_050_059_MQ_VS2_J['Carat'].astype('float64')
                    df_050_059_MQ_VS2_J['PPC'] = df_050_059_MQ_VS2_J['PPC'].astype('float64')
                    df_050_059_MQ_VS2_J['Total'] = df_050_059_MQ_VS2_J['Total'].astype('float64')
                    df_050_059_MQ_VS2_J['Total'] = df_050_059_MQ_VS2_J['Carat'] * df_050_059_MQ_VS2_J['PPC']


                elif i=="J"  and j == "SI1" and k == "MQ":
                    df_050_059_MQ_SI1_J = pd.DataFrame()
                    df_050_059_MQ_SI1_J ['Wt Range'] = None
                    df_050_059_MQ_SI1_J  = df_050_059_MQ_SI1_J.assign(Company=None)
                    df_050_059_MQ_SI1_J  = df_050_059_MQ_SI1_J.assign(Shape=None)
                    df_050_059_MQ_SI1_J  = df_050_059_MQ_SI1_J.assign(Carat=None)
                    df_050_059_MQ_SI1_J  = df_050_059_MQ_SI1_J.assign(Color=None)
                    df_050_059_MQ_SI1_J  = df_050_059_MQ_SI1_J.assign(Clarity=None)
                    df_050_059_MQ_SI1_J  = df_050_059_MQ_SI1_J.assign(Cut=None)
                    df_050_059_MQ_SI1_J  = df_050_059_MQ_SI1_J.assign(Polish=None)
                    df_050_059_MQ_SI1_J  = df_050_059_MQ_SI1_J.assign(Symmetry=None)
                    df_050_059_MQ_SI1_J  = df_050_059_MQ_SI1_J.assign(Ratio=None)
                    df_050_059_MQ_SI1_J  = df_050_059_MQ_SI1_J.assign(PPC=None)
                    df_050_059_MQ_SI1_J  = df_050_059_MQ_SI1_J.assign(Total=None)
                    df_050_059_MQ_SI1_J ['Wt Range'] = listwtrange
                    df_050_059_MQ_SI1_J ['Company'] = listcom
                    df_050_059_MQ_SI1_J ['Shape'] = listshap
                    df_050_059_MQ_SI1_J ['Carat'] = listcar
                    df_050_059_MQ_SI1_J ['Color'] = listcol
                    df_050_059_MQ_SI1_J ['Clarity'] = listclar
                    df_050_059_MQ_SI1_J ['Cut'] = listcut
                    df_050_059_MQ_SI1_J ['Polish'] = listpol
                    df_050_059_MQ_SI1_J ['Symmetry'] = listsym
                    df_050_059_MQ_SI1_J ['Ratio'] = listrat
                    df_050_059_MQ_SI1_J ['PPC'] = listdesc
                    df_050_059_MQ_SI1_J ['Total'] = listtotal
                    df_050_059_MQ_SI1_J['Carat'] = df_050_059_MQ_SI1_J['Carat'].astype('float64')
                    df_050_059_MQ_SI1_J['PPC'] = df_050_059_MQ_SI1_J['PPC'].astype('float64')
                    df_050_059_MQ_SI1_J['Total'] = df_050_059_MQ_SI1_J['Total'].astype('float64')
                    df_050_059_MQ_SI1_J['Total'] = df_050_059_MQ_SI1_J['Carat'] * df_050_059_MQ_SI1_J['PPC']


                elif i=="J"  and j == "SI2" and k == "MQ":
                    df_050_059_MQ_SI2_J = pd.DataFrame()
                    df_050_059_MQ_SI2_J ['Wt Range'] = None
                    df_050_059_MQ_SI2_J  = df_050_059_MQ_SI2_J.assign(Company=None)
                    df_050_059_MQ_SI2_J  = df_050_059_MQ_SI2_J.assign(Shape=None)
                    df_050_059_MQ_SI2_J  = df_050_059_MQ_SI2_J.assign(Carat=None)
                    df_050_059_MQ_SI2_J  = df_050_059_MQ_SI2_J.assign(Color=None)
                    df_050_059_MQ_SI2_J  = df_050_059_MQ_SI2_J.assign(Clarity=None)
                    df_050_059_MQ_SI2_J  = df_050_059_MQ_SI2_J.assign(Cut=None)
                    df_050_059_MQ_SI2_J  = df_050_059_MQ_SI2_J.assign(Polish=None)
                    df_050_059_MQ_SI2_J  = df_050_059_MQ_SI2_J.assign(Symmetry=None)
                    df_050_059_MQ_SI2_J  = df_050_059_MQ_SI2_J.assign(Ratio=None)
                    df_050_059_MQ_SI2_J  = df_050_059_MQ_SI2_J.assign(PPC=None)
                    df_050_059_MQ_SI2_J  = df_050_059_MQ_SI2_J.assign(Total=None)
                    df_050_059_MQ_SI2_J ['Wt Range'] = listwtrange
                    df_050_059_MQ_SI2_J ['Company'] = listcom
                    df_050_059_MQ_SI2_J ['Shape'] = listshap
                    df_050_059_MQ_SI2_J ['Carat'] = listcar
                    df_050_059_MQ_SI2_J ['Color'] = listcol
                    df_050_059_MQ_SI2_J ['Clarity'] = listclar
                    df_050_059_MQ_SI2_J ['Cut'] = listcut
                    df_050_059_MQ_SI2_J ['Polish'] = listpol
                    df_050_059_MQ_SI2_J ['Symmetry'] = listsym
                    df_050_059_MQ_SI2_J ['Ratio'] = listrat
                    df_050_059_MQ_SI2_J ['PPC'] = listdesc
                    df_050_059_MQ_SI2_J ['Total'] = listtotal
                    df_050_059_MQ_SI2_J['Carat'] = df_050_059_MQ_SI2_J['Carat'].astype('float64')
                    df_050_059_MQ_SI2_J['PPC'] = df_050_059_MQ_SI2_J['PPC'].astype('float64')
                    df_050_059_MQ_SI2_J['Total'] = df_050_059_MQ_SI2_J['Total'].astype('float64')
                    df_050_059_MQ_SI2_J['Total'] = df_050_059_MQ_SI2_J['Carat'] * df_050_059_MQ_SI2_J['PPC']


                elif i=="J"  and j == "I1" and k == "MQ":
                    df_050_059_MQ_I1_J = pd.DataFrame()
                    df_050_059_MQ_I1_J ['Wt Range'] = None
                    df_050_059_MQ_I1_J  = df_050_059_MQ_I1_J.assign(Company=None)
                    df_050_059_MQ_I1_J  = df_050_059_MQ_I1_J.assign(Shape=None)
                    df_050_059_MQ_I1_J  = df_050_059_MQ_I1_J.assign(Carat=None)
                    df_050_059_MQ_I1_J  = df_050_059_MQ_I1_J.assign(Color=None)
                    df_050_059_MQ_I1_J  = df_050_059_MQ_I1_J.assign(Clarity=None)
                    df_050_059_MQ_I1_J  = df_050_059_MQ_I1_J.assign(Cut=None)
                    df_050_059_MQ_I1_J  = df_050_059_MQ_I1_J.assign(Polish=None)
                    df_050_059_MQ_I1_J  = df_050_059_MQ_I1_J.assign(Symmetry=None)
                    df_050_059_MQ_I1_J  = df_050_059_MQ_I1_J.assign(Ratio=None)
                    df_050_059_MQ_I1_J  = df_050_059_MQ_I1_J.assign(PPC=None)
                    df_050_059_MQ_I1_J  = df_050_059_MQ_I1_J.assign(Total=None)
                    df_050_059_MQ_I1_J ['Wt Range'] = listwtrange
                    df_050_059_MQ_I1_J ['Company'] = listcom
                    df_050_059_MQ_I1_J ['Shape'] = listshap
                    df_050_059_MQ_I1_J ['Carat'] = listcar
                    df_050_059_MQ_I1_J ['Color'] = listcol
                    df_050_059_MQ_I1_J ['Clarity'] = listclar
                    df_050_059_MQ_I1_J ['Cut'] = listcut
                    df_050_059_MQ_I1_J ['Polish'] = listpol
                    df_050_059_MQ_I1_J ['Symmetry'] = listsym
                    df_050_059_MQ_I1_J ['Ratio'] = listrat
                    df_050_059_MQ_I1_J ['PPC'] = listdesc
                    df_050_059_MQ_I1_J ['Total'] = listtotal
                    df_050_059_MQ_I1_J['Carat'] = df_050_059_MQ_I1_J['Carat'].astype('float64')
                    df_050_059_MQ_I1_J['PPC'] = df_050_059_MQ_I1_J['PPC'].astype('float64')
                    df_050_059_MQ_I1_J['Total'] = df_050_059_MQ_I1_J['Total'].astype('float64')
                    df_050_059_MQ_I1_J['Total'] = df_050_059_MQ_I1_J['Carat'] * df_050_059_MQ_I1_J['PPC']


                elif i=="J"  and j == "I2" and k == "MQ":
                    df_050_059_MQ_I2_J = pd.DataFrame()
                    df_050_059_MQ_I2_J ['Wt Range'] = None
                    df_050_059_MQ_I2_J  = df_050_059_MQ_I2_J.assign(Company=None)
                    df_050_059_MQ_I2_J  = df_050_059_MQ_I2_J.assign(Shape=None)
                    df_050_059_MQ_I2_J  = df_050_059_MQ_I2_J.assign(Carat=None)
                    df_050_059_MQ_I2_J  = df_050_059_MQ_I2_J.assign(Color=None)
                    df_050_059_MQ_I2_J  = df_050_059_MQ_I2_J.assign(Clarity=None)
                    df_050_059_MQ_I2_J  = df_050_059_MQ_I2_J.assign(Cut=None)
                    df_050_059_MQ_I2_J  = df_050_059_MQ_I2_J.assign(Polish=None)
                    df_050_059_MQ_I2_J  = df_050_059_MQ_I2_J.assign(Symmetry=None)
                    df_050_059_MQ_I2_J  = df_050_059_MQ_I2_J.assign(Ratio=None)
                    df_050_059_MQ_I2_J  = df_050_059_MQ_I2_J.assign(PPC=None)
                    df_050_059_MQ_I2_J  = df_050_059_MQ_I2_J.assign(Total=None)
                    df_050_059_MQ_I2_J ['Wt Range'] = listwtrange
                    df_050_059_MQ_I2_J ['Company'] = listcom
                    df_050_059_MQ_I2_J ['Shape'] = listshap
                    df_050_059_MQ_I2_J ['Carat'] = listcar
                    df_050_059_MQ_I2_J ['Color'] = listcol
                    df_050_059_MQ_I2_J ['Clarity'] = listclar
                    df_050_059_MQ_I2_J ['Cut'] = listcut
                    df_050_059_MQ_I2_J ['Polish'] = listpol
                    df_050_059_MQ_I2_J ['Symmetry'] = listsym
                    df_050_059_MQ_I2_J ['Ratio'] = listrat
                    df_050_059_MQ_I2_J ['PPC'] = listdesc
                    df_050_059_MQ_I2_J ['Total'] = listtotal
                    df_050_059_MQ_I2_J['Carat'] = df_050_059_MQ_I2_J['Carat'].astype('float64')
                    df_050_059_MQ_I2_J['PPC'] = df_050_059_MQ_I2_J['PPC'].astype('float64')
                    df_050_059_MQ_I2_J['Total'] = df_050_059_MQ_I2_J['Total'].astype('float64')
                    df_050_059_MQ_I2_J['Total'] = df_050_059_MQ_I2_J['Carat'] * df_050_059_MQ_I2_J['PPC']


                elif i=="K" and j == "IF" and k == "MQ":
                    df_050_059_MQ_IF_K = pd.DataFrame()
                    df_050_059_MQ_IF_K ['Wt Range'] = None
                    df_050_059_MQ_IF_K  = df_050_059_MQ_IF_K.assign(Company=None)
                    df_050_059_MQ_IF_K  = df_050_059_MQ_IF_K.assign(Shape=None)
                    df_050_059_MQ_IF_K  = df_050_059_MQ_IF_K.assign(Carat=None)
                    df_050_059_MQ_IF_K  = df_050_059_MQ_IF_K.assign(Color=None)
                    df_050_059_MQ_IF_K  = df_050_059_MQ_IF_K.assign(Clarity=None)
                    df_050_059_MQ_IF_K  = df_050_059_MQ_IF_K.assign(Cut=None)
                    df_050_059_MQ_IF_K  = df_050_059_MQ_IF_K.assign(Polish=None)
                    df_050_059_MQ_IF_K  = df_050_059_MQ_IF_K.assign(Symmetry=None)
                    df_050_059_MQ_IF_K  = df_050_059_MQ_IF_K.assign(Ratio=None)
                    df_050_059_MQ_IF_K  = df_050_059_MQ_IF_K.assign(PPC=None)
                    df_050_059_MQ_IF_K  = df_050_059_MQ_IF_K.assign(Total=None)
                    df_050_059_MQ_IF_K ['Wt Range'] = listwtrange
                    df_050_059_MQ_IF_K ['Company'] = listcom
                    df_050_059_MQ_IF_K ['Shape'] = listshap
                    df_050_059_MQ_IF_K ['Carat'] = listcar
                    df_050_059_MQ_IF_K ['Color'] = listcol
                    df_050_059_MQ_IF_K ['Clarity'] = listclar
                    df_050_059_MQ_IF_K ['Cut'] = listcut
                    df_050_059_MQ_IF_K ['Polish'] = listpol
                    df_050_059_MQ_IF_K ['Symmetry'] = listsym
                    df_050_059_MQ_IF_K ['Ratio'] = listrat
                    df_050_059_MQ_IF_K ['PPC'] = listdesc
                    df_050_059_MQ_IF_K ['Total'] = listtotal
                    df_050_059_MQ_IF_K['Carat'] = df_050_059_MQ_IF_K['Carat'].astype('float64')
                    df_050_059_MQ_IF_K['PPC'] = df_050_059_MQ_IF_K['PPC'].astype('float64')
                    df_050_059_MQ_IF_K['Total'] = df_050_059_MQ_IF_K['Total'].astype('float64')
                    df_050_059_MQ_IF_K['Total'] = df_050_059_MQ_IF_K['Carat'] * df_050_059_MQ_IF_K['PPC']



                elif i=="K" and j == "VVS1" and k == "MQ":
                    df_050_059_MQ_VVS1_K = pd.DataFrame()
                    df_050_059_MQ_VVS1_K ['Wt Range'] = None
                    df_050_059_MQ_VVS1_K  = df_050_059_MQ_VVS1_K.assign(Company=None)
                    df_050_059_MQ_VVS1_K  = df_050_059_MQ_VVS1_K.assign(Shape=None)
                    df_050_059_MQ_VVS1_K  = df_050_059_MQ_VVS1_K.assign(Carat=None)
                    df_050_059_MQ_VVS1_K  = df_050_059_MQ_VVS1_K.assign(Color=None)
                    df_050_059_MQ_VVS1_K  = df_050_059_MQ_VVS1_K.assign(Clarity=None)
                    df_050_059_MQ_VVS1_K  = df_050_059_MQ_VVS1_K.assign(Cut=None)
                    df_050_059_MQ_VVS1_K  = df_050_059_MQ_VVS1_K.assign(Polish=None)
                    df_050_059_MQ_VVS1_K  = df_050_059_MQ_VVS1_K.assign(Symmetry=None)
                    df_050_059_MQ_VVS1_K  = df_050_059_MQ_VVS1_K.assign(Ratio=None)
                    df_050_059_MQ_VVS1_K  = df_050_059_MQ_VVS1_K.assign(PPC=None)
                    df_050_059_MQ_VVS1_K  = df_050_059_MQ_VVS1_K.assign(Total=None)
                    df_050_059_MQ_VVS1_K ['Wt Range'] = listwtrange
                    df_050_059_MQ_VVS1_K ['Company'] = listcom
                    df_050_059_MQ_VVS1_K ['Shape'] = listshap
                    df_050_059_MQ_VVS1_K ['Carat'] = listcar
                    df_050_059_MQ_VVS1_K ['Color'] = listcol
                    df_050_059_MQ_VVS1_K ['Clarity'] = listclar
                    df_050_059_MQ_VVS1_K ['Cut'] = listcut
                    df_050_059_MQ_VVS1_K ['Polish'] = listpol
                    df_050_059_MQ_VVS1_K ['Symmetry'] = listsym
                    df_050_059_MQ_VVS1_K ['Ratio'] = listrat
                    df_050_059_MQ_VVS1_K ['PPC'] = listdesc
                    df_050_059_MQ_VVS1_K ['Total'] = listtotal
                    df_050_059_MQ_VVS1_K['Carat'] = df_050_059_MQ_VVS1_K['Carat'].astype('float64')
                    df_050_059_MQ_VVS1_K['PPC'] = df_050_059_MQ_VVS1_K['PPC'].astype('float64')
                    df_050_059_MQ_VVS1_K['Total'] = df_050_059_MQ_VVS1_K['Total'].astype('float64')
                    df_050_059_MQ_VVS1_K['Total'] = df_050_059_MQ_VVS1_K['Carat'] * df_050_059_MQ_VVS1_K['PPC']


                elif i=="K" and j == "VVS2" and k == "MQ":
                    df_050_059_MQ_VVS2_K = pd.DataFrame()
                    df_050_059_MQ_VVS2_K ['Wt Range'] = None
                    df_050_059_MQ_VVS2_K  = df_050_059_MQ_VVS2_K.assign(Company=None)
                    df_050_059_MQ_VVS2_K  = df_050_059_MQ_VVS2_K.assign(Shape=None)
                    df_050_059_MQ_VVS2_K  = df_050_059_MQ_VVS2_K.assign(Carat=None)
                    df_050_059_MQ_VVS2_K  = df_050_059_MQ_VVS2_K.assign(Color=None)
                    df_050_059_MQ_VVS2_K  = df_050_059_MQ_VVS2_K.assign(Clarity=None)
                    df_050_059_MQ_VVS2_K  = df_050_059_MQ_VVS2_K.assign(Cut=None)
                    df_050_059_MQ_VVS2_K  = df_050_059_MQ_VVS2_K.assign(Polish=None)
                    df_050_059_MQ_VVS2_K  = df_050_059_MQ_VVS2_K.assign(Symmetry=None)
                    df_050_059_MQ_VVS2_K  = df_050_059_MQ_VVS2_K.assign(Ratio=None)
                    df_050_059_MQ_VVS2_K  = df_050_059_MQ_VVS2_K.assign(PPC=None)
                    df_050_059_MQ_VVS2_K  = df_050_059_MQ_VVS2_K.assign(Total=None)
                    df_050_059_MQ_VVS2_K ['Wt Range'] = listwtrange
                    df_050_059_MQ_VVS2_K ['Company'] = listcom
                    df_050_059_MQ_VVS2_K ['Shape'] = listshap
                    df_050_059_MQ_VVS2_K ['Carat'] = listcar
                    df_050_059_MQ_VVS2_K ['Color'] = listcol
                    df_050_059_MQ_VVS2_K ['Clarity'] = listclar
                    df_050_059_MQ_VVS2_K ['Cut'] = listcut
                    df_050_059_MQ_VVS2_K ['Polish'] = listpol
                    df_050_059_MQ_VVS2_K ['Symmetry'] = listsym
                    df_050_059_MQ_VVS2_K ['Ratio'] = listrat
                    df_050_059_MQ_VVS2_K ['PPC'] = listdesc
                    df_050_059_MQ_VVS2_K ['Total'] = listtotal
                    df_050_059_MQ_VVS2_K['Carat'] = df_050_059_MQ_VVS2_K['Carat'].astype('float64')
                    df_050_059_MQ_VVS2_K['PPC'] = df_050_059_MQ_VVS2_K['PPC'].astype('float64')
                    df_050_059_MQ_VVS2_K['Total'] = df_050_059_MQ_VVS2_K['Total'].astype('float64')
                    df_050_059_MQ_VVS2_K['Total'] = df_050_059_MQ_VVS2_K['Carat'] * df_050_059_MQ_VVS2_K['PPC']


                elif i=="K" and j=="VS1" and k == "MQ":
                    df_050_059_MQ_VS1_K = pd.DataFrame()
                    df_050_059_MQ_VS1_K ['Wt Range'] = None
                    df_050_059_MQ_VS1_K  = df_050_059_MQ_VS1_K.assign(Company=None)
                    df_050_059_MQ_VS1_K  = df_050_059_MQ_VS1_K.assign(Shape=None)
                    df_050_059_MQ_VS1_K  = df_050_059_MQ_VS1_K.assign(Carat=None)
                    df_050_059_MQ_VS1_K  = df_050_059_MQ_VS1_K.assign(Color=None)
                    df_050_059_MQ_VS1_K  = df_050_059_MQ_VS1_K.assign(Clarity=None)
                    df_050_059_MQ_VS1_K  = df_050_059_MQ_VS1_K.assign(Cut=None)
                    df_050_059_MQ_VS1_K  = df_050_059_MQ_VS1_K.assign(Polish=None)
                    df_050_059_MQ_VS1_K  = df_050_059_MQ_VS1_K.assign(Symmetry=None)
                    df_050_059_MQ_VS1_K  = df_050_059_MQ_VS1_K.assign(Ratio=None)
                    df_050_059_MQ_VS1_K  = df_050_059_MQ_VS1_K.assign(PPC=None)
                    df_050_059_MQ_VS1_K  = df_050_059_MQ_VS1_K.assign(Total=None)
                    df_050_059_MQ_VS1_K ['Wt Range'] = listwtrange
                    df_050_059_MQ_VS1_K ['Company'] = listcom
                    df_050_059_MQ_VS1_K ['Shape'] = listshap
                    df_050_059_MQ_VS1_K ['Carat'] = listcar
                    df_050_059_MQ_VS1_K ['Color'] = listcol
                    df_050_059_MQ_VS1_K ['Clarity'] = listclar
                    df_050_059_MQ_VS1_K ['Cut'] = listcut
                    df_050_059_MQ_VS1_K ['Polish'] = listpol
                    df_050_059_MQ_VS1_K ['Symmetry'] = listsym
                    df_050_059_MQ_VS1_K ['Ratio'] = listrat
                    df_050_059_MQ_VS1_K ['PPC'] = listdesc
                    df_050_059_MQ_VS1_K ['Total'] = listtotal
                    df_050_059_MQ_VS1_K['Carat'] = df_050_059_MQ_VS1_K['Carat'].astype('float64')
                    df_050_059_MQ_VS1_K['PPC'] = df_050_059_MQ_VS1_K['PPC'].astype('float64')
                    df_050_059_MQ_VS1_K['Total'] = df_050_059_MQ_VS1_K['Total'].astype('float64')
                    df_050_059_MQ_VS1_K['Total'] = df_050_059_MQ_VS1_K['Carat'] * df_050_059_MQ_VS1_K['PPC']


                elif i=="K" and j == "VS2" and k == "MQ":
                    df_050_059_MQ_VS2_K = pd.DataFrame()
                    df_050_059_MQ_VS2_K ['Wt Range'] = None
                    df_050_059_MQ_VS2_K  = df_050_059_MQ_VS2_K.assign(Company=None)
                    df_050_059_MQ_VS2_K  = df_050_059_MQ_VS2_K.assign(Shape=None)
                    df_050_059_MQ_VS2_K  = df_050_059_MQ_VS2_K.assign(Carat=None)
                    df_050_059_MQ_VS2_K  = df_050_059_MQ_VS2_K.assign(Color=None)
                    df_050_059_MQ_VS2_K  = df_050_059_MQ_VS2_K.assign(Clarity=None)
                    df_050_059_MQ_VS2_K  = df_050_059_MQ_VS2_K.assign(Cut=None)
                    df_050_059_MQ_VS2_K  = df_050_059_MQ_VS2_K.assign(Polish=None)
                    df_050_059_MQ_VS2_K  = df_050_059_MQ_VS2_K.assign(Symmetry=None)
                    df_050_059_MQ_VS2_K  = df_050_059_MQ_VS2_K.assign(Ratio=None)
                    df_050_059_MQ_VS2_K  = df_050_059_MQ_VS2_K.assign(PPC=None)
                    df_050_059_MQ_VS2_K  = df_050_059_MQ_VS2_K.assign(Total=None)
                    df_050_059_MQ_VS2_K ['Wt Range'] = listwtrange
                    df_050_059_MQ_VS2_K ['Company'] = listcom
                    df_050_059_MQ_VS2_K ['Shape'] = listshap
                    df_050_059_MQ_VS2_K ['Carat'] = listcar
                    df_050_059_MQ_VS2_K ['Color'] = listcol
                    df_050_059_MQ_VS2_K ['Clarity'] = listclar
                    df_050_059_MQ_VS2_K ['Cut'] = listcut
                    df_050_059_MQ_VS2_K ['Polish'] = listpol
                    df_050_059_MQ_VS2_K ['Symmetry'] = listsym
                    df_050_059_MQ_VS2_K ['Ratio'] = listrat
                    df_050_059_MQ_VS2_K ['PPC'] = listdesc
                    df_050_059_MQ_VS2_K ['Total'] = listtotal
                    df_050_059_MQ_VS2_K['Carat'] = df_050_059_MQ_VS2_K['Carat'].astype('float64')
                    df_050_059_MQ_VS2_K['PPC'] = df_050_059_MQ_VS2_K['PPC'].astype('float64')
                    df_050_059_MQ_VS2_K['Total'] = df_050_059_MQ_VS2_K['Total'].astype('float64')
                    df_050_059_MQ_VS2_K['Total'] = df_050_059_MQ_VS2_K['Carat'] * df_050_059_MQ_VS2_K['PPC']


                elif i=="K" and j == "SI1" and k == "MQ":
                    df_050_059_MQ_SI1_K = pd.DataFrame()
                    df_050_059_MQ_SI1_K ['Wt Range'] = None
                    df_050_059_MQ_SI1_K  = df_050_059_MQ_SI1_K.assign(Company=None)
                    df_050_059_MQ_SI1_K  = df_050_059_MQ_SI1_K.assign(Shape=None)
                    df_050_059_MQ_SI1_K  = df_050_059_MQ_SI1_K.assign(Carat=None)
                    df_050_059_MQ_SI1_K  = df_050_059_MQ_SI1_K.assign(Color=None)
                    df_050_059_MQ_SI1_K  = df_050_059_MQ_SI1_K.assign(Clarity=None)
                    df_050_059_MQ_SI1_K  = df_050_059_MQ_SI1_K.assign(Cut=None)
                    df_050_059_MQ_SI1_K  = df_050_059_MQ_SI1_K.assign(Polish=None)
                    df_050_059_MQ_SI1_K  = df_050_059_MQ_SI1_K.assign(Symmetry=None)
                    df_050_059_MQ_SI1_K  = df_050_059_MQ_SI1_K.assign(Ratio=None)
                    df_050_059_MQ_SI1_K  = df_050_059_MQ_SI1_K.assign(PPC=None)
                    df_050_059_MQ_SI1_K  = df_050_059_MQ_SI1_K.assign(Total=None)
                    df_050_059_MQ_SI1_K ['Wt Range'] = listwtrange
                    df_050_059_MQ_SI1_K ['Company'] = listcom
                    df_050_059_MQ_SI1_K ['Shape'] = listshap
                    df_050_059_MQ_SI1_K ['Carat'] = listcar
                    df_050_059_MQ_SI1_K ['Color'] = listcol
                    df_050_059_MQ_SI1_K ['Clarity'] = listclar
                    df_050_059_MQ_SI1_K ['Cut'] = listcut
                    df_050_059_MQ_SI1_K ['Polish'] = listpol
                    df_050_059_MQ_SI1_K ['Symmetry'] = listsym
                    df_050_059_MQ_SI1_K ['Ratio'] = listrat
                    df_050_059_MQ_SI1_K ['PPC'] = listdesc
                    df_050_059_MQ_SI1_K ['Total'] = listtotal
                    df_050_059_MQ_SI1_K['Carat'] = df_050_059_MQ_SI1_K['Carat'].astype('float64')
                    df_050_059_MQ_SI1_K['PPC'] = df_050_059_MQ_SI1_K['PPC'].astype('float64')
                    df_050_059_MQ_SI1_K['Total'] = df_050_059_MQ_SI1_K['Total'].astype('float64')
                    df_050_059_MQ_SI1_K['Total'] = df_050_059_MQ_SI1_K['Carat'] * df_050_059_MQ_SI1_K['PPC']


                elif i=="K" and j == "SI2" and k == "MQ":
                    df_050_059_MQ_SI2_K = pd.DataFrame()
                    df_050_059_MQ_SI2_K ['Wt Range'] = None
                    df_050_059_MQ_SI2_K  = df_050_059_MQ_SI2_K.assign(Company=None)
                    df_050_059_MQ_SI2_K  = df_050_059_MQ_SI2_K.assign(Shape=None)
                    df_050_059_MQ_SI2_K  = df_050_059_MQ_SI2_K.assign(Carat=None)
                    df_050_059_MQ_SI2_K  = df_050_059_MQ_SI2_K.assign(Color=None)
                    df_050_059_MQ_SI2_K  = df_050_059_MQ_SI2_K.assign(Clarity=None)
                    df_050_059_MQ_SI2_K  = df_050_059_MQ_SI2_K.assign(Cut=None)
                    df_050_059_MQ_SI2_K  = df_050_059_MQ_SI2_K.assign(Polish=None)
                    df_050_059_MQ_SI2_K  = df_050_059_MQ_SI2_K.assign(Symmetry=None)
                    df_050_059_MQ_SI2_K  = df_050_059_MQ_SI2_K.assign(Ratio=None)
                    df_050_059_MQ_SI2_K  = df_050_059_MQ_SI2_K.assign(PPC=None)
                    df_050_059_MQ_SI2_K  = df_050_059_MQ_SI2_K.assign(Total=None)
                    df_050_059_MQ_SI2_K ['Wt Range'] = listwtrange
                    df_050_059_MQ_SI2_K ['Company'] = listcom
                    df_050_059_MQ_SI2_K ['Shape'] = listshap
                    df_050_059_MQ_SI2_K ['Carat'] = listcar
                    df_050_059_MQ_SI2_K ['Color'] = listcol
                    df_050_059_MQ_SI2_K ['Clarity'] = listclar
                    df_050_059_MQ_SI2_K ['Cut'] = listcut
                    df_050_059_MQ_SI2_K ['Polish'] = listpol
                    df_050_059_MQ_SI2_K ['Symmetry'] = listsym
                    df_050_059_MQ_SI2_K ['Ratio'] = listrat
                    df_050_059_MQ_SI2_K ['PPC'] = listdesc
                    df_050_059_MQ_SI2_K ['Total'] = listtotal
                    df_050_059_MQ_SI2_K['Carat'] = df_050_059_MQ_SI2_K['Carat'].astype('float64')
                    df_050_059_MQ_SI2_K['PPC'] = df_050_059_MQ_SI2_K['PPC'].astype('float64')
                    df_050_059_MQ_SI2_K['Total'] = df_050_059_MQ_SI2_K['Total'].astype('float64')
                    df_050_059_MQ_SI2_K['Total'] = df_050_059_MQ_SI2_K['Carat'] * df_050_059_MQ_SI2_K['PPC']


                elif i=="K" and j == "I1" and k == "MQ":
                    df_050_059_MQ_I1_K = pd.DataFrame()
                    df_050_059_MQ_I1_K ['Wt Range'] = None
                    df_050_059_MQ_I1_K  = df_050_059_MQ_I1_K.assign(Company=None)
                    df_050_059_MQ_I1_K  = df_050_059_MQ_I1_K.assign(Shape=None)
                    df_050_059_MQ_I1_K  = df_050_059_MQ_I1_K.assign(Carat=None)
                    df_050_059_MQ_I1_K  = df_050_059_MQ_I1_K.assign(Color=None)
                    df_050_059_MQ_I1_K  = df_050_059_MQ_I1_K.assign(Clarity=None)
                    df_050_059_MQ_I1_K  = df_050_059_MQ_I1_K.assign(Cut=None)
                    df_050_059_MQ_I1_K  = df_050_059_MQ_I1_K.assign(Polish=None)
                    df_050_059_MQ_I1_K  = df_050_059_MQ_I1_K.assign(Symmetry=None)
                    df_050_059_MQ_I1_K  = df_050_059_MQ_I1_K.assign(Ratio=None)
                    df_050_059_MQ_I1_K  = df_050_059_MQ_I1_K.assign(PPC=None)
                    df_050_059_MQ_I1_K  = df_050_059_MQ_I1_K.assign(Total=None)
                    df_050_059_MQ_I1_K ['Wt Range'] = listwtrange
                    df_050_059_MQ_I1_K ['Company'] = listcom
                    df_050_059_MQ_I1_K ['Shape'] = listshap
                    df_050_059_MQ_I1_K ['Carat'] = listcar
                    df_050_059_MQ_I1_K ['Color'] = listcol
                    df_050_059_MQ_I1_K ['Clarity'] = listclar
                    df_050_059_MQ_I1_K ['Cut'] = listcut
                    df_050_059_MQ_I1_K ['Polish'] = listpol
                    df_050_059_MQ_I1_K ['Symmetry'] = listsym
                    df_050_059_MQ_I1_K ['Ratio'] = listrat
                    df_050_059_MQ_I1_K ['PPC'] = listdesc
                    df_050_059_MQ_I1_K ['Total'] = listtotal
                    df_050_059_MQ_I1_K['Carat'] = df_050_059_MQ_I1_K['Carat'].astype('float64')
                    df_050_059_MQ_I1_K['PPC'] = df_050_059_MQ_I1_K['PPC'].astype('float64')
                    df_050_059_MQ_I1_K['Total'] = df_050_059_MQ_I1_K['Total'].astype('float64')
                    df_050_059_MQ_I1_K['Total'] = df_050_059_MQ_I1_K['Carat'] * df_050_059_MQ_I1_K['PPC']


                elif i=="K" and j == "I2" and k == "MQ":
                    df_050_059_MQ_I2_K = pd.DataFrame()
                    df_050_059_MQ_I2_K ['Wt Range'] = None
                    df_050_059_MQ_I2_K  = df_050_059_MQ_I2_K.assign(Company=None)
                    df_050_059_MQ_I2_K  = df_050_059_MQ_I2_K.assign(Shape=None)
                    df_050_059_MQ_I2_K  = df_050_059_MQ_I2_K.assign(Carat=None)
                    df_050_059_MQ_I2_K  = df_050_059_MQ_I2_K.assign(Color=None)
                    df_050_059_MQ_I2_K  = df_050_059_MQ_I2_K.assign(Clarity=None)
                    df_050_059_MQ_I2_K  = df_050_059_MQ_I2_K.assign(Cut=None)
                    df_050_059_MQ_I2_K  = df_050_059_MQ_I2_K.assign(Polish=None)
                    df_050_059_MQ_I2_K  = df_050_059_MQ_I2_K.assign(Symmetry=None)
                    df_050_059_MQ_I2_K  = df_050_059_MQ_I2_K.assign(Ratio=None)
                    df_050_059_MQ_I2_K  = df_050_059_MQ_I2_K.assign(PPC=None)
                    df_050_059_MQ_I2_K  = df_050_059_MQ_I2_K.assign(Total=None)
                    df_050_059_MQ_I2_K ['Wt Range'] = listwtrange
                    df_050_059_MQ_I2_K ['Company'] = listcom
                    df_050_059_MQ_I2_K ['Shape'] = listshap
                    df_050_059_MQ_I2_K ['Carat'] = listcar
                    df_050_059_MQ_I2_K ['Color'] = listcol
                    df_050_059_MQ_I2_K ['Clarity'] = listclar
                    df_050_059_MQ_I2_K ['Cut'] = listcut
                    df_050_059_MQ_I2_K ['Polish'] = listpol
                    df_050_059_MQ_I2_K ['Symmetry'] = listsym
                    df_050_059_MQ_I2_K ['Ratio'] = listrat
                    df_050_059_MQ_I2_K ['PPC'] = listdesc
                    df_050_059_MQ_I2_K ['Total'] = listtotal
                    df_050_059_MQ_I2_K['Carat'] = df_050_059_MQ_I2_K['Carat'].astype('float64')
                    df_050_059_MQ_I2_K['PPC'] = df_050_059_MQ_I2_K['PPC'].astype('float64')
                    df_050_059_MQ_I2_K['Total'] = df_050_059_MQ_I2_K['Total'].astype('float64')
                    df_050_059_MQ_I2_K['Total'] = df_050_059_MQ_I2_K['Carat'] * df_050_059_MQ_I2_K['PPC']


                elif i=="L" and j == "IF" and k == "MQ":
                    df_050_059_MQ_IF_L = pd.DataFrame()
                    df_050_059_MQ_IF_L ['Wt Range'] = None
                    df_050_059_MQ_IF_L  = df_050_059_MQ_IF_L.assign(Company=None)
                    df_050_059_MQ_IF_L  = df_050_059_MQ_IF_L.assign(Shape=None)
                    df_050_059_MQ_IF_L  = df_050_059_MQ_IF_L.assign(Carat=None)
                    df_050_059_MQ_IF_L  = df_050_059_MQ_IF_L.assign(Color=None)
                    df_050_059_MQ_IF_L  = df_050_059_MQ_IF_L.assign(Clarity=None)
                    df_050_059_MQ_IF_L  = df_050_059_MQ_IF_L.assign(Cut=None)
                    df_050_059_MQ_IF_L  = df_050_059_MQ_IF_L.assign(Polish=None)
                    df_050_059_MQ_IF_L  = df_050_059_MQ_IF_L.assign(Symmetry=None)
                    df_050_059_MQ_IF_L  = df_050_059_MQ_IF_L.assign(Ratio=None)
                    df_050_059_MQ_IF_L  = df_050_059_MQ_IF_L.assign(PPC=None)
                    df_050_059_MQ_IF_L  = df_050_059_MQ_IF_L.assign(Total=None)
                    df_050_059_MQ_IF_L ['Wt Range'] = listwtrange
                    df_050_059_MQ_IF_L ['Company'] = listcom
                    df_050_059_MQ_IF_L ['Shape'] = listshap
                    df_050_059_MQ_IF_L ['Carat'] = listcar
                    df_050_059_MQ_IF_L ['Color'] = listcol
                    df_050_059_MQ_IF_L ['Clarity'] = listclar
                    df_050_059_MQ_IF_L ['Cut'] = listcut
                    df_050_059_MQ_IF_L ['Polish'] = listpol
                    df_050_059_MQ_IF_L ['Symmetry'] = listsym
                    df_050_059_MQ_IF_L ['Ratio'] = listrat
                    df_050_059_MQ_IF_L ['PPC'] = listdesc
                    df_050_059_MQ_IF_L ['Total'] = listtotal
                    df_050_059_MQ_IF_L['Carat'] = df_050_059_MQ_IF_L['Carat'].astype('float64')
                    df_050_059_MQ_IF_L['PPC'] = df_050_059_MQ_IF_L['PPC'].astype('float64')
                    df_050_059_MQ_IF_L['Total'] = df_050_059_MQ_IF_L['Total'].astype('float64')
                    df_050_059_MQ_IF_L['Total'] = df_050_059_MQ_IF_L['Carat'] * df_050_059_MQ_IF_L['PPC']


                elif i=="L" and j == "VVS1" and k == "MQ":
                    df_050_059_MQ_VVS1_L = pd.DataFrame()
                    df_050_059_MQ_VVS1_L ['Wt Range'] = None
                    df_050_059_MQ_VVS1_L  = df_050_059_MQ_VVS1_L.assign(Company=None)
                    df_050_059_MQ_VVS1_L  = df_050_059_MQ_VVS1_L.assign(Shape=None)
                    df_050_059_MQ_VVS1_L  = df_050_059_MQ_VVS1_L.assign(Carat=None)
                    df_050_059_MQ_VVS1_L  = df_050_059_MQ_VVS1_L.assign(Color=None)
                    df_050_059_MQ_VVS1_L  = df_050_059_MQ_VVS1_L.assign(Clarity=None)
                    df_050_059_MQ_VVS1_L  = df_050_059_MQ_VVS1_L.assign(Cut=None)
                    df_050_059_MQ_VVS1_L  = df_050_059_MQ_VVS1_L.assign(Polish=None)
                    df_050_059_MQ_VVS1_L  = df_050_059_MQ_VVS1_L.assign(Symmetry=None)
                    df_050_059_MQ_VVS1_L  = df_050_059_MQ_VVS1_L.assign(Ratio=None)
                    df_050_059_MQ_VVS1_L  = df_050_059_MQ_VVS1_L.assign(PPC=None)
                    df_050_059_MQ_VVS1_L  = df_050_059_MQ_VVS1_L.assign(Total=None)
                    df_050_059_MQ_VVS1_L ['Wt Range'] = listwtrange
                    df_050_059_MQ_VVS1_L ['Company'] = listcom
                    df_050_059_MQ_VVS1_L ['Shape'] = listshap
                    df_050_059_MQ_VVS1_L ['Carat'] = listcar
                    df_050_059_MQ_VVS1_L ['Color'] = listcol
                    df_050_059_MQ_VVS1_L ['Clarity'] = listclar
                    df_050_059_MQ_VVS1_L ['Cut'] = listcut
                    df_050_059_MQ_VVS1_L ['Polish'] = listpol
                    df_050_059_MQ_VVS1_L ['Symmetry'] = listsym
                    df_050_059_MQ_VVS1_L ['Ratio'] = listrat
                    df_050_059_MQ_VVS1_L ['PPC'] = listdesc
                    df_050_059_MQ_VVS1_L ['Total'] = listtotal
                    df_050_059_MQ_VVS1_L['Carat'] = df_050_059_MQ_VVS1_L['Carat'].astype('float64')
                    df_050_059_MQ_VVS1_L['PPC'] = df_050_059_MQ_VVS1_L['PPC'].astype('float64')
                    df_050_059_MQ_VVS1_L['Total'] = df_050_059_MQ_VVS1_L['Total'].astype('float64')
                    df_050_059_MQ_VVS1_L['Total'] = df_050_059_MQ_VVS1_L['Carat'] * df_050_059_MQ_VVS1_L['PPC']


                elif i=="L" and j == "VVS2" and k == "MQ":
                    df_050_059_MQ_VVS2_L = pd.DataFrame()
                    df_050_059_MQ_VVS2_L ['Wt Range'] = None
                    df_050_059_MQ_VVS2_L  = df_050_059_MQ_VVS2_L.assign(Company=None)
                    df_050_059_MQ_VVS2_L  = df_050_059_MQ_VVS2_L.assign(Shape=None)
                    df_050_059_MQ_VVS2_L  = df_050_059_MQ_VVS2_L.assign(Carat=None)
                    df_050_059_MQ_VVS2_L  = df_050_059_MQ_VVS2_L.assign(Color=None)
                    df_050_059_MQ_VVS2_L  = df_050_059_MQ_VVS2_L.assign(Clarity=None)
                    df_050_059_MQ_VVS2_L  = df_050_059_MQ_VVS2_L.assign(Cut=None)
                    df_050_059_MQ_VVS2_L  = df_050_059_MQ_VVS2_L.assign(Polish=None)
                    df_050_059_MQ_VVS2_L  = df_050_059_MQ_VVS2_L.assign(Symmetry=None)
                    df_050_059_MQ_VVS2_L  = df_050_059_MQ_VVS2_L.assign(Ratio=None)
                    df_050_059_MQ_VVS2_L  = df_050_059_MQ_VVS2_L.assign(PPC=None)
                    df_050_059_MQ_VVS2_L  = df_050_059_MQ_VVS2_L.assign(Total=None)
                    df_050_059_MQ_VVS2_L ['Wt Range'] = listwtrange
                    df_050_059_MQ_VVS2_L ['Company'] = listcom
                    df_050_059_MQ_VVS2_L ['Shape'] = listshap
                    df_050_059_MQ_VVS2_L ['Carat'] = listcar
                    df_050_059_MQ_VVS2_L ['Color'] = listcol
                    df_050_059_MQ_VVS2_L ['Clarity'] = listclar
                    df_050_059_MQ_VVS2_L ['Cut'] = listcut
                    df_050_059_MQ_VVS2_L ['Polish'] = listpol
                    df_050_059_MQ_VVS2_L ['Symmetry'] = listsym
                    df_050_059_MQ_VVS2_L ['Ratio'] = listrat
                    df_050_059_MQ_VVS2_L ['PPC'] = listdesc
                    df_050_059_MQ_VVS2_L ['Total'] = listtotal
                    df_050_059_MQ_VVS2_L['Carat'] = df_050_059_MQ_VVS2_L['Carat'].astype('float64')
                    df_050_059_MQ_VVS2_L['PPC'] = df_050_059_MQ_VVS2_L['PPC'].astype('float64')
                    df_050_059_MQ_VVS2_L['Total'] = df_050_059_MQ_VVS2_L['Total'].astype('float64')
                    df_050_059_MQ_VVS2_L['Total'] = df_050_059_MQ_VVS2_L['Carat'] * df_050_059_MQ_VVS2_L['PPC']


                elif i=="L" and j=="VS1" and k == "MQ":
                    df_050_059_MQ_VS1_L = pd.DataFrame()
                    df_050_059_MQ_VS1_L ['Wt Range'] = None
                    df_050_059_MQ_VS1_L  = df_050_059_MQ_VS1_L.assign(Company=None)
                    df_050_059_MQ_VS1_L  = df_050_059_MQ_VS1_L.assign(Shape=None)
                    df_050_059_MQ_VS1_L  = df_050_059_MQ_VS1_L.assign(Carat=None)
                    df_050_059_MQ_VS1_L  = df_050_059_MQ_VS1_L.assign(Color=None)
                    df_050_059_MQ_VS1_L  = df_050_059_MQ_VS1_L.assign(Clarity=None)
                    df_050_059_MQ_VS1_L  = df_050_059_MQ_VS1_L.assign(Cut=None)
                    df_050_059_MQ_VS1_L  = df_050_059_MQ_VS1_L.assign(Polish=None)
                    df_050_059_MQ_VS1_L  = df_050_059_MQ_VS1_L.assign(Symmetry=None)
                    df_050_059_MQ_VS1_L  = df_050_059_MQ_VS1_L.assign(Ratio=None)
                    df_050_059_MQ_VS1_L  = df_050_059_MQ_VS1_L.assign(PPC=None)
                    df_050_059_MQ_VS1_L  = df_050_059_MQ_VS1_L.assign(Total=None)
                    df_050_059_MQ_VS1_L ['Wt Range'] = listwtrange
                    df_050_059_MQ_VS1_L ['Company'] = listcom
                    df_050_059_MQ_VS1_L ['Shape'] = listshap
                    df_050_059_MQ_VS1_L ['Carat'] = listcar
                    df_050_059_MQ_VS1_L ['Color'] = listcol
                    df_050_059_MQ_VS1_L ['Clarity'] = listclar
                    df_050_059_MQ_VS1_L ['Cut'] = listcut
                    df_050_059_MQ_VS1_L ['Polish'] = listpol
                    df_050_059_MQ_VS1_L ['Symmetry'] = listsym
                    df_050_059_MQ_VS1_L ['Ratio'] = listrat
                    df_050_059_MQ_VS1_L ['PPC'] = listdesc
                    df_050_059_MQ_VS1_L ['Total'] = listtotal
                    df_050_059_MQ_VS1_L['Carat'] = df_050_059_MQ_VS1_L['Carat'].astype('float64')
                    df_050_059_MQ_VS1_L['PPC'] = df_050_059_MQ_VS1_L['PPC'].astype('float64')
                    df_050_059_MQ_VS1_L['Total'] = df_050_059_MQ_VS1_L['Total'].astype('float64')
                    df_050_059_MQ_VS1_L['Total'] = df_050_059_MQ_VS1_L['Carat'] * df_050_059_MQ_VS1_L['PPC']


                elif i=="L" and j == "VS2" and k == "MQ":
                    df_050_059_MQ_VS2_L = pd.DataFrame()
                    df_050_059_MQ_VS2_L ['Wt Range'] = None
                    df_050_059_MQ_VS2_L  = df_050_059_MQ_VS2_L.assign(Company=None)
                    df_050_059_MQ_VS2_L  = df_050_059_MQ_VS2_L.assign(Shape=None)
                    df_050_059_MQ_VS2_L  = df_050_059_MQ_VS2_L.assign(Carat=None)
                    df_050_059_MQ_VS2_L  = df_050_059_MQ_VS2_L.assign(Color=None)
                    df_050_059_MQ_VS2_L  = df_050_059_MQ_VS2_L.assign(Clarity=None)
                    df_050_059_MQ_VS2_L  = df_050_059_MQ_VS2_L.assign(Cut=None)
                    df_050_059_MQ_VS2_L  = df_050_059_MQ_VS2_L.assign(Polish=None)
                    df_050_059_MQ_VS2_L  = df_050_059_MQ_VS2_L.assign(Symmetry=None)
                    df_050_059_MQ_VS2_L  = df_050_059_MQ_VS2_L.assign(Ratio=None)
                    df_050_059_MQ_VS2_L  = df_050_059_MQ_VS2_L.assign(PPC=None)
                    df_050_059_MQ_VS2_L  = df_050_059_MQ_VS2_L.assign(Total=None)
                    df_050_059_MQ_VS2_L ['Wt Range'] = listwtrange
                    df_050_059_MQ_VS2_L ['Company'] = listcom
                    df_050_059_MQ_VS2_L ['Shape'] = listshap
                    df_050_059_MQ_VS2_L ['Carat'] = listcar
                    df_050_059_MQ_VS2_L ['Color'] = listcol
                    df_050_059_MQ_VS2_L ['Clarity'] = listclar
                    df_050_059_MQ_VS2_L ['Cut'] = listcut
                    df_050_059_MQ_VS2_L ['Polish'] = listpol
                    df_050_059_MQ_VS2_L ['Symmetry'] = listsym
                    df_050_059_MQ_VS2_L ['Ratio'] = listrat
                    df_050_059_MQ_VS2_L ['PPC'] = listdesc
                    df_050_059_MQ_VS2_L ['Total'] = listtotal
                    df_050_059_MQ_VS2_L['Carat'] = df_050_059_MQ_VS2_L['Carat'].astype('float64')
                    df_050_059_MQ_VS2_L['PPC'] = df_050_059_MQ_VS2_L['PPC'].astype('float64')
                    df_050_059_MQ_VS2_L['Total'] = df_050_059_MQ_VS2_L['Total'].astype('float64')
                    df_050_059_MQ_VS2_L['Total'] = df_050_059_MQ_VS2_L['Carat'] * df_050_059_MQ_VS2_L['PPC']


                elif i=="L" and j == "SI1" and k == "MQ":
                    df_050_059_MQ_SI1_L = pd.DataFrame()
                    df_050_059_MQ_SI1_L ['Wt Range'] = None
                    df_050_059_MQ_SI1_L  = df_050_059_MQ_SI1_L.assign(Company=None)
                    df_050_059_MQ_SI1_L  = df_050_059_MQ_SI1_L.assign(Shape=None)
                    df_050_059_MQ_SI1_L  = df_050_059_MQ_SI1_L.assign(Carat=None)
                    df_050_059_MQ_SI1_L  = df_050_059_MQ_SI1_L.assign(Color=None)
                    df_050_059_MQ_SI1_L  = df_050_059_MQ_SI1_L.assign(Clarity=None)
                    df_050_059_MQ_SI1_L  = df_050_059_MQ_SI1_L.assign(Cut=None)
                    df_050_059_MQ_SI1_L  = df_050_059_MQ_SI1_L.assign(Polish=None)
                    df_050_059_MQ_SI1_L  = df_050_059_MQ_SI1_L.assign(Symmetry=None)
                    df_050_059_MQ_SI1_L  = df_050_059_MQ_SI1_L.assign(Ratio=None)
                    df_050_059_MQ_SI1_L  = df_050_059_MQ_SI1_L.assign(PPC=None)
                    df_050_059_MQ_SI1_L  = df_050_059_MQ_SI1_L.assign(Total=None)
                    df_050_059_MQ_SI1_L ['Wt Range'] = listwtrange
                    df_050_059_MQ_SI1_L ['Company'] = listcom
                    df_050_059_MQ_SI1_L ['Shape'] = listshap
                    df_050_059_MQ_SI1_L ['Carat'] = listcar
                    df_050_059_MQ_SI1_L ['Color'] = listcol
                    df_050_059_MQ_SI1_L ['Clarity'] = listclar
                    df_050_059_MQ_SI1_L ['Cut'] = listcut
                    df_050_059_MQ_SI1_L ['Polish'] = listpol
                    df_050_059_MQ_SI1_L ['Symmetry'] = listsym
                    df_050_059_MQ_SI1_L ['Ratio'] = listrat
                    df_050_059_MQ_SI1_L ['PPC'] = listdesc
                    df_050_059_MQ_SI1_L ['Total'] = listtotal
                    df_050_059_MQ_SI1_L['Carat'] = df_050_059_MQ_SI1_L['Carat'].astype('float64')
                    df_050_059_MQ_SI1_L['PPC'] = df_050_059_MQ_SI1_L['PPC'].astype('float64')
                    df_050_059_MQ_SI1_L['Total'] = df_050_059_MQ_SI1_L['Total'].astype('float64')
                    df_050_059_MQ_SI1_L['Total'] = df_050_059_MQ_SI1_L['Carat'] * df_050_059_MQ_SI1_L['PPC']


                elif i=="L" and j == "SI2" and k == "MQ":
                    df_050_059_MQ_SI2_L = pd.DataFrame()
                    df_050_059_MQ_SI2_L ['Wt Range'] = None
                    df_050_059_MQ_SI2_L  = df_050_059_MQ_SI2_L.assign(Company=None)
                    df_050_059_MQ_SI2_L  = df_050_059_MQ_SI2_L.assign(Shape=None)
                    df_050_059_MQ_SI2_L  = df_050_059_MQ_SI2_L.assign(Carat=None)
                    df_050_059_MQ_SI2_L  = df_050_059_MQ_SI2_L.assign(Color=None)
                    df_050_059_MQ_SI2_L  = df_050_059_MQ_SI2_L.assign(Clarity=None)
                    df_050_059_MQ_SI2_L  = df_050_059_MQ_SI2_L.assign(Cut=None)
                    df_050_059_MQ_SI2_L  = df_050_059_MQ_SI2_L.assign(Polish=None)
                    df_050_059_MQ_SI2_L  = df_050_059_MQ_SI2_L.assign(Symmetry=None)
                    df_050_059_MQ_SI2_L  = df_050_059_MQ_SI2_L.assign(Ratio=None)
                    df_050_059_MQ_SI2_L  = df_050_059_MQ_SI2_L.assign(PPC=None)
                    df_050_059_MQ_SI2_L  = df_050_059_MQ_SI2_L.assign(Total=None)
                    df_050_059_MQ_SI2_L ['Wt Range'] = listwtrange
                    df_050_059_MQ_SI2_L ['Company'] = listcom
                    df_050_059_MQ_SI2_L ['Shape'] = listshap
                    df_050_059_MQ_SI2_L ['Carat'] = listcar
                    df_050_059_MQ_SI2_L ['Color'] = listcol
                    df_050_059_MQ_SI2_L ['Clarity'] = listclar
                    df_050_059_MQ_SI2_L ['Cut'] = listcut
                    df_050_059_MQ_SI2_L ['Polish'] = listpol
                    df_050_059_MQ_SI2_L ['Symmetry'] = listsym
                    df_050_059_MQ_SI2_L ['Ratio'] = listrat
                    df_050_059_MQ_SI2_L ['PPC'] = listdesc
                    df_050_059_MQ_SI2_L ['Total'] = listtotal
                    df_050_059_MQ_SI2_L['Carat'] = df_050_059_MQ_SI2_L['Carat'].astype('float64')
                    df_050_059_MQ_SI2_L['PPC'] = df_050_059_MQ_SI2_L['PPC'].astype('float64')
                    df_050_059_MQ_SI2_L['Total'] = df_050_059_MQ_SI2_L['Total'].astype('float64')
                    df_050_059_MQ_SI2_L['Total'] = df_050_059_MQ_SI2_L['Carat'] * df_050_059_MQ_SI2_L['PPC']


                elif i=="L" and j == "I1" and k == "MQ":
                    df_050_059_MQ_I1_L = pd.DataFrame()
                    df_050_059_MQ_I1_L ['Wt Range'] = None
                    df_050_059_MQ_I1_L  = df_050_059_MQ_I1_L.assign(Company=None)
                    df_050_059_MQ_I1_L  = df_050_059_MQ_I1_L.assign(Shape=None)
                    df_050_059_MQ_I1_L  = df_050_059_MQ_I1_L.assign(Carat=None)
                    df_050_059_MQ_I1_L  = df_050_059_MQ_I1_L.assign(Color=None)
                    df_050_059_MQ_I1_L  = df_050_059_MQ_I1_L.assign(Clarity=None)
                    df_050_059_MQ_I1_L  = df_050_059_MQ_I1_L.assign(Cut=None)
                    df_050_059_MQ_I1_L  = df_050_059_MQ_I1_L.assign(Polish=None)
                    df_050_059_MQ_I1_L  = df_050_059_MQ_I1_L.assign(Symmetry=None)
                    df_050_059_MQ_I1_L  = df_050_059_MQ_I1_L.assign(Ratio=None)
                    df_050_059_MQ_I1_L  = df_050_059_MQ_I1_L.assign(PPC=None)
                    df_050_059_MQ_I1_L  = df_050_059_MQ_I1_L.assign(Total=None)
                    df_050_059_MQ_I1_L ['Wt Range'] = listwtrange
                    df_050_059_MQ_I1_L ['Company'] = listcom
                    df_050_059_MQ_I1_L ['Shape'] = listshap
                    df_050_059_MQ_I1_L ['Carat'] = listcar
                    df_050_059_MQ_I1_L ['Color'] = listcol
                    df_050_059_MQ_I1_L ['Clarity'] = listclar
                    df_050_059_MQ_I1_L ['Cut'] = listcut
                    df_050_059_MQ_I1_L ['Polish'] = listpol
                    df_050_059_MQ_I1_L ['Symmetry'] = listsym
                    df_050_059_MQ_I1_L ['Ratio'] = listrat
                    df_050_059_MQ_I1_L ['PPC'] = listdesc
                    df_050_059_MQ_I1_L ['Total'] = listtotal
                    df_050_059_MQ_I1_L['Carat'] = df_050_059_MQ_I1_L['Carat'].astype('float64')
                    df_050_059_MQ_I1_L['PPC'] = df_050_059_MQ_I1_L['PPC'].astype('float64')
                    df_050_059_MQ_I1_L['Total'] = df_050_059_MQ_I1_L['Total'].astype('float64')
                    df_050_059_MQ_I1_L['Total'] = df_050_059_MQ_I1_L['Carat'] * df_050_059_MQ_I1_L['PPC']


                elif i=="L" and j == "I2" and k == "MQ":
                    df_050_059_MQ_I2_L = pd.DataFrame()
                    df_050_059_MQ_I2_L ['Wt Range'] = None
                    df_050_059_MQ_I2_L  = df_050_059_MQ_I2_L.assign(Company=None)
                    df_050_059_MQ_I2_L  = df_050_059_MQ_I2_L.assign(Shape=None)
                    df_050_059_MQ_I2_L  = df_050_059_MQ_I2_L.assign(Carat=None)
                    df_050_059_MQ_I2_L  = df_050_059_MQ_I2_L.assign(Color=None)
                    df_050_059_MQ_I2_L  = df_050_059_MQ_I2_L.assign(Clarity=None)
                    df_050_059_MQ_I2_L  = df_050_059_MQ_I2_L.assign(Cut=None)
                    df_050_059_MQ_I2_L  = df_050_059_MQ_I2_L.assign(Polish=None)
                    df_050_059_MQ_I2_L  = df_050_059_MQ_I2_L.assign(Symmetry=None)
                    df_050_059_MQ_I2_L  = df_050_059_MQ_I2_L.assign(Ratio=None)
                    df_050_059_MQ_I2_L  = df_050_059_MQ_I2_L.assign(PPC=None)
                    df_050_059_MQ_I2_L  = df_050_059_MQ_I2_L.assign(Total=None)
                    df_050_059_MQ_I2_L ['Wt Range'] = listwtrange
                    df_050_059_MQ_I2_L ['Company'] = listcom
                    df_050_059_MQ_I2_L ['Shape'] = listshap
                    df_050_059_MQ_I2_L ['Carat'] = listcar
                    df_050_059_MQ_I2_L ['Color'] = listcol
                    df_050_059_MQ_I2_L ['Clarity'] = listclar
                    df_050_059_MQ_I2_L ['Cut'] = listcut
                    df_050_059_MQ_I2_L ['Polish'] = listpol
                    df_050_059_MQ_I2_L ['Symmetry'] = listsym
                    df_050_059_MQ_I2_L ['Ratio'] = listrat
                    df_050_059_MQ_I2_L ['PPC'] = listdesc
                    df_050_059_MQ_I2_L ['Total'] = listtotal
                    df_050_059_MQ_I2_L['Carat'] = df_050_059_MQ_I2_L['Carat'].astype('float64')
                    df_050_059_MQ_I2_L['PPC'] = df_050_059_MQ_I2_L['PPC'].astype('float64')
                    df_050_059_MQ_I2_L['Total'] = df_050_059_MQ_I2_L['Total'].astype('float64')
                    df_050_059_MQ_I2_L['Total'] = df_050_059_MQ_I2_L['Carat'] * df_050_059_MQ_I2_L['PPC']


                elif i=="D" and j == "IF" and k == "CUB":
                    df_050_059_CUB_IF_D = pd.DataFrame()
                    df_050_059_CUB_IF_D ['Wt Range'] = None
                    df_050_059_CUB_IF_D  = df_050_059_CUB_IF_D.assign(Company=None)
                    df_050_059_CUB_IF_D  = df_050_059_CUB_IF_D.assign(Shape=None)
                    df_050_059_CUB_IF_D  = df_050_059_CUB_IF_D.assign(Carat=None)
                    df_050_059_CUB_IF_D  = df_050_059_CUB_IF_D.assign(Color=None)
                    df_050_059_CUB_IF_D  = df_050_059_CUB_IF_D.assign(Clarity=None)
                    df_050_059_CUB_IF_D  = df_050_059_CUB_IF_D.assign(Cut=None)
                    df_050_059_CUB_IF_D  = df_050_059_CUB_IF_D.assign(Polish=None)
                    df_050_059_CUB_IF_D  = df_050_059_CUB_IF_D.assign(Symmetry=None)
                    df_050_059_CUB_IF_D  = df_050_059_CUB_IF_D.assign(Ratio=None)
                    df_050_059_CUB_IF_D  = df_050_059_CUB_IF_D.assign(PPC=None)
                    df_050_059_CUB_IF_D  = df_050_059_CUB_IF_D.assign(Total=None)
                    df_050_059_CUB_IF_D ['Wt Range'] = listwtrange
                    df_050_059_CUB_IF_D ['Company'] = listcom
                    df_050_059_CUB_IF_D ['Shape'] = listshap
                    df_050_059_CUB_IF_D ['Carat'] = listcar
                    df_050_059_CUB_IF_D ['Color'] = listcol
                    df_050_059_CUB_IF_D ['Clarity'] = listclar
                    df_050_059_CUB_IF_D ['Cut'] = listcut
                    df_050_059_CUB_IF_D ['Polish'] = listpol
                    df_050_059_CUB_IF_D ['Symmetry'] = listsym
                    df_050_059_CUB_IF_D ['Ratio'] = listrat
                    df_050_059_CUB_IF_D ['PPC'] = listdesc
                    df_050_059_CUB_IF_D ['Total'] = listtotal
                    df_050_059_CUB_IF_D['Carat'] = df_050_059_CUB_IF_D['Carat'].astype('float64')
                    df_050_059_CUB_IF_D['PPC'] = df_050_059_CUB_IF_D['PPC'].astype('float64')
                    df_050_059_CUB_IF_D['Total'] = df_050_059_CUB_IF_D['Total'].astype('float64')
                    df_050_059_CUB_IF_D['Total'] = df_050_059_CUB_IF_D['Carat'] * df_050_059_CUB_IF_D['PPC']



                elif i=="D" and j == "VVS1" and k == "CUB" :
                    df_050_059_CUB_VVS1_D = pd.DataFrame()
                    df_050_059_CUB_VVS1_D ['Wt Range'] = None
                    df_050_059_CUB_VVS1_D  = df_050_059_CUB_VVS1_D.assign(Company=None)
                    df_050_059_CUB_VVS1_D  = df_050_059_CUB_VVS1_D.assign(Shape=None)
                    df_050_059_CUB_VVS1_D  = df_050_059_CUB_VVS1_D.assign(Carat=None)
                    df_050_059_CUB_VVS1_D  = df_050_059_CUB_VVS1_D.assign(Color=None)
                    df_050_059_CUB_VVS1_D  = df_050_059_CUB_VVS1_D.assign(Clarity=None)
                    df_050_059_CUB_VVS1_D  = df_050_059_CUB_VVS1_D.assign(Cut=None)
                    df_050_059_CUB_VVS1_D  = df_050_059_CUB_VVS1_D.assign(Polish=None)
                    df_050_059_CUB_VVS1_D  = df_050_059_CUB_VVS1_D.assign(Symmetry=None)
                    df_050_059_CUB_VVS1_D  = df_050_059_CUB_VVS1_D.assign(Ratio=None)
                    df_050_059_CUB_VVS1_D  = df_050_059_CUB_VVS1_D.assign(PPC=None)
                    df_050_059_CUB_VVS1_D  = df_050_059_CUB_VVS1_D.assign(Total=None)
                    df_050_059_CUB_VVS1_D ['Wt Range'] = listwtrange
                    df_050_059_CUB_VVS1_D ['Company'] = listcom
                    df_050_059_CUB_VVS1_D ['Shape'] = listshap
                    df_050_059_CUB_VVS1_D ['Carat'] = listcar
                    df_050_059_CUB_VVS1_D ['Color'] = listcol
                    df_050_059_CUB_VVS1_D ['Clarity'] = listclar
                    df_050_059_CUB_VVS1_D ['Cut'] = listcut
                    df_050_059_CUB_VVS1_D ['Polish'] = listpol
                    df_050_059_CUB_VVS1_D ['Symmetry'] = listsym
                    df_050_059_CUB_VVS1_D ['Ratio'] = listrat
                    df_050_059_CUB_VVS1_D ['PPC'] = listdesc
                    df_050_059_CUB_VVS1_D ['Total'] = listtotal
                    df_050_059_CUB_VVS1_D['Carat'] = df_050_059_CUB_VVS1_D['Carat'].astype('float64')
                    df_050_059_CUB_VVS1_D['PPC'] = df_050_059_CUB_VVS1_D['PPC'].astype('float64')
                    df_050_059_CUB_VVS1_D['Total'] = df_050_059_CUB_VVS1_D['Total'].astype('float64')
                    df_050_059_CUB_VVS1_D['Total'] = df_050_059_CUB_VVS1_D['Carat'] * df_050_059_CUB_VVS1_D['PPC']



                elif i=="D" and j == "VVS2" and k == "CUB" :
                    df_050_059_CUB_VVS2_D = pd.DataFrame()
                    df_050_059_CUB_VVS2_D ['Wt Range'] = None
                    df_050_059_CUB_VVS2_D  = df_050_059_CUB_VVS2_D.assign(Company=None)
                    df_050_059_CUB_VVS2_D  = df_050_059_CUB_VVS2_D.assign(Shape=None)
                    df_050_059_CUB_VVS2_D  = df_050_059_CUB_VVS2_D.assign(Carat=None)
                    df_050_059_CUB_VVS2_D  = df_050_059_CUB_VVS2_D.assign(Color=None)
                    df_050_059_CUB_VVS2_D  = df_050_059_CUB_VVS2_D.assign(Clarity=None)
                    df_050_059_CUB_VVS2_D  = df_050_059_CUB_VVS2_D.assign(Cut=None)
                    df_050_059_CUB_VVS2_D  = df_050_059_CUB_VVS2_D.assign(Polish=None)
                    df_050_059_CUB_VVS2_D  = df_050_059_CUB_VVS2_D.assign(Symmetry=None)
                    df_050_059_CUB_VVS2_D  = df_050_059_CUB_VVS2_D.assign(Ratio=None)
                    df_050_059_CUB_VVS2_D  = df_050_059_CUB_VVS2_D.assign(PPC=None)
                    df_050_059_CUB_VVS2_D  = df_050_059_CUB_VVS2_D.assign(Total=None)
                    df_050_059_CUB_VVS2_D ['Wt Range'] = listwtrange
                    df_050_059_CUB_VVS2_D ['Company'] = listcom
                    df_050_059_CUB_VVS2_D ['Shape'] = listshap
                    df_050_059_CUB_VVS2_D ['Carat'] = listcar
                    df_050_059_CUB_VVS2_D ['Color'] = listcol
                    df_050_059_CUB_VVS2_D ['Clarity'] = listclar
                    df_050_059_CUB_VVS2_D ['Cut'] = listcut
                    df_050_059_CUB_VVS2_D ['Polish'] = listpol
                    df_050_059_CUB_VVS2_D ['Symmetry'] = listsym
                    df_050_059_CUB_VVS2_D ['Ratio'] = listrat
                    df_050_059_CUB_VVS2_D ['PPC'] = listdesc
                    df_050_059_CUB_VVS2_D ['Total'] = listtotal
                    df_050_059_CUB_VVS2_D['Carat'] = df_050_059_CUB_VVS2_D['Carat'].astype('float64')
                    df_050_059_CUB_VVS2_D['PPC'] = df_050_059_CUB_VVS2_D['PPC'].astype('float64')
                    df_050_059_CUB_VVS2_D['Total'] = df_050_059_CUB_VVS2_D['Total'].astype('float64')
                    df_050_059_CUB_VVS2_D['Total'] = df_050_059_CUB_VVS2_D['Carat'] * df_050_059_CUB_VVS2_D['PPC']



                elif i=="D" and j == "VS1" and k == "CUB":
                    df_050_059_CUB_VS1_D = pd.DataFrame()
                    df_050_059_CUB_VS1_D ['Wt Range'] = None
                    df_050_059_CUB_VS1_D  = df_050_059_CUB_VS1_D.assign(Company=None)
                    df_050_059_CUB_VS1_D  = df_050_059_CUB_VS1_D.assign(Shape=None)
                    df_050_059_CUB_VS1_D  = df_050_059_CUB_VS1_D.assign(Carat=None)
                    df_050_059_CUB_VS1_D  = df_050_059_CUB_VS1_D.assign(Color=None)
                    df_050_059_CUB_VS1_D  = df_050_059_CUB_VS1_D.assign(Clarity=None)
                    df_050_059_CUB_VS1_D  = df_050_059_CUB_VS1_D.assign(Cut=None)
                    df_050_059_CUB_VS1_D  = df_050_059_CUB_VS1_D.assign(Polish=None)
                    df_050_059_CUB_VS1_D  = df_050_059_CUB_VS1_D.assign(Symmetry=None)
                    df_050_059_CUB_VS1_D  = df_050_059_CUB_VS1_D.assign(Ratio=None)
                    df_050_059_CUB_VS1_D  = df_050_059_CUB_VS1_D.assign(PPC=None)
                    df_050_059_CUB_VS1_D  = df_050_059_CUB_VS1_D.assign(Total=None)
                    df_050_059_CUB_VS1_D ['Wt Range'] = listwtrange
                    df_050_059_CUB_VS1_D ['Company'] = listcom
                    df_050_059_CUB_VS1_D ['Shape'] = listshap
                    df_050_059_CUB_VS1_D ['Carat'] = listcar
                    df_050_059_CUB_VS1_D ['Color'] = listcol
                    df_050_059_CUB_VS1_D ['Clarity'] = listclar
                    df_050_059_CUB_VS1_D ['Cut'] = listcut
                    df_050_059_CUB_VS1_D ['Polish'] = listpol
                    df_050_059_CUB_VS1_D ['Symmetry'] = listsym
                    df_050_059_CUB_VS1_D ['Ratio'] = listrat
                    df_050_059_CUB_VS1_D ['PPC'] = listdesc
                    df_050_059_CUB_VS1_D ['Total'] = listtotal
                    df_050_059_CUB_VS1_D['Carat'] = df_050_059_CUB_VS1_D['Carat'].astype('float64')
                    df_050_059_CUB_VS1_D['PPC'] = df_050_059_CUB_VS1_D['PPC'].astype('float64')
                    df_050_059_CUB_VS1_D['Total'] = df_050_059_CUB_VS1_D['Total'].astype('float64')
                    df_050_059_CUB_VS1_D['Total'] = df_050_059_CUB_VS1_D['Carat'] * df_050_059_CUB_VS1_D['PPC']


                elif i=="D" and j == "VS2" and k == "CUB":
                    df_050_059_CUB_VS2_D = pd.DataFrame()
                    df_050_059_CUB_VS2_D ['Wt Range'] = None
                    df_050_059_CUB_VS2_D  = df_050_059_CUB_VS2_D.assign(Company=None)
                    df_050_059_CUB_VS2_D  = df_050_059_CUB_VS2_D.assign(Shape=None)
                    df_050_059_CUB_VS2_D  = df_050_059_CUB_VS2_D.assign(Carat=None)
                    df_050_059_CUB_VS2_D  = df_050_059_CUB_VS2_D.assign(Color=None)
                    df_050_059_CUB_VS2_D  = df_050_059_CUB_VS2_D.assign(Clarity=None)
                    df_050_059_CUB_VS2_D  = df_050_059_CUB_VS2_D.assign(Cut=None)
                    df_050_059_CUB_VS2_D  = df_050_059_CUB_VS2_D.assign(Polish=None)
                    df_050_059_CUB_VS2_D  = df_050_059_CUB_VS2_D.assign(Symmetry=None)
                    df_050_059_CUB_VS2_D  = df_050_059_CUB_VS2_D.assign(Ratio=None)
                    df_050_059_CUB_VS2_D  = df_050_059_CUB_VS2_D.assign(PPC=None)
                    df_050_059_CUB_VS2_D  = df_050_059_CUB_VS2_D.assign(Total=None)
                    df_050_059_CUB_VS2_D ['Wt Range'] = listwtrange
                    df_050_059_CUB_VS2_D ['Company'] = listcom
                    df_050_059_CUB_VS2_D ['Shape'] = listshap
                    df_050_059_CUB_VS2_D ['Carat'] = listcar
                    df_050_059_CUB_VS2_D ['Color'] = listcol
                    df_050_059_CUB_VS2_D ['Clarity'] = listclar
                    df_050_059_CUB_VS2_D ['Cut'] = listcut
                    df_050_059_CUB_VS2_D ['Polish'] = listpol
                    df_050_059_CUB_VS2_D ['Symmetry'] = listsym
                    df_050_059_CUB_VS2_D ['Ratio'] = listrat
                    df_050_059_CUB_VS2_D ['PPC'] = listdesc
                    df_050_059_CUB_VS2_D ['Total'] = listtotal
                    df_050_059_CUB_VS2_D['Carat'] = df_050_059_CUB_VS2_D['Carat'].astype('float64')
                    df_050_059_CUB_VS2_D['PPC'] = df_050_059_CUB_VS2_D['PPC'].astype('float64')
                    df_050_059_CUB_VS2_D['Total'] = df_050_059_CUB_VS2_D['Total'].astype('float64')
                    df_050_059_CUB_VS2_D['Total'] = df_050_059_CUB_VS2_D['Carat'] * df_050_059_CUB_VS2_D['PPC']


                elif i=="D" and j == "SI1" and k == "CUB":
                    df_050_059_CUB_SI1_D = pd.DataFrame()
                    df_050_059_CUB_SI1_D ['Wt Range'] = None
                    df_050_059_CUB_SI1_D  = df_050_059_CUB_SI1_D.assign(Company=None)
                    df_050_059_CUB_SI1_D  = df_050_059_CUB_SI1_D.assign(Shape=None)
                    df_050_059_CUB_SI1_D  = df_050_059_CUB_SI1_D.assign(Carat=None)
                    df_050_059_CUB_SI1_D  = df_050_059_CUB_SI1_D.assign(Color=None)
                    df_050_059_CUB_SI1_D  = df_050_059_CUB_SI1_D.assign(Clarity=None)
                    df_050_059_CUB_SI1_D  = df_050_059_CUB_SI1_D.assign(Cut=None)
                    df_050_059_CUB_SI1_D  = df_050_059_CUB_SI1_D.assign(Polish=None)
                    df_050_059_CUB_SI1_D  = df_050_059_CUB_SI1_D.assign(Symmetry=None)
                    df_050_059_CUB_SI1_D  = df_050_059_CUB_SI1_D.assign(Ratio=None)
                    df_050_059_CUB_SI1_D  = df_050_059_CUB_SI1_D.assign(PPC=None)
                    df_050_059_CUB_SI1_D  = df_050_059_CUB_SI1_D.assign(Total=None)
                    df_050_059_CUB_SI1_D ['Wt Range'] = listwtrange
                    df_050_059_CUB_SI1_D ['Company'] = listcom
                    df_050_059_CUB_SI1_D ['Shape'] = listshap
                    df_050_059_CUB_SI1_D ['Carat'] = listcar
                    df_050_059_CUB_SI1_D ['Color'] = listcol
                    df_050_059_CUB_SI1_D ['Clarity'] = listclar
                    df_050_059_CUB_SI1_D ['Cut'] = listcut
                    df_050_059_CUB_SI1_D ['Polish'] = listpol
                    df_050_059_CUB_SI1_D ['Symmetry'] = listsym
                    df_050_059_CUB_SI1_D ['Ratio'] = listrat
                    df_050_059_CUB_SI1_D ['PPC'] = listdesc
                    df_050_059_CUB_SI1_D ['Total'] = listtotal
                    df_050_059_CUB_SI1_D['Carat'] = df_050_059_CUB_SI1_D['Carat'].astype('float64')
                    df_050_059_CUB_SI1_D['PPC'] = df_050_059_CUB_SI1_D['PPC'].astype('float64')
                    df_050_059_CUB_SI1_D['Total'] = df_050_059_CUB_SI1_D['Total'].astype('float64')
                    df_050_059_CUB_SI1_D['Total'] = df_050_059_CUB_SI1_D['Carat'] * df_050_059_CUB_SI1_D['PPC']


                elif i=="D" and j == "SI2" and k == "CUB":
                    df_050_059_CUB_SI2_D = pd.DataFrame()
                    df_050_059_CUB_SI2_D ['Wt Range'] = None
                    df_050_059_CUB_SI2_D  = df_050_059_CUB_SI2_D.assign(Company=None)
                    df_050_059_CUB_SI2_D  = df_050_059_CUB_SI2_D.assign(Shape=None)
                    df_050_059_CUB_SI2_D  = df_050_059_CUB_SI2_D.assign(Carat=None)
                    df_050_059_CUB_SI2_D  = df_050_059_CUB_SI2_D.assign(Color=None)
                    df_050_059_CUB_SI2_D  = df_050_059_CUB_SI2_D.assign(Clarity=None)
                    df_050_059_CUB_SI2_D  = df_050_059_CUB_SI2_D.assign(Cut=None)
                    df_050_059_CUB_SI2_D  = df_050_059_CUB_SI2_D.assign(Polish=None)
                    df_050_059_CUB_SI2_D  = df_050_059_CUB_SI2_D.assign(Symmetry=None)
                    df_050_059_CUB_SI2_D  = df_050_059_CUB_SI2_D.assign(Ratio=None)
                    df_050_059_CUB_SI2_D  = df_050_059_CUB_SI2_D.assign(PPC=None)
                    df_050_059_CUB_SI2_D  = df_050_059_CUB_SI2_D.assign(Total=None)
                    df_050_059_CUB_SI2_D ['Wt Range'] = listwtrange
                    df_050_059_CUB_SI2_D ['Company'] = listcom
                    df_050_059_CUB_SI2_D ['Shape'] = listshap
                    df_050_059_CUB_SI2_D ['Carat'] = listcar
                    df_050_059_CUB_SI2_D ['Color'] = listcol
                    df_050_059_CUB_SI2_D ['Clarity'] = listclar
                    df_050_059_CUB_SI2_D ['Cut'] = listcut
                    df_050_059_CUB_SI2_D ['Polish'] = listpol
                    df_050_059_CUB_SI2_D ['Symmetry'] = listsym
                    df_050_059_CUB_SI2_D ['Ratio'] = listrat
                    df_050_059_CUB_SI2_D ['PPC'] = listdesc
                    df_050_059_CUB_SI2_D ['Total'] = listtotal
                    df_050_059_CUB_SI2_D['Carat'] = df_050_059_CUB_SI2_D['Carat'].astype('float64')
                    df_050_059_CUB_SI2_D['PPC'] = df_050_059_CUB_SI2_D['PPC'].astype('float64')
                    df_050_059_CUB_SI2_D['Total'] = df_050_059_CUB_SI2_D['Total'].astype('float64')
                    df_050_059_CUB_SI2_D['Total'] = df_050_059_CUB_SI2_D['Carat'] * df_050_059_CUB_SI2_D['PPC']


                elif i=="D" and j == "I1" and k == "CUB":
                    df_050_059_CUB_I1_D = pd.DataFrame()
                    df_050_059_CUB_I1_D ['Wt Range'] = None
                    df_050_059_CUB_I1_D  = df_050_059_CUB_I1_D.assign(Company=None)
                    df_050_059_CUB_I1_D  = df_050_059_CUB_I1_D.assign(Shape=None)
                    df_050_059_CUB_I1_D  = df_050_059_CUB_I1_D.assign(Carat=None)
                    df_050_059_CUB_I1_D  = df_050_059_CUB_I1_D.assign(Color=None)
                    df_050_059_CUB_I1_D  = df_050_059_CUB_I1_D.assign(Clarity=None)
                    df_050_059_CUB_I1_D  = df_050_059_CUB_I1_D.assign(Cut=None)
                    df_050_059_CUB_I1_D  = df_050_059_CUB_I1_D.assign(Polish=None)
                    df_050_059_CUB_I1_D  = df_050_059_CUB_I1_D.assign(Symmetry=None)
                    df_050_059_CUB_I1_D  = df_050_059_CUB_I1_D.assign(Ratio=None)
                    df_050_059_CUB_I1_D  = df_050_059_CUB_I1_D.assign(PPC=None)
                    df_050_059_CUB_I1_D  = df_050_059_CUB_I1_D.assign(Total=None)
                    df_050_059_CUB_I1_D ['Wt Range'] = listwtrange
                    df_050_059_CUB_I1_D ['Company'] = listcom
                    df_050_059_CUB_I1_D ['Shape'] = listshap
                    df_050_059_CUB_I1_D ['Carat'] = listcar
                    df_050_059_CUB_I1_D ['Color'] = listcol
                    df_050_059_CUB_I1_D ['Clarity'] = listclar
                    df_050_059_CUB_I1_D ['Cut'] = listcut
                    df_050_059_CUB_I1_D ['Polish'] = listpol
                    df_050_059_CUB_I1_D ['Symmetry'] = listsym
                    df_050_059_CUB_I1_D ['Ratio'] = listrat
                    df_050_059_CUB_I1_D ['PPC'] = listdesc
                    df_050_059_CUB_I1_D ['Total'] = listtotal
                    df_050_059_CUB_I1_D['Carat'] = df_050_059_CUB_I1_D['Carat'].astype('float64')
                    df_050_059_CUB_I1_D['PPC'] = df_050_059_CUB_I1_D['PPC'].astype('float64')
                    df_050_059_CUB_I1_D['Total'] = df_050_059_CUB_I1_D['Total'].astype('float64')
                    df_050_059_CUB_I1_D['Total'] = df_050_059_CUB_I1_D['Carat'] * df_050_059_CUB_I1_D['PPC']


                elif i=="D" and j == "I2" and k == "CUB":
                    df_050_059_CUB_I2_D = pd.DataFrame()
                    df_050_059_CUB_I2_D ['Wt Range'] = None
                    df_050_059_CUB_I2_D  = df_050_059_CUB_I2_D.assign(Company=None)
                    df_050_059_CUB_I2_D  = df_050_059_CUB_I2_D.assign(Shape=None)
                    df_050_059_CUB_I2_D  = df_050_059_CUB_I2_D.assign(Carat=None)
                    df_050_059_CUB_I2_D  = df_050_059_CUB_I2_D.assign(Color=None)
                    df_050_059_CUB_I2_D  = df_050_059_CUB_I2_D.assign(Clarity=None)
                    df_050_059_CUB_I2_D  = df_050_059_CUB_I2_D.assign(Cut=None)
                    df_050_059_CUB_I2_D  = df_050_059_CUB_I2_D.assign(Polish=None)
                    df_050_059_CUB_I2_D  = df_050_059_CUB_I2_D.assign(Symmetry=None)
                    df_050_059_CUB_I2_D  = df_050_059_CUB_I2_D.assign(Ratio=None)
                    df_050_059_CUB_I2_D  = df_050_059_CUB_I2_D.assign(PPC=None)
                    df_050_059_CUB_I2_D  = df_050_059_CUB_I2_D.assign(Total=None)
                    df_050_059_CUB_I2_D ['Wt Range'] = listwtrange
                    df_050_059_CUB_I2_D ['Company'] = listcom
                    df_050_059_CUB_I2_D ['Shape'] = listshap
                    df_050_059_CUB_I2_D ['Carat'] = listcar
                    df_050_059_CUB_I2_D ['Color'] = listcol
                    df_050_059_CUB_I2_D ['Clarity'] = listclar
                    df_050_059_CUB_I2_D ['Cut'] = listcut
                    df_050_059_CUB_I2_D ['Polish'] = listpol
                    df_050_059_CUB_I2_D ['Symmetry'] = listsym
                    df_050_059_CUB_I2_D ['Ratio'] = listrat
                    df_050_059_CUB_I2_D ['PPC'] = listdesc
                    df_050_059_CUB_I2_D ['Total'] = listtotal
                    df_050_059_CUB_I2_D['Carat'] = df_050_059_CUB_I2_D['Carat'].astype('float64')
                    df_050_059_CUB_I2_D['PPC'] = df_050_059_CUB_I2_D['PPC'].astype('float64')
                    df_050_059_CUB_I2_D['Total'] = df_050_059_CUB_I2_D['Total'].astype('float64')
                    df_050_059_CUB_I2_D['Total'] = df_050_059_CUB_I2_D['Carat'] * df_050_059_CUB_I2_D['PPC']



                elif i=="E" and j == "IF" and k == "CUB":
                    df_050_059_CUB_IF_E = pd.DataFrame()
                    df_050_059_CUB_IF_E ['Wt Range'] = None
                    df_050_059_CUB_IF_E  = df_050_059_CUB_IF_E.assign(Company=None)
                    df_050_059_CUB_IF_E  = df_050_059_CUB_IF_E.assign(Shape=None)
                    df_050_059_CUB_IF_E  = df_050_059_CUB_IF_E.assign(Carat=None)
                    df_050_059_CUB_IF_E  = df_050_059_CUB_IF_E.assign(Color=None)
                    df_050_059_CUB_IF_E  = df_050_059_CUB_IF_E.assign(Clarity=None)
                    df_050_059_CUB_IF_E  = df_050_059_CUB_IF_E.assign(Cut=None)
                    df_050_059_CUB_IF_E  = df_050_059_CUB_IF_E.assign(Polish=None)
                    df_050_059_CUB_IF_E  = df_050_059_CUB_IF_E.assign(Symmetry=None)
                    df_050_059_CUB_IF_E  = df_050_059_CUB_IF_E.assign(Ratio=None)
                    df_050_059_CUB_IF_E  = df_050_059_CUB_IF_E.assign(PPC=None)
                    df_050_059_CUB_IF_E  = df_050_059_CUB_IF_E.assign(Total=None)
                    df_050_059_CUB_IF_E ['Wt Range'] = listwtrange
                    df_050_059_CUB_IF_E ['Company'] = listcom
                    df_050_059_CUB_IF_E ['Shape'] = listshap
                    df_050_059_CUB_IF_E ['Carat'] = listcar
                    df_050_059_CUB_IF_E ['Color'] = listcol
                    df_050_059_CUB_IF_E ['Clarity'] = listclar
                    df_050_059_CUB_IF_E ['Cut'] = listcut
                    df_050_059_CUB_IF_E ['Polish'] = listpol
                    df_050_059_CUB_IF_E ['Symmetry'] = listsym
                    df_050_059_CUB_IF_E ['Ratio'] = listrat
                    df_050_059_CUB_IF_E ['PPC'] = listdesc
                    df_050_059_CUB_IF_E ['Total'] = listtotal
                    df_050_059_CUB_IF_E['Carat'] = df_050_059_CUB_IF_E['Carat'].astype('float64')
                    df_050_059_CUB_IF_E['PPC'] = df_050_059_CUB_IF_E['PPC'].astype('float64')
                    df_050_059_CUB_IF_E['Total'] = df_050_059_CUB_IF_E['Total'].astype('float64')
                    df_050_059_CUB_IF_E['Total'] = df_050_059_CUB_IF_E['Carat'] * df_050_059_CUB_IF_E['PPC']



                elif i=="E" and j == "VVS1" and k == "CUB":
                    df_050_059_CUB_VVS1_E = pd.DataFrame()
                    df_050_059_CUB_VVS1_E ['Wt Range'] = None
                    df_050_059_CUB_VVS1_E  = df_050_059_CUB_VVS1_E.assign(Company=None)
                    df_050_059_CUB_VVS1_E  = df_050_059_CUB_VVS1_E.assign(Shape=None)
                    df_050_059_CUB_VVS1_E  = df_050_059_CUB_VVS1_E.assign(Carat=None)
                    df_050_059_CUB_VVS1_E  = df_050_059_CUB_VVS1_E.assign(Color=None)
                    df_050_059_CUB_VVS1_E  = df_050_059_CUB_VVS1_E.assign(Clarity=None)
                    df_050_059_CUB_VVS1_E  = df_050_059_CUB_VVS1_E.assign(Cut=None)
                    df_050_059_CUB_VVS1_E  = df_050_059_CUB_VVS1_E.assign(Polish=None)
                    df_050_059_CUB_VVS1_E  = df_050_059_CUB_VVS1_E.assign(Symmetry=None)
                    df_050_059_CUB_VVS1_E  = df_050_059_CUB_VVS1_E.assign(Ratio=None)
                    df_050_059_CUB_VVS1_E  = df_050_059_CUB_VVS1_E.assign(PPC=None)
                    df_050_059_CUB_VVS1_E  = df_050_059_CUB_VVS1_E.assign(Total=None)
                    df_050_059_CUB_VVS1_E ['Wt Range'] = listwtrange
                    df_050_059_CUB_VVS1_E ['Company'] = listcom
                    df_050_059_CUB_VVS1_E ['Shape'] = listshap
                    df_050_059_CUB_VVS1_E ['Carat'] = listcar
                    df_050_059_CUB_VVS1_E ['Color'] = listcol
                    df_050_059_CUB_VVS1_E ['Clarity'] = listclar
                    df_050_059_CUB_VVS1_E ['Cut'] = listcut
                    df_050_059_CUB_VVS1_E ['Polish'] = listpol
                    df_050_059_CUB_VVS1_E ['Symmetry'] = listsym
                    df_050_059_CUB_VVS1_E ['Ratio'] = listrat
                    df_050_059_CUB_VVS1_E ['PPC'] = listdesc
                    df_050_059_CUB_VVS1_E ['Total'] = listtotal
                    df_050_059_CUB_VVS1_E['Carat'] = df_050_059_CUB_VVS1_E['Carat'].astype('float64')
                    df_050_059_CUB_VVS1_E['PPC'] = df_050_059_CUB_VVS1_E['PPC'].astype('float64')
                    df_050_059_CUB_VVS1_E['Total'] = df_050_059_CUB_VVS1_E['Total'].astype('float64')
                    df_050_059_CUB_VVS1_E['Total'] = df_050_059_CUB_VVS1_E['Carat'] * df_050_059_CUB_VVS1_E['PPC']


                elif i=="E" and j == "VVS2" and k == "CUB":
                    df_050_059_CUB_VVS2_E = pd.DataFrame()
                    df_050_059_CUB_VVS2_E ['Wt Range'] = None
                    df_050_059_CUB_VVS2_E  = df_050_059_CUB_VVS2_E.assign(Company=None)
                    df_050_059_CUB_VVS2_E  = df_050_059_CUB_VVS2_E.assign(Shape=None)
                    df_050_059_CUB_VVS2_E  = df_050_059_CUB_VVS2_E.assign(Carat=None)
                    df_050_059_CUB_VVS2_E  = df_050_059_CUB_VVS2_E.assign(Color=None)
                    df_050_059_CUB_VVS2_E  = df_050_059_CUB_VVS2_E.assign(Clarity=None)
                    df_050_059_CUB_VVS2_E  = df_050_059_CUB_VVS2_E.assign(Cut=None)
                    df_050_059_CUB_VVS2_E  = df_050_059_CUB_VVS2_E.assign(Polish=None)
                    df_050_059_CUB_VVS2_E  = df_050_059_CUB_VVS2_E.assign(Symmetry=None)
                    df_050_059_CUB_VVS2_E  = df_050_059_CUB_VVS2_E.assign(Ratio=None)
                    df_050_059_CUB_VVS2_E  = df_050_059_CUB_VVS2_E.assign(PPC=None)
                    df_050_059_CUB_VVS2_E  = df_050_059_CUB_VVS2_E.assign(Total=None)
                    df_050_059_CUB_VVS2_E ['Wt Range'] = listwtrange
                    df_050_059_CUB_VVS2_E ['Company'] = listcom
                    df_050_059_CUB_VVS2_E ['Shape'] = listshap
                    df_050_059_CUB_VVS2_E ['Carat'] = listcar
                    df_050_059_CUB_VVS2_E ['Color'] = listcol
                    df_050_059_CUB_VVS2_E ['Clarity'] = listclar
                    df_050_059_CUB_VVS2_E ['Cut'] = listcut
                    df_050_059_CUB_VVS2_E ['Polish'] = listpol
                    df_050_059_CUB_VVS2_E ['Symmetry'] = listsym
                    df_050_059_CUB_VVS2_E ['Ratio'] = listrat
                    df_050_059_CUB_VVS2_E ['PPC'] = listdesc
                    df_050_059_CUB_VVS2_E ['Total'] = listtotal
                    df_050_059_CUB_VVS2_E['Carat'] = df_050_059_CUB_VVS2_E['Carat'].astype('float64')
                    df_050_059_CUB_VVS2_E['PPC'] = df_050_059_CUB_VVS2_E['PPC'].astype('float64')
                    df_050_059_CUB_VVS2_E['Total'] = df_050_059_CUB_VVS2_E['Total'].astype('float64')
                    df_050_059_CUB_VVS2_E['Total'] = df_050_059_CUB_VVS2_E['Carat'] * df_050_059_CUB_VVS2_E['PPC']


                elif i=="E" and j=="VS1" and k == "CUB":
                    df_050_059_CUB_VS1_E = pd.DataFrame()
                    df_050_059_CUB_VS1_E ['Wt Range'] = None
                    df_050_059_CUB_VS1_E  = df_050_059_CUB_VS1_E.assign(Company=None)
                    df_050_059_CUB_VS1_E  = df_050_059_CUB_VS1_E.assign(Shape=None)
                    df_050_059_CUB_VS1_E  = df_050_059_CUB_VS1_E.assign(Carat=None)
                    df_050_059_CUB_VS1_E  = df_050_059_CUB_VS1_E.assign(Color=None)
                    df_050_059_CUB_VS1_E  = df_050_059_CUB_VS1_E.assign(Clarity=None)
                    df_050_059_CUB_VS1_E  = df_050_059_CUB_VS1_E.assign(Cut=None)
                    df_050_059_CUB_VS1_E  = df_050_059_CUB_VS1_E.assign(Polish=None)
                    df_050_059_CUB_VS1_E  = df_050_059_CUB_VS1_E.assign(Symmetry=None)
                    df_050_059_CUB_VS1_E  = df_050_059_CUB_VS1_E.assign(Ratio=None)
                    df_050_059_CUB_VS1_E  = df_050_059_CUB_VS1_E.assign(PPC=None)
                    df_050_059_CUB_VS1_E  = df_050_059_CUB_VS1_E.assign(Total=None)
                    df_050_059_CUB_VS1_E ['Wt Range'] = listwtrange
                    df_050_059_CUB_VS1_E ['Company'] = listcom
                    df_050_059_CUB_VS1_E ['Shape'] = listshap
                    df_050_059_CUB_VS1_E ['Carat'] = listcar
                    df_050_059_CUB_VS1_E ['Color'] = listcol
                    df_050_059_CUB_VS1_E ['Clarity'] = listclar
                    df_050_059_CUB_VS1_E ['Cut'] = listcut
                    df_050_059_CUB_VS1_E ['Polish'] = listpol
                    df_050_059_CUB_VS1_E ['Symmetry'] = listsym
                    df_050_059_CUB_VS1_E ['Ratio'] = listrat
                    df_050_059_CUB_VS1_E ['PPC'] = listdesc
                    df_050_059_CUB_VS1_E ['Total'] = listtotal
                    df_050_059_CUB_VS1_E['Carat'] = df_050_059_CUB_VS1_E['Carat'].astype('float64')
                    df_050_059_CUB_VS1_E['PPC'] = df_050_059_CUB_VS1_E['PPC'].astype('float64')
                    df_050_059_CUB_VS1_E['Total'] = df_050_059_CUB_VS1_E['Total'].astype('float64')
                    df_050_059_CUB_VS1_E['Total'] = df_050_059_CUB_VS1_E['Carat'] * df_050_059_CUB_VS1_E['PPC']


                elif i=="E" and j == "VS2" and k == "CUB":
                    df_050_059_CUB_VS2_E = pd.DataFrame()
                    df_050_059_CUB_VS2_E ['Wt Range'] = None
                    df_050_059_CUB_VS2_E  = df_050_059_CUB_VS2_E.assign(Company=None)
                    df_050_059_CUB_VS2_E  = df_050_059_CUB_VS2_E.assign(Shape=None)
                    df_050_059_CUB_VS2_E  = df_050_059_CUB_VS2_E.assign(Carat=None)
                    df_050_059_CUB_VS2_E  = df_050_059_CUB_VS2_E.assign(Color=None)
                    df_050_059_CUB_VS2_E  = df_050_059_CUB_VS2_E.assign(Clarity=None)
                    df_050_059_CUB_VS2_E  = df_050_059_CUB_VS2_E.assign(Cut=None)
                    df_050_059_CUB_VS2_E  = df_050_059_CUB_VS2_E.assign(Polish=None)
                    df_050_059_CUB_VS2_E  = df_050_059_CUB_VS2_E.assign(Symmetry=None)
                    df_050_059_CUB_VS2_E  = df_050_059_CUB_VS2_E.assign(Ratio=None)
                    df_050_059_CUB_VS2_E  = df_050_059_CUB_VS2_E.assign(PPC=None)
                    df_050_059_CUB_VS2_E  = df_050_059_CUB_VS2_E.assign(Total=None)
                    df_050_059_CUB_VS2_E ['Wt Range'] = listwtrange
                    df_050_059_CUB_VS2_E ['Company'] = listcom
                    df_050_059_CUB_VS2_E ['Shape'] = listshap
                    df_050_059_CUB_VS2_E ['Carat'] = listcar
                    df_050_059_CUB_VS2_E ['Color'] = listcol
                    df_050_059_CUB_VS2_E ['Clarity'] = listclar
                    df_050_059_CUB_VS2_E ['Cut'] = listcut
                    df_050_059_CUB_VS2_E ['Polish'] = listpol
                    df_050_059_CUB_VS2_E ['Symmetry'] = listsym
                    df_050_059_CUB_VS2_E ['Ratio'] = listrat
                    df_050_059_CUB_VS2_E ['PPC'] = listdesc
                    df_050_059_CUB_VS2_E ['Total'] = listtotal
                    df_050_059_CUB_VS2_E['Carat'] = df_050_059_CUB_VS2_E['Carat'].astype('float64')
                    df_050_059_CUB_VS2_E['PPC'] = df_050_059_CUB_VS2_E['PPC'].astype('float64')
                    df_050_059_CUB_VS2_E['Total'] = df_050_059_CUB_VS2_E['Total'].astype('float64')
                    df_050_059_CUB_VS2_E['Total'] = df_050_059_CUB_VS2_E['Carat'] * df_050_059_CUB_VS2_E['PPC']


                elif i=="E" and j == "SI1" and k == "CUB":
                    df_050_059_CUB_SI1_E = pd.DataFrame()
                    df_050_059_CUB_SI1_E ['Wt Range'] = None
                    df_050_059_CUB_SI1_E  = df_050_059_CUB_SI1_E.assign(Company=None)
                    df_050_059_CUB_SI1_E  = df_050_059_CUB_SI1_E.assign(Shape=None)
                    df_050_059_CUB_SI1_E  = df_050_059_CUB_SI1_E.assign(Carat=None)
                    df_050_059_CUB_SI1_E  = df_050_059_CUB_SI1_E.assign(Color=None)
                    df_050_059_CUB_SI1_E  = df_050_059_CUB_SI1_E.assign(Clarity=None)
                    df_050_059_CUB_SI1_E  = df_050_059_CUB_SI1_E.assign(Cut=None)
                    df_050_059_CUB_SI1_E  = df_050_059_CUB_SI1_E.assign(Polish=None)
                    df_050_059_CUB_SI1_E  = df_050_059_CUB_SI1_E.assign(Symmetry=None)
                    df_050_059_CUB_SI1_E  = df_050_059_CUB_SI1_E.assign(Ratio=None)
                    df_050_059_CUB_SI1_E  = df_050_059_CUB_SI1_E.assign(PPC=None)
                    df_050_059_CUB_SI1_E  = df_050_059_CUB_SI1_E.assign(Total=None)
                    df_050_059_CUB_SI1_E ['Wt Range'] = listwtrange
                    df_050_059_CUB_SI1_E ['Company'] = listcom
                    df_050_059_CUB_SI1_E ['Shape'] = listshap
                    df_050_059_CUB_SI1_E ['Carat'] = listcar
                    df_050_059_CUB_SI1_E ['Color'] = listcol
                    df_050_059_CUB_SI1_E ['Clarity'] = listclar
                    df_050_059_CUB_SI1_E ['Cut'] = listcut
                    df_050_059_CUB_SI1_E ['Polish'] = listpol
                    df_050_059_CUB_SI1_E ['Symmetry'] = listsym
                    df_050_059_CUB_SI1_E ['Ratio'] = listrat
                    df_050_059_CUB_SI1_E ['PPC'] = listdesc
                    df_050_059_CUB_SI1_E ['Total'] = listtotal
                    df_050_059_CUB_SI1_E['Carat'] = df_050_059_CUB_SI1_E['Carat'].astype('float64')
                    df_050_059_CUB_SI1_E['PPC'] = df_050_059_CUB_SI1_E['PPC'].astype('float64')
                    df_050_059_CUB_SI1_E['Total'] = df_050_059_CUB_SI1_E['Total'].astype('float64')
                    df_050_059_CUB_SI1_E['Total'] = df_050_059_CUB_SI1_E['Carat'] * df_050_059_CUB_SI1_E['PPC']


                elif i=="E" and j == "SI2" and k == "CUB":
                    df_050_059_CUB_SI2_E = pd.DataFrame()
                    df_050_059_CUB_SI2_E ['Wt Range'] = None
                    df_050_059_CUB_SI2_E  = df_050_059_CUB_SI2_E.assign(Company=None)
                    df_050_059_CUB_SI2_E  = df_050_059_CUB_SI2_E.assign(Shape=None)
                    df_050_059_CUB_SI2_E  = df_050_059_CUB_SI2_E.assign(Carat=None)
                    df_050_059_CUB_SI2_E  = df_050_059_CUB_SI2_E.assign(Color=None)
                    df_050_059_CUB_SI2_E  = df_050_059_CUB_SI2_E.assign(Clarity=None)
                    df_050_059_CUB_SI2_E  = df_050_059_CUB_SI2_E.assign(Cut=None)
                    df_050_059_CUB_SI2_E  = df_050_059_CUB_SI2_E.assign(Polish=None)
                    df_050_059_CUB_SI2_E  = df_050_059_CUB_SI2_E.assign(Symmetry=None)
                    df_050_059_CUB_SI2_E  = df_050_059_CUB_SI2_E.assign(Ratio=None)
                    df_050_059_CUB_SI2_E  = df_050_059_CUB_SI2_E.assign(PPC=None)
                    df_050_059_CUB_SI2_E  = df_050_059_CUB_SI2_E.assign(Total=None)
                    df_050_059_CUB_SI2_E ['Wt Range'] = listwtrange
                    df_050_059_CUB_SI2_E ['Company'] = listcom
                    df_050_059_CUB_SI2_E ['Shape'] = listshap
                    df_050_059_CUB_SI2_E ['Carat'] = listcar
                    df_050_059_CUB_SI2_E ['Color'] = listcol
                    df_050_059_CUB_SI2_E ['Clarity'] = listclar
                    df_050_059_CUB_SI2_E ['Cut'] = listcut
                    df_050_059_CUB_SI2_E ['Polish'] = listpol
                    df_050_059_CUB_SI2_E ['Symmetry'] = listsym
                    df_050_059_CUB_SI2_E ['Ratio'] = listrat
                    df_050_059_CUB_SI2_E ['PPC'] = listdesc
                    df_050_059_CUB_SI2_E ['Total'] = listtotal
                    df_050_059_CUB_SI2_E['Carat'] = df_050_059_CUB_SI2_E['Carat'].astype('float64')
                    df_050_059_CUB_SI2_E['PPC'] = df_050_059_CUB_SI2_E['PPC'].astype('float64')
                    df_050_059_CUB_SI2_E['Total'] = df_050_059_CUB_SI2_E['Total'].astype('float64')
                    df_050_059_CUB_SI2_E['Total'] = df_050_059_CUB_SI2_E['Carat'] * df_050_059_CUB_SI2_E['PPC']


                elif i=="E" and j == "I1" and k == "CUB":
                    df_050_059_CUB_I1_E = pd.DataFrame()
                    df_050_059_CUB_I1_E ['Wt Range'] = None
                    df_050_059_CUB_I1_E  = df_050_059_CUB_I1_E.assign(Company=None)
                    df_050_059_CUB_I1_E  = df_050_059_CUB_I1_E.assign(Shape=None)
                    df_050_059_CUB_I1_E  = df_050_059_CUB_I1_E.assign(Carat=None)
                    df_050_059_CUB_I1_E  = df_050_059_CUB_I1_E.assign(Color=None)
                    df_050_059_CUB_I1_E  = df_050_059_CUB_I1_E.assign(Clarity=None)
                    df_050_059_CUB_I1_E  = df_050_059_CUB_I1_E.assign(Cut=None)
                    df_050_059_CUB_I1_E  = df_050_059_CUB_I1_E.assign(Polish=None)
                    df_050_059_CUB_I1_E  = df_050_059_CUB_I1_E.assign(Symmetry=None)
                    df_050_059_CUB_I1_E  = df_050_059_CUB_I1_E.assign(Ratio=None)
                    df_050_059_CUB_I1_E  = df_050_059_CUB_I1_E.assign(PPC=None)
                    df_050_059_CUB_I1_E  = df_050_059_CUB_I1_E.assign(Total=None)
                    df_050_059_CUB_I1_E ['Wt Range'] = listwtrange
                    df_050_059_CUB_I1_E ['Company'] = listcom
                    df_050_059_CUB_I1_E ['Shape'] = listshap
                    df_050_059_CUB_I1_E ['Carat'] = listcar
                    df_050_059_CUB_I1_E ['Color'] = listcol
                    df_050_059_CUB_I1_E ['Clarity'] = listclar
                    df_050_059_CUB_I1_E ['Cut'] = listcut
                    df_050_059_CUB_I1_E ['Polish'] = listpol
                    df_050_059_CUB_I1_E ['Symmetry'] = listsym
                    df_050_059_CUB_I1_E ['Ratio'] = listrat
                    df_050_059_CUB_I1_E ['PPC'] = listdesc
                    df_050_059_CUB_I1_E ['Total'] = listtotal
                    df_050_059_CUB_I1_E['Carat'] = df_050_059_CUB_I1_E['Carat'].astype('float64')
                    df_050_059_CUB_I1_E['PPC'] = df_050_059_CUB_I1_E['PPC'].astype('float64')
                    df_050_059_CUB_I1_E['Total'] = df_050_059_CUB_I1_E['Total'].astype('float64')
                    df_050_059_CUB_I1_E['Total'] = df_050_059_CUB_I1_E['Carat'] * df_050_059_CUB_I1_E['PPC']


                elif i=="E" and j == "I2" and k == "CUB":
                    df_050_059_CUB_I2_E = pd.DataFrame()
                    df_050_059_CUB_I2_E ['Wt Range'] = None
                    df_050_059_CUB_I2_E  = df_050_059_CUB_I2_E.assign(Company=None)
                    df_050_059_CUB_I2_E  = df_050_059_CUB_I2_E.assign(Shape=None)
                    df_050_059_CUB_I2_E  = df_050_059_CUB_I2_E.assign(Carat=None)
                    df_050_059_CUB_I2_E  = df_050_059_CUB_I2_E.assign(Color=None)
                    df_050_059_CUB_I2_E  = df_050_059_CUB_I2_E.assign(Clarity=None)
                    df_050_059_CUB_I2_E  = df_050_059_CUB_I2_E.assign(Cut=None)
                    df_050_059_CUB_I2_E  = df_050_059_CUB_I2_E.assign(Polish=None)
                    df_050_059_CUB_I2_E  = df_050_059_CUB_I2_E.assign(Symmetry=None)
                    df_050_059_CUB_I2_E  = df_050_059_CUB_I2_E.assign(Ratio=None)
                    df_050_059_CUB_I2_E  = df_050_059_CUB_I2_E.assign(PPC=None)
                    df_050_059_CUB_I2_E  = df_050_059_CUB_I2_E.assign(Total=None)
                    df_050_059_CUB_I2_E ['Wt Range'] = listwtrange
                    df_050_059_CUB_I2_E ['Company'] = listcom
                    df_050_059_CUB_I2_E ['Shape'] = listshap
                    df_050_059_CUB_I2_E ['Carat'] = listcar
                    df_050_059_CUB_I2_E ['Color'] = listcol
                    df_050_059_CUB_I2_E ['Clarity'] = listclar
                    df_050_059_CUB_I2_E ['Cut'] = listcut
                    df_050_059_CUB_I2_E ['Polish'] = listpol
                    df_050_059_CUB_I2_E ['Symmetry'] = listsym
                    df_050_059_CUB_I2_E ['Ratio'] = listrat
                    df_050_059_CUB_I2_E ['PPC'] = listdesc
                    df_050_059_CUB_I2_E ['Total'] = listtotal
                    df_050_059_CUB_I2_E['Carat'] = df_050_059_CUB_I2_E['Carat'].astype('float64')
                    df_050_059_CUB_I2_E['PPC'] = df_050_059_CUB_I2_E['PPC'].astype('float64')
                    df_050_059_CUB_I2_E['Total'] = df_050_059_CUB_I2_E['Total'].astype('float64')
                    df_050_059_CUB_I2_E['Total'] = df_050_059_CUB_I2_E['Carat'] * df_050_059_CUB_I2_E['PPC']
                
                elif i=="F" and j == "IF" and k == "CUB":
                    df_050_059_CUB_IF_F = pd.DataFrame()
                    df_050_059_CUB_IF_F ['Wt Range'] = None
                    df_050_059_CUB_IF_F  = df_050_059_CUB_IF_F.assign(Company=None)
                    df_050_059_CUB_IF_F  = df_050_059_CUB_IF_F.assign(Shape=None)
                    df_050_059_CUB_IF_F  = df_050_059_CUB_IF_F.assign(Carat=None)
                    df_050_059_CUB_IF_F  = df_050_059_CUB_IF_F.assign(Color=None)
                    df_050_059_CUB_IF_F  = df_050_059_CUB_IF_F.assign(Clarity=None)
                    df_050_059_CUB_IF_F  = df_050_059_CUB_IF_F.assign(Cut=None)
                    df_050_059_CUB_IF_F  = df_050_059_CUB_IF_F.assign(Polish=None)
                    df_050_059_CUB_IF_F  = df_050_059_CUB_IF_F.assign(Symmetry=None)
                    df_050_059_CUB_IF_F  = df_050_059_CUB_IF_F.assign(Ratio=None)
                    df_050_059_CUB_IF_F  = df_050_059_CUB_IF_F.assign(PPC=None)
                    df_050_059_CUB_IF_F  = df_050_059_CUB_IF_F.assign(Total=None)
                    df_050_059_CUB_IF_F ['Wt Range'] = listwtrange
                    df_050_059_CUB_IF_F ['Company'] = listcom
                    df_050_059_CUB_IF_F ['Shape'] = listshap
                    df_050_059_CUB_IF_F ['Carat'] = listcar
                    df_050_059_CUB_IF_F ['Color'] = listcol
                    df_050_059_CUB_IF_F ['Clarity'] = listclar
                    df_050_059_CUB_IF_F ['Cut'] = listcut
                    df_050_059_CUB_IF_F ['Polish'] = listpol
                    df_050_059_CUB_IF_F ['Symmetry'] = listsym
                    df_050_059_CUB_IF_F ['Ratio'] = listrat
                    df_050_059_CUB_IF_F ['PPC'] = listdesc
                    df_050_059_CUB_IF_F ['Total'] = listtotal
                    df_050_059_CUB_IF_F['Carat'] = df_050_059_CUB_IF_F['Carat'].astype('float64')
                    df_050_059_CUB_IF_F['PPC'] = df_050_059_CUB_IF_F['PPC'].astype('float64')
                    df_050_059_CUB_IF_F['Total'] = df_050_059_CUB_IF_F['Total'].astype('float64')
                    df_050_059_CUB_IF_F['Total'] = df_050_059_CUB_IF_F['Carat'] * df_050_059_CUB_IF_F['PPC']



                elif i=="F" and j == "VVS1" and k == "CUB":
                    df_050_059_CUB_VVS1_F = pd.DataFrame()
                    df_050_059_CUB_VVS1_F ['Wt Range'] = None
                    df_050_059_CUB_VVS1_F  = df_050_059_CUB_VVS1_F.assign(Company=None)
                    df_050_059_CUB_VVS1_F  = df_050_059_CUB_VVS1_F.assign(Shape=None)
                    df_050_059_CUB_VVS1_F  = df_050_059_CUB_VVS1_F.assign(Carat=None)
                    df_050_059_CUB_VVS1_F  = df_050_059_CUB_VVS1_F.assign(Color=None)
                    df_050_059_CUB_VVS1_F  = df_050_059_CUB_VVS1_F.assign(Clarity=None)
                    df_050_059_CUB_VVS1_F  = df_050_059_CUB_VVS1_F.assign(Cut=None)
                    df_050_059_CUB_VVS1_F  = df_050_059_CUB_VVS1_F.assign(Polish=None)
                    df_050_059_CUB_VVS1_F  = df_050_059_CUB_VVS1_F.assign(Symmetry=None)
                    df_050_059_CUB_VVS1_F  = df_050_059_CUB_VVS1_F.assign(Ratio=None)
                    df_050_059_CUB_VVS1_F  = df_050_059_CUB_VVS1_F.assign(PPC=None)
                    df_050_059_CUB_VVS1_F  = df_050_059_CUB_VVS1_F.assign(Total=None)
                    df_050_059_CUB_VVS1_F ['Wt Range'] = listwtrange
                    df_050_059_CUB_VVS1_F ['Company'] = listcom
                    df_050_059_CUB_VVS1_F ['Shape'] = listshap
                    df_050_059_CUB_VVS1_F ['Carat'] = listcar
                    df_050_059_CUB_VVS1_F ['Color'] = listcol
                    df_050_059_CUB_VVS1_F ['Clarity'] = listclar
                    df_050_059_CUB_VVS1_F ['Cut'] = listcut
                    df_050_059_CUB_VVS1_F ['Polish'] = listpol
                    df_050_059_CUB_VVS1_F ['Symmetry'] = listsym
                    df_050_059_CUB_VVS1_F ['Ratio'] = listrat
                    df_050_059_CUB_VVS1_F ['PPC'] = listdesc
                    df_050_059_CUB_VVS1_F ['Total'] = listtotal
                    df_050_059_CUB_VVS1_F['Carat'] = df_050_059_CUB_VVS1_F['Carat'].astype('float64')
                    df_050_059_CUB_VVS1_F['PPC'] = df_050_059_CUB_VVS1_F['PPC'].astype('float64')
                    df_050_059_CUB_VVS1_F['Total'] = df_050_059_CUB_VVS1_F['Total'].astype('float64')
                    df_050_059_CUB_VVS1_F['Total'] = df_050_059_CUB_VVS1_F['Carat'] * df_050_059_CUB_VVS1_F['PPC']


                elif i=="F" and j == "VVS2" and k == "CUB":
                    df_050_059_CUB_VVS2_F = pd.DataFrame()
                    df_050_059_CUB_VVS2_F ['Wt Range'] = None
                    df_050_059_CUB_VVS2_F  = df_050_059_CUB_VVS2_F.assign(Company=None)
                    df_050_059_CUB_VVS2_F  = df_050_059_CUB_VVS2_F.assign(Shape=None)
                    df_050_059_CUB_VVS2_F  = df_050_059_CUB_VVS2_F.assign(Carat=None)
                    df_050_059_CUB_VVS2_F  = df_050_059_CUB_VVS2_F.assign(Color=None)
                    df_050_059_CUB_VVS2_F  = df_050_059_CUB_VVS2_F.assign(Clarity=None)
                    df_050_059_CUB_VVS2_F  = df_050_059_CUB_VVS2_F.assign(Cut=None)
                    df_050_059_CUB_VVS2_F  = df_050_059_CUB_VVS2_F.assign(Polish=None)
                    df_050_059_CUB_VVS2_F  = df_050_059_CUB_VVS2_F.assign(Symmetry=None)
                    df_050_059_CUB_VVS2_F  = df_050_059_CUB_VVS2_F.assign(Ratio=None)
                    df_050_059_CUB_VVS2_F  = df_050_059_CUB_VVS2_F.assign(PPC=None)
                    df_050_059_CUB_VVS2_F  = df_050_059_CUB_VVS2_F.assign(Total=None)
                    df_050_059_CUB_VVS2_F ['Wt Range'] = listwtrange
                    df_050_059_CUB_VVS2_F ['Company'] = listcom
                    df_050_059_CUB_VVS2_F ['Shape'] = listshap
                    df_050_059_CUB_VVS2_F ['Carat'] = listcar
                    df_050_059_CUB_VVS2_F ['Color'] = listcol
                    df_050_059_CUB_VVS2_F ['Clarity'] = listclar
                    df_050_059_CUB_VVS2_F ['Cut'] = listcut
                    df_050_059_CUB_VVS2_F ['Polish'] = listpol
                    df_050_059_CUB_VVS2_F ['Symmetry'] = listsym
                    df_050_059_CUB_VVS2_F ['Ratio'] = listrat
                    df_050_059_CUB_VVS2_F ['PPC'] = listdesc
                    df_050_059_CUB_VVS2_F ['Total'] = listtotal
                    df_050_059_CUB_VVS2_F['Carat'] = df_050_059_CUB_VVS2_F['Carat'].astype('float64')
                    df_050_059_CUB_VVS2_F['PPC'] = df_050_059_CUB_VVS2_F['PPC'].astype('float64')
                    df_050_059_CUB_VVS2_F['Total'] = df_050_059_CUB_VVS2_F['Total'].astype('float64')
                    df_050_059_CUB_VVS2_F['Total'] = df_050_059_CUB_VVS2_F['Carat'] * df_050_059_CUB_VVS2_F['PPC']


                elif i=="F" and j=="VS1" and k == "CUB":
                    df_050_059_CUB_VS1_F = pd.DataFrame()
                    df_050_059_CUB_VS1_F ['Wt Range'] = None
                    df_050_059_CUB_VS1_F  = df_050_059_CUB_VS1_F.assign(Company=None)
                    df_050_059_CUB_VS1_F  = df_050_059_CUB_VS1_F.assign(Shape=None)
                    df_050_059_CUB_VS1_F  = df_050_059_CUB_VS1_F.assign(Carat=None)
                    df_050_059_CUB_VS1_F  = df_050_059_CUB_VS1_F.assign(Color=None)
                    df_050_059_CUB_VS1_F  = df_050_059_CUB_VS1_F.assign(Clarity=None)
                    df_050_059_CUB_VS1_F  = df_050_059_CUB_VS1_F.assign(Cut=None)
                    df_050_059_CUB_VS1_F  = df_050_059_CUB_VS1_F.assign(Polish=None)
                    df_050_059_CUB_VS1_F  = df_050_059_CUB_VS1_F.assign(Symmetry=None)
                    df_050_059_CUB_VS1_F  = df_050_059_CUB_VS1_F.assign(Ratio=None)
                    df_050_059_CUB_VS1_F  = df_050_059_CUB_VS1_F.assign(PPC=None)
                    df_050_059_CUB_VS1_F  = df_050_059_CUB_VS1_F.assign(Total=None)
                    df_050_059_CUB_VS1_F ['Wt Range'] = listwtrange
                    df_050_059_CUB_VS1_F ['Company'] = listcom
                    df_050_059_CUB_VS1_F ['Shape'] = listshap
                    df_050_059_CUB_VS1_F ['Carat'] = listcar
                    df_050_059_CUB_VS1_F ['Color'] = listcol
                    df_050_059_CUB_VS1_F ['Clarity'] = listclar
                    df_050_059_CUB_VS1_F ['Cut'] = listcut
                    df_050_059_CUB_VS1_F ['Polish'] = listpol
                    df_050_059_CUB_VS1_F ['Symmetry'] = listsym
                    df_050_059_CUB_VS1_F ['Ratio'] = listrat
                    df_050_059_CUB_VS1_F ['PPC'] = listdesc
                    df_050_059_CUB_VS1_F ['Total'] = listtotal
                    df_050_059_CUB_VS1_F['Carat'] = df_050_059_CUB_VS1_F['Carat'].astype('float64')
                    df_050_059_CUB_VS1_F['PPC'] = df_050_059_CUB_VS1_F['PPC'].astype('float64')
                    df_050_059_CUB_VS1_F['Total'] = df_050_059_CUB_VS1_F['Total'].astype('float64')
                    df_050_059_CUB_VS1_F['Total'] = df_050_059_CUB_VS1_F['Carat'] * df_050_059_CUB_VS1_F['PPC']


                elif i=="F" and j == "VS2" and k == "CUB":
                    df_050_059_CUB_VS2_F = pd.DataFrame()
                    df_050_059_CUB_VS2_F ['Wt Range'] = None
                    df_050_059_CUB_VS2_F  = df_050_059_CUB_VS2_F.assign(Company=None)
                    df_050_059_CUB_VS2_F  = df_050_059_CUB_VS2_F.assign(Shape=None)
                    df_050_059_CUB_VS2_F  = df_050_059_CUB_VS2_F.assign(Carat=None)
                    df_050_059_CUB_VS2_F  = df_050_059_CUB_VS2_F.assign(Color=None)
                    df_050_059_CUB_VS2_F  = df_050_059_CUB_VS2_F.assign(Clarity=None)
                    df_050_059_CUB_VS2_F  = df_050_059_CUB_VS2_F.assign(Cut=None)
                    df_050_059_CUB_VS2_F  = df_050_059_CUB_VS2_F.assign(Polish=None)
                    df_050_059_CUB_VS2_F  = df_050_059_CUB_VS2_F.assign(Symmetry=None)
                    df_050_059_CUB_VS2_F  = df_050_059_CUB_VS2_F.assign(Ratio=None)
                    df_050_059_CUB_VS2_F  = df_050_059_CUB_VS2_F.assign(PPC=None)
                    df_050_059_CUB_VS2_F  = df_050_059_CUB_VS2_F.assign(Total=None)
                    df_050_059_CUB_VS2_F ['Wt Range'] = listwtrange
                    df_050_059_CUB_VS2_F ['Company'] = listcom
                    df_050_059_CUB_VS2_F ['Shape'] = listshap
                    df_050_059_CUB_VS2_F ['Carat'] = listcar
                    df_050_059_CUB_VS2_F ['Color'] = listcol
                    df_050_059_CUB_VS2_F ['Clarity'] = listclar
                    df_050_059_CUB_VS2_F ['Cut'] = listcut
                    df_050_059_CUB_VS2_F ['Polish'] = listpol
                    df_050_059_CUB_VS2_F ['Symmetry'] = listsym
                    df_050_059_CUB_VS2_F ['Ratio'] = listrat
                    df_050_059_CUB_VS2_F ['PPC'] = listdesc
                    df_050_059_CUB_VS2_F ['Total'] = listtotal
                    df_050_059_CUB_VS2_F['Carat'] = df_050_059_CUB_VS2_F['Carat'].astype('float64')
                    df_050_059_CUB_VS2_F['PPC'] = df_050_059_CUB_VS2_F['PPC'].astype('float64')
                    df_050_059_CUB_VS2_F['Total'] = df_050_059_CUB_VS2_F['Total'].astype('float64')
                    df_050_059_CUB_VS2_F['Total'] = df_050_059_CUB_VS2_F['Carat'] * df_050_059_CUB_VS2_F['PPC']


                elif i=="F" and j == "SI1" and k == "CUB":
                    df_050_059_CUB_SI1_F = pd.DataFrame()
                    df_050_059_CUB_SI1_F ['Wt Range'] = None
                    df_050_059_CUB_SI1_F  = df_050_059_CUB_SI1_F.assign(Company=None)
                    df_050_059_CUB_SI1_F  = df_050_059_CUB_SI1_F.assign(Shape=None)
                    df_050_059_CUB_SI1_F  = df_050_059_CUB_SI1_F.assign(Carat=None)
                    df_050_059_CUB_SI1_F  = df_050_059_CUB_SI1_F.assign(Color=None)
                    df_050_059_CUB_SI1_F  = df_050_059_CUB_SI1_F.assign(Clarity=None)
                    df_050_059_CUB_SI1_F  = df_050_059_CUB_SI1_F.assign(Cut=None)
                    df_050_059_CUB_SI1_F  = df_050_059_CUB_SI1_F.assign(Polish=None)
                    df_050_059_CUB_SI1_F  = df_050_059_CUB_SI1_F.assign(Symmetry=None)
                    df_050_059_CUB_SI1_F  = df_050_059_CUB_SI1_F.assign(Ratio=None)
                    df_050_059_CUB_SI1_F  = df_050_059_CUB_SI1_F.assign(PPC=None)
                    df_050_059_CUB_SI1_F  = df_050_059_CUB_SI1_F.assign(Total=None)
                    df_050_059_CUB_SI1_F ['Wt Range'] = listwtrange
                    df_050_059_CUB_SI1_F ['Company'] = listcom
                    df_050_059_CUB_SI1_F ['Shape'] = listshap
                    df_050_059_CUB_SI1_F ['Carat'] = listcar
                    df_050_059_CUB_SI1_F ['Color'] = listcol
                    df_050_059_CUB_SI1_F ['Clarity'] = listclar
                    df_050_059_CUB_SI1_F ['Cut'] = listcut
                    df_050_059_CUB_SI1_F ['Polish'] = listpol
                    df_050_059_CUB_SI1_F ['Symmetry'] = listsym
                    df_050_059_CUB_SI1_F ['Ratio'] = listrat
                    df_050_059_CUB_SI1_F ['PPC'] = listdesc
                    df_050_059_CUB_SI1_F ['Total'] = listtotal
                    df_050_059_CUB_SI1_F['Carat'] = df_050_059_CUB_SI1_F['Carat'].astype('float64')
                    df_050_059_CUB_SI1_F['PPC'] = df_050_059_CUB_SI1_F['PPC'].astype('float64')
                    df_050_059_CUB_SI1_F['Total'] = df_050_059_CUB_SI1_F['Total'].astype('float64')
                    df_050_059_CUB_SI1_F['Total'] = df_050_059_CUB_SI1_F['Carat'] * df_050_059_CUB_SI1_F['PPC']


                elif i=="F" and j == "SI2" and k == "CUB":
                    df_050_059_CUB_SI2_F = pd.DataFrame()
                    df_050_059_CUB_SI2_F ['Wt Range'] = None
                    df_050_059_CUB_SI2_F  = df_050_059_CUB_SI2_F.assign(Company=None)
                    df_050_059_CUB_SI2_F  = df_050_059_CUB_SI2_F.assign(Shape=None)
                    df_050_059_CUB_SI2_F  = df_050_059_CUB_SI2_F.assign(Carat=None)
                    df_050_059_CUB_SI2_F  = df_050_059_CUB_SI2_F.assign(Color=None)
                    df_050_059_CUB_SI2_F  = df_050_059_CUB_SI2_F.assign(Clarity=None)
                    df_050_059_CUB_SI2_F  = df_050_059_CUB_SI2_F.assign(Cut=None)
                    df_050_059_CUB_SI2_F  = df_050_059_CUB_SI2_F.assign(Polish=None)
                    df_050_059_CUB_SI2_F  = df_050_059_CUB_SI2_F.assign(Symmetry=None)
                    df_050_059_CUB_SI2_F  = df_050_059_CUB_SI2_F.assign(Ratio=None)
                    df_050_059_CUB_SI2_F  = df_050_059_CUB_SI2_F.assign(PPC=None)
                    df_050_059_CUB_SI2_F  = df_050_059_CUB_SI2_F.assign(Total=None)
                    df_050_059_CUB_SI2_F ['Wt Range'] = listwtrange
                    df_050_059_CUB_SI2_F ['Company'] = listcom
                    df_050_059_CUB_SI2_F ['Shape'] = listshap
                    df_050_059_CUB_SI2_F ['Carat'] = listcar
                    df_050_059_CUB_SI2_F ['Color'] = listcol
                    df_050_059_CUB_SI2_F ['Clarity'] = listclar
                    df_050_059_CUB_SI2_F ['Cut'] = listcut
                    df_050_059_CUB_SI2_F ['Polish'] = listpol
                    df_050_059_CUB_SI2_F ['Symmetry'] = listsym
                    df_050_059_CUB_SI2_F ['Ratio'] = listrat
                    df_050_059_CUB_SI2_F ['PPC'] = listdesc
                    df_050_059_CUB_SI2_F ['Total'] = listtotal
                    df_050_059_CUB_SI2_F['Carat'] = df_050_059_CUB_SI2_F['Carat'].astype('float64')
                    df_050_059_CUB_SI2_F['PPC'] = df_050_059_CUB_SI2_F['PPC'].astype('float64')
                    df_050_059_CUB_SI2_F['Total'] = df_050_059_CUB_SI2_F['Total'].astype('float64')
                    df_050_059_CUB_SI2_F['Total'] = df_050_059_CUB_SI2_F['Carat'] * df_050_059_CUB_SI2_F['PPC']


                elif i=="F" and j == "I1" and k == "CUB":
                    df_050_059_CUB_I1_F = pd.DataFrame()
                    df_050_059_CUB_I1_F ['Wt Range'] = None
                    df_050_059_CUB_I1_F  = df_050_059_CUB_I1_F.assign(Company=None)
                    df_050_059_CUB_I1_F  = df_050_059_CUB_I1_F.assign(Shape=None)
                    df_050_059_CUB_I1_F  = df_050_059_CUB_I1_F.assign(Carat=None)
                    df_050_059_CUB_I1_F  = df_050_059_CUB_I1_F.assign(Color=None)
                    df_050_059_CUB_I1_F  = df_050_059_CUB_I1_F.assign(Clarity=None)
                    df_050_059_CUB_I1_F  = df_050_059_CUB_I1_F.assign(Cut=None)
                    df_050_059_CUB_I1_F  = df_050_059_CUB_I1_F.assign(Polish=None)
                    df_050_059_CUB_I1_F  = df_050_059_CUB_I1_F.assign(Symmetry=None)
                    df_050_059_CUB_I1_F  = df_050_059_CUB_I1_F.assign(Ratio=None)
                    df_050_059_CUB_I1_F  = df_050_059_CUB_I1_F.assign(PPC=None)
                    df_050_059_CUB_I1_F  = df_050_059_CUB_I1_F.assign(Total=None)
                    df_050_059_CUB_I1_F ['Wt Range'] = listwtrange
                    df_050_059_CUB_I1_F ['Company'] = listcom
                    df_050_059_CUB_I1_F ['Shape'] = listshap
                    df_050_059_CUB_I1_F ['Carat'] = listcar
                    df_050_059_CUB_I1_F ['Color'] = listcol
                    df_050_059_CUB_I1_F ['Clarity'] = listclar
                    df_050_059_CUB_I1_F ['Cut'] = listcut
                    df_050_059_CUB_I1_F ['Polish'] = listpol
                    df_050_059_CUB_I1_F ['Symmetry'] = listsym
                    df_050_059_CUB_I1_F ['Ratio'] = listrat
                    df_050_059_CUB_I1_F ['PPC'] = listdesc
                    df_050_059_CUB_I1_F ['Total'] = listtotal
                    df_050_059_CUB_I1_F['Carat'] = df_050_059_CUB_I1_F['Carat'].astype('float64')
                    df_050_059_CUB_I1_F['PPC'] = df_050_059_CUB_I1_F['PPC'].astype('float64')
                    df_050_059_CUB_I1_F['Total'] = df_050_059_CUB_I1_F['Total'].astype('float64')
                    df_050_059_CUB_I1_F['Total'] = df_050_059_CUB_I1_F['Carat'] * df_050_059_CUB_I1_F['PPC']


                elif i=="F" and j == "I2" and k == "CUB":
                    df_050_059_CUB_I2_F = pd.DataFrame()
                    df_050_059_CUB_I2_F ['Wt Range'] = None
                    df_050_059_CUB_I2_F  = df_050_059_CUB_I2_F.assign(Company=None)
                    df_050_059_CUB_I2_F  = df_050_059_CUB_I2_F.assign(Shape=None)
                    df_050_059_CUB_I2_F  = df_050_059_CUB_I2_F.assign(Carat=None)
                    df_050_059_CUB_I2_F  = df_050_059_CUB_I2_F.assign(Color=None)
                    df_050_059_CUB_I2_F  = df_050_059_CUB_I2_F.assign(Clarity=None)
                    df_050_059_CUB_I2_F  = df_050_059_CUB_I2_F.assign(Cut=None)
                    df_050_059_CUB_I2_F  = df_050_059_CUB_I2_F.assign(Polish=None)
                    df_050_059_CUB_I2_F  = df_050_059_CUB_I2_F.assign(Symmetry=None)
                    df_050_059_CUB_I2_F  = df_050_059_CUB_I2_F.assign(Ratio=None)
                    df_050_059_CUB_I2_F  = df_050_059_CUB_I2_F.assign(PPC=None)
                    df_050_059_CUB_I2_F  = df_050_059_CUB_I2_F.assign(Total=None)
                    df_050_059_CUB_I2_F ['Wt Range'] = listwtrange
                    df_050_059_CUB_I2_F ['Company'] = listcom
                    df_050_059_CUB_I2_F ['Shape'] = listshap
                    df_050_059_CUB_I2_F ['Carat'] = listcar
                    df_050_059_CUB_I2_F ['Color'] = listcol
                    df_050_059_CUB_I2_F ['Clarity'] = listclar
                    df_050_059_CUB_I2_F ['Cut'] = listcut
                    df_050_059_CUB_I2_F ['Polish'] = listpol
                    df_050_059_CUB_I2_F ['Symmetry'] = listsym
                    df_050_059_CUB_I2_F ['Ratio'] = listrat
                    df_050_059_CUB_I2_F ['PPC'] = listdesc
                    df_050_059_CUB_I2_F ['Total'] = listtotal
                    df_050_059_CUB_I2_F['Carat'] = df_050_059_CUB_I2_F['Carat'].astype('float64')
                    df_050_059_CUB_I2_F['PPC'] = df_050_059_CUB_I2_F['PPC'].astype('float64')
                    df_050_059_CUB_I2_F['Total'] = df_050_059_CUB_I2_F['Total'].astype('float64')
                    df_050_059_CUB_I2_F['Total'] = df_050_059_CUB_I2_F['Carat'] * df_050_059_CUB_I2_F['PPC']


                elif i=="G" and j == "IF" and k == "CUB":
                    df_050_059_CUB_IF_G = pd.DataFrame()
                    df_050_059_CUB_IF_G ['Wt Range'] = None
                    df_050_059_CUB_IF_G  = df_050_059_CUB_IF_G.assign(Company=None)
                    df_050_059_CUB_IF_G  = df_050_059_CUB_IF_G.assign(Shape=None)
                    df_050_059_CUB_IF_G  = df_050_059_CUB_IF_G.assign(Carat=None)
                    df_050_059_CUB_IF_G  = df_050_059_CUB_IF_G.assign(Color=None)
                    df_050_059_CUB_IF_G  = df_050_059_CUB_IF_G.assign(Clarity=None)
                    df_050_059_CUB_IF_G  = df_050_059_CUB_IF_G.assign(Cut=None)
                    df_050_059_CUB_IF_G  = df_050_059_CUB_IF_G.assign(Polish=None)
                    df_050_059_CUB_IF_G  = df_050_059_CUB_IF_G.assign(Symmetry=None)
                    df_050_059_CUB_IF_G  = df_050_059_CUB_IF_G.assign(Ratio=None)
                    df_050_059_CUB_IF_G  = df_050_059_CUB_IF_G.assign(PPC=None)
                    df_050_059_CUB_IF_G  = df_050_059_CUB_IF_G.assign(Total=None)
                    df_050_059_CUB_IF_G ['Wt Range'] = listwtrange
                    df_050_059_CUB_IF_G ['Company'] = listcom
                    df_050_059_CUB_IF_G ['Shape'] = listshap
                    df_050_059_CUB_IF_G ['Carat'] = listcar
                    df_050_059_CUB_IF_G ['Color'] = listcol
                    df_050_059_CUB_IF_G ['Clarity'] = listclar
                    df_050_059_CUB_IF_G ['Cut'] = listcut
                    df_050_059_CUB_IF_G ['Polish'] = listpol
                    df_050_059_CUB_IF_G ['Symmetry'] = listsym
                    df_050_059_CUB_IF_G ['Ratio'] = listrat
                    df_050_059_CUB_IF_G ['PPC'] = listdesc
                    df_050_059_CUB_IF_G ['Total'] = listtotal
                    df_050_059_CUB_IF_G['Carat'] = df_050_059_CUB_IF_G['Carat'].astype('float64')
                    df_050_059_CUB_IF_G['PPC'] = df_050_059_CUB_IF_G['PPC'].astype('float64')
                    df_050_059_CUB_IF_G['Total'] = df_050_059_CUB_IF_G['Total'].astype('float64')
                    df_050_059_CUB_IF_G['Total'] = df_050_059_CUB_IF_G['Carat'] * df_050_059_CUB_IF_G['PPC']



                elif i=="G" and j == "VVS1" and k == "CUB":
                    df_050_059_CUB_VVS1_G = pd.DataFrame()
                    df_050_059_CUB_VVS1_G ['Wt Range'] = None
                    df_050_059_CUB_VVS1_G  = df_050_059_CUB_VVS1_G.assign(Company=None)
                    df_050_059_CUB_VVS1_G  = df_050_059_CUB_VVS1_G.assign(Shape=None)
                    df_050_059_CUB_VVS1_G  = df_050_059_CUB_VVS1_G.assign(Carat=None)
                    df_050_059_CUB_VVS1_G  = df_050_059_CUB_VVS1_G.assign(Color=None)
                    df_050_059_CUB_VVS1_G  = df_050_059_CUB_VVS1_G.assign(Clarity=None)
                    df_050_059_CUB_VVS1_G  = df_050_059_CUB_VVS1_G.assign(Cut=None)
                    df_050_059_CUB_VVS1_G  = df_050_059_CUB_VVS1_G.assign(Polish=None)
                    df_050_059_CUB_VVS1_G  = df_050_059_CUB_VVS1_G.assign(Symmetry=None)
                    df_050_059_CUB_VVS1_G  = df_050_059_CUB_VVS1_G.assign(Ratio=None)
                    df_050_059_CUB_VVS1_G  = df_050_059_CUB_VVS1_G.assign(PPC=None)
                    df_050_059_CUB_VVS1_G  = df_050_059_CUB_VVS1_G.assign(Total=None)
                    df_050_059_CUB_VVS1_G ['Wt Range'] = listwtrange
                    df_050_059_CUB_VVS1_G ['Company'] = listcom
                    df_050_059_CUB_VVS1_G ['Shape'] = listshap
                    df_050_059_CUB_VVS1_G ['Carat'] = listcar
                    df_050_059_CUB_VVS1_G ['Color'] = listcol
                    df_050_059_CUB_VVS1_G ['Clarity'] = listclar
                    df_050_059_CUB_VVS1_G ['Cut'] = listcut
                    df_050_059_CUB_VVS1_G ['Polish'] = listpol
                    df_050_059_CUB_VVS1_G ['Symmetry'] = listsym
                    df_050_059_CUB_VVS1_G ['Ratio'] = listrat
                    df_050_059_CUB_VVS1_G ['PPC'] = listdesc
                    df_050_059_CUB_VVS1_G ['Total'] = listtotal
                    df_050_059_CUB_VVS1_G['Carat'] = df_050_059_CUB_VVS1_G['Carat'].astype('float64')
                    df_050_059_CUB_VVS1_G['PPC'] = df_050_059_CUB_VVS1_G['PPC'].astype('float64')
                    df_050_059_CUB_VVS1_G['Total'] = df_050_059_CUB_VVS1_G['Total'].astype('float64')
                    df_050_059_CUB_VVS1_G['Total'] = df_050_059_CUB_VVS1_G['Carat'] * df_050_059_CUB_VVS1_G['PPC']


                elif i=="G" and j == "VVS2" and k == "CUB":
                    df_050_059_CUB_VVS2_G = pd.DataFrame()
                    df_050_059_CUB_VVS2_G ['Wt Range'] = None
                    df_050_059_CUB_VVS2_G  = df_050_059_CUB_VVS2_G.assign(Company=None)
                    df_050_059_CUB_VVS2_G  = df_050_059_CUB_VVS2_G.assign(Shape=None)
                    df_050_059_CUB_VVS2_G  = df_050_059_CUB_VVS2_G.assign(Carat=None)
                    df_050_059_CUB_VVS2_G  = df_050_059_CUB_VVS2_G.assign(Color=None)
                    df_050_059_CUB_VVS2_G  = df_050_059_CUB_VVS2_G.assign(Clarity=None)
                    df_050_059_CUB_VVS2_G  = df_050_059_CUB_VVS2_G.assign(Cut=None)
                    df_050_059_CUB_VVS2_G  = df_050_059_CUB_VVS2_G.assign(Polish=None)
                    df_050_059_CUB_VVS2_G  = df_050_059_CUB_VVS2_G.assign(Symmetry=None)
                    df_050_059_CUB_VVS2_G  = df_050_059_CUB_VVS2_G.assign(Ratio=None)
                    df_050_059_CUB_VVS2_G  = df_050_059_CUB_VVS2_G.assign(PPC=None)
                    df_050_059_CUB_VVS2_G  = df_050_059_CUB_VVS2_G.assign(Total=None)
                    df_050_059_CUB_VVS2_G ['Wt Range'] = listwtrange
                    df_050_059_CUB_VVS2_G ['Company'] = listcom
                    df_050_059_CUB_VVS2_G ['Shape'] = listshap
                    df_050_059_CUB_VVS2_G ['Carat'] = listcar
                    df_050_059_CUB_VVS2_G ['Color'] = listcol
                    df_050_059_CUB_VVS2_G ['Clarity'] = listclar
                    df_050_059_CUB_VVS2_G ['Cut'] = listcut
                    df_050_059_CUB_VVS2_G ['Polish'] = listpol
                    df_050_059_CUB_VVS2_G ['Symmetry'] = listsym
                    df_050_059_CUB_VVS2_G ['Ratio'] = listrat
                    df_050_059_CUB_VVS2_G ['PPC'] = listdesc
                    df_050_059_CUB_VVS2_G ['Total'] = listtotal
                    df_050_059_CUB_VVS2_G['Carat'] = df_050_059_CUB_VVS2_G['Carat'].astype('float64')
                    df_050_059_CUB_VVS2_G['PPC'] = df_050_059_CUB_VVS2_G['PPC'].astype('float64')
                    df_050_059_CUB_VVS2_G['Total'] = df_050_059_CUB_VVS2_G['Total'].astype('float64')
                    df_050_059_CUB_VVS2_G['Total'] = df_050_059_CUB_VVS2_G['Carat'] * df_050_059_CUB_VVS2_G['PPC']


                elif i=="G" and j=="VS1" and k == "CUB":
                    df_050_059_CUB_VS1_G = pd.DataFrame()
                    df_050_059_CUB_VS1_G ['Wt Range'] = None
                    df_050_059_CUB_VS1_G  = df_050_059_CUB_VS1_G.assign(Company=None)
                    df_050_059_CUB_VS1_G  = df_050_059_CUB_VS1_G.assign(Shape=None)
                    df_050_059_CUB_VS1_G  = df_050_059_CUB_VS1_G.assign(Carat=None)
                    df_050_059_CUB_VS1_G  = df_050_059_CUB_VS1_G.assign(Color=None)
                    df_050_059_CUB_VS1_G  = df_050_059_CUB_VS1_G.assign(Clarity=None)
                    df_050_059_CUB_VS1_G  = df_050_059_CUB_VS1_G.assign(Cut=None)
                    df_050_059_CUB_VS1_G  = df_050_059_CUB_VS1_G.assign(Polish=None)
                    df_050_059_CUB_VS1_G  = df_050_059_CUB_VS1_G.assign(Symmetry=None)
                    df_050_059_CUB_VS1_G  = df_050_059_CUB_VS1_G.assign(Ratio=None)
                    df_050_059_CUB_VS1_G  = df_050_059_CUB_VS1_G.assign(PPC=None)
                    df_050_059_CUB_VS1_G  = df_050_059_CUB_VS1_G.assign(Total=None)
                    df_050_059_CUB_VS1_G ['Wt Range'] = listwtrange
                    df_050_059_CUB_VS1_G ['Company'] = listcom
                    df_050_059_CUB_VS1_G ['Shape'] = listshap
                    df_050_059_CUB_VS1_G ['Carat'] = listcar
                    df_050_059_CUB_VS1_G ['Color'] = listcol
                    df_050_059_CUB_VS1_G ['Clarity'] = listclar
                    df_050_059_CUB_VS1_G ['Cut'] = listcut
                    df_050_059_CUB_VS1_G ['Polish'] = listpol
                    df_050_059_CUB_VS1_G ['Symmetry'] = listsym
                    df_050_059_CUB_VS1_G ['Ratio'] = listrat
                    df_050_059_CUB_VS1_G ['PPC'] = listdesc
                    df_050_059_CUB_VS1_G ['Total'] = listtotal
                    df_050_059_CUB_VS1_G['Carat'] = df_050_059_CUB_VS1_G['Carat'].astype('float64')
                    df_050_059_CUB_VS1_G['PPC'] = df_050_059_CUB_VS1_G['PPC'].astype('float64')
                    df_050_059_CUB_VS1_G['Total'] = df_050_059_CUB_VS1_G['Total'].astype('float64')
                    df_050_059_CUB_VS1_G['Total'] = df_050_059_CUB_VS1_G['Carat'] * df_050_059_CUB_VS1_G['PPC']


                elif i=="G" and j == "VS2" and k == "CUB":
                    df_050_059_CUB_VS2_G = pd.DataFrame()
                    df_050_059_CUB_VS2_G ['Wt Range'] = None
                    df_050_059_CUB_VS2_G  = df_050_059_CUB_VS2_G.assign(Company=None)
                    df_050_059_CUB_VS2_G  = df_050_059_CUB_VS2_G.assign(Shape=None)
                    df_050_059_CUB_VS2_G  = df_050_059_CUB_VS2_G.assign(Carat=None)
                    df_050_059_CUB_VS2_G  = df_050_059_CUB_VS2_G.assign(Color=None)
                    df_050_059_CUB_VS2_G  = df_050_059_CUB_VS2_G.assign(Clarity=None)
                    df_050_059_CUB_VS2_G  = df_050_059_CUB_VS2_G.assign(Cut=None)
                    df_050_059_CUB_VS2_G  = df_050_059_CUB_VS2_G.assign(Polish=None)
                    df_050_059_CUB_VS2_G  = df_050_059_CUB_VS2_G.assign(Symmetry=None)
                    df_050_059_CUB_VS2_G  = df_050_059_CUB_VS2_G.assign(Ratio=None)
                    df_050_059_CUB_VS2_G  = df_050_059_CUB_VS2_G.assign(PPC=None)
                    df_050_059_CUB_VS2_G  = df_050_059_CUB_VS2_G.assign(Total=None)
                    df_050_059_CUB_VS2_G ['Wt Range'] = listwtrange
                    df_050_059_CUB_VS2_G ['Company'] = listcom
                    df_050_059_CUB_VS2_G ['Shape'] = listshap
                    df_050_059_CUB_VS2_G ['Carat'] = listcar
                    df_050_059_CUB_VS2_G ['Color'] = listcol
                    df_050_059_CUB_VS2_G ['Clarity'] = listclar
                    df_050_059_CUB_VS2_G ['Cut'] = listcut
                    df_050_059_CUB_VS2_G ['Polish'] = listpol
                    df_050_059_CUB_VS2_G ['Symmetry'] = listsym
                    df_050_059_CUB_VS2_G ['Ratio'] = listrat
                    df_050_059_CUB_VS2_G ['PPC'] = listdesc
                    df_050_059_CUB_VS2_G ['Total'] = listtotal
                    df_050_059_CUB_VS2_G['Carat'] = df_050_059_CUB_VS2_G['Carat'].astype('float64')
                    df_050_059_CUB_VS2_G['PPC'] = df_050_059_CUB_VS2_G['PPC'].astype('float64')
                    df_050_059_CUB_VS2_G['Total'] = df_050_059_CUB_VS2_G['Total'].astype('float64')
                    df_050_059_CUB_VS2_G['Total'] = df_050_059_CUB_VS2_G['Carat'] * df_050_059_CUB_VS2_G['PPC']


                elif i=="G" and j == "SI1" and k == "CUB":
                    df_050_059_CUB_SI1_G = pd.DataFrame()
                    df_050_059_CUB_SI1_G ['Wt Range'] = None
                    df_050_059_CUB_SI1_G  = df_050_059_CUB_SI1_G.assign(Company=None)
                    df_050_059_CUB_SI1_G  = df_050_059_CUB_SI1_G.assign(Shape=None)
                    df_050_059_CUB_SI1_G  = df_050_059_CUB_SI1_G.assign(Carat=None)
                    df_050_059_CUB_SI1_G  = df_050_059_CUB_SI1_G.assign(Color=None)
                    df_050_059_CUB_SI1_G  = df_050_059_CUB_SI1_G.assign(Clarity=None)
                    df_050_059_CUB_SI1_G  = df_050_059_CUB_SI1_G.assign(Cut=None)
                    df_050_059_CUB_SI1_G  = df_050_059_CUB_SI1_G.assign(Polish=None)
                    df_050_059_CUB_SI1_G  = df_050_059_CUB_SI1_G.assign(Symmetry=None)
                    df_050_059_CUB_SI1_G  = df_050_059_CUB_SI1_G.assign(Ratio=None)
                    df_050_059_CUB_SI1_G  = df_050_059_CUB_SI1_G.assign(PPC=None)
                    df_050_059_CUB_SI1_G  = df_050_059_CUB_SI1_G.assign(Total=None)
                    df_050_059_CUB_SI1_G ['Wt Range'] = listwtrange
                    df_050_059_CUB_SI1_G ['Company'] = listcom
                    df_050_059_CUB_SI1_G ['Shape'] = listshap
                    df_050_059_CUB_SI1_G ['Carat'] = listcar
                    df_050_059_CUB_SI1_G ['Color'] = listcol
                    df_050_059_CUB_SI1_G ['Clarity'] = listclar
                    df_050_059_CUB_SI1_G ['Cut'] = listcut
                    df_050_059_CUB_SI1_G ['Polish'] = listpol
                    df_050_059_CUB_SI1_G ['Symmetry'] = listsym
                    df_050_059_CUB_SI1_G ['Ratio'] = listrat
                    df_050_059_CUB_SI1_G ['PPC'] = listdesc
                    df_050_059_CUB_SI1_G ['Total'] = listtotal
                    df_050_059_CUB_SI1_G['Carat'] = df_050_059_CUB_SI1_G['Carat'].astype('float64')
                    df_050_059_CUB_SI1_G['PPC'] = df_050_059_CUB_SI1_G['PPC'].astype('float64')
                    df_050_059_CUB_SI1_G['Total'] = df_050_059_CUB_SI1_G['Total'].astype('float64')
                    df_050_059_CUB_SI1_G['Total'] = df_050_059_CUB_SI1_G['Carat'] * df_050_059_CUB_SI1_G['PPC']


                elif i=="G" and j == "SI2" and k == "CUB":
                    df_050_059_CUB_SI2_G = pd.DataFrame()
                    df_050_059_CUB_SI2_G ['Wt Range'] = None
                    df_050_059_CUB_SI2_G  = df_050_059_CUB_SI2_G.assign(Company=None)
                    df_050_059_CUB_SI2_G  = df_050_059_CUB_SI2_G.assign(Shape=None)
                    df_050_059_CUB_SI2_G  = df_050_059_CUB_SI2_G.assign(Carat=None)
                    df_050_059_CUB_SI2_G  = df_050_059_CUB_SI2_G.assign(Color=None)
                    df_050_059_CUB_SI2_G  = df_050_059_CUB_SI2_G.assign(Clarity=None)
                    df_050_059_CUB_SI2_G  = df_050_059_CUB_SI2_G.assign(Cut=None)
                    df_050_059_CUB_SI2_G  = df_050_059_CUB_SI2_G.assign(Polish=None)
                    df_050_059_CUB_SI2_G  = df_050_059_CUB_SI2_G.assign(Symmetry=None)
                    df_050_059_CUB_SI2_G  = df_050_059_CUB_SI2_G.assign(Ratio=None)
                    df_050_059_CUB_SI2_G  = df_050_059_CUB_SI2_G.assign(PPC=None)
                    df_050_059_CUB_SI2_G  = df_050_059_CUB_SI2_G.assign(Total=None)
                    df_050_059_CUB_SI2_G ['Wt Range'] = listwtrange
                    df_050_059_CUB_SI2_G ['Company'] = listcom
                    df_050_059_CUB_SI2_G ['Shape'] = listshap
                    df_050_059_CUB_SI2_G ['Carat'] = listcar
                    df_050_059_CUB_SI2_G ['Color'] = listcol
                    df_050_059_CUB_SI2_G ['Clarity'] = listclar
                    df_050_059_CUB_SI2_G ['Cut'] = listcut
                    df_050_059_CUB_SI2_G ['Polish'] = listpol
                    df_050_059_CUB_SI2_G ['Symmetry'] = listsym
                    df_050_059_CUB_SI2_G ['Ratio'] = listrat
                    df_050_059_CUB_SI2_G ['PPC'] = listdesc
                    df_050_059_CUB_SI2_G ['Total'] = listtotal
                    df_050_059_CUB_SI2_G['Carat'] = df_050_059_CUB_SI2_G['Carat'].astype('float64')
                    df_050_059_CUB_SI2_G['PPC'] = df_050_059_CUB_SI2_G['PPC'].astype('float64')
                    df_050_059_CUB_SI2_G['Total'] = df_050_059_CUB_SI2_G['Total'].astype('float64')
                    df_050_059_CUB_SI2_G['Total'] = df_050_059_CUB_SI2_G['Carat'] * df_050_059_CUB_SI2_G['PPC']


                elif i=="G" and j == "I1" and k == "CUB":
                    df_050_059_CUB_I1_G = pd.DataFrame()
                    df_050_059_CUB_I1_G ['Wt Range'] = None
                    df_050_059_CUB_I1_G  = df_050_059_CUB_I1_G.assign(Company=None)
                    df_050_059_CUB_I1_G  = df_050_059_CUB_I1_G.assign(Shape=None)
                    df_050_059_CUB_I1_G  = df_050_059_CUB_I1_G.assign(Carat=None)
                    df_050_059_CUB_I1_G  = df_050_059_CUB_I1_G.assign(Color=None)
                    df_050_059_CUB_I1_G  = df_050_059_CUB_I1_G.assign(Clarity=None)
                    df_050_059_CUB_I1_G  = df_050_059_CUB_I1_G.assign(Cut=None)
                    df_050_059_CUB_I1_G  = df_050_059_CUB_I1_G.assign(Polish=None)
                    df_050_059_CUB_I1_G  = df_050_059_CUB_I1_G.assign(Symmetry=None)
                    df_050_059_CUB_I1_G  = df_050_059_CUB_I1_G.assign(Ratio=None)
                    df_050_059_CUB_I1_G  = df_050_059_CUB_I1_G.assign(PPC=None)
                    df_050_059_CUB_I1_G  = df_050_059_CUB_I1_G.assign(Total=None)
                    df_050_059_CUB_I1_G ['Wt Range'] = listwtrange
                    df_050_059_CUB_I1_G ['Company'] = listcom
                    df_050_059_CUB_I1_G ['Shape'] = listshap
                    df_050_059_CUB_I1_G ['Carat'] = listcar
                    df_050_059_CUB_I1_G ['Color'] = listcol
                    df_050_059_CUB_I1_G ['Clarity'] = listclar
                    df_050_059_CUB_I1_G ['Cut'] = listcut
                    df_050_059_CUB_I1_G ['Polish'] = listpol
                    df_050_059_CUB_I1_G ['Symmetry'] = listsym
                    df_050_059_CUB_I1_G ['Ratio'] = listrat
                    df_050_059_CUB_I1_G ['PPC'] = listdesc
                    df_050_059_CUB_I1_G ['Total'] = listtotal
                    df_050_059_CUB_I1_G['Carat'] = df_050_059_CUB_I1_G['Carat'].astype('float64')
                    df_050_059_CUB_I1_G['PPC'] = df_050_059_CUB_I1_G['PPC'].astype('float64')
                    df_050_059_CUB_I1_G['Total'] = df_050_059_CUB_I1_G['Total'].astype('float64')
                    df_050_059_CUB_I1_G['Total'] = df_050_059_CUB_I1_G['Carat'] * df_050_059_CUB_I1_G['PPC']


                elif i=="G" and j == "I2" and k == "CUB":
                    df_050_059_CUB_I2_G = pd.DataFrame()
                    df_050_059_CUB_I2_G ['Wt Range'] = None
                    df_050_059_CUB_I2_G  = df_050_059_CUB_I2_G.assign(Company=None)
                    df_050_059_CUB_I2_G  = df_050_059_CUB_I2_G.assign(Shape=None)
                    df_050_059_CUB_I2_G  = df_050_059_CUB_I2_G.assign(Carat=None)
                    df_050_059_CUB_I2_G  = df_050_059_CUB_I2_G.assign(Color=None)
                    df_050_059_CUB_I2_G  = df_050_059_CUB_I2_G.assign(Clarity=None)
                    df_050_059_CUB_I2_G  = df_050_059_CUB_I2_G.assign(Cut=None)
                    df_050_059_CUB_I2_G  = df_050_059_CUB_I2_G.assign(Polish=None)
                    df_050_059_CUB_I2_G  = df_050_059_CUB_I2_G.assign(Symmetry=None)
                    df_050_059_CUB_I2_G  = df_050_059_CUB_I2_G.assign(Ratio=None)
                    df_050_059_CUB_I2_G  = df_050_059_CUB_I2_G.assign(PPC=None)
                    df_050_059_CUB_I2_G  = df_050_059_CUB_I2_G.assign(Total=None)
                    df_050_059_CUB_I2_G ['Wt Range'] = listwtrange
                    df_050_059_CUB_I2_G ['Company'] = listcom
                    df_050_059_CUB_I2_G ['Shape'] = listshap
                    df_050_059_CUB_I2_G ['Carat'] = listcar
                    df_050_059_CUB_I2_G ['Color'] = listcol
                    df_050_059_CUB_I2_G ['Clarity'] = listclar
                    df_050_059_CUB_I2_G ['Cut'] = listcut
                    df_050_059_CUB_I2_G ['Polish'] = listpol
                    df_050_059_CUB_I2_G ['Symmetry'] = listsym
                    df_050_059_CUB_I2_G ['Ratio'] = listrat
                    df_050_059_CUB_I2_G ['PPC'] = listdesc
                    df_050_059_CUB_I2_G ['Total'] = listtotal
                    df_050_059_CUB_I2_G['Carat'] = df_050_059_CUB_I2_G['Carat'].astype('float64')
                    df_050_059_CUB_I2_G['PPC'] = df_050_059_CUB_I2_G['PPC'].astype('float64')
                    df_050_059_CUB_I2_G['Total'] = df_050_059_CUB_I2_G['Total'].astype('float64')
                    df_050_059_CUB_I2_G['Total'] = df_050_059_CUB_I2_G['Carat'] * df_050_059_CUB_I2_G['PPC']


                elif i=="H" and j == "IF" and k == "CUB":
                    df_050_059_CUB_IF_H = pd.DataFrame()
                    df_050_059_CUB_IF_H ['Wt Range'] = None
                    df_050_059_CUB_IF_H  = df_050_059_CUB_IF_H.assign(Company=None)
                    df_050_059_CUB_IF_H  = df_050_059_CUB_IF_H.assign(Shape=None)
                    df_050_059_CUB_IF_H  = df_050_059_CUB_IF_H.assign(Carat=None)
                    df_050_059_CUB_IF_H  = df_050_059_CUB_IF_H.assign(Color=None)
                    df_050_059_CUB_IF_H  = df_050_059_CUB_IF_H.assign(Clarity=None)
                    df_050_059_CUB_IF_H  = df_050_059_CUB_IF_H.assign(Cut=None)
                    df_050_059_CUB_IF_H  = df_050_059_CUB_IF_H.assign(Polish=None)
                    df_050_059_CUB_IF_H  = df_050_059_CUB_IF_H.assign(Symmetry=None)
                    df_050_059_CUB_IF_H  = df_050_059_CUB_IF_H.assign(Ratio=None)
                    df_050_059_CUB_IF_H  = df_050_059_CUB_IF_H.assign(PPC=None)
                    df_050_059_CUB_IF_H  = df_050_059_CUB_IF_H.assign(Total=None)
                    df_050_059_CUB_IF_H ['Wt Range'] = listwtrange
                    df_050_059_CUB_IF_H ['Company'] = listcom
                    df_050_059_CUB_IF_H ['Shape'] = listshap
                    df_050_059_CUB_IF_H ['Carat'] = listcar
                    df_050_059_CUB_IF_H ['Color'] = listcol
                    df_050_059_CUB_IF_H ['Clarity'] = listclar
                    df_050_059_CUB_IF_H ['Cut'] = listcut
                    df_050_059_CUB_IF_H ['Polish'] = listpol
                    df_050_059_CUB_IF_H ['Symmetry'] = listsym
                    df_050_059_CUB_IF_H ['Ratio'] = listrat
                    df_050_059_CUB_IF_H ['PPC'] = listdesc
                    df_050_059_CUB_IF_H ['Total'] = listtotal
                    df_050_059_CUB_IF_H['Carat'] = df_050_059_CUB_IF_H['Carat'].astype('float64')
                    df_050_059_CUB_IF_H['PPC'] = df_050_059_CUB_IF_H['PPC'].astype('float64')
                    df_050_059_CUB_IF_H['Total'] = df_050_059_CUB_IF_H['Total'].astype('float64')
                    df_050_059_CUB_IF_H['Total'] = df_050_059_CUB_IF_H['Carat'] * df_050_059_CUB_IF_H['PPC']



                elif i=="H" and j == "VVS1" and k == "CUB":
                    df_050_059_CUB_VVS1_H = pd.DataFrame()
                    df_050_059_CUB_VVS1_H ['Wt Range'] = None
                    df_050_059_CUB_VVS1_H  = df_050_059_CUB_VVS1_H.assign(Company=None)
                    df_050_059_CUB_VVS1_H  = df_050_059_CUB_VVS1_H.assign(Shape=None)
                    df_050_059_CUB_VVS1_H  = df_050_059_CUB_VVS1_H.assign(Carat=None)
                    df_050_059_CUB_VVS1_H  = df_050_059_CUB_VVS1_H.assign(Color=None)
                    df_050_059_CUB_VVS1_H  = df_050_059_CUB_VVS1_H.assign(Clarity=None)
                    df_050_059_CUB_VVS1_H  = df_050_059_CUB_VVS1_H.assign(Cut=None)
                    df_050_059_CUB_VVS1_H  = df_050_059_CUB_VVS1_H.assign(Polish=None)
                    df_050_059_CUB_VVS1_H  = df_050_059_CUB_VVS1_H.assign(Symmetry=None)
                    df_050_059_CUB_VVS1_H  = df_050_059_CUB_VVS1_H.assign(Ratio=None)
                    df_050_059_CUB_VVS1_H  = df_050_059_CUB_VVS1_H.assign(PPC=None)
                    df_050_059_CUB_VVS1_H  = df_050_059_CUB_VVS1_H.assign(Total=None)
                    df_050_059_CUB_VVS1_H ['Wt Range'] = listwtrange
                    df_050_059_CUB_VVS1_H ['Company'] = listcom
                    df_050_059_CUB_VVS1_H ['Shape'] = listshap
                    df_050_059_CUB_VVS1_H ['Carat'] = listcar
                    df_050_059_CUB_VVS1_H ['Color'] = listcol
                    df_050_059_CUB_VVS1_H ['Clarity'] = listclar
                    df_050_059_CUB_VVS1_H ['Cut'] = listcut
                    df_050_059_CUB_VVS1_H ['Polish'] = listpol
                    df_050_059_CUB_VVS1_H ['Symmetry'] = listsym
                    df_050_059_CUB_VVS1_H ['Ratio'] = listrat
                    df_050_059_CUB_VVS1_H ['PPC'] = listdesc
                    df_050_059_CUB_VVS1_H ['Total'] = listtotal
                    df_050_059_CUB_VVS1_H['Carat'] = df_050_059_CUB_VVS1_H['Carat'].astype('float64')
                    df_050_059_CUB_VVS1_H['PPC'] = df_050_059_CUB_VVS1_H['PPC'].astype('float64')
                    df_050_059_CUB_VVS1_H['Total'] = df_050_059_CUB_VVS1_H['Total'].astype('float64')
                    df_050_059_CUB_VVS1_H['Total'] = df_050_059_CUB_VVS1_H['Carat'] * df_050_059_CUB_VVS1_H['PPC']


                elif i=="H" and j == "VVS2" and k == "CUB":
                    df_050_059_CUB_VVS2_H = pd.DataFrame()
                    df_050_059_CUB_VVS2_H ['Wt Range'] = None
                    df_050_059_CUB_VVS2_H  = df_050_059_CUB_VVS2_H.assign(Company=None)
                    df_050_059_CUB_VVS2_H  = df_050_059_CUB_VVS2_H.assign(Shape=None)
                    df_050_059_CUB_VVS2_H  = df_050_059_CUB_VVS2_H.assign(Carat=None)
                    df_050_059_CUB_VVS2_H  = df_050_059_CUB_VVS2_H.assign(Color=None)
                    df_050_059_CUB_VVS2_H  = df_050_059_CUB_VVS2_H.assign(Clarity=None)
                    df_050_059_CUB_VVS2_H  = df_050_059_CUB_VVS2_H.assign(Cut=None)
                    df_050_059_CUB_VVS2_H  = df_050_059_CUB_VVS2_H.assign(Polish=None)
                    df_050_059_CUB_VVS2_H  = df_050_059_CUB_VVS2_H.assign(Symmetry=None)
                    df_050_059_CUB_VVS2_H  = df_050_059_CUB_VVS2_H.assign(Ratio=None)
                    df_050_059_CUB_VVS2_H  = df_050_059_CUB_VVS2_H.assign(PPC=None)
                    df_050_059_CUB_VVS2_H  = df_050_059_CUB_VVS2_H.assign(Total=None)
                    df_050_059_CUB_VVS2_H ['Wt Range'] = listwtrange
                    df_050_059_CUB_VVS2_H ['Company'] = listcom
                    df_050_059_CUB_VVS2_H ['Shape'] = listshap
                    df_050_059_CUB_VVS2_H ['Carat'] = listcar
                    df_050_059_CUB_VVS2_H ['Color'] = listcol
                    df_050_059_CUB_VVS2_H ['Clarity'] = listclar
                    df_050_059_CUB_VVS2_H ['Cut'] = listcut
                    df_050_059_CUB_VVS2_H ['Polish'] = listpol
                    df_050_059_CUB_VVS2_H ['Symmetry'] = listsym
                    df_050_059_CUB_VVS2_H ['Ratio'] = listrat
                    df_050_059_CUB_VVS2_H ['PPC'] = listdesc
                    df_050_059_CUB_VVS2_H ['Total'] = listtotal
                    df_050_059_CUB_VVS2_H['Carat'] = df_050_059_CUB_VVS2_H['Carat'].astype('float64')
                    df_050_059_CUB_VVS2_H['PPC'] = df_050_059_CUB_VVS2_H['PPC'].astype('float64')
                    df_050_059_CUB_VVS2_H['Total'] = df_050_059_CUB_VVS2_H['Total'].astype('float64')
                    df_050_059_CUB_VVS2_H['Total'] = df_050_059_CUB_VVS2_H['Carat'] * df_050_059_CUB_VVS2_H['PPC']


                elif i=="H" and j=="VS1" and k == "CUB":
                    df_050_059_CUB_VS1_H = pd.DataFrame()
                    df_050_059_CUB_VS1_H ['Wt Range'] = None
                    df_050_059_CUB_VS1_H  = df_050_059_CUB_VS1_H.assign(Company=None)
                    df_050_059_CUB_VS1_H  = df_050_059_CUB_VS1_H.assign(Shape=None)
                    df_050_059_CUB_VS1_H  = df_050_059_CUB_VS1_H.assign(Carat=None)
                    df_050_059_CUB_VS1_H  = df_050_059_CUB_VS1_H.assign(Color=None)
                    df_050_059_CUB_VS1_H  = df_050_059_CUB_VS1_H.assign(Clarity=None)
                    df_050_059_CUB_VS1_H  = df_050_059_CUB_VS1_H.assign(Cut=None)
                    df_050_059_CUB_VS1_H  = df_050_059_CUB_VS1_H.assign(Polish=None)
                    df_050_059_CUB_VS1_H  = df_050_059_CUB_VS1_H.assign(Symmetry=None)
                    df_050_059_CUB_VS1_H  = df_050_059_CUB_VS1_H.assign(Ratio=None)
                    df_050_059_CUB_VS1_H  = df_050_059_CUB_VS1_H.assign(PPC=None)
                    df_050_059_CUB_VS1_H  = df_050_059_CUB_VS1_H.assign(Total=None)
                    df_050_059_CUB_VS1_H ['Wt Range'] = listwtrange
                    df_050_059_CUB_VS1_H ['Company'] = listcom
                    df_050_059_CUB_VS1_H ['Shape'] = listshap
                    df_050_059_CUB_VS1_H ['Carat'] = listcar
                    df_050_059_CUB_VS1_H ['Color'] = listcol
                    df_050_059_CUB_VS1_H ['Clarity'] = listclar
                    df_050_059_CUB_VS1_H ['Cut'] = listcut
                    df_050_059_CUB_VS1_H ['Polish'] = listpol
                    df_050_059_CUB_VS1_H ['Symmetry'] = listsym
                    df_050_059_CUB_VS1_H ['Ratio'] = listrat
                    df_050_059_CUB_VS1_H ['PPC'] = listdesc
                    df_050_059_CUB_VS1_H ['Total'] = listtotal
                    df_050_059_CUB_VS1_H['Carat'] = df_050_059_CUB_VS1_H['Carat'].astype('float64')
                    df_050_059_CUB_VS1_H['PPC'] = df_050_059_CUB_VS1_H['PPC'].astype('float64')
                    df_050_059_CUB_VS1_H['Total'] = df_050_059_CUB_VS1_H['Total'].astype('float64')
                    df_050_059_CUB_VS1_H['Total'] = df_050_059_CUB_VS1_H['Carat'] * df_050_059_CUB_VS1_H['PPC']


                elif i=="H" and j == "VS2" and k == "CUB":
                    df_050_059_CUB_VS2_H = pd.DataFrame()
                    df_050_059_CUB_VS2_H ['Wt Range'] = None
                    df_050_059_CUB_VS2_H  = df_050_059_CUB_VS2_H.assign(Company=None)
                    df_050_059_CUB_VS2_H  = df_050_059_CUB_VS2_H.assign(Shape=None)
                    df_050_059_CUB_VS2_H  = df_050_059_CUB_VS2_H.assign(Carat=None)
                    df_050_059_CUB_VS2_H  = df_050_059_CUB_VS2_H.assign(Color=None)
                    df_050_059_CUB_VS2_H  = df_050_059_CUB_VS2_H.assign(Clarity=None)
                    df_050_059_CUB_VS2_H  = df_050_059_CUB_VS2_H.assign(Cut=None)
                    df_050_059_CUB_VS2_H  = df_050_059_CUB_VS2_H.assign(Polish=None)
                    df_050_059_CUB_VS2_H  = df_050_059_CUB_VS2_H.assign(Symmetry=None)
                    df_050_059_CUB_VS2_H  = df_050_059_CUB_VS2_H.assign(Ratio=None)
                    df_050_059_CUB_VS2_H  = df_050_059_CUB_VS2_H.assign(PPC=None)
                    df_050_059_CUB_VS2_H  = df_050_059_CUB_VS2_H.assign(Total=None)
                    df_050_059_CUB_VS2_H ['Wt Range'] = listwtrange
                    df_050_059_CUB_VS2_H ['Company'] = listcom
                    df_050_059_CUB_VS2_H ['Shape'] = listshap
                    df_050_059_CUB_VS2_H ['Carat'] = listcar
                    df_050_059_CUB_VS2_H ['Color'] = listcol
                    df_050_059_CUB_VS2_H ['Clarity'] = listclar
                    df_050_059_CUB_VS2_H ['Cut'] = listcut
                    df_050_059_CUB_VS2_H ['Polish'] = listpol
                    df_050_059_CUB_VS2_H ['Symmetry'] = listsym
                    df_050_059_CUB_VS2_H ['Ratio'] = listrat
                    df_050_059_CUB_VS2_H ['PPC'] = listdesc
                    df_050_059_CUB_VS2_H ['Total'] = listtotal
                    df_050_059_CUB_VS2_H['Carat'] = df_050_059_CUB_VS2_H['Carat'].astype('float64')
                    df_050_059_CUB_VS2_H['PPC'] = df_050_059_CUB_VS2_H['PPC'].astype('float64')
                    df_050_059_CUB_VS2_H['Total'] = df_050_059_CUB_VS2_H['Total'].astype('float64')
                    df_050_059_CUB_VS2_H['Total'] = df_050_059_CUB_VS2_H['Carat'] * df_050_059_CUB_VS2_H['PPC']


                elif i=="H" and j == "SI1" and k == "CUB":
                    df_050_059_CUB_SI1_H = pd.DataFrame()
                    df_050_059_CUB_SI1_H ['Wt Range'] = None
                    df_050_059_CUB_SI1_H  = df_050_059_CUB_SI1_H.assign(Company=None)
                    df_050_059_CUB_SI1_H  = df_050_059_CUB_SI1_H.assign(Shape=None)
                    df_050_059_CUB_SI1_H  = df_050_059_CUB_SI1_H.assign(Carat=None)
                    df_050_059_CUB_SI1_H  = df_050_059_CUB_SI1_H.assign(Color=None)
                    df_050_059_CUB_SI1_H  = df_050_059_CUB_SI1_H.assign(Clarity=None)
                    df_050_059_CUB_SI1_H  = df_050_059_CUB_SI1_H.assign(Cut=None)
                    df_050_059_CUB_SI1_H  = df_050_059_CUB_SI1_H.assign(Polish=None)
                    df_050_059_CUB_SI1_H  = df_050_059_CUB_SI1_H.assign(Symmetry=None)
                    df_050_059_CUB_SI1_H  = df_050_059_CUB_SI1_H.assign(Ratio=None)
                    df_050_059_CUB_SI1_H  = df_050_059_CUB_SI1_H.assign(PPC=None)
                    df_050_059_CUB_SI1_H  = df_050_059_CUB_SI1_H.assign(Total=None)
                    df_050_059_CUB_SI1_H ['Wt Range'] = listwtrange
                    df_050_059_CUB_SI1_H ['Company'] = listcom
                    df_050_059_CUB_SI1_H ['Shape'] = listshap
                    df_050_059_CUB_SI1_H ['Carat'] = listcar
                    df_050_059_CUB_SI1_H ['Color'] = listcol
                    df_050_059_CUB_SI1_H ['Clarity'] = listclar
                    df_050_059_CUB_SI1_H ['Cut'] = listcut
                    df_050_059_CUB_SI1_H ['Polish'] = listpol
                    df_050_059_CUB_SI1_H ['Symmetry'] = listsym
                    df_050_059_CUB_SI1_H ['Ratio'] = listrat
                    df_050_059_CUB_SI1_H ['PPC'] = listdesc
                    df_050_059_CUB_SI1_H ['Total'] = listtotal
                    df_050_059_CUB_SI1_H['Carat'] = df_050_059_CUB_SI1_H['Carat'].astype('float64')
                    df_050_059_CUB_SI1_H['PPC'] = df_050_059_CUB_SI1_H['PPC'].astype('float64')
                    df_050_059_CUB_SI1_H['Total'] = df_050_059_CUB_SI1_H['Total'].astype('float64')
                    df_050_059_CUB_SI1_H['Total'] = df_050_059_CUB_SI1_H['Carat'] * df_050_059_CUB_SI1_H['PPC']


                elif i=="H" and j == "SI2" and k == "CUB":
                    df_050_059_CUB_SI2_H = pd.DataFrame()
                    df_050_059_CUB_SI2_H ['Wt Range'] = None
                    df_050_059_CUB_SI2_H  = df_050_059_CUB_SI2_H.assign(Company=None)
                    df_050_059_CUB_SI2_H  = df_050_059_CUB_SI2_H.assign(Shape=None)
                    df_050_059_CUB_SI2_H  = df_050_059_CUB_SI2_H.assign(Carat=None)
                    df_050_059_CUB_SI2_H  = df_050_059_CUB_SI2_H.assign(Color=None)
                    df_050_059_CUB_SI2_H  = df_050_059_CUB_SI2_H.assign(Clarity=None)
                    df_050_059_CUB_SI2_H  = df_050_059_CUB_SI2_H.assign(Cut=None)
                    df_050_059_CUB_SI2_H  = df_050_059_CUB_SI2_H.assign(Polish=None)
                    df_050_059_CUB_SI2_H  = df_050_059_CUB_SI2_H.assign(Symmetry=None)
                    df_050_059_CUB_SI2_H  = df_050_059_CUB_SI2_H.assign(Ratio=None)
                    df_050_059_CUB_SI2_H  = df_050_059_CUB_SI2_H.assign(PPC=None)
                    df_050_059_CUB_SI2_H  = df_050_059_CUB_SI2_H.assign(Total=None)
                    df_050_059_CUB_SI2_H ['Wt Range'] = listwtrange
                    df_050_059_CUB_SI2_H ['Company'] = listcom
                    df_050_059_CUB_SI2_H ['Shape'] = listshap
                    df_050_059_CUB_SI2_H ['Carat'] = listcar
                    df_050_059_CUB_SI2_H ['Color'] = listcol
                    df_050_059_CUB_SI2_H ['Clarity'] = listclar
                    df_050_059_CUB_SI2_H ['Cut'] = listcut
                    df_050_059_CUB_SI2_H ['Polish'] = listpol
                    df_050_059_CUB_SI2_H ['Symmetry'] = listsym
                    df_050_059_CUB_SI2_H ['Ratio'] = listrat
                    df_050_059_CUB_SI2_H ['PPC'] = listdesc
                    df_050_059_CUB_SI2_H ['Total'] = listtotal
                    df_050_059_CUB_SI2_H['Carat'] = df_050_059_CUB_SI2_H['Carat'].astype('float64')
                    df_050_059_CUB_SI2_H['PPC'] = df_050_059_CUB_SI2_H['PPC'].astype('float64')
                    df_050_059_CUB_SI2_H['Total'] = df_050_059_CUB_SI2_H['Total'].astype('float64')
                    df_050_059_CUB_SI2_H['Total'] = df_050_059_CUB_SI2_H['Carat'] * df_050_059_CUB_SI2_H['PPC']


                elif i=="H" and j == "I1" and k == "CUB":
                    df_050_059_CUB_I1_H = pd.DataFrame()
                    df_050_059_CUB_I1_H ['Wt Range'] = None
                    df_050_059_CUB_I1_H  = df_050_059_CUB_I1_H.assign(Company=None)
                    df_050_059_CUB_I1_H  = df_050_059_CUB_I1_H.assign(Shape=None)
                    df_050_059_CUB_I1_H  = df_050_059_CUB_I1_H.assign(Carat=None)
                    df_050_059_CUB_I1_H  = df_050_059_CUB_I1_H.assign(Color=None)
                    df_050_059_CUB_I1_H  = df_050_059_CUB_I1_H.assign(Clarity=None)
                    df_050_059_CUB_I1_H  = df_050_059_CUB_I1_H.assign(Cut=None)
                    df_050_059_CUB_I1_H  = df_050_059_CUB_I1_H.assign(Polish=None)
                    df_050_059_CUB_I1_H  = df_050_059_CUB_I1_H.assign(Symmetry=None)
                    df_050_059_CUB_I1_H  = df_050_059_CUB_I1_H.assign(Ratio=None)
                    df_050_059_CUB_I1_H  = df_050_059_CUB_I1_H.assign(PPC=None)
                    df_050_059_CUB_I1_H  = df_050_059_CUB_I1_H.assign(Total=None)
                    df_050_059_CUB_I1_H ['Wt Range'] = listwtrange
                    df_050_059_CUB_I1_H ['Company'] = listcom
                    df_050_059_CUB_I1_H ['Shape'] = listshap
                    df_050_059_CUB_I1_H ['Carat'] = listcar
                    df_050_059_CUB_I1_H ['Color'] = listcol
                    df_050_059_CUB_I1_H ['Clarity'] = listclar
                    df_050_059_CUB_I1_H ['Cut'] = listcut
                    df_050_059_CUB_I1_H ['Polish'] = listpol
                    df_050_059_CUB_I1_H ['Symmetry'] = listsym
                    df_050_059_CUB_I1_H ['Ratio'] = listrat
                    df_050_059_CUB_I1_H ['PPC'] = listdesc
                    df_050_059_CUB_I1_H ['Total'] = listtotal
                    df_050_059_CUB_I1_H['Carat'] = df_050_059_CUB_I1_H['Carat'].astype('float64')
                    df_050_059_CUB_I1_H['PPC'] = df_050_059_CUB_I1_H['PPC'].astype('float64')
                    df_050_059_CUB_I1_H['Total'] = df_050_059_CUB_I1_H['Total'].astype('float64')
                    df_050_059_CUB_I1_H['Total'] = df_050_059_CUB_I1_H['Carat'] * df_050_059_CUB_I1_H['PPC']


                elif i=="H" and j == "I2" and k == "CUB":
                    df_050_059_CUB_I2_H = pd.DataFrame()
                    df_050_059_CUB_I2_H ['Wt Range'] = None
                    df_050_059_CUB_I2_H  = df_050_059_CUB_I2_H.assign(Company=None)
                    df_050_059_CUB_I2_H  = df_050_059_CUB_I2_H.assign(Shape=None)
                    df_050_059_CUB_I2_H  = df_050_059_CUB_I2_H.assign(Carat=None)
                    df_050_059_CUB_I2_H  = df_050_059_CUB_I2_H.assign(Color=None)
                    df_050_059_CUB_I2_H  = df_050_059_CUB_I2_H.assign(Clarity=None)
                    df_050_059_CUB_I2_H  = df_050_059_CUB_I2_H.assign(Cut=None)
                    df_050_059_CUB_I2_H  = df_050_059_CUB_I2_H.assign(Polish=None)
                    df_050_059_CUB_I2_H  = df_050_059_CUB_I2_H.assign(Symmetry=None)
                    df_050_059_CUB_I2_H  = df_050_059_CUB_I2_H.assign(Ratio=None)
                    df_050_059_CUB_I2_H  = df_050_059_CUB_I2_H.assign(PPC=None)
                    df_050_059_CUB_I2_H  = df_050_059_CUB_I2_H.assign(Total=None)
                    df_050_059_CUB_I2_H ['Wt Range'] = listwtrange
                    df_050_059_CUB_I2_H ['Company'] = listcom
                    df_050_059_CUB_I2_H ['Shape'] = listshap
                    df_050_059_CUB_I2_H ['Carat'] = listcar
                    df_050_059_CUB_I2_H ['Color'] = listcol
                    df_050_059_CUB_I2_H ['Clarity'] = listclar
                    df_050_059_CUB_I2_H ['Cut'] = listcut
                    df_050_059_CUB_I2_H ['Polish'] = listpol
                    df_050_059_CUB_I2_H ['Symmetry'] = listsym
                    df_050_059_CUB_I2_H ['Ratio'] = listrat
                    df_050_059_CUB_I2_H ['PPC'] = listdesc
                    df_050_059_CUB_I2_H ['Total'] = listtotal
                    df_050_059_CUB_I2_H['Carat'] = df_050_059_CUB_I2_H['Carat'].astype('float64')
                    df_050_059_CUB_I2_H['PPC'] = df_050_059_CUB_I2_H['PPC'].astype('float64')
                    df_050_059_CUB_I2_H['Total'] = df_050_059_CUB_I2_H['Total'].astype('float64')
                    df_050_059_CUB_I2_H['Total'] = df_050_059_CUB_I2_H['Carat'] * df_050_059_CUB_I2_H['PPC']



                elif i== "I" and j == "IF" and k == "CUB":
                    df_050_059_CUB_IF_I = pd.DataFrame()
                    df_050_059_CUB_IF_I ['Wt Range'] = None
                    df_050_059_CUB_IF_I  = df_050_059_CUB_IF_I.assign(Company=None)
                    df_050_059_CUB_IF_I  = df_050_059_CUB_IF_I.assign(Shape=None)
                    df_050_059_CUB_IF_I  = df_050_059_CUB_IF_I.assign(Carat=None)
                    df_050_059_CUB_IF_I  = df_050_059_CUB_IF_I.assign(Color=None)
                    df_050_059_CUB_IF_I  = df_050_059_CUB_IF_I.assign(Clarity=None)
                    df_050_059_CUB_IF_I  = df_050_059_CUB_IF_I.assign(Cut=None)
                    df_050_059_CUB_IF_I  = df_050_059_CUB_IF_I.assign(Polish=None)
                    df_050_059_CUB_IF_I  = df_050_059_CUB_IF_I.assign(Symmetry=None)
                    df_050_059_CUB_IF_I  = df_050_059_CUB_IF_I.assign(Ratio=None)
                    df_050_059_CUB_IF_I  = df_050_059_CUB_IF_I.assign(PPC=None)
                    df_050_059_CUB_IF_I  = df_050_059_CUB_IF_I.assign(Total=None)
                    df_050_059_CUB_IF_I ['Wt Range'] = listwtrange
                    df_050_059_CUB_IF_I ['Company'] = listcom
                    df_050_059_CUB_IF_I ['Shape'] = listshap
                    df_050_059_CUB_IF_I ['Carat'] = listcar
                    df_050_059_CUB_IF_I ['Color'] = listcol
                    df_050_059_CUB_IF_I ['Clarity'] = listclar
                    df_050_059_CUB_IF_I ['Cut'] = listcut
                    df_050_059_CUB_IF_I ['Polish'] = listpol
                    df_050_059_CUB_IF_I ['Symmetry'] = listsym
                    df_050_059_CUB_IF_I ['Ratio'] = listrat
                    df_050_059_CUB_IF_I ['PPC'] = listdesc
                    df_050_059_CUB_IF_I ['Total'] = listtotal
                    df_050_059_CUB_IF_I['Carat'] = df_050_059_CUB_IF_I['Carat'].astype('float64')
                    df_050_059_CUB_IF_I['PPC'] = df_050_059_CUB_IF_I['PPC'].astype('float64')
                    df_050_059_CUB_IF_I['Total'] = df_050_059_CUB_IF_I['Total'].astype('float64')
                    df_050_059_CUB_IF_I['Total'] = df_050_059_CUB_IF_I['Carat'] * df_050_059_CUB_IF_I['PPC']



                elif i== "I" and j == "VVS1" and k == "CUB":
                    df_050_059_CUB_VVS1_I = pd.DataFrame()
                    df_050_059_CUB_VVS1_I ['Wt Range'] = None
                    df_050_059_CUB_VVS1_I  = df_050_059_CUB_VVS1_I.assign(Company=None)
                    df_050_059_CUB_VVS1_I  = df_050_059_CUB_VVS1_I.assign(Shape=None)
                    df_050_059_CUB_VVS1_I  = df_050_059_CUB_VVS1_I.assign(Carat=None)
                    df_050_059_CUB_VVS1_I  = df_050_059_CUB_VVS1_I.assign(Color=None)
                    df_050_059_CUB_VVS1_I  = df_050_059_CUB_VVS1_I.assign(Clarity=None)
                    df_050_059_CUB_VVS1_I  = df_050_059_CUB_VVS1_I.assign(Cut=None)
                    df_050_059_CUB_VVS1_I  = df_050_059_CUB_VVS1_I.assign(Polish=None)
                    df_050_059_CUB_VVS1_I  = df_050_059_CUB_VVS1_I.assign(Symmetry=None)
                    df_050_059_CUB_VVS1_I  = df_050_059_CUB_VVS1_I.assign(Ratio=None)
                    df_050_059_CUB_VVS1_I  = df_050_059_CUB_VVS1_I.assign(PPC=None)
                    df_050_059_CUB_VVS1_I  = df_050_059_CUB_VVS1_I.assign(Total=None)
                    df_050_059_CUB_VVS1_I ['Wt Range'] = listwtrange
                    df_050_059_CUB_VVS1_I ['Company'] = listcom
                    df_050_059_CUB_VVS1_I ['Shape'] = listshap
                    df_050_059_CUB_VVS1_I ['Carat'] = listcar
                    df_050_059_CUB_VVS1_I ['Color'] = listcol
                    df_050_059_CUB_VVS1_I ['Clarity'] = listclar
                    df_050_059_CUB_VVS1_I ['Cut'] = listcut
                    df_050_059_CUB_VVS1_I ['Polish'] = listpol
                    df_050_059_CUB_VVS1_I ['Symmetry'] = listsym
                    df_050_059_CUB_VVS1_I ['Ratio'] = listrat
                    df_050_059_CUB_VVS1_I ['PPC'] = listdesc
                    df_050_059_CUB_VVS1_I ['Total'] = listtotal
                    df_050_059_CUB_VVS1_I['Carat'] = df_050_059_CUB_VVS1_I['Carat'].astype('float64')
                    df_050_059_CUB_VVS1_I['PPC'] = df_050_059_CUB_VVS1_I['PPC'].astype('float64')
                    df_050_059_CUB_VVS1_I['Total'] = df_050_059_CUB_VVS1_I['Total'].astype('float64')
                    df_050_059_CUB_VVS1_I['Total'] = df_050_059_CUB_VVS1_I['Carat'] * df_050_059_CUB_VVS1_I['PPC']


                elif i== "I" and j == "VVS2" and k == "CUB":
                    df_050_059_CUB_VVS2_I = pd.DataFrame()
                    df_050_059_CUB_VVS2_I ['Wt Range'] = None
                    df_050_059_CUB_VVS2_I  = df_050_059_CUB_VVS2_I.assign(Company=None)
                    df_050_059_CUB_VVS2_I  = df_050_059_CUB_VVS2_I.assign(Shape=None)
                    df_050_059_CUB_VVS2_I  = df_050_059_CUB_VVS2_I.assign(Carat=None)
                    df_050_059_CUB_VVS2_I  = df_050_059_CUB_VVS2_I.assign(Color=None)
                    df_050_059_CUB_VVS2_I  = df_050_059_CUB_VVS2_I.assign(Clarity=None)
                    df_050_059_CUB_VVS2_I  = df_050_059_CUB_VVS2_I.assign(Cut=None)
                    df_050_059_CUB_VVS2_I  = df_050_059_CUB_VVS2_I.assign(Polish=None)
                    df_050_059_CUB_VVS2_I  = df_050_059_CUB_VVS2_I.assign(Symmetry=None)
                    df_050_059_CUB_VVS2_I  = df_050_059_CUB_VVS2_I.assign(Ratio=None)
                    df_050_059_CUB_VVS2_I  = df_050_059_CUB_VVS2_I.assign(PPC=None)
                    df_050_059_CUB_VVS2_I  = df_050_059_CUB_VVS2_I.assign(Total=None)
                    df_050_059_CUB_VVS2_I ['Wt Range'] = listwtrange
                    df_050_059_CUB_VVS2_I ['Company'] = listcom
                    df_050_059_CUB_VVS2_I ['Shape'] = listshap
                    df_050_059_CUB_VVS2_I ['Carat'] = listcar
                    df_050_059_CUB_VVS2_I ['Color'] = listcol
                    df_050_059_CUB_VVS2_I ['Clarity'] = listclar
                    df_050_059_CUB_VVS2_I ['Cut'] = listcut
                    df_050_059_CUB_VVS2_I ['Polish'] = listpol
                    df_050_059_CUB_VVS2_I ['Symmetry'] = listsym
                    df_050_059_CUB_VVS2_I ['Ratio'] = listrat
                    df_050_059_CUB_VVS2_I ['PPC'] = listdesc
                    df_050_059_CUB_VVS2_I ['Total'] = listtotal
                    df_050_059_CUB_VVS2_I['Carat'] = df_050_059_CUB_VVS2_I['Carat'].astype('float64')
                    df_050_059_CUB_VVS2_I['PPC'] = df_050_059_CUB_VVS2_I['PPC'].astype('float64')
                    df_050_059_CUB_VVS2_I['Total'] = df_050_059_CUB_VVS2_I['Total'].astype('float64')
                    df_050_059_CUB_VVS2_I['Total'] = df_050_059_CUB_VVS2_I['Carat'] * df_050_059_CUB_VVS2_I['PPC']


                elif i== "I" and j=="VS1" and k == "CUB":
                    df_050_059_CUB_VS1_I = pd.DataFrame()
                    df_050_059_CUB_VS1_I ['Wt Range'] = None
                    df_050_059_CUB_VS1_I  = df_050_059_CUB_VS1_I.assign(Company=None)
                    df_050_059_CUB_VS1_I  = df_050_059_CUB_VS1_I.assign(Shape=None)
                    df_050_059_CUB_VS1_I  = df_050_059_CUB_VS1_I.assign(Carat=None)
                    df_050_059_CUB_VS1_I  = df_050_059_CUB_VS1_I.assign(Color=None)
                    df_050_059_CUB_VS1_I  = df_050_059_CUB_VS1_I.assign(Clarity=None)
                    df_050_059_CUB_VS1_I  = df_050_059_CUB_VS1_I.assign(Cut=None)
                    df_050_059_CUB_VS1_I  = df_050_059_CUB_VS1_I.assign(Polish=None)
                    df_050_059_CUB_VS1_I  = df_050_059_CUB_VS1_I.assign(Symmetry=None)
                    df_050_059_CUB_VS1_I  = df_050_059_CUB_VS1_I.assign(Ratio=None)
                    df_050_059_CUB_VS1_I  = df_050_059_CUB_VS1_I.assign(PPC=None)
                    df_050_059_CUB_VS1_I  = df_050_059_CUB_VS1_I.assign(Total=None)
                    df_050_059_CUB_VS1_I ['Wt Range'] = listwtrange
                    df_050_059_CUB_VS1_I ['Company'] = listcom
                    df_050_059_CUB_VS1_I ['Shape'] = listshap
                    df_050_059_CUB_VS1_I ['Carat'] = listcar
                    df_050_059_CUB_VS1_I ['Color'] = listcol
                    df_050_059_CUB_VS1_I ['Clarity'] = listclar
                    df_050_059_CUB_VS1_I ['Cut'] = listcut
                    df_050_059_CUB_VS1_I ['Polish'] = listpol
                    df_050_059_CUB_VS1_I ['Symmetry'] = listsym
                    df_050_059_CUB_VS1_I ['Ratio'] = listrat
                    df_050_059_CUB_VS1_I ['PPC'] = listdesc
                    df_050_059_CUB_VS1_I ['Total'] = listtotal
                    df_050_059_CUB_VS1_I['Carat'] = df_050_059_CUB_VS1_I['Carat'].astype('float64')
                    df_050_059_CUB_VS1_I['PPC'] = df_050_059_CUB_VS1_I['PPC'].astype('float64')
                    df_050_059_CUB_VS1_I['Total'] = df_050_059_CUB_VS1_I['Total'].astype('float64')
                    df_050_059_CUB_VS1_I['Total'] = df_050_059_CUB_VS1_I['Carat'] * df_050_059_CUB_VS1_I['PPC']


                elif i== "I" and j == "VS2" and k == "CUB":
                    df_050_059_CUB_VS2_I = pd.DataFrame()
                    df_050_059_CUB_VS2_I ['Wt Range'] = None
                    df_050_059_CUB_VS2_I  = df_050_059_CUB_VS2_I.assign(Company=None)
                    df_050_059_CUB_VS2_I  = df_050_059_CUB_VS2_I.assign(Shape=None)
                    df_050_059_CUB_VS2_I  = df_050_059_CUB_VS2_I.assign(Carat=None)
                    df_050_059_CUB_VS2_I  = df_050_059_CUB_VS2_I.assign(Color=None)
                    df_050_059_CUB_VS2_I  = df_050_059_CUB_VS2_I.assign(Clarity=None)
                    df_050_059_CUB_VS2_I  = df_050_059_CUB_VS2_I.assign(Cut=None)
                    df_050_059_CUB_VS2_I  = df_050_059_CUB_VS2_I.assign(Polish=None)
                    df_050_059_CUB_VS2_I  = df_050_059_CUB_VS2_I.assign(Symmetry=None)
                    df_050_059_CUB_VS2_I  = df_050_059_CUB_VS2_I.assign(Ratio=None)
                    df_050_059_CUB_VS2_I  = df_050_059_CUB_VS2_I.assign(PPC=None)
                    df_050_059_CUB_VS2_I  = df_050_059_CUB_VS2_I.assign(Total=None)
                    df_050_059_CUB_VS2_I ['Wt Range'] = listwtrange
                    df_050_059_CUB_VS2_I ['Company'] = listcom
                    df_050_059_CUB_VS2_I ['Shape'] = listshap
                    df_050_059_CUB_VS2_I ['Carat'] = listcar
                    df_050_059_CUB_VS2_I ['Color'] = listcol
                    df_050_059_CUB_VS2_I ['Clarity'] = listclar
                    df_050_059_CUB_VS2_I ['Cut'] = listcut
                    df_050_059_CUB_VS2_I ['Polish'] = listpol
                    df_050_059_CUB_VS2_I ['Symmetry'] = listsym
                    df_050_059_CUB_VS2_I ['Ratio'] = listrat
                    df_050_059_CUB_VS2_I ['PPC'] = listdesc
                    df_050_059_CUB_VS2_I ['Total'] = listtotal
                    df_050_059_CUB_VS2_I['Carat'] = df_050_059_CUB_VS2_I['Carat'].astype('float64')
                    df_050_059_CUB_VS2_I['PPC'] = df_050_059_CUB_VS2_I['PPC'].astype('float64')
                    df_050_059_CUB_VS2_I['Total'] = df_050_059_CUB_VS2_I['Total'].astype('float64')
                    df_050_059_CUB_VS2_I['Total'] = df_050_059_CUB_VS2_I['Carat'] * df_050_059_CUB_VS2_I['PPC']


                elif i== "I" and j == "SI1" and k == "CUB":
                    df_050_059_CUB_SI1_I = pd.DataFrame()
                    df_050_059_CUB_SI1_I ['Wt Range'] = None
                    df_050_059_CUB_SI1_I  = df_050_059_CUB_SI1_I.assign(Company=None)
                    df_050_059_CUB_SI1_I  = df_050_059_CUB_SI1_I.assign(Shape=None)
                    df_050_059_CUB_SI1_I  = df_050_059_CUB_SI1_I.assign(Carat=None)
                    df_050_059_CUB_SI1_I  = df_050_059_CUB_SI1_I.assign(Color=None)
                    df_050_059_CUB_SI1_I  = df_050_059_CUB_SI1_I.assign(Clarity=None)
                    df_050_059_CUB_SI1_I  = df_050_059_CUB_SI1_I.assign(Cut=None)
                    df_050_059_CUB_SI1_I  = df_050_059_CUB_SI1_I.assign(Polish=None)
                    df_050_059_CUB_SI1_I  = df_050_059_CUB_SI1_I.assign(Symmetry=None)
                    df_050_059_CUB_SI1_I  = df_050_059_CUB_SI1_I.assign(Ratio=None)
                    df_050_059_CUB_SI1_I  = df_050_059_CUB_SI1_I.assign(PPC=None)
                    df_050_059_CUB_SI1_I  = df_050_059_CUB_SI1_I.assign(Total=None)
                    df_050_059_CUB_SI1_I ['Wt Range'] = listwtrange
                    df_050_059_CUB_SI1_I ['Company'] = listcom
                    df_050_059_CUB_SI1_I ['Shape'] = listshap
                    df_050_059_CUB_SI1_I ['Carat'] = listcar
                    df_050_059_CUB_SI1_I ['Color'] = listcol
                    df_050_059_CUB_SI1_I ['Clarity'] = listclar
                    df_050_059_CUB_SI1_I ['Cut'] = listcut
                    df_050_059_CUB_SI1_I ['Polish'] = listpol
                    df_050_059_CUB_SI1_I ['Symmetry'] = listsym
                    df_050_059_CUB_SI1_I ['Ratio'] = listrat
                    df_050_059_CUB_SI1_I ['PPC'] = listdesc
                    df_050_059_CUB_SI1_I ['Total'] = listtotal
                    df_050_059_CUB_SI1_I['Carat'] = df_050_059_CUB_SI1_I['Carat'].astype('float64')
                    df_050_059_CUB_SI1_I['PPC'] = df_050_059_CUB_SI1_I['PPC'].astype('float64')
                    df_050_059_CUB_SI1_I['Total'] = df_050_059_CUB_SI1_I['Total'].astype('float64')
                    df_050_059_CUB_SI1_I['Total'] = df_050_059_CUB_SI1_I['Carat'] * df_050_059_CUB_SI1_I['PPC']


                elif i== "I" and j == "SI2" and k == "CUB":
                    df_050_059_CUB_SI2_I = pd.DataFrame()
                    df_050_059_CUB_SI2_I ['Wt Range'] = None
                    df_050_059_CUB_SI2_I  = df_050_059_CUB_SI2_I.assign(Company=None)
                    df_050_059_CUB_SI2_I  = df_050_059_CUB_SI2_I.assign(Shape=None)
                    df_050_059_CUB_SI2_I  = df_050_059_CUB_SI2_I.assign(Carat=None)
                    df_050_059_CUB_SI2_I  = df_050_059_CUB_SI2_I.assign(Color=None)
                    df_050_059_CUB_SI2_I  = df_050_059_CUB_SI2_I.assign(Clarity=None)
                    df_050_059_CUB_SI2_I  = df_050_059_CUB_SI2_I.assign(Cut=None)
                    df_050_059_CUB_SI2_I  = df_050_059_CUB_SI2_I.assign(Polish=None)
                    df_050_059_CUB_SI2_I  = df_050_059_CUB_SI2_I.assign(Symmetry=None)
                    df_050_059_CUB_SI2_I  = df_050_059_CUB_SI2_I.assign(Ratio=None)
                    df_050_059_CUB_SI2_I  = df_050_059_CUB_SI2_I.assign(PPC=None)
                    df_050_059_CUB_SI2_I  = df_050_059_CUB_SI2_I.assign(Total=None)
                    df_050_059_CUB_SI2_I ['Wt Range'] = listwtrange
                    df_050_059_CUB_SI2_I ['Company'] = listcom
                    df_050_059_CUB_SI2_I ['Shape'] = listshap
                    df_050_059_CUB_SI2_I ['Carat'] = listcar
                    df_050_059_CUB_SI2_I ['Color'] = listcol
                    df_050_059_CUB_SI2_I ['Clarity'] = listclar
                    df_050_059_CUB_SI2_I ['Cut'] = listcut
                    df_050_059_CUB_SI2_I ['Polish'] = listpol
                    df_050_059_CUB_SI2_I ['Symmetry'] = listsym
                    df_050_059_CUB_SI2_I ['Ratio'] = listrat
                    df_050_059_CUB_SI2_I ['PPC'] = listdesc
                    df_050_059_CUB_SI2_I ['Total'] = listtotal
                    df_050_059_CUB_SI2_I['Carat'] = df_050_059_CUB_SI2_I['Carat'].astype('float64')
                    df_050_059_CUB_SI2_I['PPC'] = df_050_059_CUB_SI2_I['PPC'].astype('float64')
                    df_050_059_CUB_SI2_I['Total'] = df_050_059_CUB_SI2_I['Total'].astype('float64')
                    df_050_059_CUB_SI2_I['Total'] = df_050_059_CUB_SI2_I['Carat'] * df_050_059_CUB_SI2_I['PPC']


                elif i== "I" and j == "I1" and k == "CUB":
                    df_050_059_CUB_I1_I = pd.DataFrame()
                    df_050_059_CUB_I1_I ['Wt Range'] = None
                    df_050_059_CUB_I1_I  = df_050_059_CUB_I1_I.assign(Company=None)
                    df_050_059_CUB_I1_I  = df_050_059_CUB_I1_I.assign(Shape=None)
                    df_050_059_CUB_I1_I  = df_050_059_CUB_I1_I.assign(Carat=None)
                    df_050_059_CUB_I1_I  = df_050_059_CUB_I1_I.assign(Color=None)
                    df_050_059_CUB_I1_I  = df_050_059_CUB_I1_I.assign(Clarity=None)
                    df_050_059_CUB_I1_I  = df_050_059_CUB_I1_I.assign(Cut=None)
                    df_050_059_CUB_I1_I  = df_050_059_CUB_I1_I.assign(Polish=None)
                    df_050_059_CUB_I1_I  = df_050_059_CUB_I1_I.assign(Symmetry=None)
                    df_050_059_CUB_I1_I  = df_050_059_CUB_I1_I.assign(Ratio=None)
                    df_050_059_CUB_I1_I  = df_050_059_CUB_I1_I.assign(PPC=None)
                    df_050_059_CUB_I1_I  = df_050_059_CUB_I1_I.assign(Total=None)
                    df_050_059_CUB_I1_I ['Wt Range'] = listwtrange
                    df_050_059_CUB_I1_I ['Company'] = listcom
                    df_050_059_CUB_I1_I ['Shape'] = listshap
                    df_050_059_CUB_I1_I ['Carat'] = listcar
                    df_050_059_CUB_I1_I ['Color'] = listcol
                    df_050_059_CUB_I1_I ['Clarity'] = listclar
                    df_050_059_CUB_I1_I ['Cut'] = listcut
                    df_050_059_CUB_I1_I ['Polish'] = listpol
                    df_050_059_CUB_I1_I ['Symmetry'] = listsym
                    df_050_059_CUB_I1_I ['Ratio'] = listrat
                    df_050_059_CUB_I1_I ['PPC'] = listdesc
                    df_050_059_CUB_I1_I ['Total'] = listtotal
                    df_050_059_CUB_I1_I['Carat'] = df_050_059_CUB_I1_I['Carat'].astype('float64')
                    df_050_059_CUB_I1_I['PPC'] = df_050_059_CUB_I1_I['PPC'].astype('float64')
                    df_050_059_CUB_I1_I['Total'] = df_050_059_CUB_I1_I['Total'].astype('float64')
                    df_050_059_CUB_I1_I['Total'] = df_050_059_CUB_I1_I['Carat'] * df_050_059_CUB_I1_I['PPC']


                elif i== "I" and j == "I2" and k == "CUB":
                    df_050_059_CUB_I2_I = pd.DataFrame()
                    df_050_059_CUB_I2_I ['Wt Range'] = None
                    df_050_059_CUB_I2_I  = df_050_059_CUB_I2_I.assign(Company=None)
                    df_050_059_CUB_I2_I  = df_050_059_CUB_I2_I.assign(Shape=None)
                    df_050_059_CUB_I2_I  = df_050_059_CUB_I2_I.assign(Carat=None)
                    df_050_059_CUB_I2_I  = df_050_059_CUB_I2_I.assign(Color=None)
                    df_050_059_CUB_I2_I  = df_050_059_CUB_I2_I.assign(Clarity=None)
                    df_050_059_CUB_I2_I  = df_050_059_CUB_I2_I.assign(Cut=None)
                    df_050_059_CUB_I2_I  = df_050_059_CUB_I2_I.assign(Polish=None)
                    df_050_059_CUB_I2_I  = df_050_059_CUB_I2_I.assign(Symmetry=None)
                    df_050_059_CUB_I2_I  = df_050_059_CUB_I2_I.assign(Ratio=None)
                    df_050_059_CUB_I2_I  = df_050_059_CUB_I2_I.assign(PPC=None)
                    df_050_059_CUB_I2_I  = df_050_059_CUB_I2_I.assign(Total=None)
                    df_050_059_CUB_I2_I ['Wt Range'] = listwtrange
                    df_050_059_CUB_I2_I ['Company'] = listcom
                    df_050_059_CUB_I2_I ['Shape'] = listshap
                    df_050_059_CUB_I2_I ['Carat'] = listcar
                    df_050_059_CUB_I2_I ['Color'] = listcol
                    df_050_059_CUB_I2_I ['Clarity'] = listclar
                    df_050_059_CUB_I2_I ['Cut'] = listcut
                    df_050_059_CUB_I2_I ['Polish'] = listpol
                    df_050_059_CUB_I2_I ['Symmetry'] = listsym
                    df_050_059_CUB_I2_I ['Ratio'] = listrat
                    df_050_059_CUB_I2_I ['PPC'] = listdesc
                    df_050_059_CUB_I2_I ['Total'] = listtotal
                    df_050_059_CUB_I2_I['Carat'] = df_050_059_CUB_I2_I['Carat'].astype('float64')
                    df_050_059_CUB_I2_I['PPC'] = df_050_059_CUB_I2_I['PPC'].astype('float64')
                    df_050_059_CUB_I2_I['Total'] = df_050_059_CUB_I2_I['Total'].astype('float64')
                    df_050_059_CUB_I2_I['Total'] = df_050_059_CUB_I2_I['Carat'] * df_050_059_CUB_I2_I['PPC']


                elif i=="J" and j == "IF" and k == "CUB":
                    df_050_059_CUB_IF_J = pd.DataFrame()
                    df_050_059_CUB_IF_J ['Wt Range'] = None
                    df_050_059_CUB_IF_J  = df_050_059_CUB_IF_J.assign(Company=None)
                    df_050_059_CUB_IF_J  = df_050_059_CUB_IF_J.assign(Shape=None)
                    df_050_059_CUB_IF_J  = df_050_059_CUB_IF_J.assign(Carat=None)
                    df_050_059_CUB_IF_J  = df_050_059_CUB_IF_J.assign(Color=None)
                    df_050_059_CUB_IF_J  = df_050_059_CUB_IF_J.assign(Clarity=None)
                    df_050_059_CUB_IF_J  = df_050_059_CUB_IF_J.assign(Cut=None)
                    df_050_059_CUB_IF_J  = df_050_059_CUB_IF_J.assign(Polish=None)
                    df_050_059_CUB_IF_J  = df_050_059_CUB_IF_J.assign(Symmetry=None)
                    df_050_059_CUB_IF_J  = df_050_059_CUB_IF_J.assign(Ratio=None)
                    df_050_059_CUB_IF_J  = df_050_059_CUB_IF_J.assign(PPC=None)
                    df_050_059_CUB_IF_J  = df_050_059_CUB_IF_J.assign(Total=None)
                    df_050_059_CUB_IF_J ['Wt Range'] = listwtrange
                    df_050_059_CUB_IF_J ['Company'] = listcom
                    df_050_059_CUB_IF_J ['Shape'] = listshap
                    df_050_059_CUB_IF_J ['Carat'] = listcar
                    df_050_059_CUB_IF_J ['Color'] = listcol
                    df_050_059_CUB_IF_J ['Clarity'] = listclar
                    df_050_059_CUB_IF_J ['Cut'] = listcut
                    df_050_059_CUB_IF_J ['Polish'] = listpol
                    df_050_059_CUB_IF_J ['Symmetry'] = listsym
                    df_050_059_CUB_IF_J ['Ratio'] = listrat
                    df_050_059_CUB_IF_J ['PPC'] = listdesc
                    df_050_059_CUB_IF_J ['Total'] = listtotal
                    df_050_059_CUB_IF_J['Carat'] = df_050_059_CUB_IF_J['Carat'].astype('float64')
                    df_050_059_CUB_IF_J['PPC'] = df_050_059_CUB_IF_J['PPC'].astype('float64')
                    df_050_059_CUB_IF_J['Total'] = df_050_059_CUB_IF_J['Total'].astype('float64')
                    df_050_059_CUB_IF_J['Total'] = df_050_059_CUB_IF_J['Carat'] * df_050_059_CUB_IF_J['PPC']



                elif i=="J"  and j == "VVS1" and k == "CUB":
                    df_050_059_CUB_VVS1_J = pd.DataFrame()
                    df_050_059_CUB_VVS1_J ['Wt Range'] = None
                    df_050_059_CUB_VVS1_J  = df_050_059_CUB_VVS1_J.assign(Company=None)
                    df_050_059_CUB_VVS1_J  = df_050_059_CUB_VVS1_J.assign(Shape=None)
                    df_050_059_CUB_VVS1_J  = df_050_059_CUB_VVS1_J.assign(Carat=None)
                    df_050_059_CUB_VVS1_J  = df_050_059_CUB_VVS1_J.assign(Color=None)
                    df_050_059_CUB_VVS1_J  = df_050_059_CUB_VVS1_J.assign(Clarity=None)
                    df_050_059_CUB_VVS1_J  = df_050_059_CUB_VVS1_J.assign(Cut=None)
                    df_050_059_CUB_VVS1_J  = df_050_059_CUB_VVS1_J.assign(Polish=None)
                    df_050_059_CUB_VVS1_J  = df_050_059_CUB_VVS1_J.assign(Symmetry=None)
                    df_050_059_CUB_VVS1_J  = df_050_059_CUB_VVS1_J.assign(Ratio=None)
                    df_050_059_CUB_VVS1_J  = df_050_059_CUB_VVS1_J.assign(PPC=None)
                    df_050_059_CUB_VVS1_J  = df_050_059_CUB_VVS1_J.assign(Total=None)
                    df_050_059_CUB_VVS1_J ['Wt Range'] = listwtrange
                    df_050_059_CUB_VVS1_J ['Company'] = listcom
                    df_050_059_CUB_VVS1_J ['Shape'] = listshap
                    df_050_059_CUB_VVS1_J ['Carat'] = listcar
                    df_050_059_CUB_VVS1_J ['Color'] = listcol
                    df_050_059_CUB_VVS1_J ['Clarity'] = listclar
                    df_050_059_CUB_VVS1_J ['Cut'] = listcut
                    df_050_059_CUB_VVS1_J ['Polish'] = listpol
                    df_050_059_CUB_VVS1_J ['Symmetry'] = listsym
                    df_050_059_CUB_VVS1_J ['Ratio'] = listrat
                    df_050_059_CUB_VVS1_J ['PPC'] = listdesc
                    df_050_059_CUB_VVS1_J ['Total'] = listtotal
                    df_050_059_CUB_VVS1_J['Carat'] = df_050_059_CUB_VVS1_J['Carat'].astype('float64')
                    df_050_059_CUB_VVS1_J['PPC'] = df_050_059_CUB_VVS1_J['PPC'].astype('float64')
                    df_050_059_CUB_VVS1_J['Total'] = df_050_059_CUB_VVS1_J['Total'].astype('float64')
                    df_050_059_CUB_VVS1_J['Total'] = df_050_059_CUB_VVS1_J['Carat'] * df_050_059_CUB_VVS1_J['PPC']


                elif i=="J"  and j == "VVS2" and k == "CUB":
                    df_050_059_CUB_VVS2_J = pd.DataFrame()
                    df_050_059_CUB_VVS2_J ['Wt Range'] = None
                    df_050_059_CUB_VVS2_J  = df_050_059_CUB_VVS2_J.assign(Company=None)
                    df_050_059_CUB_VVS2_J  = df_050_059_CUB_VVS2_J.assign(Shape=None)
                    df_050_059_CUB_VVS2_J  = df_050_059_CUB_VVS2_J.assign(Carat=None)
                    df_050_059_CUB_VVS2_J  = df_050_059_CUB_VVS2_J.assign(Color=None)
                    df_050_059_CUB_VVS2_J  = df_050_059_CUB_VVS2_J.assign(Clarity=None)
                    df_050_059_CUB_VVS2_J  = df_050_059_CUB_VVS2_J.assign(Cut=None)
                    df_050_059_CUB_VVS2_J  = df_050_059_CUB_VVS2_J.assign(Polish=None)
                    df_050_059_CUB_VVS2_J  = df_050_059_CUB_VVS2_J.assign(Symmetry=None)
                    df_050_059_CUB_VVS2_J  = df_050_059_CUB_VVS2_J.assign(Ratio=None)
                    df_050_059_CUB_VVS2_J  = df_050_059_CUB_VVS2_J.assign(PPC=None)
                    df_050_059_CUB_VVS2_J  = df_050_059_CUB_VVS2_J.assign(Total=None)
                    df_050_059_CUB_VVS2_J ['Wt Range'] = listwtrange
                    df_050_059_CUB_VVS2_J ['Company'] = listcom
                    df_050_059_CUB_VVS2_J ['Shape'] = listshap
                    df_050_059_CUB_VVS2_J ['Carat'] = listcar
                    df_050_059_CUB_VVS2_J ['Color'] = listcol
                    df_050_059_CUB_VVS2_J ['Clarity'] = listclar
                    df_050_059_CUB_VVS2_J ['Cut'] = listcut
                    df_050_059_CUB_VVS2_J ['Polish'] = listpol
                    df_050_059_CUB_VVS2_J ['Symmetry'] = listsym
                    df_050_059_CUB_VVS2_J ['Ratio'] = listrat
                    df_050_059_CUB_VVS2_J ['PPC'] = listdesc
                    df_050_059_CUB_VVS2_J ['Total'] = listtotal
                    df_050_059_CUB_VVS2_J['Carat'] = df_050_059_CUB_VVS2_J['Carat'].astype('float64')
                    df_050_059_CUB_VVS2_J['PPC'] = df_050_059_CUB_VVS2_J['PPC'].astype('float64')
                    df_050_059_CUB_VVS2_J['Total'] = df_050_059_CUB_VVS2_J['Total'].astype('float64')
                    df_050_059_CUB_VVS2_J['Total'] = df_050_059_CUB_VVS2_J['Carat'] * df_050_059_CUB_VVS2_J['PPC']


                elif i=="J"  and j=="VS1" and k == "CUB":
                    df_050_059_CUB_VS1_J = pd.DataFrame()
                    df_050_059_CUB_VS1_J ['Wt Range'] = None
                    df_050_059_CUB_VS1_J  = df_050_059_CUB_VS1_J.assign(Company=None)
                    df_050_059_CUB_VS1_J  = df_050_059_CUB_VS1_J.assign(Shape=None)
                    df_050_059_CUB_VS1_J  = df_050_059_CUB_VS1_J.assign(Carat=None)
                    df_050_059_CUB_VS1_J  = df_050_059_CUB_VS1_J.assign(Color=None)
                    df_050_059_CUB_VS1_J  = df_050_059_CUB_VS1_J.assign(Clarity=None)
                    df_050_059_CUB_VS1_J  = df_050_059_CUB_VS1_J.assign(Cut=None)
                    df_050_059_CUB_VS1_J  = df_050_059_CUB_VS1_J.assign(Polish=None)
                    df_050_059_CUB_VS1_J  = df_050_059_CUB_VS1_J.assign(Symmetry=None)
                    df_050_059_CUB_VS1_J  = df_050_059_CUB_VS1_J.assign(Ratio=None)
                    df_050_059_CUB_VS1_J  = df_050_059_CUB_VS1_J.assign(PPC=None)
                    df_050_059_CUB_VS1_J  = df_050_059_CUB_VS1_J.assign(Total=None)
                    df_050_059_CUB_VS1_J ['Wt Range'] = listwtrange
                    df_050_059_CUB_VS1_J ['Company'] = listcom
                    df_050_059_CUB_VS1_J ['Shape'] = listshap
                    df_050_059_CUB_VS1_J ['Carat'] = listcar
                    df_050_059_CUB_VS1_J ['Color'] = listcol
                    df_050_059_CUB_VS1_J ['Clarity'] = listclar
                    df_050_059_CUB_VS1_J ['Cut'] = listcut
                    df_050_059_CUB_VS1_J ['Polish'] = listpol
                    df_050_059_CUB_VS1_J ['Symmetry'] = listsym
                    df_050_059_CUB_VS1_J ['Ratio'] = listrat
                    df_050_059_CUB_VS1_J ['PPC'] = listdesc
                    df_050_059_CUB_VS1_J ['Total'] = listtotal
                    df_050_059_CUB_VS1_J['Carat'] = df_050_059_CUB_VS1_J['Carat'].astype('float64')
                    df_050_059_CUB_VS1_J['PPC'] = df_050_059_CUB_VS1_J['PPC'].astype('float64')
                    df_050_059_CUB_VS1_J['Total'] = df_050_059_CUB_VS1_J['Total'].astype('float64')
                    df_050_059_CUB_VS1_J['Total'] = df_050_059_CUB_VS1_J['Carat'] * df_050_059_CUB_VS1_J['PPC']


                elif i=="J"  and j == "VS2" and k == "CUB":
                    df_050_059_CUB_VS2_J = pd.DataFrame()
                    df_050_059_CUB_VS2_J ['Wt Range'] = None
                    df_050_059_CUB_VS2_J  = df_050_059_CUB_VS2_J.assign(Company=None)
                    df_050_059_CUB_VS2_J  = df_050_059_CUB_VS2_J.assign(Shape=None)
                    df_050_059_CUB_VS2_J  = df_050_059_CUB_VS2_J.assign(Carat=None)
                    df_050_059_CUB_VS2_J  = df_050_059_CUB_VS2_J.assign(Color=None)
                    df_050_059_CUB_VS2_J  = df_050_059_CUB_VS2_J.assign(Clarity=None)
                    df_050_059_CUB_VS2_J  = df_050_059_CUB_VS2_J.assign(Cut=None)
                    df_050_059_CUB_VS2_J  = df_050_059_CUB_VS2_J.assign(Polish=None)
                    df_050_059_CUB_VS2_J  = df_050_059_CUB_VS2_J.assign(Symmetry=None)
                    df_050_059_CUB_VS2_J  = df_050_059_CUB_VS2_J.assign(Ratio=None)
                    df_050_059_CUB_VS2_J  = df_050_059_CUB_VS2_J.assign(PPC=None)
                    df_050_059_CUB_VS2_J  = df_050_059_CUB_VS2_J.assign(Total=None)
                    df_050_059_CUB_VS2_J ['Wt Range'] = listwtrange
                    df_050_059_CUB_VS2_J ['Company'] = listcom
                    df_050_059_CUB_VS2_J ['Shape'] = listshap
                    df_050_059_CUB_VS2_J ['Carat'] = listcar
                    df_050_059_CUB_VS2_J ['Color'] = listcol
                    df_050_059_CUB_VS2_J ['Clarity'] = listclar
                    df_050_059_CUB_VS2_J ['Cut'] = listcut
                    df_050_059_CUB_VS2_J ['Polish'] = listpol
                    df_050_059_CUB_VS2_J ['Symmetry'] = listsym
                    df_050_059_CUB_VS2_J ['Ratio'] = listrat
                    df_050_059_CUB_VS2_J ['PPC'] = listdesc
                    df_050_059_CUB_VS2_J ['Total'] = listtotal
                    df_050_059_CUB_VS2_J['Carat'] = df_050_059_CUB_VS2_J['Carat'].astype('float64')
                    df_050_059_CUB_VS2_J['PPC'] = df_050_059_CUB_VS2_J['PPC'].astype('float64')
                    df_050_059_CUB_VS2_J['Total'] = df_050_059_CUB_VS2_J['Total'].astype('float64')
                    df_050_059_CUB_VS2_J['Total'] = df_050_059_CUB_VS2_J['Carat'] * df_050_059_CUB_VS2_J['PPC']


                elif i=="J"  and j == "SI1" and k == "CUB":
                    df_050_059_CUB_SI1_J = pd.DataFrame()
                    df_050_059_CUB_SI1_J ['Wt Range'] = None
                    df_050_059_CUB_SI1_J  = df_050_059_CUB_SI1_J.assign(Company=None)
                    df_050_059_CUB_SI1_J  = df_050_059_CUB_SI1_J.assign(Shape=None)
                    df_050_059_CUB_SI1_J  = df_050_059_CUB_SI1_J.assign(Carat=None)
                    df_050_059_CUB_SI1_J  = df_050_059_CUB_SI1_J.assign(Color=None)
                    df_050_059_CUB_SI1_J  = df_050_059_CUB_SI1_J.assign(Clarity=None)
                    df_050_059_CUB_SI1_J  = df_050_059_CUB_SI1_J.assign(Cut=None)
                    df_050_059_CUB_SI1_J  = df_050_059_CUB_SI1_J.assign(Polish=None)
                    df_050_059_CUB_SI1_J  = df_050_059_CUB_SI1_J.assign(Symmetry=None)
                    df_050_059_CUB_SI1_J  = df_050_059_CUB_SI1_J.assign(Ratio=None)
                    df_050_059_CUB_SI1_J  = df_050_059_CUB_SI1_J.assign(PPC=None)
                    df_050_059_CUB_SI1_J  = df_050_059_CUB_SI1_J.assign(Total=None)
                    df_050_059_CUB_SI1_J ['Wt Range'] = listwtrange
                    df_050_059_CUB_SI1_J ['Company'] = listcom
                    df_050_059_CUB_SI1_J ['Shape'] = listshap
                    df_050_059_CUB_SI1_J ['Carat'] = listcar
                    df_050_059_CUB_SI1_J ['Color'] = listcol
                    df_050_059_CUB_SI1_J ['Clarity'] = listclar
                    df_050_059_CUB_SI1_J ['Cut'] = listcut
                    df_050_059_CUB_SI1_J ['Polish'] = listpol
                    df_050_059_CUB_SI1_J ['Symmetry'] = listsym
                    df_050_059_CUB_SI1_J ['Ratio'] = listrat
                    df_050_059_CUB_SI1_J ['PPC'] = listdesc
                    df_050_059_CUB_SI1_J ['Total'] = listtotal
                    df_050_059_CUB_SI1_J['Carat'] = df_050_059_CUB_SI1_J['Carat'].astype('float64')
                    df_050_059_CUB_SI1_J['PPC'] = df_050_059_CUB_SI1_J['PPC'].astype('float64')
                    df_050_059_CUB_SI1_J['Total'] = df_050_059_CUB_SI1_J['Total'].astype('float64')
                    df_050_059_CUB_SI1_J['Total'] = df_050_059_CUB_SI1_J['Carat'] * df_050_059_CUB_SI1_J['PPC']


                elif i=="J"  and j == "SI2" and k == "CUB":
                    df_050_059_CUB_SI2_J = pd.DataFrame()
                    df_050_059_CUB_SI2_J ['Wt Range'] = None
                    df_050_059_CUB_SI2_J  = df_050_059_CUB_SI2_J.assign(Company=None)
                    df_050_059_CUB_SI2_J  = df_050_059_CUB_SI2_J.assign(Shape=None)
                    df_050_059_CUB_SI2_J  = df_050_059_CUB_SI2_J.assign(Carat=None)
                    df_050_059_CUB_SI2_J  = df_050_059_CUB_SI2_J.assign(Color=None)
                    df_050_059_CUB_SI2_J  = df_050_059_CUB_SI2_J.assign(Clarity=None)
                    df_050_059_CUB_SI2_J  = df_050_059_CUB_SI2_J.assign(Cut=None)
                    df_050_059_CUB_SI2_J  = df_050_059_CUB_SI2_J.assign(Polish=None)
                    df_050_059_CUB_SI2_J  = df_050_059_CUB_SI2_J.assign(Symmetry=None)
                    df_050_059_CUB_SI2_J  = df_050_059_CUB_SI2_J.assign(Ratio=None)
                    df_050_059_CUB_SI2_J  = df_050_059_CUB_SI2_J.assign(PPC=None)
                    df_050_059_CUB_SI2_J  = df_050_059_CUB_SI2_J.assign(Total=None)
                    df_050_059_CUB_SI2_J ['Wt Range'] = listwtrange
                    df_050_059_CUB_SI2_J ['Company'] = listcom
                    df_050_059_CUB_SI2_J ['Shape'] = listshap
                    df_050_059_CUB_SI2_J ['Carat'] = listcar
                    df_050_059_CUB_SI2_J ['Color'] = listcol
                    df_050_059_CUB_SI2_J ['Clarity'] = listclar
                    df_050_059_CUB_SI2_J ['Cut'] = listcut
                    df_050_059_CUB_SI2_J ['Polish'] = listpol
                    df_050_059_CUB_SI2_J ['Symmetry'] = listsym
                    df_050_059_CUB_SI2_J ['Ratio'] = listrat
                    df_050_059_CUB_SI2_J ['PPC'] = listdesc
                    df_050_059_CUB_SI2_J ['Total'] = listtotal
                    df_050_059_CUB_SI2_J['Carat'] = df_050_059_CUB_SI2_J['Carat'].astype('float64')
                    df_050_059_CUB_SI2_J['PPC'] = df_050_059_CUB_SI2_J['PPC'].astype('float64')
                    df_050_059_CUB_SI2_J['Total'] = df_050_059_CUB_SI2_J['Total'].astype('float64')
                    df_050_059_CUB_SI2_J['Total'] = df_050_059_CUB_SI2_J['Carat'] * df_050_059_CUB_SI2_J['PPC']


                elif i=="J"  and j == "I1" and k == "CUB":
                    df_050_059_CUB_I1_J = pd.DataFrame()
                    df_050_059_CUB_I1_J ['Wt Range'] = None
                    df_050_059_CUB_I1_J  = df_050_059_CUB_I1_J.assign(Company=None)
                    df_050_059_CUB_I1_J  = df_050_059_CUB_I1_J.assign(Shape=None)
                    df_050_059_CUB_I1_J  = df_050_059_CUB_I1_J.assign(Carat=None)
                    df_050_059_CUB_I1_J  = df_050_059_CUB_I1_J.assign(Color=None)
                    df_050_059_CUB_I1_J  = df_050_059_CUB_I1_J.assign(Clarity=None)
                    df_050_059_CUB_I1_J  = df_050_059_CUB_I1_J.assign(Cut=None)
                    df_050_059_CUB_I1_J  = df_050_059_CUB_I1_J.assign(Polish=None)
                    df_050_059_CUB_I1_J  = df_050_059_CUB_I1_J.assign(Symmetry=None)
                    df_050_059_CUB_I1_J  = df_050_059_CUB_I1_J.assign(Ratio=None)
                    df_050_059_CUB_I1_J  = df_050_059_CUB_I1_J.assign(PPC=None)
                    df_050_059_CUB_I1_J  = df_050_059_CUB_I1_J.assign(Total=None)
                    df_050_059_CUB_I1_J ['Wt Range'] = listwtrange
                    df_050_059_CUB_I1_J ['Company'] = listcom
                    df_050_059_CUB_I1_J ['Shape'] = listshap
                    df_050_059_CUB_I1_J ['Carat'] = listcar
                    df_050_059_CUB_I1_J ['Color'] = listcol
                    df_050_059_CUB_I1_J ['Clarity'] = listclar
                    df_050_059_CUB_I1_J ['Cut'] = listcut
                    df_050_059_CUB_I1_J ['Polish'] = listpol
                    df_050_059_CUB_I1_J ['Symmetry'] = listsym
                    df_050_059_CUB_I1_J ['Ratio'] = listrat
                    df_050_059_CUB_I1_J ['PPC'] = listdesc
                    df_050_059_CUB_I1_J ['Total'] = listtotal
                    df_050_059_CUB_I1_J['Carat'] = df_050_059_CUB_I1_J['Carat'].astype('float64')
                    df_050_059_CUB_I1_J['PPC'] = df_050_059_CUB_I1_J['PPC'].astype('float64')
                    df_050_059_CUB_I1_J['Total'] = df_050_059_CUB_I1_J['Total'].astype('float64')
                    df_050_059_CUB_I1_J['Total'] = df_050_059_CUB_I1_J['Carat'] * df_050_059_CUB_I1_J['PPC']


                elif i=="J"  and j == "I2" and k == "CUB":
                    df_050_059_CUB_I2_J = pd.DataFrame()
                    df_050_059_CUB_I2_J ['Wt Range'] = None
                    df_050_059_CUB_I2_J  = df_050_059_CUB_I2_J.assign(Company=None)
                    df_050_059_CUB_I2_J  = df_050_059_CUB_I2_J.assign(Shape=None)
                    df_050_059_CUB_I2_J  = df_050_059_CUB_I2_J.assign(Carat=None)
                    df_050_059_CUB_I2_J  = df_050_059_CUB_I2_J.assign(Color=None)
                    df_050_059_CUB_I2_J  = df_050_059_CUB_I2_J.assign(Clarity=None)
                    df_050_059_CUB_I2_J  = df_050_059_CUB_I2_J.assign(Cut=None)
                    df_050_059_CUB_I2_J  = df_050_059_CUB_I2_J.assign(Polish=None)
                    df_050_059_CUB_I2_J  = df_050_059_CUB_I2_J.assign(Symmetry=None)
                    df_050_059_CUB_I2_J  = df_050_059_CUB_I2_J.assign(Ratio=None)
                    df_050_059_CUB_I2_J  = df_050_059_CUB_I2_J.assign(PPC=None)
                    df_050_059_CUB_I2_J  = df_050_059_CUB_I2_J.assign(Total=None)
                    df_050_059_CUB_I2_J ['Wt Range'] = listwtrange
                    df_050_059_CUB_I2_J ['Company'] = listcom
                    df_050_059_CUB_I2_J ['Shape'] = listshap
                    df_050_059_CUB_I2_J ['Carat'] = listcar
                    df_050_059_CUB_I2_J ['Color'] = listcol
                    df_050_059_CUB_I2_J ['Clarity'] = listclar
                    df_050_059_CUB_I2_J ['Cut'] = listcut
                    df_050_059_CUB_I2_J ['Polish'] = listpol
                    df_050_059_CUB_I2_J ['Symmetry'] = listsym
                    df_050_059_CUB_I2_J ['Ratio'] = listrat
                    df_050_059_CUB_I2_J ['PPC'] = listdesc
                    df_050_059_CUB_I2_J ['Total'] = listtotal
                    df_050_059_CUB_I2_J['Carat'] = df_050_059_CUB_I2_J['Carat'].astype('float64')
                    df_050_059_CUB_I2_J['PPC'] = df_050_059_CUB_I2_J['PPC'].astype('float64')
                    df_050_059_CUB_I2_J['Total'] = df_050_059_CUB_I2_J['Total'].astype('float64')
                    df_050_059_CUB_I2_J['Total'] = df_050_059_CUB_I2_J['Carat'] * df_050_059_CUB_I2_J['PPC']


                elif i=="K" and j == "IF" and k == "CUB":
                    df_050_059_CUB_IF_K = pd.DataFrame()
                    df_050_059_CUB_IF_K ['Wt Range'] = None
                    df_050_059_CUB_IF_K  = df_050_059_CUB_IF_K.assign(Company=None)
                    df_050_059_CUB_IF_K  = df_050_059_CUB_IF_K.assign(Shape=None)
                    df_050_059_CUB_IF_K  = df_050_059_CUB_IF_K.assign(Carat=None)
                    df_050_059_CUB_IF_K  = df_050_059_CUB_IF_K.assign(Color=None)
                    df_050_059_CUB_IF_K  = df_050_059_CUB_IF_K.assign(Clarity=None)
                    df_050_059_CUB_IF_K  = df_050_059_CUB_IF_K.assign(Cut=None)
                    df_050_059_CUB_IF_K  = df_050_059_CUB_IF_K.assign(Polish=None)
                    df_050_059_CUB_IF_K  = df_050_059_CUB_IF_K.assign(Symmetry=None)
                    df_050_059_CUB_IF_K  = df_050_059_CUB_IF_K.assign(Ratio=None)
                    df_050_059_CUB_IF_K  = df_050_059_CUB_IF_K.assign(PPC=None)
                    df_050_059_CUB_IF_K  = df_050_059_CUB_IF_K.assign(Total=None)
                    df_050_059_CUB_IF_K ['Wt Range'] = listwtrange
                    df_050_059_CUB_IF_K ['Company'] = listcom
                    df_050_059_CUB_IF_K ['Shape'] = listshap
                    df_050_059_CUB_IF_K ['Carat'] = listcar
                    df_050_059_CUB_IF_K ['Color'] = listcol
                    df_050_059_CUB_IF_K ['Clarity'] = listclar
                    df_050_059_CUB_IF_K ['Cut'] = listcut
                    df_050_059_CUB_IF_K ['Polish'] = listpol
                    df_050_059_CUB_IF_K ['Symmetry'] = listsym
                    df_050_059_CUB_IF_K ['Ratio'] = listrat
                    df_050_059_CUB_IF_K ['PPC'] = listdesc
                    df_050_059_CUB_IF_K ['Total'] = listtotal
                    df_050_059_CUB_IF_K['Carat'] = df_050_059_CUB_IF_K['Carat'].astype('float64')
                    df_050_059_CUB_IF_K['PPC'] = df_050_059_CUB_IF_K['PPC'].astype('float64')
                    df_050_059_CUB_IF_K['Total'] = df_050_059_CUB_IF_K['Total'].astype('float64')
                    df_050_059_CUB_IF_K['Total'] = df_050_059_CUB_IF_K['Carat'] * df_050_059_CUB_IF_K['PPC']



                elif i=="K" and j == "VVS1" and k == "CUB":
                    df_050_059_CUB_VVS1_K = pd.DataFrame()
                    df_050_059_CUB_VVS1_K ['Wt Range'] = None
                    df_050_059_CUB_VVS1_K  = df_050_059_CUB_VVS1_K.assign(Company=None)
                    df_050_059_CUB_VVS1_K  = df_050_059_CUB_VVS1_K.assign(Shape=None)
                    df_050_059_CUB_VVS1_K  = df_050_059_CUB_VVS1_K.assign(Carat=None)
                    df_050_059_CUB_VVS1_K  = df_050_059_CUB_VVS1_K.assign(Color=None)
                    df_050_059_CUB_VVS1_K  = df_050_059_CUB_VVS1_K.assign(Clarity=None)
                    df_050_059_CUB_VVS1_K  = df_050_059_CUB_VVS1_K.assign(Cut=None)
                    df_050_059_CUB_VVS1_K  = df_050_059_CUB_VVS1_K.assign(Polish=None)
                    df_050_059_CUB_VVS1_K  = df_050_059_CUB_VVS1_K.assign(Symmetry=None)
                    df_050_059_CUB_VVS1_K  = df_050_059_CUB_VVS1_K.assign(Ratio=None)
                    df_050_059_CUB_VVS1_K  = df_050_059_CUB_VVS1_K.assign(PPC=None)
                    df_050_059_CUB_VVS1_K  = df_050_059_CUB_VVS1_K.assign(Total=None)
                    df_050_059_CUB_VVS1_K ['Wt Range'] = listwtrange
                    df_050_059_CUB_VVS1_K ['Company'] = listcom
                    df_050_059_CUB_VVS1_K ['Shape'] = listshap
                    df_050_059_CUB_VVS1_K ['Carat'] = listcar
                    df_050_059_CUB_VVS1_K ['Color'] = listcol
                    df_050_059_CUB_VVS1_K ['Clarity'] = listclar
                    df_050_059_CUB_VVS1_K ['Cut'] = listcut
                    df_050_059_CUB_VVS1_K ['Polish'] = listpol
                    df_050_059_CUB_VVS1_K ['Symmetry'] = listsym
                    df_050_059_CUB_VVS1_K ['Ratio'] = listrat
                    df_050_059_CUB_VVS1_K ['PPC'] = listdesc
                    df_050_059_CUB_VVS1_K ['Total'] = listtotal
                    df_050_059_CUB_VVS1_K['Carat'] = df_050_059_CUB_VVS1_K['Carat'].astype('float64')
                    df_050_059_CUB_VVS1_K['PPC'] = df_050_059_CUB_VVS1_K['PPC'].astype('float64')
                    df_050_059_CUB_VVS1_K['Total'] = df_050_059_CUB_VVS1_K['Total'].astype('float64')
                    df_050_059_CUB_VVS1_K['Total'] = df_050_059_CUB_VVS1_K['Carat'] * df_050_059_CUB_VVS1_K['PPC']


                elif i=="K" and j == "VVS2" and k == "CUB":
                    df_050_059_CUB_VVS2_K = pd.DataFrame()
                    df_050_059_CUB_VVS2_K ['Wt Range'] = None
                    df_050_059_CUB_VVS2_K  = df_050_059_CUB_VVS2_K.assign(Company=None)
                    df_050_059_CUB_VVS2_K  = df_050_059_CUB_VVS2_K.assign(Shape=None)
                    df_050_059_CUB_VVS2_K  = df_050_059_CUB_VVS2_K.assign(Carat=None)
                    df_050_059_CUB_VVS2_K  = df_050_059_CUB_VVS2_K.assign(Color=None)
                    df_050_059_CUB_VVS2_K  = df_050_059_CUB_VVS2_K.assign(Clarity=None)
                    df_050_059_CUB_VVS2_K  = df_050_059_CUB_VVS2_K.assign(Cut=None)
                    df_050_059_CUB_VVS2_K  = df_050_059_CUB_VVS2_K.assign(Polish=None)
                    df_050_059_CUB_VVS2_K  = df_050_059_CUB_VVS2_K.assign(Symmetry=None)
                    df_050_059_CUB_VVS2_K  = df_050_059_CUB_VVS2_K.assign(Ratio=None)
                    df_050_059_CUB_VVS2_K  = df_050_059_CUB_VVS2_K.assign(PPC=None)
                    df_050_059_CUB_VVS2_K  = df_050_059_CUB_VVS2_K.assign(Total=None)
                    df_050_059_CUB_VVS2_K ['Wt Range'] = listwtrange
                    df_050_059_CUB_VVS2_K ['Company'] = listcom
                    df_050_059_CUB_VVS2_K ['Shape'] = listshap
                    df_050_059_CUB_VVS2_K ['Carat'] = listcar
                    df_050_059_CUB_VVS2_K ['Color'] = listcol
                    df_050_059_CUB_VVS2_K ['Clarity'] = listclar
                    df_050_059_CUB_VVS2_K ['Cut'] = listcut
                    df_050_059_CUB_VVS2_K ['Polish'] = listpol
                    df_050_059_CUB_VVS2_K ['Symmetry'] = listsym
                    df_050_059_CUB_VVS2_K ['Ratio'] = listrat
                    df_050_059_CUB_VVS2_K ['PPC'] = listdesc
                    df_050_059_CUB_VVS2_K ['Total'] = listtotal
                    df_050_059_CUB_VVS2_K['Carat'] = df_050_059_CUB_VVS2_K['Carat'].astype('float64')
                    df_050_059_CUB_VVS2_K['PPC'] = df_050_059_CUB_VVS2_K['PPC'].astype('float64')
                    df_050_059_CUB_VVS2_K['Total'] = df_050_059_CUB_VVS2_K['Total'].astype('float64')
                    df_050_059_CUB_VVS2_K['Total'] = df_050_059_CUB_VVS2_K['Carat'] * df_050_059_CUB_VVS2_K['PPC']


                elif i=="K" and j=="VS1" and k == "CUB":
                    df_050_059_CUB_VS1_K = pd.DataFrame()
                    df_050_059_CUB_VS1_K ['Wt Range'] = None
                    df_050_059_CUB_VS1_K  = df_050_059_CUB_VS1_K.assign(Company=None)
                    df_050_059_CUB_VS1_K  = df_050_059_CUB_VS1_K.assign(Shape=None)
                    df_050_059_CUB_VS1_K  = df_050_059_CUB_VS1_K.assign(Carat=None)
                    df_050_059_CUB_VS1_K  = df_050_059_CUB_VS1_K.assign(Color=None)
                    df_050_059_CUB_VS1_K  = df_050_059_CUB_VS1_K.assign(Clarity=None)
                    df_050_059_CUB_VS1_K  = df_050_059_CUB_VS1_K.assign(Cut=None)
                    df_050_059_CUB_VS1_K  = df_050_059_CUB_VS1_K.assign(Polish=None)
                    df_050_059_CUB_VS1_K  = df_050_059_CUB_VS1_K.assign(Symmetry=None)
                    df_050_059_CUB_VS1_K  = df_050_059_CUB_VS1_K.assign(Ratio=None)
                    df_050_059_CUB_VS1_K  = df_050_059_CUB_VS1_K.assign(PPC=None)
                    df_050_059_CUB_VS1_K  = df_050_059_CUB_VS1_K.assign(Total=None)
                    df_050_059_CUB_VS1_K ['Wt Range'] = listwtrange
                    df_050_059_CUB_VS1_K ['Company'] = listcom
                    df_050_059_CUB_VS1_K ['Shape'] = listshap
                    df_050_059_CUB_VS1_K ['Carat'] = listcar
                    df_050_059_CUB_VS1_K ['Color'] = listcol
                    df_050_059_CUB_VS1_K ['Clarity'] = listclar
                    df_050_059_CUB_VS1_K ['Cut'] = listcut
                    df_050_059_CUB_VS1_K ['Polish'] = listpol
                    df_050_059_CUB_VS1_K ['Symmetry'] = listsym
                    df_050_059_CUB_VS1_K ['Ratio'] = listrat
                    df_050_059_CUB_VS1_K ['PPC'] = listdesc
                    df_050_059_CUB_VS1_K ['Total'] = listtotal
                    df_050_059_CUB_VS1_K['Carat'] = df_050_059_CUB_VS1_K['Carat'].astype('float64')
                    df_050_059_CUB_VS1_K['PPC'] = df_050_059_CUB_VS1_K['PPC'].astype('float64')
                    df_050_059_CUB_VS1_K['Total'] = df_050_059_CUB_VS1_K['Total'].astype('float64')
                    df_050_059_CUB_VS1_K['Total'] = df_050_059_CUB_VS1_K['Carat'] * df_050_059_CUB_VS1_K['PPC']


                elif i=="K" and j == "VS2" and k == "CUB":
                    df_050_059_CUB_VS2_K = pd.DataFrame()
                    df_050_059_CUB_VS2_K ['Wt Range'] = None
                    df_050_059_CUB_VS2_K  = df_050_059_CUB_VS2_K.assign(Company=None)
                    df_050_059_CUB_VS2_K  = df_050_059_CUB_VS2_K.assign(Shape=None)
                    df_050_059_CUB_VS2_K  = df_050_059_CUB_VS2_K.assign(Carat=None)
                    df_050_059_CUB_VS2_K  = df_050_059_CUB_VS2_K.assign(Color=None)
                    df_050_059_CUB_VS2_K  = df_050_059_CUB_VS2_K.assign(Clarity=None)
                    df_050_059_CUB_VS2_K  = df_050_059_CUB_VS2_K.assign(Cut=None)
                    df_050_059_CUB_VS2_K  = df_050_059_CUB_VS2_K.assign(Polish=None)
                    df_050_059_CUB_VS2_K  = df_050_059_CUB_VS2_K.assign(Symmetry=None)
                    df_050_059_CUB_VS2_K  = df_050_059_CUB_VS2_K.assign(Ratio=None)
                    df_050_059_CUB_VS2_K  = df_050_059_CUB_VS2_K.assign(PPC=None)
                    df_050_059_CUB_VS2_K  = df_050_059_CUB_VS2_K.assign(Total=None)
                    df_050_059_CUB_VS2_K ['Wt Range'] = listwtrange
                    df_050_059_CUB_VS2_K ['Company'] = listcom
                    df_050_059_CUB_VS2_K ['Shape'] = listshap
                    df_050_059_CUB_VS2_K ['Carat'] = listcar
                    df_050_059_CUB_VS2_K ['Color'] = listcol
                    df_050_059_CUB_VS2_K ['Clarity'] = listclar
                    df_050_059_CUB_VS2_K ['Cut'] = listcut
                    df_050_059_CUB_VS2_K ['Polish'] = listpol
                    df_050_059_CUB_VS2_K ['Symmetry'] = listsym
                    df_050_059_CUB_VS2_K ['Ratio'] = listrat
                    df_050_059_CUB_VS2_K ['PPC'] = listdesc
                    df_050_059_CUB_VS2_K ['Total'] = listtotal
                    df_050_059_CUB_VS2_K['Carat'] = df_050_059_CUB_VS2_K['Carat'].astype('float64')
                    df_050_059_CUB_VS2_K['PPC'] = df_050_059_CUB_VS2_K['PPC'].astype('float64')
                    df_050_059_CUB_VS2_K['Total'] = df_050_059_CUB_VS2_K['Total'].astype('float64')
                    df_050_059_CUB_VS2_K['Total'] = df_050_059_CUB_VS2_K['Carat'] * df_050_059_CUB_VS2_K['PPC']


                elif i=="K" and j == "SI1" and k == "CUB":
                    df_050_059_CUB_SI1_K = pd.DataFrame()
                    df_050_059_CUB_SI1_K ['Wt Range'] = None
                    df_050_059_CUB_SI1_K  = df_050_059_CUB_SI1_K.assign(Company=None)
                    df_050_059_CUB_SI1_K  = df_050_059_CUB_SI1_K.assign(Shape=None)
                    df_050_059_CUB_SI1_K  = df_050_059_CUB_SI1_K.assign(Carat=None)
                    df_050_059_CUB_SI1_K  = df_050_059_CUB_SI1_K.assign(Color=None)
                    df_050_059_CUB_SI1_K  = df_050_059_CUB_SI1_K.assign(Clarity=None)
                    df_050_059_CUB_SI1_K  = df_050_059_CUB_SI1_K.assign(Cut=None)
                    df_050_059_CUB_SI1_K  = df_050_059_CUB_SI1_K.assign(Polish=None)
                    df_050_059_CUB_SI1_K  = df_050_059_CUB_SI1_K.assign(Symmetry=None)
                    df_050_059_CUB_SI1_K  = df_050_059_CUB_SI1_K.assign(Ratio=None)
                    df_050_059_CUB_SI1_K  = df_050_059_CUB_SI1_K.assign(PPC=None)
                    df_050_059_CUB_SI1_K  = df_050_059_CUB_SI1_K.assign(Total=None)
                    df_050_059_CUB_SI1_K ['Wt Range'] = listwtrange
                    df_050_059_CUB_SI1_K ['Company'] = listcom
                    df_050_059_CUB_SI1_K ['Shape'] = listshap
                    df_050_059_CUB_SI1_K ['Carat'] = listcar
                    df_050_059_CUB_SI1_K ['Color'] = listcol
                    df_050_059_CUB_SI1_K ['Clarity'] = listclar
                    df_050_059_CUB_SI1_K ['Cut'] = listcut
                    df_050_059_CUB_SI1_K ['Polish'] = listpol
                    df_050_059_CUB_SI1_K ['Symmetry'] = listsym
                    df_050_059_CUB_SI1_K ['Ratio'] = listrat
                    df_050_059_CUB_SI1_K ['PPC'] = listdesc
                    df_050_059_CUB_SI1_K ['Total'] = listtotal
                    df_050_059_CUB_SI1_K['Carat'] = df_050_059_CUB_SI1_K['Carat'].astype('float64')
                    df_050_059_CUB_SI1_K['PPC'] = df_050_059_CUB_SI1_K['PPC'].astype('float64')
                    df_050_059_CUB_SI1_K['Total'] = df_050_059_CUB_SI1_K['Total'].astype('float64')
                    df_050_059_CUB_SI1_K['Total'] = df_050_059_CUB_SI1_K['Carat'] * df_050_059_CUB_SI1_K['PPC']


                elif i=="K" and j == "SI2" and k == "CUB":
                    df_050_059_CUB_SI2_K = pd.DataFrame()
                    df_050_059_CUB_SI2_K ['Wt Range'] = None
                    df_050_059_CUB_SI2_K  = df_050_059_CUB_SI2_K.assign(Company=None)
                    df_050_059_CUB_SI2_K  = df_050_059_CUB_SI2_K.assign(Shape=None)
                    df_050_059_CUB_SI2_K  = df_050_059_CUB_SI2_K.assign(Carat=None)
                    df_050_059_CUB_SI2_K  = df_050_059_CUB_SI2_K.assign(Color=None)
                    df_050_059_CUB_SI2_K  = df_050_059_CUB_SI2_K.assign(Clarity=None)
                    df_050_059_CUB_SI2_K  = df_050_059_CUB_SI2_K.assign(Cut=None)
                    df_050_059_CUB_SI2_K  = df_050_059_CUB_SI2_K.assign(Polish=None)
                    df_050_059_CUB_SI2_K  = df_050_059_CUB_SI2_K.assign(Symmetry=None)
                    df_050_059_CUB_SI2_K  = df_050_059_CUB_SI2_K.assign(Ratio=None)
                    df_050_059_CUB_SI2_K  = df_050_059_CUB_SI2_K.assign(PPC=None)
                    df_050_059_CUB_SI2_K  = df_050_059_CUB_SI2_K.assign(Total=None)
                    df_050_059_CUB_SI2_K ['Wt Range'] = listwtrange
                    df_050_059_CUB_SI2_K ['Company'] = listcom
                    df_050_059_CUB_SI2_K ['Shape'] = listshap
                    df_050_059_CUB_SI2_K ['Carat'] = listcar
                    df_050_059_CUB_SI2_K ['Color'] = listcol
                    df_050_059_CUB_SI2_K ['Clarity'] = listclar
                    df_050_059_CUB_SI2_K ['Cut'] = listcut
                    df_050_059_CUB_SI2_K ['Polish'] = listpol
                    df_050_059_CUB_SI2_K ['Symmetry'] = listsym
                    df_050_059_CUB_SI2_K ['Ratio'] = listrat
                    df_050_059_CUB_SI2_K ['PPC'] = listdesc
                    df_050_059_CUB_SI2_K ['Total'] = listtotal
                    df_050_059_CUB_SI2_K['Carat'] = df_050_059_CUB_SI2_K['Carat'].astype('float64')
                    df_050_059_CUB_SI2_K['PPC'] = df_050_059_CUB_SI2_K['PPC'].astype('float64')
                    df_050_059_CUB_SI2_K['Total'] = df_050_059_CUB_SI2_K['Total'].astype('float64')
                    df_050_059_CUB_SI2_K['Total'] = df_050_059_CUB_SI2_K['Carat'] * df_050_059_CUB_SI2_K['PPC']


                elif i=="K" and j == "I1" and k == "CUB":
                    df_050_059_CUB_I1_K = pd.DataFrame()
                    df_050_059_CUB_I1_K ['Wt Range'] = None
                    df_050_059_CUB_I1_K  = df_050_059_CUB_I1_K.assign(Company=None)
                    df_050_059_CUB_I1_K  = df_050_059_CUB_I1_K.assign(Shape=None)
                    df_050_059_CUB_I1_K  = df_050_059_CUB_I1_K.assign(Carat=None)
                    df_050_059_CUB_I1_K  = df_050_059_CUB_I1_K.assign(Color=None)
                    df_050_059_CUB_I1_K  = df_050_059_CUB_I1_K.assign(Clarity=None)
                    df_050_059_CUB_I1_K  = df_050_059_CUB_I1_K.assign(Cut=None)
                    df_050_059_CUB_I1_K  = df_050_059_CUB_I1_K.assign(Polish=None)
                    df_050_059_CUB_I1_K  = df_050_059_CUB_I1_K.assign(Symmetry=None)
                    df_050_059_CUB_I1_K  = df_050_059_CUB_I1_K.assign(Ratio=None)
                    df_050_059_CUB_I1_K  = df_050_059_CUB_I1_K.assign(PPC=None)
                    df_050_059_CUB_I1_K  = df_050_059_CUB_I1_K.assign(Total=None)
                    df_050_059_CUB_I1_K ['Wt Range'] = listwtrange
                    df_050_059_CUB_I1_K ['Company'] = listcom
                    df_050_059_CUB_I1_K ['Shape'] = listshap
                    df_050_059_CUB_I1_K ['Carat'] = listcar
                    df_050_059_CUB_I1_K ['Color'] = listcol
                    df_050_059_CUB_I1_K ['Clarity'] = listclar
                    df_050_059_CUB_I1_K ['Cut'] = listcut
                    df_050_059_CUB_I1_K ['Polish'] = listpol
                    df_050_059_CUB_I1_K ['Symmetry'] = listsym
                    df_050_059_CUB_I1_K ['Ratio'] = listrat
                    df_050_059_CUB_I1_K ['PPC'] = listdesc
                    df_050_059_CUB_I1_K ['Total'] = listtotal
                    df_050_059_CUB_I1_K['Carat'] = df_050_059_CUB_I1_K['Carat'].astype('float64')
                    df_050_059_CUB_I1_K['PPC'] = df_050_059_CUB_I1_K['PPC'].astype('float64')
                    df_050_059_CUB_I1_K['Total'] = df_050_059_CUB_I1_K['Total'].astype('float64')
                    df_050_059_CUB_I1_K['Total'] = df_050_059_CUB_I1_K['Carat'] * df_050_059_CUB_I1_K['PPC']


                elif i=="K" and j == "I2" and k == "CUB":
                    df_050_059_CUB_I2_K = pd.DataFrame()
                    df_050_059_CUB_I2_K ['Wt Range'] = None
                    df_050_059_CUB_I2_K  = df_050_059_CUB_I2_K.assign(Company=None)
                    df_050_059_CUB_I2_K  = df_050_059_CUB_I2_K.assign(Shape=None)
                    df_050_059_CUB_I2_K  = df_050_059_CUB_I2_K.assign(Carat=None)
                    df_050_059_CUB_I2_K  = df_050_059_CUB_I2_K.assign(Color=None)
                    df_050_059_CUB_I2_K  = df_050_059_CUB_I2_K.assign(Clarity=None)
                    df_050_059_CUB_I2_K  = df_050_059_CUB_I2_K.assign(Cut=None)
                    df_050_059_CUB_I2_K  = df_050_059_CUB_I2_K.assign(Polish=None)
                    df_050_059_CUB_I2_K  = df_050_059_CUB_I2_K.assign(Symmetry=None)
                    df_050_059_CUB_I2_K  = df_050_059_CUB_I2_K.assign(Ratio=None)
                    df_050_059_CUB_I2_K  = df_050_059_CUB_I2_K.assign(PPC=None)
                    df_050_059_CUB_I2_K  = df_050_059_CUB_I2_K.assign(Total=None)
                    df_050_059_CUB_I2_K ['Wt Range'] = listwtrange
                    df_050_059_CUB_I2_K ['Company'] = listcom
                    df_050_059_CUB_I2_K ['Shape'] = listshap
                    df_050_059_CUB_I2_K ['Carat'] = listcar
                    df_050_059_CUB_I2_K ['Color'] = listcol
                    df_050_059_CUB_I2_K ['Clarity'] = listclar
                    df_050_059_CUB_I2_K ['Cut'] = listcut
                    df_050_059_CUB_I2_K ['Polish'] = listpol
                    df_050_059_CUB_I2_K ['Symmetry'] = listsym
                    df_050_059_CUB_I2_K ['Ratio'] = listrat
                    df_050_059_CUB_I2_K ['PPC'] = listdesc
                    df_050_059_CUB_I2_K ['Total'] = listtotal
                    df_050_059_CUB_I2_K['Carat'] = df_050_059_CUB_I2_K['Carat'].astype('float64')
                    df_050_059_CUB_I2_K['PPC'] = df_050_059_CUB_I2_K['PPC'].astype('float64')
                    df_050_059_CUB_I2_K['Total'] = df_050_059_CUB_I2_K['Total'].astype('float64')
                    df_050_059_CUB_I2_K['Total'] = df_050_059_CUB_I2_K['Carat'] * df_050_059_CUB_I2_K['PPC']


                elif i=="L" and j == "IF" and k == "CUB":
                    df_050_059_CUB_IF_L = pd.DataFrame()
                    df_050_059_CUB_IF_L ['Wt Range'] = None
                    df_050_059_CUB_IF_L  = df_050_059_CUB_IF_L.assign(Company=None)
                    df_050_059_CUB_IF_L  = df_050_059_CUB_IF_L.assign(Shape=None)
                    df_050_059_CUB_IF_L  = df_050_059_CUB_IF_L.assign(Carat=None)
                    df_050_059_CUB_IF_L  = df_050_059_CUB_IF_L.assign(Color=None)
                    df_050_059_CUB_IF_L  = df_050_059_CUB_IF_L.assign(Clarity=None)
                    df_050_059_CUB_IF_L  = df_050_059_CUB_IF_L.assign(Cut=None)
                    df_050_059_CUB_IF_L  = df_050_059_CUB_IF_L.assign(Polish=None)
                    df_050_059_CUB_IF_L  = df_050_059_CUB_IF_L.assign(Symmetry=None)
                    df_050_059_CUB_IF_L  = df_050_059_CUB_IF_L.assign(Ratio=None)
                    df_050_059_CUB_IF_L  = df_050_059_CUB_IF_L.assign(PPC=None)
                    df_050_059_CUB_IF_L  = df_050_059_CUB_IF_L.assign(Total=None)
                    df_050_059_CUB_IF_L ['Wt Range'] = listwtrange
                    df_050_059_CUB_IF_L ['Company'] = listcom
                    df_050_059_CUB_IF_L ['Shape'] = listshap
                    df_050_059_CUB_IF_L ['Carat'] = listcar
                    df_050_059_CUB_IF_L ['Color'] = listcol
                    df_050_059_CUB_IF_L ['Clarity'] = listclar
                    df_050_059_CUB_IF_L ['Cut'] = listcut
                    df_050_059_CUB_IF_L ['Polish'] = listpol
                    df_050_059_CUB_IF_L ['Symmetry'] = listsym
                    df_050_059_CUB_IF_L ['Ratio'] = listrat
                    df_050_059_CUB_IF_L ['PPC'] = listdesc
                    df_050_059_CUB_IF_L ['Total'] = listtotal
                    df_050_059_CUB_IF_L['Carat'] = df_050_059_CUB_IF_L['Carat'].astype('float64')
                    df_050_059_CUB_IF_L['PPC'] = df_050_059_CUB_IF_L['PPC'].astype('float64')
                    df_050_059_CUB_IF_L['Total'] = df_050_059_CUB_IF_L['Total'].astype('float64')
                    df_050_059_CUB_IF_L['Total'] = df_050_059_CUB_IF_L['Carat'] * df_050_059_CUB_IF_L['PPC']


                elif i=="L" and j == "VVS1" and k == "CUB":
                    df_050_059_CUB_VVS1_L = pd.DataFrame()
                    df_050_059_CUB_VVS1_L ['Wt Range'] = None
                    df_050_059_CUB_VVS1_L  = df_050_059_CUB_VVS1_L.assign(Company=None)
                    df_050_059_CUB_VVS1_L  = df_050_059_CUB_VVS1_L.assign(Shape=None)
                    df_050_059_CUB_VVS1_L  = df_050_059_CUB_VVS1_L.assign(Carat=None)
                    df_050_059_CUB_VVS1_L  = df_050_059_CUB_VVS1_L.assign(Color=None)
                    df_050_059_CUB_VVS1_L  = df_050_059_CUB_VVS1_L.assign(Clarity=None)
                    df_050_059_CUB_VVS1_L  = df_050_059_CUB_VVS1_L.assign(Cut=None)
                    df_050_059_CUB_VVS1_L  = df_050_059_CUB_VVS1_L.assign(Polish=None)
                    df_050_059_CUB_VVS1_L  = df_050_059_CUB_VVS1_L.assign(Symmetry=None)
                    df_050_059_CUB_VVS1_L  = df_050_059_CUB_VVS1_L.assign(Ratio=None)
                    df_050_059_CUB_VVS1_L  = df_050_059_CUB_VVS1_L.assign(PPC=None)
                    df_050_059_CUB_VVS1_L  = df_050_059_CUB_VVS1_L.assign(Total=None)
                    df_050_059_CUB_VVS1_L ['Wt Range'] = listwtrange
                    df_050_059_CUB_VVS1_L ['Company'] = listcom
                    df_050_059_CUB_VVS1_L ['Shape'] = listshap
                    df_050_059_CUB_VVS1_L ['Carat'] = listcar
                    df_050_059_CUB_VVS1_L ['Color'] = listcol
                    df_050_059_CUB_VVS1_L ['Clarity'] = listclar
                    df_050_059_CUB_VVS1_L ['Cut'] = listcut
                    df_050_059_CUB_VVS1_L ['Polish'] = listpol
                    df_050_059_CUB_VVS1_L ['Symmetry'] = listsym
                    df_050_059_CUB_VVS1_L ['Ratio'] = listrat
                    df_050_059_CUB_VVS1_L ['PPC'] = listdesc
                    df_050_059_CUB_VVS1_L ['Total'] = listtotal
                    df_050_059_CUB_VVS1_L['Carat'] = df_050_059_CUB_VVS1_L['Carat'].astype('float64')
                    df_050_059_CUB_VVS1_L['PPC'] = df_050_059_CUB_VVS1_L['PPC'].astype('float64')
                    df_050_059_CUB_VVS1_L['Total'] = df_050_059_CUB_VVS1_L['Total'].astype('float64')
                    df_050_059_CUB_VVS1_L['Total'] = df_050_059_CUB_VVS1_L['Carat'] * df_050_059_CUB_VVS1_L['PPC']


                elif i=="L" and j == "VVS2" and k == "CUB":
                    df_050_059_CUB_VVS2_L = pd.DataFrame()
                    df_050_059_CUB_VVS2_L ['Wt Range'] = None
                    df_050_059_CUB_VVS2_L  = df_050_059_CUB_VVS2_L.assign(Company=None)
                    df_050_059_CUB_VVS2_L  = df_050_059_CUB_VVS2_L.assign(Shape=None)
                    df_050_059_CUB_VVS2_L  = df_050_059_CUB_VVS2_L.assign(Carat=None)
                    df_050_059_CUB_VVS2_L  = df_050_059_CUB_VVS2_L.assign(Color=None)
                    df_050_059_CUB_VVS2_L  = df_050_059_CUB_VVS2_L.assign(Clarity=None)
                    df_050_059_CUB_VVS2_L  = df_050_059_CUB_VVS2_L.assign(Cut=None)
                    df_050_059_CUB_VVS2_L  = df_050_059_CUB_VVS2_L.assign(Polish=None)
                    df_050_059_CUB_VVS2_L  = df_050_059_CUB_VVS2_L.assign(Symmetry=None)
                    df_050_059_CUB_VVS2_L  = df_050_059_CUB_VVS2_L.assign(Ratio=None)
                    df_050_059_CUB_VVS2_L  = df_050_059_CUB_VVS2_L.assign(PPC=None)
                    df_050_059_CUB_VVS2_L  = df_050_059_CUB_VVS2_L.assign(Total=None)
                    df_050_059_CUB_VVS2_L ['Wt Range'] = listwtrange
                    df_050_059_CUB_VVS2_L ['Company'] = listcom
                    df_050_059_CUB_VVS2_L ['Shape'] = listshap
                    df_050_059_CUB_VVS2_L ['Carat'] = listcar
                    df_050_059_CUB_VVS2_L ['Color'] = listcol
                    df_050_059_CUB_VVS2_L ['Clarity'] = listclar
                    df_050_059_CUB_VVS2_L ['Cut'] = listcut
                    df_050_059_CUB_VVS2_L ['Polish'] = listpol
                    df_050_059_CUB_VVS2_L ['Symmetry'] = listsym
                    df_050_059_CUB_VVS2_L ['Ratio'] = listrat
                    df_050_059_CUB_VVS2_L ['PPC'] = listdesc
                    df_050_059_CUB_VVS2_L ['Total'] = listtotal
                    df_050_059_CUB_VVS2_L['Carat'] = df_050_059_CUB_VVS2_L['Carat'].astype('float64')
                    df_050_059_CUB_VVS2_L['PPC'] = df_050_059_CUB_VVS2_L['PPC'].astype('float64')
                    df_050_059_CUB_VVS2_L['Total'] = df_050_059_CUB_VVS2_L['Total'].astype('float64')
                    df_050_059_CUB_VVS2_L['Total'] = df_050_059_CUB_VVS2_L['Carat'] * df_050_059_CUB_VVS2_L['PPC']


                elif i=="L" and j=="VS1" and k == "CUB":
                    df_050_059_CUB_VS1_L = pd.DataFrame()
                    df_050_059_CUB_VS1_L ['Wt Range'] = None
                    df_050_059_CUB_VS1_L  = df_050_059_CUB_VS1_L.assign(Company=None)
                    df_050_059_CUB_VS1_L  = df_050_059_CUB_VS1_L.assign(Shape=None)
                    df_050_059_CUB_VS1_L  = df_050_059_CUB_VS1_L.assign(Carat=None)
                    df_050_059_CUB_VS1_L  = df_050_059_CUB_VS1_L.assign(Color=None)
                    df_050_059_CUB_VS1_L  = df_050_059_CUB_VS1_L.assign(Clarity=None)
                    df_050_059_CUB_VS1_L  = df_050_059_CUB_VS1_L.assign(Cut=None)
                    df_050_059_CUB_VS1_L  = df_050_059_CUB_VS1_L.assign(Polish=None)
                    df_050_059_CUB_VS1_L  = df_050_059_CUB_VS1_L.assign(Symmetry=None)
                    df_050_059_CUB_VS1_L  = df_050_059_CUB_VS1_L.assign(Ratio=None)
                    df_050_059_CUB_VS1_L  = df_050_059_CUB_VS1_L.assign(PPC=None)
                    df_050_059_CUB_VS1_L  = df_050_059_CUB_VS1_L.assign(Total=None)
                    df_050_059_CUB_VS1_L ['Wt Range'] = listwtrange
                    df_050_059_CUB_VS1_L ['Company'] = listcom
                    df_050_059_CUB_VS1_L ['Shape'] = listshap
                    df_050_059_CUB_VS1_L ['Carat'] = listcar
                    df_050_059_CUB_VS1_L ['Color'] = listcol
                    df_050_059_CUB_VS1_L ['Clarity'] = listclar
                    df_050_059_CUB_VS1_L ['Cut'] = listcut
                    df_050_059_CUB_VS1_L ['Polish'] = listpol
                    df_050_059_CUB_VS1_L ['Symmetry'] = listsym
                    df_050_059_CUB_VS1_L ['Ratio'] = listrat
                    df_050_059_CUB_VS1_L ['PPC'] = listdesc
                    df_050_059_CUB_VS1_L ['Total'] = listtotal
                    df_050_059_CUB_VS1_L['Carat'] = df_050_059_CUB_VS1_L['Carat'].astype('float64')
                    df_050_059_CUB_VS1_L['PPC'] = df_050_059_CUB_VS1_L['PPC'].astype('float64')
                    df_050_059_CUB_VS1_L['Total'] = df_050_059_CUB_VS1_L['Total'].astype('float64')
                    df_050_059_CUB_VS1_L['Total'] = df_050_059_CUB_VS1_L['Carat'] * df_050_059_CUB_VS1_L['PPC']


                elif i=="L" and j == "VS2" and k == "CUB":
                    df_050_059_CUB_VS2_L = pd.DataFrame()
                    df_050_059_CUB_VS2_L ['Wt Range'] = None
                    df_050_059_CUB_VS2_L  = df_050_059_CUB_VS2_L.assign(Company=None)
                    df_050_059_CUB_VS2_L  = df_050_059_CUB_VS2_L.assign(Shape=None)
                    df_050_059_CUB_VS2_L  = df_050_059_CUB_VS2_L.assign(Carat=None)
                    df_050_059_CUB_VS2_L  = df_050_059_CUB_VS2_L.assign(Color=None)
                    df_050_059_CUB_VS2_L  = df_050_059_CUB_VS2_L.assign(Clarity=None)
                    df_050_059_CUB_VS2_L  = df_050_059_CUB_VS2_L.assign(Cut=None)
                    df_050_059_CUB_VS2_L  = df_050_059_CUB_VS2_L.assign(Polish=None)
                    df_050_059_CUB_VS2_L  = df_050_059_CUB_VS2_L.assign(Symmetry=None)
                    df_050_059_CUB_VS2_L  = df_050_059_CUB_VS2_L.assign(Ratio=None)
                    df_050_059_CUB_VS2_L  = df_050_059_CUB_VS2_L.assign(PPC=None)
                    df_050_059_CUB_VS2_L  = df_050_059_CUB_VS2_L.assign(Total=None)
                    df_050_059_CUB_VS2_L ['Wt Range'] = listwtrange
                    df_050_059_CUB_VS2_L ['Company'] = listcom
                    df_050_059_CUB_VS2_L ['Shape'] = listshap
                    df_050_059_CUB_VS2_L ['Carat'] = listcar
                    df_050_059_CUB_VS2_L ['Color'] = listcol
                    df_050_059_CUB_VS2_L ['Clarity'] = listclar
                    df_050_059_CUB_VS2_L ['Cut'] = listcut
                    df_050_059_CUB_VS2_L ['Polish'] = listpol
                    df_050_059_CUB_VS2_L ['Symmetry'] = listsym
                    df_050_059_CUB_VS2_L ['Ratio'] = listrat
                    df_050_059_CUB_VS2_L ['PPC'] = listdesc
                    df_050_059_CUB_VS2_L ['Total'] = listtotal
                    df_050_059_CUB_VS2_L['Carat'] = df_050_059_CUB_VS2_L['Carat'].astype('float64')
                    df_050_059_CUB_VS2_L['PPC'] = df_050_059_CUB_VS2_L['PPC'].astype('float64')
                    df_050_059_CUB_VS2_L['Total'] = df_050_059_CUB_VS2_L['Total'].astype('float64')
                    df_050_059_CUB_VS2_L['Total'] = df_050_059_CUB_VS2_L['Carat'] * df_050_059_CUB_VS2_L['PPC']


                elif i=="L" and j == "SI1" and k == "CUB":
                    df_050_059_CUB_SI1_L = pd.DataFrame()
                    df_050_059_CUB_SI1_L ['Wt Range'] = None
                    df_050_059_CUB_SI1_L  = df_050_059_CUB_SI1_L.assign(Company=None)
                    df_050_059_CUB_SI1_L  = df_050_059_CUB_SI1_L.assign(Shape=None)
                    df_050_059_CUB_SI1_L  = df_050_059_CUB_SI1_L.assign(Carat=None)
                    df_050_059_CUB_SI1_L  = df_050_059_CUB_SI1_L.assign(Color=None)
                    df_050_059_CUB_SI1_L  = df_050_059_CUB_SI1_L.assign(Clarity=None)
                    df_050_059_CUB_SI1_L  = df_050_059_CUB_SI1_L.assign(Cut=None)
                    df_050_059_CUB_SI1_L  = df_050_059_CUB_SI1_L.assign(Polish=None)
                    df_050_059_CUB_SI1_L  = df_050_059_CUB_SI1_L.assign(Symmetry=None)
                    df_050_059_CUB_SI1_L  = df_050_059_CUB_SI1_L.assign(Ratio=None)
                    df_050_059_CUB_SI1_L  = df_050_059_CUB_SI1_L.assign(PPC=None)
                    df_050_059_CUB_SI1_L  = df_050_059_CUB_SI1_L.assign(Total=None)
                    df_050_059_CUB_SI1_L ['Wt Range'] = listwtrange
                    df_050_059_CUB_SI1_L ['Company'] = listcom
                    df_050_059_CUB_SI1_L ['Shape'] = listshap
                    df_050_059_CUB_SI1_L ['Carat'] = listcar
                    df_050_059_CUB_SI1_L ['Color'] = listcol
                    df_050_059_CUB_SI1_L ['Clarity'] = listclar
                    df_050_059_CUB_SI1_L ['Cut'] = listcut
                    df_050_059_CUB_SI1_L ['Polish'] = listpol
                    df_050_059_CUB_SI1_L ['Symmetry'] = listsym
                    df_050_059_CUB_SI1_L ['Ratio'] = listrat
                    df_050_059_CUB_SI1_L ['PPC'] = listdesc
                    df_050_059_CUB_SI1_L ['Total'] = listtotal
                    df_050_059_CUB_SI1_L['Carat'] = df_050_059_CUB_SI1_L['Carat'].astype('float64')
                    df_050_059_CUB_SI1_L['PPC'] = df_050_059_CUB_SI1_L['PPC'].astype('float64')
                    df_050_059_CUB_SI1_L['Total'] = df_050_059_CUB_SI1_L['Total'].astype('float64')
                    df_050_059_CUB_SI1_L['Total'] = df_050_059_CUB_SI1_L['Carat'] * df_050_059_CUB_SI1_L['PPC']


                elif i=="L" and j == "SI2" and k == "CUB":
                    df_050_059_CUB_SI2_L = pd.DataFrame()
                    df_050_059_CUB_SI2_L ['Wt Range'] = None
                    df_050_059_CUB_SI2_L  = df_050_059_CUB_SI2_L.assign(Company=None)
                    df_050_059_CUB_SI2_L  = df_050_059_CUB_SI2_L.assign(Shape=None)
                    df_050_059_CUB_SI2_L  = df_050_059_CUB_SI2_L.assign(Carat=None)
                    df_050_059_CUB_SI2_L  = df_050_059_CUB_SI2_L.assign(Color=None)
                    df_050_059_CUB_SI2_L  = df_050_059_CUB_SI2_L.assign(Clarity=None)
                    df_050_059_CUB_SI2_L  = df_050_059_CUB_SI2_L.assign(Cut=None)
                    df_050_059_CUB_SI2_L  = df_050_059_CUB_SI2_L.assign(Polish=None)
                    df_050_059_CUB_SI2_L  = df_050_059_CUB_SI2_L.assign(Symmetry=None)
                    df_050_059_CUB_SI2_L  = df_050_059_CUB_SI2_L.assign(Ratio=None)
                    df_050_059_CUB_SI2_L  = df_050_059_CUB_SI2_L.assign(PPC=None)
                    df_050_059_CUB_SI2_L  = df_050_059_CUB_SI2_L.assign(Total=None)
                    df_050_059_CUB_SI2_L ['Wt Range'] = listwtrange
                    df_050_059_CUB_SI2_L ['Company'] = listcom
                    df_050_059_CUB_SI2_L ['Shape'] = listshap
                    df_050_059_CUB_SI2_L ['Carat'] = listcar
                    df_050_059_CUB_SI2_L ['Color'] = listcol
                    df_050_059_CUB_SI2_L ['Clarity'] = listclar
                    df_050_059_CUB_SI2_L ['Cut'] = listcut
                    df_050_059_CUB_SI2_L ['Polish'] = listpol
                    df_050_059_CUB_SI2_L ['Symmetry'] = listsym
                    df_050_059_CUB_SI2_L ['Ratio'] = listrat
                    df_050_059_CUB_SI2_L ['PPC'] = listdesc
                    df_050_059_CUB_SI2_L ['Total'] = listtotal
                    df_050_059_CUB_SI2_L['Carat'] = df_050_059_CUB_SI2_L['Carat'].astype('float64')
                    df_050_059_CUB_SI2_L['PPC'] = df_050_059_CUB_SI2_L['PPC'].astype('float64')
                    df_050_059_CUB_SI2_L['Total'] = df_050_059_CUB_SI2_L['Total'].astype('float64')
                    df_050_059_CUB_SI2_L['Total'] = df_050_059_CUB_SI2_L['Carat'] * df_050_059_CUB_SI2_L['PPC']


                elif i=="L" and j == "I1" and k == "CUB":
                    df_050_059_CUB_I1_L = pd.DataFrame()
                    df_050_059_CUB_I1_L ['Wt Range'] = None
                    df_050_059_CUB_I1_L  = df_050_059_CUB_I1_L.assign(Company=None)
                    df_050_059_CUB_I1_L  = df_050_059_CUB_I1_L.assign(Shape=None)
                    df_050_059_CUB_I1_L  = df_050_059_CUB_I1_L.assign(Carat=None)
                    df_050_059_CUB_I1_L  = df_050_059_CUB_I1_L.assign(Color=None)
                    df_050_059_CUB_I1_L  = df_050_059_CUB_I1_L.assign(Clarity=None)
                    df_050_059_CUB_I1_L  = df_050_059_CUB_I1_L.assign(Cut=None)
                    df_050_059_CUB_I1_L  = df_050_059_CUB_I1_L.assign(Polish=None)
                    df_050_059_CUB_I1_L  = df_050_059_CUB_I1_L.assign(Symmetry=None)
                    df_050_059_CUB_I1_L  = df_050_059_CUB_I1_L.assign(Ratio=None)
                    df_050_059_CUB_I1_L  = df_050_059_CUB_I1_L.assign(PPC=None)
                    df_050_059_CUB_I1_L  = df_050_059_CUB_I1_L.assign(Total=None)
                    df_050_059_CUB_I1_L ['Wt Range'] = listwtrange
                    df_050_059_CUB_I1_L ['Company'] = listcom
                    df_050_059_CUB_I1_L ['Shape'] = listshap
                    df_050_059_CUB_I1_L ['Carat'] = listcar
                    df_050_059_CUB_I1_L ['Color'] = listcol
                    df_050_059_CUB_I1_L ['Clarity'] = listclar
                    df_050_059_CUB_I1_L ['Cut'] = listcut
                    df_050_059_CUB_I1_L ['Polish'] = listpol
                    df_050_059_CUB_I1_L ['Symmetry'] = listsym
                    df_050_059_CUB_I1_L ['Ratio'] = listrat
                    df_050_059_CUB_I1_L ['PPC'] = listdesc
                    df_050_059_CUB_I1_L ['Total'] = listtotal
                    df_050_059_CUB_I1_L['Carat'] = df_050_059_CUB_I1_L['Carat'].astype('float64')
                    df_050_059_CUB_I1_L['PPC'] = df_050_059_CUB_I1_L['PPC'].astype('float64')
                    df_050_059_CUB_I1_L['Total'] = df_050_059_CUB_I1_L['Total'].astype('float64')
                    df_050_059_CUB_I1_L['Total'] = df_050_059_CUB_I1_L['Carat'] * df_050_059_CUB_I1_L['PPC']


                elif i=="L" and j == "I2" and k == "CUB":
                    df_050_059_CUB_I2_L = pd.DataFrame()
                    df_050_059_CUB_I2_L ['Wt Range'] = None
                    df_050_059_CUB_I2_L  = df_050_059_CUB_I2_L.assign(Company=None)
                    df_050_059_CUB_I2_L  = df_050_059_CUB_I2_L.assign(Shape=None)
                    df_050_059_CUB_I2_L  = df_050_059_CUB_I2_L.assign(Carat=None)
                    df_050_059_CUB_I2_L  = df_050_059_CUB_I2_L.assign(Color=None)
                    df_050_059_CUB_I2_L  = df_050_059_CUB_I2_L.assign(Clarity=None)
                    df_050_059_CUB_I2_L  = df_050_059_CUB_I2_L.assign(Cut=None)
                    df_050_059_CUB_I2_L  = df_050_059_CUB_I2_L.assign(Polish=None)
                    df_050_059_CUB_I2_L  = df_050_059_CUB_I2_L.assign(Symmetry=None)
                    df_050_059_CUB_I2_L  = df_050_059_CUB_I2_L.assign(Ratio=None)
                    df_050_059_CUB_I2_L  = df_050_059_CUB_I2_L.assign(PPC=None)
                    df_050_059_CUB_I2_L  = df_050_059_CUB_I2_L.assign(Total=None)
                    df_050_059_CUB_I2_L ['Wt Range'] = listwtrange
                    df_050_059_CUB_I2_L ['Company'] = listcom
                    df_050_059_CUB_I2_L ['Shape'] = listshap
                    df_050_059_CUB_I2_L ['Carat'] = listcar
                    df_050_059_CUB_I2_L ['Color'] = listcol
                    df_050_059_CUB_I2_L ['Clarity'] = listclar
                    df_050_059_CUB_I2_L ['Cut'] = listcut
                    df_050_059_CUB_I2_L ['Polish'] = listpol
                    df_050_059_CUB_I2_L ['Symmetry'] = listsym
                    df_050_059_CUB_I2_L ['Ratio'] = listrat
                    df_050_059_CUB_I2_L ['PPC'] = listdesc
                    df_050_059_CUB_I2_L ['Total'] = listtotal
                    df_050_059_CUB_I2_L['Carat'] = df_050_059_CUB_I2_L['Carat'].astype('float64')
                    df_050_059_CUB_I2_L['PPC'] = df_050_059_CUB_I2_L['PPC'].astype('float64')
                    df_050_059_CUB_I2_L['Total'] = df_050_059_CUB_I2_L['Total'].astype('float64')
                    df_050_059_CUB_I2_L['Total'] = df_050_059_CUB_I2_L['Carat'] * df_050_059_CUB_I2_L['PPC']

                    
                elif i=="D" and j == "IF" and k == "CUM":
                    df_050_059_CUM_IF_D = pd.DataFrame()
                    df_050_059_CUM_IF_D ['Wt Range'] = None
                    df_050_059_CUM_IF_D  = df_050_059_CUM_IF_D.assign(Company=None)
                    df_050_059_CUM_IF_D  = df_050_059_CUM_IF_D.assign(Shape=None)
                    df_050_059_CUM_IF_D  = df_050_059_CUM_IF_D.assign(Carat=None)
                    df_050_059_CUM_IF_D  = df_050_059_CUM_IF_D.assign(Color=None)
                    df_050_059_CUM_IF_D  = df_050_059_CUM_IF_D.assign(Clarity=None)
                    df_050_059_CUM_IF_D  = df_050_059_CUM_IF_D.assign(Cut=None)
                    df_050_059_CUM_IF_D  = df_050_059_CUM_IF_D.assign(Polish=None)
                    df_050_059_CUM_IF_D  = df_050_059_CUM_IF_D.assign(Symmetry=None)
                    df_050_059_CUM_IF_D  = df_050_059_CUM_IF_D.assign(Ratio=None)
                    df_050_059_CUM_IF_D  = df_050_059_CUM_IF_D.assign(PPC=None)
                    df_050_059_CUM_IF_D  = df_050_059_CUM_IF_D.assign(Total=None)
                    df_050_059_CUM_IF_D ['Wt Range'] = listwtrange
                    df_050_059_CUM_IF_D ['Company'] = listcom
                    df_050_059_CUM_IF_D ['Shape'] = listshap
                    df_050_059_CUM_IF_D ['Carat'] = listcar
                    df_050_059_CUM_IF_D ['Color'] = listcol
                    df_050_059_CUM_IF_D ['Clarity'] = listclar
                    df_050_059_CUM_IF_D ['Cut'] = listcut
                    df_050_059_CUM_IF_D ['Polish'] = listpol
                    df_050_059_CUM_IF_D ['Symmetry'] = listsym
                    df_050_059_CUM_IF_D ['Ratio'] = listrat
                    df_050_059_CUM_IF_D ['PPC'] = listdesc
                    df_050_059_CUM_IF_D ['Total'] = listtotal
                    df_050_059_CUM_IF_D['Carat'] = df_050_059_CUM_IF_D['Carat'].astype('float64')
                    df_050_059_CUM_IF_D['PPC'] = df_050_059_CUM_IF_D['PPC'].astype('float64')
                    df_050_059_CUM_IF_D['Total'] = df_050_059_CUM_IF_D['Total'].astype('float64')
                    df_050_059_CUM_IF_D['Total'] = df_050_059_CUM_IF_D['Carat'] * df_050_059_CUM_IF_D['PPC']



                elif i=="D" and j == "VVS1" and k == "CUM" :
                    df_050_059_CUM_VVS1_D = pd.DataFrame()
                    df_050_059_CUM_VVS1_D ['Wt Range'] = None
                    df_050_059_CUM_VVS1_D  = df_050_059_CUM_VVS1_D.assign(Company=None)
                    df_050_059_CUM_VVS1_D  = df_050_059_CUM_VVS1_D.assign(Shape=None)
                    df_050_059_CUM_VVS1_D  = df_050_059_CUM_VVS1_D.assign(Carat=None)
                    df_050_059_CUM_VVS1_D  = df_050_059_CUM_VVS1_D.assign(Color=None)
                    df_050_059_CUM_VVS1_D  = df_050_059_CUM_VVS1_D.assign(Clarity=None)
                    df_050_059_CUM_VVS1_D  = df_050_059_CUM_VVS1_D.assign(Cut=None)
                    df_050_059_CUM_VVS1_D  = df_050_059_CUM_VVS1_D.assign(Polish=None)
                    df_050_059_CUM_VVS1_D  = df_050_059_CUM_VVS1_D.assign(Symmetry=None)
                    df_050_059_CUM_VVS1_D  = df_050_059_CUM_VVS1_D.assign(Ratio=None)
                    df_050_059_CUM_VVS1_D  = df_050_059_CUM_VVS1_D.assign(PPC=None)
                    df_050_059_CUM_VVS1_D  = df_050_059_CUM_VVS1_D.assign(Total=None)
                    df_050_059_CUM_VVS1_D ['Wt Range'] = listwtrange
                    df_050_059_CUM_VVS1_D ['Company'] = listcom
                    df_050_059_CUM_VVS1_D ['Shape'] = listshap
                    df_050_059_CUM_VVS1_D ['Carat'] = listcar
                    df_050_059_CUM_VVS1_D ['Color'] = listcol
                    df_050_059_CUM_VVS1_D ['Clarity'] = listclar
                    df_050_059_CUM_VVS1_D ['Cut'] = listcut
                    df_050_059_CUM_VVS1_D ['Polish'] = listpol
                    df_050_059_CUM_VVS1_D ['Symmetry'] = listsym
                    df_050_059_CUM_VVS1_D ['Ratio'] = listrat
                    df_050_059_CUM_VVS1_D ['PPC'] = listdesc
                    df_050_059_CUM_VVS1_D ['Total'] = listtotal
                    df_050_059_CUM_VVS1_D['Carat'] = df_050_059_CUM_VVS1_D['Carat'].astype('float64')
                    df_050_059_CUM_VVS1_D['PPC'] = df_050_059_CUM_VVS1_D['PPC'].astype('float64')
                    df_050_059_CUM_VVS1_D['Total'] = df_050_059_CUM_VVS1_D['Total'].astype('float64')
                    df_050_059_CUM_VVS1_D['Total'] = df_050_059_CUM_VVS1_D['Carat'] * df_050_059_CUM_VVS1_D['PPC']



                elif i=="D" and j == "VVS2" and k == "CUM" :
                    df_050_059_CUM_VVS2_D = pd.DataFrame()
                    df_050_059_CUM_VVS2_D ['Wt Range'] = None
                    df_050_059_CUM_VVS2_D  = df_050_059_CUM_VVS2_D.assign(Company=None)
                    df_050_059_CUM_VVS2_D  = df_050_059_CUM_VVS2_D.assign(Shape=None)
                    df_050_059_CUM_VVS2_D  = df_050_059_CUM_VVS2_D.assign(Carat=None)
                    df_050_059_CUM_VVS2_D  = df_050_059_CUM_VVS2_D.assign(Color=None)
                    df_050_059_CUM_VVS2_D  = df_050_059_CUM_VVS2_D.assign(Clarity=None)
                    df_050_059_CUM_VVS2_D  = df_050_059_CUM_VVS2_D.assign(Cut=None)
                    df_050_059_CUM_VVS2_D  = df_050_059_CUM_VVS2_D.assign(Polish=None)
                    df_050_059_CUM_VVS2_D  = df_050_059_CUM_VVS2_D.assign(Symmetry=None)
                    df_050_059_CUM_VVS2_D  = df_050_059_CUM_VVS2_D.assign(Ratio=None)
                    df_050_059_CUM_VVS2_D  = df_050_059_CUM_VVS2_D.assign(PPC=None)
                    df_050_059_CUM_VVS2_D  = df_050_059_CUM_VVS2_D.assign(Total=None)
                    df_050_059_CUM_VVS2_D ['Wt Range'] = listwtrange
                    df_050_059_CUM_VVS2_D ['Company'] = listcom
                    df_050_059_CUM_VVS2_D ['Shape'] = listshap
                    df_050_059_CUM_VVS2_D ['Carat'] = listcar
                    df_050_059_CUM_VVS2_D ['Color'] = listcol
                    df_050_059_CUM_VVS2_D ['Clarity'] = listclar
                    df_050_059_CUM_VVS2_D ['Cut'] = listcut
                    df_050_059_CUM_VVS2_D ['Polish'] = listpol
                    df_050_059_CUM_VVS2_D ['Symmetry'] = listsym
                    df_050_059_CUM_VVS2_D ['Ratio'] = listrat
                    df_050_059_CUM_VVS2_D ['PPC'] = listdesc
                    df_050_059_CUM_VVS2_D ['Total'] = listtotal
                    df_050_059_CUM_VVS2_D['Carat'] = df_050_059_CUM_VVS2_D['Carat'].astype('float64')
                    df_050_059_CUM_VVS2_D['PPC'] = df_050_059_CUM_VVS2_D['PPC'].astype('float64')
                    df_050_059_CUM_VVS2_D['Total'] = df_050_059_CUM_VVS2_D['Total'].astype('float64')
                    df_050_059_CUM_VVS2_D['Total'] = df_050_059_CUM_VVS2_D['Carat'] * df_050_059_CUM_VVS2_D['PPC']



                elif i=="D" and j == "VS1" and k == "CUM":
                    df_050_059_CUM_VS1_D = pd.DataFrame()
                    df_050_059_CUM_VS1_D ['Wt Range'] = None
                    df_050_059_CUM_VS1_D  = df_050_059_CUM_VS1_D.assign(Company=None)
                    df_050_059_CUM_VS1_D  = df_050_059_CUM_VS1_D.assign(Shape=None)
                    df_050_059_CUM_VS1_D  = df_050_059_CUM_VS1_D.assign(Carat=None)
                    df_050_059_CUM_VS1_D  = df_050_059_CUM_VS1_D.assign(Color=None)
                    df_050_059_CUM_VS1_D  = df_050_059_CUM_VS1_D.assign(Clarity=None)
                    df_050_059_CUM_VS1_D  = df_050_059_CUM_VS1_D.assign(Cut=None)
                    df_050_059_CUM_VS1_D  = df_050_059_CUM_VS1_D.assign(Polish=None)
                    df_050_059_CUM_VS1_D  = df_050_059_CUM_VS1_D.assign(Symmetry=None)
                    df_050_059_CUM_VS1_D  = df_050_059_CUM_VS1_D.assign(Ratio=None)
                    df_050_059_CUM_VS1_D  = df_050_059_CUM_VS1_D.assign(PPC=None)
                    df_050_059_CUM_VS1_D  = df_050_059_CUM_VS1_D.assign(Total=None)
                    df_050_059_CUM_VS1_D ['Wt Range'] = listwtrange
                    df_050_059_CUM_VS1_D ['Company'] = listcom
                    df_050_059_CUM_VS1_D ['Shape'] = listshap
                    df_050_059_CUM_VS1_D ['Carat'] = listcar
                    df_050_059_CUM_VS1_D ['Color'] = listcol
                    df_050_059_CUM_VS1_D ['Clarity'] = listclar
                    df_050_059_CUM_VS1_D ['Cut'] = listcut
                    df_050_059_CUM_VS1_D ['Polish'] = listpol
                    df_050_059_CUM_VS1_D ['Symmetry'] = listsym
                    df_050_059_CUM_VS1_D ['Ratio'] = listrat
                    df_050_059_CUM_VS1_D ['PPC'] = listdesc
                    df_050_059_CUM_VS1_D ['Total'] = listtotal
                    df_050_059_CUM_VS1_D['Carat'] = df_050_059_CUM_VS1_D['Carat'].astype('float64')
                    df_050_059_CUM_VS1_D['PPC'] = df_050_059_CUM_VS1_D['PPC'].astype('float64')
                    df_050_059_CUM_VS1_D['Total'] = df_050_059_CUM_VS1_D['Total'].astype('float64')
                    df_050_059_CUM_VS1_D['Total'] = df_050_059_CUM_VS1_D['Carat'] * df_050_059_CUM_VS1_D['PPC']


                elif i=="D" and j == "VS2" and k == "CUM":
                    df_050_059_CUM_VS2_D = pd.DataFrame()
                    df_050_059_CUM_VS2_D ['Wt Range'] = None
                    df_050_059_CUM_VS2_D  = df_050_059_CUM_VS2_D.assign(Company=None)
                    df_050_059_CUM_VS2_D  = df_050_059_CUM_VS2_D.assign(Shape=None)
                    df_050_059_CUM_VS2_D  = df_050_059_CUM_VS2_D.assign(Carat=None)
                    df_050_059_CUM_VS2_D  = df_050_059_CUM_VS2_D.assign(Color=None)
                    df_050_059_CUM_VS2_D  = df_050_059_CUM_VS2_D.assign(Clarity=None)
                    df_050_059_CUM_VS2_D  = df_050_059_CUM_VS2_D.assign(Cut=None)
                    df_050_059_CUM_VS2_D  = df_050_059_CUM_VS2_D.assign(Polish=None)
                    df_050_059_CUM_VS2_D  = df_050_059_CUM_VS2_D.assign(Symmetry=None)
                    df_050_059_CUM_VS2_D  = df_050_059_CUM_VS2_D.assign(Ratio=None)
                    df_050_059_CUM_VS2_D  = df_050_059_CUM_VS2_D.assign(PPC=None)
                    df_050_059_CUM_VS2_D  = df_050_059_CUM_VS2_D.assign(Total=None)
                    df_050_059_CUM_VS2_D ['Wt Range'] = listwtrange
                    df_050_059_CUM_VS2_D ['Company'] = listcom
                    df_050_059_CUM_VS2_D ['Shape'] = listshap
                    df_050_059_CUM_VS2_D ['Carat'] = listcar
                    df_050_059_CUM_VS2_D ['Color'] = listcol
                    df_050_059_CUM_VS2_D ['Clarity'] = listclar
                    df_050_059_CUM_VS2_D ['Cut'] = listcut
                    df_050_059_CUM_VS2_D ['Polish'] = listpol
                    df_050_059_CUM_VS2_D ['Symmetry'] = listsym
                    df_050_059_CUM_VS2_D ['Ratio'] = listrat
                    df_050_059_CUM_VS2_D ['PPC'] = listdesc
                    df_050_059_CUM_VS2_D ['Total'] = listtotal
                    df_050_059_CUM_VS2_D['Carat'] = df_050_059_CUM_VS2_D['Carat'].astype('float64')
                    df_050_059_CUM_VS2_D['PPC'] = df_050_059_CUM_VS2_D['PPC'].astype('float64')
                    df_050_059_CUM_VS2_D['Total'] = df_050_059_CUM_VS2_D['Total'].astype('float64')
                    df_050_059_CUM_VS2_D['Total'] = df_050_059_CUM_VS2_D['Carat'] * df_050_059_CUM_VS2_D['PPC']


                elif i=="D" and j == "SI1" and k == "CUM":
                    df_050_059_CUM_SI1_D = pd.DataFrame()
                    df_050_059_CUM_SI1_D ['Wt Range'] = None
                    df_050_059_CUM_SI1_D  = df_050_059_CUM_SI1_D.assign(Company=None)
                    df_050_059_CUM_SI1_D  = df_050_059_CUM_SI1_D.assign(Shape=None)
                    df_050_059_CUM_SI1_D  = df_050_059_CUM_SI1_D.assign(Carat=None)
                    df_050_059_CUM_SI1_D  = df_050_059_CUM_SI1_D.assign(Color=None)
                    df_050_059_CUM_SI1_D  = df_050_059_CUM_SI1_D.assign(Clarity=None)
                    df_050_059_CUM_SI1_D  = df_050_059_CUM_SI1_D.assign(Cut=None)
                    df_050_059_CUM_SI1_D  = df_050_059_CUM_SI1_D.assign(Polish=None)
                    df_050_059_CUM_SI1_D  = df_050_059_CUM_SI1_D.assign(Symmetry=None)
                    df_050_059_CUM_SI1_D  = df_050_059_CUM_SI1_D.assign(Ratio=None)
                    df_050_059_CUM_SI1_D  = df_050_059_CUM_SI1_D.assign(PPC=None)
                    df_050_059_CUM_SI1_D  = df_050_059_CUM_SI1_D.assign(Total=None)
                    df_050_059_CUM_SI1_D ['Wt Range'] = listwtrange
                    df_050_059_CUM_SI1_D ['Company'] = listcom
                    df_050_059_CUM_SI1_D ['Shape'] = listshap
                    df_050_059_CUM_SI1_D ['Carat'] = listcar
                    df_050_059_CUM_SI1_D ['Color'] = listcol
                    df_050_059_CUM_SI1_D ['Clarity'] = listclar
                    df_050_059_CUM_SI1_D ['Cut'] = listcut
                    df_050_059_CUM_SI1_D ['Polish'] = listpol
                    df_050_059_CUM_SI1_D ['Symmetry'] = listsym
                    df_050_059_CUM_SI1_D ['Ratio'] = listrat
                    df_050_059_CUM_SI1_D ['PPC'] = listdesc
                    df_050_059_CUM_SI1_D ['Total'] = listtotal
                    df_050_059_CUM_SI1_D['Carat'] = df_050_059_CUM_SI1_D['Carat'].astype('float64')
                    df_050_059_CUM_SI1_D['PPC'] = df_050_059_CUM_SI1_D['PPC'].astype('float64')
                    df_050_059_CUM_SI1_D['Total'] = df_050_059_CUM_SI1_D['Total'].astype('float64')
                    df_050_059_CUM_SI1_D['Total'] = df_050_059_CUM_SI1_D['Carat'] * df_050_059_CUM_SI1_D['PPC']


                elif i=="D" and j == "SI2" and k == "CUM":
                    df_050_059_CUM_SI2_D = pd.DataFrame()
                    df_050_059_CUM_SI2_D ['Wt Range'] = None
                    df_050_059_CUM_SI2_D  = df_050_059_CUM_SI2_D.assign(Company=None)
                    df_050_059_CUM_SI2_D  = df_050_059_CUM_SI2_D.assign(Shape=None)
                    df_050_059_CUM_SI2_D  = df_050_059_CUM_SI2_D.assign(Carat=None)
                    df_050_059_CUM_SI2_D  = df_050_059_CUM_SI2_D.assign(Color=None)
                    df_050_059_CUM_SI2_D  = df_050_059_CUM_SI2_D.assign(Clarity=None)
                    df_050_059_CUM_SI2_D  = df_050_059_CUM_SI2_D.assign(Cut=None)
                    df_050_059_CUM_SI2_D  = df_050_059_CUM_SI2_D.assign(Polish=None)
                    df_050_059_CUM_SI2_D  = df_050_059_CUM_SI2_D.assign(Symmetry=None)
                    df_050_059_CUM_SI2_D  = df_050_059_CUM_SI2_D.assign(Ratio=None)
                    df_050_059_CUM_SI2_D  = df_050_059_CUM_SI2_D.assign(PPC=None)
                    df_050_059_CUM_SI2_D  = df_050_059_CUM_SI2_D.assign(Total=None)
                    df_050_059_CUM_SI2_D ['Wt Range'] = listwtrange
                    df_050_059_CUM_SI2_D ['Company'] = listcom
                    df_050_059_CUM_SI2_D ['Shape'] = listshap
                    df_050_059_CUM_SI2_D ['Carat'] = listcar
                    df_050_059_CUM_SI2_D ['Color'] = listcol
                    df_050_059_CUM_SI2_D ['Clarity'] = listclar
                    df_050_059_CUM_SI2_D ['Cut'] = listcut
                    df_050_059_CUM_SI2_D ['Polish'] = listpol
                    df_050_059_CUM_SI2_D ['Symmetry'] = listsym
                    df_050_059_CUM_SI2_D ['Ratio'] = listrat
                    df_050_059_CUM_SI2_D ['PPC'] = listdesc
                    df_050_059_CUM_SI2_D ['Total'] = listtotal
                    df_050_059_CUM_SI2_D['Carat'] = df_050_059_CUM_SI2_D['Carat'].astype('float64')
                    df_050_059_CUM_SI2_D['PPC'] = df_050_059_CUM_SI2_D['PPC'].astype('float64')
                    df_050_059_CUM_SI2_D['Total'] = df_050_059_CUM_SI2_D['Total'].astype('float64')
                    df_050_059_CUM_SI2_D['Total'] = df_050_059_CUM_SI2_D['Carat'] * df_050_059_CUM_SI2_D['PPC']


                elif i=="D" and j == "I1" and k == "CUM":
                    df_050_059_CUM_I1_D = pd.DataFrame()
                    df_050_059_CUM_I1_D ['Wt Range'] = None
                    df_050_059_CUM_I1_D  = df_050_059_CUM_I1_D.assign(Company=None)
                    df_050_059_CUM_I1_D  = df_050_059_CUM_I1_D.assign(Shape=None)
                    df_050_059_CUM_I1_D  = df_050_059_CUM_I1_D.assign(Carat=None)
                    df_050_059_CUM_I1_D  = df_050_059_CUM_I1_D.assign(Color=None)
                    df_050_059_CUM_I1_D  = df_050_059_CUM_I1_D.assign(Clarity=None)
                    df_050_059_CUM_I1_D  = df_050_059_CUM_I1_D.assign(Cut=None)
                    df_050_059_CUM_I1_D  = df_050_059_CUM_I1_D.assign(Polish=None)
                    df_050_059_CUM_I1_D  = df_050_059_CUM_I1_D.assign(Symmetry=None)
                    df_050_059_CUM_I1_D  = df_050_059_CUM_I1_D.assign(Ratio=None)
                    df_050_059_CUM_I1_D  = df_050_059_CUM_I1_D.assign(PPC=None)
                    df_050_059_CUM_I1_D  = df_050_059_CUM_I1_D.assign(Total=None)
                    df_050_059_CUM_I1_D ['Wt Range'] = listwtrange
                    df_050_059_CUM_I1_D ['Company'] = listcom
                    df_050_059_CUM_I1_D ['Shape'] = listshap
                    df_050_059_CUM_I1_D ['Carat'] = listcar
                    df_050_059_CUM_I1_D ['Color'] = listcol
                    df_050_059_CUM_I1_D ['Clarity'] = listclar
                    df_050_059_CUM_I1_D ['Cut'] = listcut
                    df_050_059_CUM_I1_D ['Polish'] = listpol
                    df_050_059_CUM_I1_D ['Symmetry'] = listsym
                    df_050_059_CUM_I1_D ['Ratio'] = listrat
                    df_050_059_CUM_I1_D ['PPC'] = listdesc
                    df_050_059_CUM_I1_D ['Total'] = listtotal
                    df_050_059_CUM_I1_D['Carat'] = df_050_059_CUM_I1_D['Carat'].astype('float64')
                    df_050_059_CUM_I1_D['PPC'] = df_050_059_CUM_I1_D['PPC'].astype('float64')
                    df_050_059_CUM_I1_D['Total'] = df_050_059_CUM_I1_D['Total'].astype('float64')
                    df_050_059_CUM_I1_D['Total'] = df_050_059_CUM_I1_D['Carat'] * df_050_059_CUM_I1_D['PPC']


                elif i=="D" and j == "I2" and k == "CUM":
                    df_050_059_CUM_I2_D = pd.DataFrame()
                    df_050_059_CUM_I2_D ['Wt Range'] = None
                    df_050_059_CUM_I2_D  = df_050_059_CUM_I2_D.assign(Company=None)
                    df_050_059_CUM_I2_D  = df_050_059_CUM_I2_D.assign(Shape=None)
                    df_050_059_CUM_I2_D  = df_050_059_CUM_I2_D.assign(Carat=None)
                    df_050_059_CUM_I2_D  = df_050_059_CUM_I2_D.assign(Color=None)
                    df_050_059_CUM_I2_D  = df_050_059_CUM_I2_D.assign(Clarity=None)
                    df_050_059_CUM_I2_D  = df_050_059_CUM_I2_D.assign(Cut=None)
                    df_050_059_CUM_I2_D  = df_050_059_CUM_I2_D.assign(Polish=None)
                    df_050_059_CUM_I2_D  = df_050_059_CUM_I2_D.assign(Symmetry=None)
                    df_050_059_CUM_I2_D  = df_050_059_CUM_I2_D.assign(Ratio=None)
                    df_050_059_CUM_I2_D  = df_050_059_CUM_I2_D.assign(PPC=None)
                    df_050_059_CUM_I2_D  = df_050_059_CUM_I2_D.assign(Total=None)
                    df_050_059_CUM_I2_D ['Wt Range'] = listwtrange
                    df_050_059_CUM_I2_D ['Company'] = listcom
                    df_050_059_CUM_I2_D ['Shape'] = listshap
                    df_050_059_CUM_I2_D ['Carat'] = listcar
                    df_050_059_CUM_I2_D ['Color'] = listcol
                    df_050_059_CUM_I2_D ['Clarity'] = listclar
                    df_050_059_CUM_I2_D ['Cut'] = listcut
                    df_050_059_CUM_I2_D ['Polish'] = listpol
                    df_050_059_CUM_I2_D ['Symmetry'] = listsym
                    df_050_059_CUM_I2_D ['Ratio'] = listrat
                    df_050_059_CUM_I2_D ['PPC'] = listdesc
                    df_050_059_CUM_I2_D ['Total'] = listtotal
                    df_050_059_CUM_I2_D['Carat'] = df_050_059_CUM_I2_D['Carat'].astype('float64')
                    df_050_059_CUM_I2_D['PPC'] = df_050_059_CUM_I2_D['PPC'].astype('float64')
                    df_050_059_CUM_I2_D['Total'] = df_050_059_CUM_I2_D['Total'].astype('float64')
                    df_050_059_CUM_I2_D['Total'] = df_050_059_CUM_I2_D['Carat'] * df_050_059_CUM_I2_D['PPC']



                elif i=="E" and j == "IF" and k == "CUM":
                    df_050_059_CUM_IF_E = pd.DataFrame()
                    df_050_059_CUM_IF_E ['Wt Range'] = None
                    df_050_059_CUM_IF_E  = df_050_059_CUM_IF_E.assign(Company=None)
                    df_050_059_CUM_IF_E  = df_050_059_CUM_IF_E.assign(Shape=None)
                    df_050_059_CUM_IF_E  = df_050_059_CUM_IF_E.assign(Carat=None)
                    df_050_059_CUM_IF_E  = df_050_059_CUM_IF_E.assign(Color=None)
                    df_050_059_CUM_IF_E  = df_050_059_CUM_IF_E.assign(Clarity=None)
                    df_050_059_CUM_IF_E  = df_050_059_CUM_IF_E.assign(Cut=None)
                    df_050_059_CUM_IF_E  = df_050_059_CUM_IF_E.assign(Polish=None)
                    df_050_059_CUM_IF_E  = df_050_059_CUM_IF_E.assign(Symmetry=None)
                    df_050_059_CUM_IF_E  = df_050_059_CUM_IF_E.assign(Ratio=None)
                    df_050_059_CUM_IF_E  = df_050_059_CUM_IF_E.assign(PPC=None)
                    df_050_059_CUM_IF_E  = df_050_059_CUM_IF_E.assign(Total=None)
                    df_050_059_CUM_IF_E ['Wt Range'] = listwtrange
                    df_050_059_CUM_IF_E ['Company'] = listcom
                    df_050_059_CUM_IF_E ['Shape'] = listshap
                    df_050_059_CUM_IF_E ['Carat'] = listcar
                    df_050_059_CUM_IF_E ['Color'] = listcol
                    df_050_059_CUM_IF_E ['Clarity'] = listclar
                    df_050_059_CUM_IF_E ['Cut'] = listcut
                    df_050_059_CUM_IF_E ['Polish'] = listpol
                    df_050_059_CUM_IF_E ['Symmetry'] = listsym
                    df_050_059_CUM_IF_E ['Ratio'] = listrat
                    df_050_059_CUM_IF_E ['PPC'] = listdesc
                    df_050_059_CUM_IF_E ['Total'] = listtotal
                    df_050_059_CUM_IF_E['Carat'] = df_050_059_CUM_IF_E['Carat'].astype('float64')
                    df_050_059_CUM_IF_E['PPC'] = df_050_059_CUM_IF_E['PPC'].astype('float64')
                    df_050_059_CUM_IF_E['Total'] = df_050_059_CUM_IF_E['Total'].astype('float64')
                    df_050_059_CUM_IF_E['Total'] = df_050_059_CUM_IF_E['Carat'] * df_050_059_CUM_IF_E['PPC']



                elif i=="E" and j == "VVS1" and k == "CUM":
                    df_050_059_CUM_VVS1_E = pd.DataFrame()
                    df_050_059_CUM_VVS1_E ['Wt Range'] = None
                    df_050_059_CUM_VVS1_E  = df_050_059_CUM_VVS1_E.assign(Company=None)
                    df_050_059_CUM_VVS1_E  = df_050_059_CUM_VVS1_E.assign(Shape=None)
                    df_050_059_CUM_VVS1_E  = df_050_059_CUM_VVS1_E.assign(Carat=None)
                    df_050_059_CUM_VVS1_E  = df_050_059_CUM_VVS1_E.assign(Color=None)
                    df_050_059_CUM_VVS1_E  = df_050_059_CUM_VVS1_E.assign(Clarity=None)
                    df_050_059_CUM_VVS1_E  = df_050_059_CUM_VVS1_E.assign(Cut=None)
                    df_050_059_CUM_VVS1_E  = df_050_059_CUM_VVS1_E.assign(Polish=None)
                    df_050_059_CUM_VVS1_E  = df_050_059_CUM_VVS1_E.assign(Symmetry=None)
                    df_050_059_CUM_VVS1_E  = df_050_059_CUM_VVS1_E.assign(Ratio=None)
                    df_050_059_CUM_VVS1_E  = df_050_059_CUM_VVS1_E.assign(PPC=None)
                    df_050_059_CUM_VVS1_E  = df_050_059_CUM_VVS1_E.assign(Total=None)
                    df_050_059_CUM_VVS1_E ['Wt Range'] = listwtrange
                    df_050_059_CUM_VVS1_E ['Company'] = listcom
                    df_050_059_CUM_VVS1_E ['Shape'] = listshap
                    df_050_059_CUM_VVS1_E ['Carat'] = listcar
                    df_050_059_CUM_VVS1_E ['Color'] = listcol
                    df_050_059_CUM_VVS1_E ['Clarity'] = listclar
                    df_050_059_CUM_VVS1_E ['Cut'] = listcut
                    df_050_059_CUM_VVS1_E ['Polish'] = listpol
                    df_050_059_CUM_VVS1_E ['Symmetry'] = listsym
                    df_050_059_CUM_VVS1_E ['Ratio'] = listrat
                    df_050_059_CUM_VVS1_E ['PPC'] = listdesc
                    df_050_059_CUM_VVS1_E ['Total'] = listtotal
                    df_050_059_CUM_VVS1_E['Carat'] = df_050_059_CUM_VVS1_E['Carat'].astype('float64')
                    df_050_059_CUM_VVS1_E['PPC'] = df_050_059_CUM_VVS1_E['PPC'].astype('float64')
                    df_050_059_CUM_VVS1_E['Total'] = df_050_059_CUM_VVS1_E['Total'].astype('float64')
                    df_050_059_CUM_VVS1_E['Total'] = df_050_059_CUM_VVS1_E['Carat'] * df_050_059_CUM_VVS1_E['PPC']


                elif i=="E" and j == "VVS2" and k == "CUM":
                    df_050_059_CUM_VVS2_E = pd.DataFrame()
                    df_050_059_CUM_VVS2_E ['Wt Range'] = None
                    df_050_059_CUM_VVS2_E  = df_050_059_CUM_VVS2_E.assign(Company=None)
                    df_050_059_CUM_VVS2_E  = df_050_059_CUM_VVS2_E.assign(Shape=None)
                    df_050_059_CUM_VVS2_E  = df_050_059_CUM_VVS2_E.assign(Carat=None)
                    df_050_059_CUM_VVS2_E  = df_050_059_CUM_VVS2_E.assign(Color=None)
                    df_050_059_CUM_VVS2_E  = df_050_059_CUM_VVS2_E.assign(Clarity=None)
                    df_050_059_CUM_VVS2_E  = df_050_059_CUM_VVS2_E.assign(Cut=None)
                    df_050_059_CUM_VVS2_E  = df_050_059_CUM_VVS2_E.assign(Polish=None)
                    df_050_059_CUM_VVS2_E  = df_050_059_CUM_VVS2_E.assign(Symmetry=None)
                    df_050_059_CUM_VVS2_E  = df_050_059_CUM_VVS2_E.assign(Ratio=None)
                    df_050_059_CUM_VVS2_E  = df_050_059_CUM_VVS2_E.assign(PPC=None)
                    df_050_059_CUM_VVS2_E  = df_050_059_CUM_VVS2_E.assign(Total=None)
                    df_050_059_CUM_VVS2_E ['Wt Range'] = listwtrange
                    df_050_059_CUM_VVS2_E ['Company'] = listcom
                    df_050_059_CUM_VVS2_E ['Shape'] = listshap
                    df_050_059_CUM_VVS2_E ['Carat'] = listcar
                    df_050_059_CUM_VVS2_E ['Color'] = listcol
                    df_050_059_CUM_VVS2_E ['Clarity'] = listclar
                    df_050_059_CUM_VVS2_E ['Cut'] = listcut
                    df_050_059_CUM_VVS2_E ['Polish'] = listpol
                    df_050_059_CUM_VVS2_E ['Symmetry'] = listsym
                    df_050_059_CUM_VVS2_E ['Ratio'] = listrat
                    df_050_059_CUM_VVS2_E ['PPC'] = listdesc
                    df_050_059_CUM_VVS2_E ['Total'] = listtotal
                    df_050_059_CUM_VVS2_E['Carat'] = df_050_059_CUM_VVS2_E['Carat'].astype('float64')
                    df_050_059_CUM_VVS2_E['PPC'] = df_050_059_CUM_VVS2_E['PPC'].astype('float64')
                    df_050_059_CUM_VVS2_E['Total'] = df_050_059_CUM_VVS2_E['Total'].astype('float64')
                    df_050_059_CUM_VVS2_E['Total'] = df_050_059_CUM_VVS2_E['Carat'] * df_050_059_CUM_VVS2_E['PPC']


                elif i=="E" and j=="VS1" and k == "CUM":
                    df_050_059_CUM_VS1_E = pd.DataFrame()
                    df_050_059_CUM_VS1_E ['Wt Range'] = None
                    df_050_059_CUM_VS1_E  = df_050_059_CUM_VS1_E.assign(Company=None)
                    df_050_059_CUM_VS1_E  = df_050_059_CUM_VS1_E.assign(Shape=None)
                    df_050_059_CUM_VS1_E  = df_050_059_CUM_VS1_E.assign(Carat=None)
                    df_050_059_CUM_VS1_E  = df_050_059_CUM_VS1_E.assign(Color=None)
                    df_050_059_CUM_VS1_E  = df_050_059_CUM_VS1_E.assign(Clarity=None)
                    df_050_059_CUM_VS1_E  = df_050_059_CUM_VS1_E.assign(Cut=None)
                    df_050_059_CUM_VS1_E  = df_050_059_CUM_VS1_E.assign(Polish=None)
                    df_050_059_CUM_VS1_E  = df_050_059_CUM_VS1_E.assign(Symmetry=None)
                    df_050_059_CUM_VS1_E  = df_050_059_CUM_VS1_E.assign(Ratio=None)
                    df_050_059_CUM_VS1_E  = df_050_059_CUM_VS1_E.assign(PPC=None)
                    df_050_059_CUM_VS1_E  = df_050_059_CUM_VS1_E.assign(Total=None)
                    df_050_059_CUM_VS1_E ['Wt Range'] = listwtrange
                    df_050_059_CUM_VS1_E ['Company'] = listcom
                    df_050_059_CUM_VS1_E ['Shape'] = listshap
                    df_050_059_CUM_VS1_E ['Carat'] = listcar
                    df_050_059_CUM_VS1_E ['Color'] = listcol
                    df_050_059_CUM_VS1_E ['Clarity'] = listclar
                    df_050_059_CUM_VS1_E ['Cut'] = listcut
                    df_050_059_CUM_VS1_E ['Polish'] = listpol
                    df_050_059_CUM_VS1_E ['Symmetry'] = listsym
                    df_050_059_CUM_VS1_E ['Ratio'] = listrat
                    df_050_059_CUM_VS1_E ['PPC'] = listdesc
                    df_050_059_CUM_VS1_E ['Total'] = listtotal
                    df_050_059_CUM_VS1_E['Carat'] = df_050_059_CUM_VS1_E['Carat'].astype('float64')
                    df_050_059_CUM_VS1_E['PPC'] = df_050_059_CUM_VS1_E['PPC'].astype('float64')
                    df_050_059_CUM_VS1_E['Total'] = df_050_059_CUM_VS1_E['Total'].astype('float64')
                    df_050_059_CUM_VS1_E['Total'] = df_050_059_CUM_VS1_E['Carat'] * df_050_059_CUM_VS1_E['PPC']


                elif i=="E" and j == "VS2" and k == "CUM":
                    df_050_059_CUM_VS2_E = pd.DataFrame()
                    df_050_059_CUM_VS2_E ['Wt Range'] = None
                    df_050_059_CUM_VS2_E  = df_050_059_CUM_VS2_E.assign(Company=None)
                    df_050_059_CUM_VS2_E  = df_050_059_CUM_VS2_E.assign(Shape=None)
                    df_050_059_CUM_VS2_E  = df_050_059_CUM_VS2_E.assign(Carat=None)
                    df_050_059_CUM_VS2_E  = df_050_059_CUM_VS2_E.assign(Color=None)
                    df_050_059_CUM_VS2_E  = df_050_059_CUM_VS2_E.assign(Clarity=None)
                    df_050_059_CUM_VS2_E  = df_050_059_CUM_VS2_E.assign(Cut=None)
                    df_050_059_CUM_VS2_E  = df_050_059_CUM_VS2_E.assign(Polish=None)
                    df_050_059_CUM_VS2_E  = df_050_059_CUM_VS2_E.assign(Symmetry=None)
                    df_050_059_CUM_VS2_E  = df_050_059_CUM_VS2_E.assign(Ratio=None)
                    df_050_059_CUM_VS2_E  = df_050_059_CUM_VS2_E.assign(PPC=None)
                    df_050_059_CUM_VS2_E  = df_050_059_CUM_VS2_E.assign(Total=None)
                    df_050_059_CUM_VS2_E ['Wt Range'] = listwtrange
                    df_050_059_CUM_VS2_E ['Company'] = listcom
                    df_050_059_CUM_VS2_E ['Shape'] = listshap
                    df_050_059_CUM_VS2_E ['Carat'] = listcar
                    df_050_059_CUM_VS2_E ['Color'] = listcol
                    df_050_059_CUM_VS2_E ['Clarity'] = listclar
                    df_050_059_CUM_VS2_E ['Cut'] = listcut
                    df_050_059_CUM_VS2_E ['Polish'] = listpol
                    df_050_059_CUM_VS2_E ['Symmetry'] = listsym
                    df_050_059_CUM_VS2_E ['Ratio'] = listrat
                    df_050_059_CUM_VS2_E ['PPC'] = listdesc
                    df_050_059_CUM_VS2_E ['Total'] = listtotal
                    df_050_059_CUM_VS2_E['Carat'] = df_050_059_CUM_VS2_E['Carat'].astype('float64')
                    df_050_059_CUM_VS2_E['PPC'] = df_050_059_CUM_VS2_E['PPC'].astype('float64')
                    df_050_059_CUM_VS2_E['Total'] = df_050_059_CUM_VS2_E['Total'].astype('float64')
                    df_050_059_CUM_VS2_E['Total'] = df_050_059_CUM_VS2_E['Carat'] * df_050_059_CUM_VS2_E['PPC']


                elif i=="E" and j == "SI1" and k == "CUM":
                    df_050_059_CUM_SI1_E = pd.DataFrame()
                    df_050_059_CUM_SI1_E ['Wt Range'] = None
                    df_050_059_CUM_SI1_E  = df_050_059_CUM_SI1_E.assign(Company=None)
                    df_050_059_CUM_SI1_E  = df_050_059_CUM_SI1_E.assign(Shape=None)
                    df_050_059_CUM_SI1_E  = df_050_059_CUM_SI1_E.assign(Carat=None)
                    df_050_059_CUM_SI1_E  = df_050_059_CUM_SI1_E.assign(Color=None)
                    df_050_059_CUM_SI1_E  = df_050_059_CUM_SI1_E.assign(Clarity=None)
                    df_050_059_CUM_SI1_E  = df_050_059_CUM_SI1_E.assign(Cut=None)
                    df_050_059_CUM_SI1_E  = df_050_059_CUM_SI1_E.assign(Polish=None)
                    df_050_059_CUM_SI1_E  = df_050_059_CUM_SI1_E.assign(Symmetry=None)
                    df_050_059_CUM_SI1_E  = df_050_059_CUM_SI1_E.assign(Ratio=None)
                    df_050_059_CUM_SI1_E  = df_050_059_CUM_SI1_E.assign(PPC=None)
                    df_050_059_CUM_SI1_E  = df_050_059_CUM_SI1_E.assign(Total=None)
                    df_050_059_CUM_SI1_E ['Wt Range'] = listwtrange
                    df_050_059_CUM_SI1_E ['Company'] = listcom
                    df_050_059_CUM_SI1_E ['Shape'] = listshap
                    df_050_059_CUM_SI1_E ['Carat'] = listcar
                    df_050_059_CUM_SI1_E ['Color'] = listcol
                    df_050_059_CUM_SI1_E ['Clarity'] = listclar
                    df_050_059_CUM_SI1_E ['Cut'] = listcut
                    df_050_059_CUM_SI1_E ['Polish'] = listpol
                    df_050_059_CUM_SI1_E ['Symmetry'] = listsym
                    df_050_059_CUM_SI1_E ['Ratio'] = listrat
                    df_050_059_CUM_SI1_E ['PPC'] = listdesc
                    df_050_059_CUM_SI1_E ['Total'] = listtotal
                    df_050_059_CUM_SI1_E['Carat'] = df_050_059_CUM_SI1_E['Carat'].astype('float64')
                    df_050_059_CUM_SI1_E['PPC'] = df_050_059_CUM_SI1_E['PPC'].astype('float64')
                    df_050_059_CUM_SI1_E['Total'] = df_050_059_CUM_SI1_E['Total'].astype('float64')
                    df_050_059_CUM_SI1_E['Total'] = df_050_059_CUM_SI1_E['Carat'] * df_050_059_CUM_SI1_E['PPC']


                elif i=="E" and j == "SI2" and k == "CUM":
                    df_050_059_CUM_SI2_E = pd.DataFrame()
                    df_050_059_CUM_SI2_E ['Wt Range'] = None
                    df_050_059_CUM_SI2_E  = df_050_059_CUM_SI2_E.assign(Company=None)
                    df_050_059_CUM_SI2_E  = df_050_059_CUM_SI2_E.assign(Shape=None)
                    df_050_059_CUM_SI2_E  = df_050_059_CUM_SI2_E.assign(Carat=None)
                    df_050_059_CUM_SI2_E  = df_050_059_CUM_SI2_E.assign(Color=None)
                    df_050_059_CUM_SI2_E  = df_050_059_CUM_SI2_E.assign(Clarity=None)
                    df_050_059_CUM_SI2_E  = df_050_059_CUM_SI2_E.assign(Cut=None)
                    df_050_059_CUM_SI2_E  = df_050_059_CUM_SI2_E.assign(Polish=None)
                    df_050_059_CUM_SI2_E  = df_050_059_CUM_SI2_E.assign(Symmetry=None)
                    df_050_059_CUM_SI2_E  = df_050_059_CUM_SI2_E.assign(Ratio=None)
                    df_050_059_CUM_SI2_E  = df_050_059_CUM_SI2_E.assign(PPC=None)
                    df_050_059_CUM_SI2_E  = df_050_059_CUM_SI2_E.assign(Total=None)
                    df_050_059_CUM_SI2_E ['Wt Range'] = listwtrange
                    df_050_059_CUM_SI2_E ['Company'] = listcom
                    df_050_059_CUM_SI2_E ['Shape'] = listshap
                    df_050_059_CUM_SI2_E ['Carat'] = listcar
                    df_050_059_CUM_SI2_E ['Color'] = listcol
                    df_050_059_CUM_SI2_E ['Clarity'] = listclar
                    df_050_059_CUM_SI2_E ['Cut'] = listcut
                    df_050_059_CUM_SI2_E ['Polish'] = listpol
                    df_050_059_CUM_SI2_E ['Symmetry'] = listsym
                    df_050_059_CUM_SI2_E ['Ratio'] = listrat
                    df_050_059_CUM_SI2_E ['PPC'] = listdesc
                    df_050_059_CUM_SI2_E ['Total'] = listtotal
                    df_050_059_CUM_SI2_E['Carat'] = df_050_059_CUM_SI2_E['Carat'].astype('float64')
                    df_050_059_CUM_SI2_E['PPC'] = df_050_059_CUM_SI2_E['PPC'].astype('float64')
                    df_050_059_CUM_SI2_E['Total'] = df_050_059_CUM_SI2_E['Total'].astype('float64')
                    df_050_059_CUM_SI2_E['Total'] = df_050_059_CUM_SI2_E['Carat'] * df_050_059_CUM_SI2_E['PPC']


                elif i=="E" and j == "I1" and k == "CUM":
                    df_050_059_CUM_I1_E = pd.DataFrame()
                    df_050_059_CUM_I1_E ['Wt Range'] = None
                    df_050_059_CUM_I1_E  = df_050_059_CUM_I1_E.assign(Company=None)
                    df_050_059_CUM_I1_E  = df_050_059_CUM_I1_E.assign(Shape=None)
                    df_050_059_CUM_I1_E  = df_050_059_CUM_I1_E.assign(Carat=None)
                    df_050_059_CUM_I1_E  = df_050_059_CUM_I1_E.assign(Color=None)
                    df_050_059_CUM_I1_E  = df_050_059_CUM_I1_E.assign(Clarity=None)
                    df_050_059_CUM_I1_E  = df_050_059_CUM_I1_E.assign(Cut=None)
                    df_050_059_CUM_I1_E  = df_050_059_CUM_I1_E.assign(Polish=None)
                    df_050_059_CUM_I1_E  = df_050_059_CUM_I1_E.assign(Symmetry=None)
                    df_050_059_CUM_I1_E  = df_050_059_CUM_I1_E.assign(Ratio=None)
                    df_050_059_CUM_I1_E  = df_050_059_CUM_I1_E.assign(PPC=None)
                    df_050_059_CUM_I1_E  = df_050_059_CUM_I1_E.assign(Total=None)
                    df_050_059_CUM_I1_E ['Wt Range'] = listwtrange
                    df_050_059_CUM_I1_E ['Company'] = listcom
                    df_050_059_CUM_I1_E ['Shape'] = listshap
                    df_050_059_CUM_I1_E ['Carat'] = listcar
                    df_050_059_CUM_I1_E ['Color'] = listcol
                    df_050_059_CUM_I1_E ['Clarity'] = listclar
                    df_050_059_CUM_I1_E ['Cut'] = listcut
                    df_050_059_CUM_I1_E ['Polish'] = listpol
                    df_050_059_CUM_I1_E ['Symmetry'] = listsym
                    df_050_059_CUM_I1_E ['Ratio'] = listrat
                    df_050_059_CUM_I1_E ['PPC'] = listdesc
                    df_050_059_CUM_I1_E ['Total'] = listtotal
                    df_050_059_CUM_I1_E['Carat'] = df_050_059_CUM_I1_E['Carat'].astype('float64')
                    df_050_059_CUM_I1_E['PPC'] = df_050_059_CUM_I1_E['PPC'].astype('float64')
                    df_050_059_CUM_I1_E['Total'] = df_050_059_CUM_I1_E['Total'].astype('float64')
                    df_050_059_CUM_I1_E['Total'] = df_050_059_CUM_I1_E['Carat'] * df_050_059_CUM_I1_E['PPC']


                elif i=="E" and j == "I2" and k == "CUM":
                    df_050_059_CUM_I2_E = pd.DataFrame()
                    df_050_059_CUM_I2_E ['Wt Range'] = None
                    df_050_059_CUM_I2_E  = df_050_059_CUM_I2_E.assign(Company=None)
                    df_050_059_CUM_I2_E  = df_050_059_CUM_I2_E.assign(Shape=None)
                    df_050_059_CUM_I2_E  = df_050_059_CUM_I2_E.assign(Carat=None)
                    df_050_059_CUM_I2_E  = df_050_059_CUM_I2_E.assign(Color=None)
                    df_050_059_CUM_I2_E  = df_050_059_CUM_I2_E.assign(Clarity=None)
                    df_050_059_CUM_I2_E  = df_050_059_CUM_I2_E.assign(Cut=None)
                    df_050_059_CUM_I2_E  = df_050_059_CUM_I2_E.assign(Polish=None)
                    df_050_059_CUM_I2_E  = df_050_059_CUM_I2_E.assign(Symmetry=None)
                    df_050_059_CUM_I2_E  = df_050_059_CUM_I2_E.assign(Ratio=None)
                    df_050_059_CUM_I2_E  = df_050_059_CUM_I2_E.assign(PPC=None)
                    df_050_059_CUM_I2_E  = df_050_059_CUM_I2_E.assign(Total=None)
                    df_050_059_CUM_I2_E ['Wt Range'] = listwtrange
                    df_050_059_CUM_I2_E ['Company'] = listcom
                    df_050_059_CUM_I2_E ['Shape'] = listshap
                    df_050_059_CUM_I2_E ['Carat'] = listcar
                    df_050_059_CUM_I2_E ['Color'] = listcol
                    df_050_059_CUM_I2_E ['Clarity'] = listclar
                    df_050_059_CUM_I2_E ['Cut'] = listcut
                    df_050_059_CUM_I2_E ['Polish'] = listpol
                    df_050_059_CUM_I2_E ['Symmetry'] = listsym
                    df_050_059_CUM_I2_E ['Ratio'] = listrat
                    df_050_059_CUM_I2_E ['PPC'] = listdesc
                    df_050_059_CUM_I2_E ['Total'] = listtotal
                    df_050_059_CUM_I2_E['Carat'] = df_050_059_CUM_I2_E['Carat'].astype('float64')
                    df_050_059_CUM_I2_E['PPC'] = df_050_059_CUM_I2_E['PPC'].astype('float64')
                    df_050_059_CUM_I2_E['Total'] = df_050_059_CUM_I2_E['Total'].astype('float64')
                    df_050_059_CUM_I2_E['Total'] = df_050_059_CUM_I2_E['Carat'] * df_050_059_CUM_I2_E['PPC']
                
                elif i=="F" and j == "IF" and k == "CUM":
                    df_050_059_CUM_IF_F = pd.DataFrame()
                    df_050_059_CUM_IF_F ['Wt Range'] = None
                    df_050_059_CUM_IF_F  = df_050_059_CUM_IF_F.assign(Company=None)
                    df_050_059_CUM_IF_F  = df_050_059_CUM_IF_F.assign(Shape=None)
                    df_050_059_CUM_IF_F  = df_050_059_CUM_IF_F.assign(Carat=None)
                    df_050_059_CUM_IF_F  = df_050_059_CUM_IF_F.assign(Color=None)
                    df_050_059_CUM_IF_F  = df_050_059_CUM_IF_F.assign(Clarity=None)
                    df_050_059_CUM_IF_F  = df_050_059_CUM_IF_F.assign(Cut=None)
                    df_050_059_CUM_IF_F  = df_050_059_CUM_IF_F.assign(Polish=None)
                    df_050_059_CUM_IF_F  = df_050_059_CUM_IF_F.assign(Symmetry=None)
                    df_050_059_CUM_IF_F  = df_050_059_CUM_IF_F.assign(Ratio=None)
                    df_050_059_CUM_IF_F  = df_050_059_CUM_IF_F.assign(PPC=None)
                    df_050_059_CUM_IF_F  = df_050_059_CUM_IF_F.assign(Total=None)
                    df_050_059_CUM_IF_F ['Wt Range'] = listwtrange
                    df_050_059_CUM_IF_F ['Company'] = listcom
                    df_050_059_CUM_IF_F ['Shape'] = listshap
                    df_050_059_CUM_IF_F ['Carat'] = listcar
                    df_050_059_CUM_IF_F ['Color'] = listcol
                    df_050_059_CUM_IF_F ['Clarity'] = listclar
                    df_050_059_CUM_IF_F ['Cut'] = listcut
                    df_050_059_CUM_IF_F ['Polish'] = listpol
                    df_050_059_CUM_IF_F ['Symmetry'] = listsym
                    df_050_059_CUM_IF_F ['Ratio'] = listrat
                    df_050_059_CUM_IF_F ['PPC'] = listdesc
                    df_050_059_CUM_IF_F ['Total'] = listtotal
                    df_050_059_CUM_IF_F['Carat'] = df_050_059_CUM_IF_F['Carat'].astype('float64')
                    df_050_059_CUM_IF_F['PPC'] = df_050_059_CUM_IF_F['PPC'].astype('float64')
                    df_050_059_CUM_IF_F['Total'] = df_050_059_CUM_IF_F['Total'].astype('float64')
                    df_050_059_CUM_IF_F['Total'] = df_050_059_CUM_IF_F['Carat'] * df_050_059_CUM_IF_F['PPC']



                elif i=="F" and j == "VVS1" and k == "CUM":
                    df_050_059_CUM_VVS1_F = pd.DataFrame()
                    df_050_059_CUM_VVS1_F ['Wt Range'] = None
                    df_050_059_CUM_VVS1_F  = df_050_059_CUM_VVS1_F.assign(Company=None)
                    df_050_059_CUM_VVS1_F  = df_050_059_CUM_VVS1_F.assign(Shape=None)
                    df_050_059_CUM_VVS1_F  = df_050_059_CUM_VVS1_F.assign(Carat=None)
                    df_050_059_CUM_VVS1_F  = df_050_059_CUM_VVS1_F.assign(Color=None)
                    df_050_059_CUM_VVS1_F  = df_050_059_CUM_VVS1_F.assign(Clarity=None)
                    df_050_059_CUM_VVS1_F  = df_050_059_CUM_VVS1_F.assign(Cut=None)
                    df_050_059_CUM_VVS1_F  = df_050_059_CUM_VVS1_F.assign(Polish=None)
                    df_050_059_CUM_VVS1_F  = df_050_059_CUM_VVS1_F.assign(Symmetry=None)
                    df_050_059_CUM_VVS1_F  = df_050_059_CUM_VVS1_F.assign(Ratio=None)
                    df_050_059_CUM_VVS1_F  = df_050_059_CUM_VVS1_F.assign(PPC=None)
                    df_050_059_CUM_VVS1_F  = df_050_059_CUM_VVS1_F.assign(Total=None)
                    df_050_059_CUM_VVS1_F ['Wt Range'] = listwtrange
                    df_050_059_CUM_VVS1_F ['Company'] = listcom
                    df_050_059_CUM_VVS1_F ['Shape'] = listshap
                    df_050_059_CUM_VVS1_F ['Carat'] = listcar
                    df_050_059_CUM_VVS1_F ['Color'] = listcol
                    df_050_059_CUM_VVS1_F ['Clarity'] = listclar
                    df_050_059_CUM_VVS1_F ['Cut'] = listcut
                    df_050_059_CUM_VVS1_F ['Polish'] = listpol
                    df_050_059_CUM_VVS1_F ['Symmetry'] = listsym
                    df_050_059_CUM_VVS1_F ['Ratio'] = listrat
                    df_050_059_CUM_VVS1_F ['PPC'] = listdesc
                    df_050_059_CUM_VVS1_F ['Total'] = listtotal
                    df_050_059_CUM_VVS1_F['Carat'] = df_050_059_CUM_VVS1_F['Carat'].astype('float64')
                    df_050_059_CUM_VVS1_F['PPC'] = df_050_059_CUM_VVS1_F['PPC'].astype('float64')
                    df_050_059_CUM_VVS1_F['Total'] = df_050_059_CUM_VVS1_F['Total'].astype('float64')
                    df_050_059_CUM_VVS1_F['Total'] = df_050_059_CUM_VVS1_F['Carat'] * df_050_059_CUM_VVS1_F['PPC']


                elif i=="F" and j == "VVS2" and k == "CUM":
                    df_050_059_CUM_VVS2_F = pd.DataFrame()
                    df_050_059_CUM_VVS2_F ['Wt Range'] = None
                    df_050_059_CUM_VVS2_F  = df_050_059_CUM_VVS2_F.assign(Company=None)
                    df_050_059_CUM_VVS2_F  = df_050_059_CUM_VVS2_F.assign(Shape=None)
                    df_050_059_CUM_VVS2_F  = df_050_059_CUM_VVS2_F.assign(Carat=None)
                    df_050_059_CUM_VVS2_F  = df_050_059_CUM_VVS2_F.assign(Color=None)
                    df_050_059_CUM_VVS2_F  = df_050_059_CUM_VVS2_F.assign(Clarity=None)
                    df_050_059_CUM_VVS2_F  = df_050_059_CUM_VVS2_F.assign(Cut=None)
                    df_050_059_CUM_VVS2_F  = df_050_059_CUM_VVS2_F.assign(Polish=None)
                    df_050_059_CUM_VVS2_F  = df_050_059_CUM_VVS2_F.assign(Symmetry=None)
                    df_050_059_CUM_VVS2_F  = df_050_059_CUM_VVS2_F.assign(Ratio=None)
                    df_050_059_CUM_VVS2_F  = df_050_059_CUM_VVS2_F.assign(PPC=None)
                    df_050_059_CUM_VVS2_F  = df_050_059_CUM_VVS2_F.assign(Total=None)
                    df_050_059_CUM_VVS2_F ['Wt Range'] = listwtrange
                    df_050_059_CUM_VVS2_F ['Company'] = listcom
                    df_050_059_CUM_VVS2_F ['Shape'] = listshap
                    df_050_059_CUM_VVS2_F ['Carat'] = listcar
                    df_050_059_CUM_VVS2_F ['Color'] = listcol
                    df_050_059_CUM_VVS2_F ['Clarity'] = listclar
                    df_050_059_CUM_VVS2_F ['Cut'] = listcut
                    df_050_059_CUM_VVS2_F ['Polish'] = listpol
                    df_050_059_CUM_VVS2_F ['Symmetry'] = listsym
                    df_050_059_CUM_VVS2_F ['Ratio'] = listrat
                    df_050_059_CUM_VVS2_F ['PPC'] = listdesc
                    df_050_059_CUM_VVS2_F ['Total'] = listtotal
                    df_050_059_CUM_VVS2_F['Carat'] = df_050_059_CUM_VVS2_F['Carat'].astype('float64')
                    df_050_059_CUM_VVS2_F['PPC'] = df_050_059_CUM_VVS2_F['PPC'].astype('float64')
                    df_050_059_CUM_VVS2_F['Total'] = df_050_059_CUM_VVS2_F['Total'].astype('float64')
                    df_050_059_CUM_VVS2_F['Total'] = df_050_059_CUM_VVS2_F['Carat'] * df_050_059_CUM_VVS2_F['PPC']


                elif i=="F" and j=="VS1" and k == "CUM":
                    df_050_059_CUM_VS1_F = pd.DataFrame()
                    df_050_059_CUM_VS1_F ['Wt Range'] = None
                    df_050_059_CUM_VS1_F  = df_050_059_CUM_VS1_F.assign(Company=None)
                    df_050_059_CUM_VS1_F  = df_050_059_CUM_VS1_F.assign(Shape=None)
                    df_050_059_CUM_VS1_F  = df_050_059_CUM_VS1_F.assign(Carat=None)
                    df_050_059_CUM_VS1_F  = df_050_059_CUM_VS1_F.assign(Color=None)
                    df_050_059_CUM_VS1_F  = df_050_059_CUM_VS1_F.assign(Clarity=None)
                    df_050_059_CUM_VS1_F  = df_050_059_CUM_VS1_F.assign(Cut=None)
                    df_050_059_CUM_VS1_F  = df_050_059_CUM_VS1_F.assign(Polish=None)
                    df_050_059_CUM_VS1_F  = df_050_059_CUM_VS1_F.assign(Symmetry=None)
                    df_050_059_CUM_VS1_F  = df_050_059_CUM_VS1_F.assign(Ratio=None)
                    df_050_059_CUM_VS1_F  = df_050_059_CUM_VS1_F.assign(PPC=None)
                    df_050_059_CUM_VS1_F  = df_050_059_CUM_VS1_F.assign(Total=None)
                    df_050_059_CUM_VS1_F ['Wt Range'] = listwtrange
                    df_050_059_CUM_VS1_F ['Company'] = listcom
                    df_050_059_CUM_VS1_F ['Shape'] = listshap
                    df_050_059_CUM_VS1_F ['Carat'] = listcar
                    df_050_059_CUM_VS1_F ['Color'] = listcol
                    df_050_059_CUM_VS1_F ['Clarity'] = listclar
                    df_050_059_CUM_VS1_F ['Cut'] = listcut
                    df_050_059_CUM_VS1_F ['Polish'] = listpol
                    df_050_059_CUM_VS1_F ['Symmetry'] = listsym
                    df_050_059_CUM_VS1_F ['Ratio'] = listrat
                    df_050_059_CUM_VS1_F ['PPC'] = listdesc
                    df_050_059_CUM_VS1_F ['Total'] = listtotal
                    df_050_059_CUM_VS1_F['Carat'] = df_050_059_CUM_VS1_F['Carat'].astype('float64')
                    df_050_059_CUM_VS1_F['PPC'] = df_050_059_CUM_VS1_F['PPC'].astype('float64')
                    df_050_059_CUM_VS1_F['Total'] = df_050_059_CUM_VS1_F['Total'].astype('float64')
                    df_050_059_CUM_VS1_F['Total'] = df_050_059_CUM_VS1_F['Carat'] * df_050_059_CUM_VS1_F['PPC']


                elif i=="F" and j == "VS2" and k == "CUM":
                    df_050_059_CUM_VS2_F = pd.DataFrame()
                    df_050_059_CUM_VS2_F ['Wt Range'] = None
                    df_050_059_CUM_VS2_F  = df_050_059_CUM_VS2_F.assign(Company=None)
                    df_050_059_CUM_VS2_F  = df_050_059_CUM_VS2_F.assign(Shape=None)
                    df_050_059_CUM_VS2_F  = df_050_059_CUM_VS2_F.assign(Carat=None)
                    df_050_059_CUM_VS2_F  = df_050_059_CUM_VS2_F.assign(Color=None)
                    df_050_059_CUM_VS2_F  = df_050_059_CUM_VS2_F.assign(Clarity=None)
                    df_050_059_CUM_VS2_F  = df_050_059_CUM_VS2_F.assign(Cut=None)
                    df_050_059_CUM_VS2_F  = df_050_059_CUM_VS2_F.assign(Polish=None)
                    df_050_059_CUM_VS2_F  = df_050_059_CUM_VS2_F.assign(Symmetry=None)
                    df_050_059_CUM_VS2_F  = df_050_059_CUM_VS2_F.assign(Ratio=None)
                    df_050_059_CUM_VS2_F  = df_050_059_CUM_VS2_F.assign(PPC=None)
                    df_050_059_CUM_VS2_F  = df_050_059_CUM_VS2_F.assign(Total=None)
                    df_050_059_CUM_VS2_F ['Wt Range'] = listwtrange
                    df_050_059_CUM_VS2_F ['Company'] = listcom
                    df_050_059_CUM_VS2_F ['Shape'] = listshap
                    df_050_059_CUM_VS2_F ['Carat'] = listcar
                    df_050_059_CUM_VS2_F ['Color'] = listcol
                    df_050_059_CUM_VS2_F ['Clarity'] = listclar
                    df_050_059_CUM_VS2_F ['Cut'] = listcut
                    df_050_059_CUM_VS2_F ['Polish'] = listpol
                    df_050_059_CUM_VS2_F ['Symmetry'] = listsym
                    df_050_059_CUM_VS2_F ['Ratio'] = listrat
                    df_050_059_CUM_VS2_F ['PPC'] = listdesc
                    df_050_059_CUM_VS2_F ['Total'] = listtotal
                    df_050_059_CUM_VS2_F['Carat'] = df_050_059_CUM_VS2_F['Carat'].astype('float64')
                    df_050_059_CUM_VS2_F['PPC'] = df_050_059_CUM_VS2_F['PPC'].astype('float64')
                    df_050_059_CUM_VS2_F['Total'] = df_050_059_CUM_VS2_F['Total'].astype('float64')
                    df_050_059_CUM_VS2_F['Total'] = df_050_059_CUM_VS2_F['Carat'] * df_050_059_CUM_VS2_F['PPC']


                elif i=="F" and j == "SI1" and k == "CUM":
                    df_050_059_CUM_SI1_F = pd.DataFrame()
                    df_050_059_CUM_SI1_F ['Wt Range'] = None
                    df_050_059_CUM_SI1_F  = df_050_059_CUM_SI1_F.assign(Company=None)
                    df_050_059_CUM_SI1_F  = df_050_059_CUM_SI1_F.assign(Shape=None)
                    df_050_059_CUM_SI1_F  = df_050_059_CUM_SI1_F.assign(Carat=None)
                    df_050_059_CUM_SI1_F  = df_050_059_CUM_SI1_F.assign(Color=None)
                    df_050_059_CUM_SI1_F  = df_050_059_CUM_SI1_F.assign(Clarity=None)
                    df_050_059_CUM_SI1_F  = df_050_059_CUM_SI1_F.assign(Cut=None)
                    df_050_059_CUM_SI1_F  = df_050_059_CUM_SI1_F.assign(Polish=None)
                    df_050_059_CUM_SI1_F  = df_050_059_CUM_SI1_F.assign(Symmetry=None)
                    df_050_059_CUM_SI1_F  = df_050_059_CUM_SI1_F.assign(Ratio=None)
                    df_050_059_CUM_SI1_F  = df_050_059_CUM_SI1_F.assign(PPC=None)
                    df_050_059_CUM_SI1_F  = df_050_059_CUM_SI1_F.assign(Total=None)
                    df_050_059_CUM_SI1_F ['Wt Range'] = listwtrange
                    df_050_059_CUM_SI1_F ['Company'] = listcom
                    df_050_059_CUM_SI1_F ['Shape'] = listshap
                    df_050_059_CUM_SI1_F ['Carat'] = listcar
                    df_050_059_CUM_SI1_F ['Color'] = listcol
                    df_050_059_CUM_SI1_F ['Clarity'] = listclar
                    df_050_059_CUM_SI1_F ['Cut'] = listcut
                    df_050_059_CUM_SI1_F ['Polish'] = listpol
                    df_050_059_CUM_SI1_F ['Symmetry'] = listsym
                    df_050_059_CUM_SI1_F ['Ratio'] = listrat
                    df_050_059_CUM_SI1_F ['PPC'] = listdesc
                    df_050_059_CUM_SI1_F ['Total'] = listtotal
                    df_050_059_CUM_SI1_F['Carat'] = df_050_059_CUM_SI1_F['Carat'].astype('float64')
                    df_050_059_CUM_SI1_F['PPC'] = df_050_059_CUM_SI1_F['PPC'].astype('float64')
                    df_050_059_CUM_SI1_F['Total'] = df_050_059_CUM_SI1_F['Total'].astype('float64')
                    df_050_059_CUM_SI1_F['Total'] = df_050_059_CUM_SI1_F['Carat'] * df_050_059_CUM_SI1_F['PPC']


                elif i=="F" and j == "SI2" and k == "CUM":
                    df_050_059_CUM_SI2_F = pd.DataFrame()
                    df_050_059_CUM_SI2_F ['Wt Range'] = None
                    df_050_059_CUM_SI2_F  = df_050_059_CUM_SI2_F.assign(Company=None)
                    df_050_059_CUM_SI2_F  = df_050_059_CUM_SI2_F.assign(Shape=None)
                    df_050_059_CUM_SI2_F  = df_050_059_CUM_SI2_F.assign(Carat=None)
                    df_050_059_CUM_SI2_F  = df_050_059_CUM_SI2_F.assign(Color=None)
                    df_050_059_CUM_SI2_F  = df_050_059_CUM_SI2_F.assign(Clarity=None)
                    df_050_059_CUM_SI2_F  = df_050_059_CUM_SI2_F.assign(Cut=None)
                    df_050_059_CUM_SI2_F  = df_050_059_CUM_SI2_F.assign(Polish=None)
                    df_050_059_CUM_SI2_F  = df_050_059_CUM_SI2_F.assign(Symmetry=None)
                    df_050_059_CUM_SI2_F  = df_050_059_CUM_SI2_F.assign(Ratio=None)
                    df_050_059_CUM_SI2_F  = df_050_059_CUM_SI2_F.assign(PPC=None)
                    df_050_059_CUM_SI2_F  = df_050_059_CUM_SI2_F.assign(Total=None)
                    df_050_059_CUM_SI2_F ['Wt Range'] = listwtrange
                    df_050_059_CUM_SI2_F ['Company'] = listcom
                    df_050_059_CUM_SI2_F ['Shape'] = listshap
                    df_050_059_CUM_SI2_F ['Carat'] = listcar
                    df_050_059_CUM_SI2_F ['Color'] = listcol
                    df_050_059_CUM_SI2_F ['Clarity'] = listclar
                    df_050_059_CUM_SI2_F ['Cut'] = listcut
                    df_050_059_CUM_SI2_F ['Polish'] = listpol
                    df_050_059_CUM_SI2_F ['Symmetry'] = listsym
                    df_050_059_CUM_SI2_F ['Ratio'] = listrat
                    df_050_059_CUM_SI2_F ['PPC'] = listdesc
                    df_050_059_CUM_SI2_F ['Total'] = listtotal
                    df_050_059_CUM_SI2_F['Carat'] = df_050_059_CUM_SI2_F['Carat'].astype('float64')
                    df_050_059_CUM_SI2_F['PPC'] = df_050_059_CUM_SI2_F['PPC'].astype('float64')
                    df_050_059_CUM_SI2_F['Total'] = df_050_059_CUM_SI2_F['Total'].astype('float64')
                    df_050_059_CUM_SI2_F['Total'] = df_050_059_CUM_SI2_F['Carat'] * df_050_059_CUM_SI2_F['PPC']


                elif i=="F" and j == "I1" and k == "CUM":
                    df_050_059_CUM_I1_F = pd.DataFrame()
                    df_050_059_CUM_I1_F ['Wt Range'] = None
                    df_050_059_CUM_I1_F  = df_050_059_CUM_I1_F.assign(Company=None)
                    df_050_059_CUM_I1_F  = df_050_059_CUM_I1_F.assign(Shape=None)
                    df_050_059_CUM_I1_F  = df_050_059_CUM_I1_F.assign(Carat=None)
                    df_050_059_CUM_I1_F  = df_050_059_CUM_I1_F.assign(Color=None)
                    df_050_059_CUM_I1_F  = df_050_059_CUM_I1_F.assign(Clarity=None)
                    df_050_059_CUM_I1_F  = df_050_059_CUM_I1_F.assign(Cut=None)
                    df_050_059_CUM_I1_F  = df_050_059_CUM_I1_F.assign(Polish=None)
                    df_050_059_CUM_I1_F  = df_050_059_CUM_I1_F.assign(Symmetry=None)
                    df_050_059_CUM_I1_F  = df_050_059_CUM_I1_F.assign(Ratio=None)
                    df_050_059_CUM_I1_F  = df_050_059_CUM_I1_F.assign(PPC=None)
                    df_050_059_CUM_I1_F  = df_050_059_CUM_I1_F.assign(Total=None)
                    df_050_059_CUM_I1_F ['Wt Range'] = listwtrange
                    df_050_059_CUM_I1_F ['Company'] = listcom
                    df_050_059_CUM_I1_F ['Shape'] = listshap
                    df_050_059_CUM_I1_F ['Carat'] = listcar
                    df_050_059_CUM_I1_F ['Color'] = listcol
                    df_050_059_CUM_I1_F ['Clarity'] = listclar
                    df_050_059_CUM_I1_F ['Cut'] = listcut
                    df_050_059_CUM_I1_F ['Polish'] = listpol
                    df_050_059_CUM_I1_F ['Symmetry'] = listsym
                    df_050_059_CUM_I1_F ['Ratio'] = listrat
                    df_050_059_CUM_I1_F ['PPC'] = listdesc
                    df_050_059_CUM_I1_F ['Total'] = listtotal
                    df_050_059_CUM_I1_F['Carat'] = df_050_059_CUM_I1_F['Carat'].astype('float64')
                    df_050_059_CUM_I1_F['PPC'] = df_050_059_CUM_I1_F['PPC'].astype('float64')
                    df_050_059_CUM_I1_F['Total'] = df_050_059_CUM_I1_F['Total'].astype('float64')
                    df_050_059_CUM_I1_F['Total'] = df_050_059_CUM_I1_F['Carat'] * df_050_059_CUM_I1_F['PPC']


                elif i=="F" and j == "I2" and k == "CUM":
                    df_050_059_CUM_I2_F = pd.DataFrame()
                    df_050_059_CUM_I2_F ['Wt Range'] = None
                    df_050_059_CUM_I2_F  = df_050_059_CUM_I2_F.assign(Company=None)
                    df_050_059_CUM_I2_F  = df_050_059_CUM_I2_F.assign(Shape=None)
                    df_050_059_CUM_I2_F  = df_050_059_CUM_I2_F.assign(Carat=None)
                    df_050_059_CUM_I2_F  = df_050_059_CUM_I2_F.assign(Color=None)
                    df_050_059_CUM_I2_F  = df_050_059_CUM_I2_F.assign(Clarity=None)
                    df_050_059_CUM_I2_F  = df_050_059_CUM_I2_F.assign(Cut=None)
                    df_050_059_CUM_I2_F  = df_050_059_CUM_I2_F.assign(Polish=None)
                    df_050_059_CUM_I2_F  = df_050_059_CUM_I2_F.assign(Symmetry=None)
                    df_050_059_CUM_I2_F  = df_050_059_CUM_I2_F.assign(Ratio=None)
                    df_050_059_CUM_I2_F  = df_050_059_CUM_I2_F.assign(PPC=None)
                    df_050_059_CUM_I2_F  = df_050_059_CUM_I2_F.assign(Total=None)
                    df_050_059_CUM_I2_F ['Wt Range'] = listwtrange
                    df_050_059_CUM_I2_F ['Company'] = listcom
                    df_050_059_CUM_I2_F ['Shape'] = listshap
                    df_050_059_CUM_I2_F ['Carat'] = listcar
                    df_050_059_CUM_I2_F ['Color'] = listcol
                    df_050_059_CUM_I2_F ['Clarity'] = listclar
                    df_050_059_CUM_I2_F ['Cut'] = listcut
                    df_050_059_CUM_I2_F ['Polish'] = listpol
                    df_050_059_CUM_I2_F ['Symmetry'] = listsym
                    df_050_059_CUM_I2_F ['Ratio'] = listrat
                    df_050_059_CUM_I2_F ['PPC'] = listdesc
                    df_050_059_CUM_I2_F ['Total'] = listtotal
                    df_050_059_CUM_I2_F['Carat'] = df_050_059_CUM_I2_F['Carat'].astype('float64')
                    df_050_059_CUM_I2_F['PPC'] = df_050_059_CUM_I2_F['PPC'].astype('float64')
                    df_050_059_CUM_I2_F['Total'] = df_050_059_CUM_I2_F['Total'].astype('float64')
                    df_050_059_CUM_I2_F['Total'] = df_050_059_CUM_I2_F['Carat'] * df_050_059_CUM_I2_F['PPC']


                elif i=="G" and j == "IF" and k == "CUM":
                    df_050_059_CUM_IF_G = pd.DataFrame()
                    df_050_059_CUM_IF_G ['Wt Range'] = None
                    df_050_059_CUM_IF_G  = df_050_059_CUM_IF_G.assign(Company=None)
                    df_050_059_CUM_IF_G  = df_050_059_CUM_IF_G.assign(Shape=None)
                    df_050_059_CUM_IF_G  = df_050_059_CUM_IF_G.assign(Carat=None)
                    df_050_059_CUM_IF_G  = df_050_059_CUM_IF_G.assign(Color=None)
                    df_050_059_CUM_IF_G  = df_050_059_CUM_IF_G.assign(Clarity=None)
                    df_050_059_CUM_IF_G  = df_050_059_CUM_IF_G.assign(Cut=None)
                    df_050_059_CUM_IF_G  = df_050_059_CUM_IF_G.assign(Polish=None)
                    df_050_059_CUM_IF_G  = df_050_059_CUM_IF_G.assign(Symmetry=None)
                    df_050_059_CUM_IF_G  = df_050_059_CUM_IF_G.assign(Ratio=None)
                    df_050_059_CUM_IF_G  = df_050_059_CUM_IF_G.assign(PPC=None)
                    df_050_059_CUM_IF_G  = df_050_059_CUM_IF_G.assign(Total=None)
                    df_050_059_CUM_IF_G ['Wt Range'] = listwtrange
                    df_050_059_CUM_IF_G ['Company'] = listcom
                    df_050_059_CUM_IF_G ['Shape'] = listshap
                    df_050_059_CUM_IF_G ['Carat'] = listcar
                    df_050_059_CUM_IF_G ['Color'] = listcol
                    df_050_059_CUM_IF_G ['Clarity'] = listclar
                    df_050_059_CUM_IF_G ['Cut'] = listcut
                    df_050_059_CUM_IF_G ['Polish'] = listpol
                    df_050_059_CUM_IF_G ['Symmetry'] = listsym
                    df_050_059_CUM_IF_G ['Ratio'] = listrat
                    df_050_059_CUM_IF_G ['PPC'] = listdesc
                    df_050_059_CUM_IF_G ['Total'] = listtotal
                    df_050_059_CUM_IF_G['Carat'] = df_050_059_CUM_IF_G['Carat'].astype('float64')
                    df_050_059_CUM_IF_G['PPC'] = df_050_059_CUM_IF_G['PPC'].astype('float64')
                    df_050_059_CUM_IF_G['Total'] = df_050_059_CUM_IF_G['Total'].astype('float64')
                    df_050_059_CUM_IF_G['Total'] = df_050_059_CUM_IF_G['Carat'] * df_050_059_CUM_IF_G['PPC']



                elif i=="G" and j == "VVS1" and k == "CUM":
                    df_050_059_CUM_VVS1_G = pd.DataFrame()
                    df_050_059_CUM_VVS1_G ['Wt Range'] = None
                    df_050_059_CUM_VVS1_G  = df_050_059_CUM_VVS1_G.assign(Company=None)
                    df_050_059_CUM_VVS1_G  = df_050_059_CUM_VVS1_G.assign(Shape=None)
                    df_050_059_CUM_VVS1_G  = df_050_059_CUM_VVS1_G.assign(Carat=None)
                    df_050_059_CUM_VVS1_G  = df_050_059_CUM_VVS1_G.assign(Color=None)
                    df_050_059_CUM_VVS1_G  = df_050_059_CUM_VVS1_G.assign(Clarity=None)
                    df_050_059_CUM_VVS1_G  = df_050_059_CUM_VVS1_G.assign(Cut=None)
                    df_050_059_CUM_VVS1_G  = df_050_059_CUM_VVS1_G.assign(Polish=None)
                    df_050_059_CUM_VVS1_G  = df_050_059_CUM_VVS1_G.assign(Symmetry=None)
                    df_050_059_CUM_VVS1_G  = df_050_059_CUM_VVS1_G.assign(Ratio=None)
                    df_050_059_CUM_VVS1_G  = df_050_059_CUM_VVS1_G.assign(PPC=None)
                    df_050_059_CUM_VVS1_G  = df_050_059_CUM_VVS1_G.assign(Total=None)
                    df_050_059_CUM_VVS1_G ['Wt Range'] = listwtrange
                    df_050_059_CUM_VVS1_G ['Company'] = listcom
                    df_050_059_CUM_VVS1_G ['Shape'] = listshap
                    df_050_059_CUM_VVS1_G ['Carat'] = listcar
                    df_050_059_CUM_VVS1_G ['Color'] = listcol
                    df_050_059_CUM_VVS1_G ['Clarity'] = listclar
                    df_050_059_CUM_VVS1_G ['Cut'] = listcut
                    df_050_059_CUM_VVS1_G ['Polish'] = listpol
                    df_050_059_CUM_VVS1_G ['Symmetry'] = listsym
                    df_050_059_CUM_VVS1_G ['Ratio'] = listrat
                    df_050_059_CUM_VVS1_G ['PPC'] = listdesc
                    df_050_059_CUM_VVS1_G ['Total'] = listtotal
                    df_050_059_CUM_VVS1_G['Carat'] = df_050_059_CUM_VVS1_G['Carat'].astype('float64')
                    df_050_059_CUM_VVS1_G['PPC'] = df_050_059_CUM_VVS1_G['PPC'].astype('float64')
                    df_050_059_CUM_VVS1_G['Total'] = df_050_059_CUM_VVS1_G['Total'].astype('float64')
                    df_050_059_CUM_VVS1_G['Total'] = df_050_059_CUM_VVS1_G['Carat'] * df_050_059_CUM_VVS1_G['PPC']


                elif i=="G" and j == "VVS2" and k == "CUM":
                    df_050_059_CUM_VVS2_G = pd.DataFrame()
                    df_050_059_CUM_VVS2_G ['Wt Range'] = None
                    df_050_059_CUM_VVS2_G  = df_050_059_CUM_VVS2_G.assign(Company=None)
                    df_050_059_CUM_VVS2_G  = df_050_059_CUM_VVS2_G.assign(Shape=None)
                    df_050_059_CUM_VVS2_G  = df_050_059_CUM_VVS2_G.assign(Carat=None)
                    df_050_059_CUM_VVS2_G  = df_050_059_CUM_VVS2_G.assign(Color=None)
                    df_050_059_CUM_VVS2_G  = df_050_059_CUM_VVS2_G.assign(Clarity=None)
                    df_050_059_CUM_VVS2_G  = df_050_059_CUM_VVS2_G.assign(Cut=None)
                    df_050_059_CUM_VVS2_G  = df_050_059_CUM_VVS2_G.assign(Polish=None)
                    df_050_059_CUM_VVS2_G  = df_050_059_CUM_VVS2_G.assign(Symmetry=None)
                    df_050_059_CUM_VVS2_G  = df_050_059_CUM_VVS2_G.assign(Ratio=None)
                    df_050_059_CUM_VVS2_G  = df_050_059_CUM_VVS2_G.assign(PPC=None)
                    df_050_059_CUM_VVS2_G  = df_050_059_CUM_VVS2_G.assign(Total=None)
                    df_050_059_CUM_VVS2_G ['Wt Range'] = listwtrange
                    df_050_059_CUM_VVS2_G ['Company'] = listcom
                    df_050_059_CUM_VVS2_G ['Shape'] = listshap
                    df_050_059_CUM_VVS2_G ['Carat'] = listcar
                    df_050_059_CUM_VVS2_G ['Color'] = listcol
                    df_050_059_CUM_VVS2_G ['Clarity'] = listclar
                    df_050_059_CUM_VVS2_G ['Cut'] = listcut
                    df_050_059_CUM_VVS2_G ['Polish'] = listpol
                    df_050_059_CUM_VVS2_G ['Symmetry'] = listsym
                    df_050_059_CUM_VVS2_G ['Ratio'] = listrat
                    df_050_059_CUM_VVS2_G ['PPC'] = listdesc
                    df_050_059_CUM_VVS2_G ['Total'] = listtotal
                    df_050_059_CUM_VVS2_G['Carat'] = df_050_059_CUM_VVS2_G['Carat'].astype('float64')
                    df_050_059_CUM_VVS2_G['PPC'] = df_050_059_CUM_VVS2_G['PPC'].astype('float64')
                    df_050_059_CUM_VVS2_G['Total'] = df_050_059_CUM_VVS2_G['Total'].astype('float64')
                    df_050_059_CUM_VVS2_G['Total'] = df_050_059_CUM_VVS2_G['Carat'] * df_050_059_CUM_VVS2_G['PPC']


                elif i=="G" and j=="VS1" and k == "CUM":
                    df_050_059_CUM_VS1_G = pd.DataFrame()
                    df_050_059_CUM_VS1_G ['Wt Range'] = None
                    df_050_059_CUM_VS1_G  = df_050_059_CUM_VS1_G.assign(Company=None)
                    df_050_059_CUM_VS1_G  = df_050_059_CUM_VS1_G.assign(Shape=None)
                    df_050_059_CUM_VS1_G  = df_050_059_CUM_VS1_G.assign(Carat=None)
                    df_050_059_CUM_VS1_G  = df_050_059_CUM_VS1_G.assign(Color=None)
                    df_050_059_CUM_VS1_G  = df_050_059_CUM_VS1_G.assign(Clarity=None)
                    df_050_059_CUM_VS1_G  = df_050_059_CUM_VS1_G.assign(Cut=None)
                    df_050_059_CUM_VS1_G  = df_050_059_CUM_VS1_G.assign(Polish=None)
                    df_050_059_CUM_VS1_G  = df_050_059_CUM_VS1_G.assign(Symmetry=None)
                    df_050_059_CUM_VS1_G  = df_050_059_CUM_VS1_G.assign(Ratio=None)
                    df_050_059_CUM_VS1_G  = df_050_059_CUM_VS1_G.assign(PPC=None)
                    df_050_059_CUM_VS1_G  = df_050_059_CUM_VS1_G.assign(Total=None)
                    df_050_059_CUM_VS1_G ['Wt Range'] = listwtrange
                    df_050_059_CUM_VS1_G ['Company'] = listcom
                    df_050_059_CUM_VS1_G ['Shape'] = listshap
                    df_050_059_CUM_VS1_G ['Carat'] = listcar
                    df_050_059_CUM_VS1_G ['Color'] = listcol
                    df_050_059_CUM_VS1_G ['Clarity'] = listclar
                    df_050_059_CUM_VS1_G ['Cut'] = listcut
                    df_050_059_CUM_VS1_G ['Polish'] = listpol
                    df_050_059_CUM_VS1_G ['Symmetry'] = listsym
                    df_050_059_CUM_VS1_G ['Ratio'] = listrat
                    df_050_059_CUM_VS1_G ['PPC'] = listdesc
                    df_050_059_CUM_VS1_G ['Total'] = listtotal
                    df_050_059_CUM_VS1_G['Carat'] = df_050_059_CUM_VS1_G['Carat'].astype('float64')
                    df_050_059_CUM_VS1_G['PPC'] = df_050_059_CUM_VS1_G['PPC'].astype('float64')
                    df_050_059_CUM_VS1_G['Total'] = df_050_059_CUM_VS1_G['Total'].astype('float64')
                    df_050_059_CUM_VS1_G['Total'] = df_050_059_CUM_VS1_G['Carat'] * df_050_059_CUM_VS1_G['PPC']


                elif i=="G" and j == "VS2" and k == "CUM":
                    df_050_059_CUM_VS2_G = pd.DataFrame()
                    df_050_059_CUM_VS2_G ['Wt Range'] = None
                    df_050_059_CUM_VS2_G  = df_050_059_CUM_VS2_G.assign(Company=None)
                    df_050_059_CUM_VS2_G  = df_050_059_CUM_VS2_G.assign(Shape=None)
                    df_050_059_CUM_VS2_G  = df_050_059_CUM_VS2_G.assign(Carat=None)
                    df_050_059_CUM_VS2_G  = df_050_059_CUM_VS2_G.assign(Color=None)
                    df_050_059_CUM_VS2_G  = df_050_059_CUM_VS2_G.assign(Clarity=None)
                    df_050_059_CUM_VS2_G  = df_050_059_CUM_VS2_G.assign(Cut=None)
                    df_050_059_CUM_VS2_G  = df_050_059_CUM_VS2_G.assign(Polish=None)
                    df_050_059_CUM_VS2_G  = df_050_059_CUM_VS2_G.assign(Symmetry=None)
                    df_050_059_CUM_VS2_G  = df_050_059_CUM_VS2_G.assign(Ratio=None)
                    df_050_059_CUM_VS2_G  = df_050_059_CUM_VS2_G.assign(PPC=None)
                    df_050_059_CUM_VS2_G  = df_050_059_CUM_VS2_G.assign(Total=None)
                    df_050_059_CUM_VS2_G ['Wt Range'] = listwtrange
                    df_050_059_CUM_VS2_G ['Company'] = listcom
                    df_050_059_CUM_VS2_G ['Shape'] = listshap
                    df_050_059_CUM_VS2_G ['Carat'] = listcar
                    df_050_059_CUM_VS2_G ['Color'] = listcol
                    df_050_059_CUM_VS2_G ['Clarity'] = listclar
                    df_050_059_CUM_VS2_G ['Cut'] = listcut
                    df_050_059_CUM_VS2_G ['Polish'] = listpol
                    df_050_059_CUM_VS2_G ['Symmetry'] = listsym
                    df_050_059_CUM_VS2_G ['Ratio'] = listrat
                    df_050_059_CUM_VS2_G ['PPC'] = listdesc
                    df_050_059_CUM_VS2_G ['Total'] = listtotal
                    df_050_059_CUM_VS2_G['Carat'] = df_050_059_CUM_VS2_G['Carat'].astype('float64')
                    df_050_059_CUM_VS2_G['PPC'] = df_050_059_CUM_VS2_G['PPC'].astype('float64')
                    df_050_059_CUM_VS2_G['Total'] = df_050_059_CUM_VS2_G['Total'].astype('float64')
                    df_050_059_CUM_VS2_G['Total'] = df_050_059_CUM_VS2_G['Carat'] * df_050_059_CUM_VS2_G['PPC']


                elif i=="G" and j == "SI1" and k == "CUM":
                    df_050_059_CUM_SI1_G = pd.DataFrame()
                    df_050_059_CUM_SI1_G ['Wt Range'] = None
                    df_050_059_CUM_SI1_G  = df_050_059_CUM_SI1_G.assign(Company=None)
                    df_050_059_CUM_SI1_G  = df_050_059_CUM_SI1_G.assign(Shape=None)
                    df_050_059_CUM_SI1_G  = df_050_059_CUM_SI1_G.assign(Carat=None)
                    df_050_059_CUM_SI1_G  = df_050_059_CUM_SI1_G.assign(Color=None)
                    df_050_059_CUM_SI1_G  = df_050_059_CUM_SI1_G.assign(Clarity=None)
                    df_050_059_CUM_SI1_G  = df_050_059_CUM_SI1_G.assign(Cut=None)
                    df_050_059_CUM_SI1_G  = df_050_059_CUM_SI1_G.assign(Polish=None)
                    df_050_059_CUM_SI1_G  = df_050_059_CUM_SI1_G.assign(Symmetry=None)
                    df_050_059_CUM_SI1_G  = df_050_059_CUM_SI1_G.assign(Ratio=None)
                    df_050_059_CUM_SI1_G  = df_050_059_CUM_SI1_G.assign(PPC=None)
                    df_050_059_CUM_SI1_G  = df_050_059_CUM_SI1_G.assign(Total=None)
                    df_050_059_CUM_SI1_G ['Wt Range'] = listwtrange
                    df_050_059_CUM_SI1_G ['Company'] = listcom
                    df_050_059_CUM_SI1_G ['Shape'] = listshap
                    df_050_059_CUM_SI1_G ['Carat'] = listcar
                    df_050_059_CUM_SI1_G ['Color'] = listcol
                    df_050_059_CUM_SI1_G ['Clarity'] = listclar
                    df_050_059_CUM_SI1_G ['Cut'] = listcut
                    df_050_059_CUM_SI1_G ['Polish'] = listpol
                    df_050_059_CUM_SI1_G ['Symmetry'] = listsym
                    df_050_059_CUM_SI1_G ['Ratio'] = listrat
                    df_050_059_CUM_SI1_G ['PPC'] = listdesc
                    df_050_059_CUM_SI1_G ['Total'] = listtotal
                    df_050_059_CUM_SI1_G['Carat'] = df_050_059_CUM_SI1_G['Carat'].astype('float64')
                    df_050_059_CUM_SI1_G['PPC'] = df_050_059_CUM_SI1_G['PPC'].astype('float64')
                    df_050_059_CUM_SI1_G['Total'] = df_050_059_CUM_SI1_G['Total'].astype('float64')
                    df_050_059_CUM_SI1_G['Total'] = df_050_059_CUM_SI1_G['Carat'] * df_050_059_CUM_SI1_G['PPC']


                elif i=="G" and j == "SI2" and k == "CUM":
                    df_050_059_CUM_SI2_G = pd.DataFrame()
                    df_050_059_CUM_SI2_G ['Wt Range'] = None
                    df_050_059_CUM_SI2_G  = df_050_059_CUM_SI2_G.assign(Company=None)
                    df_050_059_CUM_SI2_G  = df_050_059_CUM_SI2_G.assign(Shape=None)
                    df_050_059_CUM_SI2_G  = df_050_059_CUM_SI2_G.assign(Carat=None)
                    df_050_059_CUM_SI2_G  = df_050_059_CUM_SI2_G.assign(Color=None)
                    df_050_059_CUM_SI2_G  = df_050_059_CUM_SI2_G.assign(Clarity=None)
                    df_050_059_CUM_SI2_G  = df_050_059_CUM_SI2_G.assign(Cut=None)
                    df_050_059_CUM_SI2_G  = df_050_059_CUM_SI2_G.assign(Polish=None)
                    df_050_059_CUM_SI2_G  = df_050_059_CUM_SI2_G.assign(Symmetry=None)
                    df_050_059_CUM_SI2_G  = df_050_059_CUM_SI2_G.assign(Ratio=None)
                    df_050_059_CUM_SI2_G  = df_050_059_CUM_SI2_G.assign(PPC=None)
                    df_050_059_CUM_SI2_G  = df_050_059_CUM_SI2_G.assign(Total=None)
                    df_050_059_CUM_SI2_G ['Wt Range'] = listwtrange
                    df_050_059_CUM_SI2_G ['Company'] = listcom
                    df_050_059_CUM_SI2_G ['Shape'] = listshap
                    df_050_059_CUM_SI2_G ['Carat'] = listcar
                    df_050_059_CUM_SI2_G ['Color'] = listcol
                    df_050_059_CUM_SI2_G ['Clarity'] = listclar
                    df_050_059_CUM_SI2_G ['Cut'] = listcut
                    df_050_059_CUM_SI2_G ['Polish'] = listpol
                    df_050_059_CUM_SI2_G ['Symmetry'] = listsym
                    df_050_059_CUM_SI2_G ['Ratio'] = listrat
                    df_050_059_CUM_SI2_G ['PPC'] = listdesc
                    df_050_059_CUM_SI2_G ['Total'] = listtotal
                    df_050_059_CUM_SI2_G['Carat'] = df_050_059_CUM_SI2_G['Carat'].astype('float64')
                    df_050_059_CUM_SI2_G['PPC'] = df_050_059_CUM_SI2_G['PPC'].astype('float64')
                    df_050_059_CUM_SI2_G['Total'] = df_050_059_CUM_SI2_G['Total'].astype('float64')
                    df_050_059_CUM_SI2_G['Total'] = df_050_059_CUM_SI2_G['Carat'] * df_050_059_CUM_SI2_G['PPC']


                elif i=="G" and j == "I1" and k == "CUM":
                    df_050_059_CUM_I1_G = pd.DataFrame()
                    df_050_059_CUM_I1_G ['Wt Range'] = None
                    df_050_059_CUM_I1_G  = df_050_059_CUM_I1_G.assign(Company=None)
                    df_050_059_CUM_I1_G  = df_050_059_CUM_I1_G.assign(Shape=None)
                    df_050_059_CUM_I1_G  = df_050_059_CUM_I1_G.assign(Carat=None)
                    df_050_059_CUM_I1_G  = df_050_059_CUM_I1_G.assign(Color=None)
                    df_050_059_CUM_I1_G  = df_050_059_CUM_I1_G.assign(Clarity=None)
                    df_050_059_CUM_I1_G  = df_050_059_CUM_I1_G.assign(Cut=None)
                    df_050_059_CUM_I1_G  = df_050_059_CUM_I1_G.assign(Polish=None)
                    df_050_059_CUM_I1_G  = df_050_059_CUM_I1_G.assign(Symmetry=None)
                    df_050_059_CUM_I1_G  = df_050_059_CUM_I1_G.assign(Ratio=None)
                    df_050_059_CUM_I1_G  = df_050_059_CUM_I1_G.assign(PPC=None)
                    df_050_059_CUM_I1_G  = df_050_059_CUM_I1_G.assign(Total=None)
                    df_050_059_CUM_I1_G ['Wt Range'] = listwtrange
                    df_050_059_CUM_I1_G ['Company'] = listcom
                    df_050_059_CUM_I1_G ['Shape'] = listshap
                    df_050_059_CUM_I1_G ['Carat'] = listcar
                    df_050_059_CUM_I1_G ['Color'] = listcol
                    df_050_059_CUM_I1_G ['Clarity'] = listclar
                    df_050_059_CUM_I1_G ['Cut'] = listcut
                    df_050_059_CUM_I1_G ['Polish'] = listpol
                    df_050_059_CUM_I1_G ['Symmetry'] = listsym
                    df_050_059_CUM_I1_G ['Ratio'] = listrat
                    df_050_059_CUM_I1_G ['PPC'] = listdesc
                    df_050_059_CUM_I1_G ['Total'] = listtotal
                    df_050_059_CUM_I1_G['Carat'] = df_050_059_CUM_I1_G['Carat'].astype('float64')
                    df_050_059_CUM_I1_G['PPC'] = df_050_059_CUM_I1_G['PPC'].astype('float64')
                    df_050_059_CUM_I1_G['Total'] = df_050_059_CUM_I1_G['Total'].astype('float64')
                    df_050_059_CUM_I1_G['Total'] = df_050_059_CUM_I1_G['Carat'] * df_050_059_CUM_I1_G['PPC']


                elif i=="G" and j == "I2" and k == "CUM":
                    df_050_059_CUM_I2_G = pd.DataFrame()
                    df_050_059_CUM_I2_G ['Wt Range'] = None
                    df_050_059_CUM_I2_G  = df_050_059_CUM_I2_G.assign(Company=None)
                    df_050_059_CUM_I2_G  = df_050_059_CUM_I2_G.assign(Shape=None)
                    df_050_059_CUM_I2_G  = df_050_059_CUM_I2_G.assign(Carat=None)
                    df_050_059_CUM_I2_G  = df_050_059_CUM_I2_G.assign(Color=None)
                    df_050_059_CUM_I2_G  = df_050_059_CUM_I2_G.assign(Clarity=None)
                    df_050_059_CUM_I2_G  = df_050_059_CUM_I2_G.assign(Cut=None)
                    df_050_059_CUM_I2_G  = df_050_059_CUM_I2_G.assign(Polish=None)
                    df_050_059_CUM_I2_G  = df_050_059_CUM_I2_G.assign(Symmetry=None)
                    df_050_059_CUM_I2_G  = df_050_059_CUM_I2_G.assign(Ratio=None)
                    df_050_059_CUM_I2_G  = df_050_059_CUM_I2_G.assign(PPC=None)
                    df_050_059_CUM_I2_G  = df_050_059_CUM_I2_G.assign(Total=None)
                    df_050_059_CUM_I2_G ['Wt Range'] = listwtrange
                    df_050_059_CUM_I2_G ['Company'] = listcom
                    df_050_059_CUM_I2_G ['Shape'] = listshap
                    df_050_059_CUM_I2_G ['Carat'] = listcar
                    df_050_059_CUM_I2_G ['Color'] = listcol
                    df_050_059_CUM_I2_G ['Clarity'] = listclar
                    df_050_059_CUM_I2_G ['Cut'] = listcut
                    df_050_059_CUM_I2_G ['Polish'] = listpol
                    df_050_059_CUM_I2_G ['Symmetry'] = listsym
                    df_050_059_CUM_I2_G ['Ratio'] = listrat
                    df_050_059_CUM_I2_G ['PPC'] = listdesc
                    df_050_059_CUM_I2_G ['Total'] = listtotal
                    df_050_059_CUM_I2_G['Carat'] = df_050_059_CUM_I2_G['Carat'].astype('float64')
                    df_050_059_CUM_I2_G['PPC'] = df_050_059_CUM_I2_G['PPC'].astype('float64')
                    df_050_059_CUM_I2_G['Total'] = df_050_059_CUM_I2_G['Total'].astype('float64')
                    df_050_059_CUM_I2_G['Total'] = df_050_059_CUM_I2_G['Carat'] * df_050_059_CUM_I2_G['PPC']


                elif i=="H" and j == "IF" and k == "CUM":
                    df_050_059_CUM_IF_H = pd.DataFrame()
                    df_050_059_CUM_IF_H ['Wt Range'] = None
                    df_050_059_CUM_IF_H  = df_050_059_CUM_IF_H.assign(Company=None)
                    df_050_059_CUM_IF_H  = df_050_059_CUM_IF_H.assign(Shape=None)
                    df_050_059_CUM_IF_H  = df_050_059_CUM_IF_H.assign(Carat=None)
                    df_050_059_CUM_IF_H  = df_050_059_CUM_IF_H.assign(Color=None)
                    df_050_059_CUM_IF_H  = df_050_059_CUM_IF_H.assign(Clarity=None)
                    df_050_059_CUM_IF_H  = df_050_059_CUM_IF_H.assign(Cut=None)
                    df_050_059_CUM_IF_H  = df_050_059_CUM_IF_H.assign(Polish=None)
                    df_050_059_CUM_IF_H  = df_050_059_CUM_IF_H.assign(Symmetry=None)
                    df_050_059_CUM_IF_H  = df_050_059_CUM_IF_H.assign(Ratio=None)
                    df_050_059_CUM_IF_H  = df_050_059_CUM_IF_H.assign(PPC=None)
                    df_050_059_CUM_IF_H  = df_050_059_CUM_IF_H.assign(Total=None)
                    df_050_059_CUM_IF_H ['Wt Range'] = listwtrange
                    df_050_059_CUM_IF_H ['Company'] = listcom
                    df_050_059_CUM_IF_H ['Shape'] = listshap
                    df_050_059_CUM_IF_H ['Carat'] = listcar
                    df_050_059_CUM_IF_H ['Color'] = listcol
                    df_050_059_CUM_IF_H ['Clarity'] = listclar
                    df_050_059_CUM_IF_H ['Cut'] = listcut
                    df_050_059_CUM_IF_H ['Polish'] = listpol
                    df_050_059_CUM_IF_H ['Symmetry'] = listsym
                    df_050_059_CUM_IF_H ['Ratio'] = listrat
                    df_050_059_CUM_IF_H ['PPC'] = listdesc
                    df_050_059_CUM_IF_H ['Total'] = listtotal
                    df_050_059_CUM_IF_H['Carat'] = df_050_059_CUM_IF_H['Carat'].astype('float64')
                    df_050_059_CUM_IF_H['PPC'] = df_050_059_CUM_IF_H['PPC'].astype('float64')
                    df_050_059_CUM_IF_H['Total'] = df_050_059_CUM_IF_H['Total'].astype('float64')
                    df_050_059_CUM_IF_H['Total'] = df_050_059_CUM_IF_H['Carat'] * df_050_059_CUM_IF_H['PPC']



                elif i=="H" and j == "VVS1" and k == "CUM":
                    df_050_059_CUM_VVS1_H = pd.DataFrame()
                    df_050_059_CUM_VVS1_H ['Wt Range'] = None
                    df_050_059_CUM_VVS1_H  = df_050_059_CUM_VVS1_H.assign(Company=None)
                    df_050_059_CUM_VVS1_H  = df_050_059_CUM_VVS1_H.assign(Shape=None)
                    df_050_059_CUM_VVS1_H  = df_050_059_CUM_VVS1_H.assign(Carat=None)
                    df_050_059_CUM_VVS1_H  = df_050_059_CUM_VVS1_H.assign(Color=None)
                    df_050_059_CUM_VVS1_H  = df_050_059_CUM_VVS1_H.assign(Clarity=None)
                    df_050_059_CUM_VVS1_H  = df_050_059_CUM_VVS1_H.assign(Cut=None)
                    df_050_059_CUM_VVS1_H  = df_050_059_CUM_VVS1_H.assign(Polish=None)
                    df_050_059_CUM_VVS1_H  = df_050_059_CUM_VVS1_H.assign(Symmetry=None)
                    df_050_059_CUM_VVS1_H  = df_050_059_CUM_VVS1_H.assign(Ratio=None)
                    df_050_059_CUM_VVS1_H  = df_050_059_CUM_VVS1_H.assign(PPC=None)
                    df_050_059_CUM_VVS1_H  = df_050_059_CUM_VVS1_H.assign(Total=None)
                    df_050_059_CUM_VVS1_H ['Wt Range'] = listwtrange
                    df_050_059_CUM_VVS1_H ['Company'] = listcom
                    df_050_059_CUM_VVS1_H ['Shape'] = listshap
                    df_050_059_CUM_VVS1_H ['Carat'] = listcar
                    df_050_059_CUM_VVS1_H ['Color'] = listcol
                    df_050_059_CUM_VVS1_H ['Clarity'] = listclar
                    df_050_059_CUM_VVS1_H ['Cut'] = listcut
                    df_050_059_CUM_VVS1_H ['Polish'] = listpol
                    df_050_059_CUM_VVS1_H ['Symmetry'] = listsym
                    df_050_059_CUM_VVS1_H ['Ratio'] = listrat
                    df_050_059_CUM_VVS1_H ['PPC'] = listdesc
                    df_050_059_CUM_VVS1_H ['Total'] = listtotal
                    df_050_059_CUM_VVS1_H['Carat'] = df_050_059_CUM_VVS1_H['Carat'].astype('float64')
                    df_050_059_CUM_VVS1_H['PPC'] = df_050_059_CUM_VVS1_H['PPC'].astype('float64')
                    df_050_059_CUM_VVS1_H['Total'] = df_050_059_CUM_VVS1_H['Total'].astype('float64')
                    df_050_059_CUM_VVS1_H['Total'] = df_050_059_CUM_VVS1_H['Carat'] * df_050_059_CUM_VVS1_H['PPC']


                elif i=="H" and j == "VVS2" and k == "CUM":
                    df_050_059_CUM_VVS2_H = pd.DataFrame()
                    df_050_059_CUM_VVS2_H ['Wt Range'] = None
                    df_050_059_CUM_VVS2_H  = df_050_059_CUM_VVS2_H.assign(Company=None)
                    df_050_059_CUM_VVS2_H  = df_050_059_CUM_VVS2_H.assign(Shape=None)
                    df_050_059_CUM_VVS2_H  = df_050_059_CUM_VVS2_H.assign(Carat=None)
                    df_050_059_CUM_VVS2_H  = df_050_059_CUM_VVS2_H.assign(Color=None)
                    df_050_059_CUM_VVS2_H  = df_050_059_CUM_VVS2_H.assign(Clarity=None)
                    df_050_059_CUM_VVS2_H  = df_050_059_CUM_VVS2_H.assign(Cut=None)
                    df_050_059_CUM_VVS2_H  = df_050_059_CUM_VVS2_H.assign(Polish=None)
                    df_050_059_CUM_VVS2_H  = df_050_059_CUM_VVS2_H.assign(Symmetry=None)
                    df_050_059_CUM_VVS2_H  = df_050_059_CUM_VVS2_H.assign(Ratio=None)
                    df_050_059_CUM_VVS2_H  = df_050_059_CUM_VVS2_H.assign(PPC=None)
                    df_050_059_CUM_VVS2_H  = df_050_059_CUM_VVS2_H.assign(Total=None)
                    df_050_059_CUM_VVS2_H ['Wt Range'] = listwtrange
                    df_050_059_CUM_VVS2_H ['Company'] = listcom
                    df_050_059_CUM_VVS2_H ['Shape'] = listshap
                    df_050_059_CUM_VVS2_H ['Carat'] = listcar
                    df_050_059_CUM_VVS2_H ['Color'] = listcol
                    df_050_059_CUM_VVS2_H ['Clarity'] = listclar
                    df_050_059_CUM_VVS2_H ['Cut'] = listcut
                    df_050_059_CUM_VVS2_H ['Polish'] = listpol
                    df_050_059_CUM_VVS2_H ['Symmetry'] = listsym
                    df_050_059_CUM_VVS2_H ['Ratio'] = listrat
                    df_050_059_CUM_VVS2_H ['PPC'] = listdesc
                    df_050_059_CUM_VVS2_H ['Total'] = listtotal
                    df_050_059_CUM_VVS2_H['Carat'] = df_050_059_CUM_VVS2_H['Carat'].astype('float64')
                    df_050_059_CUM_VVS2_H['PPC'] = df_050_059_CUM_VVS2_H['PPC'].astype('float64')
                    df_050_059_CUM_VVS2_H['Total'] = df_050_059_CUM_VVS2_H['Total'].astype('float64')
                    df_050_059_CUM_VVS2_H['Total'] = df_050_059_CUM_VVS2_H['Carat'] * df_050_059_CUM_VVS2_H['PPC']


                elif i=="H" and j=="VS1" and k == "CUM":
                    df_050_059_CUM_VS1_H = pd.DataFrame()
                    df_050_059_CUM_VS1_H ['Wt Range'] = None
                    df_050_059_CUM_VS1_H  = df_050_059_CUM_VS1_H.assign(Company=None)
                    df_050_059_CUM_VS1_H  = df_050_059_CUM_VS1_H.assign(Shape=None)
                    df_050_059_CUM_VS1_H  = df_050_059_CUM_VS1_H.assign(Carat=None)
                    df_050_059_CUM_VS1_H  = df_050_059_CUM_VS1_H.assign(Color=None)
                    df_050_059_CUM_VS1_H  = df_050_059_CUM_VS1_H.assign(Clarity=None)
                    df_050_059_CUM_VS1_H  = df_050_059_CUM_VS1_H.assign(Cut=None)
                    df_050_059_CUM_VS1_H  = df_050_059_CUM_VS1_H.assign(Polish=None)
                    df_050_059_CUM_VS1_H  = df_050_059_CUM_VS1_H.assign(Symmetry=None)
                    df_050_059_CUM_VS1_H  = df_050_059_CUM_VS1_H.assign(Ratio=None)
                    df_050_059_CUM_VS1_H  = df_050_059_CUM_VS1_H.assign(PPC=None)
                    df_050_059_CUM_VS1_H  = df_050_059_CUM_VS1_H.assign(Total=None)
                    df_050_059_CUM_VS1_H ['Wt Range'] = listwtrange
                    df_050_059_CUM_VS1_H ['Company'] = listcom
                    df_050_059_CUM_VS1_H ['Shape'] = listshap
                    df_050_059_CUM_VS1_H ['Carat'] = listcar
                    df_050_059_CUM_VS1_H ['Color'] = listcol
                    df_050_059_CUM_VS1_H ['Clarity'] = listclar
                    df_050_059_CUM_VS1_H ['Cut'] = listcut
                    df_050_059_CUM_VS1_H ['Polish'] = listpol
                    df_050_059_CUM_VS1_H ['Symmetry'] = listsym
                    df_050_059_CUM_VS1_H ['Ratio'] = listrat
                    df_050_059_CUM_VS1_H ['PPC'] = listdesc
                    df_050_059_CUM_VS1_H ['Total'] = listtotal
                    df_050_059_CUM_VS1_H['Carat'] = df_050_059_CUM_VS1_H['Carat'].astype('float64')
                    df_050_059_CUM_VS1_H['PPC'] = df_050_059_CUM_VS1_H['PPC'].astype('float64')
                    df_050_059_CUM_VS1_H['Total'] = df_050_059_CUM_VS1_H['Total'].astype('float64')
                    df_050_059_CUM_VS1_H['Total'] = df_050_059_CUM_VS1_H['Carat'] * df_050_059_CUM_VS1_H['PPC']


                elif i=="H" and j == "VS2" and k == "CUM":
                    df_050_059_CUM_VS2_H = pd.DataFrame()
                    df_050_059_CUM_VS2_H ['Wt Range'] = None
                    df_050_059_CUM_VS2_H  = df_050_059_CUM_VS2_H.assign(Company=None)
                    df_050_059_CUM_VS2_H  = df_050_059_CUM_VS2_H.assign(Shape=None)
                    df_050_059_CUM_VS2_H  = df_050_059_CUM_VS2_H.assign(Carat=None)
                    df_050_059_CUM_VS2_H  = df_050_059_CUM_VS2_H.assign(Color=None)
                    df_050_059_CUM_VS2_H  = df_050_059_CUM_VS2_H.assign(Clarity=None)
                    df_050_059_CUM_VS2_H  = df_050_059_CUM_VS2_H.assign(Cut=None)
                    df_050_059_CUM_VS2_H  = df_050_059_CUM_VS2_H.assign(Polish=None)
                    df_050_059_CUM_VS2_H  = df_050_059_CUM_VS2_H.assign(Symmetry=None)
                    df_050_059_CUM_VS2_H  = df_050_059_CUM_VS2_H.assign(Ratio=None)
                    df_050_059_CUM_VS2_H  = df_050_059_CUM_VS2_H.assign(PPC=None)
                    df_050_059_CUM_VS2_H  = df_050_059_CUM_VS2_H.assign(Total=None)
                    df_050_059_CUM_VS2_H ['Wt Range'] = listwtrange
                    df_050_059_CUM_VS2_H ['Company'] = listcom
                    df_050_059_CUM_VS2_H ['Shape'] = listshap
                    df_050_059_CUM_VS2_H ['Carat'] = listcar
                    df_050_059_CUM_VS2_H ['Color'] = listcol
                    df_050_059_CUM_VS2_H ['Clarity'] = listclar
                    df_050_059_CUM_VS2_H ['Cut'] = listcut
                    df_050_059_CUM_VS2_H ['Polish'] = listpol
                    df_050_059_CUM_VS2_H ['Symmetry'] = listsym
                    df_050_059_CUM_VS2_H ['Ratio'] = listrat
                    df_050_059_CUM_VS2_H ['PPC'] = listdesc
                    df_050_059_CUM_VS2_H ['Total'] = listtotal
                    df_050_059_CUM_VS2_H['Carat'] = df_050_059_CUM_VS2_H['Carat'].astype('float64')
                    df_050_059_CUM_VS2_H['PPC'] = df_050_059_CUM_VS2_H['PPC'].astype('float64')
                    df_050_059_CUM_VS2_H['Total'] = df_050_059_CUM_VS2_H['Total'].astype('float64')
                    df_050_059_CUM_VS2_H['Total'] = df_050_059_CUM_VS2_H['Carat'] * df_050_059_CUM_VS2_H['PPC']


                elif i=="H" and j == "SI1" and k == "CUM":
                    df_050_059_CUM_SI1_H = pd.DataFrame()
                    df_050_059_CUM_SI1_H ['Wt Range'] = None
                    df_050_059_CUM_SI1_H  = df_050_059_CUM_SI1_H.assign(Company=None)
                    df_050_059_CUM_SI1_H  = df_050_059_CUM_SI1_H.assign(Shape=None)
                    df_050_059_CUM_SI1_H  = df_050_059_CUM_SI1_H.assign(Carat=None)
                    df_050_059_CUM_SI1_H  = df_050_059_CUM_SI1_H.assign(Color=None)
                    df_050_059_CUM_SI1_H  = df_050_059_CUM_SI1_H.assign(Clarity=None)
                    df_050_059_CUM_SI1_H  = df_050_059_CUM_SI1_H.assign(Cut=None)
                    df_050_059_CUM_SI1_H  = df_050_059_CUM_SI1_H.assign(Polish=None)
                    df_050_059_CUM_SI1_H  = df_050_059_CUM_SI1_H.assign(Symmetry=None)
                    df_050_059_CUM_SI1_H  = df_050_059_CUM_SI1_H.assign(Ratio=None)
                    df_050_059_CUM_SI1_H  = df_050_059_CUM_SI1_H.assign(PPC=None)
                    df_050_059_CUM_SI1_H  = df_050_059_CUM_SI1_H.assign(Total=None)
                    df_050_059_CUM_SI1_H ['Wt Range'] = listwtrange
                    df_050_059_CUM_SI1_H ['Company'] = listcom
                    df_050_059_CUM_SI1_H ['Shape'] = listshap
                    df_050_059_CUM_SI1_H ['Carat'] = listcar
                    df_050_059_CUM_SI1_H ['Color'] = listcol
                    df_050_059_CUM_SI1_H ['Clarity'] = listclar
                    df_050_059_CUM_SI1_H ['Cut'] = listcut
                    df_050_059_CUM_SI1_H ['Polish'] = listpol
                    df_050_059_CUM_SI1_H ['Symmetry'] = listsym
                    df_050_059_CUM_SI1_H ['Ratio'] = listrat
                    df_050_059_CUM_SI1_H ['PPC'] = listdesc
                    df_050_059_CUM_SI1_H ['Total'] = listtotal
                    df_050_059_CUM_SI1_H['Carat'] = df_050_059_CUM_SI1_H['Carat'].astype('float64')
                    df_050_059_CUM_SI1_H['PPC'] = df_050_059_CUM_SI1_H['PPC'].astype('float64')
                    df_050_059_CUM_SI1_H['Total'] = df_050_059_CUM_SI1_H['Total'].astype('float64')
                    df_050_059_CUM_SI1_H['Total'] = df_050_059_CUM_SI1_H['Carat'] * df_050_059_CUM_SI1_H['PPC']


                elif i=="H" and j == "SI2" and k == "CUM":
                    df_050_059_CUM_SI2_H = pd.DataFrame()
                    df_050_059_CUM_SI2_H ['Wt Range'] = None
                    df_050_059_CUM_SI2_H  = df_050_059_CUM_SI2_H.assign(Company=None)
                    df_050_059_CUM_SI2_H  = df_050_059_CUM_SI2_H.assign(Shape=None)
                    df_050_059_CUM_SI2_H  = df_050_059_CUM_SI2_H.assign(Carat=None)
                    df_050_059_CUM_SI2_H  = df_050_059_CUM_SI2_H.assign(Color=None)
                    df_050_059_CUM_SI2_H  = df_050_059_CUM_SI2_H.assign(Clarity=None)
                    df_050_059_CUM_SI2_H  = df_050_059_CUM_SI2_H.assign(Cut=None)
                    df_050_059_CUM_SI2_H  = df_050_059_CUM_SI2_H.assign(Polish=None)
                    df_050_059_CUM_SI2_H  = df_050_059_CUM_SI2_H.assign(Symmetry=None)
                    df_050_059_CUM_SI2_H  = df_050_059_CUM_SI2_H.assign(Ratio=None)
                    df_050_059_CUM_SI2_H  = df_050_059_CUM_SI2_H.assign(PPC=None)
                    df_050_059_CUM_SI2_H  = df_050_059_CUM_SI2_H.assign(Total=None)
                    df_050_059_CUM_SI2_H ['Wt Range'] = listwtrange
                    df_050_059_CUM_SI2_H ['Company'] = listcom
                    df_050_059_CUM_SI2_H ['Shape'] = listshap
                    df_050_059_CUM_SI2_H ['Carat'] = listcar
                    df_050_059_CUM_SI2_H ['Color'] = listcol
                    df_050_059_CUM_SI2_H ['Clarity'] = listclar
                    df_050_059_CUM_SI2_H ['Cut'] = listcut
                    df_050_059_CUM_SI2_H ['Polish'] = listpol
                    df_050_059_CUM_SI2_H ['Symmetry'] = listsym
                    df_050_059_CUM_SI2_H ['Ratio'] = listrat
                    df_050_059_CUM_SI2_H ['PPC'] = listdesc
                    df_050_059_CUM_SI2_H ['Total'] = listtotal
                    df_050_059_CUM_SI2_H['Carat'] = df_050_059_CUM_SI2_H['Carat'].astype('float64')
                    df_050_059_CUM_SI2_H['PPC'] = df_050_059_CUM_SI2_H['PPC'].astype('float64')
                    df_050_059_CUM_SI2_H['Total'] = df_050_059_CUM_SI2_H['Total'].astype('float64')
                    df_050_059_CUM_SI2_H['Total'] = df_050_059_CUM_SI2_H['Carat'] * df_050_059_CUM_SI2_H['PPC']


                elif i=="H" and j == "I1" and k == "CUM":
                    df_050_059_CUM_I1_H = pd.DataFrame()
                    df_050_059_CUM_I1_H ['Wt Range'] = None
                    df_050_059_CUM_I1_H  = df_050_059_CUM_I1_H.assign(Company=None)
                    df_050_059_CUM_I1_H  = df_050_059_CUM_I1_H.assign(Shape=None)
                    df_050_059_CUM_I1_H  = df_050_059_CUM_I1_H.assign(Carat=None)
                    df_050_059_CUM_I1_H  = df_050_059_CUM_I1_H.assign(Color=None)
                    df_050_059_CUM_I1_H  = df_050_059_CUM_I1_H.assign(Clarity=None)
                    df_050_059_CUM_I1_H  = df_050_059_CUM_I1_H.assign(Cut=None)
                    df_050_059_CUM_I1_H  = df_050_059_CUM_I1_H.assign(Polish=None)
                    df_050_059_CUM_I1_H  = df_050_059_CUM_I1_H.assign(Symmetry=None)
                    df_050_059_CUM_I1_H  = df_050_059_CUM_I1_H.assign(Ratio=None)
                    df_050_059_CUM_I1_H  = df_050_059_CUM_I1_H.assign(PPC=None)
                    df_050_059_CUM_I1_H  = df_050_059_CUM_I1_H.assign(Total=None)
                    df_050_059_CUM_I1_H ['Wt Range'] = listwtrange
                    df_050_059_CUM_I1_H ['Company'] = listcom
                    df_050_059_CUM_I1_H ['Shape'] = listshap
                    df_050_059_CUM_I1_H ['Carat'] = listcar
                    df_050_059_CUM_I1_H ['Color'] = listcol
                    df_050_059_CUM_I1_H ['Clarity'] = listclar
                    df_050_059_CUM_I1_H ['Cut'] = listcut
                    df_050_059_CUM_I1_H ['Polish'] = listpol
                    df_050_059_CUM_I1_H ['Symmetry'] = listsym
                    df_050_059_CUM_I1_H ['Ratio'] = listrat
                    df_050_059_CUM_I1_H ['PPC'] = listdesc
                    df_050_059_CUM_I1_H ['Total'] = listtotal
                    df_050_059_CUM_I1_H['Carat'] = df_050_059_CUM_I1_H['Carat'].astype('float64')
                    df_050_059_CUM_I1_H['PPC'] = df_050_059_CUM_I1_H['PPC'].astype('float64')
                    df_050_059_CUM_I1_H['Total'] = df_050_059_CUM_I1_H['Total'].astype('float64')
                    df_050_059_CUM_I1_H['Total'] = df_050_059_CUM_I1_H['Carat'] * df_050_059_CUM_I1_H['PPC']


                elif i=="H" and j == "I2" and k == "CUM":
                    df_050_059_CUM_I2_H = pd.DataFrame()
                    df_050_059_CUM_I2_H ['Wt Range'] = None
                    df_050_059_CUM_I2_H  = df_050_059_CUM_I2_H.assign(Company=None)
                    df_050_059_CUM_I2_H  = df_050_059_CUM_I2_H.assign(Shape=None)
                    df_050_059_CUM_I2_H  = df_050_059_CUM_I2_H.assign(Carat=None)
                    df_050_059_CUM_I2_H  = df_050_059_CUM_I2_H.assign(Color=None)
                    df_050_059_CUM_I2_H  = df_050_059_CUM_I2_H.assign(Clarity=None)
                    df_050_059_CUM_I2_H  = df_050_059_CUM_I2_H.assign(Cut=None)
                    df_050_059_CUM_I2_H  = df_050_059_CUM_I2_H.assign(Polish=None)
                    df_050_059_CUM_I2_H  = df_050_059_CUM_I2_H.assign(Symmetry=None)
                    df_050_059_CUM_I2_H  = df_050_059_CUM_I2_H.assign(Ratio=None)
                    df_050_059_CUM_I2_H  = df_050_059_CUM_I2_H.assign(PPC=None)
                    df_050_059_CUM_I2_H  = df_050_059_CUM_I2_H.assign(Total=None)
                    df_050_059_CUM_I2_H ['Wt Range'] = listwtrange
                    df_050_059_CUM_I2_H ['Company'] = listcom
                    df_050_059_CUM_I2_H ['Shape'] = listshap
                    df_050_059_CUM_I2_H ['Carat'] = listcar
                    df_050_059_CUM_I2_H ['Color'] = listcol
                    df_050_059_CUM_I2_H ['Clarity'] = listclar
                    df_050_059_CUM_I2_H ['Cut'] = listcut
                    df_050_059_CUM_I2_H ['Polish'] = listpol
                    df_050_059_CUM_I2_H ['Symmetry'] = listsym
                    df_050_059_CUM_I2_H ['Ratio'] = listrat
                    df_050_059_CUM_I2_H ['PPC'] = listdesc
                    df_050_059_CUM_I2_H ['Total'] = listtotal
                    df_050_059_CUM_I2_H['Carat'] = df_050_059_CUM_I2_H['Carat'].astype('float64')
                    df_050_059_CUM_I2_H['PPC'] = df_050_059_CUM_I2_H['PPC'].astype('float64')
                    df_050_059_CUM_I2_H['Total'] = df_050_059_CUM_I2_H['Total'].astype('float64')
                    df_050_059_CUM_I2_H['Total'] = df_050_059_CUM_I2_H['Carat'] * df_050_059_CUM_I2_H['PPC']



                elif i== "I" and j == "IF" and k == "CUM":
                    df_050_059_CUM_IF_I = pd.DataFrame()
                    df_050_059_CUM_IF_I ['Wt Range'] = None
                    df_050_059_CUM_IF_I  = df_050_059_CUM_IF_I.assign(Company=None)
                    df_050_059_CUM_IF_I  = df_050_059_CUM_IF_I.assign(Shape=None)
                    df_050_059_CUM_IF_I  = df_050_059_CUM_IF_I.assign(Carat=None)
                    df_050_059_CUM_IF_I  = df_050_059_CUM_IF_I.assign(Color=None)
                    df_050_059_CUM_IF_I  = df_050_059_CUM_IF_I.assign(Clarity=None)
                    df_050_059_CUM_IF_I  = df_050_059_CUM_IF_I.assign(Cut=None)
                    df_050_059_CUM_IF_I  = df_050_059_CUM_IF_I.assign(Polish=None)
                    df_050_059_CUM_IF_I  = df_050_059_CUM_IF_I.assign(Symmetry=None)
                    df_050_059_CUM_IF_I  = df_050_059_CUM_IF_I.assign(Ratio=None)
                    df_050_059_CUM_IF_I  = df_050_059_CUM_IF_I.assign(PPC=None)
                    df_050_059_CUM_IF_I  = df_050_059_CUM_IF_I.assign(Total=None)
                    df_050_059_CUM_IF_I ['Wt Range'] = listwtrange
                    df_050_059_CUM_IF_I ['Company'] = listcom
                    df_050_059_CUM_IF_I ['Shape'] = listshap
                    df_050_059_CUM_IF_I ['Carat'] = listcar
                    df_050_059_CUM_IF_I ['Color'] = listcol
                    df_050_059_CUM_IF_I ['Clarity'] = listclar
                    df_050_059_CUM_IF_I ['Cut'] = listcut
                    df_050_059_CUM_IF_I ['Polish'] = listpol
                    df_050_059_CUM_IF_I ['Symmetry'] = listsym
                    df_050_059_CUM_IF_I ['Ratio'] = listrat
                    df_050_059_CUM_IF_I ['PPC'] = listdesc
                    df_050_059_CUM_IF_I ['Total'] = listtotal
                    df_050_059_CUM_IF_I['Carat'] = df_050_059_CUM_IF_I['Carat'].astype('float64')
                    df_050_059_CUM_IF_I['PPC'] = df_050_059_CUM_IF_I['PPC'].astype('float64')
                    df_050_059_CUM_IF_I['Total'] = df_050_059_CUM_IF_I['Total'].astype('float64')
                    df_050_059_CUM_IF_I['Total'] = df_050_059_CUM_IF_I['Carat'] * df_050_059_CUM_IF_I['PPC']



                elif i== "I" and j == "VVS1" and k == "CUM":
                    df_050_059_CUM_VVS1_I = pd.DataFrame()
                    df_050_059_CUM_VVS1_I ['Wt Range'] = None
                    df_050_059_CUM_VVS1_I  = df_050_059_CUM_VVS1_I.assign(Company=None)
                    df_050_059_CUM_VVS1_I  = df_050_059_CUM_VVS1_I.assign(Shape=None)
                    df_050_059_CUM_VVS1_I  = df_050_059_CUM_VVS1_I.assign(Carat=None)
                    df_050_059_CUM_VVS1_I  = df_050_059_CUM_VVS1_I.assign(Color=None)
                    df_050_059_CUM_VVS1_I  = df_050_059_CUM_VVS1_I.assign(Clarity=None)
                    df_050_059_CUM_VVS1_I  = df_050_059_CUM_VVS1_I.assign(Cut=None)
                    df_050_059_CUM_VVS1_I  = df_050_059_CUM_VVS1_I.assign(Polish=None)
                    df_050_059_CUM_VVS1_I  = df_050_059_CUM_VVS1_I.assign(Symmetry=None)
                    df_050_059_CUM_VVS1_I  = df_050_059_CUM_VVS1_I.assign(Ratio=None)
                    df_050_059_CUM_VVS1_I  = df_050_059_CUM_VVS1_I.assign(PPC=None)
                    df_050_059_CUM_VVS1_I  = df_050_059_CUM_VVS1_I.assign(Total=None)
                    df_050_059_CUM_VVS1_I ['Wt Range'] = listwtrange
                    df_050_059_CUM_VVS1_I ['Company'] = listcom
                    df_050_059_CUM_VVS1_I ['Shape'] = listshap
                    df_050_059_CUM_VVS1_I ['Carat'] = listcar
                    df_050_059_CUM_VVS1_I ['Color'] = listcol
                    df_050_059_CUM_VVS1_I ['Clarity'] = listclar
                    df_050_059_CUM_VVS1_I ['Cut'] = listcut
                    df_050_059_CUM_VVS1_I ['Polish'] = listpol
                    df_050_059_CUM_VVS1_I ['Symmetry'] = listsym
                    df_050_059_CUM_VVS1_I ['Ratio'] = listrat
                    df_050_059_CUM_VVS1_I ['PPC'] = listdesc
                    df_050_059_CUM_VVS1_I ['Total'] = listtotal
                    df_050_059_CUM_VVS1_I['Carat'] = df_050_059_CUM_VVS1_I['Carat'].astype('float64')
                    df_050_059_CUM_VVS1_I['PPC'] = df_050_059_CUM_VVS1_I['PPC'].astype('float64')
                    df_050_059_CUM_VVS1_I['Total'] = df_050_059_CUM_VVS1_I['Total'].astype('float64')
                    df_050_059_CUM_VVS1_I['Total'] = df_050_059_CUM_VVS1_I['Carat'] * df_050_059_CUM_VVS1_I['PPC']


                elif i== "I" and j == "VVS2" and k == "CUM":
                    df_050_059_CUM_VVS2_I = pd.DataFrame()
                    df_050_059_CUM_VVS2_I ['Wt Range'] = None
                    df_050_059_CUM_VVS2_I  = df_050_059_CUM_VVS2_I.assign(Company=None)
                    df_050_059_CUM_VVS2_I  = df_050_059_CUM_VVS2_I.assign(Shape=None)
                    df_050_059_CUM_VVS2_I  = df_050_059_CUM_VVS2_I.assign(Carat=None)
                    df_050_059_CUM_VVS2_I  = df_050_059_CUM_VVS2_I.assign(Color=None)
                    df_050_059_CUM_VVS2_I  = df_050_059_CUM_VVS2_I.assign(Clarity=None)
                    df_050_059_CUM_VVS2_I  = df_050_059_CUM_VVS2_I.assign(Cut=None)
                    df_050_059_CUM_VVS2_I  = df_050_059_CUM_VVS2_I.assign(Polish=None)
                    df_050_059_CUM_VVS2_I  = df_050_059_CUM_VVS2_I.assign(Symmetry=None)
                    df_050_059_CUM_VVS2_I  = df_050_059_CUM_VVS2_I.assign(Ratio=None)
                    df_050_059_CUM_VVS2_I  = df_050_059_CUM_VVS2_I.assign(PPC=None)
                    df_050_059_CUM_VVS2_I  = df_050_059_CUM_VVS2_I.assign(Total=None)
                    df_050_059_CUM_VVS2_I ['Wt Range'] = listwtrange
                    df_050_059_CUM_VVS2_I ['Company'] = listcom
                    df_050_059_CUM_VVS2_I ['Shape'] = listshap
                    df_050_059_CUM_VVS2_I ['Carat'] = listcar
                    df_050_059_CUM_VVS2_I ['Color'] = listcol
                    df_050_059_CUM_VVS2_I ['Clarity'] = listclar
                    df_050_059_CUM_VVS2_I ['Cut'] = listcut
                    df_050_059_CUM_VVS2_I ['Polish'] = listpol
                    df_050_059_CUM_VVS2_I ['Symmetry'] = listsym
                    df_050_059_CUM_VVS2_I ['Ratio'] = listrat
                    df_050_059_CUM_VVS2_I ['PPC'] = listdesc
                    df_050_059_CUM_VVS2_I ['Total'] = listtotal
                    df_050_059_CUM_VVS2_I['Carat'] = df_050_059_CUM_VVS2_I['Carat'].astype('float64')
                    df_050_059_CUM_VVS2_I['PPC'] = df_050_059_CUM_VVS2_I['PPC'].astype('float64')
                    df_050_059_CUM_VVS2_I['Total'] = df_050_059_CUM_VVS2_I['Total'].astype('float64')
                    df_050_059_CUM_VVS2_I['Total'] = df_050_059_CUM_VVS2_I['Carat'] * df_050_059_CUM_VVS2_I['PPC']


                elif i== "I" and j=="VS1" and k == "CUM":
                    df_050_059_CUM_VS1_I = pd.DataFrame()
                    df_050_059_CUM_VS1_I ['Wt Range'] = None
                    df_050_059_CUM_VS1_I  = df_050_059_CUM_VS1_I.assign(Company=None)
                    df_050_059_CUM_VS1_I  = df_050_059_CUM_VS1_I.assign(Shape=None)
                    df_050_059_CUM_VS1_I  = df_050_059_CUM_VS1_I.assign(Carat=None)
                    df_050_059_CUM_VS1_I  = df_050_059_CUM_VS1_I.assign(Color=None)
                    df_050_059_CUM_VS1_I  = df_050_059_CUM_VS1_I.assign(Clarity=None)
                    df_050_059_CUM_VS1_I  = df_050_059_CUM_VS1_I.assign(Cut=None)
                    df_050_059_CUM_VS1_I  = df_050_059_CUM_VS1_I.assign(Polish=None)
                    df_050_059_CUM_VS1_I  = df_050_059_CUM_VS1_I.assign(Symmetry=None)
                    df_050_059_CUM_VS1_I  = df_050_059_CUM_VS1_I.assign(Ratio=None)
                    df_050_059_CUM_VS1_I  = df_050_059_CUM_VS1_I.assign(PPC=None)
                    df_050_059_CUM_VS1_I  = df_050_059_CUM_VS1_I.assign(Total=None)
                    df_050_059_CUM_VS1_I ['Wt Range'] = listwtrange
                    df_050_059_CUM_VS1_I ['Company'] = listcom
                    df_050_059_CUM_VS1_I ['Shape'] = listshap
                    df_050_059_CUM_VS1_I ['Carat'] = listcar
                    df_050_059_CUM_VS1_I ['Color'] = listcol
                    df_050_059_CUM_VS1_I ['Clarity'] = listclar
                    df_050_059_CUM_VS1_I ['Cut'] = listcut
                    df_050_059_CUM_VS1_I ['Polish'] = listpol
                    df_050_059_CUM_VS1_I ['Symmetry'] = listsym
                    df_050_059_CUM_VS1_I ['Ratio'] = listrat
                    df_050_059_CUM_VS1_I ['PPC'] = listdesc
                    df_050_059_CUM_VS1_I ['Total'] = listtotal
                    df_050_059_CUM_VS1_I['Carat'] = df_050_059_CUM_VS1_I['Carat'].astype('float64')
                    df_050_059_CUM_VS1_I['PPC'] = df_050_059_CUM_VS1_I['PPC'].astype('float64')
                    df_050_059_CUM_VS1_I['Total'] = df_050_059_CUM_VS1_I['Total'].astype('float64')
                    df_050_059_CUM_VS1_I['Total'] = df_050_059_CUM_VS1_I['Carat'] * df_050_059_CUM_VS1_I['PPC']


                elif i== "I" and j == "VS2" and k == "CUM":
                    df_050_059_CUM_VS2_I = pd.DataFrame()
                    df_050_059_CUM_VS2_I ['Wt Range'] = None
                    df_050_059_CUM_VS2_I  = df_050_059_CUM_VS2_I.assign(Company=None)
                    df_050_059_CUM_VS2_I  = df_050_059_CUM_VS2_I.assign(Shape=None)
                    df_050_059_CUM_VS2_I  = df_050_059_CUM_VS2_I.assign(Carat=None)
                    df_050_059_CUM_VS2_I  = df_050_059_CUM_VS2_I.assign(Color=None)
                    df_050_059_CUM_VS2_I  = df_050_059_CUM_VS2_I.assign(Clarity=None)
                    df_050_059_CUM_VS2_I  = df_050_059_CUM_VS2_I.assign(Cut=None)
                    df_050_059_CUM_VS2_I  = df_050_059_CUM_VS2_I.assign(Polish=None)
                    df_050_059_CUM_VS2_I  = df_050_059_CUM_VS2_I.assign(Symmetry=None)
                    df_050_059_CUM_VS2_I  = df_050_059_CUM_VS2_I.assign(Ratio=None)
                    df_050_059_CUM_VS2_I  = df_050_059_CUM_VS2_I.assign(PPC=None)
                    df_050_059_CUM_VS2_I  = df_050_059_CUM_VS2_I.assign(Total=None)
                    df_050_059_CUM_VS2_I ['Wt Range'] = listwtrange
                    df_050_059_CUM_VS2_I ['Company'] = listcom
                    df_050_059_CUM_VS2_I ['Shape'] = listshap
                    df_050_059_CUM_VS2_I ['Carat'] = listcar
                    df_050_059_CUM_VS2_I ['Color'] = listcol
                    df_050_059_CUM_VS2_I ['Clarity'] = listclar
                    df_050_059_CUM_VS2_I ['Cut'] = listcut
                    df_050_059_CUM_VS2_I ['Polish'] = listpol
                    df_050_059_CUM_VS2_I ['Symmetry'] = listsym
                    df_050_059_CUM_VS2_I ['Ratio'] = listrat
                    df_050_059_CUM_VS2_I ['PPC'] = listdesc
                    df_050_059_CUM_VS2_I ['Total'] = listtotal
                    df_050_059_CUM_VS2_I['Carat'] = df_050_059_CUM_VS2_I['Carat'].astype('float64')
                    df_050_059_CUM_VS2_I['PPC'] = df_050_059_CUM_VS2_I['PPC'].astype('float64')
                    df_050_059_CUM_VS2_I['Total'] = df_050_059_CUM_VS2_I['Total'].astype('float64')
                    df_050_059_CUM_VS2_I['Total'] = df_050_059_CUM_VS2_I['Carat'] * df_050_059_CUM_VS2_I['PPC']


                elif i== "I" and j == "SI1" and k == "CUM":
                    df_050_059_CUM_SI1_I = pd.DataFrame()
                    df_050_059_CUM_SI1_I ['Wt Range'] = None
                    df_050_059_CUM_SI1_I  = df_050_059_CUM_SI1_I.assign(Company=None)
                    df_050_059_CUM_SI1_I  = df_050_059_CUM_SI1_I.assign(Shape=None)
                    df_050_059_CUM_SI1_I  = df_050_059_CUM_SI1_I.assign(Carat=None)
                    df_050_059_CUM_SI1_I  = df_050_059_CUM_SI1_I.assign(Color=None)
                    df_050_059_CUM_SI1_I  = df_050_059_CUM_SI1_I.assign(Clarity=None)
                    df_050_059_CUM_SI1_I  = df_050_059_CUM_SI1_I.assign(Cut=None)
                    df_050_059_CUM_SI1_I  = df_050_059_CUM_SI1_I.assign(Polish=None)
                    df_050_059_CUM_SI1_I  = df_050_059_CUM_SI1_I.assign(Symmetry=None)
                    df_050_059_CUM_SI1_I  = df_050_059_CUM_SI1_I.assign(Ratio=None)
                    df_050_059_CUM_SI1_I  = df_050_059_CUM_SI1_I.assign(PPC=None)
                    df_050_059_CUM_SI1_I  = df_050_059_CUM_SI1_I.assign(Total=None)
                    df_050_059_CUM_SI1_I ['Wt Range'] = listwtrange
                    df_050_059_CUM_SI1_I ['Company'] = listcom
                    df_050_059_CUM_SI1_I ['Shape'] = listshap
                    df_050_059_CUM_SI1_I ['Carat'] = listcar
                    df_050_059_CUM_SI1_I ['Color'] = listcol
                    df_050_059_CUM_SI1_I ['Clarity'] = listclar
                    df_050_059_CUM_SI1_I ['Cut'] = listcut
                    df_050_059_CUM_SI1_I ['Polish'] = listpol
                    df_050_059_CUM_SI1_I ['Symmetry'] = listsym
                    df_050_059_CUM_SI1_I ['Ratio'] = listrat
                    df_050_059_CUM_SI1_I ['PPC'] = listdesc
                    df_050_059_CUM_SI1_I ['Total'] = listtotal
                    df_050_059_CUM_SI1_I['Carat'] = df_050_059_CUM_SI1_I['Carat'].astype('float64')
                    df_050_059_CUM_SI1_I['PPC'] = df_050_059_CUM_SI1_I['PPC'].astype('float64')
                    df_050_059_CUM_SI1_I['Total'] = df_050_059_CUM_SI1_I['Total'].astype('float64')
                    df_050_059_CUM_SI1_I['Total'] = df_050_059_CUM_SI1_I['Carat'] * df_050_059_CUM_SI1_I['PPC']


                elif i== "I" and j == "SI2" and k == "CUM":
                    df_050_059_CUM_SI2_I = pd.DataFrame()
                    df_050_059_CUM_SI2_I ['Wt Range'] = None
                    df_050_059_CUM_SI2_I  = df_050_059_CUM_SI2_I.assign(Company=None)
                    df_050_059_CUM_SI2_I  = df_050_059_CUM_SI2_I.assign(Shape=None)
                    df_050_059_CUM_SI2_I  = df_050_059_CUM_SI2_I.assign(Carat=None)
                    df_050_059_CUM_SI2_I  = df_050_059_CUM_SI2_I.assign(Color=None)
                    df_050_059_CUM_SI2_I  = df_050_059_CUM_SI2_I.assign(Clarity=None)
                    df_050_059_CUM_SI2_I  = df_050_059_CUM_SI2_I.assign(Cut=None)
                    df_050_059_CUM_SI2_I  = df_050_059_CUM_SI2_I.assign(Polish=None)
                    df_050_059_CUM_SI2_I  = df_050_059_CUM_SI2_I.assign(Symmetry=None)
                    df_050_059_CUM_SI2_I  = df_050_059_CUM_SI2_I.assign(Ratio=None)
                    df_050_059_CUM_SI2_I  = df_050_059_CUM_SI2_I.assign(PPC=None)
                    df_050_059_CUM_SI2_I  = df_050_059_CUM_SI2_I.assign(Total=None)
                    df_050_059_CUM_SI2_I ['Wt Range'] = listwtrange
                    df_050_059_CUM_SI2_I ['Company'] = listcom
                    df_050_059_CUM_SI2_I ['Shape'] = listshap
                    df_050_059_CUM_SI2_I ['Carat'] = listcar
                    df_050_059_CUM_SI2_I ['Color'] = listcol
                    df_050_059_CUM_SI2_I ['Clarity'] = listclar
                    df_050_059_CUM_SI2_I ['Cut'] = listcut
                    df_050_059_CUM_SI2_I ['Polish'] = listpol
                    df_050_059_CUM_SI2_I ['Symmetry'] = listsym
                    df_050_059_CUM_SI2_I ['Ratio'] = listrat
                    df_050_059_CUM_SI2_I ['PPC'] = listdesc
                    df_050_059_CUM_SI2_I ['Total'] = listtotal
                    df_050_059_CUM_SI2_I['Carat'] = df_050_059_CUM_SI2_I['Carat'].astype('float64')
                    df_050_059_CUM_SI2_I['PPC'] = df_050_059_CUM_SI2_I['PPC'].astype('float64')
                    df_050_059_CUM_SI2_I['Total'] = df_050_059_CUM_SI2_I['Total'].astype('float64')
                    df_050_059_CUM_SI2_I['Total'] = df_050_059_CUM_SI2_I['Carat'] * df_050_059_CUM_SI2_I['PPC']


                elif i== "I" and j == "I1" and k == "CUM":
                    df_050_059_CUM_I1_I = pd.DataFrame()
                    df_050_059_CUM_I1_I ['Wt Range'] = None
                    df_050_059_CUM_I1_I  = df_050_059_CUM_I1_I.assign(Company=None)
                    df_050_059_CUM_I1_I  = df_050_059_CUM_I1_I.assign(Shape=None)
                    df_050_059_CUM_I1_I  = df_050_059_CUM_I1_I.assign(Carat=None)
                    df_050_059_CUM_I1_I  = df_050_059_CUM_I1_I.assign(Color=None)
                    df_050_059_CUM_I1_I  = df_050_059_CUM_I1_I.assign(Clarity=None)
                    df_050_059_CUM_I1_I  = df_050_059_CUM_I1_I.assign(Cut=None)
                    df_050_059_CUM_I1_I  = df_050_059_CUM_I1_I.assign(Polish=None)
                    df_050_059_CUM_I1_I  = df_050_059_CUM_I1_I.assign(Symmetry=None)
                    df_050_059_CUM_I1_I  = df_050_059_CUM_I1_I.assign(Ratio=None)
                    df_050_059_CUM_I1_I  = df_050_059_CUM_I1_I.assign(PPC=None)
                    df_050_059_CUM_I1_I  = df_050_059_CUM_I1_I.assign(Total=None)
                    df_050_059_CUM_I1_I ['Wt Range'] = listwtrange
                    df_050_059_CUM_I1_I ['Company'] = listcom
                    df_050_059_CUM_I1_I ['Shape'] = listshap
                    df_050_059_CUM_I1_I ['Carat'] = listcar
                    df_050_059_CUM_I1_I ['Color'] = listcol
                    df_050_059_CUM_I1_I ['Clarity'] = listclar
                    df_050_059_CUM_I1_I ['Cut'] = listcut
                    df_050_059_CUM_I1_I ['Polish'] = listpol
                    df_050_059_CUM_I1_I ['Symmetry'] = listsym
                    df_050_059_CUM_I1_I ['Ratio'] = listrat
                    df_050_059_CUM_I1_I ['PPC'] = listdesc
                    df_050_059_CUM_I1_I ['Total'] = listtotal
                    df_050_059_CUM_I1_I['Carat'] = df_050_059_CUM_I1_I['Carat'].astype('float64')
                    df_050_059_CUM_I1_I['PPC'] = df_050_059_CUM_I1_I['PPC'].astype('float64')
                    df_050_059_CUM_I1_I['Total'] = df_050_059_CUM_I1_I['Total'].astype('float64')
                    df_050_059_CUM_I1_I['Total'] = df_050_059_CUM_I1_I['Carat'] * df_050_059_CUM_I1_I['PPC']


                elif i== "I" and j == "I2" and k == "CUM":
                    df_050_059_CUM_I2_I = pd.DataFrame()
                    df_050_059_CUM_I2_I ['Wt Range'] = None
                    df_050_059_CUM_I2_I  = df_050_059_CUM_I2_I.assign(Company=None)
                    df_050_059_CUM_I2_I  = df_050_059_CUM_I2_I.assign(Shape=None)
                    df_050_059_CUM_I2_I  = df_050_059_CUM_I2_I.assign(Carat=None)
                    df_050_059_CUM_I2_I  = df_050_059_CUM_I2_I.assign(Color=None)
                    df_050_059_CUM_I2_I  = df_050_059_CUM_I2_I.assign(Clarity=None)
                    df_050_059_CUM_I2_I  = df_050_059_CUM_I2_I.assign(Cut=None)
                    df_050_059_CUM_I2_I  = df_050_059_CUM_I2_I.assign(Polish=None)
                    df_050_059_CUM_I2_I  = df_050_059_CUM_I2_I.assign(Symmetry=None)
                    df_050_059_CUM_I2_I  = df_050_059_CUM_I2_I.assign(Ratio=None)
                    df_050_059_CUM_I2_I  = df_050_059_CUM_I2_I.assign(PPC=None)
                    df_050_059_CUM_I2_I  = df_050_059_CUM_I2_I.assign(Total=None)
                    df_050_059_CUM_I2_I ['Wt Range'] = listwtrange
                    df_050_059_CUM_I2_I ['Company'] = listcom
                    df_050_059_CUM_I2_I ['Shape'] = listshap
                    df_050_059_CUM_I2_I ['Carat'] = listcar
                    df_050_059_CUM_I2_I ['Color'] = listcol
                    df_050_059_CUM_I2_I ['Clarity'] = listclar
                    df_050_059_CUM_I2_I ['Cut'] = listcut
                    df_050_059_CUM_I2_I ['Polish'] = listpol
                    df_050_059_CUM_I2_I ['Symmetry'] = listsym
                    df_050_059_CUM_I2_I ['Ratio'] = listrat
                    df_050_059_CUM_I2_I ['PPC'] = listdesc
                    df_050_059_CUM_I2_I ['Total'] = listtotal
                    df_050_059_CUM_I2_I['Carat'] = df_050_059_CUM_I2_I['Carat'].astype('float64')
                    df_050_059_CUM_I2_I['PPC'] = df_050_059_CUM_I2_I['PPC'].astype('float64')
                    df_050_059_CUM_I2_I['Total'] = df_050_059_CUM_I2_I['Total'].astype('float64')
                    df_050_059_CUM_I2_I['Total'] = df_050_059_CUM_I2_I['Carat'] * df_050_059_CUM_I2_I['PPC']


                elif i=="J" and j == "IF" and k == "CUM":
                    df_050_059_CUM_IF_J = pd.DataFrame()
                    df_050_059_CUM_IF_J ['Wt Range'] = None
                    df_050_059_CUM_IF_J  = df_050_059_CUM_IF_J.assign(Company=None)
                    df_050_059_CUM_IF_J  = df_050_059_CUM_IF_J.assign(Shape=None)
                    df_050_059_CUM_IF_J  = df_050_059_CUM_IF_J.assign(Carat=None)
                    df_050_059_CUM_IF_J  = df_050_059_CUM_IF_J.assign(Color=None)
                    df_050_059_CUM_IF_J  = df_050_059_CUM_IF_J.assign(Clarity=None)
                    df_050_059_CUM_IF_J  = df_050_059_CUM_IF_J.assign(Cut=None)
                    df_050_059_CUM_IF_J  = df_050_059_CUM_IF_J.assign(Polish=None)
                    df_050_059_CUM_IF_J  = df_050_059_CUM_IF_J.assign(Symmetry=None)
                    df_050_059_CUM_IF_J  = df_050_059_CUM_IF_J.assign(Ratio=None)
                    df_050_059_CUM_IF_J  = df_050_059_CUM_IF_J.assign(PPC=None)
                    df_050_059_CUM_IF_J  = df_050_059_CUM_IF_J.assign(Total=None)
                    df_050_059_CUM_IF_J ['Wt Range'] = listwtrange
                    df_050_059_CUM_IF_J ['Company'] = listcom
                    df_050_059_CUM_IF_J ['Shape'] = listshap
                    df_050_059_CUM_IF_J ['Carat'] = listcar
                    df_050_059_CUM_IF_J ['Color'] = listcol
                    df_050_059_CUM_IF_J ['Clarity'] = listclar
                    df_050_059_CUM_IF_J ['Cut'] = listcut
                    df_050_059_CUM_IF_J ['Polish'] = listpol
                    df_050_059_CUM_IF_J ['Symmetry'] = listsym
                    df_050_059_CUM_IF_J ['Ratio'] = listrat
                    df_050_059_CUM_IF_J ['PPC'] = listdesc
                    df_050_059_CUM_IF_J ['Total'] = listtotal
                    df_050_059_CUM_IF_J['Carat'] = df_050_059_CUM_IF_J['Carat'].astype('float64')
                    df_050_059_CUM_IF_J['PPC'] = df_050_059_CUM_IF_J['PPC'].astype('float64')
                    df_050_059_CUM_IF_J['Total'] = df_050_059_CUM_IF_J['Total'].astype('float64')
                    df_050_059_CUM_IF_J['Total'] = df_050_059_CUM_IF_J['Carat'] * df_050_059_CUM_IF_J['PPC']



                elif i=="J"  and j == "VVS1" and k == "CUM":
                    df_050_059_CUM_VVS1_J = pd.DataFrame()
                    df_050_059_CUM_VVS1_J ['Wt Range'] = None
                    df_050_059_CUM_VVS1_J  = df_050_059_CUM_VVS1_J.assign(Company=None)
                    df_050_059_CUM_VVS1_J  = df_050_059_CUM_VVS1_J.assign(Shape=None)
                    df_050_059_CUM_VVS1_J  = df_050_059_CUM_VVS1_J.assign(Carat=None)
                    df_050_059_CUM_VVS1_J  = df_050_059_CUM_VVS1_J.assign(Color=None)
                    df_050_059_CUM_VVS1_J  = df_050_059_CUM_VVS1_J.assign(Clarity=None)
                    df_050_059_CUM_VVS1_J  = df_050_059_CUM_VVS1_J.assign(Cut=None)
                    df_050_059_CUM_VVS1_J  = df_050_059_CUM_VVS1_J.assign(Polish=None)
                    df_050_059_CUM_VVS1_J  = df_050_059_CUM_VVS1_J.assign(Symmetry=None)
                    df_050_059_CUM_VVS1_J  = df_050_059_CUM_VVS1_J.assign(Ratio=None)
                    df_050_059_CUM_VVS1_J  = df_050_059_CUM_VVS1_J.assign(PPC=None)
                    df_050_059_CUM_VVS1_J  = df_050_059_CUM_VVS1_J.assign(Total=None)
                    df_050_059_CUM_VVS1_J ['Wt Range'] = listwtrange
                    df_050_059_CUM_VVS1_J ['Company'] = listcom
                    df_050_059_CUM_VVS1_J ['Shape'] = listshap
                    df_050_059_CUM_VVS1_J ['Carat'] = listcar
                    df_050_059_CUM_VVS1_J ['Color'] = listcol
                    df_050_059_CUM_VVS1_J ['Clarity'] = listclar
                    df_050_059_CUM_VVS1_J ['Cut'] = listcut
                    df_050_059_CUM_VVS1_J ['Polish'] = listpol
                    df_050_059_CUM_VVS1_J ['Symmetry'] = listsym
                    df_050_059_CUM_VVS1_J ['Ratio'] = listrat
                    df_050_059_CUM_VVS1_J ['PPC'] = listdesc
                    df_050_059_CUM_VVS1_J ['Total'] = listtotal
                    df_050_059_CUM_VVS1_J['Carat'] = df_050_059_CUM_VVS1_J['Carat'].astype('float64')
                    df_050_059_CUM_VVS1_J['PPC'] = df_050_059_CUM_VVS1_J['PPC'].astype('float64')
                    df_050_059_CUM_VVS1_J['Total'] = df_050_059_CUM_VVS1_J['Total'].astype('float64')
                    df_050_059_CUM_VVS1_J['Total'] = df_050_059_CUM_VVS1_J['Carat'] * df_050_059_CUM_VVS1_J['PPC']


                elif i=="J"  and j == "VVS2" and k == "CUM":
                    df_050_059_CUM_VVS2_J = pd.DataFrame()
                    df_050_059_CUM_VVS2_J ['Wt Range'] = None
                    df_050_059_CUM_VVS2_J  = df_050_059_CUM_VVS2_J.assign(Company=None)
                    df_050_059_CUM_VVS2_J  = df_050_059_CUM_VVS2_J.assign(Shape=None)
                    df_050_059_CUM_VVS2_J  = df_050_059_CUM_VVS2_J.assign(Carat=None)
                    df_050_059_CUM_VVS2_J  = df_050_059_CUM_VVS2_J.assign(Color=None)
                    df_050_059_CUM_VVS2_J  = df_050_059_CUM_VVS2_J.assign(Clarity=None)
                    df_050_059_CUM_VVS2_J  = df_050_059_CUM_VVS2_J.assign(Cut=None)
                    df_050_059_CUM_VVS2_J  = df_050_059_CUM_VVS2_J.assign(Polish=None)
                    df_050_059_CUM_VVS2_J  = df_050_059_CUM_VVS2_J.assign(Symmetry=None)
                    df_050_059_CUM_VVS2_J  = df_050_059_CUM_VVS2_J.assign(Ratio=None)
                    df_050_059_CUM_VVS2_J  = df_050_059_CUM_VVS2_J.assign(PPC=None)
                    df_050_059_CUM_VVS2_J  = df_050_059_CUM_VVS2_J.assign(Total=None)
                    df_050_059_CUM_VVS2_J ['Wt Range'] = listwtrange
                    df_050_059_CUM_VVS2_J ['Company'] = listcom
                    df_050_059_CUM_VVS2_J ['Shape'] = listshap
                    df_050_059_CUM_VVS2_J ['Carat'] = listcar
                    df_050_059_CUM_VVS2_J ['Color'] = listcol
                    df_050_059_CUM_VVS2_J ['Clarity'] = listclar
                    df_050_059_CUM_VVS2_J ['Cut'] = listcut
                    df_050_059_CUM_VVS2_J ['Polish'] = listpol
                    df_050_059_CUM_VVS2_J ['Symmetry'] = listsym
                    df_050_059_CUM_VVS2_J ['Ratio'] = listrat
                    df_050_059_CUM_VVS2_J ['PPC'] = listdesc
                    df_050_059_CUM_VVS2_J ['Total'] = listtotal
                    df_050_059_CUM_VVS2_J['Carat'] = df_050_059_CUM_VVS2_J['Carat'].astype('float64')
                    df_050_059_CUM_VVS2_J['PPC'] = df_050_059_CUM_VVS2_J['PPC'].astype('float64')
                    df_050_059_CUM_VVS2_J['Total'] = df_050_059_CUM_VVS2_J['Total'].astype('float64')
                    df_050_059_CUM_VVS2_J['Total'] = df_050_059_CUM_VVS2_J['Carat'] * df_050_059_CUM_VVS2_J['PPC']


                elif i=="J"  and j=="VS1" and k == "CUM":
                    df_050_059_CUM_VS1_J = pd.DataFrame()
                    df_050_059_CUM_VS1_J ['Wt Range'] = None
                    df_050_059_CUM_VS1_J  = df_050_059_CUM_VS1_J.assign(Company=None)
                    df_050_059_CUM_VS1_J  = df_050_059_CUM_VS1_J.assign(Shape=None)
                    df_050_059_CUM_VS1_J  = df_050_059_CUM_VS1_J.assign(Carat=None)
                    df_050_059_CUM_VS1_J  = df_050_059_CUM_VS1_J.assign(Color=None)
                    df_050_059_CUM_VS1_J  = df_050_059_CUM_VS1_J.assign(Clarity=None)
                    df_050_059_CUM_VS1_J  = df_050_059_CUM_VS1_J.assign(Cut=None)
                    df_050_059_CUM_VS1_J  = df_050_059_CUM_VS1_J.assign(Polish=None)
                    df_050_059_CUM_VS1_J  = df_050_059_CUM_VS1_J.assign(Symmetry=None)
                    df_050_059_CUM_VS1_J  = df_050_059_CUM_VS1_J.assign(Ratio=None)
                    df_050_059_CUM_VS1_J  = df_050_059_CUM_VS1_J.assign(PPC=None)
                    df_050_059_CUM_VS1_J  = df_050_059_CUM_VS1_J.assign(Total=None)
                    df_050_059_CUM_VS1_J ['Wt Range'] = listwtrange
                    df_050_059_CUM_VS1_J ['Company'] = listcom
                    df_050_059_CUM_VS1_J ['Shape'] = listshap
                    df_050_059_CUM_VS1_J ['Carat'] = listcar
                    df_050_059_CUM_VS1_J ['Color'] = listcol
                    df_050_059_CUM_VS1_J ['Clarity'] = listclar
                    df_050_059_CUM_VS1_J ['Cut'] = listcut
                    df_050_059_CUM_VS1_J ['Polish'] = listpol
                    df_050_059_CUM_VS1_J ['Symmetry'] = listsym
                    df_050_059_CUM_VS1_J ['Ratio'] = listrat
                    df_050_059_CUM_VS1_J ['PPC'] = listdesc
                    df_050_059_CUM_VS1_J ['Total'] = listtotal
                    df_050_059_CUM_VS1_J['Carat'] = df_050_059_CUM_VS1_J['Carat'].astype('float64')
                    df_050_059_CUM_VS1_J['PPC'] = df_050_059_CUM_VS1_J['PPC'].astype('float64')
                    df_050_059_CUM_VS1_J['Total'] = df_050_059_CUM_VS1_J['Total'].astype('float64')
                    df_050_059_CUM_VS1_J['Total'] = df_050_059_CUM_VS1_J['Carat'] * df_050_059_CUM_VS1_J['PPC']


                elif i=="J"  and j == "VS2" and k == "CUM":
                    df_050_059_CUM_VS2_J = pd.DataFrame()
                    df_050_059_CUM_VS2_J ['Wt Range'] = None
                    df_050_059_CUM_VS2_J  = df_050_059_CUM_VS2_J.assign(Company=None)
                    df_050_059_CUM_VS2_J  = df_050_059_CUM_VS2_J.assign(Shape=None)
                    df_050_059_CUM_VS2_J  = df_050_059_CUM_VS2_J.assign(Carat=None)
                    df_050_059_CUM_VS2_J  = df_050_059_CUM_VS2_J.assign(Color=None)
                    df_050_059_CUM_VS2_J  = df_050_059_CUM_VS2_J.assign(Clarity=None)
                    df_050_059_CUM_VS2_J  = df_050_059_CUM_VS2_J.assign(Cut=None)
                    df_050_059_CUM_VS2_J  = df_050_059_CUM_VS2_J.assign(Polish=None)
                    df_050_059_CUM_VS2_J  = df_050_059_CUM_VS2_J.assign(Symmetry=None)
                    df_050_059_CUM_VS2_J  = df_050_059_CUM_VS2_J.assign(Ratio=None)
                    df_050_059_CUM_VS2_J  = df_050_059_CUM_VS2_J.assign(PPC=None)
                    df_050_059_CUM_VS2_J  = df_050_059_CUM_VS2_J.assign(Total=None)
                    df_050_059_CUM_VS2_J ['Wt Range'] = listwtrange
                    df_050_059_CUM_VS2_J ['Company'] = listcom
                    df_050_059_CUM_VS2_J ['Shape'] = listshap
                    df_050_059_CUM_VS2_J ['Carat'] = listcar
                    df_050_059_CUM_VS2_J ['Color'] = listcol
                    df_050_059_CUM_VS2_J ['Clarity'] = listclar
                    df_050_059_CUM_VS2_J ['Cut'] = listcut
                    df_050_059_CUM_VS2_J ['Polish'] = listpol
                    df_050_059_CUM_VS2_J ['Symmetry'] = listsym
                    df_050_059_CUM_VS2_J ['Ratio'] = listrat
                    df_050_059_CUM_VS2_J ['PPC'] = listdesc
                    df_050_059_CUM_VS2_J ['Total'] = listtotal
                    df_050_059_CUM_VS2_J['Carat'] = df_050_059_CUM_VS2_J['Carat'].astype('float64')
                    df_050_059_CUM_VS2_J['PPC'] = df_050_059_CUM_VS2_J['PPC'].astype('float64')
                    df_050_059_CUM_VS2_J['Total'] = df_050_059_CUM_VS2_J['Total'].astype('float64')
                    df_050_059_CUM_VS2_J['Total'] = df_050_059_CUM_VS2_J['Carat'] * df_050_059_CUM_VS2_J['PPC']


                elif i=="J"  and j == "SI1" and k == "CUM":
                    df_050_059_CUM_SI1_J = pd.DataFrame()
                    df_050_059_CUM_SI1_J ['Wt Range'] = None
                    df_050_059_CUM_SI1_J  = df_050_059_CUM_SI1_J.assign(Company=None)
                    df_050_059_CUM_SI1_J  = df_050_059_CUM_SI1_J.assign(Shape=None)
                    df_050_059_CUM_SI1_J  = df_050_059_CUM_SI1_J.assign(Carat=None)
                    df_050_059_CUM_SI1_J  = df_050_059_CUM_SI1_J.assign(Color=None)
                    df_050_059_CUM_SI1_J  = df_050_059_CUM_SI1_J.assign(Clarity=None)
                    df_050_059_CUM_SI1_J  = df_050_059_CUM_SI1_J.assign(Cut=None)
                    df_050_059_CUM_SI1_J  = df_050_059_CUM_SI1_J.assign(Polish=None)
                    df_050_059_CUM_SI1_J  = df_050_059_CUM_SI1_J.assign(Symmetry=None)
                    df_050_059_CUM_SI1_J  = df_050_059_CUM_SI1_J.assign(Ratio=None)
                    df_050_059_CUM_SI1_J  = df_050_059_CUM_SI1_J.assign(PPC=None)
                    df_050_059_CUM_SI1_J  = df_050_059_CUM_SI1_J.assign(Total=None)
                    df_050_059_CUM_SI1_J ['Wt Range'] = listwtrange
                    df_050_059_CUM_SI1_J ['Company'] = listcom
                    df_050_059_CUM_SI1_J ['Shape'] = listshap
                    df_050_059_CUM_SI1_J ['Carat'] = listcar
                    df_050_059_CUM_SI1_J ['Color'] = listcol
                    df_050_059_CUM_SI1_J ['Clarity'] = listclar
                    df_050_059_CUM_SI1_J ['Cut'] = listcut
                    df_050_059_CUM_SI1_J ['Polish'] = listpol
                    df_050_059_CUM_SI1_J ['Symmetry'] = listsym
                    df_050_059_CUM_SI1_J ['Ratio'] = listrat
                    df_050_059_CUM_SI1_J ['PPC'] = listdesc
                    df_050_059_CUM_SI1_J ['Total'] = listtotal
                    df_050_059_CUM_SI1_J['Carat'] = df_050_059_CUM_SI1_J['Carat'].astype('float64')
                    df_050_059_CUM_SI1_J['PPC'] = df_050_059_CUM_SI1_J['PPC'].astype('float64')
                    df_050_059_CUM_SI1_J['Total'] = df_050_059_CUM_SI1_J['Total'].astype('float64')
                    df_050_059_CUM_SI1_J['Total'] = df_050_059_CUM_SI1_J['Carat'] * df_050_059_CUM_SI1_J['PPC']


                elif i=="J"  and j == "SI2" and k == "CUM":
                    df_050_059_CUM_SI2_J = pd.DataFrame()
                    df_050_059_CUM_SI2_J ['Wt Range'] = None
                    df_050_059_CUM_SI2_J  = df_050_059_CUM_SI2_J.assign(Company=None)
                    df_050_059_CUM_SI2_J  = df_050_059_CUM_SI2_J.assign(Shape=None)
                    df_050_059_CUM_SI2_J  = df_050_059_CUM_SI2_J.assign(Carat=None)
                    df_050_059_CUM_SI2_J  = df_050_059_CUM_SI2_J.assign(Color=None)
                    df_050_059_CUM_SI2_J  = df_050_059_CUM_SI2_J.assign(Clarity=None)
                    df_050_059_CUM_SI2_J  = df_050_059_CUM_SI2_J.assign(Cut=None)
                    df_050_059_CUM_SI2_J  = df_050_059_CUM_SI2_J.assign(Polish=None)
                    df_050_059_CUM_SI2_J  = df_050_059_CUM_SI2_J.assign(Symmetry=None)
                    df_050_059_CUM_SI2_J  = df_050_059_CUM_SI2_J.assign(Ratio=None)
                    df_050_059_CUM_SI2_J  = df_050_059_CUM_SI2_J.assign(PPC=None)
                    df_050_059_CUM_SI2_J  = df_050_059_CUM_SI2_J.assign(Total=None)
                    df_050_059_CUM_SI2_J ['Wt Range'] = listwtrange
                    df_050_059_CUM_SI2_J ['Company'] = listcom
                    df_050_059_CUM_SI2_J ['Shape'] = listshap
                    df_050_059_CUM_SI2_J ['Carat'] = listcar
                    df_050_059_CUM_SI2_J ['Color'] = listcol
                    df_050_059_CUM_SI2_J ['Clarity'] = listclar
                    df_050_059_CUM_SI2_J ['Cut'] = listcut
                    df_050_059_CUM_SI2_J ['Polish'] = listpol
                    df_050_059_CUM_SI2_J ['Symmetry'] = listsym
                    df_050_059_CUM_SI2_J ['Ratio'] = listrat
                    df_050_059_CUM_SI2_J ['PPC'] = listdesc
                    df_050_059_CUM_SI2_J ['Total'] = listtotal
                    df_050_059_CUM_SI2_J['Carat'] = df_050_059_CUM_SI2_J['Carat'].astype('float64')
                    df_050_059_CUM_SI2_J['PPC'] = df_050_059_CUM_SI2_J['PPC'].astype('float64')
                    df_050_059_CUM_SI2_J['Total'] = df_050_059_CUM_SI2_J['Total'].astype('float64')
                    df_050_059_CUM_SI2_J['Total'] = df_050_059_CUM_SI2_J['Carat'] * df_050_059_CUM_SI2_J['PPC']


                elif i=="J"  and j == "I1" and k == "CUM":
                    df_050_059_CUM_I1_J = pd.DataFrame()
                    df_050_059_CUM_I1_J ['Wt Range'] = None
                    df_050_059_CUM_I1_J  = df_050_059_CUM_I1_J.assign(Company=None)
                    df_050_059_CUM_I1_J  = df_050_059_CUM_I1_J.assign(Shape=None)
                    df_050_059_CUM_I1_J  = df_050_059_CUM_I1_J.assign(Carat=None)
                    df_050_059_CUM_I1_J  = df_050_059_CUM_I1_J.assign(Color=None)
                    df_050_059_CUM_I1_J  = df_050_059_CUM_I1_J.assign(Clarity=None)
                    df_050_059_CUM_I1_J  = df_050_059_CUM_I1_J.assign(Cut=None)
                    df_050_059_CUM_I1_J  = df_050_059_CUM_I1_J.assign(Polish=None)
                    df_050_059_CUM_I1_J  = df_050_059_CUM_I1_J.assign(Symmetry=None)
                    df_050_059_CUM_I1_J  = df_050_059_CUM_I1_J.assign(Ratio=None)
                    df_050_059_CUM_I1_J  = df_050_059_CUM_I1_J.assign(PPC=None)
                    df_050_059_CUM_I1_J  = df_050_059_CUM_I1_J.assign(Total=None)
                    df_050_059_CUM_I1_J ['Wt Range'] = listwtrange
                    df_050_059_CUM_I1_J ['Company'] = listcom
                    df_050_059_CUM_I1_J ['Shape'] = listshap
                    df_050_059_CUM_I1_J ['Carat'] = listcar
                    df_050_059_CUM_I1_J ['Color'] = listcol
                    df_050_059_CUM_I1_J ['Clarity'] = listclar
                    df_050_059_CUM_I1_J ['Cut'] = listcut
                    df_050_059_CUM_I1_J ['Polish'] = listpol
                    df_050_059_CUM_I1_J ['Symmetry'] = listsym
                    df_050_059_CUM_I1_J ['Ratio'] = listrat
                    df_050_059_CUM_I1_J ['PPC'] = listdesc
                    df_050_059_CUM_I1_J ['Total'] = listtotal
                    df_050_059_CUM_I1_J['Carat'] = df_050_059_CUM_I1_J['Carat'].astype('float64')
                    df_050_059_CUM_I1_J['PPC'] = df_050_059_CUM_I1_J['PPC'].astype('float64')
                    df_050_059_CUM_I1_J['Total'] = df_050_059_CUM_I1_J['Total'].astype('float64')
                    df_050_059_CUM_I1_J['Total'] = df_050_059_CUM_I1_J['Carat'] * df_050_059_CUM_I1_J['PPC']


                elif i=="J"  and j == "I2" and k == "CUM":
                    df_050_059_CUM_I2_J = pd.DataFrame()
                    df_050_059_CUM_I2_J ['Wt Range'] = None
                    df_050_059_CUM_I2_J  = df_050_059_CUM_I2_J.assign(Company=None)
                    df_050_059_CUM_I2_J  = df_050_059_CUM_I2_J.assign(Shape=None)
                    df_050_059_CUM_I2_J  = df_050_059_CUM_I2_J.assign(Carat=None)
                    df_050_059_CUM_I2_J  = df_050_059_CUM_I2_J.assign(Color=None)
                    df_050_059_CUM_I2_J  = df_050_059_CUM_I2_J.assign(Clarity=None)
                    df_050_059_CUM_I2_J  = df_050_059_CUM_I2_J.assign(Cut=None)
                    df_050_059_CUM_I2_J  = df_050_059_CUM_I2_J.assign(Polish=None)
                    df_050_059_CUM_I2_J  = df_050_059_CUM_I2_J.assign(Symmetry=None)
                    df_050_059_CUM_I2_J  = df_050_059_CUM_I2_J.assign(Ratio=None)
                    df_050_059_CUM_I2_J  = df_050_059_CUM_I2_J.assign(PPC=None)
                    df_050_059_CUM_I2_J  = df_050_059_CUM_I2_J.assign(Total=None)
                    df_050_059_CUM_I2_J ['Wt Range'] = listwtrange
                    df_050_059_CUM_I2_J ['Company'] = listcom
                    df_050_059_CUM_I2_J ['Shape'] = listshap
                    df_050_059_CUM_I2_J ['Carat'] = listcar
                    df_050_059_CUM_I2_J ['Color'] = listcol
                    df_050_059_CUM_I2_J ['Clarity'] = listclar
                    df_050_059_CUM_I2_J ['Cut'] = listcut
                    df_050_059_CUM_I2_J ['Polish'] = listpol
                    df_050_059_CUM_I2_J ['Symmetry'] = listsym
                    df_050_059_CUM_I2_J ['Ratio'] = listrat
                    df_050_059_CUM_I2_J ['PPC'] = listdesc
                    df_050_059_CUM_I2_J ['Total'] = listtotal
                    df_050_059_CUM_I2_J['Carat'] = df_050_059_CUM_I2_J['Carat'].astype('float64')
                    df_050_059_CUM_I2_J['PPC'] = df_050_059_CUM_I2_J['PPC'].astype('float64')
                    df_050_059_CUM_I2_J['Total'] = df_050_059_CUM_I2_J['Total'].astype('float64')
                    df_050_059_CUM_I2_J['Total'] = df_050_059_CUM_I2_J['Carat'] * df_050_059_CUM_I2_J['PPC']


                elif i=="K" and j == "IF" and k == "CUM":
                    df_050_059_CUM_IF_K = pd.DataFrame()
                    df_050_059_CUM_IF_K ['Wt Range'] = None
                    df_050_059_CUM_IF_K  = df_050_059_CUM_IF_K.assign(Company=None)
                    df_050_059_CUM_IF_K  = df_050_059_CUM_IF_K.assign(Shape=None)
                    df_050_059_CUM_IF_K  = df_050_059_CUM_IF_K.assign(Carat=None)
                    df_050_059_CUM_IF_K  = df_050_059_CUM_IF_K.assign(Color=None)
                    df_050_059_CUM_IF_K  = df_050_059_CUM_IF_K.assign(Clarity=None)
                    df_050_059_CUM_IF_K  = df_050_059_CUM_IF_K.assign(Cut=None)
                    df_050_059_CUM_IF_K  = df_050_059_CUM_IF_K.assign(Polish=None)
                    df_050_059_CUM_IF_K  = df_050_059_CUM_IF_K.assign(Symmetry=None)
                    df_050_059_CUM_IF_K  = df_050_059_CUM_IF_K.assign(Ratio=None)
                    df_050_059_CUM_IF_K  = df_050_059_CUM_IF_K.assign(PPC=None)
                    df_050_059_CUM_IF_K  = df_050_059_CUM_IF_K.assign(Total=None)
                    df_050_059_CUM_IF_K ['Wt Range'] = listwtrange
                    df_050_059_CUM_IF_K ['Company'] = listcom
                    df_050_059_CUM_IF_K ['Shape'] = listshap
                    df_050_059_CUM_IF_K ['Carat'] = listcar
                    df_050_059_CUM_IF_K ['Color'] = listcol
                    df_050_059_CUM_IF_K ['Clarity'] = listclar
                    df_050_059_CUM_IF_K ['Cut'] = listcut
                    df_050_059_CUM_IF_K ['Polish'] = listpol
                    df_050_059_CUM_IF_K ['Symmetry'] = listsym
                    df_050_059_CUM_IF_K ['Ratio'] = listrat
                    df_050_059_CUM_IF_K ['PPC'] = listdesc
                    df_050_059_CUM_IF_K ['Total'] = listtotal
                    df_050_059_CUM_IF_K['Carat'] = df_050_059_CUM_IF_K['Carat'].astype('float64')
                    df_050_059_CUM_IF_K['PPC'] = df_050_059_CUM_IF_K['PPC'].astype('float64')
                    df_050_059_CUM_IF_K['Total'] = df_050_059_CUM_IF_K['Total'].astype('float64')
                    df_050_059_CUM_IF_K['Total'] = df_050_059_CUM_IF_K['Carat'] * df_050_059_CUM_IF_K['PPC']



                elif i=="K" and j == "VVS1" and k == "CUM":
                    df_050_059_CUM_VVS1_K = pd.DataFrame()
                    df_050_059_CUM_VVS1_K ['Wt Range'] = None
                    df_050_059_CUM_VVS1_K  = df_050_059_CUM_VVS1_K.assign(Company=None)
                    df_050_059_CUM_VVS1_K  = df_050_059_CUM_VVS1_K.assign(Shape=None)
                    df_050_059_CUM_VVS1_K  = df_050_059_CUM_VVS1_K.assign(Carat=None)
                    df_050_059_CUM_VVS1_K  = df_050_059_CUM_VVS1_K.assign(Color=None)
                    df_050_059_CUM_VVS1_K  = df_050_059_CUM_VVS1_K.assign(Clarity=None)
                    df_050_059_CUM_VVS1_K  = df_050_059_CUM_VVS1_K.assign(Cut=None)
                    df_050_059_CUM_VVS1_K  = df_050_059_CUM_VVS1_K.assign(Polish=None)
                    df_050_059_CUM_VVS1_K  = df_050_059_CUM_VVS1_K.assign(Symmetry=None)
                    df_050_059_CUM_VVS1_K  = df_050_059_CUM_VVS1_K.assign(Ratio=None)
                    df_050_059_CUM_VVS1_K  = df_050_059_CUM_VVS1_K.assign(PPC=None)
                    df_050_059_CUM_VVS1_K  = df_050_059_CUM_VVS1_K.assign(Total=None)
                    df_050_059_CUM_VVS1_K ['Wt Range'] = listwtrange
                    df_050_059_CUM_VVS1_K ['Company'] = listcom
                    df_050_059_CUM_VVS1_K ['Shape'] = listshap
                    df_050_059_CUM_VVS1_K ['Carat'] = listcar
                    df_050_059_CUM_VVS1_K ['Color'] = listcol
                    df_050_059_CUM_VVS1_K ['Clarity'] = listclar
                    df_050_059_CUM_VVS1_K ['Cut'] = listcut
                    df_050_059_CUM_VVS1_K ['Polish'] = listpol
                    df_050_059_CUM_VVS1_K ['Symmetry'] = listsym
                    df_050_059_CUM_VVS1_K ['Ratio'] = listrat
                    df_050_059_CUM_VVS1_K ['PPC'] = listdesc
                    df_050_059_CUM_VVS1_K ['Total'] = listtotal
                    df_050_059_CUM_VVS1_K['Carat'] = df_050_059_CUM_VVS1_K['Carat'].astype('float64')
                    df_050_059_CUM_VVS1_K['PPC'] = df_050_059_CUM_VVS1_K['PPC'].astype('float64')
                    df_050_059_CUM_VVS1_K['Total'] = df_050_059_CUM_VVS1_K['Total'].astype('float64')
                    df_050_059_CUM_VVS1_K['Total'] = df_050_059_CUM_VVS1_K['Carat'] * df_050_059_CUM_VVS1_K['PPC']


                elif i=="K" and j == "VVS2" and k == "CUM":
                    df_050_059_CUM_VVS2_K = pd.DataFrame()
                    df_050_059_CUM_VVS2_K ['Wt Range'] = None
                    df_050_059_CUM_VVS2_K  = df_050_059_CUM_VVS2_K.assign(Company=None)
                    df_050_059_CUM_VVS2_K  = df_050_059_CUM_VVS2_K.assign(Shape=None)
                    df_050_059_CUM_VVS2_K  = df_050_059_CUM_VVS2_K.assign(Carat=None)
                    df_050_059_CUM_VVS2_K  = df_050_059_CUM_VVS2_K.assign(Color=None)
                    df_050_059_CUM_VVS2_K  = df_050_059_CUM_VVS2_K.assign(Clarity=None)
                    df_050_059_CUM_VVS2_K  = df_050_059_CUM_VVS2_K.assign(Cut=None)
                    df_050_059_CUM_VVS2_K  = df_050_059_CUM_VVS2_K.assign(Polish=None)
                    df_050_059_CUM_VVS2_K  = df_050_059_CUM_VVS2_K.assign(Symmetry=None)
                    df_050_059_CUM_VVS2_K  = df_050_059_CUM_VVS2_K.assign(Ratio=None)
                    df_050_059_CUM_VVS2_K  = df_050_059_CUM_VVS2_K.assign(PPC=None)
                    df_050_059_CUM_VVS2_K  = df_050_059_CUM_VVS2_K.assign(Total=None)
                    df_050_059_CUM_VVS2_K ['Wt Range'] = listwtrange
                    df_050_059_CUM_VVS2_K ['Company'] = listcom
                    df_050_059_CUM_VVS2_K ['Shape'] = listshap
                    df_050_059_CUM_VVS2_K ['Carat'] = listcar
                    df_050_059_CUM_VVS2_K ['Color'] = listcol
                    df_050_059_CUM_VVS2_K ['Clarity'] = listclar
                    df_050_059_CUM_VVS2_K ['Cut'] = listcut
                    df_050_059_CUM_VVS2_K ['Polish'] = listpol
                    df_050_059_CUM_VVS2_K ['Symmetry'] = listsym
                    df_050_059_CUM_VVS2_K ['Ratio'] = listrat
                    df_050_059_CUM_VVS2_K ['PPC'] = listdesc
                    df_050_059_CUM_VVS2_K ['Total'] = listtotal
                    df_050_059_CUM_VVS2_K['Carat'] = df_050_059_CUM_VVS2_K['Carat'].astype('float64')
                    df_050_059_CUM_VVS2_K['PPC'] = df_050_059_CUM_VVS2_K['PPC'].astype('float64')
                    df_050_059_CUM_VVS2_K['Total'] = df_050_059_CUM_VVS2_K['Total'].astype('float64')
                    df_050_059_CUM_VVS2_K['Total'] = df_050_059_CUM_VVS2_K['Carat'] * df_050_059_CUM_VVS2_K['PPC']


                elif i=="K" and j=="VS1" and k == "CUM":
                    df_050_059_CUM_VS1_K = pd.DataFrame()
                    df_050_059_CUM_VS1_K ['Wt Range'] = None
                    df_050_059_CUM_VS1_K  = df_050_059_CUM_VS1_K.assign(Company=None)
                    df_050_059_CUM_VS1_K  = df_050_059_CUM_VS1_K.assign(Shape=None)
                    df_050_059_CUM_VS1_K  = df_050_059_CUM_VS1_K.assign(Carat=None)
                    df_050_059_CUM_VS1_K  = df_050_059_CUM_VS1_K.assign(Color=None)
                    df_050_059_CUM_VS1_K  = df_050_059_CUM_VS1_K.assign(Clarity=None)
                    df_050_059_CUM_VS1_K  = df_050_059_CUM_VS1_K.assign(Cut=None)
                    df_050_059_CUM_VS1_K  = df_050_059_CUM_VS1_K.assign(Polish=None)
                    df_050_059_CUM_VS1_K  = df_050_059_CUM_VS1_K.assign(Symmetry=None)
                    df_050_059_CUM_VS1_K  = df_050_059_CUM_VS1_K.assign(Ratio=None)
                    df_050_059_CUM_VS1_K  = df_050_059_CUM_VS1_K.assign(PPC=None)
                    df_050_059_CUM_VS1_K  = df_050_059_CUM_VS1_K.assign(Total=None)
                    df_050_059_CUM_VS1_K ['Wt Range'] = listwtrange
                    df_050_059_CUM_VS1_K ['Company'] = listcom
                    df_050_059_CUM_VS1_K ['Shape'] = listshap
                    df_050_059_CUM_VS1_K ['Carat'] = listcar
                    df_050_059_CUM_VS1_K ['Color'] = listcol
                    df_050_059_CUM_VS1_K ['Clarity'] = listclar
                    df_050_059_CUM_VS1_K ['Cut'] = listcut
                    df_050_059_CUM_VS1_K ['Polish'] = listpol
                    df_050_059_CUM_VS1_K ['Symmetry'] = listsym
                    df_050_059_CUM_VS1_K ['Ratio'] = listrat
                    df_050_059_CUM_VS1_K ['PPC'] = listdesc
                    df_050_059_CUM_VS1_K ['Total'] = listtotal
                    df_050_059_CUM_VS1_K['Carat'] = df_050_059_CUM_VS1_K['Carat'].astype('float64')
                    df_050_059_CUM_VS1_K['PPC'] = df_050_059_CUM_VS1_K['PPC'].astype('float64')
                    df_050_059_CUM_VS1_K['Total'] = df_050_059_CUM_VS1_K['Total'].astype('float64')
                    df_050_059_CUM_VS1_K['Total'] = df_050_059_CUM_VS1_K['Carat'] * df_050_059_CUM_VS1_K['PPC']


                elif i=="K" and j == "VS2" and k == "CUM":
                    df_050_059_CUM_VS2_K = pd.DataFrame()
                    df_050_059_CUM_VS2_K ['Wt Range'] = None
                    df_050_059_CUM_VS2_K  = df_050_059_CUM_VS2_K.assign(Company=None)
                    df_050_059_CUM_VS2_K  = df_050_059_CUM_VS2_K.assign(Shape=None)
                    df_050_059_CUM_VS2_K  = df_050_059_CUM_VS2_K.assign(Carat=None)
                    df_050_059_CUM_VS2_K  = df_050_059_CUM_VS2_K.assign(Color=None)
                    df_050_059_CUM_VS2_K  = df_050_059_CUM_VS2_K.assign(Clarity=None)
                    df_050_059_CUM_VS2_K  = df_050_059_CUM_VS2_K.assign(Cut=None)
                    df_050_059_CUM_VS2_K  = df_050_059_CUM_VS2_K.assign(Polish=None)
                    df_050_059_CUM_VS2_K  = df_050_059_CUM_VS2_K.assign(Symmetry=None)
                    df_050_059_CUM_VS2_K  = df_050_059_CUM_VS2_K.assign(Ratio=None)
                    df_050_059_CUM_VS2_K  = df_050_059_CUM_VS2_K.assign(PPC=None)
                    df_050_059_CUM_VS2_K  = df_050_059_CUM_VS2_K.assign(Total=None)
                    df_050_059_CUM_VS2_K ['Wt Range'] = listwtrange
                    df_050_059_CUM_VS2_K ['Company'] = listcom
                    df_050_059_CUM_VS2_K ['Shape'] = listshap
                    df_050_059_CUM_VS2_K ['Carat'] = listcar
                    df_050_059_CUM_VS2_K ['Color'] = listcol
                    df_050_059_CUM_VS2_K ['Clarity'] = listclar
                    df_050_059_CUM_VS2_K ['Cut'] = listcut
                    df_050_059_CUM_VS2_K ['Polish'] = listpol
                    df_050_059_CUM_VS2_K ['Symmetry'] = listsym
                    df_050_059_CUM_VS2_K ['Ratio'] = listrat
                    df_050_059_CUM_VS2_K ['PPC'] = listdesc
                    df_050_059_CUM_VS2_K ['Total'] = listtotal
                    df_050_059_CUM_VS2_K['Carat'] = df_050_059_CUM_VS2_K['Carat'].astype('float64')
                    df_050_059_CUM_VS2_K['PPC'] = df_050_059_CUM_VS2_K['PPC'].astype('float64')
                    df_050_059_CUM_VS2_K['Total'] = df_050_059_CUM_VS2_K['Total'].astype('float64')
                    df_050_059_CUM_VS2_K['Total'] = df_050_059_CUM_VS2_K['Carat'] * df_050_059_CUM_VS2_K['PPC']


                elif i=="K" and j == "SI1" and k == "CUM":
                    df_050_059_CUM_SI1_K = pd.DataFrame()
                    df_050_059_CUM_SI1_K ['Wt Range'] = None
                    df_050_059_CUM_SI1_K  = df_050_059_CUM_SI1_K.assign(Company=None)
                    df_050_059_CUM_SI1_K  = df_050_059_CUM_SI1_K.assign(Shape=None)
                    df_050_059_CUM_SI1_K  = df_050_059_CUM_SI1_K.assign(Carat=None)
                    df_050_059_CUM_SI1_K  = df_050_059_CUM_SI1_K.assign(Color=None)
                    df_050_059_CUM_SI1_K  = df_050_059_CUM_SI1_K.assign(Clarity=None)
                    df_050_059_CUM_SI1_K  = df_050_059_CUM_SI1_K.assign(Cut=None)
                    df_050_059_CUM_SI1_K  = df_050_059_CUM_SI1_K.assign(Polish=None)
                    df_050_059_CUM_SI1_K  = df_050_059_CUM_SI1_K.assign(Symmetry=None)
                    df_050_059_CUM_SI1_K  = df_050_059_CUM_SI1_K.assign(Ratio=None)
                    df_050_059_CUM_SI1_K  = df_050_059_CUM_SI1_K.assign(PPC=None)
                    df_050_059_CUM_SI1_K  = df_050_059_CUM_SI1_K.assign(Total=None)
                    df_050_059_CUM_SI1_K ['Wt Range'] = listwtrange
                    df_050_059_CUM_SI1_K ['Company'] = listcom
                    df_050_059_CUM_SI1_K ['Shape'] = listshap
                    df_050_059_CUM_SI1_K ['Carat'] = listcar
                    df_050_059_CUM_SI1_K ['Color'] = listcol
                    df_050_059_CUM_SI1_K ['Clarity'] = listclar
                    df_050_059_CUM_SI1_K ['Cut'] = listcut
                    df_050_059_CUM_SI1_K ['Polish'] = listpol
                    df_050_059_CUM_SI1_K ['Symmetry'] = listsym
                    df_050_059_CUM_SI1_K ['Ratio'] = listrat
                    df_050_059_CUM_SI1_K ['PPC'] = listdesc
                    df_050_059_CUM_SI1_K ['Total'] = listtotal
                    df_050_059_CUM_SI1_K['Carat'] = df_050_059_CUM_SI1_K['Carat'].astype('float64')
                    df_050_059_CUM_SI1_K['PPC'] = df_050_059_CUM_SI1_K['PPC'].astype('float64')
                    df_050_059_CUM_SI1_K['Total'] = df_050_059_CUM_SI1_K['Total'].astype('float64')
                    df_050_059_CUM_SI1_K['Total'] = df_050_059_CUM_SI1_K['Carat'] * df_050_059_CUM_SI1_K['PPC']


                elif i=="K" and j == "SI2" and k == "CUM":
                    df_050_059_CUM_SI2_K = pd.DataFrame()
                    df_050_059_CUM_SI2_K ['Wt Range'] = None
                    df_050_059_CUM_SI2_K  = df_050_059_CUM_SI2_K.assign(Company=None)
                    df_050_059_CUM_SI2_K  = df_050_059_CUM_SI2_K.assign(Shape=None)
                    df_050_059_CUM_SI2_K  = df_050_059_CUM_SI2_K.assign(Carat=None)
                    df_050_059_CUM_SI2_K  = df_050_059_CUM_SI2_K.assign(Color=None)
                    df_050_059_CUM_SI2_K  = df_050_059_CUM_SI2_K.assign(Clarity=None)
                    df_050_059_CUM_SI2_K  = df_050_059_CUM_SI2_K.assign(Cut=None)
                    df_050_059_CUM_SI2_K  = df_050_059_CUM_SI2_K.assign(Polish=None)
                    df_050_059_CUM_SI2_K  = df_050_059_CUM_SI2_K.assign(Symmetry=None)
                    df_050_059_CUM_SI2_K  = df_050_059_CUM_SI2_K.assign(Ratio=None)
                    df_050_059_CUM_SI2_K  = df_050_059_CUM_SI2_K.assign(PPC=None)
                    df_050_059_CUM_SI2_K  = df_050_059_CUM_SI2_K.assign(Total=None)
                    df_050_059_CUM_SI2_K ['Wt Range'] = listwtrange
                    df_050_059_CUM_SI2_K ['Company'] = listcom
                    df_050_059_CUM_SI2_K ['Shape'] = listshap
                    df_050_059_CUM_SI2_K ['Carat'] = listcar
                    df_050_059_CUM_SI2_K ['Color'] = listcol
                    df_050_059_CUM_SI2_K ['Clarity'] = listclar
                    df_050_059_CUM_SI2_K ['Cut'] = listcut
                    df_050_059_CUM_SI2_K ['Polish'] = listpol
                    df_050_059_CUM_SI2_K ['Symmetry'] = listsym
                    df_050_059_CUM_SI2_K ['Ratio'] = listrat
                    df_050_059_CUM_SI2_K ['PPC'] = listdesc
                    df_050_059_CUM_SI2_K ['Total'] = listtotal
                    df_050_059_CUM_SI2_K['Carat'] = df_050_059_CUM_SI2_K['Carat'].astype('float64')
                    df_050_059_CUM_SI2_K['PPC'] = df_050_059_CUM_SI2_K['PPC'].astype('float64')
                    df_050_059_CUM_SI2_K['Total'] = df_050_059_CUM_SI2_K['Total'].astype('float64')
                    df_050_059_CUM_SI2_K['Total'] = df_050_059_CUM_SI2_K['Carat'] * df_050_059_CUM_SI2_K['PPC']


                elif i=="K" and j == "I1" and k == "CUM":
                    df_050_059_CUM_I1_K = pd.DataFrame()
                    df_050_059_CUM_I1_K ['Wt Range'] = None
                    df_050_059_CUM_I1_K  = df_050_059_CUM_I1_K.assign(Company=None)
                    df_050_059_CUM_I1_K  = df_050_059_CUM_I1_K.assign(Shape=None)
                    df_050_059_CUM_I1_K  = df_050_059_CUM_I1_K.assign(Carat=None)
                    df_050_059_CUM_I1_K  = df_050_059_CUM_I1_K.assign(Color=None)
                    df_050_059_CUM_I1_K  = df_050_059_CUM_I1_K.assign(Clarity=None)
                    df_050_059_CUM_I1_K  = df_050_059_CUM_I1_K.assign(Cut=None)
                    df_050_059_CUM_I1_K  = df_050_059_CUM_I1_K.assign(Polish=None)
                    df_050_059_CUM_I1_K  = df_050_059_CUM_I1_K.assign(Symmetry=None)
                    df_050_059_CUM_I1_K  = df_050_059_CUM_I1_K.assign(Ratio=None)
                    df_050_059_CUM_I1_K  = df_050_059_CUM_I1_K.assign(PPC=None)
                    df_050_059_CUM_I1_K  = df_050_059_CUM_I1_K.assign(Total=None)
                    df_050_059_CUM_I1_K ['Wt Range'] = listwtrange
                    df_050_059_CUM_I1_K ['Company'] = listcom
                    df_050_059_CUM_I1_K ['Shape'] = listshap
                    df_050_059_CUM_I1_K ['Carat'] = listcar
                    df_050_059_CUM_I1_K ['Color'] = listcol
                    df_050_059_CUM_I1_K ['Clarity'] = listclar
                    df_050_059_CUM_I1_K ['Cut'] = listcut
                    df_050_059_CUM_I1_K ['Polish'] = listpol
                    df_050_059_CUM_I1_K ['Symmetry'] = listsym
                    df_050_059_CUM_I1_K ['Ratio'] = listrat
                    df_050_059_CUM_I1_K ['PPC'] = listdesc
                    df_050_059_CUM_I1_K ['Total'] = listtotal
                    df_050_059_CUM_I1_K['Carat'] = df_050_059_CUM_I1_K['Carat'].astype('float64')
                    df_050_059_CUM_I1_K['PPC'] = df_050_059_CUM_I1_K['PPC'].astype('float64')
                    df_050_059_CUM_I1_K['Total'] = df_050_059_CUM_I1_K['Total'].astype('float64')
                    df_050_059_CUM_I1_K['Total'] = df_050_059_CUM_I1_K['Carat'] * df_050_059_CUM_I1_K['PPC']


                elif i=="K" and j == "I2" and k == "CUM":
                    df_050_059_CUM_I2_K = pd.DataFrame()
                    df_050_059_CUM_I2_K ['Wt Range'] = None
                    df_050_059_CUM_I2_K  = df_050_059_CUM_I2_K.assign(Company=None)
                    df_050_059_CUM_I2_K  = df_050_059_CUM_I2_K.assign(Shape=None)
                    df_050_059_CUM_I2_K  = df_050_059_CUM_I2_K.assign(Carat=None)
                    df_050_059_CUM_I2_K  = df_050_059_CUM_I2_K.assign(Color=None)
                    df_050_059_CUM_I2_K  = df_050_059_CUM_I2_K.assign(Clarity=None)
                    df_050_059_CUM_I2_K  = df_050_059_CUM_I2_K.assign(Cut=None)
                    df_050_059_CUM_I2_K  = df_050_059_CUM_I2_K.assign(Polish=None)
                    df_050_059_CUM_I2_K  = df_050_059_CUM_I2_K.assign(Symmetry=None)
                    df_050_059_CUM_I2_K  = df_050_059_CUM_I2_K.assign(Ratio=None)
                    df_050_059_CUM_I2_K  = df_050_059_CUM_I2_K.assign(PPC=None)
                    df_050_059_CUM_I2_K  = df_050_059_CUM_I2_K.assign(Total=None)
                    df_050_059_CUM_I2_K ['Wt Range'] = listwtrange
                    df_050_059_CUM_I2_K ['Company'] = listcom
                    df_050_059_CUM_I2_K ['Shape'] = listshap
                    df_050_059_CUM_I2_K ['Carat'] = listcar
                    df_050_059_CUM_I2_K ['Color'] = listcol
                    df_050_059_CUM_I2_K ['Clarity'] = listclar
                    df_050_059_CUM_I2_K ['Cut'] = listcut
                    df_050_059_CUM_I2_K ['Polish'] = listpol
                    df_050_059_CUM_I2_K ['Symmetry'] = listsym
                    df_050_059_CUM_I2_K ['Ratio'] = listrat
                    df_050_059_CUM_I2_K ['PPC'] = listdesc
                    df_050_059_CUM_I2_K ['Total'] = listtotal
                    df_050_059_CUM_I2_K['Carat'] = df_050_059_CUM_I2_K['Carat'].astype('float64')
                    df_050_059_CUM_I2_K['PPC'] = df_050_059_CUM_I2_K['PPC'].astype('float64')
                    df_050_059_CUM_I2_K['Total'] = df_050_059_CUM_I2_K['Total'].astype('float64')
                    df_050_059_CUM_I2_K['Total'] = df_050_059_CUM_I2_K['Carat'] * df_050_059_CUM_I2_K['PPC']


                elif i=="L" and j == "IF" and k == "CUM":
                    df_050_059_CUM_IF_L = pd.DataFrame()
                    df_050_059_CUM_IF_L ['Wt Range'] = None
                    df_050_059_CUM_IF_L  = df_050_059_CUM_IF_L.assign(Company=None)
                    df_050_059_CUM_IF_L  = df_050_059_CUM_IF_L.assign(Shape=None)
                    df_050_059_CUM_IF_L  = df_050_059_CUM_IF_L.assign(Carat=None)
                    df_050_059_CUM_IF_L  = df_050_059_CUM_IF_L.assign(Color=None)
                    df_050_059_CUM_IF_L  = df_050_059_CUM_IF_L.assign(Clarity=None)
                    df_050_059_CUM_IF_L  = df_050_059_CUM_IF_L.assign(Cut=None)
                    df_050_059_CUM_IF_L  = df_050_059_CUM_IF_L.assign(Polish=None)
                    df_050_059_CUM_IF_L  = df_050_059_CUM_IF_L.assign(Symmetry=None)
                    df_050_059_CUM_IF_L  = df_050_059_CUM_IF_L.assign(Ratio=None)
                    df_050_059_CUM_IF_L  = df_050_059_CUM_IF_L.assign(PPC=None)
                    df_050_059_CUM_IF_L  = df_050_059_CUM_IF_L.assign(Total=None)
                    df_050_059_CUM_IF_L ['Wt Range'] = listwtrange
                    df_050_059_CUM_IF_L ['Company'] = listcom
                    df_050_059_CUM_IF_L ['Shape'] = listshap
                    df_050_059_CUM_IF_L ['Carat'] = listcar
                    df_050_059_CUM_IF_L ['Color'] = listcol
                    df_050_059_CUM_IF_L ['Clarity'] = listclar
                    df_050_059_CUM_IF_L ['Cut'] = listcut
                    df_050_059_CUM_IF_L ['Polish'] = listpol
                    df_050_059_CUM_IF_L ['Symmetry'] = listsym
                    df_050_059_CUM_IF_L ['Ratio'] = listrat
                    df_050_059_CUM_IF_L ['PPC'] = listdesc
                    df_050_059_CUM_IF_L ['Total'] = listtotal
                    df_050_059_CUM_IF_L['Carat'] = df_050_059_CUM_IF_L['Carat'].astype('float64')
                    df_050_059_CUM_IF_L['PPC'] = df_050_059_CUM_IF_L['PPC'].astype('float64')
                    df_050_059_CUM_IF_L['Total'] = df_050_059_CUM_IF_L['Total'].astype('float64')
                    df_050_059_CUM_IF_L['Total'] = df_050_059_CUM_IF_L['Carat'] * df_050_059_CUM_IF_L['PPC']


                elif i=="L" and j == "VVS1" and k == "CUM":
                    df_050_059_CUM_VVS1_L = pd.DataFrame()
                    df_050_059_CUM_VVS1_L ['Wt Range'] = None
                    df_050_059_CUM_VVS1_L  = df_050_059_CUM_VVS1_L.assign(Company=None)
                    df_050_059_CUM_VVS1_L  = df_050_059_CUM_VVS1_L.assign(Shape=None)
                    df_050_059_CUM_VVS1_L  = df_050_059_CUM_VVS1_L.assign(Carat=None)
                    df_050_059_CUM_VVS1_L  = df_050_059_CUM_VVS1_L.assign(Color=None)
                    df_050_059_CUM_VVS1_L  = df_050_059_CUM_VVS1_L.assign(Clarity=None)
                    df_050_059_CUM_VVS1_L  = df_050_059_CUM_VVS1_L.assign(Cut=None)
                    df_050_059_CUM_VVS1_L  = df_050_059_CUM_VVS1_L.assign(Polish=None)
                    df_050_059_CUM_VVS1_L  = df_050_059_CUM_VVS1_L.assign(Symmetry=None)
                    df_050_059_CUM_VVS1_L  = df_050_059_CUM_VVS1_L.assign(Ratio=None)
                    df_050_059_CUM_VVS1_L  = df_050_059_CUM_VVS1_L.assign(PPC=None)
                    df_050_059_CUM_VVS1_L  = df_050_059_CUM_VVS1_L.assign(Total=None)
                    df_050_059_CUM_VVS1_L ['Wt Range'] = listwtrange
                    df_050_059_CUM_VVS1_L ['Company'] = listcom
                    df_050_059_CUM_VVS1_L ['Shape'] = listshap
                    df_050_059_CUM_VVS1_L ['Carat'] = listcar
                    df_050_059_CUM_VVS1_L ['Color'] = listcol
                    df_050_059_CUM_VVS1_L ['Clarity'] = listclar
                    df_050_059_CUM_VVS1_L ['Cut'] = listcut
                    df_050_059_CUM_VVS1_L ['Polish'] = listpol
                    df_050_059_CUM_VVS1_L ['Symmetry'] = listsym
                    df_050_059_CUM_VVS1_L ['Ratio'] = listrat
                    df_050_059_CUM_VVS1_L ['PPC'] = listdesc
                    df_050_059_CUM_VVS1_L ['Total'] = listtotal
                    df_050_059_CUM_VVS1_L['Carat'] = df_050_059_CUM_VVS1_L['Carat'].astype('float64')
                    df_050_059_CUM_VVS1_L['PPC'] = df_050_059_CUM_VVS1_L['PPC'].astype('float64')
                    df_050_059_CUM_VVS1_L['Total'] = df_050_059_CUM_VVS1_L['Total'].astype('float64')
                    df_050_059_CUM_VVS1_L['Total'] = df_050_059_CUM_VVS1_L['Carat'] * df_050_059_CUM_VVS1_L['PPC']


                elif i=="L" and j == "VVS2" and k == "CUM":
                    df_050_059_CUM_VVS2_L = pd.DataFrame()
                    df_050_059_CUM_VVS2_L ['Wt Range'] = None
                    df_050_059_CUM_VVS2_L  = df_050_059_CUM_VVS2_L.assign(Company=None)
                    df_050_059_CUM_VVS2_L  = df_050_059_CUM_VVS2_L.assign(Shape=None)
                    df_050_059_CUM_VVS2_L  = df_050_059_CUM_VVS2_L.assign(Carat=None)
                    df_050_059_CUM_VVS2_L  = df_050_059_CUM_VVS2_L.assign(Color=None)
                    df_050_059_CUM_VVS2_L  = df_050_059_CUM_VVS2_L.assign(Clarity=None)
                    df_050_059_CUM_VVS2_L  = df_050_059_CUM_VVS2_L.assign(Cut=None)
                    df_050_059_CUM_VVS2_L  = df_050_059_CUM_VVS2_L.assign(Polish=None)
                    df_050_059_CUM_VVS2_L  = df_050_059_CUM_VVS2_L.assign(Symmetry=None)
                    df_050_059_CUM_VVS2_L  = df_050_059_CUM_VVS2_L.assign(Ratio=None)
                    df_050_059_CUM_VVS2_L  = df_050_059_CUM_VVS2_L.assign(PPC=None)
                    df_050_059_CUM_VVS2_L  = df_050_059_CUM_VVS2_L.assign(Total=None)
                    df_050_059_CUM_VVS2_L ['Wt Range'] = listwtrange
                    df_050_059_CUM_VVS2_L ['Company'] = listcom
                    df_050_059_CUM_VVS2_L ['Shape'] = listshap
                    df_050_059_CUM_VVS2_L ['Carat'] = listcar
                    df_050_059_CUM_VVS2_L ['Color'] = listcol
                    df_050_059_CUM_VVS2_L ['Clarity'] = listclar
                    df_050_059_CUM_VVS2_L ['Cut'] = listcut
                    df_050_059_CUM_VVS2_L ['Polish'] = listpol
                    df_050_059_CUM_VVS2_L ['Symmetry'] = listsym
                    df_050_059_CUM_VVS2_L ['Ratio'] = listrat
                    df_050_059_CUM_VVS2_L ['PPC'] = listdesc
                    df_050_059_CUM_VVS2_L ['Total'] = listtotal
                    df_050_059_CUM_VVS2_L['Carat'] = df_050_059_CUM_VVS2_L['Carat'].astype('float64')
                    df_050_059_CUM_VVS2_L['PPC'] = df_050_059_CUM_VVS2_L['PPC'].astype('float64')
                    df_050_059_CUM_VVS2_L['Total'] = df_050_059_CUM_VVS2_L['Total'].astype('float64')
                    df_050_059_CUM_VVS2_L['Total'] = df_050_059_CUM_VVS2_L['Carat'] * df_050_059_CUM_VVS2_L['PPC']


                elif i=="L" and j=="VS1" and k == "CUM":
                    df_050_059_CUM_VS1_L = pd.DataFrame()
                    df_050_059_CUM_VS1_L ['Wt Range'] = None
                    df_050_059_CUM_VS1_L  = df_050_059_CUM_VS1_L.assign(Company=None)
                    df_050_059_CUM_VS1_L  = df_050_059_CUM_VS1_L.assign(Shape=None)
                    df_050_059_CUM_VS1_L  = df_050_059_CUM_VS1_L.assign(Carat=None)
                    df_050_059_CUM_VS1_L  = df_050_059_CUM_VS1_L.assign(Color=None)
                    df_050_059_CUM_VS1_L  = df_050_059_CUM_VS1_L.assign(Clarity=None)
                    df_050_059_CUM_VS1_L  = df_050_059_CUM_VS1_L.assign(Cut=None)
                    df_050_059_CUM_VS1_L  = df_050_059_CUM_VS1_L.assign(Polish=None)
                    df_050_059_CUM_VS1_L  = df_050_059_CUM_VS1_L.assign(Symmetry=None)
                    df_050_059_CUM_VS1_L  = df_050_059_CUM_VS1_L.assign(Ratio=None)
                    df_050_059_CUM_VS1_L  = df_050_059_CUM_VS1_L.assign(PPC=None)
                    df_050_059_CUM_VS1_L  = df_050_059_CUM_VS1_L.assign(Total=None)
                    df_050_059_CUM_VS1_L ['Wt Range'] = listwtrange
                    df_050_059_CUM_VS1_L ['Company'] = listcom
                    df_050_059_CUM_VS1_L ['Shape'] = listshap
                    df_050_059_CUM_VS1_L ['Carat'] = listcar
                    df_050_059_CUM_VS1_L ['Color'] = listcol
                    df_050_059_CUM_VS1_L ['Clarity'] = listclar
                    df_050_059_CUM_VS1_L ['Cut'] = listcut
                    df_050_059_CUM_VS1_L ['Polish'] = listpol
                    df_050_059_CUM_VS1_L ['Symmetry'] = listsym
                    df_050_059_CUM_VS1_L ['Ratio'] = listrat
                    df_050_059_CUM_VS1_L ['PPC'] = listdesc
                    df_050_059_CUM_VS1_L ['Total'] = listtotal
                    df_050_059_CUM_VS1_L['Carat'] = df_050_059_CUM_VS1_L['Carat'].astype('float64')
                    df_050_059_CUM_VS1_L['PPC'] = df_050_059_CUM_VS1_L['PPC'].astype('float64')
                    df_050_059_CUM_VS1_L['Total'] = df_050_059_CUM_VS1_L['Total'].astype('float64')
                    df_050_059_CUM_VS1_L['Total'] = df_050_059_CUM_VS1_L['Carat'] * df_050_059_CUM_VS1_L['PPC']


                elif i=="L" and j == "VS2" and k == "CUM":
                    df_050_059_CUM_VS2_L = pd.DataFrame()
                    df_050_059_CUM_VS2_L ['Wt Range'] = None
                    df_050_059_CUM_VS2_L  = df_050_059_CUM_VS2_L.assign(Company=None)
                    df_050_059_CUM_VS2_L  = df_050_059_CUM_VS2_L.assign(Shape=None)
                    df_050_059_CUM_VS2_L  = df_050_059_CUM_VS2_L.assign(Carat=None)
                    df_050_059_CUM_VS2_L  = df_050_059_CUM_VS2_L.assign(Color=None)
                    df_050_059_CUM_VS2_L  = df_050_059_CUM_VS2_L.assign(Clarity=None)
                    df_050_059_CUM_VS2_L  = df_050_059_CUM_VS2_L.assign(Cut=None)
                    df_050_059_CUM_VS2_L  = df_050_059_CUM_VS2_L.assign(Polish=None)
                    df_050_059_CUM_VS2_L  = df_050_059_CUM_VS2_L.assign(Symmetry=None)
                    df_050_059_CUM_VS2_L  = df_050_059_CUM_VS2_L.assign(Ratio=None)
                    df_050_059_CUM_VS2_L  = df_050_059_CUM_VS2_L.assign(PPC=None)
                    df_050_059_CUM_VS2_L  = df_050_059_CUM_VS2_L.assign(Total=None)
                    df_050_059_CUM_VS2_L ['Wt Range'] = listwtrange
                    df_050_059_CUM_VS2_L ['Company'] = listcom
                    df_050_059_CUM_VS2_L ['Shape'] = listshap
                    df_050_059_CUM_VS2_L ['Carat'] = listcar
                    df_050_059_CUM_VS2_L ['Color'] = listcol
                    df_050_059_CUM_VS2_L ['Clarity'] = listclar
                    df_050_059_CUM_VS2_L ['Cut'] = listcut
                    df_050_059_CUM_VS2_L ['Polish'] = listpol
                    df_050_059_CUM_VS2_L ['Symmetry'] = listsym
                    df_050_059_CUM_VS2_L ['Ratio'] = listrat
                    df_050_059_CUM_VS2_L ['PPC'] = listdesc
                    df_050_059_CUM_VS2_L ['Total'] = listtotal
                    df_050_059_CUM_VS2_L['Carat'] = df_050_059_CUM_VS2_L['Carat'].astype('float64')
                    df_050_059_CUM_VS2_L['PPC'] = df_050_059_CUM_VS2_L['PPC'].astype('float64')
                    df_050_059_CUM_VS2_L['Total'] = df_050_059_CUM_VS2_L['Total'].astype('float64')
                    df_050_059_CUM_VS2_L['Total'] = df_050_059_CUM_VS2_L['Carat'] * df_050_059_CUM_VS2_L['PPC']


                elif i=="L" and j == "SI1" and k == "CUM":
                    df_050_059_CUM_SI1_L = pd.DataFrame()
                    df_050_059_CUM_SI1_L ['Wt Range'] = None
                    df_050_059_CUM_SI1_L  = df_050_059_CUM_SI1_L.assign(Company=None)
                    df_050_059_CUM_SI1_L  = df_050_059_CUM_SI1_L.assign(Shape=None)
                    df_050_059_CUM_SI1_L  = df_050_059_CUM_SI1_L.assign(Carat=None)
                    df_050_059_CUM_SI1_L  = df_050_059_CUM_SI1_L.assign(Color=None)
                    df_050_059_CUM_SI1_L  = df_050_059_CUM_SI1_L.assign(Clarity=None)
                    df_050_059_CUM_SI1_L  = df_050_059_CUM_SI1_L.assign(Cut=None)
                    df_050_059_CUM_SI1_L  = df_050_059_CUM_SI1_L.assign(Polish=None)
                    df_050_059_CUM_SI1_L  = df_050_059_CUM_SI1_L.assign(Symmetry=None)
                    df_050_059_CUM_SI1_L  = df_050_059_CUM_SI1_L.assign(Ratio=None)
                    df_050_059_CUM_SI1_L  = df_050_059_CUM_SI1_L.assign(PPC=None)
                    df_050_059_CUM_SI1_L  = df_050_059_CUM_SI1_L.assign(Total=None)
                    df_050_059_CUM_SI1_L ['Wt Range'] = listwtrange
                    df_050_059_CUM_SI1_L ['Company'] = listcom
                    df_050_059_CUM_SI1_L ['Shape'] = listshap
                    df_050_059_CUM_SI1_L ['Carat'] = listcar
                    df_050_059_CUM_SI1_L ['Color'] = listcol
                    df_050_059_CUM_SI1_L ['Clarity'] = listclar
                    df_050_059_CUM_SI1_L ['Cut'] = listcut
                    df_050_059_CUM_SI1_L ['Polish'] = listpol
                    df_050_059_CUM_SI1_L ['Symmetry'] = listsym
                    df_050_059_CUM_SI1_L ['Ratio'] = listrat
                    df_050_059_CUM_SI1_L ['PPC'] = listdesc
                    df_050_059_CUM_SI1_L ['Total'] = listtotal
                    df_050_059_CUM_SI1_L['Carat'] = df_050_059_CUM_SI1_L['Carat'].astype('float64')
                    df_050_059_CUM_SI1_L['PPC'] = df_050_059_CUM_SI1_L['PPC'].astype('float64')
                    df_050_059_CUM_SI1_L['Total'] = df_050_059_CUM_SI1_L['Total'].astype('float64')
                    df_050_059_CUM_SI1_L['Total'] = df_050_059_CUM_SI1_L['Carat'] * df_050_059_CUM_SI1_L['PPC']


                elif i=="L" and j == "SI2" and k == "CUM":
                    df_050_059_CUM_SI2_L = pd.DataFrame()
                    df_050_059_CUM_SI2_L ['Wt Range'] = None
                    df_050_059_CUM_SI2_L  = df_050_059_CUM_SI2_L.assign(Company=None)
                    df_050_059_CUM_SI2_L  = df_050_059_CUM_SI2_L.assign(Shape=None)
                    df_050_059_CUM_SI2_L  = df_050_059_CUM_SI2_L.assign(Carat=None)
                    df_050_059_CUM_SI2_L  = df_050_059_CUM_SI2_L.assign(Color=None)
                    df_050_059_CUM_SI2_L  = df_050_059_CUM_SI2_L.assign(Clarity=None)
                    df_050_059_CUM_SI2_L  = df_050_059_CUM_SI2_L.assign(Cut=None)
                    df_050_059_CUM_SI2_L  = df_050_059_CUM_SI2_L.assign(Polish=None)
                    df_050_059_CUM_SI2_L  = df_050_059_CUM_SI2_L.assign(Symmetry=None)
                    df_050_059_CUM_SI2_L  = df_050_059_CUM_SI2_L.assign(Ratio=None)
                    df_050_059_CUM_SI2_L  = df_050_059_CUM_SI2_L.assign(PPC=None)
                    df_050_059_CUM_SI2_L  = df_050_059_CUM_SI2_L.assign(Total=None)
                    df_050_059_CUM_SI2_L ['Wt Range'] = listwtrange
                    df_050_059_CUM_SI2_L ['Company'] = listcom
                    df_050_059_CUM_SI2_L ['Shape'] = listshap
                    df_050_059_CUM_SI2_L ['Carat'] = listcar
                    df_050_059_CUM_SI2_L ['Color'] = listcol
                    df_050_059_CUM_SI2_L ['Clarity'] = listclar
                    df_050_059_CUM_SI2_L ['Cut'] = listcut
                    df_050_059_CUM_SI2_L ['Polish'] = listpol
                    df_050_059_CUM_SI2_L ['Symmetry'] = listsym
                    df_050_059_CUM_SI2_L ['Ratio'] = listrat
                    df_050_059_CUM_SI2_L ['PPC'] = listdesc
                    df_050_059_CUM_SI2_L ['Total'] = listtotal
                    df_050_059_CUM_SI2_L['Carat'] = df_050_059_CUM_SI2_L['Carat'].astype('float64')
                    df_050_059_CUM_SI2_L['PPC'] = df_050_059_CUM_SI2_L['PPC'].astype('float64')
                    df_050_059_CUM_SI2_L['Total'] = df_050_059_CUM_SI2_L['Total'].astype('float64')
                    df_050_059_CUM_SI2_L['Total'] = df_050_059_CUM_SI2_L['Carat'] * df_050_059_CUM_SI2_L['PPC']


                elif i=="L" and j == "I1" and k == "CUM":
                    df_050_059_CUM_I1_L = pd.DataFrame()
                    df_050_059_CUM_I1_L ['Wt Range'] = None
                    df_050_059_CUM_I1_L  = df_050_059_CUM_I1_L.assign(Company=None)
                    df_050_059_CUM_I1_L  = df_050_059_CUM_I1_L.assign(Shape=None)
                    df_050_059_CUM_I1_L  = df_050_059_CUM_I1_L.assign(Carat=None)
                    df_050_059_CUM_I1_L  = df_050_059_CUM_I1_L.assign(Color=None)
                    df_050_059_CUM_I1_L  = df_050_059_CUM_I1_L.assign(Clarity=None)
                    df_050_059_CUM_I1_L  = df_050_059_CUM_I1_L.assign(Cut=None)
                    df_050_059_CUM_I1_L  = df_050_059_CUM_I1_L.assign(Polish=None)
                    df_050_059_CUM_I1_L  = df_050_059_CUM_I1_L.assign(Symmetry=None)
                    df_050_059_CUM_I1_L  = df_050_059_CUM_I1_L.assign(Ratio=None)
                    df_050_059_CUM_I1_L  = df_050_059_CUM_I1_L.assign(PPC=None)
                    df_050_059_CUM_I1_L  = df_050_059_CUM_I1_L.assign(Total=None)
                    df_050_059_CUM_I1_L ['Wt Range'] = listwtrange
                    df_050_059_CUM_I1_L ['Company'] = listcom
                    df_050_059_CUM_I1_L ['Shape'] = listshap
                    df_050_059_CUM_I1_L ['Carat'] = listcar
                    df_050_059_CUM_I1_L ['Color'] = listcol
                    df_050_059_CUM_I1_L ['Clarity'] = listclar
                    df_050_059_CUM_I1_L ['Cut'] = listcut
                    df_050_059_CUM_I1_L ['Polish'] = listpol
                    df_050_059_CUM_I1_L ['Symmetry'] = listsym
                    df_050_059_CUM_I1_L ['Ratio'] = listrat
                    df_050_059_CUM_I1_L ['PPC'] = listdesc
                    df_050_059_CUM_I1_L ['Total'] = listtotal
                    df_050_059_CUM_I1_L['Carat'] = df_050_059_CUM_I1_L['Carat'].astype('float64')
                    df_050_059_CUM_I1_L['PPC'] = df_050_059_CUM_I1_L['PPC'].astype('float64')
                    df_050_059_CUM_I1_L['Total'] = df_050_059_CUM_I1_L['Total'].astype('float64')
                    df_050_059_CUM_I1_L['Total'] = df_050_059_CUM_I1_L['Carat'] * df_050_059_CUM_I1_L['PPC']


                elif i=="L" and j == "I2" and k == "CUM":
                    df_050_059_CUM_I2_L = pd.DataFrame()
                    df_050_059_CUM_I2_L ['Wt Range'] = None
                    df_050_059_CUM_I2_L  = df_050_059_CUM_I2_L.assign(Company=None)
                    df_050_059_CUM_I2_L  = df_050_059_CUM_I2_L.assign(Shape=None)
                    df_050_059_CUM_I2_L  = df_050_059_CUM_I2_L.assign(Carat=None)
                    df_050_059_CUM_I2_L  = df_050_059_CUM_I2_L.assign(Color=None)
                    df_050_059_CUM_I2_L  = df_050_059_CUM_I2_L.assign(Clarity=None)
                    df_050_059_CUM_I2_L  = df_050_059_CUM_I2_L.assign(Cut=None)
                    df_050_059_CUM_I2_L  = df_050_059_CUM_I2_L.assign(Polish=None)
                    df_050_059_CUM_I2_L  = df_050_059_CUM_I2_L.assign(Symmetry=None)
                    df_050_059_CUM_I2_L  = df_050_059_CUM_I2_L.assign(Ratio=None)
                    df_050_059_CUM_I2_L  = df_050_059_CUM_I2_L.assign(PPC=None)
                    df_050_059_CUM_I2_L  = df_050_059_CUM_I2_L.assign(Total=None)
                    df_050_059_CUM_I2_L ['Wt Range'] = listwtrange
                    df_050_059_CUM_I2_L ['Company'] = listcom
                    df_050_059_CUM_I2_L ['Shape'] = listshap
                    df_050_059_CUM_I2_L ['Carat'] = listcar
                    df_050_059_CUM_I2_L ['Color'] = listcol
                    df_050_059_CUM_I2_L ['Clarity'] = listclar
                    df_050_059_CUM_I2_L ['Cut'] = listcut
                    df_050_059_CUM_I2_L ['Polish'] = listpol
                    df_050_059_CUM_I2_L ['Symmetry'] = listsym
                    df_050_059_CUM_I2_L ['Ratio'] = listrat
                    df_050_059_CUM_I2_L ['PPC'] = listdesc
                    df_050_059_CUM_I2_L ['Total'] = listtotal
                    df_050_059_CUM_I2_L['Carat'] = df_050_059_CUM_I2_L['Carat'].astype('float64')
                    df_050_059_CUM_I2_L['PPC'] = df_050_059_CUM_I2_L['PPC'].astype('float64')
                    df_050_059_CUM_I2_L['Total'] = df_050_059_CUM_I2_L['Total'].astype('float64')
                    df_050_059_CUM_I2_L['Total'] = df_050_059_CUM_I2_L['Carat'] * df_050_059_CUM_I2_L['PPC']

                    
  
                elif i=="D" and j == "IF" and k == "OE":
                    df_050_059_OE_IF_D = pd.DataFrame()
                    df_050_059_OE_IF_D ['Wt Range'] = None
                    df_050_059_OE_IF_D  = df_050_059_OE_IF_D.assign(Company=None)
                    df_050_059_OE_IF_D  = df_050_059_OE_IF_D.assign(Shape=None)
                    df_050_059_OE_IF_D  = df_050_059_OE_IF_D.assign(Carat=None)
                    df_050_059_OE_IF_D  = df_050_059_OE_IF_D.assign(Color=None)
                    df_050_059_OE_IF_D  = df_050_059_OE_IF_D.assign(Clarity=None)
                    df_050_059_OE_IF_D  = df_050_059_OE_IF_D.assign(Cut=None)
                    df_050_059_OE_IF_D  = df_050_059_OE_IF_D.assign(Polish=None)
                    df_050_059_OE_IF_D  = df_050_059_OE_IF_D.assign(Symmetry=None)
                    df_050_059_OE_IF_D  = df_050_059_OE_IF_D.assign(Ratio=None)
                    df_050_059_OE_IF_D  = df_050_059_OE_IF_D.assign(PPC=None)
                    df_050_059_OE_IF_D  = df_050_059_OE_IF_D.assign(Total=None)
                    df_050_059_OE_IF_D ['Wt Range'] = listwtrange
                    df_050_059_OE_IF_D ['Company'] = listcom
                    df_050_059_OE_IF_D ['Shape'] = listshap
                    df_050_059_OE_IF_D ['Carat'] = listcar
                    df_050_059_OE_IF_D ['Color'] = listcol
                    df_050_059_OE_IF_D ['Clarity'] = listclar
                    df_050_059_OE_IF_D ['Cut'] = listcut
                    df_050_059_OE_IF_D ['Polish'] = listpol
                    df_050_059_OE_IF_D ['Symmetry'] = listsym
                    df_050_059_OE_IF_D ['Ratio'] = listrat
                    df_050_059_OE_IF_D ['PPC'] = listdesc
                    df_050_059_OE_IF_D ['Total'] = listtotal
                    df_050_059_OE_IF_D['Carat'] = df_050_059_OE_IF_D['Carat'].astype('float64')
                    df_050_059_OE_IF_D['PPC'] = df_050_059_OE_IF_D['PPC'].astype('float64')
                    df_050_059_OE_IF_D['Total'] = df_050_059_OE_IF_D['Total'].astype('float64')
                    df_050_059_OE_IF_D['Total'] = df_050_059_OE_IF_D['Carat'] * df_050_059_OE_IF_D['PPC']



                elif i=="D" and j == "VVS1" and k == "OE" :
                    df_050_059_OE_VVS1_D = pd.DataFrame()
                    df_050_059_OE_VVS1_D ['Wt Range'] = None
                    df_050_059_OE_VVS1_D  = df_050_059_OE_VVS1_D.assign(Company=None)
                    df_050_059_OE_VVS1_D  = df_050_059_OE_VVS1_D.assign(Shape=None)
                    df_050_059_OE_VVS1_D  = df_050_059_OE_VVS1_D.assign(Carat=None)
                    df_050_059_OE_VVS1_D  = df_050_059_OE_VVS1_D.assign(Color=None)
                    df_050_059_OE_VVS1_D  = df_050_059_OE_VVS1_D.assign(Clarity=None)
                    df_050_059_OE_VVS1_D  = df_050_059_OE_VVS1_D.assign(Cut=None)
                    df_050_059_OE_VVS1_D  = df_050_059_OE_VVS1_D.assign(Polish=None)
                    df_050_059_OE_VVS1_D  = df_050_059_OE_VVS1_D.assign(Symmetry=None)
                    df_050_059_OE_VVS1_D  = df_050_059_OE_VVS1_D.assign(Ratio=None)
                    df_050_059_OE_VVS1_D  = df_050_059_OE_VVS1_D.assign(PPC=None)
                    df_050_059_OE_VVS1_D  = df_050_059_OE_VVS1_D.assign(Total=None)
                    df_050_059_OE_VVS1_D ['Wt Range'] = listwtrange
                    df_050_059_OE_VVS1_D ['Company'] = listcom
                    df_050_059_OE_VVS1_D ['Shape'] = listshap
                    df_050_059_OE_VVS1_D ['Carat'] = listcar
                    df_050_059_OE_VVS1_D ['Color'] = listcol
                    df_050_059_OE_VVS1_D ['Clarity'] = listclar
                    df_050_059_OE_VVS1_D ['Cut'] = listcut
                    df_050_059_OE_VVS1_D ['Polish'] = listpol
                    df_050_059_OE_VVS1_D ['Symmetry'] = listsym
                    df_050_059_OE_VVS1_D ['Ratio'] = listrat
                    df_050_059_OE_VVS1_D ['PPC'] = listdesc
                    df_050_059_OE_VVS1_D ['Total'] = listtotal
                    df_050_059_OE_VVS1_D['Carat'] = df_050_059_OE_VVS1_D['Carat'].astype('float64')
                    df_050_059_OE_VVS1_D['PPC'] = df_050_059_OE_VVS1_D['PPC'].astype('float64')
                    df_050_059_OE_VVS1_D['Total'] = df_050_059_OE_VVS1_D['Total'].astype('float64')
                    df_050_059_OE_VVS1_D['Total'] = df_050_059_OE_VVS1_D['Carat'] * df_050_059_OE_VVS1_D['PPC']



                elif i=="D" and j == "VVS2" and k == "OE" :
                    df_050_059_OE_VVS2_D = pd.DataFrame()
                    df_050_059_OE_VVS2_D ['Wt Range'] = None
                    df_050_059_OE_VVS2_D  = df_050_059_OE_VVS2_D.assign(Company=None)
                    df_050_059_OE_VVS2_D  = df_050_059_OE_VVS2_D.assign(Shape=None)
                    df_050_059_OE_VVS2_D  = df_050_059_OE_VVS2_D.assign(Carat=None)
                    df_050_059_OE_VVS2_D  = df_050_059_OE_VVS2_D.assign(Color=None)
                    df_050_059_OE_VVS2_D  = df_050_059_OE_VVS2_D.assign(Clarity=None)
                    df_050_059_OE_VVS2_D  = df_050_059_OE_VVS2_D.assign(Cut=None)
                    df_050_059_OE_VVS2_D  = df_050_059_OE_VVS2_D.assign(Polish=None)
                    df_050_059_OE_VVS2_D  = df_050_059_OE_VVS2_D.assign(Symmetry=None)
                    df_050_059_OE_VVS2_D  = df_050_059_OE_VVS2_D.assign(Ratio=None)
                    df_050_059_OE_VVS2_D  = df_050_059_OE_VVS2_D.assign(PPC=None)
                    df_050_059_OE_VVS2_D  = df_050_059_OE_VVS2_D.assign(Total=None)
                    df_050_059_OE_VVS2_D ['Wt Range'] = listwtrange
                    df_050_059_OE_VVS2_D ['Company'] = listcom
                    df_050_059_OE_VVS2_D ['Shape'] = listshap
                    df_050_059_OE_VVS2_D ['Carat'] = listcar
                    df_050_059_OE_VVS2_D ['Color'] = listcol
                    df_050_059_OE_VVS2_D ['Clarity'] = listclar
                    df_050_059_OE_VVS2_D ['Cut'] = listcut
                    df_050_059_OE_VVS2_D ['Polish'] = listpol
                    df_050_059_OE_VVS2_D ['Symmetry'] = listsym
                    df_050_059_OE_VVS2_D ['Ratio'] = listrat
                    df_050_059_OE_VVS2_D ['PPC'] = listdesc
                    df_050_059_OE_VVS2_D ['Total'] = listtotal
                    df_050_059_OE_VVS2_D['Carat'] = df_050_059_OE_VVS2_D['Carat'].astype('float64')
                    df_050_059_OE_VVS2_D['PPC'] = df_050_059_OE_VVS2_D['PPC'].astype('float64')
                    df_050_059_OE_VVS2_D['Total'] = df_050_059_OE_VVS2_D['Total'].astype('float64')
                    df_050_059_OE_VVS2_D['Total'] = df_050_059_OE_VVS2_D['Carat'] * df_050_059_OE_VVS2_D['PPC']



                elif i=="D" and j == "VS1" and k == "OE":
                    df_050_059_OE_VS1_D = pd.DataFrame()
                    df_050_059_OE_VS1_D ['Wt Range'] = None
                    df_050_059_OE_VS1_D  = df_050_059_OE_VS1_D.assign(Company=None)
                    df_050_059_OE_VS1_D  = df_050_059_OE_VS1_D.assign(Shape=None)
                    df_050_059_OE_VS1_D  = df_050_059_OE_VS1_D.assign(Carat=None)
                    df_050_059_OE_VS1_D  = df_050_059_OE_VS1_D.assign(Color=None)
                    df_050_059_OE_VS1_D  = df_050_059_OE_VS1_D.assign(Clarity=None)
                    df_050_059_OE_VS1_D  = df_050_059_OE_VS1_D.assign(Cut=None)
                    df_050_059_OE_VS1_D  = df_050_059_OE_VS1_D.assign(Polish=None)
                    df_050_059_OE_VS1_D  = df_050_059_OE_VS1_D.assign(Symmetry=None)
                    df_050_059_OE_VS1_D  = df_050_059_OE_VS1_D.assign(Ratio=None)
                    df_050_059_OE_VS1_D  = df_050_059_OE_VS1_D.assign(PPC=None)
                    df_050_059_OE_VS1_D  = df_050_059_OE_VS1_D.assign(Total=None)
                    df_050_059_OE_VS1_D ['Wt Range'] = listwtrange
                    df_050_059_OE_VS1_D ['Company'] = listcom
                    df_050_059_OE_VS1_D ['Shape'] = listshap
                    df_050_059_OE_VS1_D ['Carat'] = listcar
                    df_050_059_OE_VS1_D ['Color'] = listcol
                    df_050_059_OE_VS1_D ['Clarity'] = listclar
                    df_050_059_OE_VS1_D ['Cut'] = listcut
                    df_050_059_OE_VS1_D ['Polish'] = listpol
                    df_050_059_OE_VS1_D ['Symmetry'] = listsym
                    df_050_059_OE_VS1_D ['Ratio'] = listrat
                    df_050_059_OE_VS1_D ['PPC'] = listdesc
                    df_050_059_OE_VS1_D ['Total'] = listtotal
                    df_050_059_OE_VS1_D['Carat'] = df_050_059_OE_VS1_D['Carat'].astype('float64')
                    df_050_059_OE_VS1_D['PPC'] = df_050_059_OE_VS1_D['PPC'].astype('float64')
                    df_050_059_OE_VS1_D['Total'] = df_050_059_OE_VS1_D['Total'].astype('float64')
                    df_050_059_OE_VS1_D['Total'] = df_050_059_OE_VS1_D['Carat'] * df_050_059_OE_VS1_D['PPC']


                elif i=="D" and j == "VS2" and k == "OE":
                    df_050_059_OE_VS2_D = pd.DataFrame()
                    df_050_059_OE_VS2_D ['Wt Range'] = None
                    df_050_059_OE_VS2_D  = df_050_059_OE_VS2_D.assign(Company=None)
                    df_050_059_OE_VS2_D  = df_050_059_OE_VS2_D.assign(Shape=None)
                    df_050_059_OE_VS2_D  = df_050_059_OE_VS2_D.assign(Carat=None)
                    df_050_059_OE_VS2_D  = df_050_059_OE_VS2_D.assign(Color=None)
                    df_050_059_OE_VS2_D  = df_050_059_OE_VS2_D.assign(Clarity=None)
                    df_050_059_OE_VS2_D  = df_050_059_OE_VS2_D.assign(Cut=None)
                    df_050_059_OE_VS2_D  = df_050_059_OE_VS2_D.assign(Polish=None)
                    df_050_059_OE_VS2_D  = df_050_059_OE_VS2_D.assign(Symmetry=None)
                    df_050_059_OE_VS2_D  = df_050_059_OE_VS2_D.assign(Ratio=None)
                    df_050_059_OE_VS2_D  = df_050_059_OE_VS2_D.assign(PPC=None)
                    df_050_059_OE_VS2_D  = df_050_059_OE_VS2_D.assign(Total=None)
                    df_050_059_OE_VS2_D ['Wt Range'] = listwtrange
                    df_050_059_OE_VS2_D ['Company'] = listcom
                    df_050_059_OE_VS2_D ['Shape'] = listshap
                    df_050_059_OE_VS2_D ['Carat'] = listcar
                    df_050_059_OE_VS2_D ['Color'] = listcol
                    df_050_059_OE_VS2_D ['Clarity'] = listclar
                    df_050_059_OE_VS2_D ['Cut'] = listcut
                    df_050_059_OE_VS2_D ['Polish'] = listpol
                    df_050_059_OE_VS2_D ['Symmetry'] = listsym
                    df_050_059_OE_VS2_D ['Ratio'] = listrat
                    df_050_059_OE_VS2_D ['PPC'] = listdesc
                    df_050_059_OE_VS2_D ['Total'] = listtotal
                    df_050_059_OE_VS2_D['Carat'] = df_050_059_OE_VS2_D['Carat'].astype('float64')
                    df_050_059_OE_VS2_D['PPC'] = df_050_059_OE_VS2_D['PPC'].astype('float64')
                    df_050_059_OE_VS2_D['Total'] = df_050_059_OE_VS2_D['Total'].astype('float64')
                    df_050_059_OE_VS2_D['Total'] = df_050_059_OE_VS2_D['Carat'] * df_050_059_OE_VS2_D['PPC']


                elif i=="D" and j == "SI1" and k == "OE":
                    df_050_059_OE_SI1_D = pd.DataFrame()
                    df_050_059_OE_SI1_D ['Wt Range'] = None
                    df_050_059_OE_SI1_D  = df_050_059_OE_SI1_D.assign(Company=None)
                    df_050_059_OE_SI1_D  = df_050_059_OE_SI1_D.assign(Shape=None)
                    df_050_059_OE_SI1_D  = df_050_059_OE_SI1_D.assign(Carat=None)
                    df_050_059_OE_SI1_D  = df_050_059_OE_SI1_D.assign(Color=None)
                    df_050_059_OE_SI1_D  = df_050_059_OE_SI1_D.assign(Clarity=None)
                    df_050_059_OE_SI1_D  = df_050_059_OE_SI1_D.assign(Cut=None)
                    df_050_059_OE_SI1_D  = df_050_059_OE_SI1_D.assign(Polish=None)
                    df_050_059_OE_SI1_D  = df_050_059_OE_SI1_D.assign(Symmetry=None)
                    df_050_059_OE_SI1_D  = df_050_059_OE_SI1_D.assign(Ratio=None)
                    df_050_059_OE_SI1_D  = df_050_059_OE_SI1_D.assign(PPC=None)
                    df_050_059_OE_SI1_D  = df_050_059_OE_SI1_D.assign(Total=None)
                    df_050_059_OE_SI1_D ['Wt Range'] = listwtrange
                    df_050_059_OE_SI1_D ['Company'] = listcom
                    df_050_059_OE_SI1_D ['Shape'] = listshap
                    df_050_059_OE_SI1_D ['Carat'] = listcar
                    df_050_059_OE_SI1_D ['Color'] = listcol
                    df_050_059_OE_SI1_D ['Clarity'] = listclar
                    df_050_059_OE_SI1_D ['Cut'] = listcut
                    df_050_059_OE_SI1_D ['Polish'] = listpol
                    df_050_059_OE_SI1_D ['Symmetry'] = listsym
                    df_050_059_OE_SI1_D ['Ratio'] = listrat
                    df_050_059_OE_SI1_D ['PPC'] = listdesc
                    df_050_059_OE_SI1_D ['Total'] = listtotal
                    df_050_059_OE_SI1_D['Carat'] = df_050_059_OE_SI1_D['Carat'].astype('float64')
                    df_050_059_OE_SI1_D['PPC'] = df_050_059_OE_SI1_D['PPC'].astype('float64')
                    df_050_059_OE_SI1_D['Total'] = df_050_059_OE_SI1_D['Total'].astype('float64')
                    df_050_059_OE_SI1_D['Total'] = df_050_059_OE_SI1_D['Carat'] * df_050_059_OE_SI1_D['PPC']


                elif i=="D" and j == "SI2" and k == "OE":
                    df_050_059_OE_SI2_D = pd.DataFrame()
                    df_050_059_OE_SI2_D ['Wt Range'] = None
                    df_050_059_OE_SI2_D  = df_050_059_OE_SI2_D.assign(Company=None)
                    df_050_059_OE_SI2_D  = df_050_059_OE_SI2_D.assign(Shape=None)
                    df_050_059_OE_SI2_D  = df_050_059_OE_SI2_D.assign(Carat=None)
                    df_050_059_OE_SI2_D  = df_050_059_OE_SI2_D.assign(Color=None)
                    df_050_059_OE_SI2_D  = df_050_059_OE_SI2_D.assign(Clarity=None)
                    df_050_059_OE_SI2_D  = df_050_059_OE_SI2_D.assign(Cut=None)
                    df_050_059_OE_SI2_D  = df_050_059_OE_SI2_D.assign(Polish=None)
                    df_050_059_OE_SI2_D  = df_050_059_OE_SI2_D.assign(Symmetry=None)
                    df_050_059_OE_SI2_D  = df_050_059_OE_SI2_D.assign(Ratio=None)
                    df_050_059_OE_SI2_D  = df_050_059_OE_SI2_D.assign(PPC=None)
                    df_050_059_OE_SI2_D  = df_050_059_OE_SI2_D.assign(Total=None)
                    df_050_059_OE_SI2_D ['Wt Range'] = listwtrange
                    df_050_059_OE_SI2_D ['Company'] = listcom
                    df_050_059_OE_SI2_D ['Shape'] = listshap
                    df_050_059_OE_SI2_D ['Carat'] = listcar
                    df_050_059_OE_SI2_D ['Color'] = listcol
                    df_050_059_OE_SI2_D ['Clarity'] = listclar
                    df_050_059_OE_SI2_D ['Cut'] = listcut
                    df_050_059_OE_SI2_D ['Polish'] = listpol
                    df_050_059_OE_SI2_D ['Symmetry'] = listsym
                    df_050_059_OE_SI2_D ['Ratio'] = listrat
                    df_050_059_OE_SI2_D ['PPC'] = listdesc
                    df_050_059_OE_SI2_D ['Total'] = listtotal
                    df_050_059_OE_SI2_D['Carat'] = df_050_059_OE_SI2_D['Carat'].astype('float64')
                    df_050_059_OE_SI2_D['PPC'] = df_050_059_OE_SI2_D['PPC'].astype('float64')
                    df_050_059_OE_SI2_D['Total'] = df_050_059_OE_SI2_D['Total'].astype('float64')
                    df_050_059_OE_SI2_D['Total'] = df_050_059_OE_SI2_D['Carat'] * df_050_059_OE_SI2_D['PPC']


                elif i=="D" and j == "I1" and k == "OE":
                    df_050_059_OE_I1_D = pd.DataFrame()
                    df_050_059_OE_I1_D ['Wt Range'] = None
                    df_050_059_OE_I1_D  = df_050_059_OE_I1_D.assign(Company=None)
                    df_050_059_OE_I1_D  = df_050_059_OE_I1_D.assign(Shape=None)
                    df_050_059_OE_I1_D  = df_050_059_OE_I1_D.assign(Carat=None)
                    df_050_059_OE_I1_D  = df_050_059_OE_I1_D.assign(Color=None)
                    df_050_059_OE_I1_D  = df_050_059_OE_I1_D.assign(Clarity=None)
                    df_050_059_OE_I1_D  = df_050_059_OE_I1_D.assign(Cut=None)
                    df_050_059_OE_I1_D  = df_050_059_OE_I1_D.assign(Polish=None)
                    df_050_059_OE_I1_D  = df_050_059_OE_I1_D.assign(Symmetry=None)
                    df_050_059_OE_I1_D  = df_050_059_OE_I1_D.assign(Ratio=None)
                    df_050_059_OE_I1_D  = df_050_059_OE_I1_D.assign(PPC=None)
                    df_050_059_OE_I1_D  = df_050_059_OE_I1_D.assign(Total=None)
                    df_050_059_OE_I1_D ['Wt Range'] = listwtrange
                    df_050_059_OE_I1_D ['Company'] = listcom
                    df_050_059_OE_I1_D ['Shape'] = listshap
                    df_050_059_OE_I1_D ['Carat'] = listcar
                    df_050_059_OE_I1_D ['Color'] = listcol
                    df_050_059_OE_I1_D ['Clarity'] = listclar
                    df_050_059_OE_I1_D ['Cut'] = listcut
                    df_050_059_OE_I1_D ['Polish'] = listpol
                    df_050_059_OE_I1_D ['Symmetry'] = listsym
                    df_050_059_OE_I1_D ['Ratio'] = listrat
                    df_050_059_OE_I1_D ['PPC'] = listdesc
                    df_050_059_OE_I1_D ['Total'] = listtotal
                    df_050_059_OE_I1_D['Carat'] = df_050_059_OE_I1_D['Carat'].astype('float64')
                    df_050_059_OE_I1_D['PPC'] = df_050_059_OE_I1_D['PPC'].astype('float64')
                    df_050_059_OE_I1_D['Total'] = df_050_059_OE_I1_D['Total'].astype('float64')
                    df_050_059_OE_I1_D['Total'] = df_050_059_OE_I1_D['Carat'] * df_050_059_OE_I1_D['PPC']


                elif i=="D" and j == "I2" and k == "OE":
                    df_050_059_OE_I2_D = pd.DataFrame()
                    df_050_059_OE_I2_D ['Wt Range'] = None
                    df_050_059_OE_I2_D  = df_050_059_OE_I2_D.assign(Company=None)
                    df_050_059_OE_I2_D  = df_050_059_OE_I2_D.assign(Shape=None)
                    df_050_059_OE_I2_D  = df_050_059_OE_I2_D.assign(Carat=None)
                    df_050_059_OE_I2_D  = df_050_059_OE_I2_D.assign(Color=None)
                    df_050_059_OE_I2_D  = df_050_059_OE_I2_D.assign(Clarity=None)
                    df_050_059_OE_I2_D  = df_050_059_OE_I2_D.assign(Cut=None)
                    df_050_059_OE_I2_D  = df_050_059_OE_I2_D.assign(Polish=None)
                    df_050_059_OE_I2_D  = df_050_059_OE_I2_D.assign(Symmetry=None)
                    df_050_059_OE_I2_D  = df_050_059_OE_I2_D.assign(Ratio=None)
                    df_050_059_OE_I2_D  = df_050_059_OE_I2_D.assign(PPC=None)
                    df_050_059_OE_I2_D  = df_050_059_OE_I2_D.assign(Total=None)
                    df_050_059_OE_I2_D ['Wt Range'] = listwtrange
                    df_050_059_OE_I2_D ['Company'] = listcom
                    df_050_059_OE_I2_D ['Shape'] = listshap
                    df_050_059_OE_I2_D ['Carat'] = listcar
                    df_050_059_OE_I2_D ['Color'] = listcol
                    df_050_059_OE_I2_D ['Clarity'] = listclar
                    df_050_059_OE_I2_D ['Cut'] = listcut
                    df_050_059_OE_I2_D ['Polish'] = listpol
                    df_050_059_OE_I2_D ['Symmetry'] = listsym
                    df_050_059_OE_I2_D ['Ratio'] = listrat
                    df_050_059_OE_I2_D ['PPC'] = listdesc
                    df_050_059_OE_I2_D ['Total'] = listtotal
                    df_050_059_OE_I2_D['Carat'] = df_050_059_OE_I2_D['Carat'].astype('float64')
                    df_050_059_OE_I2_D['PPC'] = df_050_059_OE_I2_D['PPC'].astype('float64')
                    df_050_059_OE_I2_D['Total'] = df_050_059_OE_I2_D['Total'].astype('float64')
                    df_050_059_OE_I2_D['Total'] = df_050_059_OE_I2_D['Carat'] * df_050_059_OE_I2_D['PPC']



                elif i=="E" and j == "IF" and k == "OE":
                    df_050_059_OE_IF_E = pd.DataFrame()
                    df_050_059_OE_IF_E ['Wt Range'] = None
                    df_050_059_OE_IF_E  = df_050_059_OE_IF_E.assign(Company=None)
                    df_050_059_OE_IF_E  = df_050_059_OE_IF_E.assign(Shape=None)
                    df_050_059_OE_IF_E  = df_050_059_OE_IF_E.assign(Carat=None)
                    df_050_059_OE_IF_E  = df_050_059_OE_IF_E.assign(Color=None)
                    df_050_059_OE_IF_E  = df_050_059_OE_IF_E.assign(Clarity=None)
                    df_050_059_OE_IF_E  = df_050_059_OE_IF_E.assign(Cut=None)
                    df_050_059_OE_IF_E  = df_050_059_OE_IF_E.assign(Polish=None)
                    df_050_059_OE_IF_E  = df_050_059_OE_IF_E.assign(Symmetry=None)
                    df_050_059_OE_IF_E  = df_050_059_OE_IF_E.assign(Ratio=None)
                    df_050_059_OE_IF_E  = df_050_059_OE_IF_E.assign(PPC=None)
                    df_050_059_OE_IF_E  = df_050_059_OE_IF_E.assign(Total=None)
                    df_050_059_OE_IF_E ['Wt Range'] = listwtrange
                    df_050_059_OE_IF_E ['Company'] = listcom
                    df_050_059_OE_IF_E ['Shape'] = listshap
                    df_050_059_OE_IF_E ['Carat'] = listcar
                    df_050_059_OE_IF_E ['Color'] = listcol
                    df_050_059_OE_IF_E ['Clarity'] = listclar
                    df_050_059_OE_IF_E ['Cut'] = listcut
                    df_050_059_OE_IF_E ['Polish'] = listpol
                    df_050_059_OE_IF_E ['Symmetry'] = listsym
                    df_050_059_OE_IF_E ['Ratio'] = listrat
                    df_050_059_OE_IF_E ['PPC'] = listdesc
                    df_050_059_OE_IF_E ['Total'] = listtotal
                    df_050_059_OE_IF_E['Carat'] = df_050_059_OE_IF_E['Carat'].astype('float64')
                    df_050_059_OE_IF_E['PPC'] = df_050_059_OE_IF_E['PPC'].astype('float64')
                    df_050_059_OE_IF_E['Total'] = df_050_059_OE_IF_E['Total'].astype('float64')
                    df_050_059_OE_IF_E['Total'] = df_050_059_OE_IF_E['Carat'] * df_050_059_OE_IF_E['PPC']



                elif i=="E" and j == "VVS1" and k == "OE":
                    df_050_059_OE_VVS1_E = pd.DataFrame()
                    df_050_059_OE_VVS1_E ['Wt Range'] = None
                    df_050_059_OE_VVS1_E  = df_050_059_OE_VVS1_E.assign(Company=None)
                    df_050_059_OE_VVS1_E  = df_050_059_OE_VVS1_E.assign(Shape=None)
                    df_050_059_OE_VVS1_E  = df_050_059_OE_VVS1_E.assign(Carat=None)
                    df_050_059_OE_VVS1_E  = df_050_059_OE_VVS1_E.assign(Color=None)
                    df_050_059_OE_VVS1_E  = df_050_059_OE_VVS1_E.assign(Clarity=None)
                    df_050_059_OE_VVS1_E  = df_050_059_OE_VVS1_E.assign(Cut=None)
                    df_050_059_OE_VVS1_E  = df_050_059_OE_VVS1_E.assign(Polish=None)
                    df_050_059_OE_VVS1_E  = df_050_059_OE_VVS1_E.assign(Symmetry=None)
                    df_050_059_OE_VVS1_E  = df_050_059_OE_VVS1_E.assign(Ratio=None)
                    df_050_059_OE_VVS1_E  = df_050_059_OE_VVS1_E.assign(PPC=None)
                    df_050_059_OE_VVS1_E  = df_050_059_OE_VVS1_E.assign(Total=None)
                    df_050_059_OE_VVS1_E ['Wt Range'] = listwtrange
                    df_050_059_OE_VVS1_E ['Company'] = listcom
                    df_050_059_OE_VVS1_E ['Shape'] = listshap
                    df_050_059_OE_VVS1_E ['Carat'] = listcar
                    df_050_059_OE_VVS1_E ['Color'] = listcol
                    df_050_059_OE_VVS1_E ['Clarity'] = listclar
                    df_050_059_OE_VVS1_E ['Cut'] = listcut
                    df_050_059_OE_VVS1_E ['Polish'] = listpol
                    df_050_059_OE_VVS1_E ['Symmetry'] = listsym
                    df_050_059_OE_VVS1_E ['Ratio'] = listrat
                    df_050_059_OE_VVS1_E ['PPC'] = listdesc
                    df_050_059_OE_VVS1_E ['Total'] = listtotal
                    df_050_059_OE_VVS1_E['Carat'] = df_050_059_OE_VVS1_E['Carat'].astype('float64')
                    df_050_059_OE_VVS1_E['PPC'] = df_050_059_OE_VVS1_E['PPC'].astype('float64')
                    df_050_059_OE_VVS1_E['Total'] = df_050_059_OE_VVS1_E['Total'].astype('float64')
                    df_050_059_OE_VVS1_E['Total'] = df_050_059_OE_VVS1_E['Carat'] * df_050_059_OE_VVS1_E['PPC']


                elif i=="E" and j == "VVS2" and k == "OE":
                    df_050_059_OE_VVS2_E = pd.DataFrame()
                    df_050_059_OE_VVS2_E ['Wt Range'] = None
                    df_050_059_OE_VVS2_E  = df_050_059_OE_VVS2_E.assign(Company=None)
                    df_050_059_OE_VVS2_E  = df_050_059_OE_VVS2_E.assign(Shape=None)
                    df_050_059_OE_VVS2_E  = df_050_059_OE_VVS2_E.assign(Carat=None)
                    df_050_059_OE_VVS2_E  = df_050_059_OE_VVS2_E.assign(Color=None)
                    df_050_059_OE_VVS2_E  = df_050_059_OE_VVS2_E.assign(Clarity=None)
                    df_050_059_OE_VVS2_E  = df_050_059_OE_VVS2_E.assign(Cut=None)
                    df_050_059_OE_VVS2_E  = df_050_059_OE_VVS2_E.assign(Polish=None)
                    df_050_059_OE_VVS2_E  = df_050_059_OE_VVS2_E.assign(Symmetry=None)
                    df_050_059_OE_VVS2_E  = df_050_059_OE_VVS2_E.assign(Ratio=None)
                    df_050_059_OE_VVS2_E  = df_050_059_OE_VVS2_E.assign(PPC=None)
                    df_050_059_OE_VVS2_E  = df_050_059_OE_VVS2_E.assign(Total=None)
                    df_050_059_OE_VVS2_E ['Wt Range'] = listwtrange
                    df_050_059_OE_VVS2_E ['Company'] = listcom
                    df_050_059_OE_VVS2_E ['Shape'] = listshap
                    df_050_059_OE_VVS2_E ['Carat'] = listcar
                    df_050_059_OE_VVS2_E ['Color'] = listcol
                    df_050_059_OE_VVS2_E ['Clarity'] = listclar
                    df_050_059_OE_VVS2_E ['Cut'] = listcut
                    df_050_059_OE_VVS2_E ['Polish'] = listpol
                    df_050_059_OE_VVS2_E ['Symmetry'] = listsym
                    df_050_059_OE_VVS2_E ['Ratio'] = listrat
                    df_050_059_OE_VVS2_E ['PPC'] = listdesc
                    df_050_059_OE_VVS2_E ['Total'] = listtotal
                    df_050_059_OE_VVS2_E['Carat'] = df_050_059_OE_VVS2_E['Carat'].astype('float64')
                    df_050_059_OE_VVS2_E['PPC'] = df_050_059_OE_VVS2_E['PPC'].astype('float64')
                    df_050_059_OE_VVS2_E['Total'] = df_050_059_OE_VVS2_E['Total'].astype('float64')
                    df_050_059_OE_VVS2_E['Total'] = df_050_059_OE_VVS2_E['Carat'] * df_050_059_OE_VVS2_E['PPC']


                elif i=="E" and j=="VS1" and k == "OE":
                    df_050_059_OE_VS1_E = pd.DataFrame()
                    df_050_059_OE_VS1_E ['Wt Range'] = None
                    df_050_059_OE_VS1_E  = df_050_059_OE_VS1_E.assign(Company=None)
                    df_050_059_OE_VS1_E  = df_050_059_OE_VS1_E.assign(Shape=None)
                    df_050_059_OE_VS1_E  = df_050_059_OE_VS1_E.assign(Carat=None)
                    df_050_059_OE_VS1_E  = df_050_059_OE_VS1_E.assign(Color=None)
                    df_050_059_OE_VS1_E  = df_050_059_OE_VS1_E.assign(Clarity=None)
                    df_050_059_OE_VS1_E  = df_050_059_OE_VS1_E.assign(Cut=None)
                    df_050_059_OE_VS1_E  = df_050_059_OE_VS1_E.assign(Polish=None)
                    df_050_059_OE_VS1_E  = df_050_059_OE_VS1_E.assign(Symmetry=None)
                    df_050_059_OE_VS1_E  = df_050_059_OE_VS1_E.assign(Ratio=None)
                    df_050_059_OE_VS1_E  = df_050_059_OE_VS1_E.assign(PPC=None)
                    df_050_059_OE_VS1_E  = df_050_059_OE_VS1_E.assign(Total=None)
                    df_050_059_OE_VS1_E ['Wt Range'] = listwtrange
                    df_050_059_OE_VS1_E ['Company'] = listcom
                    df_050_059_OE_VS1_E ['Shape'] = listshap
                    df_050_059_OE_VS1_E ['Carat'] = listcar
                    df_050_059_OE_VS1_E ['Color'] = listcol
                    df_050_059_OE_VS1_E ['Clarity'] = listclar
                    df_050_059_OE_VS1_E ['Cut'] = listcut
                    df_050_059_OE_VS1_E ['Polish'] = listpol
                    df_050_059_OE_VS1_E ['Symmetry'] = listsym
                    df_050_059_OE_VS1_E ['Ratio'] = listrat
                    df_050_059_OE_VS1_E ['PPC'] = listdesc
                    df_050_059_OE_VS1_E ['Total'] = listtotal
                    df_050_059_OE_VS1_E['Carat'] = df_050_059_OE_VS1_E['Carat'].astype('float64')
                    df_050_059_OE_VS1_E['PPC'] = df_050_059_OE_VS1_E['PPC'].astype('float64')
                    df_050_059_OE_VS1_E['Total'] = df_050_059_OE_VS1_E['Total'].astype('float64')
                    df_050_059_OE_VS1_E['Total'] = df_050_059_OE_VS1_E['Carat'] * df_050_059_OE_VS1_E['PPC']


                elif i=="E" and j == "VS2" and k == "OE":
                    df_050_059_OE_VS2_E = pd.DataFrame()
                    df_050_059_OE_VS2_E ['Wt Range'] = None
                    df_050_059_OE_VS2_E  = df_050_059_OE_VS2_E.assign(Company=None)
                    df_050_059_OE_VS2_E  = df_050_059_OE_VS2_E.assign(Shape=None)
                    df_050_059_OE_VS2_E  = df_050_059_OE_VS2_E.assign(Carat=None)
                    df_050_059_OE_VS2_E  = df_050_059_OE_VS2_E.assign(Color=None)
                    df_050_059_OE_VS2_E  = df_050_059_OE_VS2_E.assign(Clarity=None)
                    df_050_059_OE_VS2_E  = df_050_059_OE_VS2_E.assign(Cut=None)
                    df_050_059_OE_VS2_E  = df_050_059_OE_VS2_E.assign(Polish=None)
                    df_050_059_OE_VS2_E  = df_050_059_OE_VS2_E.assign(Symmetry=None)
                    df_050_059_OE_VS2_E  = df_050_059_OE_VS2_E.assign(Ratio=None)
                    df_050_059_OE_VS2_E  = df_050_059_OE_VS2_E.assign(PPC=None)
                    df_050_059_OE_VS2_E  = df_050_059_OE_VS2_E.assign(Total=None)
                    df_050_059_OE_VS2_E ['Wt Range'] = listwtrange
                    df_050_059_OE_VS2_E ['Company'] = listcom
                    df_050_059_OE_VS2_E ['Shape'] = listshap
                    df_050_059_OE_VS2_E ['Carat'] = listcar
                    df_050_059_OE_VS2_E ['Color'] = listcol
                    df_050_059_OE_VS2_E ['Clarity'] = listclar
                    df_050_059_OE_VS2_E ['Cut'] = listcut
                    df_050_059_OE_VS2_E ['Polish'] = listpol
                    df_050_059_OE_VS2_E ['Symmetry'] = listsym
                    df_050_059_OE_VS2_E ['Ratio'] = listrat
                    df_050_059_OE_VS2_E ['PPC'] = listdesc
                    df_050_059_OE_VS2_E ['Total'] = listtotal
                    df_050_059_OE_VS2_E['Carat'] = df_050_059_OE_VS2_E['Carat'].astype('float64')
                    df_050_059_OE_VS2_E['PPC'] = df_050_059_OE_VS2_E['PPC'].astype('float64')
                    df_050_059_OE_VS2_E['Total'] = df_050_059_OE_VS2_E['Total'].astype('float64')
                    df_050_059_OE_VS2_E['Total'] = df_050_059_OE_VS2_E['Carat'] * df_050_059_OE_VS2_E['PPC']


                elif i=="E" and j == "SI1" and k == "OE":
                    df_050_059_OE_SI1_E = pd.DataFrame()
                    df_050_059_OE_SI1_E ['Wt Range'] = None
                    df_050_059_OE_SI1_E  = df_050_059_OE_SI1_E.assign(Company=None)
                    df_050_059_OE_SI1_E  = df_050_059_OE_SI1_E.assign(Shape=None)
                    df_050_059_OE_SI1_E  = df_050_059_OE_SI1_E.assign(Carat=None)
                    df_050_059_OE_SI1_E  = df_050_059_OE_SI1_E.assign(Color=None)
                    df_050_059_OE_SI1_E  = df_050_059_OE_SI1_E.assign(Clarity=None)
                    df_050_059_OE_SI1_E  = df_050_059_OE_SI1_E.assign(Cut=None)
                    df_050_059_OE_SI1_E  = df_050_059_OE_SI1_E.assign(Polish=None)
                    df_050_059_OE_SI1_E  = df_050_059_OE_SI1_E.assign(Symmetry=None)
                    df_050_059_OE_SI1_E  = df_050_059_OE_SI1_E.assign(Ratio=None)
                    df_050_059_OE_SI1_E  = df_050_059_OE_SI1_E.assign(PPC=None)
                    df_050_059_OE_SI1_E  = df_050_059_OE_SI1_E.assign(Total=None)
                    df_050_059_OE_SI1_E ['Wt Range'] = listwtrange
                    df_050_059_OE_SI1_E ['Company'] = listcom
                    df_050_059_OE_SI1_E ['Shape'] = listshap
                    df_050_059_OE_SI1_E ['Carat'] = listcar
                    df_050_059_OE_SI1_E ['Color'] = listcol
                    df_050_059_OE_SI1_E ['Clarity'] = listclar
                    df_050_059_OE_SI1_E ['Cut'] = listcut
                    df_050_059_OE_SI1_E ['Polish'] = listpol
                    df_050_059_OE_SI1_E ['Symmetry'] = listsym
                    df_050_059_OE_SI1_E ['Ratio'] = listrat
                    df_050_059_OE_SI1_E ['PPC'] = listdesc
                    df_050_059_OE_SI1_E ['Total'] = listtotal
                    df_050_059_OE_SI1_E['Carat'] = df_050_059_OE_SI1_E['Carat'].astype('float64')
                    df_050_059_OE_SI1_E['PPC'] = df_050_059_OE_SI1_E['PPC'].astype('float64')
                    df_050_059_OE_SI1_E['Total'] = df_050_059_OE_SI1_E['Total'].astype('float64')
                    df_050_059_OE_SI1_E['Total'] = df_050_059_OE_SI1_E['Carat'] * df_050_059_OE_SI1_E['PPC']


                elif i=="E" and j == "SI2" and k == "OE":
                    df_050_059_OE_SI2_E = pd.DataFrame()
                    df_050_059_OE_SI2_E ['Wt Range'] = None
                    df_050_059_OE_SI2_E  = df_050_059_OE_SI2_E.assign(Company=None)
                    df_050_059_OE_SI2_E  = df_050_059_OE_SI2_E.assign(Shape=None)
                    df_050_059_OE_SI2_E  = df_050_059_OE_SI2_E.assign(Carat=None)
                    df_050_059_OE_SI2_E  = df_050_059_OE_SI2_E.assign(Color=None)
                    df_050_059_OE_SI2_E  = df_050_059_OE_SI2_E.assign(Clarity=None)
                    df_050_059_OE_SI2_E  = df_050_059_OE_SI2_E.assign(Cut=None)
                    df_050_059_OE_SI2_E  = df_050_059_OE_SI2_E.assign(Polish=None)
                    df_050_059_OE_SI2_E  = df_050_059_OE_SI2_E.assign(Symmetry=None)
                    df_050_059_OE_SI2_E  = df_050_059_OE_SI2_E.assign(Ratio=None)
                    df_050_059_OE_SI2_E  = df_050_059_OE_SI2_E.assign(PPC=None)
                    df_050_059_OE_SI2_E  = df_050_059_OE_SI2_E.assign(Total=None)
                    df_050_059_OE_SI2_E ['Wt Range'] = listwtrange
                    df_050_059_OE_SI2_E ['Company'] = listcom
                    df_050_059_OE_SI2_E ['Shape'] = listshap
                    df_050_059_OE_SI2_E ['Carat'] = listcar
                    df_050_059_OE_SI2_E ['Color'] = listcol
                    df_050_059_OE_SI2_E ['Clarity'] = listclar
                    df_050_059_OE_SI2_E ['Cut'] = listcut
                    df_050_059_OE_SI2_E ['Polish'] = listpol
                    df_050_059_OE_SI2_E ['Symmetry'] = listsym
                    df_050_059_OE_SI2_E ['Ratio'] = listrat
                    df_050_059_OE_SI2_E ['PPC'] = listdesc
                    df_050_059_OE_SI2_E ['Total'] = listtotal
                    df_050_059_OE_SI2_E['Carat'] = df_050_059_OE_SI2_E['Carat'].astype('float64')
                    df_050_059_OE_SI2_E['PPC'] = df_050_059_OE_SI2_E['PPC'].astype('float64')
                    df_050_059_OE_SI2_E['Total'] = df_050_059_OE_SI2_E['Total'].astype('float64')
                    df_050_059_OE_SI2_E['Total'] = df_050_059_OE_SI2_E['Carat'] * df_050_059_OE_SI2_E['PPC']


                elif i=="E" and j == "I1" and k == "OE":
                    df_050_059_OE_I1_E = pd.DataFrame()
                    df_050_059_OE_I1_E ['Wt Range'] = None
                    df_050_059_OE_I1_E  = df_050_059_OE_I1_E.assign(Company=None)
                    df_050_059_OE_I1_E  = df_050_059_OE_I1_E.assign(Shape=None)
                    df_050_059_OE_I1_E  = df_050_059_OE_I1_E.assign(Carat=None)
                    df_050_059_OE_I1_E  = df_050_059_OE_I1_E.assign(Color=None)
                    df_050_059_OE_I1_E  = df_050_059_OE_I1_E.assign(Clarity=None)
                    df_050_059_OE_I1_E  = df_050_059_OE_I1_E.assign(Cut=None)
                    df_050_059_OE_I1_E  = df_050_059_OE_I1_E.assign(Polish=None)
                    df_050_059_OE_I1_E  = df_050_059_OE_I1_E.assign(Symmetry=None)
                    df_050_059_OE_I1_E  = df_050_059_OE_I1_E.assign(Ratio=None)
                    df_050_059_OE_I1_E  = df_050_059_OE_I1_E.assign(PPC=None)
                    df_050_059_OE_I1_E  = df_050_059_OE_I1_E.assign(Total=None)
                    df_050_059_OE_I1_E ['Wt Range'] = listwtrange
                    df_050_059_OE_I1_E ['Company'] = listcom
                    df_050_059_OE_I1_E ['Shape'] = listshap
                    df_050_059_OE_I1_E ['Carat'] = listcar
                    df_050_059_OE_I1_E ['Color'] = listcol
                    df_050_059_OE_I1_E ['Clarity'] = listclar
                    df_050_059_OE_I1_E ['Cut'] = listcut
                    df_050_059_OE_I1_E ['Polish'] = listpol
                    df_050_059_OE_I1_E ['Symmetry'] = listsym
                    df_050_059_OE_I1_E ['Ratio'] = listrat
                    df_050_059_OE_I1_E ['PPC'] = listdesc
                    df_050_059_OE_I1_E ['Total'] = listtotal
                    df_050_059_OE_I1_E['Carat'] = df_050_059_OE_I1_E['Carat'].astype('float64')
                    df_050_059_OE_I1_E['PPC'] = df_050_059_OE_I1_E['PPC'].astype('float64')
                    df_050_059_OE_I1_E['Total'] = df_050_059_OE_I1_E['Total'].astype('float64')
                    df_050_059_OE_I1_E['Total'] = df_050_059_OE_I1_E['Carat'] * df_050_059_OE_I1_E['PPC']


                elif i=="E" and j == "I2" and k == "OE":
                    df_050_059_OE_I2_E = pd.DataFrame()
                    df_050_059_OE_I2_E ['Wt Range'] = None
                    df_050_059_OE_I2_E  = df_050_059_OE_I2_E.assign(Company=None)
                    df_050_059_OE_I2_E  = df_050_059_OE_I2_E.assign(Shape=None)
                    df_050_059_OE_I2_E  = df_050_059_OE_I2_E.assign(Carat=None)
                    df_050_059_OE_I2_E  = df_050_059_OE_I2_E.assign(Color=None)
                    df_050_059_OE_I2_E  = df_050_059_OE_I2_E.assign(Clarity=None)
                    df_050_059_OE_I2_E  = df_050_059_OE_I2_E.assign(Cut=None)
                    df_050_059_OE_I2_E  = df_050_059_OE_I2_E.assign(Polish=None)
                    df_050_059_OE_I2_E  = df_050_059_OE_I2_E.assign(Symmetry=None)
                    df_050_059_OE_I2_E  = df_050_059_OE_I2_E.assign(Ratio=None)
                    df_050_059_OE_I2_E  = df_050_059_OE_I2_E.assign(PPC=None)
                    df_050_059_OE_I2_E  = df_050_059_OE_I2_E.assign(Total=None)
                    df_050_059_OE_I2_E ['Wt Range'] = listwtrange
                    df_050_059_OE_I2_E ['Company'] = listcom
                    df_050_059_OE_I2_E ['Shape'] = listshap
                    df_050_059_OE_I2_E ['Carat'] = listcar
                    df_050_059_OE_I2_E ['Color'] = listcol
                    df_050_059_OE_I2_E ['Clarity'] = listclar
                    df_050_059_OE_I2_E ['Cut'] = listcut
                    df_050_059_OE_I2_E ['Polish'] = listpol
                    df_050_059_OE_I2_E ['Symmetry'] = listsym
                    df_050_059_OE_I2_E ['Ratio'] = listrat
                    df_050_059_OE_I2_E ['PPC'] = listdesc
                    df_050_059_OE_I2_E ['Total'] = listtotal
                    df_050_059_OE_I2_E['Carat'] = df_050_059_OE_I2_E['Carat'].astype('float64')
                    df_050_059_OE_I2_E['PPC'] = df_050_059_OE_I2_E['PPC'].astype('float64')
                    df_050_059_OE_I2_E['Total'] = df_050_059_OE_I2_E['Total'].astype('float64')
                    df_050_059_OE_I2_E['Total'] = df_050_059_OE_I2_E['Carat'] * df_050_059_OE_I2_E['PPC']
                
                elif i=="F" and j == "IF" and k == "OE":
                    df_050_059_OE_IF_F = pd.DataFrame()
                    df_050_059_OE_IF_F ['Wt Range'] = None
                    df_050_059_OE_IF_F  = df_050_059_OE_IF_F.assign(Company=None)
                    df_050_059_OE_IF_F  = df_050_059_OE_IF_F.assign(Shape=None)
                    df_050_059_OE_IF_F  = df_050_059_OE_IF_F.assign(Carat=None)
                    df_050_059_OE_IF_F  = df_050_059_OE_IF_F.assign(Color=None)
                    df_050_059_OE_IF_F  = df_050_059_OE_IF_F.assign(Clarity=None)
                    df_050_059_OE_IF_F  = df_050_059_OE_IF_F.assign(Cut=None)
                    df_050_059_OE_IF_F  = df_050_059_OE_IF_F.assign(Polish=None)
                    df_050_059_OE_IF_F  = df_050_059_OE_IF_F.assign(Symmetry=None)
                    df_050_059_OE_IF_F  = df_050_059_OE_IF_F.assign(Ratio=None)
                    df_050_059_OE_IF_F  = df_050_059_OE_IF_F.assign(PPC=None)
                    df_050_059_OE_IF_F  = df_050_059_OE_IF_F.assign(Total=None)
                    df_050_059_OE_IF_F ['Wt Range'] = listwtrange
                    df_050_059_OE_IF_F ['Company'] = listcom
                    df_050_059_OE_IF_F ['Shape'] = listshap
                    df_050_059_OE_IF_F ['Carat'] = listcar
                    df_050_059_OE_IF_F ['Color'] = listcol
                    df_050_059_OE_IF_F ['Clarity'] = listclar
                    df_050_059_OE_IF_F ['Cut'] = listcut
                    df_050_059_OE_IF_F ['Polish'] = listpol
                    df_050_059_OE_IF_F ['Symmetry'] = listsym
                    df_050_059_OE_IF_F ['Ratio'] = listrat
                    df_050_059_OE_IF_F ['PPC'] = listdesc
                    df_050_059_OE_IF_F ['Total'] = listtotal
                    df_050_059_OE_IF_F['Carat'] = df_050_059_OE_IF_F['Carat'].astype('float64')
                    df_050_059_OE_IF_F['PPC'] = df_050_059_OE_IF_F['PPC'].astype('float64')
                    df_050_059_OE_IF_F['Total'] = df_050_059_OE_IF_F['Total'].astype('float64')
                    df_050_059_OE_IF_F['Total'] = df_050_059_OE_IF_F['Carat'] * df_050_059_OE_IF_F['PPC']



                elif i=="F" and j == "VVS1" and k == "OE":
                    df_050_059_OE_VVS1_F = pd.DataFrame()
                    df_050_059_OE_VVS1_F ['Wt Range'] = None
                    df_050_059_OE_VVS1_F  = df_050_059_OE_VVS1_F.assign(Company=None)
                    df_050_059_OE_VVS1_F  = df_050_059_OE_VVS1_F.assign(Shape=None)
                    df_050_059_OE_VVS1_F  = df_050_059_OE_VVS1_F.assign(Carat=None)
                    df_050_059_OE_VVS1_F  = df_050_059_OE_VVS1_F.assign(Color=None)
                    df_050_059_OE_VVS1_F  = df_050_059_OE_VVS1_F.assign(Clarity=None)
                    df_050_059_OE_VVS1_F  = df_050_059_OE_VVS1_F.assign(Cut=None)
                    df_050_059_OE_VVS1_F  = df_050_059_OE_VVS1_F.assign(Polish=None)
                    df_050_059_OE_VVS1_F  = df_050_059_OE_VVS1_F.assign(Symmetry=None)
                    df_050_059_OE_VVS1_F  = df_050_059_OE_VVS1_F.assign(Ratio=None)
                    df_050_059_OE_VVS1_F  = df_050_059_OE_VVS1_F.assign(PPC=None)
                    df_050_059_OE_VVS1_F  = df_050_059_OE_VVS1_F.assign(Total=None)
                    df_050_059_OE_VVS1_F ['Wt Range'] = listwtrange
                    df_050_059_OE_VVS1_F ['Company'] = listcom
                    df_050_059_OE_VVS1_F ['Shape'] = listshap
                    df_050_059_OE_VVS1_F ['Carat'] = listcar
                    df_050_059_OE_VVS1_F ['Color'] = listcol
                    df_050_059_OE_VVS1_F ['Clarity'] = listclar
                    df_050_059_OE_VVS1_F ['Cut'] = listcut
                    df_050_059_OE_VVS1_F ['Polish'] = listpol
                    df_050_059_OE_VVS1_F ['Symmetry'] = listsym
                    df_050_059_OE_VVS1_F ['Ratio'] = listrat
                    df_050_059_OE_VVS1_F ['PPC'] = listdesc
                    df_050_059_OE_VVS1_F ['Total'] = listtotal
                    df_050_059_OE_VVS1_F['Carat'] = df_050_059_OE_VVS1_F['Carat'].astype('float64')
                    df_050_059_OE_VVS1_F['PPC'] = df_050_059_OE_VVS1_F['PPC'].astype('float64')
                    df_050_059_OE_VVS1_F['Total'] = df_050_059_OE_VVS1_F['Total'].astype('float64')
                    df_050_059_OE_VVS1_F['Total'] = df_050_059_OE_VVS1_F['Carat'] * df_050_059_OE_VVS1_F['PPC']


                elif i=="F" and j == "VVS2" and k == "OE":
                    df_050_059_OE_VVS2_F = pd.DataFrame()
                    df_050_059_OE_VVS2_F ['Wt Range'] = None
                    df_050_059_OE_VVS2_F  = df_050_059_OE_VVS2_F.assign(Company=None)
                    df_050_059_OE_VVS2_F  = df_050_059_OE_VVS2_F.assign(Shape=None)
                    df_050_059_OE_VVS2_F  = df_050_059_OE_VVS2_F.assign(Carat=None)
                    df_050_059_OE_VVS2_F  = df_050_059_OE_VVS2_F.assign(Color=None)
                    df_050_059_OE_VVS2_F  = df_050_059_OE_VVS2_F.assign(Clarity=None)
                    df_050_059_OE_VVS2_F  = df_050_059_OE_VVS2_F.assign(Cut=None)
                    df_050_059_OE_VVS2_F  = df_050_059_OE_VVS2_F.assign(Polish=None)
                    df_050_059_OE_VVS2_F  = df_050_059_OE_VVS2_F.assign(Symmetry=None)
                    df_050_059_OE_VVS2_F  = df_050_059_OE_VVS2_F.assign(Ratio=None)
                    df_050_059_OE_VVS2_F  = df_050_059_OE_VVS2_F.assign(PPC=None)
                    df_050_059_OE_VVS2_F  = df_050_059_OE_VVS2_F.assign(Total=None)
                    df_050_059_OE_VVS2_F ['Wt Range'] = listwtrange
                    df_050_059_OE_VVS2_F ['Company'] = listcom
                    df_050_059_OE_VVS2_F ['Shape'] = listshap
                    df_050_059_OE_VVS2_F ['Carat'] = listcar
                    df_050_059_OE_VVS2_F ['Color'] = listcol
                    df_050_059_OE_VVS2_F ['Clarity'] = listclar
                    df_050_059_OE_VVS2_F ['Cut'] = listcut
                    df_050_059_OE_VVS2_F ['Polish'] = listpol
                    df_050_059_OE_VVS2_F ['Symmetry'] = listsym
                    df_050_059_OE_VVS2_F ['Ratio'] = listrat
                    df_050_059_OE_VVS2_F ['PPC'] = listdesc
                    df_050_059_OE_VVS2_F ['Total'] = listtotal
                    df_050_059_OE_VVS2_F['Carat'] = df_050_059_OE_VVS2_F['Carat'].astype('float64')
                    df_050_059_OE_VVS2_F['PPC'] = df_050_059_OE_VVS2_F['PPC'].astype('float64')
                    df_050_059_OE_VVS2_F['Total'] = df_050_059_OE_VVS2_F['Total'].astype('float64')
                    df_050_059_OE_VVS2_F['Total'] = df_050_059_OE_VVS2_F['Carat'] * df_050_059_OE_VVS2_F['PPC']


                elif i=="F" and j=="VS1" and k == "OE":
                    df_050_059_OE_VS1_F = pd.DataFrame()
                    df_050_059_OE_VS1_F ['Wt Range'] = None
                    df_050_059_OE_VS1_F  = df_050_059_OE_VS1_F.assign(Company=None)
                    df_050_059_OE_VS1_F  = df_050_059_OE_VS1_F.assign(Shape=None)
                    df_050_059_OE_VS1_F  = df_050_059_OE_VS1_F.assign(Carat=None)
                    df_050_059_OE_VS1_F  = df_050_059_OE_VS1_F.assign(Color=None)
                    df_050_059_OE_VS1_F  = df_050_059_OE_VS1_F.assign(Clarity=None)
                    df_050_059_OE_VS1_F  = df_050_059_OE_VS1_F.assign(Cut=None)
                    df_050_059_OE_VS1_F  = df_050_059_OE_VS1_F.assign(Polish=None)
                    df_050_059_OE_VS1_F  = df_050_059_OE_VS1_F.assign(Symmetry=None)
                    df_050_059_OE_VS1_F  = df_050_059_OE_VS1_F.assign(Ratio=None)
                    df_050_059_OE_VS1_F  = df_050_059_OE_VS1_F.assign(PPC=None)
                    df_050_059_OE_VS1_F  = df_050_059_OE_VS1_F.assign(Total=None)
                    df_050_059_OE_VS1_F ['Wt Range'] = listwtrange
                    df_050_059_OE_VS1_F ['Company'] = listcom
                    df_050_059_OE_VS1_F ['Shape'] = listshap
                    df_050_059_OE_VS1_F ['Carat'] = listcar
                    df_050_059_OE_VS1_F ['Color'] = listcol
                    df_050_059_OE_VS1_F ['Clarity'] = listclar
                    df_050_059_OE_VS1_F ['Cut'] = listcut
                    df_050_059_OE_VS1_F ['Polish'] = listpol
                    df_050_059_OE_VS1_F ['Symmetry'] = listsym
                    df_050_059_OE_VS1_F ['Ratio'] = listrat
                    df_050_059_OE_VS1_F ['PPC'] = listdesc
                    df_050_059_OE_VS1_F ['Total'] = listtotal
                    df_050_059_OE_VS1_F['Carat'] = df_050_059_OE_VS1_F['Carat'].astype('float64')
                    df_050_059_OE_VS1_F['PPC'] = df_050_059_OE_VS1_F['PPC'].astype('float64')
                    df_050_059_OE_VS1_F['Total'] = df_050_059_OE_VS1_F['Total'].astype('float64')
                    df_050_059_OE_VS1_F['Total'] = df_050_059_OE_VS1_F['Carat'] * df_050_059_OE_VS1_F['PPC']


                elif i=="F" and j == "VS2" and k == "OE":
                    df_050_059_OE_VS2_F = pd.DataFrame()
                    df_050_059_OE_VS2_F ['Wt Range'] = None
                    df_050_059_OE_VS2_F  = df_050_059_OE_VS2_F.assign(Company=None)
                    df_050_059_OE_VS2_F  = df_050_059_OE_VS2_F.assign(Shape=None)
                    df_050_059_OE_VS2_F  = df_050_059_OE_VS2_F.assign(Carat=None)
                    df_050_059_OE_VS2_F  = df_050_059_OE_VS2_F.assign(Color=None)
                    df_050_059_OE_VS2_F  = df_050_059_OE_VS2_F.assign(Clarity=None)
                    df_050_059_OE_VS2_F  = df_050_059_OE_VS2_F.assign(Cut=None)
                    df_050_059_OE_VS2_F  = df_050_059_OE_VS2_F.assign(Polish=None)
                    df_050_059_OE_VS2_F  = df_050_059_OE_VS2_F.assign(Symmetry=None)
                    df_050_059_OE_VS2_F  = df_050_059_OE_VS2_F.assign(Ratio=None)
                    df_050_059_OE_VS2_F  = df_050_059_OE_VS2_F.assign(PPC=None)
                    df_050_059_OE_VS2_F  = df_050_059_OE_VS2_F.assign(Total=None)
                    df_050_059_OE_VS2_F ['Wt Range'] = listwtrange
                    df_050_059_OE_VS2_F ['Company'] = listcom
                    df_050_059_OE_VS2_F ['Shape'] = listshap
                    df_050_059_OE_VS2_F ['Carat'] = listcar
                    df_050_059_OE_VS2_F ['Color'] = listcol
                    df_050_059_OE_VS2_F ['Clarity'] = listclar
                    df_050_059_OE_VS2_F ['Cut'] = listcut
                    df_050_059_OE_VS2_F ['Polish'] = listpol
                    df_050_059_OE_VS2_F ['Symmetry'] = listsym
                    df_050_059_OE_VS2_F ['Ratio'] = listrat
                    df_050_059_OE_VS2_F ['PPC'] = listdesc
                    df_050_059_OE_VS2_F ['Total'] = listtotal
                    df_050_059_OE_VS2_F['Carat'] = df_050_059_OE_VS2_F['Carat'].astype('float64')
                    df_050_059_OE_VS2_F['PPC'] = df_050_059_OE_VS2_F['PPC'].astype('float64')
                    df_050_059_OE_VS2_F['Total'] = df_050_059_OE_VS2_F['Total'].astype('float64')
                    df_050_059_OE_VS2_F['Total'] = df_050_059_OE_VS2_F['Carat'] * df_050_059_OE_VS2_F['PPC']


                elif i=="F" and j == "SI1" and k == "OE":
                    df_050_059_OE_SI1_F = pd.DataFrame()
                    df_050_059_OE_SI1_F ['Wt Range'] = None
                    df_050_059_OE_SI1_F  = df_050_059_OE_SI1_F.assign(Company=None)
                    df_050_059_OE_SI1_F  = df_050_059_OE_SI1_F.assign(Shape=None)
                    df_050_059_OE_SI1_F  = df_050_059_OE_SI1_F.assign(Carat=None)
                    df_050_059_OE_SI1_F  = df_050_059_OE_SI1_F.assign(Color=None)
                    df_050_059_OE_SI1_F  = df_050_059_OE_SI1_F.assign(Clarity=None)
                    df_050_059_OE_SI1_F  = df_050_059_OE_SI1_F.assign(Cut=None)
                    df_050_059_OE_SI1_F  = df_050_059_OE_SI1_F.assign(Polish=None)
                    df_050_059_OE_SI1_F  = df_050_059_OE_SI1_F.assign(Symmetry=None)
                    df_050_059_OE_SI1_F  = df_050_059_OE_SI1_F.assign(Ratio=None)
                    df_050_059_OE_SI1_F  = df_050_059_OE_SI1_F.assign(PPC=None)
                    df_050_059_OE_SI1_F  = df_050_059_OE_SI1_F.assign(Total=None)
                    df_050_059_OE_SI1_F ['Wt Range'] = listwtrange
                    df_050_059_OE_SI1_F ['Company'] = listcom
                    df_050_059_OE_SI1_F ['Shape'] = listshap
                    df_050_059_OE_SI1_F ['Carat'] = listcar
                    df_050_059_OE_SI1_F ['Color'] = listcol
                    df_050_059_OE_SI1_F ['Clarity'] = listclar
                    df_050_059_OE_SI1_F ['Cut'] = listcut
                    df_050_059_OE_SI1_F ['Polish'] = listpol
                    df_050_059_OE_SI1_F ['Symmetry'] = listsym
                    df_050_059_OE_SI1_F ['Ratio'] = listrat
                    df_050_059_OE_SI1_F ['PPC'] = listdesc
                    df_050_059_OE_SI1_F ['Total'] = listtotal
                    df_050_059_OE_SI1_F['Carat'] = df_050_059_OE_SI1_F['Carat'].astype('float64')
                    df_050_059_OE_SI1_F['PPC'] = df_050_059_OE_SI1_F['PPC'].astype('float64')
                    df_050_059_OE_SI1_F['Total'] = df_050_059_OE_SI1_F['Total'].astype('float64')
                    df_050_059_OE_SI1_F['Total'] = df_050_059_OE_SI1_F['Carat'] * df_050_059_OE_SI1_F['PPC']


                elif i=="F" and j == "SI2" and k == "OE":
                    df_050_059_OE_SI2_F = pd.DataFrame()
                    df_050_059_OE_SI2_F ['Wt Range'] = None
                    df_050_059_OE_SI2_F  = df_050_059_OE_SI2_F.assign(Company=None)
                    df_050_059_OE_SI2_F  = df_050_059_OE_SI2_F.assign(Shape=None)
                    df_050_059_OE_SI2_F  = df_050_059_OE_SI2_F.assign(Carat=None)
                    df_050_059_OE_SI2_F  = df_050_059_OE_SI2_F.assign(Color=None)
                    df_050_059_OE_SI2_F  = df_050_059_OE_SI2_F.assign(Clarity=None)
                    df_050_059_OE_SI2_F  = df_050_059_OE_SI2_F.assign(Cut=None)
                    df_050_059_OE_SI2_F  = df_050_059_OE_SI2_F.assign(Polish=None)
                    df_050_059_OE_SI2_F  = df_050_059_OE_SI2_F.assign(Symmetry=None)
                    df_050_059_OE_SI2_F  = df_050_059_OE_SI2_F.assign(Ratio=None)
                    df_050_059_OE_SI2_F  = df_050_059_OE_SI2_F.assign(PPC=None)
                    df_050_059_OE_SI2_F  = df_050_059_OE_SI2_F.assign(Total=None)
                    df_050_059_OE_SI2_F ['Wt Range'] = listwtrange
                    df_050_059_OE_SI2_F ['Company'] = listcom
                    df_050_059_OE_SI2_F ['Shape'] = listshap
                    df_050_059_OE_SI2_F ['Carat'] = listcar
                    df_050_059_OE_SI2_F ['Color'] = listcol
                    df_050_059_OE_SI2_F ['Clarity'] = listclar
                    df_050_059_OE_SI2_F ['Cut'] = listcut
                    df_050_059_OE_SI2_F ['Polish'] = listpol
                    df_050_059_OE_SI2_F ['Symmetry'] = listsym
                    df_050_059_OE_SI2_F ['Ratio'] = listrat
                    df_050_059_OE_SI2_F ['PPC'] = listdesc
                    df_050_059_OE_SI2_F ['Total'] = listtotal
                    df_050_059_OE_SI2_F['Carat'] = df_050_059_OE_SI2_F['Carat'].astype('float64')
                    df_050_059_OE_SI2_F['PPC'] = df_050_059_OE_SI2_F['PPC'].astype('float64')
                    df_050_059_OE_SI2_F['Total'] = df_050_059_OE_SI2_F['Total'].astype('float64')
                    df_050_059_OE_SI2_F['Total'] = df_050_059_OE_SI2_F['Carat'] * df_050_059_OE_SI2_F['PPC']


                elif i=="F" and j == "I1" and k == "OE":
                    df_050_059_OE_I1_F = pd.DataFrame()
                    df_050_059_OE_I1_F ['Wt Range'] = None
                    df_050_059_OE_I1_F  = df_050_059_OE_I1_F.assign(Company=None)
                    df_050_059_OE_I1_F  = df_050_059_OE_I1_F.assign(Shape=None)
                    df_050_059_OE_I1_F  = df_050_059_OE_I1_F.assign(Carat=None)
                    df_050_059_OE_I1_F  = df_050_059_OE_I1_F.assign(Color=None)
                    df_050_059_OE_I1_F  = df_050_059_OE_I1_F.assign(Clarity=None)
                    df_050_059_OE_I1_F  = df_050_059_OE_I1_F.assign(Cut=None)
                    df_050_059_OE_I1_F  = df_050_059_OE_I1_F.assign(Polish=None)
                    df_050_059_OE_I1_F  = df_050_059_OE_I1_F.assign(Symmetry=None)
                    df_050_059_OE_I1_F  = df_050_059_OE_I1_F.assign(Ratio=None)
                    df_050_059_OE_I1_F  = df_050_059_OE_I1_F.assign(PPC=None)
                    df_050_059_OE_I1_F  = df_050_059_OE_I1_F.assign(Total=None)
                    df_050_059_OE_I1_F ['Wt Range'] = listwtrange
                    df_050_059_OE_I1_F ['Company'] = listcom
                    df_050_059_OE_I1_F ['Shape'] = listshap
                    df_050_059_OE_I1_F ['Carat'] = listcar
                    df_050_059_OE_I1_F ['Color'] = listcol
                    df_050_059_OE_I1_F ['Clarity'] = listclar
                    df_050_059_OE_I1_F ['Cut'] = listcut
                    df_050_059_OE_I1_F ['Polish'] = listpol
                    df_050_059_OE_I1_F ['Symmetry'] = listsym
                    df_050_059_OE_I1_F ['Ratio'] = listrat
                    df_050_059_OE_I1_F ['PPC'] = listdesc
                    df_050_059_OE_I1_F ['Total'] = listtotal
                    df_050_059_OE_I1_F['Carat'] = df_050_059_OE_I1_F['Carat'].astype('float64')
                    df_050_059_OE_I1_F['PPC'] = df_050_059_OE_I1_F['PPC'].astype('float64')
                    df_050_059_OE_I1_F['Total'] = df_050_059_OE_I1_F['Total'].astype('float64')
                    df_050_059_OE_I1_F['Total'] = df_050_059_OE_I1_F['Carat'] * df_050_059_OE_I1_F['PPC']


                elif i=="F" and j == "I2" and k == "OE":
                    df_050_059_OE_I2_F = pd.DataFrame()
                    df_050_059_OE_I2_F ['Wt Range'] = None
                    df_050_059_OE_I2_F  = df_050_059_OE_I2_F.assign(Company=None)
                    df_050_059_OE_I2_F  = df_050_059_OE_I2_F.assign(Shape=None)
                    df_050_059_OE_I2_F  = df_050_059_OE_I2_F.assign(Carat=None)
                    df_050_059_OE_I2_F  = df_050_059_OE_I2_F.assign(Color=None)
                    df_050_059_OE_I2_F  = df_050_059_OE_I2_F.assign(Clarity=None)
                    df_050_059_OE_I2_F  = df_050_059_OE_I2_F.assign(Cut=None)
                    df_050_059_OE_I2_F  = df_050_059_OE_I2_F.assign(Polish=None)
                    df_050_059_OE_I2_F  = df_050_059_OE_I2_F.assign(Symmetry=None)
                    df_050_059_OE_I2_F  = df_050_059_OE_I2_F.assign(Ratio=None)
                    df_050_059_OE_I2_F  = df_050_059_OE_I2_F.assign(PPC=None)
                    df_050_059_OE_I2_F  = df_050_059_OE_I2_F.assign(Total=None)
                    df_050_059_OE_I2_F ['Wt Range'] = listwtrange
                    df_050_059_OE_I2_F ['Company'] = listcom
                    df_050_059_OE_I2_F ['Shape'] = listshap
                    df_050_059_OE_I2_F ['Carat'] = listcar
                    df_050_059_OE_I2_F ['Color'] = listcol
                    df_050_059_OE_I2_F ['Clarity'] = listclar
                    df_050_059_OE_I2_F ['Cut'] = listcut
                    df_050_059_OE_I2_F ['Polish'] = listpol
                    df_050_059_OE_I2_F ['Symmetry'] = listsym
                    df_050_059_OE_I2_F ['Ratio'] = listrat
                    df_050_059_OE_I2_F ['PPC'] = listdesc
                    df_050_059_OE_I2_F ['Total'] = listtotal
                    df_050_059_OE_I2_F['Carat'] = df_050_059_OE_I2_F['Carat'].astype('float64')
                    df_050_059_OE_I2_F['PPC'] = df_050_059_OE_I2_F['PPC'].astype('float64')
                    df_050_059_OE_I2_F['Total'] = df_050_059_OE_I2_F['Total'].astype('float64')
                    df_050_059_OE_I2_F['Total'] = df_050_059_OE_I2_F['Carat'] * df_050_059_OE_I2_F['PPC']


                elif i=="G" and j == "IF" and k == "OE":
                    df_050_059_OE_IF_G = pd.DataFrame()
                    df_050_059_OE_IF_G ['Wt Range'] = None
                    df_050_059_OE_IF_G  = df_050_059_OE_IF_G.assign(Company=None)
                    df_050_059_OE_IF_G  = df_050_059_OE_IF_G.assign(Shape=None)
                    df_050_059_OE_IF_G  = df_050_059_OE_IF_G.assign(Carat=None)
                    df_050_059_OE_IF_G  = df_050_059_OE_IF_G.assign(Color=None)
                    df_050_059_OE_IF_G  = df_050_059_OE_IF_G.assign(Clarity=None)
                    df_050_059_OE_IF_G  = df_050_059_OE_IF_G.assign(Cut=None)
                    df_050_059_OE_IF_G  = df_050_059_OE_IF_G.assign(Polish=None)
                    df_050_059_OE_IF_G  = df_050_059_OE_IF_G.assign(Symmetry=None)
                    df_050_059_OE_IF_G  = df_050_059_OE_IF_G.assign(Ratio=None)
                    df_050_059_OE_IF_G  = df_050_059_OE_IF_G.assign(PPC=None)
                    df_050_059_OE_IF_G  = df_050_059_OE_IF_G.assign(Total=None)
                    df_050_059_OE_IF_G ['Wt Range'] = listwtrange
                    df_050_059_OE_IF_G ['Company'] = listcom
                    df_050_059_OE_IF_G ['Shape'] = listshap
                    df_050_059_OE_IF_G ['Carat'] = listcar
                    df_050_059_OE_IF_G ['Color'] = listcol
                    df_050_059_OE_IF_G ['Clarity'] = listclar
                    df_050_059_OE_IF_G ['Cut'] = listcut
                    df_050_059_OE_IF_G ['Polish'] = listpol
                    df_050_059_OE_IF_G ['Symmetry'] = listsym
                    df_050_059_OE_IF_G ['Ratio'] = listrat
                    df_050_059_OE_IF_G ['PPC'] = listdesc
                    df_050_059_OE_IF_G ['Total'] = listtotal
                    df_050_059_OE_IF_G['Carat'] = df_050_059_OE_IF_G['Carat'].astype('float64')
                    df_050_059_OE_IF_G['PPC'] = df_050_059_OE_IF_G['PPC'].astype('float64')
                    df_050_059_OE_IF_G['Total'] = df_050_059_OE_IF_G['Total'].astype('float64')
                    df_050_059_OE_IF_G['Total'] = df_050_059_OE_IF_G['Carat'] * df_050_059_OE_IF_G['PPC']



                elif i=="G" and j == "VVS1" and k == "OE":
                    df_050_059_OE_VVS1_G = pd.DataFrame()
                    df_050_059_OE_VVS1_G ['Wt Range'] = None
                    df_050_059_OE_VVS1_G  = df_050_059_OE_VVS1_G.assign(Company=None)
                    df_050_059_OE_VVS1_G  = df_050_059_OE_VVS1_G.assign(Shape=None)
                    df_050_059_OE_VVS1_G  = df_050_059_OE_VVS1_G.assign(Carat=None)
                    df_050_059_OE_VVS1_G  = df_050_059_OE_VVS1_G.assign(Color=None)
                    df_050_059_OE_VVS1_G  = df_050_059_OE_VVS1_G.assign(Clarity=None)
                    df_050_059_OE_VVS1_G  = df_050_059_OE_VVS1_G.assign(Cut=None)
                    df_050_059_OE_VVS1_G  = df_050_059_OE_VVS1_G.assign(Polish=None)
                    df_050_059_OE_VVS1_G  = df_050_059_OE_VVS1_G.assign(Symmetry=None)
                    df_050_059_OE_VVS1_G  = df_050_059_OE_VVS1_G.assign(Ratio=None)
                    df_050_059_OE_VVS1_G  = df_050_059_OE_VVS1_G.assign(PPC=None)
                    df_050_059_OE_VVS1_G  = df_050_059_OE_VVS1_G.assign(Total=None)
                    df_050_059_OE_VVS1_G ['Wt Range'] = listwtrange
                    df_050_059_OE_VVS1_G ['Company'] = listcom
                    df_050_059_OE_VVS1_G ['Shape'] = listshap
                    df_050_059_OE_VVS1_G ['Carat'] = listcar
                    df_050_059_OE_VVS1_G ['Color'] = listcol
                    df_050_059_OE_VVS1_G ['Clarity'] = listclar
                    df_050_059_OE_VVS1_G ['Cut'] = listcut
                    df_050_059_OE_VVS1_G ['Polish'] = listpol
                    df_050_059_OE_VVS1_G ['Symmetry'] = listsym
                    df_050_059_OE_VVS1_G ['Ratio'] = listrat
                    df_050_059_OE_VVS1_G ['PPC'] = listdesc
                    df_050_059_OE_VVS1_G ['Total'] = listtotal
                    df_050_059_OE_VVS1_G['Carat'] = df_050_059_OE_VVS1_G['Carat'].astype('float64')
                    df_050_059_OE_VVS1_G['PPC'] = df_050_059_OE_VVS1_G['PPC'].astype('float64')
                    df_050_059_OE_VVS1_G['Total'] = df_050_059_OE_VVS1_G['Total'].astype('float64')
                    df_050_059_OE_VVS1_G['Total'] = df_050_059_OE_VVS1_G['Carat'] * df_050_059_OE_VVS1_G['PPC']


                elif i=="G" and j == "VVS2" and k == "OE":
                    df_050_059_OE_VVS2_G = pd.DataFrame()
                    df_050_059_OE_VVS2_G ['Wt Range'] = None
                    df_050_059_OE_VVS2_G  = df_050_059_OE_VVS2_G.assign(Company=None)
                    df_050_059_OE_VVS2_G  = df_050_059_OE_VVS2_G.assign(Shape=None)
                    df_050_059_OE_VVS2_G  = df_050_059_OE_VVS2_G.assign(Carat=None)
                    df_050_059_OE_VVS2_G  = df_050_059_OE_VVS2_G.assign(Color=None)
                    df_050_059_OE_VVS2_G  = df_050_059_OE_VVS2_G.assign(Clarity=None)
                    df_050_059_OE_VVS2_G  = df_050_059_OE_VVS2_G.assign(Cut=None)
                    df_050_059_OE_VVS2_G  = df_050_059_OE_VVS2_G.assign(Polish=None)
                    df_050_059_OE_VVS2_G  = df_050_059_OE_VVS2_G.assign(Symmetry=None)
                    df_050_059_OE_VVS2_G  = df_050_059_OE_VVS2_G.assign(Ratio=None)
                    df_050_059_OE_VVS2_G  = df_050_059_OE_VVS2_G.assign(PPC=None)
                    df_050_059_OE_VVS2_G  = df_050_059_OE_VVS2_G.assign(Total=None)
                    df_050_059_OE_VVS2_G ['Wt Range'] = listwtrange
                    df_050_059_OE_VVS2_G ['Company'] = listcom
                    df_050_059_OE_VVS2_G ['Shape'] = listshap
                    df_050_059_OE_VVS2_G ['Carat'] = listcar
                    df_050_059_OE_VVS2_G ['Color'] = listcol
                    df_050_059_OE_VVS2_G ['Clarity'] = listclar
                    df_050_059_OE_VVS2_G ['Cut'] = listcut
                    df_050_059_OE_VVS2_G ['Polish'] = listpol
                    df_050_059_OE_VVS2_G ['Symmetry'] = listsym
                    df_050_059_OE_VVS2_G ['Ratio'] = listrat
                    df_050_059_OE_VVS2_G ['PPC'] = listdesc
                    df_050_059_OE_VVS2_G ['Total'] = listtotal
                    df_050_059_OE_VVS2_G['Carat'] = df_050_059_OE_VVS2_G['Carat'].astype('float64')
                    df_050_059_OE_VVS2_G['PPC'] = df_050_059_OE_VVS2_G['PPC'].astype('float64')
                    df_050_059_OE_VVS2_G['Total'] = df_050_059_OE_VVS2_G['Total'].astype('float64')
                    df_050_059_OE_VVS2_G['Total'] = df_050_059_OE_VVS2_G['Carat'] * df_050_059_OE_VVS2_G['PPC']


                elif i=="G" and j=="VS1" and k == "OE":
                    df_050_059_OE_VS1_G = pd.DataFrame()
                    df_050_059_OE_VS1_G ['Wt Range'] = None
                    df_050_059_OE_VS1_G  = df_050_059_OE_VS1_G.assign(Company=None)
                    df_050_059_OE_VS1_G  = df_050_059_OE_VS1_G.assign(Shape=None)
                    df_050_059_OE_VS1_G  = df_050_059_OE_VS1_G.assign(Carat=None)
                    df_050_059_OE_VS1_G  = df_050_059_OE_VS1_G.assign(Color=None)
                    df_050_059_OE_VS1_G  = df_050_059_OE_VS1_G.assign(Clarity=None)
                    df_050_059_OE_VS1_G  = df_050_059_OE_VS1_G.assign(Cut=None)
                    df_050_059_OE_VS1_G  = df_050_059_OE_VS1_G.assign(Polish=None)
                    df_050_059_OE_VS1_G  = df_050_059_OE_VS1_G.assign(Symmetry=None)
                    df_050_059_OE_VS1_G  = df_050_059_OE_VS1_G.assign(Ratio=None)
                    df_050_059_OE_VS1_G  = df_050_059_OE_VS1_G.assign(PPC=None)
                    df_050_059_OE_VS1_G  = df_050_059_OE_VS1_G.assign(Total=None)
                    df_050_059_OE_VS1_G ['Wt Range'] = listwtrange
                    df_050_059_OE_VS1_G ['Company'] = listcom
                    df_050_059_OE_VS1_G ['Shape'] = listshap
                    df_050_059_OE_VS1_G ['Carat'] = listcar
                    df_050_059_OE_VS1_G ['Color'] = listcol
                    df_050_059_OE_VS1_G ['Clarity'] = listclar
                    df_050_059_OE_VS1_G ['Cut'] = listcut
                    df_050_059_OE_VS1_G ['Polish'] = listpol
                    df_050_059_OE_VS1_G ['Symmetry'] = listsym
                    df_050_059_OE_VS1_G ['Ratio'] = listrat
                    df_050_059_OE_VS1_G ['PPC'] = listdesc
                    df_050_059_OE_VS1_G ['Total'] = listtotal
                    df_050_059_OE_VS1_G['Carat'] = df_050_059_OE_VS1_G['Carat'].astype('float64')
                    df_050_059_OE_VS1_G['PPC'] = df_050_059_OE_VS1_G['PPC'].astype('float64')
                    df_050_059_OE_VS1_G['Total'] = df_050_059_OE_VS1_G['Total'].astype('float64')
                    df_050_059_OE_VS1_G['Total'] = df_050_059_OE_VS1_G['Carat'] * df_050_059_OE_VS1_G['PPC']


                elif i=="G" and j == "VS2" and k == "OE":
                    df_050_059_OE_VS2_G = pd.DataFrame()
                    df_050_059_OE_VS2_G ['Wt Range'] = None
                    df_050_059_OE_VS2_G  = df_050_059_OE_VS2_G.assign(Company=None)
                    df_050_059_OE_VS2_G  = df_050_059_OE_VS2_G.assign(Shape=None)
                    df_050_059_OE_VS2_G  = df_050_059_OE_VS2_G.assign(Carat=None)
                    df_050_059_OE_VS2_G  = df_050_059_OE_VS2_G.assign(Color=None)
                    df_050_059_OE_VS2_G  = df_050_059_OE_VS2_G.assign(Clarity=None)
                    df_050_059_OE_VS2_G  = df_050_059_OE_VS2_G.assign(Cut=None)
                    df_050_059_OE_VS2_G  = df_050_059_OE_VS2_G.assign(Polish=None)
                    df_050_059_OE_VS2_G  = df_050_059_OE_VS2_G.assign(Symmetry=None)
                    df_050_059_OE_VS2_G  = df_050_059_OE_VS2_G.assign(Ratio=None)
                    df_050_059_OE_VS2_G  = df_050_059_OE_VS2_G.assign(PPC=None)
                    df_050_059_OE_VS2_G  = df_050_059_OE_VS2_G.assign(Total=None)
                    df_050_059_OE_VS2_G ['Wt Range'] = listwtrange
                    df_050_059_OE_VS2_G ['Company'] = listcom
                    df_050_059_OE_VS2_G ['Shape'] = listshap
                    df_050_059_OE_VS2_G ['Carat'] = listcar
                    df_050_059_OE_VS2_G ['Color'] = listcol
                    df_050_059_OE_VS2_G ['Clarity'] = listclar
                    df_050_059_OE_VS2_G ['Cut'] = listcut
                    df_050_059_OE_VS2_G ['Polish'] = listpol
                    df_050_059_OE_VS2_G ['Symmetry'] = listsym
                    df_050_059_OE_VS2_G ['Ratio'] = listrat
                    df_050_059_OE_VS2_G ['PPC'] = listdesc
                    df_050_059_OE_VS2_G ['Total'] = listtotal
                    df_050_059_OE_VS2_G['Carat'] = df_050_059_OE_VS2_G['Carat'].astype('float64')
                    df_050_059_OE_VS2_G['PPC'] = df_050_059_OE_VS2_G['PPC'].astype('float64')
                    df_050_059_OE_VS2_G['Total'] = df_050_059_OE_VS2_G['Total'].astype('float64')
                    df_050_059_OE_VS2_G['Total'] = df_050_059_OE_VS2_G['Carat'] * df_050_059_OE_VS2_G['PPC']


                elif i=="G" and j == "SI1" and k == "OE":
                    df_050_059_OE_SI1_G = pd.DataFrame()
                    df_050_059_OE_SI1_G ['Wt Range'] = None
                    df_050_059_OE_SI1_G  = df_050_059_OE_SI1_G.assign(Company=None)
                    df_050_059_OE_SI1_G  = df_050_059_OE_SI1_G.assign(Shape=None)
                    df_050_059_OE_SI1_G  = df_050_059_OE_SI1_G.assign(Carat=None)
                    df_050_059_OE_SI1_G  = df_050_059_OE_SI1_G.assign(Color=None)
                    df_050_059_OE_SI1_G  = df_050_059_OE_SI1_G.assign(Clarity=None)
                    df_050_059_OE_SI1_G  = df_050_059_OE_SI1_G.assign(Cut=None)
                    df_050_059_OE_SI1_G  = df_050_059_OE_SI1_G.assign(Polish=None)
                    df_050_059_OE_SI1_G  = df_050_059_OE_SI1_G.assign(Symmetry=None)
                    df_050_059_OE_SI1_G  = df_050_059_OE_SI1_G.assign(Ratio=None)
                    df_050_059_OE_SI1_G  = df_050_059_OE_SI1_G.assign(PPC=None)
                    df_050_059_OE_SI1_G  = df_050_059_OE_SI1_G.assign(Total=None)
                    df_050_059_OE_SI1_G ['Wt Range'] = listwtrange
                    df_050_059_OE_SI1_G ['Company'] = listcom
                    df_050_059_OE_SI1_G ['Shape'] = listshap
                    df_050_059_OE_SI1_G ['Carat'] = listcar
                    df_050_059_OE_SI1_G ['Color'] = listcol
                    df_050_059_OE_SI1_G ['Clarity'] = listclar
                    df_050_059_OE_SI1_G ['Cut'] = listcut
                    df_050_059_OE_SI1_G ['Polish'] = listpol
                    df_050_059_OE_SI1_G ['Symmetry'] = listsym
                    df_050_059_OE_SI1_G ['Ratio'] = listrat
                    df_050_059_OE_SI1_G ['PPC'] = listdesc
                    df_050_059_OE_SI1_G ['Total'] = listtotal
                    df_050_059_OE_SI1_G['Carat'] = df_050_059_OE_SI1_G['Carat'].astype('float64')
                    df_050_059_OE_SI1_G['PPC'] = df_050_059_OE_SI1_G['PPC'].astype('float64')
                    df_050_059_OE_SI1_G['Total'] = df_050_059_OE_SI1_G['Total'].astype('float64')
                    df_050_059_OE_SI1_G['Total'] = df_050_059_OE_SI1_G['Carat'] * df_050_059_OE_SI1_G['PPC']


                elif i=="G" and j == "SI2" and k == "OE":
                    df_050_059_OE_SI2_G = pd.DataFrame()
                    df_050_059_OE_SI2_G ['Wt Range'] = None
                    df_050_059_OE_SI2_G  = df_050_059_OE_SI2_G.assign(Company=None)
                    df_050_059_OE_SI2_G  = df_050_059_OE_SI2_G.assign(Shape=None)
                    df_050_059_OE_SI2_G  = df_050_059_OE_SI2_G.assign(Carat=None)
                    df_050_059_OE_SI2_G  = df_050_059_OE_SI2_G.assign(Color=None)
                    df_050_059_OE_SI2_G  = df_050_059_OE_SI2_G.assign(Clarity=None)
                    df_050_059_OE_SI2_G  = df_050_059_OE_SI2_G.assign(Cut=None)
                    df_050_059_OE_SI2_G  = df_050_059_OE_SI2_G.assign(Polish=None)
                    df_050_059_OE_SI2_G  = df_050_059_OE_SI2_G.assign(Symmetry=None)
                    df_050_059_OE_SI2_G  = df_050_059_OE_SI2_G.assign(Ratio=None)
                    df_050_059_OE_SI2_G  = df_050_059_OE_SI2_G.assign(PPC=None)
                    df_050_059_OE_SI2_G  = df_050_059_OE_SI2_G.assign(Total=None)
                    df_050_059_OE_SI2_G ['Wt Range'] = listwtrange
                    df_050_059_OE_SI2_G ['Company'] = listcom
                    df_050_059_OE_SI2_G ['Shape'] = listshap
                    df_050_059_OE_SI2_G ['Carat'] = listcar
                    df_050_059_OE_SI2_G ['Color'] = listcol
                    df_050_059_OE_SI2_G ['Clarity'] = listclar
                    df_050_059_OE_SI2_G ['Cut'] = listcut
                    df_050_059_OE_SI2_G ['Polish'] = listpol
                    df_050_059_OE_SI2_G ['Symmetry'] = listsym
                    df_050_059_OE_SI2_G ['Ratio'] = listrat
                    df_050_059_OE_SI2_G ['PPC'] = listdesc
                    df_050_059_OE_SI2_G ['Total'] = listtotal
                    df_050_059_OE_SI2_G['Carat'] = df_050_059_OE_SI2_G['Carat'].astype('float64')
                    df_050_059_OE_SI2_G['PPC'] = df_050_059_OE_SI2_G['PPC'].astype('float64')
                    df_050_059_OE_SI2_G['Total'] = df_050_059_OE_SI2_G['Total'].astype('float64')
                    df_050_059_OE_SI2_G['Total'] = df_050_059_OE_SI2_G['Carat'] * df_050_059_OE_SI2_G['PPC']


                elif i=="G" and j == "I1" and k == "OE":
                    df_050_059_OE_I1_G = pd.DataFrame()
                    df_050_059_OE_I1_G ['Wt Range'] = None
                    df_050_059_OE_I1_G  = df_050_059_OE_I1_G.assign(Company=None)
                    df_050_059_OE_I1_G  = df_050_059_OE_I1_G.assign(Shape=None)
                    df_050_059_OE_I1_G  = df_050_059_OE_I1_G.assign(Carat=None)
                    df_050_059_OE_I1_G  = df_050_059_OE_I1_G.assign(Color=None)
                    df_050_059_OE_I1_G  = df_050_059_OE_I1_G.assign(Clarity=None)
                    df_050_059_OE_I1_G  = df_050_059_OE_I1_G.assign(Cut=None)
                    df_050_059_OE_I1_G  = df_050_059_OE_I1_G.assign(Polish=None)
                    df_050_059_OE_I1_G  = df_050_059_OE_I1_G.assign(Symmetry=None)
                    df_050_059_OE_I1_G  = df_050_059_OE_I1_G.assign(Ratio=None)
                    df_050_059_OE_I1_G  = df_050_059_OE_I1_G.assign(PPC=None)
                    df_050_059_OE_I1_G  = df_050_059_OE_I1_G.assign(Total=None)
                    df_050_059_OE_I1_G ['Wt Range'] = listwtrange
                    df_050_059_OE_I1_G ['Company'] = listcom
                    df_050_059_OE_I1_G ['Shape'] = listshap
                    df_050_059_OE_I1_G ['Carat'] = listcar
                    df_050_059_OE_I1_G ['Color'] = listcol
                    df_050_059_OE_I1_G ['Clarity'] = listclar
                    df_050_059_OE_I1_G ['Cut'] = listcut
                    df_050_059_OE_I1_G ['Polish'] = listpol
                    df_050_059_OE_I1_G ['Symmetry'] = listsym
                    df_050_059_OE_I1_G ['Ratio'] = listrat
                    df_050_059_OE_I1_G ['PPC'] = listdesc
                    df_050_059_OE_I1_G ['Total'] = listtotal
                    df_050_059_OE_I1_G['Carat'] = df_050_059_OE_I1_G['Carat'].astype('float64')
                    df_050_059_OE_I1_G['PPC'] = df_050_059_OE_I1_G['PPC'].astype('float64')
                    df_050_059_OE_I1_G['Total'] = df_050_059_OE_I1_G['Total'].astype('float64')
                    df_050_059_OE_I1_G['Total'] = df_050_059_OE_I1_G['Carat'] * df_050_059_OE_I1_G['PPC']


                elif i=="G" and j == "I2" and k == "OE":
                    df_050_059_OE_I2_G = pd.DataFrame()
                    df_050_059_OE_I2_G ['Wt Range'] = None
                    df_050_059_OE_I2_G  = df_050_059_OE_I2_G.assign(Company=None)
                    df_050_059_OE_I2_G  = df_050_059_OE_I2_G.assign(Shape=None)
                    df_050_059_OE_I2_G  = df_050_059_OE_I2_G.assign(Carat=None)
                    df_050_059_OE_I2_G  = df_050_059_OE_I2_G.assign(Color=None)
                    df_050_059_OE_I2_G  = df_050_059_OE_I2_G.assign(Clarity=None)
                    df_050_059_OE_I2_G  = df_050_059_OE_I2_G.assign(Cut=None)
                    df_050_059_OE_I2_G  = df_050_059_OE_I2_G.assign(Polish=None)
                    df_050_059_OE_I2_G  = df_050_059_OE_I2_G.assign(Symmetry=None)
                    df_050_059_OE_I2_G  = df_050_059_OE_I2_G.assign(Ratio=None)
                    df_050_059_OE_I2_G  = df_050_059_OE_I2_G.assign(PPC=None)
                    df_050_059_OE_I2_G  = df_050_059_OE_I2_G.assign(Total=None)
                    df_050_059_OE_I2_G ['Wt Range'] = listwtrange
                    df_050_059_OE_I2_G ['Company'] = listcom
                    df_050_059_OE_I2_G ['Shape'] = listshap
                    df_050_059_OE_I2_G ['Carat'] = listcar
                    df_050_059_OE_I2_G ['Color'] = listcol
                    df_050_059_OE_I2_G ['Clarity'] = listclar
                    df_050_059_OE_I2_G ['Cut'] = listcut
                    df_050_059_OE_I2_G ['Polish'] = listpol
                    df_050_059_OE_I2_G ['Symmetry'] = listsym
                    df_050_059_OE_I2_G ['Ratio'] = listrat
                    df_050_059_OE_I2_G ['PPC'] = listdesc
                    df_050_059_OE_I2_G ['Total'] = listtotal
                    df_050_059_OE_I2_G['Carat'] = df_050_059_OE_I2_G['Carat'].astype('float64')
                    df_050_059_OE_I2_G['PPC'] = df_050_059_OE_I2_G['PPC'].astype('float64')
                    df_050_059_OE_I2_G['Total'] = df_050_059_OE_I2_G['Total'].astype('float64')
                    df_050_059_OE_I2_G['Total'] = df_050_059_OE_I2_G['Carat'] * df_050_059_OE_I2_G['PPC']


                elif i=="H" and j == "IF" and k == "OE":
                    df_050_059_OE_IF_H = pd.DataFrame()
                    df_050_059_OE_IF_H ['Wt Range'] = None
                    df_050_059_OE_IF_H  = df_050_059_OE_IF_H.assign(Company=None)
                    df_050_059_OE_IF_H  = df_050_059_OE_IF_H.assign(Shape=None)
                    df_050_059_OE_IF_H  = df_050_059_OE_IF_H.assign(Carat=None)
                    df_050_059_OE_IF_H  = df_050_059_OE_IF_H.assign(Color=None)
                    df_050_059_OE_IF_H  = df_050_059_OE_IF_H.assign(Clarity=None)
                    df_050_059_OE_IF_H  = df_050_059_OE_IF_H.assign(Cut=None)
                    df_050_059_OE_IF_H  = df_050_059_OE_IF_H.assign(Polish=None)
                    df_050_059_OE_IF_H  = df_050_059_OE_IF_H.assign(Symmetry=None)
                    df_050_059_OE_IF_H  = df_050_059_OE_IF_H.assign(Ratio=None)
                    df_050_059_OE_IF_H  = df_050_059_OE_IF_H.assign(PPC=None)
                    df_050_059_OE_IF_H  = df_050_059_OE_IF_H.assign(Total=None)
                    df_050_059_OE_IF_H ['Wt Range'] = listwtrange
                    df_050_059_OE_IF_H ['Company'] = listcom
                    df_050_059_OE_IF_H ['Shape'] = listshap
                    df_050_059_OE_IF_H ['Carat'] = listcar
                    df_050_059_OE_IF_H ['Color'] = listcol
                    df_050_059_OE_IF_H ['Clarity'] = listclar
                    df_050_059_OE_IF_H ['Cut'] = listcut
                    df_050_059_OE_IF_H ['Polish'] = listpol
                    df_050_059_OE_IF_H ['Symmetry'] = listsym
                    df_050_059_OE_IF_H ['Ratio'] = listrat
                    df_050_059_OE_IF_H ['PPC'] = listdesc
                    df_050_059_OE_IF_H ['Total'] = listtotal
                    df_050_059_OE_IF_H['Carat'] = df_050_059_OE_IF_H['Carat'].astype('float64')
                    df_050_059_OE_IF_H['PPC'] = df_050_059_OE_IF_H['PPC'].astype('float64')
                    df_050_059_OE_IF_H['Total'] = df_050_059_OE_IF_H['Total'].astype('float64')
                    df_050_059_OE_IF_H['Total'] = df_050_059_OE_IF_H['Carat'] * df_050_059_OE_IF_H['PPC']



                elif i=="H" and j == "VVS1" and k == "OE":
                    df_050_059_OE_VVS1_H = pd.DataFrame()
                    df_050_059_OE_VVS1_H ['Wt Range'] = None
                    df_050_059_OE_VVS1_H  = df_050_059_OE_VVS1_H.assign(Company=None)
                    df_050_059_OE_VVS1_H  = df_050_059_OE_VVS1_H.assign(Shape=None)
                    df_050_059_OE_VVS1_H  = df_050_059_OE_VVS1_H.assign(Carat=None)
                    df_050_059_OE_VVS1_H  = df_050_059_OE_VVS1_H.assign(Color=None)
                    df_050_059_OE_VVS1_H  = df_050_059_OE_VVS1_H.assign(Clarity=None)
                    df_050_059_OE_VVS1_H  = df_050_059_OE_VVS1_H.assign(Cut=None)
                    df_050_059_OE_VVS1_H  = df_050_059_OE_VVS1_H.assign(Polish=None)
                    df_050_059_OE_VVS1_H  = df_050_059_OE_VVS1_H.assign(Symmetry=None)
                    df_050_059_OE_VVS1_H  = df_050_059_OE_VVS1_H.assign(Ratio=None)
                    df_050_059_OE_VVS1_H  = df_050_059_OE_VVS1_H.assign(PPC=None)
                    df_050_059_OE_VVS1_H  = df_050_059_OE_VVS1_H.assign(Total=None)
                    df_050_059_OE_VVS1_H ['Wt Range'] = listwtrange
                    df_050_059_OE_VVS1_H ['Company'] = listcom
                    df_050_059_OE_VVS1_H ['Shape'] = listshap
                    df_050_059_OE_VVS1_H ['Carat'] = listcar
                    df_050_059_OE_VVS1_H ['Color'] = listcol
                    df_050_059_OE_VVS1_H ['Clarity'] = listclar
                    df_050_059_OE_VVS1_H ['Cut'] = listcut
                    df_050_059_OE_VVS1_H ['Polish'] = listpol
                    df_050_059_OE_VVS1_H ['Symmetry'] = listsym
                    df_050_059_OE_VVS1_H ['Ratio'] = listrat
                    df_050_059_OE_VVS1_H ['PPC'] = listdesc
                    df_050_059_OE_VVS1_H ['Total'] = listtotal
                    df_050_059_OE_VVS1_H['Carat'] = df_050_059_OE_VVS1_H['Carat'].astype('float64')
                    df_050_059_OE_VVS1_H['PPC'] = df_050_059_OE_VVS1_H['PPC'].astype('float64')
                    df_050_059_OE_VVS1_H['Total'] = df_050_059_OE_VVS1_H['Total'].astype('float64')
                    df_050_059_OE_VVS1_H['Total'] = df_050_059_OE_VVS1_H['Carat'] * df_050_059_OE_VVS1_H['PPC']


                elif i=="H" and j == "VVS2" and k == "OE":
                    df_050_059_OE_VVS2_H = pd.DataFrame()
                    df_050_059_OE_VVS2_H ['Wt Range'] = None
                    df_050_059_OE_VVS2_H  = df_050_059_OE_VVS2_H.assign(Company=None)
                    df_050_059_OE_VVS2_H  = df_050_059_OE_VVS2_H.assign(Shape=None)
                    df_050_059_OE_VVS2_H  = df_050_059_OE_VVS2_H.assign(Carat=None)
                    df_050_059_OE_VVS2_H  = df_050_059_OE_VVS2_H.assign(Color=None)
                    df_050_059_OE_VVS2_H  = df_050_059_OE_VVS2_H.assign(Clarity=None)
                    df_050_059_OE_VVS2_H  = df_050_059_OE_VVS2_H.assign(Cut=None)
                    df_050_059_OE_VVS2_H  = df_050_059_OE_VVS2_H.assign(Polish=None)
                    df_050_059_OE_VVS2_H  = df_050_059_OE_VVS2_H.assign(Symmetry=None)
                    df_050_059_OE_VVS2_H  = df_050_059_OE_VVS2_H.assign(Ratio=None)
                    df_050_059_OE_VVS2_H  = df_050_059_OE_VVS2_H.assign(PPC=None)
                    df_050_059_OE_VVS2_H  = df_050_059_OE_VVS2_H.assign(Total=None)
                    df_050_059_OE_VVS2_H ['Wt Range'] = listwtrange
                    df_050_059_OE_VVS2_H ['Company'] = listcom
                    df_050_059_OE_VVS2_H ['Shape'] = listshap
                    df_050_059_OE_VVS2_H ['Carat'] = listcar
                    df_050_059_OE_VVS2_H ['Color'] = listcol
                    df_050_059_OE_VVS2_H ['Clarity'] = listclar
                    df_050_059_OE_VVS2_H ['Cut'] = listcut
                    df_050_059_OE_VVS2_H ['Polish'] = listpol
                    df_050_059_OE_VVS2_H ['Symmetry'] = listsym
                    df_050_059_OE_VVS2_H ['Ratio'] = listrat
                    df_050_059_OE_VVS2_H ['PPC'] = listdesc
                    df_050_059_OE_VVS2_H ['Total'] = listtotal
                    df_050_059_OE_VVS2_H['Carat'] = df_050_059_OE_VVS2_H['Carat'].astype('float64')
                    df_050_059_OE_VVS2_H['PPC'] = df_050_059_OE_VVS2_H['PPC'].astype('float64')
                    df_050_059_OE_VVS2_H['Total'] = df_050_059_OE_VVS2_H['Total'].astype('float64')
                    df_050_059_OE_VVS2_H['Total'] = df_050_059_OE_VVS2_H['Carat'] * df_050_059_OE_VVS2_H['PPC']


                elif i=="H" and j=="VS1" and k == "OE":
                    df_050_059_OE_VS1_H = pd.DataFrame()
                    df_050_059_OE_VS1_H ['Wt Range'] = None
                    df_050_059_OE_VS1_H  = df_050_059_OE_VS1_H.assign(Company=None)
                    df_050_059_OE_VS1_H  = df_050_059_OE_VS1_H.assign(Shape=None)
                    df_050_059_OE_VS1_H  = df_050_059_OE_VS1_H.assign(Carat=None)
                    df_050_059_OE_VS1_H  = df_050_059_OE_VS1_H.assign(Color=None)
                    df_050_059_OE_VS1_H  = df_050_059_OE_VS1_H.assign(Clarity=None)
                    df_050_059_OE_VS1_H  = df_050_059_OE_VS1_H.assign(Cut=None)
                    df_050_059_OE_VS1_H  = df_050_059_OE_VS1_H.assign(Polish=None)
                    df_050_059_OE_VS1_H  = df_050_059_OE_VS1_H.assign(Symmetry=None)
                    df_050_059_OE_VS1_H  = df_050_059_OE_VS1_H.assign(Ratio=None)
                    df_050_059_OE_VS1_H  = df_050_059_OE_VS1_H.assign(PPC=None)
                    df_050_059_OE_VS1_H  = df_050_059_OE_VS1_H.assign(Total=None)
                    df_050_059_OE_VS1_H ['Wt Range'] = listwtrange
                    df_050_059_OE_VS1_H ['Company'] = listcom
                    df_050_059_OE_VS1_H ['Shape'] = listshap
                    df_050_059_OE_VS1_H ['Carat'] = listcar
                    df_050_059_OE_VS1_H ['Color'] = listcol
                    df_050_059_OE_VS1_H ['Clarity'] = listclar
                    df_050_059_OE_VS1_H ['Cut'] = listcut
                    df_050_059_OE_VS1_H ['Polish'] = listpol
                    df_050_059_OE_VS1_H ['Symmetry'] = listsym
                    df_050_059_OE_VS1_H ['Ratio'] = listrat
                    df_050_059_OE_VS1_H ['PPC'] = listdesc
                    df_050_059_OE_VS1_H ['Total'] = listtotal
                    df_050_059_OE_VS1_H['Carat'] = df_050_059_OE_VS1_H['Carat'].astype('float64')
                    df_050_059_OE_VS1_H['PPC'] = df_050_059_OE_VS1_H['PPC'].astype('float64')
                    df_050_059_OE_VS1_H['Total'] = df_050_059_OE_VS1_H['Total'].astype('float64')
                    df_050_059_OE_VS1_H['Total'] = df_050_059_OE_VS1_H['Carat'] * df_050_059_OE_VS1_H['PPC']


                elif i=="H" and j == "VS2" and k == "OE":
                    df_050_059_OE_VS2_H = pd.DataFrame()
                    df_050_059_OE_VS2_H ['Wt Range'] = None
                    df_050_059_OE_VS2_H  = df_050_059_OE_VS2_H.assign(Company=None)
                    df_050_059_OE_VS2_H  = df_050_059_OE_VS2_H.assign(Shape=None)
                    df_050_059_OE_VS2_H  = df_050_059_OE_VS2_H.assign(Carat=None)
                    df_050_059_OE_VS2_H  = df_050_059_OE_VS2_H.assign(Color=None)
                    df_050_059_OE_VS2_H  = df_050_059_OE_VS2_H.assign(Clarity=None)
                    df_050_059_OE_VS2_H  = df_050_059_OE_VS2_H.assign(Cut=None)
                    df_050_059_OE_VS2_H  = df_050_059_OE_VS2_H.assign(Polish=None)
                    df_050_059_OE_VS2_H  = df_050_059_OE_VS2_H.assign(Symmetry=None)
                    df_050_059_OE_VS2_H  = df_050_059_OE_VS2_H.assign(Ratio=None)
                    df_050_059_OE_VS2_H  = df_050_059_OE_VS2_H.assign(PPC=None)
                    df_050_059_OE_VS2_H  = df_050_059_OE_VS2_H.assign(Total=None)
                    df_050_059_OE_VS2_H ['Wt Range'] = listwtrange
                    df_050_059_OE_VS2_H ['Company'] = listcom
                    df_050_059_OE_VS2_H ['Shape'] = listshap
                    df_050_059_OE_VS2_H ['Carat'] = listcar
                    df_050_059_OE_VS2_H ['Color'] = listcol
                    df_050_059_OE_VS2_H ['Clarity'] = listclar
                    df_050_059_OE_VS2_H ['Cut'] = listcut
                    df_050_059_OE_VS2_H ['Polish'] = listpol
                    df_050_059_OE_VS2_H ['Symmetry'] = listsym
                    df_050_059_OE_VS2_H ['Ratio'] = listrat
                    df_050_059_OE_VS2_H ['PPC'] = listdesc
                    df_050_059_OE_VS2_H ['Total'] = listtotal
                    df_050_059_OE_VS2_H['Carat'] = df_050_059_OE_VS2_H['Carat'].astype('float64')
                    df_050_059_OE_VS2_H['PPC'] = df_050_059_OE_VS2_H['PPC'].astype('float64')
                    df_050_059_OE_VS2_H['Total'] = df_050_059_OE_VS2_H['Total'].astype('float64')
                    df_050_059_OE_VS2_H['Total'] = df_050_059_OE_VS2_H['Carat'] * df_050_059_OE_VS2_H['PPC']


                elif i=="H" and j == "SI1" and k == "OE":
                    df_050_059_OE_SI1_H = pd.DataFrame()
                    df_050_059_OE_SI1_H ['Wt Range'] = None
                    df_050_059_OE_SI1_H  = df_050_059_OE_SI1_H.assign(Company=None)
                    df_050_059_OE_SI1_H  = df_050_059_OE_SI1_H.assign(Shape=None)
                    df_050_059_OE_SI1_H  = df_050_059_OE_SI1_H.assign(Carat=None)
                    df_050_059_OE_SI1_H  = df_050_059_OE_SI1_H.assign(Color=None)
                    df_050_059_OE_SI1_H  = df_050_059_OE_SI1_H.assign(Clarity=None)
                    df_050_059_OE_SI1_H  = df_050_059_OE_SI1_H.assign(Cut=None)
                    df_050_059_OE_SI1_H  = df_050_059_OE_SI1_H.assign(Polish=None)
                    df_050_059_OE_SI1_H  = df_050_059_OE_SI1_H.assign(Symmetry=None)
                    df_050_059_OE_SI1_H  = df_050_059_OE_SI1_H.assign(Ratio=None)
                    df_050_059_OE_SI1_H  = df_050_059_OE_SI1_H.assign(PPC=None)
                    df_050_059_OE_SI1_H  = df_050_059_OE_SI1_H.assign(Total=None)
                    df_050_059_OE_SI1_H ['Wt Range'] = listwtrange
                    df_050_059_OE_SI1_H ['Company'] = listcom
                    df_050_059_OE_SI1_H ['Shape'] = listshap
                    df_050_059_OE_SI1_H ['Carat'] = listcar
                    df_050_059_OE_SI1_H ['Color'] = listcol
                    df_050_059_OE_SI1_H ['Clarity'] = listclar
                    df_050_059_OE_SI1_H ['Cut'] = listcut
                    df_050_059_OE_SI1_H ['Polish'] = listpol
                    df_050_059_OE_SI1_H ['Symmetry'] = listsym
                    df_050_059_OE_SI1_H ['Ratio'] = listrat
                    df_050_059_OE_SI1_H ['PPC'] = listdesc
                    df_050_059_OE_SI1_H ['Total'] = listtotal
                    df_050_059_OE_SI1_H['Carat'] = df_050_059_OE_SI1_H['Carat'].astype('float64')
                    df_050_059_OE_SI1_H['PPC'] = df_050_059_OE_SI1_H['PPC'].astype('float64')
                    df_050_059_OE_SI1_H['Total'] = df_050_059_OE_SI1_H['Total'].astype('float64')
                    df_050_059_OE_SI1_H['Total'] = df_050_059_OE_SI1_H['Carat'] * df_050_059_OE_SI1_H['PPC']


                elif i=="H" and j == "SI2" and k == "OE":
                    df_050_059_OE_SI2_H = pd.DataFrame()
                    df_050_059_OE_SI2_H ['Wt Range'] = None
                    df_050_059_OE_SI2_H  = df_050_059_OE_SI2_H.assign(Company=None)
                    df_050_059_OE_SI2_H  = df_050_059_OE_SI2_H.assign(Shape=None)
                    df_050_059_OE_SI2_H  = df_050_059_OE_SI2_H.assign(Carat=None)
                    df_050_059_OE_SI2_H  = df_050_059_OE_SI2_H.assign(Color=None)
                    df_050_059_OE_SI2_H  = df_050_059_OE_SI2_H.assign(Clarity=None)
                    df_050_059_OE_SI2_H  = df_050_059_OE_SI2_H.assign(Cut=None)
                    df_050_059_OE_SI2_H  = df_050_059_OE_SI2_H.assign(Polish=None)
                    df_050_059_OE_SI2_H  = df_050_059_OE_SI2_H.assign(Symmetry=None)
                    df_050_059_OE_SI2_H  = df_050_059_OE_SI2_H.assign(Ratio=None)
                    df_050_059_OE_SI2_H  = df_050_059_OE_SI2_H.assign(PPC=None)
                    df_050_059_OE_SI2_H  = df_050_059_OE_SI2_H.assign(Total=None)
                    df_050_059_OE_SI2_H ['Wt Range'] = listwtrange
                    df_050_059_OE_SI2_H ['Company'] = listcom
                    df_050_059_OE_SI2_H ['Shape'] = listshap
                    df_050_059_OE_SI2_H ['Carat'] = listcar
                    df_050_059_OE_SI2_H ['Color'] = listcol
                    df_050_059_OE_SI2_H ['Clarity'] = listclar
                    df_050_059_OE_SI2_H ['Cut'] = listcut
                    df_050_059_OE_SI2_H ['Polish'] = listpol
                    df_050_059_OE_SI2_H ['Symmetry'] = listsym
                    df_050_059_OE_SI2_H ['Ratio'] = listrat
                    df_050_059_OE_SI2_H ['PPC'] = listdesc
                    df_050_059_OE_SI2_H ['Total'] = listtotal
                    df_050_059_OE_SI2_H['Carat'] = df_050_059_OE_SI2_H['Carat'].astype('float64')
                    df_050_059_OE_SI2_H['PPC'] = df_050_059_OE_SI2_H['PPC'].astype('float64')
                    df_050_059_OE_SI2_H['Total'] = df_050_059_OE_SI2_H['Total'].astype('float64')
                    df_050_059_OE_SI2_H['Total'] = df_050_059_OE_SI2_H['Carat'] * df_050_059_OE_SI2_H['PPC']


                elif i=="H" and j == "I1" and k == "OE":
                    df_050_059_OE_I1_H = pd.DataFrame()
                    df_050_059_OE_I1_H ['Wt Range'] = None
                    df_050_059_OE_I1_H  = df_050_059_OE_I1_H.assign(Company=None)
                    df_050_059_OE_I1_H  = df_050_059_OE_I1_H.assign(Shape=None)
                    df_050_059_OE_I1_H  = df_050_059_OE_I1_H.assign(Carat=None)
                    df_050_059_OE_I1_H  = df_050_059_OE_I1_H.assign(Color=None)
                    df_050_059_OE_I1_H  = df_050_059_OE_I1_H.assign(Clarity=None)
                    df_050_059_OE_I1_H  = df_050_059_OE_I1_H.assign(Cut=None)
                    df_050_059_OE_I1_H  = df_050_059_OE_I1_H.assign(Polish=None)
                    df_050_059_OE_I1_H  = df_050_059_OE_I1_H.assign(Symmetry=None)
                    df_050_059_OE_I1_H  = df_050_059_OE_I1_H.assign(Ratio=None)
                    df_050_059_OE_I1_H  = df_050_059_OE_I1_H.assign(PPC=None)
                    df_050_059_OE_I1_H  = df_050_059_OE_I1_H.assign(Total=None)
                    df_050_059_OE_I1_H ['Wt Range'] = listwtrange
                    df_050_059_OE_I1_H ['Company'] = listcom
                    df_050_059_OE_I1_H ['Shape'] = listshap
                    df_050_059_OE_I1_H ['Carat'] = listcar
                    df_050_059_OE_I1_H ['Color'] = listcol
                    df_050_059_OE_I1_H ['Clarity'] = listclar
                    df_050_059_OE_I1_H ['Cut'] = listcut
                    df_050_059_OE_I1_H ['Polish'] = listpol
                    df_050_059_OE_I1_H ['Symmetry'] = listsym
                    df_050_059_OE_I1_H ['Ratio'] = listrat
                    df_050_059_OE_I1_H ['PPC'] = listdesc
                    df_050_059_OE_I1_H ['Total'] = listtotal
                    df_050_059_OE_I1_H['Carat'] = df_050_059_OE_I1_H['Carat'].astype('float64')
                    df_050_059_OE_I1_H['PPC'] = df_050_059_OE_I1_H['PPC'].astype('float64')
                    df_050_059_OE_I1_H['Total'] = df_050_059_OE_I1_H['Total'].astype('float64')
                    df_050_059_OE_I1_H['Total'] = df_050_059_OE_I1_H['Carat'] * df_050_059_OE_I1_H['PPC']


                elif i=="H" and j == "I2" and k == "OE":
                    df_050_059_OE_I2_H = pd.DataFrame()
                    df_050_059_OE_I2_H ['Wt Range'] = None
                    df_050_059_OE_I2_H  = df_050_059_OE_I2_H.assign(Company=None)
                    df_050_059_OE_I2_H  = df_050_059_OE_I2_H.assign(Shape=None)
                    df_050_059_OE_I2_H  = df_050_059_OE_I2_H.assign(Carat=None)
                    df_050_059_OE_I2_H  = df_050_059_OE_I2_H.assign(Color=None)
                    df_050_059_OE_I2_H  = df_050_059_OE_I2_H.assign(Clarity=None)
                    df_050_059_OE_I2_H  = df_050_059_OE_I2_H.assign(Cut=None)
                    df_050_059_OE_I2_H  = df_050_059_OE_I2_H.assign(Polish=None)
                    df_050_059_OE_I2_H  = df_050_059_OE_I2_H.assign(Symmetry=None)
                    df_050_059_OE_I2_H  = df_050_059_OE_I2_H.assign(Ratio=None)
                    df_050_059_OE_I2_H  = df_050_059_OE_I2_H.assign(PPC=None)
                    df_050_059_OE_I2_H  = df_050_059_OE_I2_H.assign(Total=None)
                    df_050_059_OE_I2_H ['Wt Range'] = listwtrange
                    df_050_059_OE_I2_H ['Company'] = listcom
                    df_050_059_OE_I2_H ['Shape'] = listshap
                    df_050_059_OE_I2_H ['Carat'] = listcar
                    df_050_059_OE_I2_H ['Color'] = listcol
                    df_050_059_OE_I2_H ['Clarity'] = listclar
                    df_050_059_OE_I2_H ['Cut'] = listcut
                    df_050_059_OE_I2_H ['Polish'] = listpol
                    df_050_059_OE_I2_H ['Symmetry'] = listsym
                    df_050_059_OE_I2_H ['Ratio'] = listrat
                    df_050_059_OE_I2_H ['PPC'] = listdesc
                    df_050_059_OE_I2_H ['Total'] = listtotal
                    df_050_059_OE_I2_H['Carat'] = df_050_059_OE_I2_H['Carat'].astype('float64')
                    df_050_059_OE_I2_H['PPC'] = df_050_059_OE_I2_H['PPC'].astype('float64')
                    df_050_059_OE_I2_H['Total'] = df_050_059_OE_I2_H['Total'].astype('float64')
                    df_050_059_OE_I2_H['Total'] = df_050_059_OE_I2_H['Carat'] * df_050_059_OE_I2_H['PPC']



                elif i== "I" and j == "IF" and k == "OE":
                    df_050_059_OE_IF_I = pd.DataFrame()
                    df_050_059_OE_IF_I ['Wt Range'] = None
                    df_050_059_OE_IF_I  = df_050_059_OE_IF_I.assign(Company=None)
                    df_050_059_OE_IF_I  = df_050_059_OE_IF_I.assign(Shape=None)
                    df_050_059_OE_IF_I  = df_050_059_OE_IF_I.assign(Carat=None)
                    df_050_059_OE_IF_I  = df_050_059_OE_IF_I.assign(Color=None)
                    df_050_059_OE_IF_I  = df_050_059_OE_IF_I.assign(Clarity=None)
                    df_050_059_OE_IF_I  = df_050_059_OE_IF_I.assign(Cut=None)
                    df_050_059_OE_IF_I  = df_050_059_OE_IF_I.assign(Polish=None)
                    df_050_059_OE_IF_I  = df_050_059_OE_IF_I.assign(Symmetry=None)
                    df_050_059_OE_IF_I  = df_050_059_OE_IF_I.assign(Ratio=None)
                    df_050_059_OE_IF_I  = df_050_059_OE_IF_I.assign(PPC=None)
                    df_050_059_OE_IF_I  = df_050_059_OE_IF_I.assign(Total=None)
                    df_050_059_OE_IF_I ['Wt Range'] = listwtrange
                    df_050_059_OE_IF_I ['Company'] = listcom
                    df_050_059_OE_IF_I ['Shape'] = listshap
                    df_050_059_OE_IF_I ['Carat'] = listcar
                    df_050_059_OE_IF_I ['Color'] = listcol
                    df_050_059_OE_IF_I ['Clarity'] = listclar
                    df_050_059_OE_IF_I ['Cut'] = listcut
                    df_050_059_OE_IF_I ['Polish'] = listpol
                    df_050_059_OE_IF_I ['Symmetry'] = listsym
                    df_050_059_OE_IF_I ['Ratio'] = listrat
                    df_050_059_OE_IF_I ['PPC'] = listdesc
                    df_050_059_OE_IF_I ['Total'] = listtotal
                    df_050_059_OE_IF_I['Carat'] = df_050_059_OE_IF_I['Carat'].astype('float64')
                    df_050_059_OE_IF_I['PPC'] = df_050_059_OE_IF_I['PPC'].astype('float64')
                    df_050_059_OE_IF_I['Total'] = df_050_059_OE_IF_I['Total'].astype('float64')
                    df_050_059_OE_IF_I['Total'] = df_050_059_OE_IF_I['Carat'] * df_050_059_OE_IF_I['PPC']



                elif i== "I" and j == "VVS1" and k == "OE":
                    df_050_059_OE_VVS1_I = pd.DataFrame()
                    df_050_059_OE_VVS1_I ['Wt Range'] = None
                    df_050_059_OE_VVS1_I  = df_050_059_OE_VVS1_I.assign(Company=None)
                    df_050_059_OE_VVS1_I  = df_050_059_OE_VVS1_I.assign(Shape=None)
                    df_050_059_OE_VVS1_I  = df_050_059_OE_VVS1_I.assign(Carat=None)
                    df_050_059_OE_VVS1_I  = df_050_059_OE_VVS1_I.assign(Color=None)
                    df_050_059_OE_VVS1_I  = df_050_059_OE_VVS1_I.assign(Clarity=None)
                    df_050_059_OE_VVS1_I  = df_050_059_OE_VVS1_I.assign(Cut=None)
                    df_050_059_OE_VVS1_I  = df_050_059_OE_VVS1_I.assign(Polish=None)
                    df_050_059_OE_VVS1_I  = df_050_059_OE_VVS1_I.assign(Symmetry=None)
                    df_050_059_OE_VVS1_I  = df_050_059_OE_VVS1_I.assign(Ratio=None)
                    df_050_059_OE_VVS1_I  = df_050_059_OE_VVS1_I.assign(PPC=None)
                    df_050_059_OE_VVS1_I  = df_050_059_OE_VVS1_I.assign(Total=None)
                    df_050_059_OE_VVS1_I ['Wt Range'] = listwtrange
                    df_050_059_OE_VVS1_I ['Company'] = listcom
                    df_050_059_OE_VVS1_I ['Shape'] = listshap
                    df_050_059_OE_VVS1_I ['Carat'] = listcar
                    df_050_059_OE_VVS1_I ['Color'] = listcol
                    df_050_059_OE_VVS1_I ['Clarity'] = listclar
                    df_050_059_OE_VVS1_I ['Cut'] = listcut
                    df_050_059_OE_VVS1_I ['Polish'] = listpol
                    df_050_059_OE_VVS1_I ['Symmetry'] = listsym
                    df_050_059_OE_VVS1_I ['Ratio'] = listrat
                    df_050_059_OE_VVS1_I ['PPC'] = listdesc
                    df_050_059_OE_VVS1_I ['Total'] = listtotal
                    df_050_059_OE_VVS1_I['Carat'] = df_050_059_OE_VVS1_I['Carat'].astype('float64')
                    df_050_059_OE_VVS1_I['PPC'] = df_050_059_OE_VVS1_I['PPC'].astype('float64')
                    df_050_059_OE_VVS1_I['Total'] = df_050_059_OE_VVS1_I['Total'].astype('float64')
                    df_050_059_OE_VVS1_I['Total'] = df_050_059_OE_VVS1_I['Carat'] * df_050_059_OE_VVS1_I['PPC']


                elif i== "I" and j == "VVS2" and k == "OE":
                    df_050_059_OE_VVS2_I = pd.DataFrame()
                    df_050_059_OE_VVS2_I ['Wt Range'] = None
                    df_050_059_OE_VVS2_I  = df_050_059_OE_VVS2_I.assign(Company=None)
                    df_050_059_OE_VVS2_I  = df_050_059_OE_VVS2_I.assign(Shape=None)
                    df_050_059_OE_VVS2_I  = df_050_059_OE_VVS2_I.assign(Carat=None)
                    df_050_059_OE_VVS2_I  = df_050_059_OE_VVS2_I.assign(Color=None)
                    df_050_059_OE_VVS2_I  = df_050_059_OE_VVS2_I.assign(Clarity=None)
                    df_050_059_OE_VVS2_I  = df_050_059_OE_VVS2_I.assign(Cut=None)
                    df_050_059_OE_VVS2_I  = df_050_059_OE_VVS2_I.assign(Polish=None)
                    df_050_059_OE_VVS2_I  = df_050_059_OE_VVS2_I.assign(Symmetry=None)
                    df_050_059_OE_VVS2_I  = df_050_059_OE_VVS2_I.assign(Ratio=None)
                    df_050_059_OE_VVS2_I  = df_050_059_OE_VVS2_I.assign(PPC=None)
                    df_050_059_OE_VVS2_I  = df_050_059_OE_VVS2_I.assign(Total=None)
                    df_050_059_OE_VVS2_I ['Wt Range'] = listwtrange
                    df_050_059_OE_VVS2_I ['Company'] = listcom
                    df_050_059_OE_VVS2_I ['Shape'] = listshap
                    df_050_059_OE_VVS2_I ['Carat'] = listcar
                    df_050_059_OE_VVS2_I ['Color'] = listcol
                    df_050_059_OE_VVS2_I ['Clarity'] = listclar
                    df_050_059_OE_VVS2_I ['Cut'] = listcut
                    df_050_059_OE_VVS2_I ['Polish'] = listpol
                    df_050_059_OE_VVS2_I ['Symmetry'] = listsym
                    df_050_059_OE_VVS2_I ['Ratio'] = listrat
                    df_050_059_OE_VVS2_I ['PPC'] = listdesc
                    df_050_059_OE_VVS2_I ['Total'] = listtotal
                    df_050_059_OE_VVS2_I['Carat'] = df_050_059_OE_VVS2_I['Carat'].astype('float64')
                    df_050_059_OE_VVS2_I['PPC'] = df_050_059_OE_VVS2_I['PPC'].astype('float64')
                    df_050_059_OE_VVS2_I['Total'] = df_050_059_OE_VVS2_I['Total'].astype('float64')
                    df_050_059_OE_VVS2_I['Total'] = df_050_059_OE_VVS2_I['Carat'] * df_050_059_OE_VVS2_I['PPC']


                elif i== "I" and j=="VS1" and k == "OE":
                    df_050_059_OE_VS1_I = pd.DataFrame()
                    df_050_059_OE_VS1_I ['Wt Range'] = None
                    df_050_059_OE_VS1_I  = df_050_059_OE_VS1_I.assign(Company=None)
                    df_050_059_OE_VS1_I  = df_050_059_OE_VS1_I.assign(Shape=None)
                    df_050_059_OE_VS1_I  = df_050_059_OE_VS1_I.assign(Carat=None)
                    df_050_059_OE_VS1_I  = df_050_059_OE_VS1_I.assign(Color=None)
                    df_050_059_OE_VS1_I  = df_050_059_OE_VS1_I.assign(Clarity=None)
                    df_050_059_OE_VS1_I  = df_050_059_OE_VS1_I.assign(Cut=None)
                    df_050_059_OE_VS1_I  = df_050_059_OE_VS1_I.assign(Polish=None)
                    df_050_059_OE_VS1_I  = df_050_059_OE_VS1_I.assign(Symmetry=None)
                    df_050_059_OE_VS1_I  = df_050_059_OE_VS1_I.assign(Ratio=None)
                    df_050_059_OE_VS1_I  = df_050_059_OE_VS1_I.assign(PPC=None)
                    df_050_059_OE_VS1_I  = df_050_059_OE_VS1_I.assign(Total=None)
                    df_050_059_OE_VS1_I ['Wt Range'] = listwtrange
                    df_050_059_OE_VS1_I ['Company'] = listcom
                    df_050_059_OE_VS1_I ['Shape'] = listshap
                    df_050_059_OE_VS1_I ['Carat'] = listcar
                    df_050_059_OE_VS1_I ['Color'] = listcol
                    df_050_059_OE_VS1_I ['Clarity'] = listclar
                    df_050_059_OE_VS1_I ['Cut'] = listcut
                    df_050_059_OE_VS1_I ['Polish'] = listpol
                    df_050_059_OE_VS1_I ['Symmetry'] = listsym
                    df_050_059_OE_VS1_I ['Ratio'] = listrat
                    df_050_059_OE_VS1_I ['PPC'] = listdesc
                    df_050_059_OE_VS1_I ['Total'] = listtotal
                    df_050_059_OE_VS1_I['Carat'] = df_050_059_OE_VS1_I['Carat'].astype('float64')
                    df_050_059_OE_VS1_I['PPC'] = df_050_059_OE_VS1_I['PPC'].astype('float64')
                    df_050_059_OE_VS1_I['Total'] = df_050_059_OE_VS1_I['Total'].astype('float64')
                    df_050_059_OE_VS1_I['Total'] = df_050_059_OE_VS1_I['Carat'] * df_050_059_OE_VS1_I['PPC']


                elif i== "I" and j == "VS2" and k == "OE":
                    df_050_059_OE_VS2_I = pd.DataFrame()
                    df_050_059_OE_VS2_I ['Wt Range'] = None
                    df_050_059_OE_VS2_I  = df_050_059_OE_VS2_I.assign(Company=None)
                    df_050_059_OE_VS2_I  = df_050_059_OE_VS2_I.assign(Shape=None)
                    df_050_059_OE_VS2_I  = df_050_059_OE_VS2_I.assign(Carat=None)
                    df_050_059_OE_VS2_I  = df_050_059_OE_VS2_I.assign(Color=None)
                    df_050_059_OE_VS2_I  = df_050_059_OE_VS2_I.assign(Clarity=None)
                    df_050_059_OE_VS2_I  = df_050_059_OE_VS2_I.assign(Cut=None)
                    df_050_059_OE_VS2_I  = df_050_059_OE_VS2_I.assign(Polish=None)
                    df_050_059_OE_VS2_I  = df_050_059_OE_VS2_I.assign(Symmetry=None)
                    df_050_059_OE_VS2_I  = df_050_059_OE_VS2_I.assign(Ratio=None)
                    df_050_059_OE_VS2_I  = df_050_059_OE_VS2_I.assign(PPC=None)
                    df_050_059_OE_VS2_I  = df_050_059_OE_VS2_I.assign(Total=None)
                    df_050_059_OE_VS2_I ['Wt Range'] = listwtrange
                    df_050_059_OE_VS2_I ['Company'] = listcom
                    df_050_059_OE_VS2_I ['Shape'] = listshap
                    df_050_059_OE_VS2_I ['Carat'] = listcar
                    df_050_059_OE_VS2_I ['Color'] = listcol
                    df_050_059_OE_VS2_I ['Clarity'] = listclar
                    df_050_059_OE_VS2_I ['Cut'] = listcut
                    df_050_059_OE_VS2_I ['Polish'] = listpol
                    df_050_059_OE_VS2_I ['Symmetry'] = listsym
                    df_050_059_OE_VS2_I ['Ratio'] = listrat
                    df_050_059_OE_VS2_I ['PPC'] = listdesc
                    df_050_059_OE_VS2_I ['Total'] = listtotal
                    df_050_059_OE_VS2_I['Carat'] = df_050_059_OE_VS2_I['Carat'].astype('float64')
                    df_050_059_OE_VS2_I['PPC'] = df_050_059_OE_VS2_I['PPC'].astype('float64')
                    df_050_059_OE_VS2_I['Total'] = df_050_059_OE_VS2_I['Total'].astype('float64')
                    df_050_059_OE_VS2_I['Total'] = df_050_059_OE_VS2_I['Carat'] * df_050_059_OE_VS2_I['PPC']


                elif i== "I" and j == "SI1" and k == "OE":
                    df_050_059_OE_SI1_I = pd.DataFrame()
                    df_050_059_OE_SI1_I ['Wt Range'] = None
                    df_050_059_OE_SI1_I  = df_050_059_OE_SI1_I.assign(Company=None)
                    df_050_059_OE_SI1_I  = df_050_059_OE_SI1_I.assign(Shape=None)
                    df_050_059_OE_SI1_I  = df_050_059_OE_SI1_I.assign(Carat=None)
                    df_050_059_OE_SI1_I  = df_050_059_OE_SI1_I.assign(Color=None)
                    df_050_059_OE_SI1_I  = df_050_059_OE_SI1_I.assign(Clarity=None)
                    df_050_059_OE_SI1_I  = df_050_059_OE_SI1_I.assign(Cut=None)
                    df_050_059_OE_SI1_I  = df_050_059_OE_SI1_I.assign(Polish=None)
                    df_050_059_OE_SI1_I  = df_050_059_OE_SI1_I.assign(Symmetry=None)
                    df_050_059_OE_SI1_I  = df_050_059_OE_SI1_I.assign(Ratio=None)
                    df_050_059_OE_SI1_I  = df_050_059_OE_SI1_I.assign(PPC=None)
                    df_050_059_OE_SI1_I  = df_050_059_OE_SI1_I.assign(Total=None)
                    df_050_059_OE_SI1_I ['Wt Range'] = listwtrange
                    df_050_059_OE_SI1_I ['Company'] = listcom
                    df_050_059_OE_SI1_I ['Shape'] = listshap
                    df_050_059_OE_SI1_I ['Carat'] = listcar
                    df_050_059_OE_SI1_I ['Color'] = listcol
                    df_050_059_OE_SI1_I ['Clarity'] = listclar
                    df_050_059_OE_SI1_I ['Cut'] = listcut
                    df_050_059_OE_SI1_I ['Polish'] = listpol
                    df_050_059_OE_SI1_I ['Symmetry'] = listsym
                    df_050_059_OE_SI1_I ['Ratio'] = listrat
                    df_050_059_OE_SI1_I ['PPC'] = listdesc
                    df_050_059_OE_SI1_I ['Total'] = listtotal
                    df_050_059_OE_SI1_I['Carat'] = df_050_059_OE_SI1_I['Carat'].astype('float64')
                    df_050_059_OE_SI1_I['PPC'] = df_050_059_OE_SI1_I['PPC'].astype('float64')
                    df_050_059_OE_SI1_I['Total'] = df_050_059_OE_SI1_I['Total'].astype('float64')
                    df_050_059_OE_SI1_I['Total'] = df_050_059_OE_SI1_I['Carat'] * df_050_059_OE_SI1_I['PPC']


                elif i== "I" and j == "SI2" and k == "OE":
                    df_050_059_OE_SI2_I = pd.DataFrame()
                    df_050_059_OE_SI2_I ['Wt Range'] = None
                    df_050_059_OE_SI2_I  = df_050_059_OE_SI2_I.assign(Company=None)
                    df_050_059_OE_SI2_I  = df_050_059_OE_SI2_I.assign(Shape=None)
                    df_050_059_OE_SI2_I  = df_050_059_OE_SI2_I.assign(Carat=None)
                    df_050_059_OE_SI2_I  = df_050_059_OE_SI2_I.assign(Color=None)
                    df_050_059_OE_SI2_I  = df_050_059_OE_SI2_I.assign(Clarity=None)
                    df_050_059_OE_SI2_I  = df_050_059_OE_SI2_I.assign(Cut=None)
                    df_050_059_OE_SI2_I  = df_050_059_OE_SI2_I.assign(Polish=None)
                    df_050_059_OE_SI2_I  = df_050_059_OE_SI2_I.assign(Symmetry=None)
                    df_050_059_OE_SI2_I  = df_050_059_OE_SI2_I.assign(Ratio=None)
                    df_050_059_OE_SI2_I  = df_050_059_OE_SI2_I.assign(PPC=None)
                    df_050_059_OE_SI2_I  = df_050_059_OE_SI2_I.assign(Total=None)
                    df_050_059_OE_SI2_I ['Wt Range'] = listwtrange
                    df_050_059_OE_SI2_I ['Company'] = listcom
                    df_050_059_OE_SI2_I ['Shape'] = listshap
                    df_050_059_OE_SI2_I ['Carat'] = listcar
                    df_050_059_OE_SI2_I ['Color'] = listcol
                    df_050_059_OE_SI2_I ['Clarity'] = listclar
                    df_050_059_OE_SI2_I ['Cut'] = listcut
                    df_050_059_OE_SI2_I ['Polish'] = listpol
                    df_050_059_OE_SI2_I ['Symmetry'] = listsym
                    df_050_059_OE_SI2_I ['Ratio'] = listrat
                    df_050_059_OE_SI2_I ['PPC'] = listdesc
                    df_050_059_OE_SI2_I ['Total'] = listtotal
                    df_050_059_OE_SI2_I['Carat'] = df_050_059_OE_SI2_I['Carat'].astype('float64')
                    df_050_059_OE_SI2_I['PPC'] = df_050_059_OE_SI2_I['PPC'].astype('float64')
                    df_050_059_OE_SI2_I['Total'] = df_050_059_OE_SI2_I['Total'].astype('float64')
                    df_050_059_OE_SI2_I['Total'] = df_050_059_OE_SI2_I['Carat'] * df_050_059_OE_SI2_I['PPC']


                elif i== "I" and j == "I1" and k == "OE":
                    df_050_059_OE_I1_I = pd.DataFrame()
                    df_050_059_OE_I1_I ['Wt Range'] = None
                    df_050_059_OE_I1_I  = df_050_059_OE_I1_I.assign(Company=None)
                    df_050_059_OE_I1_I  = df_050_059_OE_I1_I.assign(Shape=None)
                    df_050_059_OE_I1_I  = df_050_059_OE_I1_I.assign(Carat=None)
                    df_050_059_OE_I1_I  = df_050_059_OE_I1_I.assign(Color=None)
                    df_050_059_OE_I1_I  = df_050_059_OE_I1_I.assign(Clarity=None)
                    df_050_059_OE_I1_I  = df_050_059_OE_I1_I.assign(Cut=None)
                    df_050_059_OE_I1_I  = df_050_059_OE_I1_I.assign(Polish=None)
                    df_050_059_OE_I1_I  = df_050_059_OE_I1_I.assign(Symmetry=None)
                    df_050_059_OE_I1_I  = df_050_059_OE_I1_I.assign(Ratio=None)
                    df_050_059_OE_I1_I  = df_050_059_OE_I1_I.assign(PPC=None)
                    df_050_059_OE_I1_I  = df_050_059_OE_I1_I.assign(Total=None)
                    df_050_059_OE_I1_I ['Wt Range'] = listwtrange
                    df_050_059_OE_I1_I ['Company'] = listcom
                    df_050_059_OE_I1_I ['Shape'] = listshap
                    df_050_059_OE_I1_I ['Carat'] = listcar
                    df_050_059_OE_I1_I ['Color'] = listcol
                    df_050_059_OE_I1_I ['Clarity'] = listclar
                    df_050_059_OE_I1_I ['Cut'] = listcut
                    df_050_059_OE_I1_I ['Polish'] = listpol
                    df_050_059_OE_I1_I ['Symmetry'] = listsym
                    df_050_059_OE_I1_I ['Ratio'] = listrat
                    df_050_059_OE_I1_I ['PPC'] = listdesc
                    df_050_059_OE_I1_I ['Total'] = listtotal
                    df_050_059_OE_I1_I['Carat'] = df_050_059_OE_I1_I['Carat'].astype('float64')
                    df_050_059_OE_I1_I['PPC'] = df_050_059_OE_I1_I['PPC'].astype('float64')
                    df_050_059_OE_I1_I['Total'] = df_050_059_OE_I1_I['Total'].astype('float64')
                    df_050_059_OE_I1_I['Total'] = df_050_059_OE_I1_I['Carat'] * df_050_059_OE_I1_I['PPC']


                elif i== "I" and j == "I2" and k == "OE":
                    df_050_059_OE_I2_I = pd.DataFrame()
                    df_050_059_OE_I2_I ['Wt Range'] = None
                    df_050_059_OE_I2_I  = df_050_059_OE_I2_I.assign(Company=None)
                    df_050_059_OE_I2_I  = df_050_059_OE_I2_I.assign(Shape=None)
                    df_050_059_OE_I2_I  = df_050_059_OE_I2_I.assign(Carat=None)
                    df_050_059_OE_I2_I  = df_050_059_OE_I2_I.assign(Color=None)
                    df_050_059_OE_I2_I  = df_050_059_OE_I2_I.assign(Clarity=None)
                    df_050_059_OE_I2_I  = df_050_059_OE_I2_I.assign(Cut=None)
                    df_050_059_OE_I2_I  = df_050_059_OE_I2_I.assign(Polish=None)
                    df_050_059_OE_I2_I  = df_050_059_OE_I2_I.assign(Symmetry=None)
                    df_050_059_OE_I2_I  = df_050_059_OE_I2_I.assign(Ratio=None)
                    df_050_059_OE_I2_I  = df_050_059_OE_I2_I.assign(PPC=None)
                    df_050_059_OE_I2_I  = df_050_059_OE_I2_I.assign(Total=None)
                    df_050_059_OE_I2_I ['Wt Range'] = listwtrange
                    df_050_059_OE_I2_I ['Company'] = listcom
                    df_050_059_OE_I2_I ['Shape'] = listshap
                    df_050_059_OE_I2_I ['Carat'] = listcar
                    df_050_059_OE_I2_I ['Color'] = listcol
                    df_050_059_OE_I2_I ['Clarity'] = listclar
                    df_050_059_OE_I2_I ['Cut'] = listcut
                    df_050_059_OE_I2_I ['Polish'] = listpol
                    df_050_059_OE_I2_I ['Symmetry'] = listsym
                    df_050_059_OE_I2_I ['Ratio'] = listrat
                    df_050_059_OE_I2_I ['PPC'] = listdesc
                    df_050_059_OE_I2_I ['Total'] = listtotal
                    df_050_059_OE_I2_I['Carat'] = df_050_059_OE_I2_I['Carat'].astype('float64')
                    df_050_059_OE_I2_I['PPC'] = df_050_059_OE_I2_I['PPC'].astype('float64')
                    df_050_059_OE_I2_I['Total'] = df_050_059_OE_I2_I['Total'].astype('float64')
                    df_050_059_OE_I2_I['Total'] = df_050_059_OE_I2_I['Carat'] * df_050_059_OE_I2_I['PPC']


                elif i=="J" and j == "IF" and k == "OE":
                    df_050_059_OE_IF_J = pd.DataFrame()
                    df_050_059_OE_IF_J ['Wt Range'] = None
                    df_050_059_OE_IF_J  = df_050_059_OE_IF_J.assign(Company=None)
                    df_050_059_OE_IF_J  = df_050_059_OE_IF_J.assign(Shape=None)
                    df_050_059_OE_IF_J  = df_050_059_OE_IF_J.assign(Carat=None)
                    df_050_059_OE_IF_J  = df_050_059_OE_IF_J.assign(Color=None)
                    df_050_059_OE_IF_J  = df_050_059_OE_IF_J.assign(Clarity=None)
                    df_050_059_OE_IF_J  = df_050_059_OE_IF_J.assign(Cut=None)
                    df_050_059_OE_IF_J  = df_050_059_OE_IF_J.assign(Polish=None)
                    df_050_059_OE_IF_J  = df_050_059_OE_IF_J.assign(Symmetry=None)
                    df_050_059_OE_IF_J  = df_050_059_OE_IF_J.assign(Ratio=None)
                    df_050_059_OE_IF_J  = df_050_059_OE_IF_J.assign(PPC=None)
                    df_050_059_OE_IF_J  = df_050_059_OE_IF_J.assign(Total=None)
                    df_050_059_OE_IF_J ['Wt Range'] = listwtrange
                    df_050_059_OE_IF_J ['Company'] = listcom
                    df_050_059_OE_IF_J ['Shape'] = listshap
                    df_050_059_OE_IF_J ['Carat'] = listcar
                    df_050_059_OE_IF_J ['Color'] = listcol
                    df_050_059_OE_IF_J ['Clarity'] = listclar
                    df_050_059_OE_IF_J ['Cut'] = listcut
                    df_050_059_OE_IF_J ['Polish'] = listpol
                    df_050_059_OE_IF_J ['Symmetry'] = listsym
                    df_050_059_OE_IF_J ['Ratio'] = listrat
                    df_050_059_OE_IF_J ['PPC'] = listdesc
                    df_050_059_OE_IF_J ['Total'] = listtotal
                    df_050_059_OE_IF_J['Carat'] = df_050_059_OE_IF_J['Carat'].astype('float64')
                    df_050_059_OE_IF_J['PPC'] = df_050_059_OE_IF_J['PPC'].astype('float64')
                    df_050_059_OE_IF_J['Total'] = df_050_059_OE_IF_J['Total'].astype('float64')
                    df_050_059_OE_IF_J['Total'] = df_050_059_OE_IF_J['Carat'] * df_050_059_OE_IF_J['PPC']



                elif i=="J"  and j == "VVS1" and k == "OE":
                    df_050_059_OE_VVS1_J = pd.DataFrame()
                    df_050_059_OE_VVS1_J ['Wt Range'] = None
                    df_050_059_OE_VVS1_J  = df_050_059_OE_VVS1_J.assign(Company=None)
                    df_050_059_OE_VVS1_J  = df_050_059_OE_VVS1_J.assign(Shape=None)
                    df_050_059_OE_VVS1_J  = df_050_059_OE_VVS1_J.assign(Carat=None)
                    df_050_059_OE_VVS1_J  = df_050_059_OE_VVS1_J.assign(Color=None)
                    df_050_059_OE_VVS1_J  = df_050_059_OE_VVS1_J.assign(Clarity=None)
                    df_050_059_OE_VVS1_J  = df_050_059_OE_VVS1_J.assign(Cut=None)
                    df_050_059_OE_VVS1_J  = df_050_059_OE_VVS1_J.assign(Polish=None)
                    df_050_059_OE_VVS1_J  = df_050_059_OE_VVS1_J.assign(Symmetry=None)
                    df_050_059_OE_VVS1_J  = df_050_059_OE_VVS1_J.assign(Ratio=None)
                    df_050_059_OE_VVS1_J  = df_050_059_OE_VVS1_J.assign(PPC=None)
                    df_050_059_OE_VVS1_J  = df_050_059_OE_VVS1_J.assign(Total=None)
                    df_050_059_OE_VVS1_J ['Wt Range'] = listwtrange
                    df_050_059_OE_VVS1_J ['Company'] = listcom
                    df_050_059_OE_VVS1_J ['Shape'] = listshap
                    df_050_059_OE_VVS1_J ['Carat'] = listcar
                    df_050_059_OE_VVS1_J ['Color'] = listcol
                    df_050_059_OE_VVS1_J ['Clarity'] = listclar
                    df_050_059_OE_VVS1_J ['Cut'] = listcut
                    df_050_059_OE_VVS1_J ['Polish'] = listpol
                    df_050_059_OE_VVS1_J ['Symmetry'] = listsym
                    df_050_059_OE_VVS1_J ['Ratio'] = listrat
                    df_050_059_OE_VVS1_J ['PPC'] = listdesc
                    df_050_059_OE_VVS1_J ['Total'] = listtotal
                    df_050_059_OE_VVS1_J['Carat'] = df_050_059_OE_VVS1_J['Carat'].astype('float64')
                    df_050_059_OE_VVS1_J['PPC'] = df_050_059_OE_VVS1_J['PPC'].astype('float64')
                    df_050_059_OE_VVS1_J['Total'] = df_050_059_OE_VVS1_J['Total'].astype('float64')
                    df_050_059_OE_VVS1_J['Total'] = df_050_059_OE_VVS1_J['Carat'] * df_050_059_OE_VVS1_J['PPC']


                elif i=="J"  and j == "VVS2" and k == "OE":
                    df_050_059_OE_VVS2_J = pd.DataFrame()
                    df_050_059_OE_VVS2_J ['Wt Range'] = None
                    df_050_059_OE_VVS2_J  = df_050_059_OE_VVS2_J.assign(Company=None)
                    df_050_059_OE_VVS2_J  = df_050_059_OE_VVS2_J.assign(Shape=None)
                    df_050_059_OE_VVS2_J  = df_050_059_OE_VVS2_J.assign(Carat=None)
                    df_050_059_OE_VVS2_J  = df_050_059_OE_VVS2_J.assign(Color=None)
                    df_050_059_OE_VVS2_J  = df_050_059_OE_VVS2_J.assign(Clarity=None)
                    df_050_059_OE_VVS2_J  = df_050_059_OE_VVS2_J.assign(Cut=None)
                    df_050_059_OE_VVS2_J  = df_050_059_OE_VVS2_J.assign(Polish=None)
                    df_050_059_OE_VVS2_J  = df_050_059_OE_VVS2_J.assign(Symmetry=None)
                    df_050_059_OE_VVS2_J  = df_050_059_OE_VVS2_J.assign(Ratio=None)
                    df_050_059_OE_VVS2_J  = df_050_059_OE_VVS2_J.assign(PPC=None)
                    df_050_059_OE_VVS2_J  = df_050_059_OE_VVS2_J.assign(Total=None)
                    df_050_059_OE_VVS2_J ['Wt Range'] = listwtrange
                    df_050_059_OE_VVS2_J ['Company'] = listcom
                    df_050_059_OE_VVS2_J ['Shape'] = listshap
                    df_050_059_OE_VVS2_J ['Carat'] = listcar
                    df_050_059_OE_VVS2_J ['Color'] = listcol
                    df_050_059_OE_VVS2_J ['Clarity'] = listclar
                    df_050_059_OE_VVS2_J ['Cut'] = listcut
                    df_050_059_OE_VVS2_J ['Polish'] = listpol
                    df_050_059_OE_VVS2_J ['Symmetry'] = listsym
                    df_050_059_OE_VVS2_J ['Ratio'] = listrat
                    df_050_059_OE_VVS2_J ['PPC'] = listdesc
                    df_050_059_OE_VVS2_J ['Total'] = listtotal
                    df_050_059_OE_VVS2_J['Carat'] = df_050_059_OE_VVS2_J['Carat'].astype('float64')
                    df_050_059_OE_VVS2_J['PPC'] = df_050_059_OE_VVS2_J['PPC'].astype('float64')
                    df_050_059_OE_VVS2_J['Total'] = df_050_059_OE_VVS2_J['Total'].astype('float64')
                    df_050_059_OE_VVS2_J['Total'] = df_050_059_OE_VVS2_J['Carat'] * df_050_059_OE_VVS2_J['PPC']


                elif i=="J"  and j=="VS1" and k == "OE":
                    df_050_059_OE_VS1_J = pd.DataFrame()
                    df_050_059_OE_VS1_J ['Wt Range'] = None
                    df_050_059_OE_VS1_J  = df_050_059_OE_VS1_J.assign(Company=None)
                    df_050_059_OE_VS1_J  = df_050_059_OE_VS1_J.assign(Shape=None)
                    df_050_059_OE_VS1_J  = df_050_059_OE_VS1_J.assign(Carat=None)
                    df_050_059_OE_VS1_J  = df_050_059_OE_VS1_J.assign(Color=None)
                    df_050_059_OE_VS1_J  = df_050_059_OE_VS1_J.assign(Clarity=None)
                    df_050_059_OE_VS1_J  = df_050_059_OE_VS1_J.assign(Cut=None)
                    df_050_059_OE_VS1_J  = df_050_059_OE_VS1_J.assign(Polish=None)
                    df_050_059_OE_VS1_J  = df_050_059_OE_VS1_J.assign(Symmetry=None)
                    df_050_059_OE_VS1_J  = df_050_059_OE_VS1_J.assign(Ratio=None)
                    df_050_059_OE_VS1_J  = df_050_059_OE_VS1_J.assign(PPC=None)
                    df_050_059_OE_VS1_J  = df_050_059_OE_VS1_J.assign(Total=None)
                    df_050_059_OE_VS1_J ['Wt Range'] = listwtrange
                    df_050_059_OE_VS1_J ['Company'] = listcom
                    df_050_059_OE_VS1_J ['Shape'] = listshap
                    df_050_059_OE_VS1_J ['Carat'] = listcar
                    df_050_059_OE_VS1_J ['Color'] = listcol
                    df_050_059_OE_VS1_J ['Clarity'] = listclar
                    df_050_059_OE_VS1_J ['Cut'] = listcut
                    df_050_059_OE_VS1_J ['Polish'] = listpol
                    df_050_059_OE_VS1_J ['Symmetry'] = listsym
                    df_050_059_OE_VS1_J ['Ratio'] = listrat
                    df_050_059_OE_VS1_J ['PPC'] = listdesc
                    df_050_059_OE_VS1_J ['Total'] = listtotal
                    df_050_059_OE_VS1_J['Carat'] = df_050_059_OE_VS1_J['Carat'].astype('float64')
                    df_050_059_OE_VS1_J['PPC'] = df_050_059_OE_VS1_J['PPC'].astype('float64')
                    df_050_059_OE_VS1_J['Total'] = df_050_059_OE_VS1_J['Total'].astype('float64')
                    df_050_059_OE_VS1_J['Total'] = df_050_059_OE_VS1_J['Carat'] * df_050_059_OE_VS1_J['PPC']


                elif i=="J"  and j == "VS2" and k == "OE":
                    df_050_059_OE_VS2_J = pd.DataFrame()
                    df_050_059_OE_VS2_J ['Wt Range'] = None
                    df_050_059_OE_VS2_J  = df_050_059_OE_VS2_J.assign(Company=None)
                    df_050_059_OE_VS2_J  = df_050_059_OE_VS2_J.assign(Shape=None)
                    df_050_059_OE_VS2_J  = df_050_059_OE_VS2_J.assign(Carat=None)
                    df_050_059_OE_VS2_J  = df_050_059_OE_VS2_J.assign(Color=None)
                    df_050_059_OE_VS2_J  = df_050_059_OE_VS2_J.assign(Clarity=None)
                    df_050_059_OE_VS2_J  = df_050_059_OE_VS2_J.assign(Cut=None)
                    df_050_059_OE_VS2_J  = df_050_059_OE_VS2_J.assign(Polish=None)
                    df_050_059_OE_VS2_J  = df_050_059_OE_VS2_J.assign(Symmetry=None)
                    df_050_059_OE_VS2_J  = df_050_059_OE_VS2_J.assign(Ratio=None)
                    df_050_059_OE_VS2_J  = df_050_059_OE_VS2_J.assign(PPC=None)
                    df_050_059_OE_VS2_J  = df_050_059_OE_VS2_J.assign(Total=None)
                    df_050_059_OE_VS2_J ['Wt Range'] = listwtrange
                    df_050_059_OE_VS2_J ['Company'] = listcom
                    df_050_059_OE_VS2_J ['Shape'] = listshap
                    df_050_059_OE_VS2_J ['Carat'] = listcar
                    df_050_059_OE_VS2_J ['Color'] = listcol
                    df_050_059_OE_VS2_J ['Clarity'] = listclar
                    df_050_059_OE_VS2_J ['Cut'] = listcut
                    df_050_059_OE_VS2_J ['Polish'] = listpol
                    df_050_059_OE_VS2_J ['Symmetry'] = listsym
                    df_050_059_OE_VS2_J ['Ratio'] = listrat
                    df_050_059_OE_VS2_J ['PPC'] = listdesc
                    df_050_059_OE_VS2_J ['Total'] = listtotal
                    df_050_059_OE_VS2_J['Carat'] = df_050_059_OE_VS2_J['Carat'].astype('float64')
                    df_050_059_OE_VS2_J['PPC'] = df_050_059_OE_VS2_J['PPC'].astype('float64')
                    df_050_059_OE_VS2_J['Total'] = df_050_059_OE_VS2_J['Total'].astype('float64')
                    df_050_059_OE_VS2_J['Total'] = df_050_059_OE_VS2_J['Carat'] * df_050_059_OE_VS2_J['PPC']


                elif i=="J"  and j == "SI1" and k == "OE":
                    df_050_059_OE_SI1_J = pd.DataFrame()
                    df_050_059_OE_SI1_J ['Wt Range'] = None
                    df_050_059_OE_SI1_J  = df_050_059_OE_SI1_J.assign(Company=None)
                    df_050_059_OE_SI1_J  = df_050_059_OE_SI1_J.assign(Shape=None)
                    df_050_059_OE_SI1_J  = df_050_059_OE_SI1_J.assign(Carat=None)
                    df_050_059_OE_SI1_J  = df_050_059_OE_SI1_J.assign(Color=None)
                    df_050_059_OE_SI1_J  = df_050_059_OE_SI1_J.assign(Clarity=None)
                    df_050_059_OE_SI1_J  = df_050_059_OE_SI1_J.assign(Cut=None)
                    df_050_059_OE_SI1_J  = df_050_059_OE_SI1_J.assign(Polish=None)
                    df_050_059_OE_SI1_J  = df_050_059_OE_SI1_J.assign(Symmetry=None)
                    df_050_059_OE_SI1_J  = df_050_059_OE_SI1_J.assign(Ratio=None)
                    df_050_059_OE_SI1_J  = df_050_059_OE_SI1_J.assign(PPC=None)
                    df_050_059_OE_SI1_J  = df_050_059_OE_SI1_J.assign(Total=None)
                    df_050_059_OE_SI1_J ['Wt Range'] = listwtrange
                    df_050_059_OE_SI1_J ['Company'] = listcom
                    df_050_059_OE_SI1_J ['Shape'] = listshap
                    df_050_059_OE_SI1_J ['Carat'] = listcar
                    df_050_059_OE_SI1_J ['Color'] = listcol
                    df_050_059_OE_SI1_J ['Clarity'] = listclar
                    df_050_059_OE_SI1_J ['Cut'] = listcut
                    df_050_059_OE_SI1_J ['Polish'] = listpol
                    df_050_059_OE_SI1_J ['Symmetry'] = listsym
                    df_050_059_OE_SI1_J ['Ratio'] = listrat
                    df_050_059_OE_SI1_J ['PPC'] = listdesc
                    df_050_059_OE_SI1_J ['Total'] = listtotal
                    df_050_059_OE_SI1_J['Carat'] = df_050_059_OE_SI1_J['Carat'].astype('float64')
                    df_050_059_OE_SI1_J['PPC'] = df_050_059_OE_SI1_J['PPC'].astype('float64')
                    df_050_059_OE_SI1_J['Total'] = df_050_059_OE_SI1_J['Total'].astype('float64')
                    df_050_059_OE_SI1_J['Total'] = df_050_059_OE_SI1_J['Carat'] * df_050_059_OE_SI1_J['PPC']


                elif i=="J"  and j == "SI2" and k == "OE":
                    df_050_059_OE_SI2_J = pd.DataFrame()
                    df_050_059_OE_SI2_J ['Wt Range'] = None
                    df_050_059_OE_SI2_J  = df_050_059_OE_SI2_J.assign(Company=None)
                    df_050_059_OE_SI2_J  = df_050_059_OE_SI2_J.assign(Shape=None)
                    df_050_059_OE_SI2_J  = df_050_059_OE_SI2_J.assign(Carat=None)
                    df_050_059_OE_SI2_J  = df_050_059_OE_SI2_J.assign(Color=None)
                    df_050_059_OE_SI2_J  = df_050_059_OE_SI2_J.assign(Clarity=None)
                    df_050_059_OE_SI2_J  = df_050_059_OE_SI2_J.assign(Cut=None)
                    df_050_059_OE_SI2_J  = df_050_059_OE_SI2_J.assign(Polish=None)
                    df_050_059_OE_SI2_J  = df_050_059_OE_SI2_J.assign(Symmetry=None)
                    df_050_059_OE_SI2_J  = df_050_059_OE_SI2_J.assign(Ratio=None)
                    df_050_059_OE_SI2_J  = df_050_059_OE_SI2_J.assign(PPC=None)
                    df_050_059_OE_SI2_J  = df_050_059_OE_SI2_J.assign(Total=None)
                    df_050_059_OE_SI2_J ['Wt Range'] = listwtrange
                    df_050_059_OE_SI2_J ['Company'] = listcom
                    df_050_059_OE_SI2_J ['Shape'] = listshap
                    df_050_059_OE_SI2_J ['Carat'] = listcar
                    df_050_059_OE_SI2_J ['Color'] = listcol
                    df_050_059_OE_SI2_J ['Clarity'] = listclar
                    df_050_059_OE_SI2_J ['Cut'] = listcut
                    df_050_059_OE_SI2_J ['Polish'] = listpol
                    df_050_059_OE_SI2_J ['Symmetry'] = listsym
                    df_050_059_OE_SI2_J ['Ratio'] = listrat
                    df_050_059_OE_SI2_J ['PPC'] = listdesc
                    df_050_059_OE_SI2_J ['Total'] = listtotal
                    df_050_059_OE_SI2_J['Carat'] = df_050_059_OE_SI2_J['Carat'].astype('float64')
                    df_050_059_OE_SI2_J['PPC'] = df_050_059_OE_SI2_J['PPC'].astype('float64')
                    df_050_059_OE_SI2_J['Total'] = df_050_059_OE_SI2_J['Total'].astype('float64')
                    df_050_059_OE_SI2_J['Total'] = df_050_059_OE_SI2_J['Carat'] * df_050_059_OE_SI2_J['PPC']


                elif i=="J"  and j == "I1" and k == "OE":
                    df_050_059_OE_I1_J = pd.DataFrame()
                    df_050_059_OE_I1_J ['Wt Range'] = None
                    df_050_059_OE_I1_J  = df_050_059_OE_I1_J.assign(Company=None)
                    df_050_059_OE_I1_J  = df_050_059_OE_I1_J.assign(Shape=None)
                    df_050_059_OE_I1_J  = df_050_059_OE_I1_J.assign(Carat=None)
                    df_050_059_OE_I1_J  = df_050_059_OE_I1_J.assign(Color=None)
                    df_050_059_OE_I1_J  = df_050_059_OE_I1_J.assign(Clarity=None)
                    df_050_059_OE_I1_J  = df_050_059_OE_I1_J.assign(Cut=None)
                    df_050_059_OE_I1_J  = df_050_059_OE_I1_J.assign(Polish=None)
                    df_050_059_OE_I1_J  = df_050_059_OE_I1_J.assign(Symmetry=None)
                    df_050_059_OE_I1_J  = df_050_059_OE_I1_J.assign(Ratio=None)
                    df_050_059_OE_I1_J  = df_050_059_OE_I1_J.assign(PPC=None)
                    df_050_059_OE_I1_J  = df_050_059_OE_I1_J.assign(Total=None)
                    df_050_059_OE_I1_J ['Wt Range'] = listwtrange
                    df_050_059_OE_I1_J ['Company'] = listcom
                    df_050_059_OE_I1_J ['Shape'] = listshap
                    df_050_059_OE_I1_J ['Carat'] = listcar
                    df_050_059_OE_I1_J ['Color'] = listcol
                    df_050_059_OE_I1_J ['Clarity'] = listclar
                    df_050_059_OE_I1_J ['Cut'] = listcut
                    df_050_059_OE_I1_J ['Polish'] = listpol
                    df_050_059_OE_I1_J ['Symmetry'] = listsym
                    df_050_059_OE_I1_J ['Ratio'] = listrat
                    df_050_059_OE_I1_J ['PPC'] = listdesc
                    df_050_059_OE_I1_J ['Total'] = listtotal
                    df_050_059_OE_I1_J['Carat'] = df_050_059_OE_I1_J['Carat'].astype('float64')
                    df_050_059_OE_I1_J['PPC'] = df_050_059_OE_I1_J['PPC'].astype('float64')
                    df_050_059_OE_I1_J['Total'] = df_050_059_OE_I1_J['Total'].astype('float64')
                    df_050_059_OE_I1_J['Total'] = df_050_059_OE_I1_J['Carat'] * df_050_059_OE_I1_J['PPC']


                elif i=="J"  and j == "I2" and k == "OE":
                    df_050_059_OE_I2_J = pd.DataFrame()
                    df_050_059_OE_I2_J ['Wt Range'] = None
                    df_050_059_OE_I2_J  = df_050_059_OE_I2_J.assign(Company=None)
                    df_050_059_OE_I2_J  = df_050_059_OE_I2_J.assign(Shape=None)
                    df_050_059_OE_I2_J  = df_050_059_OE_I2_J.assign(Carat=None)
                    df_050_059_OE_I2_J  = df_050_059_OE_I2_J.assign(Color=None)
                    df_050_059_OE_I2_J  = df_050_059_OE_I2_J.assign(Clarity=None)
                    df_050_059_OE_I2_J  = df_050_059_OE_I2_J.assign(Cut=None)
                    df_050_059_OE_I2_J  = df_050_059_OE_I2_J.assign(Polish=None)
                    df_050_059_OE_I2_J  = df_050_059_OE_I2_J.assign(Symmetry=None)
                    df_050_059_OE_I2_J  = df_050_059_OE_I2_J.assign(Ratio=None)
                    df_050_059_OE_I2_J  = df_050_059_OE_I2_J.assign(PPC=None)
                    df_050_059_OE_I2_J  = df_050_059_OE_I2_J.assign(Total=None)
                    df_050_059_OE_I2_J ['Wt Range'] = listwtrange
                    df_050_059_OE_I2_J ['Company'] = listcom
                    df_050_059_OE_I2_J ['Shape'] = listshap
                    df_050_059_OE_I2_J ['Carat'] = listcar
                    df_050_059_OE_I2_J ['Color'] = listcol
                    df_050_059_OE_I2_J ['Clarity'] = listclar
                    df_050_059_OE_I2_J ['Cut'] = listcut
                    df_050_059_OE_I2_J ['Polish'] = listpol
                    df_050_059_OE_I2_J ['Symmetry'] = listsym
                    df_050_059_OE_I2_J ['Ratio'] = listrat
                    df_050_059_OE_I2_J ['PPC'] = listdesc
                    df_050_059_OE_I2_J ['Total'] = listtotal
                    df_050_059_OE_I2_J['Carat'] = df_050_059_OE_I2_J['Carat'].astype('float64')
                    df_050_059_OE_I2_J['PPC'] = df_050_059_OE_I2_J['PPC'].astype('float64')
                    df_050_059_OE_I2_J['Total'] = df_050_059_OE_I2_J['Total'].astype('float64')
                    df_050_059_OE_I2_J['Total'] = df_050_059_OE_I2_J['Carat'] * df_050_059_OE_I2_J['PPC']


                elif i=="K" and j == "IF" and k == "OE":
                    df_050_059_OE_IF_K = pd.DataFrame()
                    df_050_059_OE_IF_K ['Wt Range'] = None
                    df_050_059_OE_IF_K  = df_050_059_OE_IF_K.assign(Company=None)
                    df_050_059_OE_IF_K  = df_050_059_OE_IF_K.assign(Shape=None)
                    df_050_059_OE_IF_K  = df_050_059_OE_IF_K.assign(Carat=None)
                    df_050_059_OE_IF_K  = df_050_059_OE_IF_K.assign(Color=None)
                    df_050_059_OE_IF_K  = df_050_059_OE_IF_K.assign(Clarity=None)
                    df_050_059_OE_IF_K  = df_050_059_OE_IF_K.assign(Cut=None)
                    df_050_059_OE_IF_K  = df_050_059_OE_IF_K.assign(Polish=None)
                    df_050_059_OE_IF_K  = df_050_059_OE_IF_K.assign(Symmetry=None)
                    df_050_059_OE_IF_K  = df_050_059_OE_IF_K.assign(Ratio=None)
                    df_050_059_OE_IF_K  = df_050_059_OE_IF_K.assign(PPC=None)
                    df_050_059_OE_IF_K  = df_050_059_OE_IF_K.assign(Total=None)
                    df_050_059_OE_IF_K ['Wt Range'] = listwtrange
                    df_050_059_OE_IF_K ['Company'] = listcom
                    df_050_059_OE_IF_K ['Shape'] = listshap
                    df_050_059_OE_IF_K ['Carat'] = listcar
                    df_050_059_OE_IF_K ['Color'] = listcol
                    df_050_059_OE_IF_K ['Clarity'] = listclar
                    df_050_059_OE_IF_K ['Cut'] = listcut
                    df_050_059_OE_IF_K ['Polish'] = listpol
                    df_050_059_OE_IF_K ['Symmetry'] = listsym
                    df_050_059_OE_IF_K ['Ratio'] = listrat
                    df_050_059_OE_IF_K ['PPC'] = listdesc
                    df_050_059_OE_IF_K ['Total'] = listtotal
                    df_050_059_OE_IF_K['Carat'] = df_050_059_OE_IF_K['Carat'].astype('float64')
                    df_050_059_OE_IF_K['PPC'] = df_050_059_OE_IF_K['PPC'].astype('float64')
                    df_050_059_OE_IF_K['Total'] = df_050_059_OE_IF_K['Total'].astype('float64')
                    df_050_059_OE_IF_K['Total'] = df_050_059_OE_IF_K['Carat'] * df_050_059_OE_IF_K['PPC']



                elif i=="K" and j == "VVS1" and k == "OE":
                    df_050_059_OE_VVS1_K = pd.DataFrame()
                    df_050_059_OE_VVS1_K ['Wt Range'] = None
                    df_050_059_OE_VVS1_K  = df_050_059_OE_VVS1_K.assign(Company=None)
                    df_050_059_OE_VVS1_K  = df_050_059_OE_VVS1_K.assign(Shape=None)
                    df_050_059_OE_VVS1_K  = df_050_059_OE_VVS1_K.assign(Carat=None)
                    df_050_059_OE_VVS1_K  = df_050_059_OE_VVS1_K.assign(Color=None)
                    df_050_059_OE_VVS1_K  = df_050_059_OE_VVS1_K.assign(Clarity=None)
                    df_050_059_OE_VVS1_K  = df_050_059_OE_VVS1_K.assign(Cut=None)
                    df_050_059_OE_VVS1_K  = df_050_059_OE_VVS1_K.assign(Polish=None)
                    df_050_059_OE_VVS1_K  = df_050_059_OE_VVS1_K.assign(Symmetry=None)
                    df_050_059_OE_VVS1_K  = df_050_059_OE_VVS1_K.assign(Ratio=None)
                    df_050_059_OE_VVS1_K  = df_050_059_OE_VVS1_K.assign(PPC=None)
                    df_050_059_OE_VVS1_K  = df_050_059_OE_VVS1_K.assign(Total=None)
                    df_050_059_OE_VVS1_K ['Wt Range'] = listwtrange
                    df_050_059_OE_VVS1_K ['Company'] = listcom
                    df_050_059_OE_VVS1_K ['Shape'] = listshap
                    df_050_059_OE_VVS1_K ['Carat'] = listcar
                    df_050_059_OE_VVS1_K ['Color'] = listcol
                    df_050_059_OE_VVS1_K ['Clarity'] = listclar
                    df_050_059_OE_VVS1_K ['Cut'] = listcut
                    df_050_059_OE_VVS1_K ['Polish'] = listpol
                    df_050_059_OE_VVS1_K ['Symmetry'] = listsym
                    df_050_059_OE_VVS1_K ['Ratio'] = listrat
                    df_050_059_OE_VVS1_K ['PPC'] = listdesc
                    df_050_059_OE_VVS1_K ['Total'] = listtotal
                    df_050_059_OE_VVS1_K['Carat'] = df_050_059_OE_VVS1_K['Carat'].astype('float64')
                    df_050_059_OE_VVS1_K['PPC'] = df_050_059_OE_VVS1_K['PPC'].astype('float64')
                    df_050_059_OE_VVS1_K['Total'] = df_050_059_OE_VVS1_K['Total'].astype('float64')
                    df_050_059_OE_VVS1_K['Total'] = df_050_059_OE_VVS1_K['Carat'] * df_050_059_OE_VVS1_K['PPC']


                elif i=="K" and j == "VVS2" and k == "OE":
                    df_050_059_OE_VVS2_K = pd.DataFrame()
                    df_050_059_OE_VVS2_K ['Wt Range'] = None
                    df_050_059_OE_VVS2_K  = df_050_059_OE_VVS2_K.assign(Company=None)
                    df_050_059_OE_VVS2_K  = df_050_059_OE_VVS2_K.assign(Shape=None)
                    df_050_059_OE_VVS2_K  = df_050_059_OE_VVS2_K.assign(Carat=None)
                    df_050_059_OE_VVS2_K  = df_050_059_OE_VVS2_K.assign(Color=None)
                    df_050_059_OE_VVS2_K  = df_050_059_OE_VVS2_K.assign(Clarity=None)
                    df_050_059_OE_VVS2_K  = df_050_059_OE_VVS2_K.assign(Cut=None)
                    df_050_059_OE_VVS2_K  = df_050_059_OE_VVS2_K.assign(Polish=None)
                    df_050_059_OE_VVS2_K  = df_050_059_OE_VVS2_K.assign(Symmetry=None)
                    df_050_059_OE_VVS2_K  = df_050_059_OE_VVS2_K.assign(Ratio=None)
                    df_050_059_OE_VVS2_K  = df_050_059_OE_VVS2_K.assign(PPC=None)
                    df_050_059_OE_VVS2_K  = df_050_059_OE_VVS2_K.assign(Total=None)
                    df_050_059_OE_VVS2_K ['Wt Range'] = listwtrange
                    df_050_059_OE_VVS2_K ['Company'] = listcom
                    df_050_059_OE_VVS2_K ['Shape'] = listshap
                    df_050_059_OE_VVS2_K ['Carat'] = listcar
                    df_050_059_OE_VVS2_K ['Color'] = listcol
                    df_050_059_OE_VVS2_K ['Clarity'] = listclar
                    df_050_059_OE_VVS2_K ['Cut'] = listcut
                    df_050_059_OE_VVS2_K ['Polish'] = listpol
                    df_050_059_OE_VVS2_K ['Symmetry'] = listsym
                    df_050_059_OE_VVS2_K ['Ratio'] = listrat
                    df_050_059_OE_VVS2_K ['PPC'] = listdesc
                    df_050_059_OE_VVS2_K ['Total'] = listtotal
                    df_050_059_OE_VVS2_K['Carat'] = df_050_059_OE_VVS2_K['Carat'].astype('float64')
                    df_050_059_OE_VVS2_K['PPC'] = df_050_059_OE_VVS2_K['PPC'].astype('float64')
                    df_050_059_OE_VVS2_K['Total'] = df_050_059_OE_VVS2_K['Total'].astype('float64')
                    df_050_059_OE_VVS2_K['Total'] = df_050_059_OE_VVS2_K['Carat'] * df_050_059_OE_VVS2_K['PPC']


                elif i=="K" and j=="VS1" and k == "OE":
                    df_050_059_OE_VS1_K = pd.DataFrame()
                    df_050_059_OE_VS1_K ['Wt Range'] = None
                    df_050_059_OE_VS1_K  = df_050_059_OE_VS1_K.assign(Company=None)
                    df_050_059_OE_VS1_K  = df_050_059_OE_VS1_K.assign(Shape=None)
                    df_050_059_OE_VS1_K  = df_050_059_OE_VS1_K.assign(Carat=None)
                    df_050_059_OE_VS1_K  = df_050_059_OE_VS1_K.assign(Color=None)
                    df_050_059_OE_VS1_K  = df_050_059_OE_VS1_K.assign(Clarity=None)
                    df_050_059_OE_VS1_K  = df_050_059_OE_VS1_K.assign(Cut=None)
                    df_050_059_OE_VS1_K  = df_050_059_OE_VS1_K.assign(Polish=None)
                    df_050_059_OE_VS1_K  = df_050_059_OE_VS1_K.assign(Symmetry=None)
                    df_050_059_OE_VS1_K  = df_050_059_OE_VS1_K.assign(Ratio=None)
                    df_050_059_OE_VS1_K  = df_050_059_OE_VS1_K.assign(PPC=None)
                    df_050_059_OE_VS1_K  = df_050_059_OE_VS1_K.assign(Total=None)
                    df_050_059_OE_VS1_K ['Wt Range'] = listwtrange
                    df_050_059_OE_VS1_K ['Company'] = listcom
                    df_050_059_OE_VS1_K ['Shape'] = listshap
                    df_050_059_OE_VS1_K ['Carat'] = listcar
                    df_050_059_OE_VS1_K ['Color'] = listcol
                    df_050_059_OE_VS1_K ['Clarity'] = listclar
                    df_050_059_OE_VS1_K ['Cut'] = listcut
                    df_050_059_OE_VS1_K ['Polish'] = listpol
                    df_050_059_OE_VS1_K ['Symmetry'] = listsym
                    df_050_059_OE_VS1_K ['Ratio'] = listrat
                    df_050_059_OE_VS1_K ['PPC'] = listdesc
                    df_050_059_OE_VS1_K ['Total'] = listtotal
                    df_050_059_OE_VS1_K['Carat'] = df_050_059_OE_VS1_K['Carat'].astype('float64')
                    df_050_059_OE_VS1_K['PPC'] = df_050_059_OE_VS1_K['PPC'].astype('float64')
                    df_050_059_OE_VS1_K['Total'] = df_050_059_OE_VS1_K['Total'].astype('float64')
                    df_050_059_OE_VS1_K['Total'] = df_050_059_OE_VS1_K['Carat'] * df_050_059_OE_VS1_K['PPC']


                elif i=="K" and j == "VS2" and k == "OE":
                    df_050_059_OE_VS2_K = pd.DataFrame()
                    df_050_059_OE_VS2_K ['Wt Range'] = None
                    df_050_059_OE_VS2_K  = df_050_059_OE_VS2_K.assign(Company=None)
                    df_050_059_OE_VS2_K  = df_050_059_OE_VS2_K.assign(Shape=None)
                    df_050_059_OE_VS2_K  = df_050_059_OE_VS2_K.assign(Carat=None)
                    df_050_059_OE_VS2_K  = df_050_059_OE_VS2_K.assign(Color=None)
                    df_050_059_OE_VS2_K  = df_050_059_OE_VS2_K.assign(Clarity=None)
                    df_050_059_OE_VS2_K  = df_050_059_OE_VS2_K.assign(Cut=None)
                    df_050_059_OE_VS2_K  = df_050_059_OE_VS2_K.assign(Polish=None)
                    df_050_059_OE_VS2_K  = df_050_059_OE_VS2_K.assign(Symmetry=None)
                    df_050_059_OE_VS2_K  = df_050_059_OE_VS2_K.assign(Ratio=None)
                    df_050_059_OE_VS2_K  = df_050_059_OE_VS2_K.assign(PPC=None)
                    df_050_059_OE_VS2_K  = df_050_059_OE_VS2_K.assign(Total=None)
                    df_050_059_OE_VS2_K ['Wt Range'] = listwtrange
                    df_050_059_OE_VS2_K ['Company'] = listcom
                    df_050_059_OE_VS2_K ['Shape'] = listshap
                    df_050_059_OE_VS2_K ['Carat'] = listcar
                    df_050_059_OE_VS2_K ['Color'] = listcol
                    df_050_059_OE_VS2_K ['Clarity'] = listclar
                    df_050_059_OE_VS2_K ['Cut'] = listcut
                    df_050_059_OE_VS2_K ['Polish'] = listpol
                    df_050_059_OE_VS2_K ['Symmetry'] = listsym
                    df_050_059_OE_VS2_K ['Ratio'] = listrat
                    df_050_059_OE_VS2_K ['PPC'] = listdesc
                    df_050_059_OE_VS2_K ['Total'] = listtotal
                    df_050_059_OE_VS2_K['Carat'] = df_050_059_OE_VS2_K['Carat'].astype('float64')
                    df_050_059_OE_VS2_K['PPC'] = df_050_059_OE_VS2_K['PPC'].astype('float64')
                    df_050_059_OE_VS2_K['Total'] = df_050_059_OE_VS2_K['Total'].astype('float64')
                    df_050_059_OE_VS2_K['Total'] = df_050_059_OE_VS2_K['Carat'] * df_050_059_OE_VS2_K['PPC']


                elif i=="K" and j == "SI1" and k == "OE":
                    df_050_059_OE_SI1_K = pd.DataFrame()
                    df_050_059_OE_SI1_K ['Wt Range'] = None
                    df_050_059_OE_SI1_K  = df_050_059_OE_SI1_K.assign(Company=None)
                    df_050_059_OE_SI1_K  = df_050_059_OE_SI1_K.assign(Shape=None)
                    df_050_059_OE_SI1_K  = df_050_059_OE_SI1_K.assign(Carat=None)
                    df_050_059_OE_SI1_K  = df_050_059_OE_SI1_K.assign(Color=None)
                    df_050_059_OE_SI1_K  = df_050_059_OE_SI1_K.assign(Clarity=None)
                    df_050_059_OE_SI1_K  = df_050_059_OE_SI1_K.assign(Cut=None)
                    df_050_059_OE_SI1_K  = df_050_059_OE_SI1_K.assign(Polish=None)
                    df_050_059_OE_SI1_K  = df_050_059_OE_SI1_K.assign(Symmetry=None)
                    df_050_059_OE_SI1_K  = df_050_059_OE_SI1_K.assign(Ratio=None)
                    df_050_059_OE_SI1_K  = df_050_059_OE_SI1_K.assign(PPC=None)
                    df_050_059_OE_SI1_K  = df_050_059_OE_SI1_K.assign(Total=None)
                    df_050_059_OE_SI1_K ['Wt Range'] = listwtrange
                    df_050_059_OE_SI1_K ['Company'] = listcom
                    df_050_059_OE_SI1_K ['Shape'] = listshap
                    df_050_059_OE_SI1_K ['Carat'] = listcar
                    df_050_059_OE_SI1_K ['Color'] = listcol
                    df_050_059_OE_SI1_K ['Clarity'] = listclar
                    df_050_059_OE_SI1_K ['Cut'] = listcut
                    df_050_059_OE_SI1_K ['Polish'] = listpol
                    df_050_059_OE_SI1_K ['Symmetry'] = listsym
                    df_050_059_OE_SI1_K ['Ratio'] = listrat
                    df_050_059_OE_SI1_K ['PPC'] = listdesc
                    df_050_059_OE_SI1_K ['Total'] = listtotal
                    df_050_059_OE_SI1_K['Carat'] = df_050_059_OE_SI1_K['Carat'].astype('float64')
                    df_050_059_OE_SI1_K['PPC'] = df_050_059_OE_SI1_K['PPC'].astype('float64')
                    df_050_059_OE_SI1_K['Total'] = df_050_059_OE_SI1_K['Total'].astype('float64')
                    df_050_059_OE_SI1_K['Total'] = df_050_059_OE_SI1_K['Carat'] * df_050_059_OE_SI1_K['PPC']


                elif i=="K" and j == "SI2" and k == "OE":
                    df_050_059_OE_SI2_K = pd.DataFrame()
                    df_050_059_OE_SI2_K ['Wt Range'] = None
                    df_050_059_OE_SI2_K  = df_050_059_OE_SI2_K.assign(Company=None)
                    df_050_059_OE_SI2_K  = df_050_059_OE_SI2_K.assign(Shape=None)
                    df_050_059_OE_SI2_K  = df_050_059_OE_SI2_K.assign(Carat=None)
                    df_050_059_OE_SI2_K  = df_050_059_OE_SI2_K.assign(Color=None)
                    df_050_059_OE_SI2_K  = df_050_059_OE_SI2_K.assign(Clarity=None)
                    df_050_059_OE_SI2_K  = df_050_059_OE_SI2_K.assign(Cut=None)
                    df_050_059_OE_SI2_K  = df_050_059_OE_SI2_K.assign(Polish=None)
                    df_050_059_OE_SI2_K  = df_050_059_OE_SI2_K.assign(Symmetry=None)
                    df_050_059_OE_SI2_K  = df_050_059_OE_SI2_K.assign(Ratio=None)
                    df_050_059_OE_SI2_K  = df_050_059_OE_SI2_K.assign(PPC=None)
                    df_050_059_OE_SI2_K  = df_050_059_OE_SI2_K.assign(Total=None)
                    df_050_059_OE_SI2_K ['Wt Range'] = listwtrange
                    df_050_059_OE_SI2_K ['Company'] = listcom
                    df_050_059_OE_SI2_K ['Shape'] = listshap
                    df_050_059_OE_SI2_K ['Carat'] = listcar
                    df_050_059_OE_SI2_K ['Color'] = listcol
                    df_050_059_OE_SI2_K ['Clarity'] = listclar
                    df_050_059_OE_SI2_K ['Cut'] = listcut
                    df_050_059_OE_SI2_K ['Polish'] = listpol
                    df_050_059_OE_SI2_K ['Symmetry'] = listsym
                    df_050_059_OE_SI2_K ['Ratio'] = listrat
                    df_050_059_OE_SI2_K ['PPC'] = listdesc
                    df_050_059_OE_SI2_K ['Total'] = listtotal
                    df_050_059_OE_SI2_K['Carat'] = df_050_059_OE_SI2_K['Carat'].astype('float64')
                    df_050_059_OE_SI2_K['PPC'] = df_050_059_OE_SI2_K['PPC'].astype('float64')
                    df_050_059_OE_SI2_K['Total'] = df_050_059_OE_SI2_K['Total'].astype('float64')
                    df_050_059_OE_SI2_K['Total'] = df_050_059_OE_SI2_K['Carat'] * df_050_059_OE_SI2_K['PPC']


                elif i=="K" and j == "I1" and k == "OE":
                    df_050_059_OE_I1_K = pd.DataFrame()
                    df_050_059_OE_I1_K ['Wt Range'] = None
                    df_050_059_OE_I1_K  = df_050_059_OE_I1_K.assign(Company=None)
                    df_050_059_OE_I1_K  = df_050_059_OE_I1_K.assign(Shape=None)
                    df_050_059_OE_I1_K  = df_050_059_OE_I1_K.assign(Carat=None)
                    df_050_059_OE_I1_K  = df_050_059_OE_I1_K.assign(Color=None)
                    df_050_059_OE_I1_K  = df_050_059_OE_I1_K.assign(Clarity=None)
                    df_050_059_OE_I1_K  = df_050_059_OE_I1_K.assign(Cut=None)
                    df_050_059_OE_I1_K  = df_050_059_OE_I1_K.assign(Polish=None)
                    df_050_059_OE_I1_K  = df_050_059_OE_I1_K.assign(Symmetry=None)
                    df_050_059_OE_I1_K  = df_050_059_OE_I1_K.assign(Ratio=None)
                    df_050_059_OE_I1_K  = df_050_059_OE_I1_K.assign(PPC=None)
                    df_050_059_OE_I1_K  = df_050_059_OE_I1_K.assign(Total=None)
                    df_050_059_OE_I1_K ['Wt Range'] = listwtrange
                    df_050_059_OE_I1_K ['Company'] = listcom
                    df_050_059_OE_I1_K ['Shape'] = listshap
                    df_050_059_OE_I1_K ['Carat'] = listcar
                    df_050_059_OE_I1_K ['Color'] = listcol
                    df_050_059_OE_I1_K ['Clarity'] = listclar
                    df_050_059_OE_I1_K ['Cut'] = listcut
                    df_050_059_OE_I1_K ['Polish'] = listpol
                    df_050_059_OE_I1_K ['Symmetry'] = listsym
                    df_050_059_OE_I1_K ['Ratio'] = listrat
                    df_050_059_OE_I1_K ['PPC'] = listdesc
                    df_050_059_OE_I1_K ['Total'] = listtotal
                    df_050_059_OE_I1_K['Carat'] = df_050_059_OE_I1_K['Carat'].astype('float64')
                    df_050_059_OE_I1_K['PPC'] = df_050_059_OE_I1_K['PPC'].astype('float64')
                    df_050_059_OE_I1_K['Total'] = df_050_059_OE_I1_K['Total'].astype('float64')
                    df_050_059_OE_I1_K['Total'] = df_050_059_OE_I1_K['Carat'] * df_050_059_OE_I1_K['PPC']


                elif i=="K" and j == "I2" and k == "OE":
                    df_050_059_OE_I2_K = pd.DataFrame()
                    df_050_059_OE_I2_K ['Wt Range'] = None
                    df_050_059_OE_I2_K  = df_050_059_OE_I2_K.assign(Company=None)
                    df_050_059_OE_I2_K  = df_050_059_OE_I2_K.assign(Shape=None)
                    df_050_059_OE_I2_K  = df_050_059_OE_I2_K.assign(Carat=None)
                    df_050_059_OE_I2_K  = df_050_059_OE_I2_K.assign(Color=None)
                    df_050_059_OE_I2_K  = df_050_059_OE_I2_K.assign(Clarity=None)
                    df_050_059_OE_I2_K  = df_050_059_OE_I2_K.assign(Cut=None)
                    df_050_059_OE_I2_K  = df_050_059_OE_I2_K.assign(Polish=None)
                    df_050_059_OE_I2_K  = df_050_059_OE_I2_K.assign(Symmetry=None)
                    df_050_059_OE_I2_K  = df_050_059_OE_I2_K.assign(Ratio=None)
                    df_050_059_OE_I2_K  = df_050_059_OE_I2_K.assign(PPC=None)
                    df_050_059_OE_I2_K  = df_050_059_OE_I2_K.assign(Total=None)
                    df_050_059_OE_I2_K ['Wt Range'] = listwtrange
                    df_050_059_OE_I2_K ['Company'] = listcom
                    df_050_059_OE_I2_K ['Shape'] = listshap
                    df_050_059_OE_I2_K ['Carat'] = listcar
                    df_050_059_OE_I2_K ['Color'] = listcol
                    df_050_059_OE_I2_K ['Clarity'] = listclar
                    df_050_059_OE_I2_K ['Cut'] = listcut
                    df_050_059_OE_I2_K ['Polish'] = listpol
                    df_050_059_OE_I2_K ['Symmetry'] = listsym
                    df_050_059_OE_I2_K ['Ratio'] = listrat
                    df_050_059_OE_I2_K ['PPC'] = listdesc
                    df_050_059_OE_I2_K ['Total'] = listtotal
                    df_050_059_OE_I2_K['Carat'] = df_050_059_OE_I2_K['Carat'].astype('float64')
                    df_050_059_OE_I2_K['PPC'] = df_050_059_OE_I2_K['PPC'].astype('float64')
                    df_050_059_OE_I2_K['Total'] = df_050_059_OE_I2_K['Total'].astype('float64')
                    df_050_059_OE_I2_K['Total'] = df_050_059_OE_I2_K['Carat'] * df_050_059_OE_I2_K['PPC']


                elif i=="L" and j == "IF" and k == "OE":
                    df_050_059_OE_IF_L = pd.DataFrame()
                    df_050_059_OE_IF_L ['Wt Range'] = None
                    df_050_059_OE_IF_L  = df_050_059_OE_IF_L.assign(Company=None)
                    df_050_059_OE_IF_L  = df_050_059_OE_IF_L.assign(Shape=None)
                    df_050_059_OE_IF_L  = df_050_059_OE_IF_L.assign(Carat=None)
                    df_050_059_OE_IF_L  = df_050_059_OE_IF_L.assign(Color=None)
                    df_050_059_OE_IF_L  = df_050_059_OE_IF_L.assign(Clarity=None)
                    df_050_059_OE_IF_L  = df_050_059_OE_IF_L.assign(Cut=None)
                    df_050_059_OE_IF_L  = df_050_059_OE_IF_L.assign(Polish=None)
                    df_050_059_OE_IF_L  = df_050_059_OE_IF_L.assign(Symmetry=None)
                    df_050_059_OE_IF_L  = df_050_059_OE_IF_L.assign(Ratio=None)
                    df_050_059_OE_IF_L  = df_050_059_OE_IF_L.assign(PPC=None)
                    df_050_059_OE_IF_L  = df_050_059_OE_IF_L.assign(Total=None)
                    df_050_059_OE_IF_L ['Wt Range'] = listwtrange
                    df_050_059_OE_IF_L ['Company'] = listcom
                    df_050_059_OE_IF_L ['Shape'] = listshap
                    df_050_059_OE_IF_L ['Carat'] = listcar
                    df_050_059_OE_IF_L ['Color'] = listcol
                    df_050_059_OE_IF_L ['Clarity'] = listclar
                    df_050_059_OE_IF_L ['Cut'] = listcut
                    df_050_059_OE_IF_L ['Polish'] = listpol
                    df_050_059_OE_IF_L ['Symmetry'] = listsym
                    df_050_059_OE_IF_L ['Ratio'] = listrat
                    df_050_059_OE_IF_L ['PPC'] = listdesc
                    df_050_059_OE_IF_L ['Total'] = listtotal
                    df_050_059_OE_IF_L['Carat'] = df_050_059_OE_IF_L['Carat'].astype('float64')
                    df_050_059_OE_IF_L['PPC'] = df_050_059_OE_IF_L['PPC'].astype('float64')
                    df_050_059_OE_IF_L['Total'] = df_050_059_OE_IF_L['Total'].astype('float64')
                    df_050_059_OE_IF_L['Total'] = df_050_059_OE_IF_L['Carat'] * df_050_059_OE_IF_L['PPC']


                elif i=="L" and j == "VVS1" and k == "OE":
                    df_050_059_OE_VVS1_L = pd.DataFrame()
                    df_050_059_OE_VVS1_L ['Wt Range'] = None
                    df_050_059_OE_VVS1_L  = df_050_059_OE_VVS1_L.assign(Company=None)
                    df_050_059_OE_VVS1_L  = df_050_059_OE_VVS1_L.assign(Shape=None)
                    df_050_059_OE_VVS1_L  = df_050_059_OE_VVS1_L.assign(Carat=None)
                    df_050_059_OE_VVS1_L  = df_050_059_OE_VVS1_L.assign(Color=None)
                    df_050_059_OE_VVS1_L  = df_050_059_OE_VVS1_L.assign(Clarity=None)
                    df_050_059_OE_VVS1_L  = df_050_059_OE_VVS1_L.assign(Cut=None)
                    df_050_059_OE_VVS1_L  = df_050_059_OE_VVS1_L.assign(Polish=None)
                    df_050_059_OE_VVS1_L  = df_050_059_OE_VVS1_L.assign(Symmetry=None)
                    df_050_059_OE_VVS1_L  = df_050_059_OE_VVS1_L.assign(Ratio=None)
                    df_050_059_OE_VVS1_L  = df_050_059_OE_VVS1_L.assign(PPC=None)
                    df_050_059_OE_VVS1_L  = df_050_059_OE_VVS1_L.assign(Total=None)
                    df_050_059_OE_VVS1_L ['Wt Range'] = listwtrange
                    df_050_059_OE_VVS1_L ['Company'] = listcom
                    df_050_059_OE_VVS1_L ['Shape'] = listshap
                    df_050_059_OE_VVS1_L ['Carat'] = listcar
                    df_050_059_OE_VVS1_L ['Color'] = listcol
                    df_050_059_OE_VVS1_L ['Clarity'] = listclar
                    df_050_059_OE_VVS1_L ['Cut'] = listcut
                    df_050_059_OE_VVS1_L ['Polish'] = listpol
                    df_050_059_OE_VVS1_L ['Symmetry'] = listsym
                    df_050_059_OE_VVS1_L ['Ratio'] = listrat
                    df_050_059_OE_VVS1_L ['PPC'] = listdesc
                    df_050_059_OE_VVS1_L ['Total'] = listtotal
                    df_050_059_OE_VVS1_L['Carat'] = df_050_059_OE_VVS1_L['Carat'].astype('float64')
                    df_050_059_OE_VVS1_L['PPC'] = df_050_059_OE_VVS1_L['PPC'].astype('float64')
                    df_050_059_OE_VVS1_L['Total'] = df_050_059_OE_VVS1_L['Total'].astype('float64')
                    df_050_059_OE_VVS1_L['Total'] = df_050_059_OE_VVS1_L['Carat'] * df_050_059_OE_VVS1_L['PPC']


                elif i=="L" and j == "VVS2" and k == "OE":
                    df_050_059_OE_VVS2_L = pd.DataFrame()
                    df_050_059_OE_VVS2_L ['Wt Range'] = None
                    df_050_059_OE_VVS2_L  = df_050_059_OE_VVS2_L.assign(Company=None)
                    df_050_059_OE_VVS2_L  = df_050_059_OE_VVS2_L.assign(Shape=None)
                    df_050_059_OE_VVS2_L  = df_050_059_OE_VVS2_L.assign(Carat=None)
                    df_050_059_OE_VVS2_L  = df_050_059_OE_VVS2_L.assign(Color=None)
                    df_050_059_OE_VVS2_L  = df_050_059_OE_VVS2_L.assign(Clarity=None)
                    df_050_059_OE_VVS2_L  = df_050_059_OE_VVS2_L.assign(Cut=None)
                    df_050_059_OE_VVS2_L  = df_050_059_OE_VVS2_L.assign(Polish=None)
                    df_050_059_OE_VVS2_L  = df_050_059_OE_VVS2_L.assign(Symmetry=None)
                    df_050_059_OE_VVS2_L  = df_050_059_OE_VVS2_L.assign(Ratio=None)
                    df_050_059_OE_VVS2_L  = df_050_059_OE_VVS2_L.assign(PPC=None)
                    df_050_059_OE_VVS2_L  = df_050_059_OE_VVS2_L.assign(Total=None)
                    df_050_059_OE_VVS2_L ['Wt Range'] = listwtrange
                    df_050_059_OE_VVS2_L ['Company'] = listcom
                    df_050_059_OE_VVS2_L ['Shape'] = listshap
                    df_050_059_OE_VVS2_L ['Carat'] = listcar
                    df_050_059_OE_VVS2_L ['Color'] = listcol
                    df_050_059_OE_VVS2_L ['Clarity'] = listclar
                    df_050_059_OE_VVS2_L ['Cut'] = listcut
                    df_050_059_OE_VVS2_L ['Polish'] = listpol
                    df_050_059_OE_VVS2_L ['Symmetry'] = listsym
                    df_050_059_OE_VVS2_L ['Ratio'] = listrat
                    df_050_059_OE_VVS2_L ['PPC'] = listdesc
                    df_050_059_OE_VVS2_L ['Total'] = listtotal
                    df_050_059_OE_VVS2_L['Carat'] = df_050_059_OE_VVS2_L['Carat'].astype('float64')
                    df_050_059_OE_VVS2_L['PPC'] = df_050_059_OE_VVS2_L['PPC'].astype('float64')
                    df_050_059_OE_VVS2_L['Total'] = df_050_059_OE_VVS2_L['Total'].astype('float64')
                    df_050_059_OE_VVS2_L['Total'] = df_050_059_OE_VVS2_L['Carat'] * df_050_059_OE_VVS2_L['PPC']


                elif i=="L" and j=="VS1" and k == "OE":
                    df_050_059_OE_VS1_L = pd.DataFrame()
                    df_050_059_OE_VS1_L ['Wt Range'] = None
                    df_050_059_OE_VS1_L  = df_050_059_OE_VS1_L.assign(Company=None)
                    df_050_059_OE_VS1_L  = df_050_059_OE_VS1_L.assign(Shape=None)
                    df_050_059_OE_VS1_L  = df_050_059_OE_VS1_L.assign(Carat=None)
                    df_050_059_OE_VS1_L  = df_050_059_OE_VS1_L.assign(Color=None)
                    df_050_059_OE_VS1_L  = df_050_059_OE_VS1_L.assign(Clarity=None)
                    df_050_059_OE_VS1_L  = df_050_059_OE_VS1_L.assign(Cut=None)
                    df_050_059_OE_VS1_L  = df_050_059_OE_VS1_L.assign(Polish=None)
                    df_050_059_OE_VS1_L  = df_050_059_OE_VS1_L.assign(Symmetry=None)
                    df_050_059_OE_VS1_L  = df_050_059_OE_VS1_L.assign(Ratio=None)
                    df_050_059_OE_VS1_L  = df_050_059_OE_VS1_L.assign(PPC=None)
                    df_050_059_OE_VS1_L  = df_050_059_OE_VS1_L.assign(Total=None)
                    df_050_059_OE_VS1_L ['Wt Range'] = listwtrange
                    df_050_059_OE_VS1_L ['Company'] = listcom
                    df_050_059_OE_VS1_L ['Shape'] = listshap
                    df_050_059_OE_VS1_L ['Carat'] = listcar
                    df_050_059_OE_VS1_L ['Color'] = listcol
                    df_050_059_OE_VS1_L ['Clarity'] = listclar
                    df_050_059_OE_VS1_L ['Cut'] = listcut
                    df_050_059_OE_VS1_L ['Polish'] = listpol
                    df_050_059_OE_VS1_L ['Symmetry'] = listsym
                    df_050_059_OE_VS1_L ['Ratio'] = listrat
                    df_050_059_OE_VS1_L ['PPC'] = listdesc
                    df_050_059_OE_VS1_L ['Total'] = listtotal
                    df_050_059_OE_VS1_L['Carat'] = df_050_059_OE_VS1_L['Carat'].astype('float64')
                    df_050_059_OE_VS1_L['PPC'] = df_050_059_OE_VS1_L['PPC'].astype('float64')
                    df_050_059_OE_VS1_L['Total'] = df_050_059_OE_VS1_L['Total'].astype('float64')
                    df_050_059_OE_VS1_L['Total'] = df_050_059_OE_VS1_L['Carat'] * df_050_059_OE_VS1_L['PPC']


                elif i=="L" and j == "VS2" and k == "OE":
                    df_050_059_OE_VS2_L = pd.DataFrame()
                    df_050_059_OE_VS2_L ['Wt Range'] = None
                    df_050_059_OE_VS2_L  = df_050_059_OE_VS2_L.assign(Company=None)
                    df_050_059_OE_VS2_L  = df_050_059_OE_VS2_L.assign(Shape=None)
                    df_050_059_OE_VS2_L  = df_050_059_OE_VS2_L.assign(Carat=None)
                    df_050_059_OE_VS2_L  = df_050_059_OE_VS2_L.assign(Color=None)
                    df_050_059_OE_VS2_L  = df_050_059_OE_VS2_L.assign(Clarity=None)
                    df_050_059_OE_VS2_L  = df_050_059_OE_VS2_L.assign(Cut=None)
                    df_050_059_OE_VS2_L  = df_050_059_OE_VS2_L.assign(Polish=None)
                    df_050_059_OE_VS2_L  = df_050_059_OE_VS2_L.assign(Symmetry=None)
                    df_050_059_OE_VS2_L  = df_050_059_OE_VS2_L.assign(Ratio=None)
                    df_050_059_OE_VS2_L  = df_050_059_OE_VS2_L.assign(PPC=None)
                    df_050_059_OE_VS2_L  = df_050_059_OE_VS2_L.assign(Total=None)
                    df_050_059_OE_VS2_L ['Wt Range'] = listwtrange
                    df_050_059_OE_VS2_L ['Company'] = listcom
                    df_050_059_OE_VS2_L ['Shape'] = listshap
                    df_050_059_OE_VS2_L ['Carat'] = listcar
                    df_050_059_OE_VS2_L ['Color'] = listcol
                    df_050_059_OE_VS2_L ['Clarity'] = listclar
                    df_050_059_OE_VS2_L ['Cut'] = listcut
                    df_050_059_OE_VS2_L ['Polish'] = listpol
                    df_050_059_OE_VS2_L ['Symmetry'] = listsym
                    df_050_059_OE_VS2_L ['Ratio'] = listrat
                    df_050_059_OE_VS2_L ['PPC'] = listdesc
                    df_050_059_OE_VS2_L ['Total'] = listtotal
                    df_050_059_OE_VS2_L['Carat'] = df_050_059_OE_VS2_L['Carat'].astype('float64')
                    df_050_059_OE_VS2_L['PPC'] = df_050_059_OE_VS2_L['PPC'].astype('float64')
                    df_050_059_OE_VS2_L['Total'] = df_050_059_OE_VS2_L['Total'].astype('float64')
                    df_050_059_OE_VS2_L['Total'] = df_050_059_OE_VS2_L['Carat'] * df_050_059_OE_VS2_L['PPC']


                elif i=="L" and j == "SI1" and k == "OE":
                    df_050_059_OE_SI1_L = pd.DataFrame()
                    df_050_059_OE_SI1_L ['Wt Range'] = None
                    df_050_059_OE_SI1_L  = df_050_059_OE_SI1_L.assign(Company=None)
                    df_050_059_OE_SI1_L  = df_050_059_OE_SI1_L.assign(Shape=None)
                    df_050_059_OE_SI1_L  = df_050_059_OE_SI1_L.assign(Carat=None)
                    df_050_059_OE_SI1_L  = df_050_059_OE_SI1_L.assign(Color=None)
                    df_050_059_OE_SI1_L  = df_050_059_OE_SI1_L.assign(Clarity=None)
                    df_050_059_OE_SI1_L  = df_050_059_OE_SI1_L.assign(Cut=None)
                    df_050_059_OE_SI1_L  = df_050_059_OE_SI1_L.assign(Polish=None)
                    df_050_059_OE_SI1_L  = df_050_059_OE_SI1_L.assign(Symmetry=None)
                    df_050_059_OE_SI1_L  = df_050_059_OE_SI1_L.assign(Ratio=None)
                    df_050_059_OE_SI1_L  = df_050_059_OE_SI1_L.assign(PPC=None)
                    df_050_059_OE_SI1_L  = df_050_059_OE_SI1_L.assign(Total=None)
                    df_050_059_OE_SI1_L ['Wt Range'] = listwtrange
                    df_050_059_OE_SI1_L ['Company'] = listcom
                    df_050_059_OE_SI1_L ['Shape'] = listshap
                    df_050_059_OE_SI1_L ['Carat'] = listcar
                    df_050_059_OE_SI1_L ['Color'] = listcol
                    df_050_059_OE_SI1_L ['Clarity'] = listclar
                    df_050_059_OE_SI1_L ['Cut'] = listcut
                    df_050_059_OE_SI1_L ['Polish'] = listpol
                    df_050_059_OE_SI1_L ['Symmetry'] = listsym
                    df_050_059_OE_SI1_L ['Ratio'] = listrat
                    df_050_059_OE_SI1_L ['PPC'] = listdesc
                    df_050_059_OE_SI1_L ['Total'] = listtotal
                    df_050_059_OE_SI1_L['Carat'] = df_050_059_OE_SI1_L['Carat'].astype('float64')
                    df_050_059_OE_SI1_L['PPC'] = df_050_059_OE_SI1_L['PPC'].astype('float64')
                    df_050_059_OE_SI1_L['Total'] = df_050_059_OE_SI1_L['Total'].astype('float64')
                    df_050_059_OE_SI1_L['Total'] = df_050_059_OE_SI1_L['Carat'] * df_050_059_OE_SI1_L['PPC']


                elif i=="L" and j == "SI2" and k == "OE":
                    df_050_059_OE_SI2_L = pd.DataFrame()
                    df_050_059_OE_SI2_L ['Wt Range'] = None
                    df_050_059_OE_SI2_L  = df_050_059_OE_SI2_L.assign(Company=None)
                    df_050_059_OE_SI2_L  = df_050_059_OE_SI2_L.assign(Shape=None)
                    df_050_059_OE_SI2_L  = df_050_059_OE_SI2_L.assign(Carat=None)
                    df_050_059_OE_SI2_L  = df_050_059_OE_SI2_L.assign(Color=None)
                    df_050_059_OE_SI2_L  = df_050_059_OE_SI2_L.assign(Clarity=None)
                    df_050_059_OE_SI2_L  = df_050_059_OE_SI2_L.assign(Cut=None)
                    df_050_059_OE_SI2_L  = df_050_059_OE_SI2_L.assign(Polish=None)
                    df_050_059_OE_SI2_L  = df_050_059_OE_SI2_L.assign(Symmetry=None)
                    df_050_059_OE_SI2_L  = df_050_059_OE_SI2_L.assign(Ratio=None)
                    df_050_059_OE_SI2_L  = df_050_059_OE_SI2_L.assign(PPC=None)
                    df_050_059_OE_SI2_L  = df_050_059_OE_SI2_L.assign(Total=None)
                    df_050_059_OE_SI2_L ['Wt Range'] = listwtrange
                    df_050_059_OE_SI2_L ['Company'] = listcom
                    df_050_059_OE_SI2_L ['Shape'] = listshap
                    df_050_059_OE_SI2_L ['Carat'] = listcar
                    df_050_059_OE_SI2_L ['Color'] = listcol
                    df_050_059_OE_SI2_L ['Clarity'] = listclar
                    df_050_059_OE_SI2_L ['Cut'] = listcut
                    df_050_059_OE_SI2_L ['Polish'] = listpol
                    df_050_059_OE_SI2_L ['Symmetry'] = listsym
                    df_050_059_OE_SI2_L ['Ratio'] = listrat
                    df_050_059_OE_SI2_L ['PPC'] = listdesc
                    df_050_059_OE_SI2_L ['Total'] = listtotal
                    df_050_059_OE_SI2_L['Carat'] = df_050_059_OE_SI2_L['Carat'].astype('float64')
                    df_050_059_OE_SI2_L['PPC'] = df_050_059_OE_SI2_L['PPC'].astype('float64')
                    df_050_059_OE_SI2_L['Total'] = df_050_059_OE_SI2_L['Total'].astype('float64')
                    df_050_059_OE_SI2_L['Total'] = df_050_059_OE_SI2_L['Carat'] * df_050_059_OE_SI2_L['PPC']


                elif i=="L" and j == "I1" and k == "OE":
                    df_050_059_OE_I1_L = pd.DataFrame()
                    df_050_059_OE_I1_L ['Wt Range'] = None
                    df_050_059_OE_I1_L  = df_050_059_OE_I1_L.assign(Company=None)
                    df_050_059_OE_I1_L  = df_050_059_OE_I1_L.assign(Shape=None)
                    df_050_059_OE_I1_L  = df_050_059_OE_I1_L.assign(Carat=None)
                    df_050_059_OE_I1_L  = df_050_059_OE_I1_L.assign(Color=None)
                    df_050_059_OE_I1_L  = df_050_059_OE_I1_L.assign(Clarity=None)
                    df_050_059_OE_I1_L  = df_050_059_OE_I1_L.assign(Cut=None)
                    df_050_059_OE_I1_L  = df_050_059_OE_I1_L.assign(Polish=None)
                    df_050_059_OE_I1_L  = df_050_059_OE_I1_L.assign(Symmetry=None)
                    df_050_059_OE_I1_L  = df_050_059_OE_I1_L.assign(Ratio=None)
                    df_050_059_OE_I1_L  = df_050_059_OE_I1_L.assign(PPC=None)
                    df_050_059_OE_I1_L  = df_050_059_OE_I1_L.assign(Total=None)
                    df_050_059_OE_I1_L ['Wt Range'] = listwtrange
                    df_050_059_OE_I1_L ['Company'] = listcom
                    df_050_059_OE_I1_L ['Shape'] = listshap
                    df_050_059_OE_I1_L ['Carat'] = listcar
                    df_050_059_OE_I1_L ['Color'] = listcol
                    df_050_059_OE_I1_L ['Clarity'] = listclar
                    df_050_059_OE_I1_L ['Cut'] = listcut
                    df_050_059_OE_I1_L ['Polish'] = listpol
                    df_050_059_OE_I1_L ['Symmetry'] = listsym
                    df_050_059_OE_I1_L ['Ratio'] = listrat
                    df_050_059_OE_I1_L ['PPC'] = listdesc
                    df_050_059_OE_I1_L ['Total'] = listtotal
                    df_050_059_OE_I1_L['Carat'] = df_050_059_OE_I1_L['Carat'].astype('float64')
                    df_050_059_OE_I1_L['PPC'] = df_050_059_OE_I1_L['PPC'].astype('float64')
                    df_050_059_OE_I1_L['Total'] = df_050_059_OE_I1_L['Total'].astype('float64')
                    df_050_059_OE_I1_L['Total'] = df_050_059_OE_I1_L['Carat'] * df_050_059_OE_I1_L['PPC']


                elif i=="L" and j == "I2" and k == "OE":
                    df_050_059_OE_I2_L = pd.DataFrame()
                    df_050_059_OE_I2_L ['Wt Range'] = None
                    df_050_059_OE_I2_L  = df_050_059_OE_I2_L.assign(Company=None)
                    df_050_059_OE_I2_L  = df_050_059_OE_I2_L.assign(Shape=None)
                    df_050_059_OE_I2_L  = df_050_059_OE_I2_L.assign(Carat=None)
                    df_050_059_OE_I2_L  = df_050_059_OE_I2_L.assign(Color=None)
                    df_050_059_OE_I2_L  = df_050_059_OE_I2_L.assign(Clarity=None)
                    df_050_059_OE_I2_L  = df_050_059_OE_I2_L.assign(Cut=None)
                    df_050_059_OE_I2_L  = df_050_059_OE_I2_L.assign(Polish=None)
                    df_050_059_OE_I2_L  = df_050_059_OE_I2_L.assign(Symmetry=None)
                    df_050_059_OE_I2_L  = df_050_059_OE_I2_L.assign(Ratio=None)
                    df_050_059_OE_I2_L  = df_050_059_OE_I2_L.assign(PPC=None)
                    df_050_059_OE_I2_L  = df_050_059_OE_I2_L.assign(Total=None)
                    df_050_059_OE_I2_L ['Wt Range'] = listwtrange
                    df_050_059_OE_I2_L ['Company'] = listcom
                    df_050_059_OE_I2_L ['Shape'] = listshap
                    df_050_059_OE_I2_L ['Carat'] = listcar
                    df_050_059_OE_I2_L ['Color'] = listcol
                    df_050_059_OE_I2_L ['Clarity'] = listclar
                    df_050_059_OE_I2_L ['Cut'] = listcut
                    df_050_059_OE_I2_L ['Polish'] = listpol
                    df_050_059_OE_I2_L ['Symmetry'] = listsym
                    df_050_059_OE_I2_L ['Ratio'] = listrat
                    df_050_059_OE_I2_L ['PPC'] = listdesc
                    df_050_059_OE_I2_L ['Total'] = listtotal
                    df_050_059_OE_I2_L['Carat'] = df_050_059_OE_I2_L['Carat'].astype('float64')
                    df_050_059_OE_I2_L['PPC'] = df_050_059_OE_I2_L['PPC'].astype('float64')
                    df_050_059_OE_I2_L['Total'] = df_050_059_OE_I2_L['Total'].astype('float64')
                    df_050_059_OE_I2_L['Total'] = df_050_059_OE_I2_L['Carat'] * df_050_059_OE_I2_L['PPC']



                elif i=="D" and j == "IF" and k == "OM":
                    df_050_059_OM_IF_D = pd.DataFrame()
                    df_050_059_OM_IF_D ['Wt Range'] = None
                    df_050_059_OM_IF_D  = df_050_059_OM_IF_D.assign(Company=None)
                    df_050_059_OM_IF_D  = df_050_059_OM_IF_D.assign(Shape=None)
                    df_050_059_OM_IF_D  = df_050_059_OM_IF_D.assign(Carat=None)
                    df_050_059_OM_IF_D  = df_050_059_OM_IF_D.assign(Color=None)
                    df_050_059_OM_IF_D  = df_050_059_OM_IF_D.assign(Clarity=None)
                    df_050_059_OM_IF_D  = df_050_059_OM_IF_D.assign(Cut=None)
                    df_050_059_OM_IF_D  = df_050_059_OM_IF_D.assign(Polish=None)
                    df_050_059_OM_IF_D  = df_050_059_OM_IF_D.assign(Symmetry=None)
                    df_050_059_OM_IF_D  = df_050_059_OM_IF_D.assign(Ratio=None)
                    df_050_059_OM_IF_D  = df_050_059_OM_IF_D.assign(PPC=None)
                    df_050_059_OM_IF_D  = df_050_059_OM_IF_D.assign(Total=None)
                    df_050_059_OM_IF_D ['Wt Range'] = listwtrange
                    df_050_059_OM_IF_D ['Company'] = listcom
                    df_050_059_OM_IF_D ['Shape'] = listshap
                    df_050_059_OM_IF_D ['Carat'] = listcar
                    df_050_059_OM_IF_D ['Color'] = listcol
                    df_050_059_OM_IF_D ['Clarity'] = listclar
                    df_050_059_OM_IF_D ['Cut'] = listcut
                    df_050_059_OM_IF_D ['Polish'] = listpol
                    df_050_059_OM_IF_D ['Symmetry'] = listsym
                    df_050_059_OM_IF_D ['Ratio'] = listrat
                    df_050_059_OM_IF_D ['PPC'] = listdesc
                    df_050_059_OM_IF_D ['Total'] = listtotal
                    df_050_059_OM_IF_D['Carat'] = df_050_059_OM_IF_D['Carat'].astype('float64')
                    df_050_059_OM_IF_D['PPC'] = df_050_059_OM_IF_D['PPC'].astype('float64')
                    df_050_059_OM_IF_D['Total'] = df_050_059_OM_IF_D['Total'].astype('float64')
                    df_050_059_OM_IF_D['Total'] = df_050_059_OM_IF_D['Carat'] * df_050_059_OM_IF_D['PPC']



                elif i=="D" and j == "VVS1" and k == "OM" :
                    df_050_059_OM_VVS1_D = pd.DataFrame()
                    df_050_059_OM_VVS1_D ['Wt Range'] = None
                    df_050_059_OM_VVS1_D  = df_050_059_OM_VVS1_D.assign(Company=None)
                    df_050_059_OM_VVS1_D  = df_050_059_OM_VVS1_D.assign(Shape=None)
                    df_050_059_OM_VVS1_D  = df_050_059_OM_VVS1_D.assign(Carat=None)
                    df_050_059_OM_VVS1_D  = df_050_059_OM_VVS1_D.assign(Color=None)
                    df_050_059_OM_VVS1_D  = df_050_059_OM_VVS1_D.assign(Clarity=None)
                    df_050_059_OM_VVS1_D  = df_050_059_OM_VVS1_D.assign(Cut=None)
                    df_050_059_OM_VVS1_D  = df_050_059_OM_VVS1_D.assign(Polish=None)
                    df_050_059_OM_VVS1_D  = df_050_059_OM_VVS1_D.assign(Symmetry=None)
                    df_050_059_OM_VVS1_D  = df_050_059_OM_VVS1_D.assign(Ratio=None)
                    df_050_059_OM_VVS1_D  = df_050_059_OM_VVS1_D.assign(PPC=None)
                    df_050_059_OM_VVS1_D  = df_050_059_OM_VVS1_D.assign(Total=None)
                    df_050_059_OM_VVS1_D ['Wt Range'] = listwtrange
                    df_050_059_OM_VVS1_D ['Company'] = listcom
                    df_050_059_OM_VVS1_D ['Shape'] = listshap
                    df_050_059_OM_VVS1_D ['Carat'] = listcar
                    df_050_059_OM_VVS1_D ['Color'] = listcol
                    df_050_059_OM_VVS1_D ['Clarity'] = listclar
                    df_050_059_OM_VVS1_D ['Cut'] = listcut
                    df_050_059_OM_VVS1_D ['Polish'] = listpol
                    df_050_059_OM_VVS1_D ['Symmetry'] = listsym
                    df_050_059_OM_VVS1_D ['Ratio'] = listrat
                    df_050_059_OM_VVS1_D ['PPC'] = listdesc
                    df_050_059_OM_VVS1_D ['Total'] = listtotal
                    df_050_059_OM_VVS1_D['Carat'] = df_050_059_OM_VVS1_D['Carat'].astype('float64')
                    df_050_059_OM_VVS1_D['PPC'] = df_050_059_OM_VVS1_D['PPC'].astype('float64')
                    df_050_059_OM_VVS1_D['Total'] = df_050_059_OM_VVS1_D['Total'].astype('float64')
                    df_050_059_OM_VVS1_D['Total'] = df_050_059_OM_VVS1_D['Carat'] * df_050_059_OM_VVS1_D['PPC']



                elif i=="D" and j == "VVS2" and k == "OM" :
                    df_050_059_OM_VVS2_D = pd.DataFrame()
                    df_050_059_OM_VVS2_D ['Wt Range'] = None
                    df_050_059_OM_VVS2_D  = df_050_059_OM_VVS2_D.assign(Company=None)
                    df_050_059_OM_VVS2_D  = df_050_059_OM_VVS2_D.assign(Shape=None)
                    df_050_059_OM_VVS2_D  = df_050_059_OM_VVS2_D.assign(Carat=None)
                    df_050_059_OM_VVS2_D  = df_050_059_OM_VVS2_D.assign(Color=None)
                    df_050_059_OM_VVS2_D  = df_050_059_OM_VVS2_D.assign(Clarity=None)
                    df_050_059_OM_VVS2_D  = df_050_059_OM_VVS2_D.assign(Cut=None)
                    df_050_059_OM_VVS2_D  = df_050_059_OM_VVS2_D.assign(Polish=None)
                    df_050_059_OM_VVS2_D  = df_050_059_OM_VVS2_D.assign(Symmetry=None)
                    df_050_059_OM_VVS2_D  = df_050_059_OM_VVS2_D.assign(Ratio=None)
                    df_050_059_OM_VVS2_D  = df_050_059_OM_VVS2_D.assign(PPC=None)
                    df_050_059_OM_VVS2_D  = df_050_059_OM_VVS2_D.assign(Total=None)
                    df_050_059_OM_VVS2_D ['Wt Range'] = listwtrange
                    df_050_059_OM_VVS2_D ['Company'] = listcom
                    df_050_059_OM_VVS2_D ['Shape'] = listshap
                    df_050_059_OM_VVS2_D ['Carat'] = listcar
                    df_050_059_OM_VVS2_D ['Color'] = listcol
                    df_050_059_OM_VVS2_D ['Clarity'] = listclar
                    df_050_059_OM_VVS2_D ['Cut'] = listcut
                    df_050_059_OM_VVS2_D ['Polish'] = listpol
                    df_050_059_OM_VVS2_D ['Symmetry'] = listsym
                    df_050_059_OM_VVS2_D ['Ratio'] = listrat
                    df_050_059_OM_VVS2_D ['PPC'] = listdesc
                    df_050_059_OM_VVS2_D ['Total'] = listtotal
                    df_050_059_OM_VVS2_D['Carat'] = df_050_059_OM_VVS2_D['Carat'].astype('float64')
                    df_050_059_OM_VVS2_D['PPC'] = df_050_059_OM_VVS2_D['PPC'].astype('float64')
                    df_050_059_OM_VVS2_D['Total'] = df_050_059_OM_VVS2_D['Total'].astype('float64')
                    df_050_059_OM_VVS2_D['Total'] = df_050_059_OM_VVS2_D['Carat'] * df_050_059_OM_VVS2_D['PPC']



                elif i=="D" and j == "VS1" and k == "OM":
                    df_050_059_OM_VS1_D = pd.DataFrame()
                    df_050_059_OM_VS1_D ['Wt Range'] = None
                    df_050_059_OM_VS1_D  = df_050_059_OM_VS1_D.assign(Company=None)
                    df_050_059_OM_VS1_D  = df_050_059_OM_VS1_D.assign(Shape=None)
                    df_050_059_OM_VS1_D  = df_050_059_OM_VS1_D.assign(Carat=None)
                    df_050_059_OM_VS1_D  = df_050_059_OM_VS1_D.assign(Color=None)
                    df_050_059_OM_VS1_D  = df_050_059_OM_VS1_D.assign(Clarity=None)
                    df_050_059_OM_VS1_D  = df_050_059_OM_VS1_D.assign(Cut=None)
                    df_050_059_OM_VS1_D  = df_050_059_OM_VS1_D.assign(Polish=None)
                    df_050_059_OM_VS1_D  = df_050_059_OM_VS1_D.assign(Symmetry=None)
                    df_050_059_OM_VS1_D  = df_050_059_OM_VS1_D.assign(Ratio=None)
                    df_050_059_OM_VS1_D  = df_050_059_OM_VS1_D.assign(PPC=None)
                    df_050_059_OM_VS1_D  = df_050_059_OM_VS1_D.assign(Total=None)
                    df_050_059_OM_VS1_D ['Wt Range'] = listwtrange
                    df_050_059_OM_VS1_D ['Company'] = listcom
                    df_050_059_OM_VS1_D ['Shape'] = listshap
                    df_050_059_OM_VS1_D ['Carat'] = listcar
                    df_050_059_OM_VS1_D ['Color'] = listcol
                    df_050_059_OM_VS1_D ['Clarity'] = listclar
                    df_050_059_OM_VS1_D ['Cut'] = listcut
                    df_050_059_OM_VS1_D ['Polish'] = listpol
                    df_050_059_OM_VS1_D ['Symmetry'] = listsym
                    df_050_059_OM_VS1_D ['Ratio'] = listrat
                    df_050_059_OM_VS1_D ['PPC'] = listdesc
                    df_050_059_OM_VS1_D ['Total'] = listtotal
                    df_050_059_OM_VS1_D['Carat'] = df_050_059_OM_VS1_D['Carat'].astype('float64')
                    df_050_059_OM_VS1_D['PPC'] = df_050_059_OM_VS1_D['PPC'].astype('float64')
                    df_050_059_OM_VS1_D['Total'] = df_050_059_OM_VS1_D['Total'].astype('float64')
                    df_050_059_OM_VS1_D['Total'] = df_050_059_OM_VS1_D['Carat'] * df_050_059_OM_VS1_D['PPC']


                elif i=="D" and j == "VS2" and k == "OM":
                    df_050_059_OM_VS2_D = pd.DataFrame()
                    df_050_059_OM_VS2_D ['Wt Range'] = None
                    df_050_059_OM_VS2_D  = df_050_059_OM_VS2_D.assign(Company=None)
                    df_050_059_OM_VS2_D  = df_050_059_OM_VS2_D.assign(Shape=None)
                    df_050_059_OM_VS2_D  = df_050_059_OM_VS2_D.assign(Carat=None)
                    df_050_059_OM_VS2_D  = df_050_059_OM_VS2_D.assign(Color=None)
                    df_050_059_OM_VS2_D  = df_050_059_OM_VS2_D.assign(Clarity=None)
                    df_050_059_OM_VS2_D  = df_050_059_OM_VS2_D.assign(Cut=None)
                    df_050_059_OM_VS2_D  = df_050_059_OM_VS2_D.assign(Polish=None)
                    df_050_059_OM_VS2_D  = df_050_059_OM_VS2_D.assign(Symmetry=None)
                    df_050_059_OM_VS2_D  = df_050_059_OM_VS2_D.assign(Ratio=None)
                    df_050_059_OM_VS2_D  = df_050_059_OM_VS2_D.assign(PPC=None)
                    df_050_059_OM_VS2_D  = df_050_059_OM_VS2_D.assign(Total=None)
                    df_050_059_OM_VS2_D ['Wt Range'] = listwtrange
                    df_050_059_OM_VS2_D ['Company'] = listcom
                    df_050_059_OM_VS2_D ['Shape'] = listshap
                    df_050_059_OM_VS2_D ['Carat'] = listcar
                    df_050_059_OM_VS2_D ['Color'] = listcol
                    df_050_059_OM_VS2_D ['Clarity'] = listclar
                    df_050_059_OM_VS2_D ['Cut'] = listcut
                    df_050_059_OM_VS2_D ['Polish'] = listpol
                    df_050_059_OM_VS2_D ['Symmetry'] = listsym
                    df_050_059_OM_VS2_D ['Ratio'] = listrat
                    df_050_059_OM_VS2_D ['PPC'] = listdesc
                    df_050_059_OM_VS2_D ['Total'] = listtotal
                    df_050_059_OM_VS2_D['Carat'] = df_050_059_OM_VS2_D['Carat'].astype('float64')
                    df_050_059_OM_VS2_D['PPC'] = df_050_059_OM_VS2_D['PPC'].astype('float64')
                    df_050_059_OM_VS2_D['Total'] = df_050_059_OM_VS2_D['Total'].astype('float64')
                    df_050_059_OM_VS2_D['Total'] = df_050_059_OM_VS2_D['Carat'] * df_050_059_OM_VS2_D['PPC']


                elif i=="D" and j == "SI1" and k == "OM":
                    df_050_059_OM_SI1_D = pd.DataFrame()
                    df_050_059_OM_SI1_D ['Wt Range'] = None
                    df_050_059_OM_SI1_D  = df_050_059_OM_SI1_D.assign(Company=None)
                    df_050_059_OM_SI1_D  = df_050_059_OM_SI1_D.assign(Shape=None)
                    df_050_059_OM_SI1_D  = df_050_059_OM_SI1_D.assign(Carat=None)
                    df_050_059_OM_SI1_D  = df_050_059_OM_SI1_D.assign(Color=None)
                    df_050_059_OM_SI1_D  = df_050_059_OM_SI1_D.assign(Clarity=None)
                    df_050_059_OM_SI1_D  = df_050_059_OM_SI1_D.assign(Cut=None)
                    df_050_059_OM_SI1_D  = df_050_059_OM_SI1_D.assign(Polish=None)
                    df_050_059_OM_SI1_D  = df_050_059_OM_SI1_D.assign(Symmetry=None)
                    df_050_059_OM_SI1_D  = df_050_059_OM_SI1_D.assign(Ratio=None)
                    df_050_059_OM_SI1_D  = df_050_059_OM_SI1_D.assign(PPC=None)
                    df_050_059_OM_SI1_D  = df_050_059_OM_SI1_D.assign(Total=None)
                    df_050_059_OM_SI1_D ['Wt Range'] = listwtrange
                    df_050_059_OM_SI1_D ['Company'] = listcom
                    df_050_059_OM_SI1_D ['Shape'] = listshap
                    df_050_059_OM_SI1_D ['Carat'] = listcar
                    df_050_059_OM_SI1_D ['Color'] = listcol
                    df_050_059_OM_SI1_D ['Clarity'] = listclar
                    df_050_059_OM_SI1_D ['Cut'] = listcut
                    df_050_059_OM_SI1_D ['Polish'] = listpol
                    df_050_059_OM_SI1_D ['Symmetry'] = listsym
                    df_050_059_OM_SI1_D ['Ratio'] = listrat
                    df_050_059_OM_SI1_D ['PPC'] = listdesc
                    df_050_059_OM_SI1_D ['Total'] = listtotal
                    df_050_059_OM_SI1_D['Carat'] = df_050_059_OM_SI1_D['Carat'].astype('float64')
                    df_050_059_OM_SI1_D['PPC'] = df_050_059_OM_SI1_D['PPC'].astype('float64')
                    df_050_059_OM_SI1_D['Total'] = df_050_059_OM_SI1_D['Total'].astype('float64')
                    df_050_059_OM_SI1_D['Total'] = df_050_059_OM_SI1_D['Carat'] * df_050_059_OM_SI1_D['PPC']


                elif i=="D" and j == "SI2" and k == "OM":
                    df_050_059_OM_SI2_D = pd.DataFrame()
                    df_050_059_OM_SI2_D ['Wt Range'] = None
                    df_050_059_OM_SI2_D  = df_050_059_OM_SI2_D.assign(Company=None)
                    df_050_059_OM_SI2_D  = df_050_059_OM_SI2_D.assign(Shape=None)
                    df_050_059_OM_SI2_D  = df_050_059_OM_SI2_D.assign(Carat=None)
                    df_050_059_OM_SI2_D  = df_050_059_OM_SI2_D.assign(Color=None)
                    df_050_059_OM_SI2_D  = df_050_059_OM_SI2_D.assign(Clarity=None)
                    df_050_059_OM_SI2_D  = df_050_059_OM_SI2_D.assign(Cut=None)
                    df_050_059_OM_SI2_D  = df_050_059_OM_SI2_D.assign(Polish=None)
                    df_050_059_OM_SI2_D  = df_050_059_OM_SI2_D.assign(Symmetry=None)
                    df_050_059_OM_SI2_D  = df_050_059_OM_SI2_D.assign(Ratio=None)
                    df_050_059_OM_SI2_D  = df_050_059_OM_SI2_D.assign(PPC=None)
                    df_050_059_OM_SI2_D  = df_050_059_OM_SI2_D.assign(Total=None)
                    df_050_059_OM_SI2_D ['Wt Range'] = listwtrange
                    df_050_059_OM_SI2_D ['Company'] = listcom
                    df_050_059_OM_SI2_D ['Shape'] = listshap
                    df_050_059_OM_SI2_D ['Carat'] = listcar
                    df_050_059_OM_SI2_D ['Color'] = listcol
                    df_050_059_OM_SI2_D ['Clarity'] = listclar
                    df_050_059_OM_SI2_D ['Cut'] = listcut
                    df_050_059_OM_SI2_D ['Polish'] = listpol
                    df_050_059_OM_SI2_D ['Symmetry'] = listsym
                    df_050_059_OM_SI2_D ['Ratio'] = listrat
                    df_050_059_OM_SI2_D ['PPC'] = listdesc
                    df_050_059_OM_SI2_D ['Total'] = listtotal
                    df_050_059_OM_SI2_D['Carat'] = df_050_059_OM_SI2_D['Carat'].astype('float64')
                    df_050_059_OM_SI2_D['PPC'] = df_050_059_OM_SI2_D['PPC'].astype('float64')
                    df_050_059_OM_SI2_D['Total'] = df_050_059_OM_SI2_D['Total'].astype('float64')
                    df_050_059_OM_SI2_D['Total'] = df_050_059_OM_SI2_D['Carat'] * df_050_059_OM_SI2_D['PPC']


                elif i=="D" and j == "I1" and k == "OM":
                    df_050_059_OM_I1_D = pd.DataFrame()
                    df_050_059_OM_I1_D ['Wt Range'] = None
                    df_050_059_OM_I1_D  = df_050_059_OM_I1_D.assign(Company=None)
                    df_050_059_OM_I1_D  = df_050_059_OM_I1_D.assign(Shape=None)
                    df_050_059_OM_I1_D  = df_050_059_OM_I1_D.assign(Carat=None)
                    df_050_059_OM_I1_D  = df_050_059_OM_I1_D.assign(Color=None)
                    df_050_059_OM_I1_D  = df_050_059_OM_I1_D.assign(Clarity=None)
                    df_050_059_OM_I1_D  = df_050_059_OM_I1_D.assign(Cut=None)
                    df_050_059_OM_I1_D  = df_050_059_OM_I1_D.assign(Polish=None)
                    df_050_059_OM_I1_D  = df_050_059_OM_I1_D.assign(Symmetry=None)
                    df_050_059_OM_I1_D  = df_050_059_OM_I1_D.assign(Ratio=None)
                    df_050_059_OM_I1_D  = df_050_059_OM_I1_D.assign(PPC=None)
                    df_050_059_OM_I1_D  = df_050_059_OM_I1_D.assign(Total=None)
                    df_050_059_OM_I1_D ['Wt Range'] = listwtrange
                    df_050_059_OM_I1_D ['Company'] = listcom
                    df_050_059_OM_I1_D ['Shape'] = listshap
                    df_050_059_OM_I1_D ['Carat'] = listcar
                    df_050_059_OM_I1_D ['Color'] = listcol
                    df_050_059_OM_I1_D ['Clarity'] = listclar
                    df_050_059_OM_I1_D ['Cut'] = listcut
                    df_050_059_OM_I1_D ['Polish'] = listpol
                    df_050_059_OM_I1_D ['Symmetry'] = listsym
                    df_050_059_OM_I1_D ['Ratio'] = listrat
                    df_050_059_OM_I1_D ['PPC'] = listdesc
                    df_050_059_OM_I1_D ['Total'] = listtotal
                    df_050_059_OM_I1_D['Carat'] = df_050_059_OM_I1_D['Carat'].astype('float64')
                    df_050_059_OM_I1_D['PPC'] = df_050_059_OM_I1_D['PPC'].astype('float64')
                    df_050_059_OM_I1_D['Total'] = df_050_059_OM_I1_D['Total'].astype('float64')
                    df_050_059_OM_I1_D['Total'] = df_050_059_OM_I1_D['Carat'] * df_050_059_OM_I1_D['PPC']


                elif i=="D" and j == "I2" and k == "OM":
                    df_050_059_OM_I2_D = pd.DataFrame()
                    df_050_059_OM_I2_D ['Wt Range'] = None
                    df_050_059_OM_I2_D  = df_050_059_OM_I2_D.assign(Company=None)
                    df_050_059_OM_I2_D  = df_050_059_OM_I2_D.assign(Shape=None)
                    df_050_059_OM_I2_D  = df_050_059_OM_I2_D.assign(Carat=None)
                    df_050_059_OM_I2_D  = df_050_059_OM_I2_D.assign(Color=None)
                    df_050_059_OM_I2_D  = df_050_059_OM_I2_D.assign(Clarity=None)
                    df_050_059_OM_I2_D  = df_050_059_OM_I2_D.assign(Cut=None)
                    df_050_059_OM_I2_D  = df_050_059_OM_I2_D.assign(Polish=None)
                    df_050_059_OM_I2_D  = df_050_059_OM_I2_D.assign(Symmetry=None)
                    df_050_059_OM_I2_D  = df_050_059_OM_I2_D.assign(Ratio=None)
                    df_050_059_OM_I2_D  = df_050_059_OM_I2_D.assign(PPC=None)
                    df_050_059_OM_I2_D  = df_050_059_OM_I2_D.assign(Total=None)
                    df_050_059_OM_I2_D ['Wt Range'] = listwtrange
                    df_050_059_OM_I2_D ['Company'] = listcom
                    df_050_059_OM_I2_D ['Shape'] = listshap
                    df_050_059_OM_I2_D ['Carat'] = listcar
                    df_050_059_OM_I2_D ['Color'] = listcol
                    df_050_059_OM_I2_D ['Clarity'] = listclar
                    df_050_059_OM_I2_D ['Cut'] = listcut
                    df_050_059_OM_I2_D ['Polish'] = listpol
                    df_050_059_OM_I2_D ['Symmetry'] = listsym
                    df_050_059_OM_I2_D ['Ratio'] = listrat
                    df_050_059_OM_I2_D ['PPC'] = listdesc
                    df_050_059_OM_I2_D ['Total'] = listtotal
                    df_050_059_OM_I2_D['Carat'] = df_050_059_OM_I2_D['Carat'].astype('float64')
                    df_050_059_OM_I2_D['PPC'] = df_050_059_OM_I2_D['PPC'].astype('float64')
                    df_050_059_OM_I2_D['Total'] = df_050_059_OM_I2_D['Total'].astype('float64')
                    df_050_059_OM_I2_D['Total'] = df_050_059_OM_I2_D['Carat'] * df_050_059_OM_I2_D['PPC']



                elif i=="E" and j == "IF" and k == "OM":
                    df_050_059_OM_IF_E = pd.DataFrame()
                    df_050_059_OM_IF_E ['Wt Range'] = None
                    df_050_059_OM_IF_E  = df_050_059_OM_IF_E.assign(Company=None)
                    df_050_059_OM_IF_E  = df_050_059_OM_IF_E.assign(Shape=None)
                    df_050_059_OM_IF_E  = df_050_059_OM_IF_E.assign(Carat=None)
                    df_050_059_OM_IF_E  = df_050_059_OM_IF_E.assign(Color=None)
                    df_050_059_OM_IF_E  = df_050_059_OM_IF_E.assign(Clarity=None)
                    df_050_059_OM_IF_E  = df_050_059_OM_IF_E.assign(Cut=None)
                    df_050_059_OM_IF_E  = df_050_059_OM_IF_E.assign(Polish=None)
                    df_050_059_OM_IF_E  = df_050_059_OM_IF_E.assign(Symmetry=None)
                    df_050_059_OM_IF_E  = df_050_059_OM_IF_E.assign(Ratio=None)
                    df_050_059_OM_IF_E  = df_050_059_OM_IF_E.assign(PPC=None)
                    df_050_059_OM_IF_E  = df_050_059_OM_IF_E.assign(Total=None)
                    df_050_059_OM_IF_E ['Wt Range'] = listwtrange
                    df_050_059_OM_IF_E ['Company'] = listcom
                    df_050_059_OM_IF_E ['Shape'] = listshap
                    df_050_059_OM_IF_E ['Carat'] = listcar
                    df_050_059_OM_IF_E ['Color'] = listcol
                    df_050_059_OM_IF_E ['Clarity'] = listclar
                    df_050_059_OM_IF_E ['Cut'] = listcut
                    df_050_059_OM_IF_E ['Polish'] = listpol
                    df_050_059_OM_IF_E ['Symmetry'] = listsym
                    df_050_059_OM_IF_E ['Ratio'] = listrat
                    df_050_059_OM_IF_E ['PPC'] = listdesc
                    df_050_059_OM_IF_E ['Total'] = listtotal
                    df_050_059_OM_IF_E['Carat'] = df_050_059_OM_IF_E['Carat'].astype('float64')
                    df_050_059_OM_IF_E['PPC'] = df_050_059_OM_IF_E['PPC'].astype('float64')
                    df_050_059_OM_IF_E['Total'] = df_050_059_OM_IF_E['Total'].astype('float64')
                    df_050_059_OM_IF_E['Total'] = df_050_059_OM_IF_E['Carat'] * df_050_059_OM_IF_E['PPC']



                elif i=="E" and j == "VVS1" and k == "OM":
                    df_050_059_OM_VVS1_E = pd.DataFrame()
                    df_050_059_OM_VVS1_E ['Wt Range'] = None
                    df_050_059_OM_VVS1_E  = df_050_059_OM_VVS1_E.assign(Company=None)
                    df_050_059_OM_VVS1_E  = df_050_059_OM_VVS1_E.assign(Shape=None)
                    df_050_059_OM_VVS1_E  = df_050_059_OM_VVS1_E.assign(Carat=None)
                    df_050_059_OM_VVS1_E  = df_050_059_OM_VVS1_E.assign(Color=None)
                    df_050_059_OM_VVS1_E  = df_050_059_OM_VVS1_E.assign(Clarity=None)
                    df_050_059_OM_VVS1_E  = df_050_059_OM_VVS1_E.assign(Cut=None)
                    df_050_059_OM_VVS1_E  = df_050_059_OM_VVS1_E.assign(Polish=None)
                    df_050_059_OM_VVS1_E  = df_050_059_OM_VVS1_E.assign(Symmetry=None)
                    df_050_059_OM_VVS1_E  = df_050_059_OM_VVS1_E.assign(Ratio=None)
                    df_050_059_OM_VVS1_E  = df_050_059_OM_VVS1_E.assign(PPC=None)
                    df_050_059_OM_VVS1_E  = df_050_059_OM_VVS1_E.assign(Total=None)
                    df_050_059_OM_VVS1_E ['Wt Range'] = listwtrange
                    df_050_059_OM_VVS1_E ['Company'] = listcom
                    df_050_059_OM_VVS1_E ['Shape'] = listshap
                    df_050_059_OM_VVS1_E ['Carat'] = listcar
                    df_050_059_OM_VVS1_E ['Color'] = listcol
                    df_050_059_OM_VVS1_E ['Clarity'] = listclar
                    df_050_059_OM_VVS1_E ['Cut'] = listcut
                    df_050_059_OM_VVS1_E ['Polish'] = listpol
                    df_050_059_OM_VVS1_E ['Symmetry'] = listsym
                    df_050_059_OM_VVS1_E ['Ratio'] = listrat
                    df_050_059_OM_VVS1_E ['PPC'] = listdesc
                    df_050_059_OM_VVS1_E ['Total'] = listtotal
                    df_050_059_OM_VVS1_E['Carat'] = df_050_059_OM_VVS1_E['Carat'].astype('float64')
                    df_050_059_OM_VVS1_E['PPC'] = df_050_059_OM_VVS1_E['PPC'].astype('float64')
                    df_050_059_OM_VVS1_E['Total'] = df_050_059_OM_VVS1_E['Total'].astype('float64')
                    df_050_059_OM_VVS1_E['Total'] = df_050_059_OM_VVS1_E['Carat'] * df_050_059_OM_VVS1_E['PPC']


                elif i=="E" and j == "VVS2" and k == "OM":
                    df_050_059_OM_VVS2_E = pd.DataFrame()
                    df_050_059_OM_VVS2_E ['Wt Range'] = None
                    df_050_059_OM_VVS2_E  = df_050_059_OM_VVS2_E.assign(Company=None)
                    df_050_059_OM_VVS2_E  = df_050_059_OM_VVS2_E.assign(Shape=None)
                    df_050_059_OM_VVS2_E  = df_050_059_OM_VVS2_E.assign(Carat=None)
                    df_050_059_OM_VVS2_E  = df_050_059_OM_VVS2_E.assign(Color=None)
                    df_050_059_OM_VVS2_E  = df_050_059_OM_VVS2_E.assign(Clarity=None)
                    df_050_059_OM_VVS2_E  = df_050_059_OM_VVS2_E.assign(Cut=None)
                    df_050_059_OM_VVS2_E  = df_050_059_OM_VVS2_E.assign(Polish=None)
                    df_050_059_OM_VVS2_E  = df_050_059_OM_VVS2_E.assign(Symmetry=None)
                    df_050_059_OM_VVS2_E  = df_050_059_OM_VVS2_E.assign(Ratio=None)
                    df_050_059_OM_VVS2_E  = df_050_059_OM_VVS2_E.assign(PPC=None)
                    df_050_059_OM_VVS2_E  = df_050_059_OM_VVS2_E.assign(Total=None)
                    df_050_059_OM_VVS2_E ['Wt Range'] = listwtrange
                    df_050_059_OM_VVS2_E ['Company'] = listcom
                    df_050_059_OM_VVS2_E ['Shape'] = listshap
                    df_050_059_OM_VVS2_E ['Carat'] = listcar
                    df_050_059_OM_VVS2_E ['Color'] = listcol
                    df_050_059_OM_VVS2_E ['Clarity'] = listclar
                    df_050_059_OM_VVS2_E ['Cut'] = listcut
                    df_050_059_OM_VVS2_E ['Polish'] = listpol
                    df_050_059_OM_VVS2_E ['Symmetry'] = listsym
                    df_050_059_OM_VVS2_E ['Ratio'] = listrat
                    df_050_059_OM_VVS2_E ['PPC'] = listdesc
                    df_050_059_OM_VVS2_E ['Total'] = listtotal
                    df_050_059_OM_VVS2_E['Carat'] = df_050_059_OM_VVS2_E['Carat'].astype('float64')
                    df_050_059_OM_VVS2_E['PPC'] = df_050_059_OM_VVS2_E['PPC'].astype('float64')
                    df_050_059_OM_VVS2_E['Total'] = df_050_059_OM_VVS2_E['Total'].astype('float64')
                    df_050_059_OM_VVS2_E['Total'] = df_050_059_OM_VVS2_E['Carat'] * df_050_059_OM_VVS2_E['PPC']


                elif i=="E" and j=="VS1" and k == "OM":
                    df_050_059_OM_VS1_E = pd.DataFrame()
                    df_050_059_OM_VS1_E ['Wt Range'] = None
                    df_050_059_OM_VS1_E  = df_050_059_OM_VS1_E.assign(Company=None)
                    df_050_059_OM_VS1_E  = df_050_059_OM_VS1_E.assign(Shape=None)
                    df_050_059_OM_VS1_E  = df_050_059_OM_VS1_E.assign(Carat=None)
                    df_050_059_OM_VS1_E  = df_050_059_OM_VS1_E.assign(Color=None)
                    df_050_059_OM_VS1_E  = df_050_059_OM_VS1_E.assign(Clarity=None)
                    df_050_059_OM_VS1_E  = df_050_059_OM_VS1_E.assign(Cut=None)
                    df_050_059_OM_VS1_E  = df_050_059_OM_VS1_E.assign(Polish=None)
                    df_050_059_OM_VS1_E  = df_050_059_OM_VS1_E.assign(Symmetry=None)
                    df_050_059_OM_VS1_E  = df_050_059_OM_VS1_E.assign(Ratio=None)
                    df_050_059_OM_VS1_E  = df_050_059_OM_VS1_E.assign(PPC=None)
                    df_050_059_OM_VS1_E  = df_050_059_OM_VS1_E.assign(Total=None)
                    df_050_059_OM_VS1_E ['Wt Range'] = listwtrange
                    df_050_059_OM_VS1_E ['Company'] = listcom
                    df_050_059_OM_VS1_E ['Shape'] = listshap
                    df_050_059_OM_VS1_E ['Carat'] = listcar
                    df_050_059_OM_VS1_E ['Color'] = listcol
                    df_050_059_OM_VS1_E ['Clarity'] = listclar
                    df_050_059_OM_VS1_E ['Cut'] = listcut
                    df_050_059_OM_VS1_E ['Polish'] = listpol
                    df_050_059_OM_VS1_E ['Symmetry'] = listsym
                    df_050_059_OM_VS1_E ['Ratio'] = listrat
                    df_050_059_OM_VS1_E ['PPC'] = listdesc
                    df_050_059_OM_VS1_E ['Total'] = listtotal
                    df_050_059_OM_VS1_E['Carat'] = df_050_059_OM_VS1_E['Carat'].astype('float64')
                    df_050_059_OM_VS1_E['PPC'] = df_050_059_OM_VS1_E['PPC'].astype('float64')
                    df_050_059_OM_VS1_E['Total'] = df_050_059_OM_VS1_E['Total'].astype('float64')
                    df_050_059_OM_VS1_E['Total'] = df_050_059_OM_VS1_E['Carat'] * df_050_059_OM_VS1_E['PPC']


                elif i=="E" and j == "VS2" and k == "OM":
                    df_050_059_OM_VS2_E = pd.DataFrame()
                    df_050_059_OM_VS2_E ['Wt Range'] = None
                    df_050_059_OM_VS2_E  = df_050_059_OM_VS2_E.assign(Company=None)
                    df_050_059_OM_VS2_E  = df_050_059_OM_VS2_E.assign(Shape=None)
                    df_050_059_OM_VS2_E  = df_050_059_OM_VS2_E.assign(Carat=None)
                    df_050_059_OM_VS2_E  = df_050_059_OM_VS2_E.assign(Color=None)
                    df_050_059_OM_VS2_E  = df_050_059_OM_VS2_E.assign(Clarity=None)
                    df_050_059_OM_VS2_E  = df_050_059_OM_VS2_E.assign(Cut=None)
                    df_050_059_OM_VS2_E  = df_050_059_OM_VS2_E.assign(Polish=None)
                    df_050_059_OM_VS2_E  = df_050_059_OM_VS2_E.assign(Symmetry=None)
                    df_050_059_OM_VS2_E  = df_050_059_OM_VS2_E.assign(Ratio=None)
                    df_050_059_OM_VS2_E  = df_050_059_OM_VS2_E.assign(PPC=None)
                    df_050_059_OM_VS2_E  = df_050_059_OM_VS2_E.assign(Total=None)
                    df_050_059_OM_VS2_E ['Wt Range'] = listwtrange
                    df_050_059_OM_VS2_E ['Company'] = listcom
                    df_050_059_OM_VS2_E ['Shape'] = listshap
                    df_050_059_OM_VS2_E ['Carat'] = listcar
                    df_050_059_OM_VS2_E ['Color'] = listcol
                    df_050_059_OM_VS2_E ['Clarity'] = listclar
                    df_050_059_OM_VS2_E ['Cut'] = listcut
                    df_050_059_OM_VS2_E ['Polish'] = listpol
                    df_050_059_OM_VS2_E ['Symmetry'] = listsym
                    df_050_059_OM_VS2_E ['Ratio'] = listrat
                    df_050_059_OM_VS2_E ['PPC'] = listdesc
                    df_050_059_OM_VS2_E ['Total'] = listtotal
                    df_050_059_OM_VS2_E['Carat'] = df_050_059_OM_VS2_E['Carat'].astype('float64')
                    df_050_059_OM_VS2_E['PPC'] = df_050_059_OM_VS2_E['PPC'].astype('float64')
                    df_050_059_OM_VS2_E['Total'] = df_050_059_OM_VS2_E['Total'].astype('float64')
                    df_050_059_OM_VS2_E['Total'] = df_050_059_OM_VS2_E['Carat'] * df_050_059_OM_VS2_E['PPC']


                elif i=="E" and j == "SI1" and k == "OM":
                    df_050_059_OM_SI1_E = pd.DataFrame()
                    df_050_059_OM_SI1_E ['Wt Range'] = None
                    df_050_059_OM_SI1_E  = df_050_059_OM_SI1_E.assign(Company=None)
                    df_050_059_OM_SI1_E  = df_050_059_OM_SI1_E.assign(Shape=None)
                    df_050_059_OM_SI1_E  = df_050_059_OM_SI1_E.assign(Carat=None)
                    df_050_059_OM_SI1_E  = df_050_059_OM_SI1_E.assign(Color=None)
                    df_050_059_OM_SI1_E  = df_050_059_OM_SI1_E.assign(Clarity=None)
                    df_050_059_OM_SI1_E  = df_050_059_OM_SI1_E.assign(Cut=None)
                    df_050_059_OM_SI1_E  = df_050_059_OM_SI1_E.assign(Polish=None)
                    df_050_059_OM_SI1_E  = df_050_059_OM_SI1_E.assign(Symmetry=None)
                    df_050_059_OM_SI1_E  = df_050_059_OM_SI1_E.assign(Ratio=None)
                    df_050_059_OM_SI1_E  = df_050_059_OM_SI1_E.assign(PPC=None)
                    df_050_059_OM_SI1_E  = df_050_059_OM_SI1_E.assign(Total=None)
                    df_050_059_OM_SI1_E ['Wt Range'] = listwtrange
                    df_050_059_OM_SI1_E ['Company'] = listcom
                    df_050_059_OM_SI1_E ['Shape'] = listshap
                    df_050_059_OM_SI1_E ['Carat'] = listcar
                    df_050_059_OM_SI1_E ['Color'] = listcol
                    df_050_059_OM_SI1_E ['Clarity'] = listclar
                    df_050_059_OM_SI1_E ['Cut'] = listcut
                    df_050_059_OM_SI1_E ['Polish'] = listpol
                    df_050_059_OM_SI1_E ['Symmetry'] = listsym
                    df_050_059_OM_SI1_E ['Ratio'] = listrat
                    df_050_059_OM_SI1_E ['PPC'] = listdesc
                    df_050_059_OM_SI1_E ['Total'] = listtotal
                    df_050_059_OM_SI1_E['Carat'] = df_050_059_OM_SI1_E['Carat'].astype('float64')
                    df_050_059_OM_SI1_E['PPC'] = df_050_059_OM_SI1_E['PPC'].astype('float64')
                    df_050_059_OM_SI1_E['Total'] = df_050_059_OM_SI1_E['Total'].astype('float64')
                    df_050_059_OM_SI1_E['Total'] = df_050_059_OM_SI1_E['Carat'] * df_050_059_OM_SI1_E['PPC']


                elif i=="E" and j == "SI2" and k == "OM":
                    df_050_059_OM_SI2_E = pd.DataFrame()
                    df_050_059_OM_SI2_E ['Wt Range'] = None
                    df_050_059_OM_SI2_E  = df_050_059_OM_SI2_E.assign(Company=None)
                    df_050_059_OM_SI2_E  = df_050_059_OM_SI2_E.assign(Shape=None)
                    df_050_059_OM_SI2_E  = df_050_059_OM_SI2_E.assign(Carat=None)
                    df_050_059_OM_SI2_E  = df_050_059_OM_SI2_E.assign(Color=None)
                    df_050_059_OM_SI2_E  = df_050_059_OM_SI2_E.assign(Clarity=None)
                    df_050_059_OM_SI2_E  = df_050_059_OM_SI2_E.assign(Cut=None)
                    df_050_059_OM_SI2_E  = df_050_059_OM_SI2_E.assign(Polish=None)
                    df_050_059_OM_SI2_E  = df_050_059_OM_SI2_E.assign(Symmetry=None)
                    df_050_059_OM_SI2_E  = df_050_059_OM_SI2_E.assign(Ratio=None)
                    df_050_059_OM_SI2_E  = df_050_059_OM_SI2_E.assign(PPC=None)
                    df_050_059_OM_SI2_E  = df_050_059_OM_SI2_E.assign(Total=None)
                    df_050_059_OM_SI2_E ['Wt Range'] = listwtrange
                    df_050_059_OM_SI2_E ['Company'] = listcom
                    df_050_059_OM_SI2_E ['Shape'] = listshap
                    df_050_059_OM_SI2_E ['Carat'] = listcar
                    df_050_059_OM_SI2_E ['Color'] = listcol
                    df_050_059_OM_SI2_E ['Clarity'] = listclar
                    df_050_059_OM_SI2_E ['Cut'] = listcut
                    df_050_059_OM_SI2_E ['Polish'] = listpol
                    df_050_059_OM_SI2_E ['Symmetry'] = listsym
                    df_050_059_OM_SI2_E ['Ratio'] = listrat
                    df_050_059_OM_SI2_E ['PPC'] = listdesc
                    df_050_059_OM_SI2_E ['Total'] = listtotal
                    df_050_059_OM_SI2_E['Carat'] = df_050_059_OM_SI2_E['Carat'].astype('float64')
                    df_050_059_OM_SI2_E['PPC'] = df_050_059_OM_SI2_E['PPC'].astype('float64')
                    df_050_059_OM_SI2_E['Total'] = df_050_059_OM_SI2_E['Total'].astype('float64')
                    df_050_059_OM_SI2_E['Total'] = df_050_059_OM_SI2_E['Carat'] * df_050_059_OM_SI2_E['PPC']


                elif i=="E" and j == "I1" and k == "OM":
                    df_050_059_OM_I1_E = pd.DataFrame()
                    df_050_059_OM_I1_E ['Wt Range'] = None
                    df_050_059_OM_I1_E  = df_050_059_OM_I1_E.assign(Company=None)
                    df_050_059_OM_I1_E  = df_050_059_OM_I1_E.assign(Shape=None)
                    df_050_059_OM_I1_E  = df_050_059_OM_I1_E.assign(Carat=None)
                    df_050_059_OM_I1_E  = df_050_059_OM_I1_E.assign(Color=None)
                    df_050_059_OM_I1_E  = df_050_059_OM_I1_E.assign(Clarity=None)
                    df_050_059_OM_I1_E  = df_050_059_OM_I1_E.assign(Cut=None)
                    df_050_059_OM_I1_E  = df_050_059_OM_I1_E.assign(Polish=None)
                    df_050_059_OM_I1_E  = df_050_059_OM_I1_E.assign(Symmetry=None)
                    df_050_059_OM_I1_E  = df_050_059_OM_I1_E.assign(Ratio=None)
                    df_050_059_OM_I1_E  = df_050_059_OM_I1_E.assign(PPC=None)
                    df_050_059_OM_I1_E  = df_050_059_OM_I1_E.assign(Total=None)
                    df_050_059_OM_I1_E ['Wt Range'] = listwtrange
                    df_050_059_OM_I1_E ['Company'] = listcom
                    df_050_059_OM_I1_E ['Shape'] = listshap
                    df_050_059_OM_I1_E ['Carat'] = listcar
                    df_050_059_OM_I1_E ['Color'] = listcol
                    df_050_059_OM_I1_E ['Clarity'] = listclar
                    df_050_059_OM_I1_E ['Cut'] = listcut
                    df_050_059_OM_I1_E ['Polish'] = listpol
                    df_050_059_OM_I1_E ['Symmetry'] = listsym
                    df_050_059_OM_I1_E ['Ratio'] = listrat
                    df_050_059_OM_I1_E ['PPC'] = listdesc
                    df_050_059_OM_I1_E ['Total'] = listtotal
                    df_050_059_OM_I1_E['Carat'] = df_050_059_OM_I1_E['Carat'].astype('float64')
                    df_050_059_OM_I1_E['PPC'] = df_050_059_OM_I1_E['PPC'].astype('float64')
                    df_050_059_OM_I1_E['Total'] = df_050_059_OM_I1_E['Total'].astype('float64')
                    df_050_059_OM_I1_E['Total'] = df_050_059_OM_I1_E['Carat'] * df_050_059_OM_I1_E['PPC']


                elif i=="E" and j == "I2" and k == "OM":
                    df_050_059_OM_I2_E = pd.DataFrame()
                    df_050_059_OM_I2_E ['Wt Range'] = None
                    df_050_059_OM_I2_E  = df_050_059_OM_I2_E.assign(Company=None)
                    df_050_059_OM_I2_E  = df_050_059_OM_I2_E.assign(Shape=None)
                    df_050_059_OM_I2_E  = df_050_059_OM_I2_E.assign(Carat=None)
                    df_050_059_OM_I2_E  = df_050_059_OM_I2_E.assign(Color=None)
                    df_050_059_OM_I2_E  = df_050_059_OM_I2_E.assign(Clarity=None)
                    df_050_059_OM_I2_E  = df_050_059_OM_I2_E.assign(Cut=None)
                    df_050_059_OM_I2_E  = df_050_059_OM_I2_E.assign(Polish=None)
                    df_050_059_OM_I2_E  = df_050_059_OM_I2_E.assign(Symmetry=None)
                    df_050_059_OM_I2_E  = df_050_059_OM_I2_E.assign(Ratio=None)
                    df_050_059_OM_I2_E  = df_050_059_OM_I2_E.assign(PPC=None)
                    df_050_059_OM_I2_E  = df_050_059_OM_I2_E.assign(Total=None)
                    df_050_059_OM_I2_E ['Wt Range'] = listwtrange
                    df_050_059_OM_I2_E ['Company'] = listcom
                    df_050_059_OM_I2_E ['Shape'] = listshap
                    df_050_059_OM_I2_E ['Carat'] = listcar
                    df_050_059_OM_I2_E ['Color'] = listcol
                    df_050_059_OM_I2_E ['Clarity'] = listclar
                    df_050_059_OM_I2_E ['Cut'] = listcut
                    df_050_059_OM_I2_E ['Polish'] = listpol
                    df_050_059_OM_I2_E ['Symmetry'] = listsym
                    df_050_059_OM_I2_E ['Ratio'] = listrat
                    df_050_059_OM_I2_E ['PPC'] = listdesc
                    df_050_059_OM_I2_E ['Total'] = listtotal
                    df_050_059_OM_I2_E['Carat'] = df_050_059_OM_I2_E['Carat'].astype('float64')
                    df_050_059_OM_I2_E['PPC'] = df_050_059_OM_I2_E['PPC'].astype('float64')
                    df_050_059_OM_I2_E['Total'] = df_050_059_OM_I2_E['Total'].astype('float64')
                    df_050_059_OM_I2_E['Total'] = df_050_059_OM_I2_E['Carat'] * df_050_059_OM_I2_E['PPC']
                
                elif i=="F" and j == "IF" and k == "OM":
                    df_050_059_OM_IF_F = pd.DataFrame()
                    df_050_059_OM_IF_F ['Wt Range'] = None
                    df_050_059_OM_IF_F  = df_050_059_OM_IF_F.assign(Company=None)
                    df_050_059_OM_IF_F  = df_050_059_OM_IF_F.assign(Shape=None)
                    df_050_059_OM_IF_F  = df_050_059_OM_IF_F.assign(Carat=None)
                    df_050_059_OM_IF_F  = df_050_059_OM_IF_F.assign(Color=None)
                    df_050_059_OM_IF_F  = df_050_059_OM_IF_F.assign(Clarity=None)
                    df_050_059_OM_IF_F  = df_050_059_OM_IF_F.assign(Cut=None)
                    df_050_059_OM_IF_F  = df_050_059_OM_IF_F.assign(Polish=None)
                    df_050_059_OM_IF_F  = df_050_059_OM_IF_F.assign(Symmetry=None)
                    df_050_059_OM_IF_F  = df_050_059_OM_IF_F.assign(Ratio=None)
                    df_050_059_OM_IF_F  = df_050_059_OM_IF_F.assign(PPC=None)
                    df_050_059_OM_IF_F  = df_050_059_OM_IF_F.assign(Total=None)
                    df_050_059_OM_IF_F ['Wt Range'] = listwtrange
                    df_050_059_OM_IF_F ['Company'] = listcom
                    df_050_059_OM_IF_F ['Shape'] = listshap
                    df_050_059_OM_IF_F ['Carat'] = listcar
                    df_050_059_OM_IF_F ['Color'] = listcol
                    df_050_059_OM_IF_F ['Clarity'] = listclar
                    df_050_059_OM_IF_F ['Cut'] = listcut
                    df_050_059_OM_IF_F ['Polish'] = listpol
                    df_050_059_OM_IF_F ['Symmetry'] = listsym
                    df_050_059_OM_IF_F ['Ratio'] = listrat
                    df_050_059_OM_IF_F ['PPC'] = listdesc
                    df_050_059_OM_IF_F ['Total'] = listtotal
                    df_050_059_OM_IF_F['Carat'] = df_050_059_OM_IF_F['Carat'].astype('float64')
                    df_050_059_OM_IF_F['PPC'] = df_050_059_OM_IF_F['PPC'].astype('float64')
                    df_050_059_OM_IF_F['Total'] = df_050_059_OM_IF_F['Total'].astype('float64')
                    df_050_059_OM_IF_F['Total'] = df_050_059_OM_IF_F['Carat'] * df_050_059_OM_IF_F['PPC']



                elif i=="F" and j == "VVS1" and k == "OM":
                    df_050_059_OM_VVS1_F = pd.DataFrame()
                    df_050_059_OM_VVS1_F ['Wt Range'] = None
                    df_050_059_OM_VVS1_F  = df_050_059_OM_VVS1_F.assign(Company=None)
                    df_050_059_OM_VVS1_F  = df_050_059_OM_VVS1_F.assign(Shape=None)
                    df_050_059_OM_VVS1_F  = df_050_059_OM_VVS1_F.assign(Carat=None)
                    df_050_059_OM_VVS1_F  = df_050_059_OM_VVS1_F.assign(Color=None)
                    df_050_059_OM_VVS1_F  = df_050_059_OM_VVS1_F.assign(Clarity=None)
                    df_050_059_OM_VVS1_F  = df_050_059_OM_VVS1_F.assign(Cut=None)
                    df_050_059_OM_VVS1_F  = df_050_059_OM_VVS1_F.assign(Polish=None)
                    df_050_059_OM_VVS1_F  = df_050_059_OM_VVS1_F.assign(Symmetry=None)
                    df_050_059_OM_VVS1_F  = df_050_059_OM_VVS1_F.assign(Ratio=None)
                    df_050_059_OM_VVS1_F  = df_050_059_OM_VVS1_F.assign(PPC=None)
                    df_050_059_OM_VVS1_F  = df_050_059_OM_VVS1_F.assign(Total=None)
                    df_050_059_OM_VVS1_F ['Wt Range'] = listwtrange
                    df_050_059_OM_VVS1_F ['Company'] = listcom
                    df_050_059_OM_VVS1_F ['Shape'] = listshap
                    df_050_059_OM_VVS1_F ['Carat'] = listcar
                    df_050_059_OM_VVS1_F ['Color'] = listcol
                    df_050_059_OM_VVS1_F ['Clarity'] = listclar
                    df_050_059_OM_VVS1_F ['Cut'] = listcut
                    df_050_059_OM_VVS1_F ['Polish'] = listpol
                    df_050_059_OM_VVS1_F ['Symmetry'] = listsym
                    df_050_059_OM_VVS1_F ['Ratio'] = listrat
                    df_050_059_OM_VVS1_F ['PPC'] = listdesc
                    df_050_059_OM_VVS1_F ['Total'] = listtotal
                    df_050_059_OM_VVS1_F['Carat'] = df_050_059_OM_VVS1_F['Carat'].astype('float64')
                    df_050_059_OM_VVS1_F['PPC'] = df_050_059_OM_VVS1_F['PPC'].astype('float64')
                    df_050_059_OM_VVS1_F['Total'] = df_050_059_OM_VVS1_F['Total'].astype('float64')
                    df_050_059_OM_VVS1_F['Total'] = df_050_059_OM_VVS1_F['Carat'] * df_050_059_OM_VVS1_F['PPC']


                elif i=="F" and j == "VVS2" and k == "OM""OM":
                    df_050_059_OM_VVS2_F = pd.DataFrame()
                    df_050_059_OM_VVS2_F ['Wt Range'] = None
                    df_050_059_OM_VVS2_F  = df_050_059_OM_VVS2_F.assign(Company=None)
                    df_050_059_OM_VVS2_F  = df_050_059_OM_VVS2_F.assign(Shape=None)
                    df_050_059_OM_VVS2_F  = df_050_059_OM_VVS2_F.assign(Carat=None)
                    df_050_059_OM_VVS2_F  = df_050_059_OM_VVS2_F.assign(Color=None)
                    df_050_059_OM_VVS2_F  = df_050_059_OM_VVS2_F.assign(Clarity=None)
                    df_050_059_OM_VVS2_F  = df_050_059_OM_VVS2_F.assign(Cut=None)
                    df_050_059_OM_VVS2_F  = df_050_059_OM_VVS2_F.assign(Polish=None)
                    df_050_059_OM_VVS2_F  = df_050_059_OM_VVS2_F.assign(Symmetry=None)
                    df_050_059_OM_VVS2_F  = df_050_059_OM_VVS2_F.assign(Ratio=None)
                    df_050_059_OM_VVS2_F  = df_050_059_OM_VVS2_F.assign(PPC=None)
                    df_050_059_OM_VVS2_F  = df_050_059_OM_VVS2_F.assign(Total=None)
                    df_050_059_OM_VVS2_F ['Wt Range'] = listwtrange
                    df_050_059_OM_VVS2_F ['Company'] = listcom
                    df_050_059_OM_VVS2_F ['Shape'] = listshap
                    df_050_059_OM_VVS2_F ['Carat'] = listcar
                    df_050_059_OM_VVS2_F ['Color'] = listcol
                    df_050_059_OM_VVS2_F ['Clarity'] = listclar
                    df_050_059_OM_VVS2_F ['Cut'] = listcut
                    df_050_059_OM_VVS2_F ['Polish'] = listpol
                    df_050_059_OM_VVS2_F ['Symmetry'] = listsym
                    df_050_059_OM_VVS2_F ['Ratio'] = listrat
                    df_050_059_OM_VVS2_F ['PPC'] = listdesc
                    df_050_059_OM_VVS2_F ['Total'] = listtotal
                    df_050_059_OM_VVS2_F['Carat'] = df_050_059_OM_VVS2_F['Carat'].astype('float64')
                    df_050_059_OM_VVS2_F['PPC'] = df_050_059_OM_VVS2_F['PPC'].astype('float64')
                    df_050_059_OM_VVS2_F['Total'] = df_050_059_OM_VVS2_F['Total'].astype('float64')
                    df_050_059_OM_VVS2_F['Total'] = df_050_059_OM_VVS2_F['Carat'] * df_050_059_OM_VVS2_F['PPC']


                elif i=="F" and j=="VS1" and k == "OM":
                    df_050_059_OM_VS1_F = pd.DataFrame()
                    df_050_059_OM_VS1_F ['Wt Range'] = None
                    df_050_059_OM_VS1_F  = df_050_059_OM_VS1_F.assign(Company=None)
                    df_050_059_OM_VS1_F  = df_050_059_OM_VS1_F.assign(Shape=None)
                    df_050_059_OM_VS1_F  = df_050_059_OM_VS1_F.assign(Carat=None)
                    df_050_059_OM_VS1_F  = df_050_059_OM_VS1_F.assign(Color=None)
                    df_050_059_OM_VS1_F  = df_050_059_OM_VS1_F.assign(Clarity=None)
                    df_050_059_OM_VS1_F  = df_050_059_OM_VS1_F.assign(Cut=None)
                    df_050_059_OM_VS1_F  = df_050_059_OM_VS1_F.assign(Polish=None)
                    df_050_059_OM_VS1_F  = df_050_059_OM_VS1_F.assign(Symmetry=None)
                    df_050_059_OM_VS1_F  = df_050_059_OM_VS1_F.assign(Ratio=None)
                    df_050_059_OM_VS1_F  = df_050_059_OM_VS1_F.assign(PPC=None)
                    df_050_059_OM_VS1_F  = df_050_059_OM_VS1_F.assign(Total=None)
                    df_050_059_OM_VS1_F ['Wt Range'] = listwtrange
                    df_050_059_OM_VS1_F ['Company'] = listcom
                    df_050_059_OM_VS1_F ['Shape'] = listshap
                    df_050_059_OM_VS1_F ['Carat'] = listcar
                    df_050_059_OM_VS1_F ['Color'] = listcol
                    df_050_059_OM_VS1_F ['Clarity'] = listclar
                    df_050_059_OM_VS1_F ['Cut'] = listcut
                    df_050_059_OM_VS1_F ['Polish'] = listpol
                    df_050_059_OM_VS1_F ['Symmetry'] = listsym
                    df_050_059_OM_VS1_F ['Ratio'] = listrat
                    df_050_059_OM_VS1_F ['PPC'] = listdesc
                    df_050_059_OM_VS1_F ['Total'] = listtotal
                    df_050_059_OM_VS1_F['Carat'] = df_050_059_OM_VS1_F['Carat'].astype('float64')
                    df_050_059_OM_VS1_F['PPC'] = df_050_059_OM_VS1_F['PPC'].astype('float64')
                    df_050_059_OM_VS1_F['Total'] = df_050_059_OM_VS1_F['Total'].astype('float64')
                    df_050_059_OM_VS1_F['Total'] = df_050_059_OM_VS1_F['Carat'] * df_050_059_OM_VS1_F['PPC']


                elif i=="F" and j == "VS2" and k == "OM":
                    df_050_059_OM_VS2_F = pd.DataFrame()
                    df_050_059_OM_VS2_F ['Wt Range'] = None
                    df_050_059_OM_VS2_F  = df_050_059_OM_VS2_F.assign(Company=None)
                    df_050_059_OM_VS2_F  = df_050_059_OM_VS2_F.assign(Shape=None)
                    df_050_059_OM_VS2_F  = df_050_059_OM_VS2_F.assign(Carat=None)
                    df_050_059_OM_VS2_F  = df_050_059_OM_VS2_F.assign(Color=None)
                    df_050_059_OM_VS2_F  = df_050_059_OM_VS2_F.assign(Clarity=None)
                    df_050_059_OM_VS2_F  = df_050_059_OM_VS2_F.assign(Cut=None)
                    df_050_059_OM_VS2_F  = df_050_059_OM_VS2_F.assign(Polish=None)
                    df_050_059_OM_VS2_F  = df_050_059_OM_VS2_F.assign(Symmetry=None)
                    df_050_059_OM_VS2_F  = df_050_059_OM_VS2_F.assign(Ratio=None)
                    df_050_059_OM_VS2_F  = df_050_059_OM_VS2_F.assign(PPC=None)
                    df_050_059_OM_VS2_F  = df_050_059_OM_VS2_F.assign(Total=None)
                    df_050_059_OM_VS2_F ['Wt Range'] = listwtrange
                    df_050_059_OM_VS2_F ['Company'] = listcom
                    df_050_059_OM_VS2_F ['Shape'] = listshap
                    df_050_059_OM_VS2_F ['Carat'] = listcar
                    df_050_059_OM_VS2_F ['Color'] = listcol
                    df_050_059_OM_VS2_F ['Clarity'] = listclar
                    df_050_059_OM_VS2_F ['Cut'] = listcut
                    df_050_059_OM_VS2_F ['Polish'] = listpol
                    df_050_059_OM_VS2_F ['Symmetry'] = listsym
                    df_050_059_OM_VS2_F ['Ratio'] = listrat
                    df_050_059_OM_VS2_F ['PPC'] = listdesc
                    df_050_059_OM_VS2_F ['Total'] = listtotal
                    df_050_059_OM_VS2_F['Carat'] = df_050_059_OM_VS2_F['Carat'].astype('float64')
                    df_050_059_OM_VS2_F['PPC'] = df_050_059_OM_VS2_F['PPC'].astype('float64')
                    df_050_059_OM_VS2_F['Total'] = df_050_059_OM_VS2_F['Total'].astype('float64')
                    df_050_059_OM_VS2_F['Total'] = df_050_059_OM_VS2_F['Carat'] * df_050_059_OM_VS2_F['PPC']


                elif i=="F" and j == "SI1" and k == "OM":
                    df_050_059_OM_SI1_F = pd.DataFrame()
                    df_050_059_OM_SI1_F ['Wt Range'] = None
                    df_050_059_OM_SI1_F  = df_050_059_OM_SI1_F.assign(Company=None)
                    df_050_059_OM_SI1_F  = df_050_059_OM_SI1_F.assign(Shape=None)
                    df_050_059_OM_SI1_F  = df_050_059_OM_SI1_F.assign(Carat=None)
                    df_050_059_OM_SI1_F  = df_050_059_OM_SI1_F.assign(Color=None)
                    df_050_059_OM_SI1_F  = df_050_059_OM_SI1_F.assign(Clarity=None)
                    df_050_059_OM_SI1_F  = df_050_059_OM_SI1_F.assign(Cut=None)
                    df_050_059_OM_SI1_F  = df_050_059_OM_SI1_F.assign(Polish=None)
                    df_050_059_OM_SI1_F  = df_050_059_OM_SI1_F.assign(Symmetry=None)
                    df_050_059_OM_SI1_F  = df_050_059_OM_SI1_F.assign(Ratio=None)
                    df_050_059_OM_SI1_F  = df_050_059_OM_SI1_F.assign(PPC=None)
                    df_050_059_OM_SI1_F  = df_050_059_OM_SI1_F.assign(Total=None)
                    df_050_059_OM_SI1_F ['Wt Range'] = listwtrange
                    df_050_059_OM_SI1_F ['Company'] = listcom
                    df_050_059_OM_SI1_F ['Shape'] = listshap
                    df_050_059_OM_SI1_F ['Carat'] = listcar
                    df_050_059_OM_SI1_F ['Color'] = listcol
                    df_050_059_OM_SI1_F ['Clarity'] = listclar
                    df_050_059_OM_SI1_F ['Cut'] = listcut
                    df_050_059_OM_SI1_F ['Polish'] = listpol
                    df_050_059_OM_SI1_F ['Symmetry'] = listsym
                    df_050_059_OM_SI1_F ['Ratio'] = listrat
                    df_050_059_OM_SI1_F ['PPC'] = listdesc
                    df_050_059_OM_SI1_F ['Total'] = listtotal
                    df_050_059_OM_SI1_F['Carat'] = df_050_059_OM_SI1_F['Carat'].astype('float64')
                    df_050_059_OM_SI1_F['PPC'] = df_050_059_OM_SI1_F['PPC'].astype('float64')
                    df_050_059_OM_SI1_F['Total'] = df_050_059_OM_SI1_F['Total'].astype('float64')
                    df_050_059_OM_SI1_F['Total'] = df_050_059_OM_SI1_F['Carat'] * df_050_059_OM_SI1_F['PPC']


                elif i=="F" and j == "SI2" and k == "OM":
                    df_050_059_OM_SI2_F = pd.DataFrame()
                    df_050_059_OM_SI2_F ['Wt Range'] = None
                    df_050_059_OM_SI2_F  = df_050_059_OM_SI2_F.assign(Company=None)
                    df_050_059_OM_SI2_F  = df_050_059_OM_SI2_F.assign(Shape=None)
                    df_050_059_OM_SI2_F  = df_050_059_OM_SI2_F.assign(Carat=None)
                    df_050_059_OM_SI2_F  = df_050_059_OM_SI2_F.assign(Color=None)
                    df_050_059_OM_SI2_F  = df_050_059_OM_SI2_F.assign(Clarity=None)
                    df_050_059_OM_SI2_F  = df_050_059_OM_SI2_F.assign(Cut=None)
                    df_050_059_OM_SI2_F  = df_050_059_OM_SI2_F.assign(Polish=None)
                    df_050_059_OM_SI2_F  = df_050_059_OM_SI2_F.assign(Symmetry=None)
                    df_050_059_OM_SI2_F  = df_050_059_OM_SI2_F.assign(Ratio=None)
                    df_050_059_OM_SI2_F  = df_050_059_OM_SI2_F.assign(PPC=None)
                    df_050_059_OM_SI2_F  = df_050_059_OM_SI2_F.assign(Total=None)
                    df_050_059_OM_SI2_F ['Wt Range'] = listwtrange
                    df_050_059_OM_SI2_F ['Company'] = listcom
                    df_050_059_OM_SI2_F ['Shape'] = listshap
                    df_050_059_OM_SI2_F ['Carat'] = listcar
                    df_050_059_OM_SI2_F ['Color'] = listcol
                    df_050_059_OM_SI2_F ['Clarity'] = listclar
                    df_050_059_OM_SI2_F ['Cut'] = listcut
                    df_050_059_OM_SI2_F ['Polish'] = listpol
                    df_050_059_OM_SI2_F ['Symmetry'] = listsym
                    df_050_059_OM_SI2_F ['Ratio'] = listrat
                    df_050_059_OM_SI2_F ['PPC'] = listdesc
                    df_050_059_OM_SI2_F ['Total'] = listtotal
                    df_050_059_OM_SI2_F['Carat'] = df_050_059_OM_SI2_F['Carat'].astype('float64')
                    df_050_059_OM_SI2_F['PPC'] = df_050_059_OM_SI2_F['PPC'].astype('float64')
                    df_050_059_OM_SI2_F['Total'] = df_050_059_OM_SI2_F['Total'].astype('float64')
                    df_050_059_OM_SI2_F['Total'] = df_050_059_OM_SI2_F['Carat'] * df_050_059_OM_SI2_F['PPC']


                elif i=="F" and j == "I1" and k == "OM":
                    df_050_059_OM_I1_F = pd.DataFrame()
                    df_050_059_OM_I1_F ['Wt Range'] = None
                    df_050_059_OM_I1_F  = df_050_059_OM_I1_F.assign(Company=None)
                    df_050_059_OM_I1_F  = df_050_059_OM_I1_F.assign(Shape=None)
                    df_050_059_OM_I1_F  = df_050_059_OM_I1_F.assign(Carat=None)
                    df_050_059_OM_I1_F  = df_050_059_OM_I1_F.assign(Color=None)
                    df_050_059_OM_I1_F  = df_050_059_OM_I1_F.assign(Clarity=None)
                    df_050_059_OM_I1_F  = df_050_059_OM_I1_F.assign(Cut=None)
                    df_050_059_OM_I1_F  = df_050_059_OM_I1_F.assign(Polish=None)
                    df_050_059_OM_I1_F  = df_050_059_OM_I1_F.assign(Symmetry=None)
                    df_050_059_OM_I1_F  = df_050_059_OM_I1_F.assign(Ratio=None)
                    df_050_059_OM_I1_F  = df_050_059_OM_I1_F.assign(PPC=None)
                    df_050_059_OM_I1_F  = df_050_059_OM_I1_F.assign(Total=None)
                    df_050_059_OM_I1_F ['Wt Range'] = listwtrange
                    df_050_059_OM_I1_F ['Company'] = listcom
                    df_050_059_OM_I1_F ['Shape'] = listshap
                    df_050_059_OM_I1_F ['Carat'] = listcar
                    df_050_059_OM_I1_F ['Color'] = listcol
                    df_050_059_OM_I1_F ['Clarity'] = listclar
                    df_050_059_OM_I1_F ['Cut'] = listcut
                    df_050_059_OM_I1_F ['Polish'] = listpol
                    df_050_059_OM_I1_F ['Symmetry'] = listsym
                    df_050_059_OM_I1_F ['Ratio'] = listrat
                    df_050_059_OM_I1_F ['PPC'] = listdesc
                    df_050_059_OM_I1_F ['Total'] = listtotal
                    df_050_059_OM_I1_F['Carat'] = df_050_059_OM_I1_F['Carat'].astype('float64')
                    df_050_059_OM_I1_F['PPC'] = df_050_059_OM_I1_F['PPC'].astype('float64')
                    df_050_059_OM_I1_F['Total'] = df_050_059_OM_I1_F['Total'].astype('float64')
                    df_050_059_OM_I1_F['Total'] = df_050_059_OM_I1_F['Carat'] * df_050_059_OM_I1_F['PPC']


                elif i=="F" and j == "I2" and k == "OM":
                    df_050_059_OM_I2_F = pd.DataFrame()
                    df_050_059_OM_I2_F ['Wt Range'] = None
                    df_050_059_OM_I2_F  = df_050_059_OM_I2_F.assign(Company=None)
                    df_050_059_OM_I2_F  = df_050_059_OM_I2_F.assign(Shape=None)
                    df_050_059_OM_I2_F  = df_050_059_OM_I2_F.assign(Carat=None)
                    df_050_059_OM_I2_F  = df_050_059_OM_I2_F.assign(Color=None)
                    df_050_059_OM_I2_F  = df_050_059_OM_I2_F.assign(Clarity=None)
                    df_050_059_OM_I2_F  = df_050_059_OM_I2_F.assign(Cut=None)
                    df_050_059_OM_I2_F  = df_050_059_OM_I2_F.assign(Polish=None)
                    df_050_059_OM_I2_F  = df_050_059_OM_I2_F.assign(Symmetry=None)
                    df_050_059_OM_I2_F  = df_050_059_OM_I2_F.assign(Ratio=None)
                    df_050_059_OM_I2_F  = df_050_059_OM_I2_F.assign(PPC=None)
                    df_050_059_OM_I2_F  = df_050_059_OM_I2_F.assign(Total=None)
                    df_050_059_OM_I2_F ['Wt Range'] = listwtrange
                    df_050_059_OM_I2_F ['Company'] = listcom
                    df_050_059_OM_I2_F ['Shape'] = listshap
                    df_050_059_OM_I2_F ['Carat'] = listcar
                    df_050_059_OM_I2_F ['Color'] = listcol
                    df_050_059_OM_I2_F ['Clarity'] = listclar
                    df_050_059_OM_I2_F ['Cut'] = listcut
                    df_050_059_OM_I2_F ['Polish'] = listpol
                    df_050_059_OM_I2_F ['Symmetry'] = listsym
                    df_050_059_OM_I2_F ['Ratio'] = listrat
                    df_050_059_OM_I2_F ['PPC'] = listdesc
                    df_050_059_OM_I2_F ['Total'] = listtotal
                    df_050_059_OM_I2_F['Carat'] = df_050_059_OM_I2_F['Carat'].astype('float64')
                    df_050_059_OM_I2_F['PPC'] = df_050_059_OM_I2_F['PPC'].astype('float64')
                    df_050_059_OM_I2_F['Total'] = df_050_059_OM_I2_F['Total'].astype('float64')
                    df_050_059_OM_I2_F['Total'] = df_050_059_OM_I2_F['Carat'] * df_050_059_OM_I2_F['PPC']


                elif i=="G" and j == "IF" and k == "OM":
                    df_050_059_OM_IF_G = pd.DataFrame()
                    df_050_059_OM_IF_G ['Wt Range'] = None
                    df_050_059_OM_IF_G  = df_050_059_OM_IF_G.assign(Company=None)
                    df_050_059_OM_IF_G  = df_050_059_OM_IF_G.assign(Shape=None)
                    df_050_059_OM_IF_G  = df_050_059_OM_IF_G.assign(Carat=None)
                    df_050_059_OM_IF_G  = df_050_059_OM_IF_G.assign(Color=None)
                    df_050_059_OM_IF_G  = df_050_059_OM_IF_G.assign(Clarity=None)
                    df_050_059_OM_IF_G  = df_050_059_OM_IF_G.assign(Cut=None)
                    df_050_059_OM_IF_G  = df_050_059_OM_IF_G.assign(Polish=None)
                    df_050_059_OM_IF_G  = df_050_059_OM_IF_G.assign(Symmetry=None)
                    df_050_059_OM_IF_G  = df_050_059_OM_IF_G.assign(Ratio=None)
                    df_050_059_OM_IF_G  = df_050_059_OM_IF_G.assign(PPC=None)
                    df_050_059_OM_IF_G  = df_050_059_OM_IF_G.assign(Total=None)
                    df_050_059_OM_IF_G ['Wt Range'] = listwtrange
                    df_050_059_OM_IF_G ['Company'] = listcom
                    df_050_059_OM_IF_G ['Shape'] = listshap
                    df_050_059_OM_IF_G ['Carat'] = listcar
                    df_050_059_OM_IF_G ['Color'] = listcol
                    df_050_059_OM_IF_G ['Clarity'] = listclar
                    df_050_059_OM_IF_G ['Cut'] = listcut
                    df_050_059_OM_IF_G ['Polish'] = listpol
                    df_050_059_OM_IF_G ['Symmetry'] = listsym
                    df_050_059_OM_IF_G ['Ratio'] = listrat
                    df_050_059_OM_IF_G ['PPC'] = listdesc
                    df_050_059_OM_IF_G ['Total'] = listtotal
                    df_050_059_OM_IF_G['Carat'] = df_050_059_OM_IF_G['Carat'].astype('float64')
                    df_050_059_OM_IF_G['PPC'] = df_050_059_OM_IF_G['PPC'].astype('float64')
                    df_050_059_OM_IF_G['Total'] = df_050_059_OM_IF_G['Total'].astype('float64')
                    df_050_059_OM_IF_G['Total'] = df_050_059_OM_IF_G['Carat'] * df_050_059_OM_IF_G['PPC']



                elif i=="G" and j == "VVS1" and k == "OM":
                    df_050_059_OM_VVS1_G = pd.DataFrame()
                    df_050_059_OM_VVS1_G ['Wt Range'] = None
                    df_050_059_OM_VVS1_G  = df_050_059_OM_VVS1_G.assign(Company=None)
                    df_050_059_OM_VVS1_G  = df_050_059_OM_VVS1_G.assign(Shape=None)
                    df_050_059_OM_VVS1_G  = df_050_059_OM_VVS1_G.assign(Carat=None)
                    df_050_059_OM_VVS1_G  = df_050_059_OM_VVS1_G.assign(Color=None)
                    df_050_059_OM_VVS1_G  = df_050_059_OM_VVS1_G.assign(Clarity=None)
                    df_050_059_OM_VVS1_G  = df_050_059_OM_VVS1_G.assign(Cut=None)
                    df_050_059_OM_VVS1_G  = df_050_059_OM_VVS1_G.assign(Polish=None)
                    df_050_059_OM_VVS1_G  = df_050_059_OM_VVS1_G.assign(Symmetry=None)
                    df_050_059_OM_VVS1_G  = df_050_059_OM_VVS1_G.assign(Ratio=None)
                    df_050_059_OM_VVS1_G  = df_050_059_OM_VVS1_G.assign(PPC=None)
                    df_050_059_OM_VVS1_G  = df_050_059_OM_VVS1_G.assign(Total=None)
                    df_050_059_OM_VVS1_G ['Wt Range'] = listwtrange
                    df_050_059_OM_VVS1_G ['Company'] = listcom
                    df_050_059_OM_VVS1_G ['Shape'] = listshap
                    df_050_059_OM_VVS1_G ['Carat'] = listcar
                    df_050_059_OM_VVS1_G ['Color'] = listcol
                    df_050_059_OM_VVS1_G ['Clarity'] = listclar
                    df_050_059_OM_VVS1_G ['Cut'] = listcut
                    df_050_059_OM_VVS1_G ['Polish'] = listpol
                    df_050_059_OM_VVS1_G ['Symmetry'] = listsym
                    df_050_059_OM_VVS1_G ['Ratio'] = listrat
                    df_050_059_OM_VVS1_G ['PPC'] = listdesc
                    df_050_059_OM_VVS1_G ['Total'] = listtotal
                    df_050_059_OM_VVS1_G['Carat'] = df_050_059_OM_VVS1_G['Carat'].astype('float64')
                    df_050_059_OM_VVS1_G['PPC'] = df_050_059_OM_VVS1_G['PPC'].astype('float64')
                    df_050_059_OM_VVS1_G['Total'] = df_050_059_OM_VVS1_G['Total'].astype('float64')
                    df_050_059_OM_VVS1_G['Total'] = df_050_059_OM_VVS1_G['Carat'] * df_050_059_OM_VVS1_G['PPC']


                elif i=="G" and j == "VVS2" and k == "OM":
                    df_050_059_OM_VVS2_G = pd.DataFrame()
                    df_050_059_OM_VVS2_G ['Wt Range'] = None
                    df_050_059_OM_VVS2_G  = df_050_059_OM_VVS2_G.assign(Company=None)
                    df_050_059_OM_VVS2_G  = df_050_059_OM_VVS2_G.assign(Shape=None)
                    df_050_059_OM_VVS2_G  = df_050_059_OM_VVS2_G.assign(Carat=None)
                    df_050_059_OM_VVS2_G  = df_050_059_OM_VVS2_G.assign(Color=None)
                    df_050_059_OM_VVS2_G  = df_050_059_OM_VVS2_G.assign(Clarity=None)
                    df_050_059_OM_VVS2_G  = df_050_059_OM_VVS2_G.assign(Cut=None)
                    df_050_059_OM_VVS2_G  = df_050_059_OM_VVS2_G.assign(Polish=None)
                    df_050_059_OM_VVS2_G  = df_050_059_OM_VVS2_G.assign(Symmetry=None)
                    df_050_059_OM_VVS2_G  = df_050_059_OM_VVS2_G.assign(Ratio=None)
                    df_050_059_OM_VVS2_G  = df_050_059_OM_VVS2_G.assign(PPC=None)
                    df_050_059_OM_VVS2_G  = df_050_059_OM_VVS2_G.assign(Total=None)
                    df_050_059_OM_VVS2_G ['Wt Range'] = listwtrange
                    df_050_059_OM_VVS2_G ['Company'] = listcom
                    df_050_059_OM_VVS2_G ['Shape'] = listshap
                    df_050_059_OM_VVS2_G ['Carat'] = listcar
                    df_050_059_OM_VVS2_G ['Color'] = listcol
                    df_050_059_OM_VVS2_G ['Clarity'] = listclar
                    df_050_059_OM_VVS2_G ['Cut'] = listcut
                    df_050_059_OM_VVS2_G ['Polish'] = listpol
                    df_050_059_OM_VVS2_G ['Symmetry'] = listsym
                    df_050_059_OM_VVS2_G ['Ratio'] = listrat
                    df_050_059_OM_VVS2_G ['PPC'] = listdesc
                    df_050_059_OM_VVS2_G ['Total'] = listtotal
                    df_050_059_OM_VVS2_G['Carat'] = df_050_059_OM_VVS2_G['Carat'].astype('float64')
                    df_050_059_OM_VVS2_G['PPC'] = df_050_059_OM_VVS2_G['PPC'].astype('float64')
                    df_050_059_OM_VVS2_G['Total'] = df_050_059_OM_VVS2_G['Total'].astype('float64')
                    df_050_059_OM_VVS2_G['Total'] = df_050_059_OM_VVS2_G['Carat'] * df_050_059_OM_VVS2_G['PPC']


                elif i=="G" and j=="VS1" and k == "OM":
                    df_050_059_OM_VS1_G = pd.DataFrame()
                    df_050_059_OM_VS1_G ['Wt Range'] = None
                    df_050_059_OM_VS1_G  = df_050_059_OM_VS1_G.assign(Company=None)
                    df_050_059_OM_VS1_G  = df_050_059_OM_VS1_G.assign(Shape=None)
                    df_050_059_OM_VS1_G  = df_050_059_OM_VS1_G.assign(Carat=None)
                    df_050_059_OM_VS1_G  = df_050_059_OM_VS1_G.assign(Color=None)
                    df_050_059_OM_VS1_G  = df_050_059_OM_VS1_G.assign(Clarity=None)
                    df_050_059_OM_VS1_G  = df_050_059_OM_VS1_G.assign(Cut=None)
                    df_050_059_OM_VS1_G  = df_050_059_OM_VS1_G.assign(Polish=None)
                    df_050_059_OM_VS1_G  = df_050_059_OM_VS1_G.assign(Symmetry=None)
                    df_050_059_OM_VS1_G  = df_050_059_OM_VS1_G.assign(Ratio=None)
                    df_050_059_OM_VS1_G  = df_050_059_OM_VS1_G.assign(PPC=None)
                    df_050_059_OM_VS1_G  = df_050_059_OM_VS1_G.assign(Total=None)
                    df_050_059_OM_VS1_G ['Wt Range'] = listwtrange
                    df_050_059_OM_VS1_G ['Company'] = listcom
                    df_050_059_OM_VS1_G ['Shape'] = listshap
                    df_050_059_OM_VS1_G ['Carat'] = listcar
                    df_050_059_OM_VS1_G ['Color'] = listcol
                    df_050_059_OM_VS1_G ['Clarity'] = listclar
                    df_050_059_OM_VS1_G ['Cut'] = listcut
                    df_050_059_OM_VS1_G ['Polish'] = listpol
                    df_050_059_OM_VS1_G ['Symmetry'] = listsym
                    df_050_059_OM_VS1_G ['Ratio'] = listrat
                    df_050_059_OM_VS1_G ['PPC'] = listdesc
                    df_050_059_OM_VS1_G ['Total'] = listtotal
                    df_050_059_OM_VS1_G['Carat'] = df_050_059_OM_VS1_G['Carat'].astype('float64')
                    df_050_059_OM_VS1_G['PPC'] = df_050_059_OM_VS1_G['PPC'].astype('float64')
                    df_050_059_OM_VS1_G['Total'] = df_050_059_OM_VS1_G['Total'].astype('float64')
                    df_050_059_OM_VS1_G['Total'] = df_050_059_OM_VS1_G['Carat'] * df_050_059_OM_VS1_G['PPC']


                elif i=="G" and j == "VS2" and k == "OM":
                    df_050_059_OM_VS2_G = pd.DataFrame()
                    df_050_059_OM_VS2_G ['Wt Range'] = None
                    df_050_059_OM_VS2_G  = df_050_059_OM_VS2_G.assign(Company=None)
                    df_050_059_OM_VS2_G  = df_050_059_OM_VS2_G.assign(Shape=None)
                    df_050_059_OM_VS2_G  = df_050_059_OM_VS2_G.assign(Carat=None)
                    df_050_059_OM_VS2_G  = df_050_059_OM_VS2_G.assign(Color=None)
                    df_050_059_OM_VS2_G  = df_050_059_OM_VS2_G.assign(Clarity=None)
                    df_050_059_OM_VS2_G  = df_050_059_OM_VS2_G.assign(Cut=None)
                    df_050_059_OM_VS2_G  = df_050_059_OM_VS2_G.assign(Polish=None)
                    df_050_059_OM_VS2_G  = df_050_059_OM_VS2_G.assign(Symmetry=None)
                    df_050_059_OM_VS2_G  = df_050_059_OM_VS2_G.assign(Ratio=None)
                    df_050_059_OM_VS2_G  = df_050_059_OM_VS2_G.assign(PPC=None)
                    df_050_059_OM_VS2_G  = df_050_059_OM_VS2_G.assign(Total=None)
                    df_050_059_OM_VS2_G ['Wt Range'] = listwtrange
                    df_050_059_OM_VS2_G ['Company'] = listcom
                    df_050_059_OM_VS2_G ['Shape'] = listshap
                    df_050_059_OM_VS2_G ['Carat'] = listcar
                    df_050_059_OM_VS2_G ['Color'] = listcol
                    df_050_059_OM_VS2_G ['Clarity'] = listclar
                    df_050_059_OM_VS2_G ['Cut'] = listcut
                    df_050_059_OM_VS2_G ['Polish'] = listpol
                    df_050_059_OM_VS2_G ['Symmetry'] = listsym
                    df_050_059_OM_VS2_G ['Ratio'] = listrat
                    df_050_059_OM_VS2_G ['PPC'] = listdesc
                    df_050_059_OM_VS2_G ['Total'] = listtotal
                    df_050_059_OM_VS2_G['Carat'] = df_050_059_OM_VS2_G['Carat'].astype('float64')
                    df_050_059_OM_VS2_G['PPC'] = df_050_059_OM_VS2_G['PPC'].astype('float64')
                    df_050_059_OM_VS2_G['Total'] = df_050_059_OM_VS2_G['Total'].astype('float64')
                    df_050_059_OM_VS2_G['Total'] = df_050_059_OM_VS2_G['Carat'] * df_050_059_OM_VS2_G['PPC']


                elif i=="G" and j == "SI1" and k == "OM":
                    df_050_059_OM_SI1_G = pd.DataFrame()
                    df_050_059_OM_SI1_G ['Wt Range'] = None
                    df_050_059_OM_SI1_G  = df_050_059_OM_SI1_G.assign(Company=None)
                    df_050_059_OM_SI1_G  = df_050_059_OM_SI1_G.assign(Shape=None)
                    df_050_059_OM_SI1_G  = df_050_059_OM_SI1_G.assign(Carat=None)
                    df_050_059_OM_SI1_G  = df_050_059_OM_SI1_G.assign(Color=None)
                    df_050_059_OM_SI1_G  = df_050_059_OM_SI1_G.assign(Clarity=None)
                    df_050_059_OM_SI1_G  = df_050_059_OM_SI1_G.assign(Cut=None)
                    df_050_059_OM_SI1_G  = df_050_059_OM_SI1_G.assign(Polish=None)
                    df_050_059_OM_SI1_G  = df_050_059_OM_SI1_G.assign(Symmetry=None)
                    df_050_059_OM_SI1_G  = df_050_059_OM_SI1_G.assign(Ratio=None)
                    df_050_059_OM_SI1_G  = df_050_059_OM_SI1_G.assign(PPC=None)
                    df_050_059_OM_SI1_G  = df_050_059_OM_SI1_G.assign(Total=None)
                    df_050_059_OM_SI1_G ['Wt Range'] = listwtrange
                    df_050_059_OM_SI1_G ['Company'] = listcom
                    df_050_059_OM_SI1_G ['Shape'] = listshap
                    df_050_059_OM_SI1_G ['Carat'] = listcar
                    df_050_059_OM_SI1_G ['Color'] = listcol
                    df_050_059_OM_SI1_G ['Clarity'] = listclar
                    df_050_059_OM_SI1_G ['Cut'] = listcut
                    df_050_059_OM_SI1_G ['Polish'] = listpol
                    df_050_059_OM_SI1_G ['Symmetry'] = listsym
                    df_050_059_OM_SI1_G ['Ratio'] = listrat
                    df_050_059_OM_SI1_G ['PPC'] = listdesc
                    df_050_059_OM_SI1_G ['Total'] = listtotal
                    df_050_059_OM_SI1_G['Carat'] = df_050_059_OM_SI1_G['Carat'].astype('float64')
                    df_050_059_OM_SI1_G['PPC'] = df_050_059_OM_SI1_G['PPC'].astype('float64')
                    df_050_059_OM_SI1_G['Total'] = df_050_059_OM_SI1_G['Total'].astype('float64')
                    df_050_059_OM_SI1_G['Total'] = df_050_059_OM_SI1_G['Carat'] * df_050_059_OM_SI1_G['PPC']


                elif i=="G" and j == "SI2" and k == "OM":
                    df_050_059_OM_SI2_G = pd.DataFrame()
                    df_050_059_OM_SI2_G ['Wt Range'] = None
                    df_050_059_OM_SI2_G  = df_050_059_OM_SI2_G.assign(Company=None)
                    df_050_059_OM_SI2_G  = df_050_059_OM_SI2_G.assign(Shape=None)
                    df_050_059_OM_SI2_G  = df_050_059_OM_SI2_G.assign(Carat=None)
                    df_050_059_OM_SI2_G  = df_050_059_OM_SI2_G.assign(Color=None)
                    df_050_059_OM_SI2_G  = df_050_059_OM_SI2_G.assign(Clarity=None)
                    df_050_059_OM_SI2_G  = df_050_059_OM_SI2_G.assign(Cut=None)
                    df_050_059_OM_SI2_G  = df_050_059_OM_SI2_G.assign(Polish=None)
                    df_050_059_OM_SI2_G  = df_050_059_OM_SI2_G.assign(Symmetry=None)
                    df_050_059_OM_SI2_G  = df_050_059_OM_SI2_G.assign(Ratio=None)
                    df_050_059_OM_SI2_G  = df_050_059_OM_SI2_G.assign(PPC=None)
                    df_050_059_OM_SI2_G  = df_050_059_OM_SI2_G.assign(Total=None)
                    df_050_059_OM_SI2_G ['Wt Range'] = listwtrange
                    df_050_059_OM_SI2_G ['Company'] = listcom
                    df_050_059_OM_SI2_G ['Shape'] = listshap
                    df_050_059_OM_SI2_G ['Carat'] = listcar
                    df_050_059_OM_SI2_G ['Color'] = listcol
                    df_050_059_OM_SI2_G ['Clarity'] = listclar
                    df_050_059_OM_SI2_G ['Cut'] = listcut
                    df_050_059_OM_SI2_G ['Polish'] = listpol
                    df_050_059_OM_SI2_G ['Symmetry'] = listsym
                    df_050_059_OM_SI2_G ['Ratio'] = listrat
                    df_050_059_OM_SI2_G ['PPC'] = listdesc
                    df_050_059_OM_SI2_G ['Total'] = listtotal
                    df_050_059_OM_SI2_G['Carat'] = df_050_059_OM_SI2_G['Carat'].astype('float64')
                    df_050_059_OM_SI2_G['PPC'] = df_050_059_OM_SI2_G['PPC'].astype('float64')
                    df_050_059_OM_SI2_G['Total'] = df_050_059_OM_SI2_G['Total'].astype('float64')
                    df_050_059_OM_SI2_G['Total'] = df_050_059_OM_SI2_G['Carat'] * df_050_059_OM_SI2_G['PPC']


                elif i=="G" and j == "I1" and k == "OM":
                    df_050_059_OM_I1_G = pd.DataFrame()
                    df_050_059_OM_I1_G ['Wt Range'] = None
                    df_050_059_OM_I1_G  = df_050_059_OM_I1_G.assign(Company=None)
                    df_050_059_OM_I1_G  = df_050_059_OM_I1_G.assign(Shape=None)
                    df_050_059_OM_I1_G  = df_050_059_OM_I1_G.assign(Carat=None)
                    df_050_059_OM_I1_G  = df_050_059_OM_I1_G.assign(Color=None)
                    df_050_059_OM_I1_G  = df_050_059_OM_I1_G.assign(Clarity=None)
                    df_050_059_OM_I1_G  = df_050_059_OM_I1_G.assign(Cut=None)
                    df_050_059_OM_I1_G  = df_050_059_OM_I1_G.assign(Polish=None)
                    df_050_059_OM_I1_G  = df_050_059_OM_I1_G.assign(Symmetry=None)
                    df_050_059_OM_I1_G  = df_050_059_OM_I1_G.assign(Ratio=None)
                    df_050_059_OM_I1_G  = df_050_059_OM_I1_G.assign(PPC=None)
                    df_050_059_OM_I1_G  = df_050_059_OM_I1_G.assign(Total=None)
                    df_050_059_OM_I1_G ['Wt Range'] = listwtrange
                    df_050_059_OM_I1_G ['Company'] = listcom
                    df_050_059_OM_I1_G ['Shape'] = listshap
                    df_050_059_OM_I1_G ['Carat'] = listcar
                    df_050_059_OM_I1_G ['Color'] = listcol
                    df_050_059_OM_I1_G ['Clarity'] = listclar
                    df_050_059_OM_I1_G ['Cut'] = listcut
                    df_050_059_OM_I1_G ['Polish'] = listpol
                    df_050_059_OM_I1_G ['Symmetry'] = listsym
                    df_050_059_OM_I1_G ['Ratio'] = listrat
                    df_050_059_OM_I1_G ['PPC'] = listdesc
                    df_050_059_OM_I1_G ['Total'] = listtotal
                    df_050_059_OM_I1_G['Carat'] = df_050_059_OM_I1_G['Carat'].astype('float64')
                    df_050_059_OM_I1_G['PPC'] = df_050_059_OM_I1_G['PPC'].astype('float64')
                    df_050_059_OM_I1_G['Total'] = df_050_059_OM_I1_G['Total'].astype('float64')
                    df_050_059_OM_I1_G['Total'] = df_050_059_OM_I1_G['Carat'] * df_050_059_OM_I1_G['PPC']


                elif i=="G" and j == "I2" and k == "OM":
                    df_050_059_OM_I2_G = pd.DataFrame()
                    df_050_059_OM_I2_G ['Wt Range'] = None
                    df_050_059_OM_I2_G  = df_050_059_OM_I2_G.assign(Company=None)
                    df_050_059_OM_I2_G  = df_050_059_OM_I2_G.assign(Shape=None)
                    df_050_059_OM_I2_G  = df_050_059_OM_I2_G.assign(Carat=None)
                    df_050_059_OM_I2_G  = df_050_059_OM_I2_G.assign(Color=None)
                    df_050_059_OM_I2_G  = df_050_059_OM_I2_G.assign(Clarity=None)
                    df_050_059_OM_I2_G  = df_050_059_OM_I2_G.assign(Cut=None)
                    df_050_059_OM_I2_G  = df_050_059_OM_I2_G.assign(Polish=None)
                    df_050_059_OM_I2_G  = df_050_059_OM_I2_G.assign(Symmetry=None)
                    df_050_059_OM_I2_G  = df_050_059_OM_I2_G.assign(Ratio=None)
                    df_050_059_OM_I2_G  = df_050_059_OM_I2_G.assign(PPC=None)
                    df_050_059_OM_I2_G  = df_050_059_OM_I2_G.assign(Total=None)
                    df_050_059_OM_I2_G ['Wt Range'] = listwtrange
                    df_050_059_OM_I2_G ['Company'] = listcom
                    df_050_059_OM_I2_G ['Shape'] = listshap
                    df_050_059_OM_I2_G ['Carat'] = listcar
                    df_050_059_OM_I2_G ['Color'] = listcol
                    df_050_059_OM_I2_G ['Clarity'] = listclar
                    df_050_059_OM_I2_G ['Cut'] = listcut
                    df_050_059_OM_I2_G ['Polish'] = listpol
                    df_050_059_OM_I2_G ['Symmetry'] = listsym
                    df_050_059_OM_I2_G ['Ratio'] = listrat
                    df_050_059_OM_I2_G ['PPC'] = listdesc
                    df_050_059_OM_I2_G ['Total'] = listtotal
                    df_050_059_OM_I2_G['Carat'] = df_050_059_OM_I2_G['Carat'].astype('float64')
                    df_050_059_OM_I2_G['PPC'] = df_050_059_OM_I2_G['PPC'].astype('float64')
                    df_050_059_OM_I2_G['Total'] = df_050_059_OM_I2_G['Total'].astype('float64')
                    df_050_059_OM_I2_G['Total'] = df_050_059_OM_I2_G['Carat'] * df_050_059_OM_I2_G['PPC']


                elif i=="H" and j == "IF" and k == "OM":
                    df_050_059_OM_IF_H = pd.DataFrame()
                    df_050_059_OM_IF_H ['Wt Range'] = None
                    df_050_059_OM_IF_H  = df_050_059_OM_IF_H.assign(Company=None)
                    df_050_059_OM_IF_H  = df_050_059_OM_IF_H.assign(Shape=None)
                    df_050_059_OM_IF_H  = df_050_059_OM_IF_H.assign(Carat=None)
                    df_050_059_OM_IF_H  = df_050_059_OM_IF_H.assign(Color=None)
                    df_050_059_OM_IF_H  = df_050_059_OM_IF_H.assign(Clarity=None)
                    df_050_059_OM_IF_H  = df_050_059_OM_IF_H.assign(Cut=None)
                    df_050_059_OM_IF_H  = df_050_059_OM_IF_H.assign(Polish=None)
                    df_050_059_OM_IF_H  = df_050_059_OM_IF_H.assign(Symmetry=None)
                    df_050_059_OM_IF_H  = df_050_059_OM_IF_H.assign(Ratio=None)
                    df_050_059_OM_IF_H  = df_050_059_OM_IF_H.assign(PPC=None)
                    df_050_059_OM_IF_H  = df_050_059_OM_IF_H.assign(Total=None)
                    df_050_059_OM_IF_H ['Wt Range'] = listwtrange
                    df_050_059_OM_IF_H ['Company'] = listcom
                    df_050_059_OM_IF_H ['Shape'] = listshap
                    df_050_059_OM_IF_H ['Carat'] = listcar
                    df_050_059_OM_IF_H ['Color'] = listcol
                    df_050_059_OM_IF_H ['Clarity'] = listclar
                    df_050_059_OM_IF_H ['Cut'] = listcut
                    df_050_059_OM_IF_H ['Polish'] = listpol
                    df_050_059_OM_IF_H ['Symmetry'] = listsym
                    df_050_059_OM_IF_H ['Ratio'] = listrat
                    df_050_059_OM_IF_H ['PPC'] = listdesc
                    df_050_059_OM_IF_H ['Total'] = listtotal
                    df_050_059_OM_IF_H['Carat'] = df_050_059_OM_IF_H['Carat'].astype('float64')
                    df_050_059_OM_IF_H['PPC'] = df_050_059_OM_IF_H['PPC'].astype('float64')
                    df_050_059_OM_IF_H['Total'] = df_050_059_OM_IF_H['Total'].astype('float64')
                    df_050_059_OM_IF_H['Total'] = df_050_059_OM_IF_H['Carat'] * df_050_059_OM_IF_H['PPC']



                elif i=="H" and j == "VVS1" and k == "OM":
                    df_050_059_OM_VVS1_H = pd.DataFrame()
                    df_050_059_OM_VVS1_H ['Wt Range'] = None
                    df_050_059_OM_VVS1_H  = df_050_059_OM_VVS1_H.assign(Company=None)
                    df_050_059_OM_VVS1_H  = df_050_059_OM_VVS1_H.assign(Shape=None)
                    df_050_059_OM_VVS1_H  = df_050_059_OM_VVS1_H.assign(Carat=None)
                    df_050_059_OM_VVS1_H  = df_050_059_OM_VVS1_H.assign(Color=None)
                    df_050_059_OM_VVS1_H  = df_050_059_OM_VVS1_H.assign(Clarity=None)
                    df_050_059_OM_VVS1_H  = df_050_059_OM_VVS1_H.assign(Cut=None)
                    df_050_059_OM_VVS1_H  = df_050_059_OM_VVS1_H.assign(Polish=None)
                    df_050_059_OM_VVS1_H  = df_050_059_OM_VVS1_H.assign(Symmetry=None)
                    df_050_059_OM_VVS1_H  = df_050_059_OM_VVS1_H.assign(Ratio=None)
                    df_050_059_OM_VVS1_H  = df_050_059_OM_VVS1_H.assign(PPC=None)
                    df_050_059_OM_VVS1_H  = df_050_059_OM_VVS1_H.assign(Total=None)
                    df_050_059_OM_VVS1_H ['Wt Range'] = listwtrange
                    df_050_059_OM_VVS1_H ['Company'] = listcom
                    df_050_059_OM_VVS1_H ['Shape'] = listshap
                    df_050_059_OM_VVS1_H ['Carat'] = listcar
                    df_050_059_OM_VVS1_H ['Color'] = listcol
                    df_050_059_OM_VVS1_H ['Clarity'] = listclar
                    df_050_059_OM_VVS1_H ['Cut'] = listcut
                    df_050_059_OM_VVS1_H ['Polish'] = listpol
                    df_050_059_OM_VVS1_H ['Symmetry'] = listsym
                    df_050_059_OM_VVS1_H ['Ratio'] = listrat
                    df_050_059_OM_VVS1_H ['PPC'] = listdesc
                    df_050_059_OM_VVS1_H ['Total'] = listtotal
                    df_050_059_OM_VVS1_H['Carat'] = df_050_059_OM_VVS1_H['Carat'].astype('float64')
                    df_050_059_OM_VVS1_H['PPC'] = df_050_059_OM_VVS1_H['PPC'].astype('float64')
                    df_050_059_OM_VVS1_H['Total'] = df_050_059_OM_VVS1_H['Total'].astype('float64')
                    df_050_059_OM_VVS1_H['Total'] = df_050_059_OM_VVS1_H['Carat'] * df_050_059_OM_VVS1_H['PPC']


                elif i=="H" and j == "VVS2" and k == "OM":
                    df_050_059_OM_VVS2_H = pd.DataFrame()
                    df_050_059_OM_VVS2_H ['Wt Range'] = None
                    df_050_059_OM_VVS2_H  = df_050_059_OM_VVS2_H.assign(Company=None)
                    df_050_059_OM_VVS2_H  = df_050_059_OM_VVS2_H.assign(Shape=None)
                    df_050_059_OM_VVS2_H  = df_050_059_OM_VVS2_H.assign(Carat=None)
                    df_050_059_OM_VVS2_H  = df_050_059_OM_VVS2_H.assign(Color=None)
                    df_050_059_OM_VVS2_H  = df_050_059_OM_VVS2_H.assign(Clarity=None)
                    df_050_059_OM_VVS2_H  = df_050_059_OM_VVS2_H.assign(Cut=None)
                    df_050_059_OM_VVS2_H  = df_050_059_OM_VVS2_H.assign(Polish=None)
                    df_050_059_OM_VVS2_H  = df_050_059_OM_VVS2_H.assign(Symmetry=None)
                    df_050_059_OM_VVS2_H  = df_050_059_OM_VVS2_H.assign(Ratio=None)
                    df_050_059_OM_VVS2_H  = df_050_059_OM_VVS2_H.assign(PPC=None)
                    df_050_059_OM_VVS2_H  = df_050_059_OM_VVS2_H.assign(Total=None)
                    df_050_059_OM_VVS2_H ['Wt Range'] = listwtrange
                    df_050_059_OM_VVS2_H ['Company'] = listcom
                    df_050_059_OM_VVS2_H ['Shape'] = listshap
                    df_050_059_OM_VVS2_H ['Carat'] = listcar
                    df_050_059_OM_VVS2_H ['Color'] = listcol
                    df_050_059_OM_VVS2_H ['Clarity'] = listclar
                    df_050_059_OM_VVS2_H ['Cut'] = listcut
                    df_050_059_OM_VVS2_H ['Polish'] = listpol
                    df_050_059_OM_VVS2_H ['Symmetry'] = listsym
                    df_050_059_OM_VVS2_H ['Ratio'] = listrat
                    df_050_059_OM_VVS2_H ['PPC'] = listdesc
                    df_050_059_OM_VVS2_H ['Total'] = listtotal
                    df_050_059_OM_VVS2_H['Carat'] = df_050_059_OM_VVS2_H['Carat'].astype('float64')
                    df_050_059_OM_VVS2_H['PPC'] = df_050_059_OM_VVS2_H['PPC'].astype('float64')
                    df_050_059_OM_VVS2_H['Total'] = df_050_059_OM_VVS2_H['Total'].astype('float64')
                    df_050_059_OM_VVS2_H['Total'] = df_050_059_OM_VVS2_H['Carat'] * df_050_059_OM_VVS2_H['PPC']


                elif i=="H" and j=="VS1" and k == "OM":
                    df_050_059_OM_VS1_H = pd.DataFrame()
                    df_050_059_OM_VS1_H ['Wt Range'] = None
                    df_050_059_OM_VS1_H  = df_050_059_OM_VS1_H.assign(Company=None)
                    df_050_059_OM_VS1_H  = df_050_059_OM_VS1_H.assign(Shape=None)
                    df_050_059_OM_VS1_H  = df_050_059_OM_VS1_H.assign(Carat=None)
                    df_050_059_OM_VS1_H  = df_050_059_OM_VS1_H.assign(Color=None)
                    df_050_059_OM_VS1_H  = df_050_059_OM_VS1_H.assign(Clarity=None)
                    df_050_059_OM_VS1_H  = df_050_059_OM_VS1_H.assign(Cut=None)
                    df_050_059_OM_VS1_H  = df_050_059_OM_VS1_H.assign(Polish=None)
                    df_050_059_OM_VS1_H  = df_050_059_OM_VS1_H.assign(Symmetry=None)
                    df_050_059_OM_VS1_H  = df_050_059_OM_VS1_H.assign(Ratio=None)
                    df_050_059_OM_VS1_H  = df_050_059_OM_VS1_H.assign(PPC=None)
                    df_050_059_OM_VS1_H  = df_050_059_OM_VS1_H.assign(Total=None)
                    df_050_059_OM_VS1_H ['Wt Range'] = listwtrange
                    df_050_059_OM_VS1_H ['Company'] = listcom
                    df_050_059_OM_VS1_H ['Shape'] = listshap
                    df_050_059_OM_VS1_H ['Carat'] = listcar
                    df_050_059_OM_VS1_H ['Color'] = listcol
                    df_050_059_OM_VS1_H ['Clarity'] = listclar
                    df_050_059_OM_VS1_H ['Cut'] = listcut
                    df_050_059_OM_VS1_H ['Polish'] = listpol
                    df_050_059_OM_VS1_H ['Symmetry'] = listsym
                    df_050_059_OM_VS1_H ['Ratio'] = listrat
                    df_050_059_OM_VS1_H ['PPC'] = listdesc
                    df_050_059_OM_VS1_H ['Total'] = listtotal
                    df_050_059_OM_VS1_H['Carat'] = df_050_059_OM_VS1_H['Carat'].astype('float64')
                    df_050_059_OM_VS1_H['PPC'] = df_050_059_OM_VS1_H['PPC'].astype('float64')
                    df_050_059_OM_VS1_H['Total'] = df_050_059_OM_VS1_H['Total'].astype('float64')
                    df_050_059_OM_VS1_H['Total'] = df_050_059_OM_VS1_H['Carat'] * df_050_059_OM_VS1_H['PPC']


                elif i=="H" and j == "VS2" and k == "OM":
                    df_050_059_OM_VS2_H = pd.DataFrame()
                    df_050_059_OM_VS2_H ['Wt Range'] = None
                    df_050_059_OM_VS2_H  = df_050_059_OM_VS2_H.assign(Company=None)
                    df_050_059_OM_VS2_H  = df_050_059_OM_VS2_H.assign(Shape=None)
                    df_050_059_OM_VS2_H  = df_050_059_OM_VS2_H.assign(Carat=None)
                    df_050_059_OM_VS2_H  = df_050_059_OM_VS2_H.assign(Color=None)
                    df_050_059_OM_VS2_H  = df_050_059_OM_VS2_H.assign(Clarity=None)
                    df_050_059_OM_VS2_H  = df_050_059_OM_VS2_H.assign(Cut=None)
                    df_050_059_OM_VS2_H  = df_050_059_OM_VS2_H.assign(Polish=None)
                    df_050_059_OM_VS2_H  = df_050_059_OM_VS2_H.assign(Symmetry=None)
                    df_050_059_OM_VS2_H  = df_050_059_OM_VS2_H.assign(Ratio=None)
                    df_050_059_OM_VS2_H  = df_050_059_OM_VS2_H.assign(PPC=None)
                    df_050_059_OM_VS2_H  = df_050_059_OM_VS2_H.assign(Total=None)
                    df_050_059_OM_VS2_H ['Wt Range'] = listwtrange
                    df_050_059_OM_VS2_H ['Company'] = listcom
                    df_050_059_OM_VS2_H ['Shape'] = listshap
                    df_050_059_OM_VS2_H ['Carat'] = listcar
                    df_050_059_OM_VS2_H ['Color'] = listcol
                    df_050_059_OM_VS2_H ['Clarity'] = listclar
                    df_050_059_OM_VS2_H ['Cut'] = listcut
                    df_050_059_OM_VS2_H ['Polish'] = listpol
                    df_050_059_OM_VS2_H ['Symmetry'] = listsym
                    df_050_059_OM_VS2_H ['Ratio'] = listrat
                    df_050_059_OM_VS2_H ['PPC'] = listdesc
                    df_050_059_OM_VS2_H ['Total'] = listtotal
                    df_050_059_OM_VS2_H['Carat'] = df_050_059_OM_VS2_H['Carat'].astype('float64')
                    df_050_059_OM_VS2_H['PPC'] = df_050_059_OM_VS2_H['PPC'].astype('float64')
                    df_050_059_OM_VS2_H['Total'] = df_050_059_OM_VS2_H['Total'].astype('float64')
                    df_050_059_OM_VS2_H['Total'] = df_050_059_OM_VS2_H['Carat'] * df_050_059_OM_VS2_H['PPC']


                elif i=="H" and j == "SI1" and k == "OM":
                    df_050_059_OM_SI1_H = pd.DataFrame()
                    df_050_059_OM_SI1_H ['Wt Range'] = None
                    df_050_059_OM_SI1_H  = df_050_059_OM_SI1_H.assign(Company=None)
                    df_050_059_OM_SI1_H  = df_050_059_OM_SI1_H.assign(Shape=None)
                    df_050_059_OM_SI1_H  = df_050_059_OM_SI1_H.assign(Carat=None)
                    df_050_059_OM_SI1_H  = df_050_059_OM_SI1_H.assign(Color=None)
                    df_050_059_OM_SI1_H  = df_050_059_OM_SI1_H.assign(Clarity=None)
                    df_050_059_OM_SI1_H  = df_050_059_OM_SI1_H.assign(Cut=None)
                    df_050_059_OM_SI1_H  = df_050_059_OM_SI1_H.assign(Polish=None)
                    df_050_059_OM_SI1_H  = df_050_059_OM_SI1_H.assign(Symmetry=None)
                    df_050_059_OM_SI1_H  = df_050_059_OM_SI1_H.assign(Ratio=None)
                    df_050_059_OM_SI1_H  = df_050_059_OM_SI1_H.assign(PPC=None)
                    df_050_059_OM_SI1_H  = df_050_059_OM_SI1_H.assign(Total=None)
                    df_050_059_OM_SI1_H ['Wt Range'] = listwtrange
                    df_050_059_OM_SI1_H ['Company'] = listcom
                    df_050_059_OM_SI1_H ['Shape'] = listshap
                    df_050_059_OM_SI1_H ['Carat'] = listcar
                    df_050_059_OM_SI1_H ['Color'] = listcol
                    df_050_059_OM_SI1_H ['Clarity'] = listclar
                    df_050_059_OM_SI1_H ['Cut'] = listcut
                    df_050_059_OM_SI1_H ['Polish'] = listpol
                    df_050_059_OM_SI1_H ['Symmetry'] = listsym
                    df_050_059_OM_SI1_H ['Ratio'] = listrat
                    df_050_059_OM_SI1_H ['PPC'] = listdesc
                    df_050_059_OM_SI1_H ['Total'] = listtotal
                    df_050_059_OM_SI1_H['Carat'] = df_050_059_OM_SI1_H['Carat'].astype('float64')
                    df_050_059_OM_SI1_H['PPC'] = df_050_059_OM_SI1_H['PPC'].astype('float64')
                    df_050_059_OM_SI1_H['Total'] = df_050_059_OM_SI1_H['Total'].astype('float64')
                    df_050_059_OM_SI1_H['Total'] = df_050_059_OM_SI1_H['Carat'] * df_050_059_OM_SI1_H['PPC']


                elif i=="H" and j == "SI2" and k == "OM":
                    df_050_059_OM_SI2_H = pd.DataFrame()
                    df_050_059_OM_SI2_H ['Wt Range'] = None
                    df_050_059_OM_SI2_H  = df_050_059_OM_SI2_H.assign(Company=None)
                    df_050_059_OM_SI2_H  = df_050_059_OM_SI2_H.assign(Shape=None)
                    df_050_059_OM_SI2_H  = df_050_059_OM_SI2_H.assign(Carat=None)
                    df_050_059_OM_SI2_H  = df_050_059_OM_SI2_H.assign(Color=None)
                    df_050_059_OM_SI2_H  = df_050_059_OM_SI2_H.assign(Clarity=None)
                    df_050_059_OM_SI2_H  = df_050_059_OM_SI2_H.assign(Cut=None)
                    df_050_059_OM_SI2_H  = df_050_059_OM_SI2_H.assign(Polish=None)
                    df_050_059_OM_SI2_H  = df_050_059_OM_SI2_H.assign(Symmetry=None)
                    df_050_059_OM_SI2_H  = df_050_059_OM_SI2_H.assign(Ratio=None)
                    df_050_059_OM_SI2_H  = df_050_059_OM_SI2_H.assign(PPC=None)
                    df_050_059_OM_SI2_H  = df_050_059_OM_SI2_H.assign(Total=None)
                    df_050_059_OM_SI2_H ['Wt Range'] = listwtrange
                    df_050_059_OM_SI2_H ['Company'] = listcom
                    df_050_059_OM_SI2_H ['Shape'] = listshap
                    df_050_059_OM_SI2_H ['Carat'] = listcar
                    df_050_059_OM_SI2_H ['Color'] = listcol
                    df_050_059_OM_SI2_H ['Clarity'] = listclar
                    df_050_059_OM_SI2_H ['Cut'] = listcut
                    df_050_059_OM_SI2_H ['Polish'] = listpol
                    df_050_059_OM_SI2_H ['Symmetry'] = listsym
                    df_050_059_OM_SI2_H ['Ratio'] = listrat
                    df_050_059_OM_SI2_H ['PPC'] = listdesc
                    df_050_059_OM_SI2_H ['Total'] = listtotal
                    df_050_059_OM_SI2_H['Carat'] = df_050_059_OM_SI2_H['Carat'].astype('float64')
                    df_050_059_OM_SI2_H['PPC'] = df_050_059_OM_SI2_H['PPC'].astype('float64')
                    df_050_059_OM_SI2_H['Total'] = df_050_059_OM_SI2_H['Total'].astype('float64')
                    df_050_059_OM_SI2_H['Total'] = df_050_059_OM_SI2_H['Carat'] * df_050_059_OM_SI2_H['PPC']


                elif i=="H" and j == "I1" and k == "OM":
                    df_050_059_OM_I1_H = pd.DataFrame()
                    df_050_059_OM_I1_H ['Wt Range'] = None
                    df_050_059_OM_I1_H  = df_050_059_OM_I1_H.assign(Company=None)
                    df_050_059_OM_I1_H  = df_050_059_OM_I1_H.assign(Shape=None)
                    df_050_059_OM_I1_H  = df_050_059_OM_I1_H.assign(Carat=None)
                    df_050_059_OM_I1_H  = df_050_059_OM_I1_H.assign(Color=None)
                    df_050_059_OM_I1_H  = df_050_059_OM_I1_H.assign(Clarity=None)
                    df_050_059_OM_I1_H  = df_050_059_OM_I1_H.assign(Cut=None)
                    df_050_059_OM_I1_H  = df_050_059_OM_I1_H.assign(Polish=None)
                    df_050_059_OM_I1_H  = df_050_059_OM_I1_H.assign(Symmetry=None)
                    df_050_059_OM_I1_H  = df_050_059_OM_I1_H.assign(Ratio=None)
                    df_050_059_OM_I1_H  = df_050_059_OM_I1_H.assign(PPC=None)
                    df_050_059_OM_I1_H  = df_050_059_OM_I1_H.assign(Total=None)
                    df_050_059_OM_I1_H ['Wt Range'] = listwtrange
                    df_050_059_OM_I1_H ['Company'] = listcom
                    df_050_059_OM_I1_H ['Shape'] = listshap
                    df_050_059_OM_I1_H ['Carat'] = listcar
                    df_050_059_OM_I1_H ['Color'] = listcol
                    df_050_059_OM_I1_H ['Clarity'] = listclar
                    df_050_059_OM_I1_H ['Cut'] = listcut
                    df_050_059_OM_I1_H ['Polish'] = listpol
                    df_050_059_OM_I1_H ['Symmetry'] = listsym
                    df_050_059_OM_I1_H ['Ratio'] = listrat
                    df_050_059_OM_I1_H ['PPC'] = listdesc
                    df_050_059_OM_I1_H ['Total'] = listtotal
                    df_050_059_OM_I1_H['Carat'] = df_050_059_OM_I1_H['Carat'].astype('float64')
                    df_050_059_OM_I1_H['PPC'] = df_050_059_OM_I1_H['PPC'].astype('float64')
                    df_050_059_OM_I1_H['Total'] = df_050_059_OM_I1_H['Total'].astype('float64')
                    df_050_059_OM_I1_H['Total'] = df_050_059_OM_I1_H['Carat'] * df_050_059_OM_I1_H['PPC']


                elif i=="H" and j == "I2" and k == "OM":
                    df_050_059_OM_I2_H = pd.DataFrame()
                    df_050_059_OM_I2_H ['Wt Range'] = None
                    df_050_059_OM_I2_H  = df_050_059_OM_I2_H.assign(Company=None)
                    df_050_059_OM_I2_H  = df_050_059_OM_I2_H.assign(Shape=None)
                    df_050_059_OM_I2_H  = df_050_059_OM_I2_H.assign(Carat=None)
                    df_050_059_OM_I2_H  = df_050_059_OM_I2_H.assign(Color=None)
                    df_050_059_OM_I2_H  = df_050_059_OM_I2_H.assign(Clarity=None)
                    df_050_059_OM_I2_H  = df_050_059_OM_I2_H.assign(Cut=None)
                    df_050_059_OM_I2_H  = df_050_059_OM_I2_H.assign(Polish=None)
                    df_050_059_OM_I2_H  = df_050_059_OM_I2_H.assign(Symmetry=None)
                    df_050_059_OM_I2_H  = df_050_059_OM_I2_H.assign(Ratio=None)
                    df_050_059_OM_I2_H  = df_050_059_OM_I2_H.assign(PPC=None)
                    df_050_059_OM_I2_H  = df_050_059_OM_I2_H.assign(Total=None)
                    df_050_059_OM_I2_H ['Wt Range'] = listwtrange
                    df_050_059_OM_I2_H ['Company'] = listcom
                    df_050_059_OM_I2_H ['Shape'] = listshap
                    df_050_059_OM_I2_H ['Carat'] = listcar
                    df_050_059_OM_I2_H ['Color'] = listcol
                    df_050_059_OM_I2_H ['Clarity'] = listclar
                    df_050_059_OM_I2_H ['Cut'] = listcut
                    df_050_059_OM_I2_H ['Polish'] = listpol
                    df_050_059_OM_I2_H ['Symmetry'] = listsym
                    df_050_059_OM_I2_H ['Ratio'] = listrat
                    df_050_059_OM_I2_H ['PPC'] = listdesc
                    df_050_059_OM_I2_H ['Total'] = listtotal
                    df_050_059_OM_I2_H['Carat'] = df_050_059_OM_I2_H['Carat'].astype('float64')
                    df_050_059_OM_I2_H['PPC'] = df_050_059_OM_I2_H['PPC'].astype('float64')
                    df_050_059_OM_I2_H['Total'] = df_050_059_OM_I2_H['Total'].astype('float64')
                    df_050_059_OM_I2_H['Total'] = df_050_059_OM_I2_H['Carat'] * df_050_059_OM_I2_H['PPC']



                elif i== "I" and j == "IF" and k == "OM":
                    df_050_059_OM_IF_I = pd.DataFrame()
                    df_050_059_OM_IF_I ['Wt Range'] = None
                    df_050_059_OM_IF_I  = df_050_059_OM_IF_I.assign(Company=None)
                    df_050_059_OM_IF_I  = df_050_059_OM_IF_I.assign(Shape=None)
                    df_050_059_OM_IF_I  = df_050_059_OM_IF_I.assign(Carat=None)
                    df_050_059_OM_IF_I  = df_050_059_OM_IF_I.assign(Color=None)
                    df_050_059_OM_IF_I  = df_050_059_OM_IF_I.assign(Clarity=None)
                    df_050_059_OM_IF_I  = df_050_059_OM_IF_I.assign(Cut=None)
                    df_050_059_OM_IF_I  = df_050_059_OM_IF_I.assign(Polish=None)
                    df_050_059_OM_IF_I  = df_050_059_OM_IF_I.assign(Symmetry=None)
                    df_050_059_OM_IF_I  = df_050_059_OM_IF_I.assign(Ratio=None)
                    df_050_059_OM_IF_I  = df_050_059_OM_IF_I.assign(PPC=None)
                    df_050_059_OM_IF_I  = df_050_059_OM_IF_I.assign(Total=None)
                    df_050_059_OM_IF_I ['Wt Range'] = listwtrange
                    df_050_059_OM_IF_I ['Company'] = listcom
                    df_050_059_OM_IF_I ['Shape'] = listshap
                    df_050_059_OM_IF_I ['Carat'] = listcar
                    df_050_059_OM_IF_I ['Color'] = listcol
                    df_050_059_OM_IF_I ['Clarity'] = listclar
                    df_050_059_OM_IF_I ['Cut'] = listcut
                    df_050_059_OM_IF_I ['Polish'] = listpol
                    df_050_059_OM_IF_I ['Symmetry'] = listsym
                    df_050_059_OM_IF_I ['Ratio'] = listrat
                    df_050_059_OM_IF_I ['PPC'] = listdesc
                    df_050_059_OM_IF_I ['Total'] = listtotal
                    df_050_059_OM_IF_I['Carat'] = df_050_059_OM_IF_I['Carat'].astype('float64')
                    df_050_059_OM_IF_I['PPC'] = df_050_059_OM_IF_I['PPC'].astype('float64')
                    df_050_059_OM_IF_I['Total'] = df_050_059_OM_IF_I['Total'].astype('float64')
                    df_050_059_OM_IF_I['Total'] = df_050_059_OM_IF_I['Carat'] * df_050_059_OM_IF_I['PPC']



                elif i== "I" and j == "VVS1" and k == "OM":
                    df_050_059_OM_VVS1_I = pd.DataFrame()
                    df_050_059_OM_VVS1_I ['Wt Range'] = None
                    df_050_059_OM_VVS1_I  = df_050_059_OM_VVS1_I.assign(Company=None)
                    df_050_059_OM_VVS1_I  = df_050_059_OM_VVS1_I.assign(Shape=None)
                    df_050_059_OM_VVS1_I  = df_050_059_OM_VVS1_I.assign(Carat=None)
                    df_050_059_OM_VVS1_I  = df_050_059_OM_VVS1_I.assign(Color=None)
                    df_050_059_OM_VVS1_I  = df_050_059_OM_VVS1_I.assign(Clarity=None)
                    df_050_059_OM_VVS1_I  = df_050_059_OM_VVS1_I.assign(Cut=None)
                    df_050_059_OM_VVS1_I  = df_050_059_OM_VVS1_I.assign(Polish=None)
                    df_050_059_OM_VVS1_I  = df_050_059_OM_VVS1_I.assign(Symmetry=None)
                    df_050_059_OM_VVS1_I  = df_050_059_OM_VVS1_I.assign(Ratio=None)
                    df_050_059_OM_VVS1_I  = df_050_059_OM_VVS1_I.assign(PPC=None)
                    df_050_059_OM_VVS1_I  = df_050_059_OM_VVS1_I.assign(Total=None)
                    df_050_059_OM_VVS1_I ['Wt Range'] = listwtrange
                    df_050_059_OM_VVS1_I ['Company'] = listcom
                    df_050_059_OM_VVS1_I ['Shape'] = listshap
                    df_050_059_OM_VVS1_I ['Carat'] = listcar
                    df_050_059_OM_VVS1_I ['Color'] = listcol
                    df_050_059_OM_VVS1_I ['Clarity'] = listclar
                    df_050_059_OM_VVS1_I ['Cut'] = listcut
                    df_050_059_OM_VVS1_I ['Polish'] = listpol
                    df_050_059_OM_VVS1_I ['Symmetry'] = listsym
                    df_050_059_OM_VVS1_I ['Ratio'] = listrat
                    df_050_059_OM_VVS1_I ['PPC'] = listdesc
                    df_050_059_OM_VVS1_I ['Total'] = listtotal
                    df_050_059_OM_VVS1_I['Carat'] = df_050_059_OM_VVS1_I['Carat'].astype('float64')
                    df_050_059_OM_VVS1_I['PPC'] = df_050_059_OM_VVS1_I['PPC'].astype('float64')
                    df_050_059_OM_VVS1_I['Total'] = df_050_059_OM_VVS1_I['Total'].astype('float64')
                    df_050_059_OM_VVS1_I['Total'] = df_050_059_OM_VVS1_I['Carat'] * df_050_059_OM_VVS1_I['PPC']


                elif i== "I" and j == "VVS2" and k == "OM":
                    df_050_059_OM_VVS2_I = pd.DataFrame()
                    df_050_059_OM_VVS2_I ['Wt Range'] = None
                    df_050_059_OM_VVS2_I  = df_050_059_OM_VVS2_I.assign(Company=None)
                    df_050_059_OM_VVS2_I  = df_050_059_OM_VVS2_I.assign(Shape=None)
                    df_050_059_OM_VVS2_I  = df_050_059_OM_VVS2_I.assign(Carat=None)
                    df_050_059_OM_VVS2_I  = df_050_059_OM_VVS2_I.assign(Color=None)
                    df_050_059_OM_VVS2_I  = df_050_059_OM_VVS2_I.assign(Clarity=None)
                    df_050_059_OM_VVS2_I  = df_050_059_OM_VVS2_I.assign(Cut=None)
                    df_050_059_OM_VVS2_I  = df_050_059_OM_VVS2_I.assign(Polish=None)
                    df_050_059_OM_VVS2_I  = df_050_059_OM_VVS2_I.assign(Symmetry=None)
                    df_050_059_OM_VVS2_I  = df_050_059_OM_VVS2_I.assign(Ratio=None)
                    df_050_059_OM_VVS2_I  = df_050_059_OM_VVS2_I.assign(PPC=None)
                    df_050_059_OM_VVS2_I  = df_050_059_OM_VVS2_I.assign(Total=None)
                    df_050_059_OM_VVS2_I ['Wt Range'] = listwtrange
                    df_050_059_OM_VVS2_I ['Company'] = listcom
                    df_050_059_OM_VVS2_I ['Shape'] = listshap
                    df_050_059_OM_VVS2_I ['Carat'] = listcar
                    df_050_059_OM_VVS2_I ['Color'] = listcol
                    df_050_059_OM_VVS2_I ['Clarity'] = listclar
                    df_050_059_OM_VVS2_I ['Cut'] = listcut
                    df_050_059_OM_VVS2_I ['Polish'] = listpol
                    df_050_059_OM_VVS2_I ['Symmetry'] = listsym
                    df_050_059_OM_VVS2_I ['Ratio'] = listrat
                    df_050_059_OM_VVS2_I ['PPC'] = listdesc
                    df_050_059_OM_VVS2_I ['Total'] = listtotal
                    df_050_059_OM_VVS2_I['Carat'] = df_050_059_OM_VVS2_I['Carat'].astype('float64')
                    df_050_059_OM_VVS2_I['PPC'] = df_050_059_OM_VVS2_I['PPC'].astype('float64')
                    df_050_059_OM_VVS2_I['Total'] = df_050_059_OM_VVS2_I['Total'].astype('float64')
                    df_050_059_OM_VVS2_I['Total'] = df_050_059_OM_VVS2_I['Carat'] * df_050_059_OM_VVS2_I['PPC']


                elif i== "I" and j=="VS1" and k == "OM":
                    df_050_059_OM_VS1_I = pd.DataFrame()
                    df_050_059_OM_VS1_I ['Wt Range'] = None
                    df_050_059_OM_VS1_I  = df_050_059_OM_VS1_I.assign(Company=None)
                    df_050_059_OM_VS1_I  = df_050_059_OM_VS1_I.assign(Shape=None)
                    df_050_059_OM_VS1_I  = df_050_059_OM_VS1_I.assign(Carat=None)
                    df_050_059_OM_VS1_I  = df_050_059_OM_VS1_I.assign(Color=None)
                    df_050_059_OM_VS1_I  = df_050_059_OM_VS1_I.assign(Clarity=None)
                    df_050_059_OM_VS1_I  = df_050_059_OM_VS1_I.assign(Cut=None)
                    df_050_059_OM_VS1_I  = df_050_059_OM_VS1_I.assign(Polish=None)
                    df_050_059_OM_VS1_I  = df_050_059_OM_VS1_I.assign(Symmetry=None)
                    df_050_059_OM_VS1_I  = df_050_059_OM_VS1_I.assign(Ratio=None)
                    df_050_059_OM_VS1_I  = df_050_059_OM_VS1_I.assign(PPC=None)
                    df_050_059_OM_VS1_I  = df_050_059_OM_VS1_I.assign(Total=None)
                    df_050_059_OM_VS1_I ['Wt Range'] = listwtrange
                    df_050_059_OM_VS1_I ['Company'] = listcom
                    df_050_059_OM_VS1_I ['Shape'] = listshap
                    df_050_059_OM_VS1_I ['Carat'] = listcar
                    df_050_059_OM_VS1_I ['Color'] = listcol
                    df_050_059_OM_VS1_I ['Clarity'] = listclar
                    df_050_059_OM_VS1_I ['Cut'] = listcut
                    df_050_059_OM_VS1_I ['Polish'] = listpol
                    df_050_059_OM_VS1_I ['Symmetry'] = listsym
                    df_050_059_OM_VS1_I ['Ratio'] = listrat
                    df_050_059_OM_VS1_I ['PPC'] = listdesc
                    df_050_059_OM_VS1_I ['Total'] = listtotal
                    df_050_059_OM_VS1_I['Carat'] = df_050_059_OM_VS1_I['Carat'].astype('float64')
                    df_050_059_OM_VS1_I['PPC'] = df_050_059_OM_VS1_I['PPC'].astype('float64')
                    df_050_059_OM_VS1_I['Total'] = df_050_059_OM_VS1_I['Total'].astype('float64')
                    df_050_059_OM_VS1_I['Total'] = df_050_059_OM_VS1_I['Carat'] * df_050_059_OM_VS1_I['PPC']


                elif i== "I" and j == "VS2" and k == "OM":
                    df_050_059_OM_VS2_I = pd.DataFrame()
                    df_050_059_OM_VS2_I ['Wt Range'] = None
                    df_050_059_OM_VS2_I  = df_050_059_OM_VS2_I.assign(Company=None)
                    df_050_059_OM_VS2_I  = df_050_059_OM_VS2_I.assign(Shape=None)
                    df_050_059_OM_VS2_I  = df_050_059_OM_VS2_I.assign(Carat=None)
                    df_050_059_OM_VS2_I  = df_050_059_OM_VS2_I.assign(Color=None)
                    df_050_059_OM_VS2_I  = df_050_059_OM_VS2_I.assign(Clarity=None)
                    df_050_059_OM_VS2_I  = df_050_059_OM_VS2_I.assign(Cut=None)
                    df_050_059_OM_VS2_I  = df_050_059_OM_VS2_I.assign(Polish=None)
                    df_050_059_OM_VS2_I  = df_050_059_OM_VS2_I.assign(Symmetry=None)
                    df_050_059_OM_VS2_I  = df_050_059_OM_VS2_I.assign(Ratio=None)
                    df_050_059_OM_VS2_I  = df_050_059_OM_VS2_I.assign(PPC=None)
                    df_050_059_OM_VS2_I  = df_050_059_OM_VS2_I.assign(Total=None)
                    df_050_059_OM_VS2_I ['Wt Range'] = listwtrange
                    df_050_059_OM_VS2_I ['Company'] = listcom
                    df_050_059_OM_VS2_I ['Shape'] = listshap
                    df_050_059_OM_VS2_I ['Carat'] = listcar
                    df_050_059_OM_VS2_I ['Color'] = listcol
                    df_050_059_OM_VS2_I ['Clarity'] = listclar
                    df_050_059_OM_VS2_I ['Cut'] = listcut
                    df_050_059_OM_VS2_I ['Polish'] = listpol
                    df_050_059_OM_VS2_I ['Symmetry'] = listsym
                    df_050_059_OM_VS2_I ['Ratio'] = listrat
                    df_050_059_OM_VS2_I ['PPC'] = listdesc
                    df_050_059_OM_VS2_I ['Total'] = listtotal
                    df_050_059_OM_VS2_I['Carat'] = df_050_059_OM_VS2_I['Carat'].astype('float64')
                    df_050_059_OM_VS2_I['PPC'] = df_050_059_OM_VS2_I['PPC'].astype('float64')
                    df_050_059_OM_VS2_I['Total'] = df_050_059_OM_VS2_I['Total'].astype('float64')
                    df_050_059_OM_VS2_I['Total'] = df_050_059_OM_VS2_I['Carat'] * df_050_059_OM_VS2_I['PPC']


                elif i== "I" and j == "SI1" and k == "OM":
                    df_050_059_OM_SI1_I = pd.DataFrame()
                    df_050_059_OM_SI1_I ['Wt Range'] = None
                    df_050_059_OM_SI1_I  = df_050_059_OM_SI1_I.assign(Company=None)
                    df_050_059_OM_SI1_I  = df_050_059_OM_SI1_I.assign(Shape=None)
                    df_050_059_OM_SI1_I  = df_050_059_OM_SI1_I.assign(Carat=None)
                    df_050_059_OM_SI1_I  = df_050_059_OM_SI1_I.assign(Color=None)
                    df_050_059_OM_SI1_I  = df_050_059_OM_SI1_I.assign(Clarity=None)
                    df_050_059_OM_SI1_I  = df_050_059_OM_SI1_I.assign(Cut=None)
                    df_050_059_OM_SI1_I  = df_050_059_OM_SI1_I.assign(Polish=None)
                    df_050_059_OM_SI1_I  = df_050_059_OM_SI1_I.assign(Symmetry=None)
                    df_050_059_OM_SI1_I  = df_050_059_OM_SI1_I.assign(Ratio=None)
                    df_050_059_OM_SI1_I  = df_050_059_OM_SI1_I.assign(PPC=None)
                    df_050_059_OM_SI1_I  = df_050_059_OM_SI1_I.assign(Total=None)
                    df_050_059_OM_SI1_I ['Wt Range'] = listwtrange
                    df_050_059_OM_SI1_I ['Company'] = listcom
                    df_050_059_OM_SI1_I ['Shape'] = listshap
                    df_050_059_OM_SI1_I ['Carat'] = listcar
                    df_050_059_OM_SI1_I ['Color'] = listcol
                    df_050_059_OM_SI1_I ['Clarity'] = listclar
                    df_050_059_OM_SI1_I ['Cut'] = listcut
                    df_050_059_OM_SI1_I ['Polish'] = listpol
                    df_050_059_OM_SI1_I ['Symmetry'] = listsym
                    df_050_059_OM_SI1_I ['Ratio'] = listrat
                    df_050_059_OM_SI1_I ['PPC'] = listdesc
                    df_050_059_OM_SI1_I ['Total'] = listtotal
                    df_050_059_OM_SI1_I['Carat'] = df_050_059_OM_SI1_I['Carat'].astype('float64')
                    df_050_059_OM_SI1_I['PPC'] = df_050_059_OM_SI1_I['PPC'].astype('float64')
                    df_050_059_OM_SI1_I['Total'] = df_050_059_OM_SI1_I['Total'].astype('float64')
                    df_050_059_OM_SI1_I['Total'] = df_050_059_OM_SI1_I['Carat'] * df_050_059_OM_SI1_I['PPC']


                elif i== "I" and j == "SI2" and k == "OM":
                    df_050_059_OM_SI2_I = pd.DataFrame()
                    df_050_059_OM_SI2_I ['Wt Range'] = None
                    df_050_059_OM_SI2_I  = df_050_059_OM_SI2_I.assign(Company=None)
                    df_050_059_OM_SI2_I  = df_050_059_OM_SI2_I.assign(Shape=None)
                    df_050_059_OM_SI2_I  = df_050_059_OM_SI2_I.assign(Carat=None)
                    df_050_059_OM_SI2_I  = df_050_059_OM_SI2_I.assign(Color=None)
                    df_050_059_OM_SI2_I  = df_050_059_OM_SI2_I.assign(Clarity=None)
                    df_050_059_OM_SI2_I  = df_050_059_OM_SI2_I.assign(Cut=None)
                    df_050_059_OM_SI2_I  = df_050_059_OM_SI2_I.assign(Polish=None)
                    df_050_059_OM_SI2_I  = df_050_059_OM_SI2_I.assign(Symmetry=None)
                    df_050_059_OM_SI2_I  = df_050_059_OM_SI2_I.assign(Ratio=None)
                    df_050_059_OM_SI2_I  = df_050_059_OM_SI2_I.assign(PPC=None)
                    df_050_059_OM_SI2_I  = df_050_059_OM_SI2_I.assign(Total=None)
                    df_050_059_OM_SI2_I ['Wt Range'] = listwtrange
                    df_050_059_OM_SI2_I ['Company'] = listcom
                    df_050_059_OM_SI2_I ['Shape'] = listshap
                    df_050_059_OM_SI2_I ['Carat'] = listcar
                    df_050_059_OM_SI2_I ['Color'] = listcol
                    df_050_059_OM_SI2_I ['Clarity'] = listclar
                    df_050_059_OM_SI2_I ['Cut'] = listcut
                    df_050_059_OM_SI2_I ['Polish'] = listpol
                    df_050_059_OM_SI2_I ['Symmetry'] = listsym
                    df_050_059_OM_SI2_I ['Ratio'] = listrat
                    df_050_059_OM_SI2_I ['PPC'] = listdesc
                    df_050_059_OM_SI2_I ['Total'] = listtotal
                    df_050_059_OM_SI2_I['Carat'] = df_050_059_OM_SI2_I['Carat'].astype('float64')
                    df_050_059_OM_SI2_I['PPC'] = df_050_059_OM_SI2_I['PPC'].astype('float64')
                    df_050_059_OM_SI2_I['Total'] = df_050_059_OM_SI2_I['Total'].astype('float64')
                    df_050_059_OM_SI2_I['Total'] = df_050_059_OM_SI2_I['Carat'] * df_050_059_OM_SI2_I['PPC']


                elif i== "I" and j == "I1" and k == "OM":
                    df_050_059_OM_I1_I = pd.DataFrame()
                    df_050_059_OM_I1_I ['Wt Range'] = None
                    df_050_059_OM_I1_I  = df_050_059_OM_I1_I.assign(Company=None)
                    df_050_059_OM_I1_I  = df_050_059_OM_I1_I.assign(Shape=None)
                    df_050_059_OM_I1_I  = df_050_059_OM_I1_I.assign(Carat=None)
                    df_050_059_OM_I1_I  = df_050_059_OM_I1_I.assign(Color=None)
                    df_050_059_OM_I1_I  = df_050_059_OM_I1_I.assign(Clarity=None)
                    df_050_059_OM_I1_I  = df_050_059_OM_I1_I.assign(Cut=None)
                    df_050_059_OM_I1_I  = df_050_059_OM_I1_I.assign(Polish=None)
                    df_050_059_OM_I1_I  = df_050_059_OM_I1_I.assign(Symmetry=None)
                    df_050_059_OM_I1_I  = df_050_059_OM_I1_I.assign(Ratio=None)
                    df_050_059_OM_I1_I  = df_050_059_OM_I1_I.assign(PPC=None)
                    df_050_059_OM_I1_I  = df_050_059_OM_I1_I.assign(Total=None)
                    df_050_059_OM_I1_I ['Wt Range'] = listwtrange
                    df_050_059_OM_I1_I ['Company'] = listcom
                    df_050_059_OM_I1_I ['Shape'] = listshap
                    df_050_059_OM_I1_I ['Carat'] = listcar
                    df_050_059_OM_I1_I ['Color'] = listcol
                    df_050_059_OM_I1_I ['Clarity'] = listclar
                    df_050_059_OM_I1_I ['Cut'] = listcut
                    df_050_059_OM_I1_I ['Polish'] = listpol
                    df_050_059_OM_I1_I ['Symmetry'] = listsym
                    df_050_059_OM_I1_I ['Ratio'] = listrat
                    df_050_059_OM_I1_I ['PPC'] = listdesc
                    df_050_059_OM_I1_I ['Total'] = listtotal
                    df_050_059_OM_I1_I['Carat'] = df_050_059_OM_I1_I['Carat'].astype('float64')
                    df_050_059_OM_I1_I['PPC'] = df_050_059_OM_I1_I['PPC'].astype('float64')
                    df_050_059_OM_I1_I['Total'] = df_050_059_OM_I1_I['Total'].astype('float64')
                    df_050_059_OM_I1_I['Total'] = df_050_059_OM_I1_I['Carat'] * df_050_059_OM_I1_I['PPC']


                elif i== "I" and j == "I2" and k == "OM":
                    df_050_059_OM_I2_I = pd.DataFrame()
                    df_050_059_OM_I2_I ['Wt Range'] = None
                    df_050_059_OM_I2_I  = df_050_059_OM_I2_I.assign(Company=None)
                    df_050_059_OM_I2_I  = df_050_059_OM_I2_I.assign(Shape=None)
                    df_050_059_OM_I2_I  = df_050_059_OM_I2_I.assign(Carat=None)
                    df_050_059_OM_I2_I  = df_050_059_OM_I2_I.assign(Color=None)
                    df_050_059_OM_I2_I  = df_050_059_OM_I2_I.assign(Clarity=None)
                    df_050_059_OM_I2_I  = df_050_059_OM_I2_I.assign(Cut=None)
                    df_050_059_OM_I2_I  = df_050_059_OM_I2_I.assign(Polish=None)
                    df_050_059_OM_I2_I  = df_050_059_OM_I2_I.assign(Symmetry=None)
                    df_050_059_OM_I2_I  = df_050_059_OM_I2_I.assign(Ratio=None)
                    df_050_059_OM_I2_I  = df_050_059_OM_I2_I.assign(PPC=None)
                    df_050_059_OM_I2_I  = df_050_059_OM_I2_I.assign(Total=None)
                    df_050_059_OM_I2_I ['Wt Range'] = listwtrange
                    df_050_059_OM_I2_I ['Company'] = listcom
                    df_050_059_OM_I2_I ['Shape'] = listshap
                    df_050_059_OM_I2_I ['Carat'] = listcar
                    df_050_059_OM_I2_I ['Color'] = listcol
                    df_050_059_OM_I2_I ['Clarity'] = listclar
                    df_050_059_OM_I2_I ['Cut'] = listcut
                    df_050_059_OM_I2_I ['Polish'] = listpol
                    df_050_059_OM_I2_I ['Symmetry'] = listsym
                    df_050_059_OM_I2_I ['Ratio'] = listrat
                    df_050_059_OM_I2_I ['PPC'] = listdesc
                    df_050_059_OM_I2_I ['Total'] = listtotal
                    df_050_059_OM_I2_I['Carat'] = df_050_059_OM_I2_I['Carat'].astype('float64')
                    df_050_059_OM_I2_I['PPC'] = df_050_059_OM_I2_I['PPC'].astype('float64')
                    df_050_059_OM_I2_I['Total'] = df_050_059_OM_I2_I['Total'].astype('float64')
                    df_050_059_OM_I2_I['Total'] = df_050_059_OM_I2_I['Carat'] * df_050_059_OM_I2_I['PPC']


                elif i=="J" and j == "IF" and k == "OM":
                    df_050_059_OM_IF_J = pd.DataFrame()
                    df_050_059_OM_IF_J ['Wt Range'] = None
                    df_050_059_OM_IF_J  = df_050_059_OM_IF_J.assign(Company=None)
                    df_050_059_OM_IF_J  = df_050_059_OM_IF_J.assign(Shape=None)
                    df_050_059_OM_IF_J  = df_050_059_OM_IF_J.assign(Carat=None)
                    df_050_059_OM_IF_J  = df_050_059_OM_IF_J.assign(Color=None)
                    df_050_059_OM_IF_J  = df_050_059_OM_IF_J.assign(Clarity=None)
                    df_050_059_OM_IF_J  = df_050_059_OM_IF_J.assign(Cut=None)
                    df_050_059_OM_IF_J  = df_050_059_OM_IF_J.assign(Polish=None)
                    df_050_059_OM_IF_J  = df_050_059_OM_IF_J.assign(Symmetry=None)
                    df_050_059_OM_IF_J  = df_050_059_OM_IF_J.assign(Ratio=None)
                    df_050_059_OM_IF_J  = df_050_059_OM_IF_J.assign(PPC=None)
                    df_050_059_OM_IF_J  = df_050_059_OM_IF_J.assign(Total=None)
                    df_050_059_OM_IF_J ['Wt Range'] = listwtrange
                    df_050_059_OM_IF_J ['Company'] = listcom
                    df_050_059_OM_IF_J ['Shape'] = listshap
                    df_050_059_OM_IF_J ['Carat'] = listcar
                    df_050_059_OM_IF_J ['Color'] = listcol
                    df_050_059_OM_IF_J ['Clarity'] = listclar
                    df_050_059_OM_IF_J ['Cut'] = listcut
                    df_050_059_OM_IF_J ['Polish'] = listpol
                    df_050_059_OM_IF_J ['Symmetry'] = listsym
                    df_050_059_OM_IF_J ['Ratio'] = listrat
                    df_050_059_OM_IF_J ['PPC'] = listdesc
                    df_050_059_OM_IF_J ['Total'] = listtotal
                    df_050_059_OM_IF_J['Carat'] = df_050_059_OM_IF_J['Carat'].astype('float64')
                    df_050_059_OM_IF_J['PPC'] = df_050_059_OM_IF_J['PPC'].astype('float64')
                    df_050_059_OM_IF_J['Total'] = df_050_059_OM_IF_J['Total'].astype('float64')
                    df_050_059_OM_IF_J['Total'] = df_050_059_OM_IF_J['Carat'] * df_050_059_OM_IF_J['PPC']



                elif i=="J"  and j == "VVS1" and k == "OM":
                    df_050_059_OM_VVS1_J = pd.DataFrame()
                    df_050_059_OM_VVS1_J ['Wt Range'] = None
                    df_050_059_OM_VVS1_J  = df_050_059_OM_VVS1_J.assign(Company=None)
                    df_050_059_OM_VVS1_J  = df_050_059_OM_VVS1_J.assign(Shape=None)
                    df_050_059_OM_VVS1_J  = df_050_059_OM_VVS1_J.assign(Carat=None)
                    df_050_059_OM_VVS1_J  = df_050_059_OM_VVS1_J.assign(Color=None)
                    df_050_059_OM_VVS1_J  = df_050_059_OM_VVS1_J.assign(Clarity=None)
                    df_050_059_OM_VVS1_J  = df_050_059_OM_VVS1_J.assign(Cut=None)
                    df_050_059_OM_VVS1_J  = df_050_059_OM_VVS1_J.assign(Polish=None)
                    df_050_059_OM_VVS1_J  = df_050_059_OM_VVS1_J.assign(Symmetry=None)
                    df_050_059_OM_VVS1_J  = df_050_059_OM_VVS1_J.assign(Ratio=None)
                    df_050_059_OM_VVS1_J  = df_050_059_OM_VVS1_J.assign(PPC=None)
                    df_050_059_OM_VVS1_J  = df_050_059_OM_VVS1_J.assign(Total=None)
                    df_050_059_OM_VVS1_J ['Wt Range'] = listwtrange
                    df_050_059_OM_VVS1_J ['Company'] = listcom
                    df_050_059_OM_VVS1_J ['Shape'] = listshap
                    df_050_059_OM_VVS1_J ['Carat'] = listcar
                    df_050_059_OM_VVS1_J ['Color'] = listcol
                    df_050_059_OM_VVS1_J ['Clarity'] = listclar
                    df_050_059_OM_VVS1_J ['Cut'] = listcut
                    df_050_059_OM_VVS1_J ['Polish'] = listpol
                    df_050_059_OM_VVS1_J ['Symmetry'] = listsym
                    df_050_059_OM_VVS1_J ['Ratio'] = listrat
                    df_050_059_OM_VVS1_J ['PPC'] = listdesc
                    df_050_059_OM_VVS1_J ['Total'] = listtotal
                    df_050_059_OM_VVS1_J['Carat'] = df_050_059_OM_VVS1_J['Carat'].astype('float64')
                    df_050_059_OM_VVS1_J['PPC'] = df_050_059_OM_VVS1_J['PPC'].astype('float64')
                    df_050_059_OM_VVS1_J['Total'] = df_050_059_OM_VVS1_J['Total'].astype('float64')
                    df_050_059_OM_VVS1_J['Total'] = df_050_059_OM_VVS1_J['Carat'] * df_050_059_OM_VVS1_J['PPC']


                elif i=="J"  and j == "VVS2" and k == "OM":
                    df_050_059_OM_VVS2_J = pd.DataFrame()
                    df_050_059_OM_VVS2_J ['Wt Range'] = None
                    df_050_059_OM_VVS2_J  = df_050_059_OM_VVS2_J.assign(Company=None)
                    df_050_059_OM_VVS2_J  = df_050_059_OM_VVS2_J.assign(Shape=None)
                    df_050_059_OM_VVS2_J  = df_050_059_OM_VVS2_J.assign(Carat=None)
                    df_050_059_OM_VVS2_J  = df_050_059_OM_VVS2_J.assign(Color=None)
                    df_050_059_OM_VVS2_J  = df_050_059_OM_VVS2_J.assign(Clarity=None)
                    df_050_059_OM_VVS2_J  = df_050_059_OM_VVS2_J.assign(Cut=None)
                    df_050_059_OM_VVS2_J  = df_050_059_OM_VVS2_J.assign(Polish=None)
                    df_050_059_OM_VVS2_J  = df_050_059_OM_VVS2_J.assign(Symmetry=None)
                    df_050_059_OM_VVS2_J  = df_050_059_OM_VVS2_J.assign(Ratio=None)
                    df_050_059_OM_VVS2_J  = df_050_059_OM_VVS2_J.assign(PPC=None)
                    df_050_059_OM_VVS2_J  = df_050_059_OM_VVS2_J.assign(Total=None)
                    df_050_059_OM_VVS2_J ['Wt Range'] = listwtrange
                    df_050_059_OM_VVS2_J ['Company'] = listcom
                    df_050_059_OM_VVS2_J ['Shape'] = listshap
                    df_050_059_OM_VVS2_J ['Carat'] = listcar
                    df_050_059_OM_VVS2_J ['Color'] = listcol
                    df_050_059_OM_VVS2_J ['Clarity'] = listclar
                    df_050_059_OM_VVS2_J ['Cut'] = listcut
                    df_050_059_OM_VVS2_J ['Polish'] = listpol
                    df_050_059_OM_VVS2_J ['Symmetry'] = listsym
                    df_050_059_OM_VVS2_J ['Ratio'] = listrat
                    df_050_059_OM_VVS2_J ['PPC'] = listdesc
                    df_050_059_OM_VVS2_J ['Total'] = listtotal
                    df_050_059_OM_VVS2_J['Carat'] = df_050_059_OM_VVS2_J['Carat'].astype('float64')
                    df_050_059_OM_VVS2_J['PPC'] = df_050_059_OM_VVS2_J['PPC'].astype('float64')
                    df_050_059_OM_VVS2_J['Total'] = df_050_059_OM_VVS2_J['Total'].astype('float64')
                    df_050_059_OM_VVS2_J['Total'] = df_050_059_OM_VVS2_J['Carat'] * df_050_059_OM_VVS2_J['PPC']


                elif i=="J"  and j=="VS1" and k == "OM":
                    df_050_059_OM_VS1_J = pd.DataFrame()
                    df_050_059_OM_VS1_J ['Wt Range'] = None
                    df_050_059_OM_VS1_J  = df_050_059_OM_VS1_J.assign(Company=None)
                    df_050_059_OM_VS1_J  = df_050_059_OM_VS1_J.assign(Shape=None)
                    df_050_059_OM_VS1_J  = df_050_059_OM_VS1_J.assign(Carat=None)
                    df_050_059_OM_VS1_J  = df_050_059_OM_VS1_J.assign(Color=None)
                    df_050_059_OM_VS1_J  = df_050_059_OM_VS1_J.assign(Clarity=None)
                    df_050_059_OM_VS1_J  = df_050_059_OM_VS1_J.assign(Cut=None)
                    df_050_059_OM_VS1_J  = df_050_059_OM_VS1_J.assign(Polish=None)
                    df_050_059_OM_VS1_J  = df_050_059_OM_VS1_J.assign(Symmetry=None)
                    df_050_059_OM_VS1_J  = df_050_059_OM_VS1_J.assign(Ratio=None)
                    df_050_059_OM_VS1_J  = df_050_059_OM_VS1_J.assign(PPC=None)
                    df_050_059_OM_VS1_J  = df_050_059_OM_VS1_J.assign(Total=None)
                    df_050_059_OM_VS1_J ['Wt Range'] = listwtrange
                    df_050_059_OM_VS1_J ['Company'] = listcom
                    df_050_059_OM_VS1_J ['Shape'] = listshap
                    df_050_059_OM_VS1_J ['Carat'] = listcar
                    df_050_059_OM_VS1_J ['Color'] = listcol
                    df_050_059_OM_VS1_J ['Clarity'] = listclar
                    df_050_059_OM_VS1_J ['Cut'] = listcut
                    df_050_059_OM_VS1_J ['Polish'] = listpol
                    df_050_059_OM_VS1_J ['Symmetry'] = listsym
                    df_050_059_OM_VS1_J ['Ratio'] = listrat
                    df_050_059_OM_VS1_J ['PPC'] = listdesc
                    df_050_059_OM_VS1_J ['Total'] = listtotal
                    df_050_059_OM_VS1_J['Carat'] = df_050_059_OM_VS1_J['Carat'].astype('float64')
                    df_050_059_OM_VS1_J['PPC'] = df_050_059_OM_VS1_J['PPC'].astype('float64')
                    df_050_059_OM_VS1_J['Total'] = df_050_059_OM_VS1_J['Total'].astype('float64')
                    df_050_059_OM_VS1_J['Total'] = df_050_059_OM_VS1_J['Carat'] * df_050_059_OM_VS1_J['PPC']


                elif i=="J"  and j == "VS2" and k == "OM":
                    df_050_059_OM_VS2_J = pd.DataFrame()
                    df_050_059_OM_VS2_J ['Wt Range'] = None
                    df_050_059_OM_VS2_J  = df_050_059_OM_VS2_J.assign(Company=None)
                    df_050_059_OM_VS2_J  = df_050_059_OM_VS2_J.assign(Shape=None)
                    df_050_059_OM_VS2_J  = df_050_059_OM_VS2_J.assign(Carat=None)
                    df_050_059_OM_VS2_J  = df_050_059_OM_VS2_J.assign(Color=None)
                    df_050_059_OM_VS2_J  = df_050_059_OM_VS2_J.assign(Clarity=None)
                    df_050_059_OM_VS2_J  = df_050_059_OM_VS2_J.assign(Cut=None)
                    df_050_059_OM_VS2_J  = df_050_059_OM_VS2_J.assign(Polish=None)
                    df_050_059_OM_VS2_J  = df_050_059_OM_VS2_J.assign(Symmetry=None)
                    df_050_059_OM_VS2_J  = df_050_059_OM_VS2_J.assign(Ratio=None)
                    df_050_059_OM_VS2_J  = df_050_059_OM_VS2_J.assign(PPC=None)
                    df_050_059_OM_VS2_J  = df_050_059_OM_VS2_J.assign(Total=None)
                    df_050_059_OM_VS2_J ['Wt Range'] = listwtrange
                    df_050_059_OM_VS2_J ['Company'] = listcom
                    df_050_059_OM_VS2_J ['Shape'] = listshap
                    df_050_059_OM_VS2_J ['Carat'] = listcar
                    df_050_059_OM_VS2_J ['Color'] = listcol
                    df_050_059_OM_VS2_J ['Clarity'] = listclar
                    df_050_059_OM_VS2_J ['Cut'] = listcut
                    df_050_059_OM_VS2_J ['Polish'] = listpol
                    df_050_059_OM_VS2_J ['Symmetry'] = listsym
                    df_050_059_OM_VS2_J ['Ratio'] = listrat
                    df_050_059_OM_VS2_J ['PPC'] = listdesc
                    df_050_059_OM_VS2_J ['Total'] = listtotal
                    df_050_059_OM_VS2_J['Carat'] = df_050_059_OM_VS2_J['Carat'].astype('float64')
                    df_050_059_OM_VS2_J['PPC'] = df_050_059_OM_VS2_J['PPC'].astype('float64')
                    df_050_059_OM_VS2_J['Total'] = df_050_059_OM_VS2_J['Total'].astype('float64')
                    df_050_059_OM_VS2_J['Total'] = df_050_059_OM_VS2_J['Carat'] * df_050_059_OM_VS2_J['PPC']


                elif i=="J"  and j == "SI1" and k == "OM":
                    df_050_059_OM_SI1_J = pd.DataFrame()
                    df_050_059_OM_SI1_J ['Wt Range'] = None
                    df_050_059_OM_SI1_J  = df_050_059_OM_SI1_J.assign(Company=None)
                    df_050_059_OM_SI1_J  = df_050_059_OM_SI1_J.assign(Shape=None)
                    df_050_059_OM_SI1_J  = df_050_059_OM_SI1_J.assign(Carat=None)
                    df_050_059_OM_SI1_J  = df_050_059_OM_SI1_J.assign(Color=None)
                    df_050_059_OM_SI1_J  = df_050_059_OM_SI1_J.assign(Clarity=None)
                    df_050_059_OM_SI1_J  = df_050_059_OM_SI1_J.assign(Cut=None)
                    df_050_059_OM_SI1_J  = df_050_059_OM_SI1_J.assign(Polish=None)
                    df_050_059_OM_SI1_J  = df_050_059_OM_SI1_J.assign(Symmetry=None)
                    df_050_059_OM_SI1_J  = df_050_059_OM_SI1_J.assign(Ratio=None)
                    df_050_059_OM_SI1_J  = df_050_059_OM_SI1_J.assign(PPC=None)
                    df_050_059_OM_SI1_J  = df_050_059_OM_SI1_J.assign(Total=None)
                    df_050_059_OM_SI1_J ['Wt Range'] = listwtrange
                    df_050_059_OM_SI1_J ['Company'] = listcom
                    df_050_059_OM_SI1_J ['Shape'] = listshap
                    df_050_059_OM_SI1_J ['Carat'] = listcar
                    df_050_059_OM_SI1_J ['Color'] = listcol
                    df_050_059_OM_SI1_J ['Clarity'] = listclar
                    df_050_059_OM_SI1_J ['Cut'] = listcut
                    df_050_059_OM_SI1_J ['Polish'] = listpol
                    df_050_059_OM_SI1_J ['Symmetry'] = listsym
                    df_050_059_OM_SI1_J ['Ratio'] = listrat
                    df_050_059_OM_SI1_J ['PPC'] = listdesc
                    df_050_059_OM_SI1_J ['Total'] = listtotal
                    df_050_059_OM_SI1_J['Carat'] = df_050_059_OM_SI1_J['Carat'].astype('float64')
                    df_050_059_OM_SI1_J['PPC'] = df_050_059_OM_SI1_J['PPC'].astype('float64')
                    df_050_059_OM_SI1_J['Total'] = df_050_059_OM_SI1_J['Total'].astype('float64')
                    df_050_059_OM_SI1_J['Total'] = df_050_059_OM_SI1_J['Carat'] * df_050_059_OM_SI1_J['PPC']


                elif i=="J"  and j == "SI2" and k == "OM":
                    df_050_059_OM_SI2_J = pd.DataFrame()
                    df_050_059_OM_SI2_J ['Wt Range'] = None
                    df_050_059_OM_SI2_J  = df_050_059_OM_SI2_J.assign(Company=None)
                    df_050_059_OM_SI2_J  = df_050_059_OM_SI2_J.assign(Shape=None)
                    df_050_059_OM_SI2_J  = df_050_059_OM_SI2_J.assign(Carat=None)
                    df_050_059_OM_SI2_J  = df_050_059_OM_SI2_J.assign(Color=None)
                    df_050_059_OM_SI2_J  = df_050_059_OM_SI2_J.assign(Clarity=None)
                    df_050_059_OM_SI2_J  = df_050_059_OM_SI2_J.assign(Cut=None)
                    df_050_059_OM_SI2_J  = df_050_059_OM_SI2_J.assign(Polish=None)
                    df_050_059_OM_SI2_J  = df_050_059_OM_SI2_J.assign(Symmetry=None)
                    df_050_059_OM_SI2_J  = df_050_059_OM_SI2_J.assign(Ratio=None)
                    df_050_059_OM_SI2_J  = df_050_059_OM_SI2_J.assign(PPC=None)
                    df_050_059_OM_SI2_J  = df_050_059_OM_SI2_J.assign(Total=None)
                    df_050_059_OM_SI2_J ['Wt Range'] = listwtrange
                    df_050_059_OM_SI2_J ['Company'] = listcom
                    df_050_059_OM_SI2_J ['Shape'] = listshap
                    df_050_059_OM_SI2_J ['Carat'] = listcar
                    df_050_059_OM_SI2_J ['Color'] = listcol
                    df_050_059_OM_SI2_J ['Clarity'] = listclar
                    df_050_059_OM_SI2_J ['Cut'] = listcut
                    df_050_059_OM_SI2_J ['Polish'] = listpol
                    df_050_059_OM_SI2_J ['Symmetry'] = listsym
                    df_050_059_OM_SI2_J ['Ratio'] = listrat
                    df_050_059_OM_SI2_J ['PPC'] = listdesc
                    df_050_059_OM_SI2_J ['Total'] = listtotal
                    df_050_059_OM_SI2_J['Carat'] = df_050_059_OM_SI2_J['Carat'].astype('float64')
                    df_050_059_OM_SI2_J['PPC'] = df_050_059_OM_SI2_J['PPC'].astype('float64')
                    df_050_059_OM_SI2_J['Total'] = df_050_059_OM_SI2_J['Total'].astype('float64')
                    df_050_059_OM_SI2_J['Total'] = df_050_059_OM_SI2_J['Carat'] * df_050_059_OM_SI2_J['PPC']


                elif i=="J"  and j == "I1" and k == "OM":
                    df_050_059_OM_I1_J = pd.DataFrame()
                    df_050_059_OM_I1_J ['Wt Range'] = None
                    df_050_059_OM_I1_J  = df_050_059_OM_I1_J.assign(Company=None)
                    df_050_059_OM_I1_J  = df_050_059_OM_I1_J.assign(Shape=None)
                    df_050_059_OM_I1_J  = df_050_059_OM_I1_J.assign(Carat=None)
                    df_050_059_OM_I1_J  = df_050_059_OM_I1_J.assign(Color=None)
                    df_050_059_OM_I1_J  = df_050_059_OM_I1_J.assign(Clarity=None)
                    df_050_059_OM_I1_J  = df_050_059_OM_I1_J.assign(Cut=None)
                    df_050_059_OM_I1_J  = df_050_059_OM_I1_J.assign(Polish=None)
                    df_050_059_OM_I1_J  = df_050_059_OM_I1_J.assign(Symmetry=None)
                    df_050_059_OM_I1_J  = df_050_059_OM_I1_J.assign(Ratio=None)
                    df_050_059_OM_I1_J  = df_050_059_OM_I1_J.assign(PPC=None)
                    df_050_059_OM_I1_J  = df_050_059_OM_I1_J.assign(Total=None)
                    df_050_059_OM_I1_J ['Wt Range'] = listwtrange
                    df_050_059_OM_I1_J ['Company'] = listcom
                    df_050_059_OM_I1_J ['Shape'] = listshap
                    df_050_059_OM_I1_J ['Carat'] = listcar
                    df_050_059_OM_I1_J ['Color'] = listcol
                    df_050_059_OM_I1_J ['Clarity'] = listclar
                    df_050_059_OM_I1_J ['Cut'] = listcut
                    df_050_059_OM_I1_J ['Polish'] = listpol
                    df_050_059_OM_I1_J ['Symmetry'] = listsym
                    df_050_059_OM_I1_J ['Ratio'] = listrat
                    df_050_059_OM_I1_J ['PPC'] = listdesc
                    df_050_059_OM_I1_J ['Total'] = listtotal
                    df_050_059_OM_I1_J['Carat'] = df_050_059_OM_I1_J['Carat'].astype('float64')
                    df_050_059_OM_I1_J['PPC'] = df_050_059_OM_I1_J['PPC'].astype('float64')
                    df_050_059_OM_I1_J['Total'] = df_050_059_OM_I1_J['Total'].astype('float64')
                    df_050_059_OM_I1_J['Total'] = df_050_059_OM_I1_J['Carat'] * df_050_059_OM_I1_J['PPC']


                elif i=="J"  and j == "I2" and k == "OM":
                    df_050_059_OM_I2_J = pd.DataFrame()
                    df_050_059_OM_I2_J ['Wt Range'] = None
                    df_050_059_OM_I2_J  = df_050_059_OM_I2_J.assign(Company=None)
                    df_050_059_OM_I2_J  = df_050_059_OM_I2_J.assign(Shape=None)
                    df_050_059_OM_I2_J  = df_050_059_OM_I2_J.assign(Carat=None)
                    df_050_059_OM_I2_J  = df_050_059_OM_I2_J.assign(Color=None)
                    df_050_059_OM_I2_J  = df_050_059_OM_I2_J.assign(Clarity=None)
                    df_050_059_OM_I2_J  = df_050_059_OM_I2_J.assign(Cut=None)
                    df_050_059_OM_I2_J  = df_050_059_OM_I2_J.assign(Polish=None)
                    df_050_059_OM_I2_J  = df_050_059_OM_I2_J.assign(Symmetry=None)
                    df_050_059_OM_I2_J  = df_050_059_OM_I2_J.assign(Ratio=None)
                    df_050_059_OM_I2_J  = df_050_059_OM_I2_J.assign(PPC=None)
                    df_050_059_OM_I2_J  = df_050_059_OM_I2_J.assign(Total=None)
                    df_050_059_OM_I2_J ['Wt Range'] = listwtrange
                    df_050_059_OM_I2_J ['Company'] = listcom
                    df_050_059_OM_I2_J ['Shape'] = listshap
                    df_050_059_OM_I2_J ['Carat'] = listcar
                    df_050_059_OM_I2_J ['Color'] = listcol
                    df_050_059_OM_I2_J ['Clarity'] = listclar
                    df_050_059_OM_I2_J ['Cut'] = listcut
                    df_050_059_OM_I2_J ['Polish'] = listpol
                    df_050_059_OM_I2_J ['Symmetry'] = listsym
                    df_050_059_OM_I2_J ['Ratio'] = listrat
                    df_050_059_OM_I2_J ['PPC'] = listdesc
                    df_050_059_OM_I2_J ['Total'] = listtotal
                    df_050_059_OM_I2_J['Carat'] = df_050_059_OM_I2_J['Carat'].astype('float64')
                    df_050_059_OM_I2_J['PPC'] = df_050_059_OM_I2_J['PPC'].astype('float64')
                    df_050_059_OM_I2_J['Total'] = df_050_059_OM_I2_J['Total'].astype('float64')
                    df_050_059_OM_I2_J['Total'] = df_050_059_OM_I2_J['Carat'] * df_050_059_OM_I2_J['PPC']


                elif i=="K" and j == "IF" and k == "OM":
                    df_050_059_OM_IF_K = pd.DataFrame()
                    df_050_059_OM_IF_K ['Wt Range'] = None
                    df_050_059_OM_IF_K  = df_050_059_OM_IF_K.assign(Company=None)
                    df_050_059_OM_IF_K  = df_050_059_OM_IF_K.assign(Shape=None)
                    df_050_059_OM_IF_K  = df_050_059_OM_IF_K.assign(Carat=None)
                    df_050_059_OM_IF_K  = df_050_059_OM_IF_K.assign(Color=None)
                    df_050_059_OM_IF_K  = df_050_059_OM_IF_K.assign(Clarity=None)
                    df_050_059_OM_IF_K  = df_050_059_OM_IF_K.assign(Cut=None)
                    df_050_059_OM_IF_K  = df_050_059_OM_IF_K.assign(Polish=None)
                    df_050_059_OM_IF_K  = df_050_059_OM_IF_K.assign(Symmetry=None)
                    df_050_059_OM_IF_K  = df_050_059_OM_IF_K.assign(Ratio=None)
                    df_050_059_OM_IF_K  = df_050_059_OM_IF_K.assign(PPC=None)
                    df_050_059_OM_IF_K  = df_050_059_OM_IF_K.assign(Total=None)
                    df_050_059_OM_IF_K ['Wt Range'] = listwtrange
                    df_050_059_OM_IF_K ['Company'] = listcom
                    df_050_059_OM_IF_K ['Shape'] = listshap
                    df_050_059_OM_IF_K ['Carat'] = listcar
                    df_050_059_OM_IF_K ['Color'] = listcol
                    df_050_059_OM_IF_K ['Clarity'] = listclar
                    df_050_059_OM_IF_K ['Cut'] = listcut
                    df_050_059_OM_IF_K ['Polish'] = listpol
                    df_050_059_OM_IF_K ['Symmetry'] = listsym
                    df_050_059_OM_IF_K ['Ratio'] = listrat
                    df_050_059_OM_IF_K ['PPC'] = listdesc
                    df_050_059_OM_IF_K ['Total'] = listtotal
                    df_050_059_OM_IF_K['Carat'] = df_050_059_OM_IF_K['Carat'].astype('float64')
                    df_050_059_OM_IF_K['PPC'] = df_050_059_OM_IF_K['PPC'].astype('float64')
                    df_050_059_OM_IF_K['Total'] = df_050_059_OM_IF_K['Total'].astype('float64')
                    df_050_059_OM_IF_K['Total'] = df_050_059_OM_IF_K['Carat'] * df_050_059_OM_IF_K['PPC']



                elif i=="K" and j == "VVS1" and k == "OM":
                    df_050_059_OM_VVS1_K = pd.DataFrame()
                    df_050_059_OM_VVS1_K ['Wt Range'] = None
                    df_050_059_OM_VVS1_K  = df_050_059_OM_VVS1_K.assign(Company=None)
                    df_050_059_OM_VVS1_K  = df_050_059_OM_VVS1_K.assign(Shape=None)
                    df_050_059_OM_VVS1_K  = df_050_059_OM_VVS1_K.assign(Carat=None)
                    df_050_059_OM_VVS1_K  = df_050_059_OM_VVS1_K.assign(Color=None)
                    df_050_059_OM_VVS1_K  = df_050_059_OM_VVS1_K.assign(Clarity=None)
                    df_050_059_OM_VVS1_K  = df_050_059_OM_VVS1_K.assign(Cut=None)
                    df_050_059_OM_VVS1_K  = df_050_059_OM_VVS1_K.assign(Polish=None)
                    df_050_059_OM_VVS1_K  = df_050_059_OM_VVS1_K.assign(Symmetry=None)
                    df_050_059_OM_VVS1_K  = df_050_059_OM_VVS1_K.assign(Ratio=None)
                    df_050_059_OM_VVS1_K  = df_050_059_OM_VVS1_K.assign(PPC=None)
                    df_050_059_OM_VVS1_K  = df_050_059_OM_VVS1_K.assign(Total=None)
                    df_050_059_OM_VVS1_K ['Wt Range'] = listwtrange
                    df_050_059_OM_VVS1_K ['Company'] = listcom
                    df_050_059_OM_VVS1_K ['Shape'] = listshap
                    df_050_059_OM_VVS1_K ['Carat'] = listcar
                    df_050_059_OM_VVS1_K ['Color'] = listcol
                    df_050_059_OM_VVS1_K ['Clarity'] = listclar
                    df_050_059_OM_VVS1_K ['Cut'] = listcut
                    df_050_059_OM_VVS1_K ['Polish'] = listpol
                    df_050_059_OM_VVS1_K ['Symmetry'] = listsym
                    df_050_059_OM_VVS1_K ['Ratio'] = listrat
                    df_050_059_OM_VVS1_K ['PPC'] = listdesc
                    df_050_059_OM_VVS1_K ['Total'] = listtotal
                    df_050_059_OM_VVS1_K['Carat'] = df_050_059_OM_VVS1_K['Carat'].astype('float64')
                    df_050_059_OM_VVS1_K['PPC'] = df_050_059_OM_VVS1_K['PPC'].astype('float64')
                    df_050_059_OM_VVS1_K['Total'] = df_050_059_OM_VVS1_K['Total'].astype('float64')
                    df_050_059_OM_VVS1_K['Total'] = df_050_059_OM_VVS1_K['Carat'] * df_050_059_OM_VVS1_K['PPC']


                elif i=="K" and j == "VVS2" and k == "OM":
                    df_050_059_OM_VVS2_K = pd.DataFrame()
                    df_050_059_OM_VVS2_K ['Wt Range'] = None
                    df_050_059_OM_VVS2_K  = df_050_059_OM_VVS2_K.assign(Company=None)
                    df_050_059_OM_VVS2_K  = df_050_059_OM_VVS2_K.assign(Shape=None)
                    df_050_059_OM_VVS2_K  = df_050_059_OM_VVS2_K.assign(Carat=None)
                    df_050_059_OM_VVS2_K  = df_050_059_OM_VVS2_K.assign(Color=None)
                    df_050_059_OM_VVS2_K  = df_050_059_OM_VVS2_K.assign(Clarity=None)
                    df_050_059_OM_VVS2_K  = df_050_059_OM_VVS2_K.assign(Cut=None)
                    df_050_059_OM_VVS2_K  = df_050_059_OM_VVS2_K.assign(Polish=None)
                    df_050_059_OM_VVS2_K  = df_050_059_OM_VVS2_K.assign(Symmetry=None)
                    df_050_059_OM_VVS2_K  = df_050_059_OM_VVS2_K.assign(Ratio=None)
                    df_050_059_OM_VVS2_K  = df_050_059_OM_VVS2_K.assign(PPC=None)
                    df_050_059_OM_VVS2_K  = df_050_059_OM_VVS2_K.assign(Total=None)
                    df_050_059_OM_VVS2_K ['Wt Range'] = listwtrange
                    df_050_059_OM_VVS2_K ['Company'] = listcom
                    df_050_059_OM_VVS2_K ['Shape'] = listshap
                    df_050_059_OM_VVS2_K ['Carat'] = listcar
                    df_050_059_OM_VVS2_K ['Color'] = listcol
                    df_050_059_OM_VVS2_K ['Clarity'] = listclar
                    df_050_059_OM_VVS2_K ['Cut'] = listcut
                    df_050_059_OM_VVS2_K ['Polish'] = listpol
                    df_050_059_OM_VVS2_K ['Symmetry'] = listsym
                    df_050_059_OM_VVS2_K ['Ratio'] = listrat
                    df_050_059_OM_VVS2_K ['PPC'] = listdesc
                    df_050_059_OM_VVS2_K ['Total'] = listtotal
                    df_050_059_OM_VVS2_K['Carat'] = df_050_059_OM_VVS2_K['Carat'].astype('float64')
                    df_050_059_OM_VVS2_K['PPC'] = df_050_059_OM_VVS2_K['PPC'].astype('float64')
                    df_050_059_OM_VVS2_K['Total'] = df_050_059_OM_VVS2_K['Total'].astype('float64')
                    df_050_059_OM_VVS2_K['Total'] = df_050_059_OM_VVS2_K['Carat'] * df_050_059_OM_VVS2_K['PPC']


                elif i=="K" and j=="VS1" and k == "OM":
                    df_050_059_OM_VS1_K = pd.DataFrame()
                    df_050_059_OM_VS1_K ['Wt Range'] = None
                    df_050_059_OM_VS1_K  = df_050_059_OM_VS1_K.assign(Company=None)
                    df_050_059_OM_VS1_K  = df_050_059_OM_VS1_K.assign(Shape=None)
                    df_050_059_OM_VS1_K  = df_050_059_OM_VS1_K.assign(Carat=None)
                    df_050_059_OM_VS1_K  = df_050_059_OM_VS1_K.assign(Color=None)
                    df_050_059_OM_VS1_K  = df_050_059_OM_VS1_K.assign(Clarity=None)
                    df_050_059_OM_VS1_K  = df_050_059_OM_VS1_K.assign(Cut=None)
                    df_050_059_OM_VS1_K  = df_050_059_OM_VS1_K.assign(Polish=None)
                    df_050_059_OM_VS1_K  = df_050_059_OM_VS1_K.assign(Symmetry=None)
                    df_050_059_OM_VS1_K  = df_050_059_OM_VS1_K.assign(Ratio=None)
                    df_050_059_OM_VS1_K  = df_050_059_OM_VS1_K.assign(PPC=None)
                    df_050_059_OM_VS1_K  = df_050_059_OM_VS1_K.assign(Total=None)
                    df_050_059_OM_VS1_K ['Wt Range'] = listwtrange
                    df_050_059_OM_VS1_K ['Company'] = listcom
                    df_050_059_OM_VS1_K ['Shape'] = listshap
                    df_050_059_OM_VS1_K ['Carat'] = listcar
                    df_050_059_OM_VS1_K ['Color'] = listcol
                    df_050_059_OM_VS1_K ['Clarity'] = listclar
                    df_050_059_OM_VS1_K ['Cut'] = listcut
                    df_050_059_OM_VS1_K ['Polish'] = listpol
                    df_050_059_OM_VS1_K ['Symmetry'] = listsym
                    df_050_059_OM_VS1_K ['Ratio'] = listrat
                    df_050_059_OM_VS1_K ['PPC'] = listdesc
                    df_050_059_OM_VS1_K ['Total'] = listtotal
                    df_050_059_OM_VS1_K['Carat'] = df_050_059_OM_VS1_K['Carat'].astype('float64')
                    df_050_059_OM_VS1_K['PPC'] = df_050_059_OM_VS1_K['PPC'].astype('float64')
                    df_050_059_OM_VS1_K['Total'] = df_050_059_OM_VS1_K['Total'].astype('float64')
                    df_050_059_OM_VS1_K['Total'] = df_050_059_OM_VS1_K['Carat'] * df_050_059_OM_VS1_K['PPC']


                elif i=="K" and j == "VS2" and k == "OM":
                    df_050_059_OM_VS2_K = pd.DataFrame()
                    df_050_059_OM_VS2_K ['Wt Range'] = None
                    df_050_059_OM_VS2_K  = df_050_059_OM_VS2_K.assign(Company=None)
                    df_050_059_OM_VS2_K  = df_050_059_OM_VS2_K.assign(Shape=None)
                    df_050_059_OM_VS2_K  = df_050_059_OM_VS2_K.assign(Carat=None)
                    df_050_059_OM_VS2_K  = df_050_059_OM_VS2_K.assign(Color=None)
                    df_050_059_OM_VS2_K  = df_050_059_OM_VS2_K.assign(Clarity=None)
                    df_050_059_OM_VS2_K  = df_050_059_OM_VS2_K.assign(Cut=None)
                    df_050_059_OM_VS2_K  = df_050_059_OM_VS2_K.assign(Polish=None)
                    df_050_059_OM_VS2_K  = df_050_059_OM_VS2_K.assign(Symmetry=None)
                    df_050_059_OM_VS2_K  = df_050_059_OM_VS2_K.assign(Ratio=None)
                    df_050_059_OM_VS2_K  = df_050_059_OM_VS2_K.assign(PPC=None)
                    df_050_059_OM_VS2_K  = df_050_059_OM_VS2_K.assign(Total=None)
                    df_050_059_OM_VS2_K ['Wt Range'] = listwtrange
                    df_050_059_OM_VS2_K ['Company'] = listcom
                    df_050_059_OM_VS2_K ['Shape'] = listshap
                    df_050_059_OM_VS2_K ['Carat'] = listcar
                    df_050_059_OM_VS2_K ['Color'] = listcol
                    df_050_059_OM_VS2_K ['Clarity'] = listclar
                    df_050_059_OM_VS2_K ['Cut'] = listcut
                    df_050_059_OM_VS2_K ['Polish'] = listpol
                    df_050_059_OM_VS2_K ['Symmetry'] = listsym
                    df_050_059_OM_VS2_K ['Ratio'] = listrat
                    df_050_059_OM_VS2_K ['PPC'] = listdesc
                    df_050_059_OM_VS2_K ['Total'] = listtotal
                    df_050_059_OM_VS2_K['Carat'] = df_050_059_OM_VS2_K['Carat'].astype('float64')
                    df_050_059_OM_VS2_K['PPC'] = df_050_059_OM_VS2_K['PPC'].astype('float64')
                    df_050_059_OM_VS2_K['Total'] = df_050_059_OM_VS2_K['Total'].astype('float64')
                    df_050_059_OM_VS2_K['Total'] = df_050_059_OM_VS2_K['Carat'] * df_050_059_OM_VS2_K['PPC']


                elif i=="K" and j == "SI1" and k == "OM":
                    df_050_059_OM_SI1_K = pd.DataFrame()
                    df_050_059_OM_SI1_K ['Wt Range'] = None
                    df_050_059_OM_SI1_K  = df_050_059_OM_SI1_K.assign(Company=None)
                    df_050_059_OM_SI1_K  = df_050_059_OM_SI1_K.assign(Shape=None)
                    df_050_059_OM_SI1_K  = df_050_059_OM_SI1_K.assign(Carat=None)
                    df_050_059_OM_SI1_K  = df_050_059_OM_SI1_K.assign(Color=None)
                    df_050_059_OM_SI1_K  = df_050_059_OM_SI1_K.assign(Clarity=None)
                    df_050_059_OM_SI1_K  = df_050_059_OM_SI1_K.assign(Cut=None)
                    df_050_059_OM_SI1_K  = df_050_059_OM_SI1_K.assign(Polish=None)
                    df_050_059_OM_SI1_K  = df_050_059_OM_SI1_K.assign(Symmetry=None)
                    df_050_059_OM_SI1_K  = df_050_059_OM_SI1_K.assign(Ratio=None)
                    df_050_059_OM_SI1_K  = df_050_059_OM_SI1_K.assign(PPC=None)
                    df_050_059_OM_SI1_K  = df_050_059_OM_SI1_K.assign(Total=None)
                    df_050_059_OM_SI1_K ['Wt Range'] = listwtrange
                    df_050_059_OM_SI1_K ['Company'] = listcom
                    df_050_059_OM_SI1_K ['Shape'] = listshap
                    df_050_059_OM_SI1_K ['Carat'] = listcar
                    df_050_059_OM_SI1_K ['Color'] = listcol
                    df_050_059_OM_SI1_K ['Clarity'] = listclar
                    df_050_059_OM_SI1_K ['Cut'] = listcut
                    df_050_059_OM_SI1_K ['Polish'] = listpol
                    df_050_059_OM_SI1_K ['Symmetry'] = listsym
                    df_050_059_OM_SI1_K ['Ratio'] = listrat
                    df_050_059_OM_SI1_K ['PPC'] = listdesc
                    df_050_059_OM_SI1_K ['Total'] = listtotal
                    df_050_059_OM_SI1_K['Carat'] = df_050_059_OM_SI1_K['Carat'].astype('float64')
                    df_050_059_OM_SI1_K['PPC'] = df_050_059_OM_SI1_K['PPC'].astype('float64')
                    df_050_059_OM_SI1_K['Total'] = df_050_059_OM_SI1_K['Total'].astype('float64')
                    df_050_059_OM_SI1_K['Total'] = df_050_059_OM_SI1_K['Carat'] * df_050_059_OM_SI1_K['PPC']


                elif i=="K" and j == "SI2" and k == "OM":
                    df_050_059_OM_SI2_K = pd.DataFrame()
                    df_050_059_OM_SI2_K ['Wt Range'] = None
                    df_050_059_OM_SI2_K  = df_050_059_OM_SI2_K.assign(Company=None)
                    df_050_059_OM_SI2_K  = df_050_059_OM_SI2_K.assign(Shape=None)
                    df_050_059_OM_SI2_K  = df_050_059_OM_SI2_K.assign(Carat=None)
                    df_050_059_OM_SI2_K  = df_050_059_OM_SI2_K.assign(Color=None)
                    df_050_059_OM_SI2_K  = df_050_059_OM_SI2_K.assign(Clarity=None)
                    df_050_059_OM_SI2_K  = df_050_059_OM_SI2_K.assign(Cut=None)
                    df_050_059_OM_SI2_K  = df_050_059_OM_SI2_K.assign(Polish=None)
                    df_050_059_OM_SI2_K  = df_050_059_OM_SI2_K.assign(Symmetry=None)
                    df_050_059_OM_SI2_K  = df_050_059_OM_SI2_K.assign(Ratio=None)
                    df_050_059_OM_SI2_K  = df_050_059_OM_SI2_K.assign(PPC=None)
                    df_050_059_OM_SI2_K  = df_050_059_OM_SI2_K.assign(Total=None)
                    df_050_059_OM_SI2_K ['Wt Range'] = listwtrange
                    df_050_059_OM_SI2_K ['Company'] = listcom
                    df_050_059_OM_SI2_K ['Shape'] = listshap
                    df_050_059_OM_SI2_K ['Carat'] = listcar
                    df_050_059_OM_SI2_K ['Color'] = listcol
                    df_050_059_OM_SI2_K ['Clarity'] = listclar
                    df_050_059_OM_SI2_K ['Cut'] = listcut
                    df_050_059_OM_SI2_K ['Polish'] = listpol
                    df_050_059_OM_SI2_K ['Symmetry'] = listsym
                    df_050_059_OM_SI2_K ['Ratio'] = listrat
                    df_050_059_OM_SI2_K ['PPC'] = listdesc
                    df_050_059_OM_SI2_K ['Total'] = listtotal
                    df_050_059_OM_SI2_K['Carat'] = df_050_059_OM_SI2_K['Carat'].astype('float64')
                    df_050_059_OM_SI2_K['PPC'] = df_050_059_OM_SI2_K['PPC'].astype('float64')
                    df_050_059_OM_SI2_K['Total'] = df_050_059_OM_SI2_K['Total'].astype('float64')
                    df_050_059_OM_SI2_K['Total'] = df_050_059_OM_SI2_K['Carat'] * df_050_059_OM_SI2_K['PPC']


                elif i=="K" and j == "I1" and k == "OM":
                    df_050_059_OM_I1_K = pd.DataFrame()
                    df_050_059_OM_I1_K ['Wt Range'] = None
                    df_050_059_OM_I1_K  = df_050_059_OM_I1_K.assign(Company=None)
                    df_050_059_OM_I1_K  = df_050_059_OM_I1_K.assign(Shape=None)
                    df_050_059_OM_I1_K  = df_050_059_OM_I1_K.assign(Carat=None)
                    df_050_059_OM_I1_K  = df_050_059_OM_I1_K.assign(Color=None)
                    df_050_059_OM_I1_K  = df_050_059_OM_I1_K.assign(Clarity=None)
                    df_050_059_OM_I1_K  = df_050_059_OM_I1_K.assign(Cut=None)
                    df_050_059_OM_I1_K  = df_050_059_OM_I1_K.assign(Polish=None)
                    df_050_059_OM_I1_K  = df_050_059_OM_I1_K.assign(Symmetry=None)
                    df_050_059_OM_I1_K  = df_050_059_OM_I1_K.assign(Ratio=None)
                    df_050_059_OM_I1_K  = df_050_059_OM_I1_K.assign(PPC=None)
                    df_050_059_OM_I1_K  = df_050_059_OM_I1_K.assign(Total=None)
                    df_050_059_OM_I1_K ['Wt Range'] = listwtrange
                    df_050_059_OM_I1_K ['Company'] = listcom
                    df_050_059_OM_I1_K ['Shape'] = listshap
                    df_050_059_OM_I1_K ['Carat'] = listcar
                    df_050_059_OM_I1_K ['Color'] = listcol
                    df_050_059_OM_I1_K ['Clarity'] = listclar
                    df_050_059_OM_I1_K ['Cut'] = listcut
                    df_050_059_OM_I1_K ['Polish'] = listpol
                    df_050_059_OM_I1_K ['Symmetry'] = listsym
                    df_050_059_OM_I1_K ['Ratio'] = listrat
                    df_050_059_OM_I1_K ['PPC'] = listdesc
                    df_050_059_OM_I1_K ['Total'] = listtotal
                    df_050_059_OM_I1_K['Carat'] = df_050_059_OM_I1_K['Carat'].astype('float64')
                    df_050_059_OM_I1_K['PPC'] = df_050_059_OM_I1_K['PPC'].astype('float64')
                    df_050_059_OM_I1_K['Total'] = df_050_059_OM_I1_K['Total'].astype('float64')
                    df_050_059_OM_I1_K['Total'] = df_050_059_OM_I1_K['Carat'] * df_050_059_OM_I1_K['PPC']


                elif i=="K" and j == "I2" and k == "OM":
                    df_050_059_OM_I2_K = pd.DataFrame()
                    df_050_059_OM_I2_K ['Wt Range'] = None
                    df_050_059_OM_I2_K  = df_050_059_OM_I2_K.assign(Company=None)
                    df_050_059_OM_I2_K  = df_050_059_OM_I2_K.assign(Shape=None)
                    df_050_059_OM_I2_K  = df_050_059_OM_I2_K.assign(Carat=None)
                    df_050_059_OM_I2_K  = df_050_059_OM_I2_K.assign(Color=None)
                    df_050_059_OM_I2_K  = df_050_059_OM_I2_K.assign(Clarity=None)
                    df_050_059_OM_I2_K  = df_050_059_OM_I2_K.assign(Cut=None)
                    df_050_059_OM_I2_K  = df_050_059_OM_I2_K.assign(Polish=None)
                    df_050_059_OM_I2_K  = df_050_059_OM_I2_K.assign(Symmetry=None)
                    df_050_059_OM_I2_K  = df_050_059_OM_I2_K.assign(Ratio=None)
                    df_050_059_OM_I2_K  = df_050_059_OM_I2_K.assign(PPC=None)
                    df_050_059_OM_I2_K  = df_050_059_OM_I2_K.assign(Total=None)
                    df_050_059_OM_I2_K ['Wt Range'] = listwtrange
                    df_050_059_OM_I2_K ['Company'] = listcom
                    df_050_059_OM_I2_K ['Shape'] = listshap
                    df_050_059_OM_I2_K ['Carat'] = listcar
                    df_050_059_OM_I2_K ['Color'] = listcol
                    df_050_059_OM_I2_K ['Clarity'] = listclar
                    df_050_059_OM_I2_K ['Cut'] = listcut
                    df_050_059_OM_I2_K ['Polish'] = listpol
                    df_050_059_OM_I2_K ['Symmetry'] = listsym
                    df_050_059_OM_I2_K ['Ratio'] = listrat
                    df_050_059_OM_I2_K ['PPC'] = listdesc
                    df_050_059_OM_I2_K ['Total'] = listtotal
                    df_050_059_OM_I2_K['Carat'] = df_050_059_OM_I2_K['Carat'].astype('float64')
                    df_050_059_OM_I2_K['PPC'] = df_050_059_OM_I2_K['PPC'].astype('float64')
                    df_050_059_OM_I2_K['Total'] = df_050_059_OM_I2_K['Total'].astype('float64')
                    df_050_059_OM_I2_K['Total'] = df_050_059_OM_I2_K['Carat'] * df_050_059_OM_I2_K['PPC']


                elif i=="L" and j == "IF" and k == "OM":
                    df_050_059_OM_IF_L = pd.DataFrame()
                    df_050_059_OM_IF_L ['Wt Range'] = None
                    df_050_059_OM_IF_L  = df_050_059_OM_IF_L.assign(Company=None)
                    df_050_059_OM_IF_L  = df_050_059_OM_IF_L.assign(Shape=None)
                    df_050_059_OM_IF_L  = df_050_059_OM_IF_L.assign(Carat=None)
                    df_050_059_OM_IF_L  = df_050_059_OM_IF_L.assign(Color=None)
                    df_050_059_OM_IF_L  = df_050_059_OM_IF_L.assign(Clarity=None)
                    df_050_059_OM_IF_L  = df_050_059_OM_IF_L.assign(Cut=None)
                    df_050_059_OM_IF_L  = df_050_059_OM_IF_L.assign(Polish=None)
                    df_050_059_OM_IF_L  = df_050_059_OM_IF_L.assign(Symmetry=None)
                    df_050_059_OM_IF_L  = df_050_059_OM_IF_L.assign(Ratio=None)
                    df_050_059_OM_IF_L  = df_050_059_OM_IF_L.assign(PPC=None)
                    df_050_059_OM_IF_L  = df_050_059_OM_IF_L.assign(Total=None)
                    df_050_059_OM_IF_L ['Wt Range'] = listwtrange
                    df_050_059_OM_IF_L ['Company'] = listcom
                    df_050_059_OM_IF_L ['Shape'] = listshap
                    df_050_059_OM_IF_L ['Carat'] = listcar
                    df_050_059_OM_IF_L ['Color'] = listcol
                    df_050_059_OM_IF_L ['Clarity'] = listclar
                    df_050_059_OM_IF_L ['Cut'] = listcut
                    df_050_059_OM_IF_L ['Polish'] = listpol
                    df_050_059_OM_IF_L ['Symmetry'] = listsym
                    df_050_059_OM_IF_L ['Ratio'] = listrat
                    df_050_059_OM_IF_L ['PPC'] = listdesc
                    df_050_059_OM_IF_L ['Total'] = listtotal
                    df_050_059_OM_IF_L['Carat'] = df_050_059_OM_IF_L['Carat'].astype('float64')
                    df_050_059_OM_IF_L['PPC'] = df_050_059_OM_IF_L['PPC'].astype('float64')
                    df_050_059_OM_IF_L['Total'] = df_050_059_OM_IF_L['Total'].astype('float64')
                    df_050_059_OM_IF_L['Total'] = df_050_059_OM_IF_L['Carat'] * df_050_059_OM_IF_L['PPC']


                elif i=="L" and j == "VVS1" and k == "OM":
                    df_050_059_OM_VVS1_L = pd.DataFrame()
                    df_050_059_OM_VVS1_L ['Wt Range'] = None
                    df_050_059_OM_VVS1_L  = df_050_059_OM_VVS1_L.assign(Company=None)
                    df_050_059_OM_VVS1_L  = df_050_059_OM_VVS1_L.assign(Shape=None)
                    df_050_059_OM_VVS1_L  = df_050_059_OM_VVS1_L.assign(Carat=None)
                    df_050_059_OM_VVS1_L  = df_050_059_OM_VVS1_L.assign(Color=None)
                    df_050_059_OM_VVS1_L  = df_050_059_OM_VVS1_L.assign(Clarity=None)
                    df_050_059_OM_VVS1_L  = df_050_059_OM_VVS1_L.assign(Cut=None)
                    df_050_059_OM_VVS1_L  = df_050_059_OM_VVS1_L.assign(Polish=None)
                    df_050_059_OM_VVS1_L  = df_050_059_OM_VVS1_L.assign(Symmetry=None)
                    df_050_059_OM_VVS1_L  = df_050_059_OM_VVS1_L.assign(Ratio=None)
                    df_050_059_OM_VVS1_L  = df_050_059_OM_VVS1_L.assign(PPC=None)
                    df_050_059_OM_VVS1_L  = df_050_059_OM_VVS1_L.assign(Total=None)
                    df_050_059_OM_VVS1_L ['Wt Range'] = listwtrange
                    df_050_059_OM_VVS1_L ['Company'] = listcom
                    df_050_059_OM_VVS1_L ['Shape'] = listshap
                    df_050_059_OM_VVS1_L ['Carat'] = listcar
                    df_050_059_OM_VVS1_L ['Color'] = listcol
                    df_050_059_OM_VVS1_L ['Clarity'] = listclar
                    df_050_059_OM_VVS1_L ['Cut'] = listcut
                    df_050_059_OM_VVS1_L ['Polish'] = listpol
                    df_050_059_OM_VVS1_L ['Symmetry'] = listsym
                    df_050_059_OM_VVS1_L ['Ratio'] = listrat
                    df_050_059_OM_VVS1_L ['PPC'] = listdesc
                    df_050_059_OM_VVS1_L ['Total'] = listtotal
                    df_050_059_OM_VVS1_L['Carat'] = df_050_059_OM_VVS1_L['Carat'].astype('float64')
                    df_050_059_OM_VVS1_L['PPC'] = df_050_059_OM_VVS1_L['PPC'].astype('float64')
                    df_050_059_OM_VVS1_L['Total'] = df_050_059_OM_VVS1_L['Total'].astype('float64')
                    df_050_059_OM_VVS1_L['Total'] = df_050_059_OM_VVS1_L['Carat'] * df_050_059_OM_VVS1_L['PPC']


                elif i=="L" and j == "VVS2" and k == "OM":
                    df_050_059_OM_VVS2_L = pd.DataFrame()
                    df_050_059_OM_VVS2_L ['Wt Range'] = None
                    df_050_059_OM_VVS2_L  = df_050_059_OM_VVS2_L.assign(Company=None)
                    df_050_059_OM_VVS2_L  = df_050_059_OM_VVS2_L.assign(Shape=None)
                    df_050_059_OM_VVS2_L  = df_050_059_OM_VVS2_L.assign(Carat=None)
                    df_050_059_OM_VVS2_L  = df_050_059_OM_VVS2_L.assign(Color=None)
                    df_050_059_OM_VVS2_L  = df_050_059_OM_VVS2_L.assign(Clarity=None)
                    df_050_059_OM_VVS2_L  = df_050_059_OM_VVS2_L.assign(Cut=None)
                    df_050_059_OM_VVS2_L  = df_050_059_OM_VVS2_L.assign(Polish=None)
                    df_050_059_OM_VVS2_L  = df_050_059_OM_VVS2_L.assign(Symmetry=None)
                    df_050_059_OM_VVS2_L  = df_050_059_OM_VVS2_L.assign(Ratio=None)
                    df_050_059_OM_VVS2_L  = df_050_059_OM_VVS2_L.assign(PPC=None)
                    df_050_059_OM_VVS2_L  = df_050_059_OM_VVS2_L.assign(Total=None)
                    df_050_059_OM_VVS2_L ['Wt Range'] = listwtrange
                    df_050_059_OM_VVS2_L ['Company'] = listcom
                    df_050_059_OM_VVS2_L ['Shape'] = listshap
                    df_050_059_OM_VVS2_L ['Carat'] = listcar
                    df_050_059_OM_VVS2_L ['Color'] = listcol
                    df_050_059_OM_VVS2_L ['Clarity'] = listclar
                    df_050_059_OM_VVS2_L ['Cut'] = listcut
                    df_050_059_OM_VVS2_L ['Polish'] = listpol
                    df_050_059_OM_VVS2_L ['Symmetry'] = listsym
                    df_050_059_OM_VVS2_L ['Ratio'] = listrat
                    df_050_059_OM_VVS2_L ['PPC'] = listdesc
                    df_050_059_OM_VVS2_L ['Total'] = listtotal
                    df_050_059_OM_VVS2_L['Carat'] = df_050_059_OM_VVS2_L['Carat'].astype('float64')
                    df_050_059_OM_VVS2_L['PPC'] = df_050_059_OM_VVS2_L['PPC'].astype('float64')
                    df_050_059_OM_VVS2_L['Total'] = df_050_059_OM_VVS2_L['Total'].astype('float64')
                    df_050_059_OM_VVS2_L['Total'] = df_050_059_OM_VVS2_L['Carat'] * df_050_059_OM_VVS2_L['PPC']


                elif i=="L" and j=="VS1" and k == "OM":
                    df_050_059_OM_VS1_L = pd.DataFrame()
                    df_050_059_OM_VS1_L ['Wt Range'] = None
                    df_050_059_OM_VS1_L  = df_050_059_OM_VS1_L.assign(Company=None)
                    df_050_059_OM_VS1_L  = df_050_059_OM_VS1_L.assign(Shape=None)
                    df_050_059_OM_VS1_L  = df_050_059_OM_VS1_L.assign(Carat=None)
                    df_050_059_OM_VS1_L  = df_050_059_OM_VS1_L.assign(Color=None)
                    df_050_059_OM_VS1_L  = df_050_059_OM_VS1_L.assign(Clarity=None)
                    df_050_059_OM_VS1_L  = df_050_059_OM_VS1_L.assign(Cut=None)
                    df_050_059_OM_VS1_L  = df_050_059_OM_VS1_L.assign(Polish=None)
                    df_050_059_OM_VS1_L  = df_050_059_OM_VS1_L.assign(Symmetry=None)
                    df_050_059_OM_VS1_L  = df_050_059_OM_VS1_L.assign(Ratio=None)
                    df_050_059_OM_VS1_L  = df_050_059_OM_VS1_L.assign(PPC=None)
                    df_050_059_OM_VS1_L  = df_050_059_OM_VS1_L.assign(Total=None)
                    df_050_059_OM_VS1_L ['Wt Range'] = listwtrange
                    df_050_059_OM_VS1_L ['Company'] = listcom
                    df_050_059_OM_VS1_L ['Shape'] = listshap
                    df_050_059_OM_VS1_L ['Carat'] = listcar
                    df_050_059_OM_VS1_L ['Color'] = listcol
                    df_050_059_OM_VS1_L ['Clarity'] = listclar
                    df_050_059_OM_VS1_L ['Cut'] = listcut
                    df_050_059_OM_VS1_L ['Polish'] = listpol
                    df_050_059_OM_VS1_L ['Symmetry'] = listsym
                    df_050_059_OM_VS1_L ['Ratio'] = listrat
                    df_050_059_OM_VS1_L ['PPC'] = listdesc
                    df_050_059_OM_VS1_L ['Total'] = listtotal
                    df_050_059_OM_VS1_L['Carat'] = df_050_059_OM_VS1_L['Carat'].astype('float64')
                    df_050_059_OM_VS1_L['PPC'] = df_050_059_OM_VS1_L['PPC'].astype('float64')
                    df_050_059_OM_VS1_L['Total'] = df_050_059_OM_VS1_L['Total'].astype('float64')
                    df_050_059_OM_VS1_L['Total'] = df_050_059_OM_VS1_L['Carat'] * df_050_059_OM_VS1_L['PPC']


                elif i=="L" and j == "VS2" and k == "OM":
                    df_050_059_OM_VS2_L = pd.DataFrame()
                    df_050_059_OM_VS2_L ['Wt Range'] = None
                    df_050_059_OM_VS2_L  = df_050_059_OM_VS2_L.assign(Company=None)
                    df_050_059_OM_VS2_L  = df_050_059_OM_VS2_L.assign(Shape=None)
                    df_050_059_OM_VS2_L  = df_050_059_OM_VS2_L.assign(Carat=None)
                    df_050_059_OM_VS2_L  = df_050_059_OM_VS2_L.assign(Color=None)
                    df_050_059_OM_VS2_L  = df_050_059_OM_VS2_L.assign(Clarity=None)
                    df_050_059_OM_VS2_L  = df_050_059_OM_VS2_L.assign(Cut=None)
                    df_050_059_OM_VS2_L  = df_050_059_OM_VS2_L.assign(Polish=None)
                    df_050_059_OM_VS2_L  = df_050_059_OM_VS2_L.assign(Symmetry=None)
                    df_050_059_OM_VS2_L  = df_050_059_OM_VS2_L.assign(Ratio=None)
                    df_050_059_OM_VS2_L  = df_050_059_OM_VS2_L.assign(PPC=None)
                    df_050_059_OM_VS2_L  = df_050_059_OM_VS2_L.assign(Total=None)
                    df_050_059_OM_VS2_L ['Wt Range'] = listwtrange
                    df_050_059_OM_VS2_L ['Company'] = listcom
                    df_050_059_OM_VS2_L ['Shape'] = listshap
                    df_050_059_OM_VS2_L ['Carat'] = listcar
                    df_050_059_OM_VS2_L ['Color'] = listcol
                    df_050_059_OM_VS2_L ['Clarity'] = listclar
                    df_050_059_OM_VS2_L ['Cut'] = listcut
                    df_050_059_OM_VS2_L ['Polish'] = listpol
                    df_050_059_OM_VS2_L ['Symmetry'] = listsym
                    df_050_059_OM_VS2_L ['Ratio'] = listrat
                    df_050_059_OM_VS2_L ['PPC'] = listdesc
                    df_050_059_OM_VS2_L ['Total'] = listtotal
                    df_050_059_OM_VS2_L['Carat'] = df_050_059_OM_VS2_L['Carat'].astype('float64')
                    df_050_059_OM_VS2_L['PPC'] = df_050_059_OM_VS2_L['PPC'].astype('float64')
                    df_050_059_OM_VS2_L['Total'] = df_050_059_OM_VS2_L['Total'].astype('float64')
                    df_050_059_OM_VS2_L['Total'] = df_050_059_OM_VS2_L['Carat'] * df_050_059_OM_VS2_L['PPC']


                elif i=="L" and j == "SI1" and k == "OM":
                    df_050_059_OM_SI1_L = pd.DataFrame()
                    df_050_059_OM_SI1_L ['Wt Range'] = None
                    df_050_059_OM_SI1_L  = df_050_059_OM_SI1_L.assign(Company=None)
                    df_050_059_OM_SI1_L  = df_050_059_OM_SI1_L.assign(Shape=None)
                    df_050_059_OM_SI1_L  = df_050_059_OM_SI1_L.assign(Carat=None)
                    df_050_059_OM_SI1_L  = df_050_059_OM_SI1_L.assign(Color=None)
                    df_050_059_OM_SI1_L  = df_050_059_OM_SI1_L.assign(Clarity=None)
                    df_050_059_OM_SI1_L  = df_050_059_OM_SI1_L.assign(Cut=None)
                    df_050_059_OM_SI1_L  = df_050_059_OM_SI1_L.assign(Polish=None)
                    df_050_059_OM_SI1_L  = df_050_059_OM_SI1_L.assign(Symmetry=None)
                    df_050_059_OM_SI1_L  = df_050_059_OM_SI1_L.assign(Ratio=None)
                    df_050_059_OM_SI1_L  = df_050_059_OM_SI1_L.assign(PPC=None)
                    df_050_059_OM_SI1_L  = df_050_059_OM_SI1_L.assign(Total=None)
                    df_050_059_OM_SI1_L ['Wt Range'] = listwtrange
                    df_050_059_OM_SI1_L ['Company'] = listcom
                    df_050_059_OM_SI1_L ['Shape'] = listshap
                    df_050_059_OM_SI1_L ['Carat'] = listcar
                    df_050_059_OM_SI1_L ['Color'] = listcol
                    df_050_059_OM_SI1_L ['Clarity'] = listclar
                    df_050_059_OM_SI1_L ['Cut'] = listcut
                    df_050_059_OM_SI1_L ['Polish'] = listpol
                    df_050_059_OM_SI1_L ['Symmetry'] = listsym
                    df_050_059_OM_SI1_L ['Ratio'] = listrat
                    df_050_059_OM_SI1_L ['PPC'] = listdesc
                    df_050_059_OM_SI1_L ['Total'] = listtotal
                    df_050_059_OM_SI1_L['Carat'] = df_050_059_OM_SI1_L['Carat'].astype('float64')
                    df_050_059_OM_SI1_L['PPC'] = df_050_059_OM_SI1_L['PPC'].astype('float64')
                    df_050_059_OM_SI1_L['Total'] = df_050_059_OM_SI1_L['Total'].astype('float64')
                    df_050_059_OM_SI1_L['Total'] = df_050_059_OM_SI1_L['Carat'] * df_050_059_OM_SI1_L['PPC']


                elif i=="L" and j == "SI2" and k == "OM":
                    df_050_059_OM_SI2_L = pd.DataFrame()
                    df_050_059_OM_SI2_L ['Wt Range'] = None
                    df_050_059_OM_SI2_L  = df_050_059_OM_SI2_L.assign(Company=None)
                    df_050_059_OM_SI2_L  = df_050_059_OM_SI2_L.assign(Shape=None)
                    df_050_059_OM_SI2_L  = df_050_059_OM_SI2_L.assign(Carat=None)
                    df_050_059_OM_SI2_L  = df_050_059_OM_SI2_L.assign(Color=None)
                    df_050_059_OM_SI2_L  = df_050_059_OM_SI2_L.assign(Clarity=None)
                    df_050_059_OM_SI2_L  = df_050_059_OM_SI2_L.assign(Cut=None)
                    df_050_059_OM_SI2_L  = df_050_059_OM_SI2_L.assign(Polish=None)
                    df_050_059_OM_SI2_L  = df_050_059_OM_SI2_L.assign(Symmetry=None)
                    df_050_059_OM_SI2_L  = df_050_059_OM_SI2_L.assign(Ratio=None)
                    df_050_059_OM_SI2_L  = df_050_059_OM_SI2_L.assign(PPC=None)
                    df_050_059_OM_SI2_L  = df_050_059_OM_SI2_L.assign(Total=None)
                    df_050_059_OM_SI2_L ['Wt Range'] = listwtrange
                    df_050_059_OM_SI2_L ['Company'] = listcom
                    df_050_059_OM_SI2_L ['Shape'] = listshap
                    df_050_059_OM_SI2_L ['Carat'] = listcar
                    df_050_059_OM_SI2_L ['Color'] = listcol
                    df_050_059_OM_SI2_L ['Clarity'] = listclar
                    df_050_059_OM_SI2_L ['Cut'] = listcut
                    df_050_059_OM_SI2_L ['Polish'] = listpol
                    df_050_059_OM_SI2_L ['Symmetry'] = listsym
                    df_050_059_OM_SI2_L ['Ratio'] = listrat
                    df_050_059_OM_SI2_L ['PPC'] = listdesc
                    df_050_059_OM_SI2_L ['Total'] = listtotal
                    df_050_059_OM_SI2_L['Carat'] = df_050_059_OM_SI2_L['Carat'].astype('float64')
                    df_050_059_OM_SI2_L['PPC'] = df_050_059_OM_SI2_L['PPC'].astype('float64')
                    df_050_059_OM_SI2_L['Total'] = df_050_059_OM_SI2_L['Total'].astype('float64')
                    df_050_059_OM_SI2_L['Total'] = df_050_059_OM_SI2_L['Carat'] * df_050_059_OM_SI2_L['PPC']


                elif i=="L" and j == "I1" and k == "OM":
                    df_050_059_OM_I1_L = pd.DataFrame()
                    df_050_059_OM_I1_L ['Wt Range'] = None
                    df_050_059_OM_I1_L  = df_050_059_OM_I1_L.assign(Company=None)
                    df_050_059_OM_I1_L  = df_050_059_OM_I1_L.assign(Shape=None)
                    df_050_059_OM_I1_L  = df_050_059_OM_I1_L.assign(Carat=None)
                    df_050_059_OM_I1_L  = df_050_059_OM_I1_L.assign(Color=None)
                    df_050_059_OM_I1_L  = df_050_059_OM_I1_L.assign(Clarity=None)
                    df_050_059_OM_I1_L  = df_050_059_OM_I1_L.assign(Cut=None)
                    df_050_059_OM_I1_L  = df_050_059_OM_I1_L.assign(Polish=None)
                    df_050_059_OM_I1_L  = df_050_059_OM_I1_L.assign(Symmetry=None)
                    df_050_059_OM_I1_L  = df_050_059_OM_I1_L.assign(Ratio=None)
                    df_050_059_OM_I1_L  = df_050_059_OM_I1_L.assign(PPC=None)
                    df_050_059_OM_I1_L  = df_050_059_OM_I1_L.assign(Total=None)
                    df_050_059_OM_I1_L ['Wt Range'] = listwtrange
                    df_050_059_OM_I1_L ['Company'] = listcom
                    df_050_059_OM_I1_L ['Shape'] = listshap
                    df_050_059_OM_I1_L ['Carat'] = listcar
                    df_050_059_OM_I1_L ['Color'] = listcol
                    df_050_059_OM_I1_L ['Clarity'] = listclar
                    df_050_059_OM_I1_L ['Cut'] = listcut
                    df_050_059_OM_I1_L ['Polish'] = listpol
                    df_050_059_OM_I1_L ['Symmetry'] = listsym
                    df_050_059_OM_I1_L ['Ratio'] = listrat
                    df_050_059_OM_I1_L ['PPC'] = listdesc
                    df_050_059_OM_I1_L ['Total'] = listtotal
                    df_050_059_OM_I1_L['Carat'] = df_050_059_OM_I1_L['Carat'].astype('float64')
                    df_050_059_OM_I1_L['PPC'] = df_050_059_OM_I1_L['PPC'].astype('float64')
                    df_050_059_OM_I1_L['Total'] = df_050_059_OM_I1_L['Total'].astype('float64')
                    df_050_059_OM_I1_L['Total'] = df_050_059_OM_I1_L['Carat'] * df_050_059_OM_I1_L['PPC']


                elif i=="L" and j == "I2" and k == "OM":
                    df_050_059_OM_I2_L = pd.DataFrame()
                    df_050_059_OM_I2_L ['Wt Range'] = None
                    df_050_059_OM_I2_L  = df_050_059_OM_I2_L.assign(Company=None)
                    df_050_059_OM_I2_L  = df_050_059_OM_I2_L.assign(Shape=None)
                    df_050_059_OM_I2_L  = df_050_059_OM_I2_L.assign(Carat=None)
                    df_050_059_OM_I2_L  = df_050_059_OM_I2_L.assign(Color=None)
                    df_050_059_OM_I2_L  = df_050_059_OM_I2_L.assign(Clarity=None)
                    df_050_059_OM_I2_L  = df_050_059_OM_I2_L.assign(Cut=None)
                    df_050_059_OM_I2_L  = df_050_059_OM_I2_L.assign(Polish=None)
                    df_050_059_OM_I2_L  = df_050_059_OM_I2_L.assign(Symmetry=None)
                    df_050_059_OM_I2_L  = df_050_059_OM_I2_L.assign(Ratio=None)
                    df_050_059_OM_I2_L  = df_050_059_OM_I2_L.assign(PPC=None)
                    df_050_059_OM_I2_L  = df_050_059_OM_I2_L.assign(Total=None)
                    df_050_059_OM_I2_L ['Wt Range'] = listwtrange
                    df_050_059_OM_I2_L ['Company'] = listcom
                    df_050_059_OM_I2_L ['Shape'] = listshap
                    df_050_059_OM_I2_L ['Carat'] = listcar
                    df_050_059_OM_I2_L ['Color'] = listcol
                    df_050_059_OM_I2_L ['Clarity'] = listclar
                    df_050_059_OM_I2_L ['Cut'] = listcut
                    df_050_059_OM_I2_L ['Polish'] = listpol
                    df_050_059_OM_I2_L ['Symmetry'] = listsym
                    df_050_059_OM_I2_L ['Ratio'] = listrat
                    df_050_059_OM_I2_L ['PPC'] = listdesc
                    df_050_059_OM_I2_L ['Total'] = listtotal
                    df_050_059_OM_I2_L['Carat'] = df_050_059_OM_I2_L['Carat'].astype('float64')
                    df_050_059_OM_I2_L['PPC'] = df_050_059_OM_I2_L['PPC'].astype('float64')
                    df_050_059_OM_I2_L['Total'] = df_050_059_OM_I2_L['Total'].astype('float64')
                    df_050_059_OM_I2_L['Total'] = df_050_059_OM_I2_L['Carat'] * df_050_059_OM_I2_L['PPC']


                elif i=="D" and j == "IF" and k == "AS":
                    df_050_059_AS_IF_D = pd.DataFrame()
                    df_050_059_AS_IF_D ['Wt Range'] = None
                    df_050_059_AS_IF_D  = df_050_059_AS_IF_D.assign(Company=None)
                    df_050_059_AS_IF_D  = df_050_059_AS_IF_D.assign(Shape=None)
                    df_050_059_AS_IF_D  = df_050_059_AS_IF_D.assign(Carat=None)
                    df_050_059_AS_IF_D  = df_050_059_AS_IF_D.assign(Color=None)
                    df_050_059_AS_IF_D  = df_050_059_AS_IF_D.assign(Clarity=None)
                    df_050_059_AS_IF_D  = df_050_059_AS_IF_D.assign(Cut=None)
                    df_050_059_AS_IF_D  = df_050_059_AS_IF_D.assign(Polish=None)
                    df_050_059_AS_IF_D  = df_050_059_AS_IF_D.assign(Symmetry=None)
                    df_050_059_AS_IF_D  = df_050_059_AS_IF_D.assign(Ratio=None)
                    df_050_059_AS_IF_D  = df_050_059_AS_IF_D.assign(PPC=None)
                    df_050_059_AS_IF_D  = df_050_059_AS_IF_D.assign(Total=None)
                    df_050_059_AS_IF_D ['Wt Range'] = listwtrange
                    df_050_059_AS_IF_D ['Company'] = listcom
                    df_050_059_AS_IF_D ['Shape'] = listshap
                    df_050_059_AS_IF_D ['Carat'] = listcar
                    df_050_059_AS_IF_D ['Color'] = listcol
                    df_050_059_AS_IF_D ['Clarity'] = listclar
                    df_050_059_AS_IF_D ['Cut'] = listcut
                    df_050_059_AS_IF_D ['Polish'] = listpol
                    df_050_059_AS_IF_D ['Symmetry'] = listsym
                    df_050_059_AS_IF_D ['Ratio'] = listrat
                    df_050_059_AS_IF_D ['PPC'] = listdesc
                    df_050_059_AS_IF_D ['Total'] = listtotal
                    df_050_059_AS_IF_D['Carat'] = df_050_059_AS_IF_D['Carat'].astype('float64')
                    df_050_059_AS_IF_D['PPC'] = df_050_059_AS_IF_D['PPC'].astype('float64')
                    df_050_059_AS_IF_D['Total'] = df_050_059_AS_IF_D['Total'].astype('float64')
                    df_050_059_AS_IF_D['Total'] = df_050_059_AS_IF_D['Carat'] * df_050_059_AS_IF_D['PPC']



                elif i=="D" and j == "VVS1" and k == "AS" :
                    df_050_059_AS_VVS1_D = pd.DataFrame()
                    df_050_059_AS_VVS1_D ['Wt Range'] = None
                    df_050_059_AS_VVS1_D  = df_050_059_AS_VVS1_D.assign(Company=None)
                    df_050_059_AS_VVS1_D  = df_050_059_AS_VVS1_D.assign(Shape=None)
                    df_050_059_AS_VVS1_D  = df_050_059_AS_VVS1_D.assign(Carat=None)
                    df_050_059_AS_VVS1_D  = df_050_059_AS_VVS1_D.assign(Color=None)
                    df_050_059_AS_VVS1_D  = df_050_059_AS_VVS1_D.assign(Clarity=None)
                    df_050_059_AS_VVS1_D  = df_050_059_AS_VVS1_D.assign(Cut=None)
                    df_050_059_AS_VVS1_D  = df_050_059_AS_VVS1_D.assign(Polish=None)
                    df_050_059_AS_VVS1_D  = df_050_059_AS_VVS1_D.assign(Symmetry=None)
                    df_050_059_AS_VVS1_D  = df_050_059_AS_VVS1_D.assign(Ratio=None)
                    df_050_059_AS_VVS1_D  = df_050_059_AS_VVS1_D.assign(PPC=None)
                    df_050_059_AS_VVS1_D  = df_050_059_AS_VVS1_D.assign(Total=None)
                    df_050_059_AS_VVS1_D ['Wt Range'] = listwtrange
                    df_050_059_AS_VVS1_D ['Company'] = listcom
                    df_050_059_AS_VVS1_D ['Shape'] = listshap
                    df_050_059_AS_VVS1_D ['Carat'] = listcar
                    df_050_059_AS_VVS1_D ['Color'] = listcol
                    df_050_059_AS_VVS1_D ['Clarity'] = listclar
                    df_050_059_AS_VVS1_D ['Cut'] = listcut
                    df_050_059_AS_VVS1_D ['Polish'] = listpol
                    df_050_059_AS_VVS1_D ['Symmetry'] = listsym
                    df_050_059_AS_VVS1_D ['Ratio'] = listrat
                    df_050_059_AS_VVS1_D ['PPC'] = listdesc
                    df_050_059_AS_VVS1_D ['Total'] = listtotal
                    df_050_059_AS_VVS1_D['Carat'] = df_050_059_AS_VVS1_D['Carat'].astype('float64')
                    df_050_059_AS_VVS1_D['PPC'] = df_050_059_AS_VVS1_D['PPC'].astype('float64')
                    df_050_059_AS_VVS1_D['Total'] = df_050_059_AS_VVS1_D['Total'].astype('float64')
                    df_050_059_AS_VVS1_D['Total'] = df_050_059_AS_VVS1_D['Carat'] * df_050_059_AS_VVS1_D['PPC']



                elif i=="D" and j == "VVS2" and k == "AS" :
                    df_050_059_AS_VVS2_D = pd.DataFrame()
                    df_050_059_AS_VVS2_D ['Wt Range'] = None
                    df_050_059_AS_VVS2_D  = df_050_059_AS_VVS2_D.assign(Company=None)
                    df_050_059_AS_VVS2_D  = df_050_059_AS_VVS2_D.assign(Shape=None)
                    df_050_059_AS_VVS2_D  = df_050_059_AS_VVS2_D.assign(Carat=None)
                    df_050_059_AS_VVS2_D  = df_050_059_AS_VVS2_D.assign(Color=None)
                    df_050_059_AS_VVS2_D  = df_050_059_AS_VVS2_D.assign(Clarity=None)
                    df_050_059_AS_VVS2_D  = df_050_059_AS_VVS2_D.assign(Cut=None)
                    df_050_059_AS_VVS2_D  = df_050_059_AS_VVS2_D.assign(Polish=None)
                    df_050_059_AS_VVS2_D  = df_050_059_AS_VVS2_D.assign(Symmetry=None)
                    df_050_059_AS_VVS2_D  = df_050_059_AS_VVS2_D.assign(Ratio=None)
                    df_050_059_AS_VVS2_D  = df_050_059_AS_VVS2_D.assign(PPC=None)
                    df_050_059_AS_VVS2_D  = df_050_059_AS_VVS2_D.assign(Total=None)
                    df_050_059_AS_VVS2_D ['Wt Range'] = listwtrange
                    df_050_059_AS_VVS2_D ['Company'] = listcom
                    df_050_059_AS_VVS2_D ['Shape'] = listshap
                    df_050_059_AS_VVS2_D ['Carat'] = listcar
                    df_050_059_AS_VVS2_D ['Color'] = listcol
                    df_050_059_AS_VVS2_D ['Clarity'] = listclar
                    df_050_059_AS_VVS2_D ['Cut'] = listcut
                    df_050_059_AS_VVS2_D ['Polish'] = listpol
                    df_050_059_AS_VVS2_D ['Symmetry'] = listsym
                    df_050_059_AS_VVS2_D ['Ratio'] = listrat
                    df_050_059_AS_VVS2_D ['PPC'] = listdesc
                    df_050_059_AS_VVS2_D ['Total'] = listtotal
                    df_050_059_AS_VVS2_D['Carat'] = df_050_059_AS_VVS2_D['Carat'].astype('float64')
                    df_050_059_AS_VVS2_D['PPC'] = df_050_059_AS_VVS2_D['PPC'].astype('float64')
                    df_050_059_AS_VVS2_D['Total'] = df_050_059_AS_VVS2_D['Total'].astype('float64')
                    df_050_059_AS_VVS2_D['Total'] = df_050_059_AS_VVS2_D['Carat'] * df_050_059_AS_VVS2_D['PPC']



                elif i=="D" and j == "VS1" and k == "AS":
                    df_050_059_AS_VS1_D = pd.DataFrame()
                    df_050_059_AS_VS1_D ['Wt Range'] = None
                    df_050_059_AS_VS1_D  = df_050_059_AS_VS1_D.assign(Company=None)
                    df_050_059_AS_VS1_D  = df_050_059_AS_VS1_D.assign(Shape=None)
                    df_050_059_AS_VS1_D  = df_050_059_AS_VS1_D.assign(Carat=None)
                    df_050_059_AS_VS1_D  = df_050_059_AS_VS1_D.assign(Color=None)
                    df_050_059_AS_VS1_D  = df_050_059_AS_VS1_D.assign(Clarity=None)
                    df_050_059_AS_VS1_D  = df_050_059_AS_VS1_D.assign(Cut=None)
                    df_050_059_AS_VS1_D  = df_050_059_AS_VS1_D.assign(Polish=None)
                    df_050_059_AS_VS1_D  = df_050_059_AS_VS1_D.assign(Symmetry=None)
                    df_050_059_AS_VS1_D  = df_050_059_AS_VS1_D.assign(Ratio=None)
                    df_050_059_AS_VS1_D  = df_050_059_AS_VS1_D.assign(PPC=None)
                    df_050_059_AS_VS1_D  = df_050_059_AS_VS1_D.assign(Total=None)
                    df_050_059_AS_VS1_D ['Wt Range'] = listwtrange
                    df_050_059_AS_VS1_D ['Company'] = listcom
                    df_050_059_AS_VS1_D ['Shape'] = listshap
                    df_050_059_AS_VS1_D ['Carat'] = listcar
                    df_050_059_AS_VS1_D ['Color'] = listcol
                    df_050_059_AS_VS1_D ['Clarity'] = listclar
                    df_050_059_AS_VS1_D ['Cut'] = listcut
                    df_050_059_AS_VS1_D ['Polish'] = listpol
                    df_050_059_AS_VS1_D ['Symmetry'] = listsym
                    df_050_059_AS_VS1_D ['Ratio'] = listrat
                    df_050_059_AS_VS1_D ['PPC'] = listdesc
                    df_050_059_AS_VS1_D ['Total'] = listtotal
                    df_050_059_AS_VS1_D['Carat'] = df_050_059_AS_VS1_D['Carat'].astype('float64')
                    df_050_059_AS_VS1_D['PPC'] = df_050_059_AS_VS1_D['PPC'].astype('float64')
                    df_050_059_AS_VS1_D['Total'] = df_050_059_AS_VS1_D['Total'].astype('float64')
                    df_050_059_AS_VS1_D['Total'] = df_050_059_AS_VS1_D['Carat'] * df_050_059_AS_VS1_D['PPC']


                elif i=="D" and j == "VS2" and k == "AS":
                    df_050_059_AS_VS2_D = pd.DataFrame()
                    df_050_059_AS_VS2_D ['Wt Range'] = None
                    df_050_059_AS_VS2_D  = df_050_059_AS_VS2_D.assign(Company=None)
                    df_050_059_AS_VS2_D  = df_050_059_AS_VS2_D.assign(Shape=None)
                    df_050_059_AS_VS2_D  = df_050_059_AS_VS2_D.assign(Carat=None)
                    df_050_059_AS_VS2_D  = df_050_059_AS_VS2_D.assign(Color=None)
                    df_050_059_AS_VS2_D  = df_050_059_AS_VS2_D.assign(Clarity=None)
                    df_050_059_AS_VS2_D  = df_050_059_AS_VS2_D.assign(Cut=None)
                    df_050_059_AS_VS2_D  = df_050_059_AS_VS2_D.assign(Polish=None)
                    df_050_059_AS_VS2_D  = df_050_059_AS_VS2_D.assign(Symmetry=None)
                    df_050_059_AS_VS2_D  = df_050_059_AS_VS2_D.assign(Ratio=None)
                    df_050_059_AS_VS2_D  = df_050_059_AS_VS2_D.assign(PPC=None)
                    df_050_059_AS_VS2_D  = df_050_059_AS_VS2_D.assign(Total=None)
                    df_050_059_AS_VS2_D ['Wt Range'] = listwtrange
                    df_050_059_AS_VS2_D ['Company'] = listcom
                    df_050_059_AS_VS2_D ['Shape'] = listshap
                    df_050_059_AS_VS2_D ['Carat'] = listcar
                    df_050_059_AS_VS2_D ['Color'] = listcol
                    df_050_059_AS_VS2_D ['Clarity'] = listclar
                    df_050_059_AS_VS2_D ['Cut'] = listcut
                    df_050_059_AS_VS2_D ['Polish'] = listpol
                    df_050_059_AS_VS2_D ['Symmetry'] = listsym
                    df_050_059_AS_VS2_D ['Ratio'] = listrat
                    df_050_059_AS_VS2_D ['PPC'] = listdesc
                    df_050_059_AS_VS2_D ['Total'] = listtotal
                    df_050_059_AS_VS2_D['Carat'] = df_050_059_AS_VS2_D['Carat'].astype('float64')
                    df_050_059_AS_VS2_D['PPC'] = df_050_059_AS_VS2_D['PPC'].astype('float64')
                    df_050_059_AS_VS2_D['Total'] = df_050_059_AS_VS2_D['Total'].astype('float64')
                    df_050_059_AS_VS2_D['Total'] = df_050_059_AS_VS2_D['Carat'] * df_050_059_AS_VS2_D['PPC']


                elif i=="D" and j == "SI1" and k == "AS":
                    df_050_059_AS_SI1_D = pd.DataFrame()
                    df_050_059_AS_SI1_D ['Wt Range'] = None
                    df_050_059_AS_SI1_D  = df_050_059_AS_SI1_D.assign(Company=None)
                    df_050_059_AS_SI1_D  = df_050_059_AS_SI1_D.assign(Shape=None)
                    df_050_059_AS_SI1_D  = df_050_059_AS_SI1_D.assign(Carat=None)
                    df_050_059_AS_SI1_D  = df_050_059_AS_SI1_D.assign(Color=None)
                    df_050_059_AS_SI1_D  = df_050_059_AS_SI1_D.assign(Clarity=None)
                    df_050_059_AS_SI1_D  = df_050_059_AS_SI1_D.assign(Cut=None)
                    df_050_059_AS_SI1_D  = df_050_059_AS_SI1_D.assign(Polish=None)
                    df_050_059_AS_SI1_D  = df_050_059_AS_SI1_D.assign(Symmetry=None)
                    df_050_059_AS_SI1_D  = df_050_059_AS_SI1_D.assign(Ratio=None)
                    df_050_059_AS_SI1_D  = df_050_059_AS_SI1_D.assign(PPC=None)
                    df_050_059_AS_SI1_D  = df_050_059_AS_SI1_D.assign(Total=None)
                    df_050_059_AS_SI1_D ['Wt Range'] = listwtrange
                    df_050_059_AS_SI1_D ['Company'] = listcom
                    df_050_059_AS_SI1_D ['Shape'] = listshap
                    df_050_059_AS_SI1_D ['Carat'] = listcar
                    df_050_059_AS_SI1_D ['Color'] = listcol
                    df_050_059_AS_SI1_D ['Clarity'] = listclar
                    df_050_059_AS_SI1_D ['Cut'] = listcut
                    df_050_059_AS_SI1_D ['Polish'] = listpol
                    df_050_059_AS_SI1_D ['Symmetry'] = listsym
                    df_050_059_AS_SI1_D ['Ratio'] = listrat
                    df_050_059_AS_SI1_D ['PPC'] = listdesc
                    df_050_059_AS_SI1_D ['Total'] = listtotal
                    df_050_059_AS_SI1_D['Carat'] = df_050_059_AS_SI1_D['Carat'].astype('float64')
                    df_050_059_AS_SI1_D['PPC'] = df_050_059_AS_SI1_D['PPC'].astype('float64')
                    df_050_059_AS_SI1_D['Total'] = df_050_059_AS_SI1_D['Total'].astype('float64')
                    df_050_059_AS_SI1_D['Total'] = df_050_059_AS_SI1_D['Carat'] * df_050_059_AS_SI1_D['PPC']


                elif i=="D" and j == "SI2" and k == "AS":
                    df_050_059_AS_SI2_D = pd.DataFrame()
                    df_050_059_AS_SI2_D ['Wt Range'] = None
                    df_050_059_AS_SI2_D  = df_050_059_AS_SI2_D.assign(Company=None)
                    df_050_059_AS_SI2_D  = df_050_059_AS_SI2_D.assign(Shape=None)
                    df_050_059_AS_SI2_D  = df_050_059_AS_SI2_D.assign(Carat=None)
                    df_050_059_AS_SI2_D  = df_050_059_AS_SI2_D.assign(Color=None)
                    df_050_059_AS_SI2_D  = df_050_059_AS_SI2_D.assign(Clarity=None)
                    df_050_059_AS_SI2_D  = df_050_059_AS_SI2_D.assign(Cut=None)
                    df_050_059_AS_SI2_D  = df_050_059_AS_SI2_D.assign(Polish=None)
                    df_050_059_AS_SI2_D  = df_050_059_AS_SI2_D.assign(Symmetry=None)
                    df_050_059_AS_SI2_D  = df_050_059_AS_SI2_D.assign(Ratio=None)
                    df_050_059_AS_SI2_D  = df_050_059_AS_SI2_D.assign(PPC=None)
                    df_050_059_AS_SI2_D  = df_050_059_AS_SI2_D.assign(Total=None)
                    df_050_059_AS_SI2_D ['Wt Range'] = listwtrange
                    df_050_059_AS_SI2_D ['Company'] = listcom
                    df_050_059_AS_SI2_D ['Shape'] = listshap
                    df_050_059_AS_SI2_D ['Carat'] = listcar
                    df_050_059_AS_SI2_D ['Color'] = listcol
                    df_050_059_AS_SI2_D ['Clarity'] = listclar
                    df_050_059_AS_SI2_D ['Cut'] = listcut
                    df_050_059_AS_SI2_D ['Polish'] = listpol
                    df_050_059_AS_SI2_D ['Symmetry'] = listsym
                    df_050_059_AS_SI2_D ['Ratio'] = listrat
                    df_050_059_AS_SI2_D ['PPC'] = listdesc
                    df_050_059_AS_SI2_D ['Total'] = listtotal
                    df_050_059_AS_SI2_D['Carat'] = df_050_059_AS_SI2_D['Carat'].astype('float64')
                    df_050_059_AS_SI2_D['PPC'] = df_050_059_AS_SI2_D['PPC'].astype('float64')
                    df_050_059_AS_SI2_D['Total'] = df_050_059_AS_SI2_D['Total'].astype('float64')
                    df_050_059_AS_SI2_D['Total'] = df_050_059_AS_SI2_D['Carat'] * df_050_059_AS_SI2_D['PPC']


                elif i=="D" and j == "I1" and k == "AS":
                    df_050_059_AS_I1_D = pd.DataFrame()
                    df_050_059_AS_I1_D ['Wt Range'] = None
                    df_050_059_AS_I1_D  = df_050_059_AS_I1_D.assign(Company=None)
                    df_050_059_AS_I1_D  = df_050_059_AS_I1_D.assign(Shape=None)
                    df_050_059_AS_I1_D  = df_050_059_AS_I1_D.assign(Carat=None)
                    df_050_059_AS_I1_D  = df_050_059_AS_I1_D.assign(Color=None)
                    df_050_059_AS_I1_D  = df_050_059_AS_I1_D.assign(Clarity=None)
                    df_050_059_AS_I1_D  = df_050_059_AS_I1_D.assign(Cut=None)
                    df_050_059_AS_I1_D  = df_050_059_AS_I1_D.assign(Polish=None)
                    df_050_059_AS_I1_D  = df_050_059_AS_I1_D.assign(Symmetry=None)
                    df_050_059_AS_I1_D  = df_050_059_AS_I1_D.assign(Ratio=None)
                    df_050_059_AS_I1_D  = df_050_059_AS_I1_D.assign(PPC=None)
                    df_050_059_AS_I1_D  = df_050_059_AS_I1_D.assign(Total=None)
                    df_050_059_AS_I1_D ['Wt Range'] = listwtrange
                    df_050_059_AS_I1_D ['Company'] = listcom
                    df_050_059_AS_I1_D ['Shape'] = listshap
                    df_050_059_AS_I1_D ['Carat'] = listcar
                    df_050_059_AS_I1_D ['Color'] = listcol
                    df_050_059_AS_I1_D ['Clarity'] = listclar
                    df_050_059_AS_I1_D ['Cut'] = listcut
                    df_050_059_AS_I1_D ['Polish'] = listpol
                    df_050_059_AS_I1_D ['Symmetry'] = listsym
                    df_050_059_AS_I1_D ['Ratio'] = listrat
                    df_050_059_AS_I1_D ['PPC'] = listdesc
                    df_050_059_AS_I1_D ['Total'] = listtotal
                    df_050_059_AS_I1_D['Carat'] = df_050_059_AS_I1_D['Carat'].astype('float64')
                    df_050_059_AS_I1_D['PPC'] = df_050_059_AS_I1_D['PPC'].astype('float64')
                    df_050_059_AS_I1_D['Total'] = df_050_059_AS_I1_D['Total'].astype('float64')
                    df_050_059_AS_I1_D['Total'] = df_050_059_AS_I1_D['Carat'] * df_050_059_AS_I1_D['PPC']


                elif i=="D" and j == "I2" and k == "AS":
                    df_050_059_AS_I2_D = pd.DataFrame()
                    df_050_059_AS_I2_D ['Wt Range'] = None
                    df_050_059_AS_I2_D  = df_050_059_AS_I2_D.assign(Company=None)
                    df_050_059_AS_I2_D  = df_050_059_AS_I2_D.assign(Shape=None)
                    df_050_059_AS_I2_D  = df_050_059_AS_I2_D.assign(Carat=None)
                    df_050_059_AS_I2_D  = df_050_059_AS_I2_D.assign(Color=None)
                    df_050_059_AS_I2_D  = df_050_059_AS_I2_D.assign(Clarity=None)
                    df_050_059_AS_I2_D  = df_050_059_AS_I2_D.assign(Cut=None)
                    df_050_059_AS_I2_D  = df_050_059_AS_I2_D.assign(Polish=None)
                    df_050_059_AS_I2_D  = df_050_059_AS_I2_D.assign(Symmetry=None)
                    df_050_059_AS_I2_D  = df_050_059_AS_I2_D.assign(Ratio=None)
                    df_050_059_AS_I2_D  = df_050_059_AS_I2_D.assign(PPC=None)
                    df_050_059_AS_I2_D  = df_050_059_AS_I2_D.assign(Total=None)
                    df_050_059_AS_I2_D ['Wt Range'] = listwtrange
                    df_050_059_AS_I2_D ['Company'] = listcom
                    df_050_059_AS_I2_D ['Shape'] = listshap
                    df_050_059_AS_I2_D ['Carat'] = listcar
                    df_050_059_AS_I2_D ['Color'] = listcol
                    df_050_059_AS_I2_D ['Clarity'] = listclar
                    df_050_059_AS_I2_D ['Cut'] = listcut
                    df_050_059_AS_I2_D ['Polish'] = listpol
                    df_050_059_AS_I2_D ['Symmetry'] = listsym
                    df_050_059_AS_I2_D ['Ratio'] = listrat
                    df_050_059_AS_I2_D ['PPC'] = listdesc
                    df_050_059_AS_I2_D ['Total'] = listtotal
                    df_050_059_AS_I2_D['Carat'] = df_050_059_AS_I2_D['Carat'].astype('float64')
                    df_050_059_AS_I2_D['PPC'] = df_050_059_AS_I2_D['PPC'].astype('float64')
                    df_050_059_AS_I2_D['Total'] = df_050_059_AS_I2_D['Total'].astype('float64')
                    df_050_059_AS_I2_D['Total'] = df_050_059_AS_I2_D['Carat'] * df_050_059_AS_I2_D['PPC']



                elif i=="E" and j == "IF" and k == "AS":
                    df_050_059_AS_IF_E = pd.DataFrame()
                    df_050_059_AS_IF_E ['Wt Range'] = None
                    df_050_059_AS_IF_E  = df_050_059_AS_IF_E.assign(Company=None)
                    df_050_059_AS_IF_E  = df_050_059_AS_IF_E.assign(Shape=None)
                    df_050_059_AS_IF_E  = df_050_059_AS_IF_E.assign(Carat=None)
                    df_050_059_AS_IF_E  = df_050_059_AS_IF_E.assign(Color=None)
                    df_050_059_AS_IF_E  = df_050_059_AS_IF_E.assign(Clarity=None)
                    df_050_059_AS_IF_E  = df_050_059_AS_IF_E.assign(Cut=None)
                    df_050_059_AS_IF_E  = df_050_059_AS_IF_E.assign(Polish=None)
                    df_050_059_AS_IF_E  = df_050_059_AS_IF_E.assign(Symmetry=None)
                    df_050_059_AS_IF_E  = df_050_059_AS_IF_E.assign(Ratio=None)
                    df_050_059_AS_IF_E  = df_050_059_AS_IF_E.assign(PPC=None)
                    df_050_059_AS_IF_E  = df_050_059_AS_IF_E.assign(Total=None)
                    df_050_059_AS_IF_E ['Wt Range'] = listwtrange
                    df_050_059_AS_IF_E ['Company'] = listcom
                    df_050_059_AS_IF_E ['Shape'] = listshap
                    df_050_059_AS_IF_E ['Carat'] = listcar
                    df_050_059_AS_IF_E ['Color'] = listcol
                    df_050_059_AS_IF_E ['Clarity'] = listclar
                    df_050_059_AS_IF_E ['Cut'] = listcut
                    df_050_059_AS_IF_E ['Polish'] = listpol
                    df_050_059_AS_IF_E ['Symmetry'] = listsym
                    df_050_059_AS_IF_E ['Ratio'] = listrat
                    df_050_059_AS_IF_E ['PPC'] = listdesc
                    df_050_059_AS_IF_E ['Total'] = listtotal
                    df_050_059_AS_IF_E['Carat'] = df_050_059_AS_IF_E['Carat'].astype('float64')
                    df_050_059_AS_IF_E['PPC'] = df_050_059_AS_IF_E['PPC'].astype('float64')
                    df_050_059_AS_IF_E['Total'] = df_050_059_AS_IF_E['Total'].astype('float64')
                    df_050_059_AS_IF_E['Total'] = df_050_059_AS_IF_E['Carat'] * df_050_059_AS_IF_E['PPC']



                elif i=="E" and j == "VVS1" and k == "AS":
                    df_050_059_AS_VVS1_E = pd.DataFrame()
                    df_050_059_AS_VVS1_E ['Wt Range'] = None
                    df_050_059_AS_VVS1_E  = df_050_059_AS_VVS1_E.assign(Company=None)
                    df_050_059_AS_VVS1_E  = df_050_059_AS_VVS1_E.assign(Shape=None)
                    df_050_059_AS_VVS1_E  = df_050_059_AS_VVS1_E.assign(Carat=None)
                    df_050_059_AS_VVS1_E  = df_050_059_AS_VVS1_E.assign(Color=None)
                    df_050_059_AS_VVS1_E  = df_050_059_AS_VVS1_E.assign(Clarity=None)
                    df_050_059_AS_VVS1_E  = df_050_059_AS_VVS1_E.assign(Cut=None)
                    df_050_059_AS_VVS1_E  = df_050_059_AS_VVS1_E.assign(Polish=None)
                    df_050_059_AS_VVS1_E  = df_050_059_AS_VVS1_E.assign(Symmetry=None)
                    df_050_059_AS_VVS1_E  = df_050_059_AS_VVS1_E.assign(Ratio=None)
                    df_050_059_AS_VVS1_E  = df_050_059_AS_VVS1_E.assign(PPC=None)
                    df_050_059_AS_VVS1_E  = df_050_059_AS_VVS1_E.assign(Total=None)
                    df_050_059_AS_VVS1_E ['Wt Range'] = listwtrange
                    df_050_059_AS_VVS1_E ['Company'] = listcom
                    df_050_059_AS_VVS1_E ['Shape'] = listshap
                    df_050_059_AS_VVS1_E ['Carat'] = listcar
                    df_050_059_AS_VVS1_E ['Color'] = listcol
                    df_050_059_AS_VVS1_E ['Clarity'] = listclar
                    df_050_059_AS_VVS1_E ['Cut'] = listcut
                    df_050_059_AS_VVS1_E ['Polish'] = listpol
                    df_050_059_AS_VVS1_E ['Symmetry'] = listsym
                    df_050_059_AS_VVS1_E ['Ratio'] = listrat
                    df_050_059_AS_VVS1_E ['PPC'] = listdesc
                    df_050_059_AS_VVS1_E ['Total'] = listtotal
                    df_050_059_AS_VVS1_E['Carat'] = df_050_059_AS_VVS1_E['Carat'].astype('float64')
                    df_050_059_AS_VVS1_E['PPC'] = df_050_059_AS_VVS1_E['PPC'].astype('float64')
                    df_050_059_AS_VVS1_E['Total'] = df_050_059_AS_VVS1_E['Total'].astype('float64')
                    df_050_059_AS_VVS1_E['Total'] = df_050_059_AS_VVS1_E['Carat'] * df_050_059_AS_VVS1_E['PPC']


                elif i=="E" and j == "VVS2" and k == "AS":
                    df_050_059_AS_VVS2_E = pd.DataFrame()
                    df_050_059_AS_VVS2_E ['Wt Range'] = None
                    df_050_059_AS_VVS2_E  = df_050_059_AS_VVS2_E.assign(Company=None)
                    df_050_059_AS_VVS2_E  = df_050_059_AS_VVS2_E.assign(Shape=None)
                    df_050_059_AS_VVS2_E  = df_050_059_AS_VVS2_E.assign(Carat=None)
                    df_050_059_AS_VVS2_E  = df_050_059_AS_VVS2_E.assign(Color=None)
                    df_050_059_AS_VVS2_E  = df_050_059_AS_VVS2_E.assign(Clarity=None)
                    df_050_059_AS_VVS2_E  = df_050_059_AS_VVS2_E.assign(Cut=None)
                    df_050_059_AS_VVS2_E  = df_050_059_AS_VVS2_E.assign(Polish=None)
                    df_050_059_AS_VVS2_E  = df_050_059_AS_VVS2_E.assign(Symmetry=None)
                    df_050_059_AS_VVS2_E  = df_050_059_AS_VVS2_E.assign(Ratio=None)
                    df_050_059_AS_VVS2_E  = df_050_059_AS_VVS2_E.assign(PPC=None)
                    df_050_059_AS_VVS2_E  = df_050_059_AS_VVS2_E.assign(Total=None)
                    df_050_059_AS_VVS2_E ['Wt Range'] = listwtrange
                    df_050_059_AS_VVS2_E ['Company'] = listcom
                    df_050_059_AS_VVS2_E ['Shape'] = listshap
                    df_050_059_AS_VVS2_E ['Carat'] = listcar
                    df_050_059_AS_VVS2_E ['Color'] = listcol
                    df_050_059_AS_VVS2_E ['Clarity'] = listclar
                    df_050_059_AS_VVS2_E ['Cut'] = listcut
                    df_050_059_AS_VVS2_E ['Polish'] = listpol
                    df_050_059_AS_VVS2_E ['Symmetry'] = listsym
                    df_050_059_AS_VVS2_E ['Ratio'] = listrat
                    df_050_059_AS_VVS2_E ['PPC'] = listdesc
                    df_050_059_AS_VVS2_E ['Total'] = listtotal
                    df_050_059_AS_VVS2_E['Carat'] = df_050_059_AS_VVS2_E['Carat'].astype('float64')
                    df_050_059_AS_VVS2_E['PPC'] = df_050_059_AS_VVS2_E['PPC'].astype('float64')
                    df_050_059_AS_VVS2_E['Total'] = df_050_059_AS_VVS2_E['Total'].astype('float64')
                    df_050_059_AS_VVS2_E['Total'] = df_050_059_AS_VVS2_E['Carat'] * df_050_059_AS_VVS2_E['PPC']


                elif i=="E" and j=="VS1" and k == "AS":
                    df_050_059_AS_VS1_E = pd.DataFrame()
                    df_050_059_AS_VS1_E ['Wt Range'] = None
                    df_050_059_AS_VS1_E  = df_050_059_AS_VS1_E.assign(Company=None)
                    df_050_059_AS_VS1_E  = df_050_059_AS_VS1_E.assign(Shape=None)
                    df_050_059_AS_VS1_E  = df_050_059_AS_VS1_E.assign(Carat=None)
                    df_050_059_AS_VS1_E  = df_050_059_AS_VS1_E.assign(Color=None)
                    df_050_059_AS_VS1_E  = df_050_059_AS_VS1_E.assign(Clarity=None)
                    df_050_059_AS_VS1_E  = df_050_059_AS_VS1_E.assign(Cut=None)
                    df_050_059_AS_VS1_E  = df_050_059_AS_VS1_E.assign(Polish=None)
                    df_050_059_AS_VS1_E  = df_050_059_AS_VS1_E.assign(Symmetry=None)
                    df_050_059_AS_VS1_E  = df_050_059_AS_VS1_E.assign(Ratio=None)
                    df_050_059_AS_VS1_E  = df_050_059_AS_VS1_E.assign(PPC=None)
                    df_050_059_AS_VS1_E  = df_050_059_AS_VS1_E.assign(Total=None)
                    df_050_059_AS_VS1_E ['Wt Range'] = listwtrange
                    df_050_059_AS_VS1_E ['Company'] = listcom
                    df_050_059_AS_VS1_E ['Shape'] = listshap
                    df_050_059_AS_VS1_E ['Carat'] = listcar
                    df_050_059_AS_VS1_E ['Color'] = listcol
                    df_050_059_AS_VS1_E ['Clarity'] = listclar
                    df_050_059_AS_VS1_E ['Cut'] = listcut
                    df_050_059_AS_VS1_E ['Polish'] = listpol
                    df_050_059_AS_VS1_E ['Symmetry'] = listsym
                    df_050_059_AS_VS1_E ['Ratio'] = listrat
                    df_050_059_AS_VS1_E ['PPC'] = listdesc
                    df_050_059_AS_VS1_E ['Total'] = listtotal
                    df_050_059_AS_VS1_E['Carat'] = df_050_059_AS_VS1_E['Carat'].astype('float64')
                    df_050_059_AS_VS1_E['PPC'] = df_050_059_AS_VS1_E['PPC'].astype('float64')
                    df_050_059_AS_VS1_E['Total'] = df_050_059_AS_VS1_E['Total'].astype('float64')
                    df_050_059_AS_VS1_E['Total'] = df_050_059_AS_VS1_E['Carat'] * df_050_059_AS_VS1_E['PPC']


                elif i=="E" and j == "VS2" and k == "AS":
                    df_050_059_AS_VS2_E = pd.DataFrame()
                    df_050_059_AS_VS2_E ['Wt Range'] = None
                    df_050_059_AS_VS2_E  = df_050_059_AS_VS2_E.assign(Company=None)
                    df_050_059_AS_VS2_E  = df_050_059_AS_VS2_E.assign(Shape=None)
                    df_050_059_AS_VS2_E  = df_050_059_AS_VS2_E.assign(Carat=None)
                    df_050_059_AS_VS2_E  = df_050_059_AS_VS2_E.assign(Color=None)
                    df_050_059_AS_VS2_E  = df_050_059_AS_VS2_E.assign(Clarity=None)
                    df_050_059_AS_VS2_E  = df_050_059_AS_VS2_E.assign(Cut=None)
                    df_050_059_AS_VS2_E  = df_050_059_AS_VS2_E.assign(Polish=None)
                    df_050_059_AS_VS2_E  = df_050_059_AS_VS2_E.assign(Symmetry=None)
                    df_050_059_AS_VS2_E  = df_050_059_AS_VS2_E.assign(Ratio=None)
                    df_050_059_AS_VS2_E  = df_050_059_AS_VS2_E.assign(PPC=None)
                    df_050_059_AS_VS2_E  = df_050_059_AS_VS2_E.assign(Total=None)
                    df_050_059_AS_VS2_E ['Wt Range'] = listwtrange
                    df_050_059_AS_VS2_E ['Company'] = listcom
                    df_050_059_AS_VS2_E ['Shape'] = listshap
                    df_050_059_AS_VS2_E ['Carat'] = listcar
                    df_050_059_AS_VS2_E ['Color'] = listcol
                    df_050_059_AS_VS2_E ['Clarity'] = listclar
                    df_050_059_AS_VS2_E ['Cut'] = listcut
                    df_050_059_AS_VS2_E ['Polish'] = listpol
                    df_050_059_AS_VS2_E ['Symmetry'] = listsym
                    df_050_059_AS_VS2_E ['Ratio'] = listrat
                    df_050_059_AS_VS2_E ['PPC'] = listdesc
                    df_050_059_AS_VS2_E ['Total'] = listtotal
                    df_050_059_AS_VS2_E['Carat'] = df_050_059_AS_VS2_E['Carat'].astype('float64')
                    df_050_059_AS_VS2_E['PPC'] = df_050_059_AS_VS2_E['PPC'].astype('float64')
                    df_050_059_AS_VS2_E['Total'] = df_050_059_AS_VS2_E['Total'].astype('float64')
                    df_050_059_AS_VS2_E['Total'] = df_050_059_AS_VS2_E['Carat'] * df_050_059_AS_VS2_E['PPC']


                elif i=="E" and j == "SI1" and k == "AS":
                    df_050_059_AS_SI1_E = pd.DataFrame()
                    df_050_059_AS_SI1_E ['Wt Range'] = None
                    df_050_059_AS_SI1_E  = df_050_059_AS_SI1_E.assign(Company=None)
                    df_050_059_AS_SI1_E  = df_050_059_AS_SI1_E.assign(Shape=None)
                    df_050_059_AS_SI1_E  = df_050_059_AS_SI1_E.assign(Carat=None)
                    df_050_059_AS_SI1_E  = df_050_059_AS_SI1_E.assign(Color=None)
                    df_050_059_AS_SI1_E  = df_050_059_AS_SI1_E.assign(Clarity=None)
                    df_050_059_AS_SI1_E  = df_050_059_AS_SI1_E.assign(Cut=None)
                    df_050_059_AS_SI1_E  = df_050_059_AS_SI1_E.assign(Polish=None)
                    df_050_059_AS_SI1_E  = df_050_059_AS_SI1_E.assign(Symmetry=None)
                    df_050_059_AS_SI1_E  = df_050_059_AS_SI1_E.assign(Ratio=None)
                    df_050_059_AS_SI1_E  = df_050_059_AS_SI1_E.assign(PPC=None)
                    df_050_059_AS_SI1_E  = df_050_059_AS_SI1_E.assign(Total=None)
                    df_050_059_AS_SI1_E ['Wt Range'] = listwtrange
                    df_050_059_AS_SI1_E ['Company'] = listcom
                    df_050_059_AS_SI1_E ['Shape'] = listshap
                    df_050_059_AS_SI1_E ['Carat'] = listcar
                    df_050_059_AS_SI1_E ['Color'] = listcol
                    df_050_059_AS_SI1_E ['Clarity'] = listclar
                    df_050_059_AS_SI1_E ['Cut'] = listcut
                    df_050_059_AS_SI1_E ['Polish'] = listpol
                    df_050_059_AS_SI1_E ['Symmetry'] = listsym
                    df_050_059_AS_SI1_E ['Ratio'] = listrat
                    df_050_059_AS_SI1_E ['PPC'] = listdesc
                    df_050_059_AS_SI1_E ['Total'] = listtotal
                    df_050_059_AS_SI1_E['Carat'] = df_050_059_AS_SI1_E['Carat'].astype('float64')
                    df_050_059_AS_SI1_E['PPC'] = df_050_059_AS_SI1_E['PPC'].astype('float64')
                    df_050_059_AS_SI1_E['Total'] = df_050_059_AS_SI1_E['Total'].astype('float64')
                    df_050_059_AS_SI1_E['Total'] = df_050_059_AS_SI1_E['Carat'] * df_050_059_AS_SI1_E['PPC']


                elif i=="E" and j == "SI2" and k == "AS":
                    df_050_059_AS_SI2_E = pd.DataFrame()
                    df_050_059_AS_SI2_E ['Wt Range'] = None
                    df_050_059_AS_SI2_E  = df_050_059_AS_SI2_E.assign(Company=None)
                    df_050_059_AS_SI2_E  = df_050_059_AS_SI2_E.assign(Shape=None)
                    df_050_059_AS_SI2_E  = df_050_059_AS_SI2_E.assign(Carat=None)
                    df_050_059_AS_SI2_E  = df_050_059_AS_SI2_E.assign(Color=None)
                    df_050_059_AS_SI2_E  = df_050_059_AS_SI2_E.assign(Clarity=None)
                    df_050_059_AS_SI2_E  = df_050_059_AS_SI2_E.assign(Cut=None)
                    df_050_059_AS_SI2_E  = df_050_059_AS_SI2_E.assign(Polish=None)
                    df_050_059_AS_SI2_E  = df_050_059_AS_SI2_E.assign(Symmetry=None)
                    df_050_059_AS_SI2_E  = df_050_059_AS_SI2_E.assign(Ratio=None)
                    df_050_059_AS_SI2_E  = df_050_059_AS_SI2_E.assign(PPC=None)
                    df_050_059_AS_SI2_E  = df_050_059_AS_SI2_E.assign(Total=None)
                    df_050_059_AS_SI2_E ['Wt Range'] = listwtrange
                    df_050_059_AS_SI2_E ['Company'] = listcom
                    df_050_059_AS_SI2_E ['Shape'] = listshap
                    df_050_059_AS_SI2_E ['Carat'] = listcar
                    df_050_059_AS_SI2_E ['Color'] = listcol
                    df_050_059_AS_SI2_E ['Clarity'] = listclar
                    df_050_059_AS_SI2_E ['Cut'] = listcut
                    df_050_059_AS_SI2_E ['Polish'] = listpol
                    df_050_059_AS_SI2_E ['Symmetry'] = listsym
                    df_050_059_AS_SI2_E ['Ratio'] = listrat
                    df_050_059_AS_SI2_E ['PPC'] = listdesc
                    df_050_059_AS_SI2_E ['Total'] = listtotal
                    df_050_059_AS_SI2_E['Carat'] = df_050_059_AS_SI2_E['Carat'].astype('float64')
                    df_050_059_AS_SI2_E['PPC'] = df_050_059_AS_SI2_E['PPC'].astype('float64')
                    df_050_059_AS_SI2_E['Total'] = df_050_059_AS_SI2_E['Total'].astype('float64')
                    df_050_059_AS_SI2_E['Total'] = df_050_059_AS_SI2_E['Carat'] * df_050_059_AS_SI2_E['PPC']


                elif i=="E" and j == "I1" and k == "AS":
                    df_050_059_AS_I1_E = pd.DataFrame()
                    df_050_059_AS_I1_E ['Wt Range'] = None
                    df_050_059_AS_I1_E  = df_050_059_AS_I1_E.assign(Company=None)
                    df_050_059_AS_I1_E  = df_050_059_AS_I1_E.assign(Shape=None)
                    df_050_059_AS_I1_E  = df_050_059_AS_I1_E.assign(Carat=None)
                    df_050_059_AS_I1_E  = df_050_059_AS_I1_E.assign(Color=None)
                    df_050_059_AS_I1_E  = df_050_059_AS_I1_E.assign(Clarity=None)
                    df_050_059_AS_I1_E  = df_050_059_AS_I1_E.assign(Cut=None)
                    df_050_059_AS_I1_E  = df_050_059_AS_I1_E.assign(Polish=None)
                    df_050_059_AS_I1_E  = df_050_059_AS_I1_E.assign(Symmetry=None)
                    df_050_059_AS_I1_E  = df_050_059_AS_I1_E.assign(Ratio=None)
                    df_050_059_AS_I1_E  = df_050_059_AS_I1_E.assign(PPC=None)
                    df_050_059_AS_I1_E  = df_050_059_AS_I1_E.assign(Total=None)
                    df_050_059_AS_I1_E ['Wt Range'] = listwtrange
                    df_050_059_AS_I1_E ['Company'] = listcom
                    df_050_059_AS_I1_E ['Shape'] = listshap
                    df_050_059_AS_I1_E ['Carat'] = listcar
                    df_050_059_AS_I1_E ['Color'] = listcol
                    df_050_059_AS_I1_E ['Clarity'] = listclar
                    df_050_059_AS_I1_E ['Cut'] = listcut
                    df_050_059_AS_I1_E ['Polish'] = listpol
                    df_050_059_AS_I1_E ['Symmetry'] = listsym
                    df_050_059_AS_I1_E ['Ratio'] = listrat
                    df_050_059_AS_I1_E ['PPC'] = listdesc
                    df_050_059_AS_I1_E ['Total'] = listtotal
                    df_050_059_AS_I1_E['Carat'] = df_050_059_AS_I1_E['Carat'].astype('float64')
                    df_050_059_AS_I1_E['PPC'] = df_050_059_AS_I1_E['PPC'].astype('float64')
                    df_050_059_AS_I1_E['Total'] = df_050_059_AS_I1_E['Total'].astype('float64')
                    df_050_059_AS_I1_E['Total'] = df_050_059_AS_I1_E['Carat'] * df_050_059_AS_I1_E['PPC']


                elif i=="E" and j == "I2" and k == "AS":
                    df_050_059_AS_I2_E = pd.DataFrame()
                    df_050_059_AS_I2_E ['Wt Range'] = None
                    df_050_059_AS_I2_E  = df_050_059_AS_I2_E.assign(Company=None)
                    df_050_059_AS_I2_E  = df_050_059_AS_I2_E.assign(Shape=None)
                    df_050_059_AS_I2_E  = df_050_059_AS_I2_E.assign(Carat=None)
                    df_050_059_AS_I2_E  = df_050_059_AS_I2_E.assign(Color=None)
                    df_050_059_AS_I2_E  = df_050_059_AS_I2_E.assign(Clarity=None)
                    df_050_059_AS_I2_E  = df_050_059_AS_I2_E.assign(Cut=None)
                    df_050_059_AS_I2_E  = df_050_059_AS_I2_E.assign(Polish=None)
                    df_050_059_AS_I2_E  = df_050_059_AS_I2_E.assign(Symmetry=None)
                    df_050_059_AS_I2_E  = df_050_059_AS_I2_E.assign(Ratio=None)
                    df_050_059_AS_I2_E  = df_050_059_AS_I2_E.assign(PPC=None)
                    df_050_059_AS_I2_E  = df_050_059_AS_I2_E.assign(Total=None)
                    df_050_059_AS_I2_E ['Wt Range'] = listwtrange
                    df_050_059_AS_I2_E ['Company'] = listcom
                    df_050_059_AS_I2_E ['Shape'] = listshap
                    df_050_059_AS_I2_E ['Carat'] = listcar
                    df_050_059_AS_I2_E ['Color'] = listcol
                    df_050_059_AS_I2_E ['Clarity'] = listclar
                    df_050_059_AS_I2_E ['Cut'] = listcut
                    df_050_059_AS_I2_E ['Polish'] = listpol
                    df_050_059_AS_I2_E ['Symmetry'] = listsym
                    df_050_059_AS_I2_E ['Ratio'] = listrat
                    df_050_059_AS_I2_E ['PPC'] = listdesc
                    df_050_059_AS_I2_E ['Total'] = listtotal
                    df_050_059_AS_I2_E['Carat'] = df_050_059_AS_I2_E['Carat'].astype('float64')
                    df_050_059_AS_I2_E['PPC'] = df_050_059_AS_I2_E['PPC'].astype('float64')
                    df_050_059_AS_I2_E['Total'] = df_050_059_AS_I2_E['Total'].astype('float64')
                    df_050_059_AS_I2_E['Total'] = df_050_059_AS_I2_E['Carat'] * df_050_059_AS_I2_E['PPC']
                
                elif i=="F" and j == "IF" and k == "AS":
                    df_050_059_AS_IF_F = pd.DataFrame()
                    df_050_059_AS_IF_F ['Wt Range'] = None
                    df_050_059_AS_IF_F  = df_050_059_AS_IF_F.assign(Company=None)
                    df_050_059_AS_IF_F  = df_050_059_AS_IF_F.assign(Shape=None)
                    df_050_059_AS_IF_F  = df_050_059_AS_IF_F.assign(Carat=None)
                    df_050_059_AS_IF_F  = df_050_059_AS_IF_F.assign(Color=None)
                    df_050_059_AS_IF_F  = df_050_059_AS_IF_F.assign(Clarity=None)
                    df_050_059_AS_IF_F  = df_050_059_AS_IF_F.assign(Cut=None)
                    df_050_059_AS_IF_F  = df_050_059_AS_IF_F.assign(Polish=None)
                    df_050_059_AS_IF_F  = df_050_059_AS_IF_F.assign(Symmetry=None)
                    df_050_059_AS_IF_F  = df_050_059_AS_IF_F.assign(Ratio=None)
                    df_050_059_AS_IF_F  = df_050_059_AS_IF_F.assign(PPC=None)
                    df_050_059_AS_IF_F  = df_050_059_AS_IF_F.assign(Total=None)
                    df_050_059_AS_IF_F ['Wt Range'] = listwtrange
                    df_050_059_AS_IF_F ['Company'] = listcom
                    df_050_059_AS_IF_F ['Shape'] = listshap
                    df_050_059_AS_IF_F ['Carat'] = listcar
                    df_050_059_AS_IF_F ['Color'] = listcol
                    df_050_059_AS_IF_F ['Clarity'] = listclar
                    df_050_059_AS_IF_F ['Cut'] = listcut
                    df_050_059_AS_IF_F ['Polish'] = listpol
                    df_050_059_AS_IF_F ['Symmetry'] = listsym
                    df_050_059_AS_IF_F ['Ratio'] = listrat
                    df_050_059_AS_IF_F ['PPC'] = listdesc
                    df_050_059_AS_IF_F ['Total'] = listtotal
                    df_050_059_AS_IF_F['Carat'] = df_050_059_AS_IF_F['Carat'].astype('float64')
                    df_050_059_AS_IF_F['PPC'] = df_050_059_AS_IF_F['PPC'].astype('float64')
                    df_050_059_AS_IF_F['Total'] = df_050_059_AS_IF_F['Total'].astype('float64')
                    df_050_059_AS_IF_F['Total'] = df_050_059_AS_IF_F['Carat'] * df_050_059_AS_IF_F['PPC']



                elif i=="F" and j == "VVS1" and k == "AS":
                    df_050_059_AS_VVS1_F = pd.DataFrame()
                    df_050_059_AS_VVS1_F ['Wt Range'] = None
                    df_050_059_AS_VVS1_F  = df_050_059_AS_VVS1_F.assign(Company=None)
                    df_050_059_AS_VVS1_F  = df_050_059_AS_VVS1_F.assign(Shape=None)
                    df_050_059_AS_VVS1_F  = df_050_059_AS_VVS1_F.assign(Carat=None)
                    df_050_059_AS_VVS1_F  = df_050_059_AS_VVS1_F.assign(Color=None)
                    df_050_059_AS_VVS1_F  = df_050_059_AS_VVS1_F.assign(Clarity=None)
                    df_050_059_AS_VVS1_F  = df_050_059_AS_VVS1_F.assign(Cut=None)
                    df_050_059_AS_VVS1_F  = df_050_059_AS_VVS1_F.assign(Polish=None)
                    df_050_059_AS_VVS1_F  = df_050_059_AS_VVS1_F.assign(Symmetry=None)
                    df_050_059_AS_VVS1_F  = df_050_059_AS_VVS1_F.assign(Ratio=None)
                    df_050_059_AS_VVS1_F  = df_050_059_AS_VVS1_F.assign(PPC=None)
                    df_050_059_AS_VVS1_F  = df_050_059_AS_VVS1_F.assign(Total=None)
                    df_050_059_AS_VVS1_F ['Wt Range'] = listwtrange
                    df_050_059_AS_VVS1_F ['Company'] = listcom
                    df_050_059_AS_VVS1_F ['Shape'] = listshap
                    df_050_059_AS_VVS1_F ['Carat'] = listcar
                    df_050_059_AS_VVS1_F ['Color'] = listcol
                    df_050_059_AS_VVS1_F ['Clarity'] = listclar
                    df_050_059_AS_VVS1_F ['Cut'] = listcut
                    df_050_059_AS_VVS1_F ['Polish'] = listpol
                    df_050_059_AS_VVS1_F ['Symmetry'] = listsym
                    df_050_059_AS_VVS1_F ['Ratio'] = listrat
                    df_050_059_AS_VVS1_F ['PPC'] = listdesc
                    df_050_059_AS_VVS1_F ['Total'] = listtotal
                    df_050_059_AS_VVS1_F['Carat'] = df_050_059_AS_VVS1_F['Carat'].astype('float64')
                    df_050_059_AS_VVS1_F['PPC'] = df_050_059_AS_VVS1_F['PPC'].astype('float64')
                    df_050_059_AS_VVS1_F['Total'] = df_050_059_AS_VVS1_F['Total'].astype('float64')
                    df_050_059_AS_VVS1_F['Total'] = df_050_059_AS_VVS1_F['Carat'] * df_050_059_AS_VVS1_F['PPC']


                elif i=="F" and j == "VVS2" and k == "AS":
                    df_050_059_AS_VVS2_F = pd.DataFrame()
                    df_050_059_AS_VVS2_F ['Wt Range'] = None
                    df_050_059_AS_VVS2_F  = df_050_059_AS_VVS2_F.assign(Company=None)
                    df_050_059_AS_VVS2_F  = df_050_059_AS_VVS2_F.assign(Shape=None)
                    df_050_059_AS_VVS2_F  = df_050_059_AS_VVS2_F.assign(Carat=None)
                    df_050_059_AS_VVS2_F  = df_050_059_AS_VVS2_F.assign(Color=None)
                    df_050_059_AS_VVS2_F  = df_050_059_AS_VVS2_F.assign(Clarity=None)
                    df_050_059_AS_VVS2_F  = df_050_059_AS_VVS2_F.assign(Cut=None)
                    df_050_059_AS_VVS2_F  = df_050_059_AS_VVS2_F.assign(Polish=None)
                    df_050_059_AS_VVS2_F  = df_050_059_AS_VVS2_F.assign(Symmetry=None)
                    df_050_059_AS_VVS2_F  = df_050_059_AS_VVS2_F.assign(Ratio=None)
                    df_050_059_AS_VVS2_F  = df_050_059_AS_VVS2_F.assign(PPC=None)
                    df_050_059_AS_VVS2_F  = df_050_059_AS_VVS2_F.assign(Total=None)
                    df_050_059_AS_VVS2_F ['Wt Range'] = listwtrange
                    df_050_059_AS_VVS2_F ['Company'] = listcom
                    df_050_059_AS_VVS2_F ['Shape'] = listshap
                    df_050_059_AS_VVS2_F ['Carat'] = listcar
                    df_050_059_AS_VVS2_F ['Color'] = listcol
                    df_050_059_AS_VVS2_F ['Clarity'] = listclar
                    df_050_059_AS_VVS2_F ['Cut'] = listcut
                    df_050_059_AS_VVS2_F ['Polish'] = listpol
                    df_050_059_AS_VVS2_F ['Symmetry'] = listsym
                    df_050_059_AS_VVS2_F ['Ratio'] = listrat
                    df_050_059_AS_VVS2_F ['PPC'] = listdesc
                    df_050_059_AS_VVS2_F ['Total'] = listtotal
                    df_050_059_AS_VVS2_F['Carat'] = df_050_059_AS_VVS2_F['Carat'].astype('float64')
                    df_050_059_AS_VVS2_F['PPC'] = df_050_059_AS_VVS2_F['PPC'].astype('float64')
                    df_050_059_AS_VVS2_F['Total'] = df_050_059_AS_VVS2_F['Total'].astype('float64')
                    df_050_059_AS_VVS2_F['Total'] = df_050_059_AS_VVS2_F['Carat'] * df_050_059_AS_VVS2_F['PPC']


                elif i=="F" and j=="VS1" and k == "AS":
                    df_050_059_AS_VS1_F = pd.DataFrame()
                    df_050_059_AS_VS1_F ['Wt Range'] = None
                    df_050_059_AS_VS1_F  = df_050_059_AS_VS1_F.assign(Company=None)
                    df_050_059_AS_VS1_F  = df_050_059_AS_VS1_F.assign(Shape=None)
                    df_050_059_AS_VS1_F  = df_050_059_AS_VS1_F.assign(Carat=None)
                    df_050_059_AS_VS1_F  = df_050_059_AS_VS1_F.assign(Color=None)
                    df_050_059_AS_VS1_F  = df_050_059_AS_VS1_F.assign(Clarity=None)
                    df_050_059_AS_VS1_F  = df_050_059_AS_VS1_F.assign(Cut=None)
                    df_050_059_AS_VS1_F  = df_050_059_AS_VS1_F.assign(Polish=None)
                    df_050_059_AS_VS1_F  = df_050_059_AS_VS1_F.assign(Symmetry=None)
                    df_050_059_AS_VS1_F  = df_050_059_AS_VS1_F.assign(Ratio=None)
                    df_050_059_AS_VS1_F  = df_050_059_AS_VS1_F.assign(PPC=None)
                    df_050_059_AS_VS1_F  = df_050_059_AS_VS1_F.assign(Total=None)
                    df_050_059_AS_VS1_F ['Wt Range'] = listwtrange
                    df_050_059_AS_VS1_F ['Company'] = listcom
                    df_050_059_AS_VS1_F ['Shape'] = listshap
                    df_050_059_AS_VS1_F ['Carat'] = listcar
                    df_050_059_AS_VS1_F ['Color'] = listcol
                    df_050_059_AS_VS1_F ['Clarity'] = listclar
                    df_050_059_AS_VS1_F ['Cut'] = listcut
                    df_050_059_AS_VS1_F ['Polish'] = listpol
                    df_050_059_AS_VS1_F ['Symmetry'] = listsym
                    df_050_059_AS_VS1_F ['Ratio'] = listrat
                    df_050_059_AS_VS1_F ['PPC'] = listdesc
                    df_050_059_AS_VS1_F ['Total'] = listtotal
                    df_050_059_AS_VS1_F['Carat'] = df_050_059_AS_VS1_F['Carat'].astype('float64')
                    df_050_059_AS_VS1_F['PPC'] = df_050_059_AS_VS1_F['PPC'].astype('float64')
                    df_050_059_AS_VS1_F['Total'] = df_050_059_AS_VS1_F['Total'].astype('float64')
                    df_050_059_AS_VS1_F['Total'] = df_050_059_AS_VS1_F['Carat'] * df_050_059_AS_VS1_F['PPC']


                elif i=="F" and j == "VS2" and k == "AS":
                    df_050_059_AS_VS2_F = pd.DataFrame()
                    df_050_059_AS_VS2_F ['Wt Range'] = None
                    df_050_059_AS_VS2_F  = df_050_059_AS_VS2_F.assign(Company=None)
                    df_050_059_AS_VS2_F  = df_050_059_AS_VS2_F.assign(Shape=None)
                    df_050_059_AS_VS2_F  = df_050_059_AS_VS2_F.assign(Carat=None)
                    df_050_059_AS_VS2_F  = df_050_059_AS_VS2_F.assign(Color=None)
                    df_050_059_AS_VS2_F  = df_050_059_AS_VS2_F.assign(Clarity=None)
                    df_050_059_AS_VS2_F  = df_050_059_AS_VS2_F.assign(Cut=None)
                    df_050_059_AS_VS2_F  = df_050_059_AS_VS2_F.assign(Polish=None)
                    df_050_059_AS_VS2_F  = df_050_059_AS_VS2_F.assign(Symmetry=None)
                    df_050_059_AS_VS2_F  = df_050_059_AS_VS2_F.assign(Ratio=None)
                    df_050_059_AS_VS2_F  = df_050_059_AS_VS2_F.assign(PPC=None)
                    df_050_059_AS_VS2_F  = df_050_059_AS_VS2_F.assign(Total=None)
                    df_050_059_AS_VS2_F ['Wt Range'] = listwtrange
                    df_050_059_AS_VS2_F ['Company'] = listcom
                    df_050_059_AS_VS2_F ['Shape'] = listshap
                    df_050_059_AS_VS2_F ['Carat'] = listcar
                    df_050_059_AS_VS2_F ['Color'] = listcol
                    df_050_059_AS_VS2_F ['Clarity'] = listclar
                    df_050_059_AS_VS2_F ['Cut'] = listcut
                    df_050_059_AS_VS2_F ['Polish'] = listpol
                    df_050_059_AS_VS2_F ['Symmetry'] = listsym
                    df_050_059_AS_VS2_F ['Ratio'] = listrat
                    df_050_059_AS_VS2_F ['PPC'] = listdesc
                    df_050_059_AS_VS2_F ['Total'] = listtotal
                    df_050_059_AS_VS2_F['Carat'] = df_050_059_AS_VS2_F['Carat'].astype('float64')
                    df_050_059_AS_VS2_F['PPC'] = df_050_059_AS_VS2_F['PPC'].astype('float64')
                    df_050_059_AS_VS2_F['Total'] = df_050_059_AS_VS2_F['Total'].astype('float64')
                    df_050_059_AS_VS2_F['Total'] = df_050_059_AS_VS2_F['Carat'] * df_050_059_AS_VS2_F['PPC']


                elif i=="F" and j == "SI1" and k == "AS":
                    df_050_059_AS_SI1_F = pd.DataFrame()
                    df_050_059_AS_SI1_F ['Wt Range'] = None
                    df_050_059_AS_SI1_F  = df_050_059_AS_SI1_F.assign(Company=None)
                    df_050_059_AS_SI1_F  = df_050_059_AS_SI1_F.assign(Shape=None)
                    df_050_059_AS_SI1_F  = df_050_059_AS_SI1_F.assign(Carat=None)
                    df_050_059_AS_SI1_F  = df_050_059_AS_SI1_F.assign(Color=None)
                    df_050_059_AS_SI1_F  = df_050_059_AS_SI1_F.assign(Clarity=None)
                    df_050_059_AS_SI1_F  = df_050_059_AS_SI1_F.assign(Cut=None)
                    df_050_059_AS_SI1_F  = df_050_059_AS_SI1_F.assign(Polish=None)
                    df_050_059_AS_SI1_F  = df_050_059_AS_SI1_F.assign(Symmetry=None)
                    df_050_059_AS_SI1_F  = df_050_059_AS_SI1_F.assign(Ratio=None)
                    df_050_059_AS_SI1_F  = df_050_059_AS_SI1_F.assign(PPC=None)
                    df_050_059_AS_SI1_F  = df_050_059_AS_SI1_F.assign(Total=None)
                    df_050_059_AS_SI1_F ['Wt Range'] = listwtrange
                    df_050_059_AS_SI1_F ['Company'] = listcom
                    df_050_059_AS_SI1_F ['Shape'] = listshap
                    df_050_059_AS_SI1_F ['Carat'] = listcar
                    df_050_059_AS_SI1_F ['Color'] = listcol
                    df_050_059_AS_SI1_F ['Clarity'] = listclar
                    df_050_059_AS_SI1_F ['Cut'] = listcut
                    df_050_059_AS_SI1_F ['Polish'] = listpol
                    df_050_059_AS_SI1_F ['Symmetry'] = listsym
                    df_050_059_AS_SI1_F ['Ratio'] = listrat
                    df_050_059_AS_SI1_F ['PPC'] = listdesc
                    df_050_059_AS_SI1_F ['Total'] = listtotal
                    df_050_059_AS_SI1_F['Carat'] = df_050_059_AS_SI1_F['Carat'].astype('float64')
                    df_050_059_AS_SI1_F['PPC'] = df_050_059_AS_SI1_F['PPC'].astype('float64')
                    df_050_059_AS_SI1_F['Total'] = df_050_059_AS_SI1_F['Total'].astype('float64')
                    df_050_059_AS_SI1_F['Total'] = df_050_059_AS_SI1_F['Carat'] * df_050_059_AS_SI1_F['PPC']


                elif i=="F" and j == "SI2" and k == "AS":
                    df_050_059_AS_SI2_F = pd.DataFrame()
                    df_050_059_AS_SI2_F ['Wt Range'] = None
                    df_050_059_AS_SI2_F  = df_050_059_AS_SI2_F.assign(Company=None)
                    df_050_059_AS_SI2_F  = df_050_059_AS_SI2_F.assign(Shape=None)
                    df_050_059_AS_SI2_F  = df_050_059_AS_SI2_F.assign(Carat=None)
                    df_050_059_AS_SI2_F  = df_050_059_AS_SI2_F.assign(Color=None)
                    df_050_059_AS_SI2_F  = df_050_059_AS_SI2_F.assign(Clarity=None)
                    df_050_059_AS_SI2_F  = df_050_059_AS_SI2_F.assign(Cut=None)
                    df_050_059_AS_SI2_F  = df_050_059_AS_SI2_F.assign(Polish=None)
                    df_050_059_AS_SI2_F  = df_050_059_AS_SI2_F.assign(Symmetry=None)
                    df_050_059_AS_SI2_F  = df_050_059_AS_SI2_F.assign(Ratio=None)
                    df_050_059_AS_SI2_F  = df_050_059_AS_SI2_F.assign(PPC=None)
                    df_050_059_AS_SI2_F  = df_050_059_AS_SI2_F.assign(Total=None)
                    df_050_059_AS_SI2_F ['Wt Range'] = listwtrange
                    df_050_059_AS_SI2_F ['Company'] = listcom
                    df_050_059_AS_SI2_F ['Shape'] = listshap
                    df_050_059_AS_SI2_F ['Carat'] = listcar
                    df_050_059_AS_SI2_F ['Color'] = listcol
                    df_050_059_AS_SI2_F ['Clarity'] = listclar
                    df_050_059_AS_SI2_F ['Cut'] = listcut
                    df_050_059_AS_SI2_F ['Polish'] = listpol
                    df_050_059_AS_SI2_F ['Symmetry'] = listsym
                    df_050_059_AS_SI2_F ['Ratio'] = listrat
                    df_050_059_AS_SI2_F ['PPC'] = listdesc
                    df_050_059_AS_SI2_F ['Total'] = listtotal
                    df_050_059_AS_SI2_F['Carat'] = df_050_059_AS_SI2_F['Carat'].astype('float64')
                    df_050_059_AS_SI2_F['PPC'] = df_050_059_AS_SI2_F['PPC'].astype('float64')
                    df_050_059_AS_SI2_F['Total'] = df_050_059_AS_SI2_F['Total'].astype('float64')
                    df_050_059_AS_SI2_F['Total'] = df_050_059_AS_SI2_F['Carat'] * df_050_059_AS_SI2_F['PPC']


                elif i=="F" and j == "I1" and k == "AS":
                    df_050_059_AS_I1_F = pd.DataFrame()
                    df_050_059_AS_I1_F ['Wt Range'] = None
                    df_050_059_AS_I1_F  = df_050_059_AS_I1_F.assign(Company=None)
                    df_050_059_AS_I1_F  = df_050_059_AS_I1_F.assign(Shape=None)
                    df_050_059_AS_I1_F  = df_050_059_AS_I1_F.assign(Carat=None)
                    df_050_059_AS_I1_F  = df_050_059_AS_I1_F.assign(Color=None)
                    df_050_059_AS_I1_F  = df_050_059_AS_I1_F.assign(Clarity=None)
                    df_050_059_AS_I1_F  = df_050_059_AS_I1_F.assign(Cut=None)
                    df_050_059_AS_I1_F  = df_050_059_AS_I1_F.assign(Polish=None)
                    df_050_059_AS_I1_F  = df_050_059_AS_I1_F.assign(Symmetry=None)
                    df_050_059_AS_I1_F  = df_050_059_AS_I1_F.assign(Ratio=None)
                    df_050_059_AS_I1_F  = df_050_059_AS_I1_F.assign(PPC=None)
                    df_050_059_AS_I1_F  = df_050_059_AS_I1_F.assign(Total=None)
                    df_050_059_AS_I1_F ['Wt Range'] = listwtrange
                    df_050_059_AS_I1_F ['Company'] = listcom
                    df_050_059_AS_I1_F ['Shape'] = listshap
                    df_050_059_AS_I1_F ['Carat'] = listcar
                    df_050_059_AS_I1_F ['Color'] = listcol
                    df_050_059_AS_I1_F ['Clarity'] = listclar
                    df_050_059_AS_I1_F ['Cut'] = listcut
                    df_050_059_AS_I1_F ['Polish'] = listpol
                    df_050_059_AS_I1_F ['Symmetry'] = listsym
                    df_050_059_AS_I1_F ['Ratio'] = listrat
                    df_050_059_AS_I1_F ['PPC'] = listdesc
                    df_050_059_AS_I1_F ['Total'] = listtotal
                    df_050_059_AS_I1_F['Carat'] = df_050_059_AS_I1_F['Carat'].astype('float64')
                    df_050_059_AS_I1_F['PPC'] = df_050_059_AS_I1_F['PPC'].astype('float64')
                    df_050_059_AS_I1_F['Total'] = df_050_059_AS_I1_F['Total'].astype('float64')
                    df_050_059_AS_I1_F['Total'] = df_050_059_AS_I1_F['Carat'] * df_050_059_AS_I1_F['PPC']


                elif i=="F" and j == "I2" and k == "AS":
                    df_050_059_AS_I2_F = pd.DataFrame()
                    df_050_059_AS_I2_F ['Wt Range'] = None
                    df_050_059_AS_I2_F  = df_050_059_AS_I2_F.assign(Company=None)
                    df_050_059_AS_I2_F  = df_050_059_AS_I2_F.assign(Shape=None)
                    df_050_059_AS_I2_F  = df_050_059_AS_I2_F.assign(Carat=None)
                    df_050_059_AS_I2_F  = df_050_059_AS_I2_F.assign(Color=None)
                    df_050_059_AS_I2_F  = df_050_059_AS_I2_F.assign(Clarity=None)
                    df_050_059_AS_I2_F  = df_050_059_AS_I2_F.assign(Cut=None)
                    df_050_059_AS_I2_F  = df_050_059_AS_I2_F.assign(Polish=None)
                    df_050_059_AS_I2_F  = df_050_059_AS_I2_F.assign(Symmetry=None)
                    df_050_059_AS_I2_F  = df_050_059_AS_I2_F.assign(Ratio=None)
                    df_050_059_AS_I2_F  = df_050_059_AS_I2_F.assign(PPC=None)
                    df_050_059_AS_I2_F  = df_050_059_AS_I2_F.assign(Total=None)
                    df_050_059_AS_I2_F ['Wt Range'] = listwtrange
                    df_050_059_AS_I2_F ['Company'] = listcom
                    df_050_059_AS_I2_F ['Shape'] = listshap
                    df_050_059_AS_I2_F ['Carat'] = listcar
                    df_050_059_AS_I2_F ['Color'] = listcol
                    df_050_059_AS_I2_F ['Clarity'] = listclar
                    df_050_059_AS_I2_F ['Cut'] = listcut
                    df_050_059_AS_I2_F ['Polish'] = listpol
                    df_050_059_AS_I2_F ['Symmetry'] = listsym
                    df_050_059_AS_I2_F ['Ratio'] = listrat
                    df_050_059_AS_I2_F ['PPC'] = listdesc
                    df_050_059_AS_I2_F ['Total'] = listtotal
                    df_050_059_AS_I2_F['Carat'] = df_050_059_AS_I2_F['Carat'].astype('float64')
                    df_050_059_AS_I2_F['PPC'] = df_050_059_AS_I2_F['PPC'].astype('float64')
                    df_050_059_AS_I2_F['Total'] = df_050_059_AS_I2_F['Total'].astype('float64')
                    df_050_059_AS_I2_F['Total'] = df_050_059_AS_I2_F['Carat'] * df_050_059_AS_I2_F['PPC']


                elif i=="G" and j == "IF" and k == "AS":
                    df_050_059_AS_IF_G = pd.DataFrame()
                    df_050_059_AS_IF_G ['Wt Range'] = None
                    df_050_059_AS_IF_G  = df_050_059_AS_IF_G.assign(Company=None)
                    df_050_059_AS_IF_G  = df_050_059_AS_IF_G.assign(Shape=None)
                    df_050_059_AS_IF_G  = df_050_059_AS_IF_G.assign(Carat=None)
                    df_050_059_AS_IF_G  = df_050_059_AS_IF_G.assign(Color=None)
                    df_050_059_AS_IF_G  = df_050_059_AS_IF_G.assign(Clarity=None)
                    df_050_059_AS_IF_G  = df_050_059_AS_IF_G.assign(Cut=None)
                    df_050_059_AS_IF_G  = df_050_059_AS_IF_G.assign(Polish=None)
                    df_050_059_AS_IF_G  = df_050_059_AS_IF_G.assign(Symmetry=None)
                    df_050_059_AS_IF_G  = df_050_059_AS_IF_G.assign(Ratio=None)
                    df_050_059_AS_IF_G  = df_050_059_AS_IF_G.assign(PPC=None)
                    df_050_059_AS_IF_G  = df_050_059_AS_IF_G.assign(Total=None)
                    df_050_059_AS_IF_G ['Wt Range'] = listwtrange
                    df_050_059_AS_IF_G ['Company'] = listcom
                    df_050_059_AS_IF_G ['Shape'] = listshap
                    df_050_059_AS_IF_G ['Carat'] = listcar
                    df_050_059_AS_IF_G ['Color'] = listcol
                    df_050_059_AS_IF_G ['Clarity'] = listclar
                    df_050_059_AS_IF_G ['Cut'] = listcut
                    df_050_059_AS_IF_G ['Polish'] = listpol
                    df_050_059_AS_IF_G ['Symmetry'] = listsym
                    df_050_059_AS_IF_G ['Ratio'] = listrat
                    df_050_059_AS_IF_G ['PPC'] = listdesc
                    df_050_059_AS_IF_G ['Total'] = listtotal
                    df_050_059_AS_IF_G['Carat'] = df_050_059_AS_IF_G['Carat'].astype('float64')
                    df_050_059_AS_IF_G['PPC'] = df_050_059_AS_IF_G['PPC'].astype('float64')
                    df_050_059_AS_IF_G['Total'] = df_050_059_AS_IF_G['Total'].astype('float64')
                    df_050_059_AS_IF_G['Total'] = df_050_059_AS_IF_G['Carat'] * df_050_059_AS_IF_G['PPC']



                elif i=="G" and j == "VVS1" and k == "AS":
                    df_050_059_AS_VVS1_G = pd.DataFrame()
                    df_050_059_AS_VVS1_G ['Wt Range'] = None
                    df_050_059_AS_VVS1_G  = df_050_059_AS_VVS1_G.assign(Company=None)
                    df_050_059_AS_VVS1_G  = df_050_059_AS_VVS1_G.assign(Shape=None)
                    df_050_059_AS_VVS1_G  = df_050_059_AS_VVS1_G.assign(Carat=None)
                    df_050_059_AS_VVS1_G  = df_050_059_AS_VVS1_G.assign(Color=None)
                    df_050_059_AS_VVS1_G  = df_050_059_AS_VVS1_G.assign(Clarity=None)
                    df_050_059_AS_VVS1_G  = df_050_059_AS_VVS1_G.assign(Cut=None)
                    df_050_059_AS_VVS1_G  = df_050_059_AS_VVS1_G.assign(Polish=None)
                    df_050_059_AS_VVS1_G  = df_050_059_AS_VVS1_G.assign(Symmetry=None)
                    df_050_059_AS_VVS1_G  = df_050_059_AS_VVS1_G.assign(Ratio=None)
                    df_050_059_AS_VVS1_G  = df_050_059_AS_VVS1_G.assign(PPC=None)
                    df_050_059_AS_VVS1_G  = df_050_059_AS_VVS1_G.assign(Total=None)
                    df_050_059_AS_VVS1_G ['Wt Range'] = listwtrange
                    df_050_059_AS_VVS1_G ['Company'] = listcom
                    df_050_059_AS_VVS1_G ['Shape'] = listshap
                    df_050_059_AS_VVS1_G ['Carat'] = listcar
                    df_050_059_AS_VVS1_G ['Color'] = listcol
                    df_050_059_AS_VVS1_G ['Clarity'] = listclar
                    df_050_059_AS_VVS1_G ['Cut'] = listcut
                    df_050_059_AS_VVS1_G ['Polish'] = listpol
                    df_050_059_AS_VVS1_G ['Symmetry'] = listsym
                    df_050_059_AS_VVS1_G ['Ratio'] = listrat
                    df_050_059_AS_VVS1_G ['PPC'] = listdesc
                    df_050_059_AS_VVS1_G ['Total'] = listtotal
                    df_050_059_AS_VVS1_G['Carat'] = df_050_059_AS_VVS1_G['Carat'].astype('float64')
                    df_050_059_AS_VVS1_G['PPC'] = df_050_059_AS_VVS1_G['PPC'].astype('float64')
                    df_050_059_AS_VVS1_G['Total'] = df_050_059_AS_VVS1_G['Total'].astype('float64')
                    df_050_059_AS_VVS1_G['Total'] = df_050_059_AS_VVS1_G['Carat'] * df_050_059_AS_VVS1_G['PPC']


                elif i=="G" and j == "VVS2" and k == "AS":
                    df_050_059_AS_VVS2_G = pd.DataFrame()
                    df_050_059_AS_VVS2_G ['Wt Range'] = None
                    df_050_059_AS_VVS2_G  = df_050_059_AS_VVS2_G.assign(Company=None)
                    df_050_059_AS_VVS2_G  = df_050_059_AS_VVS2_G.assign(Shape=None)
                    df_050_059_AS_VVS2_G  = df_050_059_AS_VVS2_G.assign(Carat=None)
                    df_050_059_AS_VVS2_G  = df_050_059_AS_VVS2_G.assign(Color=None)
                    df_050_059_AS_VVS2_G  = df_050_059_AS_VVS2_G.assign(Clarity=None)
                    df_050_059_AS_VVS2_G  = df_050_059_AS_VVS2_G.assign(Cut=None)
                    df_050_059_AS_VVS2_G  = df_050_059_AS_VVS2_G.assign(Polish=None)
                    df_050_059_AS_VVS2_G  = df_050_059_AS_VVS2_G.assign(Symmetry=None)
                    df_050_059_AS_VVS2_G  = df_050_059_AS_VVS2_G.assign(Ratio=None)
                    df_050_059_AS_VVS2_G  = df_050_059_AS_VVS2_G.assign(PPC=None)
                    df_050_059_AS_VVS2_G  = df_050_059_AS_VVS2_G.assign(Total=None)
                    df_050_059_AS_VVS2_G ['Wt Range'] = listwtrange
                    df_050_059_AS_VVS2_G ['Company'] = listcom
                    df_050_059_AS_VVS2_G ['Shape'] = listshap
                    df_050_059_AS_VVS2_G ['Carat'] = listcar
                    df_050_059_AS_VVS2_G ['Color'] = listcol
                    df_050_059_AS_VVS2_G ['Clarity'] = listclar
                    df_050_059_AS_VVS2_G ['Cut'] = listcut
                    df_050_059_AS_VVS2_G ['Polish'] = listpol
                    df_050_059_AS_VVS2_G ['Symmetry'] = listsym
                    df_050_059_AS_VVS2_G ['Ratio'] = listrat
                    df_050_059_AS_VVS2_G ['PPC'] = listdesc
                    df_050_059_AS_VVS2_G ['Total'] = listtotal
                    df_050_059_AS_VVS2_G['Carat'] = df_050_059_AS_VVS2_G['Carat'].astype('float64')
                    df_050_059_AS_VVS2_G['PPC'] = df_050_059_AS_VVS2_G['PPC'].astype('float64')
                    df_050_059_AS_VVS2_G['Total'] = df_050_059_AS_VVS2_G['Total'].astype('float64')
                    df_050_059_AS_VVS2_G['Total'] = df_050_059_AS_VVS2_G['Carat'] * df_050_059_AS_VVS2_G['PPC']


                elif i=="G" and j=="VS1" and k == "AS":
                    df_050_059_AS_VS1_G = pd.DataFrame()
                    df_050_059_AS_VS1_G ['Wt Range'] = None
                    df_050_059_AS_VS1_G  = df_050_059_AS_VS1_G.assign(Company=None)
                    df_050_059_AS_VS1_G  = df_050_059_AS_VS1_G.assign(Shape=None)
                    df_050_059_AS_VS1_G  = df_050_059_AS_VS1_G.assign(Carat=None)
                    df_050_059_AS_VS1_G  = df_050_059_AS_VS1_G.assign(Color=None)
                    df_050_059_AS_VS1_G  = df_050_059_AS_VS1_G.assign(Clarity=None)
                    df_050_059_AS_VS1_G  = df_050_059_AS_VS1_G.assign(Cut=None)
                    df_050_059_AS_VS1_G  = df_050_059_AS_VS1_G.assign(Polish=None)
                    df_050_059_AS_VS1_G  = df_050_059_AS_VS1_G.assign(Symmetry=None)
                    df_050_059_AS_VS1_G  = df_050_059_AS_VS1_G.assign(Ratio=None)
                    df_050_059_AS_VS1_G  = df_050_059_AS_VS1_G.assign(PPC=None)
                    df_050_059_AS_VS1_G  = df_050_059_AS_VS1_G.assign(Total=None)
                    df_050_059_AS_VS1_G ['Wt Range'] = listwtrange
                    df_050_059_AS_VS1_G ['Company'] = listcom
                    df_050_059_AS_VS1_G ['Shape'] = listshap
                    df_050_059_AS_VS1_G ['Carat'] = listcar
                    df_050_059_AS_VS1_G ['Color'] = listcol
                    df_050_059_AS_VS1_G ['Clarity'] = listclar
                    df_050_059_AS_VS1_G ['Cut'] = listcut
                    df_050_059_AS_VS1_G ['Polish'] = listpol
                    df_050_059_AS_VS1_G ['Symmetry'] = listsym
                    df_050_059_AS_VS1_G ['Ratio'] = listrat
                    df_050_059_AS_VS1_G ['PPC'] = listdesc
                    df_050_059_AS_VS1_G ['Total'] = listtotal
                    df_050_059_AS_VS1_G['Carat'] = df_050_059_AS_VS1_G['Carat'].astype('float64')
                    df_050_059_AS_VS1_G['PPC'] = df_050_059_AS_VS1_G['PPC'].astype('float64')
                    df_050_059_AS_VS1_G['Total'] = df_050_059_AS_VS1_G['Total'].astype('float64')
                    df_050_059_AS_VS1_G['Total'] = df_050_059_AS_VS1_G['Carat'] * df_050_059_AS_VS1_G['PPC']


                elif i=="G" and j == "VS2" and k == "AS":
                    df_050_059_AS_VS2_G = pd.DataFrame()
                    df_050_059_AS_VS2_G ['Wt Range'] = None
                    df_050_059_AS_VS2_G  = df_050_059_AS_VS2_G.assign(Company=None)
                    df_050_059_AS_VS2_G  = df_050_059_AS_VS2_G.assign(Shape=None)
                    df_050_059_AS_VS2_G  = df_050_059_AS_VS2_G.assign(Carat=None)
                    df_050_059_AS_VS2_G  = df_050_059_AS_VS2_G.assign(Color=None)
                    df_050_059_AS_VS2_G  = df_050_059_AS_VS2_G.assign(Clarity=None)
                    df_050_059_AS_VS2_G  = df_050_059_AS_VS2_G.assign(Cut=None)
                    df_050_059_AS_VS2_G  = df_050_059_AS_VS2_G.assign(Polish=None)
                    df_050_059_AS_VS2_G  = df_050_059_AS_VS2_G.assign(Symmetry=None)
                    df_050_059_AS_VS2_G  = df_050_059_AS_VS2_G.assign(Ratio=None)
                    df_050_059_AS_VS2_G  = df_050_059_AS_VS2_G.assign(PPC=None)
                    df_050_059_AS_VS2_G  = df_050_059_AS_VS2_G.assign(Total=None)
                    df_050_059_AS_VS2_G ['Wt Range'] = listwtrange
                    df_050_059_AS_VS2_G ['Company'] = listcom
                    df_050_059_AS_VS2_G ['Shape'] = listshap
                    df_050_059_AS_VS2_G ['Carat'] = listcar
                    df_050_059_AS_VS2_G ['Color'] = listcol
                    df_050_059_AS_VS2_G ['Clarity'] = listclar
                    df_050_059_AS_VS2_G ['Cut'] = listcut
                    df_050_059_AS_VS2_G ['Polish'] = listpol
                    df_050_059_AS_VS2_G ['Symmetry'] = listsym
                    df_050_059_AS_VS2_G ['Ratio'] = listrat
                    df_050_059_AS_VS2_G ['PPC'] = listdesc
                    df_050_059_AS_VS2_G ['Total'] = listtotal
                    df_050_059_AS_VS2_G['Carat'] = df_050_059_AS_VS2_G['Carat'].astype('float64')
                    df_050_059_AS_VS2_G['PPC'] = df_050_059_AS_VS2_G['PPC'].astype('float64')
                    df_050_059_AS_VS2_G['Total'] = df_050_059_AS_VS2_G['Total'].astype('float64')
                    df_050_059_AS_VS2_G['Total'] = df_050_059_AS_VS2_G['Carat'] * df_050_059_AS_VS2_G['PPC']


                elif i=="G" and j == "SI1" and k == "AS":
                    df_050_059_AS_SI1_G = pd.DataFrame()
                    df_050_059_AS_SI1_G ['Wt Range'] = None
                    df_050_059_AS_SI1_G  = df_050_059_AS_SI1_G.assign(Company=None)
                    df_050_059_AS_SI1_G  = df_050_059_AS_SI1_G.assign(Shape=None)
                    df_050_059_AS_SI1_G  = df_050_059_AS_SI1_G.assign(Carat=None)
                    df_050_059_AS_SI1_G  = df_050_059_AS_SI1_G.assign(Color=None)
                    df_050_059_AS_SI1_G  = df_050_059_AS_SI1_G.assign(Clarity=None)
                    df_050_059_AS_SI1_G  = df_050_059_AS_SI1_G.assign(Cut=None)
                    df_050_059_AS_SI1_G  = df_050_059_AS_SI1_G.assign(Polish=None)
                    df_050_059_AS_SI1_G  = df_050_059_AS_SI1_G.assign(Symmetry=None)
                    df_050_059_AS_SI1_G  = df_050_059_AS_SI1_G.assign(Ratio=None)
                    df_050_059_AS_SI1_G  = df_050_059_AS_SI1_G.assign(PPC=None)
                    df_050_059_AS_SI1_G  = df_050_059_AS_SI1_G.assign(Total=None)
                    df_050_059_AS_SI1_G ['Wt Range'] = listwtrange
                    df_050_059_AS_SI1_G ['Company'] = listcom
                    df_050_059_AS_SI1_G ['Shape'] = listshap
                    df_050_059_AS_SI1_G ['Carat'] = listcar
                    df_050_059_AS_SI1_G ['Color'] = listcol
                    df_050_059_AS_SI1_G ['Clarity'] = listclar
                    df_050_059_AS_SI1_G ['Cut'] = listcut
                    df_050_059_AS_SI1_G ['Polish'] = listpol
                    df_050_059_AS_SI1_G ['Symmetry'] = listsym
                    df_050_059_AS_SI1_G ['Ratio'] = listrat
                    df_050_059_AS_SI1_G ['PPC'] = listdesc
                    df_050_059_AS_SI1_G ['Total'] = listtotal
                    df_050_059_AS_SI1_G['Carat'] = df_050_059_AS_SI1_G['Carat'].astype('float64')
                    df_050_059_AS_SI1_G['PPC'] = df_050_059_AS_SI1_G['PPC'].astype('float64')
                    df_050_059_AS_SI1_G['Total'] = df_050_059_AS_SI1_G['Total'].astype('float64')
                    df_050_059_AS_SI1_G['Total'] = df_050_059_AS_SI1_G['Carat'] * df_050_059_AS_SI1_G['PPC']


                elif i=="G" and j == "SI2" and k == "AS":
                    df_050_059_AS_SI2_G = pd.DataFrame()
                    df_050_059_AS_SI2_G ['Wt Range'] = None
                    df_050_059_AS_SI2_G  = df_050_059_AS_SI2_G.assign(Company=None)
                    df_050_059_AS_SI2_G  = df_050_059_AS_SI2_G.assign(Shape=None)
                    df_050_059_AS_SI2_G  = df_050_059_AS_SI2_G.assign(Carat=None)
                    df_050_059_AS_SI2_G  = df_050_059_AS_SI2_G.assign(Color=None)
                    df_050_059_AS_SI2_G  = df_050_059_AS_SI2_G.assign(Clarity=None)
                    df_050_059_AS_SI2_G  = df_050_059_AS_SI2_G.assign(Cut=None)
                    df_050_059_AS_SI2_G  = df_050_059_AS_SI2_G.assign(Polish=None)
                    df_050_059_AS_SI2_G  = df_050_059_AS_SI2_G.assign(Symmetry=None)
                    df_050_059_AS_SI2_G  = df_050_059_AS_SI2_G.assign(Ratio=None)
                    df_050_059_AS_SI2_G  = df_050_059_AS_SI2_G.assign(PPC=None)
                    df_050_059_AS_SI2_G  = df_050_059_AS_SI2_G.assign(Total=None)
                    df_050_059_AS_SI2_G ['Wt Range'] = listwtrange
                    df_050_059_AS_SI2_G ['Company'] = listcom
                    df_050_059_AS_SI2_G ['Shape'] = listshap
                    df_050_059_AS_SI2_G ['Carat'] = listcar
                    df_050_059_AS_SI2_G ['Color'] = listcol
                    df_050_059_AS_SI2_G ['Clarity'] = listclar
                    df_050_059_AS_SI2_G ['Cut'] = listcut
                    df_050_059_AS_SI2_G ['Polish'] = listpol
                    df_050_059_AS_SI2_G ['Symmetry'] = listsym
                    df_050_059_AS_SI2_G ['Ratio'] = listrat
                    df_050_059_AS_SI2_G ['PPC'] = listdesc
                    df_050_059_AS_SI2_G ['Total'] = listtotal
                    df_050_059_AS_SI2_G['Carat'] = df_050_059_AS_SI2_G['Carat'].astype('float64')
                    df_050_059_AS_SI2_G['PPC'] = df_050_059_AS_SI2_G['PPC'].astype('float64')
                    df_050_059_AS_SI2_G['Total'] = df_050_059_AS_SI2_G['Total'].astype('float64')
                    df_050_059_AS_SI2_G['Total'] = df_050_059_AS_SI2_G['Carat'] * df_050_059_AS_SI2_G['PPC']


                elif i=="G" and j == "I1" and k == "AS":
                    df_050_059_AS_I1_G = pd.DataFrame()
                    df_050_059_AS_I1_G ['Wt Range'] = None
                    df_050_059_AS_I1_G  = df_050_059_AS_I1_G.assign(Company=None)
                    df_050_059_AS_I1_G  = df_050_059_AS_I1_G.assign(Shape=None)
                    df_050_059_AS_I1_G  = df_050_059_AS_I1_G.assign(Carat=None)
                    df_050_059_AS_I1_G  = df_050_059_AS_I1_G.assign(Color=None)
                    df_050_059_AS_I1_G  = df_050_059_AS_I1_G.assign(Clarity=None)
                    df_050_059_AS_I1_G  = df_050_059_AS_I1_G.assign(Cut=None)
                    df_050_059_AS_I1_G  = df_050_059_AS_I1_G.assign(Polish=None)
                    df_050_059_AS_I1_G  = df_050_059_AS_I1_G.assign(Symmetry=None)
                    df_050_059_AS_I1_G  = df_050_059_AS_I1_G.assign(Ratio=None)
                    df_050_059_AS_I1_G  = df_050_059_AS_I1_G.assign(PPC=None)
                    df_050_059_AS_I1_G  = df_050_059_AS_I1_G.assign(Total=None)
                    df_050_059_AS_I1_G ['Wt Range'] = listwtrange
                    df_050_059_AS_I1_G ['Company'] = listcom
                    df_050_059_AS_I1_G ['Shape'] = listshap
                    df_050_059_AS_I1_G ['Carat'] = listcar
                    df_050_059_AS_I1_G ['Color'] = listcol
                    df_050_059_AS_I1_G ['Clarity'] = listclar
                    df_050_059_AS_I1_G ['Cut'] = listcut
                    df_050_059_AS_I1_G ['Polish'] = listpol
                    df_050_059_AS_I1_G ['Symmetry'] = listsym
                    df_050_059_AS_I1_G ['Ratio'] = listrat
                    df_050_059_AS_I1_G ['PPC'] = listdesc
                    df_050_059_AS_I1_G ['Total'] = listtotal
                    df_050_059_AS_I1_G['Carat'] = df_050_059_AS_I1_G['Carat'].astype('float64')
                    df_050_059_AS_I1_G['PPC'] = df_050_059_AS_I1_G['PPC'].astype('float64')
                    df_050_059_AS_I1_G['Total'] = df_050_059_AS_I1_G['Total'].astype('float64')
                    df_050_059_AS_I1_G['Total'] = df_050_059_AS_I1_G['Carat'] * df_050_059_AS_I1_G['PPC']


                elif i=="G" and j == "I2" and k == "AS":
                    df_050_059_AS_I2_G = pd.DataFrame()
                    df_050_059_AS_I2_G ['Wt Range'] = None
                    df_050_059_AS_I2_G  = df_050_059_AS_I2_G.assign(Company=None)
                    df_050_059_AS_I2_G  = df_050_059_AS_I2_G.assign(Shape=None)
                    df_050_059_AS_I2_G  = df_050_059_AS_I2_G.assign(Carat=None)
                    df_050_059_AS_I2_G  = df_050_059_AS_I2_G.assign(Color=None)
                    df_050_059_AS_I2_G  = df_050_059_AS_I2_G.assign(Clarity=None)
                    df_050_059_AS_I2_G  = df_050_059_AS_I2_G.assign(Cut=None)
                    df_050_059_AS_I2_G  = df_050_059_AS_I2_G.assign(Polish=None)
                    df_050_059_AS_I2_G  = df_050_059_AS_I2_G.assign(Symmetry=None)
                    df_050_059_AS_I2_G  = df_050_059_AS_I2_G.assign(Ratio=None)
                    df_050_059_AS_I2_G  = df_050_059_AS_I2_G.assign(PPC=None)
                    df_050_059_AS_I2_G  = df_050_059_AS_I2_G.assign(Total=None)
                    df_050_059_AS_I2_G ['Wt Range'] = listwtrange
                    df_050_059_AS_I2_G ['Company'] = listcom
                    df_050_059_AS_I2_G ['Shape'] = listshap
                    df_050_059_AS_I2_G ['Carat'] = listcar
                    df_050_059_AS_I2_G ['Color'] = listcol
                    df_050_059_AS_I2_G ['Clarity'] = listclar
                    df_050_059_AS_I2_G ['Cut'] = listcut
                    df_050_059_AS_I2_G ['Polish'] = listpol
                    df_050_059_AS_I2_G ['Symmetry'] = listsym
                    df_050_059_AS_I2_G ['Ratio'] = listrat
                    df_050_059_AS_I2_G ['PPC'] = listdesc
                    df_050_059_AS_I2_G ['Total'] = listtotal
                    df_050_059_AS_I2_G['Carat'] = df_050_059_AS_I2_G['Carat'].astype('float64')
                    df_050_059_AS_I2_G['PPC'] = df_050_059_AS_I2_G['PPC'].astype('float64')
                    df_050_059_AS_I2_G['Total'] = df_050_059_AS_I2_G['Total'].astype('float64')
                    df_050_059_AS_I2_G['Total'] = df_050_059_AS_I2_G['Carat'] * df_050_059_AS_I2_G['PPC']


                elif i=="H" and j == "IF" and k == "AS":
                    df_050_059_AS_IF_H = pd.DataFrame()
                    df_050_059_AS_IF_H ['Wt Range'] = None
                    df_050_059_AS_IF_H  = df_050_059_AS_IF_H.assign(Company=None)
                    df_050_059_AS_IF_H  = df_050_059_AS_IF_H.assign(Shape=None)
                    df_050_059_AS_IF_H  = df_050_059_AS_IF_H.assign(Carat=None)
                    df_050_059_AS_IF_H  = df_050_059_AS_IF_H.assign(Color=None)
                    df_050_059_AS_IF_H  = df_050_059_AS_IF_H.assign(Clarity=None)
                    df_050_059_AS_IF_H  = df_050_059_AS_IF_H.assign(Cut=None)
                    df_050_059_AS_IF_H  = df_050_059_AS_IF_H.assign(Polish=None)
                    df_050_059_AS_IF_H  = df_050_059_AS_IF_H.assign(Symmetry=None)
                    df_050_059_AS_IF_H  = df_050_059_AS_IF_H.assign(Ratio=None)
                    df_050_059_AS_IF_H  = df_050_059_AS_IF_H.assign(PPC=None)
                    df_050_059_AS_IF_H  = df_050_059_AS_IF_H.assign(Total=None)
                    df_050_059_AS_IF_H ['Wt Range'] = listwtrange
                    df_050_059_AS_IF_H ['Company'] = listcom
                    df_050_059_AS_IF_H ['Shape'] = listshap
                    df_050_059_AS_IF_H ['Carat'] = listcar
                    df_050_059_AS_IF_H ['Color'] = listcol
                    df_050_059_AS_IF_H ['Clarity'] = listclar
                    df_050_059_AS_IF_H ['Cut'] = listcut
                    df_050_059_AS_IF_H ['Polish'] = listpol
                    df_050_059_AS_IF_H ['Symmetry'] = listsym
                    df_050_059_AS_IF_H ['Ratio'] = listrat
                    df_050_059_AS_IF_H ['PPC'] = listdesc
                    df_050_059_AS_IF_H ['Total'] = listtotal
                    df_050_059_AS_IF_H['Carat'] = df_050_059_AS_IF_H['Carat'].astype('float64')
                    df_050_059_AS_IF_H['PPC'] = df_050_059_AS_IF_H['PPC'].astype('float64')
                    df_050_059_AS_IF_H['Total'] = df_050_059_AS_IF_H['Total'].astype('float64')
                    df_050_059_AS_IF_H['Total'] = df_050_059_AS_IF_H['Carat'] * df_050_059_AS_IF_H['PPC']



                elif i=="H" and j == "VVS1" and k == "AS":
                    df_050_059_AS_VVS1_H = pd.DataFrame()
                    df_050_059_AS_VVS1_H ['Wt Range'] = None
                    df_050_059_AS_VVS1_H  = df_050_059_AS_VVS1_H.assign(Company=None)
                    df_050_059_AS_VVS1_H  = df_050_059_AS_VVS1_H.assign(Shape=None)
                    df_050_059_AS_VVS1_H  = df_050_059_AS_VVS1_H.assign(Carat=None)
                    df_050_059_AS_VVS1_H  = df_050_059_AS_VVS1_H.assign(Color=None)
                    df_050_059_AS_VVS1_H  = df_050_059_AS_VVS1_H.assign(Clarity=None)
                    df_050_059_AS_VVS1_H  = df_050_059_AS_VVS1_H.assign(Cut=None)
                    df_050_059_AS_VVS1_H  = df_050_059_AS_VVS1_H.assign(Polish=None)
                    df_050_059_AS_VVS1_H  = df_050_059_AS_VVS1_H.assign(Symmetry=None)
                    df_050_059_AS_VVS1_H  = df_050_059_AS_VVS1_H.assign(Ratio=None)
                    df_050_059_AS_VVS1_H  = df_050_059_AS_VVS1_H.assign(PPC=None)
                    df_050_059_AS_VVS1_H  = df_050_059_AS_VVS1_H.assign(Total=None)
                    df_050_059_AS_VVS1_H ['Wt Range'] = listwtrange
                    df_050_059_AS_VVS1_H ['Company'] = listcom
                    df_050_059_AS_VVS1_H ['Shape'] = listshap
                    df_050_059_AS_VVS1_H ['Carat'] = listcar
                    df_050_059_AS_VVS1_H ['Color'] = listcol
                    df_050_059_AS_VVS1_H ['Clarity'] = listclar
                    df_050_059_AS_VVS1_H ['Cut'] = listcut
                    df_050_059_AS_VVS1_H ['Polish'] = listpol
                    df_050_059_AS_VVS1_H ['Symmetry'] = listsym
                    df_050_059_AS_VVS1_H ['Ratio'] = listrat
                    df_050_059_AS_VVS1_H ['PPC'] = listdesc
                    df_050_059_AS_VVS1_H ['Total'] = listtotal
                    df_050_059_AS_VVS1_H['Carat'] = df_050_059_AS_VVS1_H['Carat'].astype('float64')
                    df_050_059_AS_VVS1_H['PPC'] = df_050_059_AS_VVS1_H['PPC'].astype('float64')
                    df_050_059_AS_VVS1_H['Total'] = df_050_059_AS_VVS1_H['Total'].astype('float64')
                    df_050_059_AS_VVS1_H['Total'] = df_050_059_AS_VVS1_H['Carat'] * df_050_059_AS_VVS1_H['PPC']


                elif i=="H" and j == "VVS2" and k == "AS":
                    df_050_059_AS_VVS2_H = pd.DataFrame()
                    df_050_059_AS_VVS2_H ['Wt Range'] = None
                    df_050_059_AS_VVS2_H  = df_050_059_AS_VVS2_H.assign(Company=None)
                    df_050_059_AS_VVS2_H  = df_050_059_AS_VVS2_H.assign(Shape=None)
                    df_050_059_AS_VVS2_H  = df_050_059_AS_VVS2_H.assign(Carat=None)
                    df_050_059_AS_VVS2_H  = df_050_059_AS_VVS2_H.assign(Color=None)
                    df_050_059_AS_VVS2_H  = df_050_059_AS_VVS2_H.assign(Clarity=None)
                    df_050_059_AS_VVS2_H  = df_050_059_AS_VVS2_H.assign(Cut=None)
                    df_050_059_AS_VVS2_H  = df_050_059_AS_VVS2_H.assign(Polish=None)
                    df_050_059_AS_VVS2_H  = df_050_059_AS_VVS2_H.assign(Symmetry=None)
                    df_050_059_AS_VVS2_H  = df_050_059_AS_VVS2_H.assign(Ratio=None)
                    df_050_059_AS_VVS2_H  = df_050_059_AS_VVS2_H.assign(PPC=None)
                    df_050_059_AS_VVS2_H  = df_050_059_AS_VVS2_H.assign(Total=None)
                    df_050_059_AS_VVS2_H ['Wt Range'] = listwtrange
                    df_050_059_AS_VVS2_H ['Company'] = listcom
                    df_050_059_AS_VVS2_H ['Shape'] = listshap
                    df_050_059_AS_VVS2_H ['Carat'] = listcar
                    df_050_059_AS_VVS2_H ['Color'] = listcol
                    df_050_059_AS_VVS2_H ['Clarity'] = listclar
                    df_050_059_AS_VVS2_H ['Cut'] = listcut
                    df_050_059_AS_VVS2_H ['Polish'] = listpol
                    df_050_059_AS_VVS2_H ['Symmetry'] = listsym
                    df_050_059_AS_VVS2_H ['Ratio'] = listrat
                    df_050_059_AS_VVS2_H ['PPC'] = listdesc
                    df_050_059_AS_VVS2_H ['Total'] = listtotal
                    df_050_059_AS_VVS2_H['Carat'] = df_050_059_AS_VVS2_H['Carat'].astype('float64')
                    df_050_059_AS_VVS2_H['PPC'] = df_050_059_AS_VVS2_H['PPC'].astype('float64')
                    df_050_059_AS_VVS2_H['Total'] = df_050_059_AS_VVS2_H['Total'].astype('float64')
                    df_050_059_AS_VVS2_H['Total'] = df_050_059_AS_VVS2_H['Carat'] * df_050_059_AS_VVS2_H['PPC']


                elif i=="H" and j=="VS1" and k == "AS":
                    df_050_059_AS_VS1_H = pd.DataFrame()
                    df_050_059_AS_VS1_H ['Wt Range'] = None
                    df_050_059_AS_VS1_H  = df_050_059_AS_VS1_H.assign(Company=None)
                    df_050_059_AS_VS1_H  = df_050_059_AS_VS1_H.assign(Shape=None)
                    df_050_059_AS_VS1_H  = df_050_059_AS_VS1_H.assign(Carat=None)
                    df_050_059_AS_VS1_H  = df_050_059_AS_VS1_H.assign(Color=None)
                    df_050_059_AS_VS1_H  = df_050_059_AS_VS1_H.assign(Clarity=None)
                    df_050_059_AS_VS1_H  = df_050_059_AS_VS1_H.assign(Cut=None)
                    df_050_059_AS_VS1_H  = df_050_059_AS_VS1_H.assign(Polish=None)
                    df_050_059_AS_VS1_H  = df_050_059_AS_VS1_H.assign(Symmetry=None)
                    df_050_059_AS_VS1_H  = df_050_059_AS_VS1_H.assign(Ratio=None)
                    df_050_059_AS_VS1_H  = df_050_059_AS_VS1_H.assign(PPC=None)
                    df_050_059_AS_VS1_H  = df_050_059_AS_VS1_H.assign(Total=None)
                    df_050_059_AS_VS1_H ['Wt Range'] = listwtrange
                    df_050_059_AS_VS1_H ['Company'] = listcom
                    df_050_059_AS_VS1_H ['Shape'] = listshap
                    df_050_059_AS_VS1_H ['Carat'] = listcar
                    df_050_059_AS_VS1_H ['Color'] = listcol
                    df_050_059_AS_VS1_H ['Clarity'] = listclar
                    df_050_059_AS_VS1_H ['Cut'] = listcut
                    df_050_059_AS_VS1_H ['Polish'] = listpol
                    df_050_059_AS_VS1_H ['Symmetry'] = listsym
                    df_050_059_AS_VS1_H ['Ratio'] = listrat
                    df_050_059_AS_VS1_H ['PPC'] = listdesc
                    df_050_059_AS_VS1_H ['Total'] = listtotal
                    df_050_059_AS_VS1_H['Carat'] = df_050_059_AS_VS1_H['Carat'].astype('float64')
                    df_050_059_AS_VS1_H['PPC'] = df_050_059_AS_VS1_H['PPC'].astype('float64')
                    df_050_059_AS_VS1_H['Total'] = df_050_059_AS_VS1_H['Total'].astype('float64')
                    df_050_059_AS_VS1_H['Total'] = df_050_059_AS_VS1_H['Carat'] * df_050_059_AS_VS1_H['PPC']


                elif i=="H" and j == "VS2" and k == "AS":
                    df_050_059_AS_VS2_H = pd.DataFrame()
                    df_050_059_AS_VS2_H ['Wt Range'] = None
                    df_050_059_AS_VS2_H  = df_050_059_AS_VS2_H.assign(Company=None)
                    df_050_059_AS_VS2_H  = df_050_059_AS_VS2_H.assign(Shape=None)
                    df_050_059_AS_VS2_H  = df_050_059_AS_VS2_H.assign(Carat=None)
                    df_050_059_AS_VS2_H  = df_050_059_AS_VS2_H.assign(Color=None)
                    df_050_059_AS_VS2_H  = df_050_059_AS_VS2_H.assign(Clarity=None)
                    df_050_059_AS_VS2_H  = df_050_059_AS_VS2_H.assign(Cut=None)
                    df_050_059_AS_VS2_H  = df_050_059_AS_VS2_H.assign(Polish=None)
                    df_050_059_AS_VS2_H  = df_050_059_AS_VS2_H.assign(Symmetry=None)
                    df_050_059_AS_VS2_H  = df_050_059_AS_VS2_H.assign(Ratio=None)
                    df_050_059_AS_VS2_H  = df_050_059_AS_VS2_H.assign(PPC=None)
                    df_050_059_AS_VS2_H  = df_050_059_AS_VS2_H.assign(Total=None)
                    df_050_059_AS_VS2_H ['Wt Range'] = listwtrange
                    df_050_059_AS_VS2_H ['Company'] = listcom
                    df_050_059_AS_VS2_H ['Shape'] = listshap
                    df_050_059_AS_VS2_H ['Carat'] = listcar
                    df_050_059_AS_VS2_H ['Color'] = listcol
                    df_050_059_AS_VS2_H ['Clarity'] = listclar
                    df_050_059_AS_VS2_H ['Cut'] = listcut
                    df_050_059_AS_VS2_H ['Polish'] = listpol
                    df_050_059_AS_VS2_H ['Symmetry'] = listsym
                    df_050_059_AS_VS2_H ['Ratio'] = listrat
                    df_050_059_AS_VS2_H ['PPC'] = listdesc
                    df_050_059_AS_VS2_H ['Total'] = listtotal
                    df_050_059_AS_VS2_H['Carat'] = df_050_059_AS_VS2_H['Carat'].astype('float64')
                    df_050_059_AS_VS2_H['PPC'] = df_050_059_AS_VS2_H['PPC'].astype('float64')
                    df_050_059_AS_VS2_H['Total'] = df_050_059_AS_VS2_H['Total'].astype('float64')
                    df_050_059_AS_VS2_H['Total'] = df_050_059_AS_VS2_H['Carat'] * df_050_059_AS_VS2_H['PPC']


                elif i=="H" and j == "SI1" and k == "AS":
                    df_050_059_AS_SI1_H = pd.DataFrame()
                    df_050_059_AS_SI1_H ['Wt Range'] = None
                    df_050_059_AS_SI1_H  = df_050_059_AS_SI1_H.assign(Company=None)
                    df_050_059_AS_SI1_H  = df_050_059_AS_SI1_H.assign(Shape=None)
                    df_050_059_AS_SI1_H  = df_050_059_AS_SI1_H.assign(Carat=None)
                    df_050_059_AS_SI1_H  = df_050_059_AS_SI1_H.assign(Color=None)
                    df_050_059_AS_SI1_H  = df_050_059_AS_SI1_H.assign(Clarity=None)
                    df_050_059_AS_SI1_H  = df_050_059_AS_SI1_H.assign(Cut=None)
                    df_050_059_AS_SI1_H  = df_050_059_AS_SI1_H.assign(Polish=None)
                    df_050_059_AS_SI1_H  = df_050_059_AS_SI1_H.assign(Symmetry=None)
                    df_050_059_AS_SI1_H  = df_050_059_AS_SI1_H.assign(Ratio=None)
                    df_050_059_AS_SI1_H  = df_050_059_AS_SI1_H.assign(PPC=None)
                    df_050_059_AS_SI1_H  = df_050_059_AS_SI1_H.assign(Total=None)
                    df_050_059_AS_SI1_H ['Wt Range'] = listwtrange
                    df_050_059_AS_SI1_H ['Company'] = listcom
                    df_050_059_AS_SI1_H ['Shape'] = listshap
                    df_050_059_AS_SI1_H ['Carat'] = listcar
                    df_050_059_AS_SI1_H ['Color'] = listcol
                    df_050_059_AS_SI1_H ['Clarity'] = listclar
                    df_050_059_AS_SI1_H ['Cut'] = listcut
                    df_050_059_AS_SI1_H ['Polish'] = listpol
                    df_050_059_AS_SI1_H ['Symmetry'] = listsym
                    df_050_059_AS_SI1_H ['Ratio'] = listrat
                    df_050_059_AS_SI1_H ['PPC'] = listdesc
                    df_050_059_AS_SI1_H ['Total'] = listtotal
                    df_050_059_AS_SI1_H['Carat'] = df_050_059_AS_SI1_H['Carat'].astype('float64')
                    df_050_059_AS_SI1_H['PPC'] = df_050_059_AS_SI1_H['PPC'].astype('float64')
                    df_050_059_AS_SI1_H['Total'] = df_050_059_AS_SI1_H['Total'].astype('float64')
                    df_050_059_AS_SI1_H['Total'] = df_050_059_AS_SI1_H['Carat'] * df_050_059_AS_SI1_H['PPC']


                elif i=="H" and j == "SI2" and k == "AS":
                    df_050_059_AS_SI2_H = pd.DataFrame()
                    df_050_059_AS_SI2_H ['Wt Range'] = None
                    df_050_059_AS_SI2_H  = df_050_059_AS_SI2_H.assign(Company=None)
                    df_050_059_AS_SI2_H  = df_050_059_AS_SI2_H.assign(Shape=None)
                    df_050_059_AS_SI2_H  = df_050_059_AS_SI2_H.assign(Carat=None)
                    df_050_059_AS_SI2_H  = df_050_059_AS_SI2_H.assign(Color=None)
                    df_050_059_AS_SI2_H  = df_050_059_AS_SI2_H.assign(Clarity=None)
                    df_050_059_AS_SI2_H  = df_050_059_AS_SI2_H.assign(Cut=None)
                    df_050_059_AS_SI2_H  = df_050_059_AS_SI2_H.assign(Polish=None)
                    df_050_059_AS_SI2_H  = df_050_059_AS_SI2_H.assign(Symmetry=None)
                    df_050_059_AS_SI2_H  = df_050_059_AS_SI2_H.assign(Ratio=None)
                    df_050_059_AS_SI2_H  = df_050_059_AS_SI2_H.assign(PPC=None)
                    df_050_059_AS_SI2_H  = df_050_059_AS_SI2_H.assign(Total=None)
                    df_050_059_AS_SI2_H ['Wt Range'] = listwtrange
                    df_050_059_AS_SI2_H ['Company'] = listcom
                    df_050_059_AS_SI2_H ['Shape'] = listshap
                    df_050_059_AS_SI2_H ['Carat'] = listcar
                    df_050_059_AS_SI2_H ['Color'] = listcol
                    df_050_059_AS_SI2_H ['Clarity'] = listclar
                    df_050_059_AS_SI2_H ['Cut'] = listcut
                    df_050_059_AS_SI2_H ['Polish'] = listpol
                    df_050_059_AS_SI2_H ['Symmetry'] = listsym
                    df_050_059_AS_SI2_H ['Ratio'] = listrat
                    df_050_059_AS_SI2_H ['PPC'] = listdesc
                    df_050_059_AS_SI2_H ['Total'] = listtotal
                    df_050_059_AS_SI2_H['Carat'] = df_050_059_AS_SI2_H['Carat'].astype('float64')
                    df_050_059_AS_SI2_H['PPC'] = df_050_059_AS_SI2_H['PPC'].astype('float64')
                    df_050_059_AS_SI2_H['Total'] = df_050_059_AS_SI2_H['Total'].astype('float64')
                    df_050_059_AS_SI2_H['Total'] = df_050_059_AS_SI2_H['Carat'] * df_050_059_AS_SI2_H['PPC']


                elif i=="H" and j == "I1" and k == "AS":
                    df_050_059_AS_I1_H = pd.DataFrame()
                    df_050_059_AS_I1_H ['Wt Range'] = None
                    df_050_059_AS_I1_H  = df_050_059_AS_I1_H.assign(Company=None)
                    df_050_059_AS_I1_H  = df_050_059_AS_I1_H.assign(Shape=None)
                    df_050_059_AS_I1_H  = df_050_059_AS_I1_H.assign(Carat=None)
                    df_050_059_AS_I1_H  = df_050_059_AS_I1_H.assign(Color=None)
                    df_050_059_AS_I1_H  = df_050_059_AS_I1_H.assign(Clarity=None)
                    df_050_059_AS_I1_H  = df_050_059_AS_I1_H.assign(Cut=None)
                    df_050_059_AS_I1_H  = df_050_059_AS_I1_H.assign(Polish=None)
                    df_050_059_AS_I1_H  = df_050_059_AS_I1_H.assign(Symmetry=None)
                    df_050_059_AS_I1_H  = df_050_059_AS_I1_H.assign(Ratio=None)
                    df_050_059_AS_I1_H  = df_050_059_AS_I1_H.assign(PPC=None)
                    df_050_059_AS_I1_H  = df_050_059_AS_I1_H.assign(Total=None)
                    df_050_059_AS_I1_H ['Wt Range'] = listwtrange
                    df_050_059_AS_I1_H ['Company'] = listcom
                    df_050_059_AS_I1_H ['Shape'] = listshap
                    df_050_059_AS_I1_H ['Carat'] = listcar
                    df_050_059_AS_I1_H ['Color'] = listcol
                    df_050_059_AS_I1_H ['Clarity'] = listclar
                    df_050_059_AS_I1_H ['Cut'] = listcut
                    df_050_059_AS_I1_H ['Polish'] = listpol
                    df_050_059_AS_I1_H ['Symmetry'] = listsym
                    df_050_059_AS_I1_H ['Ratio'] = listrat
                    df_050_059_AS_I1_H ['PPC'] = listdesc
                    df_050_059_AS_I1_H ['Total'] = listtotal
                    df_050_059_AS_I1_H['Carat'] = df_050_059_AS_I1_H['Carat'].astype('float64')
                    df_050_059_AS_I1_H['PPC'] = df_050_059_AS_I1_H['PPC'].astype('float64')
                    df_050_059_AS_I1_H['Total'] = df_050_059_AS_I1_H['Total'].astype('float64')
                    df_050_059_AS_I1_H['Total'] = df_050_059_AS_I1_H['Carat'] * df_050_059_AS_I1_H['PPC']


                elif i=="H" and j == "I2" and k == "AS":
                    df_050_059_AS_I2_H = pd.DataFrame()
                    df_050_059_AS_I2_H ['Wt Range'] = None
                    df_050_059_AS_I2_H  = df_050_059_AS_I2_H.assign(Company=None)
                    df_050_059_AS_I2_H  = df_050_059_AS_I2_H.assign(Shape=None)
                    df_050_059_AS_I2_H  = df_050_059_AS_I2_H.assign(Carat=None)
                    df_050_059_AS_I2_H  = df_050_059_AS_I2_H.assign(Color=None)
                    df_050_059_AS_I2_H  = df_050_059_AS_I2_H.assign(Clarity=None)
                    df_050_059_AS_I2_H  = df_050_059_AS_I2_H.assign(Cut=None)
                    df_050_059_AS_I2_H  = df_050_059_AS_I2_H.assign(Polish=None)
                    df_050_059_AS_I2_H  = df_050_059_AS_I2_H.assign(Symmetry=None)
                    df_050_059_AS_I2_H  = df_050_059_AS_I2_H.assign(Ratio=None)
                    df_050_059_AS_I2_H  = df_050_059_AS_I2_H.assign(PPC=None)
                    df_050_059_AS_I2_H  = df_050_059_AS_I2_H.assign(Total=None)
                    df_050_059_AS_I2_H ['Wt Range'] = listwtrange
                    df_050_059_AS_I2_H ['Company'] = listcom
                    df_050_059_AS_I2_H ['Shape'] = listshap
                    df_050_059_AS_I2_H ['Carat'] = listcar
                    df_050_059_AS_I2_H ['Color'] = listcol
                    df_050_059_AS_I2_H ['Clarity'] = listclar
                    df_050_059_AS_I2_H ['Cut'] = listcut
                    df_050_059_AS_I2_H ['Polish'] = listpol
                    df_050_059_AS_I2_H ['Symmetry'] = listsym
                    df_050_059_AS_I2_H ['Ratio'] = listrat
                    df_050_059_AS_I2_H ['PPC'] = listdesc
                    df_050_059_AS_I2_H ['Total'] = listtotal
                    df_050_059_AS_I2_H['Carat'] = df_050_059_AS_I2_H['Carat'].astype('float64')
                    df_050_059_AS_I2_H['PPC'] = df_050_059_AS_I2_H['PPC'].astype('float64')
                    df_050_059_AS_I2_H['Total'] = df_050_059_AS_I2_H['Total'].astype('float64')
                    df_050_059_AS_I2_H['Total'] = df_050_059_AS_I2_H['Carat'] * df_050_059_AS_I2_H['PPC']



                elif i== "I" and j == "IF" and k == "AS":
                    df_050_059_AS_IF_I = pd.DataFrame()
                    df_050_059_AS_IF_I ['Wt Range'] = None
                    df_050_059_AS_IF_I  = df_050_059_AS_IF_I.assign(Company=None)
                    df_050_059_AS_IF_I  = df_050_059_AS_IF_I.assign(Shape=None)
                    df_050_059_AS_IF_I  = df_050_059_AS_IF_I.assign(Carat=None)
                    df_050_059_AS_IF_I  = df_050_059_AS_IF_I.assign(Color=None)
                    df_050_059_AS_IF_I  = df_050_059_AS_IF_I.assign(Clarity=None)
                    df_050_059_AS_IF_I  = df_050_059_AS_IF_I.assign(Cut=None)
                    df_050_059_AS_IF_I  = df_050_059_AS_IF_I.assign(Polish=None)
                    df_050_059_AS_IF_I  = df_050_059_AS_IF_I.assign(Symmetry=None)
                    df_050_059_AS_IF_I  = df_050_059_AS_IF_I.assign(Ratio=None)
                    df_050_059_AS_IF_I  = df_050_059_AS_IF_I.assign(PPC=None)
                    df_050_059_AS_IF_I  = df_050_059_AS_IF_I.assign(Total=None)
                    df_050_059_AS_IF_I ['Wt Range'] = listwtrange
                    df_050_059_AS_IF_I ['Company'] = listcom
                    df_050_059_AS_IF_I ['Shape'] = listshap
                    df_050_059_AS_IF_I ['Carat'] = listcar
                    df_050_059_AS_IF_I ['Color'] = listcol
                    df_050_059_AS_IF_I ['Clarity'] = listclar
                    df_050_059_AS_IF_I ['Cut'] = listcut
                    df_050_059_AS_IF_I ['Polish'] = listpol
                    df_050_059_AS_IF_I ['Symmetry'] = listsym
                    df_050_059_AS_IF_I ['Ratio'] = listrat
                    df_050_059_AS_IF_I ['PPC'] = listdesc
                    df_050_059_AS_IF_I ['Total'] = listtotal
                    df_050_059_AS_IF_I['Carat'] = df_050_059_AS_IF_I['Carat'].astype('float64')
                    df_050_059_AS_IF_I['PPC'] = df_050_059_AS_IF_I['PPC'].astype('float64')
                    df_050_059_AS_IF_I['Total'] = df_050_059_AS_IF_I['Total'].astype('float64')
                    df_050_059_AS_IF_I['Total'] = df_050_059_AS_IF_I['Carat'] * df_050_059_AS_IF_I['PPC']



                elif i== "I" and j == "VVS1" and k == "AS":
                    df_050_059_AS_VVS1_I = pd.DataFrame()
                    df_050_059_AS_VVS1_I ['Wt Range'] = None
                    df_050_059_AS_VVS1_I  = df_050_059_AS_VVS1_I.assign(Company=None)
                    df_050_059_AS_VVS1_I  = df_050_059_AS_VVS1_I.assign(Shape=None)
                    df_050_059_AS_VVS1_I  = df_050_059_AS_VVS1_I.assign(Carat=None)
                    df_050_059_AS_VVS1_I  = df_050_059_AS_VVS1_I.assign(Color=None)
                    df_050_059_AS_VVS1_I  = df_050_059_AS_VVS1_I.assign(Clarity=None)
                    df_050_059_AS_VVS1_I  = df_050_059_AS_VVS1_I.assign(Cut=None)
                    df_050_059_AS_VVS1_I  = df_050_059_AS_VVS1_I.assign(Polish=None)
                    df_050_059_AS_VVS1_I  = df_050_059_AS_VVS1_I.assign(Symmetry=None)
                    df_050_059_AS_VVS1_I  = df_050_059_AS_VVS1_I.assign(Ratio=None)
                    df_050_059_AS_VVS1_I  = df_050_059_AS_VVS1_I.assign(PPC=None)
                    df_050_059_AS_VVS1_I  = df_050_059_AS_VVS1_I.assign(Total=None)
                    df_050_059_AS_VVS1_I ['Wt Range'] = listwtrange
                    df_050_059_AS_VVS1_I ['Company'] = listcom
                    df_050_059_AS_VVS1_I ['Shape'] = listshap
                    df_050_059_AS_VVS1_I ['Carat'] = listcar
                    df_050_059_AS_VVS1_I ['Color'] = listcol
                    df_050_059_AS_VVS1_I ['Clarity'] = listclar
                    df_050_059_AS_VVS1_I ['Cut'] = listcut
                    df_050_059_AS_VVS1_I ['Polish'] = listpol
                    df_050_059_AS_VVS1_I ['Symmetry'] = listsym
                    df_050_059_AS_VVS1_I ['Ratio'] = listrat
                    df_050_059_AS_VVS1_I ['PPC'] = listdesc
                    df_050_059_AS_VVS1_I ['Total'] = listtotal
                    df_050_059_AS_VVS1_I['Carat'] = df_050_059_AS_VVS1_I['Carat'].astype('float64')
                    df_050_059_AS_VVS1_I['PPC'] = df_050_059_AS_VVS1_I['PPC'].astype('float64')
                    df_050_059_AS_VVS1_I['Total'] = df_050_059_AS_VVS1_I['Total'].astype('float64')
                    df_050_059_AS_VVS1_I['Total'] = df_050_059_AS_VVS1_I['Carat'] * df_050_059_AS_VVS1_I['PPC']


                elif i== "I" and j == "VVS2" and k == "AS":
                    df_050_059_AS_VVS2_I = pd.DataFrame()
                    df_050_059_AS_VVS2_I ['Wt Range'] = None
                    df_050_059_AS_VVS2_I  = df_050_059_AS_VVS2_I.assign(Company=None)
                    df_050_059_AS_VVS2_I  = df_050_059_AS_VVS2_I.assign(Shape=None)
                    df_050_059_AS_VVS2_I  = df_050_059_AS_VVS2_I.assign(Carat=None)
                    df_050_059_AS_VVS2_I  = df_050_059_AS_VVS2_I.assign(Color=None)
                    df_050_059_AS_VVS2_I  = df_050_059_AS_VVS2_I.assign(Clarity=None)
                    df_050_059_AS_VVS2_I  = df_050_059_AS_VVS2_I.assign(Cut=None)
                    df_050_059_AS_VVS2_I  = df_050_059_AS_VVS2_I.assign(Polish=None)
                    df_050_059_AS_VVS2_I  = df_050_059_AS_VVS2_I.assign(Symmetry=None)
                    df_050_059_AS_VVS2_I  = df_050_059_AS_VVS2_I.assign(Ratio=None)
                    df_050_059_AS_VVS2_I  = df_050_059_AS_VVS2_I.assign(PPC=None)
                    df_050_059_AS_VVS2_I  = df_050_059_AS_VVS2_I.assign(Total=None)
                    df_050_059_AS_VVS2_I ['Wt Range'] = listwtrange
                    df_050_059_AS_VVS2_I ['Company'] = listcom
                    df_050_059_AS_VVS2_I ['Shape'] = listshap
                    df_050_059_AS_VVS2_I ['Carat'] = listcar
                    df_050_059_AS_VVS2_I ['Color'] = listcol
                    df_050_059_AS_VVS2_I ['Clarity'] = listclar
                    df_050_059_AS_VVS2_I ['Cut'] = listcut
                    df_050_059_AS_VVS2_I ['Polish'] = listpol
                    df_050_059_AS_VVS2_I ['Symmetry'] = listsym
                    df_050_059_AS_VVS2_I ['Ratio'] = listrat
                    df_050_059_AS_VVS2_I ['PPC'] = listdesc
                    df_050_059_AS_VVS2_I ['Total'] = listtotal
                    df_050_059_AS_VVS2_I['Carat'] = df_050_059_AS_VVS2_I['Carat'].astype('float64')
                    df_050_059_AS_VVS2_I['PPC'] = df_050_059_AS_VVS2_I['PPC'].astype('float64')
                    df_050_059_AS_VVS2_I['Total'] = df_050_059_AS_VVS2_I['Total'].astype('float64')
                    df_050_059_AS_VVS2_I['Total'] = df_050_059_AS_VVS2_I['Carat'] * df_050_059_AS_VVS2_I['PPC']


                elif i== "I" and j=="VS1" and k == "AS":
                    df_050_059_AS_VS1_I = pd.DataFrame()
                    df_050_059_AS_VS1_I ['Wt Range'] = None
                    df_050_059_AS_VS1_I  = df_050_059_AS_VS1_I.assign(Company=None)
                    df_050_059_AS_VS1_I  = df_050_059_AS_VS1_I.assign(Shape=None)
                    df_050_059_AS_VS1_I  = df_050_059_AS_VS1_I.assign(Carat=None)
                    df_050_059_AS_VS1_I  = df_050_059_AS_VS1_I.assign(Color=None)
                    df_050_059_AS_VS1_I  = df_050_059_AS_VS1_I.assign(Clarity=None)
                    df_050_059_AS_VS1_I  = df_050_059_AS_VS1_I.assign(Cut=None)
                    df_050_059_AS_VS1_I  = df_050_059_AS_VS1_I.assign(Polish=None)
                    df_050_059_AS_VS1_I  = df_050_059_AS_VS1_I.assign(Symmetry=None)
                    df_050_059_AS_VS1_I  = df_050_059_AS_VS1_I.assign(Ratio=None)
                    df_050_059_AS_VS1_I  = df_050_059_AS_VS1_I.assign(PPC=None)
                    df_050_059_AS_VS1_I  = df_050_059_AS_VS1_I.assign(Total=None)
                    df_050_059_AS_VS1_I ['Wt Range'] = listwtrange
                    df_050_059_AS_VS1_I ['Company'] = listcom
                    df_050_059_AS_VS1_I ['Shape'] = listshap
                    df_050_059_AS_VS1_I ['Carat'] = listcar
                    df_050_059_AS_VS1_I ['Color'] = listcol
                    df_050_059_AS_VS1_I ['Clarity'] = listclar
                    df_050_059_AS_VS1_I ['Cut'] = listcut
                    df_050_059_AS_VS1_I ['Polish'] = listpol
                    df_050_059_AS_VS1_I ['Symmetry'] = listsym
                    df_050_059_AS_VS1_I ['Ratio'] = listrat
                    df_050_059_AS_VS1_I ['PPC'] = listdesc
                    df_050_059_AS_VS1_I ['Total'] = listtotal
                    df_050_059_AS_VS1_I['Carat'] = df_050_059_AS_VS1_I['Carat'].astype('float64')
                    df_050_059_AS_VS1_I['PPC'] = df_050_059_AS_VS1_I['PPC'].astype('float64')
                    df_050_059_AS_VS1_I['Total'] = df_050_059_AS_VS1_I['Total'].astype('float64')
                    df_050_059_AS_VS1_I['Total'] = df_050_059_AS_VS1_I['Carat'] * df_050_059_AS_VS1_I['PPC']


                elif i== "I" and j == "VS2" and k == "AS":
                    df_050_059_AS_VS2_I = pd.DataFrame()
                    df_050_059_AS_VS2_I ['Wt Range'] = None
                    df_050_059_AS_VS2_I  = df_050_059_AS_VS2_I.assign(Company=None)
                    df_050_059_AS_VS2_I  = df_050_059_AS_VS2_I.assign(Shape=None)
                    df_050_059_AS_VS2_I  = df_050_059_AS_VS2_I.assign(Carat=None)
                    df_050_059_AS_VS2_I  = df_050_059_AS_VS2_I.assign(Color=None)
                    df_050_059_AS_VS2_I  = df_050_059_AS_VS2_I.assign(Clarity=None)
                    df_050_059_AS_VS2_I  = df_050_059_AS_VS2_I.assign(Cut=None)
                    df_050_059_AS_VS2_I  = df_050_059_AS_VS2_I.assign(Polish=None)
                    df_050_059_AS_VS2_I  = df_050_059_AS_VS2_I.assign(Symmetry=None)
                    df_050_059_AS_VS2_I  = df_050_059_AS_VS2_I.assign(Ratio=None)
                    df_050_059_AS_VS2_I  = df_050_059_AS_VS2_I.assign(PPC=None)
                    df_050_059_AS_VS2_I  = df_050_059_AS_VS2_I.assign(Total=None)
                    df_050_059_AS_VS2_I ['Wt Range'] = listwtrange
                    df_050_059_AS_VS2_I ['Company'] = listcom
                    df_050_059_AS_VS2_I ['Shape'] = listshap
                    df_050_059_AS_VS2_I ['Carat'] = listcar
                    df_050_059_AS_VS2_I ['Color'] = listcol
                    df_050_059_AS_VS2_I ['Clarity'] = listclar
                    df_050_059_AS_VS2_I ['Cut'] = listcut
                    df_050_059_AS_VS2_I ['Polish'] = listpol
                    df_050_059_AS_VS2_I ['Symmetry'] = listsym
                    df_050_059_AS_VS2_I ['Ratio'] = listrat
                    df_050_059_AS_VS2_I ['PPC'] = listdesc
                    df_050_059_AS_VS2_I ['Total'] = listtotal
                    df_050_059_AS_VS2_I['Carat'] = df_050_059_AS_VS2_I['Carat'].astype('float64')
                    df_050_059_AS_VS2_I['PPC'] = df_050_059_AS_VS2_I['PPC'].astype('float64')
                    df_050_059_AS_VS2_I['Total'] = df_050_059_AS_VS2_I['Total'].astype('float64')
                    df_050_059_AS_VS2_I['Total'] = df_050_059_AS_VS2_I['Carat'] * df_050_059_AS_VS2_I['PPC']


                elif i== "I" and j == "SI1" and k == "AS":
                    df_050_059_AS_SI1_I = pd.DataFrame()
                    df_050_059_AS_SI1_I ['Wt Range'] = None
                    df_050_059_AS_SI1_I  = df_050_059_AS_SI1_I.assign(Company=None)
                    df_050_059_AS_SI1_I  = df_050_059_AS_SI1_I.assign(Shape=None)
                    df_050_059_AS_SI1_I  = df_050_059_AS_SI1_I.assign(Carat=None)
                    df_050_059_AS_SI1_I  = df_050_059_AS_SI1_I.assign(Color=None)
                    df_050_059_AS_SI1_I  = df_050_059_AS_SI1_I.assign(Clarity=None)
                    df_050_059_AS_SI1_I  = df_050_059_AS_SI1_I.assign(Cut=None)
                    df_050_059_AS_SI1_I  = df_050_059_AS_SI1_I.assign(Polish=None)
                    df_050_059_AS_SI1_I  = df_050_059_AS_SI1_I.assign(Symmetry=None)
                    df_050_059_AS_SI1_I  = df_050_059_AS_SI1_I.assign(Ratio=None)
                    df_050_059_AS_SI1_I  = df_050_059_AS_SI1_I.assign(PPC=None)
                    df_050_059_AS_SI1_I  = df_050_059_AS_SI1_I.assign(Total=None)
                    df_050_059_AS_SI1_I ['Wt Range'] = listwtrange
                    df_050_059_AS_SI1_I ['Company'] = listcom
                    df_050_059_AS_SI1_I ['Shape'] = listshap
                    df_050_059_AS_SI1_I ['Carat'] = listcar
                    df_050_059_AS_SI1_I ['Color'] = listcol
                    df_050_059_AS_SI1_I ['Clarity'] = listclar
                    df_050_059_AS_SI1_I ['Cut'] = listcut
                    df_050_059_AS_SI1_I ['Polish'] = listpol
                    df_050_059_AS_SI1_I ['Symmetry'] = listsym
                    df_050_059_AS_SI1_I ['Ratio'] = listrat
                    df_050_059_AS_SI1_I ['PPC'] = listdesc
                    df_050_059_AS_SI1_I ['Total'] = listtotal
                    df_050_059_AS_SI1_I['Carat'] = df_050_059_AS_SI1_I['Carat'].astype('float64')
                    df_050_059_AS_SI1_I['PPC'] = df_050_059_AS_SI1_I['PPC'].astype('float64')
                    df_050_059_AS_SI1_I['Total'] = df_050_059_AS_SI1_I['Total'].astype('float64')
                    df_050_059_AS_SI1_I['Total'] = df_050_059_AS_SI1_I['Carat'] * df_050_059_AS_SI1_I['PPC']


                elif i== "I" and j == "SI2" and k == "AS":
                    df_050_059_AS_SI2_I = pd.DataFrame()
                    df_050_059_AS_SI2_I ['Wt Range'] = None
                    df_050_059_AS_SI2_I  = df_050_059_AS_SI2_I.assign(Company=None)
                    df_050_059_AS_SI2_I  = df_050_059_AS_SI2_I.assign(Shape=None)
                    df_050_059_AS_SI2_I  = df_050_059_AS_SI2_I.assign(Carat=None)
                    df_050_059_AS_SI2_I  = df_050_059_AS_SI2_I.assign(Color=None)
                    df_050_059_AS_SI2_I  = df_050_059_AS_SI2_I.assign(Clarity=None)
                    df_050_059_AS_SI2_I  = df_050_059_AS_SI2_I.assign(Cut=None)
                    df_050_059_AS_SI2_I  = df_050_059_AS_SI2_I.assign(Polish=None)
                    df_050_059_AS_SI2_I  = df_050_059_AS_SI2_I.assign(Symmetry=None)
                    df_050_059_AS_SI2_I  = df_050_059_AS_SI2_I.assign(Ratio=None)
                    df_050_059_AS_SI2_I  = df_050_059_AS_SI2_I.assign(PPC=None)
                    df_050_059_AS_SI2_I  = df_050_059_AS_SI2_I.assign(Total=None)
                    df_050_059_AS_SI2_I ['Wt Range'] = listwtrange
                    df_050_059_AS_SI2_I ['Company'] = listcom
                    df_050_059_AS_SI2_I ['Shape'] = listshap
                    df_050_059_AS_SI2_I ['Carat'] = listcar
                    df_050_059_AS_SI2_I ['Color'] = listcol
                    df_050_059_AS_SI2_I ['Clarity'] = listclar
                    df_050_059_AS_SI2_I ['Cut'] = listcut
                    df_050_059_AS_SI2_I ['Polish'] = listpol
                    df_050_059_AS_SI2_I ['Symmetry'] = listsym
                    df_050_059_AS_SI2_I ['Ratio'] = listrat
                    df_050_059_AS_SI2_I ['PPC'] = listdesc
                    df_050_059_AS_SI2_I ['Total'] = listtotal
                    df_050_059_AS_SI2_I['Carat'] = df_050_059_AS_SI2_I['Carat'].astype('float64')
                    df_050_059_AS_SI2_I['PPC'] = df_050_059_AS_SI2_I['PPC'].astype('float64')
                    df_050_059_AS_SI2_I['Total'] = df_050_059_AS_SI2_I['Total'].astype('float64')
                    df_050_059_AS_SI2_I['Total'] = df_050_059_AS_SI2_I['Carat'] * df_050_059_AS_SI2_I['PPC']


                elif i== "I" and j == "I1" and k == "AS":
                    df_050_059_AS_I1_I = pd.DataFrame()
                    df_050_059_AS_I1_I ['Wt Range'] = None
                    df_050_059_AS_I1_I  = df_050_059_AS_I1_I.assign(Company=None)
                    df_050_059_AS_I1_I  = df_050_059_AS_I1_I.assign(Shape=None)
                    df_050_059_AS_I1_I  = df_050_059_AS_I1_I.assign(Carat=None)
                    df_050_059_AS_I1_I  = df_050_059_AS_I1_I.assign(Color=None)
                    df_050_059_AS_I1_I  = df_050_059_AS_I1_I.assign(Clarity=None)
                    df_050_059_AS_I1_I  = df_050_059_AS_I1_I.assign(Cut=None)
                    df_050_059_AS_I1_I  = df_050_059_AS_I1_I.assign(Polish=None)
                    df_050_059_AS_I1_I  = df_050_059_AS_I1_I.assign(Symmetry=None)
                    df_050_059_AS_I1_I  = df_050_059_AS_I1_I.assign(Ratio=None)
                    df_050_059_AS_I1_I  = df_050_059_AS_I1_I.assign(PPC=None)
                    df_050_059_AS_I1_I  = df_050_059_AS_I1_I.assign(Total=None)
                    df_050_059_AS_I1_I ['Wt Range'] = listwtrange
                    df_050_059_AS_I1_I ['Company'] = listcom
                    df_050_059_AS_I1_I ['Shape'] = listshap
                    df_050_059_AS_I1_I ['Carat'] = listcar
                    df_050_059_AS_I1_I ['Color'] = listcol
                    df_050_059_AS_I1_I ['Clarity'] = listclar
                    df_050_059_AS_I1_I ['Cut'] = listcut
                    df_050_059_AS_I1_I ['Polish'] = listpol
                    df_050_059_AS_I1_I ['Symmetry'] = listsym
                    df_050_059_AS_I1_I ['Ratio'] = listrat
                    df_050_059_AS_I1_I ['PPC'] = listdesc
                    df_050_059_AS_I1_I ['Total'] = listtotal
                    df_050_059_AS_I1_I['Carat'] = df_050_059_AS_I1_I['Carat'].astype('float64')
                    df_050_059_AS_I1_I['PPC'] = df_050_059_AS_I1_I['PPC'].astype('float64')
                    df_050_059_AS_I1_I['Total'] = df_050_059_AS_I1_I['Total'].astype('float64')
                    df_050_059_AS_I1_I['Total'] = df_050_059_AS_I1_I['Carat'] * df_050_059_AS_I1_I['PPC']


                elif i== "I" and j == "I2" and k == "AS":
                    df_050_059_AS_I2_I = pd.DataFrame()
                    df_050_059_AS_I2_I ['Wt Range'] = None
                    df_050_059_AS_I2_I  = df_050_059_AS_I2_I.assign(Company=None)
                    df_050_059_AS_I2_I  = df_050_059_AS_I2_I.assign(Shape=None)
                    df_050_059_AS_I2_I  = df_050_059_AS_I2_I.assign(Carat=None)
                    df_050_059_AS_I2_I  = df_050_059_AS_I2_I.assign(Color=None)
                    df_050_059_AS_I2_I  = df_050_059_AS_I2_I.assign(Clarity=None)
                    df_050_059_AS_I2_I  = df_050_059_AS_I2_I.assign(Cut=None)
                    df_050_059_AS_I2_I  = df_050_059_AS_I2_I.assign(Polish=None)
                    df_050_059_AS_I2_I  = df_050_059_AS_I2_I.assign(Symmetry=None)
                    df_050_059_AS_I2_I  = df_050_059_AS_I2_I.assign(Ratio=None)
                    df_050_059_AS_I2_I  = df_050_059_AS_I2_I.assign(PPC=None)
                    df_050_059_AS_I2_I  = df_050_059_AS_I2_I.assign(Total=None)
                    df_050_059_AS_I2_I ['Wt Range'] = listwtrange
                    df_050_059_AS_I2_I ['Company'] = listcom
                    df_050_059_AS_I2_I ['Shape'] = listshap
                    df_050_059_AS_I2_I ['Carat'] = listcar
                    df_050_059_AS_I2_I ['Color'] = listcol
                    df_050_059_AS_I2_I ['Clarity'] = listclar
                    df_050_059_AS_I2_I ['Cut'] = listcut
                    df_050_059_AS_I2_I ['Polish'] = listpol
                    df_050_059_AS_I2_I ['Symmetry'] = listsym
                    df_050_059_AS_I2_I ['Ratio'] = listrat
                    df_050_059_AS_I2_I ['PPC'] = listdesc
                    df_050_059_AS_I2_I ['Total'] = listtotal
                    df_050_059_AS_I2_I['Carat'] = df_050_059_AS_I2_I['Carat'].astype('float64')
                    df_050_059_AS_I2_I['PPC'] = df_050_059_AS_I2_I['PPC'].astype('float64')
                    df_050_059_AS_I2_I['Total'] = df_050_059_AS_I2_I['Total'].astype('float64')
                    df_050_059_AS_I2_I['Total'] = df_050_059_AS_I2_I['Carat'] * df_050_059_AS_I2_I['PPC']


                elif i=="J" and j == "IF" and k == "AS":
                    df_050_059_AS_IF_J = pd.DataFrame()
                    df_050_059_AS_IF_J ['Wt Range'] = None
                    df_050_059_AS_IF_J  = df_050_059_AS_IF_J.assign(Company=None)
                    df_050_059_AS_IF_J  = df_050_059_AS_IF_J.assign(Shape=None)
                    df_050_059_AS_IF_J  = df_050_059_AS_IF_J.assign(Carat=None)
                    df_050_059_AS_IF_J  = df_050_059_AS_IF_J.assign(Color=None)
                    df_050_059_AS_IF_J  = df_050_059_AS_IF_J.assign(Clarity=None)
                    df_050_059_AS_IF_J  = df_050_059_AS_IF_J.assign(Cut=None)
                    df_050_059_AS_IF_J  = df_050_059_AS_IF_J.assign(Polish=None)
                    df_050_059_AS_IF_J  = df_050_059_AS_IF_J.assign(Symmetry=None)
                    df_050_059_AS_IF_J  = df_050_059_AS_IF_J.assign(Ratio=None)
                    df_050_059_AS_IF_J  = df_050_059_AS_IF_J.assign(PPC=None)
                    df_050_059_AS_IF_J  = df_050_059_AS_IF_J.assign(Total=None)
                    df_050_059_AS_IF_J ['Wt Range'] = listwtrange
                    df_050_059_AS_IF_J ['Company'] = listcom
                    df_050_059_AS_IF_J ['Shape'] = listshap
                    df_050_059_AS_IF_J ['Carat'] = listcar
                    df_050_059_AS_IF_J ['Color'] = listcol
                    df_050_059_AS_IF_J ['Clarity'] = listclar
                    df_050_059_AS_IF_J ['Cut'] = listcut
                    df_050_059_AS_IF_J ['Polish'] = listpol
                    df_050_059_AS_IF_J ['Symmetry'] = listsym
                    df_050_059_AS_IF_J ['Ratio'] = listrat
                    df_050_059_AS_IF_J ['PPC'] = listdesc
                    df_050_059_AS_IF_J ['Total'] = listtotal
                    df_050_059_AS_IF_J['Carat'] = df_050_059_AS_IF_J['Carat'].astype('float64')
                    df_050_059_AS_IF_J['PPC'] = df_050_059_AS_IF_J['PPC'].astype('float64')
                    df_050_059_AS_IF_J['Total'] = df_050_059_AS_IF_J['Total'].astype('float64')
                    df_050_059_AS_IF_J['Total'] = df_050_059_AS_IF_J['Carat'] * df_050_059_AS_IF_J['PPC']



                elif i=="J"  and j == "VVS1" and k == "AS":
                    df_050_059_AS_VVS1_J = pd.DataFrame()
                    df_050_059_AS_VVS1_J ['Wt Range'] = None
                    df_050_059_AS_VVS1_J  = df_050_059_AS_VVS1_J.assign(Company=None)
                    df_050_059_AS_VVS1_J  = df_050_059_AS_VVS1_J.assign(Shape=None)
                    df_050_059_AS_VVS1_J  = df_050_059_AS_VVS1_J.assign(Carat=None)
                    df_050_059_AS_VVS1_J  = df_050_059_AS_VVS1_J.assign(Color=None)
                    df_050_059_AS_VVS1_J  = df_050_059_AS_VVS1_J.assign(Clarity=None)
                    df_050_059_AS_VVS1_J  = df_050_059_AS_VVS1_J.assign(Cut=None)
                    df_050_059_AS_VVS1_J  = df_050_059_AS_VVS1_J.assign(Polish=None)
                    df_050_059_AS_VVS1_J  = df_050_059_AS_VVS1_J.assign(Symmetry=None)
                    df_050_059_AS_VVS1_J  = df_050_059_AS_VVS1_J.assign(Ratio=None)
                    df_050_059_AS_VVS1_J  = df_050_059_AS_VVS1_J.assign(PPC=None)
                    df_050_059_AS_VVS1_J  = df_050_059_AS_VVS1_J.assign(Total=None)
                    df_050_059_AS_VVS1_J ['Wt Range'] = listwtrange
                    df_050_059_AS_VVS1_J ['Company'] = listcom
                    df_050_059_AS_VVS1_J ['Shape'] = listshap
                    df_050_059_AS_VVS1_J ['Carat'] = listcar
                    df_050_059_AS_VVS1_J ['Color'] = listcol
                    df_050_059_AS_VVS1_J ['Clarity'] = listclar
                    df_050_059_AS_VVS1_J ['Cut'] = listcut
                    df_050_059_AS_VVS1_J ['Polish'] = listpol
                    df_050_059_AS_VVS1_J ['Symmetry'] = listsym
                    df_050_059_AS_VVS1_J ['Ratio'] = listrat
                    df_050_059_AS_VVS1_J ['PPC'] = listdesc
                    df_050_059_AS_VVS1_J ['Total'] = listtotal
                    df_050_059_AS_VVS1_J['Carat'] = df_050_059_AS_VVS1_J['Carat'].astype('float64')
                    df_050_059_AS_VVS1_J['PPC'] = df_050_059_AS_VVS1_J['PPC'].astype('float64')
                    df_050_059_AS_VVS1_J['Total'] = df_050_059_AS_VVS1_J['Total'].astype('float64')
                    df_050_059_AS_VVS1_J['Total'] = df_050_059_AS_VVS1_J['Carat'] * df_050_059_AS_VVS1_J['PPC']


                elif i=="J"  and j == "VVS2" and k == "AS":
                    df_050_059_AS_VVS2_J = pd.DataFrame()
                    df_050_059_AS_VVS2_J ['Wt Range'] = None
                    df_050_059_AS_VVS2_J  = df_050_059_AS_VVS2_J.assign(Company=None)
                    df_050_059_AS_VVS2_J  = df_050_059_AS_VVS2_J.assign(Shape=None)
                    df_050_059_AS_VVS2_J  = df_050_059_AS_VVS2_J.assign(Carat=None)
                    df_050_059_AS_VVS2_J  = df_050_059_AS_VVS2_J.assign(Color=None)
                    df_050_059_AS_VVS2_J  = df_050_059_AS_VVS2_J.assign(Clarity=None)
                    df_050_059_AS_VVS2_J  = df_050_059_AS_VVS2_J.assign(Cut=None)
                    df_050_059_AS_VVS2_J  = df_050_059_AS_VVS2_J.assign(Polish=None)
                    df_050_059_AS_VVS2_J  = df_050_059_AS_VVS2_J.assign(Symmetry=None)
                    df_050_059_AS_VVS2_J  = df_050_059_AS_VVS2_J.assign(Ratio=None)
                    df_050_059_AS_VVS2_J  = df_050_059_AS_VVS2_J.assign(PPC=None)
                    df_050_059_AS_VVS2_J  = df_050_059_AS_VVS2_J.assign(Total=None)
                    df_050_059_AS_VVS2_J ['Wt Range'] = listwtrange
                    df_050_059_AS_VVS2_J ['Company'] = listcom
                    df_050_059_AS_VVS2_J ['Shape'] = listshap
                    df_050_059_AS_VVS2_J ['Carat'] = listcar
                    df_050_059_AS_VVS2_J ['Color'] = listcol
                    df_050_059_AS_VVS2_J ['Clarity'] = listclar
                    df_050_059_AS_VVS2_J ['Cut'] = listcut
                    df_050_059_AS_VVS2_J ['Polish'] = listpol
                    df_050_059_AS_VVS2_J ['Symmetry'] = listsym
                    df_050_059_AS_VVS2_J ['Ratio'] = listrat
                    df_050_059_AS_VVS2_J ['PPC'] = listdesc
                    df_050_059_AS_VVS2_J ['Total'] = listtotal
                    df_050_059_AS_VVS2_J['Carat'] = df_050_059_AS_VVS2_J['Carat'].astype('float64')
                    df_050_059_AS_VVS2_J['PPC'] = df_050_059_AS_VVS2_J['PPC'].astype('float64')
                    df_050_059_AS_VVS2_J['Total'] = df_050_059_AS_VVS2_J['Total'].astype('float64')
                    df_050_059_AS_VVS2_J['Total'] = df_050_059_AS_VVS2_J['Carat'] * df_050_059_AS_VVS2_J['PPC']


                elif i=="J"  and j=="VS1" and k == "AS":
                    df_050_059_AS_VS1_J = pd.DataFrame()
                    df_050_059_AS_VS1_J ['Wt Range'] = None
                    df_050_059_AS_VS1_J  = df_050_059_AS_VS1_J.assign(Company=None)
                    df_050_059_AS_VS1_J  = df_050_059_AS_VS1_J.assign(Shape=None)
                    df_050_059_AS_VS1_J  = df_050_059_AS_VS1_J.assign(Carat=None)
                    df_050_059_AS_VS1_J  = df_050_059_AS_VS1_J.assign(Color=None)
                    df_050_059_AS_VS1_J  = df_050_059_AS_VS1_J.assign(Clarity=None)
                    df_050_059_AS_VS1_J  = df_050_059_AS_VS1_J.assign(Cut=None)
                    df_050_059_AS_VS1_J  = df_050_059_AS_VS1_J.assign(Polish=None)
                    df_050_059_AS_VS1_J  = df_050_059_AS_VS1_J.assign(Symmetry=None)
                    df_050_059_AS_VS1_J  = df_050_059_AS_VS1_J.assign(Ratio=None)
                    df_050_059_AS_VS1_J  = df_050_059_AS_VS1_J.assign(PPC=None)
                    df_050_059_AS_VS1_J  = df_050_059_AS_VS1_J.assign(Total=None)
                    df_050_059_AS_VS1_J ['Wt Range'] = listwtrange
                    df_050_059_AS_VS1_J ['Company'] = listcom
                    df_050_059_AS_VS1_J ['Shape'] = listshap
                    df_050_059_AS_VS1_J ['Carat'] = listcar
                    df_050_059_AS_VS1_J ['Color'] = listcol
                    df_050_059_AS_VS1_J ['Clarity'] = listclar
                    df_050_059_AS_VS1_J ['Cut'] = listcut
                    df_050_059_AS_VS1_J ['Polish'] = listpol
                    df_050_059_AS_VS1_J ['Symmetry'] = listsym
                    df_050_059_AS_VS1_J ['Ratio'] = listrat
                    df_050_059_AS_VS1_J ['PPC'] = listdesc
                    df_050_059_AS_VS1_J ['Total'] = listtotal
                    df_050_059_AS_VS1_J['Carat'] = df_050_059_AS_VS1_J['Carat'].astype('float64')
                    df_050_059_AS_VS1_J['PPC'] = df_050_059_AS_VS1_J['PPC'].astype('float64')
                    df_050_059_AS_VS1_J['Total'] = df_050_059_AS_VS1_J['Total'].astype('float64')
                    df_050_059_AS_VS1_J['Total'] = df_050_059_AS_VS1_J['Carat'] * df_050_059_AS_VS1_J['PPC']


                elif i=="J"  and j == "VS2" and k == "AS":
                    df_050_059_AS_VS2_J = pd.DataFrame()
                    df_050_059_AS_VS2_J ['Wt Range'] = None
                    df_050_059_AS_VS2_J  = df_050_059_AS_VS2_J.assign(Company=None)
                    df_050_059_AS_VS2_J  = df_050_059_AS_VS2_J.assign(Shape=None)
                    df_050_059_AS_VS2_J  = df_050_059_AS_VS2_J.assign(Carat=None)
                    df_050_059_AS_VS2_J  = df_050_059_AS_VS2_J.assign(Color=None)
                    df_050_059_AS_VS2_J  = df_050_059_AS_VS2_J.assign(Clarity=None)
                    df_050_059_AS_VS2_J  = df_050_059_AS_VS2_J.assign(Cut=None)
                    df_050_059_AS_VS2_J  = df_050_059_AS_VS2_J.assign(Polish=None)
                    df_050_059_AS_VS2_J  = df_050_059_AS_VS2_J.assign(Symmetry=None)
                    df_050_059_AS_VS2_J  = df_050_059_AS_VS2_J.assign(Ratio=None)
                    df_050_059_AS_VS2_J  = df_050_059_AS_VS2_J.assign(PPC=None)
                    df_050_059_AS_VS2_J  = df_050_059_AS_VS2_J.assign(Total=None)
                    df_050_059_AS_VS2_J ['Wt Range'] = listwtrange
                    df_050_059_AS_VS2_J ['Company'] = listcom
                    df_050_059_AS_VS2_J ['Shape'] = listshap
                    df_050_059_AS_VS2_J ['Carat'] = listcar
                    df_050_059_AS_VS2_J ['Color'] = listcol
                    df_050_059_AS_VS2_J ['Clarity'] = listclar
                    df_050_059_AS_VS2_J ['Cut'] = listcut
                    df_050_059_AS_VS2_J ['Polish'] = listpol
                    df_050_059_AS_VS2_J ['Symmetry'] = listsym
                    df_050_059_AS_VS2_J ['Ratio'] = listrat
                    df_050_059_AS_VS2_J ['PPC'] = listdesc
                    df_050_059_AS_VS2_J ['Total'] = listtotal
                    df_050_059_AS_VS2_J['Carat'] = df_050_059_AS_VS2_J['Carat'].astype('float64')
                    df_050_059_AS_VS2_J['PPC'] = df_050_059_AS_VS2_J['PPC'].astype('float64')
                    df_050_059_AS_VS2_J['Total'] = df_050_059_AS_VS2_J['Total'].astype('float64')
                    df_050_059_AS_VS2_J['Total'] = df_050_059_AS_VS2_J['Carat'] * df_050_059_AS_VS2_J['PPC']


                elif i=="J"  and j == "SI1" and k == "AS":
                    df_050_059_AS_SI1_J = pd.DataFrame()
                    df_050_059_AS_SI1_J ['Wt Range'] = None
                    df_050_059_AS_SI1_J  = df_050_059_AS_SI1_J.assign(Company=None)
                    df_050_059_AS_SI1_J  = df_050_059_AS_SI1_J.assign(Shape=None)
                    df_050_059_AS_SI1_J  = df_050_059_AS_SI1_J.assign(Carat=None)
                    df_050_059_AS_SI1_J  = df_050_059_AS_SI1_J.assign(Color=None)
                    df_050_059_AS_SI1_J  = df_050_059_AS_SI1_J.assign(Clarity=None)
                    df_050_059_AS_SI1_J  = df_050_059_AS_SI1_J.assign(Cut=None)
                    df_050_059_AS_SI1_J  = df_050_059_AS_SI1_J.assign(Polish=None)
                    df_050_059_AS_SI1_J  = df_050_059_AS_SI1_J.assign(Symmetry=None)
                    df_050_059_AS_SI1_J  = df_050_059_AS_SI1_J.assign(Ratio=None)
                    df_050_059_AS_SI1_J  = df_050_059_AS_SI1_J.assign(PPC=None)
                    df_050_059_AS_SI1_J  = df_050_059_AS_SI1_J.assign(Total=None)
                    df_050_059_AS_SI1_J ['Wt Range'] = listwtrange
                    df_050_059_AS_SI1_J ['Company'] = listcom
                    df_050_059_AS_SI1_J ['Shape'] = listshap
                    df_050_059_AS_SI1_J ['Carat'] = listcar
                    df_050_059_AS_SI1_J ['Color'] = listcol
                    df_050_059_AS_SI1_J ['Clarity'] = listclar
                    df_050_059_AS_SI1_J ['Cut'] = listcut
                    df_050_059_AS_SI1_J ['Polish'] = listpol
                    df_050_059_AS_SI1_J ['Symmetry'] = listsym
                    df_050_059_AS_SI1_J ['Ratio'] = listrat
                    df_050_059_AS_SI1_J ['PPC'] = listdesc
                    df_050_059_AS_SI1_J ['Total'] = listtotal
                    df_050_059_AS_SI1_J['Carat'] = df_050_059_AS_SI1_J['Carat'].astype('float64')
                    df_050_059_AS_SI1_J['PPC'] = df_050_059_AS_SI1_J['PPC'].astype('float64')
                    df_050_059_AS_SI1_J['Total'] = df_050_059_AS_SI1_J['Total'].astype('float64')
                    df_050_059_AS_SI1_J['Total'] = df_050_059_AS_SI1_J['Carat'] * df_050_059_AS_SI1_J['PPC']


                elif i=="J"  and j == "SI2" and k == "AS":
                    df_050_059_AS_SI2_J = pd.DataFrame()
                    df_050_059_AS_SI2_J ['Wt Range'] = None
                    df_050_059_AS_SI2_J  = df_050_059_AS_SI2_J.assign(Company=None)
                    df_050_059_AS_SI2_J  = df_050_059_AS_SI2_J.assign(Shape=None)
                    df_050_059_AS_SI2_J  = df_050_059_AS_SI2_J.assign(Carat=None)
                    df_050_059_AS_SI2_J  = df_050_059_AS_SI2_J.assign(Color=None)
                    df_050_059_AS_SI2_J  = df_050_059_AS_SI2_J.assign(Clarity=None)
                    df_050_059_AS_SI2_J  = df_050_059_AS_SI2_J.assign(Cut=None)
                    df_050_059_AS_SI2_J  = df_050_059_AS_SI2_J.assign(Polish=None)
                    df_050_059_AS_SI2_J  = df_050_059_AS_SI2_J.assign(Symmetry=None)
                    df_050_059_AS_SI2_J  = df_050_059_AS_SI2_J.assign(Ratio=None)
                    df_050_059_AS_SI2_J  = df_050_059_AS_SI2_J.assign(PPC=None)
                    df_050_059_AS_SI2_J  = df_050_059_AS_SI2_J.assign(Total=None)
                    df_050_059_AS_SI2_J ['Wt Range'] = listwtrange
                    df_050_059_AS_SI2_J ['Company'] = listcom
                    df_050_059_AS_SI2_J ['Shape'] = listshap
                    df_050_059_AS_SI2_J ['Carat'] = listcar
                    df_050_059_AS_SI2_J ['Color'] = listcol
                    df_050_059_AS_SI2_J ['Clarity'] = listclar
                    df_050_059_AS_SI2_J ['Cut'] = listcut
                    df_050_059_AS_SI2_J ['Polish'] = listpol
                    df_050_059_AS_SI2_J ['Symmetry'] = listsym
                    df_050_059_AS_SI2_J ['Ratio'] = listrat
                    df_050_059_AS_SI2_J ['PPC'] = listdesc
                    df_050_059_AS_SI2_J ['Total'] = listtotal
                    df_050_059_AS_SI2_J['Carat'] = df_050_059_AS_SI2_J['Carat'].astype('float64')
                    df_050_059_AS_SI2_J['PPC'] = df_050_059_AS_SI2_J['PPC'].astype('float64')
                    df_050_059_AS_SI2_J['Total'] = df_050_059_AS_SI2_J['Total'].astype('float64')
                    df_050_059_AS_SI2_J['Total'] = df_050_059_AS_SI2_J['Carat'] * df_050_059_AS_SI2_J['PPC']


                elif i=="J"  and j == "I1" and k == "AS":
                    df_050_059_AS_I1_J = pd.DataFrame()
                    df_050_059_AS_I1_J ['Wt Range'] = None
                    df_050_059_AS_I1_J  = df_050_059_AS_I1_J.assign(Company=None)
                    df_050_059_AS_I1_J  = df_050_059_AS_I1_J.assign(Shape=None)
                    df_050_059_AS_I1_J  = df_050_059_AS_I1_J.assign(Carat=None)
                    df_050_059_AS_I1_J  = df_050_059_AS_I1_J.assign(Color=None)
                    df_050_059_AS_I1_J  = df_050_059_AS_I1_J.assign(Clarity=None)
                    df_050_059_AS_I1_J  = df_050_059_AS_I1_J.assign(Cut=None)
                    df_050_059_AS_I1_J  = df_050_059_AS_I1_J.assign(Polish=None)
                    df_050_059_AS_I1_J  = df_050_059_AS_I1_J.assign(Symmetry=None)
                    df_050_059_AS_I1_J  = df_050_059_AS_I1_J.assign(Ratio=None)
                    df_050_059_AS_I1_J  = df_050_059_AS_I1_J.assign(PPC=None)
                    df_050_059_AS_I1_J  = df_050_059_AS_I1_J.assign(Total=None)
                    df_050_059_AS_I1_J ['Wt Range'] = listwtrange
                    df_050_059_AS_I1_J ['Company'] = listcom
                    df_050_059_AS_I1_J ['Shape'] = listshap
                    df_050_059_AS_I1_J ['Carat'] = listcar
                    df_050_059_AS_I1_J ['Color'] = listcol
                    df_050_059_AS_I1_J ['Clarity'] = listclar
                    df_050_059_AS_I1_J ['Cut'] = listcut
                    df_050_059_AS_I1_J ['Polish'] = listpol
                    df_050_059_AS_I1_J ['Symmetry'] = listsym
                    df_050_059_AS_I1_J ['Ratio'] = listrat
                    df_050_059_AS_I1_J ['PPC'] = listdesc
                    df_050_059_AS_I1_J ['Total'] = listtotal
                    df_050_059_AS_I1_J['Carat'] = df_050_059_AS_I1_J['Carat'].astype('float64')
                    df_050_059_AS_I1_J['PPC'] = df_050_059_AS_I1_J['PPC'].astype('float64')
                    df_050_059_AS_I1_J['Total'] = df_050_059_AS_I1_J['Total'].astype('float64')
                    df_050_059_AS_I1_J['Total'] = df_050_059_AS_I1_J['Carat'] * df_050_059_AS_I1_J['PPC']


                elif i=="J"  and j == "I2" and k == "AS":
                    df_050_059_AS_I2_J = pd.DataFrame()
                    df_050_059_AS_I2_J ['Wt Range'] = None
                    df_050_059_AS_I2_J  = df_050_059_AS_I2_J.assign(Company=None)
                    df_050_059_AS_I2_J  = df_050_059_AS_I2_J.assign(Shape=None)
                    df_050_059_AS_I2_J  = df_050_059_AS_I2_J.assign(Carat=None)
                    df_050_059_AS_I2_J  = df_050_059_AS_I2_J.assign(Color=None)
                    df_050_059_AS_I2_J  = df_050_059_AS_I2_J.assign(Clarity=None)
                    df_050_059_AS_I2_J  = df_050_059_AS_I2_J.assign(Cut=None)
                    df_050_059_AS_I2_J  = df_050_059_AS_I2_J.assign(Polish=None)
                    df_050_059_AS_I2_J  = df_050_059_AS_I2_J.assign(Symmetry=None)
                    df_050_059_AS_I2_J  = df_050_059_AS_I2_J.assign(Ratio=None)
                    df_050_059_AS_I2_J  = df_050_059_AS_I2_J.assign(PPC=None)
                    df_050_059_AS_I2_J  = df_050_059_AS_I2_J.assign(Total=None)
                    df_050_059_AS_I2_J ['Wt Range'] = listwtrange
                    df_050_059_AS_I2_J ['Company'] = listcom
                    df_050_059_AS_I2_J ['Shape'] = listshap
                    df_050_059_AS_I2_J ['Carat'] = listcar
                    df_050_059_AS_I2_J ['Color'] = listcol
                    df_050_059_AS_I2_J ['Clarity'] = listclar
                    df_050_059_AS_I2_J ['Cut'] = listcut
                    df_050_059_AS_I2_J ['Polish'] = listpol
                    df_050_059_AS_I2_J ['Symmetry'] = listsym
                    df_050_059_AS_I2_J ['Ratio'] = listrat
                    df_050_059_AS_I2_J ['PPC'] = listdesc
                    df_050_059_AS_I2_J ['Total'] = listtotal
                    df_050_059_AS_I2_J['Carat'] = df_050_059_AS_I2_J['Carat'].astype('float64')
                    df_050_059_AS_I2_J['PPC'] = df_050_059_AS_I2_J['PPC'].astype('float64')
                    df_050_059_AS_I2_J['Total'] = df_050_059_AS_I2_J['Total'].astype('float64')
                    df_050_059_AS_I2_J['Total'] = df_050_059_AS_I2_J['Carat'] * df_050_059_AS_I2_J['PPC']


                elif i=="K" and j == "IF" and k == "AS":
                    df_050_059_AS_IF_K = pd.DataFrame()
                    df_050_059_AS_IF_K ['Wt Range'] = None
                    df_050_059_AS_IF_K  = df_050_059_AS_IF_K.assign(Company=None)
                    df_050_059_AS_IF_K  = df_050_059_AS_IF_K.assign(Shape=None)
                    df_050_059_AS_IF_K  = df_050_059_AS_IF_K.assign(Carat=None)
                    df_050_059_AS_IF_K  = df_050_059_AS_IF_K.assign(Color=None)
                    df_050_059_AS_IF_K  = df_050_059_AS_IF_K.assign(Clarity=None)
                    df_050_059_AS_IF_K  = df_050_059_AS_IF_K.assign(Cut=None)
                    df_050_059_AS_IF_K  = df_050_059_AS_IF_K.assign(Polish=None)
                    df_050_059_AS_IF_K  = df_050_059_AS_IF_K.assign(Symmetry=None)
                    df_050_059_AS_IF_K  = df_050_059_AS_IF_K.assign(Ratio=None)
                    df_050_059_AS_IF_K  = df_050_059_AS_IF_K.assign(PPC=None)
                    df_050_059_AS_IF_K  = df_050_059_AS_IF_K.assign(Total=None)
                    df_050_059_AS_IF_K ['Wt Range'] = listwtrange
                    df_050_059_AS_IF_K ['Company'] = listcom
                    df_050_059_AS_IF_K ['Shape'] = listshap
                    df_050_059_AS_IF_K ['Carat'] = listcar
                    df_050_059_AS_IF_K ['Color'] = listcol
                    df_050_059_AS_IF_K ['Clarity'] = listclar
                    df_050_059_AS_IF_K ['Cut'] = listcut
                    df_050_059_AS_IF_K ['Polish'] = listpol
                    df_050_059_AS_IF_K ['Symmetry'] = listsym
                    df_050_059_AS_IF_K ['Ratio'] = listrat
                    df_050_059_AS_IF_K ['PPC'] = listdesc
                    df_050_059_AS_IF_K ['Total'] = listtotal
                    df_050_059_AS_IF_K['Carat'] = df_050_059_AS_IF_K['Carat'].astype('float64')
                    df_050_059_AS_IF_K['PPC'] = df_050_059_AS_IF_K['PPC'].astype('float64')
                    df_050_059_AS_IF_K['Total'] = df_050_059_AS_IF_K['Total'].astype('float64')
                    df_050_059_AS_IF_K['Total'] = df_050_059_AS_IF_K['Carat'] * df_050_059_AS_IF_K['PPC']



                elif i=="K" and j == "VVS1" and k == "AS":
                    df_050_059_AS_VVS1_K = pd.DataFrame()
                    df_050_059_AS_VVS1_K ['Wt Range'] = None
                    df_050_059_AS_VVS1_K  = df_050_059_AS_VVS1_K.assign(Company=None)
                    df_050_059_AS_VVS1_K  = df_050_059_AS_VVS1_K.assign(Shape=None)
                    df_050_059_AS_VVS1_K  = df_050_059_AS_VVS1_K.assign(Carat=None)
                    df_050_059_AS_VVS1_K  = df_050_059_AS_VVS1_K.assign(Color=None)
                    df_050_059_AS_VVS1_K  = df_050_059_AS_VVS1_K.assign(Clarity=None)
                    df_050_059_AS_VVS1_K  = df_050_059_AS_VVS1_K.assign(Cut=None)
                    df_050_059_AS_VVS1_K  = df_050_059_AS_VVS1_K.assign(Polish=None)
                    df_050_059_AS_VVS1_K  = df_050_059_AS_VVS1_K.assign(Symmetry=None)
                    df_050_059_AS_VVS1_K  = df_050_059_AS_VVS1_K.assign(Ratio=None)
                    df_050_059_AS_VVS1_K  = df_050_059_AS_VVS1_K.assign(PPC=None)
                    df_050_059_AS_VVS1_K  = df_050_059_AS_VVS1_K.assign(Total=None)
                    df_050_059_AS_VVS1_K ['Wt Range'] = listwtrange
                    df_050_059_AS_VVS1_K ['Company'] = listcom
                    df_050_059_AS_VVS1_K ['Shape'] = listshap
                    df_050_059_AS_VVS1_K ['Carat'] = listcar
                    df_050_059_AS_VVS1_K ['Color'] = listcol
                    df_050_059_AS_VVS1_K ['Clarity'] = listclar
                    df_050_059_AS_VVS1_K ['Cut'] = listcut
                    df_050_059_AS_VVS1_K ['Polish'] = listpol
                    df_050_059_AS_VVS1_K ['Symmetry'] = listsym
                    df_050_059_AS_VVS1_K ['Ratio'] = listrat
                    df_050_059_AS_VVS1_K ['PPC'] = listdesc
                    df_050_059_AS_VVS1_K ['Total'] = listtotal
                    df_050_059_AS_VVS1_K['Carat'] = df_050_059_AS_VVS1_K['Carat'].astype('float64')
                    df_050_059_AS_VVS1_K['PPC'] = df_050_059_AS_VVS1_K['PPC'].astype('float64')
                    df_050_059_AS_VVS1_K['Total'] = df_050_059_AS_VVS1_K['Total'].astype('float64')
                    df_050_059_AS_VVS1_K['Total'] = df_050_059_AS_VVS1_K['Carat'] * df_050_059_AS_VVS1_K['PPC']


                elif i=="K" and j == "VVS2" and k == "AS":
                    df_050_059_AS_VVS2_K = pd.DataFrame()
                    df_050_059_AS_VVS2_K ['Wt Range'] = None
                    df_050_059_AS_VVS2_K  = df_050_059_AS_VVS2_K.assign(Company=None)
                    df_050_059_AS_VVS2_K  = df_050_059_AS_VVS2_K.assign(Shape=None)
                    df_050_059_AS_VVS2_K  = df_050_059_AS_VVS2_K.assign(Carat=None)
                    df_050_059_AS_VVS2_K  = df_050_059_AS_VVS2_K.assign(Color=None)
                    df_050_059_AS_VVS2_K  = df_050_059_AS_VVS2_K.assign(Clarity=None)
                    df_050_059_AS_VVS2_K  = df_050_059_AS_VVS2_K.assign(Cut=None)
                    df_050_059_AS_VVS2_K  = df_050_059_AS_VVS2_K.assign(Polish=None)
                    df_050_059_AS_VVS2_K  = df_050_059_AS_VVS2_K.assign(Symmetry=None)
                    df_050_059_AS_VVS2_K  = df_050_059_AS_VVS2_K.assign(Ratio=None)
                    df_050_059_AS_VVS2_K  = df_050_059_AS_VVS2_K.assign(PPC=None)
                    df_050_059_AS_VVS2_K  = df_050_059_AS_VVS2_K.assign(Total=None)
                    df_050_059_AS_VVS2_K ['Wt Range'] = listwtrange
                    df_050_059_AS_VVS2_K ['Company'] = listcom
                    df_050_059_AS_VVS2_K ['Shape'] = listshap
                    df_050_059_AS_VVS2_K ['Carat'] = listcar
                    df_050_059_AS_VVS2_K ['Color'] = listcol
                    df_050_059_AS_VVS2_K ['Clarity'] = listclar
                    df_050_059_AS_VVS2_K ['Cut'] = listcut
                    df_050_059_AS_VVS2_K ['Polish'] = listpol
                    df_050_059_AS_VVS2_K ['Symmetry'] = listsym
                    df_050_059_AS_VVS2_K ['Ratio'] = listrat
                    df_050_059_AS_VVS2_K ['PPC'] = listdesc
                    df_050_059_AS_VVS2_K ['Total'] = listtotal
                    df_050_059_AS_VVS2_K['Carat'] = df_050_059_AS_VVS2_K['Carat'].astype('float64')
                    df_050_059_AS_VVS2_K['PPC'] = df_050_059_AS_VVS2_K['PPC'].astype('float64')
                    df_050_059_AS_VVS2_K['Total'] = df_050_059_AS_VVS2_K['Total'].astype('float64')
                    df_050_059_AS_VVS2_K['Total'] = df_050_059_AS_VVS2_K['Carat'] * df_050_059_AS_VVS2_K['PPC']


                elif i=="K" and j=="VS1" and k == "AS":
                    df_050_059_AS_VS1_K = pd.DataFrame()
                    df_050_059_AS_VS1_K ['Wt Range'] = None
                    df_050_059_AS_VS1_K  = df_050_059_AS_VS1_K.assign(Company=None)
                    df_050_059_AS_VS1_K  = df_050_059_AS_VS1_K.assign(Shape=None)
                    df_050_059_AS_VS1_K  = df_050_059_AS_VS1_K.assign(Carat=None)
                    df_050_059_AS_VS1_K  = df_050_059_AS_VS1_K.assign(Color=None)
                    df_050_059_AS_VS1_K  = df_050_059_AS_VS1_K.assign(Clarity=None)
                    df_050_059_AS_VS1_K  = df_050_059_AS_VS1_K.assign(Cut=None)
                    df_050_059_AS_VS1_K  = df_050_059_AS_VS1_K.assign(Polish=None)
                    df_050_059_AS_VS1_K  = df_050_059_AS_VS1_K.assign(Symmetry=None)
                    df_050_059_AS_VS1_K  = df_050_059_AS_VS1_K.assign(Ratio=None)
                    df_050_059_AS_VS1_K  = df_050_059_AS_VS1_K.assign(PPC=None)
                    df_050_059_AS_VS1_K  = df_050_059_AS_VS1_K.assign(Total=None)
                    df_050_059_AS_VS1_K ['Wt Range'] = listwtrange
                    df_050_059_AS_VS1_K ['Company'] = listcom
                    df_050_059_AS_VS1_K ['Shape'] = listshap
                    df_050_059_AS_VS1_K ['Carat'] = listcar
                    df_050_059_AS_VS1_K ['Color'] = listcol
                    df_050_059_AS_VS1_K ['Clarity'] = listclar
                    df_050_059_AS_VS1_K ['Cut'] = listcut
                    df_050_059_AS_VS1_K ['Polish'] = listpol
                    df_050_059_AS_VS1_K ['Symmetry'] = listsym
                    df_050_059_AS_VS1_K ['Ratio'] = listrat
                    df_050_059_AS_VS1_K ['PPC'] = listdesc
                    df_050_059_AS_VS1_K ['Total'] = listtotal
                    df_050_059_AS_VS1_K['Carat'] = df_050_059_AS_VS1_K['Carat'].astype('float64')
                    df_050_059_AS_VS1_K['PPC'] = df_050_059_AS_VS1_K['PPC'].astype('float64')
                    df_050_059_AS_VS1_K['Total'] = df_050_059_AS_VS1_K['Total'].astype('float64')
                    df_050_059_AS_VS1_K['Total'] = df_050_059_AS_VS1_K['Carat'] * df_050_059_AS_VS1_K['PPC']


                elif i=="K" and j == "VS2" and k == "AS":
                    df_050_059_AS_VS2_K = pd.DataFrame()
                    df_050_059_AS_VS2_K ['Wt Range'] = None
                    df_050_059_AS_VS2_K  = df_050_059_AS_VS2_K.assign(Company=None)
                    df_050_059_AS_VS2_K  = df_050_059_AS_VS2_K.assign(Shape=None)
                    df_050_059_AS_VS2_K  = df_050_059_AS_VS2_K.assign(Carat=None)
                    df_050_059_AS_VS2_K  = df_050_059_AS_VS2_K.assign(Color=None)
                    df_050_059_AS_VS2_K  = df_050_059_AS_VS2_K.assign(Clarity=None)
                    df_050_059_AS_VS2_K  = df_050_059_AS_VS2_K.assign(Cut=None)
                    df_050_059_AS_VS2_K  = df_050_059_AS_VS2_K.assign(Polish=None)
                    df_050_059_AS_VS2_K  = df_050_059_AS_VS2_K.assign(Symmetry=None)
                    df_050_059_AS_VS2_K  = df_050_059_AS_VS2_K.assign(Ratio=None)
                    df_050_059_AS_VS2_K  = df_050_059_AS_VS2_K.assign(PPC=None)
                    df_050_059_AS_VS2_K  = df_050_059_AS_VS2_K.assign(Total=None)
                    df_050_059_AS_VS2_K ['Wt Range'] = listwtrange
                    df_050_059_AS_VS2_K ['Company'] = listcom
                    df_050_059_AS_VS2_K ['Shape'] = listshap
                    df_050_059_AS_VS2_K ['Carat'] = listcar
                    df_050_059_AS_VS2_K ['Color'] = listcol
                    df_050_059_AS_VS2_K ['Clarity'] = listclar
                    df_050_059_AS_VS2_K ['Cut'] = listcut
                    df_050_059_AS_VS2_K ['Polish'] = listpol
                    df_050_059_AS_VS2_K ['Symmetry'] = listsym
                    df_050_059_AS_VS2_K ['Ratio'] = listrat
                    df_050_059_AS_VS2_K ['PPC'] = listdesc
                    df_050_059_AS_VS2_K ['Total'] = listtotal
                    df_050_059_AS_VS2_K['Carat'] = df_050_059_AS_VS2_K['Carat'].astype('float64')
                    df_050_059_AS_VS2_K['PPC'] = df_050_059_AS_VS2_K['PPC'].astype('float64')
                    df_050_059_AS_VS2_K['Total'] = df_050_059_AS_VS2_K['Total'].astype('float64')
                    df_050_059_AS_VS2_K['Total'] = df_050_059_AS_VS2_K['Carat'] * df_050_059_AS_VS2_K['PPC']


                elif i=="K" and j == "SI1" and k == "AS":
                    df_050_059_AS_SI1_K = pd.DataFrame()
                    df_050_059_AS_SI1_K ['Wt Range'] = None
                    df_050_059_AS_SI1_K  = df_050_059_AS_SI1_K.assign(Company=None)
                    df_050_059_AS_SI1_K  = df_050_059_AS_SI1_K.assign(Shape=None)
                    df_050_059_AS_SI1_K  = df_050_059_AS_SI1_K.assign(Carat=None)
                    df_050_059_AS_SI1_K  = df_050_059_AS_SI1_K.assign(Color=None)
                    df_050_059_AS_SI1_K  = df_050_059_AS_SI1_K.assign(Clarity=None)
                    df_050_059_AS_SI1_K  = df_050_059_AS_SI1_K.assign(Cut=None)
                    df_050_059_AS_SI1_K  = df_050_059_AS_SI1_K.assign(Polish=None)
                    df_050_059_AS_SI1_K  = df_050_059_AS_SI1_K.assign(Symmetry=None)
                    df_050_059_AS_SI1_K  = df_050_059_AS_SI1_K.assign(Ratio=None)
                    df_050_059_AS_SI1_K  = df_050_059_AS_SI1_K.assign(PPC=None)
                    df_050_059_AS_SI1_K  = df_050_059_AS_SI1_K.assign(Total=None)
                    df_050_059_AS_SI1_K ['Wt Range'] = listwtrange
                    df_050_059_AS_SI1_K ['Company'] = listcom
                    df_050_059_AS_SI1_K ['Shape'] = listshap
                    df_050_059_AS_SI1_K ['Carat'] = listcar
                    df_050_059_AS_SI1_K ['Color'] = listcol
                    df_050_059_AS_SI1_K ['Clarity'] = listclar
                    df_050_059_AS_SI1_K ['Cut'] = listcut
                    df_050_059_AS_SI1_K ['Polish'] = listpol
                    df_050_059_AS_SI1_K ['Symmetry'] = listsym
                    df_050_059_AS_SI1_K ['Ratio'] = listrat
                    df_050_059_AS_SI1_K ['PPC'] = listdesc
                    df_050_059_AS_SI1_K ['Total'] = listtotal
                    df_050_059_AS_SI1_K['Carat'] = df_050_059_AS_SI1_K['Carat'].astype('float64')
                    df_050_059_AS_SI1_K['PPC'] = df_050_059_AS_SI1_K['PPC'].astype('float64')
                    df_050_059_AS_SI1_K['Total'] = df_050_059_AS_SI1_K['Total'].astype('float64')
                    df_050_059_AS_SI1_K['Total'] = df_050_059_AS_SI1_K['Carat'] * df_050_059_AS_SI1_K['PPC']


                elif i=="K" and j == "SI2" and k == "AS":
                    df_050_059_AS_SI2_K = pd.DataFrame()
                    df_050_059_AS_SI2_K ['Wt Range'] = None
                    df_050_059_AS_SI2_K  = df_050_059_AS_SI2_K.assign(Company=None)
                    df_050_059_AS_SI2_K  = df_050_059_AS_SI2_K.assign(Shape=None)
                    df_050_059_AS_SI2_K  = df_050_059_AS_SI2_K.assign(Carat=None)
                    df_050_059_AS_SI2_K  = df_050_059_AS_SI2_K.assign(Color=None)
                    df_050_059_AS_SI2_K  = df_050_059_AS_SI2_K.assign(Clarity=None)
                    df_050_059_AS_SI2_K  = df_050_059_AS_SI2_K.assign(Cut=None)
                    df_050_059_AS_SI2_K  = df_050_059_AS_SI2_K.assign(Polish=None)
                    df_050_059_AS_SI2_K  = df_050_059_AS_SI2_K.assign(Symmetry=None)
                    df_050_059_AS_SI2_K  = df_050_059_AS_SI2_K.assign(Ratio=None)
                    df_050_059_AS_SI2_K  = df_050_059_AS_SI2_K.assign(PPC=None)
                    df_050_059_AS_SI2_K  = df_050_059_AS_SI2_K.assign(Total=None)
                    df_050_059_AS_SI2_K ['Wt Range'] = listwtrange
                    df_050_059_AS_SI2_K ['Company'] = listcom
                    df_050_059_AS_SI2_K ['Shape'] = listshap
                    df_050_059_AS_SI2_K ['Carat'] = listcar
                    df_050_059_AS_SI2_K ['Color'] = listcol
                    df_050_059_AS_SI2_K ['Clarity'] = listclar
                    df_050_059_AS_SI2_K ['Cut'] = listcut
                    df_050_059_AS_SI2_K ['Polish'] = listpol
                    df_050_059_AS_SI2_K ['Symmetry'] = listsym
                    df_050_059_AS_SI2_K ['Ratio'] = listrat
                    df_050_059_AS_SI2_K ['PPC'] = listdesc
                    df_050_059_AS_SI2_K ['Total'] = listtotal
                    df_050_059_AS_SI2_K['Carat'] = df_050_059_AS_SI2_K['Carat'].astype('float64')
                    df_050_059_AS_SI2_K['PPC'] = df_050_059_AS_SI2_K['PPC'].astype('float64')
                    df_050_059_AS_SI2_K['Total'] = df_050_059_AS_SI2_K['Total'].astype('float64')
                    df_050_059_AS_SI2_K['Total'] = df_050_059_AS_SI2_K['Carat'] * df_050_059_AS_SI2_K['PPC']


                elif i=="K" and j == "I1" and k == "AS":
                    df_050_059_AS_I1_K = pd.DataFrame()
                    df_050_059_AS_I1_K ['Wt Range'] = None
                    df_050_059_AS_I1_K  = df_050_059_AS_I1_K.assign(Company=None)
                    df_050_059_AS_I1_K  = df_050_059_AS_I1_K.assign(Shape=None)
                    df_050_059_AS_I1_K  = df_050_059_AS_I1_K.assign(Carat=None)
                    df_050_059_AS_I1_K  = df_050_059_AS_I1_K.assign(Color=None)
                    df_050_059_AS_I1_K  = df_050_059_AS_I1_K.assign(Clarity=None)
                    df_050_059_AS_I1_K  = df_050_059_AS_I1_K.assign(Cut=None)
                    df_050_059_AS_I1_K  = df_050_059_AS_I1_K.assign(Polish=None)
                    df_050_059_AS_I1_K  = df_050_059_AS_I1_K.assign(Symmetry=None)
                    df_050_059_AS_I1_K  = df_050_059_AS_I1_K.assign(Ratio=None)
                    df_050_059_AS_I1_K  = df_050_059_AS_I1_K.assign(PPC=None)
                    df_050_059_AS_I1_K  = df_050_059_AS_I1_K.assign(Total=None)
                    df_050_059_AS_I1_K ['Wt Range'] = listwtrange
                    df_050_059_AS_I1_K ['Company'] = listcom
                    df_050_059_AS_I1_K ['Shape'] = listshap
                    df_050_059_AS_I1_K ['Carat'] = listcar
                    df_050_059_AS_I1_K ['Color'] = listcol
                    df_050_059_AS_I1_K ['Clarity'] = listclar
                    df_050_059_AS_I1_K ['Cut'] = listcut
                    df_050_059_AS_I1_K ['Polish'] = listpol
                    df_050_059_AS_I1_K ['Symmetry'] = listsym
                    df_050_059_AS_I1_K ['Ratio'] = listrat
                    df_050_059_AS_I1_K ['PPC'] = listdesc
                    df_050_059_AS_I1_K ['Total'] = listtotal
                    df_050_059_AS_I1_K['Carat'] = df_050_059_AS_I1_K['Carat'].astype('float64')
                    df_050_059_AS_I1_K['PPC'] = df_050_059_AS_I1_K['PPC'].astype('float64')
                    df_050_059_AS_I1_K['Total'] = df_050_059_AS_I1_K['Total'].astype('float64')
                    df_050_059_AS_I1_K['Total'] = df_050_059_AS_I1_K['Carat'] * df_050_059_AS_I1_K['PPC']


                elif i=="K" and j == "I2" and k == "AS":
                    df_050_059_AS_I2_K = pd.DataFrame()
                    df_050_059_AS_I2_K ['Wt Range'] = None
                    df_050_059_AS_I2_K  = df_050_059_AS_I2_K.assign(Company=None)
                    df_050_059_AS_I2_K  = df_050_059_AS_I2_K.assign(Shape=None)
                    df_050_059_AS_I2_K  = df_050_059_AS_I2_K.assign(Carat=None)
                    df_050_059_AS_I2_K  = df_050_059_AS_I2_K.assign(Color=None)
                    df_050_059_AS_I2_K  = df_050_059_AS_I2_K.assign(Clarity=None)
                    df_050_059_AS_I2_K  = df_050_059_AS_I2_K.assign(Cut=None)
                    df_050_059_AS_I2_K  = df_050_059_AS_I2_K.assign(Polish=None)
                    df_050_059_AS_I2_K  = df_050_059_AS_I2_K.assign(Symmetry=None)
                    df_050_059_AS_I2_K  = df_050_059_AS_I2_K.assign(Ratio=None)
                    df_050_059_AS_I2_K  = df_050_059_AS_I2_K.assign(PPC=None)
                    df_050_059_AS_I2_K  = df_050_059_AS_I2_K.assign(Total=None)
                    df_050_059_AS_I2_K ['Wt Range'] = listwtrange
                    df_050_059_AS_I2_K ['Company'] = listcom
                    df_050_059_AS_I2_K ['Shape'] = listshap
                    df_050_059_AS_I2_K ['Carat'] = listcar
                    df_050_059_AS_I2_K ['Color'] = listcol
                    df_050_059_AS_I2_K ['Clarity'] = listclar
                    df_050_059_AS_I2_K ['Cut'] = listcut
                    df_050_059_AS_I2_K ['Polish'] = listpol
                    df_050_059_AS_I2_K ['Symmetry'] = listsym
                    df_050_059_AS_I2_K ['Ratio'] = listrat
                    df_050_059_AS_I2_K ['PPC'] = listdesc
                    df_050_059_AS_I2_K ['Total'] = listtotal
                    df_050_059_AS_I2_K['Carat'] = df_050_059_AS_I2_K['Carat'].astype('float64')
                    df_050_059_AS_I2_K['PPC'] = df_050_059_AS_I2_K['PPC'].astype('float64')
                    df_050_059_AS_I2_K['Total'] = df_050_059_AS_I2_K['Total'].astype('float64')
                    df_050_059_AS_I2_K['Total'] = df_050_059_AS_I2_K['Carat'] * df_050_059_AS_I2_K['PPC']


                elif i=="L" and j == "IF" and k == "AS":
                    df_050_059_AS_IF_L = pd.DataFrame()
                    df_050_059_AS_IF_L ['Wt Range'] = None
                    df_050_059_AS_IF_L  = df_050_059_AS_IF_L.assign(Company=None)
                    df_050_059_AS_IF_L  = df_050_059_AS_IF_L.assign(Shape=None)
                    df_050_059_AS_IF_L  = df_050_059_AS_IF_L.assign(Carat=None)
                    df_050_059_AS_IF_L  = df_050_059_AS_IF_L.assign(Color=None)
                    df_050_059_AS_IF_L  = df_050_059_AS_IF_L.assign(Clarity=None)
                    df_050_059_AS_IF_L  = df_050_059_AS_IF_L.assign(Cut=None)
                    df_050_059_AS_IF_L  = df_050_059_AS_IF_L.assign(Polish=None)
                    df_050_059_AS_IF_L  = df_050_059_AS_IF_L.assign(Symmetry=None)
                    df_050_059_AS_IF_L  = df_050_059_AS_IF_L.assign(Ratio=None)
                    df_050_059_AS_IF_L  = df_050_059_AS_IF_L.assign(PPC=None)
                    df_050_059_AS_IF_L  = df_050_059_AS_IF_L.assign(Total=None)
                    df_050_059_AS_IF_L ['Wt Range'] = listwtrange
                    df_050_059_AS_IF_L ['Company'] = listcom
                    df_050_059_AS_IF_L ['Shape'] = listshap
                    df_050_059_AS_IF_L ['Carat'] = listcar
                    df_050_059_AS_IF_L ['Color'] = listcol
                    df_050_059_AS_IF_L ['Clarity'] = listclar
                    df_050_059_AS_IF_L ['Cut'] = listcut
                    df_050_059_AS_IF_L ['Polish'] = listpol
                    df_050_059_AS_IF_L ['Symmetry'] = listsym
                    df_050_059_AS_IF_L ['Ratio'] = listrat
                    df_050_059_AS_IF_L ['PPC'] = listdesc
                    df_050_059_AS_IF_L ['Total'] = listtotal
                    df_050_059_AS_IF_L['Carat'] = df_050_059_AS_IF_L['Carat'].astype('float64')
                    df_050_059_AS_IF_L['PPC'] = df_050_059_AS_IF_L['PPC'].astype('float64')
                    df_050_059_AS_IF_L['Total'] = df_050_059_AS_IF_L['Total'].astype('float64')
                    df_050_059_AS_IF_L['Total'] = df_050_059_AS_IF_L['Carat'] * df_050_059_AS_IF_L['PPC']


                elif i=="L" and j == "VVS1" and k == "AS":
                    df_050_059_AS_VVS1_L = pd.DataFrame()
                    df_050_059_AS_VVS1_L ['Wt Range'] = None
                    df_050_059_AS_VVS1_L  = df_050_059_AS_VVS1_L.assign(Company=None)
                    df_050_059_AS_VVS1_L  = df_050_059_AS_VVS1_L.assign(Shape=None)
                    df_050_059_AS_VVS1_L  = df_050_059_AS_VVS1_L.assign(Carat=None)
                    df_050_059_AS_VVS1_L  = df_050_059_AS_VVS1_L.assign(Color=None)
                    df_050_059_AS_VVS1_L  = df_050_059_AS_VVS1_L.assign(Clarity=None)
                    df_050_059_AS_VVS1_L  = df_050_059_AS_VVS1_L.assign(Cut=None)
                    df_050_059_AS_VVS1_L  = df_050_059_AS_VVS1_L.assign(Polish=None)
                    df_050_059_AS_VVS1_L  = df_050_059_AS_VVS1_L.assign(Symmetry=None)
                    df_050_059_AS_VVS1_L  = df_050_059_AS_VVS1_L.assign(Ratio=None)
                    df_050_059_AS_VVS1_L  = df_050_059_AS_VVS1_L.assign(PPC=None)
                    df_050_059_AS_VVS1_L  = df_050_059_AS_VVS1_L.assign(Total=None)
                    df_050_059_AS_VVS1_L ['Wt Range'] = listwtrange
                    df_050_059_AS_VVS1_L ['Company'] = listcom
                    df_050_059_AS_VVS1_L ['Shape'] = listshap
                    df_050_059_AS_VVS1_L ['Carat'] = listcar
                    df_050_059_AS_VVS1_L ['Color'] = listcol
                    df_050_059_AS_VVS1_L ['Clarity'] = listclar
                    df_050_059_AS_VVS1_L ['Cut'] = listcut
                    df_050_059_AS_VVS1_L ['Polish'] = listpol
                    df_050_059_AS_VVS1_L ['Symmetry'] = listsym
                    df_050_059_AS_VVS1_L ['Ratio'] = listrat
                    df_050_059_AS_VVS1_L ['PPC'] = listdesc
                    df_050_059_AS_VVS1_L ['Total'] = listtotal
                    df_050_059_AS_VVS1_L['Carat'] = df_050_059_AS_VVS1_L['Carat'].astype('float64')
                    df_050_059_AS_VVS1_L['PPC'] = df_050_059_AS_VVS1_L['PPC'].astype('float64')
                    df_050_059_AS_VVS1_L['Total'] = df_050_059_AS_VVS1_L['Total'].astype('float64')
                    df_050_059_AS_VVS1_L['Total'] = df_050_059_AS_VVS1_L['Carat'] * df_050_059_AS_VVS1_L['PPC']


                elif i=="L" and j == "VVS2" and k == "AS":
                    df_050_059_AS_VVS2_L = pd.DataFrame()
                    df_050_059_AS_VVS2_L ['Wt Range'] = None
                    df_050_059_AS_VVS2_L  = df_050_059_AS_VVS2_L.assign(Company=None)
                    df_050_059_AS_VVS2_L  = df_050_059_AS_VVS2_L.assign(Shape=None)
                    df_050_059_AS_VVS2_L  = df_050_059_AS_VVS2_L.assign(Carat=None)
                    df_050_059_AS_VVS2_L  = df_050_059_AS_VVS2_L.assign(Color=None)
                    df_050_059_AS_VVS2_L  = df_050_059_AS_VVS2_L.assign(Clarity=None)
                    df_050_059_AS_VVS2_L  = df_050_059_AS_VVS2_L.assign(Cut=None)
                    df_050_059_AS_VVS2_L  = df_050_059_AS_VVS2_L.assign(Polish=None)
                    df_050_059_AS_VVS2_L  = df_050_059_AS_VVS2_L.assign(Symmetry=None)
                    df_050_059_AS_VVS2_L  = df_050_059_AS_VVS2_L.assign(Ratio=None)
                    df_050_059_AS_VVS2_L  = df_050_059_AS_VVS2_L.assign(PPC=None)
                    df_050_059_AS_VVS2_L  = df_050_059_AS_VVS2_L.assign(Total=None)
                    df_050_059_AS_VVS2_L ['Wt Range'] = listwtrange
                    df_050_059_AS_VVS2_L ['Company'] = listcom
                    df_050_059_AS_VVS2_L ['Shape'] = listshap
                    df_050_059_AS_VVS2_L ['Carat'] = listcar
                    df_050_059_AS_VVS2_L ['Color'] = listcol
                    df_050_059_AS_VVS2_L ['Clarity'] = listclar
                    df_050_059_AS_VVS2_L ['Cut'] = listcut
                    df_050_059_AS_VVS2_L ['Polish'] = listpol
                    df_050_059_AS_VVS2_L ['Symmetry'] = listsym
                    df_050_059_AS_VVS2_L ['Ratio'] = listrat
                    df_050_059_AS_VVS2_L ['PPC'] = listdesc
                    df_050_059_AS_VVS2_L ['Total'] = listtotal
                    df_050_059_AS_VVS2_L['Carat'] = df_050_059_AS_VVS2_L['Carat'].astype('float64')
                    df_050_059_AS_VVS2_L['PPC'] = df_050_059_AS_VVS2_L['PPC'].astype('float64')
                    df_050_059_AS_VVS2_L['Total'] = df_050_059_AS_VVS2_L['Total'].astype('float64')
                    df_050_059_AS_VVS2_L['Total'] = df_050_059_AS_VVS2_L['Carat'] * df_050_059_AS_VVS2_L['PPC']


                elif i=="L" and j=="VS1" and k == "AS":
                    df_050_059_AS_VS1_L = pd.DataFrame()
                    df_050_059_AS_VS1_L ['Wt Range'] = None
                    df_050_059_AS_VS1_L  = df_050_059_AS_VS1_L.assign(Company=None)
                    df_050_059_AS_VS1_L  = df_050_059_AS_VS1_L.assign(Shape=None)
                    df_050_059_AS_VS1_L  = df_050_059_AS_VS1_L.assign(Carat=None)
                    df_050_059_AS_VS1_L  = df_050_059_AS_VS1_L.assign(Color=None)
                    df_050_059_AS_VS1_L  = df_050_059_AS_VS1_L.assign(Clarity=None)
                    df_050_059_AS_VS1_L  = df_050_059_AS_VS1_L.assign(Cut=None)
                    df_050_059_AS_VS1_L  = df_050_059_AS_VS1_L.assign(Polish=None)
                    df_050_059_AS_VS1_L  = df_050_059_AS_VS1_L.assign(Symmetry=None)
                    df_050_059_AS_VS1_L  = df_050_059_AS_VS1_L.assign(Ratio=None)
                    df_050_059_AS_VS1_L  = df_050_059_AS_VS1_L.assign(PPC=None)
                    df_050_059_AS_VS1_L  = df_050_059_AS_VS1_L.assign(Total=None)
                    df_050_059_AS_VS1_L ['Wt Range'] = listwtrange
                    df_050_059_AS_VS1_L ['Company'] = listcom
                    df_050_059_AS_VS1_L ['Shape'] = listshap
                    df_050_059_AS_VS1_L ['Carat'] = listcar
                    df_050_059_AS_VS1_L ['Color'] = listcol
                    df_050_059_AS_VS1_L ['Clarity'] = listclar
                    df_050_059_AS_VS1_L ['Cut'] = listcut
                    df_050_059_AS_VS1_L ['Polish'] = listpol
                    df_050_059_AS_VS1_L ['Symmetry'] = listsym
                    df_050_059_AS_VS1_L ['Ratio'] = listrat
                    df_050_059_AS_VS1_L ['PPC'] = listdesc
                    df_050_059_AS_VS1_L ['Total'] = listtotal
                    df_050_059_AS_VS1_L['Carat'] = df_050_059_AS_VS1_L['Carat'].astype('float64')
                    df_050_059_AS_VS1_L['PPC'] = df_050_059_AS_VS1_L['PPC'].astype('float64')
                    df_050_059_AS_VS1_L['Total'] = df_050_059_AS_VS1_L['Total'].astype('float64')
                    df_050_059_AS_VS1_L['Total'] = df_050_059_AS_VS1_L['Carat'] * df_050_059_AS_VS1_L['PPC']


                elif i=="L" and j == "VS2" and k == "AS":
                    df_050_059_AS_VS2_L = pd.DataFrame()
                    df_050_059_AS_VS2_L ['Wt Range'] = None
                    df_050_059_AS_VS2_L  = df_050_059_AS_VS2_L.assign(Company=None)
                    df_050_059_AS_VS2_L  = df_050_059_AS_VS2_L.assign(Shape=None)
                    df_050_059_AS_VS2_L  = df_050_059_AS_VS2_L.assign(Carat=None)
                    df_050_059_AS_VS2_L  = df_050_059_AS_VS2_L.assign(Color=None)
                    df_050_059_AS_VS2_L  = df_050_059_AS_VS2_L.assign(Clarity=None)
                    df_050_059_AS_VS2_L  = df_050_059_AS_VS2_L.assign(Cut=None)
                    df_050_059_AS_VS2_L  = df_050_059_AS_VS2_L.assign(Polish=None)
                    df_050_059_AS_VS2_L  = df_050_059_AS_VS2_L.assign(Symmetry=None)
                    df_050_059_AS_VS2_L  = df_050_059_AS_VS2_L.assign(Ratio=None)
                    df_050_059_AS_VS2_L  = df_050_059_AS_VS2_L.assign(PPC=None)
                    df_050_059_AS_VS2_L  = df_050_059_AS_VS2_L.assign(Total=None)
                    df_050_059_AS_VS2_L ['Wt Range'] = listwtrange
                    df_050_059_AS_VS2_L ['Company'] = listcom
                    df_050_059_AS_VS2_L ['Shape'] = listshap
                    df_050_059_AS_VS2_L ['Carat'] = listcar
                    df_050_059_AS_VS2_L ['Color'] = listcol
                    df_050_059_AS_VS2_L ['Clarity'] = listclar
                    df_050_059_AS_VS2_L ['Cut'] = listcut
                    df_050_059_AS_VS2_L ['Polish'] = listpol
                    df_050_059_AS_VS2_L ['Symmetry'] = listsym
                    df_050_059_AS_VS2_L ['Ratio'] = listrat
                    df_050_059_AS_VS2_L ['PPC'] = listdesc
                    df_050_059_AS_VS2_L ['Total'] = listtotal
                    df_050_059_AS_VS2_L['Carat'] = df_050_059_AS_VS2_L['Carat'].astype('float64')
                    df_050_059_AS_VS2_L['PPC'] = df_050_059_AS_VS2_L['PPC'].astype('float64')
                    df_050_059_AS_VS2_L['Total'] = df_050_059_AS_VS2_L['Total'].astype('float64')
                    df_050_059_AS_VS2_L['Total'] = df_050_059_AS_VS2_L['Carat'] * df_050_059_AS_VS2_L['PPC']


                elif i=="L" and j == "SI1" and k == "AS":
                    df_050_059_AS_SI1_L = pd.DataFrame()
                    df_050_059_AS_SI1_L ['Wt Range'] = None
                    df_050_059_AS_SI1_L  = df_050_059_AS_SI1_L.assign(Company=None)
                    df_050_059_AS_SI1_L  = df_050_059_AS_SI1_L.assign(Shape=None)
                    df_050_059_AS_SI1_L  = df_050_059_AS_SI1_L.assign(Carat=None)
                    df_050_059_AS_SI1_L  = df_050_059_AS_SI1_L.assign(Color=None)
                    df_050_059_AS_SI1_L  = df_050_059_AS_SI1_L.assign(Clarity=None)
                    df_050_059_AS_SI1_L  = df_050_059_AS_SI1_L.assign(Cut=None)
                    df_050_059_AS_SI1_L  = df_050_059_AS_SI1_L.assign(Polish=None)
                    df_050_059_AS_SI1_L  = df_050_059_AS_SI1_L.assign(Symmetry=None)
                    df_050_059_AS_SI1_L  = df_050_059_AS_SI1_L.assign(Ratio=None)
                    df_050_059_AS_SI1_L  = df_050_059_AS_SI1_L.assign(PPC=None)
                    df_050_059_AS_SI1_L  = df_050_059_AS_SI1_L.assign(Total=None)
                    df_050_059_AS_SI1_L ['Wt Range'] = listwtrange
                    df_050_059_AS_SI1_L ['Company'] = listcom
                    df_050_059_AS_SI1_L ['Shape'] = listshap
                    df_050_059_AS_SI1_L ['Carat'] = listcar
                    df_050_059_AS_SI1_L ['Color'] = listcol
                    df_050_059_AS_SI1_L ['Clarity'] = listclar
                    df_050_059_AS_SI1_L ['Cut'] = listcut
                    df_050_059_AS_SI1_L ['Polish'] = listpol
                    df_050_059_AS_SI1_L ['Symmetry'] = listsym
                    df_050_059_AS_SI1_L ['Ratio'] = listrat
                    df_050_059_AS_SI1_L ['PPC'] = listdesc
                    df_050_059_AS_SI1_L ['Total'] = listtotal
                    df_050_059_AS_SI1_L['Carat'] = df_050_059_AS_SI1_L['Carat'].astype('float64')
                    df_050_059_AS_SI1_L['PPC'] = df_050_059_AS_SI1_L['PPC'].astype('float64')
                    df_050_059_AS_SI1_L['Total'] = df_050_059_AS_SI1_L['Total'].astype('float64')
                    df_050_059_AS_SI1_L['Total'] = df_050_059_AS_SI1_L['Carat'] * df_050_059_AS_SI1_L['PPC']


                elif i=="L" and j == "SI2" and k == "AS":
                    df_050_059_AS_SI2_L = pd.DataFrame()
                    df_050_059_AS_SI2_L ['Wt Range'] = None
                    df_050_059_AS_SI2_L  = df_050_059_AS_SI2_L.assign(Company=None)
                    df_050_059_AS_SI2_L  = df_050_059_AS_SI2_L.assign(Shape=None)
                    df_050_059_AS_SI2_L  = df_050_059_AS_SI2_L.assign(Carat=None)
                    df_050_059_AS_SI2_L  = df_050_059_AS_SI2_L.assign(Color=None)
                    df_050_059_AS_SI2_L  = df_050_059_AS_SI2_L.assign(Clarity=None)
                    df_050_059_AS_SI2_L  = df_050_059_AS_SI2_L.assign(Cut=None)
                    df_050_059_AS_SI2_L  = df_050_059_AS_SI2_L.assign(Polish=None)
                    df_050_059_AS_SI2_L  = df_050_059_AS_SI2_L.assign(Symmetry=None)
                    df_050_059_AS_SI2_L  = df_050_059_AS_SI2_L.assign(Ratio=None)
                    df_050_059_AS_SI2_L  = df_050_059_AS_SI2_L.assign(PPC=None)
                    df_050_059_AS_SI2_L  = df_050_059_AS_SI2_L.assign(Total=None)
                    df_050_059_AS_SI2_L ['Wt Range'] = listwtrange
                    df_050_059_AS_SI2_L ['Company'] = listcom
                    df_050_059_AS_SI2_L ['Shape'] = listshap
                    df_050_059_AS_SI2_L ['Carat'] = listcar
                    df_050_059_AS_SI2_L ['Color'] = listcol
                    df_050_059_AS_SI2_L ['Clarity'] = listclar
                    df_050_059_AS_SI2_L ['Cut'] = listcut
                    df_050_059_AS_SI2_L ['Polish'] = listpol
                    df_050_059_AS_SI2_L ['Symmetry'] = listsym
                    df_050_059_AS_SI2_L ['Ratio'] = listrat
                    df_050_059_AS_SI2_L ['PPC'] = listdesc
                    df_050_059_AS_SI2_L ['Total'] = listtotal
                    df_050_059_AS_SI2_L['Carat'] = df_050_059_AS_SI2_L['Carat'].astype('float64')
                    df_050_059_AS_SI2_L['PPC'] = df_050_059_AS_SI2_L['PPC'].astype('float64')
                    df_050_059_AS_SI2_L['Total'] = df_050_059_AS_SI2_L['Total'].astype('float64')
                    df_050_059_AS_SI2_L['Total'] = df_050_059_AS_SI2_L['Carat'] * df_050_059_AS_SI2_L['PPC']


                elif i=="L" and j == "I1" and k == "AS":
                    df_050_059_AS_I1_L = pd.DataFrame()
                    df_050_059_AS_I1_L ['Wt Range'] = None
                    df_050_059_AS_I1_L  = df_050_059_AS_I1_L.assign(Company=None)
                    df_050_059_AS_I1_L  = df_050_059_AS_I1_L.assign(Shape=None)
                    df_050_059_AS_I1_L  = df_050_059_AS_I1_L.assign(Carat=None)
                    df_050_059_AS_I1_L  = df_050_059_AS_I1_L.assign(Color=None)
                    df_050_059_AS_I1_L  = df_050_059_AS_I1_L.assign(Clarity=None)
                    df_050_059_AS_I1_L  = df_050_059_AS_I1_L.assign(Cut=None)
                    df_050_059_AS_I1_L  = df_050_059_AS_I1_L.assign(Polish=None)
                    df_050_059_AS_I1_L  = df_050_059_AS_I1_L.assign(Symmetry=None)
                    df_050_059_AS_I1_L  = df_050_059_AS_I1_L.assign(Ratio=None)
                    df_050_059_AS_I1_L  = df_050_059_AS_I1_L.assign(PPC=None)
                    df_050_059_AS_I1_L  = df_050_059_AS_I1_L.assign(Total=None)
                    df_050_059_AS_I1_L ['Wt Range'] = listwtrange
                    df_050_059_AS_I1_L ['Company'] = listcom
                    df_050_059_AS_I1_L ['Shape'] = listshap
                    df_050_059_AS_I1_L ['Carat'] = listcar
                    df_050_059_AS_I1_L ['Color'] = listcol
                    df_050_059_AS_I1_L ['Clarity'] = listclar
                    df_050_059_AS_I1_L ['Cut'] = listcut
                    df_050_059_AS_I1_L ['Polish'] = listpol
                    df_050_059_AS_I1_L ['Symmetry'] = listsym
                    df_050_059_AS_I1_L ['Ratio'] = listrat
                    df_050_059_AS_I1_L ['PPC'] = listdesc
                    df_050_059_AS_I1_L ['Total'] = listtotal
                    df_050_059_AS_I1_L['Carat'] = df_050_059_AS_I1_L['Carat'].astype('float64')
                    df_050_059_AS_I1_L['PPC'] = df_050_059_AS_I1_L['PPC'].astype('float64')
                    df_050_059_AS_I1_L['Total'] = df_050_059_AS_I1_L['Total'].astype('float64')
                    df_050_059_AS_I1_L['Total'] = df_050_059_AS_I1_L['Carat'] * df_050_059_AS_I1_L['PPC']


                elif i=="L" and j == "I2" and k == "AS":
                    df_050_059_AS_I2_L = pd.DataFrame()
                    df_050_059_AS_I2_L ['Wt Range'] = None
                    df_050_059_AS_I2_L  = df_050_059_AS_I2_L.assign(Company=None)
                    df_050_059_AS_I2_L  = df_050_059_AS_I2_L.assign(Shape=None)
                    df_050_059_AS_I2_L  = df_050_059_AS_I2_L.assign(Carat=None)
                    df_050_059_AS_I2_L  = df_050_059_AS_I2_L.assign(Color=None)
                    df_050_059_AS_I2_L  = df_050_059_AS_I2_L.assign(Clarity=None)
                    df_050_059_AS_I2_L  = df_050_059_AS_I2_L.assign(Cut=None)
                    df_050_059_AS_I2_L  = df_050_059_AS_I2_L.assign(Polish=None)
                    df_050_059_AS_I2_L  = df_050_059_AS_I2_L.assign(Symmetry=None)
                    df_050_059_AS_I2_L  = df_050_059_AS_I2_L.assign(Ratio=None)
                    df_050_059_AS_I2_L  = df_050_059_AS_I2_L.assign(PPC=None)
                    df_050_059_AS_I2_L  = df_050_059_AS_I2_L.assign(Total=None)
                    df_050_059_AS_I2_L ['Wt Range'] = listwtrange
                    df_050_059_AS_I2_L ['Company'] = listcom
                    df_050_059_AS_I2_L ['Shape'] = listshap
                    df_050_059_AS_I2_L ['Carat'] = listcar
                    df_050_059_AS_I2_L ['Color'] = listcol
                    df_050_059_AS_I2_L ['Clarity'] = listclar
                    df_050_059_AS_I2_L ['Cut'] = listcut
                    df_050_059_AS_I2_L ['Polish'] = listpol
                    df_050_059_AS_I2_L ['Symmetry'] = listsym
                    df_050_059_AS_I2_L ['Ratio'] = listrat
                    df_050_059_AS_I2_L ['PPC'] = listdesc
                    df_050_059_AS_I2_L ['Total'] = listtotal
                    df_050_059_AS_I2_L['Carat'] = df_050_059_AS_I2_L['Carat'].astype('float64')
                    df_050_059_AS_I2_L['PPC'] = df_050_059_AS_I2_L['PPC'].astype('float64')
                    df_050_059_AS_I2_L['Total'] = df_050_059_AS_I2_L['Total'].astype('float64')
                    df_050_059_AS_I2_L['Total'] = df_050_059_AS_I2_L['Carat'] * df_050_059_AS_I2_L['PPC']



                elif i=="D" and j == "IF" and k == "HS":
                    df_050_059_HS_IF_D = pd.DataFrame()
                    df_050_059_HS_IF_D ['Wt Range'] = None
                    df_050_059_HS_IF_D  = df_050_059_HS_IF_D.assign(Company=None)
                    df_050_059_HS_IF_D  = df_050_059_HS_IF_D.assign(Shape=None)
                    df_050_059_HS_IF_D  = df_050_059_HS_IF_D.assign(Carat=None)
                    df_050_059_HS_IF_D  = df_050_059_HS_IF_D.assign(Color=None)
                    df_050_059_HS_IF_D  = df_050_059_HS_IF_D.assign(Clarity=None)
                    df_050_059_HS_IF_D  = df_050_059_HS_IF_D.assign(Cut=None)
                    df_050_059_HS_IF_D  = df_050_059_HS_IF_D.assign(Polish=None)
                    df_050_059_HS_IF_D  = df_050_059_HS_IF_D.assign(Symmetry=None)
                    df_050_059_HS_IF_D  = df_050_059_HS_IF_D.assign(Ratio=None)
                    df_050_059_HS_IF_D  = df_050_059_HS_IF_D.assign(PPC=None)
                    df_050_059_HS_IF_D  = df_050_059_HS_IF_D.assign(Total=None)
                    df_050_059_HS_IF_D ['Wt Range'] = listwtrange
                    df_050_059_HS_IF_D ['Company'] = listcom
                    df_050_059_HS_IF_D ['Shape'] = listshap
                    df_050_059_HS_IF_D ['Carat'] = listcar
                    df_050_059_HS_IF_D ['Color'] = listcol
                    df_050_059_HS_IF_D ['Clarity'] = listclar
                    df_050_059_HS_IF_D ['Cut'] = listcut
                    df_050_059_HS_IF_D ['Polish'] = listpol
                    df_050_059_HS_IF_D ['Symmetry'] = listsym
                    df_050_059_HS_IF_D ['Ratio'] = listrat
                    df_050_059_HS_IF_D ['PPC'] = listdesc
                    df_050_059_HS_IF_D ['Total'] = listtotal
                    df_050_059_HS_IF_D['Carat'] = df_050_059_HS_IF_D['Carat'].astype('float64')
                    df_050_059_HS_IF_D['PPC'] = df_050_059_HS_IF_D['PPC'].astype('float64')
                    df_050_059_HS_IF_D['Total'] = df_050_059_HS_IF_D['Total'].astype('float64')
                    df_050_059_HS_IF_D['Total'] = df_050_059_HS_IF_D['Carat'] * df_050_059_HS_IF_D['PPC']



                elif i=="D" and j == "VVS1" and k == "HS" :
                    df_050_059_HS_VVS1_D = pd.DataFrame()
                    df_050_059_HS_VVS1_D ['Wt Range'] = None
                    df_050_059_HS_VVS1_D  = df_050_059_HS_VVS1_D.assign(Company=None)
                    df_050_059_HS_VVS1_D  = df_050_059_HS_VVS1_D.assign(Shape=None)
                    df_050_059_HS_VVS1_D  = df_050_059_HS_VVS1_D.assign(Carat=None)
                    df_050_059_HS_VVS1_D  = df_050_059_HS_VVS1_D.assign(Color=None)
                    df_050_059_HS_VVS1_D  = df_050_059_HS_VVS1_D.assign(Clarity=None)
                    df_050_059_HS_VVS1_D  = df_050_059_HS_VVS1_D.assign(Cut=None)
                    df_050_059_HS_VVS1_D  = df_050_059_HS_VVS1_D.assign(Polish=None)
                    df_050_059_HS_VVS1_D  = df_050_059_HS_VVS1_D.assign(Symmetry=None)
                    df_050_059_HS_VVS1_D  = df_050_059_HS_VVS1_D.assign(Ratio=None)
                    df_050_059_HS_VVS1_D  = df_050_059_HS_VVS1_D.assign(PPC=None)
                    df_050_059_HS_VVS1_D  = df_050_059_HS_VVS1_D.assign(Total=None)
                    df_050_059_HS_VVS1_D ['Wt Range'] = listwtrange
                    df_050_059_HS_VVS1_D ['Company'] = listcom
                    df_050_059_HS_VVS1_D ['Shape'] = listshap
                    df_050_059_HS_VVS1_D ['Carat'] = listcar
                    df_050_059_HS_VVS1_D ['Color'] = listcol
                    df_050_059_HS_VVS1_D ['Clarity'] = listclar
                    df_050_059_HS_VVS1_D ['Cut'] = listcut
                    df_050_059_HS_VVS1_D ['Polish'] = listpol
                    df_050_059_HS_VVS1_D ['Symmetry'] = listsym
                    df_050_059_HS_VVS1_D ['Ratio'] = listrat
                    df_050_059_HS_VVS1_D ['PPC'] = listdesc
                    df_050_059_HS_VVS1_D ['Total'] = listtotal
                    df_050_059_HS_VVS1_D['Carat'] = df_050_059_HS_VVS1_D['Carat'].astype('float64')
                    df_050_059_HS_VVS1_D['PPC'] = df_050_059_HS_VVS1_D['PPC'].astype('float64')
                    df_050_059_HS_VVS1_D['Total'] = df_050_059_HS_VVS1_D['Total'].astype('float64')
                    df_050_059_HS_VVS1_D['Total'] = df_050_059_HS_VVS1_D['Carat'] * df_050_059_HS_VVS1_D['PPC']



                elif i=="D" and j == "VVS2" and k == "HS" :
                    df_050_059_HS_VVS2_D = pd.DataFrame()
                    df_050_059_HS_VVS2_D ['Wt Range'] = None
                    df_050_059_HS_VVS2_D  = df_050_059_HS_VVS2_D.assign(Company=None)
                    df_050_059_HS_VVS2_D  = df_050_059_HS_VVS2_D.assign(Shape=None)
                    df_050_059_HS_VVS2_D  = df_050_059_HS_VVS2_D.assign(Carat=None)
                    df_050_059_HS_VVS2_D  = df_050_059_HS_VVS2_D.assign(Color=None)
                    df_050_059_HS_VVS2_D  = df_050_059_HS_VVS2_D.assign(Clarity=None)
                    df_050_059_HS_VVS2_D  = df_050_059_HS_VVS2_D.assign(Cut=None)
                    df_050_059_HS_VVS2_D  = df_050_059_HS_VVS2_D.assign(Polish=None)
                    df_050_059_HS_VVS2_D  = df_050_059_HS_VVS2_D.assign(Symmetry=None)
                    df_050_059_HS_VVS2_D  = df_050_059_HS_VVS2_D.assign(Ratio=None)
                    df_050_059_HS_VVS2_D  = df_050_059_HS_VVS2_D.assign(PPC=None)
                    df_050_059_HS_VVS2_D  = df_050_059_HS_VVS2_D.assign(Total=None)
                    df_050_059_HS_VVS2_D ['Wt Range'] = listwtrange
                    df_050_059_HS_VVS2_D ['Company'] = listcom
                    df_050_059_HS_VVS2_D ['Shape'] = listshap
                    df_050_059_HS_VVS2_D ['Carat'] = listcar
                    df_050_059_HS_VVS2_D ['Color'] = listcol
                    df_050_059_HS_VVS2_D ['Clarity'] = listclar
                    df_050_059_HS_VVS2_D ['Cut'] = listcut
                    df_050_059_HS_VVS2_D ['Polish'] = listpol
                    df_050_059_HS_VVS2_D ['Symmetry'] = listsym
                    df_050_059_HS_VVS2_D ['Ratio'] = listrat
                    df_050_059_HS_VVS2_D ['PPC'] = listdesc
                    df_050_059_HS_VVS2_D ['Total'] = listtotal
                    df_050_059_HS_VVS2_D['Carat'] = df_050_059_HS_VVS2_D['Carat'].astype('float64')
                    df_050_059_HS_VVS2_D['PPC'] = df_050_059_HS_VVS2_D['PPC'].astype('float64')
                    df_050_059_HS_VVS2_D['Total'] = df_050_059_HS_VVS2_D['Total'].astype('float64')
                    df_050_059_HS_VVS2_D['Total'] = df_050_059_HS_VVS2_D['Carat'] * df_050_059_HS_VVS2_D['PPC']



                elif i=="D" and j == "VS1" and k == "HS":
                    df_050_059_HS_VS1_D = pd.DataFrame()
                    df_050_059_HS_VS1_D ['Wt Range'] = None
                    df_050_059_HS_VS1_D  = df_050_059_HS_VS1_D.assign(Company=None)
                    df_050_059_HS_VS1_D  = df_050_059_HS_VS1_D.assign(Shape=None)
                    df_050_059_HS_VS1_D  = df_050_059_HS_VS1_D.assign(Carat=None)
                    df_050_059_HS_VS1_D  = df_050_059_HS_VS1_D.assign(Color=None)
                    df_050_059_HS_VS1_D  = df_050_059_HS_VS1_D.assign(Clarity=None)
                    df_050_059_HS_VS1_D  = df_050_059_HS_VS1_D.assign(Cut=None)
                    df_050_059_HS_VS1_D  = df_050_059_HS_VS1_D.assign(Polish=None)
                    df_050_059_HS_VS1_D  = df_050_059_HS_VS1_D.assign(Symmetry=None)
                    df_050_059_HS_VS1_D  = df_050_059_HS_VS1_D.assign(Ratio=None)
                    df_050_059_HS_VS1_D  = df_050_059_HS_VS1_D.assign(PPC=None)
                    df_050_059_HS_VS1_D  = df_050_059_HS_VS1_D.assign(Total=None)
                    df_050_059_HS_VS1_D ['Wt Range'] = listwtrange
                    df_050_059_HS_VS1_D ['Company'] = listcom
                    df_050_059_HS_VS1_D ['Shape'] = listshap
                    df_050_059_HS_VS1_D ['Carat'] = listcar
                    df_050_059_HS_VS1_D ['Color'] = listcol
                    df_050_059_HS_VS1_D ['Clarity'] = listclar
                    df_050_059_HS_VS1_D ['Cut'] = listcut
                    df_050_059_HS_VS1_D ['Polish'] = listpol
                    df_050_059_HS_VS1_D ['Symmetry'] = listsym
                    df_050_059_HS_VS1_D ['Ratio'] = listrat
                    df_050_059_HS_VS1_D ['PPC'] = listdesc
                    df_050_059_HS_VS1_D ['Total'] = listtotal
                    df_050_059_HS_VS1_D['Carat'] = df_050_059_HS_VS1_D['Carat'].astype('float64')
                    df_050_059_HS_VS1_D['PPC'] = df_050_059_HS_VS1_D['PPC'].astype('float64')
                    df_050_059_HS_VS1_D['Total'] = df_050_059_HS_VS1_D['Total'].astype('float64')
                    df_050_059_HS_VS1_D['Total'] = df_050_059_HS_VS1_D['Carat'] * df_050_059_HS_VS1_D['PPC']


                elif i=="D" and j == "VS2" and k == "HS":
                    df_050_059_HS_VS2_D = pd.DataFrame()
                    df_050_059_HS_VS2_D ['Wt Range'] = None
                    df_050_059_HS_VS2_D  = df_050_059_HS_VS2_D.assign(Company=None)
                    df_050_059_HS_VS2_D  = df_050_059_HS_VS2_D.assign(Shape=None)
                    df_050_059_HS_VS2_D  = df_050_059_HS_VS2_D.assign(Carat=None)
                    df_050_059_HS_VS2_D  = df_050_059_HS_VS2_D.assign(Color=None)
                    df_050_059_HS_VS2_D  = df_050_059_HS_VS2_D.assign(Clarity=None)
                    df_050_059_HS_VS2_D  = df_050_059_HS_VS2_D.assign(Cut=None)
                    df_050_059_HS_VS2_D  = df_050_059_HS_VS2_D.assign(Polish=None)
                    df_050_059_HS_VS2_D  = df_050_059_HS_VS2_D.assign(Symmetry=None)
                    df_050_059_HS_VS2_D  = df_050_059_HS_VS2_D.assign(Ratio=None)
                    df_050_059_HS_VS2_D  = df_050_059_HS_VS2_D.assign(PPC=None)
                    df_050_059_HS_VS2_D  = df_050_059_HS_VS2_D.assign(Total=None)
                    df_050_059_HS_VS2_D ['Wt Range'] = listwtrange
                    df_050_059_HS_VS2_D ['Company'] = listcom
                    df_050_059_HS_VS2_D ['Shape'] = listshap
                    df_050_059_HS_VS2_D ['Carat'] = listcar
                    df_050_059_HS_VS2_D ['Color'] = listcol
                    df_050_059_HS_VS2_D ['Clarity'] = listclar
                    df_050_059_HS_VS2_D ['Cut'] = listcut
                    df_050_059_HS_VS2_D ['Polish'] = listpol
                    df_050_059_HS_VS2_D ['Symmetry'] = listsym
                    df_050_059_HS_VS2_D ['Ratio'] = listrat
                    df_050_059_HS_VS2_D ['PPC'] = listdesc
                    df_050_059_HS_VS2_D ['Total'] = listtotal
                    df_050_059_HS_VS2_D['Carat'] = df_050_059_HS_VS2_D['Carat'].astype('float64')
                    df_050_059_HS_VS2_D['PPC'] = df_050_059_HS_VS2_D['PPC'].astype('float64')
                    df_050_059_HS_VS2_D['Total'] = df_050_059_HS_VS2_D['Total'].astype('float64')
                    df_050_059_HS_VS2_D['Total'] = df_050_059_HS_VS2_D['Carat'] * df_050_059_HS_VS2_D['PPC']


                elif i=="D" and j == "SI1" and k == "HS":
                    df_050_059_HS_SI1_D = pd.DataFrame()
                    df_050_059_HS_SI1_D ['Wt Range'] = None
                    df_050_059_HS_SI1_D  = df_050_059_HS_SI1_D.assign(Company=None)
                    df_050_059_HS_SI1_D  = df_050_059_HS_SI1_D.assign(Shape=None)
                    df_050_059_HS_SI1_D  = df_050_059_HS_SI1_D.assign(Carat=None)
                    df_050_059_HS_SI1_D  = df_050_059_HS_SI1_D.assign(Color=None)
                    df_050_059_HS_SI1_D  = df_050_059_HS_SI1_D.assign(Clarity=None)
                    df_050_059_HS_SI1_D  = df_050_059_HS_SI1_D.assign(Cut=None)
                    df_050_059_HS_SI1_D  = df_050_059_HS_SI1_D.assign(Polish=None)
                    df_050_059_HS_SI1_D  = df_050_059_HS_SI1_D.assign(Symmetry=None)
                    df_050_059_HS_SI1_D  = df_050_059_HS_SI1_D.assign(Ratio=None)
                    df_050_059_HS_SI1_D  = df_050_059_HS_SI1_D.assign(PPC=None)
                    df_050_059_HS_SI1_D  = df_050_059_HS_SI1_D.assign(Total=None)
                    df_050_059_HS_SI1_D ['Wt Range'] = listwtrange
                    df_050_059_HS_SI1_D ['Company'] = listcom
                    df_050_059_HS_SI1_D ['Shape'] = listshap
                    df_050_059_HS_SI1_D ['Carat'] = listcar
                    df_050_059_HS_SI1_D ['Color'] = listcol
                    df_050_059_HS_SI1_D ['Clarity'] = listclar
                    df_050_059_HS_SI1_D ['Cut'] = listcut
                    df_050_059_HS_SI1_D ['Polish'] = listpol
                    df_050_059_HS_SI1_D ['Symmetry'] = listsym
                    df_050_059_HS_SI1_D ['Ratio'] = listrat
                    df_050_059_HS_SI1_D ['PPC'] = listdesc
                    df_050_059_HS_SI1_D ['Total'] = listtotal
                    df_050_059_HS_SI1_D['Carat'] = df_050_059_HS_SI1_D['Carat'].astype('float64')
                    df_050_059_HS_SI1_D['PPC'] = df_050_059_HS_SI1_D['PPC'].astype('float64')
                    df_050_059_HS_SI1_D['Total'] = df_050_059_HS_SI1_D['Total'].astype('float64')
                    df_050_059_HS_SI1_D['Total'] = df_050_059_HS_SI1_D['Carat'] * df_050_059_HS_SI1_D['PPC']


                elif i=="D" and j == "SI2" and k == "HS":
                    df_050_059_HS_SI2_D = pd.DataFrame()
                    df_050_059_HS_SI2_D ['Wt Range'] = None
                    df_050_059_HS_SI2_D  = df_050_059_HS_SI2_D.assign(Company=None)
                    df_050_059_HS_SI2_D  = df_050_059_HS_SI2_D.assign(Shape=None)
                    df_050_059_HS_SI2_D  = df_050_059_HS_SI2_D.assign(Carat=None)
                    df_050_059_HS_SI2_D  = df_050_059_HS_SI2_D.assign(Color=None)
                    df_050_059_HS_SI2_D  = df_050_059_HS_SI2_D.assign(Clarity=None)
                    df_050_059_HS_SI2_D  = df_050_059_HS_SI2_D.assign(Cut=None)
                    df_050_059_HS_SI2_D  = df_050_059_HS_SI2_D.assign(Polish=None)
                    df_050_059_HS_SI2_D  = df_050_059_HS_SI2_D.assign(Symmetry=None)
                    df_050_059_HS_SI2_D  = df_050_059_HS_SI2_D.assign(Ratio=None)
                    df_050_059_HS_SI2_D  = df_050_059_HS_SI2_D.assign(PPC=None)
                    df_050_059_HS_SI2_D  = df_050_059_HS_SI2_D.assign(Total=None)
                    df_050_059_HS_SI2_D ['Wt Range'] = listwtrange
                    df_050_059_HS_SI2_D ['Company'] = listcom
                    df_050_059_HS_SI2_D ['Shape'] = listshap
                    df_050_059_HS_SI2_D ['Carat'] = listcar
                    df_050_059_HS_SI2_D ['Color'] = listcol
                    df_050_059_HS_SI2_D ['Clarity'] = listclar
                    df_050_059_HS_SI2_D ['Cut'] = listcut
                    df_050_059_HS_SI2_D ['Polish'] = listpol
                    df_050_059_HS_SI2_D ['Symmetry'] = listsym
                    df_050_059_HS_SI2_D ['Ratio'] = listrat
                    df_050_059_HS_SI2_D ['PPC'] = listdesc
                    df_050_059_HS_SI2_D ['Total'] = listtotal
                    df_050_059_HS_SI2_D['Carat'] = df_050_059_HS_SI2_D['Carat'].astype('float64')
                    df_050_059_HS_SI2_D['PPC'] = df_050_059_HS_SI2_D['PPC'].astype('float64')
                    df_050_059_HS_SI2_D['Total'] = df_050_059_HS_SI2_D['Total'].astype('float64')
                    df_050_059_HS_SI2_D['Total'] = df_050_059_HS_SI2_D['Carat'] * df_050_059_HS_SI2_D['PPC']


                elif i=="D" and j == "I1" and k == "HS":
                    df_050_059_HS_I1_D = pd.DataFrame()
                    df_050_059_HS_I1_D ['Wt Range'] = None
                    df_050_059_HS_I1_D  = df_050_059_HS_I1_D.assign(Company=None)
                    df_050_059_HS_I1_D  = df_050_059_HS_I1_D.assign(Shape=None)
                    df_050_059_HS_I1_D  = df_050_059_HS_I1_D.assign(Carat=None)
                    df_050_059_HS_I1_D  = df_050_059_HS_I1_D.assign(Color=None)
                    df_050_059_HS_I1_D  = df_050_059_HS_I1_D.assign(Clarity=None)
                    df_050_059_HS_I1_D  = df_050_059_HS_I1_D.assign(Cut=None)
                    df_050_059_HS_I1_D  = df_050_059_HS_I1_D.assign(Polish=None)
                    df_050_059_HS_I1_D  = df_050_059_HS_I1_D.assign(Symmetry=None)
                    df_050_059_HS_I1_D  = df_050_059_HS_I1_D.assign(Ratio=None)
                    df_050_059_HS_I1_D  = df_050_059_HS_I1_D.assign(PPC=None)
                    df_050_059_HS_I1_D  = df_050_059_HS_I1_D.assign(Total=None)
                    df_050_059_HS_I1_D ['Wt Range'] = listwtrange
                    df_050_059_HS_I1_D ['Company'] = listcom
                    df_050_059_HS_I1_D ['Shape'] = listshap
                    df_050_059_HS_I1_D ['Carat'] = listcar
                    df_050_059_HS_I1_D ['Color'] = listcol
                    df_050_059_HS_I1_D ['Clarity'] = listclar
                    df_050_059_HS_I1_D ['Cut'] = listcut
                    df_050_059_HS_I1_D ['Polish'] = listpol
                    df_050_059_HS_I1_D ['Symmetry'] = listsym
                    df_050_059_HS_I1_D ['Ratio'] = listrat
                    df_050_059_HS_I1_D ['PPC'] = listdesc
                    df_050_059_HS_I1_D ['Total'] = listtotal
                    df_050_059_HS_I1_D['Carat'] = df_050_059_HS_I1_D['Carat'].astype('float64')
                    df_050_059_HS_I1_D['PPC'] = df_050_059_HS_I1_D['PPC'].astype('float64')
                    df_050_059_HS_I1_D['Total'] = df_050_059_HS_I1_D['Total'].astype('float64')
                    df_050_059_HS_I1_D['Total'] = df_050_059_HS_I1_D['Carat'] * df_050_059_HS_I1_D['PPC']


                elif i=="D" and j == "I2" and k == "HS":
                    df_050_059_HS_I2_D = pd.DataFrame()
                    df_050_059_HS_I2_D ['Wt Range'] = None
                    df_050_059_HS_I2_D  = df_050_059_HS_I2_D.assign(Company=None)
                    df_050_059_HS_I2_D  = df_050_059_HS_I2_D.assign(Shape=None)
                    df_050_059_HS_I2_D  = df_050_059_HS_I2_D.assign(Carat=None)
                    df_050_059_HS_I2_D  = df_050_059_HS_I2_D.assign(Color=None)
                    df_050_059_HS_I2_D  = df_050_059_HS_I2_D.assign(Clarity=None)
                    df_050_059_HS_I2_D  = df_050_059_HS_I2_D.assign(Cut=None)
                    df_050_059_HS_I2_D  = df_050_059_HS_I2_D.assign(Polish=None)
                    df_050_059_HS_I2_D  = df_050_059_HS_I2_D.assign(Symmetry=None)
                    df_050_059_HS_I2_D  = df_050_059_HS_I2_D.assign(Ratio=None)
                    df_050_059_HS_I2_D  = df_050_059_HS_I2_D.assign(PPC=None)
                    df_050_059_HS_I2_D  = df_050_059_HS_I2_D.assign(Total=None)
                    df_050_059_HS_I2_D ['Wt Range'] = listwtrange
                    df_050_059_HS_I2_D ['Company'] = listcom
                    df_050_059_HS_I2_D ['Shape'] = listshap
                    df_050_059_HS_I2_D ['Carat'] = listcar
                    df_050_059_HS_I2_D ['Color'] = listcol
                    df_050_059_HS_I2_D ['Clarity'] = listclar
                    df_050_059_HS_I2_D ['Cut'] = listcut
                    df_050_059_HS_I2_D ['Polish'] = listpol
                    df_050_059_HS_I2_D ['Symmetry'] = listsym
                    df_050_059_HS_I2_D ['Ratio'] = listrat
                    df_050_059_HS_I2_D ['PPC'] = listdesc
                    df_050_059_HS_I2_D ['Total'] = listtotal
                    df_050_059_HS_I2_D['Carat'] = df_050_059_HS_I2_D['Carat'].astype('float64')
                    df_050_059_HS_I2_D['PPC'] = df_050_059_HS_I2_D['PPC'].astype('float64')
                    df_050_059_HS_I2_D['Total'] = df_050_059_HS_I2_D['Total'].astype('float64')
                    df_050_059_HS_I2_D['Total'] = df_050_059_HS_I2_D['Carat'] * df_050_059_HS_I2_D['PPC']



                elif i=="E" and j == "IF" and k == "HS":
                    df_050_059_HS_IF_E = pd.DataFrame()
                    df_050_059_HS_IF_E ['Wt Range'] = None
                    df_050_059_HS_IF_E  = df_050_059_HS_IF_E.assign(Company=None)
                    df_050_059_HS_IF_E  = df_050_059_HS_IF_E.assign(Shape=None)
                    df_050_059_HS_IF_E  = df_050_059_HS_IF_E.assign(Carat=None)
                    df_050_059_HS_IF_E  = df_050_059_HS_IF_E.assign(Color=None)
                    df_050_059_HS_IF_E  = df_050_059_HS_IF_E.assign(Clarity=None)
                    df_050_059_HS_IF_E  = df_050_059_HS_IF_E.assign(Cut=None)
                    df_050_059_HS_IF_E  = df_050_059_HS_IF_E.assign(Polish=None)
                    df_050_059_HS_IF_E  = df_050_059_HS_IF_E.assign(Symmetry=None)
                    df_050_059_HS_IF_E  = df_050_059_HS_IF_E.assign(Ratio=None)
                    df_050_059_HS_IF_E  = df_050_059_HS_IF_E.assign(PPC=None)
                    df_050_059_HS_IF_E  = df_050_059_HS_IF_E.assign(Total=None)
                    df_050_059_HS_IF_E ['Wt Range'] = listwtrange
                    df_050_059_HS_IF_E ['Company'] = listcom
                    df_050_059_HS_IF_E ['Shape'] = listshap
                    df_050_059_HS_IF_E ['Carat'] = listcar
                    df_050_059_HS_IF_E ['Color'] = listcol
                    df_050_059_HS_IF_E ['Clarity'] = listclar
                    df_050_059_HS_IF_E ['Cut'] = listcut
                    df_050_059_HS_IF_E ['Polish'] = listpol
                    df_050_059_HS_IF_E ['Symmetry'] = listsym
                    df_050_059_HS_IF_E ['Ratio'] = listrat
                    df_050_059_HS_IF_E ['PPC'] = listdesc
                    df_050_059_HS_IF_E ['Total'] = listtotal
                    df_050_059_HS_IF_E['Carat'] = df_050_059_HS_IF_E['Carat'].astype('float64')
                    df_050_059_HS_IF_E['PPC'] = df_050_059_HS_IF_E['PPC'].astype('float64')
                    df_050_059_HS_IF_E['Total'] = df_050_059_HS_IF_E['Total'].astype('float64')
                    df_050_059_HS_IF_E['Total'] = df_050_059_HS_IF_E['Carat'] * df_050_059_HS_IF_E['PPC']



                elif i=="E" and j == "VVS1" and k == "HS":
                    df_050_059_HS_VVS1_E = pd.DataFrame()
                    df_050_059_HS_VVS1_E ['Wt Range'] = None
                    df_050_059_HS_VVS1_E  = df_050_059_HS_VVS1_E.assign(Company=None)
                    df_050_059_HS_VVS1_E  = df_050_059_HS_VVS1_E.assign(Shape=None)
                    df_050_059_HS_VVS1_E  = df_050_059_HS_VVS1_E.assign(Carat=None)
                    df_050_059_HS_VVS1_E  = df_050_059_HS_VVS1_E.assign(Color=None)
                    df_050_059_HS_VVS1_E  = df_050_059_HS_VVS1_E.assign(Clarity=None)
                    df_050_059_HS_VVS1_E  = df_050_059_HS_VVS1_E.assign(Cut=None)
                    df_050_059_HS_VVS1_E  = df_050_059_HS_VVS1_E.assign(Polish=None)
                    df_050_059_HS_VVS1_E  = df_050_059_HS_VVS1_E.assign(Symmetry=None)
                    df_050_059_HS_VVS1_E  = df_050_059_HS_VVS1_E.assign(Ratio=None)
                    df_050_059_HS_VVS1_E  = df_050_059_HS_VVS1_E.assign(PPC=None)
                    df_050_059_HS_VVS1_E  = df_050_059_HS_VVS1_E.assign(Total=None)
                    df_050_059_HS_VVS1_E ['Wt Range'] = listwtrange
                    df_050_059_HS_VVS1_E ['Company'] = listcom
                    df_050_059_HS_VVS1_E ['Shape'] = listshap
                    df_050_059_HS_VVS1_E ['Carat'] = listcar
                    df_050_059_HS_VVS1_E ['Color'] = listcol
                    df_050_059_HS_VVS1_E ['Clarity'] = listclar
                    df_050_059_HS_VVS1_E ['Cut'] = listcut
                    df_050_059_HS_VVS1_E ['Polish'] = listpol
                    df_050_059_HS_VVS1_E ['Symmetry'] = listsym
                    df_050_059_HS_VVS1_E ['Ratio'] = listrat
                    df_050_059_HS_VVS1_E ['PPC'] = listdesc
                    df_050_059_HS_VVS1_E ['Total'] = listtotal
                    df_050_059_HS_VVS1_E['Carat'] = df_050_059_HS_VVS1_E['Carat'].astype('float64')
                    df_050_059_HS_VVS1_E['PPC'] = df_050_059_HS_VVS1_E['PPC'].astype('float64')
                    df_050_059_HS_VVS1_E['Total'] = df_050_059_HS_VVS1_E['Total'].astype('float64')
                    df_050_059_HS_VVS1_E['Total'] = df_050_059_HS_VVS1_E['Carat'] * df_050_059_HS_VVS1_E['PPC']


                elif i=="E" and j == "VVS2" and k == "HS":
                    df_050_059_HS_VVS2_E = pd.DataFrame()
                    df_050_059_HS_VVS2_E ['Wt Range'] = None
                    df_050_059_HS_VVS2_E  = df_050_059_HS_VVS2_E.assign(Company=None)
                    df_050_059_HS_VVS2_E  = df_050_059_HS_VVS2_E.assign(Shape=None)
                    df_050_059_HS_VVS2_E  = df_050_059_HS_VVS2_E.assign(Carat=None)
                    df_050_059_HS_VVS2_E  = df_050_059_HS_VVS2_E.assign(Color=None)
                    df_050_059_HS_VVS2_E  = df_050_059_HS_VVS2_E.assign(Clarity=None)
                    df_050_059_HS_VVS2_E  = df_050_059_HS_VVS2_E.assign(Cut=None)
                    df_050_059_HS_VVS2_E  = df_050_059_HS_VVS2_E.assign(Polish=None)
                    df_050_059_HS_VVS2_E  = df_050_059_HS_VVS2_E.assign(Symmetry=None)
                    df_050_059_HS_VVS2_E  = df_050_059_HS_VVS2_E.assign(Ratio=None)
                    df_050_059_HS_VVS2_E  = df_050_059_HS_VVS2_E.assign(PPC=None)
                    df_050_059_HS_VVS2_E  = df_050_059_HS_VVS2_E.assign(Total=None)
                    df_050_059_HS_VVS2_E ['Wt Range'] = listwtrange
                    df_050_059_HS_VVS2_E ['Company'] = listcom
                    df_050_059_HS_VVS2_E ['Shape'] = listshap
                    df_050_059_HS_VVS2_E ['Carat'] = listcar
                    df_050_059_HS_VVS2_E ['Color'] = listcol
                    df_050_059_HS_VVS2_E ['Clarity'] = listclar
                    df_050_059_HS_VVS2_E ['Cut'] = listcut
                    df_050_059_HS_VVS2_E ['Polish'] = listpol
                    df_050_059_HS_VVS2_E ['Symmetry'] = listsym
                    df_050_059_HS_VVS2_E ['Ratio'] = listrat
                    df_050_059_HS_VVS2_E ['PPC'] = listdesc
                    df_050_059_HS_VVS2_E ['Total'] = listtotal
                    df_050_059_HS_VVS2_E['Carat'] = df_050_059_HS_VVS2_E['Carat'].astype('float64')
                    df_050_059_HS_VVS2_E['PPC'] = df_050_059_HS_VVS2_E['PPC'].astype('float64')
                    df_050_059_HS_VVS2_E['Total'] = df_050_059_HS_VVS2_E['Total'].astype('float64')
                    df_050_059_HS_VVS2_E['Total'] = df_050_059_HS_VVS2_E['Carat'] * df_050_059_HS_VVS2_E['PPC']


                elif i=="E" and j=="VS1" and k == "HS":
                    df_050_059_HS_VS1_E = pd.DataFrame()
                    df_050_059_HS_VS1_E ['Wt Range'] = None
                    df_050_059_HS_VS1_E  = df_050_059_HS_VS1_E.assign(Company=None)
                    df_050_059_HS_VS1_E  = df_050_059_HS_VS1_E.assign(Shape=None)
                    df_050_059_HS_VS1_E  = df_050_059_HS_VS1_E.assign(Carat=None)
                    df_050_059_HS_VS1_E  = df_050_059_HS_VS1_E.assign(Color=None)
                    df_050_059_HS_VS1_E  = df_050_059_HS_VS1_E.assign(Clarity=None)
                    df_050_059_HS_VS1_E  = df_050_059_HS_VS1_E.assign(Cut=None)
                    df_050_059_HS_VS1_E  = df_050_059_HS_VS1_E.assign(Polish=None)
                    df_050_059_HS_VS1_E  = df_050_059_HS_VS1_E.assign(Symmetry=None)
                    df_050_059_HS_VS1_E  = df_050_059_HS_VS1_E.assign(Ratio=None)
                    df_050_059_HS_VS1_E  = df_050_059_HS_VS1_E.assign(PPC=None)
                    df_050_059_HS_VS1_E  = df_050_059_HS_VS1_E.assign(Total=None)
                    df_050_059_HS_VS1_E ['Wt Range'] = listwtrange
                    df_050_059_HS_VS1_E ['Company'] = listcom
                    df_050_059_HS_VS1_E ['Shape'] = listshap
                    df_050_059_HS_VS1_E ['Carat'] = listcar
                    df_050_059_HS_VS1_E ['Color'] = listcol
                    df_050_059_HS_VS1_E ['Clarity'] = listclar
                    df_050_059_HS_VS1_E ['Cut'] = listcut
                    df_050_059_HS_VS1_E ['Polish'] = listpol
                    df_050_059_HS_VS1_E ['Symmetry'] = listsym
                    df_050_059_HS_VS1_E ['Ratio'] = listrat
                    df_050_059_HS_VS1_E ['PPC'] = listdesc
                    df_050_059_HS_VS1_E ['Total'] = listtotal
                    df_050_059_HS_VS1_E['Carat'] = df_050_059_HS_VS1_E['Carat'].astype('float64')
                    df_050_059_HS_VS1_E['PPC'] = df_050_059_HS_VS1_E['PPC'].astype('float64')
                    df_050_059_HS_VS1_E['Total'] = df_050_059_HS_VS1_E['Total'].astype('float64')
                    df_050_059_HS_VS1_E['Total'] = df_050_059_HS_VS1_E['Carat'] * df_050_059_HS_VS1_E['PPC']


                elif i=="E" and j == "VS2" and k == "HS":
                    df_050_059_HS_VS2_E = pd.DataFrame()
                    df_050_059_HS_VS2_E ['Wt Range'] = None
                    df_050_059_HS_VS2_E  = df_050_059_HS_VS2_E.assign(Company=None)
                    df_050_059_HS_VS2_E  = df_050_059_HS_VS2_E.assign(Shape=None)
                    df_050_059_HS_VS2_E  = df_050_059_HS_VS2_E.assign(Carat=None)
                    df_050_059_HS_VS2_E  = df_050_059_HS_VS2_E.assign(Color=None)
                    df_050_059_HS_VS2_E  = df_050_059_HS_VS2_E.assign(Clarity=None)
                    df_050_059_HS_VS2_E  = df_050_059_HS_VS2_E.assign(Cut=None)
                    df_050_059_HS_VS2_E  = df_050_059_HS_VS2_E.assign(Polish=None)
                    df_050_059_HS_VS2_E  = df_050_059_HS_VS2_E.assign(Symmetry=None)
                    df_050_059_HS_VS2_E  = df_050_059_HS_VS2_E.assign(Ratio=None)
                    df_050_059_HS_VS2_E  = df_050_059_HS_VS2_E.assign(PPC=None)
                    df_050_059_HS_VS2_E  = df_050_059_HS_VS2_E.assign(Total=None)
                    df_050_059_HS_VS2_E ['Wt Range'] = listwtrange
                    df_050_059_HS_VS2_E ['Company'] = listcom
                    df_050_059_HS_VS2_E ['Shape'] = listshap
                    df_050_059_HS_VS2_E ['Carat'] = listcar
                    df_050_059_HS_VS2_E ['Color'] = listcol
                    df_050_059_HS_VS2_E ['Clarity'] = listclar
                    df_050_059_HS_VS2_E ['Cut'] = listcut
                    df_050_059_HS_VS2_E ['Polish'] = listpol
                    df_050_059_HS_VS2_E ['Symmetry'] = listsym
                    df_050_059_HS_VS2_E ['Ratio'] = listrat
                    df_050_059_HS_VS2_E ['PPC'] = listdesc
                    df_050_059_HS_VS2_E ['Total'] = listtotal
                    df_050_059_HS_VS2_E['Carat'] = df_050_059_HS_VS2_E['Carat'].astype('float64')
                    df_050_059_HS_VS2_E['PPC'] = df_050_059_HS_VS2_E['PPC'].astype('float64')
                    df_050_059_HS_VS2_E['Total'] = df_050_059_HS_VS2_E['Total'].astype('float64')
                    df_050_059_HS_VS2_E['Total'] = df_050_059_HS_VS2_E['Carat'] * df_050_059_HS_VS2_E['PPC']


                elif i=="E" and j == "SI1" and k == "HS":
                    df_050_059_HS_SI1_E = pd.DataFrame()
                    df_050_059_HS_SI1_E ['Wt Range'] = None
                    df_050_059_HS_SI1_E  = df_050_059_HS_SI1_E.assign(Company=None)
                    df_050_059_HS_SI1_E  = df_050_059_HS_SI1_E.assign(Shape=None)
                    df_050_059_HS_SI1_E  = df_050_059_HS_SI1_E.assign(Carat=None)
                    df_050_059_HS_SI1_E  = df_050_059_HS_SI1_E.assign(Color=None)
                    df_050_059_HS_SI1_E  = df_050_059_HS_SI1_E.assign(Clarity=None)
                    df_050_059_HS_SI1_E  = df_050_059_HS_SI1_E.assign(Cut=None)
                    df_050_059_HS_SI1_E  = df_050_059_HS_SI1_E.assign(Polish=None)
                    df_050_059_HS_SI1_E  = df_050_059_HS_SI1_E.assign(Symmetry=None)
                    df_050_059_HS_SI1_E  = df_050_059_HS_SI1_E.assign(Ratio=None)
                    df_050_059_HS_SI1_E  = df_050_059_HS_SI1_E.assign(PPC=None)
                    df_050_059_HS_SI1_E  = df_050_059_HS_SI1_E.assign(Total=None)
                    df_050_059_HS_SI1_E ['Wt Range'] = listwtrange
                    df_050_059_HS_SI1_E ['Company'] = listcom
                    df_050_059_HS_SI1_E ['Shape'] = listshap
                    df_050_059_HS_SI1_E ['Carat'] = listcar
                    df_050_059_HS_SI1_E ['Color'] = listcol
                    df_050_059_HS_SI1_E ['Clarity'] = listclar
                    df_050_059_HS_SI1_E ['Cut'] = listcut
                    df_050_059_HS_SI1_E ['Polish'] = listpol
                    df_050_059_HS_SI1_E ['Symmetry'] = listsym
                    df_050_059_HS_SI1_E ['Ratio'] = listrat
                    df_050_059_HS_SI1_E ['PPC'] = listdesc
                    df_050_059_HS_SI1_E ['Total'] = listtotal
                    df_050_059_HS_SI1_E['Carat'] = df_050_059_HS_SI1_E['Carat'].astype('float64')
                    df_050_059_HS_SI1_E['PPC'] = df_050_059_HS_SI1_E['PPC'].astype('float64')
                    df_050_059_HS_SI1_E['Total'] = df_050_059_HS_SI1_E['Total'].astype('float64')
                    df_050_059_HS_SI1_E['Total'] = df_050_059_HS_SI1_E['Carat'] * df_050_059_HS_SI1_E['PPC']


                elif i=="E" and j == "SI2" and k == "HS":
                    df_050_059_HS_SI2_E = pd.DataFrame()
                    df_050_059_HS_SI2_E ['Wt Range'] = None
                    df_050_059_HS_SI2_E  = df_050_059_HS_SI2_E.assign(Company=None)
                    df_050_059_HS_SI2_E  = df_050_059_HS_SI2_E.assign(Shape=None)
                    df_050_059_HS_SI2_E  = df_050_059_HS_SI2_E.assign(Carat=None)
                    df_050_059_HS_SI2_E  = df_050_059_HS_SI2_E.assign(Color=None)
                    df_050_059_HS_SI2_E  = df_050_059_HS_SI2_E.assign(Clarity=None)
                    df_050_059_HS_SI2_E  = df_050_059_HS_SI2_E.assign(Cut=None)
                    df_050_059_HS_SI2_E  = df_050_059_HS_SI2_E.assign(Polish=None)
                    df_050_059_HS_SI2_E  = df_050_059_HS_SI2_E.assign(Symmetry=None)
                    df_050_059_HS_SI2_E  = df_050_059_HS_SI2_E.assign(Ratio=None)
                    df_050_059_HS_SI2_E  = df_050_059_HS_SI2_E.assign(PPC=None)
                    df_050_059_HS_SI2_E  = df_050_059_HS_SI2_E.assign(Total=None)
                    df_050_059_HS_SI2_E ['Wt Range'] = listwtrange
                    df_050_059_HS_SI2_E ['Company'] = listcom
                    df_050_059_HS_SI2_E ['Shape'] = listshap
                    df_050_059_HS_SI2_E ['Carat'] = listcar
                    df_050_059_HS_SI2_E ['Color'] = listcol
                    df_050_059_HS_SI2_E ['Clarity'] = listclar
                    df_050_059_HS_SI2_E ['Cut'] = listcut
                    df_050_059_HS_SI2_E ['Polish'] = listpol
                    df_050_059_HS_SI2_E ['Symmetry'] = listsym
                    df_050_059_HS_SI2_E ['Ratio'] = listrat
                    df_050_059_HS_SI2_E ['PPC'] = listdesc
                    df_050_059_HS_SI2_E ['Total'] = listtotal
                    df_050_059_HS_SI2_E['Carat'] = df_050_059_HS_SI2_E['Carat'].astype('float64')
                    df_050_059_HS_SI2_E['PPC'] = df_050_059_HS_SI2_E['PPC'].astype('float64')
                    df_050_059_HS_SI2_E['Total'] = df_050_059_HS_SI2_E['Total'].astype('float64')
                    df_050_059_HS_SI2_E['Total'] = df_050_059_HS_SI2_E['Carat'] * df_050_059_HS_SI2_E['PPC']


                elif i=="E" and j == "I1" and k == "HS":
                    df_050_059_HS_I1_E = pd.DataFrame()
                    df_050_059_HS_I1_E ['Wt Range'] = None
                    df_050_059_HS_I1_E  = df_050_059_HS_I1_E.assign(Company=None)
                    df_050_059_HS_I1_E  = df_050_059_HS_I1_E.assign(Shape=None)
                    df_050_059_HS_I1_E  = df_050_059_HS_I1_E.assign(Carat=None)
                    df_050_059_HS_I1_E  = df_050_059_HS_I1_E.assign(Color=None)
                    df_050_059_HS_I1_E  = df_050_059_HS_I1_E.assign(Clarity=None)
                    df_050_059_HS_I1_E  = df_050_059_HS_I1_E.assign(Cut=None)
                    df_050_059_HS_I1_E  = df_050_059_HS_I1_E.assign(Polish=None)
                    df_050_059_HS_I1_E  = df_050_059_HS_I1_E.assign(Symmetry=None)
                    df_050_059_HS_I1_E  = df_050_059_HS_I1_E.assign(Ratio=None)
                    df_050_059_HS_I1_E  = df_050_059_HS_I1_E.assign(PPC=None)
                    df_050_059_HS_I1_E  = df_050_059_HS_I1_E.assign(Total=None)
                    df_050_059_HS_I1_E ['Wt Range'] = listwtrange
                    df_050_059_HS_I1_E ['Company'] = listcom
                    df_050_059_HS_I1_E ['Shape'] = listshap
                    df_050_059_HS_I1_E ['Carat'] = listcar
                    df_050_059_HS_I1_E ['Color'] = listcol
                    df_050_059_HS_I1_E ['Clarity'] = listclar
                    df_050_059_HS_I1_E ['Cut'] = listcut
                    df_050_059_HS_I1_E ['Polish'] = listpol
                    df_050_059_HS_I1_E ['Symmetry'] = listsym
                    df_050_059_HS_I1_E ['Ratio'] = listrat
                    df_050_059_HS_I1_E ['PPC'] = listdesc
                    df_050_059_HS_I1_E ['Total'] = listtotal
                    df_050_059_HS_I1_E['Carat'] = df_050_059_HS_I1_E['Carat'].astype('float64')
                    df_050_059_HS_I1_E['PPC'] = df_050_059_HS_I1_E['PPC'].astype('float64')
                    df_050_059_HS_I1_E['Total'] = df_050_059_HS_I1_E['Total'].astype('float64')
                    df_050_059_HS_I1_E['Total'] = df_050_059_HS_I1_E['Carat'] * df_050_059_HS_I1_E['PPC']


                elif i=="E" and j == "I2" and k == "HS":
                    df_050_059_HS_I2_E = pd.DataFrame()
                    df_050_059_HS_I2_E ['Wt Range'] = None
                    df_050_059_HS_I2_E  = df_050_059_HS_I2_E.assign(Company=None)
                    df_050_059_HS_I2_E  = df_050_059_HS_I2_E.assign(Shape=None)
                    df_050_059_HS_I2_E  = df_050_059_HS_I2_E.assign(Carat=None)
                    df_050_059_HS_I2_E  = df_050_059_HS_I2_E.assign(Color=None)
                    df_050_059_HS_I2_E  = df_050_059_HS_I2_E.assign(Clarity=None)
                    df_050_059_HS_I2_E  = df_050_059_HS_I2_E.assign(Cut=None)
                    df_050_059_HS_I2_E  = df_050_059_HS_I2_E.assign(Polish=None)
                    df_050_059_HS_I2_E  = df_050_059_HS_I2_E.assign(Symmetry=None)
                    df_050_059_HS_I2_E  = df_050_059_HS_I2_E.assign(Ratio=None)
                    df_050_059_HS_I2_E  = df_050_059_HS_I2_E.assign(PPC=None)
                    df_050_059_HS_I2_E  = df_050_059_HS_I2_E.assign(Total=None)
                    df_050_059_HS_I2_E ['Wt Range'] = listwtrange
                    df_050_059_HS_I2_E ['Company'] = listcom
                    df_050_059_HS_I2_E ['Shape'] = listshap
                    df_050_059_HS_I2_E ['Carat'] = listcar
                    df_050_059_HS_I2_E ['Color'] = listcol
                    df_050_059_HS_I2_E ['Clarity'] = listclar
                    df_050_059_HS_I2_E ['Cut'] = listcut
                    df_050_059_HS_I2_E ['Polish'] = listpol
                    df_050_059_HS_I2_E ['Symmetry'] = listsym
                    df_050_059_HS_I2_E ['Ratio'] = listrat
                    df_050_059_HS_I2_E ['PPC'] = listdesc
                    df_050_059_HS_I2_E ['Total'] = listtotal
                    df_050_059_HS_I2_E['Carat'] = df_050_059_HS_I2_E['Carat'].astype('float64')
                    df_050_059_HS_I2_E['PPC'] = df_050_059_HS_I2_E['PPC'].astype('float64')
                    df_050_059_HS_I2_E['Total'] = df_050_059_HS_I2_E['Total'].astype('float64')
                    df_050_059_HS_I2_E['Total'] = df_050_059_HS_I2_E['Carat'] * df_050_059_HS_I2_E['PPC']
                
                elif i=="F" and j == "IF" and k == "HS":
                    df_050_059_HS_IF_F = pd.DataFrame()
                    df_050_059_HS_IF_F ['Wt Range'] = None
                    df_050_059_HS_IF_F  = df_050_059_HS_IF_F.assign(Company=None)
                    df_050_059_HS_IF_F  = df_050_059_HS_IF_F.assign(Shape=None)
                    df_050_059_HS_IF_F  = df_050_059_HS_IF_F.assign(Carat=None)
                    df_050_059_HS_IF_F  = df_050_059_HS_IF_F.assign(Color=None)
                    df_050_059_HS_IF_F  = df_050_059_HS_IF_F.assign(Clarity=None)
                    df_050_059_HS_IF_F  = df_050_059_HS_IF_F.assign(Cut=None)
                    df_050_059_HS_IF_F  = df_050_059_HS_IF_F.assign(Polish=None)
                    df_050_059_HS_IF_F  = df_050_059_HS_IF_F.assign(Symmetry=None)
                    df_050_059_HS_IF_F  = df_050_059_HS_IF_F.assign(Ratio=None)
                    df_050_059_HS_IF_F  = df_050_059_HS_IF_F.assign(PPC=None)
                    df_050_059_HS_IF_F  = df_050_059_HS_IF_F.assign(Total=None)
                    df_050_059_HS_IF_F ['Wt Range'] = listwtrange
                    df_050_059_HS_IF_F ['Company'] = listcom
                    df_050_059_HS_IF_F ['Shape'] = listshap
                    df_050_059_HS_IF_F ['Carat'] = listcar
                    df_050_059_HS_IF_F ['Color'] = listcol
                    df_050_059_HS_IF_F ['Clarity'] = listclar
                    df_050_059_HS_IF_F ['Cut'] = listcut
                    df_050_059_HS_IF_F ['Polish'] = listpol
                    df_050_059_HS_IF_F ['Symmetry'] = listsym
                    df_050_059_HS_IF_F ['Ratio'] = listrat
                    df_050_059_HS_IF_F ['PPC'] = listdesc
                    df_050_059_HS_IF_F ['Total'] = listtotal
                    df_050_059_HS_IF_F['Carat'] = df_050_059_HS_IF_F['Carat'].astype('float64')
                    df_050_059_HS_IF_F['PPC'] = df_050_059_HS_IF_F['PPC'].astype('float64')
                    df_050_059_HS_IF_F['Total'] = df_050_059_HS_IF_F['Total'].astype('float64')
                    df_050_059_HS_IF_F['Total'] = df_050_059_HS_IF_F['Carat'] * df_050_059_HS_IF_F['PPC']



                elif i=="F" and j == "VVS1" and k == "HS":
                    df_050_059_HS_VVS1_F = pd.DataFrame()
                    df_050_059_HS_VVS1_F ['Wt Range'] = None
                    df_050_059_HS_VVS1_F  = df_050_059_HS_VVS1_F.assign(Company=None)
                    df_050_059_HS_VVS1_F  = df_050_059_HS_VVS1_F.assign(Shape=None)
                    df_050_059_HS_VVS1_F  = df_050_059_HS_VVS1_F.assign(Carat=None)
                    df_050_059_HS_VVS1_F  = df_050_059_HS_VVS1_F.assign(Color=None)
                    df_050_059_HS_VVS1_F  = df_050_059_HS_VVS1_F.assign(Clarity=None)
                    df_050_059_HS_VVS1_F  = df_050_059_HS_VVS1_F.assign(Cut=None)
                    df_050_059_HS_VVS1_F  = df_050_059_HS_VVS1_F.assign(Polish=None)
                    df_050_059_HS_VVS1_F  = df_050_059_HS_VVS1_F.assign(Symmetry=None)
                    df_050_059_HS_VVS1_F  = df_050_059_HS_VVS1_F.assign(Ratio=None)
                    df_050_059_HS_VVS1_F  = df_050_059_HS_VVS1_F.assign(PPC=None)
                    df_050_059_HS_VVS1_F  = df_050_059_HS_VVS1_F.assign(Total=None)
                    df_050_059_HS_VVS1_F ['Wt Range'] = listwtrange
                    df_050_059_HS_VVS1_F ['Company'] = listcom
                    df_050_059_HS_VVS1_F ['Shape'] = listshap
                    df_050_059_HS_VVS1_F ['Carat'] = listcar
                    df_050_059_HS_VVS1_F ['Color'] = listcol
                    df_050_059_HS_VVS1_F ['Clarity'] = listclar
                    df_050_059_HS_VVS1_F ['Cut'] = listcut
                    df_050_059_HS_VVS1_F ['Polish'] = listpol
                    df_050_059_HS_VVS1_F ['Symmetry'] = listsym
                    df_050_059_HS_VVS1_F ['Ratio'] = listrat
                    df_050_059_HS_VVS1_F ['PPC'] = listdesc
                    df_050_059_HS_VVS1_F ['Total'] = listtotal
                    df_050_059_HS_VVS1_F['Carat'] = df_050_059_HS_VVS1_F['Carat'].astype('float64')
                    df_050_059_HS_VVS1_F['PPC'] = df_050_059_HS_VVS1_F['PPC'].astype('float64')
                    df_050_059_HS_VVS1_F['Total'] = df_050_059_HS_VVS1_F['Total'].astype('float64')
                    df_050_059_HS_VVS1_F['Total'] = df_050_059_HS_VVS1_F['Carat'] * df_050_059_HS_VVS1_F['PPC']


                elif i=="F" and j == "VVS2" and k == "HS":
                    df_050_059_HS_VVS2_F = pd.DataFrame()
                    df_050_059_HS_VVS2_F ['Wt Range'] = None
                    df_050_059_HS_VVS2_F  = df_050_059_HS_VVS2_F.assign(Company=None)
                    df_050_059_HS_VVS2_F  = df_050_059_HS_VVS2_F.assign(Shape=None)
                    df_050_059_HS_VVS2_F  = df_050_059_HS_VVS2_F.assign(Carat=None)
                    df_050_059_HS_VVS2_F  = df_050_059_HS_VVS2_F.assign(Color=None)
                    df_050_059_HS_VVS2_F  = df_050_059_HS_VVS2_F.assign(Clarity=None)
                    df_050_059_HS_VVS2_F  = df_050_059_HS_VVS2_F.assign(Cut=None)
                    df_050_059_HS_VVS2_F  = df_050_059_HS_VVS2_F.assign(Polish=None)
                    df_050_059_HS_VVS2_F  = df_050_059_HS_VVS2_F.assign(Symmetry=None)
                    df_050_059_HS_VVS2_F  = df_050_059_HS_VVS2_F.assign(Ratio=None)
                    df_050_059_HS_VVS2_F  = df_050_059_HS_VVS2_F.assign(PPC=None)
                    df_050_059_HS_VVS2_F  = df_050_059_HS_VVS2_F.assign(Total=None)
                    df_050_059_HS_VVS2_F ['Wt Range'] = listwtrange
                    df_050_059_HS_VVS2_F ['Company'] = listcom
                    df_050_059_HS_VVS2_F ['Shape'] = listshap
                    df_050_059_HS_VVS2_F ['Carat'] = listcar
                    df_050_059_HS_VVS2_F ['Color'] = listcol
                    df_050_059_HS_VVS2_F ['Clarity'] = listclar
                    df_050_059_HS_VVS2_F ['Cut'] = listcut
                    df_050_059_HS_VVS2_F ['Polish'] = listpol
                    df_050_059_HS_VVS2_F ['Symmetry'] = listsym
                    df_050_059_HS_VVS2_F ['Ratio'] = listrat
                    df_050_059_HS_VVS2_F ['PPC'] = listdesc
                    df_050_059_HS_VVS2_F ['Total'] = listtotal
                    df_050_059_HS_VVS2_F['Carat'] = df_050_059_HS_VVS2_F['Carat'].astype('float64')
                    df_050_059_HS_VVS2_F['PPC'] = df_050_059_HS_VVS2_F['PPC'].astype('float64')
                    df_050_059_HS_VVS2_F['Total'] = df_050_059_HS_VVS2_F['Total'].astype('float64')
                    df_050_059_HS_VVS2_F['Total'] = df_050_059_HS_VVS2_F['Carat'] * df_050_059_HS_VVS2_F['PPC']


                elif i=="F" and j=="VS1" and k == "HS":
                    df_050_059_HS_VS1_F = pd.DataFrame()
                    df_050_059_HS_VS1_F ['Wt Range'] = None
                    df_050_059_HS_VS1_F  = df_050_059_HS_VS1_F.assign(Company=None)
                    df_050_059_HS_VS1_F  = df_050_059_HS_VS1_F.assign(Shape=None)
                    df_050_059_HS_VS1_F  = df_050_059_HS_VS1_F.assign(Carat=None)
                    df_050_059_HS_VS1_F  = df_050_059_HS_VS1_F.assign(Color=None)
                    df_050_059_HS_VS1_F  = df_050_059_HS_VS1_F.assign(Clarity=None)
                    df_050_059_HS_VS1_F  = df_050_059_HS_VS1_F.assign(Cut=None)
                    df_050_059_HS_VS1_F  = df_050_059_HS_VS1_F.assign(Polish=None)
                    df_050_059_HS_VS1_F  = df_050_059_HS_VS1_F.assign(Symmetry=None)
                    df_050_059_HS_VS1_F  = df_050_059_HS_VS1_F.assign(Ratio=None)
                    df_050_059_HS_VS1_F  = df_050_059_HS_VS1_F.assign(PPC=None)
                    df_050_059_HS_VS1_F  = df_050_059_HS_VS1_F.assign(Total=None)
                    df_050_059_HS_VS1_F ['Wt Range'] = listwtrange
                    df_050_059_HS_VS1_F ['Company'] = listcom
                    df_050_059_HS_VS1_F ['Shape'] = listshap
                    df_050_059_HS_VS1_F ['Carat'] = listcar
                    df_050_059_HS_VS1_F ['Color'] = listcol
                    df_050_059_HS_VS1_F ['Clarity'] = listclar
                    df_050_059_HS_VS1_F ['Cut'] = listcut
                    df_050_059_HS_VS1_F ['Polish'] = listpol
                    df_050_059_HS_VS1_F ['Symmetry'] = listsym
                    df_050_059_HS_VS1_F ['Ratio'] = listrat
                    df_050_059_HS_VS1_F ['PPC'] = listdesc
                    df_050_059_HS_VS1_F ['Total'] = listtotal
                    df_050_059_HS_VS1_F['Carat'] = df_050_059_HS_VS1_F['Carat'].astype('float64')
                    df_050_059_HS_VS1_F['PPC'] = df_050_059_HS_VS1_F['PPC'].astype('float64')
                    df_050_059_HS_VS1_F['Total'] = df_050_059_HS_VS1_F['Total'].astype('float64')
                    df_050_059_HS_VS1_F['Total'] = df_050_059_HS_VS1_F['Carat'] * df_050_059_HS_VS1_F['PPC']


                elif i=="F" and j == "VS2" and k == "HS":
                    df_050_059_HS_VS2_F = pd.DataFrame()
                    df_050_059_HS_VS2_F ['Wt Range'] = None
                    df_050_059_HS_VS2_F  = df_050_059_HS_VS2_F.assign(Company=None)
                    df_050_059_HS_VS2_F  = df_050_059_HS_VS2_F.assign(Shape=None)
                    df_050_059_HS_VS2_F  = df_050_059_HS_VS2_F.assign(Carat=None)
                    df_050_059_HS_VS2_F  = df_050_059_HS_VS2_F.assign(Color=None)
                    df_050_059_HS_VS2_F  = df_050_059_HS_VS2_F.assign(Clarity=None)
                    df_050_059_HS_VS2_F  = df_050_059_HS_VS2_F.assign(Cut=None)
                    df_050_059_HS_VS2_F  = df_050_059_HS_VS2_F.assign(Polish=None)
                    df_050_059_HS_VS2_F  = df_050_059_HS_VS2_F.assign(Symmetry=None)
                    df_050_059_HS_VS2_F  = df_050_059_HS_VS2_F.assign(Ratio=None)
                    df_050_059_HS_VS2_F  = df_050_059_HS_VS2_F.assign(PPC=None)
                    df_050_059_HS_VS2_F  = df_050_059_HS_VS2_F.assign(Total=None)
                    df_050_059_HS_VS2_F ['Wt Range'] = listwtrange
                    df_050_059_HS_VS2_F ['Company'] = listcom
                    df_050_059_HS_VS2_F ['Shape'] = listshap
                    df_050_059_HS_VS2_F ['Carat'] = listcar
                    df_050_059_HS_VS2_F ['Color'] = listcol
                    df_050_059_HS_VS2_F ['Clarity'] = listclar
                    df_050_059_HS_VS2_F ['Cut'] = listcut
                    df_050_059_HS_VS2_F ['Polish'] = listpol
                    df_050_059_HS_VS2_F ['Symmetry'] = listsym
                    df_050_059_HS_VS2_F ['Ratio'] = listrat
                    df_050_059_HS_VS2_F ['PPC'] = listdesc
                    df_050_059_HS_VS2_F ['Total'] = listtotal
                    df_050_059_HS_VS2_F['Carat'] = df_050_059_HS_VS2_F['Carat'].astype('float64')
                    df_050_059_HS_VS2_F['PPC'] = df_050_059_HS_VS2_F['PPC'].astype('float64')
                    df_050_059_HS_VS2_F['Total'] = df_050_059_HS_VS2_F['Total'].astype('float64')
                    df_050_059_HS_VS2_F['Total'] = df_050_059_HS_VS2_F['Carat'] * df_050_059_HS_VS2_F['PPC']


                elif i=="F" and j == "SI1" and k == "HS":
                    df_050_059_HS_SI1_F = pd.DataFrame()
                    df_050_059_HS_SI1_F ['Wt Range'] = None
                    df_050_059_HS_SI1_F  = df_050_059_HS_SI1_F.assign(Company=None)
                    df_050_059_HS_SI1_F  = df_050_059_HS_SI1_F.assign(Shape=None)
                    df_050_059_HS_SI1_F  = df_050_059_HS_SI1_F.assign(Carat=None)
                    df_050_059_HS_SI1_F  = df_050_059_HS_SI1_F.assign(Color=None)
                    df_050_059_HS_SI1_F  = df_050_059_HS_SI1_F.assign(Clarity=None)
                    df_050_059_HS_SI1_F  = df_050_059_HS_SI1_F.assign(Cut=None)
                    df_050_059_HS_SI1_F  = df_050_059_HS_SI1_F.assign(Polish=None)
                    df_050_059_HS_SI1_F  = df_050_059_HS_SI1_F.assign(Symmetry=None)
                    df_050_059_HS_SI1_F  = df_050_059_HS_SI1_F.assign(Ratio=None)
                    df_050_059_HS_SI1_F  = df_050_059_HS_SI1_F.assign(PPC=None)
                    df_050_059_HS_SI1_F  = df_050_059_HS_SI1_F.assign(Total=None)
                    df_050_059_HS_SI1_F ['Wt Range'] = listwtrange
                    df_050_059_HS_SI1_F ['Company'] = listcom
                    df_050_059_HS_SI1_F ['Shape'] = listshap
                    df_050_059_HS_SI1_F ['Carat'] = listcar
                    df_050_059_HS_SI1_F ['Color'] = listcol
                    df_050_059_HS_SI1_F ['Clarity'] = listclar
                    df_050_059_HS_SI1_F ['Cut'] = listcut
                    df_050_059_HS_SI1_F ['Polish'] = listpol
                    df_050_059_HS_SI1_F ['Symmetry'] = listsym
                    df_050_059_HS_SI1_F ['Ratio'] = listrat
                    df_050_059_HS_SI1_F ['PPC'] = listdesc
                    df_050_059_HS_SI1_F ['Total'] = listtotal
                    df_050_059_HS_SI1_F['Carat'] = df_050_059_HS_SI1_F['Carat'].astype('float64')
                    df_050_059_HS_SI1_F['PPC'] = df_050_059_HS_SI1_F['PPC'].astype('float64')
                    df_050_059_HS_SI1_F['Total'] = df_050_059_HS_SI1_F['Total'].astype('float64')
                    df_050_059_HS_SI1_F['Total'] = df_050_059_HS_SI1_F['Carat'] * df_050_059_HS_SI1_F['PPC']


                elif i=="F" and j == "SI2" and k == "HS":
                    df_050_059_HS_SI2_F = pd.DataFrame()
                    df_050_059_HS_SI2_F ['Wt Range'] = None
                    df_050_059_HS_SI2_F  = df_050_059_HS_SI2_F.assign(Company=None)
                    df_050_059_HS_SI2_F  = df_050_059_HS_SI2_F.assign(Shape=None)
                    df_050_059_HS_SI2_F  = df_050_059_HS_SI2_F.assign(Carat=None)
                    df_050_059_HS_SI2_F  = df_050_059_HS_SI2_F.assign(Color=None)
                    df_050_059_HS_SI2_F  = df_050_059_HS_SI2_F.assign(Clarity=None)
                    df_050_059_HS_SI2_F  = df_050_059_HS_SI2_F.assign(Cut=None)
                    df_050_059_HS_SI2_F  = df_050_059_HS_SI2_F.assign(Polish=None)
                    df_050_059_HS_SI2_F  = df_050_059_HS_SI2_F.assign(Symmetry=None)
                    df_050_059_HS_SI2_F  = df_050_059_HS_SI2_F.assign(Ratio=None)
                    df_050_059_HS_SI2_F  = df_050_059_HS_SI2_F.assign(PPC=None)
                    df_050_059_HS_SI2_F  = df_050_059_HS_SI2_F.assign(Total=None)
                    df_050_059_HS_SI2_F ['Wt Range'] = listwtrange
                    df_050_059_HS_SI2_F ['Company'] = listcom
                    df_050_059_HS_SI2_F ['Shape'] = listshap
                    df_050_059_HS_SI2_F ['Carat'] = listcar
                    df_050_059_HS_SI2_F ['Color'] = listcol
                    df_050_059_HS_SI2_F ['Clarity'] = listclar
                    df_050_059_HS_SI2_F ['Cut'] = listcut
                    df_050_059_HS_SI2_F ['Polish'] = listpol
                    df_050_059_HS_SI2_F ['Symmetry'] = listsym
                    df_050_059_HS_SI2_F ['Ratio'] = listrat
                    df_050_059_HS_SI2_F ['PPC'] = listdesc
                    df_050_059_HS_SI2_F ['Total'] = listtotal
                    df_050_059_HS_SI2_F['Carat'] = df_050_059_HS_SI2_F['Carat'].astype('float64')
                    df_050_059_HS_SI2_F['PPC'] = df_050_059_HS_SI2_F['PPC'].astype('float64')
                    df_050_059_HS_SI2_F['Total'] = df_050_059_HS_SI2_F['Total'].astype('float64')
                    df_050_059_HS_SI2_F['Total'] = df_050_059_HS_SI2_F['Carat'] * df_050_059_HS_SI2_F['PPC']


                elif i=="F" and j == "I1" and k == "HS":
                    df_050_059_HS_I1_F = pd.DataFrame()
                    df_050_059_HS_I1_F ['Wt Range'] = None
                    df_050_059_HS_I1_F  = df_050_059_HS_I1_F.assign(Company=None)
                    df_050_059_HS_I1_F  = df_050_059_HS_I1_F.assign(Shape=None)
                    df_050_059_HS_I1_F  = df_050_059_HS_I1_F.assign(Carat=None)
                    df_050_059_HS_I1_F  = df_050_059_HS_I1_F.assign(Color=None)
                    df_050_059_HS_I1_F  = df_050_059_HS_I1_F.assign(Clarity=None)
                    df_050_059_HS_I1_F  = df_050_059_HS_I1_F.assign(Cut=None)
                    df_050_059_HS_I1_F  = df_050_059_HS_I1_F.assign(Polish=None)
                    df_050_059_HS_I1_F  = df_050_059_HS_I1_F.assign(Symmetry=None)
                    df_050_059_HS_I1_F  = df_050_059_HS_I1_F.assign(Ratio=None)
                    df_050_059_HS_I1_F  = df_050_059_HS_I1_F.assign(PPC=None)
                    df_050_059_HS_I1_F  = df_050_059_HS_I1_F.assign(Total=None)
                    df_050_059_HS_I1_F ['Wt Range'] = listwtrange
                    df_050_059_HS_I1_F ['Company'] = listcom
                    df_050_059_HS_I1_F ['Shape'] = listshap
                    df_050_059_HS_I1_F ['Carat'] = listcar
                    df_050_059_HS_I1_F ['Color'] = listcol
                    df_050_059_HS_I1_F ['Clarity'] = listclar
                    df_050_059_HS_I1_F ['Cut'] = listcut
                    df_050_059_HS_I1_F ['Polish'] = listpol
                    df_050_059_HS_I1_F ['Symmetry'] = listsym
                    df_050_059_HS_I1_F ['Ratio'] = listrat
                    df_050_059_HS_I1_F ['PPC'] = listdesc
                    df_050_059_HS_I1_F ['Total'] = listtotal
                    df_050_059_HS_I1_F['Carat'] = df_050_059_HS_I1_F['Carat'].astype('float64')
                    df_050_059_HS_I1_F['PPC'] = df_050_059_HS_I1_F['PPC'].astype('float64')
                    df_050_059_HS_I1_F['Total'] = df_050_059_HS_I1_F['Total'].astype('float64')
                    df_050_059_HS_I1_F['Total'] = df_050_059_HS_I1_F['Carat'] * df_050_059_HS_I1_F['PPC']


                elif i=="F" and j == "I2" and k == "HS":
                    df_050_059_HS_I2_F = pd.DataFrame()
                    df_050_059_HS_I2_F ['Wt Range'] = None
                    df_050_059_HS_I2_F  = df_050_059_HS_I2_F.assign(Company=None)
                    df_050_059_HS_I2_F  = df_050_059_HS_I2_F.assign(Shape=None)
                    df_050_059_HS_I2_F  = df_050_059_HS_I2_F.assign(Carat=None)
                    df_050_059_HS_I2_F  = df_050_059_HS_I2_F.assign(Color=None)
                    df_050_059_HS_I2_F  = df_050_059_HS_I2_F.assign(Clarity=None)
                    df_050_059_HS_I2_F  = df_050_059_HS_I2_F.assign(Cut=None)
                    df_050_059_HS_I2_F  = df_050_059_HS_I2_F.assign(Polish=None)
                    df_050_059_HS_I2_F  = df_050_059_HS_I2_F.assign(Symmetry=None)
                    df_050_059_HS_I2_F  = df_050_059_HS_I2_F.assign(Ratio=None)
                    df_050_059_HS_I2_F  = df_050_059_HS_I2_F.assign(PPC=None)
                    df_050_059_HS_I2_F  = df_050_059_HS_I2_F.assign(Total=None)
                    df_050_059_HS_I2_F ['Wt Range'] = listwtrange
                    df_050_059_HS_I2_F ['Company'] = listcom
                    df_050_059_HS_I2_F ['Shape'] = listshap
                    df_050_059_HS_I2_F ['Carat'] = listcar
                    df_050_059_HS_I2_F ['Color'] = listcol
                    df_050_059_HS_I2_F ['Clarity'] = listclar
                    df_050_059_HS_I2_F ['Cut'] = listcut
                    df_050_059_HS_I2_F ['Polish'] = listpol
                    df_050_059_HS_I2_F ['Symmetry'] = listsym
                    df_050_059_HS_I2_F ['Ratio'] = listrat
                    df_050_059_HS_I2_F ['PPC'] = listdesc
                    df_050_059_HS_I2_F ['Total'] = listtotal
                    df_050_059_HS_I2_F['Carat'] = df_050_059_HS_I2_F['Carat'].astype('float64')
                    df_050_059_HS_I2_F['PPC'] = df_050_059_HS_I2_F['PPC'].astype('float64')
                    df_050_059_HS_I2_F['Total'] = df_050_059_HS_I2_F['Total'].astype('float64')
                    df_050_059_HS_I2_F['Total'] = df_050_059_HS_I2_F['Carat'] * df_050_059_HS_I2_F['PPC']


                elif i=="G" and j == "IF" and k == "HS":
                    df_050_059_HS_IF_G = pd.DataFrame()
                    df_050_059_HS_IF_G ['Wt Range'] = None
                    df_050_059_HS_IF_G  = df_050_059_HS_IF_G.assign(Company=None)
                    df_050_059_HS_IF_G  = df_050_059_HS_IF_G.assign(Shape=None)
                    df_050_059_HS_IF_G  = df_050_059_HS_IF_G.assign(Carat=None)
                    df_050_059_HS_IF_G  = df_050_059_HS_IF_G.assign(Color=None)
                    df_050_059_HS_IF_G  = df_050_059_HS_IF_G.assign(Clarity=None)
                    df_050_059_HS_IF_G  = df_050_059_HS_IF_G.assign(Cut=None)
                    df_050_059_HS_IF_G  = df_050_059_HS_IF_G.assign(Polish=None)
                    df_050_059_HS_IF_G  = df_050_059_HS_IF_G.assign(Symmetry=None)
                    df_050_059_HS_IF_G  = df_050_059_HS_IF_G.assign(Ratio=None)
                    df_050_059_HS_IF_G  = df_050_059_HS_IF_G.assign(PPC=None)
                    df_050_059_HS_IF_G  = df_050_059_HS_IF_G.assign(Total=None)
                    df_050_059_HS_IF_G ['Wt Range'] = listwtrange
                    df_050_059_HS_IF_G ['Company'] = listcom
                    df_050_059_HS_IF_G ['Shape'] = listshap
                    df_050_059_HS_IF_G ['Carat'] = listcar
                    df_050_059_HS_IF_G ['Color'] = listcol
                    df_050_059_HS_IF_G ['Clarity'] = listclar
                    df_050_059_HS_IF_G ['Cut'] = listcut
                    df_050_059_HS_IF_G ['Polish'] = listpol
                    df_050_059_HS_IF_G ['Symmetry'] = listsym
                    df_050_059_HS_IF_G ['Ratio'] = listrat
                    df_050_059_HS_IF_G ['PPC'] = listdesc
                    df_050_059_HS_IF_G ['Total'] = listtotal
                    df_050_059_HS_IF_G['Carat'] = df_050_059_HS_IF_G['Carat'].astype('float64')
                    df_050_059_HS_IF_G['PPC'] = df_050_059_HS_IF_G['PPC'].astype('float64')
                    df_050_059_HS_IF_G['Total'] = df_050_059_HS_IF_G['Total'].astype('float64')
                    df_050_059_HS_IF_G['Total'] = df_050_059_HS_IF_G['Carat'] * df_050_059_HS_IF_G['PPC']



                elif i=="G" and j == "VVS1" and k == "HS":
                    df_050_059_HS_VVS1_G = pd.DataFrame()
                    df_050_059_HS_VVS1_G ['Wt Range'] = None
                    df_050_059_HS_VVS1_G  = df_050_059_HS_VVS1_G.assign(Company=None)
                    df_050_059_HS_VVS1_G  = df_050_059_HS_VVS1_G.assign(Shape=None)
                    df_050_059_HS_VVS1_G  = df_050_059_HS_VVS1_G.assign(Carat=None)
                    df_050_059_HS_VVS1_G  = df_050_059_HS_VVS1_G.assign(Color=None)
                    df_050_059_HS_VVS1_G  = df_050_059_HS_VVS1_G.assign(Clarity=None)
                    df_050_059_HS_VVS1_G  = df_050_059_HS_VVS1_G.assign(Cut=None)
                    df_050_059_HS_VVS1_G  = df_050_059_HS_VVS1_G.assign(Polish=None)
                    df_050_059_HS_VVS1_G  = df_050_059_HS_VVS1_G.assign(Symmetry=None)
                    df_050_059_HS_VVS1_G  = df_050_059_HS_VVS1_G.assign(Ratio=None)
                    df_050_059_HS_VVS1_G  = df_050_059_HS_VVS1_G.assign(PPC=None)
                    df_050_059_HS_VVS1_G  = df_050_059_HS_VVS1_G.assign(Total=None)
                    df_050_059_HS_VVS1_G ['Wt Range'] = listwtrange
                    df_050_059_HS_VVS1_G ['Company'] = listcom
                    df_050_059_HS_VVS1_G ['Shape'] = listshap
                    df_050_059_HS_VVS1_G ['Carat'] = listcar
                    df_050_059_HS_VVS1_G ['Color'] = listcol
                    df_050_059_HS_VVS1_G ['Clarity'] = listclar
                    df_050_059_HS_VVS1_G ['Cut'] = listcut
                    df_050_059_HS_VVS1_G ['Polish'] = listpol
                    df_050_059_HS_VVS1_G ['Symmetry'] = listsym
                    df_050_059_HS_VVS1_G ['Ratio'] = listrat
                    df_050_059_HS_VVS1_G ['PPC'] = listdesc
                    df_050_059_HS_VVS1_G ['Total'] = listtotal
                    df_050_059_HS_VVS1_G['Carat'] = df_050_059_HS_VVS1_G['Carat'].astype('float64')
                    df_050_059_HS_VVS1_G['PPC'] = df_050_059_HS_VVS1_G['PPC'].astype('float64')
                    df_050_059_HS_VVS1_G['Total'] = df_050_059_HS_VVS1_G['Total'].astype('float64')
                    df_050_059_HS_VVS1_G['Total'] = df_050_059_HS_VVS1_G['Carat'] * df_050_059_HS_VVS1_G['PPC']


                elif i=="G" and j == "VVS2" and k == "HS":
                    df_050_059_HS_VVS2_G = pd.DataFrame()
                    df_050_059_HS_VVS2_G ['Wt Range'] = None
                    df_050_059_HS_VVS2_G  = df_050_059_HS_VVS2_G.assign(Company=None)
                    df_050_059_HS_VVS2_G  = df_050_059_HS_VVS2_G.assign(Shape=None)
                    df_050_059_HS_VVS2_G  = df_050_059_HS_VVS2_G.assign(Carat=None)
                    df_050_059_HS_VVS2_G  = df_050_059_HS_VVS2_G.assign(Color=None)
                    df_050_059_HS_VVS2_G  = df_050_059_HS_VVS2_G.assign(Clarity=None)
                    df_050_059_HS_VVS2_G  = df_050_059_HS_VVS2_G.assign(Cut=None)
                    df_050_059_HS_VVS2_G  = df_050_059_HS_VVS2_G.assign(Polish=None)
                    df_050_059_HS_VVS2_G  = df_050_059_HS_VVS2_G.assign(Symmetry=None)
                    df_050_059_HS_VVS2_G  = df_050_059_HS_VVS2_G.assign(Ratio=None)
                    df_050_059_HS_VVS2_G  = df_050_059_HS_VVS2_G.assign(PPC=None)
                    df_050_059_HS_VVS2_G  = df_050_059_HS_VVS2_G.assign(Total=None)
                    df_050_059_HS_VVS2_G ['Wt Range'] = listwtrange
                    df_050_059_HS_VVS2_G ['Company'] = listcom
                    df_050_059_HS_VVS2_G ['Shape'] = listshap
                    df_050_059_HS_VVS2_G ['Carat'] = listcar
                    df_050_059_HS_VVS2_G ['Color'] = listcol
                    df_050_059_HS_VVS2_G ['Clarity'] = listclar
                    df_050_059_HS_VVS2_G ['Cut'] = listcut
                    df_050_059_HS_VVS2_G ['Polish'] = listpol
                    df_050_059_HS_VVS2_G ['Symmetry'] = listsym
                    df_050_059_HS_VVS2_G ['Ratio'] = listrat
                    df_050_059_HS_VVS2_G ['PPC'] = listdesc
                    df_050_059_HS_VVS2_G ['Total'] = listtotal
                    df_050_059_HS_VVS2_G['Carat'] = df_050_059_HS_VVS2_G['Carat'].astype('float64')
                    df_050_059_HS_VVS2_G['PPC'] = df_050_059_HS_VVS2_G['PPC'].astype('float64')
                    df_050_059_HS_VVS2_G['Total'] = df_050_059_HS_VVS2_G['Total'].astype('float64')
                    df_050_059_HS_VVS2_G['Total'] = df_050_059_HS_VVS2_G['Carat'] * df_050_059_HS_VVS2_G['PPC']


                elif i=="G" and j=="VS1" and k == "HS":
                    df_050_059_HS_VS1_G = pd.DataFrame()
                    df_050_059_HS_VS1_G ['Wt Range'] = None
                    df_050_059_HS_VS1_G  = df_050_059_HS_VS1_G.assign(Company=None)
                    df_050_059_HS_VS1_G  = df_050_059_HS_VS1_G.assign(Shape=None)
                    df_050_059_HS_VS1_G  = df_050_059_HS_VS1_G.assign(Carat=None)
                    df_050_059_HS_VS1_G  = df_050_059_HS_VS1_G.assign(Color=None)
                    df_050_059_HS_VS1_G  = df_050_059_HS_VS1_G.assign(Clarity=None)
                    df_050_059_HS_VS1_G  = df_050_059_HS_VS1_G.assign(Cut=None)
                    df_050_059_HS_VS1_G  = df_050_059_HS_VS1_G.assign(Polish=None)
                    df_050_059_HS_VS1_G  = df_050_059_HS_VS1_G.assign(Symmetry=None)
                    df_050_059_HS_VS1_G  = df_050_059_HS_VS1_G.assign(Ratio=None)
                    df_050_059_HS_VS1_G  = df_050_059_HS_VS1_G.assign(PPC=None)
                    df_050_059_HS_VS1_G  = df_050_059_HS_VS1_G.assign(Total=None)
                    df_050_059_HS_VS1_G ['Wt Range'] = listwtrange
                    df_050_059_HS_VS1_G ['Company'] = listcom
                    df_050_059_HS_VS1_G ['Shape'] = listshap
                    df_050_059_HS_VS1_G ['Carat'] = listcar
                    df_050_059_HS_VS1_G ['Color'] = listcol
                    df_050_059_HS_VS1_G ['Clarity'] = listclar
                    df_050_059_HS_VS1_G ['Cut'] = listcut
                    df_050_059_HS_VS1_G ['Polish'] = listpol
                    df_050_059_HS_VS1_G ['Symmetry'] = listsym
                    df_050_059_HS_VS1_G ['Ratio'] = listrat
                    df_050_059_HS_VS1_G ['PPC'] = listdesc
                    df_050_059_HS_VS1_G ['Total'] = listtotal
                    df_050_059_HS_VS1_G['Carat'] = df_050_059_HS_VS1_G['Carat'].astype('float64')
                    df_050_059_HS_VS1_G['PPC'] = df_050_059_HS_VS1_G['PPC'].astype('float64')
                    df_050_059_HS_VS1_G['Total'] = df_050_059_HS_VS1_G['Total'].astype('float64')
                    df_050_059_HS_VS1_G['Total'] = df_050_059_HS_VS1_G['Carat'] * df_050_059_HS_VS1_G['PPC']


                elif i=="G" and j == "VS2" and k == "HS":
                    df_050_059_HS_VS2_G = pd.DataFrame()
                    df_050_059_HS_VS2_G ['Wt Range'] = None
                    df_050_059_HS_VS2_G  = df_050_059_HS_VS2_G.assign(Company=None)
                    df_050_059_HS_VS2_G  = df_050_059_HS_VS2_G.assign(Shape=None)
                    df_050_059_HS_VS2_G  = df_050_059_HS_VS2_G.assign(Carat=None)
                    df_050_059_HS_VS2_G  = df_050_059_HS_VS2_G.assign(Color=None)
                    df_050_059_HS_VS2_G  = df_050_059_HS_VS2_G.assign(Clarity=None)
                    df_050_059_HS_VS2_G  = df_050_059_HS_VS2_G.assign(Cut=None)
                    df_050_059_HS_VS2_G  = df_050_059_HS_VS2_G.assign(Polish=None)
                    df_050_059_HS_VS2_G  = df_050_059_HS_VS2_G.assign(Symmetry=None)
                    df_050_059_HS_VS2_G  = df_050_059_HS_VS2_G.assign(Ratio=None)
                    df_050_059_HS_VS2_G  = df_050_059_HS_VS2_G.assign(PPC=None)
                    df_050_059_HS_VS2_G  = df_050_059_HS_VS2_G.assign(Total=None)
                    df_050_059_HS_VS2_G ['Wt Range'] = listwtrange
                    df_050_059_HS_VS2_G ['Company'] = listcom
                    df_050_059_HS_VS2_G ['Shape'] = listshap
                    df_050_059_HS_VS2_G ['Carat'] = listcar
                    df_050_059_HS_VS2_G ['Color'] = listcol
                    df_050_059_HS_VS2_G ['Clarity'] = listclar
                    df_050_059_HS_VS2_G ['Cut'] = listcut
                    df_050_059_HS_VS2_G ['Polish'] = listpol
                    df_050_059_HS_VS2_G ['Symmetry'] = listsym
                    df_050_059_HS_VS2_G ['Ratio'] = listrat
                    df_050_059_HS_VS2_G ['PPC'] = listdesc
                    df_050_059_HS_VS2_G ['Total'] = listtotal
                    df_050_059_HS_VS2_G['Carat'] = df_050_059_HS_VS2_G['Carat'].astype('float64')
                    df_050_059_HS_VS2_G['PPC'] = df_050_059_HS_VS2_G['PPC'].astype('float64')
                    df_050_059_HS_VS2_G['Total'] = df_050_059_HS_VS2_G['Total'].astype('float64')
                    df_050_059_HS_VS2_G['Total'] = df_050_059_HS_VS2_G['Carat'] * df_050_059_HS_VS2_G['PPC']


                elif i=="G" and j == "SI1" and k == "HS":
                    df_050_059_HS_SI1_G = pd.DataFrame()
                    df_050_059_HS_SI1_G ['Wt Range'] = None
                    df_050_059_HS_SI1_G  = df_050_059_HS_SI1_G.assign(Company=None)
                    df_050_059_HS_SI1_G  = df_050_059_HS_SI1_G.assign(Shape=None)
                    df_050_059_HS_SI1_G  = df_050_059_HS_SI1_G.assign(Carat=None)
                    df_050_059_HS_SI1_G  = df_050_059_HS_SI1_G.assign(Color=None)
                    df_050_059_HS_SI1_G  = df_050_059_HS_SI1_G.assign(Clarity=None)
                    df_050_059_HS_SI1_G  = df_050_059_HS_SI1_G.assign(Cut=None)
                    df_050_059_HS_SI1_G  = df_050_059_HS_SI1_G.assign(Polish=None)
                    df_050_059_HS_SI1_G  = df_050_059_HS_SI1_G.assign(Symmetry=None)
                    df_050_059_HS_SI1_G  = df_050_059_HS_SI1_G.assign(Ratio=None)
                    df_050_059_HS_SI1_G  = df_050_059_HS_SI1_G.assign(PPC=None)
                    df_050_059_HS_SI1_G  = df_050_059_HS_SI1_G.assign(Total=None)
                    df_050_059_HS_SI1_G ['Wt Range'] = listwtrange
                    df_050_059_HS_SI1_G ['Company'] = listcom
                    df_050_059_HS_SI1_G ['Shape'] = listshap
                    df_050_059_HS_SI1_G ['Carat'] = listcar
                    df_050_059_HS_SI1_G ['Color'] = listcol
                    df_050_059_HS_SI1_G ['Clarity'] = listclar
                    df_050_059_HS_SI1_G ['Cut'] = listcut
                    df_050_059_HS_SI1_G ['Polish'] = listpol
                    df_050_059_HS_SI1_G ['Symmetry'] = listsym
                    df_050_059_HS_SI1_G ['Ratio'] = listrat
                    df_050_059_HS_SI1_G ['PPC'] = listdesc
                    df_050_059_HS_SI1_G ['Total'] = listtotal
                    df_050_059_HS_SI1_G['Carat'] = df_050_059_HS_SI1_G['Carat'].astype('float64')
                    df_050_059_HS_SI1_G['PPC'] = df_050_059_HS_SI1_G['PPC'].astype('float64')
                    df_050_059_HS_SI1_G['Total'] = df_050_059_HS_SI1_G['Total'].astype('float64')
                    df_050_059_HS_SI1_G['Total'] = df_050_059_HS_SI1_G['Carat'] * df_050_059_HS_SI1_G['PPC']


                elif i=="G" and j == "SI2" and k == "HS":
                    df_050_059_HS_SI2_G = pd.DataFrame()
                    df_050_059_HS_SI2_G ['Wt Range'] = None
                    df_050_059_HS_SI2_G  = df_050_059_HS_SI2_G.assign(Company=None)
                    df_050_059_HS_SI2_G  = df_050_059_HS_SI2_G.assign(Shape=None)
                    df_050_059_HS_SI2_G  = df_050_059_HS_SI2_G.assign(Carat=None)
                    df_050_059_HS_SI2_G  = df_050_059_HS_SI2_G.assign(Color=None)
                    df_050_059_HS_SI2_G  = df_050_059_HS_SI2_G.assign(Clarity=None)
                    df_050_059_HS_SI2_G  = df_050_059_HS_SI2_G.assign(Cut=None)
                    df_050_059_HS_SI2_G  = df_050_059_HS_SI2_G.assign(Polish=None)
                    df_050_059_HS_SI2_G  = df_050_059_HS_SI2_G.assign(Symmetry=None)
                    df_050_059_HS_SI2_G  = df_050_059_HS_SI2_G.assign(Ratio=None)
                    df_050_059_HS_SI2_G  = df_050_059_HS_SI2_G.assign(PPC=None)
                    df_050_059_HS_SI2_G  = df_050_059_HS_SI2_G.assign(Total=None)
                    df_050_059_HS_SI2_G ['Wt Range'] = listwtrange
                    df_050_059_HS_SI2_G ['Company'] = listcom
                    df_050_059_HS_SI2_G ['Shape'] = listshap
                    df_050_059_HS_SI2_G ['Carat'] = listcar
                    df_050_059_HS_SI2_G ['Color'] = listcol
                    df_050_059_HS_SI2_G ['Clarity'] = listclar
                    df_050_059_HS_SI2_G ['Cut'] = listcut
                    df_050_059_HS_SI2_G ['Polish'] = listpol
                    df_050_059_HS_SI2_G ['Symmetry'] = listsym
                    df_050_059_HS_SI2_G ['Ratio'] = listrat
                    df_050_059_HS_SI2_G ['PPC'] = listdesc
                    df_050_059_HS_SI2_G ['Total'] = listtotal
                    df_050_059_HS_SI2_G['Carat'] = df_050_059_HS_SI2_G['Carat'].astype('float64')
                    df_050_059_HS_SI2_G['PPC'] = df_050_059_HS_SI2_G['PPC'].astype('float64')
                    df_050_059_HS_SI2_G['Total'] = df_050_059_HS_SI2_G['Total'].astype('float64')
                    df_050_059_HS_SI2_G['Total'] = df_050_059_HS_SI2_G['Carat'] * df_050_059_HS_SI2_G['PPC']


                elif i=="G" and j == "I1" and k == "HS":
                    df_050_059_HS_I1_G = pd.DataFrame()
                    df_050_059_HS_I1_G ['Wt Range'] = None
                    df_050_059_HS_I1_G  = df_050_059_HS_I1_G.assign(Company=None)
                    df_050_059_HS_I1_G  = df_050_059_HS_I1_G.assign(Shape=None)
                    df_050_059_HS_I1_G  = df_050_059_HS_I1_G.assign(Carat=None)
                    df_050_059_HS_I1_G  = df_050_059_HS_I1_G.assign(Color=None)
                    df_050_059_HS_I1_G  = df_050_059_HS_I1_G.assign(Clarity=None)
                    df_050_059_HS_I1_G  = df_050_059_HS_I1_G.assign(Cut=None)
                    df_050_059_HS_I1_G  = df_050_059_HS_I1_G.assign(Polish=None)
                    df_050_059_HS_I1_G  = df_050_059_HS_I1_G.assign(Symmetry=None)
                    df_050_059_HS_I1_G  = df_050_059_HS_I1_G.assign(Ratio=None)
                    df_050_059_HS_I1_G  = df_050_059_HS_I1_G.assign(PPC=None)
                    df_050_059_HS_I1_G  = df_050_059_HS_I1_G.assign(Total=None)
                    df_050_059_HS_I1_G ['Wt Range'] = listwtrange
                    df_050_059_HS_I1_G ['Company'] = listcom
                    df_050_059_HS_I1_G ['Shape'] = listshap
                    df_050_059_HS_I1_G ['Carat'] = listcar
                    df_050_059_HS_I1_G ['Color'] = listcol
                    df_050_059_HS_I1_G ['Clarity'] = listclar
                    df_050_059_HS_I1_G ['Cut'] = listcut
                    df_050_059_HS_I1_G ['Polish'] = listpol
                    df_050_059_HS_I1_G ['Symmetry'] = listsym
                    df_050_059_HS_I1_G ['Ratio'] = listrat
                    df_050_059_HS_I1_G ['PPC'] = listdesc
                    df_050_059_HS_I1_G ['Total'] = listtotal
                    df_050_059_HS_I1_G['Carat'] = df_050_059_HS_I1_G['Carat'].astype('float64')
                    df_050_059_HS_I1_G['PPC'] = df_050_059_HS_I1_G['PPC'].astype('float64')
                    df_050_059_HS_I1_G['Total'] = df_050_059_HS_I1_G['Total'].astype('float64')
                    df_050_059_HS_I1_G['Total'] = df_050_059_HS_I1_G['Carat'] * df_050_059_HS_I1_G['PPC']


                elif i=="G" and j == "I2" and k == "HS":
                    df_050_059_HS_I2_G = pd.DataFrame()
                    df_050_059_HS_I2_G ['Wt Range'] = None
                    df_050_059_HS_I2_G  = df_050_059_HS_I2_G.assign(Company=None)
                    df_050_059_HS_I2_G  = df_050_059_HS_I2_G.assign(Shape=None)
                    df_050_059_HS_I2_G  = df_050_059_HS_I2_G.assign(Carat=None)
                    df_050_059_HS_I2_G  = df_050_059_HS_I2_G.assign(Color=None)
                    df_050_059_HS_I2_G  = df_050_059_HS_I2_G.assign(Clarity=None)
                    df_050_059_HS_I2_G  = df_050_059_HS_I2_G.assign(Cut=None)
                    df_050_059_HS_I2_G  = df_050_059_HS_I2_G.assign(Polish=None)
                    df_050_059_HS_I2_G  = df_050_059_HS_I2_G.assign(Symmetry=None)
                    df_050_059_HS_I2_G  = df_050_059_HS_I2_G.assign(Ratio=None)
                    df_050_059_HS_I2_G  = df_050_059_HS_I2_G.assign(PPC=None)
                    df_050_059_HS_I2_G  = df_050_059_HS_I2_G.assign(Total=None)
                    df_050_059_HS_I2_G ['Wt Range'] = listwtrange
                    df_050_059_HS_I2_G ['Company'] = listcom
                    df_050_059_HS_I2_G ['Shape'] = listshap
                    df_050_059_HS_I2_G ['Carat'] = listcar
                    df_050_059_HS_I2_G ['Color'] = listcol
                    df_050_059_HS_I2_G ['Clarity'] = listclar
                    df_050_059_HS_I2_G ['Cut'] = listcut
                    df_050_059_HS_I2_G ['Polish'] = listpol
                    df_050_059_HS_I2_G ['Symmetry'] = listsym
                    df_050_059_HS_I2_G ['Ratio'] = listrat
                    df_050_059_HS_I2_G ['PPC'] = listdesc
                    df_050_059_HS_I2_G ['Total'] = listtotal
                    df_050_059_HS_I2_G['Carat'] = df_050_059_HS_I2_G['Carat'].astype('float64')
                    df_050_059_HS_I2_G['PPC'] = df_050_059_HS_I2_G['PPC'].astype('float64')
                    df_050_059_HS_I2_G['Total'] = df_050_059_HS_I2_G['Total'].astype('float64')
                    df_050_059_HS_I2_G['Total'] = df_050_059_HS_I2_G['Carat'] * df_050_059_HS_I2_G['PPC']


                elif i=="H" and j == "IF" and k == "HS":
                    df_050_059_HS_IF_H = pd.DataFrame()
                    df_050_059_HS_IF_H ['Wt Range'] = None
                    df_050_059_HS_IF_H  = df_050_059_HS_IF_H.assign(Company=None)
                    df_050_059_HS_IF_H  = df_050_059_HS_IF_H.assign(Shape=None)
                    df_050_059_HS_IF_H  = df_050_059_HS_IF_H.assign(Carat=None)
                    df_050_059_HS_IF_H  = df_050_059_HS_IF_H.assign(Color=None)
                    df_050_059_HS_IF_H  = df_050_059_HS_IF_H.assign(Clarity=None)
                    df_050_059_HS_IF_H  = df_050_059_HS_IF_H.assign(Cut=None)
                    df_050_059_HS_IF_H  = df_050_059_HS_IF_H.assign(Polish=None)
                    df_050_059_HS_IF_H  = df_050_059_HS_IF_H.assign(Symmetry=None)
                    df_050_059_HS_IF_H  = df_050_059_HS_IF_H.assign(Ratio=None)
                    df_050_059_HS_IF_H  = df_050_059_HS_IF_H.assign(PPC=None)
                    df_050_059_HS_IF_H  = df_050_059_HS_IF_H.assign(Total=None)
                    df_050_059_HS_IF_H ['Wt Range'] = listwtrange
                    df_050_059_HS_IF_H ['Company'] = listcom
                    df_050_059_HS_IF_H ['Shape'] = listshap
                    df_050_059_HS_IF_H ['Carat'] = listcar
                    df_050_059_HS_IF_H ['Color'] = listcol
                    df_050_059_HS_IF_H ['Clarity'] = listclar
                    df_050_059_HS_IF_H ['Cut'] = listcut
                    df_050_059_HS_IF_H ['Polish'] = listpol
                    df_050_059_HS_IF_H ['Symmetry'] = listsym
                    df_050_059_HS_IF_H ['Ratio'] = listrat
                    df_050_059_HS_IF_H ['PPC'] = listdesc
                    df_050_059_HS_IF_H ['Total'] = listtotal
                    df_050_059_HS_IF_H['Carat'] = df_050_059_HS_IF_H['Carat'].astype('float64')
                    df_050_059_HS_IF_H['PPC'] = df_050_059_HS_IF_H['PPC'].astype('float64')
                    df_050_059_HS_IF_H['Total'] = df_050_059_HS_IF_H['Total'].astype('float64')
                    df_050_059_HS_IF_H['Total'] = df_050_059_HS_IF_H['Carat'] * df_050_059_HS_IF_H['PPC']



                elif i=="H" and j == "VVS1" and k == "HS":
                    df_050_059_HS_VVS1_H = pd.DataFrame()
                    df_050_059_HS_VVS1_H ['Wt Range'] = None
                    df_050_059_HS_VVS1_H  = df_050_059_HS_VVS1_H.assign(Company=None)
                    df_050_059_HS_VVS1_H  = df_050_059_HS_VVS1_H.assign(Shape=None)
                    df_050_059_HS_VVS1_H  = df_050_059_HS_VVS1_H.assign(Carat=None)
                    df_050_059_HS_VVS1_H  = df_050_059_HS_VVS1_H.assign(Color=None)
                    df_050_059_HS_VVS1_H  = df_050_059_HS_VVS1_H.assign(Clarity=None)
                    df_050_059_HS_VVS1_H  = df_050_059_HS_VVS1_H.assign(Cut=None)
                    df_050_059_HS_VVS1_H  = df_050_059_HS_VVS1_H.assign(Polish=None)
                    df_050_059_HS_VVS1_H  = df_050_059_HS_VVS1_H.assign(Symmetry=None)
                    df_050_059_HS_VVS1_H  = df_050_059_HS_VVS1_H.assign(Ratio=None)
                    df_050_059_HS_VVS1_H  = df_050_059_HS_VVS1_H.assign(PPC=None)
                    df_050_059_HS_VVS1_H  = df_050_059_HS_VVS1_H.assign(Total=None)
                    df_050_059_HS_VVS1_H ['Wt Range'] = listwtrange
                    df_050_059_HS_VVS1_H ['Company'] = listcom
                    df_050_059_HS_VVS1_H ['Shape'] = listshap
                    df_050_059_HS_VVS1_H ['Carat'] = listcar
                    df_050_059_HS_VVS1_H ['Color'] = listcol
                    df_050_059_HS_VVS1_H ['Clarity'] = listclar
                    df_050_059_HS_VVS1_H ['Cut'] = listcut
                    df_050_059_HS_VVS1_H ['Polish'] = listpol
                    df_050_059_HS_VVS1_H ['Symmetry'] = listsym
                    df_050_059_HS_VVS1_H ['Ratio'] = listrat
                    df_050_059_HS_VVS1_H ['PPC'] = listdesc
                    df_050_059_HS_VVS1_H ['Total'] = listtotal
                    df_050_059_HS_VVS1_H['Carat'] = df_050_059_HS_VVS1_H['Carat'].astype('float64')
                    df_050_059_HS_VVS1_H['PPC'] = df_050_059_HS_VVS1_H['PPC'].astype('float64')
                    df_050_059_HS_VVS1_H['Total'] = df_050_059_HS_VVS1_H['Total'].astype('float64')
                    df_050_059_HS_VVS1_H['Total'] = df_050_059_HS_VVS1_H['Carat'] * df_050_059_HS_VVS1_H['PPC']


                elif i=="H" and j == "VVS2" and k == "HS":
                    df_050_059_HS_VVS2_H = pd.DataFrame()
                    df_050_059_HS_VVS2_H ['Wt Range'] = None
                    df_050_059_HS_VVS2_H  = df_050_059_HS_VVS2_H.assign(Company=None)
                    df_050_059_HS_VVS2_H  = df_050_059_HS_VVS2_H.assign(Shape=None)
                    df_050_059_HS_VVS2_H  = df_050_059_HS_VVS2_H.assign(Carat=None)
                    df_050_059_HS_VVS2_H  = df_050_059_HS_VVS2_H.assign(Color=None)
                    df_050_059_HS_VVS2_H  = df_050_059_HS_VVS2_H.assign(Clarity=None)
                    df_050_059_HS_VVS2_H  = df_050_059_HS_VVS2_H.assign(Cut=None)
                    df_050_059_HS_VVS2_H  = df_050_059_HS_VVS2_H.assign(Polish=None)
                    df_050_059_HS_VVS2_H  = df_050_059_HS_VVS2_H.assign(Symmetry=None)
                    df_050_059_HS_VVS2_H  = df_050_059_HS_VVS2_H.assign(Ratio=None)
                    df_050_059_HS_VVS2_H  = df_050_059_HS_VVS2_H.assign(PPC=None)
                    df_050_059_HS_VVS2_H  = df_050_059_HS_VVS2_H.assign(Total=None)
                    df_050_059_HS_VVS2_H ['Wt Range'] = listwtrange
                    df_050_059_HS_VVS2_H ['Company'] = listcom
                    df_050_059_HS_VVS2_H ['Shape'] = listshap
                    df_050_059_HS_VVS2_H ['Carat'] = listcar
                    df_050_059_HS_VVS2_H ['Color'] = listcol
                    df_050_059_HS_VVS2_H ['Clarity'] = listclar
                    df_050_059_HS_VVS2_H ['Cut'] = listcut
                    df_050_059_HS_VVS2_H ['Polish'] = listpol
                    df_050_059_HS_VVS2_H ['Symmetry'] = listsym
                    df_050_059_HS_VVS2_H ['Ratio'] = listrat
                    df_050_059_HS_VVS2_H ['PPC'] = listdesc
                    df_050_059_HS_VVS2_H ['Total'] = listtotal
                    df_050_059_HS_VVS2_H['Carat'] = df_050_059_HS_VVS2_H['Carat'].astype('float64')
                    df_050_059_HS_VVS2_H['PPC'] = df_050_059_HS_VVS2_H['PPC'].astype('float64')
                    df_050_059_HS_VVS2_H['Total'] = df_050_059_HS_VVS2_H['Total'].astype('float64')
                    df_050_059_HS_VVS2_H['Total'] = df_050_059_HS_VVS2_H['Carat'] * df_050_059_HS_VVS2_H['PPC']


                elif i=="H" and j=="VS1" and k == "HS":
                    df_050_059_HS_VS1_H = pd.DataFrame()
                    df_050_059_HS_VS1_H ['Wt Range'] = None
                    df_050_059_HS_VS1_H  = df_050_059_HS_VS1_H.assign(Company=None)
                    df_050_059_HS_VS1_H  = df_050_059_HS_VS1_H.assign(Shape=None)
                    df_050_059_HS_VS1_H  = df_050_059_HS_VS1_H.assign(Carat=None)
                    df_050_059_HS_VS1_H  = df_050_059_HS_VS1_H.assign(Color=None)
                    df_050_059_HS_VS1_H  = df_050_059_HS_VS1_H.assign(Clarity=None)
                    df_050_059_HS_VS1_H  = df_050_059_HS_VS1_H.assign(Cut=None)
                    df_050_059_HS_VS1_H  = df_050_059_HS_VS1_H.assign(Polish=None)
                    df_050_059_HS_VS1_H  = df_050_059_HS_VS1_H.assign(Symmetry=None)
                    df_050_059_HS_VS1_H  = df_050_059_HS_VS1_H.assign(Ratio=None)
                    df_050_059_HS_VS1_H  = df_050_059_HS_VS1_H.assign(PPC=None)
                    df_050_059_HS_VS1_H  = df_050_059_HS_VS1_H.assign(Total=None)
                    df_050_059_HS_VS1_H ['Wt Range'] = listwtrange
                    df_050_059_HS_VS1_H ['Company'] = listcom
                    df_050_059_HS_VS1_H ['Shape'] = listshap
                    df_050_059_HS_VS1_H ['Carat'] = listcar
                    df_050_059_HS_VS1_H ['Color'] = listcol
                    df_050_059_HS_VS1_H ['Clarity'] = listclar
                    df_050_059_HS_VS1_H ['Cut'] = listcut
                    df_050_059_HS_VS1_H ['Polish'] = listpol
                    df_050_059_HS_VS1_H ['Symmetry'] = listsym
                    df_050_059_HS_VS1_H ['Ratio'] = listrat
                    df_050_059_HS_VS1_H ['PPC'] = listdesc
                    df_050_059_HS_VS1_H ['Total'] = listtotal
                    df_050_059_HS_VS1_H['Carat'] = df_050_059_HS_VS1_H['Carat'].astype('float64')
                    df_050_059_HS_VS1_H['PPC'] = df_050_059_HS_VS1_H['PPC'].astype('float64')
                    df_050_059_HS_VS1_H['Total'] = df_050_059_HS_VS1_H['Total'].astype('float64')
                    df_050_059_HS_VS1_H['Total'] = df_050_059_HS_VS1_H['Carat'] * df_050_059_HS_VS1_H['PPC']


                elif i=="H" and j == "VS2" and k == "HS":
                    df_050_059_HS_VS2_H = pd.DataFrame()
                    df_050_059_HS_VS2_H ['Wt Range'] = None
                    df_050_059_HS_VS2_H  = df_050_059_HS_VS2_H.assign(Company=None)
                    df_050_059_HS_VS2_H  = df_050_059_HS_VS2_H.assign(Shape=None)
                    df_050_059_HS_VS2_H  = df_050_059_HS_VS2_H.assign(Carat=None)
                    df_050_059_HS_VS2_H  = df_050_059_HS_VS2_H.assign(Color=None)
                    df_050_059_HS_VS2_H  = df_050_059_HS_VS2_H.assign(Clarity=None)
                    df_050_059_HS_VS2_H  = df_050_059_HS_VS2_H.assign(Cut=None)
                    df_050_059_HS_VS2_H  = df_050_059_HS_VS2_H.assign(Polish=None)
                    df_050_059_HS_VS2_H  = df_050_059_HS_VS2_H.assign(Symmetry=None)
                    df_050_059_HS_VS2_H  = df_050_059_HS_VS2_H.assign(Ratio=None)
                    df_050_059_HS_VS2_H  = df_050_059_HS_VS2_H.assign(PPC=None)
                    df_050_059_HS_VS2_H  = df_050_059_HS_VS2_H.assign(Total=None)
                    df_050_059_HS_VS2_H ['Wt Range'] = listwtrange
                    df_050_059_HS_VS2_H ['Company'] = listcom
                    df_050_059_HS_VS2_H ['Shape'] = listshap
                    df_050_059_HS_VS2_H ['Carat'] = listcar
                    df_050_059_HS_VS2_H ['Color'] = listcol
                    df_050_059_HS_VS2_H ['Clarity'] = listclar
                    df_050_059_HS_VS2_H ['Cut'] = listcut
                    df_050_059_HS_VS2_H ['Polish'] = listpol
                    df_050_059_HS_VS2_H ['Symmetry'] = listsym
                    df_050_059_HS_VS2_H ['Ratio'] = listrat
                    df_050_059_HS_VS2_H ['PPC'] = listdesc
                    df_050_059_HS_VS2_H ['Total'] = listtotal
                    df_050_059_HS_VS2_H['Carat'] = df_050_059_HS_VS2_H['Carat'].astype('float64')
                    df_050_059_HS_VS2_H['PPC'] = df_050_059_HS_VS2_H['PPC'].astype('float64')
                    df_050_059_HS_VS2_H['Total'] = df_050_059_HS_VS2_H['Total'].astype('float64')
                    df_050_059_HS_VS2_H['Total'] = df_050_059_HS_VS2_H['Carat'] * df_050_059_HS_VS2_H['PPC']


                elif i=="H" and j == "SI1" and k == "HS":
                    df_050_059_HS_SI1_H = pd.DataFrame()
                    df_050_059_HS_SI1_H ['Wt Range'] = None
                    df_050_059_HS_SI1_H  = df_050_059_HS_SI1_H.assign(Company=None)
                    df_050_059_HS_SI1_H  = df_050_059_HS_SI1_H.assign(Shape=None)
                    df_050_059_HS_SI1_H  = df_050_059_HS_SI1_H.assign(Carat=None)
                    df_050_059_HS_SI1_H  = df_050_059_HS_SI1_H.assign(Color=None)
                    df_050_059_HS_SI1_H  = df_050_059_HS_SI1_H.assign(Clarity=None)
                    df_050_059_HS_SI1_H  = df_050_059_HS_SI1_H.assign(Cut=None)
                    df_050_059_HS_SI1_H  = df_050_059_HS_SI1_H.assign(Polish=None)
                    df_050_059_HS_SI1_H  = df_050_059_HS_SI1_H.assign(Symmetry=None)
                    df_050_059_HS_SI1_H  = df_050_059_HS_SI1_H.assign(Ratio=None)
                    df_050_059_HS_SI1_H  = df_050_059_HS_SI1_H.assign(PPC=None)
                    df_050_059_HS_SI1_H  = df_050_059_HS_SI1_H.assign(Total=None)
                    df_050_059_HS_SI1_H ['Wt Range'] = listwtrange
                    df_050_059_HS_SI1_H ['Company'] = listcom
                    df_050_059_HS_SI1_H ['Shape'] = listshap
                    df_050_059_HS_SI1_H ['Carat'] = listcar
                    df_050_059_HS_SI1_H ['Color'] = listcol
                    df_050_059_HS_SI1_H ['Clarity'] = listclar
                    df_050_059_HS_SI1_H ['Cut'] = listcut
                    df_050_059_HS_SI1_H ['Polish'] = listpol
                    df_050_059_HS_SI1_H ['Symmetry'] = listsym
                    df_050_059_HS_SI1_H ['Ratio'] = listrat
                    df_050_059_HS_SI1_H ['PPC'] = listdesc
                    df_050_059_HS_SI1_H ['Total'] = listtotal
                    df_050_059_HS_SI1_H['Carat'] = df_050_059_HS_SI1_H['Carat'].astype('float64')
                    df_050_059_HS_SI1_H['PPC'] = df_050_059_HS_SI1_H['PPC'].astype('float64')
                    df_050_059_HS_SI1_H['Total'] = df_050_059_HS_SI1_H['Total'].astype('float64')
                    df_050_059_HS_SI1_H['Total'] = df_050_059_HS_SI1_H['Carat'] * df_050_059_HS_SI1_H['PPC']


                elif i=="H" and j == "SI2" and k == "HS":
                    df_050_059_HS_SI2_H = pd.DataFrame()
                    df_050_059_HS_SI2_H ['Wt Range'] = None
                    df_050_059_HS_SI2_H  = df_050_059_HS_SI2_H.assign(Company=None)
                    df_050_059_HS_SI2_H  = df_050_059_HS_SI2_H.assign(Shape=None)
                    df_050_059_HS_SI2_H  = df_050_059_HS_SI2_H.assign(Carat=None)
                    df_050_059_HS_SI2_H  = df_050_059_HS_SI2_H.assign(Color=None)
                    df_050_059_HS_SI2_H  = df_050_059_HS_SI2_H.assign(Clarity=None)
                    df_050_059_HS_SI2_H  = df_050_059_HS_SI2_H.assign(Cut=None)
                    df_050_059_HS_SI2_H  = df_050_059_HS_SI2_H.assign(Polish=None)
                    df_050_059_HS_SI2_H  = df_050_059_HS_SI2_H.assign(Symmetry=None)
                    df_050_059_HS_SI2_H  = df_050_059_HS_SI2_H.assign(Ratio=None)
                    df_050_059_HS_SI2_H  = df_050_059_HS_SI2_H.assign(PPC=None)
                    df_050_059_HS_SI2_H  = df_050_059_HS_SI2_H.assign(Total=None)
                    df_050_059_HS_SI2_H ['Wt Range'] = listwtrange
                    df_050_059_HS_SI2_H ['Company'] = listcom
                    df_050_059_HS_SI2_H ['Shape'] = listshap
                    df_050_059_HS_SI2_H ['Carat'] = listcar
                    df_050_059_HS_SI2_H ['Color'] = listcol
                    df_050_059_HS_SI2_H ['Clarity'] = listclar
                    df_050_059_HS_SI2_H ['Cut'] = listcut
                    df_050_059_HS_SI2_H ['Polish'] = listpol
                    df_050_059_HS_SI2_H ['Symmetry'] = listsym
                    df_050_059_HS_SI2_H ['Ratio'] = listrat
                    df_050_059_HS_SI2_H ['PPC'] = listdesc
                    df_050_059_HS_SI2_H ['Total'] = listtotal
                    df_050_059_HS_SI2_H['Carat'] = df_050_059_HS_SI2_H['Carat'].astype('float64')
                    df_050_059_HS_SI2_H['PPC'] = df_050_059_HS_SI2_H['PPC'].astype('float64')
                    df_050_059_HS_SI2_H['Total'] = df_050_059_HS_SI2_H['Total'].astype('float64')
                    df_050_059_HS_SI2_H['Total'] = df_050_059_HS_SI2_H['Carat'] * df_050_059_HS_SI2_H['PPC']


                elif i=="H" and j == "I1" and k == "HS":
                    df_050_059_HS_I1_H = pd.DataFrame()
                    df_050_059_HS_I1_H ['Wt Range'] = None
                    df_050_059_HS_I1_H  = df_050_059_HS_I1_H.assign(Company=None)
                    df_050_059_HS_I1_H  = df_050_059_HS_I1_H.assign(Shape=None)
                    df_050_059_HS_I1_H  = df_050_059_HS_I1_H.assign(Carat=None)
                    df_050_059_HS_I1_H  = df_050_059_HS_I1_H.assign(Color=None)
                    df_050_059_HS_I1_H  = df_050_059_HS_I1_H.assign(Clarity=None)
                    df_050_059_HS_I1_H  = df_050_059_HS_I1_H.assign(Cut=None)
                    df_050_059_HS_I1_H  = df_050_059_HS_I1_H.assign(Polish=None)
                    df_050_059_HS_I1_H  = df_050_059_HS_I1_H.assign(Symmetry=None)
                    df_050_059_HS_I1_H  = df_050_059_HS_I1_H.assign(Ratio=None)
                    df_050_059_HS_I1_H  = df_050_059_HS_I1_H.assign(PPC=None)
                    df_050_059_HS_I1_H  = df_050_059_HS_I1_H.assign(Total=None)
                    df_050_059_HS_I1_H ['Wt Range'] = listwtrange
                    df_050_059_HS_I1_H ['Company'] = listcom
                    df_050_059_HS_I1_H ['Shape'] = listshap
                    df_050_059_HS_I1_H ['Carat'] = listcar
                    df_050_059_HS_I1_H ['Color'] = listcol
                    df_050_059_HS_I1_H ['Clarity'] = listclar
                    df_050_059_HS_I1_H ['Cut'] = listcut
                    df_050_059_HS_I1_H ['Polish'] = listpol
                    df_050_059_HS_I1_H ['Symmetry'] = listsym
                    df_050_059_HS_I1_H ['Ratio'] = listrat
                    df_050_059_HS_I1_H ['PPC'] = listdesc
                    df_050_059_HS_I1_H ['Total'] = listtotal
                    df_050_059_HS_I1_H['Carat'] = df_050_059_HS_I1_H['Carat'].astype('float64')
                    df_050_059_HS_I1_H['PPC'] = df_050_059_HS_I1_H['PPC'].astype('float64')
                    df_050_059_HS_I1_H['Total'] = df_050_059_HS_I1_H['Total'].astype('float64')
                    df_050_059_HS_I1_H['Total'] = df_050_059_HS_I1_H['Carat'] * df_050_059_HS_I1_H['PPC']


                elif i=="H" and j == "I2" and k == "HS":
                    df_050_059_HS_I2_H = pd.DataFrame()
                    df_050_059_HS_I2_H ['Wt Range'] = None
                    df_050_059_HS_I2_H  = df_050_059_HS_I2_H.assign(Company=None)
                    df_050_059_HS_I2_H  = df_050_059_HS_I2_H.assign(Shape=None)
                    df_050_059_HS_I2_H  = df_050_059_HS_I2_H.assign(Carat=None)
                    df_050_059_HS_I2_H  = df_050_059_HS_I2_H.assign(Color=None)
                    df_050_059_HS_I2_H  = df_050_059_HS_I2_H.assign(Clarity=None)
                    df_050_059_HS_I2_H  = df_050_059_HS_I2_H.assign(Cut=None)
                    df_050_059_HS_I2_H  = df_050_059_HS_I2_H.assign(Polish=None)
                    df_050_059_HS_I2_H  = df_050_059_HS_I2_H.assign(Symmetry=None)
                    df_050_059_HS_I2_H  = df_050_059_HS_I2_H.assign(Ratio=None)
                    df_050_059_HS_I2_H  = df_050_059_HS_I2_H.assign(PPC=None)
                    df_050_059_HS_I2_H  = df_050_059_HS_I2_H.assign(Total=None)
                    df_050_059_HS_I2_H ['Wt Range'] = listwtrange
                    df_050_059_HS_I2_H ['Company'] = listcom
                    df_050_059_HS_I2_H ['Shape'] = listshap
                    df_050_059_HS_I2_H ['Carat'] = listcar
                    df_050_059_HS_I2_H ['Color'] = listcol
                    df_050_059_HS_I2_H ['Clarity'] = listclar
                    df_050_059_HS_I2_H ['Cut'] = listcut
                    df_050_059_HS_I2_H ['Polish'] = listpol
                    df_050_059_HS_I2_H ['Symmetry'] = listsym
                    df_050_059_HS_I2_H ['Ratio'] = listrat
                    df_050_059_HS_I2_H ['PPC'] = listdesc
                    df_050_059_HS_I2_H ['Total'] = listtotal
                    df_050_059_HS_I2_H['Carat'] = df_050_059_HS_I2_H['Carat'].astype('float64')
                    df_050_059_HS_I2_H['PPC'] = df_050_059_HS_I2_H['PPC'].astype('float64')
                    df_050_059_HS_I2_H['Total'] = df_050_059_HS_I2_H['Total'].astype('float64')
                    df_050_059_HS_I2_H['Total'] = df_050_059_HS_I2_H['Carat'] * df_050_059_HS_I2_H['PPC']



                elif i== "I" and j == "IF" and k == "HS":
                    df_050_059_HS_IF_I = pd.DataFrame()
                    df_050_059_HS_IF_I ['Wt Range'] = None
                    df_050_059_HS_IF_I  = df_050_059_HS_IF_I.assign(Company=None)
                    df_050_059_HS_IF_I  = df_050_059_HS_IF_I.assign(Shape=None)
                    df_050_059_HS_IF_I  = df_050_059_HS_IF_I.assign(Carat=None)
                    df_050_059_HS_IF_I  = df_050_059_HS_IF_I.assign(Color=None)
                    df_050_059_HS_IF_I  = df_050_059_HS_IF_I.assign(Clarity=None)
                    df_050_059_HS_IF_I  = df_050_059_HS_IF_I.assign(Cut=None)
                    df_050_059_HS_IF_I  = df_050_059_HS_IF_I.assign(Polish=None)
                    df_050_059_HS_IF_I  = df_050_059_HS_IF_I.assign(Symmetry=None)
                    df_050_059_HS_IF_I  = df_050_059_HS_IF_I.assign(Ratio=None)
                    df_050_059_HS_IF_I  = df_050_059_HS_IF_I.assign(PPC=None)
                    df_050_059_HS_IF_I  = df_050_059_HS_IF_I.assign(Total=None)
                    df_050_059_HS_IF_I ['Wt Range'] = listwtrange
                    df_050_059_HS_IF_I ['Company'] = listcom
                    df_050_059_HS_IF_I ['Shape'] = listshap
                    df_050_059_HS_IF_I ['Carat'] = listcar
                    df_050_059_HS_IF_I ['Color'] = listcol
                    df_050_059_HS_IF_I ['Clarity'] = listclar
                    df_050_059_HS_IF_I ['Cut'] = listcut
                    df_050_059_HS_IF_I ['Polish'] = listpol
                    df_050_059_HS_IF_I ['Symmetry'] = listsym
                    df_050_059_HS_IF_I ['Ratio'] = listrat
                    df_050_059_HS_IF_I ['PPC'] = listdesc
                    df_050_059_HS_IF_I ['Total'] = listtotal
                    df_050_059_HS_IF_I['Carat'] = df_050_059_HS_IF_I['Carat'].astype('float64')
                    df_050_059_HS_IF_I['PPC'] = df_050_059_HS_IF_I['PPC'].astype('float64')
                    df_050_059_HS_IF_I['Total'] = df_050_059_HS_IF_I['Total'].astype('float64')
                    df_050_059_HS_IF_I['Total'] = df_050_059_HS_IF_I['Carat'] * df_050_059_HS_IF_I['PPC']



                elif i== "I" and j == "VVS1" and k == "HS":
                    df_050_059_HS_VVS1_I = pd.DataFrame()
                    df_050_059_HS_VVS1_I ['Wt Range'] = None
                    df_050_059_HS_VVS1_I  = df_050_059_HS_VVS1_I.assign(Company=None)
                    df_050_059_HS_VVS1_I  = df_050_059_HS_VVS1_I.assign(Shape=None)
                    df_050_059_HS_VVS1_I  = df_050_059_HS_VVS1_I.assign(Carat=None)
                    df_050_059_HS_VVS1_I  = df_050_059_HS_VVS1_I.assign(Color=None)
                    df_050_059_HS_VVS1_I  = df_050_059_HS_VVS1_I.assign(Clarity=None)
                    df_050_059_HS_VVS1_I  = df_050_059_HS_VVS1_I.assign(Cut=None)
                    df_050_059_HS_VVS1_I  = df_050_059_HS_VVS1_I.assign(Polish=None)
                    df_050_059_HS_VVS1_I  = df_050_059_HS_VVS1_I.assign(Symmetry=None)
                    df_050_059_HS_VVS1_I  = df_050_059_HS_VVS1_I.assign(Ratio=None)
                    df_050_059_HS_VVS1_I  = df_050_059_HS_VVS1_I.assign(PPC=None)
                    df_050_059_HS_VVS1_I  = df_050_059_HS_VVS1_I.assign(Total=None)
                    df_050_059_HS_VVS1_I ['Wt Range'] = listwtrange
                    df_050_059_HS_VVS1_I ['Company'] = listcom
                    df_050_059_HS_VVS1_I ['Shape'] = listshap
                    df_050_059_HS_VVS1_I ['Carat'] = listcar
                    df_050_059_HS_VVS1_I ['Color'] = listcol
                    df_050_059_HS_VVS1_I ['Clarity'] = listclar
                    df_050_059_HS_VVS1_I ['Cut'] = listcut
                    df_050_059_HS_VVS1_I ['Polish'] = listpol
                    df_050_059_HS_VVS1_I ['Symmetry'] = listsym
                    df_050_059_HS_VVS1_I ['Ratio'] = listrat
                    df_050_059_HS_VVS1_I ['PPC'] = listdesc
                    df_050_059_HS_VVS1_I ['Total'] = listtotal
                    df_050_059_HS_VVS1_I['Carat'] = df_050_059_HS_VVS1_I['Carat'].astype('float64')
                    df_050_059_HS_VVS1_I['PPC'] = df_050_059_HS_VVS1_I['PPC'].astype('float64')
                    df_050_059_HS_VVS1_I['Total'] = df_050_059_HS_VVS1_I['Total'].astype('float64')
                    df_050_059_HS_VVS1_I['Total'] = df_050_059_HS_VVS1_I['Carat'] * df_050_059_HS_VVS1_I['PPC']


                elif i== "I" and j == "VVS2" and k == "HS":
                    df_050_059_HS_VVS2_I = pd.DataFrame()
                    df_050_059_HS_VVS2_I ['Wt Range'] = None
                    df_050_059_HS_VVS2_I  = df_050_059_HS_VVS2_I.assign(Company=None)
                    df_050_059_HS_VVS2_I  = df_050_059_HS_VVS2_I.assign(Shape=None)
                    df_050_059_HS_VVS2_I  = df_050_059_HS_VVS2_I.assign(Carat=None)
                    df_050_059_HS_VVS2_I  = df_050_059_HS_VVS2_I.assign(Color=None)
                    df_050_059_HS_VVS2_I  = df_050_059_HS_VVS2_I.assign(Clarity=None)
                    df_050_059_HS_VVS2_I  = df_050_059_HS_VVS2_I.assign(Cut=None)
                    df_050_059_HS_VVS2_I  = df_050_059_HS_VVS2_I.assign(Polish=None)
                    df_050_059_HS_VVS2_I  = df_050_059_HS_VVS2_I.assign(Symmetry=None)
                    df_050_059_HS_VVS2_I  = df_050_059_HS_VVS2_I.assign(Ratio=None)
                    df_050_059_HS_VVS2_I  = df_050_059_HS_VVS2_I.assign(PPC=None)
                    df_050_059_HS_VVS2_I  = df_050_059_HS_VVS2_I.assign(Total=None)
                    df_050_059_HS_VVS2_I ['Wt Range'] = listwtrange
                    df_050_059_HS_VVS2_I ['Company'] = listcom
                    df_050_059_HS_VVS2_I ['Shape'] = listshap
                    df_050_059_HS_VVS2_I ['Carat'] = listcar
                    df_050_059_HS_VVS2_I ['Color'] = listcol
                    df_050_059_HS_VVS2_I ['Clarity'] = listclar
                    df_050_059_HS_VVS2_I ['Cut'] = listcut
                    df_050_059_HS_VVS2_I ['Polish'] = listpol
                    df_050_059_HS_VVS2_I ['Symmetry'] = listsym
                    df_050_059_HS_VVS2_I ['Ratio'] = listrat
                    df_050_059_HS_VVS2_I ['PPC'] = listdesc
                    df_050_059_HS_VVS2_I ['Total'] = listtotal
                    df_050_059_HS_VVS2_I['Carat'] = df_050_059_HS_VVS2_I['Carat'].astype('float64')
                    df_050_059_HS_VVS2_I['PPC'] = df_050_059_HS_VVS2_I['PPC'].astype('float64')
                    df_050_059_HS_VVS2_I['Total'] = df_050_059_HS_VVS2_I['Total'].astype('float64')
                    df_050_059_HS_VVS2_I['Total'] = df_050_059_HS_VVS2_I['Carat'] * df_050_059_HS_VVS2_I['PPC']


                elif i== "I" and j=="VS1" and k == "HS":
                    df_050_059_HS_VS1_I = pd.DataFrame()
                    df_050_059_HS_VS1_I ['Wt Range'] = None
                    df_050_059_HS_VS1_I  = df_050_059_HS_VS1_I.assign(Company=None)
                    df_050_059_HS_VS1_I  = df_050_059_HS_VS1_I.assign(Shape=None)
                    df_050_059_HS_VS1_I  = df_050_059_HS_VS1_I.assign(Carat=None)
                    df_050_059_HS_VS1_I  = df_050_059_HS_VS1_I.assign(Color=None)
                    df_050_059_HS_VS1_I  = df_050_059_HS_VS1_I.assign(Clarity=None)
                    df_050_059_HS_VS1_I  = df_050_059_HS_VS1_I.assign(Cut=None)
                    df_050_059_HS_VS1_I  = df_050_059_HS_VS1_I.assign(Polish=None)
                    df_050_059_HS_VS1_I  = df_050_059_HS_VS1_I.assign(Symmetry=None)
                    df_050_059_HS_VS1_I  = df_050_059_HS_VS1_I.assign(Ratio=None)
                    df_050_059_HS_VS1_I  = df_050_059_HS_VS1_I.assign(PPC=None)
                    df_050_059_HS_VS1_I  = df_050_059_HS_VS1_I.assign(Total=None)
                    df_050_059_HS_VS1_I ['Wt Range'] = listwtrange
                    df_050_059_HS_VS1_I ['Company'] = listcom
                    df_050_059_HS_VS1_I ['Shape'] = listshap
                    df_050_059_HS_VS1_I ['Carat'] = listcar
                    df_050_059_HS_VS1_I ['Color'] = listcol
                    df_050_059_HS_VS1_I ['Clarity'] = listclar
                    df_050_059_HS_VS1_I ['Cut'] = listcut
                    df_050_059_HS_VS1_I ['Polish'] = listpol
                    df_050_059_HS_VS1_I ['Symmetry'] = listsym
                    df_050_059_HS_VS1_I ['Ratio'] = listrat
                    df_050_059_HS_VS1_I ['PPC'] = listdesc
                    df_050_059_HS_VS1_I ['Total'] = listtotal
                    df_050_059_HS_VS1_I['Carat'] = df_050_059_HS_VS1_I['Carat'].astype('float64')
                    df_050_059_HS_VS1_I['PPC'] = df_050_059_HS_VS1_I['PPC'].astype('float64')
                    df_050_059_HS_VS1_I['Total'] = df_050_059_HS_VS1_I['Total'].astype('float64')
                    df_050_059_HS_VS1_I['Total'] = df_050_059_HS_VS1_I['Carat'] * df_050_059_HS_VS1_I['PPC']


                elif i== "I" and j == "VS2" and k == "HS":
                    df_050_059_HS_VS2_I = pd.DataFrame()
                    df_050_059_HS_VS2_I ['Wt Range'] = None
                    df_050_059_HS_VS2_I  = df_050_059_HS_VS2_I.assign(Company=None)
                    df_050_059_HS_VS2_I  = df_050_059_HS_VS2_I.assign(Shape=None)
                    df_050_059_HS_VS2_I  = df_050_059_HS_VS2_I.assign(Carat=None)
                    df_050_059_HS_VS2_I  = df_050_059_HS_VS2_I.assign(Color=None)
                    df_050_059_HS_VS2_I  = df_050_059_HS_VS2_I.assign(Clarity=None)
                    df_050_059_HS_VS2_I  = df_050_059_HS_VS2_I.assign(Cut=None)
                    df_050_059_HS_VS2_I  = df_050_059_HS_VS2_I.assign(Polish=None)
                    df_050_059_HS_VS2_I  = df_050_059_HS_VS2_I.assign(Symmetry=None)
                    df_050_059_HS_VS2_I  = df_050_059_HS_VS2_I.assign(Ratio=None)
                    df_050_059_HS_VS2_I  = df_050_059_HS_VS2_I.assign(PPC=None)
                    df_050_059_HS_VS2_I  = df_050_059_HS_VS2_I.assign(Total=None)
                    df_050_059_HS_VS2_I ['Wt Range'] = listwtrange
                    df_050_059_HS_VS2_I ['Company'] = listcom
                    df_050_059_HS_VS2_I ['Shape'] = listshap
                    df_050_059_HS_VS2_I ['Carat'] = listcar
                    df_050_059_HS_VS2_I ['Color'] = listcol
                    df_050_059_HS_VS2_I ['Clarity'] = listclar
                    df_050_059_HS_VS2_I ['Cut'] = listcut
                    df_050_059_HS_VS2_I ['Polish'] = listpol
                    df_050_059_HS_VS2_I ['Symmetry'] = listsym
                    df_050_059_HS_VS2_I ['Ratio'] = listrat
                    df_050_059_HS_VS2_I ['PPC'] = listdesc
                    df_050_059_HS_VS2_I ['Total'] = listtotal
                    df_050_059_HS_VS2_I['Carat'] = df_050_059_HS_VS2_I['Carat'].astype('float64')
                    df_050_059_HS_VS2_I['PPC'] = df_050_059_HS_VS2_I['PPC'].astype('float64')
                    df_050_059_HS_VS2_I['Total'] = df_050_059_HS_VS2_I['Total'].astype('float64')
                    df_050_059_HS_VS2_I['Total'] = df_050_059_HS_VS2_I['Carat'] * df_050_059_HS_VS2_I['PPC']


                elif i== "I" and j == "SI1" and k == "HS":
                    df_050_059_HS_SI1_I = pd.DataFrame()
                    df_050_059_HS_SI1_I ['Wt Range'] = None
                    df_050_059_HS_SI1_I  = df_050_059_HS_SI1_I.assign(Company=None)
                    df_050_059_HS_SI1_I  = df_050_059_HS_SI1_I.assign(Shape=None)
                    df_050_059_HS_SI1_I  = df_050_059_HS_SI1_I.assign(Carat=None)
                    df_050_059_HS_SI1_I  = df_050_059_HS_SI1_I.assign(Color=None)
                    df_050_059_HS_SI1_I  = df_050_059_HS_SI1_I.assign(Clarity=None)
                    df_050_059_HS_SI1_I  = df_050_059_HS_SI1_I.assign(Cut=None)
                    df_050_059_HS_SI1_I  = df_050_059_HS_SI1_I.assign(Polish=None)
                    df_050_059_HS_SI1_I  = df_050_059_HS_SI1_I.assign(Symmetry=None)
                    df_050_059_HS_SI1_I  = df_050_059_HS_SI1_I.assign(Ratio=None)
                    df_050_059_HS_SI1_I  = df_050_059_HS_SI1_I.assign(PPC=None)
                    df_050_059_HS_SI1_I  = df_050_059_HS_SI1_I.assign(Total=None)
                    df_050_059_HS_SI1_I ['Wt Range'] = listwtrange
                    df_050_059_HS_SI1_I ['Company'] = listcom
                    df_050_059_HS_SI1_I ['Shape'] = listshap
                    df_050_059_HS_SI1_I ['Carat'] = listcar
                    df_050_059_HS_SI1_I ['Color'] = listcol
                    df_050_059_HS_SI1_I ['Clarity'] = listclar
                    df_050_059_HS_SI1_I ['Cut'] = listcut
                    df_050_059_HS_SI1_I ['Polish'] = listpol
                    df_050_059_HS_SI1_I ['Symmetry'] = listsym
                    df_050_059_HS_SI1_I ['Ratio'] = listrat
                    df_050_059_HS_SI1_I ['PPC'] = listdesc
                    df_050_059_HS_SI1_I ['Total'] = listtotal
                    df_050_059_HS_SI1_I['Carat'] = df_050_059_HS_SI1_I['Carat'].astype('float64')
                    df_050_059_HS_SI1_I['PPC'] = df_050_059_HS_SI1_I['PPC'].astype('float64')
                    df_050_059_HS_SI1_I['Total'] = df_050_059_HS_SI1_I['Total'].astype('float64')
                    df_050_059_HS_SI1_I['Total'] = df_050_059_HS_SI1_I['Carat'] * df_050_059_HS_SI1_I['PPC']


                elif i== "I" and j == "SI2" and k == "HS":
                    df_050_059_HS_SI2_I = pd.DataFrame()
                    df_050_059_HS_SI2_I ['Wt Range'] = None
                    df_050_059_HS_SI2_I  = df_050_059_HS_SI2_I.assign(Company=None)
                    df_050_059_HS_SI2_I  = df_050_059_HS_SI2_I.assign(Shape=None)
                    df_050_059_HS_SI2_I  = df_050_059_HS_SI2_I.assign(Carat=None)
                    df_050_059_HS_SI2_I  = df_050_059_HS_SI2_I.assign(Color=None)
                    df_050_059_HS_SI2_I  = df_050_059_HS_SI2_I.assign(Clarity=None)
                    df_050_059_HS_SI2_I  = df_050_059_HS_SI2_I.assign(Cut=None)
                    df_050_059_HS_SI2_I  = df_050_059_HS_SI2_I.assign(Polish=None)
                    df_050_059_HS_SI2_I  = df_050_059_HS_SI2_I.assign(Symmetry=None)
                    df_050_059_HS_SI2_I  = df_050_059_HS_SI2_I.assign(Ratio=None)
                    df_050_059_HS_SI2_I  = df_050_059_HS_SI2_I.assign(PPC=None)
                    df_050_059_HS_SI2_I  = df_050_059_HS_SI2_I.assign(Total=None)
                    df_050_059_HS_SI2_I ['Wt Range'] = listwtrange
                    df_050_059_HS_SI2_I ['Company'] = listcom
                    df_050_059_HS_SI2_I ['Shape'] = listshap
                    df_050_059_HS_SI2_I ['Carat'] = listcar
                    df_050_059_HS_SI2_I ['Color'] = listcol
                    df_050_059_HS_SI2_I ['Clarity'] = listclar
                    df_050_059_HS_SI2_I ['Cut'] = listcut
                    df_050_059_HS_SI2_I ['Polish'] = listpol
                    df_050_059_HS_SI2_I ['Symmetry'] = listsym
                    df_050_059_HS_SI2_I ['Ratio'] = listrat
                    df_050_059_HS_SI2_I ['PPC'] = listdesc
                    df_050_059_HS_SI2_I ['Total'] = listtotal
                    df_050_059_HS_SI2_I['Carat'] = df_050_059_HS_SI2_I['Carat'].astype('float64')
                    df_050_059_HS_SI2_I['PPC'] = df_050_059_HS_SI2_I['PPC'].astype('float64')
                    df_050_059_HS_SI2_I['Total'] = df_050_059_HS_SI2_I['Total'].astype('float64')
                    df_050_059_HS_SI2_I['Total'] = df_050_059_HS_SI2_I['Carat'] * df_050_059_HS_SI2_I['PPC']


                elif i== "I" and j == "I1" and k == "HS":
                    df_050_059_HS_I1_I = pd.DataFrame()
                    df_050_059_HS_I1_I ['Wt Range'] = None
                    df_050_059_HS_I1_I  = df_050_059_HS_I1_I.assign(Company=None)
                    df_050_059_HS_I1_I  = df_050_059_HS_I1_I.assign(Shape=None)
                    df_050_059_HS_I1_I  = df_050_059_HS_I1_I.assign(Carat=None)
                    df_050_059_HS_I1_I  = df_050_059_HS_I1_I.assign(Color=None)
                    df_050_059_HS_I1_I  = df_050_059_HS_I1_I.assign(Clarity=None)
                    df_050_059_HS_I1_I  = df_050_059_HS_I1_I.assign(Cut=None)
                    df_050_059_HS_I1_I  = df_050_059_HS_I1_I.assign(Polish=None)
                    df_050_059_HS_I1_I  = df_050_059_HS_I1_I.assign(Symmetry=None)
                    df_050_059_HS_I1_I  = df_050_059_HS_I1_I.assign(Ratio=None)
                    df_050_059_HS_I1_I  = df_050_059_HS_I1_I.assign(PPC=None)
                    df_050_059_HS_I1_I  = df_050_059_HS_I1_I.assign(Total=None)
                    df_050_059_HS_I1_I ['Wt Range'] = listwtrange
                    df_050_059_HS_I1_I ['Company'] = listcom
                    df_050_059_HS_I1_I ['Shape'] = listshap
                    df_050_059_HS_I1_I ['Carat'] = listcar
                    df_050_059_HS_I1_I ['Color'] = listcol
                    df_050_059_HS_I1_I ['Clarity'] = listclar
                    df_050_059_HS_I1_I ['Cut'] = listcut
                    df_050_059_HS_I1_I ['Polish'] = listpol
                    df_050_059_HS_I1_I ['Symmetry'] = listsym
                    df_050_059_HS_I1_I ['Ratio'] = listrat
                    df_050_059_HS_I1_I ['PPC'] = listdesc
                    df_050_059_HS_I1_I ['Total'] = listtotal
                    df_050_059_HS_I1_I['Carat'] = df_050_059_HS_I1_I['Carat'].astype('float64')
                    df_050_059_HS_I1_I['PPC'] = df_050_059_HS_I1_I['PPC'].astype('float64')
                    df_050_059_HS_I1_I['Total'] = df_050_059_HS_I1_I['Total'].astype('float64')
                    df_050_059_HS_I1_I['Total'] = df_050_059_HS_I1_I['Carat'] * df_050_059_HS_I1_I['PPC']


                elif i== "I" and j == "I2" and k == "HS":
                    df_050_059_HS_I2_I = pd.DataFrame()
                    df_050_059_HS_I2_I ['Wt Range'] = None
                    df_050_059_HS_I2_I  = df_050_059_HS_I2_I.assign(Company=None)
                    df_050_059_HS_I2_I  = df_050_059_HS_I2_I.assign(Shape=None)
                    df_050_059_HS_I2_I  = df_050_059_HS_I2_I.assign(Carat=None)
                    df_050_059_HS_I2_I  = df_050_059_HS_I2_I.assign(Color=None)
                    df_050_059_HS_I2_I  = df_050_059_HS_I2_I.assign(Clarity=None)
                    df_050_059_HS_I2_I  = df_050_059_HS_I2_I.assign(Cut=None)
                    df_050_059_HS_I2_I  = df_050_059_HS_I2_I.assign(Polish=None)
                    df_050_059_HS_I2_I  = df_050_059_HS_I2_I.assign(Symmetry=None)
                    df_050_059_HS_I2_I  = df_050_059_HS_I2_I.assign(Ratio=None)
                    df_050_059_HS_I2_I  = df_050_059_HS_I2_I.assign(PPC=None)
                    df_050_059_HS_I2_I  = df_050_059_HS_I2_I.assign(Total=None)
                    df_050_059_HS_I2_I ['Wt Range'] = listwtrange
                    df_050_059_HS_I2_I ['Company'] = listcom
                    df_050_059_HS_I2_I ['Shape'] = listshap
                    df_050_059_HS_I2_I ['Carat'] = listcar
                    df_050_059_HS_I2_I ['Color'] = listcol
                    df_050_059_HS_I2_I ['Clarity'] = listclar
                    df_050_059_HS_I2_I ['Cut'] = listcut
                    df_050_059_HS_I2_I ['Polish'] = listpol
                    df_050_059_HS_I2_I ['Symmetry'] = listsym
                    df_050_059_HS_I2_I ['Ratio'] = listrat
                    df_050_059_HS_I2_I ['PPC'] = listdesc
                    df_050_059_HS_I2_I ['Total'] = listtotal
                    df_050_059_HS_I2_I['Carat'] = df_050_059_HS_I2_I['Carat'].astype('float64')
                    df_050_059_HS_I2_I['PPC'] = df_050_059_HS_I2_I['PPC'].astype('float64')
                    df_050_059_HS_I2_I['Total'] = df_050_059_HS_I2_I['Total'].astype('float64')
                    df_050_059_HS_I2_I['Total'] = df_050_059_HS_I2_I['Carat'] * df_050_059_HS_I2_I['PPC']


                elif i=="J" and j == "IF" and k == "HS":
                    df_050_059_HS_IF_J = pd.DataFrame()
                    df_050_059_HS_IF_J ['Wt Range'] = None
                    df_050_059_HS_IF_J  = df_050_059_HS_IF_J.assign(Company=None)
                    df_050_059_HS_IF_J  = df_050_059_HS_IF_J.assign(Shape=None)
                    df_050_059_HS_IF_J  = df_050_059_HS_IF_J.assign(Carat=None)
                    df_050_059_HS_IF_J  = df_050_059_HS_IF_J.assign(Color=None)
                    df_050_059_HS_IF_J  = df_050_059_HS_IF_J.assign(Clarity=None)
                    df_050_059_HS_IF_J  = df_050_059_HS_IF_J.assign(Cut=None)
                    df_050_059_HS_IF_J  = df_050_059_HS_IF_J.assign(Polish=None)
                    df_050_059_HS_IF_J  = df_050_059_HS_IF_J.assign(Symmetry=None)
                    df_050_059_HS_IF_J  = df_050_059_HS_IF_J.assign(Ratio=None)
                    df_050_059_HS_IF_J  = df_050_059_HS_IF_J.assign(PPC=None)
                    df_050_059_HS_IF_J  = df_050_059_HS_IF_J.assign(Total=None)
                    df_050_059_HS_IF_J ['Wt Range'] = listwtrange
                    df_050_059_HS_IF_J ['Company'] = listcom
                    df_050_059_HS_IF_J ['Shape'] = listshap
                    df_050_059_HS_IF_J ['Carat'] = listcar
                    df_050_059_HS_IF_J ['Color'] = listcol
                    df_050_059_HS_IF_J ['Clarity'] = listclar
                    df_050_059_HS_IF_J ['Cut'] = listcut
                    df_050_059_HS_IF_J ['Polish'] = listpol
                    df_050_059_HS_IF_J ['Symmetry'] = listsym
                    df_050_059_HS_IF_J ['Ratio'] = listrat
                    df_050_059_HS_IF_J ['PPC'] = listdesc
                    df_050_059_HS_IF_J ['Total'] = listtotal
                    df_050_059_HS_IF_J['Carat'] = df_050_059_HS_IF_J['Carat'].astype('float64')
                    df_050_059_HS_IF_J['PPC'] = df_050_059_HS_IF_J['PPC'].astype('float64')
                    df_050_059_HS_IF_J['Total'] = df_050_059_HS_IF_J['Total'].astype('float64')
                    df_050_059_HS_IF_J['Total'] = df_050_059_HS_IF_J['Carat'] * df_050_059_HS_IF_J['PPC']



                elif i=="J"  and j == "VVS1" and k == "HS":
                    df_050_059_HS_VVS1_J = pd.DataFrame()
                    df_050_059_HS_VVS1_J ['Wt Range'] = None
                    df_050_059_HS_VVS1_J  = df_050_059_HS_VVS1_J.assign(Company=None)
                    df_050_059_HS_VVS1_J  = df_050_059_HS_VVS1_J.assign(Shape=None)
                    df_050_059_HS_VVS1_J  = df_050_059_HS_VVS1_J.assign(Carat=None)
                    df_050_059_HS_VVS1_J  = df_050_059_HS_VVS1_J.assign(Color=None)
                    df_050_059_HS_VVS1_J  = df_050_059_HS_VVS1_J.assign(Clarity=None)
                    df_050_059_HS_VVS1_J  = df_050_059_HS_VVS1_J.assign(Cut=None)
                    df_050_059_HS_VVS1_J  = df_050_059_HS_VVS1_J.assign(Polish=None)
                    df_050_059_HS_VVS1_J  = df_050_059_HS_VVS1_J.assign(Symmetry=None)
                    df_050_059_HS_VVS1_J  = df_050_059_HS_VVS1_J.assign(Ratio=None)
                    df_050_059_HS_VVS1_J  = df_050_059_HS_VVS1_J.assign(PPC=None)
                    df_050_059_HS_VVS1_J  = df_050_059_HS_VVS1_J.assign(Total=None)
                    df_050_059_HS_VVS1_J ['Wt Range'] = listwtrange
                    df_050_059_HS_VVS1_J ['Company'] = listcom
                    df_050_059_HS_VVS1_J ['Shape'] = listshap
                    df_050_059_HS_VVS1_J ['Carat'] = listcar
                    df_050_059_HS_VVS1_J ['Color'] = listcol
                    df_050_059_HS_VVS1_J ['Clarity'] = listclar
                    df_050_059_HS_VVS1_J ['Cut'] = listcut
                    df_050_059_HS_VVS1_J ['Polish'] = listpol
                    df_050_059_HS_VVS1_J ['Symmetry'] = listsym
                    df_050_059_HS_VVS1_J ['Ratio'] = listrat
                    df_050_059_HS_VVS1_J ['PPC'] = listdesc
                    df_050_059_HS_VVS1_J ['Total'] = listtotal
                    df_050_059_HS_VVS1_J['Carat'] = df_050_059_HS_VVS1_J['Carat'].astype('float64')
                    df_050_059_HS_VVS1_J['PPC'] = df_050_059_HS_VVS1_J['PPC'].astype('float64')
                    df_050_059_HS_VVS1_J['Total'] = df_050_059_HS_VVS1_J['Total'].astype('float64')
                    df_050_059_HS_VVS1_J['Total'] = df_050_059_HS_VVS1_J['Carat'] * df_050_059_HS_VVS1_J['PPC']


                elif i=="J"  and j == "VVS2" and k == "HS":
                    df_050_059_HS_VVS2_J = pd.DataFrame()
                    df_050_059_HS_VVS2_J ['Wt Range'] = None
                    df_050_059_HS_VVS2_J  = df_050_059_HS_VVS2_J.assign(Company=None)
                    df_050_059_HS_VVS2_J  = df_050_059_HS_VVS2_J.assign(Shape=None)
                    df_050_059_HS_VVS2_J  = df_050_059_HS_VVS2_J.assign(Carat=None)
                    df_050_059_HS_VVS2_J  = df_050_059_HS_VVS2_J.assign(Color=None)
                    df_050_059_HS_VVS2_J  = df_050_059_HS_VVS2_J.assign(Clarity=None)
                    df_050_059_HS_VVS2_J  = df_050_059_HS_VVS2_J.assign(Cut=None)
                    df_050_059_HS_VVS2_J  = df_050_059_HS_VVS2_J.assign(Polish=None)
                    df_050_059_HS_VVS2_J  = df_050_059_HS_VVS2_J.assign(Symmetry=None)
                    df_050_059_HS_VVS2_J  = df_050_059_HS_VVS2_J.assign(Ratio=None)
                    df_050_059_HS_VVS2_J  = df_050_059_HS_VVS2_J.assign(PPC=None)
                    df_050_059_HS_VVS2_J  = df_050_059_HS_VVS2_J.assign(Total=None)
                    df_050_059_HS_VVS2_J ['Wt Range'] = listwtrange
                    df_050_059_HS_VVS2_J ['Company'] = listcom
                    df_050_059_HS_VVS2_J ['Shape'] = listshap
                    df_050_059_HS_VVS2_J ['Carat'] = listcar
                    df_050_059_HS_VVS2_J ['Color'] = listcol
                    df_050_059_HS_VVS2_J ['Clarity'] = listclar
                    df_050_059_HS_VVS2_J ['Cut'] = listcut
                    df_050_059_HS_VVS2_J ['Polish'] = listpol
                    df_050_059_HS_VVS2_J ['Symmetry'] = listsym
                    df_050_059_HS_VVS2_J ['Ratio'] = listrat
                    df_050_059_HS_VVS2_J ['PPC'] = listdesc
                    df_050_059_HS_VVS2_J ['Total'] = listtotal
                    df_050_059_HS_VVS2_J['Carat'] = df_050_059_HS_VVS2_J['Carat'].astype('float64')
                    df_050_059_HS_VVS2_J['PPC'] = df_050_059_HS_VVS2_J['PPC'].astype('float64')
                    df_050_059_HS_VVS2_J['Total'] = df_050_059_HS_VVS2_J['Total'].astype('float64')
                    df_050_059_HS_VVS2_J['Total'] = df_050_059_HS_VVS2_J['Carat'] * df_050_059_HS_VVS2_J['PPC']


                elif i=="J"  and j=="VS1" and k == "HS":
                    df_050_059_HS_VS1_J = pd.DataFrame()
                    df_050_059_HS_VS1_J ['Wt Range'] = None
                    df_050_059_HS_VS1_J  = df_050_059_HS_VS1_J.assign(Company=None)
                    df_050_059_HS_VS1_J  = df_050_059_HS_VS1_J.assign(Shape=None)
                    df_050_059_HS_VS1_J  = df_050_059_HS_VS1_J.assign(Carat=None)
                    df_050_059_HS_VS1_J  = df_050_059_HS_VS1_J.assign(Color=None)
                    df_050_059_HS_VS1_J  = df_050_059_HS_VS1_J.assign(Clarity=None)
                    df_050_059_HS_VS1_J  = df_050_059_HS_VS1_J.assign(Cut=None)
                    df_050_059_HS_VS1_J  = df_050_059_HS_VS1_J.assign(Polish=None)
                    df_050_059_HS_VS1_J  = df_050_059_HS_VS1_J.assign(Symmetry=None)
                    df_050_059_HS_VS1_J  = df_050_059_HS_VS1_J.assign(Ratio=None)
                    df_050_059_HS_VS1_J  = df_050_059_HS_VS1_J.assign(PPC=None)
                    df_050_059_HS_VS1_J  = df_050_059_HS_VS1_J.assign(Total=None)
                    df_050_059_HS_VS1_J ['Wt Range'] = listwtrange
                    df_050_059_HS_VS1_J ['Company'] = listcom
                    df_050_059_HS_VS1_J ['Shape'] = listshap
                    df_050_059_HS_VS1_J ['Carat'] = listcar
                    df_050_059_HS_VS1_J ['Color'] = listcol
                    df_050_059_HS_VS1_J ['Clarity'] = listclar
                    df_050_059_HS_VS1_J ['Cut'] = listcut
                    df_050_059_HS_VS1_J ['Polish'] = listpol
                    df_050_059_HS_VS1_J ['Symmetry'] = listsym
                    df_050_059_HS_VS1_J ['Ratio'] = listrat
                    df_050_059_HS_VS1_J ['PPC'] = listdesc
                    df_050_059_HS_VS1_J ['Total'] = listtotal
                    df_050_059_HS_VS1_J['Carat'] = df_050_059_HS_VS1_J['Carat'].astype('float64')
                    df_050_059_HS_VS1_J['PPC'] = df_050_059_HS_VS1_J['PPC'].astype('float64')
                    df_050_059_HS_VS1_J['Total'] = df_050_059_HS_VS1_J['Total'].astype('float64')
                    df_050_059_HS_VS1_J['Total'] = df_050_059_HS_VS1_J['Carat'] * df_050_059_HS_VS1_J['PPC']


                elif i=="J"  and j == "VS2" and k == "HS":
                    df_050_059_HS_VS2_J = pd.DataFrame()
                    df_050_059_HS_VS2_J ['Wt Range'] = None
                    df_050_059_HS_VS2_J  = df_050_059_HS_VS2_J.assign(Company=None)
                    df_050_059_HS_VS2_J  = df_050_059_HS_VS2_J.assign(Shape=None)
                    df_050_059_HS_VS2_J  = df_050_059_HS_VS2_J.assign(Carat=None)
                    df_050_059_HS_VS2_J  = df_050_059_HS_VS2_J.assign(Color=None)
                    df_050_059_HS_VS2_J  = df_050_059_HS_VS2_J.assign(Clarity=None)
                    df_050_059_HS_VS2_J  = df_050_059_HS_VS2_J.assign(Cut=None)
                    df_050_059_HS_VS2_J  = df_050_059_HS_VS2_J.assign(Polish=None)
                    df_050_059_HS_VS2_J  = df_050_059_HS_VS2_J.assign(Symmetry=None)
                    df_050_059_HS_VS2_J  = df_050_059_HS_VS2_J.assign(Ratio=None)
                    df_050_059_HS_VS2_J  = df_050_059_HS_VS2_J.assign(PPC=None)
                    df_050_059_HS_VS2_J  = df_050_059_HS_VS2_J.assign(Total=None)
                    df_050_059_HS_VS2_J ['Wt Range'] = listwtrange
                    df_050_059_HS_VS2_J ['Company'] = listcom
                    df_050_059_HS_VS2_J ['Shape'] = listshap
                    df_050_059_HS_VS2_J ['Carat'] = listcar
                    df_050_059_HS_VS2_J ['Color'] = listcol
                    df_050_059_HS_VS2_J ['Clarity'] = listclar
                    df_050_059_HS_VS2_J ['Cut'] = listcut
                    df_050_059_HS_VS2_J ['Polish'] = listpol
                    df_050_059_HS_VS2_J ['Symmetry'] = listsym
                    df_050_059_HS_VS2_J ['Ratio'] = listrat
                    df_050_059_HS_VS2_J ['PPC'] = listdesc
                    df_050_059_HS_VS2_J ['Total'] = listtotal
                    df_050_059_HS_VS2_J['Carat'] = df_050_059_HS_VS2_J['Carat'].astype('float64')
                    df_050_059_HS_VS2_J['PPC'] = df_050_059_HS_VS2_J['PPC'].astype('float64')
                    df_050_059_HS_VS2_J['Total'] = df_050_059_HS_VS2_J['Total'].astype('float64')
                    df_050_059_HS_VS2_J['Total'] = df_050_059_HS_VS2_J['Carat'] * df_050_059_HS_VS2_J['PPC']


                elif i=="J"  and j == "SI1" and k == "HS":
                    df_050_059_HS_SI1_J = pd.DataFrame()
                    df_050_059_HS_SI1_J ['Wt Range'] = None
                    df_050_059_HS_SI1_J  = df_050_059_HS_SI1_J.assign(Company=None)
                    df_050_059_HS_SI1_J  = df_050_059_HS_SI1_J.assign(Shape=None)
                    df_050_059_HS_SI1_J  = df_050_059_HS_SI1_J.assign(Carat=None)
                    df_050_059_HS_SI1_J  = df_050_059_HS_SI1_J.assign(Color=None)
                    df_050_059_HS_SI1_J  = df_050_059_HS_SI1_J.assign(Clarity=None)
                    df_050_059_HS_SI1_J  = df_050_059_HS_SI1_J.assign(Cut=None)
                    df_050_059_HS_SI1_J  = df_050_059_HS_SI1_J.assign(Polish=None)
                    df_050_059_HS_SI1_J  = df_050_059_HS_SI1_J.assign(Symmetry=None)
                    df_050_059_HS_SI1_J  = df_050_059_HS_SI1_J.assign(Ratio=None)
                    df_050_059_HS_SI1_J  = df_050_059_HS_SI1_J.assign(PPC=None)
                    df_050_059_HS_SI1_J  = df_050_059_HS_SI1_J.assign(Total=None)
                    df_050_059_HS_SI1_J ['Wt Range'] = listwtrange
                    df_050_059_HS_SI1_J ['Company'] = listcom
                    df_050_059_HS_SI1_J ['Shape'] = listshap
                    df_050_059_HS_SI1_J ['Carat'] = listcar
                    df_050_059_HS_SI1_J ['Color'] = listcol
                    df_050_059_HS_SI1_J ['Clarity'] = listclar
                    df_050_059_HS_SI1_J ['Cut'] = listcut
                    df_050_059_HS_SI1_J ['Polish'] = listpol
                    df_050_059_HS_SI1_J ['Symmetry'] = listsym
                    df_050_059_HS_SI1_J ['Ratio'] = listrat
                    df_050_059_HS_SI1_J ['PPC'] = listdesc
                    df_050_059_HS_SI1_J ['Total'] = listtotal
                    df_050_059_HS_SI1_J['Carat'] = df_050_059_HS_SI1_J['Carat'].astype('float64')
                    df_050_059_HS_SI1_J['PPC'] = df_050_059_HS_SI1_J['PPC'].astype('float64')
                    df_050_059_HS_SI1_J['Total'] = df_050_059_HS_SI1_J['Total'].astype('float64')
                    df_050_059_HS_SI1_J['Total'] = df_050_059_HS_SI1_J['Carat'] * df_050_059_HS_SI1_J['PPC']


                elif i=="J"  and j == "SI2" and k == "HS":
                    df_050_059_HS_SI2_J = pd.DataFrame()
                    df_050_059_HS_SI2_J ['Wt Range'] = None
                    df_050_059_HS_SI2_J  = df_050_059_HS_SI2_J.assign(Company=None)
                    df_050_059_HS_SI2_J  = df_050_059_HS_SI2_J.assign(Shape=None)
                    df_050_059_HS_SI2_J  = df_050_059_HS_SI2_J.assign(Carat=None)
                    df_050_059_HS_SI2_J  = df_050_059_HS_SI2_J.assign(Color=None)
                    df_050_059_HS_SI2_J  = df_050_059_HS_SI2_J.assign(Clarity=None)
                    df_050_059_HS_SI2_J  = df_050_059_HS_SI2_J.assign(Cut=None)
                    df_050_059_HS_SI2_J  = df_050_059_HS_SI2_J.assign(Polish=None)
                    df_050_059_HS_SI2_J  = df_050_059_HS_SI2_J.assign(Symmetry=None)
                    df_050_059_HS_SI2_J  = df_050_059_HS_SI2_J.assign(Ratio=None)
                    df_050_059_HS_SI2_J  = df_050_059_HS_SI2_J.assign(PPC=None)
                    df_050_059_HS_SI2_J  = df_050_059_HS_SI2_J.assign(Total=None)
                    df_050_059_HS_SI2_J ['Wt Range'] = listwtrange
                    df_050_059_HS_SI2_J ['Company'] = listcom
                    df_050_059_HS_SI2_J ['Shape'] = listshap
                    df_050_059_HS_SI2_J ['Carat'] = listcar
                    df_050_059_HS_SI2_J ['Color'] = listcol
                    df_050_059_HS_SI2_J ['Clarity'] = listclar
                    df_050_059_HS_SI2_J ['Cut'] = listcut
                    df_050_059_HS_SI2_J ['Polish'] = listpol
                    df_050_059_HS_SI2_J ['Symmetry'] = listsym
                    df_050_059_HS_SI2_J ['Ratio'] = listrat
                    df_050_059_HS_SI2_J ['PPC'] = listdesc
                    df_050_059_HS_SI2_J ['Total'] = listtotal
                    df_050_059_HS_SI2_J['Carat'] = df_050_059_HS_SI2_J['Carat'].astype('float64')
                    df_050_059_HS_SI2_J['PPC'] = df_050_059_HS_SI2_J['PPC'].astype('float64')
                    df_050_059_HS_SI2_J['Total'] = df_050_059_HS_SI2_J['Total'].astype('float64')
                    df_050_059_HS_SI2_J['Total'] = df_050_059_HS_SI2_J['Carat'] * df_050_059_HS_SI2_J['PPC']


                elif i=="J"  and j == "I1" and k == "HS":
                    df_050_059_HS_I1_J = pd.DataFrame()
                    df_050_059_HS_I1_J ['Wt Range'] = None
                    df_050_059_HS_I1_J  = df_050_059_HS_I1_J.assign(Company=None)
                    df_050_059_HS_I1_J  = df_050_059_HS_I1_J.assign(Shape=None)
                    df_050_059_HS_I1_J  = df_050_059_HS_I1_J.assign(Carat=None)
                    df_050_059_HS_I1_J  = df_050_059_HS_I1_J.assign(Color=None)
                    df_050_059_HS_I1_J  = df_050_059_HS_I1_J.assign(Clarity=None)
                    df_050_059_HS_I1_J  = df_050_059_HS_I1_J.assign(Cut=None)
                    df_050_059_HS_I1_J  = df_050_059_HS_I1_J.assign(Polish=None)
                    df_050_059_HS_I1_J  = df_050_059_HS_I1_J.assign(Symmetry=None)
                    df_050_059_HS_I1_J  = df_050_059_HS_I1_J.assign(Ratio=None)
                    df_050_059_HS_I1_J  = df_050_059_HS_I1_J.assign(PPC=None)
                    df_050_059_HS_I1_J  = df_050_059_HS_I1_J.assign(Total=None)
                    df_050_059_HS_I1_J ['Wt Range'] = listwtrange
                    df_050_059_HS_I1_J ['Company'] = listcom
                    df_050_059_HS_I1_J ['Shape'] = listshap
                    df_050_059_HS_I1_J ['Carat'] = listcar
                    df_050_059_HS_I1_J ['Color'] = listcol
                    df_050_059_HS_I1_J ['Clarity'] = listclar
                    df_050_059_HS_I1_J ['Cut'] = listcut
                    df_050_059_HS_I1_J ['Polish'] = listpol
                    df_050_059_HS_I1_J ['Symmetry'] = listsym
                    df_050_059_HS_I1_J ['Ratio'] = listrat
                    df_050_059_HS_I1_J ['PPC'] = listdesc
                    df_050_059_HS_I1_J ['Total'] = listtotal
                    df_050_059_HS_I1_J['Carat'] = df_050_059_HS_I1_J['Carat'].astype('float64')
                    df_050_059_HS_I1_J['PPC'] = df_050_059_HS_I1_J['PPC'].astype('float64')
                    df_050_059_HS_I1_J['Total'] = df_050_059_HS_I1_J['Total'].astype('float64')
                    df_050_059_HS_I1_J['Total'] = df_050_059_HS_I1_J['Carat'] * df_050_059_HS_I1_J['PPC']


                elif i=="J"  and j == "I2" and k == "HS":
                    df_050_059_HS_I2_J = pd.DataFrame()
                    df_050_059_HS_I2_J ['Wt Range'] = None
                    df_050_059_HS_I2_J  = df_050_059_HS_I2_J.assign(Company=None)
                    df_050_059_HS_I2_J  = df_050_059_HS_I2_J.assign(Shape=None)
                    df_050_059_HS_I2_J  = df_050_059_HS_I2_J.assign(Carat=None)
                    df_050_059_HS_I2_J  = df_050_059_HS_I2_J.assign(Color=None)
                    df_050_059_HS_I2_J  = df_050_059_HS_I2_J.assign(Clarity=None)
                    df_050_059_HS_I2_J  = df_050_059_HS_I2_J.assign(Cut=None)
                    df_050_059_HS_I2_J  = df_050_059_HS_I2_J.assign(Polish=None)
                    df_050_059_HS_I2_J  = df_050_059_HS_I2_J.assign(Symmetry=None)
                    df_050_059_HS_I2_J  = df_050_059_HS_I2_J.assign(Ratio=None)
                    df_050_059_HS_I2_J  = df_050_059_HS_I2_J.assign(PPC=None)
                    df_050_059_HS_I2_J  = df_050_059_HS_I2_J.assign(Total=None)
                    df_050_059_HS_I2_J ['Wt Range'] = listwtrange
                    df_050_059_HS_I2_J ['Company'] = listcom
                    df_050_059_HS_I2_J ['Shape'] = listshap
                    df_050_059_HS_I2_J ['Carat'] = listcar
                    df_050_059_HS_I2_J ['Color'] = listcol
                    df_050_059_HS_I2_J ['Clarity'] = listclar
                    df_050_059_HS_I2_J ['Cut'] = listcut
                    df_050_059_HS_I2_J ['Polish'] = listpol
                    df_050_059_HS_I2_J ['Symmetry'] = listsym
                    df_050_059_HS_I2_J ['Ratio'] = listrat
                    df_050_059_HS_I2_J ['PPC'] = listdesc
                    df_050_059_HS_I2_J ['Total'] = listtotal
                    df_050_059_HS_I2_J['Carat'] = df_050_059_HS_I2_J['Carat'].astype('float64')
                    df_050_059_HS_I2_J['PPC'] = df_050_059_HS_I2_J['PPC'].astype('float64')
                    df_050_059_HS_I2_J['Total'] = df_050_059_HS_I2_J['Total'].astype('float64')
                    df_050_059_HS_I2_J['Total'] = df_050_059_HS_I2_J['Carat'] * df_050_059_HS_I2_J['PPC']


                elif i=="K" and j == "IF" and k == "HS":
                    df_050_059_HS_IF_K = pd.DataFrame()
                    df_050_059_HS_IF_K ['Wt Range'] = None
                    df_050_059_HS_IF_K  = df_050_059_HS_IF_K.assign(Company=None)
                    df_050_059_HS_IF_K  = df_050_059_HS_IF_K.assign(Shape=None)
                    df_050_059_HS_IF_K  = df_050_059_HS_IF_K.assign(Carat=None)
                    df_050_059_HS_IF_K  = df_050_059_HS_IF_K.assign(Color=None)
                    df_050_059_HS_IF_K  = df_050_059_HS_IF_K.assign(Clarity=None)
                    df_050_059_HS_IF_K  = df_050_059_HS_IF_K.assign(Cut=None)
                    df_050_059_HS_IF_K  = df_050_059_HS_IF_K.assign(Polish=None)
                    df_050_059_HS_IF_K  = df_050_059_HS_IF_K.assign(Symmetry=None)
                    df_050_059_HS_IF_K  = df_050_059_HS_IF_K.assign(Ratio=None)
                    df_050_059_HS_IF_K  = df_050_059_HS_IF_K.assign(PPC=None)
                    df_050_059_HS_IF_K  = df_050_059_HS_IF_K.assign(Total=None)
                    df_050_059_HS_IF_K ['Wt Range'] = listwtrange
                    df_050_059_HS_IF_K ['Company'] = listcom
                    df_050_059_HS_IF_K ['Shape'] = listshap
                    df_050_059_HS_IF_K ['Carat'] = listcar
                    df_050_059_HS_IF_K ['Color'] = listcol
                    df_050_059_HS_IF_K ['Clarity'] = listclar
                    df_050_059_HS_IF_K ['Cut'] = listcut
                    df_050_059_HS_IF_K ['Polish'] = listpol
                    df_050_059_HS_IF_K ['Symmetry'] = listsym
                    df_050_059_HS_IF_K ['Ratio'] = listrat
                    df_050_059_HS_IF_K ['PPC'] = listdesc
                    df_050_059_HS_IF_K ['Total'] = listtotal
                    df_050_059_HS_IF_K['Carat'] = df_050_059_HS_IF_K['Carat'].astype('float64')
                    df_050_059_HS_IF_K['PPC'] = df_050_059_HS_IF_K['PPC'].astype('float64')
                    df_050_059_HS_IF_K['Total'] = df_050_059_HS_IF_K['Total'].astype('float64')
                    df_050_059_HS_IF_K['Total'] = df_050_059_HS_IF_K['Carat'] * df_050_059_HS_IF_K['PPC']



                elif i=="K" and j == "VVS1" and k == "HS":
                    df_050_059_HS_VVS1_K = pd.DataFrame()
                    df_050_059_HS_VVS1_K ['Wt Range'] = None
                    df_050_059_HS_VVS1_K  = df_050_059_HS_VVS1_K.assign(Company=None)
                    df_050_059_HS_VVS1_K  = df_050_059_HS_VVS1_K.assign(Shape=None)
                    df_050_059_HS_VVS1_K  = df_050_059_HS_VVS1_K.assign(Carat=None)
                    df_050_059_HS_VVS1_K  = df_050_059_HS_VVS1_K.assign(Color=None)
                    df_050_059_HS_VVS1_K  = df_050_059_HS_VVS1_K.assign(Clarity=None)
                    df_050_059_HS_VVS1_K  = df_050_059_HS_VVS1_K.assign(Cut=None)
                    df_050_059_HS_VVS1_K  = df_050_059_HS_VVS1_K.assign(Polish=None)
                    df_050_059_HS_VVS1_K  = df_050_059_HS_VVS1_K.assign(Symmetry=None)
                    df_050_059_HS_VVS1_K  = df_050_059_HS_VVS1_K.assign(Ratio=None)
                    df_050_059_HS_VVS1_K  = df_050_059_HS_VVS1_K.assign(PPC=None)
                    df_050_059_HS_VVS1_K  = df_050_059_HS_VVS1_K.assign(Total=None)
                    df_050_059_HS_VVS1_K ['Wt Range'] = listwtrange
                    df_050_059_HS_VVS1_K ['Company'] = listcom
                    df_050_059_HS_VVS1_K ['Shape'] = listshap
                    df_050_059_HS_VVS1_K ['Carat'] = listcar
                    df_050_059_HS_VVS1_K ['Color'] = listcol
                    df_050_059_HS_VVS1_K ['Clarity'] = listclar
                    df_050_059_HS_VVS1_K ['Cut'] = listcut
                    df_050_059_HS_VVS1_K ['Polish'] = listpol
                    df_050_059_HS_VVS1_K ['Symmetry'] = listsym
                    df_050_059_HS_VVS1_K ['Ratio'] = listrat
                    df_050_059_HS_VVS1_K ['PPC'] = listdesc
                    df_050_059_HS_VVS1_K ['Total'] = listtotal
                    df_050_059_HS_VVS1_K['Carat'] = df_050_059_HS_VVS1_K['Carat'].astype('float64')
                    df_050_059_HS_VVS1_K['PPC'] = df_050_059_HS_VVS1_K['PPC'].astype('float64')
                    df_050_059_HS_VVS1_K['Total'] = df_050_059_HS_VVS1_K['Total'].astype('float64')
                    df_050_059_HS_VVS1_K['Total'] = df_050_059_HS_VVS1_K['Carat'] * df_050_059_HS_VVS1_K['PPC']


                elif i=="K" and j == "VVS2" and k == "HS":
                    df_050_059_HS_VVS2_K = pd.DataFrame()
                    df_050_059_HS_VVS2_K ['Wt Range'] = None
                    df_050_059_HS_VVS2_K  = df_050_059_HS_VVS2_K.assign(Company=None)
                    df_050_059_HS_VVS2_K  = df_050_059_HS_VVS2_K.assign(Shape=None)
                    df_050_059_HS_VVS2_K  = df_050_059_HS_VVS2_K.assign(Carat=None)
                    df_050_059_HS_VVS2_K  = df_050_059_HS_VVS2_K.assign(Color=None)
                    df_050_059_HS_VVS2_K  = df_050_059_HS_VVS2_K.assign(Clarity=None)
                    df_050_059_HS_VVS2_K  = df_050_059_HS_VVS2_K.assign(Cut=None)
                    df_050_059_HS_VVS2_K  = df_050_059_HS_VVS2_K.assign(Polish=None)
                    df_050_059_HS_VVS2_K  = df_050_059_HS_VVS2_K.assign(Symmetry=None)
                    df_050_059_HS_VVS2_K  = df_050_059_HS_VVS2_K.assign(Ratio=None)
                    df_050_059_HS_VVS2_K  = df_050_059_HS_VVS2_K.assign(PPC=None)
                    df_050_059_HS_VVS2_K  = df_050_059_HS_VVS2_K.assign(Total=None)
                    df_050_059_HS_VVS2_K ['Wt Range'] = listwtrange
                    df_050_059_HS_VVS2_K ['Company'] = listcom
                    df_050_059_HS_VVS2_K ['Shape'] = listshap
                    df_050_059_HS_VVS2_K ['Carat'] = listcar
                    df_050_059_HS_VVS2_K ['Color'] = listcol
                    df_050_059_HS_VVS2_K ['Clarity'] = listclar
                    df_050_059_HS_VVS2_K ['Cut'] = listcut
                    df_050_059_HS_VVS2_K ['Polish'] = listpol
                    df_050_059_HS_VVS2_K ['Symmetry'] = listsym
                    df_050_059_HS_VVS2_K ['Ratio'] = listrat
                    df_050_059_HS_VVS2_K ['PPC'] = listdesc
                    df_050_059_HS_VVS2_K ['Total'] = listtotal
                    df_050_059_HS_VVS2_K['Carat'] = df_050_059_HS_VVS2_K['Carat'].astype('float64')
                    df_050_059_HS_VVS2_K['PPC'] = df_050_059_HS_VVS2_K['PPC'].astype('float64')
                    df_050_059_HS_VVS2_K['Total'] = df_050_059_HS_VVS2_K['Total'].astype('float64')
                    df_050_059_HS_VVS2_K['Total'] = df_050_059_HS_VVS2_K['Carat'] * df_050_059_HS_VVS2_K['PPC']


                elif i=="K" and j=="VS1" and k == "HS":
                    df_050_059_HS_VS1_K = pd.DataFrame()
                    df_050_059_HS_VS1_K ['Wt Range'] = None
                    df_050_059_HS_VS1_K  = df_050_059_HS_VS1_K.assign(Company=None)
                    df_050_059_HS_VS1_K  = df_050_059_HS_VS1_K.assign(Shape=None)
                    df_050_059_HS_VS1_K  = df_050_059_HS_VS1_K.assign(Carat=None)
                    df_050_059_HS_VS1_K  = df_050_059_HS_VS1_K.assign(Color=None)
                    df_050_059_HS_VS1_K  = df_050_059_HS_VS1_K.assign(Clarity=None)
                    df_050_059_HS_VS1_K  = df_050_059_HS_VS1_K.assign(Cut=None)
                    df_050_059_HS_VS1_K  = df_050_059_HS_VS1_K.assign(Polish=None)
                    df_050_059_HS_VS1_K  = df_050_059_HS_VS1_K.assign(Symmetry=None)
                    df_050_059_HS_VS1_K  = df_050_059_HS_VS1_K.assign(Ratio=None)
                    df_050_059_HS_VS1_K  = df_050_059_HS_VS1_K.assign(PPC=None)
                    df_050_059_HS_VS1_K  = df_050_059_HS_VS1_K.assign(Total=None)
                    df_050_059_HS_VS1_K ['Wt Range'] = listwtrange
                    df_050_059_HS_VS1_K ['Company'] = listcom
                    df_050_059_HS_VS1_K ['Shape'] = listshap
                    df_050_059_HS_VS1_K ['Carat'] = listcar
                    df_050_059_HS_VS1_K ['Color'] = listcol
                    df_050_059_HS_VS1_K ['Clarity'] = listclar
                    df_050_059_HS_VS1_K ['Cut'] = listcut
                    df_050_059_HS_VS1_K ['Polish'] = listpol
                    df_050_059_HS_VS1_K ['Symmetry'] = listsym
                    df_050_059_HS_VS1_K ['Ratio'] = listrat
                    df_050_059_HS_VS1_K ['PPC'] = listdesc
                    df_050_059_HS_VS1_K ['Total'] = listtotal
                    df_050_059_HS_VS1_K['Carat'] = df_050_059_HS_VS1_K['Carat'].astype('float64')
                    df_050_059_HS_VS1_K['PPC'] = df_050_059_HS_VS1_K['PPC'].astype('float64')
                    df_050_059_HS_VS1_K['Total'] = df_050_059_HS_VS1_K['Total'].astype('float64')
                    df_050_059_HS_VS1_K['Total'] = df_050_059_HS_VS1_K['Carat'] * df_050_059_HS_VS1_K['PPC']


                elif i=="K" and j == "VS2" and k == "HS":
                    df_050_059_HS_VS2_K = pd.DataFrame()
                    df_050_059_HS_VS2_K ['Wt Range'] = None
                    df_050_059_HS_VS2_K  = df_050_059_HS_VS2_K.assign(Company=None)
                    df_050_059_HS_VS2_K  = df_050_059_HS_VS2_K.assign(Shape=None)
                    df_050_059_HS_VS2_K  = df_050_059_HS_VS2_K.assign(Carat=None)
                    df_050_059_HS_VS2_K  = df_050_059_HS_VS2_K.assign(Color=None)
                    df_050_059_HS_VS2_K  = df_050_059_HS_VS2_K.assign(Clarity=None)
                    df_050_059_HS_VS2_K  = df_050_059_HS_VS2_K.assign(Cut=None)
                    df_050_059_HS_VS2_K  = df_050_059_HS_VS2_K.assign(Polish=None)
                    df_050_059_HS_VS2_K  = df_050_059_HS_VS2_K.assign(Symmetry=None)
                    df_050_059_HS_VS2_K  = df_050_059_HS_VS2_K.assign(Ratio=None)
                    df_050_059_HS_VS2_K  = df_050_059_HS_VS2_K.assign(PPC=None)
                    df_050_059_HS_VS2_K  = df_050_059_HS_VS2_K.assign(Total=None)
                    df_050_059_HS_VS2_K ['Wt Range'] = listwtrange
                    df_050_059_HS_VS2_K ['Company'] = listcom
                    df_050_059_HS_VS2_K ['Shape'] = listshap
                    df_050_059_HS_VS2_K ['Carat'] = listcar
                    df_050_059_HS_VS2_K ['Color'] = listcol
                    df_050_059_HS_VS2_K ['Clarity'] = listclar
                    df_050_059_HS_VS2_K ['Cut'] = listcut
                    df_050_059_HS_VS2_K ['Polish'] = listpol
                    df_050_059_HS_VS2_K ['Symmetry'] = listsym
                    df_050_059_HS_VS2_K ['Ratio'] = listrat
                    df_050_059_HS_VS2_K ['PPC'] = listdesc
                    df_050_059_HS_VS2_K ['Total'] = listtotal
                    df_050_059_HS_VS2_K['Carat'] = df_050_059_HS_VS2_K['Carat'].astype('float64')
                    df_050_059_HS_VS2_K['PPC'] = df_050_059_HS_VS2_K['PPC'].astype('float64')
                    df_050_059_HS_VS2_K['Total'] = df_050_059_HS_VS2_K['Total'].astype('float64')
                    df_050_059_HS_VS2_K['Total'] = df_050_059_HS_VS2_K['Carat'] * df_050_059_HS_VS2_K['PPC']


                elif i=="K" and j == "SI1" and k == "HS":
                    df_050_059_HS_SI1_K = pd.DataFrame()
                    df_050_059_HS_SI1_K ['Wt Range'] = None
                    df_050_059_HS_SI1_K  = df_050_059_HS_SI1_K.assign(Company=None)
                    df_050_059_HS_SI1_K  = df_050_059_HS_SI1_K.assign(Shape=None)
                    df_050_059_HS_SI1_K  = df_050_059_HS_SI1_K.assign(Carat=None)
                    df_050_059_HS_SI1_K  = df_050_059_HS_SI1_K.assign(Color=None)
                    df_050_059_HS_SI1_K  = df_050_059_HS_SI1_K.assign(Clarity=None)
                    df_050_059_HS_SI1_K  = df_050_059_HS_SI1_K.assign(Cut=None)
                    df_050_059_HS_SI1_K  = df_050_059_HS_SI1_K.assign(Polish=None)
                    df_050_059_HS_SI1_K  = df_050_059_HS_SI1_K.assign(Symmetry=None)
                    df_050_059_HS_SI1_K  = df_050_059_HS_SI1_K.assign(Ratio=None)
                    df_050_059_HS_SI1_K  = df_050_059_HS_SI1_K.assign(PPC=None)
                    df_050_059_HS_SI1_K  = df_050_059_HS_SI1_K.assign(Total=None)
                    df_050_059_HS_SI1_K ['Wt Range'] = listwtrange
                    df_050_059_HS_SI1_K ['Company'] = listcom
                    df_050_059_HS_SI1_K ['Shape'] = listshap
                    df_050_059_HS_SI1_K ['Carat'] = listcar
                    df_050_059_HS_SI1_K ['Color'] = listcol
                    df_050_059_HS_SI1_K ['Clarity'] = listclar
                    df_050_059_HS_SI1_K ['Cut'] = listcut
                    df_050_059_HS_SI1_K ['Polish'] = listpol
                    df_050_059_HS_SI1_K ['Symmetry'] = listsym
                    df_050_059_HS_SI1_K ['Ratio'] = listrat
                    df_050_059_HS_SI1_K ['PPC'] = listdesc
                    df_050_059_HS_SI1_K ['Total'] = listtotal
                    df_050_059_HS_SI1_K['Carat'] = df_050_059_HS_SI1_K['Carat'].astype('float64')
                    df_050_059_HS_SI1_K['PPC'] = df_050_059_HS_SI1_K['PPC'].astype('float64')
                    df_050_059_HS_SI1_K['Total'] = df_050_059_HS_SI1_K['Total'].astype('float64')
                    df_050_059_HS_SI1_K['Total'] = df_050_059_HS_SI1_K['Carat'] * df_050_059_HS_SI1_K['PPC']


                elif i=="K" and j == "SI2" and k == "HS":
                    df_050_059_HS_SI2_K = pd.DataFrame()
                    df_050_059_HS_SI2_K ['Wt Range'] = None
                    df_050_059_HS_SI2_K  = df_050_059_HS_SI2_K.assign(Company=None)
                    df_050_059_HS_SI2_K  = df_050_059_HS_SI2_K.assign(Shape=None)
                    df_050_059_HS_SI2_K  = df_050_059_HS_SI2_K.assign(Carat=None)
                    df_050_059_HS_SI2_K  = df_050_059_HS_SI2_K.assign(Color=None)
                    df_050_059_HS_SI2_K  = df_050_059_HS_SI2_K.assign(Clarity=None)
                    df_050_059_HS_SI2_K  = df_050_059_HS_SI2_K.assign(Cut=None)
                    df_050_059_HS_SI2_K  = df_050_059_HS_SI2_K.assign(Polish=None)
                    df_050_059_HS_SI2_K  = df_050_059_HS_SI2_K.assign(Symmetry=None)
                    df_050_059_HS_SI2_K  = df_050_059_HS_SI2_K.assign(Ratio=None)
                    df_050_059_HS_SI2_K  = df_050_059_HS_SI2_K.assign(PPC=None)
                    df_050_059_HS_SI2_K  = df_050_059_HS_SI2_K.assign(Total=None)
                    df_050_059_HS_SI2_K ['Wt Range'] = listwtrange
                    df_050_059_HS_SI2_K ['Company'] = listcom
                    df_050_059_HS_SI2_K ['Shape'] = listshap
                    df_050_059_HS_SI2_K ['Carat'] = listcar
                    df_050_059_HS_SI2_K ['Color'] = listcol
                    df_050_059_HS_SI2_K ['Clarity'] = listclar
                    df_050_059_HS_SI2_K ['Cut'] = listcut
                    df_050_059_HS_SI2_K ['Polish'] = listpol
                    df_050_059_HS_SI2_K ['Symmetry'] = listsym
                    df_050_059_HS_SI2_K ['Ratio'] = listrat
                    df_050_059_HS_SI2_K ['PPC'] = listdesc
                    df_050_059_HS_SI2_K ['Total'] = listtotal
                    df_050_059_HS_SI2_K['Carat'] = df_050_059_HS_SI2_K['Carat'].astype('float64')
                    df_050_059_HS_SI2_K['PPC'] = df_050_059_HS_SI2_K['PPC'].astype('float64')
                    df_050_059_HS_SI2_K['Total'] = df_050_059_HS_SI2_K['Total'].astype('float64')
                    df_050_059_HS_SI2_K['Total'] = df_050_059_HS_SI2_K['Carat'] * df_050_059_HS_SI2_K['PPC']


                elif i=="K" and j == "I1" and k == "HS":
                    df_050_059_HS_I1_K = pd.DataFrame()
                    df_050_059_HS_I1_K ['Wt Range'] = None
                    df_050_059_HS_I1_K  = df_050_059_HS_I1_K.assign(Company=None)
                    df_050_059_HS_I1_K  = df_050_059_HS_I1_K.assign(Shape=None)
                    df_050_059_HS_I1_K  = df_050_059_HS_I1_K.assign(Carat=None)
                    df_050_059_HS_I1_K  = df_050_059_HS_I1_K.assign(Color=None)
                    df_050_059_HS_I1_K  = df_050_059_HS_I1_K.assign(Clarity=None)
                    df_050_059_HS_I1_K  = df_050_059_HS_I1_K.assign(Cut=None)
                    df_050_059_HS_I1_K  = df_050_059_HS_I1_K.assign(Polish=None)
                    df_050_059_HS_I1_K  = df_050_059_HS_I1_K.assign(Symmetry=None)
                    df_050_059_HS_I1_K  = df_050_059_HS_I1_K.assign(Ratio=None)
                    df_050_059_HS_I1_K  = df_050_059_HS_I1_K.assign(PPC=None)
                    df_050_059_HS_I1_K  = df_050_059_HS_I1_K.assign(Total=None)
                    df_050_059_HS_I1_K ['Wt Range'] = listwtrange
                    df_050_059_HS_I1_K ['Company'] = listcom
                    df_050_059_HS_I1_K ['Shape'] = listshap
                    df_050_059_HS_I1_K ['Carat'] = listcar
                    df_050_059_HS_I1_K ['Color'] = listcol
                    df_050_059_HS_I1_K ['Clarity'] = listclar
                    df_050_059_HS_I1_K ['Cut'] = listcut
                    df_050_059_HS_I1_K ['Polish'] = listpol
                    df_050_059_HS_I1_K ['Symmetry'] = listsym
                    df_050_059_HS_I1_K ['Ratio'] = listrat
                    df_050_059_HS_I1_K ['PPC'] = listdesc
                    df_050_059_HS_I1_K ['Total'] = listtotal
                    df_050_059_HS_I1_K['Carat'] = df_050_059_HS_I1_K['Carat'].astype('float64')
                    df_050_059_HS_I1_K['PPC'] = df_050_059_HS_I1_K['PPC'].astype('float64')
                    df_050_059_HS_I1_K['Total'] = df_050_059_HS_I1_K['Total'].astype('float64')
                    df_050_059_HS_I1_K['Total'] = df_050_059_HS_I1_K['Carat'] * df_050_059_HS_I1_K['PPC']


                elif i=="K" and j == "I2" and k == "HS":
                    df_050_059_HS_I2_K = pd.DataFrame()
                    df_050_059_HS_I2_K ['Wt Range'] = None
                    df_050_059_HS_I2_K  = df_050_059_HS_I2_K.assign(Company=None)
                    df_050_059_HS_I2_K  = df_050_059_HS_I2_K.assign(Shape=None)
                    df_050_059_HS_I2_K  = df_050_059_HS_I2_K.assign(Carat=None)
                    df_050_059_HS_I2_K  = df_050_059_HS_I2_K.assign(Color=None)
                    df_050_059_HS_I2_K  = df_050_059_HS_I2_K.assign(Clarity=None)
                    df_050_059_HS_I2_K  = df_050_059_HS_I2_K.assign(Cut=None)
                    df_050_059_HS_I2_K  = df_050_059_HS_I2_K.assign(Polish=None)
                    df_050_059_HS_I2_K  = df_050_059_HS_I2_K.assign(Symmetry=None)
                    df_050_059_HS_I2_K  = df_050_059_HS_I2_K.assign(Ratio=None)
                    df_050_059_HS_I2_K  = df_050_059_HS_I2_K.assign(PPC=None)
                    df_050_059_HS_I2_K  = df_050_059_HS_I2_K.assign(Total=None)
                    df_050_059_HS_I2_K ['Wt Range'] = listwtrange
                    df_050_059_HS_I2_K ['Company'] = listcom
                    df_050_059_HS_I2_K ['Shape'] = listshap
                    df_050_059_HS_I2_K ['Carat'] = listcar
                    df_050_059_HS_I2_K ['Color'] = listcol
                    df_050_059_HS_I2_K ['Clarity'] = listclar
                    df_050_059_HS_I2_K ['Cut'] = listcut
                    df_050_059_HS_I2_K ['Polish'] = listpol
                    df_050_059_HS_I2_K ['Symmetry'] = listsym
                    df_050_059_HS_I2_K ['Ratio'] = listrat
                    df_050_059_HS_I2_K ['PPC'] = listdesc
                    df_050_059_HS_I2_K ['Total'] = listtotal
                    df_050_059_HS_I2_K['Carat'] = df_050_059_HS_I2_K['Carat'].astype('float64')
                    df_050_059_HS_I2_K['PPC'] = df_050_059_HS_I2_K['PPC'].astype('float64')
                    df_050_059_HS_I2_K['Total'] = df_050_059_HS_I2_K['Total'].astype('float64')
                    df_050_059_HS_I2_K['Total'] = df_050_059_HS_I2_K['Carat'] * df_050_059_HS_I2_K['PPC']


                elif i=="L" and j == "IF" and k == "HS":
                    df_050_059_HS_IF_L = pd.DataFrame()
                    df_050_059_HS_IF_L ['Wt Range'] = None
                    df_050_059_HS_IF_L  = df_050_059_HS_IF_L.assign(Company=None)
                    df_050_059_HS_IF_L  = df_050_059_HS_IF_L.assign(Shape=None)
                    df_050_059_HS_IF_L  = df_050_059_HS_IF_L.assign(Carat=None)
                    df_050_059_HS_IF_L  = df_050_059_HS_IF_L.assign(Color=None)
                    df_050_059_HS_IF_L  = df_050_059_HS_IF_L.assign(Clarity=None)
                    df_050_059_HS_IF_L  = df_050_059_HS_IF_L.assign(Cut=None)
                    df_050_059_HS_IF_L  = df_050_059_HS_IF_L.assign(Polish=None)
                    df_050_059_HS_IF_L  = df_050_059_HS_IF_L.assign(Symmetry=None)
                    df_050_059_HS_IF_L  = df_050_059_HS_IF_L.assign(Ratio=None)
                    df_050_059_HS_IF_L  = df_050_059_HS_IF_L.assign(PPC=None)
                    df_050_059_HS_IF_L  = df_050_059_HS_IF_L.assign(Total=None)
                    df_050_059_HS_IF_L ['Wt Range'] = listwtrange
                    df_050_059_HS_IF_L ['Company'] = listcom
                    df_050_059_HS_IF_L ['Shape'] = listshap
                    df_050_059_HS_IF_L ['Carat'] = listcar
                    df_050_059_HS_IF_L ['Color'] = listcol
                    df_050_059_HS_IF_L ['Clarity'] = listclar
                    df_050_059_HS_IF_L ['Cut'] = listcut
                    df_050_059_HS_IF_L ['Polish'] = listpol
                    df_050_059_HS_IF_L ['Symmetry'] = listsym
                    df_050_059_HS_IF_L ['Ratio'] = listrat
                    df_050_059_HS_IF_L ['PPC'] = listdesc
                    df_050_059_HS_IF_L ['Total'] = listtotal
                    df_050_059_HS_IF_L['Carat'] = df_050_059_HS_IF_L['Carat'].astype('float64')
                    df_050_059_HS_IF_L['PPC'] = df_050_059_HS_IF_L['PPC'].astype('float64')
                    df_050_059_HS_IF_L['Total'] = df_050_059_HS_IF_L['Total'].astype('float64')
                    df_050_059_HS_IF_L['Total'] = df_050_059_HS_IF_L['Carat'] * df_050_059_HS_IF_L['PPC']


                elif i=="L" and j == "VVS1" and k == "HS":
                    df_050_059_HS_VVS1_L = pd.DataFrame()
                    df_050_059_HS_VVS1_L ['Wt Range'] = None
                    df_050_059_HS_VVS1_L  = df_050_059_HS_VVS1_L.assign(Company=None)
                    df_050_059_HS_VVS1_L  = df_050_059_HS_VVS1_L.assign(Shape=None)
                    df_050_059_HS_VVS1_L  = df_050_059_HS_VVS1_L.assign(Carat=None)
                    df_050_059_HS_VVS1_L  = df_050_059_HS_VVS1_L.assign(Color=None)
                    df_050_059_HS_VVS1_L  = df_050_059_HS_VVS1_L.assign(Clarity=None)
                    df_050_059_HS_VVS1_L  = df_050_059_HS_VVS1_L.assign(Cut=None)
                    df_050_059_HS_VVS1_L  = df_050_059_HS_VVS1_L.assign(Polish=None)
                    df_050_059_HS_VVS1_L  = df_050_059_HS_VVS1_L.assign(Symmetry=None)
                    df_050_059_HS_VVS1_L  = df_050_059_HS_VVS1_L.assign(Ratio=None)
                    df_050_059_HS_VVS1_L  = df_050_059_HS_VVS1_L.assign(PPC=None)
                    df_050_059_HS_VVS1_L  = df_050_059_HS_VVS1_L.assign(Total=None)
                    df_050_059_HS_VVS1_L ['Wt Range'] = listwtrange
                    df_050_059_HS_VVS1_L ['Company'] = listcom
                    df_050_059_HS_VVS1_L ['Shape'] = listshap
                    df_050_059_HS_VVS1_L ['Carat'] = listcar
                    df_050_059_HS_VVS1_L ['Color'] = listcol
                    df_050_059_HS_VVS1_L ['Clarity'] = listclar
                    df_050_059_HS_VVS1_L ['Cut'] = listcut
                    df_050_059_HS_VVS1_L ['Polish'] = listpol
                    df_050_059_HS_VVS1_L ['Symmetry'] = listsym
                    df_050_059_HS_VVS1_L ['Ratio'] = listrat
                    df_050_059_HS_VVS1_L ['PPC'] = listdesc
                    df_050_059_HS_VVS1_L ['Total'] = listtotal
                    df_050_059_HS_VVS1_L['Carat'] = df_050_059_HS_VVS1_L['Carat'].astype('float64')
                    df_050_059_HS_VVS1_L['PPC'] = df_050_059_HS_VVS1_L['PPC'].astype('float64')
                    df_050_059_HS_VVS1_L['Total'] = df_050_059_HS_VVS1_L['Total'].astype('float64')
                    df_050_059_HS_VVS1_L['Total'] = df_050_059_HS_VVS1_L['Carat'] * df_050_059_HS_VVS1_L['PPC']


                elif i=="L" and j == "VVS2" and k == "HS":
                    df_050_059_HS_VVS2_L = pd.DataFrame()
                    df_050_059_HS_VVS2_L ['Wt Range'] = None
                    df_050_059_HS_VVS2_L  = df_050_059_HS_VVS2_L.assign(Company=None)
                    df_050_059_HS_VVS2_L  = df_050_059_HS_VVS2_L.assign(Shape=None)
                    df_050_059_HS_VVS2_L  = df_050_059_HS_VVS2_L.assign(Carat=None)
                    df_050_059_HS_VVS2_L  = df_050_059_HS_VVS2_L.assign(Color=None)
                    df_050_059_HS_VVS2_L  = df_050_059_HS_VVS2_L.assign(Clarity=None)
                    df_050_059_HS_VVS2_L  = df_050_059_HS_VVS2_L.assign(Cut=None)
                    df_050_059_HS_VVS2_L  = df_050_059_HS_VVS2_L.assign(Polish=None)
                    df_050_059_HS_VVS2_L  = df_050_059_HS_VVS2_L.assign(Symmetry=None)
                    df_050_059_HS_VVS2_L  = df_050_059_HS_VVS2_L.assign(Ratio=None)
                    df_050_059_HS_VVS2_L  = df_050_059_HS_VVS2_L.assign(PPC=None)
                    df_050_059_HS_VVS2_L  = df_050_059_HS_VVS2_L.assign(Total=None)
                    df_050_059_HS_VVS2_L ['Wt Range'] = listwtrange
                    df_050_059_HS_VVS2_L ['Company'] = listcom
                    df_050_059_HS_VVS2_L ['Shape'] = listshap
                    df_050_059_HS_VVS2_L ['Carat'] = listcar
                    df_050_059_HS_VVS2_L ['Color'] = listcol
                    df_050_059_HS_VVS2_L ['Clarity'] = listclar
                    df_050_059_HS_VVS2_L ['Cut'] = listcut
                    df_050_059_HS_VVS2_L ['Polish'] = listpol
                    df_050_059_HS_VVS2_L ['Symmetry'] = listsym
                    df_050_059_HS_VVS2_L ['Ratio'] = listrat
                    df_050_059_HS_VVS2_L ['PPC'] = listdesc
                    df_050_059_HS_VVS2_L ['Total'] = listtotal
                    df_050_059_HS_VVS2_L['Carat'] = df_050_059_HS_VVS2_L['Carat'].astype('float64')
                    df_050_059_HS_VVS2_L['PPC'] = df_050_059_HS_VVS2_L['PPC'].astype('float64')
                    df_050_059_HS_VVS2_L['Total'] = df_050_059_HS_VVS2_L['Total'].astype('float64')
                    df_050_059_HS_VVS2_L['Total'] = df_050_059_HS_VVS2_L['Carat'] * df_050_059_HS_VVS2_L['PPC']


                elif i=="L" and j=="VS1" and k == "HS":
                    df_050_059_HS_VS1_L = pd.DataFrame()
                    df_050_059_HS_VS1_L ['Wt Range'] = None
                    df_050_059_HS_VS1_L  = df_050_059_HS_VS1_L.assign(Company=None)
                    df_050_059_HS_VS1_L  = df_050_059_HS_VS1_L.assign(Shape=None)
                    df_050_059_HS_VS1_L  = df_050_059_HS_VS1_L.assign(Carat=None)
                    df_050_059_HS_VS1_L  = df_050_059_HS_VS1_L.assign(Color=None)
                    df_050_059_HS_VS1_L  = df_050_059_HS_VS1_L.assign(Clarity=None)
                    df_050_059_HS_VS1_L  = df_050_059_HS_VS1_L.assign(Cut=None)
                    df_050_059_HS_VS1_L  = df_050_059_HS_VS1_L.assign(Polish=None)
                    df_050_059_HS_VS1_L  = df_050_059_HS_VS1_L.assign(Symmetry=None)
                    df_050_059_HS_VS1_L  = df_050_059_HS_VS1_L.assign(Ratio=None)
                    df_050_059_HS_VS1_L  = df_050_059_HS_VS1_L.assign(PPC=None)
                    df_050_059_HS_VS1_L  = df_050_059_HS_VS1_L.assign(Total=None)
                    df_050_059_HS_VS1_L ['Wt Range'] = listwtrange
                    df_050_059_HS_VS1_L ['Company'] = listcom
                    df_050_059_HS_VS1_L ['Shape'] = listshap
                    df_050_059_HS_VS1_L ['Carat'] = listcar
                    df_050_059_HS_VS1_L ['Color'] = listcol
                    df_050_059_HS_VS1_L ['Clarity'] = listclar
                    df_050_059_HS_VS1_L ['Cut'] = listcut
                    df_050_059_HS_VS1_L ['Polish'] = listpol
                    df_050_059_HS_VS1_L ['Symmetry'] = listsym
                    df_050_059_HS_VS1_L ['Ratio'] = listrat
                    df_050_059_HS_VS1_L ['PPC'] = listdesc
                    df_050_059_HS_VS1_L ['Total'] = listtotal
                    df_050_059_HS_VS1_L['Carat'] = df_050_059_HS_VS1_L['Carat'].astype('float64')
                    df_050_059_HS_VS1_L['PPC'] = df_050_059_HS_VS1_L['PPC'].astype('float64')
                    df_050_059_HS_VS1_L['Total'] = df_050_059_HS_VS1_L['Total'].astype('float64')
                    df_050_059_HS_VS1_L['Total'] = df_050_059_HS_VS1_L['Carat'] * df_050_059_HS_VS1_L['PPC']


                elif i=="L" and j == "VS2" and k == "HS":
                    df_050_059_HS_VS2_L = pd.DataFrame()
                    df_050_059_HS_VS2_L ['Wt Range'] = None
                    df_050_059_HS_VS2_L  = df_050_059_HS_VS2_L.assign(Company=None)
                    df_050_059_HS_VS2_L  = df_050_059_HS_VS2_L.assign(Shape=None)
                    df_050_059_HS_VS2_L  = df_050_059_HS_VS2_L.assign(Carat=None)
                    df_050_059_HS_VS2_L  = df_050_059_HS_VS2_L.assign(Color=None)
                    df_050_059_HS_VS2_L  = df_050_059_HS_VS2_L.assign(Clarity=None)
                    df_050_059_HS_VS2_L  = df_050_059_HS_VS2_L.assign(Cut=None)
                    df_050_059_HS_VS2_L  = df_050_059_HS_VS2_L.assign(Polish=None)
                    df_050_059_HS_VS2_L  = df_050_059_HS_VS2_L.assign(Symmetry=None)
                    df_050_059_HS_VS2_L  = df_050_059_HS_VS2_L.assign(Ratio=None)
                    df_050_059_HS_VS2_L  = df_050_059_HS_VS2_L.assign(PPC=None)
                    df_050_059_HS_VS2_L  = df_050_059_HS_VS2_L.assign(Total=None)
                    df_050_059_HS_VS2_L ['Wt Range'] = listwtrange
                    df_050_059_HS_VS2_L ['Company'] = listcom
                    df_050_059_HS_VS2_L ['Shape'] = listshap
                    df_050_059_HS_VS2_L ['Carat'] = listcar
                    df_050_059_HS_VS2_L ['Color'] = listcol
                    df_050_059_HS_VS2_L ['Clarity'] = listclar
                    df_050_059_HS_VS2_L ['Cut'] = listcut
                    df_050_059_HS_VS2_L ['Polish'] = listpol
                    df_050_059_HS_VS2_L ['Symmetry'] = listsym
                    df_050_059_HS_VS2_L ['Ratio'] = listrat
                    df_050_059_HS_VS2_L ['PPC'] = listdesc
                    df_050_059_HS_VS2_L ['Total'] = listtotal
                    df_050_059_HS_VS2_L['Carat'] = df_050_059_HS_VS2_L['Carat'].astype('float64')
                    df_050_059_HS_VS2_L['PPC'] = df_050_059_HS_VS2_L['PPC'].astype('float64')
                    df_050_059_HS_VS2_L['Total'] = df_050_059_HS_VS2_L['Total'].astype('float64')
                    df_050_059_HS_VS2_L['Total'] = df_050_059_HS_VS2_L['Carat'] * df_050_059_HS_VS2_L['PPC']


                elif i=="L" and j == "SI1" and k == "HS":
                    df_050_059_HS_SI1_L = pd.DataFrame()
                    df_050_059_HS_SI1_L ['Wt Range'] = None
                    df_050_059_HS_SI1_L  = df_050_059_HS_SI1_L.assign(Company=None)
                    df_050_059_HS_SI1_L  = df_050_059_HS_SI1_L.assign(Shape=None)
                    df_050_059_HS_SI1_L  = df_050_059_HS_SI1_L.assign(Carat=None)
                    df_050_059_HS_SI1_L  = df_050_059_HS_SI1_L.assign(Color=None)
                    df_050_059_HS_SI1_L  = df_050_059_HS_SI1_L.assign(Clarity=None)
                    df_050_059_HS_SI1_L  = df_050_059_HS_SI1_L.assign(Cut=None)
                    df_050_059_HS_SI1_L  = df_050_059_HS_SI1_L.assign(Polish=None)
                    df_050_059_HS_SI1_L  = df_050_059_HS_SI1_L.assign(Symmetry=None)
                    df_050_059_HS_SI1_L  = df_050_059_HS_SI1_L.assign(Ratio=None)
                    df_050_059_HS_SI1_L  = df_050_059_HS_SI1_L.assign(PPC=None)
                    df_050_059_HS_SI1_L  = df_050_059_HS_SI1_L.assign(Total=None)
                    df_050_059_HS_SI1_L ['Wt Range'] = listwtrange
                    df_050_059_HS_SI1_L ['Company'] = listcom
                    df_050_059_HS_SI1_L ['Shape'] = listshap
                    df_050_059_HS_SI1_L ['Carat'] = listcar
                    df_050_059_HS_SI1_L ['Color'] = listcol
                    df_050_059_HS_SI1_L ['Clarity'] = listclar
                    df_050_059_HS_SI1_L ['Cut'] = listcut
                    df_050_059_HS_SI1_L ['Polish'] = listpol
                    df_050_059_HS_SI1_L ['Symmetry'] = listsym
                    df_050_059_HS_SI1_L ['Ratio'] = listrat
                    df_050_059_HS_SI1_L ['PPC'] = listdesc
                    df_050_059_HS_SI1_L ['Total'] = listtotal
                    df_050_059_HS_SI1_L['Carat'] = df_050_059_HS_SI1_L['Carat'].astype('float64')
                    df_050_059_HS_SI1_L['PPC'] = df_050_059_HS_SI1_L['PPC'].astype('float64')
                    df_050_059_HS_SI1_L['Total'] = df_050_059_HS_SI1_L['Total'].astype('float64')
                    df_050_059_HS_SI1_L['Total'] = df_050_059_HS_SI1_L['Carat'] * df_050_059_HS_SI1_L['PPC']


                elif i=="L" and j == "SI2" and k == "HS":
                    df_050_059_HS_SI2_L = pd.DataFrame()
                    df_050_059_HS_SI2_L ['Wt Range'] = None
                    df_050_059_HS_SI2_L  = df_050_059_HS_SI2_L.assign(Company=None)
                    df_050_059_HS_SI2_L  = df_050_059_HS_SI2_L.assign(Shape=None)
                    df_050_059_HS_SI2_L  = df_050_059_HS_SI2_L.assign(Carat=None)
                    df_050_059_HS_SI2_L  = df_050_059_HS_SI2_L.assign(Color=None)
                    df_050_059_HS_SI2_L  = df_050_059_HS_SI2_L.assign(Clarity=None)
                    df_050_059_HS_SI2_L  = df_050_059_HS_SI2_L.assign(Cut=None)
                    df_050_059_HS_SI2_L  = df_050_059_HS_SI2_L.assign(Polish=None)
                    df_050_059_HS_SI2_L  = df_050_059_HS_SI2_L.assign(Symmetry=None)
                    df_050_059_HS_SI2_L  = df_050_059_HS_SI2_L.assign(Ratio=None)
                    df_050_059_HS_SI2_L  = df_050_059_HS_SI2_L.assign(PPC=None)
                    df_050_059_HS_SI2_L  = df_050_059_HS_SI2_L.assign(Total=None)
                    df_050_059_HS_SI2_L ['Wt Range'] = listwtrange
                    df_050_059_HS_SI2_L ['Company'] = listcom
                    df_050_059_HS_SI2_L ['Shape'] = listshap
                    df_050_059_HS_SI2_L ['Carat'] = listcar
                    df_050_059_HS_SI2_L ['Color'] = listcol
                    df_050_059_HS_SI2_L ['Clarity'] = listclar
                    df_050_059_HS_SI2_L ['Cut'] = listcut
                    df_050_059_HS_SI2_L ['Polish'] = listpol
                    df_050_059_HS_SI2_L ['Symmetry'] = listsym
                    df_050_059_HS_SI2_L ['Ratio'] = listrat
                    df_050_059_HS_SI2_L ['PPC'] = listdesc
                    df_050_059_HS_SI2_L ['Total'] = listtotal
                    df_050_059_HS_SI2_L['Carat'] = df_050_059_HS_SI2_L['Carat'].astype('float64')
                    df_050_059_HS_SI2_L['PPC'] = df_050_059_HS_SI2_L['PPC'].astype('float64')
                    df_050_059_HS_SI2_L['Total'] = df_050_059_HS_SI2_L['Total'].astype('float64')
                    df_050_059_HS_SI2_L['Total'] = df_050_059_HS_SI2_L['Carat'] * df_050_059_HS_SI2_L['PPC']


                elif i=="L" and j == "I1" and k == "HS":
                    df_050_059_HS_I1_L = pd.DataFrame()
                    df_050_059_HS_I1_L ['Wt Range'] = None
                    df_050_059_HS_I1_L  = df_050_059_HS_I1_L.assign(Company=None)
                    df_050_059_HS_I1_L  = df_050_059_HS_I1_L.assign(Shape=None)
                    df_050_059_HS_I1_L  = df_050_059_HS_I1_L.assign(Carat=None)
                    df_050_059_HS_I1_L  = df_050_059_HS_I1_L.assign(Color=None)
                    df_050_059_HS_I1_L  = df_050_059_HS_I1_L.assign(Clarity=None)
                    df_050_059_HS_I1_L  = df_050_059_HS_I1_L.assign(Cut=None)
                    df_050_059_HS_I1_L  = df_050_059_HS_I1_L.assign(Polish=None)
                    df_050_059_HS_I1_L  = df_050_059_HS_I1_L.assign(Symmetry=None)
                    df_050_059_HS_I1_L  = df_050_059_HS_I1_L.assign(Ratio=None)
                    df_050_059_HS_I1_L  = df_050_059_HS_I1_L.assign(PPC=None)
                    df_050_059_HS_I1_L  = df_050_059_HS_I1_L.assign(Total=None)
                    df_050_059_HS_I1_L ['Wt Range'] = listwtrange
                    df_050_059_HS_I1_L ['Company'] = listcom
                    df_050_059_HS_I1_L ['Shape'] = listshap
                    df_050_059_HS_I1_L ['Carat'] = listcar
                    df_050_059_HS_I1_L ['Color'] = listcol
                    df_050_059_HS_I1_L ['Clarity'] = listclar
                    df_050_059_HS_I1_L ['Cut'] = listcut
                    df_050_059_HS_I1_L ['Polish'] = listpol
                    df_050_059_HS_I1_L ['Symmetry'] = listsym
                    df_050_059_HS_I1_L ['Ratio'] = listrat
                    df_050_059_HS_I1_L ['PPC'] = listdesc
                    df_050_059_HS_I1_L ['Total'] = listtotal
                    df_050_059_HS_I1_L['Carat'] = df_050_059_HS_I1_L['Carat'].astype('float64')
                    df_050_059_HS_I1_L['PPC'] = df_050_059_HS_I1_L['PPC'].astype('float64')
                    df_050_059_HS_I1_L['Total'] = df_050_059_HS_I1_L['Total'].astype('float64')
                    df_050_059_HS_I1_L['Total'] = df_050_059_HS_I1_L['Carat'] * df_050_059_HS_I1_L['PPC']


                else:
                    df_050_059_HS_I2_L = pd.DataFrame()
                    df_050_059_HS_I2_L ['Wt Range'] = None
                    df_050_059_HS_I2_L  = df_050_059_HS_I2_L.assign(Company=None)
                    df_050_059_HS_I2_L  = df_050_059_HS_I2_L.assign(Shape=None)
                    df_050_059_HS_I2_L  = df_050_059_HS_I2_L.assign(Carat=None)
                    df_050_059_HS_I2_L  = df_050_059_HS_I2_L.assign(Color=None)
                    df_050_059_HS_I2_L  = df_050_059_HS_I2_L.assign(Clarity=None)
                    df_050_059_HS_I2_L  = df_050_059_HS_I2_L.assign(Cut=None)
                    df_050_059_HS_I2_L  = df_050_059_HS_I2_L.assign(Polish=None)
                    df_050_059_HS_I2_L  = df_050_059_HS_I2_L.assign(Symmetry=None)
                    df_050_059_HS_I2_L  = df_050_059_HS_I2_L.assign(Ratio=None)
                    df_050_059_HS_I2_L  = df_050_059_HS_I2_L.assign(PPC=None)
                    df_050_059_HS_I2_L  = df_050_059_HS_I2_L.assign(Total=None)
                    df_050_059_HS_I2_L ['Wt Range'] = listwtrange
                    df_050_059_HS_I2_L ['Company'] = listcom
                    df_050_059_HS_I2_L ['Shape'] = listshap
                    df_050_059_HS_I2_L ['Carat'] = listcar
                    df_050_059_HS_I2_L ['Color'] = listcol
                    df_050_059_HS_I2_L ['Clarity'] = listclar
                    df_050_059_HS_I2_L ['Cut'] = listcut
                    df_050_059_HS_I2_L ['Polish'] = listpol
                    df_050_059_HS_I2_L ['Symmetry'] = listsym
                    df_050_059_HS_I2_L ['Ratio'] = listrat
                    df_050_059_HS_I2_L ['PPC'] = listdesc
                    df_050_059_HS_I2_L ['Total'] = listtotal
                    df_050_059_HS_I2_L['Carat'] = df_050_059_HS_I2_L['Carat'].astype('float64')
                    df_050_059_HS_I2_L['PPC'] = df_050_059_HS_I2_L['PPC'].astype('float64')
                    df_050_059_HS_I2_L['Total'] = df_050_059_HS_I2_L['Total'].astype('float64')
                    df_050_059_HS_I2_L['Total'] = df_050_059_HS_I2_L['Carat'] * df_050_059_HS_I2_L['PPC']

                    
                print("finish part 2")

                l=driver.find_element(By.XPATH, '//*[@id="inventory"]/div/div/div[1]' )
                driver.execute_script("arguments[0].scrollIntoView(true);", l)
                time.sleep(0.4)
                WebDriverWait(driver,20).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="inventory"]/div/div/div[3]/div[1]/div/div[3]/div[2]/div/button'))).click()
                time.sleep(10)
                pass

            except:
                print("df_100_109_",k,"_",i,"_",j," tiene",res)
                WebDriverWait(driver,20).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="inventory"]/div/div/div[3]/div[1]/div/div[3]/div[2]/div/button'))).click()
                time.sleep(10)
                continue
                
            if k=="MQ" and i == "L" and j == "I2":
                break            

            
driver.quit()
print("finish loop")
# Out:
# df_050_059_ BR _ IF _ D ,
# finish part 1
# finish part 2
# df_050_059_ BR _ VVS1 _ D ,
# finish part 1
# finish part 2
# df_050_059_ BR _ VVS2 _ D ,
# finish part 1
# finish part 2
# df_050_059_ BR _ VS1 _ D ,
# finish part 1
# finish part 2
# df_050_059_ BR _ VS2 _ D ,
# finish part 1
# finish part 2
# df_050_059_ BR _ SI1 _ D ,
# finish part 1
# finish part 2
# df_050_059_ BR _ SI2 _ D ,
# finish part 1
# finish part 2
# df_050_059_ BR _ I1 _ D ,
# finish part 1
# finish part 2
# df_050_059_ BR _ IF _ E ,
# finish part 1
# finish part 2
# df_050_059_ BR _ VVS1 _ E ,
# finish part 1
# finish part 2
# df_050_059_ BR _ VVS2 _ E ,
# finish part 1
# finish part 2
# df_050_059_ BR _ VS1 _ E ,
# finish part 1
# finish part 2
# df_050_059_ BR _ VS2 _ E ,
# finish part 1
# finish part 2
# df_050_059_ BR _ SI1 _ E ,
# finish part 1
# finish part 2
# df_050_059_ BR _ SI2 _ E ,
# finish part 1
# finish part 2
# df_050_059_ BR _ I1 _ E ,
# finish part 1
# finish part 2
# ...

# %%
df_050_059 = pd.concat([df_050_059_BR_IF_D,df_050_059_BR_VVS1_D,df_050_059_BR_VVS2_D,df_050_059_BR_VS1_D,df_050_059_BR_VS2_D,df_050_059_BR_SI1_D,df_050_059_BR_SI2_D,df_050_059_BR_I1_D,df_050_059_BR_IF_E,df_050_059_BR_VVS1_E,df_050_059_BR_VVS2_E,df_050_059_BR_VS1_E,df_050_059_BR_VS2_E,df_050_059_BR_SI1_E,df_050_059_BR_SI2_E,df_050_059_BR_I1_E,df_050_059_BR_IF_F,df_050_059_BR_VVS1_F,df_050_059_BR_VVS2_F,df_050_059_BR_VS1_F,df_050_059_BR_VS2_F,df_050_059_BR_SI1_F,df_050_059_BR_SI2_F,df_050_059_BR_I1_F,df_050_059_BR_IF_G,df_050_059_BR_VVS1_G,df_050_059_BR_VVS2_G,df_050_059_BR_VS1_G,df_050_059_BR_VS2_G,df_050_059_BR_SI1_G,df_050_059_BR_SI2_G,df_050_059_BR_I1_G,df_050_059_BR_IF_H,df_050_059_BR_VVS1_H])

df_050_059.to_csv("050_059_Dmarket.csv")

print("end")
# Out:
# end
